# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2_without_edges_check import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349506596**********
# Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27572 pieces after mesh split
# There were 6626 pieces found after size threshold
# max_index = 0
# max_face_len = 24286914
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6bcb73d94cc0> in <module>
#       1 start = time.time()
# ----> 2 ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-9-92169d2f84a3> in make(self, key)
#      55                                                          load_meshes_flag = False,
#      56                                                      save_meshes_flag = False,
# ---> 57                                                         pymeshfix_flag = False
#      58                                                        )
#      59         else:
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2_without_edges_check.py in stitch_neuron(segment_id, vertices, faces, **kwargs)
#    1492         main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
#    1493                                     significance_threshold=outisde_size_threshold,
# -> 1494                                         n_sample_points=n_sample_points)
#    1495
#    1496     else: #load them from a saved location
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2_without_edges_check.py in filter_mesh_significant_outside_pieces(unfiltered_mesh, significance_threshold, n_sample_points)
#      74
#      75             start_time = time.time()
# ---> 76             signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
#      77             #print(f"Total time = {time.time() - start_time}")
#      78
#
# /usr/local/lib/python3.6/dist-packages/trimesh/proximity.py in signed_distance(mesh, points)
#     232         return distance
#     233
# --> 234     inside = mesh.ray.contains_points(points[nonzero])
#     235     sign = (inside.astype(int) * 2) - 1
#     236
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in contains_points(self, points)
#     138         """
#     139
# --> 140         return contains_points(self, points)
#     141
#     142
#
# /usr/local/lib/python3.6/dist-packages/trimesh/constants.py in timed(*args, **kwargs)
#     126     def timed(*args, **kwargs):
#     127         tic = time_function()
# --> 128         result = method(*args, **kwargs)
#     129         log.debug('%s executed in %.4f seconds.',
#     130                   method.__name__,
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_util.py in contains_points(intersector, points, check_direction)
#      66         np.vstack(
#      67             (ray_directions,
# ---> 68              -ray_directions)))
#      69
#      70     # if we hit nothing in either direction just return with no hits
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in intersects_location(self, ray_origins, ray_directions, **kwargs)
#      96              ray_directions=ray_directions,
#      97              return_locations=True,
# ---> 98              **kwargs)
#      99         return locations, index_ray, index_tri
#     100
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in intersects_id(self, ray_origins, ray_directions, return_locations, multiple_hits, **kwargs)
#      55                                       tree=self.mesh.triangles_tree,
#      56                                       multiple_hits=multiple_hits,
# ---> 57                                       triangles_normal=self.mesh.face_normals)
#      58         if return_locations:
#      59             if len(index_tri) == 0:
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in ray_triangle_id(triangles, ray_origins, ray_directions, triangles_normal, tree, multiple_hits)
#     219     # triangle candidates
#     220     barycentric = triangles_mod.points_to_barycentric(
# --> 221         triangle_candidates[valid], location)
#     222
#     223     # the plane intersection is inside the triangle if all barycentric coordinates
#
# /usr/local/lib/python3.6/dist-packages/trimesh/triangles.py in points_to_barycentric(triangles, points, method)
#     523     if method == 'cross':
#     524         return method_cross()
# --> 525     return method_cramer()
#     526
#     527
#
# /usr/local/lib/python3.6/dist-packages/trimesh/triangles.py in method_cramer()
#     497         dot01 = util.diagonal_dot(edge_vectors[:, 0], edge_vectors[:, 1])
#     498         dot02 = util.diagonal_dot(edge_vectors[:, 0], w)
# --> 499         dot11 = util.diagonal_dot(edge_vectors[:, 1], edge_vectors[:, 1])
#     500         dot12 = util.diagonal_dot(edge_vectors[:, 1], w)
#     501
#
# /usr/local/lib/python3.6/dist-packages/trimesh/util.py in diagonal_dot(a, b)
#     569     # 3x faster than (a * b).sum(axis=1)
#     570     # avoiding np.ones saves 5-10% sometimes
# --> 571     result = np.dot(a * b, [1.0] * a.shape[1])
#     572     return result
#     573
#
# KeyboardInterrupt:

# %%
(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
schema.jobs
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid       connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-------+ +------------+ +------------+
# __component_au 4c6e641417ba4c reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   25316     67852          2019-06-09 15:
# __decimation35 07b959497981d9 reserved     =BLOB=                    =BLOB=     celiib@10.70.0 Brendans-MacBo 32938     65951          2019-06-09 05:
# __excitatory_s 60ab82cf1f443b error        =BLOB=     RuntimeError:  =BLOB=     celiib@10.28.0 20812b49dcd8   20195     32600          2019-06-09 04:
# __excitatory_s a53dd4ad1911ef error        =BLOB=     Exception: Too =BLOB=     celiib@10.28.0 20812b49dcd8   19507     28210          2019-06-07 07:
#  (4 tuples)

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
