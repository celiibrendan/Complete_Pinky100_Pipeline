# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473821**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1260 pieces after mesh split
# There were 82 pieces found after size threshold
# max_index = 0
# max_face_len = 1469417
# Total time for Mesh Cleansing: 205.17762994766235
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9833381850546906% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349475529**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1076 pieces after mesh split
# There were 70 pieces found after size threshold
# max_index = 0
# max_face_len = 285892
# Total time for Mesh Cleansing: 19.170328855514526
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.964469813510377% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349475540**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 339 pieces after mesh split
# There were 16 pieces found after size threshold
# max_index = 0
# max_face_len = 1211731
# Total time for Mesh Cleansing: 59.71213459968567
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9975763064194126% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349478054**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478054_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 6.13948392868042
# Number of outside child meshes =  29
# Main mesh and outside child meshes make up 0.9046354538942536% of original mesh
#  face length 2303088 using optimized facets with 3 neighbors
# Filtering edges by size finished: 74.61769509315491, facet # = 120508
# Filtering by convexity and getting centers took: 92.26597881317139, facet # = 25446
# Finished facets for main mesh: 174.9448459148407 with facet length = 25446
# Finished 25446 facets for main mesh: 174.9450876712799
# Filtering edges by size finished: 0.04532790184020996, facet # = 9
# Filtering by convexity and getting centers took: 0.02292013168334961, facet # = 8
# Filtering edges by size finished: 0.5319170951843262, facet # = 1613
# Filtering by convexity and getting centers took: 0.9558708667755127, facet # = 519
# Filtering edges by size finished: 0.49970149993896484, facet # = 1254
# Filtering by convexity and getting centers took: 0.7193655967712402, facet # = 400
# Filtering edges by size finished: 0.004349470138549805, facet # = 18
# Filtering by convexity and getting centers took: 0.008551836013793945, facet # = 9
# Filtering edges by size finished: 0.04622459411621094, facet # = 148
# Filtering by convexity and getting centers took: 0.04661083221435547, facet # = 49
# Filtering edges by size finished: 0.011477231979370117, facet # = 43
# Filtering by convexity and getting centers took: 0.01963639259338379, facet # = 16
# Filtering edges by size finished: 0.009708881378173828, facet # = 11
# Filtering by convexity and getting centers took: 0.008035421371459961, facet # = 9
# Filtering edges by size finished: 0.0036492347717285156, facet # = 11
# Filtering by convexity and getting centers took: 0.005781412124633789, facet # = 7
# Filtering edges by size finished: 0.0033414363861083984, facet # = 12
# Filtering by convexity and getting centers took: 0.006525754928588867, facet # = 10
# Filtering edges by size finished: 0.013389825820922852, facet # = 38
# Filtering by convexity and getting centers took: 0.019775390625, facet # = 26
# Filtering edges by size finished: 0.004709482192993164, facet # = 10
# Filtering by convexity and getting centers took: 0.004130363464355469, facet # = 4
# Filtering edges by size finished: 0.037029266357421875, facet # = 121
# Filtering by convexity and getting centers took: 0.11194586753845215, facet # = 46
# Filtering edges by size finished: 0.002101421356201172, facet # = 8
# Filtering by convexity and getting centers took: 0.009759902954101562, facet # = 5
# Filtering edges by size finished: 0.01628899574279785, facet # = 5
# Filtering by convexity and getting centers took: 0.003942728042602539, facet # = 5
# Filtering edges by size finished: 0.004252433776855469, facet # = 5
# Filtering by convexity and getting centers took: 0.004093170166015625, facet # = 3
# Filtering edges by size finished: 0.08237934112548828, facet # = 119
# Filtering by convexity and getting centers took: 0.0639951229095459, facet # = 38
# Filtering edges by size finished: 0.01719188690185547, facet # = 28
# Filtering by convexity and getting centers took: 0.023647069931030273, facet # = 19
# Filtering edges by size finished: 0.002665996551513672, facet # = 7
# Filtering by convexity and getting centers took: 0.005651712417602539, facet # = 7
# Filtering edges by size finished: 0.002111673355102539, facet # = 7
# Filtering by convexity and getting centers took: 0.005019664764404297, facet # = 6
# Filtering edges by size finished: 0.02737283706665039, facet # = 21
# Filtering by convexity and getting centers took: 0.02365589141845703, facet # = 7
# Filtering edges by size finished: 0.0039141178131103516, facet # = 9
# Filtering by convexity and getting centers took: 0.0059816837310791016, facet # = 9
# Filtering edges by size finished: 0.006216526031494141, facet # = 26
# Filtering by convexity and getting centers took: 0.013025283813476562, facet # = 13
# Filtering edges by size finished: 0.009504556655883789, facet # = 44
# Filtering by convexity and getting centers took: 0.020522594451904297, facet # = 21
# Filtering edges by size finished: 0.004526853561401367, facet # = 17
# Filtering by convexity and getting centers took: 0.01042938232421875, facet # = 6
# Filtering edges by size finished: 0.0034379959106445312, facet # = 12
# Filtering by convexity and getting centers took: 0.0076525211334228516, facet # = 4
# Filtering edges by size finished: 0.0019683837890625, facet # = 6
# Filtering by convexity and getting centers took: 0.004618167877197266, facet # = 6
# Filtering edges by size finished: 0.02320551872253418, facet # = 84
# Filtering by convexity and getting centers took: 0.04970908164978027, facet # = 33
# Filtering edges by size finished: 0.008793354034423828, facet # = 15
# Filtering by convexity and getting centers took: 0.012521982192993164, facet # = 15
# Filtering edges by size finished: 0.0036766529083251953, facet # = 8
# Filtering by convexity and getting centers took: 0.006394863128662109, facet # = 8
# Total time for facets: 178.88580322265625
# Zero faceted faces = []
# Starting Child 0
# 8 25446
# Done distance matrix: 0.013533353805541992
# Child 0 There were no points close enough
# Starting Child 1
# 519 25446
# Done distance matrix: 0.8360087871551514
# Done Generating final pairs: 0.8690052032470703
# best_stitch_pair = [ 353 3462]
# best_stitch_pair_size = 169993.47664729314
# best_stitch_pair_distance = 1225.8840121425328
# best_stitch_pair_size_ratio = 0.452832016245919
# Starting Child 2
# 400 25446
# Done distance matrix: 0.5586831569671631
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 9 25446
# Done distance matrix: 0.019273042678833008
# Child 3 There were no points close enough
# Starting Child 4
# 49 25446
# Done distance matrix: 0.055094003677368164
# Child 4 There were no points close enough
# Starting Child 5
# 16 25446
# Done distance matrix: 0.017316102981567383
# Done Generating final pairs: 0.041681528091430664
# best_stitch_pair = [    3 15909]
# best_stitch_pair_size = 61389.7069664498
# best_stitch_pair_distance = 1486.3453984045675
# best_stitch_pair_size_ratio = 0.8870488806094518
# Starting Child 6
# 9 25446
# Done distance matrix: 0.011281251907348633
# Done Generating final pairs: 0.041190147399902344
# best_stitch_pair = [   3 6947]
# best_stitch_pair_size = 95024.90233480904
# best_stitch_pair_distance = 759.5264133009296
# best_stitch_pair_size_ratio = 0.5759485002784783
# Starting Child 7
# 7 25446
# Done distance matrix: 0.010247945785522461
# Child 7 There were no points close enough
# Starting Child 8
# 10 25446
# Done distance matrix: 0.014324426651000977
# Child 8 There were no points close enough
# Starting Child 9
# 26 25446
# Done distance matrix: 0.0294950008392334
# Done Generating final pairs: 0.06103372573852539
# best_stitch_pair = [  22 8007]
# best_stitch_pair_size = 231653.763838028
# best_stitch_pair_distance = 1481.367041677378
# best_stitch_pair_size_ratio = 0.9914343951139618
# Starting Child 10
# 4 25446
# Done distance matrix: 0.00578761100769043
# Child 10 There were no points close enough
# Starting Child 11
# 46 25446
# Done distance matrix: 0.09957623481750488
# Child 11 There were no points close enough
# Starting Child 12
# 5 25446
# Done distance matrix: 0.0066072940826416016
# Child 12 There were no points close enough
# Starting Child 13
# 5 25446
# Done distance matrix: 0.0064868927001953125
# Done Generating final pairs: 0.0501713752746582
# best_stitch_pair = [   4 4133]
# best_stitch_pair_size = 246712.2554280538
# best_stitch_pair_distance = 960.3472613474148
# best_stitch_pair_size_ratio = 0.1507234395998216
# Starting Child 14
# 3 25446
# Done distance matrix: 0.004401683807373047
# Done Generating final pairs: 0.032863616943359375
# best_stitch_pair = [   0 4140]
# best_stitch_pair_size = 177375.12063391347
# best_stitch_pair_distance = 530.9847707146062
# best_stitch_pair_size_ratio = 0.17759812404941705
# Starting Child 15
# 38 25446
# Done distance matrix: 0.0409848690032959
# Child 15 There were no points close enough
# Starting Child 16
# 19 25446
# Done distance matrix: 0.020970821380615234
# Child 16 There were no points close enough
# Starting Child 17
# 7 25446
# Done distance matrix: 0.008546113967895508
# Child 17 There were no points close enough
# Starting Child 18
# 6 25446
# Done distance matrix: 0.007435798645019531
# Child 18 There were no points close enough
# Starting Child 19
# 7 25446
# Done distance matrix: 0.008581161499023438
# Done Generating final pairs: 0.031890869140625
# best_stitch_pair = [   6 6678]
# best_stitch_pair_size = 89911.85038002481
# best_stitch_pair_distance = 1182.4866938437149
# best_stitch_pair_size_ratio = 0.8173217727464149
# Starting Child 20
# 9 25446
# Done distance matrix: 0.008893966674804688
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 13 25446
# Done distance matrix: 0.030896663665771484
# Done Generating final pairs: 0.08165550231933594
# best_stitch_pair = [   6 6678]
# best_stitch_pair_size = 172065.38594365818
# best_stitch_pair_distance = 1020.2584801079935
# best_stitch_pair_size_ratio = 0.3072050754149836
# Starting Child 22
# 21 25446
# Done distance matrix: 0.01723313331604004
# Done Generating final pairs: 0.038247108459472656
# best_stitch_pair = [  2 197]
# best_stitch_pair_size = 167885.43720224703
# best_stitch_pair_distance = 1500.5012142393048
# best_stitch_pair_size_ratio = 0.5574803064278915
# Starting Child 23
# 6 25446
# Done distance matrix: 0.007585763931274414
# Done Generating final pairs: 0.03188276290893555
# best_stitch_pair = [    1 11294]
# best_stitch_pair_size = 44844.6429212974
# best_stitch_pair_distance = 1979.9268829801135
# best_stitch_pair_size_ratio = 0.6013248831820682
# Starting Child 24
# 4 25446
# Done distance matrix: 0.005471944808959961
# Done Generating final pairs: 0.028996944427490234
# best_stitch_pair = [   1 9716]
# best_stitch_pair_size = 33469.015234473605
# best_stitch_pair_distance = 1259.302893879102
# best_stitch_pair_size_ratio = 0.3553901971971781
# Starting Child 25
# 6 25446
# Done distance matrix: 0.0072612762451171875
# Child 25 There were no points close enough
# Starting Child 26
# 33 25446
# Done distance matrix: 0.03751730918884277
# Child 26 There were no points close enough
# Starting Child 27
# 15 25446
# Done distance matrix: 0.016223907470703125
# Child 27 There were no points close enough
# Starting Child 28
# 8 25446
# Done distance matrix: 0.010483741760253906
# Child 28 There were no points close enough
# repeat_main_facets = [6678]
# child_mesh_double_indexes = [19, 21]
# min_child = 21, max_ratio = 1020.2584801079935
# child_meshes_stitch_facets = {1: [353, 3462], 5: [3, 15909], 6: [3, 6947], 9: [22, 8007], 13: [4, 4133], 14: [0, 4140], 21: [6, 6678], 22: [2, 197], 23: [1, 11294], 24: [1, 9716]}
# ---Stitching child 1 with pair: [353, 3462]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 399810, starting edge 2nd facet= 1158174,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.044145822525024414
# returned from stitch mesh: 1.6707422733306885
# Finished stitching child 1 : 1.9102740287780762
# ---Stitching child 5 with pair: [3, 15909]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1001349, starting edge 2nd facet= 1162185,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.7894973754882812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.054167747497558594
# returned from stitch mesh: 2.021131992340088
# Finished stitching child 5 : 2.2808635234832764
# ---Stitching child 6 with pair: [3, 6947]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 794361, starting edge 2nd facet= 1162382,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 4
# About to add faces
# Finished adding faces: 4.57763671875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1553797721862793
# returned from stitch mesh: 2.1176769733428955
# Finished stitching child 6 : 2.3576910495758057
# ---Stitching child 9 with pair: [22, 8007]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 552584, starting edge 2nd facet= 1162569,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.4332275390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.006867647171020508
# returned from stitch mesh: 2.3599746227264404
# Finished stitching child 9 : 2.662459373474121
# ---Stitching child 13 with pair: [4, 4133]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 283058, starting edge 2nd facet= 1162597,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.9087066650390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0334775447845459
# returned from stitch mesh: 2.3997373580932617
# Finished stitching child 13 : 2.806156635284424
# ---Stitching child 14 with pair: [0, 4140]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 178909, starting edge 2nd facet= 1162632,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.814697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.13901686668395996
# returned from stitch mesh: 2.6249301433563232
# Finished stitching child 14 : 2.952911138534546
# ---Stitching child 21 with pair: [6, 6678]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 851822, starting edge 2nd facet= 1162749,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.2901763916015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05577230453491211
# returned from stitch mesh: 1.5484354496002197
# Finished stitching child 21 : 1.898291826248169
# ---Stitching child 22 with pair: [2, 197]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1017651, starting edge 2nd facet= 1162781,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03503131866455078
# returned from stitch mesh: 2.4328219890594482
# Finished stitching child 22 : 2.918680429458618
# ---Stitching child 23 with pair: [1, 11294]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 912486, starting edge 2nd facet= 1162923,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07424259185791016
# returned from stitch mesh: 2.286748170852661
# Finished stitching child 23 : 2.8757483959198
# ---Stitching child 24 with pair: [1, 9716]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 342599, starting edge 2nd facet= 1162981,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11964559555053711
# returned from stitch mesh: 2.4617745876312256
# Finished stitching child 24 : 2.8808279037475586
# ***************Finished big stitching iteration: 29.172279596328735***************
# Starting Child 0
# 8 26048
# Done distance matrix: 0.013881206512451172
# Child 0 There were no points close enough
# Starting Child 2
# 400 26048
# Done distance matrix: 0.5951812267303467
# Done Generating final pairs: 0.6001870632171631
# best_stitch_pair = [  314 26040]
# best_stitch_pair_size = 27888.51072939884
# best_stitch_pair_distance = 915.0231333510445
# best_stitch_pair_size_ratio = 0.44839301991091846
# Starting Child 3
# 9 26048
# Done distance matrix: 0.018229246139526367
# Child 3 There were no points close enough
# Starting Child 4
# 49 26048
# Done distance matrix: 0.043599605560302734
# Done Generating final pairs: 0.046884775161743164
# best_stitch_pair = [   39 25962]
# best_stitch_pair_size = 51740.86379892178
# best_stitch_pair_distance = 1746.478718313861
# best_stitch_pair_size_ratio = 0.23655629559864116
# Starting Child 7
# 7 26048
# Done distance matrix: 0.011669397354125977
# Child 7 There were no points close enough
# Starting Child 8
# 10 26048
# Done distance matrix: 0.01563239097595215
# Child 8 There were no points close enough
# Starting Child 10
# 4 26048
# Done distance matrix: 0.007673978805541992
# Child 10 There were no points close enough
# Starting Child 11
# 46 26048
# Done distance matrix: 0.05066490173339844
# Child 11 There were no points close enough
# Starting Child 12
# 5 26048
# Done distance matrix: 0.00714421272277832
# Child 12 There were no points close enough
# Starting Child 15
# 38 26048
# Done distance matrix: 0.08419299125671387
# Child 15 There were no points close enough
# Starting Child 16
# 19 26048
# Done distance matrix: 0.021181344985961914
# Child 16 There were no points close enough
# Starting Child 17
# 7 26048
# Done distance matrix: 0.00875401496887207
# Child 17 There were no points close enough
# Starting Child 18
# 6 26048
# Done distance matrix: 0.0075223445892333984
# Child 18 There were no points close enough
# Starting Child 19
# 7 26048
# Done distance matrix: 0.008684873580932617
# Done Generating final pairs: 0.013469219207763672
# best_stitch_pair = [    3 26012]
# best_stitch_pair_size = 188603.92698342883
# best_stitch_pair_distance = 879.7697547885423
# best_stitch_pair_size_ratio = 0.27653959853047705
# Starting Child 20
# 9 26048
# Done distance matrix: 0.011043310165405273
# Done Generating final pairs: 0.01654338836669922
# best_stitch_pair = [    4 26018]
# best_stitch_pair_size = 121466.5406058069
# best_stitch_pair_distance = 1850.6322107730687
# best_stitch_pair_size_ratio = 0.18935506204416744
# Starting Child 25
# 6 26048
# Done distance matrix: 0.0075228214263916016
# Child 25 There were no points close enough
# Starting Child 26
# 33 26048
# Done distance matrix: 0.041686058044433594
# Child 26 There were no points close enough
# Starting Child 27
# 15 26048
# Done distance matrix: 0.01673150062561035
# Child 27 There were no points close enough
# Starting Child 28
# 8 26048
# Done distance matrix: 0.010132551193237305
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [314, 26040], 4: [39, 25962], 19: [3, 26012], 20: [4, 26018]}
# ---Stitching child 2 with pair: [314, 26040]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162898, starting edge 2nd facet= 1164618,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04917144775390625
# returned from stitch mesh: 1.9126863479614258
# Finished stitching child 2 : 2.311387538909912
# ---Stitching child 4 with pair: [39, 25962]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162308, starting edge 2nd facet= 1168474,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.15601563453674316
# returned from stitch mesh: 2.204845666885376
# Finished stitching child 4 : 2.559016704559326
# ---Stitching child 19 with pair: [3, 26012]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162725, starting edge 2nd facet= 1168785,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 4.0531158447265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11184334754943848
# returned from stitch mesh: 1.7881722450256348
# Finished stitching child 19 : 1.944915771484375
# ---Stitching child 20 with pair: [4, 26018]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162734, starting edge 2nd facet= 1168809,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 3.7670135498046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04030871391296387
# returned from stitch mesh: 2.001594066619873
# Finished stitching child 20 : 2.402203321456909
# ***************Finished big stitching iteration: 13.053655624389648***************
# Starting Child 0
# 8 26505
# Done distance matrix: 0.023019075393676758
# Done Generating final pairs: 0.03518104553222656
# best_stitch_pair = [    0 26497]
# best_stitch_pair_size = 240990.6248549464
# best_stitch_pair_distance = 1415.6207052805867
# best_stitch_pair_size_ratio = 0.6150855777318592
# Starting Child 3
# 9 26505
# Done distance matrix: 0.03765678405761719
# Child 3 There were no points close enough
# Starting Child 7
# 7 26505
# Done distance matrix: 0.009374618530273438
# Child 7 There were no points close enough
# Starting Child 8
# 10 26505
# Done distance matrix: 0.011688232421875
# Child 8 There were no points close enough
# Starting Child 10
# 4 26505
# Done distance matrix: 0.005088329315185547
# Child 10 There were no points close enough
# Starting Child 11
# 46 26505
# Done distance matrix: 0.047824859619140625
# Child 11 There were no points close enough
# Starting Child 12
# 5 26505
# Done distance matrix: 0.006343841552734375
# Done Generating final pairs: 0.008022546768188477
# best_stitch_pair = [    1 26459]
# best_stitch_pair_size = 34548.701543223695
# best_stitch_pair_distance = 1192.4874363273957
# best_stitch_pair_size_ratio = 0.6540754045262915
# Starting Child 15
# 38 26505
# Done distance matrix: 0.05103015899658203
# Child 15 There were no points close enough
# Starting Child 16
# 19 26505
# Done distance matrix: 0.044611215591430664
# Child 16 There were no points close enough
# Starting Child 17
# 7 26505
# Done distance matrix: 0.008871316909790039
# Child 17 There were no points close enough
# Starting Child 18
# 6 26505
# Done distance matrix: 0.008255243301391602
# Child 18 There were no points close enough
# Starting Child 25
# 6 26505
# Done distance matrix: 0.030770301818847656
# Child 25 There were no points close enough
# Starting Child 26
# 33 26505
# Done distance matrix: 0.10792112350463867
# Child 26 There were no points close enough
# Starting Child 27
# 15 26505
# Done distance matrix: 0.02563619613647461
# Child 27 There were no points close enough
# Starting Child 28
# 8 26505
# Done distance matrix: 0.010256052017211914
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 26497], 12: [1, 26459]}
# ---Stitching child 0 with pair: [0, 26497]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1168825, starting edge 2nd facet= 1168842,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 7.152557373046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04212784767150879
# returned from stitch mesh: 1.9115643501281738
# Finished stitching child 0 : 2.1663174629211426
# ---Stitching child 12 with pair: [1, 26459]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1168406, starting edge 2nd facet= 1168930,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.7404556274414062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.037789344787597656
# returned from stitch mesh: 1.7649390697479248
# Finished stitching child 12 : 2.08321475982666
# ***************Finished big stitching iteration: 7.189064264297485***************
# Starting Child 3
# 9 26514
# Done distance matrix: 0.03145956993103027
# Child 3 There were no points close enough
# Starting Child 7
# 7 26514
# Done distance matrix: 0.022490262985229492
# Child 7 There were no points close enough
# Starting Child 8
# 10 26514
# Done distance matrix: 0.02599334716796875
# Child 8 There were no points close enough
# Starting Child 10
# 4 26514
# Done distance matrix: 0.006823062896728516
# Child 10 There were no points close enough
# Starting Child 11
# 46 26514
# Done distance matrix: 0.07233929634094238
# Done Generating final pairs: 0.07752060890197754
# best_stitch_pair = [   23 26510]
# best_stitch_pair_size = 113447.81916082851
# best_stitch_pair_distance = 1078.3448518320308
# best_stitch_pair_size_ratio = 0.1592288358533423
# Starting Child 15
# 38 26514
# Done distance matrix: 0.03457355499267578
# Child 15 There were no points close enough
# Starting Child 16
# 19 26514
# Done distance matrix: 0.01669907569885254
# Child 16 There were no points close enough
# Starting Child 17
# 7 26514
# Done distance matrix: 0.008172035217285156
# Child 17 There were no points close enough
# Starting Child 18
# 6 26514
# Done distance matrix: 0.012171268463134766
# Child 18 There were no points close enough
# Starting Child 25
# 6 26514
# Done distance matrix: 0.008342742919921875
# Child 25 There were no points close enough
# Starting Child 26
# 33 26514
# Done distance matrix: 0.03850269317626953
# Child 26 There were no points close enough
# Starting Child 27
# 15 26514
# Done distance matrix: 0.017783641815185547
# Child 27 There were no points close enough
# Starting Child 28
# 8 26514
# Done distance matrix: 0.011212587356567383
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [23, 26510]}
# ---Stitching child 11 with pair: [23, 26510]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1168925, starting edge 2nd facet= 1169416,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.6226043701171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04049801826477051
# returned from stitch mesh: 1.9776556491851807
# Finished stitching child 11 : 2.3479559421539307
# ***************Finished big stitching iteration: 5.055310249328613***************
# Starting Child 3
# 9 26558
# Done distance matrix: 0.015422582626342773
# Child 3 There were no points close enough
# Starting Child 7
# 7 26558
# Done distance matrix: 0.011924505233764648
# Child 7 There were no points close enough
# Starting Child 8
# 10 26558
# Done distance matrix: 0.012746095657348633
# Child 8 There were no points close enough
# Starting Child 10
# 4 26558
# Done distance matrix: 0.004952907562255859
# Child 10 There were no points close enough
# Starting Child 15
# 38 26558
# Done distance matrix: 0.03451204299926758
# Child 15 There were no points close enough
# Starting Child 16
# 19 26558
# Done distance matrix: 0.04639840126037598
# Child 16 There were no points close enough
# Starting Child 17
# 7 26558
# Done distance matrix: 0.013988494873046875
# Child 17 There were no points close enough
# Starting Child 18
# 6 26558
# Done distance matrix: 0.00823664665222168
# Child 18 There were no points close enough
# Starting Child 25
# 6 26558
# Done distance matrix: 0.008307218551635742
# Child 25 There were no points close enough
# Starting Child 26
# 33 26558
# Done distance matrix: 0.02862381935119629
# Child 26 There were no points close enough
# Starting Child 27
# 15 26558
# Done distance matrix: 0.012686014175415039
# Child 27 There were no points close enough
# Starting Child 28
# 8 26558
# Done distance matrix: 0.008284807205200195
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 3
# 9 26558
# Done distance matrix: 0.008670806884765625
# Child 3 There were no points close enough
# Starting Child 7
# 7 26558
# Done distance matrix: 0.006903886795043945
# Child 7 There were no points close enough
# Starting Child 8
# 10 26558
# Done distance matrix: 0.010072946548461914
# Child 8 There were no points close enough
# Starting Child 10
# 4 26558
# Done distance matrix: 0.004167795181274414
# Child 10 There were no points close enough
# Starting Child 15
# 38 26558
# Done distance matrix: 0.032160282135009766
# Child 15 There were no points close enough
# Starting Child 16
# 19 26558
# Done distance matrix: 0.016678810119628906
# Child 16 There were no points close enough
# Starting Child 17
# 7 26558
# Done distance matrix: 0.009094715118408203
# Child 17 There were no points close enough
# Starting Child 18
# 6 26558
# Done distance matrix: 0.007953166961669922
# Child 18 There were no points close enough
# Starting Child 25
# 6 26558
# Done distance matrix: 0.007811546325683594
# Child 25 There were no points close enough
# Starting Child 26
# 33 26558
# Done distance matrix: 0.037508249282836914
# Child 26 There were no points close enough
# Starting Child 27
# 15 26558
# Done distance matrix: 0.016938209533691406
# Child 27 There were no points close enough
# Starting Child 28
# 8 26558
# Done distance matrix: 0.010456085205078125
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 3
# 9 26558
# Done distance matrix: 0.008695125579833984
# Child 3 There were no points close enough
# Starting Child 7
# 7 26558
# Done distance matrix: 0.0067691802978515625
# Child 7 There were no points close enough
# Starting Child 8
# 10 26558
# Done distance matrix: 0.009692907333374023
# Child 8 There were no points close enough
# Starting Child 10
# 4 26558
# Done distance matrix: 0.003918170928955078
# Child 10 There were no points close enough
# Starting Child 15
# 38 26558
# Done distance matrix: 0.03168344497680664
# Child 15 There were no points close enough
# Starting Child 16
# 19 26558
# Done distance matrix: 0.01608872413635254
# Child 16 There were no points close enough
# Starting Child 17
# 7 26558
# Done distance matrix: 0.006854057312011719
# Child 17 There were no points close enough
# Starting Child 18
# 6 26558
# Done distance matrix: 0.005815267562866211
# Child 18 There were no points close enough
# Starting Child 25
# 6 26558
# Done distance matrix: 0.005777835845947266
# Done Generating final pairs: 0.007241010665893555
# best_stitch_pair = [    1 26000]
# best_stitch_pair_size = 42393.46905701015
# best_stitch_pair_distance = 3341.4592779099266
# best_stitch_pair_size_ratio = 0.7548561981261109
# Starting Child 26
# 33 26558
# Done distance matrix: 0.0332489013671875
# Child 26 There were no points close enough
# Starting Child 27
# 15 26558
# Done distance matrix: 0.012787818908691406
# Child 27 There were no points close enough
# Starting Child 28
# 8 26558
# Done distance matrix: 0.00845479965209961
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {25: [1, 26000]}
# ---Stitching child 25 with pair: [1, 26000]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162497, starting edge 2nd facet= 1169454,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02302718162536621
# returned from stitch mesh: 3.0237135887145996
# Finished stitching child 25 : 3.5057923793792725
# ***************Finished big stitching iteration: 4.05247163772583***************
# Starting Child 3
# 9 26562
# Done distance matrix: 0.012324094772338867
# Child 3 There were no points close enough
# Starting Child 7
# 7 26562
# Done distance matrix: 0.009580850601196289
# Child 7 There were no points close enough
# Starting Child 8
# 10 26562
# Done distance matrix: 0.012740135192871094
# Child 8 There were no points close enough
# Starting Child 10
# 4 26562
# Done distance matrix: 0.005140781402587891
# Child 10 There were no points close enough
# Starting Child 15
# 38 26562
# Done distance matrix: 0.03876304626464844
# Child 15 There were no points close enough
# Starting Child 16
# 19 26562
# Done distance matrix: 0.12463545799255371
# Child 16 There were no points close enough
# Starting Child 17
# 7 26562
# Done distance matrix: 0.00916743278503418
# Child 17 There were no points close enough
# Starting Child 18
# 6 26562
# Done distance matrix: 0.008258342742919922
# Child 18 There were no points close enough
# Starting Child 26
# 33 26562
# Done distance matrix: 0.03754067420959473
# Child 26 There were no points close enough
# Starting Child 27
# 15 26562
# Done distance matrix: 0.02623581886291504
# Child 27 There were no points close enough
# Starting Child 28
# 8 26562
# Done distance matrix: 0.010337591171264648
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 3
# 9 26562
# Done distance matrix: 0.01118159294128418
# Child 3 There were no points close enough
# Starting Child 7
# 7 26562
# Done distance matrix: 0.008968591690063477
# Done Generating final pairs: 0.011397361755371094
# best_stitch_pair = [    4 26019]
# best_stitch_pair_size = 54640.20181157165
# best_stitch_pair_distance = 3903.711974420613
# best_stitch_pair_size_ratio = 0.1736482358983781
# Starting Child 8
# 10 26562
# Done distance matrix: 0.022704601287841797
# Child 8 There were no points close enough
# Starting Child 10
# 4 26562
# Done distance matrix: 0.03309321403503418
# Done Generating final pairs: 0.0405120849609375
# best_stitch_pair = [    0 26002]
# best_stitch_pair_size = 15730.111960515103
# best_stitch_pair_distance = 3587.4977483177613
# best_stitch_pair_size_ratio = 0.6589033478409047
# Starting Child 15
# 38 26562
# Done distance matrix: 0.040348052978515625
# Child 15 There were no points close enough
# Starting Child 16
# 19 26562
# Done distance matrix: 0.020969152450561523
# Child 16 There were no points close enough
# Starting Child 17
# 7 26562
# Done distance matrix: 0.009024620056152344
# Child 17 There were no points close enough
# Starting Child 18
# 6 26562
# Done distance matrix: 0.007749080657958984
# Child 18 There were no points close enough
# Starting Child 26
# 33 26562
# Done distance matrix: 0.0334014892578125
# Child 26 There were no points close enough
# Starting Child 27
# 15 26562
# Done distance matrix: 0.01279306411743164
# Child 27 There were no points close enough
# Starting Child 28
# 8 26562
# Done distance matrix: 0.00953054428100586
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {7: [4, 26019], 10: [0, 26002]}
# ---Stitching child 7 with pair: [4, 26019]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162847, starting edge 2nd facet= 1169508,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03496098518371582
# returned from stitch mesh: 1.8085718154907227
# Finished stitching child 7 : 2.0538289546966553
# ---Stitching child 10 with pair: [0, 26002]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1162599, starting edge 2nd facet= 1169562,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05187678337097168
# returned from stitch mesh: 2.452671527862549
# Finished stitching child 10 : 2.6830334663391113
# ***************Finished big stitching iteration: 5.6665403842926025***************
# Starting Child 3
# 9 26569
# Done distance matrix: 0.024968624114990234
# Done Generating final pairs: 0.03926849365234375
# best_stitch_pair = [    8 26563]
# best_stitch_pair_size = 44395.707733967545
# best_stitch_pair_distance = 1790.213050803738
# best_stitch_pair_size_ratio = 0.645823647265499
# Starting Child 8
# 10 26569
# Done distance matrix: 0.042624711990356445
# Done Generating final pairs: 0.10919690132141113
# best_stitch_pair = [    0 26563]
# best_stitch_pair_size = 115738.11273211491
# best_stitch_pair_distance = 242.90319712086352
# best_stitch_pair_size_ratio = 0.30389532358440385
# Starting Child 15
# 38 26569
# Done distance matrix: 0.04431557655334473
# Child 15 There were no points close enough
# Starting Child 16
# 19 26569
# Done distance matrix: 0.017713308334350586
# Child 16 There were no points close enough
# Starting Child 17
# 7 26569
# Done distance matrix: 0.009238243103027344
# Child 17 There were no points close enough
# Starting Child 18
# 6 26569
# Done distance matrix: 0.0061948299407958984
# Child 18 There were no points close enough
# Starting Child 26
# 33 26569
# Done distance matrix: 0.028072595596313477
# Child 26 There were no points close enough
# Starting Child 27
# 15 26569
# Done distance matrix: 0.013035297393798828
# Child 27 There were no points close enough
# Starting Child 28
# 8 26569
# Done distance matrix: 0.008262395858764648
# Child 28 There were no points close enough
# repeat_main_facets = [26563]
# child_mesh_double_indexes = [3, 8]
# min_child = 8, max_ratio = 242.90319712086352
# child_meshes_stitch_facets = {8: [0, 26563]}
# ---Stitching child 8 with pair: [0, 26563]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1169501, starting edge 2nd facet= 1169600,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.71661376953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.038060665130615234
# returned from stitch mesh: 1.8005695343017578
# Finished stitching child 8 : 2.0441267490386963
# ***************Finished big stitching iteration: 4.628645658493042***************
# Starting Child 3
# 9 26577
# Done distance matrix: 0.012078285217285156
# Done Generating final pairs: 0.016055822372436523
# best_stitch_pair = [    8 26568]
# best_stitch_pair_size = 100625.44659994393
# best_stitch_pair_distance = 1494.1475418547452
# best_stitch_pair_size_ratio = 0.20937498255429293
# Starting Child 15
# 38 26577
# Done distance matrix: 0.05862879753112793
# Child 15 There were no points close enough
# Starting Child 16
# 19 26577
# Done distance matrix: 0.022982120513916016
# Child 16 There were no points close enough
# Starting Child 17
# 7 26577
# Done distance matrix: 0.012110471725463867
# Child 17 There were no points close enough
# Starting Child 18
# 6 26577
# Done distance matrix: 0.008300065994262695
# Child 18 There were no points close enough
# Starting Child 26
# 33 26577
# Done distance matrix: 0.048169851303100586
# Child 26 There were no points close enough
# Starting Child 27
# 15 26577
# Done distance matrix: 0.017158031463623047
# Child 27 There were no points close enough
# Starting Child 28
# 8 26577
# Done distance matrix: 0.010717153549194336
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [8, 26568]}
# ---Stitching child 3 with pair: [8, 26568]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1169585, starting edge 2nd facet= 1169617,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04976487159729004
# returned from stitch mesh: 1.957475185394287
# Finished stitching child 3 : 2.370659112930298
# ***************Finished big stitching iteration: 4.842801094055176***************
# Starting Child 15
# 38 26584
# Done distance matrix: 0.061026811599731445
# Child 15 There were no points close enough
# Starting Child 16
# 19 26584
# Done distance matrix: 0.042764902114868164
# Child 16 There were no points close enough
# Starting Child 17
# 7 26584
# Done distance matrix: 0.02347397804260254
# Child 17 There were no points close enough
# Starting Child 18
# 6 26584
# Done distance matrix: 0.008186101913452148
# Child 18 There were no points close enough
# Starting Child 26
# 33 26584
# Done distance matrix: 0.080780029296875
# Child 26 There were no points close enough
# Starting Child 27
# 15 26584
# Done distance matrix: 0.01656508445739746
# Child 27 There were no points close enough
# Starting Child 28
# 8 26584
# Done distance matrix: 0.013531208038330078
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 15
# 38 26584
# Done distance matrix: 0.13811063766479492
# Child 15 There were no points close enough
# Starting Child 16
# 19 26584
# Done distance matrix: 0.06537270545959473
# Child 16 There were no points close enough
# Starting Child 17
# 7 26584
# Done distance matrix: 0.01776266098022461
# Child 17 There were no points close enough
# Starting Child 18
# 6 26584
# Done distance matrix: 0.00766301155090332
# Child 18 There were no points close enough
# Starting Child 26
# 33 26584
# Done distance matrix: 0.0671224594116211
# Child 26 There were no points close enough
# Starting Child 27
# 15 26584
# Done distance matrix: 0.07187867164611816
# Child 27 There were no points close enough
# Starting Child 28
# 8 26584
# Done distance matrix: 0.0113525390625
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 15
# 38 26584
# Done distance matrix: 0.05594062805175781
# Child 15 There were no points close enough
# Starting Child 16
# 19 26584
# Done distance matrix: 0.021199941635131836
# Child 16 There were no points close enough
# Starting Child 17
# 7 26584
# Done distance matrix: 0.008929252624511719
# Child 17 There were no points close enough
# Starting Child 18
# 6 26584
# Done distance matrix: 0.007954597473144531
# Child 18 There were no points close enough
# Starting Child 26
# 33 26584
# Done distance matrix: 0.037209272384643555
# Child 26 There were no points close enough
# Starting Child 27
# 15 26584
# Done distance matrix: 0.016571998596191406
# Child 27 There were no points close enough
# Starting Child 28
# 8 26584
# Done distance matrix: 0.008488178253173828
# Child 28 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 15
# 38 26584
# Done distance matrix: 0.03341054916381836
# Done Generating final pairs: 0.03543710708618164
# best_stitch_pair = [   17 26567]
# best_stitch_pair_size = 36492.7484357933
# best_stitch_pair_distance = 8236.01270445099
# best_stitch_pair_size_ratio = 0.4701434641536864
# Starting Child 16
# 19 26584
# Done distance matrix: 0.015679121017456055
# Done Generating final pairs: 0.0182492733001709
# best_stitch_pair = [    1 26567]
# best_stitch_pair_size = 181622.19188768422
# best_stitch_pair_distance = 7339.736072807234
# best_stitch_pair_size_ratio = 0.068667451331526
# Starting Child 17
# 7 26584
# Done distance matrix: 0.01705455780029297
# Done Generating final pairs: 0.0269315242767334
# best_stitch_pair = [    4 26567]
# best_stitch_pair_size = 165640.2520138626
# best_stitch_pair_distance = 7554.193286902687
# best_stitch_pair_size_ratio = 0.07579506390880458
# ...
# best_stitch_pair_distance = 317.867549080297
# best_stitch_pair_size_ratio = 0.7627716457747317
# Starting Child 39
# 84 31716
# Done distance matrix: 0.1200416088104248
# Child 39 There were no points close enough
# Starting Child 40
# 4 31716
# Done distance matrix: 0.007023334503173828
# Child 40 There were no points close enough
# Starting Child 41
# 8 31716
# Done distance matrix: 0.01177072525024414
# Done Generating final pairs: 0.028446674346923828
# best_stitch_pair = [    1 23412]
# best_stitch_pair_size = 689446.6323732932
# best_stitch_pair_distance = 93.72637460606221
# best_stitch_pair_size_ratio = 0.9132573158860668
# Starting Child 43
# 3 31716
# Done distance matrix: 0.003957986831665039
# Done Generating final pairs: 0.014417409896850586
# best_stitch_pair = [    1 31153]
# best_stitch_pair_size = 148037.4024019387
# best_stitch_pair_distance = 1498.3681280077176
# best_stitch_pair_size_ratio = 0.2522483658287424
# Starting Child 44
# 11 31716
# Done distance matrix: 0.013987541198730469
# Done Generating final pairs: 0.017409324645996094
# best_stitch_pair = [    4 31200]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1713.768795607088
# best_stitch_pair_size_ratio = 0.0
# Starting Child 45
# 31 31716
# Done distance matrix: 0.04116010665893555
# Child 45 There were no points close enough
# Starting Child 46
# 88 31716
# Done distance matrix: 0.1101388931274414
# Done Generating final pairs: 0.13058805465698242
# best_stitch_pair = [    3 27541]
# best_stitch_pair_size = 2952082.3002379364
# best_stitch_pair_distance = 783.5818234713298
# best_stitch_pair_size_ratio = 0.8106036143328068
# Starting Child 47
# 41 31716
# Done distance matrix: 0.04590582847595215
# Child 47 There were no points close enough
# Starting Child 48
# 34 31716
# Done distance matrix: 0.03916740417480469
# Child 48 There were no points close enough
# Starting Child 54
# 14 31716
# Done distance matrix: 0.014081478118896484
# Done Generating final pairs: 0.03658032417297363
# best_stitch_pair = [    2 31175]
# best_stitch_pair_size = 899282.8223273451
# best_stitch_pair_distance = 1906.3040330723948
# best_stitch_pair_size_ratio = 0.8815603156095244
# Starting Child 55
# 15 31716
# Done distance matrix: 0.021811246871948242
# Done Generating final pairs: 0.04170870780944824
# best_stitch_pair = [    5 30873]
# best_stitch_pair_size = 936187.9450725052
# best_stitch_pair_distance = 1394.0905771678756
# best_stitch_pair_size_ratio = 0.7359961999966818
# Starting Child 61
# 11 31716
# Done distance matrix: 0.01110386848449707
# Done Generating final pairs: 0.03874063491821289
# best_stitch_pair = [    0 31638]
# best_stitch_pair_size = 555479.8450303982
# best_stitch_pair_distance = 1394.6945182066079
# best_stitch_pair_size_ratio = 0.9781788332074501
# Starting Child 63
# 21 31716
# Done distance matrix: 0.021607398986816406
# Child 63 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 64
# 128 31716
# Done distance matrix: 0.19807982444763184
# Done Generating final pairs: 0.2595551013946533
# best_stitch_pair = [    7 30873]
# best_stitch_pair_size = 748702.3264191359
# best_stitch_pair_distance = 1010.4209668933557
# best_stitch_pair_size_ratio = 0.8863372291581922
# Starting Child 70
# 10 31716
# Done distance matrix: 0.022197723388671875
# Done Generating final pairs: 0.04158377647399902
# best_stitch_pair = [    3 31638]
# best_stitch_pair_size = 796052.8313060653
# best_stitch_pair_distance = 919.9722479013989
# best_stitch_pair_size_ratio = 0.5449861284219589
# Starting Child 73
# 8 31716
# Done distance matrix: 0.010763168334960938
# Done Generating final pairs: 0.017047405242919922
# best_stitch_pair = [    2 31610]
# best_stitch_pair_size = 710298.2013866913
# best_stitch_pair_distance = 1435.5731191570896
# best_stitch_pair_size_ratio = 0.5209827568602021
# Starting Child 74
# 2 31716
# Done distance matrix: 0.003093242645263672
# Done Generating final pairs: 0.011365652084350586
# best_stitch_pair = [    1 30657]
# best_stitch_pair_size = 30498.815595535074
# best_stitch_pair_distance = 685.0879601348502
# best_stitch_pair_size_ratio = 0.3531430613712393
# Starting Child 75
# 9 31716
# Done distance matrix: 0.01659679412841797
# Done Generating final pairs: 0.023680686950683594
# best_stitch_pair = [    6 31384]
# best_stitch_pair_size = 228780.53270344622
# best_stitch_pair_distance = 1537.7108593286387
# best_stitch_pair_size_ratio = 0.24412978480809694
# Starting Child 76
# 13 31716
# Done distance matrix: 0.014761924743652344
# Child 76 There were no points close enough
# Starting Child 77
# 8 31716
# Done distance matrix: 0.010791778564453125
# Child 77 There were no points close enough
# Starting Child 78
# 11 31716
# Done distance matrix: 0.012577533721923828
# Child 78 There were no points close enough
# Starting Child 82
# 30 31716
# Done distance matrix: 0.034502267837524414
# Done Generating final pairs: 0.06830668449401855
# best_stitch_pair = [    1 31218]
# best_stitch_pair_size = 1679675.1511901915
# best_stitch_pair_distance = 1411.712001090635
# best_stitch_pair_size_ratio = 0.510745154531899
# Starting Child 86
# 12 31716
# Done distance matrix: 0.013948678970336914
# Done Generating final pairs: 0.019796371459960938
# best_stitch_pair = [    2 31690]
# best_stitch_pair_size = 1181737.938712587
# best_stitch_pair_distance = 807.8392210646886
# best_stitch_pair_size_ratio = 0.7563869051635547
# repeat_main_facets = [31690, 30873, 31638]
# child_mesh_double_indexes = [4, 86]
# min_child = 4, max_ratio = 654.8725469038426
# child_mesh_double_indexes = [55, 64]
# min_child = 64, max_ratio = 1010.4209668933557
# child_mesh_double_indexes = [61, 70]
# min_child = 70, max_ratio = 919.9722479013989
# child_meshes_stitch_facets = {4: [90, 31690], 7: [9, 31439], 22: [0, 24327], 31: [127, 28901], 36: [47, 28237], 38: [0, 31401], 41: [1, 23412], 43: [1, 31153], 44: [4, 31200], 46: [3, 27541], 54: [2, 31175], 64: [7, 30873], 70: [3, 31638], 73: [2, 31610], 74: [1, 30657], 75: [6, 31384], 82: [1, 31218]}
# ---Stitching child 4 with pair: [90, 31690]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1356731, starting edge 2nd facet= 1357597,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 5.221366882324219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08974075317382812
# returned from stitch mesh: 1.6978802680969238
# Finished stitching child 4 : 2.0215389728546143
# ---Stitching child 7 with pair: [9, 31439]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1355158, starting edge 2nd facet= 1358938,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.044877052307128906
# returned from stitch mesh: 1.6418688297271729
# Finished stitching child 7 : 1.8909730911254883
# ---Stitching child 22 with pair: [0, 24327]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1192748, starting edge 2nd facet= 1358980,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 4.124641418457031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05462765693664551
# returned from stitch mesh: 1.7311615943908691
# Finished stitching child 22 : 1.9622883796691895
# ---Stitching child 31 with pair: [127, 28901]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1314664, starting edge 2nd facet= 1362920,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.7670135498046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023929595947265625
# returned from stitch mesh: 2.0648889541625977
# Finished stitching child 31 : 2.399580240249634
# ---Stitching child 36 with pair: [47, 28237]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1300493, starting edge 2nd facet= 1368616,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 4.982948303222656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04765009880065918
# returned from stitch mesh: 1.807535171508789
# Finished stitching child 36 : 2.011080026626587
# ---Stitching child 38 with pair: [0, 31401]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1353573, starting edge 2nd facet= 1369952,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 33
# Starting Organizing vertices for side 1
# edge_1_order done, len = 53
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 20
# About to add faces
# Finished adding faces: 8.082389831542969e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04219675064086914
# returned from stitch mesh: 1.5752184391021729
# Finished stitching child 38 : 1.8609426021575928
# ---Stitching child 41 with pair: [1, 23412]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1173558, starting edge 2nd facet= 1370590,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 6.031990051269531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07932901382446289
# returned from stitch mesh: 1.6748054027557373
# Finished stitching child 41 : 1.9026594161987305
# ---Stitching child 43 with pair: [1, 31153]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1351270, starting edge 2nd facet= 1370816,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.051026105880737305
# returned from stitch mesh: 1.483506202697754
# Finished stitching child 43 : 1.8183143138885498
# ---Stitching child 44 with pair: [4, 31200]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1351011, starting edge 2nd facet= 1370851,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 3.1948089599609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07211136817932129
# returned from stitch mesh: 1.7877156734466553
# Finished stitching child 44 : 2.0874321460723877
# ---Stitching child 46 with pair: [3, 27541]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1293103, starting edge 2nd facet= 1372361,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 47
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 18
# About to add faces
# Finished adding faces: 7.081031799316406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.047434091567993164
# returned from stitch mesh: 2.0794475078582764
# Finished stitching child 46 : 2.3765509128570557
# ---Stitching child 54 with pair: [2, 31175]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1351826, starting edge 2nd facet= 1372580,
# Starting Organizing vertices for side 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-6bcb73d94cc0> in <module>
#       1 start = time.time()
# ----> 2 ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-5-9cd9be709079> in make(self, key)
#      55                                                          load_meshes_flag = True,
#      56                                                      save_meshes_flag = False,
# ---> 57                                                         pymeshfix_flag = False
#      58                                                        )
#      59         else:
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_neuron(segment_id, vertices, faces, **kwargs)
#    1643                                                                                                 size_ratio_expansion_percentage = size_ratio_expansion_percentage,
#    1644                                                                                                 no_new_children_limit = no_new_children_limit,
# -> 1645                                                                                                 consider_same_direction_normals = consider_same_direction_normals
#    1646                                                                                                                                                       )
#    1647
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_iteration(main_mesh, main_mesh_facets_centers, main_mesh_facets, child_meshes, child_meshes_facets, bounding_box_threshold, stitch_distance_threshold, size_ratio_threshold, normal_closeness, bbox_expansion_percentage, stitch_expansion_percentage, size_ratio_expansion_percentage, no_new_children_limit, consider_same_direction_normals)
#    1209                                                               delete_facets=False,
#    1210                                                               return_added_mesh=False,
# -> 1211                                                                fix_normals = False)
#    1212
#    1213                 print(f"returned from stitch mesh: {time.time() - start_time}")
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_mesh_piece_vp4(new_mesh, facet_1, facet_2, delete_facets, return_added_mesh, fix_normals)
#     454
#     455         if starting_edges.size > 4:
# --> 456             raise Exception("Too many edges for 1st facet start point")
#     457
#     458         #np.where(starting_edges[1,:] != start_point)[0][0]
#
# Exception: Too many edges for 1st facet start point

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
