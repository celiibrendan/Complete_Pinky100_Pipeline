# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349471500**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349471500_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.9652493000030518
# Number of outside child meshes =  2
# Main mesh and outside child meshes make up 0.9312360944532893% of original mesh
#  face length 1488932 using optimized facets with 3 neighbors
# Filtering edges by size finished: 23.70734143257141, facet # = 80808
# Filtering by convexity and getting centers took: 31.459879398345947, facet # = 15161
# Finished facets for main mesh: 57.66302680969238 with facet length = 15161
# Finished 15161 facets for main mesh: 57.66315579414368
# Filtering edges by size finished: 0.005414247512817383, facet # = 23
# Filtering by convexity and getting centers took: 0.008005380630493164, facet # = 6
# Filtering edges by size finished: 0.003249645233154297, facet # = 7
# Filtering by convexity and getting centers took: 0.002987384796142578, facet # = 2
# Total time for facets: 57.68757700920105
# Zero faceted faces = []
# Starting Child 0
# 6 15161
# Done distance matrix: 0.004544258117675781
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 2 15161
# Done distance matrix: 0.0011501312255859375
# Child 1 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# 6 15161
# Done distance matrix: 0.003276824951171875
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 2 15161
# Done distance matrix: 0.0012183189392089844
# Done Generating final pairs: 0.009633064270019531
# best_stitch_pair = [   0 9896]
# best_stitch_pair_size = 282355.3472707425
# best_stitch_pair_distance = 2274.4572030591517
# best_stitch_pair_size_ratio = 0.44883356300191934
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [0, 9896]}
# ---Stitching child 1 with pair: [0, 9896]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 303720, starting edge 2nd facet= 743809,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.021949291229248047
# returned from stitch mesh: 0.7433240413665771
# Finished stitching child 1 : 0.8741881847381592
# ***************Finished big stitching iteration: 0.9878594875335693***************
# Starting Child 0
# 6 15161
# Done distance matrix: 0.0039250850677490234
# Done Generating final pairs: 0.00470733642578125
# best_stitch_pair = [    5 15160]
# best_stitch_pair_size = 25110.644799569192
# best_stitch_pair_distance = 473.9741453853516
# best_stitch_pair_size_ratio = 0.8959686574204434
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [5, 15160]}
# ---Stitching child 0 with pair: [5, 15160]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 743804, starting edge 2nd facet= 743861,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.0967254638671875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022778987884521484
# returned from stitch mesh: 0.7350475788116455
# Finished stitching child 0 : 0.8657183647155762
# ***************Finished big stitching iteration: 1.658987045288086***************
# All children have been processed
# total_stitch_processing_time = 2.758434772491455
# Total time for restitching = 2.761129379272461
# missed_children = []
# Whole stitching function complete: 63.919090032577515
#
#
#
# *****Running Neuron Stitcher for 648518346349473811**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473811_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 2.8776297569274902
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9650344478093874% of original mesh
#  face length 1669538 using optimized facets with 3 neighbors
# Filtering edges by size finished: 25.815032720565796, facet # = 87057
# Filtering by convexity and getting centers took: 63.13574528694153, facet # = 18803
# Finished facets for main mesh: 91.67566227912903 with facet length = 18803
# Finished 18803 facets for main mesh: 91.67586016654968
# Filtering edges by size finished: 0.046677350997924805, facet # = 49
# Filtering by convexity and getting centers took: 0.03169131278991699, facet # = 2
# Total time for facets: 91.76344108581543
# Zero faceted faces = []
# Starting Child 0
# 2 18803
# Done distance matrix: 0.001856088638305664
# Done Generating final pairs: 0.01766681671142578
# best_stitch_pair = [  1 445]
# best_stitch_pair_size = 60302.917045383816
# best_stitch_pair_distance = 1999.7442297455354
# best_stitch_pair_size_ratio = 0.1957393596736391
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1, 445]}
# ---Stitching child 0 with pair: [1, 445]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 429621, starting edge 2nd facet= 837310,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028855562210083008
# returned from stitch mesh: 1.302776575088501
# Finished stitching child 0 : 1.5174438953399658
# ***************Finished big stitching iteration: 1.884720802307129***************
# All children have been processed
# total_stitch_processing_time = 1.8869991302490234
# Total time for restitching = 1.9047777652740479
# missed_children = []
# Whole stitching function complete: 99.23960709571838
#
#
#
# *****Running Neuron Stitcher for 648518346349475101**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2687 pieces after mesh split
# There were 246 pieces found after size threshold
# max_index = 0
# max_face_len = 1107164
# Total time for Mesh Cleansing: 225.44911861419678
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.842437975465631% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349478183**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478183_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.8257529735565186
# Number of outside child meshes =  22
# Main mesh and outside child meshes make up 0.9781048452145399% of original mesh
#  face length 2356354 using optimized facets with 3 neighbors
# Filtering edges by size finished: 70.16773748397827, facet # = 124421
# Filtering by convexity and getting centers took: 99.33982968330383, facet # = 24493
# Finished facets for main mesh: 178.25933718681335 with facet length = 24493
# Finished 24493 facets for main mesh: 178.25943183898926
# Filtering edges by size finished: 0.0018825531005859375, facet # = 16
# Filtering by convexity and getting centers took: 0.00611567497253418, facet # = 10
# Filtering edges by size finished: 0.0068149566650390625, facet # = 52
# Filtering by convexity and getting centers took: 0.017104148864746094, facet # = 18
# Filtering edges by size finished: 0.01901531219482422, facet # = 99
# Filtering by convexity and getting centers took: 0.03226900100708008, facet # = 36
# Filtering edges by size finished: 0.036113739013671875, facet # = 204
# Filtering by convexity and getting centers took: 0.09128737449645996, facet # = 39
# Filtering edges by size finished: 0.010020971298217773, facet # = 38
# Filtering by convexity and getting centers took: 0.01820850372314453, facet # = 14
# Filtering edges by size finished: 0.0010051727294921875, facet # = 5
# Filtering by convexity and getting centers took: 0.0028450489044189453, facet # = 4
# Filtering edges by size finished: 0.5001099109649658, facet # = 1109
# Filtering by convexity and getting centers took: 0.5995941162109375, facet # = 263
# Filtering edges by size finished: 0.011891841888427734, facet # = 51
# Filtering by convexity and getting centers took: 0.029555320739746094, facet # = 15
# Filtering edges by size finished: 0.0034508705139160156, facet # = 14
# Filtering by convexity and getting centers took: 0.006709575653076172, facet # = 7
# Filtering edges by size finished: 0.022995710372924805, facet # = 57
# Filtering by convexity and getting centers took: 0.055029869079589844, facet # = 18
# Filtering edges by size finished: 0.04391884803771973, facet # = 57
# Filtering by convexity and getting centers took: 0.0271909236907959, facet # = 12
# Filtering edges by size finished: 0.014316320419311523, facet # = 58
# Filtering by convexity and getting centers took: 0.025183916091918945, facet # = 17
# Filtering edges by size finished: 0.08096480369567871, facet # = 327
# Filtering by convexity and getting centers took: 0.476071834564209, facet # = 81
# Filtering edges by size finished: 0.0023202896118164062, facet # = 7
# Filtering by convexity and getting centers took: 0.003972768783569336, facet # = 6
# Filtering edges by size finished: 0.1616814136505127, facet # = 297
# Filtering by convexity and getting centers took: 0.23915719985961914, facet # = 63
# Filtering edges by size finished: 0.05978965759277344, facet # = 83
# Filtering by convexity and getting centers took: 0.09410738945007324, facet # = 36
# Filtering edges by size finished: 0.004160881042480469, facet # = 7
# Filtering by convexity and getting centers took: 0.0038537979125976562, facet # = 4
# Filtering edges by size finished: 0.014105081558227539, facet # = 57
# Filtering by convexity and getting centers took: 0.05810117721557617, facet # = 15
# Filtering edges by size finished: 0.03975844383239746, facet # = 83
# Filtering by convexity and getting centers took: 0.029458999633789062, facet # = 16
# Filtering edges by size finished: 0.0012733936309814453, facet # = 6
# Filtering by convexity and getting centers took: 0.0032508373260498047, facet # = 6
# Filtering edges by size finished: 0.0012607574462890625, facet # = 8
# Filtering by convexity and getting centers took: 0.004244089126586914, facet # = 8
# Filtering edges by size finished: 0.0018548965454101562, facet # = 10
# Filtering by convexity and getting centers took: 0.006075859069824219, facet # = 9
# Total time for facets: 181.23774528503418
# Zero faceted faces = []
# Starting Child 0
# 10 24493
# Done distance matrix: 0.014867782592773438
# Child 0 There were no points close enough
# Starting Child 1
# 18 24493
# Done distance matrix: 0.019829511642456055
# Child 1 There were no points close enough
# Starting Child 2
# 36 24493
# Done distance matrix: 0.033315181732177734
# Child 2 There were no points close enough
# Starting Child 3
# 39 24493
# Done distance matrix: 0.045089006423950195
# Child 3 There were no points close enough
# Starting Child 4
# 14 24493
# Done distance matrix: 0.01461482048034668
# Child 4 There were no points close enough
# Starting Child 5
# 4 24493
# Done distance matrix: 0.006007671356201172
# Child 5 There were no points close enough
# Starting Child 6
# 263 24493
# Done distance matrix: 0.2635362148284912
# Done Generating final pairs: 0.29039430618286133
# best_stitch_pair = [  16 1316]
# best_stitch_pair_size = 383049.7862805213
# best_stitch_pair_distance = 210.9867756081072
# best_stitch_pair_size_ratio = 0.5497482469972497
# Starting Child 7
# 15 24493
# Done distance matrix: 0.011751651763916016
# Child 7 There were no points close enough
# Starting Child 8
# 7 24493
# Done distance matrix: 0.0075380802154541016
# Child 8 There were no points close enough
# Starting Child 9
# 18 24493
# Done distance matrix: 0.013782978057861328
# Child 9 There were no points close enough
# Starting Child 10
# 12 24493
# Done distance matrix: 0.01066899299621582
# Child 10 There were no points close enough
# Starting Child 11
# 17 24493
# Done distance matrix: 0.013249635696411133
# Child 11 There were no points close enough
# Starting Child 12
# 81 24493
# Done distance matrix: 0.08756375312805176
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 6 24493
# Done distance matrix: 0.009103536605834961
# Done Generating final pairs: 0.03763556480407715
# best_stitch_pair = [    2 13236]
# best_stitch_pair_size = 130714.64470025862
# best_stitch_pair_distance = 1862.3688416554628
# best_stitch_pair_size_ratio = 0.9357063636092418
# Starting Child 14
# 63 24493
# Done distance matrix: 0.07580280303955078
# Child 14 There were no points close enough
# Starting Child 15
# 36 24493
# Done distance matrix: 0.07299137115478516
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 16
# 4 24493
# Done distance matrix: 0.004808902740478516
# Child 16 There were no points close enough
# Starting Child 17
# 15 24493
# Done distance matrix: 0.015873432159423828
# Child 17 There were no points close enough
# Starting Child 18
# 16 24493
# Done distance matrix: 0.026546478271484375
# Child 18 There were no points close enough
# Starting Child 19
# 6 24493
# Done distance matrix: 0.01775360107421875
# Child 19 There were no points close enough
# Starting Child 20
# 8 24493
# Done distance matrix: 0.021881580352783203
# Child 20 There were no points close enough
# Starting Child 21
# 9 24493
# Done distance matrix: 0.010539054870605469
# Done Generating final pairs: 0.14029884338378906
# best_stitch_pair = [    6 17522]
# best_stitch_pair_size = 35304.95127624617
# best_stitch_pair_distance = 1892.509087902699
# best_stitch_pair_size_ratio = 0.3057084671498642
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [16, 1316], 13: [2, 13236], 21: [6, 17522]}
# ---Stitching child 6 with pair: [16, 1316]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 296410, starting edge 2nd facet= 1185091,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 22
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 4.792213439941406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08365321159362793
# returned from stitch mesh: 1.9881834983825684
# Finished stitching child 6 : 2.2917685508728027
# ---Stitching child 13 with pair: [2, 13236]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 423511, starting edge 2nd facet= 1186638,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 4.2438507080078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0793001651763916
# returned from stitch mesh: 2.427309036254883
# Finished stitching child 13 : 2.8804972171783447
# ---Stitching child 21 with pair: [6, 17522]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 357318, starting edge 2nd facet= 1186689,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0850381851196289
# returned from stitch mesh: 2.029968500137329
# Finished stitching child 21 : 2.290931463241577
# ***************Finished big stitching iteration: 9.577576875686646***************
# Starting Child 0
# 10 24765
# Done distance matrix: 0.02490544319152832
# Child 0 There were no points close enough
# Starting Child 1
# 18 24765
# Done distance matrix: 0.04053759574890137
# Child 1 There were no points close enough
# Starting Child 2
# 36 24765
# Done distance matrix: 0.04518437385559082
# Child 2 There were no points close enough
# Starting Child 3
# 39 24765
# Done distance matrix: 0.03321218490600586
# Child 3 There were no points close enough
# Starting Child 4
# 14 24765
# Done distance matrix: 0.012304544448852539
# Child 4 There were no points close enough
# Starting Child 5
# 4 24765
# Done distance matrix: 0.004521608352661133
# Child 5 There were no points close enough
# Starting Child 7
# 15 24765
# Done distance matrix: 0.014194488525390625
# Child 7 There were no points close enough
# Starting Child 8
# 7 24765
# Done distance matrix: 0.00919651985168457
# Child 8 There were no points close enough
# Starting Child 9
# 18 24765
# Done distance matrix: 0.02808666229248047
# Child 9 There were no points close enough
# Starting Child 10
# 12 24765
# Done distance matrix: 0.0234832763671875
# Child 10 There were no points close enough
# Starting Child 11
# 17 24765
# Done distance matrix: 0.027090072631835938
# Child 11 There were no points close enough
# Starting Child 12
# 81 24765
# Done distance matrix: 0.09269523620605469
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 63 24765
# Done distance matrix: 0.055954933166503906
# Child 14 There were no points close enough
# Starting Child 15
# 36 24765
# Done distance matrix: 0.037401437759399414
# Done Generating final pairs: 0.04206061363220215
# best_stitch_pair = [   32 24761]
# best_stitch_pair_size = 62783.17918688906
# best_stitch_pair_distance = 572.9484708803583
# best_stitch_pair_size_ratio = 0.5235016434886801
# Starting Child 16
# 4 24765
# Done distance matrix: 0.0049228668212890625
# Child 16 There were no points close enough
# Starting Child 17
# 15 24765
# Done distance matrix: 0.015916824340820312
# Child 17 There were no points close enough
# Starting Child 18
# 16 24765
# Done distance matrix: 0.0191342830657959
# Child 18 There were no points close enough
# Starting Child 19
# 6 24765
# Done distance matrix: 0.020580768585205078
# Child 19 There were no points close enough
# Starting Child 20
# 8 24765
# Done distance matrix: 0.010382652282714844
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {15: [32, 24761]}
# ---Stitching child 15 with pair: [32, 24761]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1186683, starting edge 2nd facet= 1186759,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07440638542175293
# returned from stitch mesh: 2.4430158138275146
# Finished stitching child 15 : 2.763852596282959
# ***************Finished big stitching iteration: 6.314880132675171***************
# Starting Child 0
# 10 24799
# Done distance matrix: 0.025431156158447266
# Child 0 There were no points close enough
# Starting Child 1
# 18 24799
# Done distance matrix: 0.04180788993835449
# Child 1 There were no points close enough
# Starting Child 2
# 36 24799
# Done distance matrix: 0.08613300323486328
# Child 2 There were no points close enough
# Starting Child 3
# 39 24799
# Done distance matrix: 0.08176422119140625
# Child 3 There were no points close enough
# Starting Child 4
# 14 24799
# Done distance matrix: 0.021319866180419922
# Child 4 There were no points close enough
# Starting Child 5
# 4 24799
# Done distance matrix: 0.007414817810058594
# Child 5 There were no points close enough
# Starting Child 7
# 15 24799
# Done distance matrix: 0.02164292335510254
# Child 7 There were no points close enough
# Starting Child 8
# 7 24799
# Done distance matrix: 0.01199650764465332
# Child 8 There were no points close enough
# Starting Child 9
# 18 24799
# Done distance matrix: 0.023340225219726562
# Done Generating final pairs: 0.029172897338867188
# best_stitch_pair = [    0 24770]
# best_stitch_pair_size = 471440.55160535476
# best_stitch_pair_distance = 1571.4578993123425
# best_stitch_pair_size_ratio = 0.6473263567870737
# Starting Child 10
# 12 24799
# Done distance matrix: 0.013082027435302734
# Done Generating final pairs: 0.023683786392211914
# best_stitch_pair = [    2 24770]
# best_stitch_pair_size = 804096.4193197526
# best_stitch_pair_distance = 565.237880230065
# best_stitch_pair_size_ratio = 0.5525760219966283
# Starting Child 11
# 17 24799
# Done distance matrix: 0.027682781219482422
# Child 11 There were no points close enough
# Starting Child 12
# 81 24799
# Done distance matrix: 0.17219138145446777
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 63 24799
# Done distance matrix: 0.1156013011932373
# Child 14 There were no points close enough
# Starting Child 16
# 4 24799
# Done distance matrix: 0.005366086959838867
# Child 16 There were no points close enough
# Starting Child 17
# 15 24799
# Done distance matrix: 0.02596569061279297
# Child 17 There were no points close enough
# Starting Child 18
# 16 24799
# Done distance matrix: 0.030852317810058594
# Child 18 There were no points close enough
# Starting Child 19
# 6 24799
# Done distance matrix: 0.0076677799224853516
# Child 19 There were no points close enough
# Starting Child 20
# 8 24799
# Done distance matrix: 0.00953984260559082
# Child 20 There were no points close enough
# repeat_main_facets = [24770]
# child_mesh_double_indexes = [9, 10]
# min_child = 10, max_ratio = 565.237880230065
# child_meshes_stitch_facets = {10: [2, 24770]}
# ---Stitching child 10 with pair: [2, 24770]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1186793, starting edge 2nd facet= 1187175,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 7.081031799316406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.10592055320739746
# returned from stitch mesh: 2.06018328666687
# Finished stitching child 10 : 2.4504573345184326
# ***************Finished big stitching iteration: 6.131554841995239***************
# Starting Child 0
# 10 24809
# Done distance matrix: 0.016168832778930664
# Child 0 There were no points close enough
# Starting Child 1
# 18 24809
# Done distance matrix: 0.048560380935668945
# Child 1 There were no points close enough
# Starting Child 2
# 36 24809
# Done distance matrix: 0.038496971130371094
# Child 2 There were no points close enough
# Starting Child 3
# 39 24809
# Done distance matrix: 0.043851375579833984
# Child 3 There were no points close enough
# Starting Child 4
# 14 24809
# Done distance matrix: 0.015776634216308594
# Child 4 There were no points close enough
# Starting Child 5
# 4 24809
# Done distance matrix: 0.0057523250579833984
# Child 5 There were no points close enough
# Starting Child 7
# 15 24809
# Done distance matrix: 0.05089068412780762
# Child 7 There were no points close enough
# Starting Child 8
# 7 24809
# Done distance matrix: 0.008727550506591797
# Child 8 There were no points close enough
# Starting Child 9
# 18 24809
# Done distance matrix: 0.04192614555358887
# Done Generating final pairs: 0.052635908126831055
# best_stitch_pair = [    0 24799]
# best_stitch_pair_size = 710971.1837837388
# best_stitch_pair_distance = 471.4384342903728
# best_stitch_pair_size_ratio = 0.35238665946485664
# Starting Child 11
# 17 24809
# Done distance matrix: 0.01901102066040039
# Child 11 There were no points close enough
# Starting Child 12
# 81 24809
# Done distance matrix: 0.07052063941955566
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 63 24809
# Done distance matrix: 0.14310860633850098
# Child 14 There were no points close enough
# Starting Child 16
# 4 24809
# Done distance matrix: 0.004784822463989258
# Child 16 There were no points close enough
# Starting Child 17
# 15 24809
# Done distance matrix: 0.03309965133666992
# Child 17 There were no points close enough
# Starting Child 18
# 16 24809
# Done distance matrix: 0.05576062202453613
# Child 18 There were no points close enough
# Starting Child 19
# 6 24809
# Done distance matrix: 0.018998384475708008
# Child 19 There were no points close enough
# Starting Child 20
# 8 24809
# Done distance matrix: 0.009912967681884766
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {9: [0, 24799]}
# ---Stitching child 9 with pair: [0, 24799]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1187168, starting edge 2nd facet= 1187422,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 12
# About to add faces
# Finished adding faces: 3.838539123535156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04005622863769531
# returned from stitch mesh: 2.023021936416626
# Finished stitching child 9 : 2.254354476928711
# ***************Finished big stitching iteration: 5.680580139160156***************
# Starting Child 0
# 10 24825
# Done distance matrix: 0.013288736343383789
# Child 0 There were no points close enough
# Starting Child 1
# 18 24825
# Done distance matrix: 0.02088022232055664
# Child 1 There were no points close enough
# Starting Child 2
# 36 24825
# Done distance matrix: 0.045237064361572266
# Child 2 There were no points close enough
# Starting Child 3
# 39 24825
# Done distance matrix: 0.04045701026916504
# Child 3 There were no points close enough
# Starting Child 4
# 14 24825
# Done distance matrix: 0.016299724578857422
# Child 4 There were no points close enough
# Starting Child 5
# 4 24825
# Done distance matrix: 0.006524324417114258
# Child 5 There were no points close enough
# Starting Child 7
# 15 24825
# Done distance matrix: 0.0200803279876709
# Done Generating final pairs: 0.024283647537231445
# best_stitch_pair = [    4 24820]
# best_stitch_pair_size = 143607.10971580257
# best_stitch_pair_distance = 909.1922297778879
# best_stitch_pair_size_ratio = 0.26635046167535464
# Starting Child 8
# 7 24825
# Done distance matrix: 0.017730712890625
# Done Generating final pairs: 0.02049732208251953
# best_stitch_pair = [    6 24815]
# best_stitch_pair_size = 28185.3459732359
# best_stitch_pair_distance = 1022.1335799825935
# best_stitch_pair_size_ratio = 0.8876843704528338
# Starting Child 11
# 17 24825
# Done distance matrix: 0.019405603408813477
# Child 11 There were no points close enough
# Starting Child 12
# 81 24825
# Done distance matrix: 0.2415027618408203
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 63 24825
# Done distance matrix: 0.11284732818603516
# Child 14 There were no points close enough
# Starting Child 16
# 4 24825
# Done distance matrix: 0.004889488220214844
# Child 16 There were no points close enough
# Starting Child 17
# 15 24825
# Done distance matrix: 0.016043901443481445
# Child 17 There were no points close enough
# Starting Child 18
# 16 24825
# Done distance matrix: 0.027074098587036133
# Child 18 There were no points close enough
# Starting Child 19
# 6 24825
# Done distance matrix: 0.0370635986328125
# Child 19 There were no points close enough
# Starting Child 20
# 8 24825
# Done distance matrix: 0.02791595458984375
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {7: [4, 24820], 8: [6, 24815]}
# ---Stitching child 7 with pair: [4, 24820]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1187391, starting edge 2nd facet= 1187600,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 3.170967102050781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09169435501098633
# returned from stitch mesh: 1.8452117443084717
# Finished stitching child 7 : 2.095806360244751
# ---Stitching child 8 with pair: [6, 24815]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1187429, starting edge 2nd facet= 1187727,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11145830154418945
# returned from stitch mesh: 1.9544932842254639
# Finished stitching child 8 : 2.3911421298980713
# ***************Finished big stitching iteration: 7.759896755218506***************
# Starting Child 0
# 10 24843
# Done distance matrix: 0.016156435012817383
# Child 0 There were no points close enough
# Starting Child 1
# 18 24843
# Done distance matrix: 0.01998114585876465
# Child 1 There were no points close enough
# Starting Child 2
# 36 24843
# Done distance matrix: 0.04254937171936035
# Child 2 There were no points close enough
# Starting Child 3
# 39 24843
# Done distance matrix: 0.045998573303222656
# Child 3 There were no points close enough
# Starting Child 4
# 14 24843
# Done distance matrix: 0.015845298767089844
# Child 4 There were no points close enough
# Starting Child 5
# 4 24843
# Done distance matrix: 0.0045359134674072266
# Child 5 There were no points close enough
# Starting Child 11
# 17 24843
# Done distance matrix: 0.01453089714050293
# Child 11 There were no points close enough
# Starting Child 12
# 81 24843
# Done distance matrix: 0.06887388229370117
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 63 24843
# Done distance matrix: 0.058012962341308594
# Child 14 There were no points close enough
# Starting Child 16
# 4 24843
# Done distance matrix: 0.0037412643432617188
# Child 16 There were no points close enough
# Starting Child 17
# 15 24843
# Done distance matrix: 0.012348651885986328
# Child 17 There were no points close enough
# Starting Child 18
# 16 24843
# Done distance matrix: 0.012783527374267578
# Child 18 There were no points close enough
# Starting Child 19
# 6 24843
# Done distance matrix: 0.005825996398925781
# Child 19 There were no points close enough
# Starting Child 20
# 8 24843
# Done distance matrix: 0.007430315017700195
# Child 20 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# 10 24843
# Done distance matrix: 0.019148826599121094
# Child 0 There were no points close enough
# Starting Child 1
# 18 24843
# Done distance matrix: 0.027955055236816406
# Child 1 There were no points close enough
# Starting Child 2
# 36 24843
# Done distance matrix: 0.07222604751586914
# Child 2 There were no points close enough
# Starting Child 3
# 39 24843
# Done distance matrix: 0.06522798538208008
# Child 3 There were no points close enough
# Starting Child 4
# 14 24843
# Done distance matrix: 0.025792360305786133
# Child 4 There were no points close enough
# Starting Child 5
# 4 24843
# Done distance matrix: 0.00496220588684082
# Child 5 There were no points close enough
# Starting Child 11
# 17 24843
# Done distance matrix: 0.018082857131958008
# Child 11 There were no points close enough
# Starting Child 12
# 81 24843
# Done distance matrix: 0.07833576202392578
# Done Generating final pairs: 0.0802154541015625
# best_stitch_pair = [  16 3065]
# best_stitch_pair_size = 35128.10260775361
# best_stitch_pair_distance = 2225.9955476614095
# best_stitch_pair_size_ratio = 0.6245652690502675
# Starting Child 14
# 63 24843
# Done distance matrix: 0.04959297180175781
# Child 14 There were no points close enough
# Starting Child 16
# 4 24843
# Done distance matrix: 0.003674745559692383
# Child 16 There were no points close enough
# Starting Child 17
# 15 24843
# Done distance matrix: 0.013114690780639648
# Child 17 There were no points close enough
# Starting Child 18
# 16 24843
# Done distance matrix: 0.017063140869140625
# Child 18 There were no points close enough
# Starting Child 19
# 6 24843
# Done distance matrix: 0.007354259490966797
# Child 19 There were no points close enough
# Starting Child 20
# 8 24843
# Done distance matrix: 0.009660482406616211
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {12: [16, 3065]}
# ---Stitching child 12 with pair: [16, 3065]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1006092, starting edge 2nd facet= 1188304,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.3126602172851562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08656716346740723
# returned from stitch mesh: 2.024583578109741
# Finished stitching child 12 : 2.3868465423583984
# ***************Finished big stitching iteration: 3.0935068130493164***************
# Starting Child 0
# 10 24922
# Done distance matrix: 0.012804269790649414
# Child 0 There were no points close enough
# Starting Child 1
# 18 24922
# Done distance matrix: 0.015549182891845703
# Child 1 There were no points close enough
# Starting Child 2
# 36 24922
# Done distance matrix: 0.03145122528076172
# Child 2 There were no points close enough
# Starting Child 3
# 39 24922
# Done distance matrix: 0.033524513244628906
# Child 3 There were no points close enough
# Starting Child 4
# 14 24922
# Done distance matrix: 0.012351512908935547
# Child 4 There were no points close enough
# Starting Child 5
# 4 24922
# Done distance matrix: 0.0052547454833984375
# Child 5 There were no points close enough
# Starting Child 11
# 17 24922
# Done distance matrix: 0.015054941177368164
# Child 11 There were no points close enough
# Starting Child 14
# 63 24922
# Done distance matrix: 0.07065558433532715
# Done Generating final pairs: 0.07519745826721191
# best_stitch_pair = [   30 24913]
# best_stitch_pair_size = 68914.5311693403
# best_stitch_pair_distance = 363.2201684843187
# best_stitch_pair_size_ratio = 0.22103643327856315
# Starting Child 16
# 4 24922
# Done distance matrix: 0.004937887191772461
# Child 16 There were no points close enough
# Starting Child 17
# 15 24922
# Done distance matrix: 0.015928030014038086
# Child 17 There were no points close enough
# Starting Child 18
# 16 24922
# Done distance matrix: 0.016971111297607422
# Child 18 There were no points close enough
# Starting Child 19
# 6 24922
# Done distance matrix: 0.006085634231567383
# Child 19 There were no points close enough
# Starting Child 20
# 8 24922
# Done distance matrix: 0.007475137710571289
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {14: [30, 24913]}
# ---Stitching child 14 with pair: [30, 24913]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1188286, starting edge 2nd facet= 1189533,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.2636184692382812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.035989999771118164
# returned from stitch mesh: 1.8081614971160889
# Finished stitching child 14 : 2.3071043491363525
# ***************Finished big stitching iteration: 4.653481721878052***************
# Starting Child 0
# 10 24983
# Done distance matrix: 0.009732246398925781
# Child 0 There were no points close enough
# Starting Child 1
# 18 24983
# Done distance matrix: 0.035015106201171875
# Child 1 There were no points close enough
# Starting Child 2
# 36 24983
# Done distance matrix: 0.0503082275390625
# Child 2 There were no points close enough
# Starting Child 3
# 39 24983
# Done distance matrix: 0.045104026794433594
# Child 3 There were no points close enough
# Starting Child 4
# 14 24983
# Done distance matrix: 0.026274442672729492
# Child 4 There were no points close enough
# Starting Child 5
# 4 24983
# Done distance matrix: 0.01474905014038086
# Child 5 There were no points close enough
# Starting Child 11
# 17 24983
# Done distance matrix: 0.039501190185546875
# Done Generating final pairs: 0.04793095588684082
# best_stitch_pair = [    7 24961]
# best_stitch_pair_size = 123702.3012821408
# best_stitch_pair_distance = 2369.90641584861
# best_stitch_pair_size_ratio = 0.3034184880835165
# Starting Child 16
# 4 24983
# Done distance matrix: 0.004984855651855469
# Done Generating final pairs: 0.008231163024902344
# best_stitch_pair = [    1 24970]
# best_stitch_pair_size = 28410.09537357677
# best_stitch_pair_distance = 695.6039442936483
# best_stitch_pair_size_ratio = 0.7596343484296125
# Starting Child 17
# 15 24983
# Done distance matrix: 0.015550374984741211
# Child 17 There were no points close enough
# Starting Child 18
# 16 24983
# Done distance matrix: 0.013153314590454102
# Child 18 There were no points close enough
# Starting Child 19
# 6 24983
# Done distance matrix: 0.006658792495727539
# Child 19 There were no points close enough
# Starting Child 20
# 8 24983
# Done distance matrix: 0.009258031845092773
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [7, 24961], 16: [1, 24970]}
# ---Stitching child 11 with pair: [7, 24961]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1189487, starting edge 2nd facet= 1190212,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.2931966781616211
# returned from stitch mesh: 2.7523930072784424
# Finished stitching child 11 : 3.0316240787506104
# ---Stitching child 16 with pair: [1, 24970]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1189505, starting edge 2nd facet= 1190286,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.5020370483398438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0339205265045166
# returned from stitch mesh: 2.1704275608062744
# Finished stitching child 16 : 2.3664510250091553
# ***************Finished big stitching iteration: 8.113668203353882***************
# Starting Child 0
# 10 25000
# Done distance matrix: 0.01388859748840332
# Done Generating final pairs: 0.015506982803344727
# best_stitch_pair = [    5 24986]
# best_stitch_pair_size = 29087.303089909838
# best_stitch_pair_distance = 2261.1327976053026
# best_stitch_pair_size_ratio = 0.6378824268778212
# Starting Child 1
# 18 25000
# Done distance matrix: 0.020172119140625
# Done Generating final pairs: 0.022790193557739258
# best_stitch_pair = [   10 24986]
# best_stitch_pair_size = 59623.921520406344
# best_stitch_pair_distance = 588.7254035227542
# best_stitch_pair_size_ratio = 0.4242007145338684
# Starting Child 2
# 36 25000
# Done distance matrix: 0.054553985595703125
# Child 2 There were no points close enough
# Starting Child 3
# 39 25000
# Done distance matrix: 0.04134058952331543
# Child 3 There were no points close enough
# Starting Child 4
# 14 25000
# Done distance matrix: 0.011238574981689453
# Child 4 There were no points close enough
# Starting Child 5
# 4 25000
# Done distance matrix: 0.0036499500274658203
# Child 5 There were no points close enough
# Starting Child 17
# 15 25000
# Done distance matrix: 0.011869192123413086
# Child 17 There were no points close enough
# Starting Child 18
# 16 25000
# Done distance matrix: 0.013756990432739258
# Child 18 There were no points close enough
# Starting Child 19
# 6 25000
# Done distance matrix: 0.0054585933685302734
# Child 19 There were no points close enough
# Starting Child 20
# 8 25000
# Done distance matrix: 0.007288932800292969
# Child 20 There were no points close enough
# repeat_main_facets = [24986]
# child_mesh_double_indexes = [0, 1]
# min_child = 1, max_ratio = 588.7254035227542
# child_meshes_stitch_facets = {1: [10, 24986]}
# ---Stitching child 1 with pair: [10, 24986]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1190115, starting edge 2nd facet= 1190395,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.2636184692382812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0370938777923584
# returned from stitch mesh: 2.1663637161254883
# Finished stitching child 1 : 2.376051425933838
# ***************Finished big stitching iteration: 4.923770427703857***************
# Starting Child 0
# 10 25016
# Done distance matrix: 0.015961647033691406
# Done Generating final pairs: 0.021768808364868164
# best_stitch_pair = [    4 25003]
# best_stitch_pair_size = 35742.27435647574
# best_stitch_pair_distance = 1378.9575187517146
# best_stitch_pair_size_ratio = 0.4200865634899122
# Starting Child 2
# 36 25016
# Done distance matrix: 0.04580426216125488
# Done Generating final pairs: 0.05072784423828125
# best_stitch_pair = [   22 24999]
# best_stitch_pair_size = 34717.40278552579
# best_stitch_pair_distance = 2140.091375782092
# best_stitch_pair_size_ratio = 0.7739786705848833
# Starting Child 3
# 39 25016
# Done distance matrix: 0.03702974319458008
# Child 3 There were no points close enough
# Starting Child 4
# 14 25016
# Done distance matrix: 0.01240086555480957
# Child 4 There were no points close enough
# Starting Child 5
# 4 25016
# Done distance matrix: 0.004415273666381836
# Child 5 There were no points close enough
# Starting Child 17
# 15 25016
# Done distance matrix: 0.013187170028686523
# Child 17 There were no points close enough
# Starting Child 18
# 16 25016
# Done distance matrix: 0.014342069625854492
# Child 18 There were no points close enough
# Starting Child 19
# 6 25016
# Done distance matrix: 0.006850004196166992
# Child 19 There were no points close enough
# Starting Child 20
# 8 25016
# Done distance matrix: 0.00792074203491211
# Child 20 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [4, 25003], 2: [22, 24999]}
# ---Stitching child 0 with pair: [4, 25003]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1190454, starting edge 2nd facet= 1190504,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.5735626220703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.035440683364868164
# returned from stitch mesh: 2.1978118419647217
# Finished stitching child 0 : 2.5560522079467773
# ---Stitching child 2 with pair: [22, 24999]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1190441, starting edge 2nd facet= 1190793,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0522007942199707
# returned from stitch mesh: 1.7241175174713135
# Finished stitching child 2 : 1.9387624263763428
# ***************Finished big stitching iteration: 7.1741273403167725***************
# Starting Child 3
# 39 25058
# Done distance matrix: 0.04987764358520508
# Child 3 There were no points close enough
# Starting Child 4
# 14 25058
# Done distance matrix: 0.01612401008605957
# Child 4 There were no points close enough
# Starting Child 5
# 4 25058
# Done distance matrix: 0.006446361541748047
# Child 5 There were no points close enough
# Starting Child 17
# 15 25058
# Done distance matrix: 0.017350435256958008
# Done Generating final pairs: 0.023056983947753906
# best_stitch_pair = [    3 25032]
# best_stitch_pair_size = 179186.61836029938
# best_stitch_pair_distance = 1221.5190015768612
# best_stitch_pair_size_ratio = 0.5128738444036292
# Starting Child 18
# 16 25058
# Done distance matrix: 0.017570018768310547
# Child 18 There were no points close enough
# Starting Child 19
# 6 25058
# Done distance matrix: 0.009839296340942383
# Done Generating final pairs: 0.015748023986816406
# best_stitch_pair = [    3 25032]
# best_stitch_pair_size = 137590.68130938485
# best_stitch_pair_distance = 1002.8091484121463
# best_stitch_pair_size_ratio = 0.7904897023092187
# Starting Child 20
# 8 25058
# Done distance matrix: 0.016160249710083008
# Done Generating final pairs: 0.025641441345214844
# best_stitch_pair = [    1 25046]
# best_stitch_pair_size = 195737.82049080104
# best_stitch_pair_distance = 2295.4590741570364
# best_stitch_pair_size_ratio = 0.27502112348492797
# repeat_main_facets = [25032]
# child_mesh_double_indexes = [17, 19]
# min_child = 19, max_ratio = 1002.8091484121463
# child_meshes_stitch_facets = {19: [3, 25032], 20: [1, 25046]}
# ---Stitching child 19 with pair: [3, 25032]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1190769, starting edge 2nd facet= 1190935,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.0517578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03926849365234375
# returned from stitch mesh: 2.0326945781707764
# Finished stitching child 19 : 2.293945789337158
# ---Stitching child 20 with pair: [1, 25046]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1190783, starting edge 2nd facet= 1190953,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.6464462280273438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.3323171138763428
# returned from stitch mesh: 2.0604465007781982
# Finished stitching child 20 : 2.2846648693084717
# ***************Finished big stitching iteration: 7.419918537139893***************
# Starting Child 3
# 39 25068
# Done distance matrix: 0.03643941879272461
# Child 3 There were no points close enough
# Starting Child 4
# 14 25068
# Done distance matrix: 0.0156710147857666
# Child 4 There were no points close enough
# Starting Child 5
# 4 25068
# Done distance matrix: 0.004183530807495117
# Child 5 There were no points close enough
# Starting Child 17
# 15 25068
# Done distance matrix: 0.01204991340637207
# Done Generating final pairs: 0.01653003692626953
# best_stitch_pair = [    3 25056]
# ...
# Starting Child 28
# 1 33746
# Done distance matrix: 0.0014967918395996094
# Child 28 There were no points close enough
# Starting Child 29
# 1 33746
# Done distance matrix: 0.0017752647399902344
# Child 29 There were no points close enough
# Starting Child 30
# 41 33746
# Done distance matrix: 0.11536240577697754
# Done Generating final pairs: 0.14936375617980957
# best_stitch_pair = [    1 32504]
# best_stitch_pair_size = 754726.350222273
# best_stitch_pair_distance = 872.000413255533
# best_stitch_pair_size_ratio = 0.3107364856699981
# Starting Child 31
# 7 33746
# Done distance matrix: 0.011957645416259766
# Done Generating final pairs: 0.01799154281616211
# best_stitch_pair = [    3 32499]
# best_stitch_pair_size = 848052.8372052144
# best_stitch_pair_distance = 1022.070124965267
# best_stitch_pair_size_ratio = 0.742736160262786
# Starting Child 44
# 1 33746
# Done distance matrix: 0.001636505126953125
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33746
# Done distance matrix: 0.0016672611236572266
# Child 48 There were no points close enough
# repeat_main_facets = [32504]
# child_mesh_double_indexes = [17, 30]
# min_child = 30, max_ratio = 872.000413255533
# child_meshes_stitch_facets = {11: [3, 33635], 21: [2, 33173], 24: [0, 31289], 26: [5, 33429], 30: [1, 32504], 31: [3, 32499]}
# ---Stitching child 11 with pair: [3, 33635]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1353489, starting edge 2nd facet= 1361609,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04773902893066406
# returned from stitch mesh: 2.0000460147857666
# Finished stitching child 11 : 2.271207809448242
# ---Stitching child 21 with pair: [2, 33173]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1355621, starting edge 2nd facet= 1361796,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.5111908912658691
# returned from stitch mesh: 2.105652093887329
# Finished stitching child 21 : 2.3793723583221436
# ---Stitching child 24 with pair: [0, 31289]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1246024, starting edge 2nd facet= 1361880,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.007766246795654297
# returned from stitch mesh: 1.3262939453125
# Finished stitching child 24 : 1.515580654144287
# ---Stitching child 26 with pair: [5, 33429]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1355458, starting edge 2nd facet= 1361939,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0452878475189209
# returned from stitch mesh: 1.4815692901611328
# Finished stitching child 26 : 1.6483466625213623
# ---Stitching child 30 with pair: [1, 32504]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1315518, starting edge 2nd facet= 1362212,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 5
# About to add faces
# Finished adding faces: 4.696846008300781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0591127872467041
# returned from stitch mesh: 1.8511772155761719
# Finished stitching child 30 : 2.0749616622924805
# ---Stitching child 31 with pair: [3, 32499]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1326669, starting edge 2nd facet= 1362505,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 3.4332275390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0464625358581543
# returned from stitch mesh: 1.6927340030670166
# Finished stitching child 31 : 1.973271369934082
# ***************Finished big stitching iteration: 14.163996934890747***************
# Starting Child 13
# 2 33811
# Done distance matrix: 0.003480672836303711
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 2 33811
# Done distance matrix: 0.0026214122772216797
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 3 33811
# Done distance matrix: 0.004038095474243164
# Done Generating final pairs: 0.009072303771972656
# best_stitch_pair = [    0 33767]
# best_stitch_pair_size = 243024.2720946783
# best_stitch_pair_distance = 1158.5307703945643
# best_stitch_pair_size_ratio = 0.1726593521922521
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33811
# Done distance matrix: 0.0011391639709472656
# Child 28 There were no points close enough
# Starting Child 29
# 1 33811
# Done distance matrix: 0.0011544227600097656
# Child 29 There were no points close enough
# Starting Child 44
# 1 33811
# Done distance matrix: 0.0013957023620605469
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33811
# Done distance matrix: 0.0014476776123046875
# Child 48 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {17: [0, 33767]}
# ---Stitching child 17 with pair: [0, 33767]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1362376, starting edge 2nd facet= 1362710,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.0265579223632812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.059145212173461914
# returned from stitch mesh: 1.7044460773468018
# Finished stitching child 17 : 1.968778133392334
# ***************Finished big stitching iteration: 3.96751070022583***************
# Starting Child 13
# 2 33812
# Done distance matrix: 0.004632234573364258
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 2 33812
# Done distance matrix: 0.0033392906188964844
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.0014464855194091797
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.001373291015625
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.0011639595031738281
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0013337135314941406
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 13
# 2 33812
# Done distance matrix: 0.0026073455810546875
# Done Generating final pairs: 0.006251335144042969
# best_stitch_pair = [    1 14016]
# best_stitch_pair_size = 26360.940802634468
# best_stitch_pair_distance = 2023.1114388994306
# best_stitch_pair_size_ratio = 0.7007299270072993
# Starting Child 14
# 2 33812
# Done distance matrix: 0.002630472183227539
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.001554250717163086
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.0013616085052490234
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.001220703125
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0014052391052246094
# Child 48 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {13: [1, 14016]}
# ---Stitching child 13 with pair: [1, 14016]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 46231, starting edge 2nd facet= 1362734,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 3.695487976074219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04089713096618652
# returned from stitch mesh: 1.7946884632110596
# Finished stitching child 13 : 2.0404930114746094
# ***************Finished big stitching iteration: 2.2969930171966553***************
# Starting Child 14
# 2 33812
# Done distance matrix: 0.0045795440673828125
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.003192424774169922
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.002994060516357422
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.0028111934661865234
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0027205944061279297
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 14
# 2 33812
# Done distance matrix: 0.003019571304321289
# Done Generating final pairs: 0.0075032711029052734
# best_stitch_pair = [    0 11825]
# best_stitch_pair_size = 38391.82780396769
# best_stitch_pair_distance = 2415.3730165260367
# best_stitch_pair_size_ratio = 0.8113632608454148
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.0013566017150878906
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.001257181167602539
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.001215219497680664
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0012080669403076172
# Child 48 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {14: [0, 11825]}
# ---Stitching child 14 with pair: [0, 11825]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 50673, starting edge 2nd facet= 1362774,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 26
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.936622619628906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.007974624633789062
# returned from stitch mesh: 1.44203519821167
# Finished stitching child 14 : 1.9954345226287842
# ***************Finished big stitching iteration: 2.398205518722534***************
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.0013399124145507812
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.001378774642944336
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.001459360122680664
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0013644695281982422
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.0014395713806152344
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.0013499259948730469
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.0013463497161865234
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.001478433609008789
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.001489877700805664
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.001409292221069336
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.0013988018035888672
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0016176700592041016
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 27
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 1 33812
# Done distance matrix: 0.0017626285552978516
# Child 28 There were no points close enough
# Starting Child 29
# 1 33812
# Done distance matrix: 0.0016579627990722656
# Child 29 There were no points close enough
# Starting Child 44
# 1 33812
# Done distance matrix: 0.0016727447509765625
# Child 44 There were no points close enough
# Starting Child 47
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 48
# 1 33812
# Done distance matrix: 0.0019330978393554688
# Child 48 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 116.03939318656921
# Total time for restitching = 116.0505154132843
# missed_children = [44.0, 47.0, 48.0, 27.0, 28.0, 29.0]
# Whole stitching function complete: 251.48418378829956
# 6002.978438138962

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
