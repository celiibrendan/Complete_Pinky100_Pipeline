# %%
import trimesh
import numpy as np
from collections import Counter
import time
import math
from tqdm import tqdm

# %%
#pick the mesh to process: 
file_location = "./test_meshes/"
file_location = "./"
file_name ="seperated_mesh.off"

# %%
#visualize the neuron to make sure it is correct
visualize = False
if visualize == True:
    visualize_mesh = trimesh.load_mesh(file_location + file_name )
    visualize_mesh.show()

# %% [markdown]
# # Gets parts that are outside of the main mesh

# %%
def filter_mesh_significant_outside_pieces(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces, including the main one that are not inside of main mesh

    """

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []

    #find piece with largest size
    max_index = 0
    max_face_len = len(significant_pieces[max_index].faces)

    for i in range(1,len(significant_pieces)):
        if max_face_len < len(significant_pieces[i].faces):
            max_index = i
            max_face_len = len(significant_pieces[i].faces)

    print("max_index = " + str(max_index))
    print("max_face_len = " + str(max_face_len))

    final_mesh_pieces = []

    main_mesh = significant_pieces[max_index]

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        if i != max_index:
            #get a random sample of points
            # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
            idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
            points = mesh.vertices[idx,:]
            
            
            start_time = time.time()
            signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
            print(f"Total time = {time.time() - start_time}")

            outside_percentage = sum(signed_distance < 0)/n_sample_points
            if outside_percentage > 0.9:
                final_mesh_pieces.append(mesh)
                print(f"Mesh piece {i} OUTSIDE mesh")
            else:
                print(f"Mesh piece {i} inside mesh :( ")
                
    return main_mesh,final_mesh_pieces

# %% [markdown]
# # Can probably optimize the mesh inside_outside finding process --> no

# %%
# unfiltered_mesh
# significance_threshold = 100
# n_sample_points = 3



# #def filter_mesh_significant_outside_pieces_optimized(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
# """
# Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
# with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

# Pseudocode: 
# 1) split the meshes to unconnected pieces
# 2) Filter the meshes for only those above the significance_threshold
# 3) find the biggest mesh piece
# 4) Iterate through all of the remaining pieces:
#     a. Determine if mesh inside or outside main mesh
#     b. If outside add to final list to return

# Returns: 
# 1) list of significant mesh pieces, including the main one that are not inside of main mesh

# """
# start_time = time.time()

# mesh_pieces = unfiltered_mesh.split(only_watertight=False)

# print(f"There were {len(mesh_pieces)} pieces after mesh split: {time.time() - start_time}")

# start_time = time.time()

# significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

# print(f"There were {len(significant_pieces)} pieces found after size threshold: {time.time() - start_time}")

# start_time = time.time()
# if len(significant_pieces) <=0:
#     print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
#     #return []
#     raise Exception("exiting")

# #find piece with largest size
# max_index = 0
# max_face_len = len(significant_pieces[max_index].faces)

# for i in range(1,len(significant_pieces)):
#     if max_face_len < len(significant_pieces[i].faces):
#         max_index = i
#         max_face_len = len(significant_pieces[i].faces)

# print("max_index = " + str(max_index))
# print("max_face_len = " + str(max_face_len))

# print(f"Found max len and faces: {time.time() - start_time}")

# start_time_inside = time.time()
# final_mesh_pieces = []

# main_mesh = significant_pieces[max_index]

# #final_mesh_pieces.append(main_mesh)

# for i,mesh in enumerate(significant_pieces):
#     if i != max_index:
#         print("Starting processing piece " + str(i))
#         #get a random sample of points
#         # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
#         start_time = time.time()
#         idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
#         points = mesh.vertices[idx,:]
#         print(f"Total time for finding points = {time.time() - start_time}")

#         start_time = time.time()
#         signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
#         print(f"Total time for proximity check = {time.time() - start_time}")
        
#         start_time = time.time()
#         outside_percentage = sum(signed_distance < 0)/n_sample_points
#         if outside_percentage > 0.6:
#             final_mesh_pieces.append(mesh)
#             print(f"Mesh piece {i} OUTSIDE mesh")
#         else:
#             print(f"Mesh piece {i} inside mesh :( ")
#         print(f"Total time determining Group and Appending = {time.time() - start_time}")

# print(f"Total time for Inside/Outside Cleansing: {time.time() - start_time_inside}")
# print((len(final_mesh_pieces)))

# %% [markdown]
# # This version where di all at once caused my computer to shutdown :(

# %%
# """

# """

# unfiltered_mesh
# significance_threshold = 100
# n_sample_points = 3



# #def filter_mesh_significant_outside_pieces_optimized(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
# """
# Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
# with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

# Pseudocode: 
# 1) split the meshes to unconnected pieces
# 2) Filter the meshes for only those above the significance_threshold
# 3) find the biggest mesh piece
# 4) Iterate through all of the remaining pieces:
#     a. Determine if mesh inside or outside main mesh
#     b. If outside add to final list to return

# Returns: 
# 1) list of significant mesh pieces, including the main one that are not inside of main mesh

# """
# start_time = time.time()

# mesh_pieces = unfiltered_mesh.split(only_watertight=False)

# print(f"There were {len(mesh_pieces)} pieces after mesh split: {time.time() - start_time}")

# start_time = time.time()

# significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

# print(f"There were {len(significant_pieces)} pieces found after size threshold: {time.time() - start_time}")

# start_time = time.time()
# if len(significant_pieces) <=0:
#     print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
#     #return []
#     raise Exception("exiting")

# #find piece with largest size
# max_index = 0
# max_face_len = len(significant_pieces[max_index].faces)

# for i in range(1,len(significant_pieces)):
#     if max_face_len < len(significant_pieces[i].faces):
#         max_index = i
#         max_face_len = len(significant_pieces[i].faces)

# print("max_index = " + str(max_index))
# print("max_face_len = " + str(max_face_len))

# print(f"Found max len and faces: {time.time() - start_time}")

# start_time_inside = time.time()
# final_mesh_pieces = []

# main_mesh = significant_pieces[max_index]

# #final_mesh_pieces.append(main_mesh)

# #aggregate the number of points
# print("Assembling list of points")
# total_points = np.array([])
# assembling_time = time.time()
# for i,mesh in enumerate(significant_pieces):
#     if i != max_index:
#         #print("Starting processing piece " + str(i))
#         #get a random sample of points
#         # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
#         start_time = time.time()
#         idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
#         points = mesh.vertices[idx,:]
        
#         if len(total_points) <= 0:
#             total_points = points.copy()
#         else:
#             total_points = np.concatenate([total_points,points])

#         #print(f"Total time for finding points = {time.time() - start_time}")
# print(f"Total time for assembling points = {time.time() - assembling_time}")


# start_time = time.time()
# signed_distance = trimesh.proximity.signed_distance(main_mesh,total_points)
# print(f"Total time for proximity check = {time.time() - start_time}")

# # start_time = time.time()
# # outside_percentage = sum(signed_distance < 0)/n_sample_points
# # if outside_percentage > 0.6:
# #     final_mesh_pieces.append(mesh)
# #     print(f"Mesh piece {i} OUTSIDE mesh")
# # else:
# #     print(f"Mesh piece {i} inside mesh :( ")
# # print(f"Total time determining Group and Appending = {time.time() - start_time}")        
        
# # print(f"Total time for Inside/Outside Cleansing: {time.time() - start_time_inside}")
# # print((len(final_mesh_pieces)))

# %%
#Runs the filtering function for inside and outside meshes
global_timer = time.time()

unfiltered_mesh = trimesh.load_mesh(file_location + file_name)

#setting thresholds
significance_threshold=10 #number of faces needed for pieces to be considered to be kept
n_sample_points = 3 #number of points sampled on the mesh for determination of inside or outside
start_time = time.time()

#the main mesh is the first mesh in the piece
main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
                            significance_threshold=significance_threshold,
                                n_sample_points=n_sample_points)
print(f"Total time for Mesh Cleansing: {time.time() - start_time}")
# Out:
# There were 3902 pieces after mesh split
# There were 721 pieces found after size threshold
# max_index = 0
# max_face_len = 1845336
# Total time = 23.944220066070557
# Mesh piece 1 OUTSIDE mesh
# Total time = 0.13158464431762695
# Mesh piece 2 inside mesh :(
# Total time = 0.23721909523010254
# Mesh piece 3 OUTSIDE mesh
# Total time = 1.3988544940948486
# Mesh piece 4 OUTSIDE mesh
# Total time = 0.5651600360870361
# Mesh piece 5 inside mesh :(
# Total time = 0.45454955101013184
# Mesh piece 6 inside mesh :(
# Total time = 0.3984987735748291
# Mesh piece 7 inside mesh :(
# Total time = 0.37824511528015137
# Mesh piece 8 inside mesh :(
# Total time = 0.5323667526245117
# Mesh piece 9 inside mesh :(
# Total time = 0.48783063888549805
# Mesh piece 10 inside mesh :(
# Total time = 0.5203046798706055
# Mesh piece 11 inside mesh :(
# Total time = 0.4103817939758301
# Mesh piece 12 inside mesh :(
# Total time = 0.41873955726623535
# Mesh piece 13 inside mesh :(
# Total time = 0.4172177314758301
# Mesh piece 14 inside mesh :(
# Total time = 0.4386782646179199
# Mesh piece 15 inside mesh :(
# Total time = 0.7365067005157471
# Mesh piece 16 inside mesh :(
# Total time = 0.6846294403076172
# Mesh piece 17 inside mesh :(
# Total time = 0.5413854122161865
# Mesh piece 18 inside mesh :(
# Total time = 0.6314811706542969
# Mesh piece 19 inside mesh :(
# Total time = 0.6678335666656494
# Mesh piece 20 inside mesh :(
# Total time = 0.4888753890991211
# Mesh piece 21 inside mesh :(
# Total time = 0.549067497253418
# Mesh piece 22 inside mesh :(
# Total time = 0.7120828628540039
# Mesh piece 23 inside mesh :(
# Total time = 0.5839929580688477
# Mesh piece 24 inside mesh :(
# Total time = 0.6033575534820557
# Mesh piece 25 inside mesh :(
# Total time = 0.6119179725646973
# Mesh piece 26 inside mesh :(
# Total time = 0.4773879051208496
# Mesh piece 27 inside mesh :(
# Total time = 0.5524749755859375
# Mesh piece 28 inside mesh :(
# Total time = 0.5338735580444336
# Mesh piece 29 inside mesh :(
# Total time = 0.539273738861084
# Mesh piece 30 inside mesh :(
# Total time = 0.5782594680786133
# Mesh piece 31 inside mesh :(
# Total time = 0.6676466464996338
# Mesh piece 32 inside mesh :(
# Total time = 0.6877572536468506
# Mesh piece 33 inside mesh :(
# Total time = 0.7214534282684326
# Mesh piece 34 inside mesh :(
# Total time = 0.7230966091156006
# Mesh piece 35 inside mesh :(
# Total time = 0.6290774345397949
# Mesh piece 36 inside mesh :(
# Total time = 0.5167250633239746
# Mesh piece 37 inside mesh :(
# Total time = 0.5545423030853271
# Mesh piece 38 inside mesh :(
# Total time = 0.6196966171264648
# Mesh piece 39 inside mesh :(
# Total time = 0.6117472648620605
# Mesh piece 40 inside mesh :(
# Total time = 0.6493039131164551
# Mesh piece 41 inside mesh :(
# Total time = 0.589890718460083
# Mesh piece 42 inside mesh :(
# Total time = 0.5586321353912354
# Mesh piece 43 inside mesh :(
# Total time = 0.5978491306304932
# Mesh piece 44 inside mesh :(
# Total time = 0.5867300033569336
# Mesh piece 45 inside mesh :(
# Total time = 0.6184666156768799
# Mesh piece 46 inside mesh :(
# Total time = 0.5825920104980469
# Mesh piece 47 inside mesh :(
# Total time = 0.7352404594421387
# Mesh piece 48 inside mesh :(
# Total time = 0.7729768753051758
# Mesh piece 49 inside mesh :(
# Total time = 0.667757511138916
# Mesh piece 50 inside mesh :(
# Total time = 0.452070951461792
# Mesh piece 51 inside mesh :(
# Total time = 0.41857004165649414
# Mesh piece 52 inside mesh :(
# Total time = 0.4544105529785156
# Mesh piece 53 inside mesh :(
# Total time = 0.501035213470459
# Mesh piece 54 inside mesh :(
# Total time = 0.5545353889465332
# Mesh piece 55 inside mesh :(
# Total time = 0.3847064971923828
# Mesh piece 56 inside mesh :(
# Total time = 0.5147523880004883
# Mesh piece 57 inside mesh :(
# Total time = 0.4768197536468506
# Mesh piece 58 inside mesh :(
# Total time = 0.547111988067627
# Mesh piece 59 inside mesh :(
# Total time = 0.3587489128112793
# Mesh piece 60 inside mesh :(
# Total time = 0.46885037422180176
# Mesh piece 61 inside mesh :(
# Total time = 0.45531654357910156
# Mesh piece 62 inside mesh :(
# Total time = 0.501953125
# Mesh piece 63 inside mesh :(
# Total time = 0.46039414405822754
# Mesh piece 64 inside mesh :(
# Total time = 0.4226372241973877
# Mesh piece 65 inside mesh :(
# Total time = 0.47290897369384766
# Mesh piece 66 inside mesh :(
# Total time = 0.5257749557495117
# Mesh piece 67 inside mesh :(
# Total time = 0.42913079261779785
# Mesh piece 68 inside mesh :(
# Total time = 0.6645519733428955
# Mesh piece 69 inside mesh :(
# Total time = 0.5725159645080566
# Mesh piece 70 inside mesh :(
# Total time = 0.5739779472351074
# Mesh piece 71 inside mesh :(
# Total time = 0.3966348171234131
# Mesh piece 72 inside mesh :(
# Total time = 0.5514285564422607
# Mesh piece 73 inside mesh :(
# Total time = 0.5346174240112305
# Mesh piece 74 inside mesh :(
# Total time = 0.16812920570373535
# Mesh piece 75 OUTSIDE mesh
# Total time = 0.06815814971923828
# Mesh piece 76 OUTSIDE mesh
# Total time = 0.1712024211883545
# Mesh piece 77 OUTSIDE mesh
# Total time = 0.07051801681518555
# Mesh piece 78 OUTSIDE mesh
# Total time = 0.08836150169372559
# Mesh piece 79 OUTSIDE mesh
# Total time = 0.11488127708435059
# Mesh piece 80 OUTSIDE mesh
# Total time = 0.7942535877227783
# Mesh piece 81 OUTSIDE mesh
# Total time = 0.15659856796264648
# Mesh piece 82 OUTSIDE mesh
# Total time = 0.5401005744934082
# Mesh piece 83 inside mesh :(
# Total time = 0.42564988136291504
# Mesh piece 84 inside mesh :(
# Total time = 2.170337438583374
# Mesh piece 85 OUTSIDE mesh
# Total time = 0.4117586612701416
# Mesh piece 86 inside mesh :(
# Total time = 0.6685454845428467
# Mesh piece 87 inside mesh :(
# Total time = 0.6724743843078613
# Mesh piece 88 inside mesh :(
# Total time = 0.6510133743286133
# Mesh piece 89 inside mesh :(
# Total time = 0.702916145324707
# Mesh piece 90 inside mesh :(
# Total time = 0.80668044090271
# Mesh piece 91 inside mesh :(
# Total time = 0.786719799041748
# Mesh piece 92 inside mesh :(
# Total time = 0.6607260704040527
# Mesh piece 93 inside mesh :(
# Total time = 0.6966311931610107
# Mesh piece 94 inside mesh :(
# Total time = 0.7349710464477539
# Mesh piece 95 inside mesh :(
# Total time = 0.2390117645263672
# Mesh piece 96 OUTSIDE mesh
# Total time = 0.15927839279174805
# Mesh piece 97 OUTSIDE mesh
# Total time = 0.06536245346069336
# Mesh piece 98 OUTSIDE mesh
# Total time = 0.08619189262390137
# Mesh piece 99 OUTSIDE mesh
# Total time = 0.41648340225219727
# Mesh piece 100 inside mesh :(
# Total time = 0.4105260372161865
# Mesh piece 101 inside mesh :(
# Total time = 0.33568644523620605
# Mesh piece 102 inside mesh :(
# Total time = 0.8807721138000488
# Mesh piece 103 inside mesh :(
# Total time = 1.7917392253875732
# Mesh piece 104 OUTSIDE mesh
# Total time = 1.277733564376831
# Mesh piece 105 inside mesh :(
# Total time = 1.0215866565704346
# Mesh piece 106 inside mesh :(
# Total time = 0.9181098937988281
# Mesh piece 107 inside mesh :(
# Total time = 0.8611354827880859
# Mesh piece 108 inside mesh :(
# Total time = 0.7685825824737549
# Mesh piece 109 inside mesh :(
# Total time = 0.6567063331604004
# Mesh piece 110 inside mesh :(
# Total time = 0.5328030586242676
# Mesh piece 111 inside mesh :(
# Total time = 0.6110668182373047
# Mesh piece 112 inside mesh :(
# Total time = 0.6282289028167725
# Mesh piece 113 inside mesh :(
# Total time = 0.6050586700439453
# Mesh piece 114 inside mesh :(
# Total time = 0.7359447479248047
# Mesh piece 115 inside mesh :(
# Total time = 0.8337335586547852
# Mesh piece 116 inside mesh :(
# Total time = 0.6598412990570068
# Mesh piece 117 inside mesh :(
# Total time = 0.694969654083252
# Mesh piece 118 inside mesh :(
# Total time = 0.6490554809570312
# Mesh piece 119 inside mesh :(
# Total time = 0.6114232540130615
# Mesh piece 120 inside mesh :(
# Total time = 0.6131973266601562
# Mesh piece 121 inside mesh :(
# Total time = 0.6206409931182861
# Mesh piece 122 inside mesh :(
# Total time = 0.6777510643005371
# Mesh piece 123 inside mesh :(
# Total time = 0.7021434307098389
# Mesh piece 124 inside mesh :(
# Total time = 0.6531760692596436
# Mesh piece 125 inside mesh :(
# Total time = 0.6116592884063721
# Mesh piece 126 inside mesh :(
# Total time = 0.6315085887908936
# Mesh piece 127 inside mesh :(
# Total time = 0.6296701431274414
# Mesh piece 128 inside mesh :(
# Total time = 0.6339058876037598
# Mesh piece 129 inside mesh :(
# Total time = 0.7009656429290771
# Mesh piece 130 inside mesh :(
# Total time = 0.6308693885803223
# Mesh piece 131 inside mesh :(
# Total time = 0.779956579208374
# Mesh piece 132 inside mesh :(
# Total time = 0.5983176231384277
# Mesh piece 133 inside mesh :(
# Total time = 0.8731169700622559
# Mesh piece 134 inside mesh :(
# Total time = 0.7066640853881836
# Mesh piece 135 inside mesh :(
# Total time = 0.5057206153869629
# Mesh piece 136 inside mesh :(
# Total time = 0.47003769874572754
# Mesh piece 137 inside mesh :(
# Total time = 0.5319540500640869
# Mesh piece 138 inside mesh :(
# Total time = 0.5927724838256836
# Mesh piece 139 inside mesh :(
# Total time = 0.5927104949951172
# Mesh piece 140 inside mesh :(
# Total time = 0.6156110763549805
# Mesh piece 141 inside mesh :(
# Total time = 0.5823080539703369
# Mesh piece 142 inside mesh :(
# Total time = 0.5987377166748047
# Mesh piece 143 inside mesh :(
# Total time = 0.30437707901000977
# Mesh piece 144 inside mesh :(
# Total time = 0.30747389793395996
# Mesh piece 145 inside mesh :(
# Total time = 0.4426891803741455
# Mesh piece 146 inside mesh :(
# Total time = 0.3364417552947998
# Mesh piece 147 inside mesh :(
# Total time = 0.2724487781524658
# Mesh piece 148 inside mesh :(
# Total time = 0.28427624702453613
# Mesh piece 149 inside mesh :(
# Total time = 0.28348875045776367
# Mesh piece 150 inside mesh :(
# Total time = 0.26587915420532227
# Mesh piece 151 inside mesh :(
# Total time = 0.15094542503356934
# Mesh piece 152 OUTSIDE mesh
# Total time = 0.12040472030639648
# Mesh piece 153 OUTSIDE mesh
# Total time = 0.022298097610473633
# Mesh piece 154 OUTSIDE mesh
# Total time = 0.025683164596557617
# Mesh piece 155 OUTSIDE mesh
# Total time = 0.034714698791503906
# Mesh piece 156 OUTSIDE mesh
# Total time = 0.031897783279418945
# Mesh piece 157 OUTSIDE mesh
# Total time = 0.3507227897644043
# Mesh piece 158 inside mesh :(
# Total time = 0.029648303985595703
# Mesh piece 159 OUTSIDE mesh
# Total time = 1.722834587097168
# Mesh piece 160 OUTSIDE mesh
# Total time = 0.9714934825897217
# Mesh piece 161 inside mesh :(
# Total time = 0.8238639831542969
# Mesh piece 162 inside mesh :(
# Total time = 0.8165595531463623
# Mesh piece 163 inside mesh :(
# Total time = 0.838383674621582
# Mesh piece 164 inside mesh :(
# Total time = 0.8210701942443848
# Mesh piece 165 inside mesh :(
# Total time = 0.8170459270477295
# Mesh piece 166 inside mesh :(
# Total time = 0.589613676071167
# Mesh piece 167 inside mesh :(
# Total time = 0.48227429389953613
# Mesh piece 168 inside mesh :(
# Total time = 0.4657001495361328
# Mesh piece 169 inside mesh :(
# Total time = 0.48819684982299805
# Mesh piece 170 inside mesh :(
# Total time = 0.5446875095367432
# Mesh piece 171 inside mesh :(
# Total time = 0.5452878475189209
# Mesh piece 172 inside mesh :(
# Total time = 0.45558857917785645
# Mesh piece 173 inside mesh :(
# Total time = 0.5493619441986084
# Mesh piece 174 inside mesh :(
# Total time = 0.45700931549072266
# Mesh piece 175 inside mesh :(
# Total time = 0.38024115562438965
# Mesh piece 176 inside mesh :(
# Total time = 0.40770530700683594
# Mesh piece 177 inside mesh :(
# Total time = 0.44437694549560547
# Mesh piece 178 inside mesh :(
# Total time = 0.47504711151123047
# Mesh piece 179 inside mesh :(
# Total time = 0.5555593967437744
# Mesh piece 180 inside mesh :(
# Total time = 0.5133678913116455
# Mesh piece 181 inside mesh :(
# Total time = 0.48493528366088867
# Mesh piece 182 inside mesh :(
# Total time = 0.5169427394866943
# Mesh piece 183 inside mesh :(
# Total time = 0.5335206985473633
# Mesh piece 184 inside mesh :(
# Total time = 0.4940173625946045
# Mesh piece 185 inside mesh :(
# Total time = 0.5923800468444824
# Mesh piece 186 inside mesh :(
# Total time = 0.5284252166748047
# Mesh piece 187 inside mesh :(
# Total time = 0.5287361145019531
# Mesh piece 188 inside mesh :(
# Total time = 0.6251356601715088
# Mesh piece 189 inside mesh :(
# Total time = 0.5849146842956543
# Mesh piece 190 inside mesh :(
# Total time = 0.5290625095367432
# Mesh piece 191 inside mesh :(
# Total time = 0.7052161693572998
# Mesh piece 192 inside mesh :(
# Total time = 0.5414328575134277
# Mesh piece 193 inside mesh :(
# Total time = 0.49070191383361816
# Mesh piece 194 inside mesh :(
# Total time = 0.6070990562438965
# Mesh piece 195 inside mesh :(
# Total time = 0.6091785430908203
# Mesh piece 196 inside mesh :(
# Total time = 0.07612919807434082
# Mesh piece 197 OUTSIDE mesh
# Total time = 0.029848098754882812
# Mesh piece 198 OUTSIDE mesh
# Total time = 0.05035710334777832
# Mesh piece 199 OUTSIDE mesh
# Total time = 0.03729724884033203
# Mesh piece 200 OUTSIDE mesh
# Total time = 0.10534834861755371
# Mesh piece 201 OUTSIDE mesh
# Total time = 0.15204596519470215
# Mesh piece 202 OUTSIDE mesh
# Total time = 0.5106511116027832
# Mesh piece 203 inside mesh :(
# Total time = 0.4753899574279785
# Mesh piece 204 inside mesh :(
# Total time = 0.452803373336792
# Mesh piece 205 inside mesh :(
# Total time = 0.6784524917602539
# Mesh piece 206 inside mesh :(
# Total time = 0.5844593048095703
# Mesh piece 207 inside mesh :(
# Total time = 0.5396196842193604
# Mesh piece 208 inside mesh :(
# Total time = 0.5972914695739746
# Mesh piece 209 inside mesh :(
# Total time = 0.537590742111206
# Mesh piece 210 inside mesh :(
# Total time = 0.5556533336639404
# Mesh piece 211 inside mesh :(
# Total time = 0.8383679389953613
# Mesh piece 212 inside mesh :(
# Total time = 0.5990896224975586
# Mesh piece 213 inside mesh :(
# Total time = 0.4218411445617676
# Mesh piece 214 inside mesh :(
# Total time = 0.6599719524383545
# Mesh piece 215 inside mesh :(
# Total time = 0.5190961360931396
# Mesh piece 216 inside mesh :(
# Total time = 0.6090137958526611
# Mesh piece 217 inside mesh :(
# Total time = 0.6220793724060059
# Mesh piece 218 inside mesh :(
# Total time = 0.525813102722168
# Mesh piece 219 inside mesh :(
# Total time = 0.7684230804443359
# Mesh piece 220 inside mesh :(
# Total time = 0.7305188179016113
# Mesh piece 221 inside mesh :(
# Total time = 0.7631819248199463
# Mesh piece 222 inside mesh :(
# Total time = 0.7475438117980957
# Mesh piece 223 inside mesh :(
# Total time = 0.7673196792602539
# Mesh piece 224 inside mesh :(
# Total time = 0.7918722629547119
# Mesh piece 225 inside mesh :(
# Total time = 0.5823466777801514
# Mesh piece 226 inside mesh :(
# Total time = 0.6330420970916748
# Mesh piece 227 inside mesh :(
# Total time = 0.6068079471588135
# Mesh piece 228 inside mesh :(
# Total time = 0.7285139560699463
# Mesh piece 229 inside mesh :(
# Total time = 0.5199530124664307
# Mesh piece 230 inside mesh :(
# Total time = 0.6691625118255615
# Mesh piece 231 inside mesh :(
# Total time = 0.7484960556030273
# Mesh piece 232 inside mesh :(
# Total time = 0.49889206886291504
# Mesh piece 233 inside mesh :(
# Total time = 0.628288745880127
# Mesh piece 234 inside mesh :(
# Total time = 0.6425161361694336
# Mesh piece 235 inside mesh :(
# Total time = 0.5335371494293213
# Mesh piece 236 inside mesh :(
# Total time = 0.5094883441925049
# Mesh piece 237 inside mesh :(
# Total time = 0.5655298233032227
# Mesh piece 238 inside mesh :(
# Total time = 0.796994686126709
# Mesh piece 239 inside mesh :(
# Total time = 0.09537577629089355
# Mesh piece 240 OUTSIDE mesh
# Total time = 0.7543449401855469
# Mesh piece 241 OUTSIDE mesh
# Total time = 0.35306334495544434
# Mesh piece 242 inside mesh :(
# Total time = 0.7346060276031494
# Mesh piece 243 inside mesh :(
# Total time = 0.8340826034545898
# Mesh piece 244 inside mesh :(
# Total time = 0.6327693462371826
# Mesh piece 245 inside mesh :(
# Total time = 0.6950297355651855
# Mesh piece 246 inside mesh :(
# Total time = 0.9982030391693115
# Mesh piece 247 inside mesh :(
# Total time = 0.9317886829376221
# Mesh piece 248 inside mesh :(
# Total time = 0.8446106910705566
# Mesh piece 249 inside mesh :(
# Total time = 0.8821847438812256
# Mesh piece 250 inside mesh :(
# Total time = 1.0798933506011963
# Mesh piece 251 inside mesh :(
# Total time = 1.094850778579712
# Mesh piece 252 inside mesh :(
# Total time = 0.7745509147644043
# Mesh piece 253 inside mesh :(
# Total time = 0.8776605129241943
# Mesh piece 254 inside mesh :(
# Total time = 0.764232873916626
# Mesh piece 255 inside mesh :(
# Total time = 0.7838802337646484
# Mesh piece 256 inside mesh :(
# Total time = 0.8054158687591553
# Mesh piece 257 inside mesh :(
# Total time = 0.859898567199707
# Mesh piece 258 inside mesh :(
# Total time = 0.8748211860656738
# Mesh piece 259 inside mesh :(
# Total time = 1.0070710182189941
# Mesh piece 260 inside mesh :(
# Total time = 0.9972143173217773
# Mesh piece 261 inside mesh :(
# Total time = 1.0610055923461914
# Mesh piece 262 inside mesh :(
# Total time = 0.8551332950592041
# Mesh piece 263 inside mesh :(
# Total time = 0.8177919387817383
# Mesh piece 264 inside mesh :(
# Total time = 0.8713970184326172
# Mesh piece 265 inside mesh :(
# Total time = 0.7956411838531494
# Mesh piece 266 inside mesh :(
# Total time = 0.8948180675506592
# Mesh piece 267 inside mesh :(
# Total time = 0.8471338748931885
# Mesh piece 268 inside mesh :(
# Total time = 0.9144856929779053
# Mesh piece 269 inside mesh :(
# Total time = 0.8054559230804443
# Mesh piece 270 inside mesh :(
# Total time = 1.08101487159729
# Mesh piece 271 inside mesh :(
# Total time = 0.8484964370727539
# Mesh piece 272 inside mesh :(
# Total time = 0.8962974548339844
# Mesh piece 273 inside mesh :(
# Total time = 1.046630620956421
# Mesh piece 274 inside mesh :(
# Total time = 0.5521512031555176
# Mesh piece 275 inside mesh :(
# Total time = 0.5578155517578125
# Mesh piece 276 inside mesh :(
# Total time = 0.5190565586090088
# Mesh piece 277 inside mesh :(
# Total time = 0.5309457778930664
# Mesh piece 278 inside mesh :(
# Total time = 0.6843645572662354
# Mesh piece 279 inside mesh :(
# Total time = 0.6634299755096436
# Mesh piece 280 inside mesh :(
# Total time = 0.6899514198303223
# Mesh piece 281 inside mesh :(
# Total time = 0.6712334156036377
# Mesh piece 282 inside mesh :(
# Total time = 0.6776161193847656
# Mesh piece 283 inside mesh :(
# Total time = 0.002378702163696289
# Mesh piece 284 OUTSIDE mesh
# Total time = 0.6633222103118896
# Mesh piece 285 inside mesh :(
# Total time = 0.5549957752227783
# Mesh piece 286 inside mesh :(
# Total time = 0.7837035655975342
# Mesh piece 287 inside mesh :(
# Total time = 0.6871778964996338
# Mesh piece 288 inside mesh :(
# Total time = 0.6182620525360107
# Mesh piece 289 inside mesh :(
# Total time = 0.790630578994751
# Mesh piece 290 inside mesh :(
# Total time = 0.9440732002258301
# Mesh piece 291 inside mesh :(
# Total time = 1.0068347454071045
# Mesh piece 292 inside mesh :(
# Total time = 0.7032389640808105
# Mesh piece 293 inside mesh :(
# Total time = 0.6487019062042236
# Mesh piece 294 inside mesh :(
# Total time = 0.7433586120605469
# Mesh piece 295 inside mesh :(
# Total time = 0.7196216583251953
# Mesh piece 296 inside mesh :(
# Total time = 0.510115385055542
# Mesh piece 297 inside mesh :(
# Total time = 0.5760862827301025
# Mesh piece 298 inside mesh :(
# Total time = 0.8656365871429443
# Mesh piece 299 inside mesh :(
# Total time = 0.1465928554534912
# Mesh piece 300 OUTSIDE mesh
# Total time = 0.15232372283935547
# Mesh piece 301 OUTSIDE mesh
# Total time = 0.15628409385681152
# Mesh piece 302 OUTSIDE mesh
# Total time = 0.15648460388183594
# Mesh piece 303 inside mesh :(
# Total time = 0.03200650215148926
# Mesh piece 304 OUTSIDE mesh
# Total time = 0.03184914588928223
# Mesh piece 305 OUTSIDE mesh
# Total time = 0.5258004665374756
# Mesh piece 306 inside mesh :(
# Total time = 1.069465160369873
# Mesh piece 307 inside mesh :(
# Total time = 1.088667631149292
# Mesh piece 308 inside mesh :(
# Total time = 0.9802653789520264
# Mesh piece 309 inside mesh :(
# Total time = 0.9358959197998047
# Mesh piece 310 inside mesh :(
# Total time = 0.9378602504730225
# Mesh piece 311 inside mesh :(
# Total time = 1.0027997493743896
# Mesh piece 312 inside mesh :(
# Total time = 1.1043508052825928
# Mesh piece 313 inside mesh :(
# Total time = 1.0948879718780518
# Mesh piece 314 inside mesh :(
# Total time = 1.20401930809021
# Mesh piece 315 inside mesh :(
# Total time = 1.1603617668151855
# Mesh piece 316 inside mesh :(
# Total time = 1.0095045566558838
# Mesh piece 317 inside mesh :(
# Total time = 0.9821691513061523
# Mesh piece 318 inside mesh :(
# Total time = 1.266381025314331
# Mesh piece 319 inside mesh :(
# Total time = 1.0054059028625488
# Mesh piece 320 inside mesh :(
# Total time = 1.0093131065368652
# Mesh piece 321 inside mesh :(
# Total time = 0.987767219543457
# Mesh piece 322 inside mesh :(
# Total time = 1.0285110473632812
# Mesh piece 323 inside mesh :(
# Total time = 1.185199499130249
# Mesh piece 324 inside mesh :(
# Total time = 0.9146337509155273
# Mesh piece 325 inside mesh :(
# Total time = 1.0333125591278076
# Mesh piece 326 inside mesh :(
# Total time = 1.143289566040039
# Mesh piece 327 inside mesh :(
# Total time = 1.046194076538086
# Mesh piece 328 inside mesh :(
# Total time = 1.0489447116851807
# Mesh piece 329 inside mesh :(
# Total time = 1.169492244720459
# Mesh piece 330 inside mesh :(
# Total time = 1.0433437824249268
# Mesh piece 331 inside mesh :(
# Total time = 0.9438230991363525
# Mesh piece 332 inside mesh :(
# Total time = 0.7881820201873779
# Mesh piece 333 inside mesh :(
# Total time = 1.0188865661621094
# Mesh piece 334 inside mesh :(
# Total time = 0.641655445098877
# Mesh piece 335 inside mesh :(
# Total time = 0.5547254085540771
# Mesh piece 336 inside mesh :(
# Total time = 0.7595114707946777
# Mesh piece 337 inside mesh :(
# Total time = 0.5385270118713379
# Mesh piece 338 inside mesh :(
# Total time = 0.7008659839630127
# Mesh piece 339 inside mesh :(
# Total time = 0.577254056930542
# Mesh piece 340 inside mesh :(
# Total time = 0.6649985313415527
# Mesh piece 341 inside mesh :(
# Total time = 0.5541903972625732
# Mesh piece 342 inside mesh :(
# Total time = 0.6539595127105713
# Mesh piece 343 inside mesh :(
# Total time = 0.6231725215911865
# Mesh piece 344 inside mesh :(
# Total time = 0.2910611629486084
# Mesh piece 345 inside mesh :(
# Total time = 1.9027323722839355
# Mesh piece 346 OUTSIDE mesh
# Total time = 0.6330351829528809
# Mesh piece 347 inside mesh :(
# Total time = 0.4667489528656006
# Mesh piece 348 inside mesh :(
# Total time = 0.47328805923461914
# Mesh piece 349 inside mesh :(
# Total time = 0.435837984085083
# Mesh piece 350 inside mesh :(
# Total time = 0.4654994010925293
# Mesh piece 351 inside mesh :(
# Total time = 0.6628701686859131
# Mesh piece 352 inside mesh :(
# Total time = 0.6181313991546631
# Mesh piece 353 inside mesh :(
# Total time = 0.5598123073577881
# Mesh piece 354 inside mesh :(
# Total time = 0.7055442333221436
# Mesh piece 355 inside mesh :(
# Total time = 0.6906979084014893
# Mesh piece 356 inside mesh :(
# Total time = 0.621711254119873
# Mesh piece 357 inside mesh :(
# Total time = 0.7133212089538574
# Mesh piece 358 inside mesh :(
# Total time = 0.44165825843811035
# Mesh piece 359 inside mesh :(
# Total time = 0.6719563007354736
# Mesh piece 360 inside mesh :(
# Total time = 0.6154682636260986
# Mesh piece 361 inside mesh :(
# Total time = 0.5429129600524902
# Mesh piece 362 inside mesh :(
# Total time = 0.4549388885498047
# Mesh piece 363 inside mesh :(
# Total time = 0.49851512908935547
# Mesh piece 364 inside mesh :(
# Total time = 0.3305854797363281
# Mesh piece 365 inside mesh :(
# Total time = 0.446321964263916
# Mesh piece 366 inside mesh :(
# Total time = 2.3854637145996094
# Mesh piece 367 OUTSIDE mesh
# Total time = 0.7738072872161865
# Mesh piece 368 inside mesh :(
# Total time = 0.45496678352355957
# Mesh piece 369 inside mesh :(
# Total time = 0.49962592124938965
# Mesh piece 370 inside mesh :(
# Total time = 0.5177104473114014
# Mesh piece 371 inside mesh :(
# Total time = 0.44314098358154297
# Mesh piece 372 inside mesh :(
# Total time = 0.41355323791503906
# Mesh piece 373 inside mesh :(
# Total time = 0.5189118385314941
# Mesh piece 374 inside mesh :(
# Total time = 0.43338775634765625
# Mesh piece 375 inside mesh :(
# Total time = 0.5610084533691406
# Mesh piece 376 inside mesh :(
# Total time = 0.8766269683837891
# Mesh piece 377 inside mesh :(
# Total time = 0.950397253036499
# Mesh piece 378 inside mesh :(
# Total time = 0.21158838272094727
# Mesh piece 379 inside mesh :(
# Total time = 0.9772496223449707
# Mesh piece 380 inside mesh :(
# Total time = 0.787996768951416
# Mesh piece 381 inside mesh :(
# Total time = 0.6409139633178711
# Mesh piece 382 inside mesh :(
# Total time = 0.5342659950256348
# Mesh piece 383 inside mesh :(
# Total time = 0.5446929931640625
# Mesh piece 384 inside mesh :(
# Total time = 0.45795321464538574
# Mesh piece 385 inside mesh :(
# Total time = 0.5965983867645264
# Mesh piece 386 inside mesh :(
# Total time = 0.768552303314209
# Mesh piece 387 inside mesh :(
# Total time = 0.8446571826934814
# Mesh piece 388 inside mesh :(
# Total time = 0.940812349319458
# Mesh piece 389 inside mesh :(
# Total time = 0.6795587539672852
# Mesh piece 390 inside mesh :(
# Total time = 0.6288206577301025
# Mesh piece 391 inside mesh :(
# Total time = 0.5463573932647705
# Mesh piece 392 inside mesh :(
# Total time = 0.6045558452606201
# Mesh piece 393 inside mesh :(
# Total time = 0.5609004497528076
# Mesh piece 394 inside mesh :(
# Total time = 0.6369931697845459
# Mesh piece 395 inside mesh :(
# Total time = 0.8428530693054199
# Mesh piece 396 inside mesh :(
# Total time = 0.6259567737579346
# Mesh piece 397 inside mesh :(
# Total time = 0.5954012870788574
# Mesh piece 398 inside mesh :(
# Total time = 0.7216722965240479
# Mesh piece 399 inside mesh :(
# Total time = 0.5833053588867188
# Mesh piece 400 inside mesh :(
# Total time = 0.47388410568237305
# Mesh piece 401 inside mesh :(
# Total time = 0.4954102039337158
# Mesh piece 402 inside mesh :(
# Total time = 0.49259305000305176
# Mesh piece 403 inside mesh :(
# Total time = 0.5195484161376953
# Mesh piece 404 inside mesh :(
# Total time = 0.5367085933685303
# Mesh piece 405 inside mesh :(
# Total time = 0.6069025993347168
# Mesh piece 406 inside mesh :(
# Total time = 0.5191652774810791
# Mesh piece 407 inside mesh :(
# Total time = 0.5948805809020996
# Mesh piece 408 inside mesh :(
# Total time = 0.5136806964874268
# Mesh piece 409 inside mesh :(
# Total time = 0.5646648406982422
# Mesh piece 410 inside mesh :(
# Total time = 0.5889992713928223
# Mesh piece 411 inside mesh :(
# Total time = 0.5363318920135498
# Mesh piece 412 inside mesh :(
# Total time = 0.04370546340942383
# Mesh piece 413 OUTSIDE mesh
# Total time = 0.11910295486450195
# Mesh piece 414 OUTSIDE mesh
# Total time = 1.238168716430664
# Mesh piece 415 OUTSIDE mesh
# Total time = 0.6001479625701904
# Mesh piece 416 inside mesh :(
# Total time = 0.6052956581115723
# Mesh piece 417 inside mesh :(
# Total time = 0.5675666332244873
# Mesh piece 418 inside mesh :(
# Total time = 0.5769772529602051
# Mesh piece 419 inside mesh :(
# Total time = 0.5609169006347656
# Mesh piece 420 inside mesh :(
# Total time = 0.3446800708770752
# Mesh piece 421 inside mesh :(
# Total time = 0.37682461738586426
# Mesh piece 422 inside mesh :(
# Total time = 0.40486860275268555
# Mesh piece 423 inside mesh :(
# Total time = 0.4250485897064209
# Mesh piece 424 inside mesh :(
# Total time = 0.40755724906921387
# Mesh piece 425 inside mesh :(
# Total time = 1.2389941215515137
# Mesh piece 426 inside mesh :(
# Total time = 0.8320739269256592
# Mesh piece 427 inside mesh :(
# Total time = 0.6540570259094238
# Mesh piece 428 inside mesh :(
# Total time = 0.686255693435669
# Mesh piece 429 inside mesh :(
# Total time = 0.7259345054626465
# Mesh piece 430 inside mesh :(
# Total time = 0.7221477031707764
# Mesh piece 431 inside mesh :(
# Total time = 0.8679876327514648
# Mesh piece 432 inside mesh :(
# Total time = 0.9761030673980713
# Mesh piece 433 inside mesh :(
# Total time = 0.8781428337097168
# Mesh piece 434 inside mesh :(
# Total time = 0.8086903095245361
# Mesh piece 435 inside mesh :(
# Total time = 0.8352861404418945
# Mesh piece 436 inside mesh :(
# Total time = 0.7300589084625244
# Mesh piece 437 inside mesh :(
# Total time = 0.7927286624908447
# Mesh piece 438 inside mesh :(
# Total time = 0.8389370441436768
# Mesh piece 439 inside mesh :(
# Total time = 0.6560237407684326
# Mesh piece 440 inside mesh :(
# Total time = 0.7083530426025391
# Mesh piece 441 inside mesh :(
# Total time = 0.8253438472747803
# Mesh piece 442 inside mesh :(
# Total time = 0.7313897609710693
# Mesh piece 443 inside mesh :(
# Total time = 0.7306208610534668
# Mesh piece 444 inside mesh :(
# Total time = 0.6748971939086914
# Mesh piece 445 inside mesh :(
# Total time = 0.8094761371612549
# Mesh piece 446 inside mesh :(
# Total time = 0.8696606159210205
# Mesh piece 447 inside mesh :(
# Total time = 0.4264841079711914
# Mesh piece 448 OUTSIDE mesh
# Total time = 0.47684288024902344
# Mesh piece 449 OUTSIDE mesh
# Total time = 0.45485424995422363
# Mesh piece 450 OUTSIDE mesh
# Total time = 0.8990130424499512
# Mesh piece 451 inside mesh :(
# Total time = 0.8500852584838867
# Mesh piece 452 inside mesh :(
# Total time = 0.8913323879241943
# Mesh piece 453 inside mesh :(
# Total time = 1.0767343044281006
# Mesh piece 454 inside mesh :(
# Total time = 0.9811604022979736
# Mesh piece 455 inside mesh :(
# Total time = 0.7221193313598633
# Mesh piece 456 inside mesh :(
# Total time = 0.7336862087249756
# Mesh piece 457 inside mesh :(
# Total time = 0.6972899436950684
# Mesh piece 458 inside mesh :(
# Total time = 0.7026355266571045
# Mesh piece 459 inside mesh :(
# Total time = 0.4232320785522461
# Mesh piece 460 inside mesh :(
# Total time = 0.5229229927062988
# Mesh piece 461 inside mesh :(
# Total time = 0.6402411460876465
# Mesh piece 462 inside mesh :(
# Total time = 0.6621944904327393
# Mesh piece 463 inside mesh :(
# Total time = 0.5181980133056641
# Mesh piece 464 inside mesh :(
# Total time = 0.4933493137359619
# Mesh piece 465 inside mesh :(
# Total time = 0.4830665588378906
# Mesh piece 466 inside mesh :(
# Total time = 0.5209767818450928
# Mesh piece 467 inside mesh :(
# Total time = 0.4604790210723877
# Mesh piece 468 inside mesh :(
# Total time = 0.4749417304992676
# Mesh piece 469 inside mesh :(
# Total time = 0.5286595821380615
# Mesh piece 470 inside mesh :(
# Total time = 0.5042743682861328
# Mesh piece 471 inside mesh :(
# Total time = 0.5039019584655762
# Mesh piece 472 inside mesh :(
# Total time = 0.5013759136199951
# Mesh piece 473 inside mesh :(
# Total time = 0.5236608982086182
# Mesh piece 474 inside mesh :(
# Total time = 0.7359204292297363
# Mesh piece 475 inside mesh :(
# Total time = 0.614344596862793
# Mesh piece 476 inside mesh :(
# Total time = 0.5176470279693604
# Mesh piece 477 inside mesh :(
# Total time = 0.6409761905670166
# Mesh piece 478 inside mesh :(
# Total time = 0.6603183746337891
# Mesh piece 479 inside mesh :(
# Total time = 0.7643897533416748
# Mesh piece 480 inside mesh :(
# Total time = 0.9101831912994385
# Mesh piece 481 inside mesh :(
# Total time = 0.9277751445770264
# Mesh piece 482 inside mesh :(
# Total time = 0.8061482906341553
# Mesh piece 483 inside mesh :(
# Total time = 0.7705137729644775
# Mesh piece 484 inside mesh :(
# Total time = 0.8002710342407227
# Mesh piece 485 inside mesh :(
# Total time = 0.8204348087310791
# Mesh piece 486 inside mesh :(
# Total time = 0.7608809471130371
# Mesh piece 487 inside mesh :(
# Total time = 0.9575760364532471
# Mesh piece 488 inside mesh :(
# Total time = 1.340649127960205
# Mesh piece 489 inside mesh :(
# Total time = 1.0167102813720703
# Mesh piece 490 inside mesh :(
# Total time = 0.9286513328552246
# Mesh piece 491 inside mesh :(
# Total time = 0.7940709590911865
# Mesh piece 492 inside mesh :(
# Total time = 1.0416746139526367
# Mesh piece 493 inside mesh :(
# Total time = 1.0131220817565918
# Mesh piece 494 inside mesh :(
# Total time = 1.0332794189453125
# Mesh piece 495 inside mesh :(
# Total time = 0.8294224739074707
# Mesh piece 496 inside mesh :(
# Total time = 0.8171918392181396
# Mesh piece 497 inside mesh :(
# Total time = 0.9005236625671387
# Mesh piece 498 inside mesh :(
# Total time = 0.7058348655700684
# Mesh piece 499 inside mesh :(
# Total time = 0.6952652931213379
# Mesh piece 500 inside mesh :(
# Total time = 0.6689453125
# Mesh piece 501 inside mesh :(
# Total time = 0.7678632736206055
# Mesh piece 502 inside mesh :(
# Total time = 0.9241111278533936
# Mesh piece 503 inside mesh :(
# Total time = 0.983379602432251
# Mesh piece 504 inside mesh :(
# Total time = 0.8095240592956543
# Mesh piece 505 inside mesh :(
# Total time = 1.1635596752166748
# Mesh piece 506 inside mesh :(
# Total time = 0.8210122585296631
# Mesh piece 507 inside mesh :(
# Total time = 1.055934190750122
# Mesh piece 508 inside mesh :(
# Total time = 1.0468578338623047
# Mesh piece 509 inside mesh :(
# Total time = 0.9127113819122314
# Mesh piece 510 inside mesh :(
# Total time = 1.0979344844818115
# Mesh piece 511 inside mesh :(
# Total time = 1.1563291549682617
# Mesh piece 512 inside mesh :(
# Total time = 1.171210765838623
# Mesh piece 513 inside mesh :(
# Total time = 1.001169204711914
# Mesh piece 514 inside mesh :(
# Total time = 0.9300785064697266
# Mesh piece 515 inside mesh :(
# Total time = 1.0223572254180908
# Mesh piece 516 inside mesh :(
# Total time = 1.052504301071167
# Mesh piece 517 inside mesh :(
# Total time = 1.2418198585510254
# Mesh piece 518 inside mesh :(
# Total time = 1.1152405738830566
# Mesh piece 519 inside mesh :(
# Total time = 1.0115160942077637
# Mesh piece 520 inside mesh :(
# Total time = 0.8982231616973877
# Mesh piece 521 inside mesh :(
# Total time = 1.0817289352416992
# Mesh piece 522 inside mesh :(
# Total time = 1.0680246353149414
# Mesh piece 523 inside mesh :(
# Total time = 0.9309239387512207
# Mesh piece 524 inside mesh :(
# Total time = 0.6495349407196045
# Mesh piece 525 inside mesh :(
# Total time = 0.5731894969940186
# Mesh piece 526 inside mesh :(
# Total time = 0.7017714977264404
# Mesh piece 527 inside mesh :(
# Total time = 0.7817370891571045
# Mesh piece 528 inside mesh :(
# Total time = 0.6502492427825928
# Mesh piece 529 OUTSIDE mesh
# Total time = 0.658024787902832
# Mesh piece 530 OUTSIDE mesh
# Total time = 0.7804532051086426
# Mesh piece 531 inside mesh :(
# Total time = 1.1337592601776123
# Mesh piece 532 inside mesh :(
# Total time = 1.14912748336792
# Mesh piece 533 inside mesh :(
# Total time = 0.8808474540710449
# Mesh piece 534 inside mesh :(
# Total time = 1.108597993850708
# Mesh piece 535 inside mesh :(
# Total time = 1.2051467895507812
# Mesh piece 536 inside mesh :(
# Total time = 0.8848376274108887
# Mesh piece 537 inside mesh :(
# Total time = 1.0270602703094482
# Mesh piece 538 inside mesh :(
# Total time = 1.0704731941223145
# Mesh piece 539 inside mesh :(
# Total time = 0.9165916442871094
# Mesh piece 540 inside mesh :(
# Total time = 0.9232170581817627
# Mesh piece 541 inside mesh :(
# Total time = 0.9614348411560059
# Mesh piece 542 inside mesh :(
# Total time = 1.0017609596252441
# Mesh piece 543 inside mesh :(
# Total time = 0.9526407718658447
# Mesh piece 544 inside mesh :(
# Total time = 1.1010551452636719
# Mesh piece 545 inside mesh :(
# Total time = 1.1677775382995605
# Mesh piece 546 inside mesh :(
# Total time = 0.7265818119049072
# Mesh piece 547 inside mesh :(
# Total time = 0.9669387340545654
# Mesh piece 548 inside mesh :(
# Total time = 0.8132481575012207
# Mesh piece 549 inside mesh :(
# Total time = 0.7911512851715088
# Mesh piece 550 inside mesh :(
# Total time = 1.051156759262085
# Mesh piece 551 inside mesh :(
# Total time = 0.9736328125
# Mesh piece 552 inside mesh :(
# Total time = 0.053171634674072266
# Mesh piece 553 OUTSIDE mesh
# Total time = 0.03797769546508789
# Mesh piece 554 inside mesh :(
# Total time = 0.8429334163665771
# Mesh piece 555 inside mesh :(
# Total time = 0.6410942077636719
# Mesh piece 556 inside mesh :(
# Total time = 0.6193370819091797
# Mesh piece 557 inside mesh :(
# Total time = 0.8111906051635742
# Mesh piece 558 inside mesh :(
# Total time = 0.7345497608184814
# Mesh piece 559 inside mesh :(
# Total time = 0.7078568935394287
# Mesh piece 560 inside mesh :(
# Total time = 0.735694169998169
# Mesh piece 561 inside mesh :(
# Total time = 0.6197502613067627
# Mesh piece 562 inside mesh :(
# Total time = 0.8418776988983154
# Mesh piece 563 inside mesh :(
# Total time = 0.7706894874572754
# Mesh piece 564 inside mesh :(
# Total time = 0.7988662719726562
# Mesh piece 565 inside mesh :(
# Total time = 0.9639334678649902
# Mesh piece 566 inside mesh :(
# Total time = 0.7604649066925049
# Mesh piece 567 inside mesh :(
# Total time = 1.043360948562622
# Mesh piece 568 inside mesh :(
# Total time = 0.2621932029724121
# Mesh piece 569 inside mesh :(
# Total time = 0.22326207160949707
# Mesh piece 570 inside mesh :(
# Total time = 0.17218542098999023
# Mesh piece 571 OUTSIDE mesh
# Total time = 0.46979260444641113
# Mesh piece 572 inside mesh :(
# Total time = 0.863091230392456
# Mesh piece 573 inside mesh :(
# Total time = 1.017491102218628
# Mesh piece 574 inside mesh :(
# Total time = 0.8502054214477539
# Mesh piece 575 inside mesh :(
# Total time = 0.744269847869873
# Mesh piece 576 inside mesh :(
# Total time = 0.6893205642700195
# Mesh piece 577 inside mesh :(
# Total time = 0.8231587409973145
# Mesh piece 578 inside mesh :(
# Total time = 0.6351056098937988
# Mesh piece 579 inside mesh :(
# Total time = 0.6742570400238037
# Mesh piece 580 inside mesh :(
# Total time = 0.864264726638794
# Mesh piece 581 inside mesh :(
# Total time = 0.6019260883331299
# Mesh piece 582 inside mesh :(
# Total time = 0.5815422534942627
# Mesh piece 583 inside mesh :(
# Total time = 0.9325480461120605
# Mesh piece 584 inside mesh :(
# Total time = 0.6664140224456787
# Mesh piece 585 inside mesh :(
# Total time = 1.1186518669128418
# Mesh piece 586 inside mesh :(
# Total time = 1.1025211811065674
# Mesh piece 587 inside mesh :(
# Total time = 0.879941463470459
# Mesh piece 588 inside mesh :(
# Total time = 0.6920144557952881
# Mesh piece 589 inside mesh :(
# Total time = 0.7772395610809326
# Mesh piece 590 inside mesh :(
# Total time = 0.746739387512207
# Mesh piece 591 inside mesh :(
# Total time = 0.7778282165527344
# Mesh piece 592 inside mesh :(
# Total time = 0.7098932266235352
# Mesh piece 593 inside mesh :(
# Total time = 0.5691933631896973
# Mesh piece 594 inside mesh :(
# Total time = 0.694638729095459
# Mesh piece 595 inside mesh :(
# Total time = 0.6092259883880615
# Mesh piece 596 inside mesh :(
# Total time = 0.6312909126281738
# Mesh piece 597 inside mesh :(
# Total time = 0.6822090148925781
# Mesh piece 598 inside mesh :(
# Total time = 0.5665829181671143
# Mesh piece 599 inside mesh :(
# Total time = 0.6730639934539795
# Mesh piece 600 inside mesh :(
# Total time = 0.8519206047058105
# Mesh piece 601 inside mesh :(
# Total time = 0.6333093643188477
# Mesh piece 602 inside mesh :(
# Total time = 0.8137602806091309
# Mesh piece 603 inside mesh :(
# Total time = 0.8676187992095947
# Mesh piece 604 inside mesh :(
# Total time = 0.7451858520507812
# Mesh piece 605 inside mesh :(
# Total time = 0.7112627029418945
# Mesh piece 606 inside mesh :(
# Total time = 0.7202484607696533
# Mesh piece 607 inside mesh :(
# Total time = 0.6572210788726807
# Mesh piece 608 inside mesh :(
# Total time = 0.7134652137756348
# Mesh piece 609 inside mesh :(
# Total time = 0.9899990558624268
# Mesh piece 610 inside mesh :(
# Total time = 0.234236478805542
# Mesh piece 611 inside mesh :(
# Total time = 0.2048330307006836
# Mesh piece 612 inside mesh :(
# Total time = 0.2438831329345703
# Mesh piece 613 inside mesh :(
# Total time = 0.2251286506652832
# Mesh piece 614 inside mesh :(
# Total time = 0.279742956161499
# Mesh piece 615 inside mesh :(
# Total time = 1.0072503089904785
# Mesh piece 616 inside mesh :(
# Total time = 1.1427905559539795
# Mesh piece 617 inside mesh :(
# Total time = 0.9861588478088379
# Mesh piece 618 inside mesh :(
# Total time = 0.7713584899902344
# Mesh piece 619 inside mesh :(
# Total time = 0.9270274639129639
# Mesh piece 620 inside mesh :(
# Total time = 0.979816198348999
# Mesh piece 621 inside mesh :(
# Total time = 0.8283812999725342
# Mesh piece 622 inside mesh :(
# Total time = 0.740447998046875
# Mesh piece 623 inside mesh :(
# Total time = 0.9511826038360596
# Mesh piece 624 inside mesh :(
# Total time = 0.8462963104248047
# Mesh piece 625 inside mesh :(
# Total time = 0.6888186931610107
# Mesh piece 626 inside mesh :(
# Total time = 0.9649932384490967
# Mesh piece 627 inside mesh :(
# Total time = 0.845921516418457
# Mesh piece 628 inside mesh :(
# Total time = 0.7852396965026855
# Mesh piece 629 inside mesh :(
# Total time = 0.779545783996582
# Mesh piece 630 inside mesh :(
# Total time = 0.6381258964538574
# Mesh piece 631 inside mesh :(
# Total time = 0.659848690032959
# Mesh piece 632 inside mesh :(
# Total time = 0.6491248607635498
# Mesh piece 633 inside mesh :(
# Total time = 0.800424337387085
# Mesh piece 634 inside mesh :(
# Total time = 0.6606979370117188
# Mesh piece 635 inside mesh :(
# Total time = 0.644505500793457
# Mesh piece 636 inside mesh :(
# Total time = 0.6273860931396484
# Mesh piece 637 inside mesh :(
# Total time = 0.6307852268218994
# Mesh piece 638 inside mesh :(
# Total time = 0.5839176177978516
# Mesh piece 639 inside mesh :(
# Total time = 0.6236557960510254
# Mesh piece 640 inside mesh :(
# Total time = 0.5448141098022461
# Mesh piece 641 inside mesh :(
# Total time = 0.8245968818664551
# Mesh piece 642 inside mesh :(
# Total time = 0.8006861209869385
# Mesh piece 643 inside mesh :(
# Total time = 0.7767488956451416
# Mesh piece 644 inside mesh :(
# Total time = 0.8088209629058838
# Mesh piece 645 inside mesh :(
# Total time = 0.7747366428375244
# Mesh piece 646 inside mesh :(
# Total time = 0.590430736541748
# Mesh piece 647 inside mesh :(
# Total time = 0.8353936672210693
# Mesh piece 648 inside mesh :(
# Total time = 0.9627156257629395
# Mesh piece 649 inside mesh :(
# Total time = 0.7861254215240479
# Mesh piece 650 inside mesh :(
# Total time = 0.6491739749908447
# Mesh piece 651 inside mesh :(
# Total time = 0.7818965911865234
# Mesh piece 652 inside mesh :(
# Total time = 0.7767796516418457
# Mesh piece 653 inside mesh :(
# Total time = 1.034489393234253
# Mesh piece 654 inside mesh :(
# Total time = 0.9223840236663818
# Mesh piece 655 inside mesh :(
# Total time = 0.7966759204864502
# Mesh piece 656 inside mesh :(
# Total time = 1.0678431987762451
# Mesh piece 657 inside mesh :(
# Total time = 1.0178239345550537
# Mesh piece 658 inside mesh :(
# Total time = 0.8155660629272461
# Mesh piece 659 inside mesh :(
# Total time = 0.7063179016113281
# Mesh piece 660 inside mesh :(
# Total time = 0.7892794609069824
# Mesh piece 661 inside mesh :(
# Total time = 0.7846426963806152
# Mesh piece 662 inside mesh :(
# Total time = 0.7853891849517822
# Mesh piece 663 inside mesh :(
# Total time = 0.7677145004272461
# Mesh piece 664 inside mesh :(
# Total time = 0.6991407871246338
# Mesh piece 665 inside mesh :(
# Total time = 0.8187520503997803
# Mesh piece 666 inside mesh :(
# Total time = 0.7354984283447266
# Mesh piece 667 inside mesh :(
# Total time = 0.7502467632293701
# Mesh piece 668 inside mesh :(
# Total time = 0.7890298366546631
# Mesh piece 669 inside mesh :(
# Total time = 0.9866671562194824
# Mesh piece 670 inside mesh :(
# Total time = 0.87994384765625
# Mesh piece 671 inside mesh :(
# Total time = 0.828132152557373
# Mesh piece 672 inside mesh :(
# Total time = 0.9708359241485596
# Mesh piece 673 inside mesh :(
# Total time = 0.49378275871276855
# Mesh piece 674 inside mesh :(
# Total time = 0.4919157028198242
# Mesh piece 675 inside mesh :(
# Total time = 0.5949509143829346
# Mesh piece 676 inside mesh :(
# Total time = 0.3553640842437744
# Mesh piece 677 inside mesh :(
# Total time = 0.536853551864624
# Mesh piece 678 inside mesh :(
# Total time = 0.5020480155944824
# Mesh piece 679 inside mesh :(
# Total time = 0.4046313762664795
# Mesh piece 680 inside mesh :(
# Total time = 0.44687986373901367
# Mesh piece 681 inside mesh :(
# Total time = 0.5019478797912598
# Mesh piece 682 inside mesh :(
# Total time = 0.6522524356842041
# Mesh piece 683 inside mesh :(
# Total time = 0.5030574798583984
# Mesh piece 684 inside mesh :(
# Total time = 0.6086533069610596
# Mesh piece 685 inside mesh :(
# Total time = 0.5602133274078369
# Mesh piece 686 inside mesh :(
# Total time = 0.6032149791717529
# Mesh piece 687 inside mesh :(
# Total time = 0.5334360599517822
# Mesh piece 688 inside mesh :(
# Total time = 0.5305283069610596
# Mesh piece 689 inside mesh :(
# Total time = 0.4994230270385742
# Mesh piece 690 inside mesh :(
# Total time = 0.4860079288482666
# Mesh piece 691 inside mesh :(
# Total time = 0.6156008243560791
# Mesh piece 692 inside mesh :(
# Total time = 0.7951076030731201
# Mesh piece 693 inside mesh :(
# Total time = 0.8269002437591553
# Mesh piece 694 inside mesh :(
# Total time = 0.9292325973510742
# Mesh piece 695 inside mesh :(
# Total time = 0.6879711151123047
# Mesh piece 696 inside mesh :(
# Total time = 0.8558318614959717
# Mesh piece 697 inside mesh :(
# Total time = 1.0532450675964355
# Mesh piece 698 inside mesh :(
# Total time = 0.9175624847412109
# Mesh piece 699 inside mesh :(
# Total time = 0.8775389194488525
# Mesh piece 700 inside mesh :(
# Total time = 0.9358232021331787
# Mesh piece 701 inside mesh :(
# Total time = 0.8198184967041016
# Mesh piece 702 inside mesh :(
# Total time = 0.7639591693878174
# Mesh piece 703 inside mesh :(
# Total time = 0.6624088287353516
# Mesh piece 704 inside mesh :(
# Total time = 0.7429542541503906
# Mesh piece 705 inside mesh :(
# Total time = 1.111215353012085
# Mesh piece 706 inside mesh :(
# Total time = 0.9054722785949707
# Mesh piece 707 inside mesh :(
# Total time = 0.9105544090270996
# Mesh piece 708 inside mesh :(
# Total time = 0.6790568828582764
# Mesh piece 709 inside mesh :(
# Total time = 0.5393543243408203
# Mesh piece 710 inside mesh :(
# Total time = 0.5397100448608398
# Mesh piece 711 inside mesh :(
# Total time = 0.6144704818725586
# Mesh piece 712 inside mesh :(
# Total time = 0.6628203392028809
# Mesh piece 713 inside mesh :(
# Total time = 0.7647366523742676
# Mesh piece 714 inside mesh :(
# Total time = 0.8557050228118896
# Mesh piece 715 inside mesh :(
# Total time = 0.8584470748901367
# Mesh piece 716 inside mesh :(
# Total time = 0.9076261520385742
# Mesh piece 717 inside mesh :(
# Total time = 0.26818275451660156
# Mesh piece 718 inside mesh :(
# Total time = 0.27199459075927734
# Mesh piece 719 inside mesh :(
# Total time = 0.28087615966796875
# Mesh piece 720 inside mesh :(
# Total time for Mesh Cleansing: 519.2917590141296

# %% [markdown]
# # HOW TO SAVE AND LOAD OF THE MESHES

# %%
np.savez("./test_meshes/main_and_child_meshes_array.npz",main_mesh=[main_mesh],child_meshes=child_meshes)

# %%
# loaded_meshes = np.load("./test_meshes/main_and_child_meshes_array.npz")
# loaded_meshes.files

# main_mesh_loaded = loaded_meshes["main_mesh"][0]
# child_meshes_loaded = loaded_meshes["child_meshes"]

# print(len(child_meshes_loaded))

# %%
# main_mesh = main_mesh_loaded
# child_meshes = child_meshes_loaded

# %% [markdown]
# # FACET GENERATION AND FILTERING FUNCTIONS

# %%
import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# need a way of finding the neighbors that have to share adjacent faces
def create_neighbors_lookup(mesh):
    start_time = time.time()
    neighbors_lookup = dict([(i,[]) for i in range(0,len(mesh.faces))])
    #print(f"Creating empty dictionary : {time.time() - start_time}")
    
    start_time = time.time()
    for adj in mesh.face_adjacency:
        neighbors_lookup[adj[0]].append(adj[1])
        neighbors_lookup[adj[1]].append(adj[0])
    #print(f"Filling in neighbors lookup : {time.time() - start_time}")
    
    return neighbors_lookup

# need a way of finding the neighbors that have to share adjacent faces
def create_facet_lookup(mesh):
    start_time = time.time()
    facets_lookup = np.ones(len(main_mesh.faces))*-1
    
    start_time = time.time()
    for jj,facet in enumerate(mesh.facets):
        for fac in facet:
            facets_lookup[fac] = jj
    
    print(f"Filling in facet lookup : {time.time() - start_time}")
    
    return facets_lookup

def filter_and_expand_facets(new_mesh,
                             first_pass_size_threshold=2000,
                             normal_closeness=0.985):
    
    """
    
    """
    
    #filter the facets that are below a size threshold
    new_facets = new_mesh.facets[np.where(new_mesh.facets_area > first_pass_size_threshold)[0]]

    #is a fast lookup for the neighbors of a certain face
    neighbors_lookup = create_neighbors_lookup(new_mesh)
    
    #generate a normals lookup table and see if works faster than regular lookup
    normal_lookup = {}

    for i in range(0,len(new_mesh.faces)):
        normal_lookup[i] = new_mesh.face_normals[i]
    
    global_start_time = time.time()
    final_facets= [0]*len(new_facets)
    
    #creates entire list of neighbors that have been added in expansion
    #if a neighbor was already added that was already in the current facet
    #then that facet has already been absorbed and need to delete that
    

    #these are facets that need to be deleted at the end
    
    
    
    """
    Other way to optimize

    1) Create lookup dictionary that maps the face back to the facet
    2) when add a neighbor add the set of all their facets to the facet to delete


    """
    print("Total number of facets = " + str(len(new_facets)))
    facet_lookup = create_facet_lookup(new_mesh)
    facets_to_delete = set()
    
    for i,facet in enumerate(new_facets):
#         mini_global_start_time = time.time()
    #     print(facet)
    #     print(type(facet))
    #     start_time = time.time()
    #     print([find_neighbors(k) for k in facet])
    
    

#         new_time = time.time()
#         # make sure that there are no repeats of facets by checking for common elements
#         if not set(total_added_neighbors).isdisjoint(facet):
#             facets_to_delete.append(i)
#             #print("found overlapping neighbor")
#             continue
#         print(f"Time for check = {time.time() - new_time}")
            
        if i in facets_to_delete:
            continue
    
    
    #gets all of the neighbors
        total_neighbors = list(set(np.hstack([neighbors_lookup[k] for k in facet])).difference(set(facet)))
    #     print(total_neighbors)
    #     print(f"time initial neighbors: {(time.time() - start_time)}")
        neighbors_to_add = []
        neighbors_checked = []
        #print(total_neighbors)

        #just get the normal from one of the faces already in the facet
    #     start_time = time.time()
        facet_normal = normal_lookup[facet[0]]

    #     total_dot_time = 0
        while len(total_neighbors) > 0:
            current_neighbor = total_neighbors.pop()
            neighbors_checked.append(current_neighbor)

    #         print("--------------")
    # #         #check to see if neighbor has same normal face
    # #         start_dot_time = time.time()
    # #         dot_result = np.dot(new_mesh.face_normals[current_neighbor],facet_normal) #> normal_closeness
    # #         print(dot_result)
    # #         print((time.time() - start_dot_time) * 1000)

    #         start_dot_time = time.time()
    #         print(current_neighbor)
    #         #a = new_mesh.face_normals[current_neighbor]

    #         print((time.time() - start_dot_time) * 1000)
    #         dot_result = a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness
    #         print(dot_result)
    #         print((time.time() - start_dot_time) * 1000)
    #         print("--------------")

    #         total_dot_time += (time.time() - start_dot_time)*1000

            a = normal_lookup[current_neighbor]
            if a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness:

                neighbors_to_add.append(current_neighbor)
                #get the neighbors of this current face
                for neigh in neighbors_lookup[current_neighbor]:
                    #only add those neighbors that havent already been checked, in original facet group, or already in list to check
                    if neigh not in neighbors_checked and neigh not in facet and neigh not in total_neighbors:
                        total_neighbors.append(neigh)
    #     print(f"Total dot time: {total_dot_time}")
    #     print(f"time loop: {(time.time() - start_time)}")
    #     print("neighbors_to_add = " + str(neighbors_to_add))abs
    #     print("neighbors_checked = " + str(neighbors_checked))
    #     print("adding list = " + str(list(facet) + neighbors_to_add))
    #     start_time = time.time()
        
        #get all the facets of the neighbors to add
        neighbors_to_add_facets = facet_lookup[neighbors_to_add]
        facets_to_delete = facets_to_delete.union(set(neighbors_to_add_facets))
        
        final_facets[i] = np.array(list(facet) + neighbors_to_add)
    #     print(f"Appending to list: {(time.time() - start_time)}")

#         print(f"Total time: {(time.time() - mini_global_start_time)}")
    #     print("------------------------------------------------------")


    print(f"Total Facet building time: {(time.time() - global_start_time)}")
    print(f"Found Total number of overlapping faces: {len(facets_to_delete)}")
    
    #print("facets_to_delete = " + str(facets_to_delete))
    #delete the faces = 
    final_facets = np.delete(final_facets,list(facets_to_delete),axis=0)
    return final_facets

def filter_final_facets(gap_mesh):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """
    
    final_facets = filter_and_expand_facets(gap_mesh,
                                 first_pass_size_threshold=2000,
                                 normal_closeness=0.985)
    
    

    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #print(final_facets_mean_filtered)
    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
# THE OLDER FACET FILTERING METHOD THAT DOESN'T RETURN AS MANY FACETS BUT MISSES OUT ON THE 
#SMALL ONES

def filter_final_facets_working(gap_mesh,final_facets):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """


    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    
#     #need to make sure they are array of arrays
#     thresholld_boolean_results = final_facets_mean > adjacency_threshold
#     for fa,individual_facet in  enumerate(final_facets):
#         if thresholld_boolean_results[fa] == True:
#             np
    
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]
    
    if len(final_facets_mean_filtered.shape) > 1:
        total_array = np.empty(final_facets_mean_filtered.shape[0],object)
        total_array[:] = [x for x in final_facets_mean_filtered]
        final_facets_mean_filtered = total_array
        print("Had to restructure the array because was 2D array")

    

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %% [markdown]
# # Fixing the non-array of arrays problem

# %%
# example_array_2D = np.array([[2,2],[3,3]])
# example_array_1D = np.array([np.array([2,2]),np.array([3,3,5])])

# #can't tell the difference from the shapes but can by the length of the shapes
# print(len(example_array_2D.shape) > 1) 
# print(len(example_array_1D.shape) > 1)


# #how to turn it into 

# if len(example_array_2D.shape) > 1:
#     total_array = np.empty(example_array_2D.shape[0],object)
#     total_array[:] = [x for x in example_array_2D]
#     example_array_2D = total_array
#     print("inside loop")

# print(example_array_2D)

# if len(example_array_1D.shape) > 1:
#     total_array = np.empty(example_array_1D.shape[0],object)
#     total_array[:] = [x for x in example_array_1D]
#     example_array_1D = total_array
#     print("inside loop")

# print(example_array_1D)

# # total_array = np.array(example_array_2D[0])
# # for i,arr in enumerate(example_array_2D):
# #     if i == 0:
# #         continue
# #     total_array = np.hstack([total_array,np.array(arr)])

# # print(total_array)

# %%
def filter_final_facets_optimized_with_checks(example_mesh,
                                  normal_closeness=0.99,
                                  first_pass_size_threshold=6000):
    """
    Way of computing facets that uses trimesh grouping function and normals threshold
    instead of the pre-built trimesh.facets
    
    """

    #get the facets for the child mesh
    start_time_total = time.time()

    #switch out with dot product
    
    
    #Old way of computing the dot product manually
    total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
    
    #using manual method
#     print(len(total_normals[:,0]*total_normals[:,1]))
    start_normal = time.time()
    total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
    print(f"Total normals took {time.time() - start_normal}")
    ''' DONT HAVE TO DO DOT PRODUCT BECAUSE JUST WANT TO MULTIPLY THE ROWS OF EACH COLUMN'''
#     print("About to do dot product")
#     dot_start = time.time()
#     a = total_normals[:,0]
#     b = total_normals[:,1].T
#     #new way using the dot product
#     total_normal_dots = np.dot(a,b)
    
    
    #get the True/False value if face adjacency is within normal closeness
    start_normal = time.time()
    total_normal_dots_facet_mask = total_normal_dots > normal_closeness
    print(f"Boolean mask finished: {time.time() - start_normal}")

    #getting the grouping of the faces into facets within the threshold
    start_normal = time.time()
    components = trimesh.graph.connected_components(example_mesh.face_adjacency[total_normal_dots_facet_mask],
                                          nodes=np.arange(len(example_mesh.faces)),
                                          min_len=2,
                                          engine="None")
    print(f"Grouping took: {time.time() - start_normal}")
    
    

    #print(f"Lenght of facets BEFORE filtering = {len(components)}")
    
    #filter by the size
    
    start_normal = time.time()
    size_filtered_components = [facet_list for facet_list in components 
                                    if find_polygon_area(example_mesh,facet_list) > first_pass_size_threshold]
    print(f"Filtering edges by size finished: {time.time() - start_normal}, facet # = {len(size_filtered_components)}")

#     if facet_index in checking_list:
#         print("size_filtered_components = " + str(size_filtered_components))

    #filter by the convexity
    #final_facets_mean_filtered,final_facets_centers = filter_final_facets(example_mesh,size_filtered_components)
    
    start_normal = time.time()
    final_facets_mean_filtered,final_facets_centers = filter_final_facets_working(example_mesh,size_filtered_components)
    print(f"Filtering by convexity and getting centers took: {time.time() - start_normal}, facet # = {len(final_facets_mean_filtered)}")

#     if facet_index in checking_list:
#         print("final_facets_mean_filtered = " + str(final_facets_mean_filtered))
    
    print(f"Total Time = {time.time() - start_time_total}")

    return final_facets_mean_filtered,final_facets_centers

# %% [markdown]
# # DEBUGGING THE FILTER FACETS SPEED

# %%
# start_time = time.time()

# #facets_list, centers_list,neighbors_added = filter_final_facets(main_mesh)
# final_facets,facet_centers = filter_final_facets(main_mesh)

# print(f"Total time for overlapping check = {time.time() - start_time}")

# final_facets_1 = final_facets[0]
# len(total_added_neighbors)


# len(final_facets)

# new_time = time.time()
# # make sure that there are no repeats of facets by checking for common elements
# if not set(total_added_neighbors).isdisjoint(final_facets_1):
#     #facets_to_delete.append(i)
#     print("found overlapping neighbor")
# print(f"Time for check = {(time.time() - new_time)*len(final_facets)/60}")

# """
# Conclusion this method would be too slow
# """

# %% [markdown]
# # ACTUALLY CALCULATING THE FACETS

# %%
"""
Rule: 
1) if mesh size is above a threshold --> run the unoptimized less careful version
2) if mesh is below that size --> run optimized more generous (but with all the filters )

"""
facet_time = time.time()
start_time = time.time()

length_threshold = 60000

if len(main_mesh.faces > length_threshold):
    print(f" face length {len(main_mesh.faces)} using unoptimized facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
    
else:
    print(f" face length {len(main_mesh.faces)} using OPTIMIZED facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets_optimized_with_checks(main_mesh)
    

print(f"Finished { len(main_mesh_facets)} facets for main mesh: {time.time() - start_time}")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    print("Starting child " + str(jj))
    start_time = time.time()
    if len(gap_mesh.faces) > length_threshold:
        print(f" face length {len(gap_mesh.faces)} using unoptimized facets")
        child_meshes_facets.append(filter_final_facets(gap_mesh))
    else:
        print(f" face length {len(gap_mesh.faces)} using OPTIMIZED facets")
        child_meshes_facets.append(filter_final_facets_optimized_with_checks(gap_mesh))

    
    print(f"Finished facets for child {jj} : {time.time() - start_time} with facet length = {len(child_meshes_facets[jj][0])}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]
# Out:
#  face length 1845336 using unoptimized facets
# Total number of facets = 59411
# Filling in facet lookup : 0.10857701301574707
# Total Facet building time: 17.032164812088013
# Found Total number of overlapping faces: 17861
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: FutureWarning: in the future negative indices will not be ignored by `numpy.delete`.
# Finished 11118 facets for main mesh: 56.04564428329468
# Starting child 0
#  face length 117018 using unoptimized facets
# Total number of facets = 3693
# Filling in facet lookup : 0.006978750228881836
# Total Facet building time: 0.3807353973388672
# Found Total number of overlapping faces: 1091
# Finished facets for child 0 : 2.5485422611236572 with facet length = 699
# Starting child 1
#  face length 16458 using OPTIMIZED facets
# Total normals took 0.000579833984375
# Boolean mask finished: 0.0002155303955078125
# Grouping took: 0.006208181381225586
# Filtering edges by size finished: 0.4717590808868408, facet # = 2151
# Filtering by convexity and getting centers took: 0.6288547515869141, facet # = 644
# Total Time = 1.1165363788604736
# Finished facets for child 1 : 1.1169114112854004 with facet length = 644
# Starting child 2
#  face length 32560 using OPTIMIZED facets
# Total normals took 0.0010776519775390625
# Boolean mask finished: 0.0001404285430908203
# Grouping took: 0.011780738830566406
# Filtering edges by size finished: 1.0181002616882324, facet # = 4380
# Filtering by convexity and getting centers took: 1.1754651069641113, facet # = 485
# Total Time = 2.2243564128875732
# Finished facets for child 2 : 2.225159168243408 with facet length = 485
# Starting child 3
#  face length 27890 using OPTIMIZED facets
# Total normals took 0.0008840560913085938
# Boolean mask finished: 8.106231689453125e-05
# Grouping took: 0.009358406066894531
# Filtering edges by size finished: 0.8036725521087646, facet # = 3670
# Filtering by convexity and getting centers took: 1.123178482055664, facet # = 887
# Total Time = 1.9523515701293945
# Finished facets for child 3 : 1.953040361404419 with facet length = 887
# Starting child 4
#  face length 17314 using OPTIMIZED facets
# Total normals took 0.0007579326629638672
# Boolean mask finished: 0.00021886825561523438
# Grouping took: 0.006325244903564453
# Filtering edges by size finished: 0.6470892429351807, facet # = 2120
# Filtering by convexity and getting centers took: 0.6740882396697998, facet # = 521
# Total Time = 1.3382153511047363
# Finished facets for child 4 : 1.3386282920837402 with facet length = 521
# Starting child 5
#  face length 5608 using OPTIMIZED facets
# Total normals took 0.0002110004425048828
# Boolean mask finished: 0.0002009868621826172
# Grouping took: 0.0025298595428466797
# Filtering edges by size finished: 0.1393890380859375, facet # = 718
# Filtering by convexity and getting centers took: 0.23980379104614258, facet # = 203
# Total Time = 0.3859596252441406
# Finished facets for child 5 : 0.38611388206481934 with facet length = 203
# Starting child 6
#  face length 16714 using OPTIMIZED facets
# Total normals took 0.0006837844848632812
# Boolean mask finished: 0.00020313262939453125
# Grouping took: 0.006095409393310547
# Filtering edges by size finished: 0.5523221492767334, facet # = 2168
# Filtering by convexity and getting centers took: 0.6797964572906494, facet # = 567
# Total Time = 1.2479286193847656
# Finished facets for child 6 : 1.2482972145080566 with facet length = 567
# Starting child 7
#  face length 8374 using OPTIMIZED facets
# Total normals took 0.00029540061950683594
# Boolean mask finished: 0.0002009868621826172
# Grouping took: 0.0032129287719726562
# Filtering edges by size finished: 0.24295258522033691, facet # = 976
# Filtering by convexity and getting centers took: 0.28658437728881836, facet # = 212
# Total Time = 0.5380847454071045
# Finished facets for child 7 : 0.5382859706878662 with facet length = 212
# Starting child 8
#  face length 5420 using OPTIMIZED facets
# Total normals took 0.00019168853759765625
# Boolean mask finished: 0.00012731552124023438
# Grouping took: 0.00262451171875
# Filtering edges by size finished: 0.18436050415039062, facet # = 653
# Filtering by convexity and getting centers took: 0.187485933303833, facet # = 170
# Total Time = 0.3787569999694824
# Finished facets for child 8 : 0.3790154457092285 with facet length = 170
# Starting child 9
#  face length 19204 using OPTIMIZED facets
# Total normals took 0.0006666183471679688
# Boolean mask finished: 8.058547973632812e-05
# Grouping took: 0.006653547286987305
# Filtering edges by size finished: 0.5414328575134277, facet # = 2357
# Filtering by convexity and getting centers took: 0.7245697975158691, facet # = 460
# Total Time = 1.2828178405761719
# Finished facets for child 9 : 1.2834742069244385 with facet length = 460
# Starting child 10
#  face length 3524 using OPTIMIZED facets
# Total normals took 0.00018978118896484375
# Boolean mask finished: 8.034706115722656e-05
# Grouping took: 0.0020236968994140625
# Filtering edges by size finished: 0.09822773933410645, facet # = 430
# Filtering by convexity and getting centers took: 0.1705336570739746, facet # = 130
# Total Time = 0.27388548851013184
# Finished facets for child 10 : 0.2739877700805664 with facet length = 130
# Starting child 11
#  face length 12664 using OPTIMIZED facets
# Total normals took 0.0004315376281738281
# Boolean mask finished: 8.0108642578125e-05
# Grouping took: 0.004660129547119141
# Filtering edges by size finished: 0.3499734401702881, facet # = 1752
# Filtering by convexity and getting centers took: 0.5253064632415771, facet # = 290
# Total Time = 0.886890172958374
# Finished facets for child 11 : 0.8871822357177734 with facet length = 290
# Starting child 12
#  face length 6432 using OPTIMIZED facets
# Total normals took 0.0002357959747314453
# Boolean mask finished: 8.988380432128906e-05
# Grouping took: 0.002838134765625
# Filtering edges by size finished: 0.19319868087768555, facet # = 830
# Filtering by convexity and getting centers took: 0.2633397579193115, facet # = 191
# Total Time = 0.46352148056030273
# Finished facets for child 12 : 0.46367812156677246 with facet length = 191
# Starting child 13
#  face length 6132 using OPTIMIZED facets
# Total normals took 0.00022149085998535156
# Boolean mask finished: 9.393692016601562e-05
# Grouping took: 0.002603292465209961
# Filtering edges by size finished: 0.18798589706420898, facet # = 792
# Filtering by convexity and getting centers took: 0.2556469440460205, facet # = 185
# Total Time = 0.4502730369567871
# Finished facets for child 13 : 0.45041775703430176 with facet length = 185
# Starting child 14
#  face length 14 using OPTIMIZED facets
# Total normals took 2.09808349609375e-05
# Boolean mask finished: 6.9141387939453125e-06
# Grouping took: 0.0007724761962890625
# Filtering edges by size finished: 0.0005035400390625, facet # = 0
# Filtering by convexity and getting centers took: 7.367134094238281e-05, facet # = 0
# Total Time = 0.002146482467651367
# Finished facets for child 14 : 0.0021877288818359375 with facet length = 0
# Starting child 15
#  face length 26 using OPTIMIZED facets
# Total normals took 2.2411346435546875e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0007805824279785156
# Filtering edges by size finished: 0.0013325214385986328, facet # = 2
# Filtering by convexity and getting centers took: 0.0012583732604980469, facet # = 2
# Total Time = 0.004224538803100586
# Finished facets for child 15 : 0.004270315170288086 with facet length = 2
# Starting child 16
#  face length 8086 using OPTIMIZED facets
# Total normals took 0.0002760887145996094
# Boolean mask finished: 8.249282836914062e-05
# Grouping took: 0.0032854080200195312
# Filtering edges by size finished: 0.2669975757598877, facet # = 1076
# Filtering by convexity and getting centers took: 0.305783748626709, facet # = 187
# Total Time = 0.5816657543182373
# Finished facets for child 16 : 0.581862211227417 with facet length = 187
# Starting child 17
#  face length 19179 using OPTIMIZED facets
# Total normals took 0.0007007122039794922
# Boolean mask finished: 0.00013446807861328125
# Grouping took: 0.006886005401611328
# Filtering edges by size finished: 0.5690155029296875, facet # = 2353
# Filtering by convexity and getting centers took: 0.638190746307373, facet # = 470
# Total Time = 1.224879264831543
# Finished facets for child 17 : 1.2254865169525146 with facet length = 470
# Starting child 18
#  face length 8014 using OPTIMIZED facets
# Total normals took 0.0003185272216796875
# Boolean mask finished: 0.0001380443572998047
# Grouping took: 0.003429412841796875
# Filtering edges by size finished: 0.20855116844177246, facet # = 1011
# Filtering by convexity and getting centers took: 0.2959902286529541, facet # = 261
# Total Time = 0.5130221843719482
# Finished facets for child 18 : 0.5133309364318848 with facet length = 261
# Starting child 19
#  face length 348 using OPTIMIZED facets
# Total normals took 6.4849853515625e-05
# Boolean mask finished: 9.5367431640625e-06
# Grouping took: 0.0010900497436523438
# Filtering edges by size finished: 0.009872198104858398, facet # = 39
# Filtering by convexity and getting centers took: 0.01232767105102539, facet # = 10
# Total Time = 0.024944782257080078
# Finished facets for child 19 : 0.02499675750732422 with facet length = 10
# Starting child 20
#  face length 268 using OPTIMIZED facets
# Total normals took 7.557868957519531e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0012311935424804688
# Filtering edges by size finished: 0.007942676544189453, facet # = 40
# Filtering by convexity and getting centers took: 0.013123035430908203, facet # = 16
# Total Time = 0.023980379104614258
# Finished facets for child 20 : 0.02403116226196289 with facet length = 16
# Starting child 21
#  face length 74 using OPTIMIZED facets
# Total normals took 2.7179718017578125e-05
# Boolean mask finished: 6.198883056640625e-06
# Grouping took: 0.0008349418640136719
# Filtering edges by size finished: 0.0018763542175292969, facet # = 12
# Filtering by convexity and getting centers took: 0.0040056705474853516, facet # = 4
# Total Time = 0.00781869888305664
# Finished facets for child 21 : 0.007865428924560547 with facet length = 4
# Starting child 22
#  face length 14 using OPTIMIZED facets
# Total normals took 2.1457672119140625e-05
# Boolean mask finished: 5.9604644775390625e-06
# Grouping took: 0.0006654262542724609
# Filtering edges by size finished: 0.0005064010620117188, facet # = 3
# Filtering by convexity and getting centers took: 0.0014903545379638672, facet # = 3
# Total Time = 0.0033118724822998047
# Finished facets for child 22 : 0.003359556198120117 with facet length = 3
# Starting child 23
#  face length 216 using OPTIMIZED facets
# Total normals took 5.9604644775390625e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0010666847229003906
# Filtering edges by size finished: 0.007028102874755859, facet # = 28
# Filtering by convexity and getting centers took: 0.009743928909301758, facet # = 16
# Total Time = 0.019678592681884766
# Finished facets for child 23 : 0.019726037979125977 with facet length = 16
# Starting child 24
#  face length 596 using OPTIMIZED facets
# Total normals took 0.00017023086547851562
# Boolean mask finished: 1.1682510375976562e-05
# Grouping took: 0.001920938491821289
# Filtering edges by size finished: 0.022029876708984375, facet # = 54
# Filtering by convexity and getting centers took: 0.017794132232666016, facet # = 14
# Total Time = 0.04401707649230957
# Finished facets for child 24 : 0.04407334327697754 with facet length = 14
# Starting child 25
#  face length 32 using OPTIMIZED facets
# Total normals took 2.6702880859375e-05
# Boolean mask finished: 5.7220458984375e-06
# Grouping took: 0.000774383544921875
# Filtering edges by size finished: 0.00162506103515625, facet # = 0
# Filtering by convexity and getting centers took: 0.00012493133544921875, facet # = 0
# Total Time = 0.003470182418823242
# Finished facets for child 25 : 0.0035142898559570312 with facet length = 0
# Starting child 26
#  face length 1256 using OPTIMIZED facets
# Total normals took 0.0002262592315673828
# Boolean mask finished: 1.1205673217773438e-05
# Grouping took: 0.002562999725341797
# Filtering edges by size finished: 0.03621363639831543, facet # = 156
# Filtering by convexity and getting centers took: 0.04909062385559082, facet # = 63
# Total Time = 0.09069037437438965
# Finished facets for child 26 : 0.09075331687927246 with facet length = 63
# Starting child 27
#  face length 236 using OPTIMIZED facets
# Total normals took 0.0001614093780517578
# Boolean mask finished: 7.152557373046875e-06
# Grouping took: 0.0010242462158203125
# Filtering edges by size finished: 0.005858182907104492, facet # = 21
# Filtering by convexity and getting centers took: 0.007231235504150391, facet # = 8
# Total Time = 0.015779733657836914
# Finished facets for child 27 : 0.015826940536499023 with facet length = 8
# Starting child 28
#  face length 1390 using OPTIMIZED facets
# Total normals took 0.00011992454528808594
# Boolean mask finished: 1.0251998901367188e-05
# Grouping took: 0.0013530254364013672
# Filtering edges by size finished: 0.03983044624328613, facet # = 177
# Filtering by convexity and getting centers took: 0.047574758529663086, facet # = 56
# Total Time = 0.09104132652282715
# Finished facets for child 28 : 0.09111166000366211 with facet length = 56
# Starting child 29
#  face length 54 using OPTIMIZED facets
# Total normals took 3.647804260253906e-05
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.0007681846618652344
# Filtering edges by size finished: 0.0018107891082763672, facet # = 10
# Filtering by convexity and getting centers took: 0.003482818603515625, facet # = 5
# Total Time = 0.007098197937011719
# Finished facets for child 29 : 0.0071413516998291016 with facet length = 5
# Starting child 30
#  face length 80 using OPTIMIZED facets
# Total normals took 2.7418136596679688e-05
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.000705718994140625
# Filtering edges by size finished: 0.0018393993377685547, facet # = 10
# Filtering by convexity and getting centers took: 0.003299713134765625, facet # = 3
# Total Time = 0.006859779357910156
# Finished facets for child 30 : 0.006903886795043945 with facet length = 3
# Starting child 31
#  face length 2672 using OPTIMIZED facets
# Total normals took 0.000110626220703125
# Boolean mask finished: 1.1920928955078125e-05
# Grouping took: 0.0017304420471191406
# Filtering edges by size finished: 0.0775601863861084, facet # = 337
# Filtering by convexity and getting centers took: 0.10777044296264648, facet # = 124
# Total Time = 0.1904611587524414
# Finished facets for child 31 : 0.19055962562561035 with facet length = 124
# Starting child 32
#  face length 5268 using OPTIMIZED facets
# Total normals took 0.0001933574676513672
# Boolean mask finished: 8.296966552734375e-05
# Grouping took: 0.002490520477294922
# Filtering edges by size finished: 0.1543285846710205, facet # = 684
# Filtering by convexity and getting centers took: 0.23625493049621582, facet # = 184
# Total Time = 0.39698219299316406
# Finished facets for child 32 : 0.3971233367919922 with facet length = 184
# Starting child 33
#  face length 1724 using OPTIMIZED facets
# Total normals took 8.249282836914062e-05
# Boolean mask finished: 1.2874603271484375e-05
# Grouping took: 0.0014917850494384766
# Filtering edges by size finished: 0.0630486011505127, facet # = 162
# Filtering by convexity and getting centers took: 0.043699026107788086, facet # = 34
# Total Time = 0.11049056053161621
# Finished facets for child 33 : 0.11058211326599121 with facet length = 34
# Starting child 34
#  face length 3786 using OPTIMIZED facets
# Total normals took 0.00014901161193847656
# Boolean mask finished: 0.00019788742065429688
# Grouping took: 0.002083301544189453
# Filtering edges by size finished: 0.13971996307373047, facet # = 399
# Filtering by convexity and getting centers took: 0.1781322956085205, facet # = 53
# Total Time = 0.32315850257873535
# Finished facets for child 34 : 0.3233206272125244 with facet length = 53
# Starting child 35
#  face length 802 using OPTIMIZED facets
# Total normals took 7.772445678710938e-05
# Boolean mask finished: 1.2159347534179688e-05
# Grouping took: 0.0013401508331298828
# Filtering edges by size finished: 0.03099346160888672, facet # = 106
# Filtering by convexity and getting centers took: 0.029262304306030273, facet # = 27
# Total Time = 0.0636591911315918
# Finished facets for child 35 : 0.06373190879821777 with facet length = 27
# Starting child 36
#  face length 606 using OPTIMIZED facets
# Total normals took 6.437301635742188e-05
# Boolean mask finished: 0.000209808349609375
# Grouping took: 0.0010113716125488281
# Filtering edges by size finished: 0.029268741607666016, facet # = 67
# Filtering by convexity and getting centers took: 0.020265579223632812, facet # = 28
# Total Time = 0.05266928672790527
# Finished facets for child 36 : 0.05273628234863281 with facet length = 28
# Starting child 37
#  face length 1456 using OPTIMIZED facets
# Total normals took 9.608268737792969e-05
# Boolean mask finished: 1.2874603271484375e-05
# Grouping took: 0.0014183521270751953
# Filtering edges by size finished: 0.03514361381530762, facet # = 189
# Filtering by convexity and getting centers took: 0.05133318901062012, facet # = 63
# Total Time = 0.08998513221740723
# Finished facets for child 37 : 0.09006714820861816 with facet length = 63
# Starting child 38
#  face length 18 using OPTIMIZED facets
# Total normals took 3.0279159545898438e-05
# Boolean mask finished: 7.62939453125e-06
# Grouping took: 0.0009443759918212891
# Filtering edges by size finished: 0.0008044242858886719, facet # = 4
# Filtering by convexity and getting centers took: 0.0023381710052490234, facet # = 4
# Total Time = 0.005223989486694336
# Finished facets for child 38 : 0.005283355712890625 with facet length = 4
# Starting child 39
#  face length 632 using OPTIMIZED facets
# Total normals took 7.104873657226562e-05
# Boolean mask finished: 1.0967254638671875e-05
# Grouping took: 0.0011875629425048828
# Filtering edges by size finished: 0.016690492630004883, facet # = 96
# Filtering by convexity and getting centers took: 0.03113269805908203, facet # = 18
# Total Time = 0.05123257637023926
# Finished facets for child 39 : 0.05130171775817871 with facet length = 18
# Starting child 40
#  face length 92 using OPTIMIZED facets
# Total normals took 3.814697265625e-05
# Boolean mask finished: 9.059906005859375e-06
# Grouping took: 0.001153707504272461
# Filtering edges by size finished: 0.005243062973022461, facet # = 7
# Filtering by convexity and getting centers took: 0.0029685497283935547, facet # = 5
# Total Time = 0.01108551025390625
# Finished facets for child 40 : 0.011144638061523438 with facet length = 5
# Starting child 41
#  face length 968 using OPTIMIZED facets
# Total normals took 5.7220458984375e-05
# Boolean mask finished: 1.1920928955078125e-05
# Grouping took: 0.001308441162109375
# Filtering edges by size finished: 0.048326730728149414, facet # = 95
# Filtering by convexity and getting centers took: 0.02783489227294922, facet # = 37
# Total Time = 0.07944226264953613
# Finished facets for child 41 : 0.07951688766479492 with facet length = 37
# Starting child 42
#  face length 12 using OPTIMIZED facets
# Total normals took 2.4318695068359375e-05
# Boolean mask finished: 7.152557373046875e-06
# Grouping took: 0.0007460117340087891
# Filtering edges by size finished: 0.0006356239318847656, facet # = 0
# Filtering by convexity and getting centers took: 7.2479248046875e-05, facet # = 0
# Total Time = 0.0023877620697021484
# Finished facets for child 42 : 0.0026247501373291016 with facet length = 0
# Starting child 43
#  face length 20 using OPTIMIZED facets
# Total normals took 2.5033950805664062e-05
# Boolean mask finished: 8.58306884765625e-06
# Grouping took: 0.0009577274322509766
# Filtering edges by size finished: 0.0003838539123535156, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.001550436019897461, facet # = 2
# Total Time = 0.0038404464721679688
# Finished facets for child 43 : 0.003895998001098633 with facet length = 2
# Starting child 44
#  face length 170 using OPTIMIZED facets
# Total normals took 0.00020647048950195312
# Boolean mask finished: 8.821487426757812e-06
# Grouping took: 0.0017659664154052734
# Filtering edges by size finished: 0.00638127326965332, facet # = 23
# Filtering by convexity and getting centers took: 0.0073397159576416016, facet # = 10
# Total Time = 0.018432140350341797
# Finished facets for child 44 : 0.018492698669433594 with facet length = 10
# Starting child 45
#  face length 260 using OPTIMIZED facets
# Total normals took 4.5299530029296875e-05
# Boolean mask finished: 8.106231689453125e-06
# Grouping took: 0.0012240409851074219
# Filtering edges by size finished: 0.011495351791381836, facet # = 35
# Filtering by convexity and getting centers took: 0.01053166389465332, facet # = 17
# Total Time = 0.02498483657836914
# Finished facets for child 45 : 0.025046825408935547 with facet length = 17
# Starting child 46
#  face length 18 using OPTIMIZED facets
# Total normals took 2.384185791015625e-05
# Boolean mask finished: 7.152557373046875e-06
# Grouping took: 0.0009922981262207031
# Filtering edges by size finished: 0.0011286735534667969, facet # = 6
# Filtering by convexity and getting centers took: 0.0035347938537597656, facet # = 6
# Total Time = 0.006765127182006836
# Finished facets for child 46 : 0.00682520866394043 with facet length = 6
# Starting child 47
#  face length 66 using OPTIMIZED facets
# Total normals took 3.170967102050781e-05
# Boolean mask finished: 8.821487426757812e-06
# Grouping took: 0.0009844303131103516
# Filtering edges by size finished: 0.0014569759368896484, facet # = 7
# Filtering by convexity and getting centers took: 0.0031366348266601562, facet # = 4
# Total Time = 0.007454633712768555
# Finished facets for child 47 : 0.007512092590332031 with facet length = 4
# Starting child 48
#  face length 124 using OPTIMIZED facets
# Total normals took 0.00021505355834960938
# Boolean mask finished: 8.821487426757812e-06
# Grouping took: 0.0011742115020751953
# Filtering edges by size finished: 0.003336668014526367, facet # = 14
# Filtering by convexity and getting centers took: 0.004336118698120117, facet # = 6
# Total Time = 0.010600566864013672
# Finished facets for child 48 : 0.010675191879272461 with facet length = 6
# Starting child 49
#  face length 260 using OPTIMIZED facets
# Total normals took 3.147125244140625e-05
# Boolean mask finished: 7.867813110351562e-06
# Grouping took: 0.0012056827545166016
# Filtering edges by size finished: 0.011579751968383789, facet # = 41
# Filtering by convexity and getting centers took: 0.010832548141479492, facet # = 7
# Total Time = 0.025353193283081055
# Finished facets for child 49 : 0.025415658950805664 with facet length = 7
# Starting child 50
#  face length 22 using OPTIMIZED facets
# Total normals took 2.384185791015625e-05
# Boolean mask finished: 7.3909759521484375e-06
# Grouping took: 0.0007374286651611328
# Filtering edges by size finished: 0.0011382102966308594, facet # = 0
# Filtering by convexity and getting centers took: 9.608268737792969e-05, facet # = 0
# Total Time = 0.003110170364379883
# Finished facets for child 50 : 0.0031654834747314453 with facet length = 0
# Total time for facets: 75.2872724533081

# %%
# filter_final_facets_optimized_with_checks(child_meshes[43],43)
# filter_final_facets_optimized_with_checks(child_meshes[41],41)

# %%
# Check the ones that don't have any facets
zero_faced = []

for i,ch in enumerate(child_meshes_facets):
    num_facets = len(ch[1])
    if num_facets == 0:
        zero_faced.append(i)
    #print(f"Child {i} has {num_facets} facets")
print(zero_faced)
# Out:
# [14, 25, 42, 50]

# %%
"""
Conclusion: The ones that are zero faced are not being filtered away becuase of the convexity
But instead there are no 2 neighboring faces that have similar normals

"""
# Out:
# '\nConclusion: The ones that are zero faced are not being filtered away becuase of the convexity\nBut instead there are no 2 neighboring faces that have similar normals\n\n'

# %% [markdown]
# # Check that facet extraction for each piece worked

# %%
# # download the facets and make sure they match

# current_facets = main_mesh_facets
# current_mesh = main_mesh
# index = "main"


# facets_group = np.zeros(len(current_mesh.faces)).astype(int)

# for i,facet_group in enumerate(current_facets):
#     for face in facet_group:
#         facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

# np.savez("./test_meshes/" + str(index) + "_debug_june_facet_" + str(index) + ".npz",
#          facets_group=facets_group)

# from print_trimesh import print_trimesh
# print_trimesh(current_mesh,"./test_meshes/piece_debug_june_" + str(index) + ".off")

# %% [markdown]
# # START ITERATIVE PROCESS THAT CONNECTS THE MESHES

# %%
def apply_bbox_filter(child,min_bb_zone,max_bb_zone):
    """
    Determines if child is withing the bounding box zone
    designated by the bounding box corners
    
    """
    #get the min and max of the bounding box for the mesh
    min_bb = np.array(child.bounding_box.vertices).min(0)
    max_bb = np.array(child.bounding_box.vertices).max(0)
    
    #print(min_bb,max_bb)
    #print(min_bb_zone,max_bb_zone)
    
    #if fails any of these checks then return false, else return True
    if min(min_bb[0],max_bb[0])>max_bb_zone[0]:
        print("returning x greater max")
        return False
    
    if max(min_bb[0],max_bb[0])<min_bb_zone[0]:
        print("returning x less min")
        return False
    
    if min(min_bb[1],max_bb[1])>max_bb_zone[1]:
        print("returning y greater max")
        return False
    
    if max(min_bb[1],max_bb[1])<min_bb_zone[1]:
        print("returning y less min")
        return False
        
    if min(min_bb[2],max_bb[2])>max_bb_zone[2]:
        print("returning z greater max")
        return False
    
    if max(min_bb[2],max_bb[2])<min_bb_zone[2]:
        print("returning z less mim")
        return False
    return True

import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# restitching functions
import trimesh
import numpy as np
from collections import Counter
import time
import math

#gets the projection of point p onto line a
def ClosestPointOnLine(a, b, p):
    ap = p-a
    ab = b-a
    #base_vector = ab
    result = np.dot(ap,ab)/np.dot(ab,ab) # * ab
    return result



#now have the mesh and the facet faces, can send to function
def stitch_mesh_piece_vp4(new_mesh,facet_1,facet_2,
                          delete_facets=False,
                         return_added_mesh = False,
                         fix_normals = False):

    """
    Changed since last version: 
    1) parameter for deleting facets at end or not
    2) parameter for returning added mesh or not 
    3) Changed normals check to print statement and not exception


    """
    #how to find the normals of facet groups:
    facet_group_1_normal = new_mesh.face_normals[facet_1[0]] #main_mesh_normals
    facet_group_2_normal = new_mesh.face_normals[facet_2[0]] #child_mesh_normals


    #get the correct version of the normals: (might need to flip them if going in opposite direction)
    if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
        raise Exception("same direction normals")
    elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
        print("opposite direction normals")
    else:
        print("Not correct normals")
        #raise Exception("Not correct normals")

    # make each row correspond to a single face 
    edges = new_mesh.edges_sorted.reshape((-1, 6))
    # get the edges for each facet
    edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
    edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                               for i in edges_facet])

    #the list of boundary edges and unique points in the boundary edges
    edge_0 = edges_boundary[0]
    edge_1 = edges_boundary[1]

    #gets the unique number of points
    edge_0_points = np.unique(np.hstack(edge_0))
    edge_1_points = np.unique(np.hstack(edge_1))
    print("Found boundary edges")
    """
    get the dot product of all the points
    """

    #get any 2 points on the triangle and make that the reference edge
    edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

    #gets the starting index for the 1st facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_0_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_0_starting_point = edge_0_points[max_index]

    #gets the starting index for the 2nd facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_1_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_1_starting_point = edge_1_points[max_index]

    print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
    #print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

    """
    Need to order the points for restitching

    Pseudocode: 
    1) Get starting piont
    2) Find the two edges corresponding to that point
    3) Need to decide which direction to start....
    - go in direction that make the cross of the (1st and last) point in the same direction of the 
    normal of the first facet
    4) loop through and record the orders of the vertices as you traverse along the edges 
    until you arrive back at the start
    5) Error if:
        a. You arrive back at the start and haven't processed all the edges
        b. Processsed all the edges but haven't arrived back at start

    6) Repeat steps 1 through 5 for 2nd facet group
    """
    start_point_list = [edge_0_starting_point,edge_1_starting_point]
    edge_list = [edge_0,edge_1]
    edge_order_list = []



    #loop that organizes the unique boundary points into the correct order
    for i,start_point in enumerate(start_point_list):
        print(f"Starting Organizing vertices for side {i}")
        #print(f"start_point = {start_point}")
        edge_order = [start_point]
        processed_edges = []

        #find the matching edges to the starting point
        starting_edges_indices = np.where(np.logical_or(edge_list[i][:,0] == start_point,edge_list[i][:,1] == start_point) == True)[0]

        starting_edges = edge_list[i][starting_edges_indices]
        #print(f"starting edges = {starting_edges}") #the list of the two possible edges

        if starting_edges.size < 4:
            raise Exception("Not enough edges for 1st facet start point")

        if starting_edges.size > 4:
            raise Exception("Too many edges for 1st facet start point") 

        #np.where(starting_edges[1,:] != start_point)[0][0]
        #gets the vectors that will be used for the cross product
        #print("np.where(starting_edges[0,:] != start_point)[0][0] = " + str(np.where(starting_edges[0,:] != start_point)[0][0]))
        #print("np.where(starting_edges[1,:] != start_point)[0][0] = " + str(np.where(starting_edges[1,:] != start_point)[0][0]))

        """*************** where pick the starting edge starts ************
        The way it works: 
        1) Gets the two possible starting edges
        2) Generates the vectors for the edges where origin is the starting point
        3) Gets the cross porduct of both vectors
        4) Chooses the cross product that is in the direction of the face normals

        Why that doesn't work:
        1) they are opposite normals


        """

        """
        Possible other solution:
        1) Get the starting points on the child edge
        2) Pick the first edge as the default edge

        """
        processed_edges.append(starting_edges_indices[0])
        current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]




    #         #gets the possible starting vectors from the two possible edges
    #         possible_starting_vector_1 = new_mesh.vertices[starting_edges[0,:][np.where(starting_edges[0,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
    #         #just start with a random edge
    #         possible_starting_vector_2 = new_mesh.vertices[starting_edges[1,:][np.where(starting_edges[1,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]


    #         #find the cross product of the starting vectors
    #         starting_edges_cross = np.cross(possible_starting_vector_1,possible_starting_vector_2)

    #         #make sure that the order of the vectors goes so that the cross product is in line with the starting normal
    #         #this ensures the the circular direction of the stitching will be the same
    #         if np.dot(starting_edges_cross,facet_group_1_normal) > 0:
    #             print("Edge 1 picked for direction")
    #             processed_edges.append(starting_edges_indices[0])
    #             current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]
    #         else:
    #             print("Edge 2 picked for direction")
    #             processed_edges.append(starting_edges_indices[1])
    #             #print("np.where(starting_edges[1,:] != start_point) = " + str(np.where(starting_edges[1,:] != start_point)))
    #             current_vertex = starting_edges[1][np.where(starting_edges[1,:] != start_point)[0][0]]

        #print(f"current_vertex = {current_vertex}" )
        #print("edge_list = " + str(edge_list))



        """*************** where pick the starting edge ends ************"""
        #now iterate through number of 
        for z in range(1,edge_list[i][:,0].size):
            #print("edge_order_temp = " + str(edge_order))
            if current_vertex == start_point:
                print("Start vertex reached before processed all of edges")

                """

                These should be ok because the extra loops are created from holes inside and this process should always get the outside loop


                """
                break

            #get the next edge
            counter = 0
            next_vertex = -1
            for j,edg in enumerate(edge_list[i]):
                #print("edg = " + str(edg))
                #print("processed_edges = " + str(processed_edges))
                if current_vertex in edg and j not in processed_edges:
                    current_edge_index = j
                    if edg[0] != current_vertex:
                        next_vertex = edg[0]
                    else:
                        next_vertex = edg[1]


                    counter += 1
                    if counter >= 2:
                        #raise Exception(f"More than 2 edges possibilities for {current_vertex}")
                        #Don't want to make it an exception anymore put just print out warning
                        print("More than 2 edges possibilities for {current_vertex}") # BAC change

            #make sure the next vertex was found
            if next_vertex <= -1:
                raise Exception(f"No next vertex was found for {current_vertex} ")

            #if found next vertex then add the old vertex and edge index
            #to the processed edges lists and the order of vertices
            processed_edges.append(current_edge_index)
            edge_order.append(current_vertex)

            current_vertex = next_vertex


        edge_order_list.append(edge_order)
        print(f"edge_{i}_order done, len = {len(edge_order)} ")#"= {edge_order}")

    #     #print the edge orders
    #     for e in edge_order_list:
    #         print(type(e))
    lengths_of_boundaries = [len(x) for x in edge_order_list]



    """ ************ PROCESS OF ORDERING THE EDGE PATHS SO THAT *********
    main mesh loop goes in counter clockwise in reference to the gap
    child goes clockwise in reference to gap




    """

    """
    1) Pick the starting point as your P point
    2) For each point in ordered list calculate point - P and store that vector
    3) Do the cross product of list[0:n-2] x list[1:n-1]
    4) Take the sum of these lists of cross products
    5) Do the dot product to compare the direction with the normal vector 
    Result: 
    - if positive --> conuter-clockwise according to normal
    - if negative --> clockwise according to normal

    """

    starter_point = np.array([0,0,0])

    #     list_of_points = [1,2,3,4,0]

    #     list_of_points = [list_of_points[len(list_of_points) - x -1] for x in range(0,len(list_of_points))]
    #     print(list_of_points)

    #print("facet_group_2_normal = " + str(facet_group_2_normal))

    for ed,e_loop in enumerate(edge_order_list):

        #get the vertices according to the points
        vertices_list = new_mesh.vertices[e_loop]

        #get the cross product of the offsetted list
        #vertices_list[0:len(vertices_list)-1,:]
        """ Wrong earlier previous way

        cross_products = np.cross(vertices_list[0:len(vertices_list)-1,:],vertices_list[1:len(vertices_list)])
        """

        cross_products = np.cross(vertices_list[0:len(vertices_list),:],
                             np.vstack([vertices_list[1:len(vertices_list),:],vertices_list[0,:]]))

        sum_cross_products = np.sum(cross_products,axis=0)

        #print("cross_products = " + str(cross_products))
        #print("sum_cross_products = " + str(sum_cross_products))

        #print("Before edge list = " + str(edge_order_list[ed]))
        if ed == 0:
            #get the dot product
            normals_dot = np.dot(sum_cross_products,facet_group_1_normal)
            #print(' normals_dot = ' + str(normals_dot))
            if normals_dot > 0:
                print("Main originally was counter-clockwise --> keeping")


            else:
                print("Main originally was clockwise --> flipping")
                edge_order_list[ed] = [e_loop[len(e_loop) - x -1] for x in range(0,len(e_loop))]


        else: 
            # for the children want the cross product to be counter clockwise
            normals_dot = np.dot(sum_cross_products,facet_group_2_normal)
            #print(' normals_dot = ' + str(normals_dot))
            if normals_dot > 0:
                print("Child originally was counter-clockwise --> flipping")
                edge_order_list[ed] = [e_loop[len(e_loop) - x -1] for x in range(0,len(e_loop))]
            else:
                print("Child originally was clockwise --> keeping")


        #print("After edge list = " + str(edge_order_list[ed]))
    """  SHOWS THAT DOING THE CROSS PRODUCT THAT WAY WORKS
    #do the cross products manually
    for jj in range(0,len(vertices_list)-1):
        print(np.cross(vertices_list[jj],vertices_list[jj+1]))

    """




    #getting which one is the bigger one
    bigger = lengths_of_boundaries.index(max(lengths_of_boundaries))
    smaller = 1-bigger

    if bigger == 0:
        starter_face = "child" #if the bigger one was the main, then child is the smaller one you start from
    else:
        starter_face = "main" #if the bigger one was the child, then main is the smaller one you start from


    print("smaller_face = " + str(starter_face))    

    """ The rules that have to be following in order for normals to be correctly aligned
    1) if the smaller is the child (will be traveling in clockwise direction
    --> need to stitch points as:
    Regular: other_2, other_1,current_point
    Neighbor: current,other_1,current-1


    1) if the smaller is the main mesh (
    --> need to stitch points as:
    Regular: current_point,other_1,other_2
    Neighbor: current,current-1,other
    """


    #print(f"index of bigger facets = {bigger}\nindex of smaller facets = {smaller}",)

    #calculates the number of vertices will be stitched to each vertices on smaller side
    dividend = int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])
    remainder = lengths_of_boundaries[bigger] - int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])*lengths_of_boundaries[smaller]

    print(f"dividend = {dividend}, remainder = {remainder}")

    #loop that adds the new faces
    print("About to add faces")
    start_time = time.time()
    new_faces = []
    current_bigger = 0

    for i,current_smaller in enumerate(edge_order_list[smaller]):
        #print("current_smaller =" + str(current_smaller))
        #print("current_bigger=" + str(edge_order_list[bigger][current_bigger]))

        #connecting to the neighbor on the shorter side
        """
        if i == 0:

            new_faces.append([current_smaller,edge_order_list[smaller][-1],edge_order_list[bigger][current_bigger]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])
        """


        if starter_face == "main":
            new_faces.append([current_smaller,edge_order_list[bigger][current_bigger],edge_order_list[smaller][i-1]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])


        for j in range(0,dividend + int(i<remainder)):
            if current_bigger > len(edge_order_list[bigger]):
                raise Exception("Somehow rapped around too much")

            if current_bigger >= len(edge_order_list[bigger])-1:
                next_bigger = 0
            else:
                next_bigger = current_bigger+1

            if starter_face == "main":
                new_faces.append([edge_order_list[bigger][next_bigger],
                                  edge_order_list[bigger][current_bigger],
                                  current_smaller,
                                ])
            else:
                new_faces.append([
                                current_smaller,
                                  edge_order_list[bigger][current_bigger],
                                  edge_order_list[bigger][next_bigger],

                                ])

            current_bigger += 1

            total_counter += 1



    #print("new_faces = " + str(new_faces))
    print(f"Finished adding faces: {time.time() - start_time}")


    print("Starting creating stitch mesh")
    start_time = time.time()
    stitch_mesh = trimesh.Trimesh()

    stitch_mesh.vertices = new_mesh.vertices
    stitch_mesh.faces = np.vstack([new_mesh.faces, new_faces])
    print(f"Finished creating stitch mesh: {time.time() - start_time}")




    if delete_facets == True:
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(stitch_mesh.faces)-1,len(stitch_mesh.faces)).astype("int")
        facet_faces = np.hstack([facet_1 ,facet_2])
        faces_to_keep = set(total_faces).difference(set(facet_faces))
        faces_to_keep

        stitch_mesh = stitch_mesh.submesh([list(faces_to_keep)])[0]

    if fix_normals == True:
        trimesh.repair.fix_inversion(stitch_mesh)
        trimesh.repair.fix_winding(stitch_mesh)
        trimesh.repair.fix_normals(stitch_mesh)

    #print("Finished stitching")

    if return_added_mesh == True:
        added_mesh = trimesh.Trimesh()
        added_mesh.vertices = new_mesh.vertices
        added_mesh.faces = new_faces
        trimesh.repair.fix_inversion(added_mesh)
        trimesh.repair.fix_winding(added_mesh)
        trimesh.repair.fix_normals(added_mesh)

        return stitch_mesh,added_mesh

    else:
        return stitch_mesh

# %%
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh_saved = main_mesh.copy()
main_mesh_facets_centers_saved = main_mesh_facets_centers.copy()
main_mesh_facets_saved = main_mesh_facets.copy()

#save off the child information as well
from copy import deepcopy

child_meshes_saved = deepcopy(child_meshes)
child_meshes_facets_saved = deepcopy(child_meshes_facets) #has both the centers and the facet lists

# %%
restitch_time = time.time()

# %%
"""

Pseudocode for loop at the end that will keep everything going:
1) When process a child, will add that index to a list
2) Have no_new_children_processed counter set at end of loop 
    if no children were added to main mesh
    --> this will prompt the expansion of the initial parameters
3) If this gets too high



Things that still need to add:
1) Better way of making sure that the normals are good
- Can sample one of the neighboring points and flip normals if the dot product is negative


Change list: 
1) Reduced the stitch distance
2) Added the copy features that allows this cell to be rerun without rerunning whole notebook
3) added the new tie_breaker for childs that want to connect to same parent is just the one with closest facet
    Uses the added feature of child_meshes_stitch_distances that is saved along the way
4) Iterates through the repeated faces instead of just doing so once which was incorrect before
5) Fixed bug that was adding to current_main_mesh but then was using main mesh also in the loop
6) Made changes to the stitching mechanism that not error if find a vertices with more than 2 edges
--> because did observe some facets with cut out faces along the boundary
7) Changed the consider_same_direction normal as False 
8) Changed the max index error that was used for finding the starting point in stitch meshes

"""
total_stitch_processing_time = time.time()
#load our main mesh stuff from the copies
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh = main_mesh_saved.copy()
main_mesh_facets_centers = main_mesh_facets_centers_saved.copy()
main_mesh_facets = main_mesh_facets_saved.copy()

#load the child info from the saved copies
child_meshes_facets_saved = deepcopy(child_meshes_facets_saved)
child_meshes  = deepcopy(child_meshes_saved)


#sets 
initial_parameters = dict(bounding_box_threshold=4000,
                         stitch_distance_threshold=800,
                         size_ratio_threshold=0.15,
                         normal_closeness= 0.95)

bounding_box_threshold = initial_parameters["bounding_box_threshold"]
stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]
size_ratio_threshold = initial_parameters["size_ratio_threshold"]
normal_closeness=initial_parameters["normal_closeness"]

no_new_children_multiplier = 0
bbox_expansion_percentage = 0.10
stitch_expansion_percentage = 0.20
size_ratio_expansion_percentage = 0.10

no_new_children_limit = 4

consider_same_direction_normals = False
children_processed = []

#lists to store the faces that need to be removed later from main mesh
child_faces_to_remove = []
main_faces_to_remove = []

while len(children_processed) < len(child_meshes):
    stitch_loop_time = time.time()
    if no_new_children_multiplier >= no_new_children_limit:
        print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
        print(f"total_stitch_processing_time = {time.time() - total_stitch_processing_time}")
        raise Exception("Finished the mesh stitiching")
    
    #update the thresholds
    bounding_box_threshold = initial_parameters["bounding_box_threshold"]*(1 + bbox_expansion_percentage*no_new_children_multiplier)
    stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]*(1 + stitch_expansion_percentage*no_new_children_multiplier)
    #reduces the 
    size_ratio_threshold = initial_parameters["size_ratio_threshold"]*(1 - size_ratio_expansion_percentage*no_new_children_multiplier)
    
    #print thresholds
#     print(f"bounding_box_threshold = {bounding_box_threshold}")
#     print(f"stitch_distance_threshold = {stitch_distance_threshold}" )
#     print(f"size_ratio_threshold = {size_ratio_threshold}")

    #get the main mesh facets normals
    main_mesh_normals = [main_mesh.face_normals[fac[0]] for fac in main_mesh_facets]
    hit_indexes_list= []
    
    
    #dictionary to save the stitch points
    child_meshes_stitch_facets = dict()
    child_meshes_stitch_face_ratios = dict()
    child_meshes_stitch_distances = dict()
    for i,child in enumerate(child_meshes):
        
        if i in children_processed:
            #print(f"Child {i} already processed")
            continue
        
        print(f"Starting Child {i}")

        #initialize the stitch index
        #child_meshes_stitch_facets[i] = [-1,-1]

        #two highest points for the bounding box
        min_bb = np.array(main_mesh.bounding_box.vertices).min(0)
        max_bb = np.array(main_mesh.bounding_box.vertices).max(0)

        min_bb_zone = min_bb - bounding_box_threshold
        max_bb_zone = max_bb + bounding_box_threshold



        #then send mesh to function that decides if with
        pass_bbox_filter = apply_bbox_filter(child,min_bb_zone,max_bb_zone)

        if not pass_bbox_filter:
            print("skipped by bounding box filter")
            continue

        #### used for validation to make sure that bounding box was correctly filtering
    #     #add the following to main mesh just to visualize
    #     final_mesh = final_mesh + child
    #     print("just added")

        #
        """

        Do pairwise calculation of distances between centers of facets on child piece and main piece
            Filter the pairs for stitch distance threshold
            Filter the pairs for matching or opposite normals
            Filter for those that are reasonable in size matching (within 50% of each other)

        If there are still ties after this point then pitch the best matching size

        If None remaining then keep going (might loosen up the parameters later), BUT WITH GLOBAL CHECK SO DOESN’T KEEP ITERATING


        """
 
        """ OLD WAY OF COMPUTING PAIRWISE ***************************************************************
        
        child_facets,child_facets_centers = child_meshes_facets[i]

        facet_distances = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))
        facet_normals = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))

        start_time = time.time()
        #do the pairwise comparison
        for cc,child_center in enumerate(child_facets_centers):

            #get the normal of the child
            child_normal = child.face_normals[child_facets[cc][0]]
            for mm, main_center in enumerate(main_mesh_facets_centers):
                #get the euclidean distance
    #             facet_distances[cc,mm] = math.sqrt((child_center[0] - main_center[0])**2 + 
    #                                                  (child_center[1] - main_center[1])**2 + 
    #                                                  (child_center[2] - main_center[2])**2 )



                facet_distances[cc,mm] = np.linalg.norm(np.array(child_center) - np.array(main_center))

                main_normal = main_mesh_normals[mm]
    #             print("main_normal = " + str(main_normal))
    #             print("child_normal = " + str(child_normal))
                #get whether the normals are line up (or possibly opposite)
                normals_dot = np.dot(child_normal,main_normal)
                #print(normals_dot)
                if consider_same_direction_normals == True:
                    facet_normals[cc,mm] =  normals_dot < -0.95  or normals_dot > 0.95
                else:
                    facet_normals[cc,mm] =  normals_dot < -0.95 # or normals_dot > 0.95


        
        print(f"Total pairwise : {time.time() - start_time}")

    #     if i == 1:
    #         4,12
    #         print("4,12 facet distance = " + str(facet_distances[4,12]))

        #apply the filters
        #stitch_distance_booleans = facet_distances < stitch_distance_threshold

        
        #how to debug certain faces that have been filtered
#         main_facet_bebug = 124
#         piece_facet_debug = 11
        
#         if i == 2 and (0 in children_processed):
#             print("**********" + str(facet_normals[piece_facet_debug,main_facet_bebug]) + "**********")
#             print("**********" + str((facet_distances < stitch_distance_threshold)[piece_facet_debug,main_facet_bebug]) + "**********")
        
        
        #get the indexes that make it through the first two filters
        hit_indexes = np.where(np.logical_and(facet_distances < stitch_distance_threshold,facet_normals)== True) 

        possible_stitch_pairs = np.vstack(hit_indexes).T
        
        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        
        face_0_unique_facets = np.unique(hit_indexes[0])
        face_1_unique_facets = np.unique(hit_indexes[1])
        
        if len(hit_indexes[0]) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(hit_indexes[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

            

         *************************************************************** """
        
        """  NEW WAY OF COMPUTING THE PAIRWISE CALCULATIONS  *************************************************************** """
        
        child_facets,child_facets_centers = child_meshes_facets[i]
        pairs_start_time = time.time()

        
        if len(child_facets_centers) == 0:
            print("child_facets_centers for child {i} was 0, so skipping")
            continue
        
        start_time = time.time()
        a_New = np.array(child_facets_centers).astype("float")
        b_New = np.array(main_mesh_facets_centers).astype("float")

        print(len(a_New),len(b_New))
#         print("starting distance matrix")
        start_time = time.time()
        from scipy.spatial import distance_matrix
        a_b_distance = distance_matrix(a_New, b_New)
        
        #print(f"Time = {time.time() - start_time}")

        #now get the indexes that are within stitch distance

#         print("min(a_b_distance) = " + str(np.amin(a_b_distance.shape)))
        indexes_not = np.where(a_b_distance < stitch_distance_threshold)
        print(f"Done distance matrix: {time.time() - start_time}")
        
        
#         print("(indexes_not) = " + str((indexes_not)))
#         print("starting normals")
        start_time = time.time()

#         #old way to do it
#         child_normals = child.face_normals[indexes_not[0]]
#         main_normals = main_mesh.face_normals[indexes_not[1]]

        if not indexes_not[0].any():
            print(f"Child {i} There were no points close enough")
            continue

        #old way to do it
#         print(indexes_not[0])
#         print(child_facets[indexes_not[0]])
 
        
        child_normals = child.face_normals[[p[0] for p in child_facets[indexes_not[0]]]]
        main_normals = main_mesh.face_normals[[p[0] for p in main_mesh_facets[indexes_not[1]]]]
                                           
                                           
                                           
#         print(child_facets[indexes_not[0]][0])
#         print('child_normals = ' + str(child_normals))
#         print(main_mesh_facets[indexes_not[1]][0])
#         print('main_normals = ' + str(main_normals))
        #start_time = time.time()
        #dot_products = np.dot(child_normals,main_normals.T)
        
        total_normal_dots = np.sum(child_normals*main_normals,axis=1)
#         print("total_normal_dots = " + str(total_normal_dots))
        total_normal_dots_facet_mask = total_normal_dots < -normal_closeness
        
#         print(f"Done Normals generation: {time.time() - start_time}")
#         print("starting pair generation")
        
        
        start_time = time.time()
        final_pairs = (np.array(indexes_not).T)[total_normal_dots_facet_mask]
        #print(final_pairs)
        
        
        #get the sizes of all the unique ones
        face_0_unique_facets = np.unique(final_pairs[:,0])
        face_1_unique_facets = np.unique(final_pairs[:,1])
        #print("final_pairs = " + str(final_pairs))
#         print("face_0_unique_facets = " + str(face_0_unique_facets))
#         print("face_1_unique_facets = " + str(face_1_unique_facets))
        
        
        if len(final_pairs) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(final_pairs[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

        
        possible_stitch_pairs = final_pairs
        print(f"Done Generating final pairs: {time.time() - pairs_start_time}")
        
        
        """  NEW WAY OF COMPUTING THE PAIRWISE  *************************************************************** """
        




    #     print("possible_stitch_pairs = " + str(possible_stitch_pairs))
    #     print("len(hit_indexes) = " + str(len(hit_indexes)))
    #     print("hit_indexes[0].any() = " + str(hit_indexes[0].any()))
    #     print("hit_indexes = " + str(hit_indexes))
    #     print("hit_indexes[0] = " + str(hit_indexes[0]))
    #     print("len(hit_indexes[0]) = " + str(len(hit_indexes[0])))

        #find the sizes of all of them
        face_pair_sizes = np.zeros(len(possible_stitch_pairs[:,0]))
        face_size_ratios = np.zeros(len(possible_stitch_pairs[:,0]))

        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        for numba,pair in enumerate(possible_stitch_pairs):
            #print("pair = " + str(pair))
            sizes = [face_0_facet_sizes[pair[0]],face_1_facet_sizes[pair[1]]]
            min_area = min(sizes)
            max_area = max(sizes)

            ratio = min_area/max_area

            #print(f"ratio = {ratio}")
            #print(f"Total size  = {min_area + max_area}")
            if ratio >= size_ratio_threshold:
                face_pair_sizes[numba] = min_area + max_area
                face_size_ratios[numba] = ratio
            
                #print(f"face_pair_sizes[numba] = {face_pair_sizes[numba]}, face_size_ratios[numba] = {face_size_ratios[numba]}")


        #check that made it past stitch ratio threshold

        #best possible stitch pair is just the maximum sized matching ones
        best_index = np.where(face_pair_sizes == max(face_pair_sizes))
        best_stitch_pair = possible_stitch_pairs[best_index][0]
        best_stitch_pair_size = face_pair_sizes[best_index][0]
        best_stitch_pair_size_ratio = face_size_ratios[best_index][0]
        
        #get the distance of the best_stitch_pair
        best_stitch_pair_distance = a_b_distance[possible_stitch_pairs[best_index][0][0],
                                                   possible_stitch_pairs[best_index][0][1]]
        
        print("best_stitch_pair = " + str(best_stitch_pair))
        print("best_stitch_pair_size = " + str(best_stitch_pair_size))
        print("best_stitch_pair_distance = " + str(best_stitch_pair_distance))
        print("best_stitch_pair_size_ratio = " + str(best_stitch_pair_size_ratio))

        child_meshes_stitch_facets[i] = [best_stitch_pair[0],best_stitch_pair[1]]
        child_meshes_stitch_face_ratios[i] = best_stitch_pair_size_ratio
        child_meshes_stitch_distances[i] = best_stitch_pair_distance
        
#         if i == 1:
#             print("Just processed piece 1")
#             raise Exception("stoping")

    
#     if 1 in child_meshes_stitch_facets.keys():
#         print("Just processed piece 1")
#         raise Exception("stoping")
    
    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
        
    # makes sure that no two child branches try to connect to the same main branch
    from collections import Counter
    mesh_stitch_counter = Counter(np.array([val for val in child_meshes_stitch_facets.values()])[:,1])

    repeat_main_facets = [key for key,val in mesh_stitch_counter.items() if (key != -1 and val > 1)] #gets the main mesh facet with multiples
    print("repeat_main_facets = " + str(repeat_main_facets))


    #how to fix that some faces are trying to branch to same main facet
    #make it iterate through all of the repeats
    if len(repeat_main_facets)>0:
        for repeat_main in repeat_main_facets:
            child_mesh_double_indexes = [key for key,val in child_meshes_stitch_facets.items() if val[1] == repeat_main]
            print("child_mesh_double_indexes = " + str(child_mesh_double_indexes))


            #decide which one to keep and then ditch all the rest --> pick the CLOSEST ONE, and not the best matching area:

            ###### picks the closest area
            min_distance = 10000000000
            min_child = -1


            for child_index in child_mesh_double_indexes:
                current_distance = child_meshes_stitch_distances[child_index]

                if current_distance < min_distance:
                    min_child = child_index
                    min_distance = current_distance

            print(f"min_child = {min_child}, max_ratio = {min_distance}")

    #         ###### picks the maximum area
    #         max_ratio = -1
    #         max_child = -1


    #         for child_index in child_mesh_double_indexes:
    #             current_ratio = child_meshes_stitch_face_ratios[child_index]

    #             if current_ratio > max_ratio:
    #                 max_child = child_index
    #                 max_ratio = current_ratio

    #         print(f"max_child = {max_child}, max_ratio = {max_ratio}")



            #remove the others from the stitch facets
            for double_index in child_mesh_double_indexes:
                if double_index != min_child:
                    del child_meshes_stitch_facets[double_index]
    
    """
    Pseudocode for stitching:
    1) For each pair in the child_meshes_stitch_facets:
    a. Get the child mesh for that pair
    b. Get the list of faces for the child facet (from the facet number)
    c. Get the list of faces for the main facet (from the main number)

    d. Get the original number of faces and vertices in the main mesh
    d2. Use the orignal number of faces and add to list of faces for child facet to offset them correctly
        - Save this number list in a dictionary (to use for later and creating the submesh)
    e. Add the two meshes together to get big mesh
    f. Send the two meshes and the two facet lists to the restitching function to get a main mesh that is stitched up
     - but send it to function that doesnt delete the original facet faces 
         (because this would remove meshes from original and screw up facet number)
    g. reassign the main_mesh to this newly stitched up mesh
    h. recompute the facets for the main mesh



    """
    

    current_main_mesh = main_mesh.copy()
    
    main_mesh_facet_index_to_delete = []

    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
    else: #if there were stitch points found
        print("child_meshes_stitch_facets = " + str(child_meshes_stitch_facets))
        for child_key,pair in child_meshes_stitch_facets.items():
            """
            child_key has the child that is currently being processed
            
            pair has the facet ids that are to be stitched together
            
            """
            
            child_used_facet_index = pair[0]
            main_used_faceet_index = pair[1]
            
            stitch_time = time.time()
            print(f"---Stitching child {child_key} with pair: {pair}---")
            current_child_mesh = child_meshes[child_key]
            current_child_facet_faces = child_meshes_facets[child_key][0][pair[0]]


            current_main_mesh_facet_faces = main_mesh_facets[pair[1]]

            #Get the original number of faces and vertices in the main mesh
            original_mesh_faces_len = len(current_main_mesh.faces)
            current_child_facet_faces_adjusted = current_child_facet_faces + original_mesh_faces_len

            #Save the faces number for deletion later
            child_faces_to_remove += current_child_facet_faces_adjusted.tolist()
            main_faces_to_remove += current_main_mesh_facet_faces.tolist()

            combined_mesh = current_main_mesh + current_child_mesh

            #how to stitch up the mesh
            start_time = time.time()
            current_main_mesh = stitch_mesh_piece_vp4(new_mesh=combined_mesh,
                                                           facet_1=current_main_mesh_facet_faces,
                                                           facet_2=current_child_facet_faces_adjusted,
                                                          delete_facets=False,
                                                          return_added_mesh=False,
                                                           fix_normals = False)
            
            print(f"returned from stitch mesh: {time.time() - start_time}")
            
            
            #Don't need to do any deletion now 
            
            #add the child to processed child
            children_processed.append(child_key)
            print(f"Finished stitching child {child_key} : {time.time() - stitch_time}")
            
            """
            Add all of the child facets that weren't the ones used to the main mesh facets (with adjusted facet numbers)
            """
            original_mesh_faces_len #the original number of faces in the main mesh (including all those stitched before)
            
            #remove certian rows from array of the child facets and cetners
            current_child_facet_faces_with_deletion = np.delete(child_meshes_facets[child_key][0],(child_used_facet_index),axis=0)
            current_child_facet_centers_with_deletion = np.delete(child_meshes_facets[child_key][1],(child_used_facet_index),axis=0)

            #have to adjust the faces of the child_facets list to account for the faces off set
            current_child_facet_faces_with_deletion = current_child_facet_faces_with_deletion + original_mesh_faces_len

            #append this list to the main mesh list
            main_mesh_facets = np.concatenate([main_mesh_facets,current_child_facet_faces_with_deletion])
            main_mesh_facets_centers = np.concatenate([main_mesh_facets_centers,current_child_facet_centers_with_deletion])

            #save off the facets to delete for the main mesh at the end of the loop
            main_mesh_facet_index_to_delete.append(pair[1])
            



        #reset the no_new_children_multiplier because there were successful stitching
        no_new_children_multiplier = 0
        """recompute the main mesh facets  ###Not going to recompute anymore
        #main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
        
        Now we just remove the main mesh facets that are used and reassign
        """
        main_mesh = current_main_mesh
    
    
        #at the end of the big loop have to delete the facets used from main mesh
        #remove certian rows from array
        
        #creating the new facets
        main_mesh_facets = np.delete(main_mesh_facets,(main_mesh_facet_index_to_delete),axis=0)
        main_mesh_facets_centers = np.delete(main_mesh_facets_centers,(main_mesh_facet_index_to_delete),axis=0)

        
        print(f"***************Finished big stitching iteration: {time.time() - stitch_loop_time}***************")
        
#         if 0 in children_processed and 1 in children_processed:
#             print("Exiting before does piece 2")
#             break

        if len(np.unique(children_processed)) == len(child_meshes):
            print("All children have been processed")
            break
    

#children  that weren't attached:
non_attached = [10,14,15,19,20,21,22,25,28,29,30,33,42,44,45,46,47,48,50]
# Out:
# Starting Child 0
# 699 11118
# Done distance matrix: 0.35055971145629883
# Child 0 There were no points close enough
# Starting Child 1
# 644 11118
# Done distance matrix: 0.3002750873565674
# Done Generating final pairs: 0.3143625259399414
# best_stitch_pair = [ 297 2053]
# best_stitch_pair_size = 126407.37080777145
# best_stitch_pair_distance = 322.83217480906654
# best_stitch_pair_size_ratio = 0.4329072487180667
# Starting Child 2
# 485 11118
# Done distance matrix: 0.3146355152130127
# Done Generating final pairs: 0.42852330207824707
# best_stitch_pair = [  11 7052]
# best_stitch_pair_size = 3722036.954014628
# best_stitch_pair_distance = 134.73286075380463
# best_stitch_pair_size_ratio = 0.936193249947911
# Starting Child 3
# 887 11118
# Done distance matrix: 0.5621311664581299
# Child 3 There were no points close enough
# Starting Child 4
# 521 11118
# Done distance matrix: 0.2721414566040039
# Child 4 There were no points close enough
# Starting Child 5
# 203 11118
# Done distance matrix: 0.08751487731933594
# Child 5 There were no points close enough
# Starting Child 6
# 567 11118
# Done distance matrix: 0.33533692359924316
# Child 6 There were no points close enough
# Starting Child 7
# 212 11118
# Done distance matrix: 0.12251973152160645
# Child 7 There were no points close enough
# Starting Child 8
# 170 11118
# Done distance matrix: 0.07317018508911133
# Child 8 There were no points close enough
# Starting Child 9
# 460 11118
# Done distance matrix: 0.223829984664917
# Done Generating final pairs: 0.2344074249267578
# best_stitch_pair = [   64 10707]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 789.664948922311
# best_stitch_pair_size_ratio = 0.0
# Starting Child 10
# 130 11118
# Done distance matrix: 0.08101224899291992
# Child 10 There were no points close enough
# Starting Child 11
# 290 11118
# Done distance matrix: 0.13146018981933594
# Child 11 There were no points close enough
# Starting Child 12
# 191 11118
# Done distance matrix: 0.07985568046569824
# Child 12 There were no points close enough
# Starting Child 13
# 185 11118
# Done distance matrix: 0.10495615005493164
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 11118
# Done distance matrix: 0.0025336742401123047
# Child 15 There were no points close enough
# Starting Child 16
# 187 11118
# Done distance matrix: 0.1002359390258789
# Child 16 There were no points close enough
# Starting Child 17
# 470 11118
# Done distance matrix: 0.2904479503631592
# Child 17 There were no points close enough
# Starting Child 18
# 261 11118
# Done distance matrix: 0.13222551345825195
# Child 18 There were no points close enough
# Starting Child 19
# 10 11118
# Done distance matrix: 0.007414340972900391
# Child 19 There were no points close enough
# Starting Child 20
# 16 11118
# Done distance matrix: 0.010782957077026367
# Child 20 There were no points close enough
# Starting Child 21
# 4 11118
# Done distance matrix: 0.002585172653198242
# Child 21 There were no points close enough
# Starting Child 22
# 3 11118
# Done distance matrix: 0.0021142959594726562
# Child 22 There were no points close enough
# Starting Child 23
# 16 11118
# Done distance matrix: 0.009473085403442383
# Child 23 There were no points close enough
# Starting Child 24
# 14 11118
# Done distance matrix: 0.008778095245361328
# Child 24 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 26
# 63 11118
# Done distance matrix: 0.03581047058105469
# Child 26 There were no points close enough
# Starting Child 27
# 8 11118
# Done distance matrix: 0.004956245422363281
# Done Generating final pairs: 0.016559600830078125
# best_stitch_pair = [   2 8006]
# best_stitch_pair_size = 75520.57459223573
# best_stitch_pair_distance = 170.50810536391745
# best_stitch_pair_size_ratio = 0.47765958862343944
# Starting Child 28
# 56 11118
# Done distance matrix: 0.036376953125
# Child 28 There were no points close enough
# Starting Child 29
# 5 11118
# Done distance matrix: 0.0032110214233398438
# Child 29 There were no points close enough
# Starting Child 30
# 3 11118
# Done distance matrix: 0.0019075870513916016
# Child 30 There were no points close enough
# Starting Child 31
# 124 11118
# Done distance matrix: 0.07680916786193848
# Child 31 There were no points close enough
# Starting Child 32
# 184 11118
# Done distance matrix: 0.10025453567504883
# Done Generating final pairs: 0.11255693435668945
# best_stitch_pair = [ 122 2269]
# best_stitch_pair_size = 44775.11831009884
# best_stitch_pair_distance = 446.8338762966404
# best_stitch_pair_size_ratio = 0.36436845554798764
# Starting Child 33
# 34 11118
# Done distance matrix: 0.016839981079101562
# Child 33 There were no points close enough
# Starting Child 34
# 53 11118
# Done distance matrix: 0.02770686149597168
# Child 34 There were no points close enough
# Starting Child 35
# 27 11118
# Done distance matrix: 0.014842510223388672
# Done Generating final pairs: 0.026174306869506836
# best_stitch_pair = [  2 662]
# best_stitch_pair_size = 676419.9238749678
# best_stitch_pair_distance = 200.96274019074056
# best_stitch_pair_size_ratio = 0.45746294362954565
# Starting Child 36
# 28 11118
# Done distance matrix: 0.014970779418945312
# Child 36 There were no points close enough
# Starting Child 37
# 63 11118
# Done distance matrix: 0.030833959579467773
# Child 37 There were no points close enough
# Starting Child 38
# 4 11118
# Done distance matrix: 0.0020949840545654297
# Child 38 There were no points close enough
# Starting Child 39
# 18 11118
# Done distance matrix: 0.009228706359863281
# Child 39 There were no points close enough
# Starting Child 40
# 5 11118
# Done distance matrix: 0.002611398696899414
# Child 40 There were no points close enough
# Starting Child 41
# 37 11118
# Done distance matrix: 0.01871037483215332
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 11118
# Done distance matrix: 0.001653909683227539
# Child 43 There were no points close enough
# Starting Child 44
# 10 11118
# Done distance matrix: 0.005203723907470703
# Child 44 There were no points close enough
# Starting Child 45
# 17 11118
# Done distance matrix: 0.008801460266113281
# Child 45 There were no points close enough
# Starting Child 46
# 6 11118
# Done distance matrix: 0.003103494644165039
# Child 46 There were no points close enough
# Starting Child 47
# 4 11118
# Done distance matrix: 0.0022759437561035156
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 11118
# Done distance matrix: 0.003297090530395508
# Child 48 There were no points close enough
# Starting Child 49
# 7 11118
# Done distance matrix: 0.003721475601196289
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [297, 2053], 2: [11, 7052], 9: [64, 10707], 27: [2, 8006], 32: [122, 2269], 35: [2, 662]}
# ---Stitching child 1 with pair: [297, 2053]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 82661, starting edge 2nd facet= 928098,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.6226043701171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027158498764038086
# returned from stitch mesh: 0.9262416362762451
# Finished stitching child 1 : 1.1224377155303955
# ---Stitching child 2 with pair: [11, 7052]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 28330, starting edge 2nd facet= 935417,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 48
# Starting Organizing vertices for side 1
# edge_1_order done, len = 42
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 0.00018548965454101562
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0316159725189209
# returned from stitch mesh: 1.1614389419555664
# Finished stitching child 2 : 1.3103363513946533
# ---Stitching child 9 with pair: [64, 10707]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 58736, starting edge 2nd facet= 951380,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 0
# About to add faces
# Finished adding faces: 1.4066696166992188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02654242515563965
# returned from stitch mesh: 0.9538049697875977
# Finished stitching child 9 : 1.1415774822235107
# ---Stitching child 27 with pair: [2, 8006]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 837126, starting edge 2nd facet= 960303,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.031494855880737305
# returned from stitch mesh: 0.948967695236206
# Finished stitching child 27 : 1.1028494834899902
# ---Stitching child 32 with pair: [122, 2269]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 421339, starting edge 2nd facet= 961731,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.018166065216064453
# returned from stitch mesh: 1.3585646152496338
# Finished stitching child 32 : 1.5566349029541016
# ---Stitching child 35 with pair: [2, 662]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 94575, starting edge 2nd facet= 963012,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 4.076957702636719e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03211641311645508
# returned from stitch mesh: 1.0314221382141113
# Finished stitching child 35 : 1.2360680103302002
# ***************Finished big stitching iteration: 13.717343807220459***************
# Starting Child 0
# 699 12914
# Done distance matrix: 0.48188090324401855
# Done Generating final pairs: 0.5165209770202637
# best_stitch_pair = [  295 11777]
# best_stitch_pair_size = 2781600.2288127085
# best_stitch_pair_distance = 160.7360024620024
# best_stitch_pair_size_ratio = 0.5732400896866683
# Starting Child 3
# 887 12914
# Done distance matrix: 0.4371488094329834
# Child 3 There were no points close enough
# Starting Child 4
# 521 12914
# Done distance matrix: 0.20984959602355957
# Child 4 There were no points close enough
# Starting Child 5
# 203 12914
# Done distance matrix: 0.08393311500549316
# Done Generating final pairs: 0.08589768409729004
# best_stitch_pair = [  153 12700]
# best_stitch_pair_size = 59248.422708488375
# best_stitch_pair_distance = 692.5219206272919
# best_stitch_pair_size_ratio = 0.8272948027230579
# Starting Child 6
# 567 12914
# Done distance matrix: 0.31420302391052246
# Child 6 There were no points close enough
# Starting Child 7
# 212 12914
# Done distance matrix: 0.14867877960205078
# Child 7 There were no points close enough
# Starting Child 8
# 170 12914
# Done distance matrix: 0.07646465301513672
# Child 8 There were no points close enough
# Starting Child 10
# 130 12914
# Done distance matrix: 0.05855870246887207
# Child 10 There were no points close enough
# Starting Child 11
# 290 12914
# Done distance matrix: 0.15712690353393555
# Child 11 There were no points close enough
# Starting Child 12
# 191 12914
# Done distance matrix: 0.11441445350646973
# Child 12 There were no points close enough
# Starting Child 13
# 185 12914
# Done distance matrix: 0.0758512020111084
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 12914
# Done distance matrix: 0.002469301223754883
# Child 15 There were no points close enough
# Starting Child 16
# 187 12914
# Done distance matrix: 0.13611149787902832
# Done Generating final pairs: 0.16252875328063965
# best_stitch_pair = [   30 11882]
# best_stitch_pair_size = 2883036.8729235698
# best_stitch_pair_distance = 390.2646613688339
# best_stitch_pair_size_ratio = 0.756428523739565
# Starting Child 17
# 470 12914
# Done distance matrix: 0.20956802368164062
# Child 17 There were no points close enough
# Starting Child 18
# 261 12914
# Done distance matrix: 0.11021971702575684
# Child 18 There were no points close enough
# Starting Child 19
# 10 12914
# Done distance matrix: 0.004939556121826172
# Child 19 There were no points close enough
# Starting Child 20
# 16 12914
# Done distance matrix: 0.010684728622436523
# Child 20 There were no points close enough
# Starting Child 21
# 4 12914
# Done distance matrix: 0.0019328594207763672
# Child 21 There were no points close enough
# Starting Child 22
# 3 12914
# Done distance matrix: 0.0016124248504638672
# Child 22 There were no points close enough
# Starting Child 23
# 16 12914
# Done distance matrix: 0.00652003288269043
# Child 23 There were no points close enough
# Starting Child 24
# 14 12914
# Done distance matrix: 0.006203413009643555
# Done Generating final pairs: 0.010416507720947266
# best_stitch_pair = [    5 11821]
# best_stitch_pair_size = 445825.1688913071
# best_stitch_pair_distance = 417.2369812716303
# best_stitch_pair_size_ratio = 0.7097850609379541
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 26
# 63 12914
# Done distance matrix: 0.02585315704345703
# Child 26 There were no points close enough
# Starting Child 28
# 56 12914
# Done distance matrix: 0.032598257064819336
# Child 28 There were no points close enough
# Starting Child 29
# 5 12914
# Done distance matrix: 0.002370595932006836
# Child 29 There were no points close enough
# Starting Child 30
# 3 12914
# Done distance matrix: 0.0014255046844482422
# Child 30 There were no points close enough
# Starting Child 31
# 124 12914
# Done distance matrix: 0.0554502010345459
# Child 31 There were no points close enough
# Starting Child 33
# 34 12914
# Done distance matrix: 0.01365971565246582
# Child 33 There were no points close enough
# Starting Child 34
# 53 12914
# Done distance matrix: 0.021190881729125977
# Child 34 There were no points close enough
# Starting Child 36
# 28 12914
# Done distance matrix: 0.011400222778320312
# Done Generating final pairs: 0.01653289794921875
# best_stitch_pair = [    0 12888]
# best_stitch_pair_size = 883352.4059815214
# best_stitch_pair_distance = 646.9399508826754
# best_stitch_pair_size_ratio = 0.6418572978661629
# Starting Child 37
# 63 12914
# Done distance matrix: 0.025123119354248047
# Child 37 There were no points close enough
# Starting Child 38
# 4 12914
# Done distance matrix: 0.002039670944213867
# Child 38 There were no points close enough
# Starting Child 39
# 18 12914
# Done distance matrix: 0.014388084411621094
# Done Generating final pairs: 0.017779827117919922
# best_stitch_pair = [    8 11864]
# best_stitch_pair_size = 25771.093255100695
# best_stitch_pair_distance = 725.4242984625582
# best_stitch_pair_size_ratio = 0.5414248529874082
# Starting Child 40
# 5 12914
# Done distance matrix: 0.002277851104736328
# Child 40 There were no points close enough
# Starting Child 41
# 37 12914
# Done distance matrix: 0.014499425888061523
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 12914
# Done distance matrix: 0.0014619827270507812
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 12914
# Done distance matrix: 0.0041141510009765625
# Child 44 There were no points close enough
# Starting Child 45
# 17 12914
# Done distance matrix: 0.006833553314208984
# Child 45 There were no points close enough
# Starting Child 46
# 6 12914
# Done distance matrix: 0.002557516098022461
# Child 46 There were no points close enough
# Starting Child 47
# 4 12914
# Done distance matrix: 0.0019099712371826172
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 12914
# Done distance matrix: 0.0024328231811523438
# Child 48 There were no points close enough
# Starting Child 49
# 7 12914
# Done distance matrix: 0.0027763843536376953
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [295, 11777], 5: [153, 12700], 16: [30, 11882], 24: [5, 11821], 36: [0, 12888], 39: [8, 11864]}
# ---Stitching child 0 with pair: [295, 11777]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 938420, starting edge 2nd facet= 1005482,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 40
# Starting Organizing vertices for side 1
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_1_order done, len = 51
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 11
# About to add faces
# Finished adding faces: 0.0001513957977294922
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04638504981994629
# returned from stitch mesh: 1.3244166374206543
# Finished stitching child 0 : 1.4887065887451172
# ---Stitching child 5 with pair: [153, 12700]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 960213, starting edge 2nd facet= 1022553,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 5.054473876953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05630636215209961
# returned from stitch mesh: 1.5309042930603027
# Finished stitching child 5 : 1.8197503089904785
# ---Stitching child 16 with pair: [30, 11882]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934312, starting edge 2nd facet= 1025081,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 31
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 7.677078247070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03529047966003418
# returned from stitch mesh: 1.216052532196045
# Finished stitching child 16 : 1.5032951831817627
# ---Stitching child 24 with pair: [5, 11821]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934536, starting edge 2nd facet= 1029027,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030864715576171875
# returned from stitch mesh: 1.0597739219665527
# Finished stitching child 24 : 1.2628135681152344
# ---Stitching child 36 with pair: [0, 12888]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 963013, starting edge 2nd facet= 1029281,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.695487976074219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0406804084777832
# returned from stitch mesh: 1.0063018798828125
# Finished stitching child 36 : 1.1782464981079102
# ---Stitching child 39 with pair: [8, 11864]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 944297, starting edge 2nd facet= 1029586,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028481245040893555
# returned from stitch mesh: 0.9706821441650391
# Finished stitching child 39 : 1.1467804908752441
# ***************Finished big stitching iteration: 12.997873306274414***************
# Starting Child 3
# 887 14051
# Done distance matrix: 0.6448895931243896
# Child 3 There were no points close enough
# Starting Child 4
# 521 14051
# Done distance matrix: 0.4475572109222412
# Child 4 There were no points close enough
# Starting Child 6
# 567 14051
# Done distance matrix: 0.38061094284057617
# Child 6 There were no points close enough
# Starting Child 7
# 212 14051
# Done distance matrix: 0.1197056770324707
# Child 7 There were no points close enough
# Starting Child 8
# 170 14051
# Done distance matrix: 0.12616539001464844
# Child 8 There were no points close enough
# Starting Child 10
# 130 14051
# Done distance matrix: 0.08698534965515137
# Child 10 There were no points close enough
# Starting Child 11
# 290 14051
# Done distance matrix: 0.2498795986175537
# Done Generating final pairs: 0.2696530818939209
# best_stitch_pair = [  206 13847]
# best_stitch_pair_size = 2134758.3459845064
# best_stitch_pair_distance = 252.54897008950022
# best_stitch_pair_size_ratio = 0.9143665334861354
# Starting Child 12
# 191 14051
# Done distance matrix: 0.12491202354431152
# Done Generating final pairs: 0.12826848030090332
# best_stitch_pair = [  165 13800]
# best_stitch_pair_size = 75763.34031957734
# best_stitch_pair_distance = 133.59897154753196
# best_stitch_pair_size_ratio = 0.8622937409390152
# Starting Child 13
# 185 14051
# Done distance matrix: 0.1122744083404541
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 14051
# Done distance matrix: 0.003427267074584961
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 470 14051
# Done distance matrix: 0.2917156219482422
# Child 17 There were no points close enough
# Starting Child 18
# 261 14051
# Done distance matrix: 0.16781902313232422
# Child 18 There were no points close enough
# Starting Child 19
# 10 14051
# Done distance matrix: 0.006239652633666992
# Child 19 There were no points close enough
# Starting Child 20
# 16 14051
# Done distance matrix: 0.010720252990722656
# Child 20 There were no points close enough
# Starting Child 21
# 4 14051
# Done distance matrix: 0.0024595260620117188
# Child 21 There were no points close enough
# Starting Child 22
# 3 14051
# Done distance matrix: 0.0018279552459716797
# Child 22 There were no points close enough
# Starting Child 23
# 16 14051
# Done distance matrix: 0.009039640426635742
# Child 23 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 26
# 63 14051
# Done distance matrix: 0.033959388732910156
# Done Generating final pairs: 0.03692984580993652
# best_stitch_pair = [    4 13629]
# best_stitch_pair_size = 142549.35198714465
# best_stitch_pair_distance = 301.4510828666649
# best_stitch_pair_size_ratio = 0.501101426366464
# Starting Child 28
# 56 14051
# Done distance matrix: 0.030226469039916992
# Child 28 There were no points close enough
# Starting Child 29
# 5 14051
# Done distance matrix: 0.003544330596923828
# Child 29 There were no points close enough
# Starting Child 30
# 3 14051
# Done distance matrix: 0.001981019973754883
# Child 30 There were no points close enough
# Starting Child 31
# 124 14051
# Done distance matrix: 0.05835580825805664
# Child 31 There were no points close enough
# Starting Child 33
# 34 14051
# Done distance matrix: 0.015813350677490234
# Child 33 There were no points close enough
# Starting Child 34
# 53 14051
# Done distance matrix: 0.023209810256958008
# Done Generating final pairs: 0.029160022735595703
# best_stitch_pair = [   29 14010]
# best_stitch_pair_size = 611219.884607617
# best_stitch_pair_distance = 156.93980186490012
# best_stitch_pair_size_ratio = 0.982445965311448
# Starting Child 37
# 63 14051
# Done distance matrix: 0.0259554386138916
# Child 37 There were no points close enough
# Starting Child 38
# 4 14051
# Done distance matrix: 0.0020749568939208984
# Child 38 There were no points close enough
# Starting Child 40
# 5 14051
# Done distance matrix: 0.0023529529571533203
# Done Generating final pairs: 0.006163120269775391
# best_stitch_pair = [    1 13925]
# best_stitch_pair_size = 56922.70292744968
# best_stitch_pair_distance = 477.9635701685829
# best_stitch_pair_size_ratio = 0.676302071523766
# Starting Child 41
# 37 14051
# Done distance matrix: 0.01627516746520996
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 14051
# Done distance matrix: 0.0017018318176269531
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 14051
# Done distance matrix: 0.0047414302825927734
# Child 44 There were no points close enough
# Starting Child 45
# 17 14051
# Done distance matrix: 0.007736921310424805
# Child 45 There were no points close enough
# Starting Child 46
# 6 14051
# Done distance matrix: 0.0027768611907958984
# Child 46 There were no points close enough
# Starting Child 47
# 4 14051
# Done distance matrix: 0.0019838809967041016
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 14051
# Done distance matrix: 0.00266265869140625
# Child 48 There were no points close enough
# Starting Child 49
# 7 14051
# Done distance matrix: 0.003228425979614258
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [206, 13847], 12: [165, 13800], 26: [4, 13629], 34: [29, 14010], 40: [1, 13925]}
# ---Stitching child 11 with pair: [206, 13847]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1024903, starting edge 2nd facet= 1029920,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 0.0001251697540283203
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03826451301574707
# returned from stitch mesh: 1.5863399505615234
# Finished stitching child 11 : 1.7678799629211426
# ---Stitching child 12 with pair: [165, 13800]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1022677, starting edge 2nd facet= 1037457,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.552436828613281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05113577842712402
# returned from stitch mesh: 1.1457853317260742
# Finished stitching child 12 : 1.3617379665374756
# ---Stitching child 26 with pair: [4, 13629]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1022259, starting edge 2nd facet= 1039606,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.035227060317993164
# returned from stitch mesh: 1.0945966243743896
# Finished stitching child 26 : 1.3174495697021484
# ---Stitching child 34 with pair: [29, 14010]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1029508, starting edge 2nd facet= 1040436,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.8623809814453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04192495346069336
# returned from stitch mesh: 1.1773126125335693
# Finished stitching child 34 : 1.3632068634033203
# ---Stitching child 40 with pair: [1, 13925]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1025367, starting edge 2nd facet= 1041983,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03314065933227539
# returned from stitch mesh: 1.225020170211792
# Finished stitching child 40 : 1.4358043670654297
# ***************Finished big stitching iteration: 11.882404804229736***************
# Starting Child 3
# 887 14643
# Done distance matrix: 0.4047219753265381
# Child 3 There were no points close enough
# Starting Child 4
# 521 14643
# Done distance matrix: 0.2578749656677246
# Child 4 There were no points close enough
# Starting Child 6
# 567 14643
# Done distance matrix: 0.36487388610839844
# Child 6 There were no points close enough
# Starting Child 7
# 212 14643
# Done distance matrix: 0.09734320640563965
# Child 7 There were no points close enough
# Starting Child 8
# 170 14643
# Done distance matrix: 0.08018898963928223
# Child 8 There were no points close enough
# Starting Child 10
# 130 14643
# Done distance matrix: 0.06246161460876465
# Child 10 There were no points close enough
# Starting Child 13
# 185 14643
# Done distance matrix: 0.09540987014770508
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 14643
# Done distance matrix: 0.002027750015258789
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 470 14643
# Done distance matrix: 0.2464001178741455
# Done Generating final pairs: 0.25138235092163086
# best_stitch_pair = [  221 14600]
# best_stitch_pair_size = 859620.1038684781
# best_stitch_pair_distance = 737.0193281922791
# best_stitch_pair_size_ratio = 0.3821383730413649
# Starting Child 18
# 261 14643
# Done distance matrix: 0.12949347496032715
# Child 18 There were no points close enough
# Starting Child 19
# 10 14643
# Done distance matrix: 0.005371809005737305
# Child 19 There were no points close enough
# Starting Child 20
# 16 14643
# Done distance matrix: 0.00810551643371582
# Child 20 There were no points close enough
# Starting Child 21
# 4 14643
# Done distance matrix: 0.00225067138671875
# Child 21 There were no points close enough
# Starting Child 22
# 3 14643
# Done distance matrix: 0.0017361640930175781
# Child 22 There were no points close enough
# Starting Child 23
# 16 14643
# Done distance matrix: 0.007943868637084961
# Child 23 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 14643
# Done distance matrix: 0.02697277069091797
# Child 28 There were no points close enough
# Starting Child 29
# 5 14643
# Done distance matrix: 0.0026450157165527344
# Child 29 There were no points close enough
# Starting Child 30
# 3 14643
# Done distance matrix: 0.0017714500427246094
# Child 30 There were no points close enough
# Starting Child 31
# 124 14643
# Done distance matrix: 0.059728384017944336
# Child 31 There were no points close enough
# Starting Child 33
# 34 14643
# Done distance matrix: 0.017042160034179688
# Child 33 There were no points close enough
# Starting Child 37
# 63 14643
# Done distance matrix: 0.029308557510375977
# Done Generating final pairs: 0.030810117721557617
# best_stitch_pair = [    3 14577]
# best_stitch_pair_size = 49084.28270166188
# best_stitch_pair_distance = 297.5936887733172
# best_stitch_pair_size_ratio = 0.48412922201830955
# Starting Child 38
# 4 14643
# Done distance matrix: 0.002333402633666992
# Done Generating final pairs: 0.003964662551879883
# best_stitch_pair = [    0 14577]
# best_stitch_pair_size = 43698.055978165095
# best_stitch_pair_distance = 135.2604041681748
# best_stitch_pair_size_ratio = 0.578313193141808
# Starting Child 41
# 37 14643
# Done distance matrix: 0.01776862144470215
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 14643
# Done distance matrix: 0.0017960071563720703
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 14643
# Done distance matrix: 0.00805354118347168
# Child 44 There were no points close enough
# Starting Child 45
# 17 14643
# Done distance matrix: 0.013444662094116211
# Child 45 There were no points close enough
# Starting Child 46
# 6 14643
# Done distance matrix: 0.004892587661743164
# Child 46 There were no points close enough
# Starting Child 47
# 4 14643
# Done distance matrix: 0.003245115280151367
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 14643
# Done distance matrix: 0.004737138748168945
# Child 48 There were no points close enough
# Starting Child 49
# 7 14643
# Done distance matrix: 0.008954524993896484
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = [14577]
# child_mesh_double_indexes = [37, 38]
# min_child = 38, max_ratio = 135.2604041681748
# child_meshes_stitch_facets = {17: [221, 14600], 38: [0, 14577]}
# ---Stitching child 17 with pair: [221, 14600]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1040092, starting edge 2nd facet= 1045308,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 4.172325134277344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04355931282043457
# returned from stitch mesh: 1.0736172199249268
# Finished stitching child 17 : 1.264660358428955
# ---Stitching child 38 with pair: [0, 14577]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1039941, starting edge 2nd facet= 1051650,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4781951904296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03438520431518555
# returned from stitch mesh: 1.172569990158081
# Finished stitching child 38 : 1.348177433013916
# ***************Finished big stitching iteration: 5.964207172393799***************
# Starting Child 3
# 887 15113
# Done distance matrix: 0.7134549617767334
# Done Generating final pairs: 0.7255895137786865
# best_stitch_pair = [  232 14761]
# best_stitch_pair_size = 690856.3646172398
# best_stitch_pair_distance = 270.2210230377153
# best_stitch_pair_size_ratio = 0.7589459759005658
# Starting Child 4
# 521 15113
# Done distance matrix: 0.35059332847595215
# Child 4 There were no points close enough
# Starting Child 6
# 567 15113
# Done distance matrix: 0.40398097038269043
# Child 6 There were no points close enough
# Starting Child 7
# 212 15113
# Done distance matrix: 0.18101143836975098
# Child 7 There were no points close enough
# Starting Child 8
# 170 15113
# Done distance matrix: 0.10832595825195312
# Child 8 There were no points close enough
# Starting Child 10
# 130 15113
# Done distance matrix: 0.07465934753417969
# Child 10 There were no points close enough
# Starting Child 13
# 185 15113
# Done distance matrix: 0.10549426078796387
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 15113
# Done distance matrix: 0.0018267631530761719
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 15113
# Done distance matrix: 0.23647665977478027
# Child 18 There were no points close enough
# Starting Child 19
# 10 15113
# Done distance matrix: 0.007102251052856445
# Child 19 There were no points close enough
# Starting Child 20
# 16 15113
# Done distance matrix: 0.009664058685302734
# Child 20 There were no points close enough
# Starting Child 21
# 4 15113
# Done distance matrix: 0.002622842788696289
# Child 21 There were no points close enough
# Starting Child 22
# 3 15113
# Done distance matrix: 0.0020601749420166016
# Child 22 There were no points close enough
# Starting Child 23
# 16 15113
# Done distance matrix: 0.009608983993530273
# Child 23 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 15113
# Done distance matrix: 0.03143501281738281
# Child 28 There were no points close enough
# Starting Child 29
# 5 15113
# Done distance matrix: 0.003323078155517578
# Child 29 There were no points close enough
# Starting Child 30
# 3 15113
# Done distance matrix: 0.0019383430480957031
# Child 30 There were no points close enough
# Starting Child 31
# 124 15113
# Done distance matrix: 0.06995439529418945
# Child 31 There were no points close enough
# Starting Child 33
# 34 15113
# Done distance matrix: 0.02029132843017578
# Child 33 There were no points close enough
# Starting Child 37
# 63 15113
# Done distance matrix: 0.03574490547180176
# Done Generating final pairs: 0.03740262985229492
# best_stitch_pair = [    3 14576]
# best_stitch_pair_size = 44769.959798623386
# best_stitch_pair_distance = 323.9721750738081
# best_stitch_pair_size_ratio = 0.3536798736486835
# Starting Child 41
# 37 15113
# Done distance matrix: 0.02096271514892578
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 15113
# Done distance matrix: 0.001718759536743164
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 15113
# Done distance matrix: 0.0061397552490234375
# Child 44 There were no points close enough
# Starting Child 45
# 17 15113
# Done distance matrix: 0.010306358337402344
# Child 45 There were no points close enough
# Starting Child 46
# 6 15113
# Done distance matrix: 0.003746509552001953
# Child 46 There were no points close enough
# Starting Child 47
# 4 15113
# Done distance matrix: 0.0024182796478271484
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 15113
# Done distance matrix: 0.003535032272338867
# Child 48 There were no points close enough
# Starting Child 49
# 7 15113
# Done distance matrix: 0.004254341125488281
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [232, 14761], 37: [3, 14576]}
# ---Stitching child 3 with pair: [232, 14761]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1050787, starting edge 2nd facet= 1059859,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 3.9577484130859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.051476240158081055
# returned from stitch mesh: 1.527261734008789
# Finished stitching child 3 : 1.8286685943603516
# ---Stitching child 37 with pair: [3, 14576]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1039853, starting edge 2nd facet= 1066237,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3589859008789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0202791690826416
# returned from stitch mesh: 1.4484496116638184
# Finished stitching child 37 : 1.7240982055664062
# ***************Finished big stitching iteration: 7.272221088409424***************
# Starting Child 4
# 521 16059
# Done distance matrix: 0.38533520698547363
# Child 4 There were no points close enough
# Starting Child 6
# 567 16059
# Done distance matrix: 0.41097354888916016
# Child 6 There were no points close enough
# Starting Child 7
# 212 16059
# Done distance matrix: 0.22519469261169434
# Child 7 There were no points close enough
# Starting Child 8
# 170 16059
# Done distance matrix: 0.10593605041503906
# Child 8 There were no points close enough
# Starting Child 10
# 130 16059
# Done distance matrix: 0.07501506805419922
# Child 10 There were no points close enough
# Starting Child 13
# 185 16059
# Done distance matrix: 0.11490964889526367
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16059
# Done distance matrix: 0.0017704963684082031
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16059
# Done distance matrix: 0.16180419921875
# Child 18 There were no points close enough
# Starting Child 19
# 10 16059
# Done distance matrix: 0.011689901351928711
# Child 19 There were no points close enough
# Starting Child 20
# 16 16059
# Done distance matrix: 0.016948223114013672
# Child 20 There were no points close enough
# Starting Child 21
# 4 16059
# Done distance matrix: 0.004408359527587891
# Child 21 There were no points close enough
# Starting Child 22
# 3 16059
# Done distance matrix: 0.003192424774169922
# Child 22 There were no points close enough
# Starting Child 23
# 16 16059
# Done distance matrix: 0.0153961181640625
# Child 23 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 16059
# Done distance matrix: 0.042665719985961914
# Child 28 There were no points close enough
# Starting Child 29
# 5 16059
# Done distance matrix: 0.004102230072021484
# Child 29 There were no points close enough
# Starting Child 30
# 3 16059
# Done distance matrix: 0.0022542476654052734
# Child 30 There were no points close enough
# Starting Child 31
# 124 16059
# Done distance matrix: 0.0763707160949707
# Done Generating final pairs: 0.07819008827209473
# best_stitch_pair = [   90 16005]
# best_stitch_pair_size = 28857.48103081534
# best_stitch_pair_distance = 410.16058459605557
# best_stitch_pair_size_ratio = 0.7328099769970607
# Starting Child 33
# 34 16059
# Done distance matrix: 0.020790815353393555
# Child 33 There were no points close enough
# Starting Child 41
# 37 16059
# Done distance matrix: 0.02236461639404297
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16059
# Done distance matrix: 0.0017240047454833984
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16059
# Done distance matrix: 0.006516933441162109
# Child 44 There were no points close enough
# Starting Child 45
# 17 16059
# Done distance matrix: 0.010847330093383789
# Child 45 There were no points close enough
# Starting Child 46
# 6 16059
# Done distance matrix: 0.004011631011962891
# Child 46 There were no points close enough
# Starting Child 47
# 4 16059
# Done distance matrix: 0.002592802047729492
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16059
# Done distance matrix: 0.0037424564361572266
# Child 48 There were no points close enough
# Starting Child 49
# 7 16059
# Done distance matrix: 0.004473209381103516
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {31: [90, 16005]}
# ---Stitching child 31 with pair: [90, 16005]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1065863, starting edge 2nd facet= 1067323,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05309796333312988
# returned from stitch mesh: 1.4135563373565674
# Finished stitching child 31 : 1.6606268882751465
# ***************Finished big stitching iteration: 4.454838037490845***************
# Starting Child 4
# 521 16181
# Done distance matrix: 0.4003176689147949
# Child 4 There were no points close enough
# Starting Child 6
# 567 16181
# Done distance matrix: 0.6381151676177979
# Child 6 There were no points close enough
# Starting Child 7
# 212 16181
# Done distance matrix: 0.20008158683776855
# Child 7 There were no points close enough
# Starting Child 8
# 170 16181
# Done distance matrix: 0.12031102180480957
# Child 8 There were no points close enough
# Starting Child 10
# 130 16181
# Done distance matrix: 0.07953238487243652
# Child 10 There were no points close enough
# Starting Child 13
# 185 16181
# Done distance matrix: 0.11993789672851562
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16181
# Done distance matrix: 0.001725912094116211
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16181
# Done distance matrix: 0.16127371788024902
# Child 18 There were no points close enough
# Starting Child 19
# 10 16181
# Done distance matrix: 0.00646662712097168
# Child 19 There were no points close enough
# Starting Child 20
# 16 16181
# Done distance matrix: 0.010242462158203125
# Child 20 There were no points close enough
# Starting Child 21
# 4 16181
# Done distance matrix: 0.0025262832641601562
# Child 21 There were no points close enough
# Starting Child 22
# 3 16181
# Done distance matrix: 0.002141237258911133
# Child 22 There were no points close enough
# ...
# Starting Child 33
# 34 16181
# Done distance matrix: 0.01637554168701172
# Child 33 There were no points close enough
# Starting Child 41
# 37 16181
# Done distance matrix: 0.018138885498046875
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16181
# Done distance matrix: 0.001493692398071289
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16181
# Done distance matrix: 0.005486488342285156
# Child 44 There were no points close enough
# Starting Child 45
# 17 16181
# Done distance matrix: 0.00900125503540039
# Child 45 There were no points close enough
# Starting Child 46
# 6 16181
# Done distance matrix: 0.003145933151245117
# Child 46 There were no points close enough
# Starting Child 47
# 4 16181
# Done distance matrix: 0.002053976058959961
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16181
# Done distance matrix: 0.002958536148071289
# Child 48 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 49
# 7 16181
# Done distance matrix: 0.0037398338317871094
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {23: [4, 778]}
# ---Stitching child 23 with pair: [4, 778]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 74451, starting edge 2nd facet= 1067702,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.5497207641601562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.031632184982299805
# returned from stitch mesh: 1.2664451599121094
# Finished stitching child 23 : 1.5078833103179932
# ***************Finished big stitching iteration: 2.9561071395874023***************
# Starting Child 4
# 521 16195
# Done distance matrix: 0.3218832015991211
# Child 4 There were no points close enough
# Starting Child 6
# 567 16195
# Done distance matrix: 0.4899435043334961
# Child 6 There were no points close enough
# Starting Child 7
# 212 16195
# Done distance matrix: 0.14118075370788574
# Child 7 There were no points close enough
# Starting Child 8
# 170 16195
# Done distance matrix: 0.13589835166931152
# Child 8 There were no points close enough
# Starting Child 10
# 130 16195
# Done distance matrix: 0.14489293098449707
# Child 10 There were no points close enough
# Starting Child 13
# 185 16195
# Done distance matrix: 0.16626501083374023
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16195
# Done distance matrix: 0.0018668174743652344
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16195
# Done distance matrix: 0.1747114658355713
# Child 18 There were no points close enough
# Starting Child 19
# 10 16195
# Done distance matrix: 0.011725664138793945
# Child 19 There were no points close enough
# Starting Child 20
# 16 16195
# Done distance matrix: 0.019608497619628906
# Child 20 There were no points close enough
# Starting Child 21
# 4 16195
# Done distance matrix: 0.0050280094146728516
# Child 21 There were no points close enough
# Starting Child 22
# 3 16195
# Done distance matrix: 0.003383159637451172
# Child 22 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 16195
# Done distance matrix: 0.051542043685913086
# Child 28 There were no points close enough
# Starting Child 29
# 5 16195
# Done distance matrix: 0.0043964385986328125
# Child 29 There were no points close enough
# Starting Child 30
# 3 16195
# Done distance matrix: 0.0025196075439453125
# Child 30 There were no points close enough
# Starting Child 33
# 34 16195
# Done distance matrix: 0.024225234985351562
# Child 33 There were no points close enough
# Starting Child 41
# 37 16195
# Done distance matrix: 0.02443385124206543
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16195
# Done distance matrix: 0.0017931461334228516
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16195
# Done distance matrix: 0.0067081451416015625
# Child 44 There were no points close enough
# Starting Child 45
# 17 16195
# Done distance matrix: 0.01100015640258789
# Child 45 There were no points close enough
# Starting Child 46
# 6 16195
# Done distance matrix: 0.003881216049194336
# Child 46 There were no points close enough
# Starting Child 47
# 4 16195
# Done distance matrix: 0.0025157928466796875
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16195
# Done distance matrix: 0.0038881301879882812
# Child 48 There were no points close enough
# Starting Child 49
# 7 16195
# Done distance matrix: 0.004459381103515625
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 4
# 521 16195
# Done distance matrix: 0.5687637329101562
# Child 4 There were no points close enough
# Starting Child 6
# 567 16195
# Done distance matrix: 0.3753962516784668
# Child 6 There were no points close enough
# Starting Child 7
# 212 16195
# Done distance matrix: 0.13141536712646484
# Child 7 There were no points close enough
# Starting Child 8
# 170 16195
# Done distance matrix: 0.10284423828125
# Child 8 There were no points close enough
# Starting Child 10
# 130 16195
# Done distance matrix: 0.07007145881652832
# Child 10 There were no points close enough
# Starting Child 13
# 185 16195
# Done distance matrix: 0.14157462120056152
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16195
# Done distance matrix: 0.0024085044860839844
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16195
# Done distance matrix: 0.22892308235168457
# Child 18 There were no points close enough
# Starting Child 19
# 10 16195
# Done distance matrix: 0.010426044464111328
# Child 19 There were no points close enough
# Starting Child 20
# 16 16195
# Done distance matrix: 0.015543222427368164
# Child 20 There were no points close enough
# Starting Child 21
# 4 16195
# Done distance matrix: 0.0037717819213867188
# Child 21 There were no points close enough
# Starting Child 22
# 3 16195
# Done distance matrix: 0.0027687549591064453
# Child 22 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 16195
# Done distance matrix: 0.04195976257324219
# Child 28 There were no points close enough
# Starting Child 29
# 5 16195
# Done distance matrix: 0.003960132598876953
# Child 29 There were no points close enough
# Starting Child 30
# 3 16195
# Done distance matrix: 0.0022842884063720703
# Child 30 There were no points close enough
# Starting Child 33
# 34 16195
# Done distance matrix: 0.02223515510559082
# Child 33 There were no points close enough
# Starting Child 41
# 37 16195
# Done distance matrix: 0.02288365364074707
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16195
# Done distance matrix: 0.0016667842864990234
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16195
# Done distance matrix: 0.006484031677246094
# Child 44 There were no points close enough
# Starting Child 45
# 17 16195
# Done distance matrix: 0.01087188720703125
# Child 45 There were no points close enough
# Starting Child 46
# 6 16195
# Done distance matrix: 0.0039081573486328125
# Child 46 There were no points close enough
# Starting Child 47
# 4 16195
# Done distance matrix: 0.002527475357055664
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16195
# Done distance matrix: 0.003711700439453125
# Child 48 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 49
# 7 16195
# Done distance matrix: 0.0044291019439697266
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 4
# 521 16195
# Done distance matrix: 0.4496726989746094
# Child 4 There were no points close enough
# Starting Child 6
# 567 16195
# Done distance matrix: 0.5053391456604004
# Child 6 There were no points close enough
# Starting Child 7
# 212 16195
# Done distance matrix: 0.1624443531036377
# Child 7 There were no points close enough
# Starting Child 8
# 170 16195
# Done distance matrix: 0.12381124496459961
# Child 8 There were no points close enough
# Starting Child 10
# 130 16195
# Done distance matrix: 0.1099097728729248
# Child 10 There were no points close enough
# Starting Child 13
# 185 16195
# Done distance matrix: 0.14724206924438477
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16195
# Done distance matrix: 0.002210855484008789
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16195
# Done distance matrix: 0.20314288139343262
# Child 18 There were no points close enough
# Starting Child 19
# 10 16195
# Done distance matrix: 0.00634312629699707
# Child 19 There were no points close enough
# Starting Child 20
# 16 16195
# Done distance matrix: 0.029715538024902344
# Child 20 There were no points close enough
# Starting Child 21
# 4 16195
# Done distance matrix: 0.002340555191040039
# Child 21 There were no points close enough
# Starting Child 22
# 3 16195
# Done distance matrix: 0.001741647720336914
# Child 22 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 16195
# Done distance matrix: 0.028350353240966797
# Child 28 There were no points close enough
# Starting Child 29
# 5 16195
# Done distance matrix: 0.002864360809326172
# Child 29 There were no points close enough
# Starting Child 30
# 3 16195
# Done distance matrix: 0.00173187255859375
# Child 30 There were no points close enough
# Starting Child 33
# 34 16195
# Done distance matrix: 0.01706218719482422
# Child 33 There were no points close enough
# Starting Child 41
# 37 16195
# Done distance matrix: 0.019036531448364258
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16195
# Done distance matrix: 0.0014278888702392578
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16195
# Done distance matrix: 0.022463560104370117
# Child 44 There were no points close enough
# Starting Child 45
# 17 16195
# Done distance matrix: 0.00992441177368164
# Child 45 There were no points close enough
# Starting Child 46
# 6 16195
# Done distance matrix: 0.0032205581665039062
# Child 46 There were no points close enough
# Starting Child 47
# 4 16195
# Done distance matrix: 0.0022420883178710938
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16195
# Done distance matrix: 0.0033254623413085938
# Child 48 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 49
# 7 16195
# Done distance matrix: 0.0037736892700195312
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 4
# 521 16195
# Done distance matrix: 0.3288745880126953
# Child 4 There were no points close enough
# Starting Child 6
# 567 16195
# Done distance matrix: 0.36216115951538086
# Child 6 There were no points close enough
# Starting Child 7
# 212 16195
# Done distance matrix: 0.10197019577026367
# Child 7 There were no points close enough
# Starting Child 8
# 170 16195
# Done distance matrix: 0.08599543571472168
# Child 8 There were no points close enough
# Starting Child 10
# 130 16195
# Done distance matrix: 0.06419777870178223
# Child 10 There were no points close enough
# Starting Child 13
# 185 16195
# Done distance matrix: 0.09484195709228516
# Child 13 There were no points close enough
# Starting Child 14
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 15
# 2 16195
# Done distance matrix: 0.00138092041015625
# Child 15 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 261 16195
# Done distance matrix: 0.12504053115844727
# Child 18 There were no points close enough
# Starting Child 19
# 10 16195
# Done distance matrix: 0.005146026611328125
# Child 19 There were no points close enough
# Starting Child 20
# 16 16195
# Done distance matrix: 0.0079498291015625
# Child 20 There were no points close enough
# Starting Child 21
# 4 16195
# Done distance matrix: 0.002140045166015625
# Child 21 There were no points close enough
# Starting Child 22
# 3 16195
# Done distance matrix: 0.0016918182373046875
# Child 22 There were no points close enough
# Starting Child 25
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 28
# 56 16195
# Done distance matrix: 0.02628302574157715
# Child 28 There were no points close enough
# Starting Child 29
# 5 16195
# Done distance matrix: 0.002686023712158203
# Child 29 There were no points close enough
# Starting Child 30
# 3 16195
# Done distance matrix: 0.0016393661499023438
# Child 30 There were no points close enough
# Starting Child 33
# 34 16195
# Done distance matrix: 0.024937868118286133
# Child 33 There were no points close enough
# Starting Child 41
# 37 16195
# Done distance matrix: 0.035694122314453125
# Child 41 There were no points close enough
# Starting Child 42
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 2 16195
# Done distance matrix: 0.0029363632202148438
# Child 43 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 44
# 10 16195
# Done distance matrix: 0.013036727905273438
# Child 44 There were no points close enough
# Starting Child 45
# 17 16195
# Done distance matrix: 0.019868850708007812
# Child 45 There were no points close enough
# Starting Child 46
# 6 16195
# Done distance matrix: 0.006630420684814453
# Child 46 There were no points close enough
# Starting Child 47
# 4 16195
# Done distance matrix: 0.004261493682861328
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 6 16195
# Done distance matrix: 0.0060045719146728516
# Child 48 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 49
# 7 16195
# Done distance matrix: 0.006807804107666016
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 70.8696117401123
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-a35225b0f4c4> in <module>
#      70         print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
#      71         print(f"total_stitch_processing_time = {time.time() - total_stitch_processing_time}")
# ---> 72         raise Exception("Finished the mesh stitiching")
#      73
#      74     #update the thresholds
#
# Exception: Finished the mesh stitiching

# %%
"""
Error we are encountering: 
1) Some mesh facets are stored differently than others so that can't concatenate
- one is array of 1D arrays
- other is 2D array

for child 43


"""

# %%
#now to extract the full mesh after it's done so don't screw up all the facets numbers:


#remove all of the processed facets from the main mesh
#now take away the original facet faces:
total_faces = np.linspace(0,len(main_mesh.faces)-1,len(main_mesh.faces)).astype("int")


#these are the faces that need to be removed
facet_faces = np.hstack([child_faces_to_remove ,main_faces_to_remove])
faces_to_keep = set(total_faces).difference(set(facet_faces))


main_mesh = main_mesh.submesh([list(faces_to_keep)])[0]

# %%
print(len(main_mesh.faces))
# Out:
# 2128741

# %%
from print_trimesh import print_trimesh

print_trimesh(main_mesh,"./test_meshes/entire_neuron_facets_optimized_RECHECK_no_delete.off" )

# %%
print(f"Total time for restitching = {time.time() - restitch_time}")
# Out:
# Total time for restitching = 133.70814204216003

# %%
#PRINT THE SIZES OF THE ONES THAT DIDN'T MAKE IT IN
# export the children that weren't attached
non_attached = [10,14,15,19,20,21,22,25,28,29,30,33,42,44,45,46,47,48,50]

for yy in range(0,len(non_attached)):
    #output the child mesh
    child_id = non_attached[yy]
    print(f"child {child_id} missed with {len(child_meshes[child_id].faces)}")
# Out:
# child 10 missed with 3524
# child 14 missed with 14
# child 15 missed with 26
# child 19 missed with 348
# child 20 missed with 268
# child 21 missed with 74
# child 22 missed with 14
# child 25 missed with 32
# child 28 missed with 1390
# child 29 missed with 54
# child 30 missed with 80
# child 33 missed with 1724
# child 42 missed with 12
# child 44 missed with 170
# child 45 missed with 260
# child 46 missed with 18
# child 47 missed with 66
# child 48 missed with 124
# child 50 missed with 22

# %%
# export the children that weren't attached
non_attached = [10,14,15,19,20,21,22,25,28,29,30,33,42,44,45,46,47,48,50]

for yy in range(0,10):
    #output the child mesh
    child_id = non_attached[yy]
    
    print_trimesh(child_meshes[child_id],"./test_meshes/piece_Not_" + str(child_id) + ".off")

# %%
"""
print all the child sizes
"""

# %%
# download the facets and make sure they match
index = 29
current_facets = child_meshes_facets[index][0]
current_mesh = child_meshes[index]



facets_group = np.zeros(len(current_mesh.faces)).astype(int)

for i,facet_group in enumerate(current_facets):
    for face in facet_group:
        facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

np.savez("./test_meshes/" + "big_TEST_NEURON_" + str(index) + ".npz",
         facets_group=facets_group)

# from print_trimesh import print_trimesh
# print_trimesh(current_mesh,"./test_meshes/piece_debug_june_" + str(index) + ".off")

# %%
#get the facets group
for gr in child_meshes_facets[index][0]:
    if 31 in gr:
        print(gr)

# %%
#get the normals of this guy
child_meshes[index].face_normals[31]

# %%
#get the main mesh facets downloaded
main_mesh_facets

# download the facets and make sure they match
index = "main"
current_facets = main_mesh_facets
current_mesh = main_mesh



facets_group = np.zeros(len(current_mesh.faces)).astype(int)

for i,facet_group in enumerate(current_facets):
    for face in facet_group:
        facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

np.savez("./test_meshes/" + "big_TEST_NEURON_no_delete" + str(index) + ".npz",
         facets_group=facets_group)

# from print_trimesh import print_trimesh
# print_trimesh(current_mesh,"./test_meshes/piece_debug_june_" + str(index) + ".off")

# %%
#PRINT THE SIZES OF THE ONES THAT DIDN'T MAKE IT IN
# export the children that weren't attached
non_attached = [10,14,15,19,20,21,22,25,28,29,30,33,42,44,45,46,47,48,50]

for yy in range(0,len(non_attached)):
    #output the child mesh
    child_id = non_attached[yy]
    print(f"child {child_id} missed with {len(child_meshes[child_id].faces)}")
# Out:
# child 10 missed with 3524
# child 14 missed with 14
# child 15 missed with 26
# child 19 missed with 348
# child 20 missed with 268
# child 21 missed with 74
# child 22 missed with 14
# child 25 missed with 32
# child 28 missed with 1390
# child 29 missed with 54
# child 30 missed with 80
# child 33 missed with 1724
# child 42 missed with 12
# child 44 missed with 170
# child 45 missed with 260
# child 46 missed with 18
# child 47 missed with 66
# child 48 missed with 124
# child 50 missed with 22

# %%
print_trimesh(main_mesh_saved,"./test_meshes/main_mesh_saved.off")
print_trimesh(main_mesh,"./test_meshes/main_mesh_before_deletion.off")
