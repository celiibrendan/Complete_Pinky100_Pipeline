# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341379284: Dendrite-0
# Component found in Orphans
# len of vertices = 21074
# Step 1: extracted Soma Mesh = 2.2784106731414795
# Mesh successfully extracted
# Total time = 2.880502223968506
#
#
# 648518346341379423: Dendrite-0
# Component found in Orphans
# len of vertices = 57106
# Step 1: extracted Soma Mesh = 2.2673697471618652
# Mesh successfully extracted
# Total time = 2.9977660179138184
#
#
# 648518346341379688: Dendrite-0
# Component found in Orphans
# len of vertices = 29217
# Step 1: extracted Soma Mesh = 2.2678349018096924
# Mesh successfully extracted
# Total time = 3.0570554733276367
#
#
# 648518346341381931: Dendrite-0
# Component found in Orphans
# len of vertices = 12958
# Step 1: extracted Soma Mesh = 1.6789603233337402
# Mesh successfully extracted
# Total time = 2.011751890182495
#
#
# 648518346341382689: Dendrite-0
# Component found in Orphans
# len of vertices = 12858
# Step 1: extracted Soma Mesh = 1.4334743022918701
# Mesh successfully extracted
# Total time = 1.7992351055145264
#
#
# 648518346341383167: Dendrite-0
# Component found in Orphans
# len of vertices = 10097
# Step 1: extracted Soma Mesh = 1.058567762374878
# Mesh successfully extracted
# Total time = 1.9099915027618408
#
#
# 648518346341384917: Dendrite-0
# Component found in Orphans
# len of vertices = 11579
# Step 1: extracted Soma Mesh = 1.1510565280914307
# Mesh successfully extracted
# Total time = 1.5082972049713135
#
#
# 648518346341384946: Dendrite-0
# Component found in Orphans
# len of vertices = 15933
# Step 1: extracted Soma Mesh = 1.180063247680664
# Mesh successfully extracted
# Total time = 1.6661796569824219
#
#
# 648518346341386109: Dendrite-0
# Component found in Orphans
# len of vertices = 52924
# Step 1: extracted Soma Mesh = 2.529665946960449
# Mesh successfully extracted
# Total time = 3.222062587738037
#
#
# 648518346341389651: Dendrite-0
# Component found in Orphans
# len of vertices = 26279
# Step 1: extracted Soma Mesh = 1.6541528701782227
# Mesh successfully extracted
# Total time = 2.272327184677124
#
#
# 648518346341392422: Dendrite-0
# Component found in Orphans
# len of vertices = 29981
# Step 1: extracted Soma Mesh = 1.6530747413635254
# Mesh successfully extracted
# Total time = 2.5494863986968994
#
#
# 648518346341392729: Dendrite-0
# Component found in Orphans
# len of vertices = 27234
# Step 1: extracted Soma Mesh = 1.3068671226501465
# Mesh successfully extracted
# Total time = 1.8670258522033691
#
#
# 648518346341394208: Dendrite-0
# Component found in Orphans
# len of vertices = 80857
# Step 1: extracted Soma Mesh = 2.371328592300415
# Mesh successfully extracted
# Total time = 3.0555732250213623
#
#
# 648518346341395045: Dendrite-0
# Component found in Orphans
# len of vertices = 14797
# Step 1: extracted Soma Mesh = 1.3192284107208252
# Mesh successfully extracted
# Total time = 1.91520094871521
#
#
# 648518346341395326: Dendrite-0
# Component found in Orphans
# len of vertices = 27639
# Step 1: extracted Soma Mesh = 1.1520166397094727
# Mesh successfully extracted
# Total time = 1.8283734321594238
#
#
# 648518346341396317: Dendrite-0
# Component found in Orphans
# len of vertices = 29359
# Step 1: extracted Soma Mesh = 1.6219651699066162
# Mesh successfully extracted
# Total time = 2.3109853267669678
#
#
# 648518346341397156: Dendrite-1
# Component found in Orphans
# len of vertices = 99193
# Step 1: extracted Soma Mesh = 3.54058837890625
# Mesh successfully extracted
# Total time = 4.62791895866394
#
#
# 648518346341398502: Dendrite-0
# Component found in Orphans
# len of vertices = 48694
# Step 1: extracted Soma Mesh = 1.5589747428894043
# Mesh successfully extracted
# Total time = 2.1569955348968506
#
#
# 648518346341398598: Dendrite-0
# Component found in Orphans
# len of vertices = 82125
# Step 1: extracted Soma Mesh = 2.5324652194976807
# Mesh successfully extracted
# Total time = 3.8269784450531006
#
#
# 648518346341399708: Dendrite-0
# Component found in Orphans
# len of vertices = 39177
# Step 1: extracted Soma Mesh = 1.4327971935272217
# Mesh successfully extracted
# Total time = 2.065739631652832
#
#
# 648518346341399912: Dendrite-0
# Component found in Orphans
# len of vertices = 30373
# Step 1: extracted Soma Mesh = 1.6056320667266846
# Mesh successfully extracted
# Total time = 2.335481882095337
#
#
# 648518346341401368: Dendrite-0
# Component found in Orphans
# len of vertices = 38516
# Step 1: extracted Soma Mesh = 1.4354076385498047
# Mesh successfully extracted
# Total time = 2.049360752105713
#
#
# 648518346341402107: Dendrite-0
# Component found in Orphans
# len of vertices = 17226
# Step 1: extracted Soma Mesh = 0.9033985137939453
# Mesh successfully extracted
# Total time = 1.3261616230010986
#
#
# 648518346341402446: Dendrite-0
# Component found in Orphans
# len of vertices = 63333
# Step 1: extracted Soma Mesh = 1.9509129524230957
# Mesh successfully extracted
# Total time = 2.577672243118286
#
#
# 648518346341402616: Dendrite-0
# Component found in Orphans
# len of vertices = 16581
# Step 1: extracted Soma Mesh = 0.9102935791015625
# Mesh successfully extracted
# Total time = 1.357588768005371
#
#
# 648518346341403533: Dendrite-0
# Component found in Orphans
# len of vertices = 16037
# Step 1: extracted Soma Mesh = 0.8964252471923828
# Mesh successfully extracted
# Total time = 1.2716448307037354
#
#
# 648518346341403822: Dendrite-0
# Component found in Orphans
# len of vertices = 41187
# Step 1: extracted Soma Mesh = 1.2503423690795898
# Mesh successfully extracted
# Total time = 2.0029006004333496
#
#
# 648518346341403967: Basal-1
# Component found in Orphans
# len of vertices = 35833
# Step 1: extracted Soma Mesh = 4.6738786697387695
# Mesh successfully extracted
# Total time = 6.076056003570557
#
#
# 648518346341404564: Dendrite-1
# Component found in Orphans
# len of vertices = 164388
# Step 1: extracted Soma Mesh = 5.922333478927612
# Mesh successfully extracted
# Total time = 7.532552242279053
#
#
# 648518346341407642: Dendrite-0
# Component found in Orphans
# len of vertices = 65483
# Step 1: extracted Soma Mesh = 2.280071973800659
# Mesh successfully extracted
# Total time = 3.020965576171875
#
#
# 648518346341408647: Dendrite-0
# Component found in Orphans
# len of vertices = 44681
# Step 1: extracted Soma Mesh = 1.8362438678741455
# Mesh successfully extracted
# Total time = 2.4612224102020264
#
#
# 648518346341409551: Dendrite-0
# Component found in Orphans
# len of vertices = 42375
# Step 1: extracted Soma Mesh = 1.3464038372039795
# Mesh successfully extracted
# Total time = 1.941368818283081
#
#
# 648518346341410108: Dendrite-0
# Component found in Orphans
# len of vertices = 97575
# Step 1: extracted Soma Mesh = 2.7795474529266357
# Mesh successfully extracted
# Total time = 3.5480129718780518
#
#
# 648518346341410817: Dendrite-0
# Component found in Orphans
# len of vertices = 16595
# Step 1: extracted Soma Mesh = 1.1576032638549805
# Mesh successfully extracted
# Total time = 1.555866003036499
#
#
# 648518346341411107: Dendrite-0
# Component found in Orphans
# len of vertices = 21575
# Step 1: extracted Soma Mesh = 1.1178464889526367
# Mesh successfully extracted
# Total time = 1.622079849243164
#
#
# 648518346341411405: Dendrite-0
# Component found in Orphans
# len of vertices = 40019
# Step 1: extracted Soma Mesh = 1.2041115760803223
# Mesh successfully extracted
# Total time = 1.8207898139953613
#
#
# 648518346341413915: Dendrite-4
# Component found in Orphans
# len of vertices = 36514
# Step 1: extracted Soma Mesh = 1.3965795040130615
# Mesh successfully extracted
# Total time = 1.9013075828552246
#
#
# 648518346341414522: Dendrite-0
# Component found in Orphans
# len of vertices = 43003
# Step 1: extracted Soma Mesh = 1.4802329540252686
# Mesh successfully extracted
# Total time = 2.2599194049835205
#
#
# 648518346341414670: Dendrite-0
# Component found in Orphans
# len of vertices = 28414
# Step 1: extracted Soma Mesh = 1.1004455089569092
# Mesh successfully extracted
# Total time = 1.7631645202636719
#
#
# 648518346341419781: Dendrite-0
# Component found in Orphans
# len of vertices = 18401
# Step 1: extracted Soma Mesh = 1.0511910915374756
# Mesh successfully extracted
# Total time = 1.4547555446624756
#
#
# 648518346342106194: Dendrite-0
# Component found in Orphans
# len of vertices = 15793
# Step 1: extracted Soma Mesh = 1.034353494644165
# Mesh successfully extracted
# Total time = 1.3507575988769531
#
#
# 648518346342413345: Dendrite-0
# Component found in Orphans
# len of vertices = 14566
# Step 1: extracted Soma Mesh = 0.9285831451416016
# Mesh successfully extracted
# Total time = 1.2934086322784424
#
#
# 648518346342788331: Dendrite-0
# Component found in Orphans
# len of vertices = 30883
# Step 1: extracted Soma Mesh = 1.3291380405426025
# Mesh successfully extracted
# Total time = 2.0742907524108887
#
#
# 648518346342790164: Dendrite-0
# Component found in Orphans
# len of vertices = 18773
# Step 1: extracted Soma Mesh = 1.095635175704956
# Mesh successfully extracted
# Total time = 1.7247581481933594
#
#
# 648518346342790849: Dendrite-0
# Component found in Orphans
# len of vertices = 39882
# Step 1: extracted Soma Mesh = 1.3901383876800537
# Mesh successfully extracted
# Total time = 1.9021270275115967
#
#
# 648518346342791236: Dendrite-0
# Component found in Orphans
# len of vertices = 51492
# Step 1: extracted Soma Mesh = 1.8395092487335205
# Mesh successfully extracted
# Total time = 2.696256160736084
#
#
# 648518346342791920: Dendrite-0
# Component found in Orphans
# len of vertices = 51721
# Step 1: extracted Soma Mesh = 2.034393072128296
# Mesh successfully extracted
# Total time = 2.785320520401001
#
#
# 648518346342792324: Dendrite-0
# Component found in Orphans
# len of vertices = 27562
# Step 1: extracted Soma Mesh = 1.6894569396972656
# Mesh successfully extracted
# Total time = 2.18690824508667
#
#
# 648518346342792507: Apical-0
# Component found in Orphans
# len of vertices = 235351
# Step 1: extracted Soma Mesh = 9.345446586608887
# Mesh successfully extracted
# Total time = 11.86605954170227
#
#
# 648518346342797668: Dendrite-0
# Component found in Orphans
# len of vertices = 140824
# Step 1: extracted Soma Mesh = 6.074240207672119
# Mesh successfully extracted
# Total time = 7.265077590942383
#
#
# 648518346342799285: Dendrite-0
# Component found in Orphans
# len of vertices = 111284
# Step 1: extracted Soma Mesh = 6.08020281791687
# Mesh successfully extracted
# Total time = 7.207826375961304
#
#
# 648518346342803414: Dendrite-0
# Component found in Orphans
# len of vertices = 55380
# Step 1: extracted Soma Mesh = 7.254358291625977
# Mesh successfully extracted
# Total time = 8.143731832504272
#
#
# 648518346342806369: Dendrite-0
# Component found in Orphans
# len of vertices = 67595
# Step 1: extracted Soma Mesh = 3.390183925628662
# Mesh successfully extracted
# Total time = 4.302502870559692
#
#
# 648518346342807927: Dendrite-0
# Component found in Orphans
# len of vertices = 26717
# Step 1: extracted Soma Mesh = 3.924025535583496
# Mesh successfully extracted
# Total time = 4.615954399108887
#
#
# 648518346342808823: Dendrite-0
# Component found in Orphans
# len of vertices = 38536
# Step 1: extracted Soma Mesh = 2.6121957302093506
# Mesh successfully extracted
# Total time = 3.185391426086426
#
#
# 648518346342916318: Dendrite-0
# Component found in Orphans
# len of vertices = 41539
# Step 1: extracted Soma Mesh = 2.337616205215454
# Mesh successfully extracted
# Total time = 2.839733362197876
#
#
# 648518346342918233: Dendrite-0
# Component found in Orphans
# len of vertices = 12375
# Step 1: extracted Soma Mesh = 1.0049183368682861
# Mesh successfully extracted
# Total time = 1.4314861297607422
#
#
# 648518346342918937: Dendrite-0
# Component found in Orphans
# len of vertices = 144147
# Step 1: extracted Soma Mesh = 5.30410623550415
# Mesh successfully extracted
# Total time = 7.882487535476685
#
#
# 648518346342926794: Dendrite-0
# Component found in Orphans
# len of vertices = 17024
# Step 1: extracted Soma Mesh = 2.254572629928589
# Mesh successfully extracted
# Total time = 2.8921430110931396
#
#
# 648518346342930614: Dendrite-0
# Component found in Orphans
# len of vertices = 41872
# Step 1: extracted Soma Mesh = 4.783952236175537
# Mesh successfully extracted
# Total time = 5.8535475730896
#
#
# 648518346344079623: Dendrite-0
# Component found in Orphans
# len of vertices = 20924
# Step 1: extracted Soma Mesh = 2.490884304046631
# Mesh successfully extracted
# Total time = 2.9955718517303467
#
#
# 648518346344465695: Dendrite-0
# Component found in Orphans
# len of vertices = 24704
# Step 1: extracted Soma Mesh = 1.906559944152832
# Mesh successfully extracted
# Total time = 2.271121025085449
#
#
# 648518346344509876: Dendrite-0
# Component found in Orphans
# len of vertices = 12640
# Step 1: extracted Soma Mesh = 1.047098159790039
# Mesh successfully extracted
# Total time = 1.4133975505828857
#
#
# 648518346344517858: Dendrite-0
# Component found in Orphans
# len of vertices = 14301
# Step 1: extracted Soma Mesh = 1.0679726600646973
# Mesh successfully extracted
# Total time = 1.4699790477752686
#
#
# 648518346345772713: Dendrite-0
# Component found in Orphans
# len of vertices = 17902
# Step 1: extracted Soma Mesh = 1.1367111206054688
# Mesh successfully extracted
# Total time = 1.5233407020568848
#
#
# 648518346346295977: Dendrite-0
# Component found in Orphans
# len of vertices = 34128
# Step 1: extracted Soma Mesh = 1.989499807357788
# Mesh successfully extracted
# Total time = 2.9333701133728027
#
#
# 648518346346301140: Dendrite-0
# Component found in Orphans
# len of vertices = 26333
# Step 1: extracted Soma Mesh = 1.9632318019866943
# Mesh successfully extracted
# Total time = 2.5314741134643555
#
#
# 648518346346302624: Dendrite-0
# Component found in Orphans
# len of vertices = 22750
# Step 1: extracted Soma Mesh = 1.2601089477539062
# Mesh successfully extracted
# Total time = 1.8426463603973389
#
#
# 648518346346312285: Dendrite-0
# Component found in Orphans
# len of vertices = 26609
# Step 1: extracted Soma Mesh = 1.5398099422454834
# Mesh successfully extracted
# Total time = 2.065990686416626
#
#
# 648518346346589334: Dendrite-0
# Component found in Orphans
# len of vertices = 18501
# Step 1: extracted Soma Mesh = 1.0954790115356445
# Mesh successfully extracted
# Total time = 1.5385372638702393
#
#
# 648518346346595427: Dendrite-0
# Component found in Orphans
# len of vertices = 16674
# Step 1: extracted Soma Mesh = 0.9296221733093262
# Mesh successfully extracted
# Total time = 1.3783159255981445
#
#
# 648518346347001783: Dendrite-0
# Component found in Orphans
# len of vertices = 12613
# Step 1: extracted Soma Mesh = 1.007171869277954
# Mesh successfully extracted
# Total time = 1.433485984802246
#
#
# 648518346348123146: Dendrite-0
# Component found in Orphans
# len of vertices = 28593
# Step 1: extracted Soma Mesh = 1.7415964603424072
# Mesh successfully extracted
# Total time = 2.313502311706543
#
#
# 648518346348192292: Dendrite-0
# Component found in Orphans
# len of vertices = 14578
# Step 1: extracted Soma Mesh = 1.0960662364959717
# Mesh successfully extracted
# Total time = 1.7024939060211182
#
#
# 648518346348206287: Dendrite-0
# Component found in Orphans
# len of vertices = 19822
# Step 1: extracted Soma Mesh = 0.977611780166626
# Mesh successfully extracted
# Total time = 1.429351568222046
#
#
# 648518346348209332: Dendrite-0
# Component found in Orphans
# len of vertices = 11470
# Step 1: extracted Soma Mesh = 0.8932976722717285
# Mesh successfully extracted
# Total time = 1.2731359004974365
#
#
# 648518346348464469: Dendrite-0
# Component found in Orphans
# len of vertices = 12438
# Step 1: extracted Soma Mesh = 0.8418619632720947
# Mesh successfully extracted
# Total time = 1.2514417171478271
#
#
# 648518346349370267: Dendrite-0
# Component found in Orphans
# len of vertices = 89538
# Step 1: extracted Soma Mesh = 2.246375322341919
# Mesh successfully extracted
# Total time = 3.0714824199676514
#
#
# 648518346349381022: Dendrite-0
# Component found in Orphans
# len of vertices = 109478
# Step 1: extracted Soma Mesh = 2.825810670852661
# Mesh successfully extracted
# Total time = 4.007886171340942
#
#
# 648518346349471277: Dendrite-4
# Component found in Orphans
# len of vertices = 29613
# Step 1: extracted Soma Mesh = 3.7094199657440186
# Mesh successfully extracted
# Total time = 4.716658353805542
#
#
# 648518346349475412: Apical-0
# Component found in Orphans
# len of vertices = 18578
# Step 1: extracted Soma Mesh = 1.3878684043884277
# Mesh successfully extracted
# Total time = 1.8972575664520264
#
#
# 648518346349477155: Oblique-0
# Component found in Orphans
# len of vertices = 45416
# Step 1: extracted Soma Mesh = 10.230620384216309
# Mesh successfully extracted
# Total time = 12.22444200515747
#
#
# 648518346349492682: Basal-0
# Component found in Orphans
# len of vertices = 29296
# Step 1: extracted Soma Mesh = 8.890847444534302
# Mesh successfully extracted
# Total time = 13.361846208572388
#
#
# 648518346349494801: Oblique-4
# Component found in Orphans
# len of vertices = 38318
# Step 1: extracted Soma Mesh = 8.514490127563477
# Mesh successfully extracted
# Total time = 11.803386211395264
#
#
# 648518346349505858: Apical-0
# Component found in Orphans
# len of vertices = 133578
# Step 1: extracted Soma Mesh = 11.50889539718628
# Mesh successfully extracted
# Total time = 22.410892009735107
#
#
# 648518346349509529: Dendrite-0
# Component found in Orphans
# len of vertices = 99395
# Step 1: extracted Soma Mesh = 4.540959358215332
# Mesh successfully extracted
# Total time = 5.83339262008667
#
#
# 648518346349509539: Dendrite-0
# Component found in Orphans
# len of vertices = 37771
# Step 1: extracted Soma Mesh = 2.990354299545288
# Mesh successfully extracted
# Total time = 4.094013929367065
#
#
# 648518346349509588: Dendrite-0
# Component found in Orphans
# len of vertices = 39073
# Step 1: extracted Soma Mesh = 3.053806781768799
# Mesh successfully extracted
# Total time = 3.6706676483154297
#
#
# 648518346349512609: Dendrite-0
# Component found in Orphans
# len of vertices = 139356
# Step 1: extracted Soma Mesh = 5.0760321617126465
# Mesh successfully extracted
# Total time = 6.147708415985107
# Total time = 513.3232724666595
