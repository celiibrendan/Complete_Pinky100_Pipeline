# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341380208: Dendrite-0
# Component found in Orphans
# len of vertices = 80758
# Step 1: extracted Soma Mesh = 2.323089361190796
# Mesh successfully extracted
# Total time = 3.111178398132324
#
#
# 648518346341383043: Dendrite-0
# Component found in Orphans
# len of vertices = 76382
# Step 1: extracted Soma Mesh = 2.5090630054473877
# Mesh successfully extracted
# Total time = 3.1266679763793945
#
#
# 648518346341383525: Dendrite-0
# Component found in Orphans
# len of vertices = 32161
# Step 1: extracted Soma Mesh = 1.2351436614990234
# Mesh successfully extracted
# Total time = 1.715867280960083
#
#
# 648518346341385331: Dendrite-0
# Component found in Orphans
# len of vertices = 55832
# Step 1: extracted Soma Mesh = 2.3454840183258057
# Mesh successfully extracted
# Total time = 2.988762378692627
#
#
# 648518346341387674: Dendrite-0
# Component found in Orphans
# len of vertices = 16468
# Step 1: extracted Soma Mesh = 1.049381971359253
# Mesh successfully extracted
# Total time = 1.667654037475586
#
#
# 648518346341388112: Dendrite-0
# Component found in Orphans
# len of vertices = 104026
# Step 1: extracted Soma Mesh = 2.8445427417755127
# Mesh successfully extracted
# Total time = 3.9665918350219727
#
#
# 648518346341393799: Dendrite-0
# Component found in Orphans
# len of vertices = 83874
# Step 1: extracted Soma Mesh = 2.282137393951416
# Mesh successfully extracted
# Total time = 3.287825345993042
#
#
# 648518346341394813: Dendrite-0
# Component found in Orphans
# len of vertices = 46959
# Step 1: extracted Soma Mesh = 1.9139578342437744
# Mesh successfully extracted
# Total time = 2.964764356613159
#
#
# 648518346341395959: Dendrite-0
# Component found in Orphans
# len of vertices = 13376
# Step 1: extracted Soma Mesh = 1.3764328956604004
# Mesh successfully extracted
# Total time = 1.952462911605835
#
#
# 648518346341396536: Dendrite-0
# Component found in Orphans
# len of vertices = 14519
# Step 1: extracted Soma Mesh = 1.1157915592193604
# Mesh successfully extracted
# Total time = 1.5202701091766357
#
#
# 648518346341397329: Dendrite-0
# Component found in Orphans
# len of vertices = 135009
# Step 1: extracted Soma Mesh = 4.368098974227905
# Mesh successfully extracted
# Total time = 6.514411687850952
#
#
# 648518346341399129: Dendrite-0
# Component found in Orphans
# len of vertices = 19947
# Step 1: extracted Soma Mesh = 1.0662477016448975
# Mesh successfully extracted
# Total time = 1.5161793231964111
#
#
# 648518346341399296: Dendrite-0
# Component found in Orphans
# len of vertices = 69824
# Step 1: extracted Soma Mesh = 2.6188547611236572
# Mesh successfully extracted
# Total time = 3.5406479835510254
#
#
# 648518346341400285: Dendrite-0
# Component found in Orphans
# len of vertices = 26317
# Step 1: extracted Soma Mesh = 1.1941313743591309
# Mesh successfully extracted
# Total time = 1.8392493724822998
#
#
# 648518346341401733: Dendrite-0
# Component found in Orphans
# len of vertices = 17596
# Step 1: extracted Soma Mesh = 1.019697666168213
# Mesh successfully extracted
# Total time = 1.41176176071167
#
#
# 648518346341402112: Dendrite-0
# Component found in Orphans
# len of vertices = 45323
# Step 1: extracted Soma Mesh = 1.4244117736816406
# Mesh successfully extracted
# Total time = 2.025970220565796
#
#
# 648518346341402597: Dendrite-0
# Component found in Orphans
# len of vertices = 24240
# Step 1: extracted Soma Mesh = 2.796482801437378
# Mesh successfully extracted
# Total time = 3.171705484390259
#
#
# 648518346341403291: Dendrite-0
# Component found in Orphans
# len of vertices = 44089
# Step 1: extracted Soma Mesh = 2.3483731746673584
# Mesh successfully extracted
# Total time = 3.0466630458831787
#
#
# 648518346341403915: Dendrite-0
# Component found in Orphans
# len of vertices = 23029
# Step 1: extracted Soma Mesh = 1.3599536418914795
# Mesh successfully extracted
# Total time = 1.8625884056091309
#
#
# 648518346341403967: Oblique-2
# Component found in Orphans
# len of vertices = 32070
# Step 1: extracted Soma Mesh = 5.681036949157715
# Mesh successfully extracted
# Total time = 8.522281169891357
#
#
# 648518346341406426: Dendrite-0
# Component found in Orphans
# len of vertices = 84485
# Step 1: extracted Soma Mesh = 3.4727389812469482
# Mesh successfully extracted
# Total time = 4.255857706069946
#
#
# 648518346341409381: Dendrite-0
# Component found in Orphans
# len of vertices = 63649
# Step 1: extracted Soma Mesh = 2.1263177394866943
# Mesh successfully extracted
# Total time = 2.8232476711273193
#
#
# 648518346341410186: Dendrite-0
# Component found in Orphans
# len of vertices = 23375
# Step 1: extracted Soma Mesh = 2.9196505546569824
# Mesh successfully extracted
# Total time = 3.494486093521118
#
#
# 648518346341410882: Dendrite-0
# Component found in Orphans
# len of vertices = 55741
# Step 1: extracted Soma Mesh = 3.2095823287963867
# Mesh successfully extracted
# Total time = 3.7098844051361084
#
#
# 648518346341416360: Dendrite-0
# Component found in Orphans
# len of vertices = 19565
# Step 1: extracted Soma Mesh = 2.5135610103607178
# Mesh successfully extracted
# Total time = 2.89581036567688
#
#
# 648518346342789414: Dendrite-0
# Component found in Orphans
# len of vertices = 19163
# Step 1: extracted Soma Mesh = 2.620490550994873
# Mesh successfully extracted
# Total time = 3.4128377437591553
#
#
# 648518346342791293: Dendrite-0
# Component found in Orphans
# len of vertices = 17104
# Step 1: extracted Soma Mesh = 1.598071575164795
# Mesh successfully extracted
# Total time = 2.146803140640259
#
#
# 648518346342791873: Dendrite-0
# Component found in Orphans
# len of vertices = 19147
# Step 1: extracted Soma Mesh = 1.6881048679351807
# Mesh successfully extracted
# Total time = 2.1854569911956787
#
#
# 648518346342792135: Dendrite-0
# Component found in Orphans
# len of vertices = 33383
# Step 1: extracted Soma Mesh = 2.223579168319702
# Mesh successfully extracted
# Total time = 2.941779375076294
#
#
# 648518346342792507: Basal-0
# Component found in Orphans
# len of vertices = 53990
# Step 1: extracted Soma Mesh = 8.812108755111694
# Mesh successfully extracted
# Total time = 10.804993867874146
#
#
# 648518346342796829: Dendrite-0
# Component found in Orphans
# len of vertices = 42547
# Step 1: extracted Soma Mesh = 1.6654810905456543
# Mesh successfully extracted
# Total time = 2.3852012157440186
#
#
# 648518346342797591: Dendrite-0
# Component found in Orphans
# len of vertices = 35547
# Step 1: extracted Soma Mesh = 4.950771331787109
# Mesh successfully extracted
# Total time = 5.888556480407715
#
#
# 648518346342798654: Dendrite-0
# Component found in Orphans
# len of vertices = 30765
# Step 1: extracted Soma Mesh = 2.2987935543060303
# Mesh successfully extracted
# Total time = 2.9375181198120117
#
#
# 648518346342799047: Dendrite-0
# Component found in Orphans
# len of vertices = 54248
# Step 1: extracted Soma Mesh = 4.580505609512329
# Mesh successfully extracted
# Total time = 5.20892858505249
#
#
# 648518346342800676: Dendrite-0
# Component found in Orphans
# len of vertices = 26703
# Step 1: extracted Soma Mesh = 3.3699851036071777
# Mesh successfully extracted
# Total time = 3.837587356567383
#
#
# 648518346342801913: Dendrite-0
# Component found in Orphans
# len of vertices = 63053
# Step 1: extracted Soma Mesh = 3.0586612224578857
# Mesh successfully extracted
# Total time = 3.88655424118042
#
#
# 648518346342803020: Dendrite-0
# Component found in Orphans
# len of vertices = 86041
# Step 1: extracted Soma Mesh = 3.7678985595703125
# Mesh successfully extracted
# Total time = 4.451861619949341
#
#
# 648518346342803651: Dendrite-0
# Component found in Orphans
# len of vertices = 43201
# Step 1: extracted Soma Mesh = 2.5367774963378906
# Mesh successfully extracted
# Total time = 3.445669412612915
#
#
# 648518346342804347: Dendrite-0
# Component found in Orphans
# len of vertices = 42699
# Step 1: extracted Soma Mesh = 1.3864707946777344
# Mesh successfully extracted
# Total time = 2.055349826812744
#
#
# 648518346342804950: Dendrite-0
# Component found in Orphans
# len of vertices = 42376
# Step 1: extracted Soma Mesh = 1.5121955871582031
# Mesh successfully extracted
# Total time = 2.159850597381592
#
#
# 648518346342805834: Dendrite-0
# Component found in Orphans
# len of vertices = 28904
# Step 1: extracted Soma Mesh = 1.262129306793213
# Mesh successfully extracted
# Total time = 1.760596752166748
#
#
# 648518346342806333: Dendrite-0
# Component found in Orphans
# len of vertices = 44589
# Step 1: extracted Soma Mesh = 2.8302853107452393
# Mesh successfully extracted
# Total time = 3.9597976207733154
#
#
# 648518346342806968: Dendrite-0
# Component found in Orphans
# len of vertices = 20829
# Step 1: extracted Soma Mesh = 1.2311856746673584
# Mesh successfully extracted
# Total time = 1.9996190071105957
#
#
# 648518346342807619: Dendrite-0
# Component found in Orphans
# len of vertices = 51738
# Step 1: extracted Soma Mesh = 2.326193332672119
# Mesh successfully extracted
# Total time = 3.5427558422088623
#
#
# 648518346342807807: Dendrite-0
# Component found in Orphans
# len of vertices = 85404
# Step 1: extracted Soma Mesh = 5.897535800933838
# Mesh successfully extracted
# Total time = 6.798702716827393
#
#
# 648518346342918556: Dendrite-0
# Component found in Orphans
# len of vertices = 24389
# Step 1: extracted Soma Mesh = 1.444594383239746
# Mesh successfully extracted
# Total time = 1.8766767978668213
#
#
# 648518346342919716: Dendrite-0
# Component found in Orphans
# len of vertices = 81343
# Step 1: extracted Soma Mesh = 4.18806529045105
# Mesh successfully extracted
# Total time = 6.945923805236816
#
#
# 648518346342925590: Dendrite-0
# Component found in Orphans
# len of vertices = 13935
# Step 1: extracted Soma Mesh = 1.6812989711761475
# Mesh successfully extracted
# Total time = 2.4395673274993896
#
#
# 648518346342927984: Dendrite-0
# Component found in Orphans
# len of vertices = 18875
# Step 1: extracted Soma Mesh = 1.1496484279632568
# Mesh successfully extracted
# Total time = 1.6127865314483643
#
#
# 648518346342930218: Dendrite-0
# Component found in Orphans
# len of vertices = 61292
# Step 1: extracted Soma Mesh = 2.1982223987579346
# Mesh successfully extracted
# Total time = 2.8244292736053467
#
#
# 648518346342935449: Dendrite-0
# Component found in Orphans
# len of vertices = 14359
# Step 1: extracted Soma Mesh = 2.258514881134033
# Mesh successfully extracted
# Total time = 3.1939609050750732
#
#
# 648518346343163536: Dendrite-0
# Component found in Orphans
# len of vertices = 10062
# Step 1: extracted Soma Mesh = 1.1249384880065918
# Mesh successfully extracted
# Total time = 1.47125244140625
#
#
# 648518346343970816: Dendrite-0
# Component found in Orphans
# len of vertices = 16219
# Step 1: extracted Soma Mesh = 1.680431604385376
# Mesh successfully extracted
# Total time = 2.763995409011841
#
#
# 648518346344076765: Dendrite-0
# Component found in Orphans
# len of vertices = 16449
# Step 1: extracted Soma Mesh = 1.249096393585205
# Mesh successfully extracted
# Total time = 1.8207099437713623
#
#
# 648518346344081039: Dendrite-0
# Component found in Orphans
# len of vertices = 17760
# Step 1: extracted Soma Mesh = 1.21004319190979
# Mesh successfully extracted
# Total time = 1.9710783958435059
#
#
# 648518346344142665: Dendrite-0
# Component found in Orphans
# len of vertices = 18764
# Step 1: extracted Soma Mesh = 1.2375707626342773
# Mesh successfully extracted
# Total time = 1.6268808841705322
#
#
# 648518346344420099: Dendrite-0
# Component found in Orphans
# len of vertices = 10553
# Step 1: extracted Soma Mesh = 1.1110174655914307
# Mesh successfully extracted
# Total time = 1.4663662910461426
#
#
# 648518346344461704: Dendrite-0
# Component found in Orphans
# len of vertices = 15243
# Step 1: extracted Soma Mesh = 0.9321901798248291
# Mesh successfully extracted
# Total time = 1.2941381931304932
#
#
# 648518346344465416: Dendrite-0
# Component found in Orphans
# len of vertices = 17725
# Step 1: extracted Soma Mesh = 1.0731570720672607
# Mesh successfully extracted
# Total time = 1.3968169689178467
#
#
# 648518346344502405: Dendrite-0
# Component found in Orphans
# len of vertices = 21564
# Step 1: extracted Soma Mesh = 1.122126579284668
# Mesh successfully extracted
# Total time = 1.5633039474487305
#
#
# 648518346344515629: Dendrite-0
# Component found in Orphans
# len of vertices = 14268
# Step 1: extracted Soma Mesh = 0.9575314521789551
# Mesh successfully extracted
# Total time = 1.3246099948883057
#
#
# 648518346344518919: Dendrite-0
# Component found in Orphans
# len of vertices = 14958
# Step 1: extracted Soma Mesh = 0.9919054508209229
# Mesh successfully extracted
# Total time = 1.3814599514007568
#
#
# 648518346345771100: Dendrite-0
# Component found in Orphans
# len of vertices = 13632
# Step 1: extracted Soma Mesh = 1.2773489952087402
# Mesh successfully extracted
# Total time = 1.7676563262939453
#
#
# 648518346345883978: Dendrite-0
# Component found in Orphans
# len of vertices = 11249
# Step 1: extracted Soma Mesh = 1.0033535957336426
# Mesh successfully extracted
# Total time = 1.3627955913543701
#
#
# 648518346346296733: Dendrite-0
# Component found in Orphans
# len of vertices = 21332
# Step 1: extracted Soma Mesh = 1.9109220504760742
# Mesh successfully extracted
# Total time = 2.3658456802368164
#
#
# 648518346346301093: Dendrite-0
# Component found in Orphans
# len of vertices = 10030
# Step 1: extracted Soma Mesh = 1.1315703392028809
# Mesh successfully extracted
# Total time = 2.026526927947998
#
#
# 648518346346302352: Dendrite-0
# Component found in Orphans
# len of vertices = 45718
# Step 1: extracted Soma Mesh = 2.29244327545166
# Mesh successfully extracted
# Total time = 2.8867990970611572
#
#
# 648518346346584570: Dendrite-0
# Component found in Orphans
# len of vertices = 12274
# Step 1: extracted Soma Mesh = 1.1065328121185303
# Mesh successfully extracted
# Total time = 1.5058324337005615
#
#
# 648518346346593203: Dendrite-0
# Component found in Orphans
# len of vertices = 18349
# Step 1: extracted Soma Mesh = 1.1040539741516113
# Mesh successfully extracted
# Total time = 1.5266649723052979
#
#
# 648518346346595591: Dendrite-0
# Component found in Orphans
# len of vertices = 10363
# Step 1: extracted Soma Mesh = 0.9869053363800049
# Mesh successfully extracted
# Total time = 1.456211805343628
#
#
# 648518346347291057: Dendrite-0
# Component found in Orphans
# len of vertices = 10786
# Step 1: extracted Soma Mesh = 0.8962078094482422
# Mesh successfully extracted
# Total time = 1.2480645179748535
#
#
# 648518346348189549: Dendrite-0
# Component found in Orphans
# len of vertices = 15850
# Step 1: extracted Soma Mesh = 1.4035711288452148
# Mesh successfully extracted
# Total time = 1.8964755535125732
#
#
# 648518346348192004: Dendrite-0
# Component found in Orphans
# len of vertices = 13756
# Step 1: extracted Soma Mesh = 1.1117565631866455
# Mesh successfully extracted
# Total time = 1.4949026107788086
#
#
# 648518346348199740: Dendrite-0
# Component found in Orphans
# len of vertices = 17670
# Step 1: extracted Soma Mesh = 1.198350191116333
# Mesh successfully extracted
# Total time = 1.6740367412567139
#
#
# 648518346348206984: Dendrite-0
# Component found in Orphans
# len of vertices = 18202
# Step 1: extracted Soma Mesh = 1.6082496643066406
# Mesh successfully extracted
# Total time = 2.23152232170105
#
#
# 648518346348719136: Dendrite-0
# Component found in Orphans
# len of vertices = 12335
# Step 1: extracted Soma Mesh = 1.0462071895599365
# Mesh successfully extracted
# Total time = 1.4489779472351074
#
#
# 648518346349373319: Dendrite-0
# Component found in Orphans
# len of vertices = 26238
# Step 1: extracted Soma Mesh = 1.7404639720916748
# Mesh successfully extracted
# Total time = 2.3720340728759766
#
#
# 648518346349379849: Dendrite-0
# Component found in Orphans
# len of vertices = 10834
# Step 1: extracted Soma Mesh = 1.1303229331970215
# Mesh successfully extracted
# Total time = 1.5612659454345703
#
#
# 648518346349383833: Dendrite-0
# Component found in Orphans
# len of vertices = 29725
# Step 1: extracted Soma Mesh = 3.0151729583740234
# Mesh successfully extracted
# Total time = 3.6540379524230957
#
#
# 648518346349470217: Dendrite-0
# Component found in Orphans
# len of vertices = 74620
# Step 1: extracted Soma Mesh = 5.463341236114502
# Mesh successfully extracted
# Total time = 6.640953302383423
#
#
# 648518346349479381: Dendrite-0
# Component found in Orphans
# len of vertices = 16719
# Step 1: extracted Soma Mesh = 4.4808900356292725
# Mesh successfully extracted
# Total time = 5.506099462509155
#
#
# 648518346349483683: Dendrite-0
# Component found in Orphans
# len of vertices = 21617
# Step 1: extracted Soma Mesh = 2.7488138675689697
# Mesh successfully extracted
# Total time = 3.4492664337158203
#
#
# 648518346349492682: Apical-0
# Component found in Orphans
# len of vertices = 11426
# Step 1: extracted Soma Mesh = 11.058171510696411
# Mesh successfully extracted
# Total time = 14.965217351913452
#
#
# 648518346349496069: Dendrite-0
# Component found in Orphans
# len of vertices = 40529
# Step 1: extracted Soma Mesh = 4.6391050815582275
# Mesh successfully extracted
# Total time = 5.9383015632629395
#
#
# 648518346349501064: Dendrite-0
# Component found in Orphans
# len of vertices = 94551
# Step 1: extracted Soma Mesh = 2.9321115016937256
# Mesh successfully extracted
# Total time = 4.523124694824219
#
#
# 648518346349505858: Oblique-0
# Component found in Orphans
# len of vertices = 40028
# Step 1: extracted Soma Mesh = 11.2293062210083
# Mesh successfully extracted
# Total time = 19.3502197265625
#
#
# 648518346349509121: Dendrite-0
# Component found in Orphans
# len of vertices = 35538
# Step 1: extracted Soma Mesh = 1.4483656883239746
# Mesh successfully extracted
# Total time = 1.94413161277771
#
#
# 648518346349509415: Basal-1
# Component found in Orphans
# len of vertices = 74382
# Step 1: extracted Soma Mesh = 14.312403917312622
# Mesh successfully extracted
# Total time = 17.799511909484863
# Total time = 499.8326904773712
