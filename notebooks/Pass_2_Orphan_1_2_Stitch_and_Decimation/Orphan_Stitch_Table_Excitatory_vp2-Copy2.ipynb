# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341367927**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 120 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 429043
# Total time for Mesh Cleansing: 7.0850207805633545
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998443143314592% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341369029**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 35 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 185810
# Total time for Mesh Cleansing: 3.577172040939331
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982700449143619% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341371997**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 111 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 525006
# Total time for Mesh Cleansing: 8.884394884109497
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989420848539278% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341374332**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 81 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 331452
# Total time for Mesh Cleansing: 5.296172618865967
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984516486628149% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341377469**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 273 pieces after mesh split
# There were 15 pieces found after size threshold
# max_index = 0
# max_face_len = 541318
# Total time for Mesh Cleansing: 18.55370306968689
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9935065411778525% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341385454**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 39 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 344581
# Total time for Mesh Cleansing: 6.32578182220459
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993213752301959% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341395530**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 244 pieces after mesh split
# There were 11 pieces found after size threshold
# max_index = 0
# max_face_len = 552085
# Total time for Mesh Cleansing: 20.990005493164062
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9967898198652013% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341401564**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 106784
# Total time for Mesh Cleansing: 3.5540833473205566
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989148737137512% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341404564**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 291 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 1222722
# Total time for Mesh Cleansing: 42.93100905418396
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983058417027475% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342801949**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 295 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 1102112
# Total time for Mesh Cleansing: 38.39761710166931
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982120957968854% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346296124**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 38 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 213814
# Total time for Mesh Cleansing: 7.514413833618164
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989347884994534% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346595591**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 59150
# Total time for Mesh Cleansing: 2.4449896812438965
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9974368486728947% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346347001492**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 62660
# Total time for Mesh Cleansing: 0.6209328174591064
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994895680469598% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346347290381**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 11440
# Total time for Mesh Cleansing: 0.07784485816955566
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346347291057**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 61366
# Total time for Mesh Cleansing: 0.23999810218811035
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985030427283673% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348110351**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 28002
# Total time for Mesh Cleansing: 0.10664248466491699
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348117121**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 55512
# Total time for Mesh Cleansing: 0.24523282051086426
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995318520652526% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348189549**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 90350
# Total time for Mesh Cleansing: 0.3784637451171875
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999424791486914% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348206287**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 113214
# Total time for Mesh Cleansing: 0.47407007217407227
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995056060739825% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348463614**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 45282
# Total time for Mesh Cleansing: 0.344820499420166
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.99735694462799% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348717878**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 19430
# Total time for Mesh Cleansing: 0.19827723503112793
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998970769864142% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349370267**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 156 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 550778
# Total time for Mesh Cleansing: 21.45818829536438
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9970240142499756% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349504464**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 102 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 478990
# Total time for Mesh Cleansing: 19.002930641174316
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998266023650437% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509415**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 651 pieces after mesh split
# There were 62 pieces found after size threshold
# max_index = 0
# max_face_len = 1989970
# Total time for Mesh Cleansing: 240.5680046081543
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9932749436999888% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509415_30_main_and_child_meshes_array.npz
#  face length 1989970 using optimized facets with 3 neighbors
# Filtering edges by size finished: 58.88226842880249, facet # = 105510
# Filtering by convexity and getting centers took: 85.62000036239624, facet # = 21131
# Finished facets for main mesh: 150.2992548942566 with facet length = 21131
# Finished 21131 facets for main mesh: 150.29951548576355
# Filtering edges by size finished: 0.008481025695800781, facet # = 12
# Filtering by convexity and getting centers took: 0.009971857070922852, facet # = 5
# Total time for facets: 150.32908844947815
# Zero faceted faces = []
# Starting Child 0
# 5 21131
# Done distance matrix: 0.007332801818847656
# Done Generating final pairs: 0.03204703330993652
# best_stitch_pair = [   2 7428]
# best_stitch_pair_size = 19776.86291034084
# best_stitch_pair_distance = 1551.3119193683492
# best_stitch_pair_size_ratio = 0.5731173827280129
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [2, 7428]}
# ---Stitching child 0 with pair: [2, 7428]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 522092, starting edge 2nd facet= 998106,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.005377054214477539
# returned from stitch mesh: 1.9360246658325195
# Finished stitching child 0 : 2.163177728652954
# ***************Finished big stitching iteration: 2.518965482711792***************
# All children have been processed
# total_stitch_processing_time = 2.5195794105529785
# Total time for restitching = 2.526596784591675
# missed_children = []
# Whole stitching function complete: 401.45964002609253
#
#
#
# *****Running Neuron Stitcher for 648518346344506020**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 60584
# Total time for Mesh Cleansing: 0.2512655258178711
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995380452715634% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346300372**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 127 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 421012
# Total time for Mesh Cleansing: 16.14117693901062
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9977107811307698% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349502882**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 664 pieces after mesh split
# There were 116 pieces found after size threshold
# max_index = 0
# max_face_len = 807886
# Total time for Mesh Cleansing: 186.60376358032227
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.974954141726202% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342799085**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 119270
# Total time for Mesh Cleansing: 0.40332627296447754
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994804411222472% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342799664**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 26 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 107514
# Total time for Mesh Cleansing: 0.3924283981323242
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990521855486173% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342800526**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 218108
# Total time for Mesh Cleansing: 0.7166593074798584
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995783684692943% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342804347**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 70 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 243566
# Total time for Mesh Cleansing: 1.120208501815796
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984750223417426% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342806273**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 46 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 316802
# Total time for Mesh Cleansing: 10.627585887908936
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9950561600120612% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342917445**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 52808
# Total time for Mesh Cleansing: 0.3291971683502197
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996214128871054% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342919716**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 198 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 0
# max_face_len = 465688
# Total time for Mesh Cleansing: 27.673072338104248
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9961837286511278% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509560**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 92 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 362244
# Total time for Mesh Cleansing: 18.715864658355713
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9955474789177794% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509560_30_main_and_child_meshes_array.npz
#  face length 362244 using optimized facets with 3 neighbors
# Filtering edges by size finished: 13.526381015777588, facet # = 19429
# Filtering by convexity and getting centers took: 17.65448307991028, facet # = 3857
# Finished 3857 facets for main mesh: 32.05557179450989
# Filtering edges by size finished: 0.015776634216308594, facet # = 64
# Filtering by convexity and getting centers took: 0.028557538986206055, facet # = 25
# Total time for facets: 32.10727596282959
# Zero faceted faces = []
# Starting Child 0
# 25 3857
# Done distance matrix: 0.0048274993896484375
# Done Generating final pairs: 0.008113861083984375
# best_stitch_pair = [ 7 27]
# best_stitch_pair_size = 25601.691072161615
# best_stitch_pair_distance = 1894.5143825644807
# best_stitch_pair_size_ratio = 0.7423920194216244
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [7, 27]}
# ---Stitching child 0 with pair: [7, 27]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 101956, starting edge 2nd facet= 181774,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.2411346435546875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002351045608520508
# returned from stitch mesh: 0.3646693229675293
# Finished stitching child 0 : 0.3917515277862549
# ***************Finished big stitching iteration: 0.4502236843109131***************
# All children have been processed
# total_stitch_processing_time = 0.45074915885925293
# Total time for restitching = 0.45217180252075195
# missed_children = []
# Whole stitching function complete: 52.80333924293518
# 1009.9603862762451

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
