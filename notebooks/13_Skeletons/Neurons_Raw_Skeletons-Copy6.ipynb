# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.CoarseLabelFinal() #ta3p100.CoarseLabelOrphan()

# %%
#function that will filter out error triangles
def generate_neighborhood(triangles, num_vertices):
    neighborhood = dict()
    for i in range(num_vertices):
        neighborhood[i] = set()
    for node1, node2, node3 in triangles:
        neighborhood[node1].update([node2, node3])
        neighborhood[node2].update([node1, node3])
        neighborhood[node3].update([node1, node2])
    return neighborhood

def set_search_first(starting_node, neighborhood):
    """
    Modified Depth-First-Search utilizing sets to reduce duplicate checks:

    Neighborhood must be a dict with the keys being the vertex indices!
    """    
    visited_nodes = set()
    temp_stack = set()
    temp_stack.add(starting_node)
    while len(temp_stack) > 0:
        starting_node = temp_stack.pop()
        if starting_node not in visited_nodes:
            visited_nodes.add(starting_node)
            temp_stack.update(neighborhood[starting_node])
    return list(visited_nodes)
def get_connected_portions(neighborhood):
    neighborhood_copy = neighborhood.copy()
    portions = []
    while len(neighborhood_copy) > 0:
        starting_node = next(iter(neighborhood_copy))
        portion = set_search_first(starting_node, neighborhood_copy)
        for node in portion:
            neighborhood_copy.pop(node)
        portions.append(portion)
    return portions

def get_largest_portion_index(portions):
    portion_lengths = [len(portion) for portion in portions]
    return portion_lengths.index(max(portion_lengths))

def get_largest_portion(portions):
    return portions[get_largest_portion_index(portions)]

def remove_floating_artifacts(mesh,key,mesh_labels):    
    mesh_copy = mesh.copy()
    
#     #get the labels for the mesh
#     #find out if in Orphan Table or Regular Neuron Table
#     if len(ta3p100.CoarseLabelFinal() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
#     elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
#     else:
#         raise Exception('neuron' + str(key["segment_id"]) + 
#                         'not present in any labels!')

    
    #look for errors
    not_errors = [i for i,k in enumerate(mesh_labels["triangles"]) if k != 10]
    original_triangles = mesh["triangles"]
    """
    print(type(not_errors))
    print(len(not_errors))
    print("not_errors = "+ str(not_errors[:100]))
    print(type(original_triangles))
    print(len(original_triangles))
    #print(original_triangles)
    print("not_errors = " + str(original_triangles[not_errors]))
    """
    
    mesh_copy['triangles'] = np.array(original_triangles[not_errors])
    
    return mesh_copy


def remove_isolated_vertices(mesh):
    mesh_copy = mesh.copy()

    neighborhood = generate_neighborhood(mesh_copy['triangles'], len(mesh_copy['vertices']))
    isolated_nodes = [portion.pop() for portion in get_connected_portions(neighborhood) if len(portion) == 1]

    vertices = mesh_copy['vertices']
    triangles = mesh_copy['triangles']
    vertex_list = list(vertices)

    if len(isolated_nodes) > 0:
        num_isolated_nodes_passed = 0
        isolated_nodes_set = set(isolated_nodes)
        count_to_decrement = np.zeros(len(vertices))
        for i in range(len(vertices)):
            if i in isolated_nodes_set:
                num_isolated_nodes_passed += 1
            else:
                count_to_decrement[i] = num_isolated_nodes_passed

        for i, triangle in enumerate(triangles):
            start = time.time()
            node1, node2, node3 = triangle
            triangles[i][0] -= count_to_decrement[node1]
            triangles[i][1] -= count_to_decrement[node2]
            triangles[i][2] -= count_to_decrement[node3]
        for i, isolated_node in enumerate(isolated_nodes):
            vertex_list.pop(isolated_node - i)

    mesh_copy['vertices'] = np.array(vertex_list)

    return mesh_copy


def remove_error_segments(key):

    full_start = time.time()

    print(str(key['segment_id']) +  ":")
    start = time.time()

    #find out if in Orphan Table or Regular Neuron Table
    if len(ta3p100.CoarseLabelFinal() & key) > 0:
        mesh = (ta3p100.CleansedMesh & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
    elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
        mesh = (ta3p100.CleansedMeshOrphan & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
    else:
        raise Exception('neuron' + str(key["segment_id"]) + 
                        'not present in any labels!')
    
    print(key['segment_id'], "mesh fetched.", time.time() - start)
    start = time.time()
    
    #print(mesh['triangles'])
    myCounter = Counter(mesh_labels['triangles'])#.tolist())
    print(myCounter)
    
    keys = list(myCounter.keys())
    #print(len(keys))
    
    if len(keys) < 2 and keys[0] == 10:
        print("only error segments")
        key['n_vertices'] = 0
        key['n_triangles'] = 0
        key['vertices'] = np.ndarray([])
        key['triangles'] = np.ndarray([])
        
        print("This took ", time.time() - full_start, "seconds.")
        print()
        return key
    
    neighborhood = generate_neighborhood(mesh['triangles'], len(mesh['vertices']))
    print(key['segment_id'] , "neighborhood generated.", time.time() - start)
    start = time.time()
    
    mesh = remove_floating_artifacts(mesh,key,mesh_labels)
    print(key['segment_id'], "floating artifacts removed.", time.time() - start)
    start = time.time()

    mesh = remove_isolated_vertices(mesh)
    print(key['segment_id'], "isolated nodes removed.", time.time() - start)
    start = time.time()

    key['n_vertices'] = len(mesh['vertices'])
    key['n_triangles'] = len(mesh['triangles'])
    key['vertices'] = mesh['vertices']
    key['triangles'] = mesh['triangles']

    #self.insert1(key, skip_duplicates=True)
    print(key['segment_id'], "key successfully filtered.", time.time() - start)
    start = time.time()

    print("This took ", time.time() - full_start, "seconds.")
    print()
    return key

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY, this is outdated for one below"""
#
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_neurons")) == False:
    os.mkdir("pymesh_neurons")

# %%
#keysource for neuron table
ta3p100.CoarseLabelFinal()
print(len(ta3p100.CoarseLabelFinal()))
# Out:
# 322

# %%
ta3p100.CoarseLabelOrphan()
print(len(ta3p100.CoarseLabelOrphan()))
# Out:
# 702

# %%
ns_table = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
print(len(ns_table))
ns_table
# Out:
# 1024
# *segmentation  *segment_id
# +------------+ +------------+
# 2              64851834634136
# 2              64851834634137
# 2              64851834634138
# 2              64851834634139
# 2              64851834634279
# 2              64851834634280
# 2              64851834634938
# 2              64851834634946
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
#    ...
#  (1024 tuples)

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_neurons"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_neurons"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting remeshing_remove_non_man_edges")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuronRawSkeleton(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the component labels were updated
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_vertices   :int unsigned #number of vertices in mesh filtered of error segments
    n_triangles  :int unsigned #number of faces in mesh filtered of error segments
    vertices     :longblob #mesh data for vertices in mesh filtered of error segments
    triangles    :longblob #mesh data for faces in mesh filtered of error segments
     
    """
    
    key_source = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        new_key = remove_error_segments(key)
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        
        #where i deal with the error segments
        if new_key["vertices"].size<2:
            start_time = time.time()
            print("All faces were error segments, inserting dummy entry")
            #create the key with None
            new_key["n_vertices"] = 0
            new_key["n_triangles"] = 0
            new_key["vertices"] = np.array([]).astype(float)
            new_key["triangles"] = np.array([]).astype(float)
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["time_updated"]=str(datetime.datetime.now())
            self.insert1(new_key,skip_duplicates=True)
            
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = 0,
                                           correspondence=np.array([]).astype(float))
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            print(f"Step 2: Inserting dummy dictionary: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")
        
        else:
        
            #print("Step 2: Remove all error semgents")
            start_time = time.time()
            #pass the vertices and faces to pymeshfix to become watertight
            meshfix = pymeshfix.MeshFix(new_key["vertices"],new_key["triangles"])
            meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
            print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")

            #print("Step 2: Writing Off File")
            start_time = time.time()
            #write the new mesh to off file
            path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
            print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

            #Run the meshlabserver scripts
            start_time = time.time()
            output_mesh = meshlab_fix_manifold(key)
            print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

            print(output_mesh[:-4])

            #send to be skeletonized
            start_time = time.time()
            return_value = cm.calcification(output_mesh[:-4])
            if return_value > 0:
                raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                ' did not finish... exited with error code: ' + str(return_value))
            #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



            #read in the skeleton files into an array
            #start_time = time.time()
            
            ##****** this needs to be changed for reading them in******
            bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            correspondence_array = read_raw_skeleton(output_mesh[:-4]+"_correspondance.cgal")
            #print(bone_array)
            if len(bone_array) <= 0:
                raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
            
            if len(correspondence_array) <= 0:
                raise Exception('No CORRESPONDENCE generated for ' + str(new_key["segment_id"]))
                
            print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


            start_time = time.time()
            
            new_key["n_edges"] = bone_array.shape[0]
            new_key["edges"] = bone_array
            #new_key["branches"] = []

            time_updated = str(datetime.datetime.now())
            new_key["time_updated"]=time_updated
            #print(key)
            #if all goes well then write to database
            self.insert1(new_key,skip_duplicates=True)
            
            #create a new dictionary key to be inserted into correspondence table
            """
            time_updated      :timestamp    # the time at which the component labels were updated
            ---
            n_correspondence   :int unsigned #number of mappings from skeleton vert to original surface vert 
            correspondence     :longblob #array storing mapping of every skeleton vert to original surface vert  
            """
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = correspondence_array.shape[0],
                                           correspondence=correspondence_array)
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            os.system("rm "+str(path_and_filename)+"*")
            print(f"Step 6: Inserting both dictionaries: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#ta3p100.NeuronSkeletons()#.delete()
#(schema.jobs & "table_name='__neuron_skeletons'").delete()

# %%
start = time.time()
NeuronRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346349473804:
# 648518346349473804 mesh fetched. 0.49927449226379395
# Counter({3: 874363, 2: 237119, 5: 150885, 7: 31796})
# 648518346349473804 neighborhood generated. 10.36832332611084
# 648518346349473804 floating artifacts removed. 1.8364148139953613
# 648518346349473804 isolated nodes removed. 14.967662811279297
# 648518346349473804 key successfully filtered. 1.049041748046875e-05
# This took  27.674033164978027 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 28.103070497512817
# Step 2: Pymesh shrinkwrapping: 532.3293490409851
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 7.397064447402954
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 19.327921390533447
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500657_mls
# Step 5: Generating and reading Skeleton: 57.40942120552063
# Step 6: Inserting both dictionaries: 5.030767440795898
# Total time: 221.79672360420227
#
#
#
# 648518346349500954:
# 648518346349500954 mesh fetched. 0.24350333213806152
# Counter({3: 458651, 2: 138947, 5: 54950, 4: 11191, 6: 10704})
# 648518346349500954 neighborhood generated. 5.436753511428833
# 648518346349500954 floating artifacts removed. 1.17149019241333
# 648518346349500954 isolated nodes removed. 7.560608625411987
# 648518346349500954 key successfully filtered. 5.7220458984375e-06
# This took  14.413421154022217 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 14.626518726348877
# Step 2: Pymesh shrinkwrapping: 60.96067714691162
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.602184295654297
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 9.330385684967041
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500954_mls
# Step 5: Generating and reading Skeleton: 33.43266010284424
# Step 6: Inserting both dictionaries: 3.2147412300109863
# Total time: 125.16822290420532
#
#
#
# 648518346349501597:
# 648518346349501597 mesh fetched. 0.37848377227783203
# Counter({3: 934445, 2: 174494, 5: 68107, 6: 15464})
# 648518346349501597 neighborhood generated. 9.713001251220703
# 648518346349501597 floating artifacts removed. 2.112854242324829
# 648518346349501597 isolated nodes removed. 13.620787143707275
# 648518346349501597 key successfully filtered. 5.9604644775390625e-06
# This took  25.826333045959473 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 26.225836992263794
# Step 2: Pymesh shrinkwrapping: 108.87908244132996
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 6.7502570152282715
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 16.266987085342407
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349501597_mls
# Step 5: Generating and reading Skeleton: 57.7717604637146
# Step 6: Inserting both dictionaries: 6.344628095626831
# Total time: 222.23976826667786
#
#
#
# 648518346349502920:
# 648518346349502920 mesh fetched. 0.18851804733276367
# Counter({2: 234696, 4: 121723, 3: 94842, 5: 55155, 10: 2028})
# 648518346349502920 neighborhood generated. 4.137232065200806
# 648518346349502920 floating artifacts removed. 0.8962810039520264
# 648518346349502920 isolated nodes removed. 11.744343757629395
# 648518346349502920 key successfully filtered. 8.344650268554688e-06
# This took  16.968573331832886 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 17.1822612285614
# Step 2: Pymesh shrinkwrapping: 54.23001313209534
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.7747254371643066
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 6.997479677200317
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349502920_mls
# Step 5: Generating and reading Skeleton: 28.560081005096436
# Step 6: Inserting both dictionaries: 2.625610113143921
# Total time: 112.3713595867157
#
#
#
# 648518346349503086:
# 648518346349503086 mesh fetched. 0.28372693061828613
# Counter({2: 228339, 4: 186840, 3: 110222, 5: 76458, 10: 8993})
# 648518346349503086 neighborhood generated. 5.375131130218506
# 648518346349503086 floating artifacts removed. 1.100428581237793
# 648518346349503086 isolated nodes removed. 14.230550765991211
# 648518346349503086 key successfully filtered. 8.58306884765625e-06
# This took  20.99172568321228 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 21.24967360496521
# Step 2: Pymesh shrinkwrapping: 150.64768600463867
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.912865400314331
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 8.42990231513977
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349503086_mls
# Step 5: Generating and reading Skeleton: 23.89356279373169
# Step 6: Inserting both dictionaries: 2.9975061416625977
# Total time: 210.1322042942047
#
#
#
# 648518346349503592:
# 648518346349503592 mesh fetched. 0.2804408073425293
# Counter({3: 585645, 2: 163263, 4: 138842, 5: 64359, 6: 52061, 12: 757})
# 648518346349503592 neighborhood generated. 8.021560907363892
# 648518346349503592 floating artifacts removed. 1.804497241973877
# 648518346349503592 isolated nodes removed. 13.161279916763306
# 648518346349503592 key successfully filtered. 5.4836273193359375e-06
# This took  23.268877029418945 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 23.790117263793945
# Step 2: Pymesh shrinkwrapping: 113.80609917640686
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 5.51230525970459
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 14.979450225830078
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7071609497070312
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.3198182582855225
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341379951_mls
# Step 5: Generating and reading Skeleton: 7.763032674789429
# Step 6: Inserting both dictionaries: 0.7839581966400146
# Total time: 24.646645069122314
#
#
#
# 648518346341383270:
# 648518346341383270 mesh fetched. 0.10953164100646973
# Counter({5: 11148, 8: 3555})
# 648518346341383270 neighborhood generated. 0.14815044403076172
# 648518346341383270 floating artifacts removed. 0.031424760818481445
# 648518346341383270 isolated nodes removed. 0.17555022239685059
# 648518346341383270 key successfully filtered. 5.0067901611328125e-06
# This took  0.46549034118652344 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4703187942504883
# Step 2: Pymesh shrinkwrapping: 0.3206641674041748
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07753133773803711
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7786870002746582
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341383270_mls
# Step 5: Generating and reading Skeleton: 1.891326665878296
# Step 6: Inserting both dictionaries: 0.24934983253479004
# Total time: 3.788511276245117
#
#
#
# 648518346341384074:
# 648518346341384074 mesh fetched. 0.2547426223754883
# Counter({10: 381925})
# only error segments
# This took  0.37291526794433594 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3730137348175049
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.04417920112609863
# Total time: 0.41735172271728516
#
#
#
# 648518346341384076:
# 648518346341384076 mesh fetched. 0.1512749195098877
# Counter({8: 27746})
# 648518346341384076 neighborhood generated. 0.29434800148010254
# 648518346341384076 floating artifacts removed. 0.05968117713928223
# 648518346341384076 isolated nodes removed. 0.4096248149871826
# 648518346341384076 key successfully filtered. 4.76837158203125e-06
# This took  0.9156901836395264 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9262039661407471
# Step 2: Pymesh shrinkwrapping: 0.7649850845336914
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1406702995300293
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.009047508239746
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341384076_mls
# Step 5: Generating and reading Skeleton: 2.024747848510742
# Step 6: Inserting both dictionaries: 0.35673046112060547
# Total time: 5.223886013031006
#
#
#
# 648518346341386306:
# 648518346341386306 mesh fetched. 0.08092999458312988
# Counter({8: 16183, 10: 1890})
# 648518346341386306 neighborhood generated. 0.1997830867767334
# 648518346341386306 floating artifacts removed. 0.0390775203704834
# 648518346341386306 isolated nodes removed. 0.49181556701660156
# 648518346341386306 key successfully filtered. 5.0067901611328125e-06
# This took  0.8124723434448242 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8192510604858398
# Step 2: Pymesh shrinkwrapping: 0.32413625717163086
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.13709259033203125
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7671022415161133
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341386306_mls
# Step 5: Generating and reading Skeleton: 1.1831693649291992
# Step 6: Inserting both dictionaries: 0.18145012855529785
# Total time: 3.4129292964935303
#
#
#
# 648518346341389651:
# 648518346341389651 mesh fetched. 0.04741096496582031
# Counter({8: 52719})
# 648518346341389651 neighborhood generated. 0.4393012523651123
# 648518346341389651 floating artifacts removed. 0.09451508522033691
# 648518346341389651 isolated nodes removed. 0.5700206756591797
# 648518346341389651 key successfully filtered. 5.7220458984375e-06
# This took  1.152336597442627 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.169828176498413
# Step 2: Pymesh shrinkwrapping: 1.4162728786468506
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2711145877838135
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1484506130218506
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341389651_mls
# Step 5: Generating and reading Skeleton: 5.227564334869385
# Step 6: Inserting both dictionaries: 0.4629638195037842
# Total time: 9.697285175323486
#
#
#
# 648518346341392564:
# 648518346341392564 mesh fetched. 0.041199445724487305
# Counter({8: 35520})
# 648518346341392564 neighborhood generated. 0.39484286308288574
# 648518346341392564 floating artifacts removed. 0.07624697685241699
# 648518346341392564 isolated nodes removed. 0.4403047561645508
# 648518346341392564 key successfully filtered. 4.76837158203125e-06
# This took  0.9534645080566406 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9654130935668945
# Step 2: Pymesh shrinkwrapping: 0.8715305328369141
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1871192455291748
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9388182163238525
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341392564_mls
# Step 5: Generating and reading Skeleton: 1.6652753353118896
# Step 6: Inserting both dictionaries: 0.33132243156433105
# Total time: 4.96071982383728
#
#
#
# 648518346341393950:
# 648518346341393950 mesh fetched. 0.12892580032348633
# Counter({8: 126703})
# 648518346341393950 neighborhood generated. 1.1150224208831787
# 648518346341393950 floating artifacts removed. 0.22885990142822266
# 648518346341393950 isolated nodes removed. 1.4732012748718262
# 648518346341393950 key successfully filtered. 6.198883056640625e-06
# This took  2.9468634128570557 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.987722396850586
# Step 2: Pymesh shrinkwrapping: 6.391997814178467
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6880052089691162
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.9553542137145996
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341393950_mls
# Step 5: Generating and reading Skeleton: 5.69996452331543
# Step 6: Inserting both dictionaries: 0.7708733081817627
# Total time: 18.495107889175415
#
#
#
# 648518346341394638:
# 648518346341394638 mesh fetched. 0.1856529712677002
# Counter({8: 128511})
# 648518346341394638 neighborhood generated. 1.3563575744628906
# 648518346341394638 floating artifacts removed. 0.27044129371643066
# 648518346341394638 isolated nodes removed. 1.3774878978729248
# 648518346341394638 key successfully filtered. 5.4836273193359375e-06
# This took  3.190917730331421 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.2362778186798096
# Step 2: Pymesh shrinkwrapping: 6.716415643692017
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.8102359771728516
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.463862895965576
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341394638_mls
# Step 5: Generating and reading Skeleton: 5.863385915756226
# Step 6: Inserting both dictionaries: 0.8254489898681641
# Total time: 19.916973114013672
#
#
#
# 648518346341395751:
# 648518346341395751 mesh fetched. 0.045775651931762695
# Counter({8: 15586, 10: 11581})
# 648518346341395751 neighborhood generated. 0.2698395252227783
# 648518346341395751 floating artifacts removed. 0.05754804611206055
# 648518346341395751 isolated nodes removed. 0.45018601417541504
# 648518346341395751 key successfully filtered. 4.291534423828125e-06
# This took  0.8245539665222168 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8325386047363281
# Step 2: Pymesh shrinkwrapping: 0.3281362056732178
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07848334312438965
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.789386510848999
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341395751_mls
# Step 5: Generating and reading Skeleton: 1.4888768196105957
# Step 6: Inserting both dictionaries: 0.24926090240478516
# Total time: 3.7676334381103516
#
#
#
# 648518346341396532:
# 648518346341396532 mesh fetched. 0.0939326286315918
# Counter({8: 61377})
# 648518346341396532 neighborhood generated. 0.6457138061523438
# 648518346341396532 floating artifacts removed. 0.13152289390563965
# 648518346341396532 isolated nodes removed. 0.6678323745727539
# 648518346341396532 key successfully filtered. 5.245208740234375e-06
# This took  1.5398850440979004 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.5605454444885254
# Step 2: Pymesh shrinkwrapping: 4.968171119689941
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3219139575958252
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.507974624633789
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341396532_mls
# Step 5: Generating and reading Skeleton: 4.52281379699707
# Step 6: Inserting both dictionaries: 0.4991340637207031
# Total time: 13.381444931030273
#
#
#
# 648518346341398503:
# 648518346341398503 mesh fetched. 0.2107851505279541
# Counter({8: 166279})
# 648518346341398503 neighborhood generated. 1.5121545791625977
# 648518346341398503 floating artifacts removed. 0.29508423805236816
# 648518346341398503 isolated nodes removed. 1.8981716632843018
# 648518346341398503 key successfully filtered. 5.4836273193359375e-06
# This took  3.9176411628723145 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341402454_mls
# Step 5: Generating and reading Skeleton: 18.56099557876587
# Step 6: Inserting both dictionaries: 2.437478542327881
# Total time: 66.07705307006836
#
#
#
# 648518346341414090:
# 648518346341414090 mesh fetched. 0.053431034088134766
# Counter({8: 28009})
# 648518346341414090 neighborhood generated. 0.28229403495788574
# 648518346341414090 floating artifacts removed. 0.060894012451171875
# 648518346341414090 isolated nodes removed. 0.3565847873687744
# 648518346341414090 key successfully filtered. 5.4836273193359375e-06
# This took  0.753917932510376 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.7659175395965576
# Step 2: Pymesh shrinkwrapping: 1.1371848583221436
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.13940048217773438
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8554017543792725
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341414090_mls
# Step 5: Generating and reading Skeleton: 2.4725682735443115
# Step 6: Inserting both dictionaries: 0.2538919448852539
# Total time: 5.625476360321045
#
#
#
# 648518346341415428:
# 648518346341415428 mesh fetched. 0.13774704933166504
# Counter({8: 15473})
# 648518346341415428 neighborhood generated. 0.20978045463562012
# 648518346341415428 floating artifacts removed. 0.035238027572631836
# 648518346341415428 isolated nodes removed. 0.20203042030334473
# 648518346341415428 key successfully filtered. 5.9604644775390625e-06
# This took  0.5859804153442383 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5918283462524414
# Step 2: Pymesh shrinkwrapping: 0.4793543815612793
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09482121467590332
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8429274559020996
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341415428_mls
# Step 5: Generating and reading Skeleton: 1.910951852798462
# Step 6: Inserting both dictionaries: 0.23943161964416504
# Total time: 4.160595893859863
#
#
#
# 648518346341416762:
# 648518346341416762 mesh fetched. 0.07839536666870117
# Counter({8: 14416})
# 648518346341416762 neighborhood generated. 0.2329103946685791
# ...
# Counter({8: 292732, 10: 4189})
# 648518346342921511 neighborhood generated. 2.4567298889160156
# 648518346342921511 floating artifacts removed. 0.519373893737793
# 648518346342921511 isolated nodes removed. 6.717753887176514
# 648518346342921511 key successfully filtered. 8.58306884765625e-06
# This took  9.907902002334595 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 10.031304121017456
# Step 2: Pymesh shrinkwrapping: 15.358948945999146
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.6776134967803955
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 4.615407705307007
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342921511_mls
# Step 5: Generating and reading Skeleton: 12.608622074127197
# Step 6: Inserting both dictionaries: 1.51808500289917
# Total time: 45.81115698814392
#
#
#
# 648518346345771100:
# 648518346345771100 mesh fetched. 0.08609867095947266
# Counter({8: 27213})
# 648518346345771100 neighborhood generated. 0.24261760711669922
# 648518346345771100 floating artifacts removed. 0.05773210525512695
# 648518346345771100 isolated nodes removed. 0.31983447074890137
# 648518346345771100 key successfully filtered. 4.291534423828125e-06
# This took  0.7069156169891357 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.7154624462127686
# Step 2: Pymesh shrinkwrapping: 0.5895588397979736
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.16820335388183594
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7684292793273926
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346345771100_mls
# Step 5: Generating and reading Skeleton: 1.6094648838043213
# Step 6: Inserting both dictionaries: 0.28407788276672363
# Total time: 4.135874271392822
#
#
#
# 648518346346304212:
# 648518346346304212 mesh fetched. 0.12899470329284668
# Counter({8: 97044, 10: 6986})
# 648518346346304212 neighborhood generated. 0.8744673728942871
# 648518346346304212 floating artifacts removed. 0.17937564849853516
# 648518346346304212 isolated nodes removed. 2.3967134952545166
# 648518346346304212 key successfully filtered. 5.4836273193359375e-06
# This took  3.580630302429199 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.6137449741363525
# Step 2: Pymesh shrinkwrapping: 3.088549852371216
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5069856643676758
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.6014456748962402
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346304212_mls
# Step 5: Generating and reading Skeleton: 4.589080095291138
# Step 6: Inserting both dictionaries: 0.6747195720672607
# Total time: 14.076827764511108
#
#
#
# 648518346346885538:
# 648518346346885538 mesh fetched. 0.12409520149230957
# Counter({8: 13009})
# 648518346346885538 neighborhood generated. 0.1642003059387207
# 648518346346885538 floating artifacts removed. 0.028542280197143555
# 648518346346885538 isolated nodes removed. 0.16697120666503906
# 648518346346885538 key successfully filtered. 4.0531158447265625e-06
# This took  0.48539304733276367 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4899156093597412
# Step 2: Pymesh shrinkwrapping: 0.27806687355041504
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07720279693603516
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7045559883117676
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346885538_mls
# Step 5: Generating and reading Skeleton: 1.4304275512695312
# Step 6: Inserting both dictionaries: 0.16750121116638184
# Total time: 3.1487181186676025
#
#
#
# 648518346347001492:
# 648518346347001492 mesh fetched. 0.10683989524841309
# Counter({8: 21936})
# 648518346347001492 neighborhood generated. 0.24416375160217285
# 648518346347001492 floating artifacts removed. 0.04743695259094238
# 648518346347001492 isolated nodes removed. 0.2757551670074463
# 648518346347001492 key successfully filtered. 6.67572021484375e-06
# This took  0.6754341125488281 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6834390163421631
# Step 2: Pymesh shrinkwrapping: 0.7673535346984863
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.11219334602355957
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8057205677032471
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346347001492_mls
# Step 5: Generating and reading Skeleton: 1.7875745296478271
# Step 6: Inserting both dictionaries: 0.22258758544921875
# Total time: 4.379564046859741
#
#
#
# 648518346348109695:
# 648518346348109695 mesh fetched. 0.1009976863861084
# Counter({8: 8899})
# 648518346348109695 neighborhood generated. 0.07927322387695312
# 648518346348109695 floating artifacts removed. 0.019257545471191406
# 648518346348109695 isolated nodes removed. 0.11139798164367676
# 648518346348109695 key successfully filtered. 3.337860107421875e-06
# This took  0.311779260635376 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3143599033355713
# Step 2: Pymesh shrinkwrapping: 0.28501367568969727
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.043389320373535156
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6991267204284668
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348109695_mls
# Step 5: Generating and reading Skeleton: 1.0143747329711914
# Step 6: Inserting both dictionaries: 0.20496129989624023
# Total time: 2.5621683597564697
#
#
#
# 648518346348114848:
# 648518346348114848 mesh fetched. 0.07461380958557129
# Counter({8: 11978})
# 648518346348114848 neighborhood generated. 0.1349034309387207
# 648518346348114848 floating artifacts removed. 0.02599477767944336
# 648518346348114848 isolated nodes removed. 0.14713311195373535
# 648518346348114848 key successfully filtered. 3.5762786865234375e-06
# This took  0.38344740867614746 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3874857425689697
# Step 2: Pymesh shrinkwrapping: 0.29994845390319824
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07174801826477051
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7595093250274658
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348114848_mls
# Step 5: Generating and reading Skeleton: 1.7894456386566162
# Step 6: Inserting both dictionaries: 0.2068924903869629
# Total time: 3.5160255432128906
#
#
#
# 648518346348125439:
# 648518346348125439 mesh fetched. 0.15032315254211426
# Counter({8: 16731})
# 648518346348125439 neighborhood generated. 0.20641303062438965
# 648518346348125439 floating artifacts removed. 0.06622695922851562
# 648518346348125439 isolated nodes removed. 0.23620367050170898
# 648518346348125439 key successfully filtered. 3.337860107421875e-06
# This took  0.66015625 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6660304069519043
# Step 2: Pymesh shrinkwrapping: 0.3478817939758301
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09702324867248535
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6459226608276367
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348125439_mls
# Step 5: Generating and reading Skeleton: 1.5330018997192383
# Step 6: Inserting both dictionaries: 0.2526211738586426
# Total time: 3.5437939167022705
#
#
#
# 648518346348191601:
# 648518346348191601 mesh fetched. 0.12331628799438477
# Counter({8: 31289})
# 648518346348191601 neighborhood generated. 0.49239301681518555
# 648518346348191601 floating artifacts removed. 0.12173748016357422
# 648518346348191601 isolated nodes removed. 0.47214555740356445
# 648518346348191601 key successfully filtered. 5.9604644775390625e-06
# This took  1.2109451293945312 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.222726821899414
# Step 2: Pymesh shrinkwrapping: 1.0453517436981201
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15895462036132812
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9653029441833496
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348191601_mls
# Step 5: Generating and reading Skeleton: 1.6932525634765625
# Step 6: Inserting both dictionaries: 0.3000638484954834
# Total time: 5.387722730636597
#
#
#
# 648518346348199802:
# 648518346348199802 mesh fetched. 0.16520404815673828
# Counter({10: 79931})
# only error segments
# This took  0.18272781372070312 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.182816743850708
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.01244044303894043
# Total time: 0.19533920288085938
#
#
#
# 648518346348200133:
# 648518346348200133 mesh fetched. 0.12598490715026855
# Counter({10: 135768})
# only error segments
# This took  0.1778109073638916 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.17793512344360352
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.009645223617553711
# Total time: 0.18772625923156738
#
#
#
# 648518346348202534:
# 648518346348202534 mesh fetched. 0.11162471771240234
# Counter({8: 43272})
# 648518346348202534 neighborhood generated. 0.41066956520080566
# 648518346348202534 floating artifacts removed. 0.09333181381225586
# 648518346348202534 isolated nodes removed. 0.5632410049438477
# 648518346348202534 key successfully filtered. 5.245208740234375e-06
# This took  1.1799533367156982 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.1928343772888184
# Step 2: Pymesh shrinkwrapping: 1.7315008640289307
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2119457721710205
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.2342095375061035
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348202534_mls
# Step 5: Generating and reading Skeleton: 1.973127841949463
# Step 6: Inserting both dictionaries: 0.3524739742279053
# Total time: 6.696844100952148
#
#
#
# 648518346348212893:
# 648518346348212893 mesh fetched. 0.12639641761779785
# Counter({8: 17915})
# 648518346348212893 neighborhood generated. 0.1919543743133545
# 648518346348212893 floating artifacts removed. 0.06167197227478027
# 648518346348212893 isolated nodes removed. 0.2570064067840576
# 648518346348212893 key successfully filtered. 3.814697265625e-06
# This took  0.6381914615631104 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6458921432495117
# Step 2: Pymesh shrinkwrapping: 0.39315319061279297
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10563778877258301
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7957010269165039
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348212893_mls
# Step 5: Generating and reading Skeleton: 2.6400537490844727
# Step 6: Inserting both dictionaries: 0.2843811511993408
# Total time: 4.865760087966919
#
#
#
# 648518346348466883:
# 648518346348466883 mesh fetched. 0.16826224327087402
# Counter({10: 3940})
# only error segments
# This took  0.1709733009338379 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.17111873626708984
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.019111156463623047
# Total time: 0.19036173820495605
#
#
#
# 648518346348497856:
# 648518346348497856 mesh fetched. 0.1320934295654297
# Counter({8: 13836})
# 648518346348497856 neighborhood generated. 0.18126368522644043
# 648518346348497856 floating artifacts removed. 0.030614614486694336
# 648518346348497856 isolated nodes removed. 0.16727638244628906
# 648518346348497856 key successfully filtered. 4.291534423828125e-06
# This took  0.5119624137878418 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5167250633239746
# Step 2: Pymesh shrinkwrapping: 0.4976048469543457
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08165311813354492
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7844862937927246
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348497856_mls
# Step 5: Generating and reading Skeleton: 1.2194771766662598
# Step 6: Inserting both dictionaries: 0.1777195930480957
# Total time: 3.2784457206726074
#
#
#
# 648518346349372788:
# 648518346349372788 mesh fetched. 0.1680293083190918
# Counter({10: 28837})
# only error segments
# This took  0.17941641807556152 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.1796875
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.048548221588134766
# Total time: 0.228318452835083
#
#
#
# 648518346349375122:
# 648518346349375122 mesh fetched. 0.10542607307434082
# Counter({8: 117719})
# 648518346349375122 neighborhood generated. 1.0025229454040527
# 648518346349375122 floating artifacts removed. 0.2819986343383789
# 648518346349375122 isolated nodes removed. 1.4040071964263916
# 648518346349375122 key successfully filtered. 4.5299530029296875e-06
# This took  2.795039653778076 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.830589532852173
# Step 2: Pymesh shrinkwrapping: 3.560530662536621
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6064636707305908
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.8661584854125977
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349375122_mls
# Step 5: Generating and reading Skeleton: 4.95951509475708
# Step 6: Inserting both dictionaries: 0.7452919483184814
# Total time: 14.57218050956726
#
#
#
# 648518346349386649:
# 648518346349386649 mesh fetched. 0.15465521812438965
# Counter({8: 44577})
# 648518346349386649 neighborhood generated. 0.4308321475982666
# 648518346349386649 floating artifacts removed. 0.09597611427307129
# 648518346349386649 isolated nodes removed. 0.5058102607727051
# 648518346349386649 key successfully filtered. 4.76837158203125e-06
# This took  1.188338041305542 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.2008161544799805
# Step 2: Pymesh shrinkwrapping: 1.247513771057129
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.22493839263916016
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.141981601715088
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349386649_mls
# Step 5: Generating and reading Skeleton: 2.2280054092407227
# Step 6: Inserting both dictionaries: 0.32555317878723145
# Total time: 6.370487689971924
#
#
#
# 648518346349470217:
# 648518346349470217 mesh fetched. 0.2168257236480713
# Counter({8: 149229, 10: 4847})
# 648518346349470217 neighborhood generated. 1.5948560237884521
# 648518346349470217 floating artifacts removed. 0.29413390159606934
# 648518346349470217 isolated nodes removed. 3.5485312938690186
# 648518346349470217 key successfully filtered. 5.0067901611328125e-06
# This took  5.656177759170532 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.76158595085144
# Step 2: Pymesh shrinkwrapping: 8.512932300567627
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7826499938964844
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.2678728103637695
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349470217_mls
# Step 5: Generating and reading Skeleton: 6.875791788101196
# Step 6: Inserting both dictionaries: 1.054657220840454
# Total time: 25.256713151931763
#
#
#
# 648518346349483062:
# 648518346349483062 mesh fetched. 0.20366477966308594
# Counter({3: 158568, 5: 61017, 2: 14370})
# 648518346349483062 neighborhood generated. 2.016383647918701
# 648518346349483062 floating artifacts removed. 0.41886281967163086
# 648518346349483062 isolated nodes removed. 2.7202670574188232
# 648518346349483062 key successfully filtered. 5.0067901611328125e-06
# This took  5.360130071640015 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.4359211921691895
# Step 2: Pymesh shrinkwrapping: 30.260186910629272
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.2344558238983154
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 3.0611627101898193
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349483062_mls
# Step 5: Generating and reading Skeleton: 15.007333278656006
# Step 6: Inserting both dictionaries: 1.2139654159545898
# Total time: 56.21536827087402
#
#
#
# 7053.944894790649
