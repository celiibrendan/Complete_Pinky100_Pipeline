# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349499581******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.1236116886138916
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1329.8206541538239
# 2) Finished: Generating CGAL segmentation for neuron: 1352.7403678894043
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 25
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2807891368865967
# 5) Staring: Finding Apical Index
# Soma Index = 25
# Soma Connections = [13, 27, 39, 84, 144, 5, 17, 62, 38, 80, 170]
# soma_80_percent = 215922.665625
# Debugging the axon filter
# [(13, 233876.90625), (27, 236095.578125), (39, 236917.28125), (84, 212963.1875), (144, 221451.84375), (5, 212562.75), (17, 232267.609375), (62, 219270.171875), (38, 248862.421875), (80, 221233.140625), (170, 221629.65625)]
# possible_Axons_filter_1 = [84, 5]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.09872889518737793
# 6) Staring: Classifying Entire Neuron
# 80 = stub soma
# 84 = cilia
# 144 = stub soma
# 170 = stub soma
# 8 = stub apical
# 22 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = error
# 31 = stub apical
# 33 = stub apical
# 41 = stub apical
# 44 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 66 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 74 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 81 = stub apical
# 85 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 96 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 110 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 132 = stub apical
# 133 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 152 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 164 = stub apical
# 165 = stub apical
# 167 = stub apical
# 168 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 203 = stub apical
# 204 = stub apical
# 207 = stub apical
# 208 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 225 = stub apical
# 226 = stub apical
# 228 = stub apical
# 229 = stub apical
# 237 = stub apical
# 238 = stub apical
# 240 = stub apical
# 241 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 251 = stub apical
# 256 = stub apical
# 260 = stub apical
# 261 = stub apical
# Total Labels found = {'soma', 'basal', 'error', 'cilia', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.4689857959747314
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6830925941467285
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.322356939315796
# Finished Auto Labeling: 1369.6395161151886
# 1369.9371614456177

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
