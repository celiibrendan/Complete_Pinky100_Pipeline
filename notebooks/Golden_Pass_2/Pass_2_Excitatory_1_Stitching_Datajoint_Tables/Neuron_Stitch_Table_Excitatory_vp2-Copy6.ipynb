# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349472574**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3653 pieces after mesh split
# There were 374 pieces found after size threshold
# max_index = 0
# max_face_len = 3192100
# Total time for Mesh Cleansing: 1332.816015958786
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9674850934069714% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349490749**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349490749_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.10494327545166
# Number of outside child meshes =  119
# Main mesh and outside child meshes make up 0.9305907987688214% of original mesh
#  face length 2677958 using optimized facets with 3 neighbors
# Filtering edges by size finished: 52.228490591049194, facet # = 138072
# Filtering by convexity and getting centers took: 76.80328607559204, facet # = 28844
# Finished facets for main mesh: 135.90209650993347 with facet length = 28844
# Finished 28844 facets for main mesh: 135.90221500396729
# Filtering edges by size finished: 1.3282363414764404, facet # = 3025
# Filtering by convexity and getting centers took: 1.8712890148162842, facet # = 890
# Filtering edges by size finished: 1.0915369987487793, facet # = 2487
# Filtering by convexity and getting centers took: 0.8676021099090576, facet # = 624
# Filtering edges by size finished: 0.03856325149536133, facet # = 97
# Filtering by convexity and getting centers took: 0.04123520851135254, facet # = 13
# Filtering edges by size finished: 0.6126506328582764, facet # = 2585
# Filtering by convexity and getting centers took: 1.278104543685913, facet # = 790
# Filtering edges by size finished: 0.6077277660369873, facet # = 1778
# Filtering by convexity and getting centers took: 0.813452959060669, facet # = 482
# Filtering edges by size finished: 0.0016205310821533203, facet # = 12
# Filtering by convexity and getting centers took: 0.004553318023681641, facet # = 6
# Filtering edges by size finished: 0.009949445724487305, facet # = 36
# Filtering by convexity and getting centers took: 0.011409282684326172, facet # = 12
# Filtering edges by size finished: 0.002705812454223633, facet # = 6
# Filtering by convexity and getting centers took: 0.0032765865325927734, facet # = 3
# Filtering edges by size finished: 1.1755521297454834, facet # = 3367
# Filtering by convexity and getting centers took: 1.4355409145355225, facet # = 936
# Filtering edges by size finished: 0.0507504940032959, facet # = 21
# Filtering by convexity and getting centers took: 0.023775100708007812, facet # = 8
# Filtering edges by size finished: 0.01895880699157715, facet # = 30
# Filtering by convexity and getting centers took: 0.012428760528564453, facet # = 5
# Filtering edges by size finished: 0.030736446380615234, facet # = 97
# Filtering by convexity and getting centers took: 0.029277563095092773, facet # = 25
# Filtering edges by size finished: 0.031125783920288086, facet # = 84
# Filtering by convexity and getting centers took: 0.028548002243041992, facet # = 20
# Filtering edges by size finished: 0.008404970169067383, facet # = 38
# Filtering by convexity and getting centers took: 0.013896465301513672, facet # = 10
# Filtering edges by size finished: 0.560183048248291, facet # = 2186
# Filtering by convexity and getting centers took: 0.9289429187774658, facet # = 614
# Filtering edges by size finished: 0.009762287139892578, facet # = 36
# Filtering by convexity and getting centers took: 0.010856389999389648, facet # = 10
# Filtering edges by size finished: 0.0010802745819091797, facet # = 9
# Filtering by convexity and getting centers took: 0.0034301280975341797, facet # = 4
# Filtering edges by size finished: 0.0023500919342041016, facet # = 17
# Filtering by convexity and getting centers took: 0.006102800369262695, facet # = 9
# Filtering edges by size finished: 0.001150369644165039, facet # = 7
# Filtering by convexity and getting centers took: 0.002875804901123047, facet # = 4
# Filtering edges by size finished: 0.0023345947265625, facet # = 6
# Filtering by convexity and getting centers took: 0.0029807090759277344, facet # = 4
# Filtering edges by size finished: 0.003546476364135742, facet # = 9
# Filtering by convexity and getting centers took: 0.003339529037475586, facet # = 4
# Filtering edges by size finished: 0.009371280670166016, facet # = 58
# Filtering by convexity and getting centers took: 0.018277406692504883, facet # = 32
# Filtering edges by size finished: 0.005525112152099609, facet # = 22
# Filtering by convexity and getting centers took: 0.00659942626953125, facet # = 6
# Filtering edges by size finished: 0.0033648014068603516, facet # = 26
# Filtering by convexity and getting centers took: 0.008731365203857422, facet # = 9
# Filtering edges by size finished: 0.0025467872619628906, facet # = 20
# Filtering by convexity and getting centers took: 0.0066280364990234375, facet # = 5
# Filtering edges by size finished: 0.002717733383178711, facet # = 22
# Filtering by convexity and getting centers took: 0.007982254028320312, facet # = 11
# Filtering edges by size finished: 0.004138469696044922, facet # = 24
# Filtering by convexity and getting centers took: 0.007309913635253906, facet # = 7
# Filtering edges by size finished: 0.0034165382385253906, facet # = 12
# Filtering by convexity and getting centers took: 0.004899501800537109, facet # = 6
# Filtering edges by size finished: 0.008173227310180664, facet # = 40
# Filtering by convexity and getting centers took: 0.013247013092041016, facet # = 15
# Filtering edges by size finished: 0.024155139923095703, facet # = 68
# Filtering by convexity and getting centers took: 0.02406620979309082, facet # = 15
# Filtering edges by size finished: 0.0035920143127441406, facet # = 26
# Filtering by convexity and getting centers took: 0.009241580963134766, facet # = 8
# Filtering edges by size finished: 0.0021851062774658203, facet # = 19
# Filtering by convexity and getting centers took: 0.006582021713256836, facet # = 9
# Filtering edges by size finished: 0.006678581237792969, facet # = 22
# Filtering by convexity and getting centers took: 0.008457183837890625, facet # = 11
# Filtering edges by size finished: 0.013553142547607422, facet # = 27
# Filtering by convexity and getting centers took: 0.020668745040893555, facet # = 8
# Filtering edges by size finished: 0.049927711486816406, facet # = 38
# Filtering by convexity and getting centers took: 0.045777320861816406, facet # = 19
# Filtering edges by size finished: 0.00213623046875, facet # = 11
# Filtering by convexity and getting centers took: 0.0059604644775390625, facet # = 6
# Filtering edges by size finished: 0.009281635284423828, facet # = 15
# Filtering by convexity and getting centers took: 0.006603717803955078, facet # = 5
# Filtering edges by size finished: 0.015321731567382812, facet # = 29
# Filtering by convexity and getting centers took: 0.016933679580688477, facet # = 13
# Filtering edges by size finished: 0.010147333145141602, facet # = 16
# Filtering by convexity and getting centers took: 0.010601282119750977, facet # = 4
# Filtering edges by size finished: 0.004453420639038086, facet # = 20
# Filtering by convexity and getting centers took: 0.009959936141967773, facet # = 7
# Filtering edges by size finished: 0.00833439826965332, facet # = 29
# Filtering by convexity and getting centers took: 0.014556884765625, facet # = 8
# Filtering edges by size finished: 0.013036012649536133, facet # = 26
# Filtering by convexity and getting centers took: 0.014505863189697266, facet # = 13
# Filtering edges by size finished: 0.006547451019287109, facet # = 29
# Filtering by convexity and getting centers took: 0.014046430587768555, facet # = 8
# Filtering edges by size finished: 0.010403156280517578, facet # = 39
# Filtering by convexity and getting centers took: 0.02129530906677246, facet # = 7
# Filtering edges by size finished: 0.003226041793823242, facet # = 11
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.014814138412475586, facet # = 5
# Filtering edges by size finished: 0.05919671058654785, facet # = 64
# Filtering by convexity and getting centers took: 0.036866188049316406, facet # = 29
# Filtering edges by size finished: 0.01289820671081543, facet # = 39
# Filtering by convexity and getting centers took: 0.020021438598632812, facet # = 16
# Filtering edges by size finished: 0.0030264854431152344, facet # = 12
# Filtering by convexity and getting centers took: 0.005187034606933594, facet # = 4
# Filtering edges by size finished: 0.022342681884765625, facet # = 77
# Filtering by convexity and getting centers took: 0.028837919235229492, facet # = 33
# Filtering edges by size finished: 0.0035886764526367188, facet # = 25
# Filtering by convexity and getting centers took: 0.009640216827392578, facet # = 4
# Filtering edges by size finished: 0.0017161369323730469, facet # = 11
# Filtering by convexity and getting centers took: 0.0048215389251708984, facet # = 4
# Filtering edges by size finished: 0.0010802745819091797, facet # = 4
# Filtering by convexity and getting centers took: 0.002171754837036133, facet # = 3
# Filtering edges by size finished: 0.006258964538574219, facet # = 34
# Filtering by convexity and getting centers took: 0.011957168579101562, facet # = 8
# Filtering edges by size finished: 0.004010438919067383, facet # = 31
# Filtering by convexity and getting centers took: 0.03213930130004883, facet # = 9
# Filtering edges by size finished: 0.01989579200744629, facet # = 23
# Filtering by convexity and getting centers took: 0.025652170181274414, facet # = 10
# Filtering edges by size finished: 0.004834890365600586, facet # = 14
# Filtering by convexity and getting centers took: 0.0063784122467041016, facet # = 5
# Filtering edges by size finished: 0.015399932861328125, facet # = 63
# Filtering by convexity and getting centers took: 0.021691560745239258, facet # = 19
# Filtering edges by size finished: 0.0047986507415771484, facet # = 25
# Filtering by convexity and getting centers took: 0.007741212844848633, facet # = 5
# Filtering edges by size finished: 0.00830698013305664, facet # = 33
# Filtering by convexity and getting centers took: 0.01096343994140625, facet # = 16
# Filtering edges by size finished: 0.0036973953247070312, facet # = 30
# Filtering by convexity and getting centers took: 0.07337760925292969, facet # = 11
# Filtering edges by size finished: 0.005503177642822266, facet # = 15
# Filtering by convexity and getting centers took: 0.008993387222290039, facet # = 5
# Filtering edges by size finished: 0.005296468734741211, facet # = 8
# Filtering by convexity and getting centers took: 0.0060808658599853516, facet # = 7
# Filtering edges by size finished: 0.012952089309692383, facet # = 26
# Filtering by convexity and getting centers took: 0.016852378845214844, facet # = 16
# Filtering edges by size finished: 0.0016150474548339844, facet # = 5
# Filtering by convexity and getting centers took: 0.027016878128051758, facet # = 3
# Filtering edges by size finished: 0.020974159240722656, facet # = 26
# Filtering by convexity and getting centers took: 0.024408578872680664, facet # = 10
# Filtering edges by size finished: 0.0018663406372070312, facet # = 9
# Filtering by convexity and getting centers took: 0.004190683364868164, facet # = 4
# Filtering edges by size finished: 0.0035037994384765625, facet # = 14
# Filtering by convexity and getting centers took: 0.00480341911315918, facet # = 5
# Filtering edges by size finished: 0.008269309997558594, facet # = 26
# Filtering by convexity and getting centers took: 0.008945703506469727, facet # = 11
# Filtering edges by size finished: 0.00269317626953125, facet # = 18
# Filtering by convexity and getting centers took: 0.0066127777099609375, facet # = 10
# Filtering edges by size finished: 0.002735137939453125, facet # = 20
# Filtering by convexity and getting centers took: 0.006119728088378906, facet # = 2
# Filtering edges by size finished: 0.0058062076568603516, facet # = 19
# Filtering by convexity and getting centers took: 0.008244037628173828, facet # = 3
# Filtering edges by size finished: 0.005288839340209961, facet # = 24
# Filtering by convexity and getting centers took: 0.011025428771972656, facet # = 7
# Filtering edges by size finished: 0.002281665802001953, facet # = 13
# Filtering by convexity and getting centers took: 0.006434202194213867, facet # = 11
# Filtering edges by size finished: 0.005609989166259766, facet # = 27
# Filtering by convexity and getting centers took: 0.01139378547668457, facet # = 10
# Filtering edges by size finished: 0.007939815521240234, facet # = 32
# Filtering by convexity and getting centers took: 0.013870000839233398, facet # = 11
# Filtering edges by size finished: 0.0057485103607177734, facet # = 18
# Filtering by convexity and getting centers took: 0.007158517837524414, facet # = 9
# Filtering edges by size finished: 0.006211996078491211, facet # = 43
# Filtering by convexity and getting centers took: 0.03452038764953613, facet # = 15
# Filtering edges by size finished: 0.0029044151306152344, facet # = 14
# Filtering by convexity and getting centers took: 0.006194114685058594, facet # = 4
# Filtering edges by size finished: 0.007683753967285156, facet # = 33
# Filtering by convexity and getting centers took: 0.02567458152770996, facet # = 16
# Filtering edges by size finished: 0.0022830963134765625, facet # = 13
# Filtering by convexity and getting centers took: 0.005059719085693359, facet # = 7
# Filtering edges by size finished: 0.005678653717041016, facet # = 20
# Filtering by convexity and getting centers took: 0.0072705745697021484, facet # = 7
# Filtering edges by size finished: 0.0012958049774169922, facet # = 9
# Filtering by convexity and getting centers took: 0.0034301280975341797, facet # = 7
# Filtering edges by size finished: 0.002923727035522461, facet # = 21
# Filtering by convexity and getting centers took: 0.007201194763183594, facet # = 7
# Filtering edges by size finished: 0.0017282962799072266, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0016045570373535156, facet # = 2
# Filtering edges by size finished: 0.00531458854675293, facet # = 8
# Filtering by convexity and getting centers took: 0.005704402923583984, facet # = 6
# Filtering edges by size finished: 0.0015094280242919922, facet # = 8
# Filtering by convexity and getting centers took: 0.004777669906616211, facet # = 5
# Filtering edges by size finished: 0.0072519779205322266, facet # = 21
# Filtering by convexity and getting centers took: 0.010459184646606445, facet # = 6
# Filtering edges by size finished: 0.020576953887939453, facet # = 30
# Filtering by convexity and getting centers took: 0.027348995208740234, facet # = 15
# Filtering edges by size finished: 0.0033884048461914062, facet # = 14
# Filtering by convexity and getting centers took: 0.005960702896118164, facet # = 3
# Filtering edges by size finished: 0.002666950225830078, facet # = 14
# Filtering by convexity and getting centers took: 0.005270242691040039, facet # = 8
# Filtering edges by size finished: 0.002086162567138672, facet # = 17
# Filtering by convexity and getting centers took: 0.004446744918823242, facet # = 0
# Filtering edges by size finished: 0.001146554946899414, facet # = 10
# Filtering by convexity and getting centers took: 0.003473520278930664, facet # = 4
# Filtering edges by size finished: 0.0018641948699951172, facet # = 15
# Filtering by convexity and getting centers took: 0.005647182464599609, facet # = 13
# Filtering edges by size finished: 0.0024509429931640625, facet # = 19
# Filtering by convexity and getting centers took: 0.00618743896484375, facet # = 9
# Filtering edges by size finished: 0.0043871402740478516, facet # = 27
# Filtering by convexity and getting centers took: 0.00782918930053711, facet # = 8
# Filtering edges by size finished: 0.020754098892211914, facet # = 134
# Filtering by convexity and getting centers took: 0.03695178031921387, facet # = 37
# Filtering edges by size finished: 0.0039746761322021484, facet # = 31
# Filtering by convexity and getting centers took: 0.009711027145385742, facet # = 16
# Filtering edges by size finished: 0.005431175231933594, facet # = 21
# Filtering by convexity and getting centers took: 0.007123470306396484, facet # = 4
# Filtering edges by size finished: 0.003244638442993164, facet # = 25
# Filtering by convexity and getting centers took: 0.008608341217041016, facet # = 11
# Filtering edges by size finished: 0.001596689224243164, facet # = 10
# Filtering by convexity and getting centers took: 0.003641366958618164, facet # = 2
# Filtering edges by size finished: 0.0020656585693359375, facet # = 18
# Filtering by convexity and getting centers took: 0.0062541961669921875, facet # = 9
# Filtering edges by size finished: 0.012574195861816406, facet # = 49
# Filtering by convexity and getting centers took: 0.015349864959716797, facet # = 15
# Filtering edges by size finished: 0.002665996551513672, facet # = 21
# Filtering by convexity and getting centers took: 0.007559061050415039, facet # = 11
# Filtering edges by size finished: 0.007860183715820312, facet # = 49
# Filtering by convexity and getting centers took: 0.022742748260498047, facet # = 26
# Filtering edges by size finished: 0.005689144134521484, facet # = 29
# Filtering by convexity and getting centers took: 0.04567742347717285, facet # = 11
# Filtering edges by size finished: 0.016666889190673828, facet # = 59
# Filtering by convexity and getting centers took: 0.01735854148864746, facet # = 31
# Filtering edges by size finished: 0.006109714508056641, facet # = 28
# Filtering by convexity and getting centers took: 0.009054899215698242, facet # = 14
# Filtering edges by size finished: 0.0008687973022460938, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0012116432189941406, facet # = 1
# Filtering edges by size finished: 0.002111196517944336, facet # = 19
# Filtering by convexity and getting centers took: 0.00670313835144043, facet # = 10
# Filtering edges by size finished: 0.003292560577392578, facet # = 25
# Filtering by convexity and getting centers took: 0.008519887924194336, facet # = 10
# Filtering edges by size finished: 0.0029382705688476562, facet # = 20
# Filtering by convexity and getting centers took: 0.006857395172119141, facet # = 6
# Filtering edges by size finished: 0.002660989761352539, facet # = 22
# Filtering by convexity and getting centers took: 0.007224321365356445, facet # = 9
# Filtering edges by size finished: 0.0035009384155273438, facet # = 28
# Filtering by convexity and getting centers took: 0.00881505012512207, facet # = 7
# Filtering edges by size finished: 0.004839420318603516, facet # = 37
# Filtering by convexity and getting centers took: 0.011704683303833008, facet # = 21
# Filtering edges by size finished: 0.0017442703247070312, facet # = 14
# Filtering by convexity and getting centers took: 0.003980875015258789, facet # = 1
# Filtering edges by size finished: 0.004729747772216797, facet # = 31
# Filtering by convexity and getting centers took: 0.010127782821655273, facet # = 8
# Filtering edges by size finished: 0.00205230712890625, facet # = 14
# Filtering by convexity and getting centers took: 0.004697561264038086, facet # = 5
# Filtering edges by size finished: 0.002258777618408203, facet # = 18
# Filtering by convexity and getting centers took: 0.0060176849365234375, facet # = 7
# Filtering edges by size finished: 0.004172563552856445, facet # = 33
# Filtering by convexity and getting centers took: 0.009514808654785156, facet # = 8
# Total time for facets: 151.5175268650055
# Zero faceted faces = [90]
# Starting Child 0
# 890 28844
# Done distance matrix: 1.4246044158935547
# Done Generating final pairs: 1.4680886268615723
# best_stitch_pair = [  367 21710]
# best_stitch_pair_size = 155834.30621450322
# best_stitch_pair_distance = 1362.7899045379843
# best_stitch_pair_size_ratio = 0.6357643517358074
# Starting Child 1
# 624 28844
# Done distance matrix: 0.723773717880249
# Child 1 There were no points close enough
# Starting Child 2
# 13 28844
# Done distance matrix: 0.022220134735107422
# Done Generating final pairs: 0.04188203811645508
# best_stitch_pair = [   11 21042]
# best_stitch_pair_size = 59702.25840189804
# best_stitch_pair_distance = 407.69390744599355
# best_stitch_pair_size_ratio = 0.4692255097881682
# Starting Child 3
# 790 28844
# Done distance matrix: 0.9343464374542236
# Done Generating final pairs: 1.0039105415344238
# best_stitch_pair = [ 603 9084]
# best_stitch_pair_size = 149732.49531023623
# best_stitch_pair_distance = 1695.5339784824287
# best_stitch_pair_size_ratio = 0.6495024173811476
# Starting Child 4
# 482 28844
# Done distance matrix: 0.6523926258087158
# Done Generating final pairs: 0.6825768947601318
# best_stitch_pair = [ 422 5794]
# best_stitch_pair_size = 40503.678322502725
# best_stitch_pair_distance = 1920.789251313148
# best_stitch_pair_size_ratio = 0.39742344214243447
# Starting Child 5
# 6 28844
# Done distance matrix: 0.019719600677490234
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# 12 28844
# Done distance matrix: 0.016035079956054688
# Done Generating final pairs: 0.06215190887451172
# best_stitch_pair = [    6 26452]
# best_stitch_pair_size = 26939.65742754354
# best_stitch_pair_distance = 858.389369467182
# best_stitch_pair_size_ratio = 0.4178506445725431
# Starting Child 7
# 3 28844
# Done distance matrix: 0.004477024078369141
# Done Generating final pairs: 0.03900146484375
# best_stitch_pair = [   1 3240]
# best_stitch_pair_size = 326097.74763656466
# best_stitch_pair_distance = 1390.6191115782751
# best_stitch_pair_size_ratio = 0.23759114220781205
# Starting Child 8
# 936 28844
# Done distance matrix: 1.2189278602600098
# Child 8 There were no points close enough
# Starting Child 9
# 8 28844
# Done distance matrix: 0.02340555191040039
# Done Generating final pairs: 0.05160665512084961
# best_stitch_pair = [    1 16298]
# best_stitch_pair_size = 233263.7653212795
# best_stitch_pair_distance = 1820.2263110127963
# best_stitch_pair_size_ratio = 0.4885130913798642
# Starting Child 10
# 5 28844
# Done distance matrix: 0.005778312683105469
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 25 28844
# Done distance matrix: 0.02453327178955078
# Done Generating final pairs: 0.04506874084472656
# best_stitch_pair = [   17 20032]
# best_stitch_pair_size = 101025.10860280177
# best_stitch_pair_distance = 1847.1084212555945
# best_stitch_pair_size_ratio = 0.5128553556895346
# Starting Child 12
# 20 28844
# Done distance matrix: 0.02401113510131836
# Done Generating final pairs: 0.046559810638427734
# best_stitch_pair = [   1 2596]
# best_stitch_pair_size = 35560.2986269597
# best_stitch_pair_distance = 1587.1783819215166
# best_stitch_pair_size_ratio = 0.7173746262227143
# Starting Child 13
# 10 28844
# Done distance matrix: 0.013544559478759766
# Done Generating final pairs: 0.045583486557006836
# best_stitch_pair = [    4 20158]
# best_stitch_pair_size = 109000.66377404731
# best_stitch_pair_distance = 1412.5144953588824
# best_stitch_pair_size_ratio = 0.462957296035454
# Starting Child 14
# 614 28844
# Done distance matrix: 0.8355953693389893
# Done Generating final pairs: 0.8601956367492676
# best_stitch_pair = [  95 2383]
# best_stitch_pair_size = 315925.6783588936
# best_stitch_pair_distance = 1443.1876634120215
# best_stitch_pair_size_ratio = 0.6098219763112177
# Starting Child 15
# 10 28844
# Done distance matrix: 0.018952369689941406
# Done Generating final pairs: 0.037828683853149414
# best_stitch_pair = [   1 8456]
# best_stitch_pair_size = 104753.85605048142
# best_stitch_pair_distance = 1288.2687605416352
# best_stitch_pair_size_ratio = 0.2866760379328798
# Starting Child 16
# 4 28844
# Done distance matrix: 0.004582881927490234
# Done Generating final pairs: 0.022254228591918945
# best_stitch_pair = [    3 12271]
# best_stitch_pair_size = 27286.7145561898
# best_stitch_pair_distance = 1782.9257885758952
# best_stitch_pair_size_ratio = 0.6997791553623196
# Starting Child 17
# 9 28844
# Done distance matrix: 0.010442972183227539
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 4 28844
# Done distance matrix: 0.004585742950439453
# Done Generating final pairs: 0.027163267135620117
# best_stitch_pair = [   1 4262]
# best_stitch_pair_size = 312976.7227588646
# best_stitch_pair_distance = 773.0745343967067
# best_stitch_pair_size_ratio = 0.15071629183119645
# Starting Child 19
# 4 28844
# Done distance matrix: 0.005959987640380859
# Child 19 There were no points close enough
# Starting Child 20
# 4 28844
# Done distance matrix: 0.0057718753814697266
# Done Generating final pairs: 0.033447980880737305
# best_stitch_pair = [    0 19329]
# best_stitch_pair_size = 46920.6884974406
# best_stitch_pair_distance = 1957.1918831840421
# best_stitch_pair_size_ratio = 0.2257175718722598
# Starting Child 21
# 32 28844
# Done distance matrix: 0.03263688087463379
# Done Generating final pairs: 0.06158328056335449
# best_stitch_pair = [   13 15992]
# best_stitch_pair_size = 46044.03935018633
# best_stitch_pair_distance = 1616.5213710724415
# best_stitch_pair_size_ratio = 0.9277600714095661
# Starting Child 22
# 6 28844
# Done distance matrix: 0.006611347198486328
# Done Generating final pairs: 0.029871225357055664
# best_stitch_pair = [    3 16443]
# best_stitch_pair_size = 28849.289085997643
# best_stitch_pair_distance = 1947.4173347397666
# best_stitch_pair_size_ratio = 0.3937121425280976
# Starting Child 23
# 9 28844
# Done distance matrix: 0.01306915283203125
# Done Generating final pairs: 0.04424571990966797
# best_stitch_pair = [   8 9788]
# best_stitch_pair_size = 53182.380027250285
# best_stitch_pair_distance = 1508.2378042391938
# best_stitch_pair_size_ratio = 0.2033007429864618
# Starting Child 24
# 5 28844
# Done distance matrix: 0.007189273834228516
# Done Generating final pairs: 0.07706713676452637
# best_stitch_pair = [    0 23266]
# best_stitch_pair_size = 55539.19396312535
# best_stitch_pair_distance = 1893.481819370283
# best_stitch_pair_size_ratio = 0.6348851694542057
# Starting Child 25
# 11 28844
# Done distance matrix: 0.011981010437011719
# Done Generating final pairs: 0.031889915466308594
# best_stitch_pair = [    2 23265]
# best_stitch_pair_size = 91899.54916123567
# best_stitch_pair_distance = 1729.485030589227
# best_stitch_pair_size_ratio = 0.7291396926031924
# Starting Child 26
# 7 28844
# Done distance matrix: 0.007859230041503906
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 6 28844
# Done distance matrix: 0.007002353668212891
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# 15 28844
# Done distance matrix: 0.014986991882324219
# Done Generating final pairs: 0.03528618812561035
# best_stitch_pair = [    4 26731]
# best_stitch_pair_size = 167062.43451814214
# best_stitch_pair_distance = 1817.3882670611545
# best_stitch_pair_size_ratio = 0.7222063504264605
# Starting Child 29
# 15 28844
# Done distance matrix: 0.014987945556640625
# Done Generating final pairs: 0.039763689041137695
# best_stitch_pair = [    7 12934]
# best_stitch_pair_size = 117953.00330227167
# best_stitch_pair_distance = 1838.5025359193603
# best_stitch_pair_size_ratio = 0.47052033298071955
# Starting Child 30
# 8 28844
# Done distance matrix: 0.00891423225402832
# Done Generating final pairs: 0.027544260025024414
# best_stitch_pair = [    1 22229]
# best_stitch_pair_size = 55812.369107216786
# best_stitch_pair_distance = 1330.9673675297424
# best_stitch_pair_size_ratio = 0.774680424485273
# Starting Child 31
# 9 28844
# Done distance matrix: 0.013018608093261719
# Done Generating final pairs: 0.0338749885559082
# best_stitch_pair = [    8 21139]
# best_stitch_pair_size = 15981.030989670337
# best_stitch_pair_distance = 1601.038465891576
# best_stitch_pair_size_ratio = 0.6778301705501579
# Starting Child 32
# 11 28844
# Done distance matrix: 0.012143611907958984
# Done Generating final pairs: 0.04048776626586914
# best_stitch_pair = [    7 22531]
# best_stitch_pair_size = 60996.7796839171
# best_stitch_pair_distance = 1924.003618826552
# best_stitch_pair_size_ratio = 0.24316625247992193
# Starting Child 33
# 8 28844
# Done distance matrix: 0.02213311195373535
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# 19 28844
# Done distance matrix: 0.029569149017333984
# Done Generating final pairs: 0.07283616065979004
# best_stitch_pair = [    9 10904]
# best_stitch_pair_size = 38828.48762844918
# best_stitch_pair_distance = 1949.969081676943
# best_stitch_pair_size_ratio = 0.5754399491508279
# Starting Child 35
# 6 28844
# Done distance matrix: 0.0076181888580322266
# Done Generating final pairs: 0.02613997459411621
# best_stitch_pair = [    3 13922]
# best_stitch_pair_size = 32663.653314481613
# best_stitch_pair_distance = 1053.5415489375239
# best_stitch_pair_size_ratio = 0.5073837232839884
# Starting Child 36
# 5 28844
# Done distance matrix: 0.00846552848815918
# Done Generating final pairs: 0.041420698165893555
# best_stitch_pair = [    4 25058]
# best_stitch_pair_size = 43678.657816305335
# best_stitch_pair_distance = 1503.4596094787817
# best_stitch_pair_size_ratio = 0.2793201586076235
# Starting Child 37
# 13 28844
# Done distance matrix: 0.019566059112548828
# Done Generating final pairs: 0.05440187454223633
# best_stitch_pair = [    4 23639]
# best_stitch_pair_size = 60127.959656007064
# best_stitch_pair_distance = 1821.0078537880984
# best_stitch_pair_size_ratio = 0.8700619579108746
# Starting Child 38
# 4 28844
# Done distance matrix: 0.005260944366455078
# Done Generating final pairs: 0.0263824462890625
# best_stitch_pair = [    0 18020]
# best_stitch_pair_size = 59818.142243344846
# best_stitch_pair_distance = 1999.9357988223842
# best_stitch_pair_size_ratio = 0.34317605070105817
# Starting Child 39
# 7 28844
# Done distance matrix: 0.007589578628540039
# Done Generating final pairs: 0.026661396026611328
# best_stitch_pair = [    6 24105]
# best_stitch_pair_size = 22972.03738284334
# best_stitch_pair_distance = 1537.6015098173898
# best_stitch_pair_size_ratio = 0.4033126358660809
# Starting Child 40
# 8 28844
# Done distance matrix: 0.008707761764526367
# Done Generating final pairs: 0.027817487716674805
# best_stitch_pair = [   1 7669]
# best_stitch_pair_size = 147220.5532561324
# best_stitch_pair_distance = 1300.1867578322108
# best_stitch_pair_size_ratio = 0.6991769616029374
# Starting Child 41
# 13 28844
# Done distance matrix: 0.012963533401489258
# Done Generating final pairs: 0.03383159637451172
# best_stitch_pair = [   3 4241]
# best_stitch_pair_size = 133643.09593786902
# best_stitch_pair_distance = 1186.2302916474835
# best_stitch_pair_size_ratio = 0.49179903647554857
# Starting Child 42
# 8 28844
# Done distance matrix: 0.020479917526245117
# Done Generating final pairs: 0.08616876602172852
# best_stitch_pair = [    0 15985]
# best_stitch_pair_size = 99886.42827434823
# best_stitch_pair_distance = 1056.5711613131089
# best_stitch_pair_size_ratio = 0.1628027217652836
# Starting Child 43
# 7 28844
# Done distance matrix: 0.00883936882019043
# Done Generating final pairs: 0.02873516082763672
# best_stitch_pair = [    6 14866]
# best_stitch_pair_size = 98642.95939997735
# best_stitch_pair_distance = 1760.8074389954825
# best_stitch_pair_size_ratio = 0.22861147813566524
# Starting Child 44
# 5 28844
# Done distance matrix: 0.006371736526489258
# Done Generating final pairs: 0.028131723403930664
# best_stitch_pair = [   1 8422]
# best_stitch_pair_size = 74496.72425364488
# best_stitch_pair_distance = 1639.6871090225457
# best_stitch_pair_size_ratio = 0.4448691638303452
# Starting Child 45
# 29 28844
# Done distance matrix: 0.04387664794921875
# Done Generating final pairs: 0.08061885833740234
# best_stitch_pair = [   16 27745]
# best_stitch_pair_size = 101244.3839169922
# best_stitch_pair_distance = 1925.0663431954476
# best_stitch_pair_size_ratio = 0.6619120828934305
# Starting Child 46
# 16 28844
# Done distance matrix: 0.07601141929626465
# Done Generating final pairs: 0.12260985374450684
# best_stitch_pair = [    5 13167]
# best_stitch_pair_size = 120606.53756594114
# best_stitch_pair_distance = 1907.148358609099
# best_stitch_pair_size_ratio = 0.5720356129888181
# Starting Child 47
# 4 28844
# Done distance matrix: 0.006628513336181641
# Done Generating final pairs: 0.0525515079498291
# best_stitch_pair = [    1 19349]
# best_stitch_pair_size = 84311.60837782874
# best_stitch_pair_distance = 859.1480129584306
# best_stitch_pair_size_ratio = 0.26642520672007164
# Starting Child 48
# 33 28844
# Done distance matrix: 0.05544018745422363
# Done Generating final pairs: 0.16661691665649414
# best_stitch_pair = [  20 6997]
# best_stitch_pair_size = 102198.67614112503
# best_stitch_pair_distance = 1822.9758236043047
# best_stitch_pair_size_ratio = 0.24552692228552947
# Starting Child 49
# 4 28844
# Done distance matrix: 0.005106687545776367
# Child 49 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 50
# 4 28844
# Done distance matrix: 0.005082130432128906
# Done Generating final pairs: 0.024344205856323242
# best_stitch_pair = [    0 18745]
# best_stitch_pair_size = 34349.49344658901
# best_stitch_pair_distance = 1270.028042330133
# best_stitch_pair_size_ratio = 0.5607325241998711
# Starting Child 51
# 3 28844
# Done distance matrix: 0.004023075103759766
# Done Generating final pairs: 0.023680925369262695
# best_stitch_pair = [    2 18737]
# best_stitch_pair_size = 37235.629707545144
# best_stitch_pair_distance = 1114.5145389743095
# best_stitch_pair_size_ratio = 0.2193960462246814
# Starting Child 52
# 8 28844
# Done distance matrix: 0.014215469360351562
# Done Generating final pairs: 0.06331348419189453
# best_stitch_pair = [   4 5819]
# best_stitch_pair_size = 137253.35503868482
# best_stitch_pair_distance = 1920.3943253657142
# best_stitch_pair_size_ratio = 0.42322796429475085
# Starting Child 53
# 9 28844
# Done distance matrix: 0.017111539840698242
# Done Generating final pairs: 0.05524015426635742
# best_stitch_pair = [    1 18421]
# best_stitch_pair_size = 35293.48765818975
# best_stitch_pair_distance = 1116.9544527334526
# best_stitch_pair_size_ratio = 0.3851558310717462
# Starting Child 54
# 10 28844
# Done distance matrix: 0.014455556869506836
# Done Generating final pairs: 0.04876852035522461
# best_stitch_pair = [    2 20607]
# best_stitch_pair_size = 77987.4625299091
# best_stitch_pair_distance = 1614.0048967568803
# best_stitch_pair_size_ratio = 0.3838605929771101
# Starting Child 55
# 5 28844
# Done distance matrix: 0.005465984344482422
# Done Generating final pairs: 0.02252340316772461
# best_stitch_pair = [    0 28039]
# best_stitch_pair_size = 149060.89303549688
# best_stitch_pair_distance = 163.7459573589762
# best_stitch_pair_size_ratio = 0.862441053998058
# Starting Child 56
# 19 28844
# Done distance matrix: 0.03710532188415527
# Done Generating final pairs: 0.06039857864379883
# best_stitch_pair = [    2 19486]
# best_stitch_pair_size = 81064.75848976341
# best_stitch_pair_distance = 1991.8581335028623
# best_stitch_pair_size_ratio = 0.6514570505581548
# Starting Child 57
# 5 28844
# Done distance matrix: 0.009825706481933594
# Done Generating final pairs: 0.035149335861206055
# best_stitch_pair = [   0 6738]
# best_stitch_pair_size = 30535.304241750655
# best_stitch_pair_distance = 1657.4474627265583
# best_stitch_pair_size_ratio = 0.4944245037116392
# Starting Child 58
# 16 28844
# Done distance matrix: 0.02060079574584961
# Done Generating final pairs: 0.0689542293548584
# best_stitch_pair = [    2 17951]
# best_stitch_pair_size = 103392.139378664
# best_stitch_pair_distance = 1359.7899531268338
# best_stitch_pair_size_ratio = 0.41214730398259114
# Starting Child 59
# 11 28844
# Done distance matrix: 0.011810064315795898
# Done Generating final pairs: 0.02937912940979004
# best_stitch_pair = [    6 26759]
# best_stitch_pair_size = 24318.78099382981
# best_stitch_pair_distance = 1999.1010116459581
# best_stitch_pair_size_ratio = 0.5870622217625151
# Starting Child 60
# 5 28844
# Done distance matrix: 0.00673675537109375
# Done Generating final pairs: 0.026250600814819336
# best_stitch_pair = [    3 11370]
# best_stitch_pair_size = 28740.773745607206
# best_stitch_pair_distance = 557.1879599730445
# best_stitch_pair_size_ratio = 0.9354670831343367
# Starting Child 61
# 7 28844
# Done distance matrix: 0.008677005767822266
# Done Generating final pairs: 0.03477644920349121
# best_stitch_pair = [    0 17817]
# best_stitch_pair_size = 39029.69895007492
# best_stitch_pair_distance = 1539.590388123025
# best_stitch_pair_size_ratio = 0.851456133256523
# Starting Child 62
# 16 28844
# Done distance matrix: 0.017033815383911133
# Done Generating final pairs: 0.04230475425720215
# best_stitch_pair = [   0 4262]
# best_stitch_pair_size = 376005.9467675752
# best_stitch_pair_distance = 1903.465284119008
# best_stitch_pair_size_ratio = 0.3824547875537096
# Starting Child 63
# 3 28844
# Done distance matrix: 0.004494667053222656
# Done Generating final pairs: 0.035393476486206055
# best_stitch_pair = [    2 20600]
# best_stitch_pair_size = 40578.58474722924
# best_stitch_pair_distance = 1417.5686716744078
# best_stitch_pair_size_ratio = 0.5841659467630752
# Starting Child 64
# 10 28844
# Done distance matrix: 0.049277544021606445
# Done Generating final pairs: 0.08650875091552734
# best_stitch_pair = [    0 26731]
# best_stitch_pair_size = 85048.4714505177
# best_stitch_pair_distance = 1242.137842641143
# best_stitch_pair_size_ratio = 0.21398016269181608
# Starting Child 65
# 4 28844
# Done distance matrix: 0.008477926254272461
# Done Generating final pairs: 0.05161142349243164
# best_stitch_pair = [    0 24347]
# best_stitch_pair_size = 28510.101806394923
# best_stitch_pair_distance = 1899.2825167459152
# best_stitch_pair_size_ratio = 0.5555623159049711
# Starting Child 66
# 5 28844
# Done distance matrix: 0.006410360336303711
# Done Generating final pairs: 0.030323028564453125
# best_stitch_pair = [    3 10725]
# best_stitch_pair_size = 111209.78406187009
# best_stitch_pair_distance = 1827.5304579179517
# best_stitch_pair_size_ratio = 0.1816626389623162
# Starting Child 67
# 11 28844
# Done distance matrix: 0.013926029205322266
# Done Generating final pairs: 0.04822492599487305
# best_stitch_pair = [    0 24787]
# best_stitch_pair_size = 469399.66610400885
# best_stitch_pair_distance = 760.716183760657
# best_stitch_pair_size_ratio = 0.7309985980006527
# Starting Child 68
# 10 28844
# Done distance matrix: 0.023385047912597656
# Done Generating final pairs: 0.0651407241821289
# best_stitch_pair = [   1 4262]
# best_stitch_pair_size = 350557.45058108534
# best_stitch_pair_distance = 1697.471671450531
# best_stitch_pair_size_ratio = 0.28888872645414315
# Starting Child 69
# 2 28844
# Done distance matrix: 0.0023641586303710938
# Done Generating final pairs: 0.02051067352294922
# best_stitch_pair = [    0 23520]
# best_stitch_pair_size = 98856.79004569905
# best_stitch_pair_distance = 1549.912933175484
# best_stitch_pair_size_ratio = 0.6601359071517429
# Starting Child 70
# 3 28844
# Done distance matrix: 0.0034072399139404297
# Child 70 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 71
# 7 28844
# Done distance matrix: 0.03159070014953613
# Done Generating final pairs: 0.05229306221008301
# best_stitch_pair = [    5 24075]
# best_stitch_pair_size = 145842.56393051063
# best_stitch_pair_distance = 1988.497710957336
# best_stitch_pair_size_ratio = 0.4379955077493777
# Starting Child 72
# 11 28844
# Done distance matrix: 0.011780500411987305
# Done Generating final pairs: 0.03345012664794922
# best_stitch_pair = [    3 24083]
# best_stitch_pair_size = 43981.08572246965
# best_stitch_pair_distance = 1578.5189480651616
# best_stitch_pair_size_ratio = 0.25959519922119073
# Starting Child 73
# 10 28844
# Done distance matrix: 0.01071619987487793
# Done Generating final pairs: 0.02976059913635254
# best_stitch_pair = [    2 14798]
# best_stitch_pair_size = 60007.66367799245
# best_stitch_pair_distance = 1789.8259972160965
# best_stitch_pair_size_ratio = 0.5003861371323263
# Starting Child 74
# 11 28844
# Done distance matrix: 0.011830806732177734
# Done Generating final pairs: 0.030753135681152344
# best_stitch_pair = [    7 18725]
# best_stitch_pair_size = 59672.402386442845
# best_stitch_pair_distance = 1692.2591520611109
# best_stitch_pair_size_ratio = 0.7140631639573491
# Starting Child 75
# 9 28844
# Done distance matrix: 0.009734392166137695
# Done Generating final pairs: 0.029554128646850586
# best_stitch_pair = [   8 5603]
# best_stitch_pair_size = 95601.6752803482
# best_stitch_pair_distance = 1236.4689324606904
# best_stitch_pair_size_ratio = 0.3518937808658443
# Starting Child 76
# 15 28844
# Done distance matrix: 0.018056869506835938
# Done Generating final pairs: 0.043869733810424805
# best_stitch_pair = [   9 9872]
# best_stitch_pair_size = 32737.690187112523
# best_stitch_pair_distance = 1513.0958743181338
# best_stitch_pair_size_ratio = 0.7498228030057658
# Starting Child 77
# 4 28844
# Done distance matrix: 0.005999326705932617
# Done Generating final pairs: 0.0347440242767334
# best_stitch_pair = [    3 25104]
# best_stitch_pair_size = 23187.324585494047
# best_stitch_pair_distance = 1850.9958810992787
# best_stitch_pair_size_ratio = 0.6737658610491921
# Starting Child 78
# 16 28844
# Done distance matrix: 0.02259969711303711
# Done Generating final pairs: 0.05232858657836914
# best_stitch_pair = [    6 25053]
# best_stitch_pair_size = 123741.30149818039
# best_stitch_pair_distance = 1986.1810642088114
# best_stitch_pair_size_ratio = 0.7206277565516117
# Starting Child 79
# 7 28844
# Done distance matrix: 0.00999593734741211
# Done Generating final pairs: 0.043863534927368164
# best_stitch_pair = [   5 7477]
# best_stitch_pair_size = 79859.66236954593
# best_stitch_pair_distance = 1209.9990171089464
# best_stitch_pair_size_ratio = 0.30719626152865276
# Starting Child 80
# 7 28844
# Done distance matrix: 0.007543802261352539
# Done Generating final pairs: 0.02614307403564453
# best_stitch_pair = [    6 19796]
# best_stitch_pair_size = 50567.045513532496
# best_stitch_pair_distance = 1739.866285455871
# best_stitch_pair_size_ratio = 0.5971760128299682
# Starting Child 81
# 7 28844
# Done distance matrix: 0.007723331451416016
# Done Generating final pairs: 0.025743961334228516
# best_stitch_pair = [    6 23989]
# best_stitch_pair_size = 25870.928922104264
# best_stitch_pair_distance = 1917.5501719694114
# best_stitch_pair_size_ratio = 0.41522826271814955
# Starting Child 82
# 7 28844
# Done distance matrix: 0.007455110549926758
# Done Generating final pairs: 0.025425434112548828
# best_stitch_pair = [    6 17812]
# best_stitch_pair_size = 42240.88006459855
# best_stitch_pair_distance = 1761.8426357222884
# best_stitch_pair_size_ratio = 0.2711426441496281
# Starting Child 83
# 2 28844
# Done distance matrix: 0.004795074462890625
# Done Generating final pairs: 0.05691981315612793
# best_stitch_pair = [ 1 35]
# best_stitch_pair_size = 98885.13541783963
# best_stitch_pair_distance = 1647.360697272782
# best_stitch_pair_size_ratio = 0.15036698970601142
# Starting Child 84
# 6 28844
# Done distance matrix: 0.006432533264160156
# Done Generating final pairs: 0.023982524871826172
# best_stitch_pair = [    5 14972]
# best_stitch_pair_size = 21934.88959598854
# best_stitch_pair_distance = 1875.861517983967
# best_stitch_pair_size_ratio = 0.7171984329218037
# Starting Child 85
# 5 28844
# Done distance matrix: 0.005494117736816406
# Done Generating final pairs: 0.0241391658782959
# best_stitch_pair = [    4 14972]
# best_stitch_pair_size = 26879.838832694015
# best_stitch_pair_distance = 1160.3701706470351
# best_stitch_pair_size_ratio = 0.5170409572310555
# Starting Child 86
# 6 28844
# Done distance matrix: 0.009254217147827148
# Done Generating final pairs: 0.03820347785949707
# best_stitch_pair = [    1 14922]
# best_stitch_pair_size = 75420.79068154863
# best_stitch_pair_distance = 1561.2767575754858
# best_stitch_pair_size_ratio = 0.19523721859928872
# Starting Child 87
# 15 28844
# Done distance matrix: 0.023413658142089844
# Done Generating final pairs: 0.06941604614257812
# best_stitch_pair = [    2 25857]
# best_stitch_pair_size = 133219.25642792915
# best_stitch_pair_distance = 1970.1576925869945
# best_stitch_pair_size_ratio = 0.16060963270175133
# Starting Child 88
# 3 28844
# Done distance matrix: 0.004408836364746094
# Child 88 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 89
# 8 28844
# Done distance matrix: 0.008452177047729492
# Done Generating final pairs: 0.02656078338623047
# best_stitch_pair = [   6 6347]
# best_stitch_pair_size = 82037.56151424772
# best_stitch_pair_distance = 1371.1636631130048
# best_stitch_pair_size_ratio = 0.18512833322796673
# Starting Child 90
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 91
# 4 28844
# Done distance matrix: 0.0058133602142333984
# Done Generating final pairs: 0.035155296325683594
# best_stitch_pair = [   2 1069]
# best_stitch_pair_size = 62437.725703614036
# best_stitch_pair_distance = 1800.3976235486884
# best_stitch_pair_size_ratio = 0.3535068741647815
# Starting Child 92
# 13 28844
# Done distance matrix: 0.012305021286010742
# Done Generating final pairs: 0.030199050903320312
# best_stitch_pair = [   7 4093]
# best_stitch_pair_size = 41097.50598798356
# best_stitch_pair_distance = 1940.9949016925689
# best_stitch_pair_size_ratio = 0.6715559699192263
# Starting Child 93
# 9 28844
# Done distance matrix: 0.009941816329956055
# Child 93 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 94
# 8 28844
# Done distance matrix: 0.008853435516357422
# Done Generating final pairs: 0.02763843536376953
# best_stitch_pair = [    4 21480]
# best_stitch_pair_size = 62464.74758076976
# best_stitch_pair_distance = 1703.5879818056542
# best_stitch_pair_size_ratio = 0.2683518783082324
# Starting Child 95
# 37 28844
# Done distance matrix: 0.04698038101196289
# Done Generating final pairs: 0.08162951469421387
# best_stitch_pair = [ 22 439]
# best_stitch_pair_size = 55674.31412054342
# best_stitch_pair_distance = 1937.1506298823126
# best_stitch_pair_size_ratio = 0.4807026264527667
# Starting Child 96
# 16 28844
# Done distance matrix: 0.015430450439453125
# Done Generating final pairs: 0.05008053779602051
# best_stitch_pair = [  3 469]
# best_stitch_pair_size = 27331.96476835183
# best_stitch_pair_distance = 945.1963235610065
# best_stitch_pair_size_ratio = 0.8064264910038369
# Starting Child 97
# 4 28844
# Done distance matrix: 0.00442957878112793
# Done Generating final pairs: 0.022526979446411133
# best_stitch_pair = [   3 3257]
# best_stitch_pair_size = 117512.40329983487
# best_stitch_pair_distance = 1906.327114019361
# best_stitch_pair_size_ratio = 0.6521883820757722
# Starting Child 98
# 11 28844
# Done distance matrix: 0.01185750961303711
# Done Generating final pairs: 0.02958369255065918
# best_stitch_pair = [    8 17812]
# best_stitch_pair_size = 82641.33060604101
# best_stitch_pair_distance = 1649.2936496191076
# best_stitch_pair_size_ratio = 0.6725393825784134
# Starting Child 99
# 2 28844
# Done distance matrix: 0.002367258071899414
# Done Generating final pairs: 0.01910853385925293
# best_stitch_pair = [   0 3486]
# best_stitch_pair_size = 36214.05124859296
# best_stitch_pair_distance = 1446.6776593028333
# best_stitch_pair_size_ratio = 0.28383677748374253
# Starting Child 100
# 9 28844
# Done distance matrix: 0.00985407829284668
# Done Generating final pairs: 0.027463674545288086
# best_stitch_pair = [   0 2254]
# best_stitch_pair_size = 33883.209956205115
# best_stitch_pair_distance = 916.0090774955794
# best_stitch_pair_size_ratio = 0.4903262476979932
# Starting Child 101
# 15 28844
# Done distance matrix: 0.019226789474487305
# Done Generating final pairs: 0.06547880172729492
# best_stitch_pair = [   0 8861]
# best_stitch_pair_size = 614054.4740280516
# best_stitch_pair_distance = 1613.937886060265
# best_stitch_pair_size_ratio = 0.9337855832657312
# Starting Child 102
# 11 28844
# Done distance matrix: 0.01930379867553711
# Done Generating final pairs: 0.055976152420043945
# best_stitch_pair = [   1 9055]
# best_stitch_pair_size = 71310.11095336909
# best_stitch_pair_distance = 1380.510988127312
# best_stitch_pair_size_ratio = 0.6695120920216439
# Starting Child 103
# 26 28844
# Done distance matrix: 0.03826451301574707
# Done Generating final pairs: 0.09536910057067871
# best_stitch_pair = [   19 16930]
# best_stitch_pair_size = 47061.656158820915
# best_stitch_pair_distance = 1657.8884402510303
# best_stitch_pair_size_ratio = 0.2321204521070136
# Starting Child 104
# 11 28844
# Done distance matrix: 0.016318082809448242
# Done Generating final pairs: 0.0367887020111084
# best_stitch_pair = [    5 12221]
# best_stitch_pair_size = 79316.91541956112
# best_stitch_pair_distance = 1980.069172828903
# best_stitch_pair_size_ratio = 0.7618484736579458
# Starting Child 105
# 31 28844
# Done distance matrix: 0.030354976654052734
# Done Generating final pairs: 0.052123069763183594
# best_stitch_pair = [   22 24696]
# best_stitch_pair_size = 52811.62239342161
# ...
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09277462959289551
# returned from stitch mesh: 2.8982417583465576
# Finished stitching child 32 : 3.378723382949829
# ---Stitching child 33 with pair: [1, 48523]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2117744, starting edge 2nd facet= 2468131,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.2874603271484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09488439559936523
# returned from stitch mesh: 3.716085433959961
# Finished stitching child 33 : 4.2635369300842285
# ***************Finished big stitching iteration: 40.84031128883362***************
# Starting Child 4
# 83 56152
# Done distance matrix: 0.20085382461547852
# Done Generating final pairs: 0.2186598777770996
# best_stitch_pair = [    5 56010]
# best_stitch_pair_size = 541000.4502433065
# best_stitch_pair_distance = 1889.6799951100263
# best_stitch_pair_size_ratio = 0.2759755595724654
# Starting Child 7
# 66 56152
# Done distance matrix: 0.2001335620880127
# Done Generating final pairs: 0.21271228790283203
# best_stitch_pair = [   10 56087]
# best_stitch_pair_size = 728423.2347977678
# best_stitch_pair_distance = 1252.2091035615188
# best_stitch_pair_size_ratio = 0.17989332021886834
# Starting Child 17
# 44 56152
# Done distance matrix: 0.11469364166259766
# Child 17 There were no points close enough
# Starting Child 18
# 29 56152
# Done distance matrix: 0.06133151054382324
# Child 18 There were no points close enough
# Starting Child 19
# 12 56152
# Done distance matrix: 0.021648168563842773
# Child 19 There were no points close enough
# Starting Child 20
# 14 56152
# Done distance matrix: 0.026418685913085938
# Child 20 There were no points close enough
# Starting Child 21
# 13 56152
# Done distance matrix: 0.02474069595336914
# Child 21 There were no points close enough
# Starting Child 22
# 2 56152
# Done distance matrix: 0.007674694061279297
# Child 22 There were no points close enough
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56152
# Done distance matrix: 0.0026352405548095703
# Child 30 There were no points close enough
# Starting Child 35
# 21 56152
# Done distance matrix: 0.05443263053894043
# Child 35 There were no points close enough
# Starting Child 36
# 18 56152
# Done distance matrix: 0.04561734199523926
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [5, 56010], 7: [10, 56087]}
# ---Stitching child 4 with pair: [5, 56010]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2467019, starting edge 2nd facet= 2468296,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 23
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.8848648071289062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07921004295349121
# returned from stitch mesh: 3.442870616912842
# Finished stitching child 4 : 3.8976781368255615
# ---Stitching child 7 with pair: [10, 56087]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2467743, starting edge 2nd facet= 2470063,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 19
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.6716461181640625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.048844337463378906
# returned from stitch mesh: 4.126654148101807
# Finished stitching child 7 : 4.605384349822998
# ***************Finished big stitching iteration: 13.043132543563843***************
# Starting Child 17
# 44 56297
# Done distance matrix: 0.10713839530944824
# Done Generating final pairs: 0.14333486557006836
# best_stitch_pair = [    6 56232]
# best_stitch_pair_size = 860607.055137608
# best_stitch_pair_distance = 1081.0510624945828
# best_stitch_pair_size_ratio = 0.8039344526907731
# Starting Child 18
# 29 56297
# Done distance matrix: 0.07402539253234863
# Child 18 There were no points close enough
# Starting Child 19
# 12 56297
# Done distance matrix: 0.02277088165283203
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# 14 56297
# Done distance matrix: 0.02895331382751465
# Done Generating final pairs: 0.05160689353942871
# best_stitch_pair = [    0 56232]
# best_stitch_pair_size = 768878.882646648
# best_stitch_pair_distance = 271.36398318654255
# best_stitch_pair_size_ratio = 0.6116613244948319
# Starting Child 21
# 13 56297
# Done distance matrix: 0.033158302307128906
# Child 21 There were no points close enough
# Starting Child 22
# 2 56297
# Done distance matrix: 0.0074939727783203125
# Done Generating final pairs: 0.033945560455322266
# best_stitch_pair = [    0 56249]
# best_stitch_pair_size = 116838.99853742702
# best_stitch_pair_distance = 1985.9331900567768
# best_stitch_pair_size_ratio = 0.18567647582312613
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56297
# Done distance matrix: 0.0019271373748779297
# Child 30 There were no points close enough
# Starting Child 35
# 21 56297
# Done distance matrix: 0.04043292999267578
# Child 35 There were no points close enough
# Starting Child 36
# 18 56297
# Done distance matrix: 0.03512692451477051
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = [56232]
# child_mesh_double_indexes = [17, 20]
# min_child = 20, max_ratio = 271.36398318654255
# child_meshes_stitch_facets = {20: [0, 56232], 22: [0, 56249]}
# ---Stitching child 20 with pair: [0, 56232]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2469913, starting edge 2nd facet= 2470090,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 33
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 16
# About to add faces
# Finished adding faces: 4.172325134277344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0749359130859375
# returned from stitch mesh: 2.7526090145111084
# Finished stitching child 20 : 3.270781993865967
# ---Stitching child 22 with pair: [0, 56249]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2469616, starting edge 2nd facet= 2470231,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.7404556274414062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0780181884765625
# returned from stitch mesh: 2.725641965866089
# Finished stitching child 22 : 3.175424814224243
# ***************Finished big stitching iteration: 10.586821794509888***************
# Starting Child 17
# 44 56309
# Done distance matrix: 0.08430099487304688
# Done Generating final pairs: 0.1061255931854248
# best_stitch_pair = [    6 56238]
# best_stitch_pair_size = 744980.8370158876
# best_stitch_pair_distance = 1501.3840032962728
# best_stitch_pair_size_ratio = 0.9424073460190533
# Starting Child 18
# 29 56309
# Done distance matrix: 0.05368161201477051
# Done Generating final pairs: 0.055830955505371094
# best_stitch_pair = [   20 56300]
# best_stitch_pair_size = 205933.24799601224
# best_stitch_pair_distance = 1960.295019813424
# best_stitch_pair_size_ratio = 0.20397718265847092
# Starting Child 19
# 12 56309
# Done distance matrix: 0.0210421085357666
# Done Generating final pairs: 0.026958703994750977
# best_stitch_pair = [    2 56298]
# best_stitch_pair_size = 363231.70021697535
# best_stitch_pair_distance = 1712.396670473509
# best_stitch_pair_size_ratio = 0.7031983759412552
# Starting Child 21
# 13 56309
# Done distance matrix: 0.02445530891418457
# Child 21 There were no points close enough
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56309
# Done distance matrix: 0.0021414756774902344
# Child 30 There were no points close enough
# Starting Child 35
# 21 56309
# Done distance matrix: 0.0391697883605957
# Child 35 There were no points close enough
# Starting Child 36
# 18 56309
# Done distance matrix: 0.03348946571350098
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {17: [6, 56238], 18: [20, 56300], 19: [2, 56298]}
# ---Stitching child 17 with pair: [6, 56238]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2469646, starting edge 2nd facet= 2470324,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 26
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 12
# About to add faces
# Finished adding faces: 5.1021575927734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11801290512084961
# returned from stitch mesh: 3.751674175262451
# Finished stitching child 17 : 4.306270122528076
# ---Stitching child 18 with pair: [20, 56300]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2470120, starting edge 2nd facet= 2470676,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12100005149841309
# returned from stitch mesh: 2.8879013061523438
# Finished stitching child 18 : 3.506833076477051
# ---Stitching child 19 with pair: [2, 56298]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2470196, starting edge 2nd facet= 2470865,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08270883560180664
# returned from stitch mesh: 2.6833178997039795
# Finished stitching child 19 : 3.1663382053375244
# ***************Finished big stitching iteration: 14.526420593261719***************
# Starting Child 21
# 13 56388
# Done distance matrix: 0.026230335235595703
# Done Generating final pairs: 0.03590083122253418
# best_stitch_pair = [    1 56378]
# best_stitch_pair_size = 691542.4263829679
# best_stitch_pair_distance = 1382.1211610559144
# best_stitch_pair_size_ratio = 0.7594008940487499
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56388
# Done distance matrix: 0.0025665760040283203
# Child 30 There were no points close enough
# Starting Child 35
# 21 56388
# Done distance matrix: 0.0526430606842041
# Child 35 There were no points close enough
# Starting Child 36
# 18 56388
# Done distance matrix: 0.04059767723083496
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {21: [1, 56378]}
# ---Stitching child 21 with pair: [1, 56378]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2470885, starting edge 2nd facet= 2470942,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.409385681152344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0158689022064209
# returned from stitch mesh: 4.04052734375
# Finished stitching child 21 : 4.526554822921753
# ***************Finished big stitching iteration: 7.780820846557617***************
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56399
# Done distance matrix: 0.0022575855255126953
# Child 30 There were no points close enough
# Starting Child 35
# 21 56399
# Done distance matrix: 0.050481319427490234
# Child 35 There were no points close enough
# Starting Child 36
# 18 56399
# Done distance matrix: 0.045067548751831055
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56399
# Done distance matrix: 0.002332925796508789
# Child 30 There were no points close enough
# Starting Child 35
# 21 56399
# Done distance matrix: 0.04091048240661621
# Child 35 There were no points close enough
# Starting Child 36
# 18 56399
# Done distance matrix: 0.03347063064575195
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56399
# Done distance matrix: 0.002366781234741211
# Child 30 There were no points close enough
# Starting Child 35
# 21 56399
# Done distance matrix: 0.03736257553100586
# Child 35 There were no points close enough
# Starting Child 36
# 18 56399
# Done distance matrix: 0.0317835807800293
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 28
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 30
# 1 56399
# Done distance matrix: 0.0019145011901855469
# Child 30 There were no points close enough
# Starting Child 35
# 21 56399
# Done distance matrix: 0.03621983528137207
# Child 35 There were no points close enough
# Starting Child 36
# 18 56399
# Done distance matrix: 0.03126072883605957
# Child 36 There were no points close enough
# Starting Child 37
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 177.0951645374298
# Total time for restitching = 177.10653018951416
# missed_children = [35.0, 36.0, 37.0, 38.0, 28.0, 30.0]
# Whole stitching function complete: 391.7099893093109
# 6108.006008863449

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
