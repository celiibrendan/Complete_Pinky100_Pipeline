# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349497094******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09226441383361816
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1008.7701463699341
# 2) Finished: Generating CGAL segmentation for neuron: 1030.3090584278107
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.33978724479675293
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [4, 26, 24, 7, 223, 191, 58, 31, 8, 219, 176, 165, 93, 238, 212, 157]
# soma_80_percent = 220870.421875
# Debugging the axon filter
# [(4, 217193.140625), (26, 222251.265625), (24, 253809.0), (7, 226088.984375), (223, 229155.125), (191, 227989.359375), (58, 249982.46875), (31, 248462.03125), (8, 239949.3125), (219, 224824.5625), (176, 227133.359375), (165, 222300.5), (93, 232559.734375), (238, 220274.859375), (212, 226232.71875), (157, 227443.203125)]
# possible_Axons_filter_1 = [4, 238]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.17112326622009277
# 6) Staring: Classifying Entire Neuron
# 165 = cilia
# 93 = stub soma
# 157 = stub soma
# 176 = stub soma
# 191 = stub soma
# 212 = stub soma
# 219 = stub soma
# 223 = stub soma
# 238 = stub soma
# 25 = stub apical
# 30 = stub apical
# 32 = stub apical
# 34 = error
# 37 = stub apical
# 39 = stub apical
# 42 = stub apical
# 48 = stub apical
# 52 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 59 = stub apical
# 60 = stub apical
# 63 = stub apical
# 66 = stub apical
# 70 = error
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 75 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 94 = stub apical
# 95 = stub apical
# 97 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 106 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 124 = stub apical
# 125 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 158 = stub apical
# 163 = stub apical
# 164 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 174 = stub apical
# 175 = stub apical
# 177 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 224 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 230 = stub apical
# 232 = stub apical
# 233 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# Total Labels found = {'oblique', 'soma', 'error', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.5517446994781494
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5631210803985596
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.733910322189331
# Finished Auto Labeling: 1047.7033054828644
#
#
# *****Starting Auto Labeling for 648518346349499896******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.031339406967163086
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 465.2011821269989
# 2) Finished: Generating CGAL segmentation for neuron: 478.3029263019562
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.17326140403747559
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [17, 4, 8, 9, 20, 39, 203, 250, 281]
# soma_80_percent = 200928.0953125
# Debugging the axon filter
# [(17, 223960.296875), (4, 209980.125), (8, 199303.9375), (9, 211981.859375), (20, 228033.765625), (39, 230485.375), (203, 198101.859375), (250, 197500.890625), (281, 199849.875)]
# possible_Axons_filter_1 = [8, 203, 250, 281]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.0969991683959961
# 6) Staring: Classifying Entire Neuron
# 203 = stub soma
# 281 = cilia
# 250 = stub soma
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.5995464324951172
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6437475681304932
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.851953268051147
# Finished Auto Labeling: 490.3886926174164
#
#
# *****Starting Auto Labeling for 648518346349500440******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05357480049133301
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 808.2319633960724
# 2) Finished: Generating CGAL segmentation for neuron: 828.0352907180786
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2662637233734131
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [4, 40, 7, 214, 235, 11, 156, 19, 246, 22, 47, 261, 72, 29, 91, 252, 158, 140, 203]
# soma_80_percent = 258433.6796875
# Debugging the axon filter
# [(4, 256468.125), (40, 267840.0625), (7, 275693.53125), (214, 261114.46875), (235, 262248.5), (11, 284237.90625), (156, 265799.5), (19, 276388.53125), (246, 266413.53125), (22, 266967.78125), (47, 279366.59375), (261, 265971.9375), (72, 263042.15625), (29, 263282.125), (91, 255350.40625), (252, 266777.125), (158, 265000.03125), (140, 264006.125), (203, 266759.78125)]
# possible_Axons_filter_1 = [4, 91]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.17312979698181152
# 6) Staring: Classifying Entire Neuron
# 19 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 22
# 40 = axon
# 72 = stub soma
# 91 = cilia
# 140 = stub soma
# 156 = stub soma
# 158 = stub soma
# 203 = stub soma
# 214 = stub soma
# 235 = stub soma
# 246 = stub soma
# 252 = stub soma
# 261 = stub soma
# 0 = error
# 17 = stub apical
# 20 = stub apical
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = error
# 45 = stub apical
# 46 = stub apical
# 49 = error
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 55 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 138 = stub apical
# 139 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 146 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 157 = error
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 245 = stub apical
# 247 = stub apical
# 248 = stub apical
# 250 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 260 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# Total Labels found = {'axon', 'oblique', 'soma', 'error', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.2029504776000977
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.49764561653137207
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.915369987487793
# Finished Auto Labeling: 843.7918365001678
#
#
# *****Starting Auto Labeling for 648518346349502049******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05477499961853027
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 758.7570707798004
# 2) Finished: Generating CGAL segmentation for neuron: 775.524341583252
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.20352745056152344
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [9, 20, 38, 6, 79, 27, 87, 11, 30, 21, 13, 80, 100, 97]
# soma_80_percent = 159477.8578125
# Debugging the axon filter
# [(9, 165344.0), (20, 171081.796875), (38, 166404.234375), (6, 169805.390625), (79, 165401.140625), (27, 169307.53125), (87, 166196.9375), (11, 156821.375), (30, 174710.03125), (21, 175514.046875), (13, 184333.546875), (80, 164972.84375), (100, 166727.765625), (97, 164203.125)]
# possible_Axons_filter_1 = [11]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.06879806518554688
# 6) Staring: Classifying Entire Neuron
# 20 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 87
# 79 = stub soma
# 80 = stub soma
# 97 = stub soma
# 100 = stub soma
# Total Labels found = {'axon', 'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.817047357559204
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6518230438232422
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.35755968093872
# Finished Auto Labeling: 788.3707084655762
#
#
# *****Starting Auto Labeling for 648518346349504565******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.018336772918701172
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 183.98759627342224
# 2) Finished: Generating CGAL segmentation for neuron: 191.19298458099365
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.09404897689819336
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [23, 0, 15, 17, 101, 14, 57, 73, 56, 88, 77, 55]
# soma_80_percent = 181934.440625
# Debugging the axon filter
# [(23, 187915.984375), (0, 179980.265625), (15, 190855.359375), (17, 197990.8125), (101, 186115.953125), (14, 183868.109375), (57, 180384.453125), (73, 186367.953125), (56, 181130.71875), (88, 179882.359375), (77, 188992.53125), (55, 184289.046875)]
# possible_Axons_filter_1 = [0, 57, 56, 88]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.03996443748474121
# 6) Staring: Classifying Entire Neuron
# 55 = stub soma
# 56 = stub soma
# 57 = stub soma
# 73 = stub soma
# 77 = stub soma
# 88 = cilia
# 101 = stub soma
# 5 = stub apical
# 10 = stub apical
# 13 = stub apical
# 18 = stub apical
# 19 = stub apical
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 63 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 79 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# Total Labels found = {'oblique', 'soma', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.0457780361175537
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.19651269912719727
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.050231218338013
# Finished Auto Labeling: 196.97682905197144
#
#
# *****Starting Auto Labeling for 648518346349504955******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0677342414855957
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1018.8909220695496
# 2) Finished: Generating CGAL segmentation for neuron: 1039.1470394134521
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 13
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.25519299507141113
# 5) Staring: Finding Apical Index
# Soma Index = 13
# Soma Connections = [15, 25, 0, 32, 30, 291, 27, 232, 17, 231, 266, 267, 240, 145, 146]
# soma_80_percent = 269770.615625
# Debugging the axon filter
# [(15, 297141.1875), (25, 292046.8125), (0, 266734.71875), (32, 283358.6875), (30, 276087.71875), (291, 273430.8125), (27, 290457.6875), (232, 277997.6875), (17, 277787.59375), (231, 268877.90625), (266, 265778.53125), (267, 278829.09375), (240, 267151.5625), (145, 278086.90625), (146, 278421.28125)]
# possible_Axons_filter_1 = [0, 231, 266, 240]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.14153528213500977
# 6) Staring: Classifying Entire Neuron
# 145 = stub soma
# 146 = stub soma
# 231 = cilia
# 240 = stub soma
# 266 = stub soma
# 267 = stub soma
# 291 = stub soma
# 11 = stub apical
# 21 = stub apical
# 22 = stub apical
# 24 = stub apical
# 26 = stub apical
# 31 = stub apical
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 42 = error
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 69 = stub apical
# 70 = error
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 101 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 237 = stub apical
# 238 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 283 = stub apical
# 284 = stub apical
# 289 = stub apical
# 290 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# Total Labels found = {'oblique', 'error', 'soma', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.689406156539917
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4841926097869873
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.58085322380066
# Finished Auto Labeling: 1055.0576837062836
#
#
# *****Starting Auto Labeling for 648518346349506684******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03633403778076172
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 653.9257590770721
# 2) Finished: Generating CGAL segmentation for neuron: 669.0431265830994
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.18732404708862305
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [3, 12, 14, 24, 19, 53, 20, 25, 18, 32, 55, 36, 56, 49, 31, 48, 54, 62, 52]
# soma_80_percent = 165931.4484375
# Debugging the axon filter
# [(3, 175406.859375), (12, 172516.8125), (14, 174232.78125), (24, 175139.453125), (19, 187286.96875), (53, 175249.171875), (20, 166466.75), (25, 169115.875), (18, 187540.046875), (32, 168072.859375), (55, 167900.8125), (36, 176281.640625), (56, 163457.375), (49, 177368.9375), (31, 169740.984375), (48, 163583.953125), (54, 176108.609375), (62, 168198.5), (52, 168645.5)]
# possible_Axons_filter_1 = [56, 48]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.06045699119567871
# 6) Staring: Classifying Entire Neuron
# 31 = stub soma
# 32 = stub soma
# 36 = stub soma
# 48 = stub soma
# 49 = stub soma
# 52 = stub soma
# 53 = stub soma
# 54 = stub soma
# 55 = stub soma
# 56 = stub soma
# 62 = stub soma
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.6642279624938965
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5944197177886963
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.212528228759766
# Finished Auto Labeling: 681.3937902450562
#
#
# *****Starting Auto Labeling for 648518346349508772******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.014751195907592773
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 91.46384143829346
# 2) Finished: Generating CGAL segmentation for neuron: 97.27965760231018
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.07260704040527344
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [45, 184, 509, 282, 152, 54, 253, 377, 407, 445, 431, 466, 24, 494, 241, 183, 129, 452, 111, 167, 346, 435, 548, 456, 608, 30, 311, 77, 194, 398, 481, 31, 90, 1, 242, 20, 423, 284, 110, 472, 364, 318, 514, 424, 177, 220, 428, 575, 347, 363, 543, 534, 125, 540, 0, 265, 513, 108, 464, 313, 425, 176, 611, 493, 247, 539, 70, 323, 238, 521, 578, 201, 281, 624, 519, 207, 324, 227, 58, 133, 33, 401, 438, 579, 212, 327, 250, 383, 225, 308, 213, 43, 454, 80, 469, 78, 502, 551, 293, 621, 248, 106, 23, 294, 491, 205, 9, 360, 85, 512, 348, 468, 6, 411, 433, 94, 455, 182, 503, 25, 379, 50, 501, 362, 53, 596, 319, 606, 451, 511, 320, 114, 590, 610, 7, 252, 577, 358, 49, 585, 211, 332, 101, 580, 186, 193, 112, 288, 208, 602, 426, 122, 123, 627, 219, 209, 359, 328, 203, 410, 408, 380, 180, 272, 278, 378, 210, 496, 544, 287, 409, 549, 100, 413, 552, 592, 629, 605, 619, 479, 497, 325, 233, 437, 329, 295, 620, 57, 556, 4, 595, 124, 314, 19, 609, 536, 414, 79, 630, 628, 200, 76, 587, 430, 508, 22, 218, 532, 179, 365, 290, 594, 405, 465, 591, 570, 126, 93, 322, 617, 191, 303, 357, 254, 206, 127, 26, 130, 289, 506, 196, 240, 576, 399, 495, 331, 215, 603, 550, 61, 55, 232, 427, 586, 46, 392, 336, 489, 249, 181, 66, 283, 517, 356, 185, 102, 406, 273, 361, 239, 44, 234, 277, 92, 542, 224, 470, 569, 516, 195, 342, 187, 394, 538, 276, 62, 292, 626, 510, 317, 11, 321, 307, 198, 236, 188, 604, 60, 87, 581, 490, 28, 310, 178, 462, 457, 588, 189, 535, 229, 622, 235, 530, 436, 614, 616, 330, 623, 275, 29, 518, 400, 256, 613, 415, 190, 335, 533, 618, 432, 520, 255, 488, 279]
# soma_80_percent = 193885.203125
# Debugging the axon filter
# [(45, 261271.421875), (184, 262013.8125), (509, 259679.609375), (282, 238007.46875), (152, 266441.5), (54, 192340.1875), (253, 269797.78125), (377, 270919.71875), (407, 243524.8125), (445, 187560.921875), (431, 196600.328125), (466, 238543.71875), (24, 182063.703125), (494, 200910.875), (241, 237582.3125), (183, 255326.046875), (129, 177218.40625), (452, 162605.640625), (111, 217687.765625), (167, 172228.09375), (346, 217371.125), (435, 170825.890625), (548, 218693.765625), (456, 218488.890625), (608, 234229.40625), (30, 233094.734375), (311, 241648.421875), (77, 242405.40625), (194, 244055.09375), (398, 230783.890625), (481, 216914.046875), (31, 207141.25), (90, 207196.109375), (1, 253405.21875), (242, 240941.984375), (20, 192710.078125), (423, 238238.4375), (284, 203922.078125), (110, 250629.703125), (472, 200098.296875), (364, 253833.0625), (318, 201171.796875), (514, 193124.1875), (424, 238914.65625), (177, 213814.0625), (220, 242717.953125), (428, 245857.140625), (575, 256466.609375), (347, 172027.8125), (363, 250652.640625), (543, 229802.859375), (534, 203865.59375), (125, 178551.1875), (540, 163095.890625), (0, 301762.6875), (265, 267476.40625), (513, 262480.4375), (108, 177003.328125), (464, 181839.65625), (313, 185021.796875), (425, 208711.390625), (176, 214836.15625), (611, 207048.421875), (493, 184785.65625), (247, 227207.234375), (539, 162612.984375), (70, 221325.546875), (323, 195502.859375), (238, 206304.546875), (521, 199597.109375), (578, 260431.0625), (201, 229447.46875), (281, 208779.421875), (624, 193896.390625), (519, 225434.9375), (207, 262831.125), (324, 193738.375), (227, 251559.125), (58, 217855.8125), (133, 176164.0625), (33, 244599.0625), (401, 232891.640625), (438, 182102.703125), (579, 268217.125), (212, 265504.5625), (327, 217071.078125), (250, 183451.609375), (383, 188159.46875), (225, 269109.28125), (308, 216000.578125), (213, 172493.8125), (43, 194348.5625), (454, 161916.21875), (80, 236570.046875), (469, 240854.984375), (78, 211907.421875), (502, 216897.5625), (551, 192050.765625), (293, 258543.28125), (621, 186200.671875), (248, 233718.890625), (106, 242865.1875), (23, 255654.953125), (294, 194731.578125), (491, 169858.359375), (205, 233636.015625), (9, 161228.4375), (360, 253834.171875), (85, 205074.6875), (512, 260084.6875), (348, 180956.921875), (468, 239672.578125), (6, 214076.078125), (411, 241948.578125), (433, 196203.375), (94, 221194.171875), (455, 163699.0625), (182, 254461.921875), (503, 218302.609375), (25, 208050.609375), (379, 250137.140625), (50, 231698.734375), (501, 216482.515625), (362, 251738.3125), (53, 188167.1875), (596, 182296.96875), (319, 176923.9375), (606, 186833.046875), (451, 163158.15625), (511, 262609.71875), (320, 176823.609375), (114, 179609.171875), (590, 214240.0), (610, 207208.375), (7, 186995.5625), (252, 270835.1875), (577, 168520.703125), (358, 196288.125), (49, 268710.25), (585, 191917.703125), (211, 262439.34375), (332, 175648.296875), (101, 189462.765625), (580, 268386.5625), (186, 239598.375), (193, 199029.78125), (112, 242683.359375), (288, 218093.5625), (208, 265319.21875), (602, 189084.9375), (426, 246646.90625), (122, 177672.84375), (123, 178517.75), (627, 244343.34375), (219, 243262.5), (209, 266250.84375), (359, 251898.9375), (328, 175317.5), (203, 235670.890625), (410, 243663.5), (408, 244165.984375), (380, 261299.0), (180, 183814.296875), (272, 242027.046875), (278, 204493.171875), (378, 183377.546875), (210, 264622.03125), (496, 166726.3125), (544, 217791.46875), (287, 221837.234375), (409, 243210.34375), (549, 213047.078125), (100, 196886.03125), (413, 201417.546875), (552, 200743.171875), (592, 217877.828125), (629, 235521.515625), (605, 188105.328125), (619, 186018.734375), (479, 173653.65625), (497, 167199.328125), (325, 193809.328125), (233, 207092.015625), (437, 181257.953125), (329, 174656.578125), (295, 215974.34375), (620, 186535.59375), (57, 186835.5625), (556, 246795.140625), (4, 242021.234375), (595, 238436.578125), (124, 177024.35 ...
# possible_Axons_filter_1 = [54, 445, 24, 129, 452, 167, 435, 20, 514, 347, 125, 540, 108, 464, 313, 493, 539, 324, 133, 438, 250, 383, 213, 454, 551, 621, 491, 9, 348, 455, 53, 596, 319, 606, 451, 320, 114, 7, 577, 585, 332, 101, 602, 122, 123, 328, 180, 378, 496, 605, 619, 479, 497, 325, 437, 329, 620, 57, 124, 314, 218, 465, 570, 126, 93, 322, 617, 303, 357, 127, 130, 495, 331, 215, 603, 550, 61, 55, 586, 46, 392, 249, 181, 66, 517, 516, 394, 538, 317, 321, 307, 604, 229, 436, 614, 616, 330, 518, 613, 335, 618, 520]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.16824030876159668
# 6) Staring: Classifying Entire Neuron
# 4 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 6
# 7 = cilia
# 11 = stub soma
# 586 = stub soma
# 19 = cilia
# 20 = cilia
# 22 = cilia
# 23 = stub soma
# 24 = stub soma
# 25 = cilia
# 26 = cilia
# 28 = stub soma
# 29 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 30
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 31
# 33 = axon
# 43 = stub soma
# 44 = stub soma
# 45 = cilia
# 46 = stub soma
# 49 = axon
# 50 = cilia
# 53 = stub soma
# 54 = cilia
# 55 = cilia
# 57 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 58
# 61 = cilia
# 62 = stub soma
# 66 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 70
# 538 = cilia
# 76 = stub soma
# 77 = cilia
# 78 = cilia
# 79 = stub soma
# 80 = stub soma
# 85 = stub soma
# 196 = cilia
# 87 = stub soma
# 90 = cilia
# 93 = cilia
# 94 = cilia
# 100 = stub soma
# 101 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 102
# 106 = cilia
# 108 = stub soma
# 110 = cilia
# 111 = stub soma
# 112 = cilia
# 114 = cilia
# 122 = stub soma
# 123 = stub soma
# 124 = stub soma
# 125 = stub soma
# 126 = stub soma
# 127 = cilia
# 129 = cilia
# 130 = stub soma
# 133 = stub soma
# 152 = stub soma
# 167 = stub soma
# 176 = stub soma
# 178 = cilia
# 179 = cilia
# 181 = stub soma
# 182 = stub soma
# 183 = cilia
# 184 = stub soma
# 185 = stub soma
# 186 = stub soma
# 187 = stub soma
# 188 = stub soma
# 189 = stub soma
# 190 = stub soma
# 191 = stub soma
# 193 = stub soma
# 194 = stub soma
# 195 = stub soma
# 198 = stub soma
# 200 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 201
# 203 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 205
# 206 = cilia
# 207 = stub soma
# 208 = cilia
# 209 = stub soma
# 210 = stub soma
# 211 = stub soma
# 212 = stub soma
# 213 = stub soma
# 215 = stub soma
# 218 = cilia
# 219 = stub soma
# 220 = stub soma
# 224 = stub soma
# 225 = stub soma
# 227 = stub soma
# 229 = stub soma
# 232 = stub soma
# 233 = stub soma
# 234 = stub soma
# 235 = stub soma
# 236 = stub soma
# 238 = stub soma
# 239 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 240
# 241 = stub soma
# 242 = stub soma
# 247 = stub soma
# 248 = stub soma
# 249 = cilia
# 250 = stub soma
# 252 = axon
# 253 = stub soma
# 254 = stub soma
# 255 = stub soma
# 256 = stub soma
# 265 = cilia
# 272 = cilia
# 273 = cilia
# 276 = cilia
# 275 = stub soma
# 277 = cilia
# 279 = stub soma
# 281 = stub soma
# 282 = stub soma
# 283 = stub soma
# 284 = cilia
# 288 = stub soma
# 289 = stub soma
# 290 = stub soma
# 292 = stub soma
# 293 = stub soma
# 294 = stub soma
# 295 = stub soma
# 303 = stub soma
# 307 = stub soma
# 308 = cilia
# 310 = stub soma
# 311 = cilia
# 313 = cilia
# 314 = stub soma
# 317 = cilia
# 318 = stub soma
# 319 = cilia
# 320 = stub soma
# 321 = cilia
# 322 = stub soma
# 323 = stub soma
# 324 = stub soma
# 325 = stub soma
# 327 = cilia
# 328 = cilia
# 329 = cilia
# 330 = stub soma
# 331 = stub soma
# 332 = stub soma
# 335 = cilia
# 336 = cilia
# 342 = stub soma
# 346 = cilia
# 347 = stub soma
# 348 = stub soma
# 356 = stub soma
# 357 = stub soma
# 358 = stub soma
# 359 = stub soma
# 360 = stub soma
# 361 = stub soma
# 362 = stub soma
# 363 = stub soma
# 364 = stub soma
# 365 = stub soma
# 377 = stub soma
# 378 = cilia
# 379 = stub soma
# 380 = stub soma
# 383 = stub soma
# 392 = stub soma
# 394 = stub soma
# 398 = stub soma
# 399 = stub soma
# 400 = cilia
# 401 = stub soma
# 405 = cilia
# 406 = stub soma
# 407 = stub soma
# 408 = stub soma
# 409 = cilia
# 410 = cilia
# 411 = stub soma
# 413 = stub soma
# 414 = cilia
# 415 = stub soma
# 424 = stub soma
# 425 = stub soma
# 426 = cilia
# 427 = stub soma
# 428 = axon
# 430 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 431
# 432 = stub soma
# 433 = stub soma
# 436 = stub soma
# 437 = stub soma
# 438 = stub soma
# 445 = stub soma
# 451 = stub soma
# 452 = stub soma
# 454 = stub soma
# 455 = stub soma
# 456 = stub soma
# 457 = stub soma
# 462 = stub soma
# 464 = cilia
# 465 = stub soma
# 466 = stub soma
# 468 = cilia
# 469 = stub soma
# 470 = stub soma
# 472 = stub soma
# 479 = stub soma
# 481 = stub soma
# 488 = stub soma
# 489 = stub soma
# 490 = stub soma
# 491 = stub soma
# 493 = stub soma
# 494 = cilia
# 495 = cilia
# 496 = cilia
# 497 = cilia
# 501 = cilia
# 502 = stub soma
# 503 = stub soma
# 506 = stub soma
# 508 = stub soma
# 509 = stub soma
# 510 = stub soma
# 511 = stub soma
# 512 = stub soma
# 513 = stub soma
# 516 = stub soma
# 517 = stub soma
# 518 = stub soma
# 519 = cilia
# 520 = stub soma
# 521 = cilia
# 530 = stub soma
# 532 = cilia
# 533 = stub soma
# 534 = cilia
# 535 = stub soma
# 536 = stub soma
# 539 = stub soma
# 540 = stub soma
# 542 = stub soma
# 543 = stub soma
# 544 = stub soma
# 548 = cilia
# 549 = stub soma
# 550 = stub soma
# 551 = stub soma
# 552 = cilia
# 556 = cilia
# 569 = stub soma
# 570 = stub soma
# 575 = cilia
# 576 = stub soma
# 577 = stub soma
# 578 = cilia
# 580 = cilia
# 581 = stub soma
# 585 = stub soma
# 587 = stub soma
# 588 = stub soma
# 590 = stub soma
# 591 = stub soma
# 592 = cilia
# 594 = stub soma
# 595 = stub soma
# 596 = stub soma
# 602 = stub soma
# 603 = stub soma
# 604 = stub soma
# 605 = stub soma
# 606 = stub soma
# 608 = stub soma
# 609 = stub soma
# 610 = stub soma
# 611 = stub soma
# 613 = stub soma
# 614 = stub soma
# 616 = stub soma
# 617 = stub soma
# 618 = stub soma
# 619 = cilia
# 620 = stub soma
# 621 = stub soma
# 622 = stub soma
# 623 = stub soma
# 624 = stub soma
# 626 = stub soma
# 627 = stub soma
# 628 = stub soma
# 629 = stub soma
# 630 = stub soma
# 36 = stub apical
# 8 = stub apical
# 16 = error
# 98 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 151 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 169 = stub apical
# 285 = stub apical
# 306 = stub apical
# 333 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 373 = stub apical
# 453 = stub apical
# 482 = stub apical
# 523 = stub apical
# 563 = stub apical
# 589 = stub apical
# 601 = stub apical
# Total Labels found = {'axon', 'error', 'soma', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.1471025943756104
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.11071014404296875
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.7513909339904785
# Finished Auto Labeling: 101.74430823326111
#
#
# *****Starting Auto Labeling for 648518346349509122******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03618979454040527
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 339.73509407043457
# 2) Finished: Generating CGAL segmentation for neuron: 350.4109444618225
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1341257095336914
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [6, 2, 15, 19, 18, 10, 101, 120, 156, 127, 110, 168, 93]
# soma_80_percent = 225180.5890625
# Debugging the axon filter
# [(6, 221964.03125), (2, 240234.78125), (15, 229236.671875), (19, 253633.453125), (18, 234275.5), (10, 225561.8125), (101, 224599.6875), (120, 234073.21875), (156, 230388.453125), (127, 225177.921875), (110, 234748.546875), (168, 223095.15625), (93, 221247.65625)]
# possible_Axons_filter_1 = [6, 101, 127, 168, 93]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.061438798904418945
# 6) Staring: Classifying Entire Neuron
# 10 = cilia
# 93 = stub soma
# 101 = stub soma
# 110 = stub soma
# 120 = stub soma
# 127 = stub soma
# 156 = stub soma
# 168 = stub soma
# 9 = stub apical
# 13 = stub apical
# 16 = error
# 17 = stub apical
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 25 = error
# 26 = stub apical
# 27 = stub apical
# 30 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 78 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 95 = stub apical
# 96 = stub apical
# 98 = stub apical
# 104 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 111 = stub apical
# 112 = stub apical
# 118 = stub apical
# 121 = stub apical
# 122 = stub apical
# 124 = stub apical
# 126 = stub apical
# 128 = stub apical
# 130 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# Total Labels found = {'oblique', 'soma', 'error', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.2862131595611572
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.2780303955078125
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.117070913314819
# Finished Auto Labeling: 358.7371904850006
#
#
# *****Starting Auto Labeling for 648518346349509410******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07258105278015137
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1279.2574229240417
# 2) Finished: Generating CGAL segmentation for neuron: 1302.6005218029022
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.36704182624816895
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [17, 22, 18, 48, 30, 46, 24, 187, 168, 134, 180, 200, 68]
# soma_80_percent = 257119.2703125
# Debugging the axon filter
# [(17, 259726.234375), (22, 278472.34375), (18, 254341.625), (48, 276233.6875), (30, 265642.1875), (46, 263624.6875), (24, 282185.625), (187, 267594.5), (168, 262680.625), (134, 268405.78125), (180, 264718.0), (200, 253205.46875), (68, 261964.21875)]
# possible_Axons_filter_1 = [18, 200]
# possible_Axons_filter_2 = [18]
# possible_Apical = 18
# 5) Finished: Finding Apical Index: 0.11832880973815918
# 6) Staring: Classifying Entire Neuron
# 200 = cilia
# 68 = stub soma
# 134 = stub soma
# 168 = stub soma
# 180 = stub soma
# 187 = stub soma
# 12 = stub apical
# 20 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 29 = stub apical
# 31 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 45 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 52 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 69 = error
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 136 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 154 = stub apical
# 155 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 169 = stub apical
# 170 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 186 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# Total Labels found = {'oblique', 'soma', 'error', 'cilia', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.3708860874176025
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6408982276916504
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.257376194000244
# Finished Auto Labeling: 1321.2738955020905
# 6888.03089261055

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
