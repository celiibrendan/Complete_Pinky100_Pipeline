# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[:-4]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #check to see if the face_indexes is empty
    if not face_indexes.any():
        #create an empty mesh
        current_mesh = trimesh.Trimesh(np.array([]),np.array([]),process=False)
        return current_mesh,np.array([])
    
    
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
import warnings
from pymeshfix import _meshfix
import pymeshfix

def clean_from_arrays_celii(v, f, verbose=False, joincomp=False,
                      remove_smallest_components=True,clean=True):
    """
    Performs default cleaning procedure on vertex and face arrays
    Returns cleaned vertex and face arrays
    
    Parameters
    ----------
    v : numpy.ndarray
        Numpy n x 3 array of vertices
    f : numpy.ndarray
        Numpy n x 3 array of faces.
    verbose : bool, optional
        Prints progress to stdout.  Default True.
    joincomp : bool, optional
        Attempts to join nearby open components.  Default False
    remove_smallest_components : bool, optional
        Remove all but the largest isolated component from the mesh
        before beginning the repair process.  Default True.
    Examples
    --------
    >>>
    >>> CleanFromFile('inmesh.ply', 'outmesh.ply')
    """
    # Create mesh object and load from file
    tin = _meshfix.PyTMesh(verbose)
    tin.load_array(v, f)

    # repari and return vertex and face arrays
    repair_celii(tin, verbose, joincomp, remove_smallest_components,clean)
    return tin.return_arrays()

#what the repair function does: 
def repair_celii(tin, verbose=False, joincomp=True, remove_smallest_components=True,clean=True):
    """
    Performs mesh repair using default cleaning procedure using a tin object.
    Internal function.  Use CleanFromFile or CleanFromVF.
    """

    # Keep only the largest component (i.e. with most triangles)
    if remove_smallest_components:
        sc = tin.remove_smallest_components()
        if sc and verbose:
            print('Removed %d small components' % sc)

    # join closest components
    if joincomp:
        tin.join_closest_components()
    
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
    
        
    tin.boundaries()
    if clean == True:
        # Perform mesh cleaning
        if verbose:
            print('Fixing degeneracies and intersections')
        result = tin.clean()
    else:
        print("Skipping the degenerative cleaning")
        result = False

    # Check boundaries again
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
        if verbose:
            print('Performing final check...')
        if clean == True:
            if verbose:
                print('Fixing degeneracies and intersections')
            result = tin.clean()
        else:
            print("Skipping the degenerative cleaning")
            result = False

    if result:
        warnings.warn('MeshFix could not fix everything')

# %%
@schema
class NeuronSkeletonStitched(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """
    
    
    key_source = ((dj.U("segmentation","segment_id") & pinky.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & pinky.CoarseLabelOrphan.proj()))
    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        mesh,face_indexes = get_mesh_minus_errors_and_spines(key)
        
        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])
        
        """
        Handle the poosibility that there is no mesh
        """
        if len(mesh.faces) < 50:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
        
                #send the data through the hole patching function from pymesh:
                cleaned_verts, cleaned_triangles= clean_from_arrays_celii(m.vertices,m.faces,verbose=True,joincomp=True,remove_smallest_components=False,clean=False)
                #cleaned_mesh = make_trimesh_object(m.vertices,m.faces)
            
            
        
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),cleaned_verts, cleaned_triangles)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                
                
                meshlab_script_2 = str(pathlib.Path.cwd()) + "/" + "remove_intersecting_faces.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(output_mesh,key["segment_id"],meshlab_script_2)
                
                print("About to run pymeshfix")
                start_time_py = time.time()
                loaded_mesh = trimesh.load_mesh(output_mesh,process=False)
                meshfix = pymeshfix.MeshFix(loaded_mesh.vertices,loaded_mesh.faces)
                meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                print(f"Total time for pymeshfix = {time.time() - start_time_py}")
                
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v, meshfix.f)
                
                
                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(path_and_filename)

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(path_and_filename + ".off")

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(path_and_filename)
                if return_value > 0:
                    raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                    

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(path_and_filename+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'" & "status='error'").delete()

# %%
#NeuronSkeletonStitched & "segment_id=neuron648518346349487734"

# %%
start = time.time()
NeuronSkeletonStitched.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346349475526:----------
# Step 1: Retrieving Mesh and removing error segments: 0.7436833381652832
# There were 453 after split and significance threshold
# There were 8 after split and significance threshold
# Mesh piece 0 with number of faces 428642
# Mesh piece 1 with number of faces 286
# Mesh piece 2 with number of faces 291
# Mesh piece 3 with number of faces 1679
# Mesh piece 4 with number of faces 615
# Mesh piece 5 with number of faces 265
# Mesh piece 6 with number of faces 995
# Mesh piece 7 with number of faces 204
# Step 2a: Getting the number of splits: 0.555741548538208
# largest mesh perc = 0.9824411017114253
# Working on split 0 with face total = 428642
# Patching holes...
# Patched 756 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 31.697381734848022
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 88.31139969825745
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_0
# Step 5: Generating Skeleton: 16.44939613342285
# Step 5: Generating and reading Skeleton: 16.453173398971558
# Working on split 1 with face total = 286
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.011032342910766602
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5099279880523682
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_1
# Step 5: Generating Skeleton: 0.01048421859741211
# Step 5: Generating and reading Skeleton: 0.011080741882324219
# Working on split 2 with face total = 291
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.019733905792236328
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.481497049331665
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_2
# Step 5: Generating Skeleton: 0.004859209060668945
# Step 5: Generating and reading Skeleton: 0.005354166030883789
# Working on split 3 with face total = 1679
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03987598419189453
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5691516399383545
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_3
# Step 5: Generating Skeleton: 0.1023859977722168
# Step 5: Generating and reading Skeleton: 0.10334944725036621
# Working on split 4 with face total = 615
# Patching holes...
# Patched 6 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.007095813751220703
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.4808640480041504
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_4
# Step 5: Generating Skeleton: 0.004811763763427734
# Step 5: Generating and reading Skeleton: 0.005380392074584961
# Working on split 5 with face total = 265
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.00795602798461914
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.435112476348877
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_5
# Step 5: Generating Skeleton: 0.015423297882080078
# Step 5: Generating and reading Skeleton: 0.015998125076293945
# Working on split 6 with face total = 995
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03975725173950195
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5035369396209717
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_6
# Step 5: Generating Skeleton: 0.06386446952819824
# Step 5: Generating and reading Skeleton: 0.0644838809967041
# Working on split 7 with face total = 204
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.008517265319824219
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.4740309715270996
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475526_piece_7
# Step 5: Generating Skeleton: 0.004866123199462891
# Step 5: Generating and reading Skeleton: 0.005649089813232422
# len_subgraphs AT BEGINNING = 9
# min_dist = 528.2426431101554
# min_dist_subgraph_index = 4
# min_dist_edge_index = [112, 111]
# min_dist_edge = [array([206660., 266066.,  43209.]), array([206556. , 266041. ,  42691.7])]
# len_subgraphs AT END= 8
# min_dist = 1160.1326691374559
# min_dist_subgraph_index = 7
# min_dist_edge_index = [768, 769]
# min_dist_edge = [array([301734. , 285568. ,  60694.7]), array([302191. , 286618. ,  60508.8])]
# len_subgraphs AT END= 7
# min_dist = 1203.8864730530063
# min_dist_subgraph_index = 4
# min_dist_edge_index = [128, 141]
# min_dist_edge = [array([207219. , 265227. ,  43161.4]), array([207726. , 264452. ,  42392.2])]
# len_subgraphs AT END= 6
# min_dist = 1514.823936964294
# min_dist_subgraph_index = 2
# min_dist_edge_index = [108, 100]
# min_dist_edge = [array([205663. , 266714. ,  43232.4]), array([204712., 266494.,  42074.])]
# len_subgraphs AT END= 5
# min_dist = 1627.2528998284195
# min_dist_subgraph_index = 1
# min_dist_edge_index = [99, 19]
# min_dist_edge = [array([204711. , 266494. ,  42074.1]), array([203099. , 266382. ,  42266.1])]
# len_subgraphs AT END= 4
# min_dist = 2084.11211070806
# min_dist_subgraph_index = 2
# min_dist_edge_index = [213, 187]
# min_dist_edge = [array([209921. , 265893. ,  42485.1]), array([208763. , 267583. ,  42867.8])]
# len_subgraphs AT END= 3
# min_dist = 2466.9968869052104
# min_dist_subgraph_index = 1
# min_dist_edge_index = [94, 103]
# min_dist_edge = [array([203247. , 268518. ,  42282.6]), array([205488. , 269532. ,  42093.4])]
# len_subgraphs AT END= 2
# min_dist = 3413.0266055218485
# min_dist_subgraph_index = 1
# min_dist_edge_index = [252, 247]
# min_dist_edge = [array([214433. , 272333. ,  44830.5]), array([213087. , 273730. ,  42022.4])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.28227663040161133
# Total time: 124.20125889778137
#
#
#
# ----------Working on 648518346349475529:----------
# Step 1: Retrieving Mesh and removing error segments: 0.369464635848999
# There were 405 after split and significance threshold
# There were 7 after split and significance threshold
# Mesh piece 0 with number of faces 165052
# Mesh piece 1 with number of faces 201
# Mesh piece 2 with number of faces 469
# Mesh piece 3 with number of faces 273
# Mesh piece 4 with number of faces 334
# Mesh piece 5 with number of faces 575
# Mesh piece 6 with number of faces 762
# Step 2a: Getting the number of splits: 0.3004286289215088
# largest mesh perc = 0.9636722444737672
# Working on split 0 with face total = 165052
# Patching holes...
# Patched 237 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 30.129913091659546
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 43.69443988800049
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_0
# Step 5: Generating Skeleton: 20.05656337738037
# Step 5: Generating and reading Skeleton: 20.08142113685608
# Working on split 1 with face total = 201
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.004177093505859375
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.045839786529541
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_1
# Step 5: Generating Skeleton: 0.0029981136322021484
# Step 5: Generating and reading Skeleton: 0.0038912296295166016
# Working on split 2 with face total = 469
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.0031557083129882812
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 7.392630338668823
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_2
# Step 5: Generating Skeleton: 0.0046122074127197266
# Step 5: Generating and reading Skeleton: 0.00553584098815918
# Working on split 3 with face total = 273
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.009204864501953125
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.267739772796631
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_3
# Step 5: Generating Skeleton: 0.02157759666442871
# Step 5: Generating and reading Skeleton: 0.031209945678710938
# Working on split 4 with face total = 334
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.009919166564941406
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.341966152191162
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_4
# Step 5: Generating Skeleton: 0.07230329513549805
# Step 5: Generating and reading Skeleton: 0.07324886322021484
# Working on split 5 with face total = 575
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.009717226028442383
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 4.576387643814087
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_5
# Step 5: Generating Skeleton: 0.053665876388549805
# Step 5: Generating and reading Skeleton: 0.05807042121887207
# Working on split 6 with face total = 762
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03811454772949219
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 4.965131521224976
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349475529_piece_6
# Step 5: Generating Skeleton: 0.13788652420043945
# Step 5: Generating and reading Skeleton: 0.13920164108276367
# len_subgraphs AT BEGINNING = 8
# min_dist = 127.84302875010437
# min_dist_subgraph_index = 3
# min_dist_edge_index = [26, 33]
# min_dist_edge = [array([199360. , 281942. ,  24028.4]), array([199464. , 281868. ,  24021.2])]
# len_subgraphs AT END= 7
# min_dist = 830.6027931568735
# min_dist_subgraph_index = 2
# min_dist_edge_index = [28, 15]
# min_dist_edge = [array([199373. , 281490. ,  24011.7]), array([198738. , 281600. ,  24535.7])]
# len_subgraphs AT END= 6
# min_dist = 993.3162437008655
# min_dist_subgraph_index = 2
# min_dist_edge_index = [73, 69]
# min_dist_edge = [array([201423. , 284377. ,  25234.2]), array([201261. , 284576. ,  26193.8])]
# len_subgraphs AT END= 5
# min_dist = 1293.3769017575657
# min_dist_subgraph_index = 1
# min_dist_edge_index = [12, 7]
# min_dist_edge = [array([198733., 281618.,  24537.]), array([198113. , 282753. ,  24522.9])]
# len_subgraphs AT END= 4
# min_dist = 1390.4984717719037
# min_dist_subgraph_index = 3
# min_dist_edge_index = [346, 304]
# min_dist_edge = [array([212276., 286563.,  26149.]), array([211907., 285344.,  26707.])]
# len_subgraphs AT END= 3
# min_dist = 1500.6757011426544
# min_dist_subgraph_index = 1
# min_dist_edge_index = [74, 78]
# min_dist_edge = [array([201545. , 286211. ,  24660.6]), array([202649., 286411.,  23664.])]
# len_subgraphs AT END= 2
# min_dist = 2270.919437144348
# min_dist_subgraph_index = 1
# min_dist_edge_index = [140, 155]
# min_dist_edge = [array([205359. , 279150. ,  24997.4]), array([205583. , 278753. ,  22772.7])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.3449275493621826
# Total time: 103.63956809043884
#
#
#
# ----------Working on 648518346349507788:----------
# Step 1: Retrieving Mesh and removing error segments: 5.468886613845825
# There were 1096 after split and significance threshold
# There were 61 after split and significance threshold
# Mesh piece 0 with number of faces 949528
# Mesh piece 1 with number of faces 27781
# Mesh piece 2 with number of faces 42098
# Mesh piece 3 with number of faces 15441
# Mesh piece 4 with number of faces 20116
# Mesh piece 5 with number of faces 17122
# Mesh piece 6 with number of faces 12817
# Mesh piece 7 with number of faces 21756
# Mesh piece 8 with number of faces 2813
# Mesh piece 9 with number of faces 9994
# Mesh piece 10 with number of faces 28618
# Mesh piece 11 with number of faces 2497
# Mesh piece 12 with number of faces 600
# Mesh piece 13 with number of faces 387
# Mesh piece 14 with number of faces 10069
# Mesh piece 15 with number of faces 16661
# Mesh piece 16 with number of faces 268
# Mesh piece 17 with number of faces 5131
# Mesh piece 18 with number of faces 350
# Mesh piece 19 with number of faces 12538
# Mesh piece 20 with number of faces 9953
# Mesh piece 21 with number of faces 11452
# Mesh piece 22 with number of faces 2666
# Mesh piece 23 with number of faces 7710
# Mesh piece 24 with number of faces 628
# Mesh piece 25 with number of faces 552
# Mesh piece 26 with number of faces 1907
# Mesh piece 27 with number of faces 7376
# Mesh piece 28 with number of faces 9264
# Mesh piece 29 with number of faces 3709
# Mesh piece 30 with number of faces 240
# Mesh piece 31 with number of faces 1068
# Mesh piece 32 with number of faces 2886
# Mesh piece 33 with number of faces 2331
# Mesh piece 34 with number of faces 246
# Mesh piece 35 with number of faces 10454
# Mesh piece 36 with number of faces 6381
# Mesh piece 37 with number of faces 2601
# Mesh piece 38 with number of faces 840
# Mesh piece 39 with number of faces 924
# Mesh piece 40 with number of faces 2064
# Mesh piece 41 with number of faces 710
# Mesh piece 42 with number of faces 656
# Mesh piece 43 with number of faces 278
# Mesh piece 44 with number of faces 684
# Mesh piece 45 with number of faces 1082
# Mesh piece 46 with number of faces 3364
# Mesh piece 47 with number of faces 246
# Mesh piece 48 with number of faces 700
# Mesh piece 49 with number of faces 222
# Mesh piece 50 with number of faces 238
# Mesh piece 51 with number of faces 328
# Mesh piece 52 with number of faces 247
# Mesh piece 53 with number of faces 708
# Mesh piece 54 with number of faces 422
# Mesh piece 55 with number of faces 4458
# Mesh piece 56 with number of faces 863
# Mesh piece 57 with number of faces 778
# Mesh piece 58 with number of faces 287
# Mesh piece 59 with number of faces 498
# Mesh piece 60 with number of faces 322
# Step 2a: Getting the number of splits: 6.655035495758057
# largest mesh perc = 0.728383488926903
# Working on split 0 with face total = 949528
# Patching holes...
# Patched 1872 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1241.803695678711
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1763.6393449306488
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_0
# Step 5: Generating Skeleton: 156.0393931865692
# Step 5: Generating and reading Skeleton: 156.04774165153503
# Working on split 1 with face total = 27781
# Patching holes...
# Patched 87 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.8966660499572754
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 13.418809413909912
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_1
# Step 5: Generating Skeleton: 2.649296760559082
# Step 5: Generating and reading Skeleton: 2.6548449993133545
# Working on split 2 with face total = 42098
# Patching holes...
# Patched 78 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 5.064834833145142
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 22.3140971660614
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_2
# Step 5: Generating Skeleton: 5.1231019496917725
# Step 5: Generating and reading Skeleton: 5.132613182067871
# Working on split 3 with face total = 15441
# Patching holes...
# Patched 52 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.6270039081573486
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 10.780948877334595
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_3
# Step 5: Generating Skeleton: 1.5722980499267578
# Step 5: Generating and reading Skeleton: 1.5743722915649414
# Working on split 4 with face total = 20116
# Patching holes...
# Patched 57 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 2.737103223800659
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 12.055880784988403
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_4
# Step 5: Generating Skeleton: 2.2265775203704834
# Step 5: Generating and reading Skeleton: 2.2293288707733154
# Working on split 5 with face total = 17122
# Patching holes...
# Patched 53 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 2.3920583724975586
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 12.01211142539978
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_5
# Step 5: Generating Skeleton: 2.817185163497925
# Step 5: Generating and reading Skeleton: 2.8343145847320557
# Working on split 6 with face total = 12817
# Patching holes...
# Patched 46 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.4385390281677246
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 9.575268507003784
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_6
# Step 5: Generating Skeleton: 1.6431076526641846
# Step 5: Generating and reading Skeleton: 1.647113561630249
# Working on split 7 with face total = 21756
# Patching holes...
# Patched 66 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 2.5000643730163574
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 12.412173509597778
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_7
# Step 5: Generating Skeleton: 1.8890268802642822
# Step 5: Generating and reading Skeleton: 1.893592119216919
# Working on split 8 with face total = 2813
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.24688029289245605
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.547442436218262
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_8
# Step 5: Generating Skeleton: 0.7994406223297119
# Step 5: Generating and reading Skeleton: 0.8023037910461426
# Working on split 9 with face total = 9994
# Patching holes...
# Patched 37 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.1282391548156738
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 8.603648662567139
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_9
# Step 5: Generating Skeleton: 1.5388262271881104
# Step 5: Generating and reading Skeleton: 1.5414276123046875
# Working on split 10 with face total = 28618
# Patching holes...
# Patched 82 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 4.374665021896362
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 15.211236476898193
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_10
# Step 5: Generating Skeleton: 5.403139114379883
# Step 5: Generating and reading Skeleton: 5.409531354904175
# Working on split 11 with face total = 2497
# Patching holes...
# Patched 11 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.13453388214111328
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 4.980258226394653
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_11
# Step 5: Generating Skeleton: 0.6523101329803467
# Step 5: Generating and reading Skeleton: 0.6543078422546387
# Working on split 12 with face total = 600
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.013090848922729492
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.579635143280029
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_12
# Step 5: Generating Skeleton: 0.11953496932983398
# Step 5: Generating and reading Skeleton: 0.13305425643920898
# Working on split 13 with face total = 387
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03422975540161133
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.5367584228515625
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_13
# Step 5: Generating Skeleton: 0.0075931549072265625
# Step 5: Generating and reading Skeleton: 0.02308487892150879
# Working on split 14 with face total = 10069
# Patching holes...
# Patched 9 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_14_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_14_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.4891116619110107
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 8.609983205795288
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_14
# Step 5: Generating Skeleton: 2.124631881713867
# Step 5: Generating and reading Skeleton: 2.1279563903808594
# Working on split 15 with face total = 16661
# Patching holes...
# Patched 53 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_15.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349507788_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# ...
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03434562683105469
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.55868935585022
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_1
# Step 5: Generating Skeleton: 0.12270879745483398
# Step 5: Generating and reading Skeleton: 0.12689781188964844
# Working on split 2 with face total = 616
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.02929401397705078
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.674411773681641
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_2
# Step 5: Generating Skeleton: 0.2496039867401123
# Step 5: Generating and reading Skeleton: 0.25069570541381836
# Working on split 3 with face total = 372
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.013489723205566406
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 6.47624659538269
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_3
# Step 5: Generating Skeleton: 0.06911206245422363
# Step 5: Generating and reading Skeleton: 0.07026791572570801
# Working on split 4 with face total = 728
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.04812431335449219
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.704096555709839
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346348192292_piece_4
# Step 5: Generating Skeleton: 0.1916675567626953
# Step 5: Generating and reading Skeleton: 0.19310212135314941
# len_subgraphs AT BEGINNING = 5
# min_dist = 143.98263784220651
# min_dist_subgraph_index = 4
# min_dist_edge_index = [366, 368]
# min_dist_edge = [array([468503. , 237869. ,  65828.2]), array([468524. , 237732. ,  65867.2])]
# len_subgraphs AT END= 4
# min_dist = 159.10361403814386
# min_dist_subgraph_index = 3
# min_dist_edge_index = [280, 283]
# min_dist_edge = [array([464333. , 222334. ,  61607.8]), array([464415. , 222263. ,  61724.2])]
# len_subgraphs AT END= 3
# min_dist = 186.66129754182953
# min_dist_subgraph_index = 2
# min_dist_edge_index = [233, 206]
# min_dist_edge = [array([462728. , 218329. ,  61024.1]), array([462573. , 218353. ,  60922.9])]
# len_subgraphs AT END= 2
# min_dist = 328.405907376832
# min_dist_subgraph_index = 1
# min_dist_edge_index = [119, 97]
# min_dist_edge = [array([461156. , 200725. ,  54657.4]), array([460833. , 200733. ,  54598.6])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.13701462745666504
# Total time: 65.90406394004822
#
#
#
# ----------Working on 648518346349496069:----------
# Step 1: Retrieving Mesh and removing error segments: 0.6057612895965576
# There were 95 after split and significance threshold
# There were 1 after split and significance threshold
# Mesh piece 0 with number of faces 110465
# Step 2a: Getting the number of splits: 0.5873148441314697
# largest mesh perc = 0.9970665222493005
# Working on split 0 with face total = 110465
# Patching holes...
# Patched 230 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349496069_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349496069_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349496069_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349496069_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 17.803970098495483
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 51.1042058467865
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349496069_piece_0
# Step 5: Generating Skeleton: 12.160030126571655
# Step 5: Generating and reading Skeleton: 12.162668228149414
# len_subgraphs AT BEGINNING = 1
# Step 6: Inserting dictionary: 0.2148754596710205
# Total time: 69.62460565567017
#
#
#
# ----------Working on 648518346349509121:----------
# Step 1: Retrieving Mesh and removing error segments: 0.5223486423492432
# There were 136 after split and significance threshold
# There were 2 after split and significance threshold
# Mesh piece 0 with number of faces 72186
# Mesh piece 1 with number of faces 14749
# Step 2a: Getting the number of splits: 0.5431246757507324
# largest mesh perc = 0.8264468487034174
# Working on split 0 with face total = 72186
# Patching holes...
# Patched 195 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 10.50359296798706
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 38.079641342163086
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_0
# Step 5: Generating Skeleton: 9.080096244812012
# Step 5: Generating and reading Skeleton: 9.082478284835815
# Working on split 1 with face total = 14749
# Patching holes...
# Patched 42 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.8971905708312988
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 10.570074558258057
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349509121_piece_1
# Step 5: Generating Skeleton: 3.3988635540008545
# Step 5: Generating and reading Skeleton: 3.4002044200897217
# len_subgraphs AT BEGINNING = 2
# min_dist = 2185.8634998553744
# min_dist_subgraph_index = 1
# min_dist_edge_index = [430, 397]
# min_dist_edge = [array([450790. , 174160. ,  49208.7]), array([450364. , 172903. ,  47471.9])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.2311570644378662
# Total time: 68.21253752708435
#
#
#
# ----------Working on 648518346349511899:----------
# Step 1: Retrieving Mesh and removing error segments: 0.7627048492431641
# There were 125 after split and significance threshold
# There were 3 after split and significance threshold
# Mesh piece 0 with number of faces 93567
# Mesh piece 1 with number of faces 18075
# Mesh piece 2 with number of faces 1219
# Step 2a: Getting the number of splits: 0.6170907020568848
# largest mesh perc = 0.8258194912711161
# Working on split 0 with face total = 93567
# Patching holes...
# Patched 170 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 14.015552997589111
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 45.43780541419983
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_0
# Step 5: Generating Skeleton: 10.3135244846344
# Step 5: Generating and reading Skeleton: 10.316924810409546
# Working on split 1 with face total = 18075
# Patching holes...
# Patched 54 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 2.611250162124634
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 10.862866163253784
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_1
# Step 5: Generating Skeleton: 2.462542772293091
# Step 5: Generating and reading Skeleton: 2.4647469520568848
# Working on split 2 with face total = 1219
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/copies/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.30828404426574707
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.206403970718384
# /notebooks/Pass_2_Sk_Neurons_Final/copies/pymesh_NEURONS/neuron_648518346349511899_piece_2
# Step 5: Generating Skeleton: 0.7203357219696045
# Step 5: Generating and reading Skeleton: 0.7228167057037354
# len_subgraphs AT BEGINNING = 3
# min_dist = 655.6508293291487
# min_dist_subgraph_index = 2
# min_dist_edge_index = [601, 660]
# min_dist_edge = [array([462873., 270819.,  56247.]), array([463087. , 270223. ,  56077.1])]
# len_subgraphs AT END= 2
# min_dist = 368.16014178615274
# min_dist_subgraph_index = 1
# min_dist_edge_index = [605, 578]
# min_dist_edge = [array([462954. , 268892. ,  53967.5]), array([462587. , 268918. ,  53980.8])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.13751816749572754
# Total time: 83.62980723381042
#
#
#
# 4173.940692424774
