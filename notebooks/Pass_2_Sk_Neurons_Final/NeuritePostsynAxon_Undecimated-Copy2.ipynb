# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#pinky.NeuritePostsynAxon.drop()

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[:-4]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #check to see if the face_indexes is empty
    if not face_indexes.any():
        #create an empty mesh
        current_mesh = trimesh.Trimesh(np.array([]),np.array([]),process=False)
        return current_mesh,np.array([])
    
    
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
import warnings
from pymeshfix import _meshfix
import pymeshfix

def clean_from_arrays_celii(v, f, verbose=False, joincomp=False,
                      remove_smallest_components=True,clean=True):
    """
    Performs default cleaning procedure on vertex and face arrays
    Returns cleaned vertex and face arrays
    
    Parameters
    ----------
    v : numpy.ndarray
        Numpy n x 3 array of vertices
    f : numpy.ndarray
        Numpy n x 3 array of faces.
    verbose : bool, optional
        Prints progress to stdout.  Default True.
    joincomp : bool, optional
        Attempts to join nearby open components.  Default False
    remove_smallest_components : bool, optional
        Remove all but the largest isolated component from the mesh
        before beginning the repair process.  Default True.
    Examples
    --------
    >>>
    >>> CleanFromFile('inmesh.ply', 'outmesh.ply')
    """
    # Create mesh object and load from file
    tin = _meshfix.PyTMesh(verbose)
    tin.load_array(v, f)

    # repari and return vertex and face arrays
    repair_celii(tin, verbose, joincomp, remove_smallest_components,clean)
    return tin.return_arrays()

#what the repair function does: 
def repair_celii(tin, verbose=False, joincomp=True, remove_smallest_components=True,clean=True):
    """
    Performs mesh repair using default cleaning procedure using a tin object.
    Internal function.  Use CleanFromFile or CleanFromVF.
    """

    # Keep only the largest component (i.e. with most triangles)
    if remove_smallest_components:
        sc = tin.remove_smallest_components()
        if sc and verbose:
            print('Removed %d small components' % sc)

    # join closest components
    if joincomp:
        tin.join_closest_components()
    
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
    
        
    tin.boundaries()
    if clean == True:
        # Perform mesh cleaning
        if verbose:
            print('Fixing degeneracies and intersections')
        result = tin.clean()
    else:
        print("Skipping the degenerative cleaning")
        result = False

    # Check boundaries again
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
        if verbose:
            print('Performing final check...')
        if clean == True:
            if verbose:
                print('Fixing degeneracies and intersections')
            result = tin.clean()
        else:
            print("Skipping the degenerative cleaning")
            result = False

    if result:
        warnings.warn('MeshFix could not fix everything')

# %%
def get_axon_mesh(key):
    """
    Will return a trimesh object representing the mesh for that soma
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    
    #get the labels for the mesh
    face_labels = (pinky.UndecimatedNeuronLabels & key).fetch1("coarse_triangles_labels")
    
    y = np.where(face_labels==6)
    z = np.where(face_labels==7)
    axon_indexes = np.hstack((y,z))
    
    print("axon_indexes = " + str(axon_indexes))
    
    if not axon_indexes.any():
        return trimesh.Trimesh(np.array([]),np.array([])),axon_indexes
    
    #get a submesh
    axon_mesh = current_mesh.submesh(axon_indexes,append=True)
    return axon_mesh,axon_indexes

# %%
@schema
class NeuritePostsynAxon(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """

    
    key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]))  + (dj.U("segment_id","segmentation") & (pinky.CompartmentOrphan.ComponentOrphan() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]])) 

    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        #gets the axons
        mesh,face_indexes = get_axon_mesh(key)
        
        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])
        
        """
        Handle the poosibility that there is no mesh
        """
        print("mesh.faces = " + str(len(mesh.faces)))
        
        if len(mesh.faces) < 5:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
        
                #send the data through the hole patching function from pymesh:
                cleaned_verts, cleaned_triangles= clean_from_arrays_celii(m.vertices,m.faces,verbose=True,joincomp=True,remove_smallest_components=False,clean=False)
                #cleaned_mesh = make_trimesh_object(m.vertices,m.faces)
            
            
        
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),cleaned_verts, cleaned_triangles)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                
                
                meshlab_script_2 = str(pathlib.Path.cwd()) + "/" + "remove_intersecting_faces.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(output_mesh,key["segment_id"],meshlab_script_2)
                
                print("About to run pymeshfix")
                start_time_py = time.time()
                loaded_mesh = trimesh.load_mesh(output_mesh,process=False)
                meshfix = pymeshfix.MeshFix(loaded_mesh.vertices,loaded_mesh.faces)
                meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                print(f"Total time for pymeshfix = {time.time() - start_time_py}")
                
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v, meshfix.f)
                
                
                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(path_and_filename)

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(path_and_filename + ".off")

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(path_and_filename)
                if return_value > 0:
                    raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                    

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(path_and_filename+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neurite_postsyn_axon'" & "status='error'").delete()

# %%
#NeuronSkeletonStitched & "segment_id=neuron648518346349487734"

# %%
start = time.time()
NeuritePostsynAxon.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346349496672:----------
# axon_indexes = [[ 235001  235002  235003 ... 3522388 3522389 3522390]]
# mesh.faces = 37158
# Step 1: Retrieving Mesh and removing error segments: 2.369295597076416
# There were 5 after split and significance threshold
# There were 1 after split and significance threshold
# Mesh piece 0 with number of faces 37139
# Step 2a: Getting the number of splits: 0.03742837905883789
# largest mesh perc = 0.9994886700037677
# Working on split 0 with face total = 37139
# Patching holes...
# Patched 13 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349496672_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349496672_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349496672_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349496672_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.8614511489868164
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 6.806503534317017
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349496672_piece_0
# Step 5: Generating Skeleton: 1.2712266445159912
# Step 5: Generating and reading Skeleton: 1.2754993438720703
# len_subgraphs AT BEGINNING = 1
# Step 6: Inserting dictionary: 5.323116302490234
# Total time: 16.392245769500732
#
#
#
# ----------Working on 648518346349508765:----------
# axon_indexes = [[  21008   21009   21010 ... 1899409 1899410 1899411]]
# mesh.faces = 211931
# Step 1: Retrieving Mesh and removing error segments: 1.4079303741455078
# There were 71 after split and significance threshold
# There were 20 after split and significance threshold
# Mesh piece 0 with number of faces 58915
# Mesh piece 1 with number of faces 44901
# Mesh piece 2 with number of faces 45259
# Mesh piece 3 with number of faces 14032
# Mesh piece 4 with number of faces 2630
# Mesh piece 5 with number of faces 348
# Mesh piece 6 with number of faces 635
# Mesh piece 7 with number of faces 604
# Mesh piece 8 with number of faces 704
# Mesh piece 9 with number of faces 9922
# Mesh piece 10 with number of faces 3587
# Mesh piece 11 with number of faces 523
# Mesh piece 12 with number of faces 18539
# Mesh piece 13 with number of faces 1914
# Mesh piece 14 with number of faces 254
# Mesh piece 15 with number of faces 4076
# Mesh piece 16 with number of faces 794
# Mesh piece 17 with number of faces 1706
# Mesh piece 18 with number of faces 480
# Mesh piece 19 with number of faces 1782
# Step 2a: Getting the number of splits: 0.27562689781188965
# largest mesh perc = 0.27799142173631985
# Working on split 0 with face total = 58915
# Patching holes...
# Patched 29 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.889580249786377
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 9.682261228561401
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_0
# Step 5: Generating Skeleton: 1.3392360210418701
# Step 5: Generating and reading Skeleton: 1.342775583267212
# Working on split 1 with face total = 44901
# Patching holes...
# Patched 12 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.823418140411377
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 7.854076862335205
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_1
# Step 5: Generating Skeleton: 1.5316119194030762
# Step 5: Generating and reading Skeleton: 1.535325527191162
# Working on split 2 with face total = 45259
# Patching holes...
# Patched 33 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.9119799137115479
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 7.909142255783081
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_2
# Step 5: Generating Skeleton: 1.1960480213165283
# Step 5: Generating and reading Skeleton: 1.1998860836029053
# Working on split 3 with face total = 14032
# Patching holes...
# Patched 8 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.43796825408935547
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.058180570602417
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_3
# Step 5: Generating Skeleton: 0.41866159439086914
# Step 5: Generating and reading Skeleton: 0.42139148712158203
# Working on split 4 with face total = 2630
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.08556318283081055
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7221918106079102
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_4
# Step 5: Generating Skeleton: 0.09980916976928711
# Step 5: Generating and reading Skeleton: 0.10142135620117188
# Working on split 5 with face total = 348
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.023341894149780273
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6300249099731445
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_5
# Step 5: Generating Skeleton: 0.014755964279174805
# Step 5: Generating and reading Skeleton: 0.01542520523071289
# Working on split 6 with face total = 635
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.019260168075561523
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6460199356079102
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_6
# Step 5: Generating Skeleton: 0.056580305099487305
# Step 5: Generating and reading Skeleton: 0.05823564529418945
# Working on split 7 with face total = 604
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01663827896118164
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.624624252319336
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_7
# Step 5: Generating Skeleton: 0.03847336769104004
# Step 5: Generating and reading Skeleton: 0.03902125358581543
# Working on split 8 with face total = 704
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01638936996459961
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5458617210388184
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_8
# Step 5: Generating Skeleton: 0.05097556114196777
# Step 5: Generating and reading Skeleton: 0.05186200141906738
# Working on split 9 with face total = 9922
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.2990896701812744
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.440703868865967
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_9
# Step 5: Generating Skeleton: 0.3170332908630371
# Step 5: Generating and reading Skeleton: 0.3189988136291504
# Working on split 10 with face total = 3587
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.07783222198486328
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9002454280853271
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_10
# Step 5: Generating Skeleton: 0.15547418594360352
# Step 5: Generating and reading Skeleton: 0.15710997581481934
# Working on split 11 with face total = 523
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01721668243408203
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.570805311203003
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_11
# Step 5: Generating Skeleton: 0.03680109977722168
# Step 5: Generating and reading Skeleton: 0.03780841827392578
# Working on split 12 with face total = 18539
# Patching holes...
# Patched 7 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.5776364803314209
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.351851463317871
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_12
# Step 5: Generating Skeleton: 0.7166848182678223
# Step 5: Generating and reading Skeleton: 0.7206668853759766
# Working on split 13 with face total = 1914
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03988289833068848
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7137107849121094
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_13
# Step 5: Generating Skeleton: 0.09772896766662598
# Step 5: Generating and reading Skeleton: 0.09877443313598633
# Working on split 14 with face total = 254
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_14_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_14_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01173257827758789
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5859935283660889
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_14
# Step 5: Generating Skeleton: 0.012163639068603516
# Step 5: Generating and reading Skeleton: 0.012777328491210938
# Working on split 15 with face total = 4076
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_15.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_15_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_15_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.09428882598876953
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8327348232269287
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_15
# Step 5: Generating Skeleton: 0.21172738075256348
# Step 5: Generating and reading Skeleton: 0.21355295181274414
# Working on split 16 with face total = 794
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_16.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_16_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_16_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_16_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.0208280086517334
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5529046058654785
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_16
# Step 5: Generating Skeleton: 0.041643619537353516
# Step 5: Generating and reading Skeleton: 0.04245305061340332
# Working on split 17 with face total = 1706
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_17.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_17_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_17_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_17_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.05846405029296875
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7061169147491455
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_17
# Step 5: Generating Skeleton: 0.13704276084899902
# Step 5: Generating and reading Skeleton: 0.13926315307617188
# Working on split 18 with face total = 480
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_18.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_18_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_18_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_18_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.014212846755981445
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6082983016967773
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_18
# Step 5: Generating Skeleton: 0.0900275707244873
# Step 5: Generating and reading Skeleton: 0.09114813804626465
# Working on split 19 with face total = 1782
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_19.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_19_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_19_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_19_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.0472409725189209
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7393712997436523
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349508765_piece_19
# Step 5: Generating Skeleton: 0.11967825889587402
# Step 5: Generating and reading Skeleton: 0.12065911293029785
# len_subgraphs AT BEGINNING = 20
# min_dist = 71906.0432856655
# min_dist_subgraph_index = 3
# min_dist_edge_index = [72, 191]
# min_dist_edge = [array([322359., 163827.,  19119.]), array([381127., 177498.,  58233.])]
# len_subgraphs AT END= 19
# min_dist = 2724.258497279582
# min_dist_subgraph_index = 2
# min_dist_edge_index = [285, 155]
# min_dist_edge = [array([381536. , 177082. ,  58565.6]), array([380636., 178414.,  60765.])]
# len_subgraphs AT END= 18
# min_dist = 24062.352611704453
# min_dist_subgraph_index = 2
# min_dist_edge_index = [291, 404]
# min_dist_edge = [array([381580. , 176957. ,  58656.3]), array([402492. , 169339. ,  49510.2])]
# len_subgraphs AT END= 17
# min_dist = 813.2956166118206
# min_dist_subgraph_index = 11
# min_dist_edge_index = [2892, 2922]
# min_dist_edge = [array([451108. , 178640. ,  47837.5]), array([451734. , 178832. ,  48319.9])]
# len_subgraphs AT END= 16
# min_dist = 1116.4918450217192
# min_dist_subgraph_index = 8
# min_dist_edge_index = [2630, 2623]
# min_dist_edge = [array([442280. , 160097. ,  47991.5]), array([442219. , 159086. ,  48461.3])]
# len_subgraphs AT END= 15
# min_dist = 1130.1391109062617
# min_dist_subgraph_index = 5
# min_dist_edge_index = [2057, 2050]
# min_dist_edge = [array([437749. , 212798. ,  34451.2]), array([437697. , 213872. ,  34103.3])]
# len_subgraphs AT END= 14
# min_dist = 169.19999999999897
# min_dist_subgraph_index = 5
# min_dist_edge_index = [1661, 1664]
# min_dist_edge = [array([433207. , 221044. ,  15330.3]), array([433257. , 221016. ,  15171.1])]
# len_subgraphs AT END= 13
# min_dist = 430.97959348442487
# min_dist_subgraph_index = 4
# min_dist_edge_index = [1464, 1347]
# min_dist_edge = [array([432400. , 217315. ,  13336.5]), array([432183. , 216965. ,  13209.4])]
# len_subgraphs AT END= 12
# min_dist = 257.03820727666164
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1432, 1379]
# min_dist_edge = [array([432357. , 213107. ,  12500.9]), array([432263. , 212871. ,  12540.1])]
# len_subgraphs AT END= 11
# min_dist = 1239.1702707860616
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2773, 2779]
# min_dist_edge = [array([448011. , 204164. ,  47818.4]), array([449112. , 204482. ,  48289.8])]
# len_subgraphs AT END= 10
# min_dist = 1574.5213113832401
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2140, 2218]
# min_dist_edge = [array([438222. , 269312. ,  32256.4]), array([439017., 270458.,  32987.])]
# len_subgraphs AT END= 9
# min_dist = 906.7949272023978
# min_dist_subgraph_index = 1
# min_dist_edge_index = [638, 632]
# min_dist_edge = [array([424172. , 260482. ,  13206.6]), array([424081. , 260548. ,  12306.8])]
# len_subgraphs AT END= 8
# min_dist = 2198.8112151796904
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1719, 1816]
# min_dist_edge = [array([434116. , 277859. ,  34306.3]), array([434866. , 279635. ,  35363.7])]
# len_subgraphs AT END= 7
# min_dist = 14505.782374280954
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2054, 2792]
# min_dist_edge = [array([437712., 226382.,  25255.]), array([449628. , 224195. ,  17277.3])]
# len_subgraphs AT END= 6
# min_dist = 584.5328391117139
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2949, 2959]
# min_dist_edge = [array([452022. , 222622. ,  15358.7]), array([452155. , 222623. ,  14789.5])]
# len_subgraphs AT END= 5
# min_dist = 883.8809648363289
# min_dist_subgraph_index = 1
# min_dist_edge_index = [3217, 3242]
# min_dist_edge = [array([454335. , 220161. ,  11862.9]), array([454408. , 219460. ,  11329.5])]
# len_subgraphs AT END= 4
# min_dist = 753.4388363364349
# min_dist_subgraph_index = 1
# min_dist_edge_index = [3252, 3258]
# min_dist_edge = [array([454536.  , 215581.  ,   7804.56]), array([454623.  , 215521.  ,   7058.57])]
# len_subgraphs AT END= 3
# min_dist = 857.312200368104
# min_dist_subgraph_index = 2
# min_dist_edge_index = [3851, 3884]
# min_dist_edge = [array([462290.  , 214410.  ,   2597.61]), array([462812.  , 214119.  ,   1982.94])]
# len_subgraphs AT END= 2
# min_dist = 1402.8082249901445
# min_dist_subgraph_index = 1
# min_dist_edge_index = [3836, 3858]
# min_dist_edge = [array([461922.  , 214684.  ,   2858.11]), array([462522. , 215007. ,   4084.3])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.1645827293395996
# Total time: 75.1799669265747
#
#
#
# 92.1667594909668
