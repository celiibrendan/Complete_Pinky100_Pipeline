# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498566******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.045667171478271484
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 297.7801105976105
# 2) Finished: Generating CGAL segmentation for neuron: 307.8206477165222
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.12247109413146973
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [17, 16, 36, 15, 5, 18, 2, 29, 92, 20, 106, 66, 41, 76, 67, 63, 27, 78, 123, 103, 79, 60, 124, 93]
# soma_80_percent = 221992.8796875
# Debugging the axon filter
# [(17, 221088.171875), (16, 239346.65625), (36, 231916.453125), (15, 229594.53125), (5, 218589.28125), (18, 237787.375), (2, 231919.34375), (29, 240639.015625), (92, 225538.40625), (20, 230762.375), (106, 218998.390625), (66, 227965.1875), (41, 218770.484375), (76, 228732.109375), (67, 224016.484375), (63, 222646.765625), (27, 225951.734375), (78, 229072.28125), (123, 222752.5), (103, 226528.71875), (79, 227593.40625), (60, 224747.046875), (124, 222477.140625), (93, 225867.578125)]
# possible_Axons_filter_1 = [17, 5, 106, 41]
# possible_Axons_filter_2 = [17, 5]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.07296562194824219
# 6) Staring: Classifying Entire Neuron
# 18 = axon
# 16 = axon
# 27 = cilia
# 41 = stub soma
# 60 = stub soma
# 63 = stub soma
# 66 = stub soma
# 67 = stub soma
# 76 = stub soma
# 78 = stub soma
# 79 = stub soma
# 92 = stub soma
# 93 = stub soma
# 103 = stub soma
# 106 = stub soma
# 123 = stub soma
# 124 = stub soma
# Total Labels found = {'basal', 'soma', 'apical', 'axon', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.1036810874938965
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.2883765697479248
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.092649459838867
# Finished Auto Labeling: 314.88979482650757
#
#
# *****Starting Auto Labeling for 648518346349499679******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04691338539123535
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 618.1225378513336
# 2) Finished: Generating CGAL segmentation for neuron: 633.6057372093201
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1914217472076416
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [19, 7, 11, 18, 37, 22, 23, 20, 30, 13, 38, 29]
# soma_80_percent = 157439.8640625
# Debugging the axon filter
# [(19, 178271.5), (7, 163196.40625), (11, 155090.5625), (18, 157088.3125), (37, 157068.703125), (22, 177481.109375), (23, 164472.75), (20, 175612.6875), (30, 160079.171875), (13, 160818.703125), (38, 161225.171875), (29, 165060.34375)]
# possible_Axons_filter_1 = [11, 18, 37]
# possible_Axons_filter_2 = [11, 18]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.060433149337768555
# 6) Staring: Classifying Entire Neuron
# 29 = stub soma
# 30 = stub soma
# 37 = cilia
# 38 = stub soma
# 27 = stub apical
# 32 = stub apical
# 35 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 2.5571093559265137
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4274168014526367
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.47356915473938
# Finished Auto Labeling: 645.8857474327087
#
#
# *****Starting Auto Labeling for 648518346349499828******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.045343637466430664
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 650.8439521789551
# 2) Finished: Generating CGAL segmentation for neuron: 668.4283261299133
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 16
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1963188648223877
# 5) Staring: Finding Apical Index
# Soma Index = 16
# Soma Connections = [25, 22, 14, 19, 15, 17, 4, 13, 51, 35, 41, 47]
# soma_80_percent = 160237.3171875
# Debugging the axon filter
# [(25, 181107.171875), (22, 181594.53125), (14, 157459.4375), (19, 157818.140625), (15, 175864.203125), (17, 166832.421875), (4, 175296.34375), (13, 180095.96875), (51, 155650.140625), (35, 158399.671875), (41, 158488.375), (47, 169902.046875)]
# possible_Axons_filter_1 = [14, 19, 51, 35, 41]
# possible_Axons_filter_2 = [14, 19]
# possible_Apical = 19
# 5) Finished: Finding Apical Index: 0.052292823791503906
# 6) Staring: Classifying Entire Neuron
# 22 = error
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 17
# 51 = cilia
# 35 = stub soma
# 41 = stub soma
# 47 = stub soma
# Total Labels found = {'basal', 'soma', 'apical', 'error', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.7413287162780762
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.40838193893432617
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.347437858581543
# Finished Auto Labeling: 679.8346796035767
#
#
# *****Starting Auto Labeling for 648518346349500742******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04093432426452637
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 190.54061245918274
# 2) Finished: Generating CGAL segmentation for neuron: 197.8714907169342
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.09075188636779785
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [1, 46, 41, 14, 3, 17, 20, 49, 36, 45]
# soma_80_percent = 233850.9375
# Debugging the axon filter
# [(1, 240959.53125), (46, 244460.609375), (41, 239559.5), (14, 254290.25), (3, 245757.234375), (17, 232578.296875), (20, 242574.359375), (49, 243063.109375), (36, 239197.21875), (45, 243281.703125)]
# possible_Axons_filter_1 = [17]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.02724766731262207
# 6) Staring: Classifying Entire Neuron
# 46 = axon
# 14 = axon
# 17 = cilia
# 36 = stub soma
# 45 = stub soma
# 49 = stub soma
# Total Labels found = {'unsure', 'soma', 'axon', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.1870207786560059
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5051360130310059
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.746043682098389
# Finished Auto Labeling: 204.71660089492798
#
#
# *****Starting Auto Labeling for 648518346349501216******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07976126670837402
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1121.4652535915375
# 2) Finished: Generating CGAL segmentation for neuron: 1142.139643907547
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2745649814605713
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [116, 11, 325, 18, 64, 6, 357, 7, 367, 371, 69, 182]
# soma_80_percent = 286397.3375
# Debugging the axon filter
# [(116, 295905.40625), (11, 295832.875), (325, 302353.1875), (18, 298913.75), (64, 303932.1875), (6, 282855.78125), (357, 290041.75), (7, 302578.46875), (367, 283770.5625), (371, 296036.1875), (69, 283779.5), (182, 295325.625)]
# possible_Axons_filter_1 = [6, 367, 69]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.14234638214111328
# 6) Staring: Classifying Entire Neuron
# 69 = stub soma
# 116 = stub soma
# 182 = stub soma
# 367 = cilia
# 357 = stub soma
# 371 = stub soma
# 19 = stub apical
# 20 = stub apical
# 22 = stub apical
# 24 = stub apical
# 25 = error
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = error
# 38 = error
# 39 = stub apical
# 41 = stub apical
# 44 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 70 = stub apical
# 71 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 87 = stub apical
# 88 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = error
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 154 = stub apical
# 155 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 180 = stub apical
# 181 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 273 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 326 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 347 = error
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 358 = stub apical
# 359 = stub apical
# 365 = stub apical
# 366 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 403 = stub apical
# 404 = stub apical
# 405 = stub apical
# 407 = stub apical
# 408 = stub apical
# 409 = stub apical
# 410 = stub apical
# 411 = stub apical
# 412 = stub apical
# Total Labels found = {'basal', 'soma', 'apical', 'error', 'oblique', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 3.0592284202575684
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.49939489364624023
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.532276153564453
# Finished Auto Labeling: 1158.5605845451355
#
#
# *****Starting Auto Labeling for 648518346349504185******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08788752555847168
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1970.8667223453522
# 2) Finished: Generating CGAL segmentation for neuron: 1997.9806725978851
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 12
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3594493865966797
# 5) Staring: Finding Apical Index
# Soma Index = 12
# Soma Connections = [27, 0, 24, 22, 49, 25, 86, 309, 183]
# soma_80_percent = 261647.7375
# Debugging the axon filter
# [(27, 257695.984375), (0, 279975.78125), (24, 272660.5625), (22, 263202.40625), (49, 273065.46875), (25, 293044.25), (86, 283531.84375), (309, 268886.59375), (183, 260667.96875)]
# possible_Axons_filter_1 = [27, 183]
# possible_Axons_filter_2 = [27]
# possible_Apical = 27
# 5) Finished: Finding Apical Index: 0.139312744140625
# 6) Staring: Classifying Entire Neuron
# 86 = axon
# 183 = stub soma
# 309 = stub soma
# 17 = stub apical
# 29 = stub apical
# 30 = stub apical
# 36 = stub apical
# 37 = error
# 39 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 54 = stub apical
# 55 = stub apical
# 63 = stub apical
# 64 = stub apical
# 66 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 87 = stub apical
# 88 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 108 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 199 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 226 = stub apical
# 227 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 266 = stub apical
# 269 = stub apical
# 273 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 310 = stub apical
# 311 = stub apical
# Total Labels found = {'basal', 'soma', 'axon', 'apical', 'error', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.9870386123657227
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6062889099121094
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 15.599357604980469
# Finished Auto Labeling: 2019.805991411209
#
#
# *****Starting Auto Labeling for 648518346349508212******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06474518775939941
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 765.4480919837952
# 2) Finished: Generating CGAL segmentation for neuron: 782.2345817089081
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21854376792907715
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [7, 3, 324, 11, 22, 29, 28, 131, 76, 74, 250]
# soma_80_percent = 253757.6546875
# Debugging the axon filter
# [(7, 261928.46875), (3, 249857.28125), (324, 266118.59375), (11, 290100.71875), (22, 268437.21875), (29, 262515.8125), (28, 278330.15625), (131, 262467.25), (76, 265294.5), (74, 258394.453125), (250, 257807.703125)]
# possible_Axons_filter_1 = [3]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.10314369201660156
# 6) Staring: Classifying Entire Neuron
# 74 = stub soma
# 76 = stub soma
# 131 = stub soma
# 250 = stub soma
# 324 = stub soma
# 1 = error
# 6 = stub apical
# 14 = stub apical
# 16 = stub apical
# 17 = stub apical
# 18 = stub apical
# 19 = stub apical
# 20 = stub apical
# 21 = stub apical
# 24 = error
# 25 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 35 = stub apical
# 36 = stub apical
# 39 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = error
# 46 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 53 = error
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 150 = stub apical
# 151 = stub apical
# 153 = stub apical
# 155 = stub apical
# 156 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 251 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 275 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 325 = stub apical
# 326 = stub apical
# Total Labels found = {'basal', 'soma', 'apical', 'error', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.354781150817871
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.38335442543029785
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.349661827087402
# Finished Auto Labeling: 795.3997037410736
#
#
# *****Starting Auto Labeling for 648518346349510900******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.010964155197143555
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 144.67480778694153
# 2) Finished: Generating CGAL segmentation for neuron: 150.5088872909546
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 12
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.0722200870513916
# 5) Staring: Finding Apical Index
# Soma Index = 12
# Soma Connections = [17, 26, 43, 23, 13, 11, 18, 57, 7, 54, 66, 2, 31, 60, 69, 55, 38, 52, 50, 47, 45, 73, 65, 53, 64, 74, 81, 75]
# soma_80_percent = 277977.63125
# Debugging the axon filter
# [(17, 289390.9375), (26, 283256.28125), (43, 281200.71875), (23, 278215.6875), (13, 274383.96875), (11, 299565.84375), (18, 282291.53125), (57, 277914.71875), (7, 297650.5625), (54, 286866.6875), (66, 284643.53125), (2, 298571.71875), (31, 286727.34375), (60, 288946.65625), (69, 286791.46875), (55, 282830.625), (38, 278435.90625), (52, 284817.40625), (50, 286880.46875), (47, 290098.21875), (45, 275882.46875), (73, 285198.53125), (65, 284224.59375), (53, 285389.84375), (64, 275416.21875), (74, 289410.6875), (81, 281718.15625), (75, 287911.59375)]
# possible_Axons_filter_1 = [13, 57, 45, 64]
# possible_Axons_filter_2 = [13]
# possible_Apical = 13
# 5) Finished: Finding Apical Index: 0.05808305740356445
# 6) Staring: Classifying Entire Neuron
# 2 = axon
# 7 = axon
# 11 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 26
# 64 = cilia
# 31 = stub soma
# 38 = stub soma
# 43 = stub soma
# 45 = stub soma
# 47 = stub soma
# 50 = stub soma
# 52 = stub soma
# 53 = stub soma
# 54 = stub soma
# 55 = stub soma
# 57 = stub soma
# 60 = stub soma
# 65 = stub soma
# 66 = stub soma
# 69 = stub soma
# 73 = stub soma
# 74 = stub soma
# 75 = stub soma
# 81 = stub soma
# 5 = error
# 16 = stub apical
# 19 = stub apical
# 21 = stub apical
# 22 = stub apical
# 24 = stub apical
# 25 = stub apical
# 29 = stub apical
# 30 = stub apical
# 32 = stub apical
# 33 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 46 = stub apical
# 49 = stub apical
# 51 = stub apical
# 56 = stub apical
# 58 = stub apical
# 59 = stub apical
# 63 = stub apical
# 67 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 82 = stub apical
# Total Labels found = {'basal', 'soma', 'axon', 'apical', 'error', 'oblique', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 0.80177903175354
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.18201947212219238
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.998832941055298
# Finished Auto Labeling: 154.8522231578827
#
#
# *****Starting Auto Labeling for 648518346349511321******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.038312673568725586
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 434.5006477832794
# 2) Finished: Generating CGAL segmentation for neuron: 446.674955368042
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.15279269218444824
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [30, 2, 6, 14, 4, 28, 34, 11, 20, 33, 43, 44, 42, 45]
# soma_80_percent = 281069.69375
# Debugging the axon filter
# [(30, 286586.25), (2, 279703.5625), (6, 277178.46875), (14, 305715.28125), (4, 303047.9375), (28, 294342.25), (34, 279487.5), (11, 281608.6875), (20, 292281.9375), (33, 277209.28125), (43, 289359.3125), (44, 285396.125), (42, 281732.15625), (45, 283101.21875)]
# possible_Axons_filter_1 = [2, 6, 34, 33]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.05378842353820801
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 6
# 28 = error
# 30 = stub soma
# 33 = stub soma
# 34 = stub soma
# 42 = stub soma
# 43 = stub soma
# 44 = stub soma
# 45 = stub soma
# Total Labels found = {'unsure', 'soma', 'error'}
# 6) Finished: Classifying Entire Neuron: 1.5682039260864258
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5592696666717529
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.740762233734131
# Finished Auto Labeling: 456.29932260513306
#
#
# *****Starting Auto Labeling for 648518346349512869******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.10496735572814941
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 2070.4714789390564
# 2) Finished: Generating CGAL segmentation for neuron: 2100.2966270446777
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 5
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3471794128417969
# 5) Staring: Finding Apical Index
# Soma Index = 5
# Soma Connections = [12, 13, 19, 21, 26, 35, 33, 44, 66]
# soma_80_percent = 205876.1375
# Debugging the axon filter
# [(12, 202425.796875), (13, 224941.421875), (19, 225832.421875), (21, 227611.046875), (26, 222657.296875), (35, 227659.78125), (33, 207797.015625), (44, 205232.546875), (66, 205353.953125)]
# possible_Axons_filter_1 = [12, 44, 66]
# possible_Axons_filter_2 = [12]
# possible_Apical = 12
# 5) Finished: Finding Apical Index: 0.0937502384185791
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 33
# 66 = stub soma
# 18 = stub apical
# 24 = error
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 32 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 54 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 95 = stub apical
# 96 = error
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 112 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 121 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# Total Labels found = {'basal', 'soma', 'apical', 'error', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.0058300495147705
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6151127815246582
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 17.34169292449951
# Finished Auto Labeling: 2122.964464902878
# 8556.031115293503

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
