# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341382699: Dendrite-0
# Component found in Orphans
# len of vertices = 89430
# Step 1: extracted Soma Mesh = 3.488621473312378
# Mesh successfully extracted
# Total time = 4.3451104164123535
#
#
# 648518346341385454: Dendrite-0
# Component found in Orphans
# len of vertices = 60436
# Step 1: extracted Soma Mesh = 2.3041062355041504
# Mesh successfully extracted
# Total time = 3.2381479740142822
#
#
# 648518346341389643: Dendrite-0
# Component found in Orphans
# len of vertices = 21621
# Step 1: extracted Soma Mesh = 1.5280301570892334
# Mesh successfully extracted
# Total time = 2.0960755348205566
#
#
# 648518346341391767: Dendrite-0
# Component found in Orphans
# len of vertices = 63965
# Step 1: extracted Soma Mesh = 2.8989014625549316
# Mesh successfully extracted
# Total time = 3.6740574836730957
#
#
# 648518346341393878: Dendrite-0
# Component found in Orphans
# len of vertices = 21277
# Step 1: extracted Soma Mesh = 1.2178852558135986
# Mesh successfully extracted
# Total time = 1.7094316482543945
#
#
# 648518346341394374: Dendrite-0
# Component found in Orphans
# len of vertices = 106021
# Step 1: extracted Soma Mesh = 3.4225845336914062
# Mesh successfully extracted
# Total time = 5.112062215805054
#
#
# 648518346341397321: Dendrite-0
# Component found in Orphans
# len of vertices = 62932
# Step 1: extracted Soma Mesh = 2.755012273788452
# Mesh successfully extracted
# Total time = 4.06041407585144
#
#
# 648518346341398044: Dendrite-0
# Component found in Orphans
# len of vertices = 28994
# Step 1: extracted Soma Mesh = 1.629133939743042
# Mesh successfully extracted
# Total time = 2.4021849632263184
#
#
# 648518346341398705: Dendrite-0
# Component found in Orphans
# len of vertices = 44282
# Step 1: extracted Soma Mesh = 2.164538860321045
# Mesh successfully extracted
# Total time = 3.1834635734558105
#
#
# 648518346341399382: Dendrite-0
# Component found in Orphans
# len of vertices = 33688
# Step 1: extracted Soma Mesh = 1.512610673904419
# Mesh successfully extracted
# Total time = 2.1505136489868164
#
#
# 648518346341399775: Dendrite-0
# Component found in Orphans
# len of vertices = 121063
# Step 1: extracted Soma Mesh = 3.64913010597229
# Mesh successfully extracted
# Total time = 4.893705606460571
#
#
# 648518346341402768: Dendrite-0
# Component found in Orphans
# len of vertices = 25398
# Step 1: extracted Soma Mesh = 1.2781038284301758
# Mesh successfully extracted
# Total time = 1.7236831188201904
#
#
# 648518346341403789: Dendrite-0
# Component found in Orphans
# len of vertices = 96726
# Step 1: extracted Soma Mesh = 2.2766144275665283
# Mesh successfully extracted
# Total time = 3.1633071899414062
#
#
# 648518346341403967: Apical-0
# Component found in Orphans
# len of vertices = 66367
# Step 1: extracted Soma Mesh = 4.4885783195495605
# Mesh successfully extracted
# Total time = 5.964406490325928
#
#
# 648518346341404564: Dendrite-0
# Component found in Orphans
# len of vertices = 27300
# Step 1: extracted Soma Mesh = 4.223364591598511
# Mesh successfully extracted
# Total time = 5.823037624359131
#
#
# 648518346341405293: Dendrite-0
# Component found in Orphans
# len of vertices = 41118
# Step 1: extracted Soma Mesh = 1.4745814800262451
# Mesh successfully extracted
# Total time = 2.093780994415283
#
#
# 648518346341405932: Dendrite-0
# Component found in Orphans
# len of vertices = 24043
# Step 1: extracted Soma Mesh = 1.1016790866851807
# Mesh successfully extracted
# Total time = 1.6641216278076172
#
#
# 648518346341406928: Dendrite-0
# Component found in Orphans
# len of vertices = 24041
# Step 1: extracted Soma Mesh = 1.2774264812469482
# Mesh successfully extracted
# Total time = 1.757878065109253
#
#
# 648518346341407401: Dendrite-0
# Component found in Orphans
# len of vertices = 40369
# Step 1: extracted Soma Mesh = 1.3501057624816895
# Mesh successfully extracted
# Total time = 2.159291982650757
#
#
# 648518346341408346: Dendrite-0
# Component found in Orphans
# len of vertices = 32925
# Step 1: extracted Soma Mesh = 2.1233644485473633
# Mesh successfully extracted
# Total time = 2.874159812927246
#
#
# 648518346341409710: Dendrite-0
# Component found in Orphans
# len of vertices = 50934
# Step 1: extracted Soma Mesh = 2.556640148162842
# Mesh successfully extracted
# Total time = 3.2224185466766357
#
#
# 648518346341410553: Dendrite-0
# Component found in Orphans
# len of vertices = 56225
# Step 1: extracted Soma Mesh = 2.511263370513916
# Mesh successfully extracted
# Total time = 3.216186285018921
#
#
# 648518346341411303: Dendrite-0
# Component found in Orphans
# len of vertices = 21832
# Step 1: extracted Soma Mesh = 1.2374114990234375
# Mesh successfully extracted
# Total time = 1.668149709701538
#
#
# 648518346341412652: Dendrite-0
# Component found in Orphans
# len of vertices = 38826
# Step 1: extracted Soma Mesh = 2.439457416534424
# Mesh successfully extracted
# Total time = 2.9713709354400635
#
#
# 648518346341414621: Dendrite-0
# Component found in Orphans
# len of vertices = 28636
# Step 1: extracted Soma Mesh = 1.2238612174987793
# Mesh successfully extracted
# Total time = 1.8207206726074219
#
#
# 648518346341416667: Dendrite-0
# Component found in Orphans
# len of vertices = 11524
# Step 1: extracted Soma Mesh = 0.8575952053070068
# Mesh successfully extracted
# Total time = 1.176215648651123
#
#
# 648518346341420202: Dendrite-0
# Component found in Orphans
# len of vertices = 25615
# Step 1: extracted Soma Mesh = 1.0490126609802246
# Mesh successfully extracted
# Total time = 1.5636448860168457
#
#
# 648518346342154237: Dendrite-0
# Component found in Orphans
# len of vertices = 21245
# Step 1: extracted Soma Mesh = 1.000622272491455
# Mesh successfully extracted
# Total time = 1.3872671127319336
#
#
# 648518346342788606: Dendrite-0
# Component found in Orphans
# len of vertices = 44027
# Step 1: extracted Soma Mesh = 1.6730895042419434
# Mesh successfully extracted
# Total time = 2.838442087173462
#
#
# 648518346342790597: Dendrite-0
# Component found in Orphans
# len of vertices = 49552
# Step 1: extracted Soma Mesh = 1.6340675354003906
# Mesh successfully extracted
# Total time = 2.3675153255462646
#
#
# 648518346342790997: Dendrite-0
# Component found in Orphans
# len of vertices = 47295
# Step 1: extracted Soma Mesh = 1.9142932891845703
# Mesh successfully extracted
# Total time = 2.6757586002349854
#
#
# 648518346342791382: Dendrite-0
# Component found in Orphans
# len of vertices = 66139
# Step 1: extracted Soma Mesh = 1.8775792121887207
# Mesh successfully extracted
# Total time = 2.6482126712799072
#
#
# 648518346342792282: Dendrite-0
# Component found in Orphans
# len of vertices = 72974
# Step 1: extracted Soma Mesh = 2.223092555999756
# Mesh successfully extracted
# Total time = 3.0575363636016846
#
#
# 648518346342792761: Dendrite-0
# Component found in Orphans
# len of vertices = 15083
# Step 1: extracted Soma Mesh = 1.5294160842895508
# Mesh successfully extracted
# Total time = 1.9297864437103271
#
#
# 648518346342793061: Dendrite-0
# Component found in Orphans
# len of vertices = 21026
# Step 1: extracted Soma Mesh = 2.3288865089416504
# Mesh successfully extracted
# Total time = 3.279740571975708
#
#
# 648518346342793555: Dendrite-0
# Component found in Orphans
# len of vertices = 36809
# Step 1: extracted Soma Mesh = 1.4435136318206787
# Mesh successfully extracted
# Total time = 2.096961259841919
#
#
# 648518346342793923: Dendrite-0
# Component found in Orphans
# len of vertices = 56115
# Step 1: extracted Soma Mesh = 1.8051586151123047
# Mesh successfully extracted
# Total time = 2.5793404579162598
#
#
# 648518346342794090: Dendrite-0
# Component found in Orphans
# len of vertices = 28095
# Step 1: extracted Soma Mesh = 1.1811325550079346
# Mesh successfully extracted
# Total time = 1.9440982341766357
#
#
# 648518346342796477: Dendrite-0
# Component found in Orphans
# len of vertices = 61329
# Step 1: extracted Soma Mesh = 2.0441043376922607
# Mesh successfully extracted
# Total time = 3.2048299312591553
#
#
# 648518346342796842: Dendrite-0
# Component found in Orphans
# len of vertices = 82320
# Step 1: extracted Soma Mesh = 2.369255542755127
# Mesh successfully extracted
# Total time = 3.132566213607788
#
#
# 648518346342797719: Dendrite-0
# Component found in Orphans
# len of vertices = 54691
# Step 1: extracted Soma Mesh = 4.197940111160278
# Mesh successfully extracted
# Total time = 5.355215311050415
#
#
# 648518346342799012: Dendrite-0
# Component found in Orphans
# len of vertices = 25774
# Step 1: extracted Soma Mesh = 2.445518970489502
# Mesh successfully extracted
# Total time = 3.1638734340667725
#
#
# 648518346342799085: Dendrite-0
# Component found in Orphans
# len of vertices = 18864
# Step 1: extracted Soma Mesh = 1.0232393741607666
# Mesh successfully extracted
# Total time = 1.5466406345367432
#
#
# 648518346342799664: Dendrite-0
# Component found in Orphans
# len of vertices = 18841
# Step 1: extracted Soma Mesh = 0.9709358215332031
# Mesh successfully extracted
# Total time = 1.3363711833953857
#
#
# 648518346342800079: Dendrite-0
# Component found in Orphans
# len of vertices = 19105
# Step 1: extracted Soma Mesh = 1.0585110187530518
# Mesh successfully extracted
# Total time = 1.5212044715881348
#
#
# 648518346342800590: Dendrite-0
# Component found in Orphans
# len of vertices = 55543
# Step 1: extracted Soma Mesh = 3.7377841472625732
# Mesh successfully extracted
# Total time = 5.417169809341431
#
#
# 648518346342802989: Dendrite-0
# Component found in Orphans
# len of vertices = 77914
# Step 1: extracted Soma Mesh = 2.9402732849121094
# Mesh successfully extracted
# Total time = 4.45377779006958
#
#
# 648518346342803865: Dendrite-0
# Component found in Orphans
# len of vertices = 10405
# Step 1: extracted Soma Mesh = 2.543745994567871
# Mesh successfully extracted
# Total time = 3.0283541679382324
#
#
# 648518346342804024: Dendrite-0
# Component found in Orphans
# len of vertices = 22831
# Step 1: extracted Soma Mesh = 1.5280790328979492
# Mesh successfully extracted
# Total time = 1.9705326557159424
#
#
# 648518346342804584: Dendrite-0
# Component found in Orphans
# len of vertices = 62366
# Step 1: extracted Soma Mesh = 2.869356393814087
# Mesh successfully extracted
# Total time = 3.520488739013672
#
#
# 648518346342806373: Dendrite-0
# Component found in Orphans
# len of vertices = 11292
# Step 1: extracted Soma Mesh = 1.4762675762176514
# Mesh successfully extracted
# Total time = 1.8749237060546875
#
#
# 648518346342807112: Dendrite-0
# Component found in Orphans
# len of vertices = 106536
# Step 1: extracted Soma Mesh = 4.048336744308472
# Mesh successfully extracted
# Total time = 5.865052700042725
#
#
# 648518346342807966: Dendrite-0
# Component found in Orphans
# len of vertices = 27727
# Step 1: extracted Soma Mesh = 3.188397169113159
# Mesh successfully extracted
# Total time = 3.7625880241394043
#
#
# 648518346342808805: Dendrite-0
# Component found in Orphans
# len of vertices = 12606
# Step 1: extracted Soma Mesh = 2.4065921306610107
# Mesh successfully extracted
# Total time = 2.958324432373047
#
#
# 648518346342915059: Dendrite-0
# Component found in Orphans
# len of vertices = 21012
# Step 1: extracted Soma Mesh = 1.9907894134521484
# Mesh successfully extracted
# Total time = 2.6993789672851562
#
#
# 648518346342917417: Dendrite-0
# Component found in Orphans
# len of vertices = 15092
# Step 1: extracted Soma Mesh = 1.3956327438354492
# Mesh successfully extracted
# Total time = 1.8114879131317139
#
#
# 648518346342918705: Dendrite-0
# Component found in Orphans
# len of vertices = 86479
# Step 1: extracted Soma Mesh = 4.809091329574585
# Mesh successfully extracted
# Total time = 6.249097108840942
#
#
# 648518346342924888: Dendrite-0
# Component found in Orphans
# len of vertices = 20664
# Step 1: extracted Soma Mesh = 3.094536781311035
# Mesh successfully extracted
# Total time = 4.340294122695923
#
#
# 648518346342930214: Dendrite-0
# Component found in Orphans
# len of vertices = 25541
# Step 1: extracted Soma Mesh = 2.5190811157226562
# Mesh successfully extracted
# Total time = 2.987653970718384
#
#
# 648518346342934077: Dendrite-0
# Component found in Orphans
# len of vertices = 22056
# Step 1: extracted Soma Mesh = 3.036719799041748
# Mesh successfully extracted
# Total time = 3.6217284202575684
#
#
# 648518346343455381: Dendrite-0
# Component found in Orphans
# len of vertices = 10992
# Step 1: extracted Soma Mesh = 1.8583309650421143
# Mesh successfully extracted
# Total time = 2.223600149154663
#
#
# 648518346344071871: Dendrite-0
# Component found in Orphans
# len of vertices = 10527
# Step 1: extracted Soma Mesh = 1.0794906616210938
# Mesh successfully extracted
# Total time = 2.1162972450256348
#
#
# 648518346344072937: Dendrite-0
# Component found in Orphans
# len of vertices = 14544
# Step 1: extracted Soma Mesh = 2.4997506141662598
# Mesh successfully extracted
# Total time = 2.874046564102173
#
#
# 648518346344083113: Dendrite-0
# Component found in Orphans
# len of vertices = 16894
# Step 1: extracted Soma Mesh = 1.6615417003631592
# Mesh successfully extracted
# Total time = 2.090059995651245
#
#
# 648518346344419601: Dendrite-0
# Component found in Orphans
# len of vertices = 35853
# Step 1: extracted Soma Mesh = 2.1892659664154053
# Mesh successfully extracted
# Total time = 2.6632354259490967
#
#
# 648518346345768473: Dendrite-0
# Component found in Orphans
# len of vertices = 12627
# Step 1: extracted Soma Mesh = 1.0805726051330566
# Mesh successfully extracted
# Total time = 1.4218392372131348
#
#
# 648518346345771930: Dendrite-0
# Component found in Orphans
# len of vertices = 17579
# Step 1: extracted Soma Mesh = 1.1219298839569092
# Mesh successfully extracted
# Total time = 1.5171380043029785
#
#
# 648518346346296426: Dendrite-0
# Component found in Orphans
# len of vertices = 54721
# Step 1: extracted Soma Mesh = 2.689361333847046
# Mesh successfully extracted
# Total time = 3.589069128036499
#
#
# 648518346346302170: Dendrite-0
# Component found in Orphans
# len of vertices = 13989
# Step 1: extracted Soma Mesh = 2.3160171508789062
# Mesh successfully extracted
# Total time = 2.9145936965942383
#
#
# 648518346346310958: Dendrite-0
# Component found in Orphans
# len of vertices = 33745
# Step 1: extracted Soma Mesh = 3.270488977432251
# Mesh successfully extracted
# Total time = 3.9131014347076416
#
#
# 648518346348109623: Dendrite-0
# Component found in Orphans
# len of vertices = 14849
# Step 1: extracted Soma Mesh = 1.256960391998291
# Mesh successfully extracted
# Total time = 1.6619787216186523
#
#
# 648518346348190705: Dendrite-0
# Component found in Orphans
# len of vertices = 105359
# Step 1: extracted Soma Mesh = 4.344873428344727
# Mesh successfully extracted
# Total time = 5.118685245513916
#
#
# 648518346349462805: Dendrite-0
# Component found in Orphans
# len of vertices = 56336
# Step 1: extracted Soma Mesh = 5.632383823394775
# Mesh successfully extracted
# Total time = 6.953446865081787
#
#
# 648518346349477155: Oblique-1
# Component found in Orphans
# len of vertices = 41870
# Step 1: extracted Soma Mesh = 13.098233699798584
# Mesh successfully extracted
# Total time = 14.625311136245728
#
#
# 648518346349493495: Dendrite-0
# Component found in Orphans
# len of vertices = 61844
# Step 1: extracted Soma Mesh = 2.8703038692474365
# Mesh successfully extracted
# Total time = 4.464020490646362
#
#
# 648518346349494801: Apical-0
# Component found in Orphans
# len of vertices = 147418
# Step 1: extracted Soma Mesh = 6.802056312561035
# Mesh successfully extracted
# Total time = 12.033586025238037
#
#
# 648518346349500257: Dendrite-0
# Component found in Orphans
# len of vertices = 81885
# Step 1: extracted Soma Mesh = 2.278773784637451
# Mesh successfully extracted
# Total time = 2.8261752128601074
#
#
# 648518346349502882: Dendrite-0
# Component found in Orphans
# len of vertices = 141659
# Step 1: extracted Soma Mesh = 6.75013542175293
# Mesh successfully extracted
# Total time = 10.283382415771484
#
#
# 648518346349508477: Dendrite-0
# Component found in Orphans
# len of vertices = 42898
# Step 1: extracted Soma Mesh = 7.611943244934082
# Mesh successfully extracted
# Total time = 9.891171932220459
#
#
# 648518346349508581: Dendrite-3
# Component found in Orphans
# len of vertices = 27396
# Step 1: extracted Soma Mesh = 3.00287127494812
# Mesh successfully extracted
# Total time = 3.467069149017334
#
#
# 648518346349509415: Apical-0
# Component found in Orphans
# len of vertices = 150002
# Step 1: extracted Soma Mesh = 14.658068656921387
# Mesh successfully extracted
# Total time = 20.027069091796875
# Total time = 496.3097183704376
