# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473160**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473160_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.6648008823394775
# Number of outside child meshes =  10
# Main mesh and outside child meshes make up 0.9650425132557241% of original mesh
#  face length 3778423 using optimized facets with 3 neighbors
# Filtering edges by size finished: 73.98366618156433, facet # = 197024
# Filtering by convexity and getting centers took: 118.81484365463257, facet # = 41414
# Finished facets for main mesh: 199.45252060890198 with facet length = 41414
# Finished 41414 facets for main mesh: 199.45268082618713
# Filtering edges by size finished: 0.47993016242980957, facet # = 1742
# Filtering by convexity and getting centers took: 0.8530840873718262, facet # = 493
# Filtering edges by size finished: 0.6559247970581055, facet # = 1750
# Filtering by convexity and getting centers took: 0.9716949462890625, facet # = 555
# Filtering edges by size finished: 0.8028123378753662, facet # = 1904
# Filtering by convexity and getting centers took: 1.1176631450653076, facet # = 362
# Filtering edges by size finished: 0.17207980155944824, facet # = 781
# Filtering by convexity and getting centers took: 0.30987071990966797, facet # = 254
# Filtering edges by size finished: 0.2711167335510254, facet # = 1155
# Filtering by convexity and getting centers took: 0.45337963104248047, facet # = 298
# Filtering edges by size finished: 0.8427374362945557, facet # = 1803
# Filtering by convexity and getting centers took: 1.1296699047088623, facet # = 443
# Filtering edges by size finished: 0.00776219367980957, facet # = 12
# Filtering by convexity and getting centers took: 0.0061604976654052734, facet # = 7
# Filtering edges by size finished: 0.021235942840576172, facet # = 32
# Filtering by convexity and getting centers took: 0.023714065551757812, facet # = 3
# Filtering edges by size finished: 0.025880098342895508, facet # = 25
# Filtering by convexity and getting centers took: 0.02274346351623535, facet # = 6
# Filtering edges by size finished: 0.005478382110595703, facet # = 25
# Filtering by convexity and getting centers took: 0.022195816040039062, facet # = 14
# Total time for facets: 207.82607460021973
# Zero faceted faces = []
# Starting Child 0
# 493 41414
# Done distance matrix: 1.0674173831939697
# Child 0 There were no points close enough
# Starting Child 1
# 555 41414
# Done distance matrix: 1.2211799621582031
# Done Generating final pairs: 1.2637355327606201
# best_stitch_pair = [  216 16831]
# best_stitch_pair_size = 129634.26440471836
# best_stitch_pair_distance = 32.59881631788062
# best_stitch_pair_size_ratio = 0.8547892154857366
# Starting Child 2
# 362 41414
# Done distance matrix: 0.7895040512084961
# Done Generating final pairs: 0.8446142673492432
# best_stitch_pair = [ 207 1686]
# best_stitch_pair_size = 2704924.4565931694
# best_stitch_pair_distance = 611.6804494780337
# best_stitch_pair_size_ratio = 0.892440457927661
# Starting Child 3
# 254 41414
# Done distance matrix: 0.6041440963745117
# Done Generating final pairs: 0.6500747203826904
# best_stitch_pair = [  182 24426]
# best_stitch_pair_size = 71274.25391931988
# best_stitch_pair_distance = 1187.1520574353553
# best_stitch_pair_size_ratio = 0.8980137588463438
# Starting Child 4
# 298 41414
# Done distance matrix: 0.5925388336181641
# Done Generating final pairs: 0.6395156383514404
# best_stitch_pair = [   22 14031]
# best_stitch_pair_size = 58707.14697336708
# best_stitch_pair_distance = 118.4902467408563
# best_stitch_pair_size_ratio = 0.9842908214218783
# Starting Child 5
# 443 41414
# Done distance matrix: 1.0031218528747559
# Done Generating final pairs: 1.039369821548462
# best_stitch_pair = [  313 26592]
# best_stitch_pair_size = 30103.469274618652
# best_stitch_pair_distance = 858.0055046395855
# best_stitch_pair_size_ratio = 0.5473067231869783
# Starting Child 6
# 7 41414
# Done distance matrix: 0.04683279991149902
# Child 6 There were no points close enough
# Starting Child 7
# 3 41414
# Done distance matrix: 0.00439143180847168
# Child 7 There were no points close enough
# Starting Child 8
# 6 41414
# Done distance matrix: 0.0087738037109375
# Done Generating final pairs: 0.03327155113220215
# best_stitch_pair = [    4 15342]
# best_stitch_pair_size = 46155.3153770451
# best_stitch_pair_distance = 188.5900364720884
# best_stitch_pair_size_ratio = 0.2594145329689089
# Starting Child 9
# 14 41414
# Done distance matrix: 0.025945186614990234
# Child 9 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [216, 16831], 2: [207, 1686], 3: [182, 24426], 4: [22, 14031], 5: [313, 26592], 8: [4, 15342]}
# ---Stitching child 1 with pair: [216, 16831]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 646970, starting edge 2nd facet= 1898117,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 3.910064697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.26354241371154785
# returned from stitch mesh: 3.019575595855713
# Finished stitching child 1 : 3.5664100646972656
# ---Stitching child 2 with pair: [207, 1686]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 530981, starting edge 2nd facet= 1904049,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# edge_1_order done, len = 32
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 7.510185241699219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1334683895111084
# returned from stitch mesh: 3.537721872329712
# Finished stitching child 2 : 3.8983101844787598
# ---Stitching child 3 with pair: [182, 24426]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1118273, starting edge 2nd facet= 1909616,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3589859008789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08232760429382324
# returned from stitch mesh: 3.367150068283081
# Finished stitching child 3 : 3.7826194763183594
# ---Stitching child 4 with pair: [22, 14031]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 665764, starting edge 2nd facet= 1912428,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.10474586486816406
# returned from stitch mesh: 3.208348274230957
# Finished stitching child 4 : 3.6223864555358887
# ---Stitching child 5 with pair: [313, 26592]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1137644, starting edge 2nd facet= 1918011,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.7404556274414062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06971979141235352
# returned from stitch mesh: 2.831214189529419
# Finished stitching child 5 : 3.2199583053588867
# ---Stitching child 8 with pair: [4, 15342]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 115646, starting edge 2nd facet= 1922504,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.2636184692382812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1373889446258545
# returned from stitch mesh: 2.589128255844116
# Finished stitching child 8 : 2.9975879192352295
# ***************Finished big stitching iteration: 28.27880311012268***************
# Starting Child 0
# 493 43320
# Done distance matrix: 1.526137351989746
# Done Generating final pairs: 1.5299384593963623
# best_stitch_pair = [  318 41677]
# best_stitch_pair_size = 20888.211951113208
# best_stitch_pair_distance = 1558.5638583923997
# best_stitch_pair_size_ratio = 0.8201633263816724
# Starting Child 6
# 7 43320
# Done distance matrix: 0.02444148063659668
# Done Generating final pairs: 0.030272960662841797
# best_stitch_pair = [    3 41683]
# best_stitch_pair_size = 67468.14208482255
# best_stitch_pair_distance = 790.2014895807099
# best_stitch_pair_size_ratio = 0.34592739648767945
# Starting Child 7
# 3 43320
# Done distance matrix: 0.006851673126220703
# Done Generating final pairs: 0.015337467193603516
# best_stitch_pair = [    1 43099]
# best_stitch_pair_size = 113625.49073931917
# best_stitch_pair_distance = 891.6102005728931
# best_stitch_pair_size_ratio = 0.5656942302978782
# Starting Child 9
# 14 43320
# Done distance matrix: 0.027322769165039062
# Child 9 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [318, 41677], 6: [3, 41683], 7: [1, 43099]}
# ---Stitching child 0 with pair: [318, 41677]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1896629, starting edge 2nd facet= 1927991,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.19280552864074707
# returned from stitch mesh: 4.609485626220703
# Finished stitching child 0 : 5.184329986572266
# ---Stitching child 6 with pair: [3, 41683]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1896453, starting edge 2nd facet= 1929418,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.9325485229492188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.061777591705322266
# returned from stitch mesh: 3.4290692806243896
# Finished stitching child 6 : 4.100579738616943
# ---Stitching child 7 with pair: [1, 43099]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1918765, starting edge 2nd facet= 1929510,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.6464462280273438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.15288972854614258
# returned from stitch mesh: 3.0395255088806152
# Finished stitching child 7 : 3.5152547359466553
# ***************Finished big stitching iteration: 18.242291688919067***************
# Starting Child 9
# 14 43817
# Done distance matrix: 0.029729843139648438
# Done Generating final pairs: 0.7691972255706787
# best_stitch_pair = [    2 43432]
# best_stitch_pair_size = 81142.31172493134
# best_stitch_pair_distance = 1804.6186802232867
# best_stitch_pair_size_ratio = 0.24557690621313685
# repeat_main_facets = []
# child_meshes_stitch_facets = {9: [2, 43432]}
# ---Stitching child 9 with pair: [2, 43432]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1926810, starting edge 2nd facet= 1929667,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.2874603271484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05712580680847168
# returned from stitch mesh: 3.348933458328247
# Finished stitching child 9 : 3.9898557662963867
# ***************Finished big stitching iteration: 8.799649953842163***************
# All children have been processed
# total_stitch_processing_time = 55.34434962272644
# Total time for restitching = 55.351431131362915
# missed_children = []
# Whole stitching function complete: 275.00459337234497
#
#
#
# *****Running Neuron Stitcher for 648518346349476961**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349476961_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.046764850616455
# Number of outside child meshes =  29
# Main mesh and outside child meshes make up 0.982465542282439% of original mesh
#  face length 2226071 using optimized facets with 3 neighbors
# Filtering edges by size finished: 69.31301951408386, facet # = 109195
# Filtering by convexity and getting centers took: 73.26795864105225, facet # = 25706
# Finished facets for main mesh: 150.28144931793213 with facet length = 25706
# Finished 25706 facets for main mesh: 150.28183031082153
# Filtering edges by size finished: 0.02402663230895996, facet # = 52
# Filtering by convexity and getting centers took: 0.024591684341430664, facet # = 17
# Filtering edges by size finished: 0.043581485748291016, facet # = 135
# Filtering by convexity and getting centers took: 0.07312965393066406, facet # = 50
# Filtering edges by size finished: 0.20293235778808594, facet # = 632
# Filtering by convexity and getting centers took: 0.6737501621246338, facet # = 193
# Filtering edges by size finished: 0.6644291877746582, facet # = 1542
# Filtering by convexity and getting centers took: 0.6181836128234863, facet # = 367
# Filtering edges by size finished: 0.0723717212677002, facet # = 205
# Filtering by convexity and getting centers took: 0.17080283164978027, facet # = 58
# Filtering edges by size finished: 0.017621755599975586, facet # = 38
# Filtering by convexity and getting centers took: 0.018056154251098633, facet # = 15
# Filtering edges by size finished: 0.08523273468017578, facet # = 382
# Filtering by convexity and getting centers took: 0.19524240493774414, facet # = 120
# Filtering edges by size finished: 0.015776634216308594, facet # = 75
# Filtering by convexity and getting centers took: 0.023720502853393555, facet # = 36
# Filtering edges by size finished: 0.013820648193359375, facet # = 58
# Filtering by convexity and getting centers took: 0.01825881004333496, facet # = 23
# Filtering edges by size finished: 0.0027647018432617188, facet # = 4
# Filtering by convexity and getting centers took: 0.0025281906127929688, facet # = 4
# Filtering edges by size finished: 0.03610849380493164, facet # = 231
# Filtering by convexity and getting centers took: 0.06450700759887695, facet # = 54
# Filtering edges by size finished: 0.051729440689086914, facet # = 257
# Filtering by convexity and getting centers took: 0.1760408878326416, facet # = 99
# Filtering edges by size finished: 0.01866936683654785, facet # = 51
# Filtering by convexity and getting centers took: 0.05368638038635254, facet # = 17
# Filtering edges by size finished: 0.05353236198425293, facet # = 141
# Filtering by convexity and getting centers took: 0.12824654579162598, facet # = 30
# Filtering edges by size finished: 0.0060503482818603516, facet # = 31
# Filtering by convexity and getting centers took: 0.01577281951904297, facet # = 16
# Filtering edges by size finished: 0.025188446044921875, facet # = 83
# Filtering by convexity and getting centers took: 0.07715201377868652, facet # = 40
# Filtering edges by size finished: 0.06379842758178711, facet # = 81
# Filtering by convexity and getting centers took: 0.04791426658630371, facet # = 33
# Filtering edges by size finished: 0.030606508255004883, facet # = 60
# Filtering by convexity and getting centers took: 0.057062387466430664, facet # = 14
# Filtering edges by size finished: 0.028824329376220703, facet # = 54
# Filtering by convexity and getting centers took: 0.04350900650024414, facet # = 15
# Filtering edges by size finished: 0.017964839935302734, facet # = 79
# Filtering by convexity and getting centers took: 0.03401899337768555, facet # = 25
# Filtering edges by size finished: 0.005119800567626953, facet # = 19
# Filtering by convexity and getting centers took: 0.008798360824584961, facet # = 9
# Filtering edges by size finished: 0.06367921829223633, facet # = 131
# Filtering by convexity and getting centers took: 0.06941604614257812, facet # = 58
# Filtering edges by size finished: 0.07185983657836914, facet # = 127
# Filtering by convexity and getting centers took: 0.10427331924438477, facet # = 36
# Filtering edges by size finished: 0.00226593017578125, facet # = 9
# Filtering by convexity and getting centers took: 0.004879951477050781, facet # = 6
# Filtering edges by size finished: 0.01153111457824707, facet # = 38
# Filtering by convexity and getting centers took: 0.017732858657836914, facet # = 22
# Filtering edges by size finished: 0.0014836788177490234, facet # = 6
# Filtering by convexity and getting centers took: 0.0030679702758789062, facet # = 4
# Filtering edges by size finished: 0.013352394104003906, facet # = 41
# Filtering by convexity and getting centers took: 0.018436431884765625, facet # = 14
# Filtering edges by size finished: 0.12421131134033203, facet # = 315
# Filtering by convexity and getting centers took: 0.40809106826782227, facet # = 99
# Filtering edges by size finished: 0.0068171024322509766, facet # = 36
# Filtering by convexity and getting centers took: 0.032352447509765625, facet # = 16
# Total time for facets: 155.4813733100891
# Zero faceted faces = []
# Starting Child 0
# 17 25706
# Done distance matrix: 0.030904531478881836
# Child 0 There were no points close enough
# Starting Child 1
# 50 25706
# Done distance matrix: 0.10999107360839844
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# 193 25706
# Done distance matrix: 0.3086700439453125
# Done Generating final pairs: 0.33373498916625977
# best_stitch_pair = [  41 5527]
# best_stitch_pair_size = 76653.52732930337
# best_stitch_pair_distance = 1658.2765884071794
# best_stitch_pair_size_ratio = 0.6704810844425274
# Starting Child 3
# 367 25706
# Done distance matrix: 0.35013842582702637
# Done Generating final pairs: 0.3783705234527588
# best_stitch_pair = [   97 16732]
# best_stitch_pair_size = 536977.1035937646
# best_stitch_pair_distance = 812.9726915779902
# best_stitch_pair_size_ratio = 0.37157342253248105
# Starting Child 4
# returning x greater max
# skipped by bounding box filter
# Starting Child 5
# returning x less min
# skipped by bounding box filter
# Starting Child 6
# 120 25706
# Done distance matrix: 0.17733216285705566
# Child 6 There were no points close enough
# Starting Child 7
# 36 25706
# Done distance matrix: 0.03769254684448242
# Child 7 There were no points close enough
# Starting Child 8
# returning x less min
# skipped by bounding box filter
# Starting Child 9
# returning x greater max
# skipped by bounding box filter
# Starting Child 10
# 54 25706
# Done distance matrix: 0.05527472496032715
# Done Generating final pairs: 0.0693669319152832
# best_stitch_pair = [   21 16740]
# best_stitch_pair_size = 27314.416296853815
# best_stitch_pair_distance = 1044.63979826343
# best_stitch_pair_size_ratio = 0.33359365103255273
# Starting Child 11
# 99 25706
# Done distance matrix: 0.08507776260375977
# Done Generating final pairs: 0.10745835304260254
# best_stitch_pair = [  79 5526]
# best_stitch_pair_size = 129107.71082945722
# best_stitch_pair_distance = 589.4110719469768
# best_stitch_pair_size_ratio = 0.4529014267898131
# Starting Child 12
# 17 25706
# Done distance matrix: 0.018567562103271484
# Child 12 There were no points close enough
# Starting Child 13
# 30 25706
# Done distance matrix: 0.02778458595275879
# Child 13 There were no points close enough
# Starting Child 14
# 16 25706
# Done distance matrix: 0.013503313064575195
# Child 14 There were no points close enough
# Starting Child 15
# 40 25706
# Done distance matrix: 0.043633460998535156
# Done Generating final pairs: 0.062256574630737305
# best_stitch_pair = [   1 8716]
# best_stitch_pair_size = 64601.3983876941
# best_stitch_pair_distance = 712.6457538405825
# best_stitch_pair_size_ratio = 0.4254207633601088
# Starting Child 16
# 33 25706
# Done distance matrix: 0.0385136604309082
# Child 16 There were no points close enough
# Starting Child 17
# 14 25706
# Done distance matrix: 0.015748977661132812
# Child 17 There were no points close enough
# Starting Child 18
# 15 25706
# Done distance matrix: 0.01732468605041504
# Child 18 There were no points close enough
# Starting Child 19
# 25 25706
# Done distance matrix: 0.02755594253540039
# Child 19 There were no points close enough
# Starting Child 20
# 9 25706
# Done distance matrix: 0.011641740798950195
# Child 20 There were no points close enough
# Starting Child 21
# 58 25706
# Done distance matrix: 0.10069918632507324
# Done Generating final pairs: 0.1656055450439453
# best_stitch_pair = [   2 7044]
# best_stitch_pair_size = 60699.36065037907
# best_stitch_pair_distance = 1813.6032887258518
# best_stitch_pair_size_ratio = 0.9350504488179978
# Starting Child 22
# 36 25706
# Done distance matrix: 0.03908252716064453
# Child 22 There were no points close enough
# Starting Child 23
# 6 25706
# Done distance matrix: 0.008317708969116211
# Child 23 There were no points close enough
# Starting Child 24
# 22 25706
# Done distance matrix: 0.02371048927307129
# Child 24 There were no points close enough
# Starting Child 25
# 4 25706
# Done distance matrix: 0.003785371780395508
# Child 25 There were no points close enough
# Starting Child 26
# returning x greater max
# skipped by bounding box filter
# Starting Child 27
# returning x greater max
# skipped by bounding box filter
# Starting Child 28
# 16 25706
# Done distance matrix: 0.017464160919189453
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [41, 5527], 3: [97, 16732], 10: [21, 16740], 11: [79, 5526], 15: [1, 8716], 21: [2, 7044]}
# ---Stitching child 2 with pair: [41, 5527]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 364201, starting edge 2nd facet= 1119126,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03938937187194824
# returned from stitch mesh: 1.5863170623779297
# Finished stitching child 2 : 1.9401485919952393
# ---Stitching child 3 with pair: [97, 16732]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1024963, starting edge 2nd facet= 1125309,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 4.38690185546875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03920912742614746
# returned from stitch mesh: 1.7861742973327637
# Finished stitching child 3 : 2.060026168823242
# ---Stitching child 10 with pair: [21, 16740]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 498323, starting edge 2nd facet= 1126078,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.2636184692382812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.034680843353271484
# returned from stitch mesh: 2.2259442806243896
# Finished stitching child 10 : 2.4713029861450195
# ---Stitching child 11 with pair: [79, 5526]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1110398, starting edge 2nd facet= 1127448,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 6.771087646484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06575608253479004
# returned from stitch mesh: 1.630826711654663
# Finished stitching child 11 : 1.8203907012939453
# ---Stitching child 15 with pair: [1, 8716]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1063770, starting edge 2nd facet= 1127765,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03810572624206543
# returned from stitch mesh: 2.053032875061035
# Finished stitching child 15 : 2.468111991882324
# ---Stitching child 21 with pair: [2, 7044]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 608840, starting edge 2nd facet= 1127990,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0060269832611083984
# returned from stitch mesh: 1.735445261001587
# Finished stitching child 21 : 1.9269707202911377
# ***************Finished big stitching iteration: 15.732259511947632***************
# Starting Child 0
# 17 26505
# Done distance matrix: 0.02002716064453125
# Done Generating final pairs: 0.024385690689086914
# best_stitch_pair = [   16 26298]
# best_stitch_pair_size = 44039.47322665746
# best_stitch_pair_distance = 364.99366823410213
# best_stitch_pair_size_ratio = 0.824717676003071
# Starting Child 1
# 50 26505
# Done distance matrix: 0.04884052276611328
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# returning x greater max
# skipped by bounding box filter
# Starting Child 5
# 15 26505
# Done distance matrix: 0.01897144317626953
# Child 5 There were no points close enough
# Starting Child 6
# 120 26505
# Done distance matrix: 0.13213276863098145
# Child 6 There were no points close enough
# Starting Child 7
# 36 26505
# Done distance matrix: 0.029952049255371094
# Child 7 There were no points close enough
# Starting Child 8
# 23 26505
# Done distance matrix: 0.025089263916015625
# Done Generating final pairs: 0.0296022891998291
# best_stitch_pair = [   11 26461]
# best_stitch_pair_size = 295649.2346276391
# best_stitch_pair_distance = 1810.711241052368
# best_stitch_pair_size_ratio = 0.31507756567591266
# Starting Child 9
# returning x greater max
# skipped by bounding box filter
# Starting Child 12
# 17 26505
# Done distance matrix: 0.019562244415283203
# Child 12 There were no points close enough
# Starting Child 13
# 30 26505
# Done distance matrix: 0.030304431915283203
# Child 13 There were no points close enough
# Starting Child 14
# 16 26505
# Done distance matrix: 0.013018131256103516
# Child 14 There were no points close enough
# Starting Child 16
# 33 26505
# Done distance matrix: 0.03899812698364258
# Child 16 There were no points close enough
# Starting Child 17
# 14 26505
# Done distance matrix: 0.015019416809082031
# Done Generating final pairs: 0.017175912857055664
# best_stitch_pair = [    8 26433]
# best_stitch_pair_size = 54746.55390868244
# best_stitch_pair_distance = 1708.5115111515108
# best_stitch_pair_size_ratio = 0.6707336827783412
# Starting Child 18
# 15 26505
# Done distance matrix: 0.01639842987060547
# Child 18 There were no points close enough
# Starting Child 19
# 25 26505
# Done distance matrix: 0.02706432342529297
# Child 19 There were no points close enough
# Starting Child 20
# 9 26505
# Done distance matrix: 0.013231754302978516
# Done Generating final pairs: 0.018868446350097656
# best_stitch_pair = [    2 26433]
# best_stitch_pair_size = 50362.110976246826
# best_stitch_pair_distance = 572.6318005462795
# best_stitch_pair_size_ratio = 0.5369309871847854
# Starting Child 22
# 36 26505
# Done distance matrix: 0.04053521156311035
# Child 22 There were no points close enough
# Starting Child 23
# 6 26505
# Done distance matrix: 0.0077092647552490234
# Child 23 There were no points close enough
# Starting Child 24
# 22 26505
# Done distance matrix: 0.024017333984375
# Child 24 There were no points close enough
# Starting Child 25
# 4 26505
# Done distance matrix: 0.005095005035400391
# Child 25 There were no points close enough
# Starting Child 26
# 14 26505
# Done distance matrix: 0.015289068222045898
# Done Generating final pairs: 0.019988059997558594
# best_stitch_pair = [    0 25990]
# best_stitch_pair_size = 106362.20411466784
# best_stitch_pair_distance = 1124.8359380858315
# best_stitch_pair_size_ratio = 0.5385249412580709
# Starting Child 27
# 99 26505
# Done distance matrix: 0.10259699821472168
# Done Generating final pairs: 0.1057131290435791
# best_stitch_pair = [   43 25990]
# best_stitch_pair_size = 137368.56581877035
# best_stitch_pair_distance = 1885.8604572996974
# best_stitch_pair_size_ratio = 0.9870306977578295
# Starting Child 28
# 16 26505
# Done distance matrix: 0.017416000366210938
# Child 28 There were no points close enough
# repeat_main_facets = [26433, 25990]
# child_mesh_double_indexes = [17, 20]
# min_child = 20, max_ratio = 572.6318005462795
# child_mesh_double_indexes = [26, 27]
# min_child = 26, max_ratio = 1124.8359380858315
# child_meshes_stitch_facets = {0: [16, 26298], 8: [11, 26461], 20: [2, 26433], 26: [0, 25990]}
# ---Stitching child 0 with pair: [16, 26298]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1126311, starting edge 2nd facet= 1128612,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.1920928955078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03341865539550781
# returned from stitch mesh: 1.6035194396972656
# Finished stitching child 0 : 1.9360182285308838
# ---Stitching child 8 with pair: [11, 26461]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1128045, starting edge 2nd facet= 1128874,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.7670135498046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.056621551513671875
# returned from stitch mesh: 2.0581297874450684
# Finished stitching child 8 : 2.243690252304077
# ---Stitching child 20 with pair: [2, 26433]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1127916, starting edge 2nd facet= 1128985,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03789854049682617
# returned from stitch mesh: 1.6223669052124023
# Finished stitching child 20 : 1.9246044158935547
# ---Stitching child 26 with pair: [0, 25990]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1123100, starting edge 2nd facet= 1129031,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.5033950805664062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03391265869140625
# returned from stitch mesh: 1.808319091796875
# Finished stitching child 26 : 2.2652666568756104
# ***************Finished big stitching iteration: 11.170243978500366***************
# Starting Child 1
# 50 26560
# Done distance matrix: 0.08470273017883301
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 58 26560
# Done distance matrix: 0.10289239883422852
# Child 4 There were no points close enough
# Starting Child 5
# 15 26560
# Done distance matrix: 0.029535293579101562
# Child 5 There were no points close enough
# Starting Child 6
# 120 26560
# Done distance matrix: 0.23041415214538574
# Child 6 There were no points close enough
# Starting Child 7
# 36 26560
# Done distance matrix: 0.030347824096679688
# Child 7 There were no points close enough
# Starting Child 9
# returning x greater max
# skipped by bounding box filter
# Starting Child 12
# 17 26560
# Done distance matrix: 0.014570236206054688
# Child 12 There were no points close enough
# Starting Child 13
# 30 26560
# Done distance matrix: 0.024930953979492188
# Child 13 There were no points close enough
# Starting Child 14
# 16 26560
# Done distance matrix: 0.013435125350952148
# Child 14 There were no points close enough
# Starting Child 16
# 33 26560
# Done distance matrix: 0.028981685638427734
# Child 16 There were no points close enough
# Starting Child 17
# 14 26560
# Done distance matrix: 0.024855852127075195
# Done Generating final pairs: 0.02866053581237793
# best_stitch_pair = [    8 26542]
# best_stitch_pair_size = 56660.23198471775
# best_stitch_pair_distance = 508.01014006186443
# best_stitch_pair_size_ratio = 0.6337236687020239
# Starting Child 18
# 15 26560
# Done distance matrix: 0.017569303512573242
# Child 18 There were no points close enough
# Starting Child 19
# 25 26560
# Done distance matrix: 0.027417659759521484
# Done Generating final pairs: 0.029955387115478516
# best_stitch_pair = [   21 26504]
# best_stitch_pair_size = 23857.142147535313
# best_stitch_pair_distance = 1706.0800147577847
# best_stitch_pair_size_ratio = 0.9180132055029866
# Starting Child 22
# 36 26560
# Done distance matrix: 0.04612445831298828
# Child 22 There were no points close enough
# Starting Child 23
# 6 26560
# Done distance matrix: 0.008141756057739258
# Child 23 There were no points close enough
# Starting Child 24
# 22 26560
# Done distance matrix: 0.08572101593017578
# Child 24 There were no points close enough
# Starting Child 25
# 4 26560
# Done distance matrix: 0.052193403244018555
# Child 25 There were no points close enough
# Starting Child 27
# 99 26560
# Done distance matrix: 0.2069845199584961
# Done Generating final pairs: 0.21506881713867188
# best_stitch_pair = [   43 26552]
# best_stitch_pair_size = 185197.90230765135
# best_stitch_pair_distance = 428.91169992902377
# best_stitch_pair_size_ratio = 0.5834034032160014
# Starting Child 28
# 16 26560
# Done distance matrix: 0.018772125244140625
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {17: [8, 26542], 19: [21, 26504], 27: [43, 26552]}
# ---Stitching child 17 with pair: [8, 26542]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1128950, starting edge 2nd facet= 1129369,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03896331787109375
# returned from stitch mesh: 1.4637129306793213
# Finished stitching child 17 : 1.757904052734375
# ---Stitching child 19 with pair: [21, 26504]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1128624, starting edge 2nd facet= 1129767,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03389787673950195
# returned from stitch mesh: 1.8923990726470947
# Finished stitching child 19 : 2.3711471557617188
# ---Stitching child 27 with pair: [43, 26552]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129156, starting edge 2nd facet= 1130618,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.6464462280273438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022214412689208984
# returned from stitch mesh: 2.3856348991394043
# Finished stitching child 27 : 2.6034843921661377
# ***************Finished big stitching iteration: 10.393812656402588***************
# Starting Child 1
# 50 26692
# Done distance matrix: 0.0592343807220459
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 58 26692
# Done distance matrix: 0.04953718185424805
# Done Generating final pairs: 0.054152727127075195
# best_stitch_pair = [    5 26639]
# best_stitch_pair_size = 79364.72248989188
# best_stitch_pair_distance = 1370.2113777400155
# best_stitch_pair_size_ratio = 0.16451624291596528
# Starting Child 5
# 15 26692
# Done distance matrix: 0.016188383102416992
# Child 5 There were no points close enough
# Starting Child 6
# 120 26692
# Done distance matrix: 0.16143012046813965
# Child 6 There were no points close enough
# Starting Child 7
# 36 26692
# Done distance matrix: 0.04415488243103027
# Child 7 There were no points close enough
# Starting Child 9
# returning x greater max
# skipped by bounding box filter
# Starting Child 12
# 17 26692
# Done distance matrix: 0.019220829010009766
# Child 12 There were no points close enough
# Starting Child 13
# 30 26692
# Done distance matrix: 0.03440070152282715
# Child 13 There were no points close enough
# Starting Child 14
# 16 26692
# Done distance matrix: 0.03960895538330078
# Child 14 There were no points close enough
# Starting Child 16
# 33 26692
# Done distance matrix: 0.05460619926452637
# Done Generating final pairs: 0.05988812446594238
# best_stitch_pair = [   23 26570]
# best_stitch_pair_size = 567821.8555532625
# best_stitch_pair_distance = 961.1032695690939
# best_stitch_pair_size_ratio = 0.17334863562517888
# Starting Child 18
# 15 26692
# Done distance matrix: 0.017665386199951172
# Done Generating final pairs: 0.03336763381958008
# best_stitch_pair = [    4 26570]
# best_stitch_pair_size = 924465.648810853
# best_stitch_pair_distance = 282.36903499100544
# best_stitch_pair_size_ratio = 0.9103183456326327
# Starting Child 22
# 36 26692
# Done distance matrix: 0.09021472930908203
# Child 22 There were no points close enough
# Starting Child 23
# 6 26692
# Done distance matrix: 0.015743732452392578
# Child 23 There were no points close enough
# Starting Child 24
# 22 26692
# Done distance matrix: 0.04507136344909668
# Done Generating final pairs: 0.05424642562866211
# best_stitch_pair = [    4 26563]
# best_stitch_pair_size = 38367.810307581436
# best_stitch_pair_distance = 1291.470626602624
# best_stitch_pair_size_ratio = 0.42834043330994565
# Starting Child 25
# 4 26692
# Done distance matrix: 0.04015469551086426
# Done Generating final pairs: 0.04868316650390625
# best_stitch_pair = [    0 26566]
# best_stitch_pair_size = 92662.46703391167
# best_stitch_pair_distance = 1322.278887806358
# best_stitch_pair_size_ratio = 0.209615802376154
# Starting Child 28
# 16 26692
# Done distance matrix: 0.029847145080566406
# Child 28 There were no points close enough
# repeat_main_facets = [26570]
# child_mesh_double_indexes = [16, 18]
# min_child = 18, max_ratio = 282.36903499100544
# child_meshes_stitch_facets = {4: [5, 26639], 18: [4, 26570], 24: [4, 26563], 25: [0, 26566]}
# ---Stitching child 4 with pair: [5, 26639]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1130229, starting edge 2nd facet= 1131607,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.47955322265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07028937339782715
# returned from stitch mesh: 2.0154192447662354
# Finished stitching child 4 : 2.364107370376587
# ---Stitching child 18 with pair: [4, 26570]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129506, starting edge 2nd facet= 1131828,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 22
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 5.6743621826171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04195046424865723
# returned from stitch mesh: 1.6636462211608887
# Finished stitching child 18 : 1.9275391101837158
# ---Stitching child 24 with pair: [4, 26563]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129331, starting edge 2nd facet= 1132009,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03804802894592285
# returned from stitch mesh: 1.9498412609100342
# Finished stitching child 24 : 2.204685926437378
# ---Stitching child 25 with pair: [0, 26566]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129311, starting edge 2nd facet= 1132084,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.4080276489257812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.044858694076538086
# returned from stitch mesh: 1.5460124015808105
# Finished stitching child 25 : 1.7560615539550781
# ***************Finished big stitching iteration: 10.76879620552063***************
# Starting Child 1
# 50 26783
# Done distance matrix: 0.0743551254272461
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 15 26783
# Done distance matrix: 0.017983675003051758
# Child 5 There were no points close enough
# Starting Child 6
# 120 26783
# Done distance matrix: 0.2937605381011963
# Child 6 There were no points close enough
# Starting Child 7
# 36 26783
# Done distance matrix: 0.06046414375305176
# Child 7 There were no points close enough
# Starting Child 9
# 4 26783
# Done distance matrix: 0.005868196487426758
# Done Generating final pairs: 0.020757675170898438
# best_stitch_pair = [    1 26707]
# best_stitch_pair_size = 631961.6163590504
# best_stitch_pair_distance = 966.2046620905359
# best_stitch_pair_size_ratio = 0.20546785827128358
# Starting Child 12
# 17 26783
# Done distance matrix: 0.01902604103088379
# Child 12 There were no points close enough
# Starting Child 13
# 30 26783
# Done distance matrix: 0.033527374267578125
# Child 13 There were no points close enough
# Starting Child 14
# 16 26783
# Done distance matrix: 0.021094560623168945
# Child 14 There were no points close enough
# Starting Child 16
# 33 26783
# Done distance matrix: 0.04871034622192383
# Done Generating final pairs: 0.058652639389038086
# best_stitch_pair = [   23 26752]
# best_stitch_pair_size = 336737.436815221
# best_stitch_pair_distance = 207.98571589147116
# best_stitch_pair_size_ratio = 0.3317762800362231
# Starting Child 22
# 36 26783
# Done distance matrix: 0.09909820556640625
# Child 22 There were no points close enough
# Starting Child 23
# 6 26783
# Done distance matrix: 0.008615732192993164
# Child 23 There were no points close enough
# Starting Child 28
# 16 26783
# Done distance matrix: 0.036676645278930664
# Child 28 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {9: [1, 26707], 16: [23, 26752]}
# ---Stitching child 9 with pair: [1, 26707]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1131246, starting edge 2nd facet= 1132128,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 46
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 10
# About to add faces
# Finished adding faces: 7.653236389160156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12088561058044434
# returned from stitch mesh: 1.673133134841919
# Finished stitching child 9 : 2.1010305881500244
# ---Stitching child 16 with pair: [23, 26752]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1131798, starting edge 2nd facet= 1132414,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 3.409385681152344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03742170333862305
# returned from stitch mesh: 1.5295019149780273
# Finished stitching child 16 : 1.7606072425842285
# ***************Finished big stitching iteration: 6.5225934982299805***************
# Starting Child 1
# 50 26816
# Done distance matrix: 0.0442960262298584
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 15 26816
# Done distance matrix: 0.012776851654052734
# Child 5 There were no points close enough
# Starting Child 6
# 120 26816
# Done distance matrix: 0.11236953735351562
# Child 6 There were no points close enough
# Starting Child 7
# 36 26816
# Done distance matrix: 0.04358863830566406
# ...
# Starting Child 45
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 47
# 1 39013
# Done distance matrix: 0.0015289783477783203
# Child 47 There were no points close enough
# Starting Child 54
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 56
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 66
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 86
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 91
# 1 39013
# Done distance matrix: 0.0013375282287597656
# Child 91 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 94
# 1 39013
# Done distance matrix: 0.0014510154724121094
# Child 94 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 109
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# 1 39013
# Done distance matrix: 0.0014295578002929688
# Child 112 There were no points close enough
# Starting Child 113
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 114
# 1 39013
# Done distance matrix: 0.0014963150024414062
# Child 114 There were no points close enough
# Starting Child 120
# 1 39013
# Done distance matrix: 0.0015544891357421875
# Child 120 There were no points close enough
# Starting Child 122
# 1 39013
# Done distance matrix: 0.0015788078308105469
# Child 122 There were no points close enough
# Starting Child 131
# 1 39013
# Done distance matrix: 0.0013935565948486328
# Child 131 There were no points close enough
# Starting Child 133
# 1 39013
# Done distance matrix: 0.0014033317565917969
# Child 133 There were no points close enough
# Starting Child 134
# 1 39013
# Done distance matrix: 0.0013756752014160156
# Child 134 There were no points close enough
# Starting Child 145
# 1 39013
# Done distance matrix: 0.0013170242309570312
# Child 145 There were no points close enough
# Starting Child 152
# 1 39013
# Done distance matrix: 0.0013356208801269531
# Child 152 There were no points close enough
# Starting Child 159
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 163
# 1 39013
# Done distance matrix: 0.0012965202331542969
# Child 163 There were no points close enough
# Starting Child 175
# 1 39013
# Done distance matrix: 0.0013315677642822266
# Child 175 There were no points close enough
# Starting Child 195
# 1 39013
# Done distance matrix: 0.0013918876647949219
# Child 195 There were no points close enough
# Starting Child 201
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 202
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 203
# 1 39013
# Done distance matrix: 0.001470804214477539
# Child 203 There were no points close enough
# Starting Child 204
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 205
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 215
# 1 39013
# Done distance matrix: 0.001338958740234375
# Child 215 There were no points close enough
# Starting Child 218
# 1 39013
# Done distance matrix: 0.0014605522155761719
# Child 218 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 224
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 230
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 235
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 258
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 39013
# Done distance matrix: 0.0015447139739990234
# Child 266 There were no points close enough
# Starting Child 268
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 278
# 1 39013
# Done distance matrix: 0.0014333724975585938
# Child 278 There were no points close enough
# Starting Child 287
# 1 39013
# Done distance matrix: 0.0013759136199951172
# Child 287 There were no points close enough
# Starting Child 290
# 1 39013
# Done distance matrix: 0.0034193992614746094
# Child 290 There were no points close enough
# Starting Child 293
# 1 39013
# Done distance matrix: 0.0013535022735595703
# Child 293 There were no points close enough
# Starting Child 304
# 1 39013
# Done distance matrix: 0.0012547969818115234
# Child 304 There were no points close enough
# Starting Child 306
# 1 39013
# Done distance matrix: 0.0013370513916015625
# Child 306 There were no points close enough
# Starting Child 329
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 344
# 1 39013
# Done distance matrix: 0.0012955665588378906
# Child 344 There were no points close enough
# Starting Child 366
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 386
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 393
# 1 39013
# Done distance matrix: 0.001512765884399414
# Child 393 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 1 39013
# Done distance matrix: 0.0013909339904785156
# Child 43 There were no points close enough
# Starting Child 45
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 47
# 1 39013
# Done distance matrix: 0.0012919902801513672
# Child 47 There were no points close enough
# Starting Child 54
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 56
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 66
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 86
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 91
# 1 39013
# Done distance matrix: 0.001459360122680664
# Child 91 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 94
# 1 39013
# Done distance matrix: 0.0014548301696777344
# Child 94 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 109
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# 1 39013
# Done distance matrix: 0.0016129016876220703
# Child 112 There were no points close enough
# Starting Child 113
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 114
# 1 39013
# Done distance matrix: 0.001241922378540039
# Child 114 There were no points close enough
# Starting Child 120
# 1 39013
# Done distance matrix: 0.0013568401336669922
# Child 120 There were no points close enough
# Starting Child 122
# 1 39013
# Done distance matrix: 0.0014200210571289062
# Child 122 There were no points close enough
# Starting Child 131
# 1 39013
# Done distance matrix: 0.0013878345489501953
# Child 131 There were no points close enough
# Starting Child 133
# 1 39013
# Done distance matrix: 0.0011913776397705078
# Child 133 There were no points close enough
# Starting Child 134
# 1 39013
# Done distance matrix: 0.0012125968933105469
# Child 134 There were no points close enough
# Starting Child 145
# 1 39013
# Done distance matrix: 0.0011398792266845703
# Child 145 There were no points close enough
# Starting Child 152
# 1 39013
# Done distance matrix: 0.0011866092681884766
# Child 152 There were no points close enough
# Starting Child 159
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 163
# 1 39013
# Done distance matrix: 0.0012476444244384766
# Child 163 There were no points close enough
# Starting Child 175
# 1 39013
# Done distance matrix: 0.0014011859893798828
# Child 175 There were no points close enough
# Starting Child 195
# 1 39013
# Done distance matrix: 0.0011501312255859375
# Child 195 There were no points close enough
# Starting Child 201
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 202
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 203
# 1 39013
# Done distance matrix: 0.0015606880187988281
# Child 203 There were no points close enough
# Starting Child 204
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 205
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 215
# 1 39013
# Done distance matrix: 0.0014638900756835938
# Child 215 There were no points close enough
# Starting Child 218
# 1 39013
# Done distance matrix: 0.0014066696166992188
# Child 218 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 224
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 230
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 235
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 258
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 39013
# Done distance matrix: 0.0016090869903564453
# Child 266 There were no points close enough
# Starting Child 268
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 278
# 1 39013
# Done distance matrix: 0.001470804214477539
# Child 278 There were no points close enough
# Starting Child 287
# 1 39013
# Done distance matrix: 0.0014586448669433594
# Child 287 There were no points close enough
# Starting Child 290
# 1 39013
# Done distance matrix: 0.0013079643249511719
# Child 290 There were no points close enough
# Starting Child 293
# 1 39013
# Done distance matrix: 0.0013027191162109375
# Child 293 There were no points close enough
# Starting Child 304
# 1 39013
# Done distance matrix: 0.0012698173522949219
# Child 304 There were no points close enough
# Starting Child 306
# 1 39013
# Done distance matrix: 0.0012638568878173828
# Child 306 There were no points close enough
# Starting Child 329
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 344
# 1 39013
# Done distance matrix: 0.0013267993927001953
# Child 344 There were no points close enough
# Starting Child 366
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 386
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 393
# 1 39013
# Done distance matrix: 0.0014417171478271484
# Child 393 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 38
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 43
# 1 39013
# Done distance matrix: 0.0014657974243164062
# Child 43 There were no points close enough
# Starting Child 45
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 47
# 1 39013
# Done distance matrix: 0.0013799667358398438
# Child 47 There were no points close enough
# Starting Child 54
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 56
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 66
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 86
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 91
# 1 39013
# Done distance matrix: 0.0014879703521728516
# Child 91 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 94
# 1 39013
# Done distance matrix: 0.001682281494140625
# Child 94 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 109
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# 1 39013
# Done distance matrix: 0.0015485286712646484
# Child 112 There were no points close enough
# Starting Child 113
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 114
# 1 39013
# Done distance matrix: 0.0015118122100830078
# Child 114 There were no points close enough
# Starting Child 120
# 1 39013
# Done distance matrix: 0.0015420913696289062
# Child 120 There were no points close enough
# Starting Child 122
# 1 39013
# Done distance matrix: 0.0015866756439208984
# Child 122 There were no points close enough
# Starting Child 131
# 1 39013
# Done distance matrix: 0.0014176368713378906
# Child 131 There were no points close enough
# Starting Child 133
# 1 39013
# Done distance matrix: 0.0014417171478271484
# Child 133 There were no points close enough
# Starting Child 134
# 1 39013
# Done distance matrix: 0.001399993896484375
# Child 134 There were no points close enough
# Starting Child 145
# 1 39013
# Done distance matrix: 0.0013115406036376953
# Child 145 There were no points close enough
# Starting Child 152
# 1 39013
# Done distance matrix: 0.0012993812561035156
# Child 152 There were no points close enough
# Starting Child 159
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 163
# 1 39013
# Done distance matrix: 0.0014104843139648438
# Child 163 There were no points close enough
# Starting Child 175
# 1 39013
# Done distance matrix: 0.0013451576232910156
# Child 175 There were no points close enough
# Starting Child 195
# 1 39013
# Done distance matrix: 0.0013866424560546875
# Child 195 There were no points close enough
# Starting Child 201
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 202
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 203
# 1 39013
# Done distance matrix: 0.0014424324035644531
# Child 203 There were no points close enough
# Starting Child 204
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 205
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 215
# 1 39013
# Done distance matrix: 0.0014431476593017578
# Child 215 There were no points close enough
# Starting Child 218
# 1 39013
# Done distance matrix: 0.0013768672943115234
# Child 218 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 224
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 230
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 235
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 258
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 39013
# Done distance matrix: 0.0015385150909423828
# Child 266 There were no points close enough
# Starting Child 268
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 278
# 1 39013
# Done distance matrix: 0.001476287841796875
# Child 278 There were no points close enough
# Starting Child 287
# 1 39013
# Done distance matrix: 0.00140380859375
# Child 287 There were no points close enough
# Starting Child 290
# 1 39013
# Done distance matrix: 0.0012998580932617188
# Child 290 There were no points close enough
# Starting Child 293
# 1 39013
# Done distance matrix: 0.0012788772583007812
# Child 293 There were no points close enough
# Starting Child 304
# 1 39013
# Done distance matrix: 0.0012254714965820312
# Child 304 There were no points close enough
# Starting Child 306
# 1 39013
# Done distance matrix: 0.001176595687866211
# Child 306 There were no points close enough
# Starting Child 329
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 344
# 1 39013
# Done distance matrix: 0.0013720989227294922
# Child 344 There were no points close enough
# Starting Child 366
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 386
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 393
# 1 39013
# Done distance matrix: 0.0013568401336669922
# Child 393 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 604.8720591068268
# Total time for restitching = 604.8792538642883
# missed_children = [258.0, 131.0, 386.0, 133.0, 134.0, 393.0, 266.0, 268.0, 145.0, 278.0, 152.0, 159.0, 287.0, 290.0, 163.0, 293.0, 38.0, 43.0, 45.0, 47.0, 175.0, 304.0, 306.0, 54.0, 56.0, 66.0, 195.0, 201.0, 202.0, 203.0, 204.0, 205.0, 206.0, 329.0, 86.0, 215.0, 344.0, 90.0, 91.0, 92.0, 218.0, 94.0, 221.0, 224.0, 102.0, 230.0, 235.0, 109.0, 366.0, 112.0, 113.0, 114.0, 120.0, 122.0]
# Whole stitching function complete: 749.7417273521423
# 6613.830434322357

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
