# %%
import datajoint as dj
import numpy as np
import time
from tqdm import tqdm

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

pinky = dj.create_virtual_module('pinky', 'microns_pinky')
schema = dj.schema('microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.ProofreadLabelOrphan() & "segment_id=648518346341352006"

# %%
#ta3p100.CleansedMeshOrphan()

# %%
@schema
class CoarseLabelOrphan(dj.Computed):
    definition = """
    # Vertex labels for pinky.ProofreadLabelOrphan did not correctly match the triangle labels, so these are regenerated from the correct triangle labels.
    -> pinky.ProofreadLabelOrphan
    ---
    vertices  : longblob # Corrected vertex labels
    triangles : longblob # Same triangle labels as pinky.ProofreadLabelOrphan
    """
    
    key_source = pinky.ProofreadLabelOrphan & 'status="complete"'
    
    def make(self, key):
        start = time.time()
        
        print(key["segment_id"])
        labels = (pinky.ProofreadLabelOrphan & key).fetch1()
        corrected_vertex_labels = np.zeros(labels['vertices'].shape, np.uint8)
        
        mesh = (pinky.Decimation35OrphanStitched & 'decimation_ratio=0.35' & dict(segment_id=key['segment_id'])).fetch1()
        mesh_triangles = mesh['triangles']
        
        vertex_label_dict = dict()
        for i, label in enumerate(labels['triangles']):
            triangle = mesh_triangles[i]
            for node in triangle:
                if node in vertex_label_dict:
                    if vertex_label_dict[node] < label:
                        vertex_label_dict[node] = label
                else:
                    vertex_label_dict[node] = label
                
        for node, label in vertex_label_dict.items():
            corrected_vertex_labels[node] = label
            
        self.insert1(dict(key,
                          vertices=corrected_vertex_labels,
                          triangles=labels['triangles']))
        
        print("Segment {} vertex labels regenerated in: {} seconds.".format(key['segment_id'], time.time() - start))

# %%
start = time.time()
CoarseLabelOrphan.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341379591
# Segment 648518346341379591 vertex labels regenerated in: 0.9974567890167236 seconds.
# 648518346341381313
# Segment 648518346341381313 vertex labels regenerated in: 0.5288147926330566 seconds.
# 648518346341382069
# Segment 648518346341382069 vertex labels regenerated in: 1.0304756164550781 seconds.
# 648518346341383070
# Segment 648518346341383070 vertex labels regenerated in: 0.5411012172698975 seconds.
# 648518346341383573
# Segment 648518346341383573 vertex labels regenerated in: 0.4962272644042969 seconds.
# 648518346341385331
# Segment 648518346341385331 vertex labels regenerated in: 0.7440943717956543 seconds.
# 648518346341386109
# Segment 648518346341386109 vertex labels regenerated in: 0.7111461162567139 seconds.
# 648518346341389516
# Segment 648518346341389516 vertex labels regenerated in: 0.44698309898376465 seconds.
# 648518346341391113
# Segment 648518346341391113 vertex labels regenerated in: 0.5435965061187744 seconds.
# 648518346341392729
# Segment 648518346341392729 vertex labels regenerated in: 0.5733194351196289 seconds.
# 648518346341393878
# Segment 648518346341393878 vertex labels regenerated in: 0.5787324905395508 seconds.
# 648518346341394694
# Segment 648518346341394694 vertex labels regenerated in: 0.41484665870666504 seconds.
# 648518346341395182
# Segment 648518346341395182 vertex labels regenerated in: 0.5021712779998779 seconds.
# 648518346341396317
# Segment 648518346345770568 vertex labels regenerated in: 0.5243613719940186 seconds.
# 648518346345883620
# Segment 648518346345883620 vertex labels regenerated in: 0.5017058849334717 seconds.
# 648518346346296756
# Segment 648518346346296756 vertex labels regenerated in: 0.4776644706726074 seconds.
# 648518346346301140
# Segment 648518346346301140 vertex labels regenerated in: 0.5502707958221436 seconds.
# 648518346346307265
# Segment 648518346346307265 vertex labels regenerated in: 0.5397617816925049 seconds.
# 648518346346319686
# Segment 648518346346319686 vertex labels regenerated in: 0.8377437591552734 seconds.
# 648518346346595591
# Segment 648518346346595591 vertex labels regenerated in: 0.5273077487945557 seconds.
# 648518346346955064
# Segment 648518346346955064 vertex labels regenerated in: 0.5521030426025391 seconds.
# 648518346348103539
# Segment 648518346348103539 vertex labels regenerated in: 0.7789239883422852 seconds.
# 648518346348115442
# Segment 648518346348115442 vertex labels regenerated in: 0.5795798301696777 seconds.
# 648518346348119782
# Segment 648518346348119782 vertex labels regenerated in: 0.8542561531066895 seconds.
# 648518346348191367
# Segment 648518346348191367 vertex labels regenerated in: 0.46445631980895996 seconds.
# 648518346348199740
# Segment 648518346348199740 vertex labels regenerated in: 0.4868509769439697 seconds.
# 648518346348209958
# Segment 648518346348209958 vertex labels regenerated in: 0.739534854888916 seconds.
# 648518346348458490
# Segment 648518346348458490 vertex labels regenerated in: 0.4736518859863281 seconds.
# 648518346348464469
# Segment 648518346348464469 vertex labels regenerated in: 0.5544512271881104 seconds.
# 648518346348525348
# Segment 648518346348525348 vertex labels regenerated in: 0.5681464672088623 seconds.
# 648518346349369636
# Segment 648518346349369636 vertex labels regenerated in: 0.5127861499786377 seconds.
# 648518346349373749
# Segment 648518346349373749 vertex labels regenerated in: 0.46541571617126465 seconds.
# 648518346349378789
# Segment 648518346349378789 vertex labels regenerated in: 0.4919767379760742 seconds.
# 648518346349383833
# Segment 648518346349383833 vertex labels regenerated in: 0.6362340450286865 seconds.
# 648518346349468622
# Segment 648518346349468622 vertex labels regenerated in: 0.716139554977417 seconds.
# 648518346349479381
# Segment 648518346349479381 vertex labels regenerated in: 0.654472827911377 seconds.
# 648518346349484055
# Segment 648518346349484055 vertex labels regenerated in: 0.5464096069335938 seconds.
# 648518346349496069
# Segment 648518346349496069 vertex labels regenerated in: 0.6756110191345215 seconds.
# 648518346349502858
# Segment 648518346349502858 vertex labels regenerated in: 0.785414457321167 seconds.
# 648518346349508581
# Segment 648518346349508581 vertex labels regenerated in: 0.8929324150085449 seconds.
# 648518346349509415
# Segment 648518346349509415 vertex labels regenerated in: 1.9896676540374756 seconds.
# 75.57493591308594

# %%
(schema.jobs & "table_name='__coarse_label_orphan'").delete()

# %%
ta3p100.CoarseLabelOrphan()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a9fbc87cb26d> in <module>
# ----> 1 ta3p100.CoarseLabelOrphan()
#
# NameError: name 'ta3p100' is not defined

# %%
ta3p100.SegmentExclude()
