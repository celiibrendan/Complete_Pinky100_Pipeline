# %%
import cgal_Segmentation_Module as csm
#help(csm)

# %%
import datajoint as dj
import numpy as np
import datetime
import math


#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20


schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#if temp folder doesn't exist then create it
import os
if (os.path.isdir(os.getcwd() + "/temp")) == False:
    os.mkdir("temp")

# %%
import os
import pathlib

def generate_component_off_file(neuron_ID, compartment_type, component_id, n_vertex_indices, n_triangle_indices, 
                                vertex_indices, triangle_indices,vertices, triangles):
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / "temp"
    filename = "neuron_" + str(neuron_ID) + "_" + str(compartment_type) + "_" + str(component_id)
    path_and_filename = file_loc / filename
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(n_vertex_indices) + " " + str(n_triangle_indices) + " 0\n" )
    
    #start writing all of the vertices
    """
        4. For the vertices:
        For each index in the vertices blob of the components table, 
         write the coordinates in the index location of the Cleansed mesh table
            while creating a lookup dictionary where it has old_vert_index:new_index  (vert_lookup)
    """       
    verts_lookup = {}
    for i, vin in enumerate(vertex_indices):
        #get the coordinates of the vertex
        coordinates = vertices[vin]
        #write the coordinates to the off file
        f.write(str(coordinates[0]) + " " + str(coordinates[1]) + " " + str(coordinates[2])+"\n")
        #create lookup dictionary for vertices
        verts_lookup[vin] = i
    
    """    5. For the faces:
        For each index in the faces blob of the components table,
             Get the new index by (vert_lookup) and save to list
        Write the list to the file"""
    for i,fac in enumerate(triangle_indices):
        verts_in_fac = triangles[fac]
        #write the verties to the off file
        f.write("3 " + str(verts_lookup[verts_in_fac[0]]) + " " + str(verts_lookup[verts_in_fac[1]]) + " " + str(verts_lookup[verts_in_fac[2]])+"\n")
        
    
    print("Done making OFF file " + str(filename))
    #return the name of the off file you created and the location
    return str(path_and_filename),str(filename)

# %%
#################THE ONE WE ARE USING
import cgal_Segmentation_Module as csm
import csv
import decimal
import time
import os

@schema
class ComponentAutoSegmentFinal(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.CompartmentFinal.ComponentFinal
    clusters     : tinyint unsigned  #what the clustering parameter was set to
    smoothness   : decimal(3,2)             #what the smoothness parameter was set to, number betwee 0 and 1
    ---
    n_triangles  : int unsigned # number of faces
    seg_group    : longblob     # group segmentation ID's for faces from automatic CGAL segmentation
    sdf          : longblob     #  width values for faces from from automatic CGAL segmentation
    median_sdf   : decimal(6,5) # the median width value for the sdf values
    mean_sdf     : decimal(6,5) #the mean width value for the sdf values
    third_q      : decimal(6,5) #the upper quartile for the mean width values
    ninety_perc  : decimal(6,5) #the 90th percentile for the mean width values
    time_updated : timestamp    # the time at which the segmentation was performed
   """
    
    key_source = pinky.CompartmentFinal.ComponentFinal & 'n_triangle_indices>100' & [dict(compartment_type=comp) for comp in ['Basal', 'Apical', 'Oblique', 'Dendrite']]
    
    whole_neuron_dicts = dict()
    
    def make(self, key):
        print("key = " + str(key))
        #key passed to function is just dictionary with the following attributes
        """segmentation
        segment_id
        decimation_ratio
        compartment_type
        component_index
        """
        start_time = time.time()
        
        #clusters_default = 18
        smoothness = 0.04

        Apical_Basal_Oblique_default = [12]
        basal_big = [16]

        neuron_ID = key["segment_id"]
        component = (pinky.CompartmentFinal.ComponentFinal & key).fetch1()        

        component_id = component["component_index"]
        compartment_type = component["compartment_type"]
        component_size = int(component["n_triangle_indices"])

        print("component_size = " + str(component_size))

        if (compartment_type == "Basal") & (component_size > 160000):
            cluster_list = basal_big
        else:
            cluster_list = Apical_Basal_Oblique_default


        for clusters in cluster_list:
            smoothness = 0.04
            print(str(component["segment_id"]) + " type:" + str(component["compartment_type"]) 
                      + " index:" + str(component["component_index"]) + " cluster:" + str(clusters) 
                  + " smoothness:" + str(smoothness))

            #generate the off file for each component
            #what need to send them:
            """----From cleansed Mesh---
            vertices
            triangles
            ----From component table--
            n_vertex_indices
            n_triangle_indices
            vertex_indices
            triangle_indices"""
            
            if key['segment_id'] not in self.whole_neuron_dicts:
                self.whole_neuron_dicts[key['segment_id']] = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & 'decimation_ratio=0.35' & dict(segment_id=key['segment_id'])).fetch1()
            
            path_and_filename, off_file_name = generate_component_off_file(neuron_ID, compartment_type, component_id,
                                        component["n_vertex_indices"],
                                        component["n_triangle_indices"],
                                        component["vertex_indices"],
                                        component["triangle_indices"],
                                        self.whole_neuron_dicts[key['segment_id']]["vertices"],
                                        self.whole_neuron_dicts[key['segment_id']]["triangles"])
            
            print(len(component['vertex_indices']), len(component['triangle_indices']))
            
            #will have generated the component file by now so now need to run the segmentation

            csm.cgal_segmentation(path_and_filename,clusters,smoothness)

            #generate the name of the files
            cgal_file_name = path_and_filename + "-cgal_" + str(clusters) + "_"+str(smoothness)
            group_csv_cgal_file = cgal_file_name + ".csv"
            sdf_csv_file_name = cgal_file_name+"_sdf.csv"

            
            try:
                with open(group_csv_cgal_file) as f:
                  reader = csv.reader(f)
                  your_list = list(reader)
                group_list = []
                for item in your_list:
                    group_list.append(int(item[0]))

                with open(sdf_csv_file_name) as f:
                  reader = csv.reader(f)
                  your_list = list(reader)
                sdf_list = []
                for item in your_list:
                    sdf_list.append(float(item[0]))
            except:
                print("no CGAL segmentation for " + str(off_file_name) )
                return

            #print(group_list)
            #print(sdf_list)

            #now write them to the datajoint table  
            #table columns for ComponentAutoSegmentation: segmentation, segment_id, decimation_ratio, compartment_type, component_index, seg_group, sdf
#             print(dict(key,
#                                 clusters=clusters,
#                                 smoothness=smoothness,
#                                 n_triangles=component["n_triangle_indices"],
#                                 seg_group=group_list,
#                                 sdf=sdf_list,
#                                 median_sdf=np.median(sdf_list),
#                                 mean_sdf=np.mean(sdf_list),
#                                 third_q=np.percentile(sdf_list, 75),
#                                 ninety_perc=np.percentile(sdf_list, 90),
#                                 time_updated=str(datetime.datetime.now())[0:19]))
            
            comp_dict = dict(key,
                                clusters=clusters,
                                smoothness=smoothness,
                                n_triangles=component["n_triangle_indices"],
                                seg_group=group_list,
                                sdf=sdf_list,
                                median_sdf=np.median(sdf_list),
                                mean_sdf=np.mean(sdf_list),
                                third_q=np.percentile(sdf_list, 75),
                                ninety_perc=np.percentile(sdf_list, 90),
                                time_updated=str(datetime.datetime.now())[0:19])

            self.insert1(comp_dict)

            #then go and erase all of the files used: the sdf files, 
            real_off_file_name = path_and_filename + ".off"

            files_to_delete = [group_csv_cgal_file,sdf_csv_file_name,real_off_file_name]
            for fl in files_to_delete:
                if os.path.exists(fl):
                    os.remove(fl)
                else:
                    print(fl + " file does not exist")

        print("finished")
        print("--- %s seconds ---" % (time.time() - start_time))

# %%
start_time = time.time()
ComponentAutoSegmentFinal.populate(reserve_jobs=True)
print(f"Total_time = {time.time() - start_time}")
# Out:
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 231784
# 648518346341371119 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Apical_0
# 115849 231784
# finished
# --- 70.74881744384766 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 8416
# 648518346341371119 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_0
# 4231 8416
# finished
# --- 1.489654779434204 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 208
# 648518346341371119 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_1
# 110 208
# finished
# --- 0.05541539192199707 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 44613
# 648518346341371119 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_2
# 22310 44613
# finished
# --- 8.342058897018433 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 1988
# 648518346341371119 type:Basal index:3 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_3
# 1021 1988
# finished
# --- 0.38544440269470215 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 80121
# 648518346341371119 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_4
# 40075 80121
# finished
# --- 18.14480996131897 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 954
# 648518346341371119 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Basal_5
# 514 954
# finished
# --- 0.216080904006958 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 20142
# 648518346341371119 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346341371119_Oblique_0
# 10066 20142
# finished
# --- 3.4841253757476807 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349386137, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 31692
# 648518346349386137 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349386137_Basal_1
# 15855 31692
# finished
# --- 7.9055867195129395 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 21204
# 648518346349470171 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Apical_0
# 10652 21204
# finished
# --- 6.500075578689575 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 18676
# 648518346349470171 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_0
# 9356 18676
# finished
# --- 2.9584805965423584 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 24340
# 648518346349470171 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_1
# 12166 24340
# finished
# --- 4.151547908782959 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 50140
# 648518346349470171 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_2
# 25083 50140
# finished
# --- 9.855508804321289 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 263569
# 648518346349470171 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_3
# 131688 263569
# finished
# --- 84.60448479652405 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 71597
# 648518346349470171 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_4
# 35779 71597
# finished
# --- 14.463114261627197 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 65966
# 648518346349470171 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_5
# 32994 65966
# finished
# --- 13.241430521011353 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 6}
# component_size = 5524
# 648518346349470171 type:Basal index:6 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Basal_6
# 2785 5524
# finished
# --- 0.8600537776947021 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349470171, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 9570
# 648518346349470171 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349470171_Oblique_0
# 4787 9570
# finished
# --- 1.5233590602874756 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 3861
# 648518346349471156 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Apical_0
# 1988 3861
# finished
# --- 3.229226589202881 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 98371
# 648518346349471156 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Basal_0
# 49179 98371
# finished
# --- 22.945987939834595 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 6068
# 648518346349471156 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Basal_1
# 3069 6068
# finished
# --- 1.0682930946350098 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 1115
# 648518346349471156 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Basal_4
# 572 1115
# finished
# --- 0.1758711338043213 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 6}
# component_size = 87652
# 648518346349471156 type:Basal index:6 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Basal_6
# 43780 87652
# finished
# --- 18.90951681137085 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471156, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 7}
# component_size = 140733
# 648518346349471156 type:Basal index:7 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471156_Basal_7
# 70318 140733
# finished
# --- 33.76398539543152 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 37938
# 648518346349471500 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Apical_0
# 19034 37938
# finished
# --- 9.107846975326538 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 1959
# 648518346349471500 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_0
# 990 1959
# finished
# --- 0.36138129234313965 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 10469
# 648518346349471500 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_1
# 5253 10469
# finished
# --- 1.5859620571136475 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 7562
# 648518346349471500 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_2
# 3794 7562
# finished
# --- 1.028014898300171 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 97550
# 648518346349471500 type:Basal index:3 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_3
# 48748 97550
# finished
# --- 19.770532608032227 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 45209
# 648518346349471500 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_4
# 22599 45209
# finished
# --- 8.233267307281494 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 37364
# 648518346349471500 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_5
# 18671 37364
# finished
# --- 6.019235849380493 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 6}
# component_size = 5578
# 648518346349471500 type:Basal index:6 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_6
# 2817 5578
# finished
# --- 0.8467857837677002 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471500, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 7}
# component_size = 127791
# 648518346349471500 type:Basal index:7 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471500_Basal_7
# 63887 127791
# finished
# --- 27.769436359405518 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349471562, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 201395
# 648518346349471562 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349471562_Apical_0
# 100685 201395
# finished
# --- 92.87624335289001 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349475035, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 1}
# component_size = 89694
# 648518346349475035 type:Apical index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349475035_Apical_1
# 44849 89694
# finished
# --- 34.35704255104065 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349475518, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 29946
# 648518346349475518 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349475518_Basal_4
# 14996 29946
# finished
# --- 13.57053256034851 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349475523, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 212084
# 648518346349475523 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349475523_Basal_3
# 105982 212084
# finished
# --- 120.03283333778381 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349478860, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 16011
# 648518346349478860 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349478860_Basal_2
# 8011 16011
# finished
# --- 6.414745330810547 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349479254, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 58903
# 648518346349479254 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349479254_Apical_0
# 29483 58903
# finished
# --- 25.551060438156128 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349479706, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 1691
# 648518346349479706 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349479706_Basal_2
# 854 1691
# finished
# --- 2.3244822025299072 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349479837, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 309449
# 648518346349479837 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349479837_Apical_0
# 154643 309449
# finished
# --- 182.3044559955597 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349490654, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 68909
# 648518346349490654 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349490654_Basal_1
# 34453 68909
# finished
# --- 24.402456521987915 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349490796, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 43667
# 648518346349490796 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349490796_Oblique_0
# 21823 43667
# finished
# --- 16.894389629364014 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349491311, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 139734
# 648518346349491311 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349491311_Basal_2
# 69854 139734
# finished
# --- 60.6078999042511 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349493117, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 1}
# component_size = 141527
# 648518346349493117 type:Apical index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349493117_Apical_1
# 70759 141527
# finished
# --- 63.18532037734985 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349494087, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 79135
# 648518346349494087 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349494087_Basal_4
# 39555 79135
# finished
# --- 35.832399129867554 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349494969, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 140726
# 648518346349494969 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349494969_Basal_4
# 70328 140726
# finished
# --- 64.7769467830658 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349495846, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Apical', 'component_index': 0}
# component_size = 27063
# 648518346349495846 type:Apical index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349495846_Apical_0
# 13597 27063
# finished
# --- 10.322710275650024 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349495935, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 106572
# 648518346349495935 type:Basal index:3 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349495935_Basal_3
# 53272 106572
# finished
# --- 46.426416635513306 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349496925, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 89405
# 648518346349496925 type:Basal index:3 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349496925_Basal_3
# 44669 89405
# finished
# --- 37.461148500442505 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349497752, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 8}
# component_size = 40984
# 648518346349497752 type:Basal index:8 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349497752_Basal_8
# 20497 40984
# finished
# --- 15.473579168319702 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349498116, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 116412
# 648518346349498116 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349498116_Oblique_0
# 58167 116412
# finished
# --- 49.99917197227478 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349498632, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 315314
# 648518346349498632 type:Basal index:0 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349498632_Basal_0
# 157537 315314
# finished
# --- 201.38902258872986 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349499896, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 492
# 648518346349499896 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349499896_Basal_0
# 264 492
# finished
# --- 2.3913257122039795 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349499896, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 172031
# 648518346349499896 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349499896_Basal_3
# 85912 172031
# finished
# --- 91.80170798301697 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500431, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 6529
# 648518346349500431 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500431_Basal_1
# 3274 6529
# finished
# --- 3.773963212966919 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500431, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 55392
# 648518346349500431 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500431_Oblique_0
# 27656 55392
# finished
# --- 19.553645133972168 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500486, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 40383
# 648518346349500486 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500486_Basal_0
# 20233 40383
# finished
# --- 17.0248441696167 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500627, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 101415
# 648518346349500627 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500627_Basal_5
# 50738 101415
# finished
# --- 46.781524896621704 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500939, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 45273
# 648518346349500939 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500939_Basal_4
# 22620 45273
# finished
# --- 16.981688737869263 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349500954, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 6}
# component_size = 18824
# 648518346349500954 type:Basal index:6 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349500954_Basal_6
# 9423 18824
# finished
# --- 7.439664602279663 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349501175, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 171762
# 648518346349501175 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349501175_Oblique_0
# 85825 171762
# finished
# --- 83.83236455917358 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349501787, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 47987
# 648518346349501787 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349501787_Basal_5
# 23974 47987
# finished
# --- 20.64355969429016 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349502203, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 5}
# component_size = 49951
# 648518346349502203 type:Basal index:5 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349502203_Basal_5
# 24984 49951
# finished
# --- 21.705328941345215 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349502920, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 2306
# 648518346349502920 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349502920_Basal_2
# 1174 2306
# finished
# --- 2.730098247528076 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349502920, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 68581
# 648518346349502920 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349502920_Basal_4
# 34291 68581
# finished
# --- 23.631618976593018 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349503140, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 1}
# component_size = 50244
# 648518346349503140 type:Oblique index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349503140_Oblique_1
# 25116 50244
# finished
# --- 23.686100959777832 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349503473, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 163989
# 648518346349503473 type:Basal index:0 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349503473_Basal_0
# 81970 163989
# finished
# --- 81.98947763442993 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349504185, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 56803
# 648518346349504185 type:Basal index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349504185_Basal_0
# 28384 56803
# finished
# --- 26.17876887321472 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349504442, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 190345
# 648518346349504442 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349504442_Basal_3
# 95114 190345
# finished
# --- 104.75400614738464 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349505144, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 197892
# 648518346349505144 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349505144_Basal_3
# 98885 197892
# finished
# --- 104.04799365997314 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349505911, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 12024
# 648518346349505911 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349505911_Basal_2
# 6025 12024
# finished
# --- 5.768808364868164 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349506008, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Oblique', 'component_index': 0}
# component_size = 168672
# 648518346349506008 type:Oblique index:0 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349506008_Oblique_0
# 84252 168672
# finished
# --- 83.75550842285156 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349507015, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 5542
# 648518346349507015 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349507015_Basal_1
# 2810 5542
# finished
# --- 3.3697752952575684 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349507015, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 3}
# component_size = 220756
# 648518346349507015 type:Basal index:3 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349507015_Basal_3
# 110330 220756
# finished
# --- 118.78188347816467 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349508447, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 4}
# component_size = 62840
# 648518346349508447 type:Basal index:4 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349508447_Basal_4
# 31445 62840
# finished
# --- 25.11852264404297 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349508969, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 1}
# component_size = 113621
# 648518346349508969 type:Basal index:1 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349508969_Basal_1
# 56807 113621
# finished
# --- 47.424692153930664 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349509300, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 325026
# 648518346349509300 type:Basal index:0 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349509300_Basal_0
# 162394 325026
# finished
# --- 202.14690041542053 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349512199, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 2}
# component_size = 58308
# 648518346349512199 type:Basal index:2 cluster:12 smoothness:0.04
# Done making OFF file neuron_648518346349512199_Basal_2
# 29143 58308
# finished
# --- 17.720520973205566 seconds ---
# key = {'segmentation': 3, 'segment_id': 648518346349512869, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Basal', 'component_index': 0}
# component_size = 584829
# 648518346349512869 type:Basal index:0 cluster:16 smoothness:0.04
# Done making OFF file neuron_648518346349512869_Basal_0
# 292185 584829
# finished
# --- 359.938618183136 seconds ---
# Total_time = 3132.874788761139
