# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'").delete()

# %%
# #different types of errors

# #IndexError
# print((schema.jobs & "key_hash = '3808fc0c6b3bcd5ec7d82f4eb8ed9955'").fetch1("key","error_message"))
# #string is not a file
# print((schema.jobs & "key_hash = '08aa5df56afaa2fe130b05582cf9cd62'").fetch1("key","error_message"))

# print((schema.jobs & "key_hash = '10c18713710c7047bb2fe919c0423b4d'").fetch1("key","error_message"))

# print((schema.jobs & "key_hash = '188fa44ea025fb0d461d0330a1804295'").fetch1("key","error_message"))

# #then one where it is reserved but hasnt finished
# print((schema.jobs & "key_hash = '188fa44ea025fb0d461d0330a1804295'").fetch1("key","error_message"))

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'").delete()

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %% [markdown]
# # Debugging the skeleton stitching function

# %%
# key = dict(segmentation=3,segment_id=648518346341395072)

# split_significance_threshold = 100

# global_time = time.time()
# #get the mesh with the error segments filtered away
# start_time = time.time()
# print(str(key['segment_id']) +  ":")
# my_dict = (pinky.Mesh & pinky.Neurite.proj() & pinky.CurrentSegmentation
#                    & key).fetch1()
# print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
# new_key = dict(segmentation=key["segmentation"],
#                segment_id=key["segment_id"])


# # Don't need these attributes      
# #vertices=key["vertices"],
# #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
# #                       n_triangles=key["n_triangles"])


# start_time = time.time()
# #pass the vertices and faces to pymeshfix to become watertight

# mesh = trimesh_io.Mesh(vertices=my_dict["vertices"], faces=my_dict["triangles"])

# """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
# count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
#                                                     mesh.edges_sparse,
#                                                     directed=False,
#                                                     return_labels=True)


# label_counter = Counter(labels)


# new_key["n_bodies"] = count
# values = np.array(labels)


# list_counter = Counter(labels)
# max_counter = max(list_counter.values())

# max_label = -1
# for label_key,label_number in list_counter.items():
#     if label_number==max_counter:
#         max_label = label_key
# print("max label = " + str(max_label))

# searchval = max_label

# ii = np.where(values == searchval)[0]
# new_key["largest_mesh_perc"] = len(ii)/len(labels)

# print("n_bodies = " + str(new_key["n_bodies"]))
# print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
# """



# total_splits = mesh.split(only_watertight=False)
# print(f"There were {len(total_splits)} after split and significance threshold")
# mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
# print(f"There were {len(mesh_pieces)} after split and significance threshold")
# for g,mh in enumerate(mesh_pieces):
#     print(f"Mesh piece {g} with number of faces {len(mh.faces)}")
    
# print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

# #get the largest mesh piece
# largest_mesh_index = -1
# largest_mesh_size = 0

# for t,msh in enumerate(mesh_pieces):
#     if len(msh.faces) > largest_mesh_size:
#         largest_mesh_index = t
#         largest_mesh_size = len(msh.faces) 

# #largest mesh piece
# largest_mesh_perc = largest_mesh_size/len(mesh.faces)
# new_key["largest_mesh_perc"] = largest_mesh_perc
# print("largest mesh perc = " + str(largest_mesh_perc))

# largest_mesh_skeleton_distance = -1

# paths_used = []
# total_edges = np.array([])
# for h,m in enumerate(mesh_pieces): 
    
#     print(f"Working on split {h} with face total = {len(m.faces)}")


#     start_time = time.time()
#     #pass the vertices and faces to pymeshfix to become watertight
#     meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
#     meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
#     print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

#     #print("Step 2: Writing Off File")
#     start_time = time.time()
#     #write the new mesh to off file
#     path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
#     print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
#     #add the path to be deleted later
#     paths_used.append(path_and_filename)


#     #Run the meshlabserver scripts
#     start_time = time.time()
#     output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
#     print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

#     print(output_mesh[:-4])

#     #send to be skeletonized
#     start_time = time.time()
#     return_value = cm.calcification(output_mesh[:-4])
#     if return_value > 0:
#         raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
#                         ' did not finish... exited with error code: ' + str(return_value))
#     #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



#     #read in the skeleton files into an array
#     bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

#     #print(bone_array)
#     if len(bone_array) <= 0:
#         raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
#     print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

#     #get the largest mesh skeleton distance
#     if h == largest_mesh_index:
#         largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

#     #add the skeleton edges to the total edges
#     if not total_edges.any():
#         total_edges = bone_array
#     else:
#         total_edges = np.vstack([total_edges,bone_array])

    

# total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

# #get the total skeleton distance for the stitched skeleton
# total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

# largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


# start_time = time.time()
# new_key["n_edges"] = len(total_edges_stitched)
# new_key["edges"] = bone_array
# new_key["n_bodies"] = len(total_splits)
# new_key["n_bodies_stitched"] = len(mesh_pieces)
# new_key["largest_mesh_perc"] = largest_mesh_perc
# new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc

# #self.insert1(new_key,skip_duplicates=True)
# print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
# #raise Exception("done with one neuron")
# for path_and_filename in paths_used:
#     os.system("rm "+str(path_and_filename)+"*")

# print(f"Total time: {time.time() - global_time}")
# print("\n\n")

# %%
pinky.UndecimatedNeuronLabels.describe()
# Out:
# # Undecimated Mesh Coarse and Overlayed Labels
# -> pinky.Mesh
# ---
# coarse_vertices_labels : longblob                     # vertex labels for the base compartments
# coarse_triangles_labels : longblob                     # traingle labels for the base compartments
# overlay_vertices_labels : longblob                     # vertex labels for the spine compartments overlayed over the base compartments
# overlay_triangles_labels : longblob                     # triangles labels for the spine compartments overlayed over the base compartments
# '# Undecimated Mesh Coarse and Overlayed Labels\n-> pinky.Mesh\n---\ncoarse_vertices_labels : longblob                     # vertex labels for the base compartments\ncoarse_triangles_labels : longblob                     # traingle labels for the base compartments\noverlay_vertices_labels : longblob                     # vertex labels for the spine compartments overlayed over the base compartments\noverlay_triangles_labels : longblob                     # triangles labels for the spine compartments overlayed over the base compartments\n'

# %%
coarse_test = np.array([4,5,5,5,5,6,7,1,2,10])
spine_test = np.array([12,13,5,5,14,15,2,3,10,2])

non_errors = coarse_test != 10
non_spines = spine_test<12

total_mesh_mask = np.logical_and(non_errors,non_spines)
total_mesh_mask

#get the indices 
total_indices = np.linspace(0,len(coarse_test)-1,len(coarse_test)).astype("int")
face_indexes = total_indices[total_mesh_mask]

print(coarse_test[face_indexes])
print(spine_test[face_indexes])
# Out:
# [5 5 7 1 2]
# [ 5  5  2  3 10]

# %%
help(trimesh.Trimesh.submesh)
# Out:
# Help on function submesh in module trimesh.base:
#
# submesh(self, faces_sequence, **kwargs)
#     Return a subset of the mesh.
#
#     Parameters
#     ----------
#     faces_sequence : sequence (m,) int
#       Face indices of mesh
#     only_watertight : bool
#       Only return submeshes which are watertight
#     append : bool
#       Return a single mesh which has the faces appended.
#       if this flag is set, only_watertight is ignored
#
#     Returns
#     ---------
#     if append : trimesh.Trimesh object
#     else :      list of trimesh.Trimesh objects

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #check to see if the face_indexes is empty
    if not face_indexes.any():
        #create an empty mesh
        current_mesh = trimesh.Trimesh(np.array([]),np.array([]),process=False)
        return current_mesh,np.array([])
    
    
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
#different types of errors

#IndexError
#######print((schema.jobs & "key_hash = '3808fc0c6b3bcd5ec7d82f4eb8ed9955'").fetch1("key","error_message"))
#string is not a file
#print((schema.jobs & "key_hash = '08aa5df56afaa2fe130b05582cf9cd62'").fetch1("key","error_message"))

#print((schema.jobs & "key_hash = '09c57a9a9ce51ad14acc9a89abce05a0'").fetch1("key","error_message"))

#print((schema.jobs & "key_hash = '11d28c04739ffed6715289f434fd8d5b'").fetch1("key","error_message"))

# %%
#schema.jobs & "timestamp>'2019-07-14 10:00:00'"

# %%
#delete the schema so can run it again
#(schema.jobs & "key_hash = '11d28c04739ffed6715289f434fd8d5b'").delete()#.fetch1("key","error_message"))

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'").delete()

# %%
@schema
class NeuronSkeletonStitched(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """
    
    
    key_source = ((dj.U("segmentation","segment_id") & pinky.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & pinky.CoarseLabelOrphan.proj()))
    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        mesh,face_indexes = get_mesh_minus_errors_and_spines(key)
        
        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])
        
        """
        Handle the poosibility that there is no mesh
        """
        if len(mesh.faces) < 50:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),m.vertices,m.faces)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)

                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(output_mesh[:-4])

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(output_mesh)

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(output_mesh[:-4])
                if return_value > 0:
                    print('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'").delete()

# %%
#NeuronSkeletonStitched & "segment_id=neuron648518346349487734"

# %%
start = time.time()
NeuronSkeletonStitched.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346349473811:----------
# Step 1: Retrieving Mesh and removing error segments: 1.5070562362670898
# There were 662 after split and significance threshold
# There were 5 after split and significance threshold
# Mesh piece 0 with number of faces 669275
# Mesh piece 1 with number of faces 16097
# Mesh piece 2 with number of faces 390
# Mesh piece 3 with number of faces 1539
# Mesh piece 4 with number of faces 385
# Step 2a: Getting the number of splits: 1.0167922973632812
# largest mesh perc = 0.9689484786231238
# Working on split 0 with face total = 669275
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 132.6709463596344
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_0_mls
# Step 5: Generating Skeleton: 29.517683267593384
# Step 5: Generating and reading Skeleton: 29.591247081756592
# Working on split 1 with face total = 16097
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.8482341766357422
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_1_mls
# Step 5: Generating Skeleton: 0.5633141994476318
# Step 5: Generating and reading Skeleton: 0.5647156238555908
# Working on split 2 with face total = 390
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9873561859130859
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_2_mls
# Step 5: Generating Skeleton: 0.030440092086791992
# Step 5: Generating and reading Skeleton: 0.031057119369506836
# Working on split 3 with face total = 1539
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1014657020568848
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_3_mls
# Step 5: Generating Skeleton: 0.12921357154846191
# Step 5: Generating and reading Skeleton: 0.13065552711486816
# Working on split 4 with face total = 385
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1023073196411133
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473811_piece_4_mls
# Step 5: Generating Skeleton: 0.035077571868896484
# Step 5: Generating and reading Skeleton: 0.03598284721374512
# len_subgraphs AT BEGINNING = 27
# min_dist = 349.94793898521624
# min_dist_subgraph_index = 5
# min_dist_edge_index = [173, 175]
# min_dist_edge = [array([365656. , 281969. ,  57155.1]), array([365933. , 281921. ,  56946.7])]
# len_subgraphs AT END= 26
# min_dist = 379.88762812179215
# min_dist_subgraph_index = 5
# min_dist_edge_index = [208, 209]
# min_dist_edge = [array([378322. , 278135. ,  56843.9]), array([378438. , 278076. ,  57200.8])]
# len_subgraphs AT END= 25
# min_dist = 496.3215087017707
# min_dist_subgraph_index = 3
# min_dist_edge_index = [157, 153]
# min_dist_edge = [array([358505., 284492.,  57487.]), array([358335. , 284148. ,  57801.8])]
# len_subgraphs AT END= 24
# min_dist = 219.77554459038663
# min_dist_subgraph_index = 3
# min_dist_edge_index = [153, 156]
# min_dist_edge = [array([358335. , 284148. ,  57801.8]), array([358483. , 284036. ,  57684.1])]
# len_subgraphs AT END= 23
# min_dist = 688.0033502825331
# min_dist_subgraph_index = 5
# min_dist_edge_index = [728, 726]
# min_dist_edge = [array([402927. , 169734. ,  68525.9]), array([402851. , 169361. ,  67952.8])]
# len_subgraphs AT END= 22
# min_dist = 774.9041295541035
# min_dist_subgraph_index = 19
# min_dist_edge_index = [930, 921]
# min_dist_edge = [array([417024. , 310105. ,  76379.2]), array([416348. , 310447. ,  76542.1])]
# len_subgraphs AT END= 21
# min_dist = 689.8269710586851
# min_dist_subgraph_index = 19
# min_dist_edge_index = [921, 925]
# min_dist_edge = [array([416348. , 310447. ,  76542.1]), array([416377. , 310147. ,  75921.6])]
# len_subgraphs AT END= 20
# min_dist = 937.2791739924663
# min_dist_subgraph_index = 14
# min_dist_edge_index = [869, 874]
# min_dist_edge = [array([408819. , 309484. ,  79892.8]), array([409407. , 310198. ,  80044.3])]
# len_subgraphs AT END= 19
# min_dist = 994.9387719854918
# min_dist_subgraph_index = 14
# min_dist_edge_index = [869, 875]
# min_dist_edge = [array([408819. , 309484. ,  79892.8]), array([409552. , 308825. ,  80028.2])]
# len_subgraphs AT END= 18
# min_dist = 844.4374221930183
# min_dist_subgraph_index = 13
# min_dist_edge_index = [875, 873]
# min_dist_edge = [array([409552. , 308825. ,  80028.2]), array([409356. , 308245. ,  79446.6])]
# len_subgraphs AT END= 17
# min_dist = 1000.2374518083245
# min_dist_subgraph_index = 13
# min_dist_edge_index = [881, 886]
# min_dist_edge = [array([410686. , 309183. ,  79529.3]), array([411354. , 308718. ,  78947.9])]
# len_subgraphs AT END= 16
# min_dist = 1245.329631061592
# min_dist_subgraph_index = 12
# min_dist_edge_index = [834, 822]
# min_dist_edge = [array([406393. , 306755. ,  72826.3]), array([405772., 307829.,  72718.])]
# len_subgraphs AT END= 15
# min_dist = 1082.934093100776
# min_dist_subgraph_index = 9
# min_dist_edge_index = [820, 811]
# min_dist_edge = [array([405769. , 307830. ,  72716.8]), array([405457. , 308216. ,  73679.3])]
# len_subgraphs AT END= 14
# min_dist = 1325.8435201787593
# min_dist_subgraph_index = 3
# min_dist_edge_index = [397, 504]
# min_dist_edge = [array([393112. , 275059. ,  66116.3]), array([393818. , 274224. ,  65366.5])]
# len_subgraphs AT END= 13
# min_dist = 1456.2792486333108
# min_dist_subgraph_index = 4
# min_dist_edge_index = [810, 763]
# min_dist_edge = [array([405456. , 308216. ,  73679.2]), array([404162. , 308807. ,  73367.7])]
# len_subgraphs AT END= 12
# min_dist = 930.7040345888697
# min_dist_subgraph_index = 4
# min_dist_edge_index = [763, 770]
# min_dist_edge = [array([404162. , 308807. ,  73367.7]), array([404377. , 308931. ,  72470.7])]
# len_subgraphs AT END= 11
# min_dist = 825.1639594650223
# min_dist_subgraph_index = 4
# min_dist_edge_index = [771, 791]
# min_dist_edge = [array([404378. , 308932. ,  72470.4]), array([404878., 309223.,  71882.])]
# len_subgraphs AT END= 10
# min_dist = 823.161369355975
# min_dist_subgraph_index = 4
# min_dist_edge_index = [792, 805]
# min_dist_edge = [array([404879. , 309221. ,  71881.5]), array([405262. , 309528. ,  71220.7])]
# len_subgraphs AT END= 9
# min_dist = 726.4882999746108
# min_dist_subgraph_index = 4
# min_dist_edge_index = [805, 813]
# min_dist_edge = [array([405262. , 309528. ,  71220.7]), array([405475. , 308846. ,  71352.2])]
# len_subgraphs AT END= 8
# min_dist = 193.95195281305755
# min_dist_subgraph_index = 4
# min_dist_edge_index = [813, 817]
# min_dist_edge = [array([405475. , 308846. ,  71352.2]), array([405642. , 308797. ,  71266.6])]
# len_subgraphs AT END= 7
# min_dist = 1496.863470728042
# min_dist_subgraph_index = 1
# min_dist_edge_index = [67, 76]
# min_dist_edge = [array([324801. , 245147. ,  70097.6]), array([324910. , 245680. ,  68703.1])]
# len_subgraphs AT END= 6
# min_dist = 268.7224590539392
# min_dist_subgraph_index = 1
# min_dist_edge_index = [34, 46]
# min_dist_edge = [array([324463. , 245774. ,  68121.2]), array([324566. , 245675. ,  67893.6])]
# len_subgraphs AT END= 5
# min_dist = 1642.524352939706
# min_dist_subgraph_index = 3
# min_dist_edge_index = [906, 912]
# min_dist_edge = [array([414036. , 309129. ,  67746.3]), array([415344. , 309359. ,  66779.8])]
# len_subgraphs AT END= 4
# min_dist = 1996.2171950967663
# min_dist_subgraph_index = 1
# min_dist_edge_index = [604, 634]
# min_dist_edge = [array([398716., 280242.,  71496.]), array([400582. , 279573. ,  71731.3])]
# len_subgraphs AT END= 3
# min_dist = 2166.740614379118
# min_dist_subgraph_index = 1
# min_dist_edge_index = [893, 890]
# min_dist_edge = [array([411976. , 309364. ,  69308.5]), array([411366. , 311436. ,  69136.8])]
# len_subgraphs AT END= 2
# min_dist = 2173.9029164155404
# min_dist_subgraph_index = 1
# min_dist_edge_index = [942, 944]
# min_dist_edge = [array([420669. , 304692. ,  83034.5]), array([421909. , 305759. ,  81602.8])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.46511173248291016
# Total time: 177.24240016937256
#
#
#
# ----------Working on 648518346349473821:----------
# Step 1: Retrieving Mesh and removing error segments: 1.1865289211273193
# There were 671 after split and significance threshold
# There were 3 after split and significance threshold
# Mesh piece 0 with number of faces 27795
# Mesh piece 1 with number of faces 606893
# Mesh piece 2 with number of faces 15302
# Step 2a: Getting the number of splits: 1.0807251930236816
# largest mesh perc = 0.9295173009532678
# Working on split 0 with face total = 27795
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.842616081237793
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_0_mls
# Step 5: Generating Skeleton: 0.9207675457000732
# Step 5: Generating and reading Skeleton: 0.9253230094909668
# Working on split 1 with face total = 606893
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 132.54634070396423
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_1_mls
# Step 5: Generating Skeleton: 26.996694564819336
# Step 5: Generating and reading Skeleton: 27.01312279701233
# Working on split 2 with face total = 15302
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.677183151245117
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473821_piece_2_mls
# Step 5: Generating Skeleton: 0.5297188758850098
# Step 5: Generating and reading Skeleton: 0.53131103515625
# len_subgraphs AT BEGINNING = 18
# min_dist = 4076.92730496878
# min_dist_subgraph_index = 1
# min_dist_edge_index = [472, 473]
# min_dist_edge = [array([341071. , 294577. ,  60341.4]), array([345123. , 294127. ,  60329.9])]
# len_subgraphs AT END= 17
# min_dist = 268.4850833845314
# min_dist_subgraph_index = 1
# min_dist_edge_index = [486, 485]
# min_dist_edge = [array([353773. , 292120. ,  61688.2]), array([353552. , 292176. ,  61546.4])]
# len_subgraphs AT END= 16
# min_dist = 401.9754345728107
# min_dist_subgraph_index = 6
# min_dist_edge_index = [1282, 1280]
# min_dist_edge = [array([445943. , 309918. ,  48178.4]), array([445826. , 310135. ,  48495.9])]
# len_subgraphs AT END= 15
# min_dist = 316.4955607903519
# min_dist_subgraph_index = 6
# min_dist_edge_index = [1280, 1284]
# min_dist_edge = [array([445826. , 310135. ,  48495.9]), array([446060. , 310333. ,  48574.7])]
# len_subgraphs AT END= 14
# min_dist = 606.6316510041327
# min_dist_subgraph_index = 8
# min_dist_edge_index = [1337, 1327]
# min_dist_edge = [array([450536. , 311830. ,  58296.9]), array([450286. , 311279. ,  58340.5])]
# len_subgraphs AT END= 13
# min_dist = 660.8808061973041
# min_dist_subgraph_index = 11
# min_dist_edge_index = [1362, 1360]
# min_dist_edge = [array([455208. , 310890. ,  58192.3]), array([454633. , 311109. ,  58433.5])]
# len_subgraphs AT END= 12
# min_dist = 824.6812778279872
# min_dist_subgraph_index = 10
# min_dist_edge_index = [1356, 1351]
# min_dist_edge = [array([452367. , 311164. ,  56682.1]), array([452204., 311707.,  57281.])]
# len_subgraphs AT END= 11
# min_dist = 723.5898631130763
# min_dist_subgraph_index = 9
# min_dist_edge_index = [1351, 1347]
# min_dist_edge = [array([452204., 311707.,  57281.]), array([451649. , 311251. ,  57193.7])]
# len_subgraphs AT END= 10
# min_dist = 1109.5748059504597
# min_dist_subgraph_index = 9
# min_dist_edge_index = [1366, 1363]
# min_dist_edge = [array([455884. , 311835. ,  55511.9]), array([455434. , 312367. ,  56375.4])]
# len_subgraphs AT END= 9
# min_dist = 1240.3422269680266
# min_dist_subgraph_index = 8
# min_dist_edge_index = [1341, 1331]
# min_dist_edge = [array([451196. , 310643. ,  55344.1]), array([450431. , 311369. ,  55996.9])]
# len_subgraphs AT END= 8
# min_dist = 1326.3229659475862
# min_dist_subgraph_index = 5
# min_dist_edge_index = [1264, 1254]
# min_dist_edge = [array([444702. , 311333. ,  47783.7]), array([443827. , 312015. ,  48510.6])]
# len_subgraphs AT END= 7
# min_dist = 1439.7316590253893
# min_dist_subgraph_index = 4
# min_dist_edge_index = [1254, 1247]
# min_dist_edge = [array([443827. , 312015. ,  48510.6]), array([443755. , 311276. ,  49744.1])]
# len_subgraphs AT END= 6
# min_dist = 348.64595222087405
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1247, 1246]
# min_dist_edge = [array([443755. , 311276. ,  49744.1]), array([443678. , 311551. ,  49944.1])]
# len_subgraphs AT END= 5
# min_dist = 1536.3491660426666
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1337, 1314]
# min_dist_edge = [array([450536. , 311830. ,  58296.9]), array([449341. , 312319. ,  57464.3])]
# len_subgraphs AT END= 4
# min_dist = 1737.9431549967348
# min_dist_subgraph_index = 1
# min_dist_edge_index = [970, 1018]
# min_dist_edge = [array([427178. , 263091. ,  37603.4]), array([427797. , 263032. ,  35980.5])]
# len_subgraphs AT END= 3
# min_dist = 18.63437683422949
# min_dist_subgraph_index = 1
# min_dist_edge_index = [954, 955]
# min_dist_edge = [array([426884. , 262080. ,  21398.6]), array([426896. , 262088. ,  21410.4])]
# len_subgraphs AT END= 2
# min_dist = 2275.1326466823853
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1329, 1326]
# min_dist_edge = [array([450304. , 310752. ,  47927.4]), array([450272. , 311993. ,  46020.8])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.43303370475769043
# Total time: 174.98265075683594
#
#
#
# ----------Working on 648518346349473835:----------
# Step 1: Retrieving Mesh and removing error segments: 0.8186407089233398
# There were 987 after split and significance threshold
# There were 10 after split and significance threshold
# Mesh piece 0 with number of faces 482342
# Mesh piece 1 with number of faces 12750
# Mesh piece 2 with number of faces 205
# Mesh piece 3 with number of faces 311
# Mesh piece 4 with number of faces 257
# Mesh piece 5 with number of faces 554
# Mesh piece 6 with number of faces 2363
# Mesh piece 7 with number of faces 361
# Mesh piece 8 with number of faces 276
# Mesh piece 9 with number of faces 336
# Step 2a: Getting the number of splits: 0.9097821712493896
# largest mesh perc = 0.9535786233524375
# Working on split 0 with face total = 482342
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 54.63281583786011
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_0_mls
# skeletonization for neuron 648518346349473835 did not finish... exited with error code: 4
# Trying skeletonization with pymesh
# Step 2b: Pymesh shrinkwrapping: 151.77448296546936
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.9739887714385986
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 41.8691987991333
# Step 5: Generating Skeleton: 16.84471082687378
# Step 5: Generating and reading Skeleton: 16.860684156417847
# Working on split 1 with face total = 12750
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.694397211074829
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_1_mls
# Step 5: Generating Skeleton: 0.48371052742004395
# Step 5: Generating and reading Skeleton: 0.4852426052093506
# Working on split 2 with face total = 205
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.9781076908111572
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_2_mls
# Step 5: Generating Skeleton: 0.018118858337402344
# Step 5: Generating and reading Skeleton: 0.018768787384033203
# Working on split 3 with face total = 311
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1497149467468262
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_3_mls
# Number of faces are less than 20 so not generating skeleton
# Working on split 4 with face total = 257
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0121378898620605
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_4_mls
# Number of faces are less than 20 so not generating skeleton
# Working on split 5 with face total = 554
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.046128749847412
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_5_mls
# Step 5: Generating Skeleton: 0.054013729095458984
# Step 5: Generating and reading Skeleton: 0.05461549758911133
# Working on split 6 with face total = 2363
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1320290565490723
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_6_mls
# skeletonization for neuron 648518346349473835 did not finish... exited with error code: 4
# Trying skeletonization with pymesh
# Step 2b: Pymesh shrinkwrapping: 0.03312349319458008
# Number of faces are less than 20 so not generating skeleton
# Working on split 7 with face total = 361
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0284953117370605
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_7_mls
# Number of faces are less than 20 so not generating skeleton
# Working on split 8 with face total = 276
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.066678762435913
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_8_mls
# Number of faces are less than 20 so not generating skeleton
# Working on split 9 with face total = 336
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0443577766418457
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349473835_piece_9_mls
# Step 5: Generating Skeleton: 0.024687767028808594
# Step 5: Generating and reading Skeleton: 0.02565741539001465
# len_subgraphs AT BEGINNING = 6
# min_dist = 1618.4652884754742
# min_dist_subgraph_index = 1
# min_dist_edge_index = [432, 427]
# min_dist_edge = [array([422352. , 251047. ,  10374.8]), array([422012. , 252610. ,  10621.5])]
# len_subgraphs AT END= 5
# min_dist = 1782.8699363666449
# min_dist_subgraph_index = 4
# min_dist_edge_index = [937, 968]
# min_dist_edge = [array([449548. , 258414. ,  20008.6]), array([449847. , 257547. ,  21537.5])]
# len_subgraphs AT END= 4
# min_dist = 2350.3321552495513
# min_dist_subgraph_index = 3
# min_dist_edge_index = [660, 666]
# min_dist_edge = [array([443421. , 253376. ,  23935.6]), array([443750. , 255547. ,  24773.8])]
# len_subgraphs AT END= 3
# min_dist = 3100.4686742491044
# min_dist_subgraph_index = 2
# min_dist_edge_index = [606, 621]
# min_dist_edge = [array([439905. , 254966. ,  17355.8]), array([440656. , 254937. ,  20363.8])]
# len_subgraphs AT END= 2
# min_dist = 547.2398834149427
# min_dist_subgraph_index = 1
# min_dist_edge_index = [621, 615]
# min_dist_edge = [array([440656. , 254937. ,  20363.8]), array([440471. , 254425. ,  20419.5])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.36765360832214355
# Total time: 285.92206263542175
#
#
#
# ----------Working on 648518346349474146:----------
# Step 1: Retrieving Mesh and removing error segments: 5.46516489982605
# There were 1015 after split and significance threshold
# There were 17 after split and significance threshold
# Mesh piece 0 with number of faces 30147
# Mesh piece 1 with number of faces 1765154
# Mesh piece 2 with number of faces 22136
# Mesh piece 3 with number of faces 9838
# Mesh piece 4 with number of faces 588
# Mesh piece 5 with number of faces 22538
# Mesh piece 6 with number of faces 5370
# Mesh piece 7 with number of faces 13477
# Mesh piece 8 with number of faces 7548
# Mesh piece 9 with number of faces 2010
# Mesh piece 10 with number of faces 322
# Mesh piece 11 with number of faces 5526
# Mesh piece 12 with number of faces 284
# Mesh piece 13 with number of faces 220
# Mesh piece 14 with number of faces 2982
# Mesh piece 15 with number of faces 266
# Mesh piece 16 with number of faces 618
# Step 2a: Getting the number of splits: 2.9137885570526123
# largest mesh perc = 0.9320974746322629
# Working on split 0 with face total = 30147
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 3.804489850997925
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_0_mls
# Step 5: Generating Skeleton: 0.8625028133392334
# Step 5: Generating and reading Skeleton: 0.8663606643676758
# Working on split 1 with face total = 1765154
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 262.2465682029724
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_1_mls
# skeletonization for neuron 648518346349474146 did not finish... exited with error code: 4
# Trying skeletonization with pymesh
# Step 2b: Pymesh shrinkwrapping: 1117.5541853904724
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 6.166734218597412
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 201.06741571426392
# Step 5: Generating Skeleton: 61.87794065475464
# Step 5: Generating and reading Skeleton: 61.904825925827026
# Working on split 2 with face total = 22136
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 3.095778465270996
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_2_mls
# Step 5: Generating Skeleton: 0.6893081665039062
# Step 5: Generating and reading Skeleton: 0.6912004947662354
# Working on split 3 with face total = 9838
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.729274034500122
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_3_mls
# Step 5: Generating Skeleton: 0.29382777214050293
# Step 5: Generating and reading Skeleton: 0.2953054904937744
# Working on split 4 with face total = 588
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1065542697906494
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_4_mls
# Step 5: Generating Skeleton: 0.03187870979309082
# Step 5: Generating and reading Skeleton: 0.03251934051513672
# Working on split 5 with face total = 22538
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 3.093425989151001
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_5_mls
# Step 5: Generating Skeleton: 0.6752166748046875
# Step 5: Generating and reading Skeleton: 0.6789484024047852
# Working on split 6 with face total = 5370
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.4382145404815674
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_6_mls
# Step 5: Generating Skeleton: 0.18271803855895996
# Step 5: Generating and reading Skeleton: 0.18364524841308594
# Working on split 7 with face total = 13477
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.274061441421509
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_7_mls
# Step 5: Generating Skeleton: 0.43209314346313477
# Step 5: Generating and reading Skeleton: 0.4349954128265381
# Working on split 8 with face total = 7548
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.5761210918426514
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_8_mls
# Step 5: Generating Skeleton: 0.315201997756958
# Step 5: Generating and reading Skeleton: 0.3168792724609375
# Working on split 9 with face total = 2010
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1575393676757812
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_9_mls
# Step 5: Generating Skeleton: 0.1152808666229248
# Step 5: Generating and reading Skeleton: 0.1163179874420166
# Working on split 10 with face total = 322
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.118173599243164
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_10_mls
# Step 5: Generating Skeleton: 0.02265787124633789
# Step 5: Generating and reading Skeleton: 0.02332925796508789
# Working on split 11 with face total = 5526
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.3472042083740234
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_11_mls
# Step 5: Generating Skeleton: 0.23047304153442383
# Step 5: Generating and reading Skeleton: 0.23203182220458984
# Working on split 12 with face total = 284
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1164605617523193
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_12_mls
# Step 5: Generating Skeleton: 0.022980690002441406
# Step 5: Generating and reading Skeleton: 0.02358865737915039
# Working on split 13 with face total = 220
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0989792346954346
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_13_mls
# Step 5: Generating Skeleton: 0.02292037010192871
# Step 5: Generating and reading Skeleton: 0.023557662963867188
# Working on split 14 with face total = 2982
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.2347593307495117
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_14_mls
# Step 5: Generating Skeleton: 0.1276562213897705
# Step 5: Generating and reading Skeleton: 0.128631591796875
# Working on split 15 with face total = 266
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_15.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.071493148803711
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_15_mls
# Step 5: Generating Skeleton: 0.02266669273376465
# Step 5: Generating and reading Skeleton: 0.023442983627319336
# Working on split 16 with face total = 618
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_16.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_16_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.145862102508545
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349474146_piece_16_mls
# Step 5: Generating Skeleton: 0.041375160217285156
# Step 5: Generating and reading Skeleton: 0.04171156883239746
# len_subgraphs AT BEGINNING = 18
# min_dist = 991.2393706870222
# min_dist_subgraph_index = 3
# min_dist_edge_index = [335, 349]
# min_dist_edge = [array([280514. , 179557. ,  33667.7]), array([280945., 178919.,  34292.])]
# len_subgraphs AT END= 17
# min_dist = 1268.6793330073601
# min_dist_subgraph_index = 3
# min_dist_edge_index = [979, 1023]
# min_dist_edge = [array([310011. , 182849. ,  54635.9]), array([310504. , 182925. ,  55802.4])]
# len_subgraphs AT END= 16
# min_dist = 9447.016714815318
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1070, 929]
# min_dist_edge = [array([310569. , 182984. ,  56479.7]), array([308289. , 192140. ,  56943.8])]
# len_subgraphs AT END= 15
# min_dist = 1172.8846874266844
# min_dist_subgraph_index = 5
# min_dist_edge_index = [2079, 2078]
# min_dist_edge = [array([401510. , 240468. ,  33117.9]), array([401448. , 239900. ,  34142.2])]
# len_subgraphs AT END= 14
# min_dist = 2093.318144573347
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1175, 1179]
# min_dist_edge = [array([327240. , 188068. ,  10219.6]), array([328309.  , 186288.  ,   9953.48])]
# len_subgraphs AT END= 13
# min_dist = 2308.4613836926105
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1151, 1140]
# min_dist_edge = [array([321040. , 199519. ,  21596.8]), array([319035. , 200463. ,  22243.2])]
# len_subgraphs AT END= 12
# min_dist = 2318.502973903634
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2745, 2795]
# min_dist_edge = [array([416610. , 269960. ,  16137.4]), array([417904. , 270318. ,  14247.2])]
# len_subgraphs AT END= 11
# min_dist = 2551.8655842344083
# min_dist_subgraph_index = 3
# min_dist_edge_index = [2220, 2261]
# min_dist_edge = [array([404728., 215446.,  67827.]), array([406003. , 217038. ,  69360.6])]
# len_subgraphs AT END= 10
# min_dist = 678.3056022177612
# min_dist_subgraph_index = 3
# min_dist_edge_index = [3057, 3077]
# min_dist_edge = [array([422999. , 240183. ,  86062.5]), array([423350. , 240762. ,  86021.8])]
# len_subgraphs AT END= 9
# min_dist = 10214.143018873392
# min_dist_subgraph_index = 5
# min_dist_edge_index = [3401, 3614]
# min_dist_edge = [array([448083. , 174013. ,  28237.3]), array([453648. , 175482. ,  36675.4])]
# len_subgraphs AT END= 8
# min_dist = 767.8578579398644
# min_dist_subgraph_index = 5
# min_dist_edge_index = [3733, 3735]
# min_dist_edge = [array([454965. , 187549. ,  33611.6]), array([454981. , 188229. ,  33255.3])]
# len_subgraphs AT END= 7
# min_dist = 603.9991390722386
# min_dist_subgraph_index = 5
# min_dist_edge_index = [3763, 3779]
# min_dist_edge = [array([455036. , 188515. ,  33276.2]), array([455195. , 188868. ,  33739.8])]
# len_subgraphs AT END= 6
# min_dist = 1211.3368647903026
# min_dist_subgraph_index = 4
# min_dist_edge_index = [3614, 3688]
# min_dist_edge = [array([453648. , 175482. ,  36675.4]), array([454244. , 174543. ,  37155.4])]
# len_subgraphs AT END= 5
# min_dist = 12579.581827707945
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1770, 1684]
# min_dist_edge = [array([391204. , 274984. ,  43938.4]), array([383109. , 277122. ,  34549.8])]
# len_subgraphs AT END= 4
# min_dist = 15307.787299280062
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1372, 1483]
# min_dist_edge = [array([358039. , 225715. ,  19273.1]), array([372163. , 225891. ,  25173.1])]
# len_subgraphs AT END= 3
# min_dist = 22706.86729692143
# min_dist_subgraph_index = 2
# min_dist_edge_index = [4106, 4125]
# min_dist_edge = [array([456682. , 201487. ,  26003.6]), array([456752. , 223114. ,  32922.4])]
# len_subgraphs AT END= 2
# min_dist = 17973.896522735413
# min_dist_subgraph_index = 1
# min_dist_edge_index = [4039, 4216]
# min_dist_edge = [array([456275. , 223629. ,  33047.2]), array([459077. , 230342. ,  49483.3])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 1.4900288581848145
# Total time: 1710.8898553848267
#
#
#
# ----------Working on 648518346349475132:----------
# Step 1: Retrieving Mesh and removing error segments: 3.341357469558716
# There were 736 after split and significance threshold
# There were 4 after split and significance threshold
# Mesh piece 0 with number of faces 747802
# Mesh piece 1 with number of faces 45442
# Mesh piece 2 with number of faces 25613
# Mesh piece 3 with number of faces 298
# Step 2a: Getting the number of splits: 1.565225601196289
# largest mesh perc = 0.9087309881542044
# Working on split 0 with face total = 747802
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 106.8205726146698
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_0_mls
# skeletonization for neuron 648518346349475132 did not finish... exited with error code: 4
# Trying skeletonization with pymesh
# Step 2b: Pymesh shrinkwrapping: 250.69258880615234
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.0785717964172363
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 95.1754744052887
# Step 5: Generating Skeleton: 28.283179759979248
# Step 5: Generating and reading Skeleton: 28.28843641281128
# Working on split 1 with face total = 45442
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 6.071836471557617
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_1_mls
# Step 5: Generating Skeleton: 1.3790593147277832
# Step 5: Generating and reading Skeleton: 1.3806869983673096
# Working on split 2 with face total = 25613
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 3.0255424976348877
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_2_mls
# Step 5: Generating Skeleton: 0.8195130825042725
# Step 5: Generating and reading Skeleton: 0.8206400871276855
# Working on split 3 with face total = 298
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1242458820343018
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475132_piece_3_mls
# Step 5: Generating Skeleton: 0.020142793655395508
# Step 5: Generating and reading Skeleton: 0.020806312561035156
# len_subgraphs AT BEGINNING = 6
# min_dist = 1392.4847719095542
# min_dist_subgraph_index = 4
# min_dist_edge_index = [607, 622]
# min_dist_edge = [array([245140. , 292643. ,  56041.7]), array([245911. , 291550. ,  56428.9])]
# len_subgraphs AT END= 5
# min_dist = 504.2892126547955
# min_dist_subgraph_index = 4
# min_dist_edge_index = [1202, 1212]
# min_dist_edge = [array([274191. , 272927. ,  82390.9]), array([274524. , 272838. ,  82022.8])]
# len_subgraphs AT END= 4
# min_dist = 1426.454079176755
# min_dist_subgraph_index = 3
# min_dist_edge_index = [558, 560]
# min_dist_edge = [array([242177. , 265478. ,  68165.5]), array([242469. , 266718. ,  68807.3])]
# len_subgraphs AT END= 3
# min_dist = 2632.8300002089013
# min_dist_subgraph_index = 1
# min_dist_edge_index = [130, 110]
# min_dist_edge = [array([215710. , 276449. ,  50665.6]), array([215077. , 273979. ,  50009.7])]
# len_subgraphs AT END= 2
# min_dist = 2163.6903660182065
# min_dist_subgraph_index = 1
# min_dist_edge_index = [118, 126]
# min_dist_edge = [array([215120. , 273639. ,  49995.4]), array([215396. , 271493. ,  50003.4])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.5347342491149902
# Total time: 507.4508047103882
#
#
#
# ----------Working on 648518346349475518:----------
# Step 1: Retrieving Mesh and removing error segments: 3.2378287315368652
# There were 1365 after split and significance threshold
# There were 7 after split and significance threshold
# Mesh piece 0 with number of faces 1407463
# Mesh piece 1 with number of faces 115449
# Mesh piece 2 with number of faces 1587
# Mesh piece 3 with number of faces 3439
# Mesh piece 4 with number of faces 241
# Mesh piece 5 with number of faces 1101
# Mesh piece 6 with number of faces 333
# Step 2a: Getting the number of splits: 2.542393922805786
# largest mesh perc = 0.9169510429737228
# Working on split 0 with face total = 1407463
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute.mls
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-1c75e0c54da0> in <module>
#       1 start = time.time()
# ----> 2 NeuronSkeletonStitched.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-22-094593227357> in make(self, key)
#     151                 #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
#     152                 meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute.mls"
# --> 153                 output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
#     154
#     155                 print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")
#
# <ipython-input-11-9871fe572ed4> in meshlab_fix_manifold_path_specific_mls(path_and_filename, segment_id, meshlab_script)
#      71     if str(subprocess_result_1)[-13:] != "returncode=0)":
#      72         raise Exception('neuron' + str(segment_id) +
# ---> 73                          ' did not fix the manifold edges')
#      74
#      75     return output_mesh
#
# Exception: neuron648518346349475518 did not fix the manifold edges
