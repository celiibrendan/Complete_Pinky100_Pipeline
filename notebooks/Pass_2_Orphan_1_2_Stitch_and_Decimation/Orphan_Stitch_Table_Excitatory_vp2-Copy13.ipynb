# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346342802989**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 43 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 453081
# Total time for Mesh Cleansing: 0.89164137840271
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994749834002105% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342803184**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 157 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 398043
# Total time for Mesh Cleansing: 9.21358323097229
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9974690078761468% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342914599**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 46 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 193962
# Total time for Mesh Cleansing: 4.4973530769348145
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985482177055662% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342921511**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 182 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 847640
# Total time for Mesh Cleansing: 28.650784254074097
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986545426269643% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346593203**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 104670
# Total time for Mesh Cleansing: 4.506344795227051
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9980928768952035% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348109681**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 20282
# Total time for Mesh Cleansing: 0.06654763221740723
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986213687838503% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348109921**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 25132
# Total time for Mesh Cleansing: 0.17920279502868652
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996022591679262% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348118246**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 37598
# Total time for Mesh Cleansing: 0.19748353958129883
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994152046783625% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348124657**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 24708
# Total time for Mesh Cleansing: 0.05731940269470215
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348193043**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 93 pieces after mesh split
# There were 19 pieces found after size threshold
# max_index = 0
# max_face_len = 197120
# Total time for Mesh Cleansing: 16.73906683921814
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9895383626834803% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349484055**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 79142
# Total time for Mesh Cleansing: 0.4373483657836914
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994948346846505% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349493495**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 352818
# Total time for Mesh Cleansing: 1.2591285705566406
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999257958536309% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349497305**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 62 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 285154
# Total time for Mesh Cleansing: 0.8360223770141602
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987810943531044% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349502858**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 263 pieces after mesh split
# There were 59 pieces found after size threshold
# max_index = 0
# max_face_len = 432962
# Total time for Mesh Cleansing: 40.50656723976135
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9836111010141398% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349513651**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 134 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 394116
# Total time for Mesh Cleansing: 16.9573335647583
# Number of outside child meshes =  3
# Main mesh and outside child meshes make up 0.9983662104056674% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349513651_30_main_and_child_meshes_array.npz
#  face length 394116 using optimized facets with 3 neighbors
# Filtering edges by size finished: 17.341390132904053, facet # = 21866
# Filtering by convexity and getting centers took: 23.291947841644287, facet # = 3856
# Finished 3856 facets for main mesh: 42.007487773895264
# Filtering edges by size finished: 3.592130422592163, facet # = 5831
# Filtering by convexity and getting centers took: 3.483672857284546, facet # = 1003
# Filtering edges by size finished: 0.0075571537017822266, facet # = 9
# Filtering by convexity and getting centers took: 0.005166292190551758, facet # = 1
# Filtering edges by size finished: 0.00344085693359375, facet # = 5
# Filtering by convexity and getting centers took: 0.002434968948364258, facet # = 0
# Total time for facets: 49.2066330909729
# Zero faceted faces = [2]
# Starting Child 0
# 1003 3856
# Done distance matrix: 0.47330665588378906
# Done Generating final pairs: 0.5193228721618652
# best_stitch_pair = [ 203 3670]
# best_stitch_pair_size = 93241.22181754545
# best_stitch_pair_distance = 1754.7363033585684
# best_stitch_pair_size_ratio = 0.23779644029746755
# Starting Child 1
# 1 3856
# Done distance matrix: 0.011307716369628906
# Child 1 There were no points close enough
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [203, 3670]}
# ---Stitching child 0 with pair: [203, 3670]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 125248, starting edge 2nd facet= 217995,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0061054229736328125
# returned from stitch mesh: 0.25368475914001465
# Finished stitching child 0 : 0.322678804397583
# ***************Finished big stitching iteration: 1.130422592163086***************
# Starting Child 1
# 1 4857
# Done distance matrix: 0.0005495548248291016
# Child 1 There were no points close enough
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# 1 4857
# Done distance matrix: 0.0004565715789794922
# Child 1 There were no points close enough
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 1
# 1 4857
# Done distance matrix: 0.0007662773132324219
# Child 1 There were no points close enough
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 1
# 1 4857
# Done distance matrix: 0.0003998279571533203
# Child 1 There were no points close enough
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 2.0805227756500244
# Total time for restitching = 2.092085123062134
# missed_children = [1.0, 2.0]
# Whole stitching function complete: 70.1128318309784
#
#
#
# *****Running Neuron Stitcher for 648518346341404064**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 56 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 245970
# Total time for Mesh Cleansing: 10.146691799163818
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986682798885902% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410889**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 39 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 175978
# Total time for Mesh Cleansing: 0.5100252628326416
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990575892451631% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341414523**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 72 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 306499
# Total time for Mesh Cleansing: 10.286900997161865
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998709656397139% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342804152**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 140894
# Total time for Mesh Cleansing: 3.967695951461792
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991490206646149% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342807112**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 134 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 608073
# Total time for Mesh Cleansing: 17.593863487243652
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983040718692642% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349490009**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 330 pieces after mesh split
# There were 84 pieces found after size threshold
# max_index = 3
# max_face_len = 301446
# Total time for Mesh Cleansing: 16.41206192970276
# Number of outside child meshes =  11
# Main mesh and outside child meshes make up 0.9722893216455822% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349490009_30_main_and_child_meshes_array.npz
#  face length 301446 using optimized facets with 3 neighbors
# Filtering edges by size finished: 7.680144309997559, facet # = 16450
# Filtering by convexity and getting centers took: 12.329354047775269, facet # = 2680
# Finished 2680 facets for main mesh: 20.34868311882019
# Filtering edges by size finished: 0.018300294876098633, facet # = 24
# Filtering by convexity and getting centers took: 0.022617816925048828, facet # = 18
# Filtering edges by size finished: 0.0051152706146240234, facet # = 25
# Filtering by convexity and getting centers took: 0.011714935302734375, facet # = 5
# Filtering edges by size finished: 0.006673097610473633, facet # = 27
# Filtering by convexity and getting centers took: 0.0239408016204834, facet # = 14
# Filtering edges by size finished: 0.026200532913208008, facet # = 52
# Filtering by convexity and getting centers took: 0.03396153450012207, facet # = 18
# Filtering edges by size finished: 0.3562800884246826, facet # = 1019
# Filtering by convexity and getting centers took: 0.5420293807983398, facet # = 121
# Filtering edges by size finished: 0.016567707061767578, facet # = 33
# Filtering by convexity and getting centers took: 0.017030000686645508, facet # = 13
# Filtering edges by size finished: 0.17188262939453125, facet # = 124
# Filtering by convexity and getting centers took: 0.14949393272399902, facet # = 43
# Filtering edges by size finished: 0.02581000328063965, facet # = 92
# Filtering by convexity and getting centers took: 0.04398465156555176, facet # = 23
# Filtering edges by size finished: 0.017667293548583984, facet # = 66
# Filtering by convexity and getting centers took: 0.029810428619384766, facet # = 25
# Filtering edges by size finished: 0.007210969924926758, facet # = 33
# Filtering by convexity and getting centers took: 0.014989852905273438, facet # = 15
# Filtering edges by size finished: 0.0019104480743408203, facet # = 6
# Filtering by convexity and getting centers took: 0.003393411636352539, facet # = 4
# Total time for facets: 21.98626136779785
# Zero faceted faces = []
# Starting Child 0
# 18 2680
# Done distance matrix: 0.0027642250061035156
# Child 0 There were no points close enough
# Starting Child 1
# 5 2680
# Done distance matrix: 0.0009675025939941406
# Done Generating final pairs: 0.003985404968261719
# best_stitch_pair = [   0 1759]
# best_stitch_pair_size = 138286.80437797477
# best_stitch_pair_distance = 1309.1721382189937
# best_stitch_pair_size_ratio = 0.7409628911106529
# Starting Child 2
# 14 2680
# Done distance matrix: 0.0019078254699707031
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 18 2680
# Done distance matrix: 0.0023987293243408203
# Done Generating final pairs: 0.007407665252685547
# best_stitch_pair = [   9 1759]
# best_stitch_pair_size = 143137.67487967893
# best_stitch_pair_distance = 177.85832846920692
# best_stitch_pair_size_ratio = 0.8020329662420977
# Starting Child 4
# 121 2680
# Done distance matrix: 0.020559072494506836
# Done Generating final pairs: 0.026256799697875977
# best_stitch_pair = [ 13 979]
# best_stitch_pair_size = 341333.94038186956
# best_stitch_pair_distance = 144.28258716031888
# best_stitch_pair_size_ratio = 0.8519991403790766
# Starting Child 5
# returning x less min
# skipped by bounding box filter
# Starting Child 6
# 43 2680
# Done distance matrix: 0.005486726760864258
# Done Generating final pairs: 0.01822066307067871
# best_stitch_pair = [ 37 131]
# best_stitch_pair_size = 74740.721472516
# best_stitch_pair_distance = 1807.263182080462
# best_stitch_pair_size_ratio = 0.3892569296577702
# Starting Child 7
# returning y less min
# skipped by bounding box filter
# Starting Child 8
# returning y less min
# skipped by bounding box filter
# Starting Child 9
# returning y less min
# skipped by bounding box filter
# Starting Child 10
# 4 2680
# Done distance matrix: 0.0009007453918457031
# Done Generating final pairs: 0.004436492919921875
# best_stitch_pair = [  3 987]
# best_stitch_pair_size = 25119.881493804412
# best_stitch_pair_distance = 389.7356611759783
# best_stitch_pair_size_ratio = 0.4945357162800715
# repeat_main_facets = [1759]
# child_mesh_double_indexes = [1, 3]
# min_child = 3, max_ratio = 177.85832846920692
# child_meshes_stitch_facets = {3: [9, 1759], 4: [13, 979], 6: [37, 131], 10: [3, 987]}
# ---Stitching child 3 with pair: [9, 1759]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 91110, starting edge 2nd facet= 151821,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.2649765014648438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0016939640045166016
# returned from stitch mesh: 0.25969958305358887
# Finished stitching child 3 : 0.27979040145874023
# ---Stitching child 4 with pair: [13, 979]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 71630, starting edge 2nd facet= 152734,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.8848648071289062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0017192363739013672
# returned from stitch mesh: 0.4479844570159912
# Finished stitching child 4 : 0.533738374710083
# ---Stitching child 6 with pair: [37, 131]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 71087, starting edge 2nd facet= 155768,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0018420219421386719
# returned from stitch mesh: 0.3364415168762207
# Finished stitching child 6 : 0.3682248592376709
# ---Stitching child 10 with pair: [3, 987]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 139317, starting edge 2nd facet= 155995,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.5735626220703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0045108795166015625
# returned from stitch mesh: 0.2589552402496338
# Finished stitching child 10 : 0.32376909255981445
# ***************Finished big stitching iteration: 1.6678409576416016***************
# Starting Child 0
# 18 2858
# Done distance matrix: 0.002891063690185547
# Done Generating final pairs: 0.006078243255615234
# best_stitch_pair = [   9 2691]
# best_stitch_pair_size = 123139.86932896753
# best_stitch_pair_distance = 1838.0566263955263
# best_stitch_pair_size_ratio = 0.3209803978504417
# Starting Child 1
# 5 2858
# Done distance matrix: 0.0009295940399169922
# Done Generating final pairs: 0.005535125732421875
# best_stitch_pair = [   0 2691]
# best_stitch_pair_size = 88776.91088584223
# best_stitch_pair_distance = 914.8845319540757
# best_stitch_pair_size_ratio = 0.5083854838693659
# Starting Child 2
# 14 2858
# Done distance matrix: 0.0020825862884521484
# Done Generating final pairs: 0.007683277130126953
# best_stitch_pair = [   5 2691]
# best_stitch_pair_size = 203652.29498115665
# best_stitch_pair_distance = 1517.2543403387979
# best_stitch_pair_size_ratio = 0.17222793033850795
# Starting Child 5
# 13 2858
# Done distance matrix: 0.001817464828491211
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 7
# 23 2858
# Done distance matrix: 0.0036995410919189453
# Done Generating final pairs: 0.017446041107177734
# best_stitch_pair = [   1 2770]
# best_stitch_pair_size = 1376324.6298242449
# best_stitch_pair_distance = 1350.4805933907767
# best_stitch_pair_size_ratio = 0.7770014884097418
# Starting Child 8
# 25 2858
# Done distance matrix: 0.002665996551513672
# Done Generating final pairs: 0.008571386337280273
# best_stitch_pair = [   1 2770]
# best_stitch_pair_size = 1108731.9894016944
# best_stitch_pair_distance = 1794.9414801950666
# best_stitch_pair_size_ratio = 0.8423478722501336
# Starting Child 9
# 15 2858
# Done distance matrix: 0.0018153190612792969
# Done Generating final pairs: 0.002958536148071289
# best_stitch_pair = [   9 2776]
# best_stitch_pair_size = 76281.89035784495
# best_stitch_pair_distance = 1751.6961598068933
# best_stitch_pair_size_ratio = 0.21750505702695822
# repeat_main_facets = [2691, 2770]
# child_mesh_double_indexes = [0, 1, 2]
# min_child = 1, max_ratio = 914.8845319540757
# child_mesh_double_indexes = [7, 8]
# min_child = 7, max_ratio = 1350.4805933907767
# child_meshes_stitch_facets = {1: [0, 2691], 7: [1, 2770], 9: [9, 2776]}
# ---Stitching child 1 with pair: [0, 2691]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 151827, starting edge 2nd facet= 156052,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00409698486328125
# returned from stitch mesh: 0.2694699764251709
# Finished stitching child 1 : 0.2897820472717285
# ---Stitching child 7 with pair: [1, 2770]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 153251, starting edge 2nd facet= 156165,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 5.53131103515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004410266876220703
# returned from stitch mesh: 0.24041390419006348
# Finished stitching child 7 : 0.26392412185668945
# ---Stitching child 9 with pair: [9, 2776]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 152968, starting edge 2nd facet= 156471,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.0265579223632812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.005207538604736328
# returned from stitch mesh: 0.33438801765441895
# Finished stitching child 9 : 0.429293155670166
# ***************Finished big stitching iteration: 1.4495749473571777***************
# Starting Child 0
# 18 2895
# Done distance matrix: 0.0030639171600341797
# Done Generating final pairs: 0.009423255920410156
# best_stitch_pair = [  15 2855]
# best_stitch_pair_size = 484781.7514644193
# best_stitch_pair_distance = 1148.3470660376292
# best_stitch_pair_size_ratio = 0.5168042353268271
# Starting Child 2
# 14 2895
# Done distance matrix: 0.002410411834716797
# Done Generating final pairs: 0.009065628051757812
# best_stitch_pair = [   5 2855]
# best_stitch_pair_size = 338905.39131981804
# best_stitch_pair_distance = 430.1099426465895
# best_stitch_pair_size_ratio = 0.9507482863581334
# Starting Child 5
# 13 2895
# Done distance matrix: 0.0014300346374511719
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 8
# 25 2895
# Done distance matrix: 0.0031447410583496094
# Done Generating final pairs: 0.014237403869628906
# best_stitch_pair = [   1 2867]
# best_stitch_pair_size = 1582418.2761000723
# best_stitch_pair_distance = 706.2233455291515
# best_stitch_pair_size_ratio = 0.47134619329103034
# repeat_main_facets = [2855]
# child_mesh_double_indexes = [0, 2]
# min_child = 2, max_ratio = 430.1099426465895
# child_meshes_stitch_facets = {2: [5, 2855], 8: [1, 2867]}
# ---Stitching child 2 with pair: [5, 2855]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 156095, starting edge 2nd facet= 156521,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.6941299438476562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002295255661010742
# returned from stitch mesh: 0.23353242874145508
# Finished stitching child 2 : 0.25552845001220703
# ---Stitching child 8 with pair: [1, 2867]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 156174, starting edge 2nd facet= 156678,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 5.1975250244140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0020155906677246094
# returned from stitch mesh: 0.23775982856750488
# Finished stitching child 8 : 0.2557814121246338
# ***************Finished big stitching iteration: 0.9537556171417236***************
# Starting Child 0
# 18 2930
# Done distance matrix: 0.002721071243286133
# Done Generating final pairs: 0.01235818862915039
# best_stitch_pair = [  15 2893]
# best_stitch_pair_size = 575511.5705445502
# best_stitch_pair_distance = 532.6547193774467
# best_stitch_pair_size_ratio = 0.8006832663247171
# Starting Child 5
# 13 2930
# Done distance matrix: 0.002241373062133789
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [15, 2893]}
# ---Stitching child 0 with pair: [15, 2893]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 156556, starting edge 2nd facet= 156870,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.361701965332031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0020546913146972656
# returned from stitch mesh: 0.2686135768890381
# Finished stitching child 0 : 0.28664374351501465
# ***************Finished big stitching iteration: 0.7102158069610596***************
# Starting Child 5
# 13 2946
# Done distance matrix: 0.0015304088592529297
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 5
# 13 2946
# Done distance matrix: 0.0015535354614257812
# Done Generating final pairs: 0.003530263900756836
# best_stitch_pair = [   7 2817]
# best_stitch_pair_size = 150265.26852786014
# best_stitch_pair_distance = 2026.341337318291
# best_stitch_pair_size_ratio = 0.1518059148788421
# repeat_main_facets = []
# child_meshes_stitch_facets = {5: [7, 2817]}
# ---Stitching child 5 with pair: [7, 2817]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 155980, starting edge 2nd facet= 157020,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0017387866973876953
# returned from stitch mesh: 0.2561321258544922
# Finished stitching child 5 : 0.271942138671875
# ***************Finished big stitching iteration: 0.29283618927001953***************
# All children have been processed
# total_stitch_processing_time = 5.425509214401245
# Total time for restitching = 5.444223642349243
# missed_children = []
# Whole stitching function complete: 44.8574583530426
#
#
#
# *****Running Neuron Stitcher for 648518346341375951**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 38 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 201192
# Total time for Mesh Cleansing: 7.962540149688721
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987490319890391% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341376611**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 40 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 199388
# Total time for Mesh Cleansing: 4.881776809692383
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985826684896655% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341378999**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 608 pieces after mesh split
# There were 101 pieces found after size threshold
# max_index = 0
# max_face_len = 793595
# Total time for Mesh Cleansing: 139.4917757511139
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9819982354608033% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342801913**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 82 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 359714
# Total time for Mesh Cleansing: 9.150154829025269
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983070791842897% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342803997**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 123440
# Total time for Mesh Cleansing: 0.26340413093566895
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994656130066556% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342804481**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 31 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 198594
# Total time for Mesh Cleansing: 0.6396596431732178
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993055974880743% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342804584**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 63 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 355618
# Total time for Mesh Cleansing: 9.955403804779053
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990336047106152% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342806968**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 110 pieces after mesh split
# There were 26 pieces found after size threshold
# max_index = 0
# max_face_len = 119476
# Total time for Mesh Cleansing: 8.530212879180908
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9800666086985054% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808593**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 142 pieces after mesh split
# There were 50 pieces found after size threshold
# max_index = 0
# max_face_len = 181722
# Total time for Mesh Cleansing: 16.7641339302063
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9752801511313383% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342920209**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 28686
# Total time for Mesh Cleansing: 0.22135424613952637
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9977045075125208% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342920983**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 26 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 150462
# Total time for Mesh Cleansing: 0.5773541927337646
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991632799426249% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342923554**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 49440
# Total time for Mesh Cleansing: 0.2800278663635254
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342923698**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 27666
# Total time for Mesh Cleansing: 0.4424748420715332
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988446819264929% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342924673**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 187864
# Total time for Mesh Cleansing: 0.7643156051635742
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989152859603972% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342926026**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 43340
# Total time for Mesh Cleansing: 1.358013391494751
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9967801287948482% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342929203**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 30284
# Total time for Mesh Cleansing: 1.045067548751831
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9973653010143592% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343163536**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 57490
# Total time for Mesh Cleansing: 0.17049121856689453
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999547951874261% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343462325**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 38 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 0
# max_face_len = 27176
# Total time for Mesh Cleansing: 1.3055129051208496
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9407366380504015% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343786226**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 44852
# Total time for Mesh Cleansing: 1.1991314888000488
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982195317368467% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344079907**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 59208
# Total time for Mesh Cleansing: 0.1452789306640625
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999426082846629% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344081708**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 107602
# Total time for Mesh Cleansing: 0.36736249923706055
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996098249786333% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344104314**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 37282
# Total time for Mesh Cleansing: 0.15085673332214355
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997318459723264% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344106316**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 33180
# Total time for Mesh Cleansing: 0.24436545372009277
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998192008678358% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344398924**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 29794
# Total time for Mesh Cleansing: 0.21437931060791016
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989940987124464% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344513743**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 34752
# Total time for Mesh Cleansing: 0.11726164817810059
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981044287437533% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346302352**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 55 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 260665
# Total time for Mesh Cleansing: 11.160180807113647
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985022370679087% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349381502**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 32188
# Total time for Mesh Cleansing: 0.1484081745147705
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999875745526839% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349387852**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 30420
# Total time for Mesh Cleansing: 0.06620502471923828
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349471277**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 566 pieces after mesh split
# There were 135 pieces found after size threshold
# max_index = 0
# max_face_len = 1120747
# Total time for Mesh Cleansing: 298.852801322937
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.986467598810733% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349471277_30_main_and_child_meshes_array.npz
#  face length 1120747 using optimized facets with 3 neighbors
# Filtering edges by size finished: 22.45427894592285, facet # = 56667
# Filtering by convexity and getting centers took: 27.565735816955566, facet # = 14238
# Finished facets for main mesh: 52.32560658454895 with facet length = 14238
# Finished 14238 facets for main mesh: 52.32623076438904
# Filtering edges by size finished: 0.0009405612945556641, facet # = 3
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0020880699157714844, facet # = 2
# Total time for facets: 52.336257219314575
# Zero faceted faces = []
# Starting Child 0
# 2 14238
# Done distance matrix: 0.0022139549255371094
# Done Generating final pairs: 0.019162416458129883
# best_stitch_pair = [  0 526]
# best_stitch_pair_size = 23416.51754241755
# best_stitch_pair_distance = 1171.5941717106782
# best_stitch_pair_size_ratio = 0.6321827553983076
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 526]}
# ---Stitching child 0 with pair: [0, 526]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 383810, starting edge 2nd facet= 560716,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.006292819976806641
# returned from stitch mesh: 0.541179895401001
# Finished stitching child 0 : 0.6460576057434082
# ***************Finished big stitching iteration: 0.8336081504821777***************
# All children have been processed
# total_stitch_processing_time = 0.8341760635375977
# Total time for restitching = 0.8390734195709229
# missed_children = []
# Whole stitching function complete: 355.75454545021057
# 924.491117477417

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
