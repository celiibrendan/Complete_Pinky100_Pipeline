# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473597**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473597_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 4.370524644851685
# Number of outside child meshes =  18
# Main mesh and outside child meshes make up 0.9808312205467206% of original mesh
#  face length 2709628 using optimized facets with 3 neighbors
# Filtering edges by size finished: 45.22829747200012, facet # = 139024
# Filtering by convexity and getting centers took: 86.09403491020203, facet # = 29323
# Finished facets for main mesh: 136.11077666282654 with facet length = 29323
# Finished 29323 facets for main mesh: 136.11141538619995
# Filtering edges by size finished: 1.3453896045684814, facet # = 5035
# Filtering by convexity and getting centers took: 2.141232490539551, facet # = 1438
# Filtering edges by size finished: 0.19089198112487793, facet # = 760
# Filtering by convexity and getting centers took: 0.34823155403137207, facet # = 242
# Filtering edges by size finished: 0.5354082584381104, facet # = 1660
# Filtering by convexity and getting centers took: 0.9959630966186523, facet # = 499
# Filtering edges by size finished: 0.013276815414428711, facet # = 65
# Filtering by convexity and getting centers took: 0.023832321166992188, facet # = 28
# Filtering edges by size finished: 0.011091470718383789, facet # = 48
# Filtering by convexity and getting centers took: 0.014963626861572266, facet # = 21
# Filtering edges by size finished: 0.26941823959350586, facet # = 948
# Filtering by convexity and getting centers took: 0.7000637054443359, facet # = 305
# Filtering edges by size finished: 0.021589040756225586, facet # = 62
# Filtering by convexity and getting centers took: 0.024834871292114258, facet # = 10
# Filtering edges by size finished: 0.0017580986022949219, facet # = 7
# Filtering by convexity and getting centers took: 0.004267215728759766, facet # = 6
# Filtering edges by size finished: 0.12022852897644043, facet # = 330
# Filtering by convexity and getting centers took: 0.4372894763946533, facet # = 115
# Filtering edges by size finished: 0.010127067565917969, facet # = 17
# Filtering by convexity and getting centers took: 0.009870052337646484, facet # = 14
# Filtering edges by size finished: 0.04142308235168457, facet # = 141
# Filtering by convexity and getting centers took: 0.05962991714477539, facet # = 47
# Filtering edges by size finished: 0.010335683822631836, facet # = 16
# Filtering by convexity and getting centers took: 0.008487939834594727, facet # = 8
# Filtering edges by size finished: 0.015944480895996094, facet # = 64
# Filtering by convexity and getting centers took: 0.02962946891784668, facet # = 31
# Filtering edges by size finished: 0.02189040184020996, facet # = 52
# Filtering by convexity and getting centers took: 0.022884845733642578, facet # = 18
# Filtering edges by size finished: 0.010872364044189453, facet # = 53
# Filtering by convexity and getting centers took: 0.02137017250061035, facet # = 20
# Filtering edges by size finished: 0.0069196224212646484, facet # = 22
# Filtering by convexity and getting centers took: 0.010611534118652344, facet # = 12
# Filtering edges by size finished: 0.002972126007080078, facet # = 16
# Filtering by convexity and getting centers took: 0.006900787353515625, facet # = 7
# Filtering edges by size finished: 0.002138853073120117, facet # = 7
# Filtering by convexity and getting centers took: 0.003994464874267578, facet # = 7
# Total time for facets: 143.74641156196594
# Zero faceted faces = []
# Starting Child 0
# 1438 29323
# Done distance matrix: 1.8914225101470947
# Done Generating final pairs: 2.1086297035217285
# best_stitch_pair = [1186  632]
# best_stitch_pair_size = 195841.55678088602
# best_stitch_pair_distance = 1622.7366916828626
# best_stitch_pair_size_ratio = 0.5617202172539545
# Starting Child 1
# 242 29323
# Done distance matrix: 0.471743106842041
# Child 1 There were no points close enough
# Starting Child 2
# 499 29323
# Done distance matrix: 0.5706596374511719
# Child 2 There were no points close enough
# Starting Child 3
# 28 29323
# Done distance matrix: 0.06130480766296387
# Child 3 There were no points close enough
# Starting Child 4
# 21 29323
# Done distance matrix: 0.027147531509399414
# Child 4 There were no points close enough
# Starting Child 5
# 305 29323
# Done distance matrix: 0.5893230438232422
# Child 5 There were no points close enough
# Starting Child 6
# 10 29323
# Done distance matrix: 0.03050971031188965
# Child 6 There were no points close enough
# Starting Child 7
# 6 29323
# Done distance matrix: 0.008510351181030273
# Child 7 There were no points close enough
# Starting Child 8
# 115 29323
# Done distance matrix: 0.11644291877746582
# Done Generating final pairs: 0.1376042366027832
# best_stitch_pair = [ 79 518]
# best_stitch_pair_size = 101483.83583556222
# best_stitch_pair_distance = 1228.8140764161906
# best_stitch_pair_size_ratio = 0.1662164044792466
# Starting Child 9
# 14 29323
# Done distance matrix: 0.029196739196777344
# Child 9 There were no points close enough
# Starting Child 10
# 47 29323
# Done distance matrix: 0.114715576171875
# Done Generating final pairs: 0.16720819473266602
# best_stitch_pair = [    1 17117]
# best_stitch_pair_size = 42715.34313952843
# best_stitch_pair_distance = 976.1094524959875
# best_stitch_pair_size_ratio = 0.3359821851678327
# Starting Child 11
# 8 29323
# Done distance matrix: 0.00816798210144043
# Child 11 There were no points close enough
# Starting Child 12
# 31 29323
# Done distance matrix: 0.05260348320007324
# Child 12 There were no points close enough
# Starting Child 13
# 18 29323
# Done distance matrix: 0.02305126190185547
# Child 13 There were no points close enough
# Starting Child 14
# 20 29323
# Done distance matrix: 0.04465341567993164
# Child 14 There were no points close enough
# Starting Child 15
# 12 29323
# Done distance matrix: 0.014878034591674805
# Child 15 There were no points close enough
# Starting Child 16
# 7 29323
# Done distance matrix: 0.007401466369628906
# Child 16 There were no points close enough
# Starting Child 17
# 7 29323
# Done distance matrix: 0.00755763053894043
# Child 17 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1186, 632], 8: [79, 518], 10: [1, 17117]}
# ---Stitching child 0 with pair: [1186, 632]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1131273, starting edge 2nd facet= 1376435,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04131627082824707
# returned from stitch mesh: 1.9057085514068604
# Finished stitching child 0 : 2.281949758529663
# ---Stitching child 8 with pair: [79, 518]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1278062, starting edge 2nd facet= 1379533,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 4, remainder = 0
# About to add faces
# Finished adding faces: 3.147125244140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09844684600830078
# returned from stitch mesh: 2.0550928115844727
# Finished stitching child 8 : 2.3505287170410156
# ---Stitching child 10 with pair: [1, 17117]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 483018, starting edge 2nd facet= 1380643,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.048333168029785156
# returned from stitch mesh: 2.3040921688079834
# Finished stitching child 10 : 2.589491367340088
# ***************Finished big stitching iteration: 12.795015096664429***************
# Starting Child 1
# 242 30917
# Done distance matrix: 0.2933018207550049
# Done Generating final pairs: 0.2966737747192383
# best_stitch_pair = [   94 30287]
# best_stitch_pair_size = 44854.312730819205
# best_stitch_pair_distance = 975.6741658327858
# best_stitch_pair_size_ratio = 0.6435287575501248
# Starting Child 2
# 499 30917
# Done distance matrix: 0.7243845462799072
# Done Generating final pairs: 0.7286937236785889
# best_stitch_pair = [   79 30893]
# best_stitch_pair_size = 65935.3336976616
# best_stitch_pair_distance = 300.035940816312
# best_stitch_pair_size_ratio = 0.575138996134942
# Starting Child 3
# 28 30917
# Done distance matrix: 0.046033620834350586
# Child 3 There were no points close enough
# Starting Child 4
# 21 30917
# Done distance matrix: 0.02979278564453125
# Child 4 There were no points close enough
# Starting Child 5
# 305 30917
# Done distance matrix: 0.6770727634429932
# Done Generating final pairs: 0.6824769973754883
# best_stitch_pair = [  144 30088]
# best_stitch_pair_size = 129033.51359613943
# best_stitch_pair_distance = 253.26930110242628
# best_stitch_pair_size_ratio = 0.611832610861629
# Starting Child 6
# 10 30917
# Done distance matrix: 0.02280902862548828
# Child 6 There were no points close enough
# Starting Child 7
# 6 30917
# Done distance matrix: 0.010581254959106445
# Child 7 There were no points close enough
# Starting Child 9
# 14 30917
# Done distance matrix: 0.02575516700744629
# Child 9 There were no points close enough
# Starting Child 11
# 8 30917
# Done distance matrix: 0.015007495880126953
# Child 11 There were no points close enough
# Starting Child 12
# 31 30917
# Done distance matrix: 0.05176401138305664
# Child 12 There were no points close enough
# Starting Child 13
# 18 30917
# Done distance matrix: 0.01920771598815918
# Child 13 There were no points close enough
# Starting Child 14
# 20 30917
# Done distance matrix: 0.024658918380737305
# Child 14 There were no points close enough
# Starting Child 15
# 12 30917
# Done distance matrix: 0.01591324806213379
# Child 15 There were no points close enough
# Starting Child 16
# 7 30917
# Done distance matrix: 0.010356426239013672
# Child 16 There were no points close enough
# Starting Child 17
# 7 30917
# Done distance matrix: 0.010245561599731445
# Child 17 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [94, 30287], 2: [79, 30893], 5: [144, 30088]}
# ---Stitching child 1 with pair: [94, 30287]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1369958, starting edge 2nd facet= 1381522,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.27353525161743164
# returned from stitch mesh: 2.4085917472839355
# Finished stitching child 1 : 2.719425916671753
# ---Stitching child 2 with pair: [79, 30893]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1380680, starting edge 2nd facet= 1385245,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.8835067749023438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05354619026184082
# returned from stitch mesh: 2.194918632507324
# Finished stitching child 2 : 2.6101911067962646
# ---Stitching child 5 with pair: [144, 30088]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1366839, starting edge 2nd facet= 1392877,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.4318695068359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0547032356262207
# returned from stitch mesh: 2.258323907852173
# Finished stitching child 5 : 2.6603097915649414
# ***************Finished big stitching iteration: 12.339518785476685***************
# Starting Child 3
# 28 31957
# Done distance matrix: 0.03963422775268555
# Child 3 There were no points close enough
# Starting Child 4
# 21 31957
# Done distance matrix: 0.029062986373901367
# Child 4 There were no points close enough
# Starting Child 6
# 10 31957
# Done distance matrix: 0.016739606857299805
# Child 6 There were no points close enough
# Starting Child 7
# 6 31957
# Done distance matrix: 0.009174585342407227
# Child 7 There were no points close enough
# Starting Child 9
# 14 31957
# Done distance matrix: 0.018050670623779297
# Done Generating final pairs: 0.03721761703491211
# best_stitch_pair = [    6 31522]
# best_stitch_pair_size = 735567.7870482951
# best_stitch_pair_distance = 903.8963895900408
# best_stitch_pair_size_ratio = 0.9662851419870057
# Starting Child 11
# 8 31957
# Done distance matrix: 0.026897192001342773
# Done Generating final pairs: 0.05634474754333496
# best_stitch_pair = [    0 31533]
# best_stitch_pair_size = 733463.7531664381
# best_stitch_pair_distance = 134.968608296438
# best_stitch_pair_size_ratio = 0.8147231339757085
# Starting Child 12
# 31 31957
# Done distance matrix: 0.0400233268737793
# Done Generating final pairs: 0.05230116844177246
# best_stitch_pair = [    2 31171]
# best_stitch_pair_size = 856157.0804921538
# best_stitch_pair_distance = 1973.0288955492854
# best_stitch_pair_size_ratio = 0.5269713600684087
# Starting Child 13
# 18 31957
# Done distance matrix: 0.023230314254760742
# Child 13 There were no points close enough
# Starting Child 14
# 20 31957
# Done distance matrix: 0.026281118392944336
# Child 14 There were no points close enough
# Starting Child 15
# 12 31957
# Done distance matrix: 0.015408992767333984
# Done Generating final pairs: 0.027905702590942383
# best_stitch_pair = [    0 31533]
# best_stitch_pair_size = 626298.1347949624
# best_stitch_pair_distance = 1146.4091526320212
# best_stitch_pair_size_ratio = 0.5495758434845878
# Starting Child 16
# 7 31957
# Done distance matrix: 0.009904623031616211
# Done Generating final pairs: 0.016120433807373047
# best_stitch_pair = [    4 31533]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1738.1004363905502
# best_stitch_pair_size_ratio = 0.0
# Starting Child 17
# 7 31957
# Done distance matrix: 0.010108709335327148
# Child 17 There were no points close enough
# repeat_main_facets = [31533]
# child_mesh_double_indexes = [11, 15, 16]
# min_child = 11, max_ratio = 134.968608296438
# child_meshes_stitch_facets = {9: [6, 31522], 11: [0, 31533], 12: [2, 31171]}
# ---Stitching child 9 with pair: [6, 31522]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1385573, starting edge 2nd facet= 1394312,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 5.2928924560546875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.13101577758789062
# returned from stitch mesh: 2.5324957370758057
# Finished stitching child 9 : 2.921457529067993
# ---Stitching child 11 with pair: [0, 31533]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1383710, starting edge 2nd facet= 1394415,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 4.982948303222656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.044975996017456055
# returned from stitch mesh: 2.203493118286133
# Finished stitching child 11 : 2.653447389602661
# ---Stitching child 12 with pair: [2, 31171]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1386314, starting edge 2nd facet= 1394666,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 5.888938903808594e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05515289306640625
# returned from stitch mesh: 2.1911604404449463
# Finished stitching child 12 : 2.4792428016662598
# ***************Finished big stitching iteration: 11.716710805892944***************
# Starting Child 3
# 28 32004
# Done distance matrix: 0.03722548484802246
# Child 3 There were no points close enough
# Starting Child 4
# 21 32004
# Done distance matrix: 0.028456449508666992
# Done Generating final pairs: 0.030350923538208008
# best_stitch_pair = [    9 32000]
# best_stitch_pair_size = 19174.74672220675
# best_stitch_pair_distance = 1896.8800451840043
# best_stitch_pair_size_ratio = 0.8834976480386371
# Starting Child 6
# 10 32004
# Done distance matrix: 0.013581991195678711
# Child 6 There were no points close enough
# Starting Child 7
# 6 32004
# Done distance matrix: 0.008849143981933594
# Child 7 There were no points close enough
# Starting Child 13
# 18 32004
# Done distance matrix: 0.023393630981445312
# Done Generating final pairs: 0.02770709991455078
# best_stitch_pair = [    7 31984]
# best_stitch_pair_size = 55447.66430595494
# best_stitch_pair_distance = 1677.6548605302655
# best_stitch_pair_size_ratio = 0.2212672981301086
# Starting Child 14
# 20 32004
# Done distance matrix: 0.024277448654174805
# Done Generating final pairs: 0.031087398529052734
# best_stitch_pair = [    9 31958]
# best_stitch_pair_size = 45265.31341363738
# best_stitch_pair_distance = 1445.2534930483587
# best_stitch_pair_size_ratio = 0.21341449347648647
# Starting Child 15
# 12 32004
# Done distance matrix: 0.026363372802734375
# Done Generating final pairs: 0.053481101989746094
# best_stitch_pair = [    0 31967]
# best_stitch_pair_size = 574567.2094886877
# best_stitch_pair_distance = 907.7049909489357
# best_stitch_pair_size_ratio = 0.630241561812135
# Starting Child 16
# 7 32004
# Done distance matrix: 0.010532855987548828
# Done Generating final pairs: 0.01955580711364746
# best_stitch_pair = [    4 31969]
# best_stitch_pair_size = 37546.889182729195
# best_stitch_pair_distance = 1661.1789220971434
# best_stitch_pair_size_ratio = 0.34626619798758246
# Starting Child 17
# 7 32004
# Done distance matrix: 0.010188102722167969
# Child 17 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [9, 32000], 13: [7, 31984], 14: [9, 31958], 15: [0, 31967], 16: [4, 31969]}
# ---Stitching child 4 with pair: [9, 32000]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394633, starting edge 2nd facet= 1394832,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.5735626220703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06063556671142578
# returned from stitch mesh: 2.2796926498413086
# Finished stitching child 4 : 2.6273605823516846
# ---Stitching child 13 with pair: [7, 31984]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394509, starting edge 2nd facet= 1395005,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04949545860290527
# returned from stitch mesh: 2.0011541843414307
# Finished stitching child 13 : 2.319216251373291
# ---Stitching child 14 with pair: [9, 31958]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394284, starting edge 2nd facet= 1395132,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.059635162353515625
# returned from stitch mesh: 1.9690911769866943
# Finished stitching child 14 : 2.344238758087158
# ---Stitching child 15 with pair: [0, 31967]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394408, starting edge 2nd facet= 1395317,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 19
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.8371810913085938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04631924629211426
# returned from stitch mesh: 3.0664920806884766
# Finished stitching child 15 : 3.4837911128997803
# ---Stitching child 16 with pair: [4, 31969]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394390, starting edge 2nd facet= 1395368,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.046183109283447266
# returned from stitch mesh: 2.325969934463501
# Finished stitching child 16 : 2.764497995376587
# ***************Finished big stitching iteration: 16.886772871017456***************
# Starting Child 3
# 28 32072
# Done distance matrix: 0.0446624755859375
# Done Generating final pairs: 0.04999041557312012
# best_stitch_pair = [   12 32003]
# best_stitch_pair_size = 111627.98636879388
# best_stitch_pair_distance = 460.1422070144391
# best_stitch_pair_size_ratio = 0.38570567475269185
# Starting Child 6
# 10 32072
# Done distance matrix: 0.029134035110473633
# Done Generating final pairs: 0.04042816162109375
# best_stitch_pair = [    7 32042]
# best_stitch_pair_size = 170906.36724460535
# best_stitch_pair_distance = 560.6660955254779
# best_stitch_pair_size_ratio = 0.5787305930656564
# Starting Child 7
# 6 32072
# Done distance matrix: 0.006832122802734375
# Child 7 There were no points close enough
# Starting Child 17
# 7 32072
# Done distance matrix: 0.007966041564941406
# Done Generating final pairs: 0.011014461517333984
# best_stitch_pair = [    0 32042]
# best_stitch_pair_size = 199218.84384617882
# best_stitch_pair_distance = 140.468862097707
# best_stitch_pair_size_ratio = 0.45875159527455883
# repeat_main_facets = [32042]
# child_mesh_double_indexes = [6, 17]
# min_child = 17, max_ratio = 140.468862097707
# child_meshes_stitch_facets = {3: [12, 32003], 17: [0, 32042]}
# ---Stitching child 3 with pair: [12, 32003]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1394824, starting edge 2nd facet= 1395586,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.051770925521850586
# returned from stitch mesh: 2.2386868000030518
# Finished stitching child 3 : 2.749171018600464
# ---Stitching child 17 with pair: [0, 32042]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1395153, starting edge 2nd facet= 1395632,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 2.6226043701171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08493781089782715
# returned from stitch mesh: 2.083503007888794
# Finished stitching child 17 : 2.477454662322998
# ***************Finished big stitching iteration: 8.357605934143066***************
# Starting Child 6
# 10 32103
# Done distance matrix: 0.015465259552001953
# Done Generating final pairs: 0.02029132843017578
# best_stitch_pair = [    7 32098]
# best_stitch_pair_size = 241499.1010989269
# best_stitch_pair_distance = 438.5475014008723
# best_stitch_pair_size_ratio = 0.8124638712340018
# Starting Child 7
# 6 32103
# Done distance matrix: 0.009475946426391602
# Child 7 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [7, 32098]}
# ---Stitching child 6 with pair: [7, 32098]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1395631, starting edge 2nd facet= 1395986,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.075599670410156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04754638671875
# returned from stitch mesh: 1.8707327842712402
# Finished stitching child 6 : 2.138608932495117
# ***************Finished big stitching iteration: 4.34632420539856***************
# Starting Child 7
# 6 32111
# Done distance matrix: 0.006680727005004883
# Done Generating final pairs: 0.007953166961669922
# best_stitch_pair = [    1 32110]
# best_stitch_pair_size = 62280.45718843241
# best_stitch_pair_distance = 355.0371024851714
# best_stitch_pair_size_ratio = 0.24014535474119292
# repeat_main_facets = []
# child_meshes_stitch_facets = {7: [1, 32110]}
# ---Stitching child 7 with pair: [1, 32110]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1395995, starting edge 2nd facet= 1396056,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.10742545127868652
# returned from stitch mesh: 2.2714269161224365
# Finished stitching child 7 : 2.601349115371704
# ***************Finished big stitching iteration: 5.299371004104614***************
# All children have been processed
# total_stitch_processing_time = 71.75019907951355
# Total time for restitching = 71.76402592658997
# missed_children = []
# Whole stitching function complete: 224.57193899154663
#
#
#
# *****Running Neuron Stitcher for 648518346349475534**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349475534_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 0.606269121170044
# Number of outside child meshes =  8
# Main mesh and outside child meshes make up 0.8084933646959697% of original mesh
#  face length 183945 using optimized facets with 3 neighbors
# Filtering edges by size finished: 6.763248920440674, facet # = 9628
# Filtering by convexity and getting centers took: 7.83022928237915, facet # = 2101
# Finished 2101 facets for main mesh: 15.0346097946167
# Filtering edges by size finished: 0.0030481815338134766, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002605438232421875, facet # = 2
# Filtering edges by size finished: 0.0029654502868652344, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002386808395385742, facet # = 2
# Filtering edges by size finished: 0.0013248920440673828, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.001848459243774414, facet # = 2
# Filtering edges by size finished: 0.001508951187133789, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018563270568847656, facet # = 2
# Filtering edges by size finished: 0.0017027854919433594, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0020437240600585938, facet # = 2
# Filtering edges by size finished: 0.0013060569763183594, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018045902252197266, facet # = 2
# Filtering edges by size finished: 0.0013170242309570312, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017271041870117188, facet # = 2
# Filtering edges by size finished: 0.002231597900390625, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0021317005157470703, facet # = 2
# Total time for facets: 15.079928398132324
# Zero faceted faces = []
# Starting Child 0
# 2 2101
# Done distance matrix: 0.00038814544677734375
# Done Generating final pairs: 0.005112171173095703
# best_stitch_pair = [   0 1065]
# best_stitch_pair_size = 34614.34601869618
# best_stitch_pair_distance = 1766.8128227139152
# best_stitch_pair_size_ratio = 0.6453330844014484
# Starting Child 1
# 2 2101
# Done distance matrix: 0.0003123283386230469
# Done Generating final pairs: 0.012857437133789062
# best_stitch_pair = [   0 1059]
# best_stitch_pair_size = 37400.56284808563
# best_stitch_pair_distance = 1849.6548209636592
# best_stitch_pair_size_ratio = 0.5698617362430242
# Starting Child 2
# 2 2101
# Done distance matrix: 0.0003139972686767578
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 2 2101
# Done distance matrix: 0.0003409385681152344
# Done Generating final pairs: 0.02539229393005371
# best_stitch_pair = [   1 1264]
# best_stitch_pair_size = 21377.13888881851
# best_stitch_pair_distance = 1340.7651428697468
# best_stitch_pair_size_ratio = 0.8168172921454597
# Starting Child 4
# 2 2101
# Done distance matrix: 0.00032019615173339844
# Done Generating final pairs: 0.010183572769165039
# best_stitch_pair = [  1 418]
# best_stitch_pair_size = 40155.037455180776
# best_stitch_pair_distance = 1899.5100043932805
# best_stitch_pair_size_ratio = 0.5108040569580335
# Starting Child 5
# 2 2101
# Done distance matrix: 0.0003361701965332031
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# 2 2101
# Done distance matrix: 0.00029158592224121094
# Done Generating final pairs: 0.010593175888061523
# best_stitch_pair = [  0 418]
# best_stitch_pair_size = 37439.74741542444
# best_stitch_pair_distance = 1924.1541867291483
# best_stitch_pair_size_ratio = 0.4086432455664273
# Starting Child 7
# 2 2101
# Done distance matrix: 0.00033164024353027344
# Done Generating final pairs: 0.014801502227783203
# best_stitch_pair = [   0 1963]
# best_stitch_pair_size = 24194.86556453928
# best_stitch_pair_distance = 1997.0026176583258
# best_stitch_pair_size_ratio = 0.6992205818558543
# repeat_main_facets = [418]
# child_mesh_double_indexes = [4, 6]
# min_child = 4, max_ratio = 1899.5100043932805
# child_meshes_stitch_facets = {0: [0, 1065], 1: [0, 1059], 3: [1, 1264], 4: [1, 418], 7: [0, 1963]}
# ---Stitching child 0 with pair: [0, 1065]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 61592, starting edge 2nd facet= 92813,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 1
# About to add faces
# Finished adding faces: 3.24249267578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004067897796630859
# returned from stitch mesh: 0.1641068458557129
# Finished stitching child 0 : 0.17871689796447754
# ---Stitching child 1 with pair: [0, 1059]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 59076, starting edge 2nd facet= 92858,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 4, remainder = 1
# About to add faces
# Finished adding faces: 3.266334533691406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0025510787963867188
# returned from stitch mesh: 0.18950510025024414
# Finished stitching child 1 : 0.2118690013885498
# ---Stitching child 3 with pair: [1, 1264]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 11715, starting edge 2nd facet= 92867,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 4.5299530029296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00597071647644043
# returned from stitch mesh: 0.17002606391906738
# Finished stitching child 3 : 0.18761372566223145
# ---Stitching child 4 with pair: [1, 418]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 60344, starting edge 2nd facet= 92915,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 4, remainder = 0
# About to add faces
# Finished adding faces: 3.719329833984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0026750564575195312
# returned from stitch mesh: 0.1715548038482666
# Finished stitching child 4 : 0.19281435012817383
# ---Stitching child 7 with pair: [0, 1963]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 55641, starting edge 2nd facet= 92942,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.8371810913085938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002740144729614258
# returned from stitch mesh: 0.17839288711547852
# Finished stitching child 7 : 0.19156765937805176
# ***************Finished big stitching iteration: 1.2260127067565918***************
# Starting Child 2
# 2 2101
# Done distance matrix: 0.0008056163787841797
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 2101
# Done distance matrix: 0.00036644935607910156
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# 2 2101
# Done distance matrix: 0.0004093647003173828
# Done Generating final pairs: 0.002535104751586914
# best_stitch_pair = [   1 2069]
# best_stitch_pair_size = 23179.858620706415
# best_stitch_pair_distance = 1858.5229799888216
# best_stitch_pair_size_ratio = 0.8816808198374596
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [1, 2069]}
# ---Stitching child 6 with pair: [1, 2069]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 84830, starting edge 2nd facet= 92968,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 3.218650817871094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0011878013610839844
# returned from stitch mesh: 0.15506672859191895
# Finished stitching child 6 : 0.16659903526306152
# ***************Finished big stitching iteration: 0.3627285957336426***************
# Starting Child 2
# 2 2101
# Done distance matrix: 0.0007190704345703125
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 2101
# Done distance matrix: 0.0004413127899169922
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 2
# 2 2101
# Done distance matrix: 0.0005588531494140625
# Done Generating final pairs: 0.003504037857055664
# best_stitch_pair = [   0 1198]
# best_stitch_pair_size = 21866.164845360603
# best_stitch_pair_distance = 2183.99072322456
# best_stitch_pair_size_ratio = 0.8359344033222084
# Starting Child 5
# 2 2101
# Done distance matrix: 0.0005381107330322266
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [0, 1198]}
# ---Stitching child 2 with pair: [0, 1198]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 69393, starting edge 2nd facet= 93013,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.7894973754882812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.001093149185180664
# returned from stitch mesh: 0.12807798385620117
# Finished stitching child 2 : 0.13996267318725586
# ***************Finished big stitching iteration: 0.17096304893493652***************
# Starting Child 5
# 2 2101
# Done distance matrix: 0.0006716251373291016
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 5
# 2 2101
# Done distance matrix: 0.0003447532653808594
# Done Generating final pairs: 0.0047910213470458984
# best_stitch_pair = [   1 2099]
# best_stitch_pair_size = 20817.22363813199
# best_stitch_pair_distance = 2434.663510663486
# best_stitch_pair_size_ratio = 0.9166666666666656
# repeat_main_facets = []
# child_meshes_stitch_facets = {5: [1, 2099]}
# ---Stitching child 5 with pair: [1, 2099]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 92981, starting edge 2nd facet= 93041,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 4.3392181396484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0015506744384765625
# returned from stitch mesh: 0.20202398300170898
# Finished stitching child 5 : 0.21243882179260254
# ***************Finished big stitching iteration: 0.2352614402770996***************
# All children have been processed
# total_stitch_processing_time = 2.3479998111724854
# Total time for restitching = 2.3486602306365967
# missed_children = []
# Whole stitching function complete: 18.323742389678955
#
#
#
# *****Running Neuron Stitcher for 648518346349475573**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1396 pieces after mesh split
# There were 117 pieces found after size threshold
# max_index = 0
# max_face_len = 381194
# Total time for Mesh Cleansing: 85.47943997383118
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9497764103586154% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349475573_30_main_and_child_meshes_array.npz
#  face length 381194 using optimized facets with 3 neighbors
# Filtering edges by size finished: 12.752889156341553, facet # = 21718
# Filtering by convexity and getting centers took: 14.328622341156006, facet # = 3224
# Finished 3224 facets for main mesh: 27.897704124450684
# Filtering edges by size finished: 0.0025467872619628906, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0011241436004638672, facet # = 0
# Total time for facets: 27.904523372650146
# Zero faceted faces = [0]
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 0.12070035934448242
# Total time for restitching = 0.1217811107635498
# missed_children = [0.0]
# Whole stitching function complete: 114.54943823814392
#
#
#
# *****Running Neuron Stitcher for 648518346349478348**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478348_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 3.815094232559204
# Number of outside child meshes =  42
# Main mesh and outside child meshes make up 0.9848431817431379% of original mesh
#  face length 1783618 using optimized facets with 3 neighbors
# Filtering edges by size finished: 42.644460916519165, facet # = 91440
# Filtering by convexity and getting centers took: 63.53646922111511, facet # = 19980
# Finished facets for main mesh: 110.79836392402649 with facet length = 19980
# Finished 19980 facets for main mesh: 110.79860377311707
# Filtering edges by size finished: 0.08160281181335449, facet # = 179
# Filtering by convexity and getting centers took: 0.1444089412689209, facet # = 63
# Filtering edges by size finished: 2.625807523727417, facet # = 5030
# Filtering by convexity and getting centers took: 3.1194777488708496, facet # = 1079
# Filtering edges by size finished: 0.05604290962219238, facet # = 64
# Filtering by convexity and getting centers took: 0.04674673080444336, facet # = 29
# Filtering edges by size finished: 2.3240506649017334, facet # = 6663
# Filtering by convexity and getting centers took: 3.1641385555267334, facet # = 2179
# Filtering edges by size finished: 2.1078970432281494, facet # = 6514
# Filtering by convexity and getting centers took: 3.586381673812866, facet # = 1721
# Filtering edges by size finished: 0.3978898525238037, facet # = 961
# Filtering by convexity and getting centers took: 0.6029777526855469, facet # = 286
# Filtering edges by size finished: 1.4751722812652588, facet # = 3488
# Filtering by convexity and getting centers took: 1.6111514568328857, facet # = 917
# Filtering edges by size finished: 0.2095935344696045, facet # = 329
# Filtering by convexity and getting centers took: 0.37353014945983887, facet # = 99
# Filtering edges by size finished: 0.967700719833374, facet # = 3350
# Filtering by convexity and getting centers took: 1.4105758666992188, facet # = 862
# Filtering edges by size finished: 0.017251253128051758, facet # = 61
# Filtering by convexity and getting centers took: 0.028778553009033203, facet # = 30
# Filtering edges by size finished: 0.3082108497619629, facet # = 527
# Filtering by convexity and getting centers took: 0.4188880920410156, facet # = 155
# Filtering edges by size finished: 0.006089210510253906, facet # = 10
# Filtering by convexity and getting centers took: 0.0063762664794921875, facet # = 8
# Filtering edges by size finished: 0.006922245025634766, facet # = 9
# Filtering by convexity and getting centers took: 0.005831003189086914, facet # = 7
# Filtering edges by size finished: 0.001832723617553711, facet # = 8
# Filtering by convexity and getting centers took: 0.004729509353637695, facet # = 8
# Filtering edges by size finished: 0.00330352783203125, facet # = 16
# Filtering by convexity and getting centers took: 0.00835871696472168, facet # = 15
# Filtering edges by size finished: 0.5944850444793701, facet # = 995
# Filtering by convexity and getting centers took: 0.6856248378753662, facet # = 302
# Filtering edges by size finished: 0.25116539001464844, facet # = 1291
# Filtering by convexity and getting centers took: 0.5896308422088623, facet # = 385
# Filtering edges by size finished: 0.017482280731201172, facet # = 101
# Filtering by convexity and getting centers took: 0.04782390594482422, facet # = 25
# Filtering edges by size finished: 0.025801897048950195, facet # = 64
# Filtering by convexity and getting centers took: 0.030986547470092773, facet # = 19
# Filtering edges by size finished: 0.0024378299713134766, facet # = 8
# Filtering by convexity and getting centers took: 0.004746913909912109, facet # = 3
# Filtering edges by size finished: 0.003834962844848633, facet # = 5
# Filtering by convexity and getting centers took: 0.0037412643432617188, facet # = 2
# Filtering edges by size finished: 0.0021495819091796875, facet # = 9
# Filtering by convexity and getting centers took: 0.004893064498901367, facet # = 5
# Filtering edges by size finished: 0.003070831298828125, facet # = 15
# Filtering by convexity and getting centers took: 0.00668644905090332, facet # = 7
# Filtering edges by size finished: 0.0011920928955078125, facet # = 7
# Filtering by convexity and getting centers took: 0.003521442413330078, facet # = 6
# Filtering edges by size finished: 0.009249210357666016, facet # = 14
# Filtering by convexity and getting centers took: 0.00866556167602539, facet # = 12
# Filtering edges by size finished: 0.002184152603149414, facet # = 2
# Filtering by convexity and getting centers took: 0.0019304752349853516, facet # = 1
# Filtering edges by size finished: 0.01590871810913086, facet # = 49
# Filtering by convexity and getting centers took: 0.024291515350341797, facet # = 15
# Filtering edges by size finished: 0.024457216262817383, facet # = 49
# Filtering by convexity and getting centers took: 0.029968738555908203, facet # = 19
# Filtering edges by size finished: 0.1492760181427002, facet # = 371
# Filtering by convexity and getting centers took: 0.45687294006347656, facet # = 120
# Filtering edges by size finished: 0.02766561508178711, facet # = 193
# Filtering by convexity and getting centers took: 0.09137201309204102, facet # = 69
# Filtering edges by size finished: 0.0013849735260009766, facet # = 7
# Filtering by convexity and getting centers took: 0.003842592239379883, facet # = 4
# ...
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.003135204315185547
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0015141963958740234
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0014719963073730469
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0014925003051757812
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.0015037059783935547
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0014801025390625
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 200
# 2 35381
# Done distance matrix: 0.003476381301879883
# Child 200 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.001856088638305664
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.001508951187133789
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0014612674713134766
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.0015625953674316406
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0014700889587402344
# Child 292 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 34
# 1 35381
# Done distance matrix: 0.0011703968048095703
# Child 34 There were no points close enough
# Starting Child 51
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 58
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 35381
# Done distance matrix: 0.0012900829315185547
# Child 61 There were no points close enough
# Starting Child 71
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 78
# 1 35381
# Done distance matrix: 0.0015513896942138672
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.001440286636352539
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0013058185577392578
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0012755393981933594
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0011510848999023438
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.0012867450714111328
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0012888908386230469
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 200
# 2 35381
# Done distance matrix: 0.002707958221435547
# Done Generating final pairs: 0.010951042175292969
# best_stitch_pair = [    0 11763]
# best_stitch_pair_size = 37707.94478145864
# best_stitch_pair_distance = 4506.531095367123
# best_stitch_pair_size_ratio = 0.8384158005173719
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.0013039112091064453
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.001293182373046875
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0013308525085449219
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.0015265941619873047
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0015175342559814453
# Child 292 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {200: [0, 11763]}
# ---Stitching child 200 with pair: [0, 11763]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 731694, starting edge 2nd facet= 1298142,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 1
# About to add faces
# Finished adding faces: 2.5272369384765625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06156659126281738
# returned from stitch mesh: 1.609217643737793
# Finished stitching child 200 : 1.8223357200622559
# ***************Finished big stitching iteration: 2.1392269134521484***************
# Starting Child 34
# 1 35381
# Done distance matrix: 0.0015411376953125
# Child 34 There were no points close enough
# Starting Child 51
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 58
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 35381
# Done distance matrix: 0.0014770030975341797
# Child 61 There were no points close enough
# Starting Child 71
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 78
# 1 35381
# Done distance matrix: 0.0013282299041748047
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.001409292221069336
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0013527870178222656
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0013339519500732422
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0012514591217041016
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.001272439956665039
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0012822151184082031
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.0015513896942138672
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.0013089179992675781
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0017001628875732422
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.0015442371368408203
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0014879703521728516
# Child 292 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 34
# 1 35381
# Done distance matrix: 0.0011856555938720703
# Child 34 There were no points close enough
# Starting Child 51
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 58
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 35381
# Done distance matrix: 0.0014185905456542969
# Child 61 There were no points close enough
# Starting Child 71
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 78
# 1 35381
# Done distance matrix: 0.0013566017150878906
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.0013613700866699219
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0010647773742675781
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0011878013610839844
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0012602806091308594
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.0011930465698242188
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0014243125915527344
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.001249551773071289
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.0011289119720458984
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0012629032135009766
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.0012738704681396484
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0010495185852050781
# Child 292 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 34
# 1 35381
# Done distance matrix: 0.0013194084167480469
# Child 34 There were no points close enough
# Starting Child 51
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 58
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 35381
# Done distance matrix: 0.0013248920440673828
# Child 61 There were no points close enough
# Starting Child 71
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 78
# 1 35381
# Done distance matrix: 0.0015256404876708984
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.0014109611511230469
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0012156963348388672
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0012652873992919922
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0015347003936767578
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.0012066364288330078
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0014395713806152344
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.0015230178833007812
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.0014045238494873047
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0013327598571777344
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.0014188289642333984
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0013256072998046875
# Child 292 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 34
# 1 35381
# Done distance matrix: 0.0015218257904052734
# Child 34 There were no points close enough
# Starting Child 51
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 58
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 35381
# Done distance matrix: 0.0014295578002929688
# Child 61 There were no points close enough
# Starting Child 71
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 78
# 1 35381
# Done distance matrix: 0.0016186237335205078
# Child 78 There were no points close enough
# Starting Child 83
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 90
# 1 35381
# Done distance matrix: 0.0015668869018554688
# Child 90 There were no points close enough
# Starting Child 91
# 1 35381
# Done distance matrix: 0.0013802051544189453
# Child 91 There were no points close enough
# Starting Child 103
# 1 35381
# Done distance matrix: 0.0012638568878173828
# Child 103 There were no points close enough
# Starting Child 106
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 124
# 1 35381
# Done distance matrix: 0.0013651847839355469
# Child 124 There were no points close enough
# Starting Child 158
# 1 35381
# Done distance matrix: 0.001237630844116211
# Child 158 There were no points close enough
# Starting Child 165
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 173
# 1 35381
# Done distance matrix: 0.0014147758483886719
# Child 173 There were no points close enough
# Starting Child 181
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 206
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 208
# 1 35381
# Done distance matrix: 0.0016033649444580078
# Child 208 There were no points close enough
# Starting Child 213
# 1 35381
# Done distance matrix: 0.0012180805206298828
# Child 213 There were no points close enough
# Starting Child 221
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 241
# 1 35381
# Done distance matrix: 0.0017552375793457031
# Child 241 There were no points close enough
# Starting Child 243
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 247
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 266
# 1 35381
# Done distance matrix: 0.001435995101928711
# Child 266 There were no points close enough
# Starting Child 292
# 1 35381
# Done distance matrix: 0.0012598037719726562
# Child 292 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 544.2889332771301
# Total time for restitching = 544.2960410118103
# missed_children = [266.0, 158.0, 34.0, 292.0, 165.0, 173.0, 51.0, 181.0, 58.0, 61.0, 71.0, 78.0, 206.0, 208.0, 83.0, 213.0, 90.0, 91.0, 221.0, 103.0, 106.0, 241.0, 243.0, 247.0, 124.0]
# Whole stitching function complete: 680.6611933708191
# 6186.244811058044

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
