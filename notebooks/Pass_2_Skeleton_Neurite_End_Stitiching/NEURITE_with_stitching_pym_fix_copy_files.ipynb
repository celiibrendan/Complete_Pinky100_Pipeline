# %%
import datajoint as dj
import numpy as np

# %%
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

# %%
pinky.NeuriteSkeletonStitched()
# Out:
# *segmentation  *segment_id    n_edges     edges      n_bodies     n_bodies_stitc largest_mesh_p largest_mesh_d
# +------------+ +------------+ +---------+ +--------+ +----------+ +------------+ +------------+ +------------+
# 3              64851834634135 465         =BLOB=     4            1              0.998535       1.0
# 3              64851834634135 313         =BLOB=     2            1              0.999551       1.0
# 3              64851834634135 570         =BLOB=     82           10             0.968804       0.99006
# 3              64851834634135 329         =BLOB=     5            1              0.99879        1.0
# 3              64851834634135 546         =BLOB=     6            1              0.999284       1.0
# 3              64851834634135 370         =BLOB=     5            1              0.999652       0.992396
# 3              64851834634135 308         =BLOB=     1            1              1.0            0.990195
#    ...
#  (30025 tuples)

# %%
import shutil

import os

def copy_file_and_create_shell_script(original_file,num_copies):
    #create copies folder if not already there
#     if not os.path.exists("copies"):
#         os.makedirs("copies")
    
    #create the new files
    new_file_names = []
    for i in range(0,num_copies):
        # Copy the file in same folder with different name
        new_name = str(i) + "_" + str(original_file)
        shutil.copy(original_file, str(new_name))
        
        new_file_names.append(new_name)

    #write the shell script
    f = open("run_multiple_" + str(original_file)[:-3] + ".sh", "w")
    f.write("#!/bin/bash")
    f.write("\n")
    for file_name in new_file_names:
        f.write("python3 " + str(file_name) + " &")
        f.write("\n")
    f.close()

# %%
copy_file_and_create_shell_script("NEURITE_Skeleton_with_stitching_pym_fix.py",100)

# %%
#how to convert a jupyter notebook to python
#jupyter nbconvert --to script NEURITE_Skeleton.ipynb
