# %%
import numpy as np
import datajoint as dj

# %%
ta3p100 = dj.create_virtual_module("ta3p100","microns_ta3p100")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
total_synapses = ta3p100.ContactPrePost2().fetch("total_n_synapses")

# %%
from collections import Counter
Counter(total_synapses).most_common()
# Out:
# [(0, 1783735),
#  (1, 863611),
#  (2, 303584),
#  (3, 102179),
#  (4, 36592),
#  (5, 13941),
#  (6, 5622),
#  (7, 2367),
#  (8, 1129),
#  (9, 525),
#  (10, 242),
#  (11, 128),
#  (12, 79),
#  (13, 42),
#  (14, 15),
#  (15, 13),
#  (16, 4),
#  (18, 3),
#  (17, 2),
#  (19, 2),
#  (23, 1)]

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as 

sns.distplot(total_synapses)
