# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349496103******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.15384626388549805
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1048.8021721839905
# 2) Finished: Generating CGAL segmentation for neuron: 1071.5283358097076
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 14
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2728846073150635
# 5) Staring: Finding Apical Index
# Soma Index = 14
# Soma Connections = [31, 23, 57, 12, 72, 17, 5, 113, 10, 320, 290, 319]
# soma_80_percent = 247936.478125
# Debugging the axon filter
# [(31, 275499.8125), (23, 252326.03125), (57, 261347.5625), (12, 276763.5625), (72, 254820.78125), (17, 268934.96875), (5, 244698.265625), (113, 249982.0), (10, 265514.15625), (320, 253208.3125), (290, 250720.296875), (319, 248542.171875)]
# possible_Axons_filter_1 = [5]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.1275796890258789
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 72
# 113 = cilia
# 290 = stub soma
# 319 = stub soma
# 320 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.7231125831604004
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.8334453105926514
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.620279788970947
# Finished Auto Labeling: 1088.1376566886902
#
#
# *****Starting Auto Labeling for 648518346349499928******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.027111053466796875
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 205.0565061569214
# 2) Finished: Generating CGAL segmentation for neuron: 211.92303681373596
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.08626699447631836
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [0, 8, 14, 13, 19, 5, 23, 62, 46, 60, 63, 55, 37]
# soma_80_percent = 194403.4875
# Debugging the axon filter
# [(0, 213541.484375), (8, 201767.140625), (14, 194102.921875), (13, 191466.3125), (19, 211678.453125), (5, 205141.890625), (23, 207242.4375), (62, 197606.375), (46, 196064.765625), (60, 200072.859375), (63, 197344.96875), (55, 202079.0), (37, 202429.421875)]
# possible_Axons_filter_1 = [14, 13]
# possible_Axons_filter_2 = [13]
# possible_Apical = 13
# 5) Finished: Finding Apical Index: 0.04158759117126465
# 6) Staring: Classifying Entire Neuron
# 5 = axon
# 37 = stub soma
# 46 = stub soma
# 55 = stub soma
# 60 = stub soma
# 63 = stub soma
# 62 = stub soma
# 40 = stub apical
# 43 = stub apical
# 44 = stub apical
# 58 = stub apical
# Total Labels found = {'oblique', 'soma', 'apical', 'axon', 'basal'}
# 6) Finished: Classifying Entire Neuron: 0.9180474281311035
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.24492621421813965
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.742295503616333
# Finished Auto Labeling: 217.24594473838806
#
#
# *****Starting Auto Labeling for 648518346349500155******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04019784927368164
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 802.1466884613037
# 2) Finished: Generating CGAL segmentation for neuron: 819.746324300766
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 11
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21515655517578125
# 5) Staring: Finding Apical Index
# Soma Index = 11
# Soma Connections = [10, 25, 19, 26, 15, 23, 40, 29, 13, 14, 53, 61, 52, 37]
# soma_80_percent = 213311.54375
# Debugging the axon filter
# [(10, 241526.171875), (25, 240932.65625), (19, 222854.203125), (26, 220627.5), (15, 231354.25), (23, 231923.484375), (40, 225883.609375), (29, 210306.484375), (13, 224405.453125), (14, 217354.25), (53, 228172.40625), (61, 216030.5), (52, 212618.1875), (37, 225449.34375)]
# possible_Axons_filter_1 = [29, 52]
# possible_Axons_filter_2 = [29]
# possible_Apical = 29
# 5) Finished: Finding Apical Index: 0.06334114074707031
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 13
# 37 = stub soma
# 40 = stub soma
# 52 = stub soma
# 61 = stub soma
# Total Labels found = {'oblique', 'apical', 'soma', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.138007879257202
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4500617980957031
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.990090370178223
# Finished Auto Labeling: 833.2558345794678
#
#
# *****Starting Auto Labeling for 648518346349501746******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03491926193237305
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 577.1363506317139
# 2) Finished: Generating CGAL segmentation for neuron: 591.8642222881317
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19460225105285645
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [25, 24, 1, 76, 31, 28, 9, 10, 26, 221, 220, 151, 120, 94]
# soma_80_percent = 213191.99375
# Debugging the axon filter
# [(25, 219011.96875), (24, 225744.125), (1, 209240.546875), (76, 210183.53125), (31, 238741.625), (28, 236333.6875), (9, 222578.046875), (10, 229011.90625), (26, 229461.0625), (221, 210684.3125), (220, 209875.4375), (151, 213807.46875), (120, 209852.09375), (94, 223562.046875)]
# possible_Axons_filter_1 = [1, 76, 221, 220, 120]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.0916585922241211
# 6) Staring: Classifying Entire Neuron
# 10 = axon
# 76 = stub soma
# 94 = stub soma
# 120 = stub soma
# 151 = stub soma
# 221 = cilia
# 220 = stub soma
# 11 = error
# 14 = stub apical
# 16 = stub apical
# 17 = stub apical
# 20 = stub apical
# 22 = stub apical
# 23 = stub apical
# 27 = stub apical
# 29 = stub apical
# 30 = error
# 34 = error
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 150 = stub apical
# 154 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 222 = stub apical
# 223 = stub apical
# 225 = stub apical
# Total Labels found = {'oblique', 'cilia', 'soma', 'apical', 'axon', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.062000036239624
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3586697578430176
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.785099029541016
# Finished Auto Labeling: 602.9196617603302
#
#
# *****Starting Auto Labeling for 648518346349503591******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.053754329681396484
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 812.1938962936401
# 2) Finished: Generating CGAL segmentation for neuron: 831.2874886989594
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2455425262451172
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [19, 293, 41, 45, 13, 148, 21, 17, 7, 125, 2, 294]
# soma_80_percent = 195476.9609375
# Debugging the axon filter
# [(19, 195167.609375), (293, 200050.9375), (41, 216360.75), (45, 197401.421875), (13, 197087.0625), (148, 197184.8125), (21, 218145.828125), (17, 215913.0), (7, 218493.65625), (125, 202347.140625), (2, 203515.34375), (294, 199320.59375)]
# possible_Axons_filter_1 = [19]
# possible_Axons_filter_2 = [19]
# possible_Apical = 19
# 5) Finished: Finding Apical Index: 0.0883641242980957
# 6) Staring: Classifying Entire Neuron
# 41 = error
# 148 = stub soma
# 294 = stub soma
# 293 = stub soma
# 15 = error
# 18 = stub apical
# 27 = stub apical
# 32 = error
# 59 = stub apical
# 63 = stub apical
# 78 = stub apical
# 84 = stub apical
# 96 = stub apical
# 106 = stub apical
# 123 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 136 = stub apical
# 138 = stub apical
# 139 = stub apical
# 147 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 176 = stub apical
# 189 = stub apical
# 195 = stub apical
# 197 = stub apical
# 211 = stub apical
# 212 = stub apical
# 214 = stub apical
# 215 = stub apical
# 231 = stub apical
# 239 = stub apical
# 251 = stub apical
# 252 = stub apical
# 260 = stub apical
# 265 = stub apical
# 266 = stub apical
# 272 = stub apical
# 286 = stub apical
# 296 = stub apical
# 297 = stub apical
# Total Labels found = {'oblique', 'soma', 'apical', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.62876033782959
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.47446227073669434
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.023610591888428
# Finished Auto Labeling: 846.5270318984985
#
#
# *****Starting Auto Labeling for 648518346349505144******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04676246643066406
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 626.2413938045502
# 2) Finished: Generating CGAL segmentation for neuron: 641.702481508255
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 11
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19582033157348633
# 5) Staring: Finding Apical Index
# Soma Index = 11
# Soma Connections = [13, 27, 233, 8, 10, 22, 247, 218, 226, 219, 243]
# soma_80_percent = 239773.6796875
# Debugging the axon filter
# [(13, 242930.9375), (27, 237639.78125), (233, 236196.34375), (8, 268610.5625), (10, 241568.796875), (22, 279560.28125), (247, 248782.484375), (218, 250651.15625), (226, 241385.4375), (219, 250637.390625), (243, 239449.734375)]
# possible_Axons_filter_1 = [27, 233, 243]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.07294464111328125
# 6) Staring: Classifying Entire Neuron
# 218 = stub soma
# 219 = stub soma
# 226 = stub soma
# 243 = stub soma
# 247 = stub soma
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 1.8330628871917725
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6084403991699219
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.114726305007935
# Finished Auto Labeling: 654.2292499542236
#
#
# *****Starting Auto Labeling for 648518346349506159******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04007363319396973
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 553.56405210495
# 2) Finished: Generating CGAL segmentation for neuron: 567.601480960846
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.17608928680419922
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 30, 17, 31, 135, 134, 18, 132, 139, 138, 4, 133, 14, 19, 66, 12, 43, 32, 108, 73, 72]
# soma_80_percent = 255001.915625
# Debugging the axon filter
# [(2, 254473.5), (30, 254870.359375), (17, 260298.1875), (31, 275502.65625), (135, 255474.046875), (134, 266406.65625), (18, 270058.3125), (132, 266387.03125), (139, 253368.78125), (138, 255623.484375), (4, 258592.015625), (133, 257931.140625), (14, 257371.875), (19, 274426.21875), (66, 261823.015625), (12, 259059.046875), (43, 260946.28125), (32, 265723.875), (108, 256758.90625), (73, 252745.703125), (72, 251664.734375)]
# possible_Axons_filter_1 = [2, 30, 139, 73, 72]
# possible_Axons_filter_2 = [2, 30]
# possible_Apical = 2
# 5) Finished: Finding Apical Index: 0.08139777183532715
# 6) Staring: Classifying Entire Neuron
# 17 = stub soma
# 18 = axon
# 32 = stub soma
# 66 = stub soma
# 72 = stub soma
# 73 = stub soma
# 108 = stub soma
# 132 = stub soma
# 133 = stub soma
# 134 = stub soma
# 135 = stub soma
# 138 = stub soma
# 139 = stub soma
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 26 = stub apical
# 28 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# Total Labels found = {'oblique', 'soma', 'apical', 'axon', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.8611888885498047
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.34847164154052734
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.690412998199463
# Finished Auto Labeling: 578.2610301971436
#
#
# *****Starting Auto Labeling for 648518346349507226******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04289650917053223
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 782.7005274295807
# 2) Finished: Generating CGAL segmentation for neuron: 799.2869131565094
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2543156147003174
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [111, 46, 13, 192, 836, 260, 1376, 1391, 1180, 893, 1298, 38, 639, 1049, 1003, 1294, 522, 1073, 819, 1422, 994, 498, 568, 896, 603, 664, 867, 634, 665, 4, 525, 735, 1380, 736, 11, 813, 37, 1325, 1022, 127, 931, 1050, 947, 1342, 1020, 596, 8, 238, 1023, 1072, 631, 1008, 1, 1382, 645, 1000, 929, 1387, 211, 185, 266, 223, 597, 574, 272, 1051, 821, 505, 487, 1095, 632, 1426, 58, 1024, 199, 41, 1123, 600, 218, 528, 516, 872, 1156, 823, 1388, 1030, 1355, 486, 115, 103, 1352, 825, 942, 1021, 1001, 734, 1236, 1335, 1367, 10, 1002, 1155, 1399, 1238, 144, 1372, 640, 890, 12, 602, 1423, 33, 1379, 1289, 488, 212, 489, 1336, 1046, 949, 495, 1241, 485, 1159, 941, 584, 514, 193, 1267, 503, 1093, 1010, 1401, 824, 1371, 490, 1354, 245, 1045, 871, 629, 638, 1109, 563, 1334, 1151, 252, 1369, 599, 1381, 1350, 1019, 641, 1356, 1009, 786, 705, 667, 575, 139, 222, 1160, 197, 932, 940, 625, 1086, 128, 1005, 960, 1395, 1378, 1400, 1176, 1070, 113, 1025, 1392, 822, 1338, 515, 637, 787, 1053, 213, 513, 504, 1006, 944, 566, 225, 1421, 943, 700, 989, 731, 818, 868, 889, 99, 789, 701, 702, 633, 945, 946, 723, 999, 207, 1029, 565, 635, 123, 907, 1071, 216, 1251, 908, 990, 1398, 569, 866, 1406, 1094, 1389, 1425, 1069, 991, 1054, 1007, 1164, 636, 1052, 598, 1384, 1370, 820, 832, 733, 1306, 891, 834, 905, 1158, 1390, 567, 208, 1351, 66, 1297, 518, 1383, 720, 892]
# soma_80_percent = 184880.3625
# Debugging the axon filter
# [(111, 171161.078125), (46, 168141.953125), (13, 292037.15625), (192, 168545.40625), (836, 180243.078125), (260, 148915.546875), (1376, 189039.46875), (1391, 191611.46875), (1180, 205427.421875), (893, 172001.65625), (1298, 175492.09375), (38, 183723.3125), (639, 196669.375), (1049, 154805.21875), (1003, 167205.28125), (1294, 172940.4375), (522, 200922.453125), (1073, 169356.71875), (819, 170576.515625), (1422, 194772.109375), (994, 170196.859375), (498, 173042.640625), (568, 178259.078125), (896, 171963.234375), (603, 183502.25), (664, 174734.984375), (867, 167825.21875), (634, 180396.546875), (665, 158581.921875), (4, 148780.984375), (525, 151610.09375), (735, 202963.734375), (1380, 206418.1875), (736, 156221.953125), (11, 201862.875), (813, 204680.90625), (37, 155175.859375), (1325, 149504.515625), (1022, 148019.28125), (127, 208250.359375), (931, 170181.40625), (1050, 155261.953125), (947, 173850.5), (1342, 167339.75), (1020, 208717.9375), (596, 166264.375), (8, 230707.546875), (238, 157910.171875), (1023, 151520.234375), (1072, 170049.3125), (631, 181201.515625), (1008, 167440.84375), (1, 237209.359375), (1382, 186119.9375), (645, 159536.96875), (1000, 161533.453125), (929, 221353.40625), (1387, 198482.375), (211, 159274.859375), (185, 157844.046875), (266, 205071.578125), (223, 176782.96875), (597, 268770.75), (574, 169734.375), (272, 168706.671875), (1051, 156689.53125), (821, 164762.890625), (505, 159837.390625), (487, 161270.34375), (1095, 260220.796875), (632, 184011.046875), (1426, 204055.515625), (58, 295200.84375), (1024, 150544.296875), (199, 163554.0625), (41, 264082.0625), (1123, 176973.65625), (600, 176772.25), (218, 171614.015625), (528, 217070.96875), (516, 193603.875), (872, 151762.125), (1156, 150250.4375), (823, 164811.609375), (1388, 198040.921875), (1030, 163954.25), (1355, 179930.234375), (486, 161234.109375), (115, 198275.25), (103, 213547.59375), (1352, 179781.203125), (825, 193963.640625), (942, 173678.09375), (1021, 150502.015625), (1001, 166940.703125), (734, 194677.84375), (1236, 202712.046875), (1335, 208011.921875), (1367, 188879.109375), (10, 170314.6875), (1002, 166173.90625), (1155, 151248.46875), (1399, 162138.296875), (1238, 217628.953125), (144, 152478.375), (1372, 155316.015625), (640, 198234.6875), (890, 171760.921875), (12, 272754.375), (602, 199110.0), (1423, 203837.328125), (33, 230585.421875), (1379, 210533.625), (1289, 259963.640625), (488, 163194.515625), (212, 201383.921875), (489, 161457.578125), (1336, 260627.5625), (1046, 208224.09375), (949, 180413.6875), (495, 168059.875), (1241, 153067.859375), (485, 163489.75), (1159, 151594.109375), (941, 173039.953125), (584, 168011.984375), (514, 208762.09375), (193, 271371.1875), (1267, 153964.328125), (503, 160624.0), (1093, 259818.578125), (1010, 168196.078125), (1401, 162213.46875), (824, 164559.0), (1371, 152320.125), (490, 163580.078125), (1354, 179943.6875), (245, 268380.0), (1045, 206734.71875), (871, 159923.171875), (629, 182966.71875), (638, 198381.828125), (1109, 199564.25), (563, 178121.40625), (1334, 206720.703125), (1151, 201974.046875), (252, 182961.78125), (1369, 182091.65625), (599, 196804.96875), (1381, 187359.765625), (1350, 178120.421875), (1019, 195201.28125), (641, 199266.890625), (1356, 176845.359375), (1009, 166790.171875), (786, 260240.265625), (705, 261287.453125), (667, 168806.796875), (575, 176292.15625), (139, 156329.28125), (222, 214487.953125), (1160, 167722.40625), (197, 171204.859375), (932, 216746.171875), (940, 260630.28125), (625, 151356.28125), (1086, 163871.515625), (128, 161466.78125), (1005, 165539.625), (960, 156998.0625), (1395, 160094.625), (1378, 187492.546875), (1400, 163397.8125), (1176, 191132.875), (1070, 168689.5), (113, 152715.984375), (1025, 156798.9375), (1392, 189490.109375), (822, 168469.46875), (1338, 223470.53125), (515, 189569.703125), (637, 198952.921875), (787, 261472.515625), (1053, 154277.75), (213, 191635.796875), (513, 166189.140625), (504, 161310.109375), (1006, 165265.2343 ...
# possible_Axons_filter_1 = [111, 46, 192, 836, 260, 893, 1298, 38, 1049, 1003, 1294, 1073, 819, 994, 498, 568, 896, 603, 664, 867, 634, 665, 4, 525, 736, 37, 1325, 1022, 931, 1050, 947, 1342, 596, 238, 1023, 1072, 631, 1008, 645, 1000, 211, 185, 223, 574, 272, 1051, 821, 505, 487, 632, 1024, 199, 1123, 600, 218, 872, 1156, 823, 1030, 1355, 486, 1352, 942, 1021, 1001, 10, 1002, 1155, 1399, 144, 1372, 890, 488, 489, 949, 495, 1241, 485, 1159, 941, 584, 1267, 503, 1010, 1401, 824, 1371, 490, 1354, 871, 629, 563, 252, 1369, 1350, 1356, 1009, 667, 575, 139, 1160, 197, 625, 1086, 128, 1005, 960, 1395, 1400, 1070, 113, 1025, 822, 1053, 513, 504, 1006, 944, 566, 943, 818, 868, 99, 633, 945, 946, 1029, 565, 123, 1071, 1398, 569, 866, 1406, 1069, 1054, 1007, 1052, 598, 1370, 820, 891, 1158, 567, 208, 1351, 66, 1297, 720, 892]
# possible_Axons_filter_2 = [46, 4, 37]
# possible_Apical = 37
# 5) Finished: Finding Apical Index: 0.5285186767578125
# 6) Staring: Classifying Entire Neuron
# 4 = error
# 10 = cilia
# 38 = stub soma
# 66 = stub soma
# 505 = stub soma
# 99 = cilia
# 111 = stub soma
# 113 = stub soma
# 115 = stub soma
# 123 = stub soma
# 127 = stub soma
# 128 = stub soma
# 1070 = cilia
# 139 = stub soma
# 144 = cilia
# 185 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 192
# 193 = axon
# 197 = stub soma
# 199 = stub soma
# 207 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 208
# 789 = stub soma
# 211 = stub soma
# 212 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 213
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 216
# 218 = cilia
# 260 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 222
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 223
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 238
# 252 = cilia
# 266 = cilia
# 272 = cilia
# 485 = cilia
# 486 = cilia
# 487 = stub soma
# 488 = stub soma
# 489 = cilia
# 490 = cilia
# 495 = stub soma
# 503 = cilia
# 504 = stub soma
# 513 = stub soma
# 514 = stub soma
# 515 = stub soma
# 516 = cilia
# 518 = stub soma
# 522 = stub soma
# 525 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 528
# 563 = cilia
# 568 = cilia
# 565 = stub soma
# 566 = stub soma
# 567 = stub soma
# 569 = stub soma
# 574 = cilia
# 575 = stub soma
# 584 = cilia
# 596 = cilia
# 598 = stub soma
# 599 = stub soma
# 600 = stub soma
# 602 = cilia
# 603 = stub soma
# 625 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 629
# 631 = stub soma
# 632 = cilia
# 633 = stub soma
# 634 = stub soma
# 635 = stub soma
# 636 = stub soma
# 637 = stub soma
# 638 = stub soma
# 639 = stub soma
# 640 = stub soma
# 641 = stub soma
# 645 = stub soma
# 664 = cilia
# 665 = stub soma
# 667 = cilia
# 700 = stub soma
# 701 = stub soma
# 702 = stub soma
# 705 = axon
# 720 = stub soma
# 731 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 734
# 735 = cilia
# 736 = stub soma
# 786 = stub soma
# 787 = cilia
# 813 = stub soma
# 818 = stub soma
# 819 = stub soma
# 820 = cilia
# 821 = stub soma
# 822 = stub soma
# 823 = stub soma
# 824 = stub soma
# 825 = stub soma
# 832 = stub soma
# 834 = stub soma
# 1372 = cilia
# 836 = stub soma
# 866 = stub soma
# 867 = stub soma
# 868 = cilia
# 871 = cilia
# 872 = stub soma
# 1401 = stub soma
# 889 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 890
# 891 = stub soma
# 892 = stub soma
# 893 = stub soma
# 896 = cilia
# 905 = cilia
# 907 = stub soma
# 908 = cilia
# 929 = stub soma
# 931 = cilia
# 932 = stub soma
# 940 = cilia
# 941 = stub soma
# 942 = stub soma
# 943 = stub soma
# 944 = stub soma
# 945 = stub soma
# 946 = stub soma
# 947 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 949
# 960 = cilia
# 989 = stub soma
# 990 = stub soma
# 991 = stub soma
# 994 = cilia
# 1000 = cilia
# 1002 = cilia
# 1003 = cilia
# 1006 = stub soma
# 1005 = stub soma
# 1007 = stub soma
# 1008 = stub soma
# 1009 = stub soma
# 1010 = cilia
# 1019 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 1020
# 1021 = stub soma
# 1022 = stub soma
# 1023 = stub soma
# 1024 = cilia
# 1025 = stub soma
# 1029 = stub soma
# 1030 = stub soma
# 1046 = stub soma
# 1050 = cilia
# 1051 = cilia
# 1052 = cilia
# 1054 = stub soma
# 1071 = stub soma
# 1072 = cilia
# 1073 = cilia
# 1086 = stub soma
# 1093 = stub soma
# 1094 = cilia
# 1095 = stub soma
# 1109 = stub soma
# 1123 = stub soma
# 1155 = cilia
# 1156 = stub soma
# 1158 = cilia
# 1159 = stub soma
# 1160 = cilia
# 1164 = stub soma
# 1176 = cilia
# 1180 = stub soma
# 1236 = cilia
# 1238 = stub soma
# 1241 = cilia
# 1251 = stub soma
# 1267 = cilia
# 1289 = stub soma
# 1294 = stub soma
# 1297 = stub soma
# 1298 = cilia
# 1306 = stub soma
# 1325 = stub soma
# 1335 = cilia
# 1336 = cilia
# 1338 = stub soma
# 1342 = cilia
# 1350 = stub soma
# 1351 = cilia
# 1352 = cilia
# 1354 = stub soma
# 1355 = stub soma
# 1356 = stub soma
# 1367 = stub soma
# 1369 = stub soma
# 1370 = stub soma
# 1371 = stub soma
# 1376 = stub soma
# 1378 = stub soma
# 1379 = cilia
# 1380 = stub soma
# 1381 = stub soma
# 1382 = stub soma
# 1383 = stub soma
# 1384 = stub soma
# 1387 = cilia
# 1388 = stub soma
# 1389 = stub soma
# 1390 = stub soma
# 1391 = cilia
# 1392 = stub soma
# 1395 = stub soma
# 1398 = cilia
# 1399 = cilia
# 1400 = stub soma
# 1406 = stub soma
# 1422 = stub soma
# 1423 = cilia
# 1425 = stub soma
# 1426 = stub soma
# 251 = stub apical
# 261 = stub apical
# 436 = stub apical
# 437 = stub apical
# 508 = stub apical
# 512 = stub apical
# 627 = stub apical
# 646 = stub apical
# 680 = stub apical
# 814 = stub apical
# 840 = stub apical
# 969 = stub apical
# 970 = stub apical
# 971 = stub apical
# 972 = stub apical
# 997 = stub apical
# 1262 = stub apical
# 1263 = stub apical
# 1264 = stub apical
# 1265 = stub apical
# 1266 = stub apical
# 1268 = stub apical
# 1337 = stub apical
# Total Labels found = {'cilia', 'soma', 'apical', 'axon', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.566284656524658
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4909026622772217
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.252373218536377
# Finished Auto Labeling: 813.9649343490601
#
#
# *****Starting Auto Labeling for 648518346349509487******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09946823120117188
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1305.5528197288513
# 2) Finished: Generating CGAL segmentation for neuron: 1329.2766635417938
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.30520105361938477
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [0]
# soma_80_percent = 231699.4140625
# Debugging the axon filter
# [(0, 244583.359375)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.027884721755981445
# 6) Staring: Classifying Entire Neuron
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.895049571990967
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.8992938995361328
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.716780424118042
# Finished Auto Labeling: 1349.428251028061
# 6986.862130403519

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
