# %%
import datajoint as dj
import numpy as np
import time
from tqdm import tqdm

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

pinky = dj.create_virtual_module('pinky', 'microns_pinky')
schema = dj.schema('microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.ProofreadLabelOrphan() & "segment_id=648518346341352006"

# %%
#ta3p100.CleansedMeshOrphan()

# %%
@schema
class CoarseLabelOrphan(dj.Computed):
    definition = """
    # Vertex labels for pinky.ProofreadLabelOrphan did not correctly match the triangle labels, so these are regenerated from the correct triangle labels.
    -> pinky.ProofreadLabelOrphan
    ---
    vertices  : longblob # Corrected vertex labels
    triangles : longblob # Same triangle labels as pinky.ProofreadLabelOrphan
    """
    
    key_source = pinky.ProofreadLabelOrphan & 'status="complete"'
    
    def make(self, key):
        start = time.time()
        
        print(key["segment_id"])
        labels = (pinky.ProofreadLabelOrphan & key).fetch1()
        corrected_vertex_labels = np.zeros(labels['vertices'].shape, np.uint8)
        
        mesh = (pinky.Decimation35OrphanStitched & 'decimation_ratio=0.35' & dict(segment_id=key['segment_id'])).fetch1()
        mesh_triangles = mesh['triangles']
        
        vertex_label_dict = dict()
        for i, label in enumerate(labels['triangles']):
            triangle = mesh_triangles[i]
            for node in triangle:
                if node in vertex_label_dict:
                    if vertex_label_dict[node] < label:
                        vertex_label_dict[node] = label
                else:
                    vertex_label_dict[node] = label
                
        for node, label in vertex_label_dict.items():
            corrected_vertex_labels[node] = label
            
        self.insert1(dict(key,
                          vertices=corrected_vertex_labels,
                          triangles=labels['triangles']))
        
        print("Segment {} vertex labels regenerated in: {} seconds.".format(key['segment_id'], time.time() - start))

# %%
start = time.time()
CoarseLabelOrphan.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341374333
# Segment 648518346341374333 vertex labels regenerated in: 0.5930025577545166 seconds.
# 648518346341376363
# Segment 648518346341376363 vertex labels regenerated in: 0.9476022720336914 seconds.
# 648518346341376757
# Segment 648518346341376757 vertex labels regenerated in: 0.5822365283966064 seconds.
# 648518346341377360
# Segment 648518346341377360 vertex labels regenerated in: 0.6885457038879395 seconds.
# 648518346341378999
# Segment 648518346341378999 vertex labels regenerated in: 0.9623308181762695 seconds.
# 648518346341379581
# Segment 648518346341379581 vertex labels regenerated in: 0.46230030059814453 seconds.
# 648518346341380003
# Segment 648518346341380003 vertex labels regenerated in: 0.6670882701873779 seconds.
# 648518346341380208
# Segment 648518346341380208 vertex labels regenerated in: 0.8082928657531738 seconds.
# 648518346341382445
# Segment 648518346341382445 vertex labels regenerated in: 0.5366098880767822 seconds.
# 648518346341382814
# Segment 648518346341382814 vertex labels regenerated in: 0.4980442523956299 seconds.
# 648518346341383167
# Segment 648518346341383167 vertex labels regenerated in: 0.4860961437225342 seconds.
# 648518346341384917
# Segment 648518346341384917 vertex labels regenerated in: 0.5652174949645996 seconds.
# 648518346341385454
# Segment 648518346341385454 vertex labels regenerated in: 0.7516775131225586 seconds.
# 648518346341388112
# Segment 648518346341388112 vertex labels regenerated in: 0.8280503749847412 seconds.
# 648518346341391211
# Segment 648518346341391211 vertex labels regenerated in: 0.5736687183380127 seconds.
# 648518346341393145
# Segment 648518346346302352 vertex labels regenerated in: 0.9430396556854248 seconds.
# 648518346346584570
# Segment 648518346346584570 vertex labels regenerated in: 0.9286284446716309 seconds.
# 648518346346725935
# Segment 648518346346725935 vertex labels regenerated in: 0.5488922595977783 seconds.
# 648518346347001492
# Segment 648518346347001492 vertex labels regenerated in: 0.829448938369751 seconds.
# 648518346348109681
# Segment 648518346348109681 vertex labels regenerated in: 0.8794224262237549 seconds.
# 648518346348123146
# Segment 648518346348123146 vertex labels regenerated in: 1.0086240768432617 seconds.
# 648518346348198836
# Segment 648518346348198836 vertex labels regenerated in: 0.8474855422973633 seconds.
# 648518346348212893
# Segment 648518346348212893 vertex labels regenerated in: 0.8846542835235596 seconds.
# 648518346348463614
# Segment 648518346348463614 vertex labels regenerated in: 0.9424800872802734 seconds.
# 648518346349369491
# Segment 648518346349369491 vertex labels regenerated in: 0.8881983757019043 seconds.
# 648518346349378042
# Segment 648518346349378042 vertex labels regenerated in: 0.8181071281433105 seconds.
# 648518346349387039
# Segment 648518346349387039 vertex labels regenerated in: 0.878032922744751 seconds.
# 648518346349475412
# Segment 648518346349475412 vertex labels regenerated in: 0.9680404663085938 seconds.
# 648518346349493110
# Segment 648518346349493110 vertex labels regenerated in: 0.6976101398468018 seconds.
# 648518346349497305
# Segment 648518346349497305 vertex labels regenerated in: 0.920114278793335 seconds.
# 648518346349504464
# Segment 648518346349504464 vertex labels regenerated in: 0.9999063014984131 seconds.
# 648518346349509323
# Segment 648518346349509323 vertex labels regenerated in: 1.2013888359069824 seconds.
# 648518346349509593
# Segment 648518346349509593 vertex labels regenerated in: 0.9304263591766357 seconds.
# 648518346349511899
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# <ipython-input-6-30731291f93f> in <module>
#       1 start = time.time()
# ----> 2 CoarseLabelOrphan.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-5-ae2acaf9c19e> in make(self, key)
#      36         self.insert1(dict(key,
#      37                           vertices=corrected_vertex_labels,
# ---> 38                           triangles=labels['triangles']))
#      39
#      40         print("Segment {} vertex labels regenerated in: {} seconds.".format(key['segment_id'], time.time() - start))
#
# /usr/local/lib/python3.6/dist-packages/datajoint/table.py in insert1(self, row, **kwargs)
#     146         For kwargs, see insert()
#     147         """
# --> 148         self.insert((row,), **kwargs)
#     149
#     150     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, ignore_errors=False,
#
# /usr/local/lib/python3.6/dist-packages/datajoint/table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, ignore_errors, allow_direct_insert)
#     309                     raise DuplicateError(
#     310                         '{} : To ignore duplicate entries, set skip_duplicates=True in insert.'.format(err.args[1])
# --> 311                     ) from None
#     312                 else:
#     313                     raise
#
# DuplicateError: Duplicate entry '3-648518346349511899-0.35-computer_Auto-celiib-2019-06-27 21:25:' for key 'PRIMARY' : To ignore duplicate entries, set skip_duplicates=True in insert.

# %%
(schema.jobs & "table_name='__coarse_label_orphan'").delete()

# %%
ta3p100.CoarseLabelOrphan()

# %%
ta3p100.SegmentExclude()
