# %%
"""
Purpose: To test computing of the confusion matrix for the following:
1) On all of the previously automatically labeled data compared to the proofread version

2) Efficiency of one older auatomatically labeled neuron in comparison to the newer automated version

"""

# %%
import celii_confusion_plotting as cp

# %% [markdown]
# # Generating the Labels for each of the test neurons

# %%
from OPTIMIZED_whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron as op_extract
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron as unop_extract
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

dj.config["database.host"] = "10.28.0.34"
dj.config["database.user"] = "celiib"
dj.config["database.password"] = "newceliipass"
dj.config["safemode"] = True
dj.config["display.limit"] = 20

# %%
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
key = dict(segmentation=3,segment_id=648518346349471910)
#key = dict(segmentation=3,segment_id=648518346349475536)

# %%
""" Do the labels from theh older version """
start_time = time.time()

print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")

segment_id = key["segment_id"]

#get the vertices and faces from datajoint
# get the newly stitched mesh
# get the original mesh


verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")

cgal_location = "/notebooks/Pass_2_Excitatory_4_Auto_Classifier_Whole_Neuron_Run_2/automatic_classifier_revised_efficiency/temp/"
cgal_file_sdf = str(key["segment_id"]) + "_fixed-cgal_3_0.20_sdf.csv"
cgal_file_seg = str(key["segment_id"]) + "_fixed-cgal_3_0.20.csv"

#run the whole algorithm on the neuron to test
verts_labels, faces_labels = unop_extract(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                     triangles=faces,pymeshfix_Flag=False,
                     import_CGAL_Flag=True,
                     import_CGAL_paths = [cgal_location + cgal_file_seg,
                                         cgal_location + cgal_file_sdf],
                     return_Only_Labels=True,
                     clusters=3,
                     smoothness=0.2)

print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
#oblique labels that need to check to make sure getting correct
should_be_obliques = [8,103,5]   
should_not_be_obliques = [11,10,15,26]

#things need to add
#1) increase the apical stub size (classifier_stub_threshold_apical)
#2) make sure automatically checks obliques (1029)

# %%
# import importlib
# from OPTIMIZED_whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron as op_extract
# importlib.reload(op_extract)

# %%
""" Do the labels from theh older version """
start_time = time.time()

print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")

segment_id = key["segment_id"]

#get the vertices and faces from datajoint
# get the newly stitched mesh
# get the original mesh


verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")

cgal_location = "/notebooks/Pass_2_Excitatory_4_Auto_Classifier_Whole_Neuron_Run_2/automatic_classifier_revised_efficiency/temp/"
cgal_file_sdf = str(key["segment_id"]) + "_fixed-cgal_3_0.20_sdf.csv"
cgal_file_seg = str(key["segment_id"]) + "_fixed-cgal_3_0.20.csv"

#run the whole algorithm on the neuron to test
verts_labels_opt, faces_labels_opt = op_extract(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                     triangles=faces,pymeshfix_Flag=False,
                     import_CGAL_Flag=True,
                     import_CGAL_paths = [cgal_location + cgal_file_seg,
                                         cgal_location + cgal_file_sdf],
                     return_Only_Labels=True,
                     clusters=3,
                     smoothness=0.2,
                     classifier_stub_threshold_apical=1500)

print(f"Finished Auto Labeling: {time.time() - start_time}")
# Out:
# *****Starting Auto Labeling for 648518346349471910******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.15360760688781738
# 2) Staring: Generating CGAL segmentation for neuron
# 2) Finished: Generating CGAL segmentation for neuron: 32.501861333847046
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.7963378429412842
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [133, 49, 112, 240, 130, 25, 33, 14, 5, 21, 26, 24, 139, 7, 53, 40, 113, 167, 201, 134]
# soma_80_percent = 200871.95625
# possible_Axons_filter_1 = [112, 130, 24, 26, 240, 167]
# size_threshold_filter = [24, 26]
# height_threshold_filter = [24, 26]
# sdf_threshold_filter = [112, 130, 24, 26, 167]
# possible_Axons_filter_2 = [24, 26]
# STARTER picked_apical = 24 with highest connection 197526.921875
# Next possible apical 26 with highest y 196596.40625
# changing apical to 26
# possible_Apical = 26
# 5) Finished: Finding Apical Index: 2.0590591430664062
# 6) Staring: Classifying Entire Neuron
# 21 = axon
# 112 = stub soma
# 113 = stub soma
# 133 = cilia
# 134 = stub soma
# 139 = stub soma
# 167 = stub soma
# 201 = stub soma
# 240 = stub soma
# top_box = 160000
# 2 = stub apical
# 27 = top box touching oblique --> change to apical
# 29 = stub apical
# 31 = top box touching oblique --> change to apical
# 32 = stub apical
# 34 = top box touching oblique --> change to apical
# 36 = stub apical
# 37 = stub apical
# 37 = top box touching oblique --> change to apical
# 42 = stub apical
# 45 = stub apical
# 48 = stub apical
# 52 = stub apical
# 54 = stub apical
# 58 = stub apical
# 59 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 75 = stub apical
# 80 = stub apical
# 82 = stub apical
# 86 = stub apical
# 87 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 102 = stub apical
# 106 = stub apical
# 106 = top box touching oblique --> change to apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 109 = top box touching oblique --> change to apical
# 110 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 138 = stub apical
# 146 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 168 = stub apical
# 168 = top box touching oblique --> change to apical
# 176 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 190 = top box touching oblique --> change to apical
# 200 = stub apical
# 200 = top box touching oblique --> change to apical
# 202 = stub apical
# 208 = stub apical
# 209 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 218 = top box touching oblique --> change to apical
# 219 = stub apical
# 219 = top box touching oblique --> change to apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 231 = stub apical
# 233 = stub apical
# 235 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 262 = stub apical
# 265 = stub apical
# 266 = stub apical
# 270 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 288 = stub apical
# 289 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 304 = stub apical
# 305 = stub apical
# 305 = top box touching oblique --> change to apical
# 306 = stub apical
# 307 = stub apical
# 310 = stub apical
# 317 = stub apical
# 321 = stub apical
# 322 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 334 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# oblique_cutoff = 195000
# neighbor 284 had too high of a connector point --> being labeled as apical
# neighbor 48 had too high of a connector point --> being labeled as apical
# neighbor 96 had too high of a connector point --> being labeled as apical
# neighbor 190 had too high of a connector point --> being labeled as apical
# neighbor 246 had too high of a connector point --> being labeled as apical
# neighbor 31 had too high of a connector point --> being labeled as apical
# neighbor 37 had too high of a connector point --> being labeled as apical
# neighbor 217 had too high of a connector point --> being labeled as apical
# neighbor 42 had too high of a connector point --> being labeled as apical
# neighbor 235 had too high of a connector point --> being labeled as apical
# neighbor 358 had too high of a connector point --> being labeled as apical
# neighbor 27 had too high of a connector point --> being labeled as apical
# neighbor 54 had too high of a connector point --> being labeled as apical
# neighbor 270 had too high of a connector point --> being labeled as apical
# neighbor 109 had too high of a connector point --> being labeled as apical
# neighbor 86 had too high of a connector point --> being labeled as apical
# neighbor 87 had too high of a connector point --> being labeled as apical
# neighbor 11 had too high of a connector point --> being labeled as apical
# neighbor 73 had too high of a connector point --> being labeled as apical
# neighbor 321 had too high of a connector point --> being labeled as apical
# neighbor 76 had too high of a connector point --> being labeled as apical
# neighbor 150 had too high of a connector point --> being labeled as apical
# neighbor 98 had too high of a connector point --> being labeled as apical
# neighbor 34 had too high of a connector point --> being labeled as apical
# neighbor 262 had too high of a connector point --> being labeled as apical
# neighbor 256 had too high of a connector point --> being labeled as apical
# neighbor 181 had too high of a connector point --> being labeled as apical
# neighbor 160 had too high of a connector point --> being labeled as apical
# neighbor 97 had too high of a connector point --> being labeled as apical
# neighbor 216 had too high of a connector point --> being labeled as apical
# neighbor 116 had too high of a connector point --> being labeled as apical
# neighbor 304 had too high of a connector point --> being labeled as apical
# neighbor 329 had too high of a connector point --> being labeled as apical
# neighbor 17 had too high of a connector point --> being labeled as apical
# neighbor 184 had too high of a connector point --> being labeled as apical
# neighbor 218 had too high of a connector point --> being labeled as apical
# neighbor 300 had too high of a connector point --> being labeled as apical
# neighbor 70 had too high of a connector point --> being labeled as apical
# neighbor 146 had too high of a connector point --> being labeled as apical
# neighbor 124 had too high of a connector point --> being labeled as apical
# neighbor 36 had too high of a connector point --> being labeled as apical
# neighbor 69 had too high of a connector point --> being labeled as apical
# neighbor 310 had too high of a connector point --> being labeled as apical
# neighbor 226 had too high of a connector point --> being labeled as apical
# neighbor 159 had too high of a connector point --> being labeled as apical
# neighbor 233 had too high of a connector point --> being labeled as apical
# neighbor 258 had too high of a connector point --> being labeled as apical
# neighbor 185 had too high of a connector point --> being labeled as apical
# neighbor 326 had too high of a connector point --> being labeled as apical
# neighbor 3 had too high of a connector point --> being labeled as apical
# neighbor 108 had too high of a connector point --> being labeled as apical
# neighbor 243 had too high of a connector point --> being labeled as apical
# neighbor 120 had too high of a connector point --> being labeled as apical
# neighbor 332 had too high of a connector point --> being labeled as apical
# neighbor 94 had too high of a connector point --> being labeled as apical
# neighbor 242 had too high of a connector point --> being labeled as apical
# neighbor 183 had too high of a connector point --> being labeled as apical
# neighbor 29 had too high of a connector point --> being labeled as apical
# neighbor 289 had too high of a connector point --> being labeled as apical
# neighbor 188 had too high of a connector point --> being labeled as apical
# neighbor 200 had too high of a connector point --> being labeled as apical
# neighbor 285 had too high of a connector point --> being labeled as apical
# neighbor 59 had too high of a connector point --> being labeled as apical
# neighbor 247 had too high of a connector point --> being labeled as apical
# neighbor 178 had too high of a connector point --> being labeled as apical
# neighbor 266 had too high of a connector point --> being labeled as apical
# neighbor 122 had too high of a connector point --> being labeled as apical
# neighbor 209 had too high of a connector point --> being labeled as apical
# neighbor 259 had too high of a connector point --> being labeled as apical
# neighbor 202 had too high of a connector point --> being labeled as apical
# neighbor 123 had too high of a connector point --> being labeled as apical
# neighbor 219 had too high of a connector point --> being labeled as apical
# neighbor 322 had too high of a connector point --> being labeled as apical
# neighbor 359 had too high of a connector point --> being labeled as apical
# neighbor 225 had too high of a connector point --> being labeled as apical
# neighbor 187 had too high of a connector point --> being labeled as apical
# neighbor 32 had too high of a connector point --> being labeled as apical
# neighbor 357 had too high of a connector point --> being labeled as apical
# neighbor 186 had too high of a connector point --> being labeled as apical
# neighbor 299 had too high of a connector point --> being labeled as apical
# neighbor 189 had too high of a connector point --> being labeled as apical
# neighbor 151 had too high of a connector point --> being labeled as apical
# neighbor 301 had too high of a connector point --> being labeled as apical
# neighbor 182 had too high of a connector point --> being labeled as apical
# neighbor 208 had too high of a connector point --> being labeled as apical
# neighbor 306 had too high of a connector point --> being labeled as apical
# neighbor 179 had too high of a connector point --> being labeled as apical
# neighbor 149 had too high of a connector point --> being labeled as apical
# neighbor 334 had too high of a connector point --> being labeled as apical
# neighbor 68 had too high of a connector point --> being labeled as apical
# neighbor 286 had too high of a connector point --> being labeled as apical
# neighbor 80 had too high of a connector point --> being labeled as apical
# neighbor 282 had too high of a connector point --> being labeled as apical
# neighbor 107 had too high of a connector point --> being labeled as apical
# neighbor 278 had too high of a connector point --> being labeled as apical
# neighbor 168 had too high of a connector point --> being labeled as apical
# neighbor 279 had too high of a connector point --> being labeled as apical
# neighbor 121 had too high of a connector point --> being labeled as apical
# neighbor 330 had too high of a connector point --> being labeled as apical
# neighbor 317 had too high of a connector point --> being labeled as apical
# neighbor 99 had too high of a connector point --> being labeled as apical
# neighbor 288 had too high of a connector point --> being labeled as apical
# neighbor 2 had too high of a connector point --> being labeled as apical
# neighbor 118 had too high of a connector point --> being labeled as apical
# neighbor 305 had too high of a connector point --> being labeled as apical
# neighbor 110 had too high of a connector point --> being labeled as apical
# neighbor 298 had too high of a connector point --> being labeled as apical
# neighbor 244 had too high of a connector point --> being labeled as apical
# neighbor 327 had too high of a connector point --> being labeled as apical
# neighbor 223 had too high of a connector point --> being labeled as apical
# neighbor 152 had too high of a connector point --> being labeled as apical
# neighbor 106 had too high of a connector point --> being labeled as apical
# neighbor 100 had too high of a connector point --> being labeled as apical
# neighbor 82 had too high of a connector point --> being labeled as apical
# neighbor 221 had too high of a connector point --> being labeled as apical
# neighbor 154 had too high of a connector point --> being labeled as apical
# neighbor 176 had too high of a connector point --> being labeled as apical
# neighbor 280 had too high of a connector point --> being labeled as apical
# neighbor 138 had too high of a connector point --> being labeled as apical
# neighbor 255 had too high of a connector point --> being labeled as apical
# neighbor 117 had too high of a connector point --> being labeled as apical
# neighbor 153 had too high of a connector point --> being labeled as apical
# neighbor 58 had too high of a connector point --> being labeled as apical
# neighbor 231 had too high of a connector point --> being labeled as apical
# neighbor 45 had too high of a connector point --> being labeled as apical
# neighbor 257 had too high of a connector point --> being labeled as apical
# neighbor 265 had too high of a connector point --> being labeled as apical
# neighbor 125 had too high of a connector point --> being labeled as apical
# neighbor 281 had too high of a connector point --> being labeled as apical
# neighbor 75 had too high of a connector point --> being labeled as apical
# neighbor 95 had too high of a connector point --> being labeled as apical
# neighbor 245 had too high of a connector point --> being labeled as apical
# neighbor 331 had too high of a connector point --> being labeled as apical
# neighbor 52 had too high of a connector point --> being labeled as apical
# neighbor 297 had too high of a connector point --> being labeled as apical
# neighbor 158 had too high of a connector point --> being labeled as apical
# neighbor 224 had too high of a connector point --> being labeled as apical
# neighbor 102 had too high of a connector point --> being labeled as apical
# neighbor 307 had too high of a connector point --> being labeled as apical
# neighbor 119 had too high of a connector point --> being labeled as apical
# neighbor 180 had too high of a connector point --> being labeled as apical
# neighbor 283 had too high of a connector point --> being labeled as apical
# neighbor 222 had too high of a connector point --> being labeled as apical
# neighbor 325 had too high of a connector point --> being labeled as apical
# Total Labels found = {'cilia', 'axon', 'soma', 'apical', 'basal'}
# 6) Finished: Classifying Entire Neuron: 4.478664398193359
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 1.4286623001098633
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 24.585731744766235
# Finished Auto Labeling: 70.58826494216919

# %% [markdown]
# # COMPUTING THE CONFUSION MATRIX FOR BOTH OF THE OPTIONS

# %%
actual_labels = (pinky.ProofreadLabel & key).fetch1("triangles")

# %%
#make sure they are all the same size
print(len(faces_labels),len(faces_labels_opt),len(actual_labels))

# %%
import celii_confusion_plotting as cp
import importlib
importlib.reload(cp)
help(cp.plot_confusion_matrix_from_raw_data)

# %%
Label_key_data = pinky.LabelKey.fetch(as_dict=True)
kept_data = Label_key_data[2:9] + Label_key_data[10:13]
kept_data

classes = [k["description"] for k in kept_data]
cm_labels = [k["numeric"] for k in kept_data]
classes.append("unknown")
cm_labels.append(13)

# %%
cm_labels

# %%
cp.plot_confusion_matrix_from_raw_data(y_true=actual_labels,
                                       y_pred=faces_labels_opt,
                                       classes=classes,
                                       cm_labels=cm_labels)

# %%
#how to print out the actual labels
#export the labels
labels_opt = faces_labels_opt.astype("int")
np.savetxt("temp/" + str(key["segment_id"]) + '_optimized_output_labels.csv', labels_opt, fmt='%d', delimiter='\n')

# %%
#change all of the labels that are above allowed value to unknown
faces_labels[faces_labels>=13] = 13

from collections import Counter
Counter(faces_labels)

# %%
#change all of the labels that are above allowed value to unknown
faces_labels[faces_labels>=13] = 13

cp.plot_confusion_matrix_from_raw_data(y_true=actual_labels,
                                       y_pred=faces_labels,
                                       classes=classes,
                                       cm_labels=cm_labels)

# %%
#how to print out the actual labels
#export the labels
labels = faces_labels.astype("int")
np.savetxt("temp/" + str(key["segment_id"]) + 'NOT_optimized_output_labels.csv', labels, fmt='%d', delimiter='\n')
