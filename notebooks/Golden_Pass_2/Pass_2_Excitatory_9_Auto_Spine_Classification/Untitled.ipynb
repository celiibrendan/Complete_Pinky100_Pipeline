# %%
file_name = "./dendrite_branches/648518346349478473_Basal_1-cgal_12_0.04.csv"

import numpy as np

# %%
cgal_data = np.genfromtxt(file_name,delimiter="\n")
cgal_data.astype("int")
# Out:
# array([ 8,  8,  8,  8,  8, 17,  1,  1,  1, 25, 25,  0,  0,  0,  6,  6,  6,
#        15,  0, 15, 15, 25, 25, 25, 15, 15, 12,  2,  7, 15, 15, 15, 23, 23,
#        15, 15, 23,  5,  5, 20, 20, 20, 25, 25, 15, 30, 15,  6,  6,  2,  2,
#        23, 23, 23, 23, 23, 29, 26, 26, 15, 15, 12, 14, 30, 14, 15, 15, 15,
#        15, 15, 18, 18,  6, 15, 25, 25, 25, 15, 27, 24, 10, 15, 33, 17,  5,
#         5, 32, 32, 17, 17, 23, 23, 15,  6,  6, 15, 15, 23, 15, 15, 23, 23,
#        24, 24, 25, 18,  8, 23, 15, 15, 15, 23, 23, 23, 15, 16, 15, 15, 15,
#        15, 14,  6, 15, 24, 24, 15, 18, 18, 23,  4, 15, 23, 26, 23,  5, 18,
#         2, 15, 23, 15, 23, 15, 12,  7, 25, 17, 15, 15, 15,  5,  5, 25, 15,
#        15, 29, 23, 23, 15,  7,  2,  2,  2, 19, 25, 24, 24, 23, 23, 23,  5,
#        15, 15, 15, 23, 23, 23, 23, 15,  6, 25, 12, 15, 15, 19,  3, 26, 15,
#        26, 15, 25, 25, 15, 15,  2,  2,  2, 15, 15,  0,  0,  0,  6, 15, 20,
# ...
