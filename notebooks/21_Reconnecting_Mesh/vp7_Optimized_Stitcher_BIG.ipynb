# %%
import trimesh
import numpy as np
from collections import Counter
import time
import math
from tqdm import tqdm

# %%
#pick the mesh to process: 
file_location = "./test_meshes/"
file_location = "./"
file_name ="seperated_mesh.off"

# %%
#visualize the neuron to make sure it is correct
visualize = False
if visualize == True:
    visualize_mesh = trimesh.load_mesh(file_location + file_name )
    visualize_mesh.show()

# %% [markdown]
# # Gets parts that are outside of the main mesh

# %%
def filter_mesh_significant_outside_pieces(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces, including the main one that are not inside of main mesh

    """

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []

    #find piece with largest size
    max_index = 0
    max_face_len = len(significant_pieces[max_index].faces)

    for i in range(1,len(significant_pieces)):
        if max_face_len < len(significant_pieces[i].faces):
            max_index = i
            max_face_len = len(significant_pieces[i].faces)

    print("max_index = " + str(max_index))
    print("max_face_len = " + str(max_face_len))

    final_mesh_pieces = []

    main_mesh = significant_pieces[max_index]

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        if i != max_index:
            #get a random sample of points
            # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
            idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
            points = mesh.vertices[idx,:]
            
            
            start_time = time.time()
            signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
            print(f"Total time = {time.time() - start_time}")

            outside_percentage = sum(signed_distance < 0)/n_sample_points
            if outside_percentage > 0.9:
                final_mesh_pieces.append(mesh)
                print(f"Mesh piece {i} OUTSIDE mesh")
            else:
                print(f"Mesh piece {i} inside mesh :( ")
                
    return main_mesh,final_mesh_pieces

# %%
#start the global timer
global_timer = time.time()

unfiltered_mesh = trimesh.load_mesh(file_location + file_name)

#setting thresholds
significance_threshold=30 #number of faces needed for pieces to be considered to be kept
n_sample_points = 2 #number of points sampled on the mesh for determination of inside or outside
start_time = time.time()

#the main mesh is the first mesh in the piece
main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
                            significance_threshold=significance_threshold,
                                n_sample_points=n_sample_points)
print(f"Total time for Mesh Cleansing: {time.time() - start_time}")
# Out:
# There were 3902 pieces after mesh split
# There were 378 pieces found after size threshold
# max_index = 0
# max_face_len = 1845336
# Total time = 24.19038414955139
# Mesh piece 1 OUTSIDE mesh
# Total time = 0.10218572616577148
# Mesh piece 2 inside mesh :(
# Total time = 0.270585298538208
# Mesh piece 3 OUTSIDE mesh
# Total time = 0.9120712280273438
# Mesh piece 4 OUTSIDE mesh
# Total time = 0.2939729690551758
# Mesh piece 5 inside mesh :(
# Total time = 0.24408960342407227
# Mesh piece 6 inside mesh :(
# Total time = 0.275646448135376
# Mesh piece 7 inside mesh :(
# Total time = 0.2459580898284912
# Mesh piece 8 inside mesh :(
# Total time = 0.2978534698486328
# Mesh piece 9 inside mesh :(
# Total time = 0.32506561279296875
# Mesh piece 10 inside mesh :(
# Total time = 0.31484317779541016
# Mesh piece 11 inside mesh :(
# Total time = 0.5436050891876221
# Mesh piece 12 inside mesh :(
# Total time = 0.5200083255767822
# Mesh piece 13 inside mesh :(
# Total time = 0.45659422874450684
# Mesh piece 14 inside mesh :(
# Total time = 0.5849108695983887
# Mesh piece 15 inside mesh :(
# Total time = 0.351238489151001
# Mesh piece 16 inside mesh :(
# Total time = 0.4388844966888428
# Mesh piece 17 inside mesh :(
# Total time = 0.3974945545196533
# Mesh piece 18 inside mesh :(
# Total time = 0.3701505661010742
# Mesh piece 19 inside mesh :(
# Total time = 0.44563770294189453
# Mesh piece 20 inside mesh :(
# Total time = 0.4244394302368164
# Mesh piece 21 inside mesh :(
# Total time = 0.3549792766571045
# Mesh piece 22 inside mesh :(
# Total time = 0.38098645210266113
# Mesh piece 23 inside mesh :(
# Total time = 0.39114975929260254
# Mesh piece 24 inside mesh :(
# Total time = 0.3802518844604492
# Mesh piece 25 inside mesh :(
# Total time = 0.4369196891784668
# Mesh piece 26 inside mesh :(
# Total time = 0.4250667095184326
# Mesh piece 27 inside mesh :(
# Total time = 0.41120433807373047
# Mesh piece 28 inside mesh :(
# Total time = 0.43493199348449707
# Mesh piece 29 inside mesh :(
# Total time = 0.5122079849243164
# Mesh piece 30 inside mesh :(
# Total time = 0.44271326065063477
# Mesh piece 31 inside mesh :(
# Total time = 0.38343143463134766
# Mesh piece 32 inside mesh :(
# Total time = 0.3371706008911133
# Mesh piece 33 inside mesh :(
# Total time = 0.3082125186920166
# Mesh piece 34 inside mesh :(
# Total time = 0.304882287979126
# Mesh piece 35 inside mesh :(
# Total time = 0.2680392265319824
# Mesh piece 36 inside mesh :(
# Total time = 0.31441497802734375
# Mesh piece 37 inside mesh :(
# Total time = 0.28757309913635254
# Mesh piece 38 inside mesh :(
# Total time = 0.2929105758666992
# Mesh piece 39 inside mesh :(
# Total time = 0.349625825881958
# Mesh piece 40 inside mesh :(
# Total time = 0.29867982864379883
# Mesh piece 41 inside mesh :(
# Total time = 0.3752281665802002
# Mesh piece 42 inside mesh :(
# Total time = 0.31098055839538574
# Mesh piece 43 inside mesh :(
# Total time = 0.31679606437683105
# Mesh piece 44 inside mesh :(
# Total time = 0.2537415027618408
# Mesh piece 45 inside mesh :(
# Total time = 0.3475799560546875
# Mesh piece 46 inside mesh :(
# Total time = 0.08206343650817871
# Mesh piece 47 OUTSIDE mesh
# Total time = 0.04027199745178223
# Mesh piece 48 OUTSIDE mesh
# Total time = 0.15563011169433594
# Mesh piece 49 OUTSIDE mesh
# Total time = 0.05029106140136719
# Mesh piece 50 OUTSIDE mesh
# Total time = 0.05512285232543945
# Mesh piece 51 OUTSIDE mesh
# Total time = 0.06893301010131836
# Mesh piece 52 OUTSIDE mesh
# Total time = 0.5074572563171387
# Mesh piece 53 OUTSIDE mesh
# Total time = 0.10013031959533691
# Mesh piece 54 OUTSIDE mesh
# Total time = 0.4069795608520508
# Mesh piece 55 inside mesh :(
# Total time = 1.3049530982971191
# Mesh piece 56 OUTSIDE mesh
# Total time = 0.3733177185058594
# Mesh piece 57 inside mesh :(
# Total time = 0.5530619621276855
# Mesh piece 58 inside mesh :(
# Total time = 0.45566534996032715
# Mesh piece 59 inside mesh :(
# Total time = 0.46360087394714355
# Mesh piece 60 inside mesh :(
# Total time = 0.5091757774353027
# Mesh piece 61 inside mesh :(
# Total time = 0.466630220413208
# Mesh piece 62 inside mesh :(
# Total time = 0.18348288536071777
# Mesh piece 63 OUTSIDE mesh
# Total time = 0.11920952796936035
# Mesh piece 64 OUTSIDE mesh
# Total time = 1.3855323791503906
# Mesh piece 65 OUTSIDE mesh
# Total time = 0.6493372917175293
# Mesh piece 66 inside mesh :(
# Total time = 0.5198991298675537
# Mesh piece 67 inside mesh :(
# Total time = 0.4703481197357178
# Mesh piece 68 inside mesh :(
# Total time = 0.3173072338104248
# Mesh piece 69 inside mesh :(
# Total time = 0.3983948230743408
# Mesh piece 70 inside mesh :(
# Total time = 0.431689977645874
# Mesh piece 71 inside mesh :(
# Total time = 0.41433024406433105
# Mesh piece 72 inside mesh :(
# Total time = 0.445098876953125
# Mesh piece 73 inside mesh :(
# Total time = 0.4707951545715332
# Mesh piece 74 inside mesh :(
# Total time = 0.4267592430114746
# Mesh piece 75 inside mesh :(
# Total time = 0.47380948066711426
# Mesh piece 76 inside mesh :(
# Total time = 0.43248414993286133
# Mesh piece 77 inside mesh :(
# Total time = 0.4427504539489746
# Mesh piece 78 inside mesh :(
# Total time = 0.4452478885650635
# Mesh piece 79 inside mesh :(
# Total time = 0.587895393371582
# Mesh piece 80 inside mesh :(
# Total time = 0.4121685028076172
# Mesh piece 81 inside mesh :(
# Total time = 0.4259474277496338
# Mesh piece 82 inside mesh :(
# Total time = 0.44089293479919434
# Mesh piece 83 inside mesh :(
# Total time = 0.44388771057128906
# Mesh piece 84 inside mesh :(
# Total time = 0.37501025199890137
# Mesh piece 85 inside mesh :(
# Total time = 0.388120174407959
# Mesh piece 86 inside mesh :(
# Total time = 0.3946805000305176
# Mesh piece 87 inside mesh :(
# Total time = 0.4203910827636719
# Mesh piece 88 inside mesh :(
# Total time = 0.2736318111419678
# Mesh piece 89 inside mesh :(
# Total time = 0.15808486938476562
# Mesh piece 90 inside mesh :(
# Total time = 0.06952929496765137
# Mesh piece 91 OUTSIDE mesh
# Total time = 0.13211917877197266
# Mesh piece 92 OUTSIDE mesh
# Total time = 0.01652050018310547
# Mesh piece 93 OUTSIDE mesh
# Total time = 0.022631406784057617
# Mesh piece 94 OUTSIDE mesh
# Total time = 0.029912233352661133
# Mesh piece 95 OUTSIDE mesh
# Total time = 0.02171921730041504
# Mesh piece 96 OUTSIDE mesh
# Total time = 1.2298588752746582
# Mesh piece 97 OUTSIDE mesh
# Total time = 0.550717830657959
# Mesh piece 98 inside mesh :(
# Total time = 0.5803537368774414
# Mesh piece 99 inside mesh :(
# Total time = 0.3594827651977539
# Mesh piece 100 inside mesh :(
# Total time = 0.34690189361572266
# Mesh piece 101 inside mesh :(
# Total time = 0.2766568660736084
# Mesh piece 102 inside mesh :(
# Total time = 0.29560017585754395
# Mesh piece 103 inside mesh :(
# Total time = 0.357973575592041
# Mesh piece 104 inside mesh :(
# Total time = 0.34691333770751953
# Mesh piece 105 inside mesh :(
# Total time = 0.394512414932251
# Mesh piece 106 inside mesh :(
# Total time = 0.3120689392089844
# Mesh piece 107 inside mesh :(
# Total time = 0.3327934741973877
# Mesh piece 108 inside mesh :(
# Total time = 0.3705790042877197
# Mesh piece 109 inside mesh :(
# Total time = 0.37586402893066406
# Mesh piece 110 inside mesh :(
# Total time = 0.42026591300964355
# Mesh piece 111 inside mesh :(
# Total time = 0.4082217216491699
# Mesh piece 112 inside mesh :(
# Total time = 0.4857749938964844
# Mesh piece 113 inside mesh :(
# Total time = 0.5634324550628662
# Mesh piece 114 inside mesh :(
# Total time = 0.08068156242370605
# Mesh piece 115 OUTSIDE mesh
# Total time = 0.029543638229370117
# Mesh piece 116 OUTSIDE mesh
# Total time = 0.052974700927734375
# Mesh piece 117 OUTSIDE mesh
# Total time = 0.020632028579711914
# Mesh piece 118 OUTSIDE mesh
# Total time = 0.07395100593566895
# Mesh piece 119 OUTSIDE mesh
# Total time = 0.09556031227111816
# Mesh piece 120 OUTSIDE mesh
# Total time = 0.3378169536590576
# Mesh piece 121 inside mesh :(
# Total time = 0.35831308364868164
# Mesh piece 122 inside mesh :(
# Total time = 0.30228638648986816
# Mesh piece 123 inside mesh :(
# Total time = 0.3538684844970703
# Mesh piece 124 inside mesh :(
# Total time = 0.33147382736206055
# Mesh piece 125 inside mesh :(
# Total time = 0.3726027011871338
# Mesh piece 126 inside mesh :(
# Total time = 0.37775444984436035
# Mesh piece 127 inside mesh :(
# Total time = 0.46643948554992676
# Mesh piece 128 inside mesh :(
# Total time = 0.43122100830078125
# Mesh piece 129 inside mesh :(
# Total time = 0.3494079113006592
# Mesh piece 130 inside mesh :(
# Total time = 0.39934229850769043
# Mesh piece 131 inside mesh :(
# Total time = 0.39511609077453613
# Mesh piece 132 inside mesh :(
# Total time = 0.3639688491821289
# Mesh piece 133 inside mesh :(
# Total time = 0.5033504962921143
# Mesh piece 134 inside mesh :(
# Total time = 0.5256447792053223
# Mesh piece 135 inside mesh :(
# Total time = 0.5043830871582031
# Mesh piece 136 inside mesh :(
# Total time = 0.43360066413879395
# Mesh piece 137 inside mesh :(
# Total time = 0.448427677154541
# Mesh piece 138 inside mesh :(
# Total time = 0.39298248291015625
# Mesh piece 139 inside mesh :(
# Total time = 0.53934645652771
# Mesh piece 140 inside mesh :(
# Total time = 0.5632386207580566
# Mesh piece 141 inside mesh :(
# Total time = 0.43086862564086914
# Mesh piece 142 inside mesh :(
# Total time = 0.46151065826416016
# Mesh piece 143 inside mesh :(
# Total time = 0.08452439308166504
# Mesh piece 144 OUTSIDE mesh
# Total time = 0.34265732765197754
# Mesh piece 145 OUTSIDE mesh
# Total time = 0.46213603019714355
# Mesh piece 146 inside mesh :(
# Total time = 0.4547762870788574
# Mesh piece 147 inside mesh :(
# Total time = 0.5642919540405273
# Mesh piece 148 inside mesh :(
# Total time = 0.56201171875
# Mesh piece 149 inside mesh :(
# Total time = 0.4032917022705078
# Mesh piece 150 inside mesh :(
# Total time = 0.5498952865600586
# Mesh piece 151 inside mesh :(
# Total time = 0.5689558982849121
# Mesh piece 152 inside mesh :(
# Total time = 0.6339035034179688
# Mesh piece 153 inside mesh :(
# Total time = 0.7062609195709229
# Mesh piece 154 inside mesh :(
# Total time = 0.6068387031555176
# Mesh piece 155 inside mesh :(
# Total time = 0.8615097999572754
# Mesh piece 156 inside mesh :(
# Total time = 0.5219459533691406
# Mesh piece 157 inside mesh :(
# Total time = 0.600628137588501
# Mesh piece 158 inside mesh :(
# Total time = 0.6126880645751953
# Mesh piece 159 inside mesh :(
# Total time = 0.6598882675170898
# Mesh piece 160 inside mesh :(
# Total time = 0.7770740985870361
# Mesh piece 161 inside mesh :(
# Total time = 0.6063172817230225
# Mesh piece 162 inside mesh :(
# Total time = 0.64096999168396
# Mesh piece 163 inside mesh :(
# Total time = 0.682793378829956
# Mesh piece 164 inside mesh :(
# Total time = 0.5710301399230957
# Mesh piece 165 inside mesh :(
# Total time = 0.3545045852661133
# Mesh piece 166 inside mesh :(
# Total time = 0.43714118003845215
# Mesh piece 167 inside mesh :(
# Total time = 0.4459099769592285
# Mesh piece 168 inside mesh :(
# Total time = 0.5399613380432129
# Mesh piece 169 inside mesh :(
# Total time = 0.5733456611633301
# Mesh piece 170 inside mesh :(
# Total time = 0.5345151424407959
# Mesh piece 171 inside mesh :(
# Total time = 0.48696112632751465
# Mesh piece 172 inside mesh :(
# Total time = 0.002120494842529297
# Mesh piece 173 OUTSIDE mesh
# Total time = 0.5849616527557373
# Mesh piece 174 inside mesh :(
# Total time = 0.438152551651001
# Mesh piece 175 inside mesh :(
# Total time = 0.45842838287353516
# Mesh piece 176 inside mesh :(
# Total time = 0.4696922302246094
# Mesh piece 177 inside mesh :(
# Total time = 0.525667667388916
# Mesh piece 178 inside mesh :(
# Total time = 0.09535956382751465
# Mesh piece 179 OUTSIDE mesh
# Total time = 0.10947489738464355
# Mesh piece 180 OUTSIDE mesh
# Total time = 0.10706472396850586
# Mesh piece 181 OUTSIDE mesh
# Total time = 0.025745630264282227
# Mesh piece 182 OUTSIDE mesh
# Total time = 0.6077308654785156
# Mesh piece 183 inside mesh :(
# Total time = 0.5785961151123047
# Mesh piece 184 inside mesh :(
# Total time = 0.5702767372131348
# Mesh piece 185 inside mesh :(
# Total time = 0.5910811424255371
# Mesh piece 186 inside mesh :(
# Total time = 0.5730173587799072
# Mesh piece 187 inside mesh :(
# Total time = 0.6715545654296875
# Mesh piece 188 inside mesh :(
# Total time = 0.563331127166748
# Mesh piece 189 inside mesh :(
# Total time = 0.6264097690582275
# Mesh piece 190 inside mesh :(
# Total time = 0.5909321308135986
# Mesh piece 191 inside mesh :(
# Total time = 0.6529607772827148
# Mesh piece 192 inside mesh :(
# Total time = 0.6315391063690186
# Mesh piece 193 inside mesh :(
# Total time = 0.6222734451293945
# Mesh piece 194 inside mesh :(
# Total time = 0.7514617443084717
# Mesh piece 195 inside mesh :(
# Total time = 0.5015826225280762
# Mesh piece 196 inside mesh :(
# Total time = 0.5315029621124268
# Mesh piece 197 inside mesh :(
# Total time = 0.3760864734649658
# Mesh piece 198 inside mesh :(
# Total time = 0.32434916496276855
# Mesh piece 199 inside mesh :(
# Total time = 0.3385584354400635
# Mesh piece 200 inside mesh :(
# Total time = 0.30545759201049805
# Mesh piece 201 inside mesh :(
# Total time = 0.40468645095825195
# Mesh piece 202 inside mesh :(
# Total time = 0.4050099849700928
# Mesh piece 203 inside mesh :(
# Total time = 0.19445300102233887
# Mesh piece 204 inside mesh :(
# Total time = 0.9082295894622803
# Mesh piece 205 OUTSIDE mesh
# Total time = 0.36528825759887695
# Mesh piece 206 inside mesh :(
# Total time = 0.37480616569519043
# Mesh piece 207 inside mesh :(
# Total time = 0.4575614929199219
# Mesh piece 208 inside mesh :(
# Total time = 0.31055521965026855
# Mesh piece 209 inside mesh :(
# Total time = 0.37942981719970703
# Mesh piece 210 inside mesh :(
# Total time = 0.24122262001037598
# Mesh piece 211 inside mesh :(
# Total time = 0.3987751007080078
# Mesh piece 212 inside mesh :(
# Total time = 0.31020164489746094
# Mesh piece 213 inside mesh :(
# Total time = 1.140373945236206
# Mesh piece 214 OUTSIDE mesh
# Total time = 0.42760682106018066
# Mesh piece 215 inside mesh :(
# Total time = 0.26809024810791016
# Mesh piece 216 inside mesh :(
# Total time = 0.35675930976867676
# Mesh piece 217 inside mesh :(
# Total time = 0.307941198348999
# Mesh piece 218 inside mesh :(
# Total time = 0.48122549057006836
# Mesh piece 219 inside mesh :(
# Total time = 0.3512439727783203
# Mesh piece 220 inside mesh :(
# Total time = 0.6367087364196777
# Mesh piece 221 inside mesh :(
# Total time = 0.43285274505615234
# Mesh piece 222 inside mesh :(
# Total time = 0.4105873107910156
# Mesh piece 223 inside mesh :(
# Total time = 0.3902757167816162
# Mesh piece 224 inside mesh :(
# Total time = 0.5592565536499023
# Mesh piece 225 inside mesh :(
# Total time = 0.5020437240600586
# Mesh piece 226 inside mesh :(
# Total time = 0.42401790618896484
# Mesh piece 227 inside mesh :(
# Total time = 0.30785250663757324
# Mesh piece 228 inside mesh :(
# Total time = 0.3297309875488281
# Mesh piece 229 inside mesh :(
# Total time = 0.3478105068206787
# Mesh piece 230 inside mesh :(
# Total time = 0.36543774604797363
# Mesh piece 231 inside mesh :(
# Total time = 0.6449706554412842
# Mesh piece 232 inside mesh :(
# Total time = 0.041567325592041016
# Mesh piece 233 OUTSIDE mesh
# Total time = 0.5036919116973877
# Mesh piece 234 inside mesh :(
# Total time = 0.3857157230377197
# Mesh piece 235 inside mesh :(
# Total time = 0.3995022773742676
# Mesh piece 236 inside mesh :(
# Total time = 0.5167090892791748
# Mesh piece 237 inside mesh :(
# Total time = 1.1066052913665771
# Mesh piece 238 inside mesh :(
# Total time = 0.551121711730957
# Mesh piece 239 inside mesh :(
# Total time = 0.5240926742553711
# Mesh piece 240 inside mesh :(
# Total time = 0.5654909610748291
# Mesh piece 241 inside mesh :(
# Total time = 0.5092389583587646
# Mesh piece 242 inside mesh :(
# Total time = 0.47840237617492676
# Mesh piece 243 inside mesh :(
# Total time = 0.5659205913543701
# Mesh piece 244 inside mesh :(
# Total time = 0.5769987106323242
# Mesh piece 245 inside mesh :(
# Total time = 0.5634615421295166
# Mesh piece 246 inside mesh :(
# Total time = 0.29238295555114746
# Mesh piece 247 OUTSIDE mesh
# Total time = 0.33370113372802734
# Mesh piece 248 OUTSIDE mesh
# Total time = 0.5917091369628906
# Mesh piece 249 inside mesh :(
# Total time = 0.642636775970459
# Mesh piece 250 inside mesh :(
# Total time = 0.709648847579956
# Mesh piece 251 inside mesh :(
# Total time = 0.6613729000091553
# Mesh piece 252 inside mesh :(
# Total time = 0.4739205837249756
# Mesh piece 253 inside mesh :(
# Total time = 0.48041772842407227
# Mesh piece 254 inside mesh :(
# Total time = 0.3395731449127197
# Mesh piece 255 inside mesh :(
# Total time = 0.3864870071411133
# Mesh piece 256 inside mesh :(
# Total time = 0.31899571418762207
# Mesh piece 257 inside mesh :(
# Total time = 0.36768674850463867
# Mesh piece 258 inside mesh :(
# Total time = 0.3456878662109375
# Mesh piece 259 inside mesh :(
# Total time = 0.4387705326080322
# Mesh piece 260 inside mesh :(
# Total time = 0.43348264694213867
# Mesh piece 261 inside mesh :(
# Total time = 0.49247241020202637
# Mesh piece 262 inside mesh :(
# Total time = 0.3909742832183838
# Mesh piece 263 inside mesh :(
# Total time = 0.42186760902404785
# Mesh piece 264 inside mesh :(
# Total time = 0.4381082057952881
# Mesh piece 265 inside mesh :(
# Total time = 0.4327361583709717
# Mesh piece 266 inside mesh :(
# Total time = 0.4749157428741455
# Mesh piece 267 inside mesh :(
# Total time = 0.46941685676574707
# Mesh piece 268 inside mesh :(
# Total time = 0.49155569076538086
# Mesh piece 269 inside mesh :(
# Total time = 0.5030074119567871
# Mesh piece 270 inside mesh :(
# Total time = 0.46362972259521484
# Mesh piece 271 inside mesh :(
# Total time = 0.49805331230163574
# Mesh piece 272 inside mesh :(
# Total time = 0.5000762939453125
# Mesh piece 273 inside mesh :(
# Total time = 0.4564175605773926
# Mesh piece 274 inside mesh :(
# Total time = 0.4403533935546875
# Mesh piece 275 inside mesh :(
# Total time = 0.4650399684906006
# Mesh piece 276 inside mesh :(
# Total time = 0.5844485759735107
# Mesh piece 277 inside mesh :(
# Total time = 0.5589253902435303
# Mesh piece 278 inside mesh :(
# Total time = 0.4422740936279297
# Mesh piece 279 inside mesh :(
# Total time = 0.6133031845092773
# Mesh piece 280 inside mesh :(
# Total time = 0.5742282867431641
# Mesh piece 281 inside mesh :(
# Total time = 0.5898981094360352
# Mesh piece 282 inside mesh :(
# Total time = 0.41990017890930176
# Mesh piece 283 inside mesh :(
# Total time = 0.42647576332092285
# Mesh piece 284 inside mesh :(
# Total time = 0.4769766330718994
# Mesh piece 285 inside mesh :(
# Total time = 0.4577174186706543
# Mesh piece 286 inside mesh :(
# Total time = 0.3765735626220703
# Mesh piece 287 inside mesh :(
# Total time = 0.40740036964416504
# Mesh piece 288 OUTSIDE mesh
# Total time = 0.5821070671081543
# Mesh piece 289 OUTSIDE mesh
# Total time = 0.6685972213745117
# Mesh piece 290 inside mesh :(
# Total time = 0.6783843040466309
# Mesh piece 291 inside mesh :(
# Total time = 0.4728658199310303
# Mesh piece 292 inside mesh :(
# Total time = 0.5068535804748535
# Mesh piece 293 inside mesh :(
# Total time = 0.7136633396148682
# Mesh piece 294 inside mesh :(
# Total time = 0.5372908115386963
# Mesh piece 295 inside mesh :(
# Total time = 0.6043336391448975
# Mesh piece 296 inside mesh :(
# Total time = 0.6307921409606934
# Mesh piece 297 inside mesh :(
# Total time = 0.4102301597595215
# Mesh piece 298 inside mesh :(
# Total time = 0.49682044982910156
# Mesh piece 299 inside mesh :(
# Total time = 0.520594596862793
# Mesh piece 300 inside mesh :(
# Total time = 0.05147695541381836
# Mesh piece 301 OUTSIDE mesh
# Total time = 0.4329380989074707
# Mesh piece 302 inside mesh :(
# Total time = 0.34408092498779297
# Mesh piece 303 inside mesh :(
# Total time = 0.3932077884674072
# Mesh piece 304 inside mesh :(
# Total time = 0.33577442169189453
# Mesh piece 305 inside mesh :(
# Total time = 0.3993797302246094
# Mesh piece 306 inside mesh :(
# Total time = 0.3838062286376953
# Mesh piece 307 inside mesh :(
# Total time = 0.39673638343811035
# Mesh piece 308 inside mesh :(
# Total time = 0.602283239364624
# Mesh piece 309 inside mesh :(
# Total time = 0.5157790184020996
# Mesh piece 310 inside mesh :(
# Total time = 0.44629812240600586
# Mesh piece 311 inside mesh :(
# Total time = 0.36753177642822266
# Mesh piece 312 inside mesh :(
# Total time = 0.3374936580657959
# Mesh piece 313 inside mesh :(
# Total time = 0.5030450820922852
# Mesh piece 314 inside mesh :(
# Total time = 0.37302446365356445
# Mesh piece 315 inside mesh :(
# Total time = 0.4675443172454834
# Mesh piece 316 inside mesh :(
# Total time = 0.4229450225830078
# Mesh piece 317 inside mesh :(
# Total time = 0.4210047721862793
# Mesh piece 318 inside mesh :(
# Total time = 0.44797372817993164
# Mesh piece 319 inside mesh :(
# Total time = 0.44495177268981934
# Mesh piece 320 inside mesh :(
# Total time = 0.3964531421661377
# Mesh piece 321 inside mesh :(
# Total time = 0.42346715927124023
# Mesh piece 322 inside mesh :(
# Total time = 0.42122840881347656
# Mesh piece 323 inside mesh :(
# Total time = 0.39426112174987793
# Mesh piece 324 inside mesh :(
# Total time = 0.39797234535217285
# Mesh piece 325 inside mesh :(
# Total time = 0.44666481018066406
# Mesh piece 326 inside mesh :(
# Total time = 0.5393514633178711
# Mesh piece 327 inside mesh :(
# Total time = 0.44097161293029785
# Mesh piece 328 inside mesh :(
# Total time = 0.5905406475067139
# Mesh piece 329 inside mesh :(
# Total time = 0.5570328235626221
# Mesh piece 330 inside mesh :(
# Total time = 0.18712282180786133
# Mesh piece 331 inside mesh :(
# Total time = 0.6497578620910645
# Mesh piece 332 inside mesh :(
# Total time = 0.6150212287902832
# Mesh piece 333 inside mesh :(
# Total time = 0.5998404026031494
# Mesh piece 334 inside mesh :(
# Total time = 0.7612826824188232
# Mesh piece 335 inside mesh :(
# Total time = 0.6439268589019775
# Mesh piece 336 inside mesh :(
# Total time = 0.5929126739501953
# Mesh piece 337 inside mesh :(
# Total time = 0.661970853805542
# Mesh piece 338 inside mesh :(
# Total time = 0.4548938274383545
# Mesh piece 339 inside mesh :(
# Total time = 0.4342989921569824
# Mesh piece 340 inside mesh :(
# Total time = 0.4647800922393799
# Mesh piece 341 inside mesh :(
# Total time = 0.5214645862579346
# Mesh piece 342 inside mesh :(
# Total time = 0.5938313007354736
# Mesh piece 343 inside mesh :(
# Total time = 0.5461304187774658
# Mesh piece 344 inside mesh :(
# Total time = 0.6462631225585938
# Mesh piece 345 inside mesh :(
# Total time = 0.5477426052093506
# Mesh piece 346 inside mesh :(
# Total time = 0.39851975440979004
# Mesh piece 347 inside mesh :(
# Total time = 0.4402754306793213
# Mesh piece 348 inside mesh :(
# Total time = 0.5202734470367432
# Mesh piece 349 inside mesh :(
# Total time = 0.5568666458129883
# Mesh piece 350 inside mesh :(
# Total time = 0.6431677341461182
# Mesh piece 351 inside mesh :(
# Total time = 0.6421821117401123
# Mesh piece 352 inside mesh :(
# Total time = 0.4836447238922119
# Mesh piece 353 inside mesh :(
# Total time = 0.43804216384887695
# Mesh piece 354 inside mesh :(
# Total time = 0.5063910484313965
# Mesh piece 355 inside mesh :(
# Total time = 0.6064393520355225
# Mesh piece 356 inside mesh :(
# Total time = 0.5470211505889893
# Mesh piece 357 inside mesh :(
# Total time = 0.47647619247436523
# Mesh piece 358 inside mesh :(
# Total time = 0.2853994369506836
# Mesh piece 359 inside mesh :(
# Total time = 0.2849302291870117
# Mesh piece 360 inside mesh :(
# Total time = 0.2307145595550537
# Mesh piece 361 inside mesh :(
# Total time = 0.346327543258667
# Mesh piece 362 inside mesh :(
# Total time = 0.38123488426208496
# Mesh piece 363 inside mesh :(
# Total time = 0.29409146308898926
# Mesh piece 364 inside mesh :(
# Total time = 0.3512396812438965
# Mesh piece 365 inside mesh :(
# Total time = 0.4684474468231201
# Mesh piece 366 inside mesh :(
# Total time = 0.6878550052642822
# Mesh piece 367 inside mesh :(
# Total time = 0.6029469966888428
# Mesh piece 368 inside mesh :(
# Total time = 0.45952534675598145
# Mesh piece 369 inside mesh :(
# Total time = 0.46599817276000977
# Mesh piece 370 inside mesh :(
# Total time = 0.4950084686279297
# Mesh piece 371 inside mesh :(
# Total time = 0.47477126121520996
# Mesh piece 372 inside mesh :(
# Total time = 0.5339674949645996
# Mesh piece 373 inside mesh :(
# Total time = 0.6002511978149414
# Mesh piece 374 inside mesh :(
# Total time = 0.6303377151489258
# Mesh piece 375 inside mesh :(
# Total time = 0.45772242546081543
# Mesh piece 376 inside mesh :(
# Total time = 0.4778881072998047
# Mesh piece 377 inside mesh :(
# Total time for Mesh Cleansing: 195.86387968063354

# %% [markdown]
# # OPTOMIZED WAY OF FINDING FACETS

# %%
import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))


#will filter according to convexity of the boundary
def final_facets_convexity_and_generate_centers(gap_mesh,final_facets):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """


    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    print("len(edges) = " + str(len(edges)))
    print("len(gap_mesh.faces) = " + str(len(gap_mesh.faces)))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers




#will filter according to convexity of the boundary
def facets_generate_centers(gap_mesh,final_facets):
    """
    Just generates the midpoints of the facets without filtering for convexity
    """

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_centers

# %%
def filter_final_facets_optimized(example_mesh,
                                  normal_closeness=0.99,
                                  first_pass_size_threshold=6000):
    """
    Way of computing facets that uses trimesh grouping function and normals threshold
    instead of the pre-built trimesh.facets
    
    """

    #get the facets for the child mesh
    start_time_total = time.time()

    #switch out with dot product
    
    
    #Old way of computing the dot product manually
    total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
    
    #using manual method
#     print(len(total_normals[:,0]*total_normals[:,1]))
    start_normal = time.time()
    total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
    print(f"Total normals took {time.time() - start_normal}")
    ''' DONT HAVE TO DO DOT PRODUCT BECAUSE JUST WANT TO MULTIPLY THE ROWS OF EACH COLUMN'''
#     print("About to do dot product")
#     dot_start = time.time()
#     a = total_normals[:,0]
#     b = total_normals[:,1].T
#     #new way using the dot product
#     total_normal_dots = np.dot(a,b)
    
    
    #get the True/False value if face adjacency is within normal closeness
    start_normal = time.time()
    total_normal_dots_facet_mask = total_normal_dots > normal_closeness
    print(f"Boolean mask finished: {time.time() - start_normal}")

    #getting the grouping of the faces into facets within the threshold
    start_normal = time.time()
    components = trimesh.graph.connected_components(example_mesh.face_adjacency[total_normal_dots_facet_mask],
                                          nodes=np.arange(len(example_mesh.faces)),
                                          min_len=2,
                                          engine="None")
    print(f"Grouping took: {time.time() - start_normal}")
    
    
    """ This was taking a long time and only cutting them down by like 1/4, going to get rid of it and see if doesn't hurt accuracy but increases speed

    print(f"Lenght of facets BEFORE filtering = {len(components)}")
    
    #filter by the size
    start_normal = time.time()
    size_filtered_components = [facet_list for facet_list in components 
                                    if find_polygon_area(example_mesh,facet_list) > first_pass_size_threshold]
    print(f"Filtering edges by size finished: {time.time() - start_normal}")
    
    print(f"Lenght of facets AFTER filtering = {len(size_filtered_components)}")
    
    """

    #filter by the convexity
    #final_facets_mean_filtered,final_facets_centers = filter_final_facets(example_mesh,size_filtered_components)
    
    """ this was taking a while so going to see if not filtering for convexity and only generating facet centers will work just fine while improving speed
    start_normal = time.time()
    final_facets_mean_filtered,final_facets_centers = final_facets_convexity_and_generate_centers(example_mesh,components)
    print(f"Filtering by convexity and getting centers took: {time.time() - start_normal}")
    """

    
    final_facets_centers = facets_generate_centers(example_mesh,components)
    
    print(f"Total Time = {time.time() - start_time_total}")

    return components,final_facets_centers

# %%
# #get the faces that are surrounding by neighbors who's normal is within the allowed threshold for their dot product
# example_mesh = child_meshes[1]

# #get the normals of the first adjacency pair and compute the normal dot product
# normals = example_mesh.face_normals[example_mesh.face_adjacency[1]]

# #that's the number i'm looking for, for all of the adjacency pairs, that's the example

# total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
# len(total_normals[:,0]*total_normals[:,1])

# np.dot(normals[0],normals[1])

# %% [markdown]
# # Unoptimized Less Careful Face Finder

# %%
# start_time = time.time()
# first_pass_size_threshold=6000


# example_mesh = child_meshes[3]

# normal_closeness=0.995
# total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
# print(len(total_normals[:,0]*total_normals[:,1]))
# total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
# total_normal_dots_facet_mask = total_normal_dots > normal_closeness

# #try sending it to the graph function


# mesh2 = example_mesh
# components = trimesh.graph.connected_components(mesh2.face_adjacency[total_normal_dots_facet_mask],
#                                       nodes=np.arange(len(mesh2.faces)),
#                                       min_len=2,
#                                       engine="None")


# #filter by the size
# size_filtered_components = [facet_list for facet_list in components if find_polygon_area(mesh2,facet_list) > first_pass_size_threshold]

# #filter by the convexity
# final_facets_mean_filtered,final_facets_centers = filter_final_facets(mesh2,size_filtered_components)

# print(f"Total Time = {time.time() - start_time}")

# print(len(final_facets_mean_filtered))

# %% [markdown]
# # Download the facets for the mesh

# %%
# import math
# def area(vertices):
#     """
#     Calculates the area of a 3D triangle from it's coordinates
#     """
#     side_a = np.linalg.norm(vertices[0]-vertices[1])
#     side_b = np.linalg.norm(vertices[1]-vertices[2])
#     side_c = np.linalg.norm(vertices[2]-vertices[0])
#     s = 0.5 * ( side_a + side_b + side_c)
#     return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

# def find_polygon_area(mesh,list_of_faces):
#     "Calculates the area of a 3D polygon that is created from connected traingles"
#     return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %% [markdown]
# # Older way of calculating the facets

# %%
import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))


#will filter according to convexity of the boundary
def final_facets_convexity_and_generate_centers(gap_mesh,final_facets):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """


    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    print("len(edges) = " + str(len(edges)))
    print("len(gap_mesh.faces) = " + str(len(gap_mesh.faces)))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
# need a way of finding the neighbors that have to share adjacent faces
def create_neighbors_lookup(mesh):
    start_time = time.time()
    neighbors_lookup = dict([(i,[]) for i in range(0,len(mesh.faces))])
    #print(f"Creating empty dictionary : {time.time() - start_time}")
    
    start_time = time.time()
    for adj in mesh.face_adjacency:
        neighbors_lookup[adj[0]].append(adj[1])
        neighbors_lookup[adj[1]].append(adj[0])
    #print(f"Filling in neighbors lookup : {time.time() - start_time}")
    
    return neighbors_lookup

def filter_and_expand_facets(new_mesh,
                             first_pass_size_threshold=2000,
                             normal_closeness=0.985):
    
    """
    
    """
    
    #filter the facets that are below a size threshold
    new_facets = new_mesh.facets[np.where(new_mesh.facets_area > first_pass_size_threshold)[0]]

    neighbors_lookup = create_neighbors_lookup(new_mesh)
    
    #generate a normals lookup table and see if works faster than regular lookup
    normal_lookup = {}

    for i in range(0,len(new_mesh.faces)):
        normal_lookup[i] = new_mesh.face_normals[i]
    
    global_start_time = time.time()
    final_facets= [0]*len(new_facets)
    
    for i,facet in enumerate(new_facets):
    #     mini_global_start_time = time.time()
    #     print(facet)
    #     print(type(facet))
    #     start_time = time.time()
    #     print([find_neighbors(k) for k in facet])
        total_neighbors = list(set(np.hstack([neighbors_lookup[k] for k in facet])).difference(set(facet)))
    #     print(total_neighbors)
    #     print(f"time initial neighbors: {(time.time() - start_time)}")
        neighbors_to_add = []
        neighbors_checked = []
        #print(total_neighbors)

        #just get the normal from one of the faces already in the facet
    #     start_time = time.time()
        facet_normal = normal_lookup[facet[0]]

    #     total_dot_time = 0
        while len(total_neighbors) > 0:
            current_neighbor = total_neighbors.pop()
            neighbors_checked.append(current_neighbor)

    #         print("--------------")
    # #         #check to see if neighbor has same normal face
    # #         start_dot_time = time.time()
    # #         dot_result = np.dot(new_mesh.face_normals[current_neighbor],facet_normal) #> normal_closeness
    # #         print(dot_result)
    # #         print((time.time() - start_dot_time) * 1000)

    #         start_dot_time = time.time()
    #         print(current_neighbor)
    #         #a = new_mesh.face_normals[current_neighbor]

    #         print((time.time() - start_dot_time) * 1000)
    #         dot_result = a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness
    #         print(dot_result)
    #         print((time.time() - start_dot_time) * 1000)
    #         print("--------------")

    #         total_dot_time += (time.time() - start_dot_time)*1000

            a = normal_lookup[current_neighbor]
            if a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness:

                neighbors_to_add.append(current_neighbor)
                #get the neighbors of this current face
                for neigh in neighbors_lookup[current_neighbor]:
                    #only add those neighbors that havent already been checked, in original facet group, or already in list to check
                    if neigh not in neighbors_checked and neigh not in facet and neigh not in total_neighbors:
                        total_neighbors.append(neigh)
    #     print(f"Total dot time: {total_dot_time}")
    #     print(f"time loop: {(time.time() - start_time)}")
    #     print("neighbors_to_add = " + str(neighbors_to_add))abs
    #     print("neighbors_checked = " + str(neighbors_checked))
    #     print("adding list = " + str(list(facet) + neighbors_to_add))
    #     start_time = time.time()
        final_facets[i] = list(facet) + neighbors_to_add
    #     print(f"Appending to list: {(time.time() - start_time)}")

    #     print(f"Total time: {(time.time() - mini_global_start_time)}")
    #     print("------------------------------------------------------")


    print(f"Total Facet building time: {(time.time() - global_start_time)}")
    return final_facets

def filter_final_facets(gap_mesh):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """
    
    final_facets = filter_and_expand_facets(gap_mesh,
                                 first_pass_size_threshold=2000,
                                 normal_closeness=0.985)

    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
# facet_time = time.time()
# main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
# print("Finished facets for main mesh")
# child_meshes_facets= []
# for jj,gap_mesh in enumerate(child_meshes):
#     start_time = time.time()
#     child_meshes_facets.append(filter_final_facets(gap_mesh))
#     print(f"Finished facets for child {jj} : {time.time() - start_time}")


# print(f"Total time for facets: {time.time() - facet_time}")
# #child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]

# %% [markdown]
# # OPTOMIZED WAYS WITH CHECKS

# %% [markdown]
# # Working Version from Old Script

# %%
import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))


def filter_final_facets_working(gap_mesh,final_facets):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """


    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
def filter_final_facets_optimized_with_checks(example_mesh,
                                  normal_closeness=0.99,
                                  first_pass_size_threshold=6000):
    """
    Way of computing facets that uses trimesh grouping function and normals threshold
    instead of the pre-built trimesh.facets
    
    """

    #get the facets for the child mesh
    start_time_total = time.time()

    #switch out with dot product
    
    
    #Old way of computing the dot product manually
    total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
    
    #using manual method
#     print(len(total_normals[:,0]*total_normals[:,1]))
    start_normal = time.time()
    total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
    print(f"Total normals took {time.time() - start_normal}")
    ''' DONT HAVE TO DO DOT PRODUCT BECAUSE JUST WANT TO MULTIPLY THE ROWS OF EACH COLUMN'''
#     print("About to do dot product")
#     dot_start = time.time()
#     a = total_normals[:,0]
#     b = total_normals[:,1].T
#     #new way using the dot product
#     total_normal_dots = np.dot(a,b)
    
    
    #get the True/False value if face adjacency is within normal closeness
    start_normal = time.time()
    total_normal_dots_facet_mask = total_normal_dots > normal_closeness
    print(f"Boolean mask finished: {time.time() - start_normal}")

    #getting the grouping of the faces into facets within the threshold
    start_normal = time.time()
    components = trimesh.graph.connected_components(example_mesh.face_adjacency[total_normal_dots_facet_mask],
                                          nodes=np.arange(len(example_mesh.faces)),
                                          min_len=2,
                                          engine="None")
    print(f"Grouping took: {time.time() - start_normal}")
    
    

    #print(f"Lenght of facets BEFORE filtering = {len(components)}")
    
    #filter by the size
    
    start_normal = time.time()
    size_filtered_components = [facet_list for facet_list in components 
                                    if find_polygon_area(example_mesh,facet_list) > first_pass_size_threshold]
    print(f"Filtering edges by size finished: {time.time() - start_normal}")
    


    #filter by the convexity
    #final_facets_mean_filtered,final_facets_centers = filter_final_facets(example_mesh,size_filtered_components)
    
    start_normal = time.time()
    final_facets_mean_filtered,final_facets_centers = filter_final_facets_working(example_mesh,size_filtered_components)
    print(f"Filtering by convexity and getting centers took: {time.time() - start_normal}")

    
    print(f"Total Time = {time.time() - start_time_total}")

    return final_facets_mean_filtered,final_facets_centers

# %%
len(child_meshes[1].faces)
# Out:
# 16458

# %% [markdown]
# # ACTUALLY CALCULATING THE FACETS

# %%
"""
New method takes about 50 seconds less time but without it have about 25 - 50% more facets
Trying it without it for now 

"""
# Out:
# '\nNew method takes about 50 seconds less time but without it have about 25 - 50% more facets\nTrying it without it for now \n\n'

# %%
facet_time = time.time()
start_time = time.time()
main_mesh_facets,main_mesh_facets_centers = filter_final_facets_optimized(main_mesh)
print(f"Finished facets for main mesh: {time.time() - start_time}")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    start_time = time.time()
    child_meshes_facets.append(filter_final_facets_optimized(gap_mesh))
    print(f"Finished facets for child {jj} : {time.time() - start_time}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]

# %%
saved_main_mesh_facets_centers = main_mesh_facets_centers.copy()
saved_main_mesh_facets = main_mesh_facets.copy()

import copy

saved_child_meshes_facets = copy.deepcopy(child_meshes_facets)

# %%
#compare the using convex vs. non-convex
print(f" len(saved_main_mesh_facets) - len(main_mesh_facets) = { ( len(main_mesh_facets) - len(saved_main_mesh_facets))/len(main_mesh_facets)}")
for i,gap_mesh in enumerate(child_meshes):
    print(f" len(child {i} mesh_facets saved) - len(child {i} mesh_facets) = {(len(child_meshes_facets[i][0]) - len(saved_child_meshes_facets[i][0]) )/len(child_meshes_facets[i][0])}")

# %% [markdown]
# # Finding the facets in a manner that won't create a ton of facets

# %%
"""
Rule: 
1) if mesh size is above a threshold --> run the unoptimized less careful version
2) if mesh is below that size --> run optimized more generous (but with all the filters )

"""
facet_time = time.time()
start_time = time.time()

length_threshold = 60000

if len(main_mesh.faces > length_threshold):
    print(f" face length {len(main_mesh.faces)} using unoptimized facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
    
else:
    print(f" face length {len(main_mesh.faces)} using OPTIMIZED facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets_optimized_with_checks(main_mesh)
    

print(f"Finished { len(main_mesh_facets)} facets for main mesh: {time.time() - start_time}")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    
    start_time = time.time()
    if len(gap_mesh.faces) > length_threshold:
        print(f" face length {len(gap_mesh.faces)} using unoptimized facets")
        child_meshes_facets.append(filter_final_facets(gap_mesh))
    else:
        print(f" face length {len(gap_mesh.faces)} using OPTIMIZED facets")
        child_meshes_facets.append(filter_final_facets_optimized_with_checks(gap_mesh))

    
    print(f"Finished facets for child {jj} : {time.time() - start_time} with facet length = {len(child_meshes_facets[jj][0])}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]
# Out:
#  face length 1845336 using unoptimized facets
# Total Facet building time: 6.2851481437683105
# Finished 13547 facets for main mesh: 44.452144622802734
#  face length 117018 using unoptimized facets
# Total Facet building time: 0.3048272132873535
# Finished facets for child 0 : 2.4181501865386963 with facet length = 863
#  face length 16458 using OPTIMIZED facets
# Total normals took 0.0005996227264404297
# Boolean mask finished: 2.0265579223632812e-05
# Grouping took: 0.006300687789916992
# Filtering edges by size finished: 0.4390225410461426
# Filtering by convexity and getting centers took: 0.5661885738372803
# Total Time = 1.0144166946411133
# Finished facets for child 1 : 1.0147552490234375 with facet length = 644
#  face length 32560 using OPTIMIZED facets
# Total normals took 0.0012028217315673828
# Boolean mask finished: 9.965896606445312e-05
# Grouping took: 0.010546445846557617
# Filtering edges by size finished: 0.9870278835296631
# Filtering by convexity and getting centers took: 1.1386442184448242
# Total Time = 2.1422677040100098
# Finished facets for child 2 : 2.1429951190948486 with facet length = 485
#  face length 27890 using OPTIMIZED facets
# Total normals took 0.0009593963623046875
# Boolean mask finished: 0.00011086463928222656
# Grouping took: 0.00831913948059082
# Filtering edges by size finished: 0.615410566329956
# Filtering by convexity and getting centers took: 1.0279266834259033
# Total Time = 1.6566720008850098
# Finished facets for child 3 : 1.6571853160858154 with facet length = 887
#  face length 17314 using OPTIMIZED facets
# Total normals took 0.0006160736083984375
# Boolean mask finished: 1.9550323486328125e-05
# Grouping took: 0.0061762332916259766
# Filtering edges by size finished: 0.4565613269805908
# Filtering by convexity and getting centers took: 0.5657086372375488
# Total Time = 1.0316834449768066
# Finished facets for child 4 : 1.032038688659668 with facet length = 521
#  face length 5608 using OPTIMIZED facets
# Total normals took 0.00030994415283203125
# Boolean mask finished: 3.0517578125e-05
# Grouping took: 0.002762317657470703
# Filtering edges by size finished: 0.13474774360656738
# Filtering by convexity and getting centers took: 0.19061636924743652
# Total Time = 0.32958555221557617
# Finished facets for child 5 : 0.329723596572876 with facet length = 203
#  face length 16714 using OPTIMIZED facets
# Total normals took 0.0006268024444580078
# Boolean mask finished: 9.512901306152344e-05
# Grouping took: 0.005356311798095703
# Filtering edges by size finished: 0.4342195987701416
# Filtering by convexity and getting centers took: 0.6208033561706543
# Total Time = 1.0633392333984375
# Finished facets for child 6 : 1.0637214183807373 with facet length = 567
#  face length 8374 using OPTIMIZED facets
# Total normals took 0.0003495216369628906
# Boolean mask finished: 0.00010037422180175781
# Grouping took: 0.003507375717163086
# Filtering edges by size finished: 0.2560904026031494
# Filtering by convexity and getting centers took: 0.25495147705078125
# Total Time = 0.5164635181427002
# Finished facets for child 7 : 0.5166630744934082 with facet length = 212
#  face length 5420 using OPTIMIZED facets
# Total normals took 0.0002262592315673828
# Boolean mask finished: 7.43865966796875e-05
# Grouping took: 0.0024826526641845703
# Filtering edges by size finished: 0.1341876983642578
# Filtering by convexity and getting centers took: 0.1823287010192871
# Total Time = 0.32023167610168457
# Finished facets for child 8 : 0.32036519050598145 with facet length = 170
#  face length 19204 using OPTIMIZED facets
# Total normals took 0.0006704330444335938
# Boolean mask finished: 9.369850158691406e-05
# Grouping took: 0.005990266799926758
# Filtering edges by size finished: 0.5735013484954834
# Filtering by convexity and getting centers took: 0.716418981552124
# Total Time = 1.2994303703308105
# Finished facets for child 9 : 1.2998690605163574 with facet length = 460
#  face length 3524 using OPTIMIZED facets
# Total normals took 0.00037026405334472656
# Boolean mask finished: 7.939338684082031e-05
# Grouping took: 0.0020360946655273438
# Filtering edges by size finished: 0.10321617126464844
# Filtering by convexity and getting centers took: 0.12353849411010742
# Total Time = 0.23031973838806152
# Finished facets for child 10 : 0.23046469688415527 with facet length = 130
#  face length 12664 using OPTIMIZED facets
# Total normals took 0.0005023479461669922
# Boolean mask finished: 8.463859558105469e-05
# Grouping took: 0.00464320182800293
# Filtering edges by size finished: 0.38074755668640137
# Filtering by convexity and getting centers took: 0.47313570976257324
# Total Time = 0.8614046573638916
# Finished facets for child 11 : 0.8618128299713135 with facet length = 290
#  face length 6432 using OPTIMIZED facets
# Total normals took 0.000335693359375
# Boolean mask finished: 0.0001506805419921875
# Grouping took: 0.0026922225952148438
# Filtering edges by size finished: 0.17830371856689453
# Filtering by convexity and getting centers took: 0.2277665138244629
# Total Time = 0.41053009033203125
# Finished facets for child 12 : 0.41076207160949707 with facet length = 191
#  face length 6132 using OPTIMIZED facets
# Total normals took 0.00034689903259277344
# Boolean mask finished: 3.457069396972656e-05
# Grouping took: 0.0032291412353515625
# Filtering edges by size finished: 0.17641067504882812
# Filtering by convexity and getting centers took: 0.21443939208984375
# Total Time = 0.3960082530975342
# Finished facets for child 13 : 0.3961942195892334 with facet length = 185
#  face length 8086 using OPTIMIZED facets
# Total normals took 0.0003445148468017578
# Boolean mask finished: 9.679794311523438e-05
# Grouping took: 0.0035598278045654297
# Filtering edges by size finished: 0.2598860263824463
# Filtering by convexity and getting centers took: 0.27837300300598145
# Total Time = 0.5437023639678955
# Finished facets for child 14 : 0.5440568923950195 with facet length = 187
#  face length 19179 using OPTIMIZED facets
# Total normals took 0.0006842613220214844
# Boolean mask finished: 3.6716461181640625e-05
# Grouping took: 0.005976200103759766
# Filtering edges by size finished: 0.48018813133239746
# Filtering by convexity and getting centers took: 0.6208431720733643
# Total Time = 1.1104555130004883
# Finished facets for child 15 : 1.1108512878417969 with facet length = 470
#  face length 8014 using OPTIMIZED facets
# Total normals took 0.00032329559326171875
# Boolean mask finished: 0.00014257431030273438
# Grouping took: 0.0032575130462646484
# Filtering edges by size finished: 0.18993401527404785
# Filtering by convexity and getting centers took: 0.31936120986938477
# Total Time = 0.5143721103668213
# Finished facets for child 16 : 0.5145909786224365 with facet length = 261
#  face length 348 using OPTIMIZED facets
# Total normals took 0.00011849403381347656
# Boolean mask finished: 1.1205673217773438e-05
# Grouping took: 0.0011451244354248047
# Filtering edges by size finished: 0.008543968200683594
# Filtering by convexity and getting centers took: 0.011925220489501953
# Total Time = 0.022478103637695312
# Finished facets for child 17 : 0.022531986236572266 with facet length = 10
#  face length 268 using OPTIMIZED facets
# Total normals took 0.0001418590545654297
# Boolean mask finished: 5.9604644775390625e-06
# Grouping took: 0.0009255409240722656
# Filtering edges by size finished: 0.00699305534362793
# Filtering by convexity and getting centers took: 0.01239156723022461
# Total Time = 0.02096104621887207
# Finished facets for child 18 : 0.021011829376220703 with facet length = 16
#  face length 74 using OPTIMIZED facets
# Total normals took 2.7179718017578125e-05
# Boolean mask finished: 5.4836273193359375e-06
# Grouping took: 0.0006551742553710938
# Filtering edges by size finished: 0.0018050670623779297
# Filtering by convexity and getting centers took: 0.003694295883178711
# Total Time = 0.006541252136230469
# Finished facets for child 19 : 0.006587982177734375 with facet length = 4
#  face length 216 using OPTIMIZED facets
# Total normals took 0.000148773193359375
# Boolean mask finished: 5.7220458984375e-06
# Grouping took: 0.0009999275207519531
# Filtering edges by size finished: 0.006247997283935547
# Filtering by convexity and getting centers took: 0.009497404098510742
# Total Time = 0.017370223999023438
# Finished facets for child 20 : 0.017418622970581055 with facet length = 16
#  face length 596 using OPTIMIZED facets
# Total normals took 0.00015854835510253906
# Boolean mask finished: 8.58306884765625e-06
# Grouping took: 0.001604318618774414
# Filtering edges by size finished: 0.019782066345214844
# Filtering by convexity and getting centers took: 0.017531633377075195
# Total Time = 0.03966236114501953
# Finished facets for child 21 : 0.0397186279296875 with facet length = 14
#  face length 32 using OPTIMIZED facets
# Total normals took 2.5033950805664062e-05
# Boolean mask finished: 5.9604644775390625e-06
# Grouping took: 0.0007166862487792969
# Filtering edges by size finished: 0.001741647720336914
# Filtering by convexity and getting centers took: 0.0001323223114013672
# Total Time = 0.0029799938201904297
# Finished facets for child 22 : 0.0030689239501953125 with facet length = 0
#  face length 1256 using OPTIMIZED facets
# Total normals took 0.0002155303955078125
# Boolean mask finished: 9.775161743164062e-06
# Grouping took: 0.002366304397583008
# Filtering edges by size finished: 0.03408384323120117
# Filtering by convexity and getting centers took: 0.05040907859802246
# Total Time = 0.08774948120117188
# Finished facets for child 23 : 0.08781576156616211 with facet length = 63
#  face length 236 using OPTIMIZED facets
# Total normals took 7.104873657226562e-05
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.0009915828704833984
# Filtering edges by size finished: 0.005615949630737305
# Filtering by convexity and getting centers took: 0.007025480270385742
# Total Time = 0.014533281326293945
# Finished facets for child 24 : 0.014580965042114258 with facet length = 8
#  face length 1390 using OPTIMIZED facets
# Total normals took 0.00010657310485839844
# Boolean mask finished: 1.0013580322265625e-05
# Grouping took: 0.0024166107177734375
# Filtering edges by size finished: 0.03831219673156738
# Filtering by convexity and getting centers took: 0.056035518646240234
# Total Time = 0.09757804870605469
# Finished facets for child 25 : 0.09764409065246582 with facet length = 56
#  face length 54 using OPTIMIZED facets
# Total normals took 2.6702880859375e-05
# Boolean mask finished: 5.7220458984375e-06
# Grouping took: 0.0006620883941650391
# Filtering edges by size finished: 0.001767873764038086
# Filtering by convexity and getting centers took: 0.0032052993774414062
# Total Time = 0.006232738494873047
# Finished facets for child 26 : 0.00627589225769043 with facet length = 5
#  face length 80 using OPTIMIZED facets
# Total normals took 2.7418136596679688e-05
# Boolean mask finished: 5.4836273193359375e-06
# Grouping took: 0.0007145404815673828
# Filtering edges by size finished: 0.001604318618774414
# Filtering by convexity and getting centers took: 0.003088235855102539
# Total Time = 0.005883455276489258
# Finished facets for child 27 : 0.005927324295043945 with facet length = 3
#  face length 2672 using OPTIMIZED facets
# Total normals took 0.00023746490478515625
# Boolean mask finished: 1.0251998901367188e-05
# Grouping took: 0.002864837646484375
# Filtering edges by size finished: 0.06991767883300781
# Filtering by convexity and getting centers took: 0.1053013801574707
# Total Time = 0.17903494834899902
# Finished facets for child 28 : 0.1792163848876953 with facet length = 124
#  face length 5268 using OPTIMIZED facets
# Total normals took 0.00025081634521484375
# Boolean mask finished: 5.7220458984375e-05
# Grouping took: 0.00396275520324707
# Filtering edges by size finished: 0.13945603370666504
# Filtering by convexity and getting centers took: 0.21727514266967773
# Total Time = 0.36206626892089844
# Finished facets for child 29 : 0.36258411407470703 with facet length = 184
#  face length 1724 using OPTIMIZED facets
# Total normals took 0.0002765655517578125
# Boolean mask finished: 1.239776611328125e-05
# Grouping took: 0.0030112266540527344
# Filtering edges by size finished: 0.049335479736328125
# Filtering by convexity and getting centers took: 0.04714059829711914
# Total Time = 0.10063719749450684
# Finished facets for child 30 : 0.10073208808898926 with facet length = 34
#  face length 3786 using OPTIMIZED facets
# Total normals took 0.0003044605255126953
# Boolean mask finished: 1.2159347534179688e-05
# Grouping took: 0.0024890899658203125
# Filtering edges by size finished: 0.13886022567749023
# Filtering by convexity and getting centers took: 0.11289048194885254
# Total Time = 0.2556447982788086
# Finished facets for child 31 : 0.2557859420776367 with facet length = 53
#  face length 802 using OPTIMIZED facets
# Total normals took 0.00028204917907714844
# Boolean mask finished: 1.0013580322265625e-05
# Grouping took: 0.0014481544494628906
# Filtering edges by size finished: 0.022869586944580078
# Filtering by convexity and getting centers took: 0.030332565307617188
# Total Time = 0.05560708045959473
# Finished facets for child 32 : 0.05567455291748047 with facet length = 27
#  face length 606 using OPTIMIZED facets
# Total normals took 0.00016260147094726562
# Boolean mask finished: 8.821487426757812e-06
# Grouping took: 0.001636505126953125
# Filtering edges by size finished: 0.021810054779052734
# Filtering by convexity and getting centers took: 0.02132701873779297
# Total Time = 0.04581141471862793
# Finished facets for child 33 : 0.04587721824645996 with facet length = 28
#  face length 1456 using OPTIMIZED facets
# Total normals took 0.0003268718719482422
# Boolean mask finished: 1.1205673217773438e-05
# Grouping took: 0.002171754837036133
# Filtering edges by size finished: 0.03914976119995117
# Filtering by convexity and getting centers took: 0.054370880126953125
# Total Time = 0.09667110443115234
# Finished facets for child 34 : 0.0967555046081543 with facet length = 63
#  face length 632 using OPTIMIZED facets
# Total normals took 9.369850158691406e-05
# Boolean mask finished: 1.049041748046875e-05
# Grouping took: 0.0021991729736328125
# Filtering edges by size finished: 0.019228219985961914
# Filtering by convexity and getting centers took: 0.0300595760345459
# Total Time = 0.052396535873413086
# Finished facets for child 35 : 0.05246591567993164 with facet length = 18
#  face length 92 using OPTIMIZED facets
# Total normals took 3.814697265625e-05
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.0008840560913085938
# Filtering edges by size finished: 0.0039751529693603516
# Filtering by convexity and getting centers took: 0.003251314163208008
# Total Time = 0.008673667907714844
# Finished facets for child 36 : 0.008735895156860352 with facet length = 5
#  face length 968 using OPTIMIZED facets
# Total normals took 0.00020194053649902344
# Boolean mask finished: 1.0251998901367188e-05
# Grouping took: 0.0022270679473876953
# Filtering edges by size finished: 0.03665947914123535
# Filtering by convexity and getting centers took: 0.03407859802246094
# Total Time = 0.07402825355529785
# Finished facets for child 37 : 0.0740973949432373 with facet length = 37
#  face length 170 using OPTIMIZED facets
# Total normals took 0.00014829635620117188
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.0010914802551269531
# Filtering edges by size finished: 0.004747867584228516
# Filtering by convexity and getting centers took: 0.00800323486328125
# Total Time = 0.014604330062866211
# Finished facets for child 38 : 0.014658927917480469 with facet length = 10
#  face length 260 using OPTIMIZED facets
# Total normals took 0.0001595020294189453
# Boolean mask finished: 5.9604644775390625e-06
# Grouping took: 0.001224517822265625
# Filtering edges by size finished: 0.008514642715454102
# Filtering by convexity and getting centers took: 0.012527227401733398
# Total Time = 0.022945404052734375
# Finished facets for child 39 : 0.023004531860351562 with facet length = 17
#  face length 66 using OPTIMIZED facets
# Total normals took 3.743171691894531e-05
# Boolean mask finished: 6.4373016357421875e-06
# Grouping took: 0.0008437633514404297
# Filtering edges by size finished: 0.0011057853698730469
# Filtering by convexity and getting centers took: 0.002721071243286133
# Total Time = 0.005149126052856445
# Finished facets for child 40 : 0.005198240280151367 with facet length = 4
#  face length 124 using OPTIMIZED facets
# Total normals took 3.9577484130859375e-05
# Boolean mask finished: 5.9604644775390625e-06
# Grouping took: 0.0008785724639892578
# Filtering edges by size finished: 0.0026557445526123047
# Filtering by convexity and getting centers took: 0.0047779083251953125
# Total Time = 0.008713006973266602
# Finished facets for child 41 : 0.00876307487487793 with facet length = 6
#  face length 260 using OPTIMIZED facets
# Total normals took 9.608268737792969e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0011768341064453125
# Filtering edges by size finished: 0.009009361267089844
# Filtering by convexity and getting centers took: 0.013131856918334961
# Total Time = 0.024077415466308594
# Finished facets for child 42 : 0.024137020111083984 with facet length = 7
# Total time for facets: 61.9559428691864

# %%
"""
Rule: 
1) if mesh size is above a threshold --> run the unoptimized less careful version
2) if mesh is below that size --> run optimized more generous (but with all the filters )

"""
facet_time = time.time()
start_time = time.time()

length_threshold = 60000

if len(main_mesh.faces > length_threshold):
    print(f" face length {len(main_mesh.faces)} using unoptimized facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
    
else:
    print(f" face length {len(main_mesh.faces)} using OPTIMIZED facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets_optimized_with_checks(main_mesh)
    

print(f"Finished { len(main_mesh_facets)} facets for main mesh: {time.time() - start_time}")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    
    start_time = time.time()
    if len(main_mesh.faces > length_threshold):
        print(f" face length {len(gap_mesh.faces)} using unoptimized facets")
        child_meshes_facets.append(filter_final_facets(gap_mesh))
    else:
        print(f" face length {len(gap_mesh.faces)} using OPTIMIZED facets")
        child_meshes_facets.append(filter_final_facets_optimized_with_checks(gap_mesh))

    
    print(f"Finished facets for child {jj} : {time.time() - start_time} with facet length = {len(child_meshes_facets[jj][0])}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]

# %% [markdown]
# # Check that facet extraction for each piece worked

# %%
# download the facets and make sure they match
final_facets_mean_filtered

# download the facets list and see if the process worked:
index = 1
facets_group = np.zeros(len(child_meshes[index].faces)).astype(int)

for i,facet_group in enumerate(size_filtered_components):
    for face in facet_group:
        facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

np.savez("./test_meshes/" + "1_facet_piece_" + str(index) + ".npz",
         facets_group=facets_group,facets_group_centers=final_facets_centers)

from print_trimesh import print_trimesh
print_trimesh(child_meshes[index],"./test_meshes/piece_" + str(index) + ".off")


len(final_facets_mean_filtered)

# %%
# # download the facets list and see if the process worked:
# index = 2
# facets_group = np.zeros(len(child_meshes[index].faces)).astype(int)

# for i,facet_group in enumerate(child_meshes_facets[index][0]):
#     for face in facet_group:
#         facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

# np.savez("./test_meshes/" + file_name[:-4] + "_facet_piece_" + str(index) + ".npz",
#          facets_group=facets_group,
#         facets_group_centers=child_meshes_facets[index][1])

# from print_trimesh import print_trimesh
# print_trimesh(child_meshes[index],"./test_meshes/piece_" + str(index) + ".off")


# len(facets_group)

# %% [markdown]
# # START ITERATIVE PROCESS THAT CONNECTS THE MESHES

# %%
def apply_bbox_filter(child,min_bb_zone,max_bb_zone):
    """
    Determines if child is withing the bounding box zone
    designated by the bounding box corners
    
    """
    #get the min and max of the bounding box for the mesh
    min_bb = np.array(child.bounding_box.vertices).min(0)
    max_bb = np.array(child.bounding_box.vertices).max(0)
    
    #print(min_bb,max_bb)
    #print(min_bb_zone,max_bb_zone)
    
    #if fails any of these checks then return false, else return True
    if min(min_bb[0],max_bb[0])>max_bb_zone[0]:
        print("returning x greater max")
        return False
    
    if max(min_bb[0],max_bb[0])<min_bb_zone[0]:
        print("returning x less min")
        return False
    
    if min(min_bb[1],max_bb[1])>max_bb_zone[1]:
        print("returning y greater max")
        return False
    
    if max(min_bb[1],max_bb[1])<min_bb_zone[1]:
        print("returning y less min")
        return False
        
    if min(min_bb[2],max_bb[2])>max_bb_zone[2]:
        print("returning z greater max")
        return False
    
    if max(min_bb[2],max_bb[2])<min_bb_zone[2]:
        print("returning z less mim")
        return False
    return True

import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# restitching functions
import trimesh
import numpy as np
from collections import Counter
import time
import math

#gets the projection of point p onto line a
def ClosestPointOnLine(a, b, p):
    ap = p-a
    ab = b-a
    #base_vector = ab
    result = np.dot(ap,ab)/np.dot(ab,ab) # * ab
    return result




#now have the mesh and the facet faces, can send to function
def stitch_mesh_piece_vp3(new_mesh,facet_1,facet_2,
                          delete_facets=False,
                         return_added_mesh = False,
                         fix_normals = False):
    """
    Changed since last version: 
    1) parameter for deleting facets at end or not
    2) parameter for returning added mesh or not 
    3) Changed normals check to print statement and not exception
    
    
    """
    #how to find the normals of facet groups:
    facet_group_1_normal = new_mesh.face_normals[facet_1[0]]
    facet_group_2_normal = new_mesh.face_normals[facet_2[0]]


    #get the correct version of the normals: (might need to flip them if going in opposite direction)
    if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
        print("same direction normals")
        pass
    elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
        print("opposite direction normals")
        facet_group_2_normal = facet_group_2_normal*-1
    else:
        print("Not correct normals")
        #raise Exception("Not correct normals")

    #print(facet_group_1_normal,facet_group_2_normal)

    # make each row correspond to a single face 
    edges = new_mesh.edges_sorted.reshape((-1, 6))
    # get the edges for each facet
    edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
    edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                               for i in edges_facet])

    #the list of boundary edges and unique points in the boundary edges
    edge_0 = edges_boundary[0]
    edge_1 = edges_boundary[1]

    #gets the unique number of points
    edge_0_points = np.unique(np.hstack(edge_0))
    edge_1_points = np.unique(np.hstack(edge_1))
    print("Found boundary edges")
    """
    get the dot product of all the points
    """

    #get any 2 points on the triangle and make that the reference edge
    edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

    #gets the starting index for the 1st facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_0_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_0_starting_point = edge_0_points[max_index]

    #gets the starting index for the 2nd facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_1_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_1_starting_point = edge_1_points[max_index]

    print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
    #print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

    """
    Need to order the points for restitching

    Pseudocode: 
    1) Get starting piont
    2) Find the two edges corresponding to that point
    3) Need to decide which direction to start....
    - go in direction that make the cross of the (1st and last) point in the same direction of the 
    normal of the first facet
    4) loop through and record the orders of the vertices as you traverse along the edges 
    until you arrive back at the start
    5) Error if:
        a. You arrive back at the start and haven't processed all the edges
        b. Processsed all the edges but haven't arrived back at start

    6) Repeat steps 1 through 5 for 2nd facet group
    """
    start_point_list = [edge_0_starting_point,edge_1_starting_point]
    edge_list = [edge_0,edge_1]
    edge_order_list = []

    #loop that organizes the unique boundary points into the correct order
    for i,start_point in enumerate(start_point_list):
        print(f"Starting Organizing vertices for side {i}")
        #print(f"start_point = {start_point}")
        edge_order = [start_point]
        processed_edges = []

        #find the matching edges
        starting_edges_indices = np.where(np.logical_or(edge_list[i][:,0] == start_point,edge_list[i][:,1] == start_point) == True)[0]
        print(starting_edges_indices)
        starting_edges = edge_list[i][starting_edges_indices]
        #print(f"starting edges = {starting_edges}") #the list of the two possible edges

        if starting_edges.size < 4:
            raise Exception("Not enough edges for 1st facet start point")

        if starting_edges.size > 4:
            raise Exception("Too many edges for 1st facet start point") 

        #np.where(starting_edges[1,:] != start_point)[0][0]
        #gets the vectors that will be used for the cross product
        #print("np.where(starting_edges[0,:] != start_point)[0][0] = " + str(np.where(starting_edges[0,:] != start_point)[0][0]))
        #print("np.where(starting_edges[1,:] != start_point)[0][0] = " + str(np.where(starting_edges[1,:] != start_point)[0][0]))


        #gets the possible starting vectors
        possible_starting_vector_1 = new_mesh.vertices[starting_edges[0,:][np.where(starting_edges[0,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        possible_starting_vector_2 = new_mesh.vertices[starting_edges[1,:][np.where(starting_edges[1,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        

        #find the cross product of the starting vectors
        starting_edges_cross = np.cross(possible_starting_vector_1,possible_starting_vector_2)

        #make sure that the order of the vectors goes so that the cross product is in line with the starting normal
        #this ensures the the circular direction of the stitching will be the same
        if np.dot(starting_edges_cross,facet_group_1_normal) > 0:
            print("Edge 1 picked for direction")
            processed_edges.append(starting_edges_indices[0])
            current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]
        else:
            print("Edge 2 picked for direction")
            processed_edges.append(starting_edges_indices[1])
            #print("np.where(starting_edges[1,:] != start_point) = " + str(np.where(starting_edges[1,:] != start_point)))
            current_vertex = starting_edges[1][np.where(starting_edges[1,:] != start_point)[0][0]]

        #print(f"current_vertex = {current_vertex}" )
        #print("edge_list = " + str(edge_list))

        #now iterate through number of 
        for z in range(1,edge_list[i][:,0].size):
            #print("edge_order_temp = " + str(edge_order))
            if current_vertex == start_point:
                print("Start vertex reached before processed all of edges")
                
                """
                
                These should be ok because the extra loops are created from holes inside and this process should always get the outside loop
                
                
                """
                break

            #get the next edge
            counter = 0
            next_vertex = -1
            for j,edg in enumerate(edge_list[i]):
                #print("edg = " + str(edg))
                #print("processed_edges = " + str(processed_edges))
                if current_vertex in edg and j not in processed_edges:
                    current_edge_index = j
                    if edg[0] != current_vertex:
                        next_vertex = edg[0]
                    else:
                        next_vertex = edg[1]


                    counter += 1
                    if counter >= 2:
                        #raise Exception(f"More than 2 edges possibilities for {current_vertex}")
                        #Don't want to make it an exception anymore put just print out warning
                        print("More than 2 edges possibilities for {current_vertex}") # BAC change

            #make sure the next vertex was found
            if next_vertex <= -1:
                raise Exception(f"No next vertex was found for {current_vertex} ")

            #if found next vertex then add the old vertex and edge index
            #to the processed edges lists and the order of vertices
            processed_edges.append(current_edge_index)
            edge_order.append(current_vertex)

            current_vertex = next_vertex


        edge_order_list.append(edge_order)
        print(f"edge_{i}_order done, len = {len(edge_order)} ")#"= {edge_order}")

    lengths_of_boundaries = [len(x) for x in edge_order_list]
    bigger = lengths_of_boundaries.index(max(lengths_of_boundaries))
    smaller = 1-bigger

    #print(f"index of bigger facets = {bigger}\nindex of smaller facets = {smaller}",)

    #calculates the number of vertices will be stitched to each vertices on smaller side
    dividend = int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])
    remainder = lengths_of_boundaries[bigger] - int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])*lengths_of_boundaries[smaller]

    print(f"dividend = {dividend}, remainder = {remainder}")

    #loop that adds the new faces
    print("About to add faces")
    start_time = time.time()
    new_faces = []
    current_bigger = 0
    for i,current_smaller in enumerate(edge_order_list[smaller]):
        #print("current_smaller =" + str(current_smaller))
        #print("current_bigger=" + str(current_bigger))
        if i == 0:
            new_faces.append([current_smaller,edge_order_list[smaller][-1],edge_order_list[bigger][current_bigger]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])

        for j in range(0,dividend + int(i<remainder)):
            if current_bigger > len(edge_order_list[bigger]):
                raise Exception("Somehow rapped around too much")

            if current_bigger >= len(edge_order_list[bigger])-1:
                next_bigger = 0
            else:
                next_bigger = current_bigger+1

            new_faces.append([current_smaller,edge_order_list[bigger][current_bigger],
                                edge_order_list[bigger][next_bigger]])

            current_bigger += 1

    #print("new_faces = " + str(new_faces))
    print(f"Finished adding faces: {time.time() - start_time}")
    

    print("Starting creating stitch mesh")
    start_time = time.time()
    stitch_mesh = trimesh.Trimesh()

    stitch_mesh.vertices = new_mesh.vertices
    stitch_mesh.faces = np.vstack([new_mesh.faces, new_faces])
    print(f"Finished creating stitch mesh: {time.time() - start_time}")
    



    if delete_facets == True:
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(stitch_mesh.faces)-1,len(stitch_mesh.faces)).astype("int")
        facet_faces = np.hstack([facet_1 ,facet_2])
        faces_to_keep = set(total_faces).difference(set(facet_faces))
        faces_to_keep

        stitch_mesh = stitch_mesh.submesh([list(faces_to_keep)])[0]

    if fix_normals == True:
        trimesh.repair.fix_inversion(stitch_mesh)
        trimesh.repair.fix_winding(stitch_mesh)
        trimesh.repair.fix_normals(stitch_mesh)
    
    #print("Finished stitching")

    if return_added_mesh == True:
        added_mesh = trimesh.Trimesh()
        added_mesh.vertices = new_mesh.vertices
        added_mesh.faces = new_faces
        trimesh.repair.fix_inversion(added_mesh)
        trimesh.repair.fix_winding(added_mesh)
        trimesh.repair.fix_normals(added_mesh)

        return stitch_mesh,added_mesh
    
    else:
        return stitch_mesh

# %%
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh_saved = main_mesh.copy()
main_mesh_facets_centers_saved = main_mesh_facets_centers.copy()
main_mesh_facets_saved = main_mesh_facets.copy()

# %%
"""

Pseudocode for loop at the end that will keep everything going:
1) When process a child, will add that index to a list
2) Have no_new_children_processed counter set at end of loop 
    if no children were added to main mesh
    --> this will prompt the expansion of the initial parameters
3) If this gets too high



Things that still need to add:
1) Better way of making sure that the normals are good
- Can sample one of the neighboring points and flip normals if the dot product is negative


Change list: 
1) Reduced the stitch distance
2) Added the copy features that allows this cell to be rerun without rerunning whole notebook
3) added the new tie_breaker for childs that want to connect to same parent is just the one with closest facet
    Uses the added feature of child_meshes_stitch_distances that is saved along the way
4) Iterates through the repeated faces instead of just doing so once which was incorrect before
5) Fixed bug that was adding to current_main_mesh but then was using main mesh also in the loop
6) Made changes to the stitching mechanism that not error if find a vertices with more than 2 edges
--> because did observe some facets with cut out faces along the boundary
7) Changed the consider_same_direction normal as False 
8) Changed the max index error that was used for finding the starting point in stitch meshes

"""

#load our main mesh stuff from the copies
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh = main_mesh_saved.copy()
main_mesh_facets_centers = main_mesh_facets_centers_saved.copy()
main_mesh_facets = main_mesh_facets_saved.copy()



#sets 
initial_parameters = dict(bounding_box_threshold=4000,
                         stitch_distance_threshold=2000,
                         size_ratio_threshold=0.15,
                         normal_closeness= 0.95)

bounding_box_threshold = initial_parameters["bounding_box_threshold"]
stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]
size_ratio_threshold = initial_parameters["size_ratio_threshold"]
normal_closeness=initial_parameters["normal_closeness"]

no_new_children_multiplier = 0
bbox_expansion_percentage = 0.10
stitch_expansion_percentage = 1
size_ratio_expansion_percentage = 0.10

no_new_children_limit = 4

consider_same_direction_normals = False
children_processed = []

while len(children_processed) < len(child_meshes):
    stitch_loop_time = time.time()
    if no_new_children_multiplier >= no_new_children_limit:
        print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
        
    
    #update the thresholds
    bounding_box_threshold = initial_parameters["bounding_box_threshold"]*(1 + bbox_expansion_percentage*no_new_children_multiplier)
    stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]*(1 + stitch_expansion_percentage*no_new_children_multiplier)
    #reduces the 
    size_ratio_threshold = initial_parameters["size_ratio_threshold"]*(1 - size_ratio_expansion_percentage*no_new_children_multiplier)
    
    #print thresholds
#     print(f"bounding_box_threshold = {bounding_box_threshold}")
#     print(f"stitch_distance_threshold = {stitch_distance_threshold}" )
#     print(f"size_ratio_threshold = {size_ratio_threshold}")

    #get the main mesh facets normals
    main_mesh_normals = [main_mesh.face_normals[fac[0]] for fac in main_mesh_facets]
    hit_indexes_list= []
    
    
    #dictionary to save the stitch points
    child_meshes_stitch_facets = dict()
    child_meshes_stitch_face_ratios = dict()
    child_meshes_stitch_distances = dict()
    for i,child in enumerate(child_meshes):
        
        if i in children_processed:
            #print(f"Child {i} already processed")
            continue
        
        print(f"Starting Child {i}")

        #initialize the stitch index
        #child_meshes_stitch_facets[i] = [-1,-1]

        #two highest points for the bounding box
        min_bb = np.array(main_mesh.bounding_box.vertices).min(0)
        max_bb = np.array(main_mesh.bounding_box.vertices).max(0)

        min_bb_zone = min_bb - bounding_box_threshold
        max_bb_zone = max_bb + bounding_box_threshold



        #then send mesh to function that decides if with
        pass_bbox_filter = apply_bbox_filter(child,min_bb_zone,max_bb_zone)

        if not pass_bbox_filter:
            print("skipped by bounding box filter")
            continue

        #### used for validation to make sure that bounding box was correctly filtering
    #     #add the following to main mesh just to visualize
    #     final_mesh = final_mesh + child
    #     print("just added")

        #
        """

        Do pairwise calculation of distances between centers of facets on child piece and main piece
            Filter the pairs for stitch distance threshold
            Filter the pairs for matching or opposite normals
            Filter for those that are reasonable in size matching (within 50% of each other)

        If there are still ties after this point then pitch the best matching size

        If None remaining then keep going (might loosen up the parameters later), BUT WITH GLOBAL CHECK SO DOESN’T KEEP ITERATING


        """
 
        """ OLD WAY OF COMPUTING PAIRWISE ***************************************************************
        
        child_facets,child_facets_centers = child_meshes_facets[i]

        facet_distances = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))
        facet_normals = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))

        start_time = time.time()
        #do the pairwise comparison
        for cc,child_center in enumerate(child_facets_centers):

            #get the normal of the child
            child_normal = child.face_normals[child_facets[cc][0]]
            for mm, main_center in enumerate(main_mesh_facets_centers):
                #get the euclidean distance
    #             facet_distances[cc,mm] = math.sqrt((child_center[0] - main_center[0])**2 + 
    #                                                  (child_center[1] - main_center[1])**2 + 
    #                                                  (child_center[2] - main_center[2])**2 )



                facet_distances[cc,mm] = np.linalg.norm(np.array(child_center) - np.array(main_center))

                main_normal = main_mesh_normals[mm]
    #             print("main_normal = " + str(main_normal))
    #             print("child_normal = " + str(child_normal))
                #get whether the normals are line up (or possibly opposite)
                normals_dot = np.dot(child_normal,main_normal)
                #print(normals_dot)
                if consider_same_direction_normals == True:
                    facet_normals[cc,mm] =  normals_dot < -0.95  or normals_dot > 0.95
                else:
                    facet_normals[cc,mm] =  normals_dot < -0.95 # or normals_dot > 0.95


        
        print(f"Total pairwise : {time.time() - start_time}")

    #     if i == 1:
    #         4,12
    #         print("4,12 facet distance = " + str(facet_distances[4,12]))

        #apply the filters
        #stitch_distance_booleans = facet_distances < stitch_distance_threshold

        
        #how to debug certain faces that have been filtered
#         main_facet_bebug = 124
#         piece_facet_debug = 11
        
#         if i == 2 and (0 in children_processed):
#             print("**********" + str(facet_normals[piece_facet_debug,main_facet_bebug]) + "**********")
#             print("**********" + str((facet_distances < stitch_distance_threshold)[piece_facet_debug,main_facet_bebug]) + "**********")
        
        
        #get the indexes that make it through the first two filters
        hit_indexes = np.where(np.logical_and(facet_distances < stitch_distance_threshold,facet_normals)== True) 

        possible_stitch_pairs = np.vstack(hit_indexes).T
        
        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        
        face_0_unique_facets = np.unique(hit_indexes[0])
        face_1_unique_facets = np.unique(hit_indexes[1])
        
        if len(hit_indexes[0]) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(hit_indexes[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

            

         *************************************************************** """
        
        """  NEW WAY OF COMPUTING THE PAIRWISE CALCULATIONS  *************************************************************** """
        
        child_facets,child_facets_centers = child_meshes_facets[i]
        pairs_start_time = time.time()

        
        if len(child_facets_centers) == 0:
            print("child_facets_centers for child {i} was 0, so skipping")
            continue
        
        start_time = time.time()
        a_New = np.array(child_facets_centers).astype("float")
        b_New = np.array(main_mesh_facets_centers).astype("float")

        print(len(a_New),len(b_New))
#         print("starting distance matrix")
        start_time = time.time()
        from scipy.spatial import distance_matrix
        a_b_distance = distance_matrix(a_New, b_New)
        
        #print(f"Time = {time.time() - start_time}")

        #now get the indexes that are within stitch distance

#         print("min(a_b_distance) = " + str(np.amin(a_b_distance.shape)))
        indexes_not = np.where(a_b_distance < stitch_distance_threshold)
        print(f"Done distance matrix: {time.time() - start_time}")
        
        
#         print("(indexes_not) = " + str((indexes_not)))
#         print("starting normals")
        start_time = time.time()

#         #old way to do it
#         child_normals = child.face_normals[indexes_not[0]]
#         main_normals = main_mesh.face_normals[indexes_not[1]]

        if not indexes_not[0].any():
            print(f"Child {i} There were no points close enough")
            continue

        #old way to do it
#         print(indexes_not[0])
#         print(child_facets[indexes_not[0]])
 
        
        child_normals = child.face_normals[[p[0] for p in child_facets[indexes_not[0]]]]
        main_normals = main_mesh.face_normals[[p[0] for p in main_mesh_facets[indexes_not[1]]]]
                                           
                                           
                                           
#         print(child_facets[indexes_not[0]][0])
#         print('child_normals = ' + str(child_normals))
#         print(main_mesh_facets[indexes_not[1]][0])
#         print('main_normals = ' + str(main_normals))
        #start_time = time.time()
        #dot_products = np.dot(child_normals,main_normals.T)
        
        total_normal_dots = np.sum(child_normals*main_normals,axis=1)
#         print("total_normal_dots = " + str(total_normal_dots))
        total_normal_dots_facet_mask = total_normal_dots < -normal_closeness
        
#         print(f"Done Normals generation: {time.time() - start_time}")
#         print("starting pair generation")
        
        
        start_time = time.time()
        final_pairs = (np.array(indexes_not).T)[total_normal_dots_facet_mask]
        #print(final_pairs)
        
        
        #get the sizes of all the unique ones
        face_0_unique_facets = np.unique(final_pairs[:,0])
        face_1_unique_facets = np.unique(final_pairs[:,1])
        print("final_pairs = " + str(final_pairs))
#         print("face_0_unique_facets = " + str(face_0_unique_facets))
#         print("face_1_unique_facets = " + str(face_1_unique_facets))
        
        
        if len(final_pairs) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(final_pairs[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

        
        possible_stitch_pairs = final_pairs
        print(f"Done Generating final pairs: {time.time() - pairs_start_time}")
        
        
        """  NEW WAY OF COMPUTING THE PAIRWISE  *************************************************************** """
        




    #     print("possible_stitch_pairs = " + str(possible_stitch_pairs))
    #     print("len(hit_indexes) = " + str(len(hit_indexes)))
    #     print("hit_indexes[0].any() = " + str(hit_indexes[0].any()))
    #     print("hit_indexes = " + str(hit_indexes))
    #     print("hit_indexes[0] = " + str(hit_indexes[0]))
    #     print("len(hit_indexes[0]) = " + str(len(hit_indexes[0])))

        #find the sizes of all of them
        face_pair_sizes = np.zeros(len(possible_stitch_pairs[:,0]))
        face_size_ratios = np.zeros(len(possible_stitch_pairs[:,0]))

        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        for numba,pair in enumerate(possible_stitch_pairs):
            #print("pair = " + str(pair))
            sizes = [face_0_facet_sizes[pair[0]],face_1_facet_sizes[pair[1]]]
            min_area = min(sizes)
            max_area = max(sizes)

            ratio = min_area/max_area

            #print(f"ratio = {ratio}")
            #print(f"Total size  = {min_area + max_area}")
            if ratio >= size_ratio_threshold:
                face_pair_sizes[numba] = min_area + max_area
                face_size_ratios[numba] = ratio
            
                #print(f"face_pair_sizes[numba] = {face_pair_sizes[numba]}, face_size_ratios[numba] = {face_size_ratios[numba]}")


        #check that made it past stitch ratio threshold

        #best possible stitch pair is just the maximum sized matching ones
        best_index = np.where(face_pair_sizes == max(face_pair_sizes))
        best_stitch_pair = possible_stitch_pairs[best_index][0]
        best_stitch_pair_size = face_pair_sizes[best_index][0]
        best_stitch_pair_size_ratio = face_size_ratios[best_index][0]
        
        #get the distance of the best_stitch_pair
        best_stitch_pair_distance = a_b_distance[possible_stitch_pairs[best_index][0][0],
                                                   possible_stitch_pairs[best_index][0][1]]
        
        print("best_stitch_pair = " + str(best_stitch_pair))
        print("best_stitch_pair_size = " + str(best_stitch_pair_size))
        print("best_stitch_pair_distance = " + str(best_stitch_pair_distance))
        print("best_stitch_pair_size_ratio = " + str(best_stitch_pair_size_ratio))

        child_meshes_stitch_facets[i] = [best_stitch_pair[0],best_stitch_pair[1]]
        child_meshes_stitch_face_ratios[i] = best_stitch_pair_size_ratio
        child_meshes_stitch_distances[i] = best_stitch_pair_distance
        
#         if i == 1:
#             print("Just processed piece 1")
#             raise Exception("stoping")

    
#     if 1 in child_meshes_stitch_facets.keys():
#         print("Just processed piece 1")
#         raise Exception("stoping")
    
    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
        
    # makes sure that no two child branches try to connect to the same main branch
    from collections import Counter
    mesh_stitch_counter = Counter(np.array([val for val in child_meshes_stitch_facets.values()])[:,1])

    repeat_main_facets = [key for key,val in mesh_stitch_counter.items() if (key != -1 and val > 1)] #gets the main mesh facet with multiples
    print("repeat_main_facets = " + str(repeat_main_facets))


    #how to fix that some faces are trying to branch to same main facet
    #make it iterate through all of the repeats
    if len(repeat_main_facets)>0:
        for repeat_main in repeat_main_facets:
            child_mesh_double_indexes = [key for key,val in child_meshes_stitch_facets.items() if val[1] == repeat_main]
            print("child_mesh_double_indexes = " + str(child_mesh_double_indexes))


            #decide which one to keep and then ditch all the rest --> pick the CLOSEST ONE, and not the best matching area:

            ###### picks the closest area
            min_distance = 10000000000
            min_child = -1


            for child_index in child_mesh_double_indexes:
                current_distance = child_meshes_stitch_distances[child_index]

                if current_distance < min_distance:
                    min_child = child_index
                    min_distance = current_distance

            print(f"min_child = {min_child}, max_ratio = {min_distance}")

    #         ###### picks the maximum area
    #         max_ratio = -1
    #         max_child = -1


    #         for child_index in child_mesh_double_indexes:
    #             current_ratio = child_meshes_stitch_face_ratios[child_index]

    #             if current_ratio > max_ratio:
    #                 max_child = child_index
    #                 max_ratio = current_ratio

    #         print(f"max_child = {max_child}, max_ratio = {max_ratio}")



            #remove the others from the stitch facets
            for double_index in child_mesh_double_indexes:
                if double_index != min_child:
                    del child_meshes_stitch_facets[double_index]
    
    """
    Pseudocode for stitching:
    1) For each pair in the child_meshes_stitch_facets:
    a. Get the child mesh for that pair
    b. Get the list of faces for the child facet (from the facet number)
    c. Get the list of faces for the main facet (from the main number)

    d. Get the original number of faces and vertices in the main mesh
    d2. Use the orignal number of faces and add to list of faces for child facet to offset them correctly
        - Save this number list in a dictionary (to use for later and creating the submesh)
    e. Add the two meshes together to get big mesh
    f. Send the two meshes and the two facet lists to the restitching function to get a main mesh that is stitched up
     - but send it to function that doesnt delete the original facet faces 
         (because this would remove meshes from original and screw up facet number)
    g. reassign the main_mesh to this newly stitched up mesh
    h. recompute the facets for the main mesh



    """
    
    #lists to store the faces that need to be removed later
    child_faces_to_remove = []
    main_faces_to_remove = []
    current_main_mesh = main_mesh.copy()

    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
    else: #if there were stitch points found
        print("child_meshes_stitch_facets = " + str(child_meshes_stitch_facets))
        for child_key,pair in child_meshes_stitch_facets.items():
            stitch_time = time.time()
            print(f"---Stitching child {child_key} with pair: {pair}---")
            current_child_mesh = child_meshes[child_key]
            current_child_facet_faces = child_meshes_facets[child_key][0][pair[0]]


            current_main_mesh_facet_faces = main_mesh_facets[pair[1]]

            #Get the original number of faces and vertices in the main mesh
            original_mesh_faces_len = len(current_main_mesh.faces)
            current_child_facet_faces_adjusted = [k + original_mesh_faces_len 
                                                              for k in current_child_facet_faces]

            #Save the faces number for deletion later
            child_faces_to_remove += current_child_facet_faces_adjusted
            main_faces_to_remove += current_main_mesh_facet_faces

            combined_mesh = current_main_mesh + current_child_mesh

            #how to stitch up the mesh
            start_time = time.time()
            current_main_mesh = stitch_mesh_piece_vp3(new_mesh=combined_mesh,
                                                           facet_1=current_main_mesh_facet_faces,
                                                           facet_2=current_child_facet_faces_adjusted,
                                                          delete_facets=False,
                                                          return_added_mesh=False,
                                                           fix_normals = False)
            
            print(f"returned from stitch mesh: {time.time() - start_time}")
            
            #add the child to processed child
            children_processed.append(child_key)
            print(f"Finished stitching child {child_key} : {time.time() - stitch_time}")

        #remove all of the processed facets from the main mesh
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(current_main_mesh.faces)-1,len(current_main_mesh.faces)).astype("int")
        facet_faces = np.hstack([child_faces_to_remove ,main_faces_to_remove])
        faces_to_keep = set(total_faces).difference(set(facet_faces))


        main_mesh = current_main_mesh.submesh([list(faces_to_keep)])[0]


        #reset the no_new_children_multiplier because there were successful stitching
        no_new_children_multiplier = 0
        #recompute the main mesh facets
        main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
        print(f"***************Finished big stitching iteration: {time.time() - stitch_loop_time}***************")
        
#         if 0 in children_processed and 1 in children_processed:
#             print("Exiting before does piece 2")
#             break

        if len(np.unique(children_processed)) == len(child_meshes):
            print("All children have been processed")
            break
# Out:
# Starting Child 0
# 863 13547
# Done distance matrix: 0.37883424758911133
# Child 0 There were no points close enough
# Starting Child 1
# 644 13547
# Done distance matrix: 0.27570271492004395
# final_pairs = [[ 260 2528]
#  [ 296 2528]
#  [ 297 2528]
#  [ 301 8655]
#  [ 314 8655]]
# Done Generating final pairs: 0.2863149642944336
# best_stitch_pair = [ 297 2528]
# best_stitch_pair_size = 126407.37080777145
# best_stitch_pair_distance = 322.83217480906654
# best_stitch_pair_size_ratio = 0.4329072487180667
# Starting Child 2
# 485 13547
# Done distance matrix: 0.20781517028808594
# final_pairs = [[   11  8603]
#  [   11  8607]
#  [   11  8610]
#  [   11  8613]
#  [   11  8614]
#  [   11  9753]
#  [   11  9757]
#  [   11 10067]
#  [   11 10068]
#  [   13  9754]
#  [   53  8603]
#  [   53  8607]
#  [   53  8610]
#  [   53  8613]
#  [   53  8614]
#  [   53  9753]
#  [   53  9757]
#  [   53 10067]
#  [   53 10068]
#  [  464  9755]
#  [  471  8603]
#  [  471  8607]
#  [  471  8610]
#  [  471  8613]
#  [  471  8614]
#  [  471  9753]
#  [  471  9757]
#  [  471 10067]
#  [  471 10068]]
# Done Generating final pairs: 0.2837564945220947
# best_stitch_pair = [  11 8607]
# best_stitch_pair_size = 3722036.954014628
# best_stitch_pair_distance = 134.73286075380463
# best_stitch_pair_size_ratio = 0.936193249947911
# Starting Child 3
# 887 13547
# Done distance matrix: 0.37334465980529785
# Child 3 There were no points close enough
# Starting Child 4
# 521 13547
# Done distance matrix: 0.22432303428649902
# final_pairs = [[   2 7161]
#  [   5 7161]]
# Done Generating final pairs: 0.2371985912322998
# best_stitch_pair = [   2 7161]
# best_stitch_pair_size = 446458.5834444849
# best_stitch_pair_distance = 1948.800612497353
# best_stitch_pair_size_ratio = 0.6707399165863215
# Starting Child 5
# 203 13547
# Done distance matrix: 0.08118295669555664
# final_pairs = [[ 153 9789]]
# Done Generating final pairs: 0.08980441093444824
# best_stitch_pair = [ 153 9789]
# best_stitch_pair_size = 77932.54022281384
# best_stitch_pair_distance = 1638.676906538496
# best_stitch_pair_size_ratio = 0.5248528754952313
# Starting Child 6
# 567 13547
# Done distance matrix: 0.23796772956848145
# Child 6 There were no points close enough
# Starting Child 7
# 212 13547
# Done distance matrix: 0.08592772483825684
# Child 7 There were no points close enough
# Starting Child 8
# 170 13547
# Done distance matrix: 0.0742487907409668
# Child 8 There were no points close enough
# Starting Child 9
# 460 13547
# Done distance matrix: 0.19560956954956055
# final_pairs = [[   40 13059]
#  [   44  8098]
#  [   44  8101]
#  [   44 13059]
#  [   64  4947]
#  [   64  8098]
#  [   64  8101]
#  [   64 13058]
#  [   64 13059]
#  [   64 13066]
#  [   67  4923]
#  [   67  4924]
#  [   67  4931]
#  [   67  4934]
#  [   67  4935]
#  [   67  4944]
#  [   67  4948]
#  [   67 13057]
#  [   67 13060]
#  [   67 13065]
#  [   67 13067]
#  [   67 13068]
#  [   67 13089]
#  [   67 13091]
#  [   67 13100]
#  [   67 13101]
#  [   69 13061]
#  [   81 13059]
#  [   89 13059]
#  [   93 13059]
#  [   99 13061]
#  [  102  4945]
#  [  138 13056]
#  [  141 13056]]
# Done Generating final pairs: 0.38212108612060547
# best_stitch_pair = [   89 13059]
# best_stitch_pair_size = 104565.14624507955
# best_stitch_pair_distance = 1913.659841069676
# best_stitch_pair_size_ratio = 0.7961305933314071
# Starting Child 10
# 130 13547
# Done distance matrix: 0.05272197723388672
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 13547
# Done distance matrix: 0.11710000038146973
# Child 11 There were no points close enough
# Starting Child 12
# 191 13547
# Done distance matrix: 0.08045792579650879
# Child 12 There were no points close enough
# Starting Child 13
# 185 13547
# Done distance matrix: 0.07127046585083008
# Child 13 There were no points close enough
# Starting Child 14
# 187 13547
# Done distance matrix: 0.07105135917663574
# Child 14 There were no points close enough
# Starting Child 15
# 470 13547
# Done distance matrix: 0.20529723167419434
# Child 15 There were no points close enough
# Starting Child 16
# 261 13547
# Done distance matrix: 0.1095740795135498
# Child 16 There were no points close enough
# Starting Child 17
# 10 13547
# Done distance matrix: 0.0046498775482177734
# Child 17 There were no points close enough
# Starting Child 18
# 16 13547
# Done distance matrix: 0.007241487503051758
# Child 18 There were no points close enough
# Starting Child 19
# 4 13547
# Done distance matrix: 0.0020728111267089844
# Child 19 There were no points close enough
# Starting Child 20
# 16 13547
# Done distance matrix: 0.006550312042236328
# final_pairs = [[   0  962]
#  [   1  942]
#  [   1  943]
#  [   1 4460]
#  [   3 4460]
#  [   4  962]
#  [   5  962]
#  [  11 4463]
#  [  13 4463]]
# Done Generating final pairs: 0.017165184020996094
# best_stitch_pair = [  1 942]
# best_stitch_pair_size = 197046.001939911
# best_stitch_pair_distance = 1611.825160400705
# best_stitch_pair_size_ratio = 0.19808558642766733
# Starting Child 21
# 14 13547
# Done distance matrix: 0.00658726692199707
# Child 21 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 13547
# Done distance matrix: 0.025554656982421875
# Child 23 There were no points close enough
# Starting Child 24
# 8 13547
# Done distance matrix: 0.004155397415161133
# final_pairs = [[   2 9789]]
# Done Generating final pairs: 0.010771751403808594
# best_stitch_pair = [   2 9789]
# best_stitch_pair_size = 75520.57459223573
# best_stitch_pair_distance = 170.50810536391745
# best_stitch_pair_size_ratio = 0.47765958862343944
# Starting Child 25
# 56 13547
# Done distance matrix: 0.021931886672973633
# Child 25 There were no points close enough
# Starting Child 26
# 5 13547
# Done distance matrix: 0.0023124217987060547
# Child 26 There were no points close enough
# Starting Child 27
# 3 13547
# Done distance matrix: 0.0015981197357177734
# Child 27 There were no points close enough
# Starting Child 28
# 124 13547
# Done distance matrix: 0.06275534629821777
# Child 28 There were no points close enough
# Starting Child 29
# 184 13547
# Done distance matrix: 0.07236456871032715
# final_pairs = [[ 122 2784]
#  [ 125 2770]
#  [ 182 2770]]
# Done Generating final pairs: 0.08231163024902344
# best_stitch_pair = [ 122 2784]
# best_stitch_pair_size = 44775.11831009884
# best_stitch_pair_distance = 446.8338762966404
# best_stitch_pair_size_ratio = 0.36436845554798764
# Starting Child 30
# 34 13547
# Done distance matrix: 0.013843059539794922
# final_pairs = [[   9 2309]]
# Done Generating final pairs: 0.022502899169921875
# best_stitch_pair = [   9 2309]
# best_stitch_pair_size = 60300.9092027488
# best_stitch_pair_distance = 182.8628502143914
# best_stitch_pair_size_ratio = 0.1512208524128488
# Starting Child 31
# 53 13547
# Done distance matrix: 0.021282672882080078
# final_pairs = [[ 29 812]]
# Done Generating final pairs: 0.03223586082458496
# best_stitch_pair = [ 29 812]
# best_stitch_pair_size = 520628.1589685889
# best_stitch_pair_distance = 1851.0419016672158
# best_stitch_pair_size_ratio = 0.6886184811173013
# Starting Child 32
# 27 13547
# Done distance matrix: 0.01118922233581543
# final_pairs = [[  2 812]
#  [  3 812]
#  [ 17 827]
#  [ 19 812]
#  [ 25 812]
#  [ 26 812]]
# Done Generating final pairs: 0.021833181381225586
# best_stitch_pair = [  2 812]
# best_stitch_pair_size = 676419.9238749678
# best_stitch_pair_distance = 200.96274019074056
# best_stitch_pair_size_ratio = 0.45746294362954565
# Starting Child 33
# 28 13547
# Done distance matrix: 0.011366128921508789
# final_pairs = [[  0 812]
#  [  2 812]
#  [  5 811]
#  [ 19 812]]
# Done Generating final pairs: 0.02400064468383789
# best_stitch_pair = [  0 812]
# best_stitch_pair_size = 557644.3187814185
# best_stitch_pair_distance = 1210.7507345982985
# best_stitch_pair_size_ratio = 0.6148054629726685
# Starting Child 34
# 63 13547
# Done distance matrix: 0.025548219680786133
# Child 34 There were no points close enough
# Starting Child 35
# 18 13547
# Done distance matrix: 0.01012277603149414
# Child 35 There were no points close enough
# Starting Child 36
# 5 13547
# Done distance matrix: 0.0022737979888916016
# Child 36 There were no points close enough
# Starting Child 37
# 37 13547
# Done distance matrix: 0.015437602996826172
# final_pairs = [[   2 7161]
#  [   3 7160]
#  [   7 7161]
#  [  18 7161]
#  [  33 7160]]
# Done Generating final pairs: 0.02951335906982422
# best_stitch_pair = [   7 7161]
# best_stitch_pair_size = 518370.9220367422
# best_stitch_pair_distance = 1505.551709646238
# best_stitch_pair_size_ratio = 0.5285117192004759
# Starting Child 38
# 10 13547
# Done distance matrix: 0.0046575069427490234
# Child 38 There were no points close enough
# Starting Child 39
# 17 13547
# Done distance matrix: 0.007803916931152344
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 13547
# Done distance matrix: 0.0019674301147460938
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 13547
# Done distance matrix: 0.002786874771118164
# final_pairs = [[    3  1478]
#  [    4 13063]]
# Done Generating final pairs: 0.009139537811279297
# best_stitch_pair = [    4 13063]
# best_stitch_pair_size = 25585.373303641238
# best_stitch_pair_distance = 1936.4671665837875
# best_stitch_pair_size_ratio = 0.36964275258335866
# Starting Child 42
# 7 13547
# Done distance matrix: 0.0032339096069335938
# final_pairs = [[   0 7161]
#  [   6 7161]]
# Done Generating final pairs: 0.01264500617980957
# best_stitch_pair = [   6 7161]
# best_stitch_pair_size = 360632.16416292306
# best_stitch_pair_distance = 183.46491980517186
# best_stitch_pair_size_ratio = 0.9880970540178713
# repeat_main_facets = [7161, 9789, 812]
# child_mesh_double_indexes = [4, 37, 42]
# min_child = 42, max_ratio = 183.46491980517186
# child_mesh_double_indexes = [5, 24]
# min_child = 24, max_ratio = 170.50810536391745
# child_mesh_double_indexes = [31, 32, 33]
# min_child = 32, max_ratio = 200.96274019074056
# child_meshes_stitch_facets = {1: [297, 2528], 2: [11, 8607], 9: [89, 13059], 20: [1, 942], 24: [2, 9789], 29: [122, 2784], 30: [9, 2309], 32: [2, 812], 41: [4, 13063], 42: [6, 7161]}
# ---Stitching child 1 with pair: [297, 2528]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 82661, starting edge 2nd facet= 928098,
# Starting Organizing vertices for side 0
# [0 3]
# Edge 1 picked for direction
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# [1 7]
# Edge 2 picked for direction
# edge_1_order done, len = 9
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02693319320678711
# returned from stitch mesh: 0.8425960540771484
# Finished stitching child 1 : 0.9823839664459229
# ---Stitching child 2 with pair: [11, 8607]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 28330, starting edge 2nd facet= 935417,
# Starting Organizing vertices for side 0
# [ 0 10]
# Edge 2 picked for direction
# Start vertex reached before processed all of edges
# edge_0_order done, len = 48
# Starting Organizing vertices for side 1
# [ 1 23]
# Edge 1 picked for direction
# edge_1_order done, len = 42
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 6.365776062011719e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026662588119506836
# returned from stitch mesh: 0.8643476963043213
# Finished stitching child 2 : 1.019237995147705
# ---Stitching child 9 with pair: [89, 13059]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 756198, starting edge 2nd facet= 954634,
# Starting Organizing vertices for side 0
# [5 6]
# Edge 1 picked for direction
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# [0 3]
# Edge 2 picked for direction
# edge_1_order done, len = 6
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02707982063293457
# returned from stitch mesh: 0.8522005081176758
# Finished stitching child 9 : 1.008035659790039
# ---Stitching child 20 with pair: [1, 942]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 237180, starting edge 2nd facet= 960260,
# Starting Organizing vertices for side 0
# [1 2]
# Edge 1 picked for direction
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# [4 5]
# Edge 2 picked for direction
# edge_1_order done, len = 13
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027721405029296875
# returned from stitch mesh: 0.8553459644317627
# Finished stitching child 20 : 1.0088346004486084
# ---Stitching child 24 with pair: [2, 9789]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 837126, starting edge 2nd facet= 960413,
# Starting Organizing vertices for side 0
# [6 7]
# Edge 2 picked for direction
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# [1 2]
# Edge 1 picked for direction
# edge_1_order done, len = 5
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.1444091796875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0263671875
# returned from stitch mesh: 0.8366448879241943
# Finished stitching child 24 : 0.9985349178314209
# ---Stitching child 29 with pair: [122, 2784]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 421339, starting edge 2nd facet= 961841,
# Starting Organizing vertices for side 0
# [0 2]
# Edge 1 picked for direction
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# [0 1]
# Edge 1 picked for direction
# edge_1_order done, len = 7
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.1205673217773438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027027130126953125
# returned from stitch mesh: 0.8194901943206787
# Finished stitching child 29 : 0.9688007831573486
# ---Stitching child 30 with pair: [9, 2309]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 831453, starting edge 2nd facet= 963782,
# Starting Organizing vertices for side 0
# [2 3]
# Edge 1 picked for direction
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# [0 2]
# Edge 1 picked for direction
# edge_1_order done, len = 4
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.0251998901367188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02717304229736328
# returned from stitch mesh: 0.8180060386657715
# Finished stitching child 30 : 0.9715883731842041
# ---Stitching child 32 with pair: [2, 812]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 94575, starting edge 2nd facet= 963986,
# Starting Organizing vertices for side 0
# [0 7]
# Edge 2 picked for direction
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# [0 2]
# Edge 1 picked for direction
# edge_1_order done, len = 17
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.21341657638549805
# returned from stitch mesh: 1.0049638748168945
# Finished stitching child 32 : 1.1587486267089844
# ---Stitching child 41 with pair: [4, 13063]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 659292, starting edge 2nd facet= 964352,
# Starting Organizing vertices for side 0
# [0 3]
# Edge 2 picked for direction
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# [0 2]
# Edge 2 picked for direction
# edge_1_order done, len = 4
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03815174102783203
# returned from stitch mesh: 0.8640491962432861
# Finished stitching child 41 : 0.9425201416015625
# ---Stitching child 42 with pair: [6, 7161]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 730182, starting edge 2nd facet= 964438,
# Starting Organizing vertices for side 0
# [6 7]
# Edge 1 picked for direction
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# [0 3]
# Edge 2 picked for direction
# edge_1_order done, len = 12
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.71661376953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027644872665405273
# returned from stitch mesh: 0.9266543388366699
# Finished stitching child 42 : 1.111501932144165
# Total Facet building time: 6.2368011474609375
# ***************Finished big stitching iteration: 66.83479833602905***************
# Starting Child 0
# 863 14047
# Done distance matrix: 0.3722951412200928
# final_pairs = [[  238 13687]
#  [  242 13706]
#  [  242 13713]
#  [  376 13682]
#  [  376 13686]
#  [  376 13688]
#  [  376 13689]
#  [  376 13690]
#  [  376 13707]
#  [  376 13712]
#  [  377 13682]
#  [  377 13686]
#  [  377 13688]
#  [  377 13689]
#  [  377 13690]
#  [  377 13707]
#  [  377 13712]
#  [  378 13711]
#  [  381 13711]
#  [  650 13682]
#  [  650 13686]
#  [  650 13688]
#  [  650 13689]
#  [  650 13690]
#  [  650 13707]
#  [  650 13712]
#  [  652 13682]
#  [  652 13686]
#  [  652 13688]
#  [  652 13689]
#  [  652 13690]
#  [  652 13707]
#  [  652 13712]
#  [  679 13706]
#  [  679 13713]
#  [  680 13706]
#  [  680 13713]
#  [  693 13682]
#  [  693 13686]
#  [  693 13688]
#  [  693 13689]
#  [  693 13690]
#  [  693 13707]
#  [  693 13712]
#  [  697 13706]
#  [  697 13713]
#  [  707 13682]
#  [  707 13686]
#  [  707 13688]
#  [  707 13689]
#  [  707 13690]
#  [  707 13707]
#  [  707 13712]]
# Done Generating final pairs: 0.4243044853210449
# best_stitch_pair = [  376 13688]
# best_stitch_pair_size = 3436922.281370676
# best_stitch_pair_distance = 572.7117941840214
# best_stitch_pair_size_ratio = 0.9438824681495176
# Starting Child 3
# 887 14047
# Done distance matrix: 0.3840482234954834
# Child 3 There were no points close enough
# Starting Child 4
# 521 14047
# Done distance matrix: 0.23263120651245117
# final_pairs = [[    2 14044]
#  [    2 14045]
#  [    5 14044]
#  [    5 14045]]
# Done Generating final pairs: 0.2458019256591797
# best_stitch_pair = [    2 14045]
# best_stitch_pair_size = 471490.6745251275
# best_stitch_pair_distance = 1273.952270121484
# best_stitch_pair_size_ratio = 0.7644151539205241
# Starting Child 5
# 203 14047
# Done distance matrix: 0.09222412109375
# final_pairs = [[  151 13980]
#  [  152 13980]
#  [  153 13980]
#  [  178 13980]
#  [  182 13980]]
# Done Generating final pairs: 0.1023111343383789
# best_stitch_pair = [  151 13980]
# best_stitch_pair_size = 182014.01881742995
# best_stitch_pair_distance = 1972.004851465701
# best_stitch_pair_size_ratio = 0.21675339105095245
# Starting Child 6
# 567 14047
# Done distance matrix: 0.2602086067199707
# Child 6 There were no points close enough
# Starting Child 7
# 212 14047
# Done distance matrix: 0.08945274353027344
# Child 7 There were no points close enough
# Starting Child 8
# 170 14047
# Done distance matrix: 0.07727456092834473
# Child 8 There were no points close enough
# Starting Child 10
# 130 14047
# Done distance matrix: 0.05485963821411133
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 14047
# Done distance matrix: 0.12892484664916992
# Child 11 There were no points close enough
# Starting Child 12
# 191 14047
# Done distance matrix: 0.07930827140808105
# Child 12 There were no points close enough
# Starting Child 13
# 185 14047
# Done distance matrix: 0.0819101333618164
# Child 13 There were no points close enough
# Starting Child 14
# 187 14047
# Done distance matrix: 0.07636189460754395
# final_pairs = [[   12 13716]
#  [   12 13718]
#  [   12 13719]
#  [   12 13739]
#  [   12 13782]
#  [   12 13789]
#  [   22 13716]
#  [   22 13718]
#  [   22 13719]
#  [   22 13739]
#  [   22 13782]
#  [   22 13789]
#  [   30 13692]
#  [   30 13693]
#  [   30 13716]
#  [   30 13718]
#  [   30 13719]
#  [   30 13739]
#  [   30 13782]
#  [   30 13783]
#  [   30 13784]
#  [   30 13788]
#  [   30 13789]
#  [   30 13796]
#  [   41 13716]
#  [   41 13718]
#  [   41 13719]
#  [   41 13739]
#  [   41 13782]
#  [   41 13789]
#  [   78 13692]
#  [   78 13693]
#  [   78 13716]
#  [   78 13718]
#  [   78 13719]
#  [   78 13739]
#  [   78 13782]
#  [   78 13783]
#  [   78 13784]
#  [   78 13788]
#  [   78 13789]
#  [   78 13796]
#  [   95 13793]
#  [   95 13797]
#  [   96 13695]
#  [  102 13694]
#  [  105 13695]
#  [  134 13716]
#  [  134 13718]
#  [  134 13719]
#  [  134 13739]
#  [  134 13782]
#  [  134 13789]]
# Done Generating final pairs: 0.16822195053100586
# best_stitch_pair = [   30 13716]
# best_stitch_pair_size = 2883036.8729235707
# best_stitch_pair_distance = 390.2646613688339
# best_stitch_pair_size_ratio = 0.7564285237395645
# Starting Child 15
# 470 14047
# Done distance matrix: 0.19066262245178223
# Child 15 There were no points close enough
# Starting Child 16
# 261 14047
# Done distance matrix: 0.11258268356323242
# Child 16 There were no points close enough
# Starting Child 17
# 10 14047
# Done distance matrix: 0.0045087337493896484
# Child 17 There were no points close enough
# Starting Child 18
# 16 14047
# Done distance matrix: 0.007005929946899414
# Child 18 There were no points close enough
# Starting Child 19
# 4 14047
# Done distance matrix: 0.0020432472229003906
# Child 19 There were no points close enough
# Starting Child 21
# 14 14047
# Done distance matrix: 0.00561070442199707
# final_pairs = [[    1 13704]
#  [    5 13692]
#  [    5 13693]
#  [    5 13783]
#  [    5 13784]
#  [    5 13788]
#  [    5 13796]
#  [    6 13692]
#  [    6 13693]
#  [    6 13783]
#  [    6 13784]
#  [    6 13788]
#  [    6 13796]
#  [    8 13692]
#  [    8 13693]
#  [    8 13783]
#  [    8 13784]
#  [    8 13788]
#  [    8 13796]]
# Done Generating final pairs: 0.02493739128112793
# best_stitch_pair = [    5 13693]
# best_stitch_pair_size = 449701.693492813
# best_stitch_pair_distance = 430.9685698484413
# best_stitch_pair_size_ratio = 0.6993873614871552
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 14047
# Done distance matrix: 0.026953458786010742
# Child 23 There were no points close enough
# Starting Child 25
# 56 14047
# Done distance matrix: 0.02242302894592285
# Child 25 There were no points close enough
# Starting Child 26
# 5 14047
# Done distance matrix: 0.0024831295013427734
# Child 26 There were no points close enough
# Starting Child 27
# 3 14047
# Done distance matrix: 0.0015993118286132812
# Child 27 There were no points close enough
# Starting Child 28
# 124 14047
# Done distance matrix: 0.04922008514404297
# Child 28 There were no points close enough
# Starting Child 31
# 53 14047
# Done distance matrix: 0.021290302276611328
# final_pairs = [[   29 14034]
#  [   29 14036]
#  [   29 14038]
#  [   29 14041]
#  [   29 14043]]
# Done Generating final pairs: 0.03427290916442871
# best_stitch_pair = [   29 14034]
# best_stitch_pair_size = 846336.2461686919
# best_stitch_pair_distance = 1238.4060049849497
# best_stitch_pair_size_ratio = 0.5730566111683719
# Starting Child 33
# 28 14047
# Done distance matrix: 0.01107025146484375
# final_pairs = [[    0 14034]
#  [    0 14036]
#  [    0 14038]
#  [    0 14041]
#  [    0 14042]
#  [    0 14043]
#  [    2 14034]
#  [    2 14036]
#  [    2 14041]
#  [    2 14042]
#  [    2 14043]
#  [    4 14039]
#  [    5   810]
#  [   12 14039]
#  [   12 14040]
#  [   13 14037]
#  [   17 14039]
#  [   17 14040]
#  [   19 14034]
#  [   19 14036]
#  [   19 14038]
#  [   19 14041]
#  [   19 14043]
#  [   25 14039]
#  [   25 14040]]
# Done Generating final pairs: 0.030276775360107422
# best_stitch_pair = [    0 14034]
# best_stitch_pair_size = 883352.4059815215
# best_stitch_pair_distance = 646.9399508826754
# best_stitch_pair_size_ratio = 0.6418572978661627
# Starting Child 34
# 63 14047
# Done distance matrix: 0.025719165802001953
# Child 34 There were no points close enough
# Starting Child 35
# 18 14047
# Done distance matrix: 0.008312463760375977
# final_pairs = [[    0 13703]]
# Done Generating final pairs: 0.015526056289672852
# best_stitch_pair = [    0 13703]
# best_stitch_pair_size = 95170.04553797239
# best_stitch_pair_distance = 1974.146539600966
# best_stitch_pair_size_ratio = 0.27609727021656366
# Starting Child 36
# 5 14047
# Done distance matrix: 0.0028383731842041016
# Child 36 There were no points close enough
# Starting Child 37
# 37 14047
# Done distance matrix: 0.03811287879943848
# final_pairs = [[    2 14044]
#  [    2 14045]
#  [    3  7148]
#  [    7 14044]
#  [    7 14045]
#  [    9 14046]
#  [   12 14046]
#  [   18 14044]
#  [   18 14045]
#  [   33  7148]]
# Done Generating final pairs: 0.06209897994995117
# best_stitch_pair = [    7 14045]
# best_stitch_pair_size = 543403.0131173849
# best_stitch_pair_distance = 901.0225763628129
# best_stitch_pair_size_ratio = 0.6023234299780027
# Starting Child 38
# 10 14047
# Done distance matrix: 0.007283449172973633
# Child 38 There were no points close enough
# Starting Child 39
# 17 14047
# Done distance matrix: 0.011614084243774414
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 14047
# Done distance matrix: 0.0028710365295410156
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [14045, 14034]
# child_mesh_double_indexes = [4, 37]
# min_child = 37, max_ratio = 901.0225763628129
# child_mesh_double_indexes = [31, 33]
# min_child = 33, max_ratio = 646.9399508826754
# child_meshes_stitch_facets = {0: [376, 13688], 5: [151, 13980], 14: [30, 13716], 21: [5, 13693], 33: [0, 14034], 35: [0, 13703], 37: [7, 14045]}
# ---Stitching child 0 with pair: [376, 13688]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 938254, starting edge 2nd facet= 1006471,
# Starting Organizing vertices for side 0
# [14 38]
# Edge 2 picked for direction
# edge_0_order done, len = 58
# Starting Organizing vertices for side 1
# [36 37]
# Edge 2 picked for direction
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# edge_1_order done, len = 56
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 0.00014591217041015625
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0294950008392334
# returned from stitch mesh: 0.9535937309265137
# Finished stitching child 0 : 1.0889525413513184
# ---Stitching child 5 with pair: [151, 13980]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 960142, starting edge 2nd facet= 1023769,
# Starting Organizing vertices for side 0
# [1 5]
# Edge 2 picked for direction
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# [0 1]
# Edge 2 picked for direction
# edge_1_order done, len = 10
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.52587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029100656509399414
# returned from stitch mesh: 1.0508031845092773
# Finished stitching child 5 : 1.2438671588897705
# ---Stitching child 14 with pair: [30, 13716]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934224, starting edge 2nd facet= 1026070,
# Starting Organizing vertices for side 0
# [ 3 19]
# Edge 1 picked for direction
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# [0 7]
# Edge 2 picked for direction
# edge_1_order done, len = 31
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 4.744529724121094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028922080993652344
# returned from stitch mesh: 0.9310925006866455
# Finished stitching child 14 : 1.0895869731903076
# ---Stitching child 21 with pair: [5, 13693]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934446, starting edge 2nd facet= 1030016,
# Starting Organizing vertices for side 0
# [0 3]
# Edge 2 picked for direction
# Start vertex reached before processed all of edges
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# [2 3]
# Edge 2 picked for direction
# edge_1_order done, len = 7
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.33514404296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029402971267700195
# returned from stitch mesh: 0.9088828563690186
# Finished stitching child 21 : 1.0676360130310059
# ---Stitching child 33 with pair: [0, 14034]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 963806, starting edge 2nd facet= 1030270,
# Starting Organizing vertices for side 0
# [14 21]
# Edge 1 picked for direction
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# [ 0 16]
# Edge 1 picked for direction
# edge_1_order done, len = 21
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.9577484130859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028959035873413086
# returned from stitch mesh: 0.8925881385803223
# Finished stitching child 33 : 1.0515456199645996
# ---Stitching child 35 with pair: [0, 13703]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 936231, starting edge 2nd facet= 1030542,
# Starting Organizing vertices for side 0
# [0 4]
# Edge 2 picked for direction
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# [1 8]
# Edge 1 picked for direction
# edge_1_order done, len = 11
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 1.5974044799804688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02737736701965332
# returned from stitch mesh: 0.8752238750457764
# Finished stitching child 35 : 1.0297558307647705
# ---Stitching child 37 with pair: [7, 14045]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 964243, starting edge 2nd facet= 1030869,
# Starting Organizing vertices for side 0
# [2 7]
# Edge 1 picked for direction
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# [13 19]
# Edge 2 picked for direction
# edge_1_order done, len = 21
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 2.8848648071289062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01649332046508789
# returned from stitch mesh: 1.030080795288086
# Finished stitching child 37 : 1.1843540668487549
# Total Facet building time: 6.984728097915649
# ***************Finished big stitching iteration: 66.6285936832428***************
# Starting Child 3
# 887 15014
# Done distance matrix: 0.42080116271972656
# Child 3 There were no points close enough
# Starting Child 4
# 521 15014
# Done distance matrix: 0.2554442882537842
# final_pairs = [[    2 14999]
#  [    2 15002]
#  [    2 15004]
#  [    2 15005]
#  [    2 15007]
#  [    5 14999]
#  [    5 15002]
#  [    5 15003]
#  [    5 15004]
#  [    5 15005]
#  [    5 15007]
#  [    9 15013]
#  [   11 15013]
#  [  200 14999]
#  [  200 15002]
#  [  200 15004]
#  [  200 15005]
#  [  200 15007]
#  [  207 15010]
#  [  207 15011]
#  [  259 14999]
#  [  259 15002]
#  [  259 15004]
#  [  259 15005]
#  [  259 15007]
#  [  261 14999]
#  [  261 15002]
#  [  261 15004]
#  [  261 15005]
#  [  261 15007]
#  [  262 14999]
#  [  262 15002]
#  [  262 15004]
#  [  262 15005]
#  [  262 15007]
#  [  263 14999]
#  [  263 15002]
#  [  263 15004]
#  [  263 15005]
#  [  263 15007]
#  [  264 15010]
#  [  264 15011]
#  [  266 15010]
#  [  266 15011]
#  [  272 15013]
#  [  418 15010]
#  [  433 14999]
#  [  433 15002]
#  [  433 15003]
#  [  433 15004]
#  [  433 15005]
#  [  433 15007]]
# Done Generating final pairs: 0.2921428680419922
# best_stitch_pair = [    2 14999]
# best_stitch_pair_size = 579724.5914219486
# best_stitch_pair_distance = 114.04782222263135
# best_stitch_pair_size_ratio = 0.8551037405509867
# Starting Child 6
# 567 15014
# Done distance matrix: 0.26854848861694336
# Child 6 There were no points close enough
# Starting Child 7
# 212 15014
# Done distance matrix: 0.10689997673034668
# Child 7 There were no points close enough
# Starting Child 8
# 170 15014
# Done distance matrix: 0.084686279296875
# Child 8 There were no points close enough
# Starting Child 10
# 130 15014
# Done distance matrix: 0.06309890747070312
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 15014
# Done distance matrix: 0.1336960792541504
# final_pairs = [[  146 14928]
#  [  146 14960]
#  [  146 14961]
#  [  146 14963]
#  [  206 14919]
#  [  206 14928]
#  [  206 14932]
#  [  206 14943]
#  [  206 14945]
#  [  206 14960]
#  [  206 14961]
#  [  206 14963]
#  [  207 14952]
#  [  209 14928]
#  [  209 14943]
#  [  209 14960]
#  [  209 14961]
#  [  209 14963]
#  [  210 14952]
#  [  212 14928]
#  [  212 14960]
#  [  212 14961]
#  [  212 14963]
#  [  213 14952]
#  [  214 14952]
#  [  217 14928]
#  [  217 14943]
#  [  217 14960]
#  [  217 14961]
#  [  217 14963]
#  [  218 14939]
#  [  218 14959]
#  [  219 14928]
#  [  219 14960]
#  [  219 14961]
#  [  219 14963]
#  [  220 14952]]
# Done Generating final pairs: 0.16517877578735352
# best_stitch_pair = [  206 14960]
# best_stitch_pair_size = 2140828.9260933343
# best_stitch_pair_distance = 240.5141215679018
# best_stitch_pair_size_ratio = 0.9094158054917909
# Starting Child 12
# 191 15014
# Done distance matrix: 0.09139752388000488
# final_pairs = []
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 15014
# Done distance matrix: 0.083160400390625
# Child 13 There were no points close enough
# Starting Child 15
# 470 15014
# Done distance matrix: 0.2133944034576416
# Child 15 There were no points close enough
# Starting Child 16
# 261 15014
# Done distance matrix: 0.11738348007202148
# Child 16 There were no points close enough
# Starting Child 17
# 10 15014
# Done distance matrix: 0.0057451725006103516
# Child 17 There were no points close enough
# Starting Child 18
# 16 15014
# Done distance matrix: 0.009168386459350586
# Child 18 There were no points close enough
# Starting Child 19
# 4 15014
# Done distance matrix: 0.002324819564819336
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 15014
# Done distance matrix: 0.030991315841674805
# final_pairs = [[    4 14892]
#  [    4 14895]
#  [    4 14897]
#  [    6 14900]]
# Done Generating final pairs: 0.04090404510498047
# best_stitch_pair = [    4 14895]
# best_stitch_pair_size = 142549.35198714465
# best_stitch_pair_distance = 301.4510828666649
# best_stitch_pair_size_ratio = 0.5011014263664639
# Starting Child 25
# 56 15014
# Done distance matrix: 0.024352312088012695
# Child 25 There were no points close enough
# Starting Child 26
# 5 15014
# Done distance matrix: 0.0028076171875
# Child 26 There were no points close enough
# Starting Child 27
# 3 15014
# Done distance matrix: 0.0017542839050292969
# Child 27 There were no points close enough
# Starting Child 28
# 124 15014
# Done distance matrix: 0.055528879165649414
# Child 28 There were no points close enough
# Starting Child 31
# 53 15014
# Done distance matrix: 0.02453303337097168
# final_pairs = [[   29 14018]
#  [   29 14020]
#  [   29 14023]
#  [   29 14025]
#  [   29 14993]
#  [   29 14994]
#  [   29 14997]]
# Done Generating final pairs: 0.044120073318481445
# best_stitch_pair = [   29 14993]
# best_stitch_pair_size = 611219.884607617
# best_stitch_pair_distance = 156.93980186490012
# best_stitch_pair_size_ratio = 0.9824459653114482
# Starting Child 34
# 63 15014
# Done distance matrix: 0.028980493545532227
# Child 34 There were no points close enough
# Starting Child 36
# 5 15014
# Done distance matrix: 0.002938508987426758
# final_pairs = [[    0 14952]
#  [    1 14928]
#  [    1 14943]
#  [    1 14960]
#  [    1 14961]
#  [    1 14963]
#  [    3 14962]
#  [    4 14939]
#  [    4 14956]
#  [    4 14959]]
# Done Generating final pairs: 0.028390169143676758
# best_stitch_pair = [    0 14952]
# best_stitch_pair_size = 121382.56885210043
# best_stitch_pair_distance = 832.943134981319
# best_stitch_pair_size_ratio = 0.5893754752864937
# Starting Child 38
# 10 15014
# Done distance matrix: 0.0051381587982177734
# Child 38 There were no points close enough
# Starting Child 39
# 17 15014
# Done distance matrix: 0.008368968963623047
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 15014
# Done distance matrix: 0.0022695064544677734
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [2, 14999], 11: [206, 14960], 23: [4, 14895], 31: [29, 14993], 36: [0, 14952]}
# ---Stitching child 4 with pair: [2, 14999]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1031011, starting edge 2nd facet= 1032810,
# Starting Organizing vertices for side 0
# [13 14]
# Edge 2 picked for direction
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# [ 2 16]
# Edge 2 picked for direction
# edge_1_order done, len = 18
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030682086944580078
# returned from stitch mesh: 1.0679645538330078
# Finished stitching child 4 : 1.2289152145385742
# ---Stitching child 11 with pair: [206, 14960]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1025744, starting edge 2nd facet= 1039776,
# Starting Organizing vertices for side 0
# [ 0 21]
# Edge 2 picked for direction
# edge_0_order done, len = 37
# Starting Organizing vertices for side 1
# [0 7]
# Edge 2 picked for direction
# edge_1_order done, len = 29
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 4.9114227294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03040337562561035
# returned from stitch mesh: 0.9435036182403564
# Finished stitching child 11 : 1.1029260158538818
# ---Stitching child 23 with pair: [4, 14895]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1023101, starting edge 2nd facet= 1046244,
# Starting Organizing vertices for side 0
# [3 5]
# Edge 2 picked for direction
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# [0 4]
# Edge 1 picked for direction
# edge_1_order done, len = 6
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.52587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03122711181640625
# returned from stitch mesh: 0.9261875152587891
# Finished stitching child 23 : 1.0812427997589111
# ---Stitching child 31 with pair: [29, 14993]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1030246, starting edge 2nd facet= 1047074,
# Starting Organizing vertices for side 0
# [11 12]
# Edge 1 picked for direction
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# [0 7]
# Edge 2 picked for direction
# edge_1_order done, len = 20
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.5272369384765625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.032999515533447266
# returned from stitch mesh: 0.9865372180938721
# Finished stitching child 31 : 1.1478211879730225
# ---Stitching child 36 with pair: [0, 14952]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1026280, starting edge 2nd facet= 1048609,
# Starting Organizing vertices for side 0
# [5 7]
# Edge 2 picked for direction
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# [1 4]
# Edge 1 picked for direction
# edge_1_order done, len = 9
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02806687355041504
# returned from stitch mesh: 0.9351601600646973
# Finished stitching child 36 : 1.1115217208862305
# Total Facet building time: 6.994823455810547
# ***************Finished big stitching iteration: 66.15846133232117***************
# Starting Child 3
# 887 15265
# Done distance matrix: 0.4114968776702881
# Child 3 There were no points close enough
# Starting Child 6
# 567 15265
# Done distance matrix: 0.2814352512359619
# Child 6 There were no points close enough
# Starting Child 7
# 212 15265
# Done distance matrix: 0.10669159889221191
# final_pairs = [[   30 15065]
#  [   36 15028]
#  [   36 15030]
#  [   36 15053]
#  [   36 15055]
#  [   36 15065]
#  [   36 15091]
#  [   36 15098]
#  [   37 15016]
#  [   37 15063]
#  [   37 15092]
#  [   37 15094]
#  [   37 15095]
#  [   37 15099]
#  [   37 15116]
#  [   37 15120]
#  [   40 15016]
#  [   40 15021]
#  [   40 15063]
#  [   40 15092]
#  [   40 15094]
#  [   40 15095]
#  [   40 15099]
#  [   40 15116]
#  [   40 15120]
#  [   42 15062]
#  [   42 15066]
#  [   42 15085]
#  [   42 15096]
#  [   42 15110]
#  [   42 15111]
#  [   42 15117]
#  [   42 15118]
#  [   42 15119]
#  [   43 15121]
#  [   46 15013]
#  [   46 15025]
#  [   46 15026]
#  [   46 15039]
#  [   46 15042]
#  [   46 15047]
#  [   46 15062]
#  [   46 15066]
#  [   46 15085]
#  [   46 15096]
#  [   46 15110]
#  [   46 15111]
#  [   46 15117]
#  [   46 15118]
#  [   46 15119]
#  [   47 15016]
#  [   47 15021]
#  [   47 15063]
#  [   47 15092]
#  [   47 15094]
#  [   47 15095]
#  [   47 15099]
#  [   47 15116]
#  [   47 15120]
#  [   48 15025]
#  [   48 15039]
#  [   48 15042]
#  [   48 15047]
#  [   48 15062]
#  [   48 15066]
#  [   48 15085]
#  [   48 15096]
#  [   48 15110]
#  [   48 15111]
#  [   48 15117]
#  [   48 15118]
#  [   48 15119]
#  [   57 15016]
#  [   57 15063]
#  [   57 15092]
#  [   57 15094]
#  [   57 15099]
#  [   57 15116]
#  [   57 15120]
#  [   74 15063]
#  [   74 15099]
#  [   74 15116]
#  [   75 15028]
#  [   75 15030]
#  [   75 15053]
#  [   75 15055]
#  [   75 15065]
#  [   75 15091]
#  [   75 15098]
#  [  160 15085]
#  [  161 15062]
#  [  161 15066]
#  [  161 15085]
#  [  161 15096]
#  [  161 15110]
#  [  161 15111]
#  [  161 15117]
#  [  161 15118]
#  [  161 15119]
#  [  163 15063]
#  [  163 15099]
#  [  178 15083]]
# Done Generating final pairs: 0.15202069282531738
# best_stitch_pair = [   46 15096]
# best_stitch_pair_size = 136007.9956301315
# best_stitch_pair_distance = 534.6311217289636
# best_stitch_pair_size_ratio = 0.7482800030866306
# Starting Child 8
# 170 15265
# Done distance matrix: 0.07959365844726562
# Child 8 There were no points close enough
# Starting Child 10
# 130 15265
# Done distance matrix: 0.06592679023742676
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 191 15265
# Done distance matrix: 0.08807897567749023
# final_pairs = []
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 15265
# Done distance matrix: 0.08579492568969727
# Child 13 There were no points close enough
# Starting Child 15
# 470 15265
# Done distance matrix: 0.23906230926513672
# final_pairs = [[  221 15231]
#  [  221 15235]
#  [  221 15238]
#  [  221 15239]
#  [  221 15240]
#  [  221 15242]
#  [  221 15256]
#  [  221 15260]
#  [  235 15231]
#  [  235 15235]
#  [  235 15238]
#  [  235 15239]
#  [  235 15240]
#  [  235 15242]
#  [  235 15256]
#  [  235 15260]
#  [  277 15231]
#  [  277 15235]
#  [  277 15238]
#  [  277 15239]
#  [  277 15240]
#  [  277 15242]
#  [  277 15256]
#  [  277 15260]
#  [  303 15229]
#  [  313 15231]
#  [  313 15235]
#  [  313 15238]
#  [  313 15239]
#  [  313 15240]
#  [  313 15242]
#  [  313 15256]
#  [  313 15260]
#  [  315 15231]
#  [  315 15235]
#  [  315 15238]
#  [  315 15239]
#  [  315 15240]
#  [  315 15242]
#  [  315 15256]
#  [  315 15260]
#  [  322 15229]
#  [  406 15241]
#  [  424 15231]
#  [  424 15235]
#  [  424 15238]
#  [  424 15239]
#  [  424 15240]
#  [  424 15242]
#  [  424 15251]
#  [  424 15256]
#  [  424 15260]
#  [  444 15230]
#  [  466 15231]
#  [  466 15235]
#  [  466 15238]
#  [  466 15239]
#  [  466 15240]
#  [  466 15242]
#  [  466 15256]
#  [  466 15260]]
# Done Generating final pairs: 0.266085147857666
# best_stitch_pair = [  221 15256]
# best_stitch_pair_size = 859620.1038684787
# best_stitch_pair_distance = 737.0193281922791
# best_stitch_pair_size_ratio = 0.38213837304136455
# Starting Child 16
# 261 15265
# Done distance matrix: 0.12587904930114746
# Child 16 There were no points close enough
# Starting Child 17
# 10 15265
# Done distance matrix: 0.00510859489440918
# Child 17 There were no points close enough
# Starting Child 18
# 16 15265
# Done distance matrix: 0.009613990783691406
# Child 18 There were no points close enough
# Starting Child 19
# 4 15265
# Done distance matrix: 0.0025086402893066406
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 15265
# Done distance matrix: 0.025175809860229492
# Child 25 There were no points close enough
# Starting Child 26
# 5 15265
# Done distance matrix: 0.002561807632446289
# Child 26 There were no points close enough
# Starting Child 27
# 3 15265
# Done distance matrix: 0.0017094612121582031
# Child 27 There were no points close enough
# Starting Child 28
# 124 15265
# Done distance matrix: 0.054772138595581055
# Child 28 There were no points close enough
# Starting Child 34
# 63 15265
# Done distance matrix: 0.028650760650634766
# final_pairs = []
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# 10 15265
# Done distance matrix: 0.00484466552734375
# Child 38 There were no points close enough
# Starting Child 39
# 17 15265
# Done distance matrix: 0.008176803588867188
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 15265
# Done distance matrix: 0.0023114681243896484
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {7: [46, 15096], 15: [221, 15256]}
# ---Stitching child 7 with pair: [46, 15096]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1038911, starting edge 2nd facet= 1049884,
# Starting Organizing vertices for side 0
# [6 7]
# Edge 2 picked for direction
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# [0 2]
# Edge 2 picked for direction
# edge_1_order done, len = 6
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.016794919967651367
# returned from stitch mesh: 0.6886167526245117
# Finished stitching child 7 : 0.7900042533874512
# ---Stitching child 15 with pair: [221, 15256]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1046647, starting edge 2nd facet= 1056035,
# Starting Organizing vertices for side 0
# [0 5]
# Edge 2 picked for direction
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# [3 7]
# Edge 2 picked for direction
# edge_1_order done, len = 15
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 3.24249267578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030704021453857422
# returned from stitch mesh: 0.9151947498321533
# Finished stitching child 15 : 1.0607337951660156
# Total Facet building time: 6.97874903678894
# ***************Finished big stitching iteration: 63.321327924728394***************
# Starting Child 3
# 887 15403
# Done distance matrix: 0.41361522674560547
# final_pairs = [[   14 15346]
#  [  232 15340]
#  [  246 15340]
#  [  264 15346]
#  [  336 15340]
#  [  346 15346]
#  [  370 15340]
#  [  374 15346]
#  [  383 15340]
#  [  387 15340]
#  [  425 15346]
#  [  610 15340]]
# Done Generating final pairs: 0.4264540672302246
# best_stitch_pair = [  232 15340]
# best_stitch_pair_size = 690856.3646172397
# best_stitch_pair_distance = 270.2210230377153
# best_stitch_pair_size_ratio = 0.7589459759005659
# Starting Child 6
# 567 15403
# Done distance matrix: 0.26754021644592285
# Child 6 There were no points close enough
# Starting Child 8
# 170 15403
# Done distance matrix: 0.0782468318939209
# final_pairs = [[   14 15248]
#  [   14 15262]
#  [   14 15272]
#  [   14 15273]
#  [   14 15284]
#  [   14 15286]
#  [   14 15287]
#  [   14 15288]
#  [   14 15306]
#  [   14 15310]
#  [   15 15279]
#  [   15 15283]
#  [   20 15308]
#  [   25 15248]
#  [   25 15262]
#  [   25 15272]
#  [   25 15273]
#  [   25 15284]
#  [   25 15286]
#  [   25 15287]
#  [   28 15279]
#  [   30 15248]
#  [   30 15273]
#  [   30 15284]
#  [   30 15286]
#  [   30 15287]
#  [   30 15306]
#  [   35 15248]
#  [   35 15262]
#  [   35 15272]
#  [   35 15273]
#  [   35 15284]
#  [   35 15286]
#  [   35 15287]
#  [   35 15288]
#  [   35 15306]
#  [   35 15310]
#  [   37 15248]
#  [   37 15262]
#  [   37 15272]
#  [   37 15273]
#  [   37 15284]
#  [   37 15286]
#  [   37 15287]
#  [   37 15288]
#  [   37 15306]
#  [   37 15310]
#  [   40 15267]
#  [   41 15248]
#  [   41 15262]
#  [   41 15272]
#  [   41 15273]
#  [   41 15284]
#  [   41 15286]
#  [   41 15287]
#  [   41 15288]
#  [   41 15306]
#  [   41 15310]
#  [   76 15276]
#  [   76 15309]
#  [   78 15277]
#  [   79 15311]
#  [   84 15311]
#  [   85 15272]
#  [   85 15273]
#  [   85 15284]
#  [   85 15286]
#  [   85 15287]
#  [   85 15288]
#  [   85 15306]
#  [   85 15310]
#  [   86 15248]
#  [   86 15262]
#  [   86 15272]
#  [   86 15273]
#  [   86 15284]
#  [   86 15286]
#  [   86 15287]
#  [   86 15288]
#  [   86 15306]
#  [   86 15310]
#  [  100 15272]
#  [  100 15273]
#  [  100 15284]
#  [  100 15286]
#  [  100 15287]
#  [  100 15288]
#  [  100 15306]
#  [  100 15310]
#  [  106 15309]
#  [  108 15308]
#  [  112 15248]
#  [  112 15262]
#  [  112 15272]
#  [  112 15273]
#  [  112 15284]
#  [  112 15286]
#  [  112 15287]
#  [  112 15288]
#  [  112 15306]
#  [  112 15310]
#  [  117 15308]
#  [  122 15248]
#  [  122 15262]
#  [  122 15272]
#  [  122 15273]
#  [  122 15284]
#  [  122 15286]
#  [  122 15287]
#  [  122 15288]
#  [  122 15306]
#  [  122 15310]
#  [  127 15276]
#  [  127 15309]
#  [  131 15308]
#  [  137 15260]
#  [  137 15311]
#  [  144 15311]
#  [  150 15272]
#  [  150 15273]
#  [  150 15284]
#  [  150 15286]
#  [  150 15287]
#  [  150 15288]
#  [  150 15306]
#  [  150 15310]
#  [  157 15273]
#  [  157 15284]
#  [  157 15286]
#  [  157 15287]
#  [  157 15306]
#  [  160 15311]
#  [  169 15296]]
# Done Generating final pairs: 0.1206979751586914
# best_stitch_pair = [   37 15306]
# best_stitch_pair_size = 1134104.8523841288
# best_stitch_pair_distance = 417.6392176470307
# best_stitch_pair_size_ratio = 0.47967654423080586
# Starting Child 10
# 130 15403
# Done distance matrix: 0.06315279006958008
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 191 15403
# Done distance matrix: 0.09241724014282227
# final_pairs = []
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 15403
# Done distance matrix: 0.08954644203186035
# Child 13 There were no points close enough
# Starting Child 16
# 261 15403
# Done distance matrix: 0.12209796905517578
# Child 16 There were no points close enough
# Starting Child 17
# 10 15403
# Done distance matrix: 0.006012678146362305
# Child 17 There were no points close enough
# Starting Child 18
# 16 15403
# Done distance matrix: 0.008200407028198242
# Child 18 There were no points close enough
# Starting Child 19
# 4 15403
# Done distance matrix: 0.0027124881744384766
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 15403
# Done distance matrix: 0.02522444725036621
# Child 25 There were no points close enough
# Starting Child 26
# 5 15403
# Done distance matrix: 0.0027060508728027344
# Child 26 There were no points close enough
# Starting Child 27
# 3 15403
# Done distance matrix: 0.0016608238220214844
# Child 27 There were no points close enough
# Starting Child 28
# 124 15403
# Done distance matrix: 0.05541539192199707
# Child 28 There were no points close enough
# Starting Child 34
# 63 15403
# Done distance matrix: 0.03054499626159668
# final_pairs = []
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# 10 15403
# Done distance matrix: 0.00497889518737793
# Child 38 There were no points close enough
# Starting Child 39
# 17 15403
# Done distance matrix: 0.010375261306762695
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 15403
# Done distance matrix: 0.0022919178009033203
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [232, 15340], 8: [37, 15306]}
# ---Stitching child 3 with pair: [232, 15340]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1061506, starting edge 2nd facet= 1070567,
# Starting Organizing vertices for side 0
# [15 19]
# Edge 1 picked for direction
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# [ 3 12]
# Edge 1 picked for direction
# edge_1_order done, len = 14
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 4.1484832763671875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023128747940063477
# returned from stitch mesh: 0.8859336376190186
# Finished stitching child 3 : 0.991405725479126
# ---Stitching child 8 with pair: [37, 15306]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1050595, starting edge 2nd facet= 1078825,
# Starting Organizing vertices for side 0
# [ 5 25]
# Edge 1 picked for direction
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# [13 14]
# Edge 2 picked for direction
# edge_1_order done, len = 15
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 3.123283386230469e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030802488327026367
# returned from stitch mesh: 1.0803987979888916
# Finished stitching child 8 : 1.2891485691070557
# Total Facet building time: 7.092900037765503
# ***************Finished big stitching iteration: 63.34047865867615***************
# Starting Child 6
# 567 15618
# Done distance matrix: 0.2834320068359375
# Child 6 There were no points close enough
# Starting Child 10
# 130 15618
# Done distance matrix: 0.06523919105529785
# final_pairs = []
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 191 15618
# Done distance matrix: 0.1000831127166748
# final_pairs = []
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 15618
# Done distance matrix: 0.09166526794433594
# final_pairs = [[    4 15605]
#  [   10 15580]
#  [   10 15594]
#  [   10 15599]
#  [   10 15606]
#  [   10 15607]
#  [   10 15608]
#  [   10 15609]
#  [   81 15615]
#  [   90 15580]
#  [   90 15594]
#  [   90 15599]
#  [   90 15606]
#  [   90 15607]
#  [   90 15608]
#  [   90 15609]
#  [   99 15615]
#  [  108 15580]
#  [  108 15594]
#  [  108 15599]
#  [  108 15606]
#  [  108 15607]
#  [  108 15608]
#  [  108 15609]
#  [  141 15580]
#  [  141 15594]
#  [  141 15599]
#  [  141 15606]
#  [  141 15607]
#  [  141 15608]
#  [  141 15609]
#  [  144 15615]
#  [  158 15580]
#  [  158 15594]
#  [  158 15599]
#  [  158 15606]
#  [  158 15607]
#  [  158 15608]
#  [  158 15609]]
# Done Generating final pairs: 0.12112879753112793
# best_stitch_pair = [   10 15609]
# best_stitch_pair_size = 696655.6337785332
# best_stitch_pair_distance = 194.72002184223322
# best_stitch_pair_size_ratio = 0.8266906389457586
# Starting Child 16
# 261 15618
# Done distance matrix: 0.13558197021484375
# Child 16 There were no points close enough
# Starting Child 17
# 10 15618
# Done distance matrix: 0.006250858306884766
# Child 17 There were no points close enough
# Starting Child 18
# 16 15618
# Done distance matrix: 0.010151863098144531
# Child 18 There were no points close enough
# Starting Child 19
# 4 15618
# Done distance matrix: 0.002638578414916992
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 15618
# Done distance matrix: 0.026432514190673828
# Child 25 There were no points close enough
# Starting Child 26
# 5 15618
# Done distance matrix: 0.0027055740356445312
# Child 26 There were no points close enough
# Starting Child 27
# 3 15618
# Done distance matrix: 0.0016551017761230469
# Child 27 There were no points close enough
# Starting Child 28
# 124 15618
# Done distance matrix: 0.058713674545288086
# Child 28 There were no points close enough
# Starting Child 34
# 63 15618
# Done distance matrix: 0.032804012298583984
# final_pairs = []
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# 10 15618
# Done distance matrix: 0.0055179595947265625
# Child 38 There were no points close enough
# Starting Child 39
# 17 15618
# Done distance matrix: 0.008905172348022461
# final_pairs = []
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 15618
# Done distance matrix: 0.0023272037506103516
# final_pairs = []
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {13: [10, 15609]}
# ---Stitching child 13 with pair: [10, 15609]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1078410, starting edge 2nd facet= 1081264,
# Starting Organizing vertices for side 0
# [ 9 24]
# Edge 1 picked for direction
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# [17 18]
# Edge 2 picked for direction
# edge_1_order done, len = 23
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.4332275390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.005807161331176758
# returned from stitch mesh: 0.7058107852935791
# Finished stitching child 13 : 0.8377330303192139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-977ffc4108c9> in <module>
#     511         no_new_children_multiplier = 0
#     512         #recompute the main mesh facets
# --> 513         main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
#     514         print(f"***************Finished big stitching iteration: {time.time() - stitch_loop_time}***************")
#     515
#
# <ipython-input-6-ac88d000d616> in filter_final_facets(gap_mesh)
#     121     final_facets = filter_and_expand_facets(gap_mesh,
#     122                                  first_pass_size_threshold=2000,
# --> 123                                  normal_closeness=0.985)
#     124
#     125     # after computing final faces, filter for convexity
#
# <ipython-input-6-ac88d000d616> in filter_and_expand_facets(new_mesh, first_pass_size_threshold, normal_closeness)
#      30
#      31     for i in range(0,len(new_mesh.faces)):
# ---> 32         normal_lookup[i] = new_mesh.face_normals[i]
#      33
#      34     global_start_time = time.time()
#
# /usr/local/lib/python3.6/dist-packages/trimesh/base.py in face_normals(self)
#     319         """
#     320         # check shape of cached normals
# --> 321         cached = self._cache['face_normals']
#     322         if np.shape(cached) == np.shape(self._data['faces']):
#     323             return cached
#
# /usr/local/lib/python3.6/dist-packages/trimesh/caching.py in __getitem__(self, key)
#     444         cached : object, or None
#     445         """
# --> 446         self.verify()
#     447         if key in self.cache:
#     448             return self.cache[key]
#
# /usr/local/lib/python3.6/dist-packages/trimesh/caching.py in verify(self)
#     391
#     392         # check the hash of our data
# --> 393         id_new = self._id_function()
#     394
#     395         # things changed
#
# /usr/local/lib/python3.6/dist-packages/trimesh/caching.py in fast_hash(self)
#     595         hashed: int, checksum of data
#     596         """
# --> 597         fast = sum(i.fast_hash() for i in self.data.values())
#     598         return fast
#     599
#
# /usr/local/lib/python3.6/dist-packages/trimesh/caching.py in <genexpr>(.0)
#     595         hashed: int, checksum of data
#     596         """
# --> 597         fast = sum(i.fast_hash() for i in self.data.values())
#     598         return fast
#     599
#
# /usr/local/lib/python3.6/dist-packages/trimesh/caching.py in crc(self)
#     171         return self._hashed_md5
#     172
# --> 173     def crc(self):
#     174         """
#     175         A zlib.crc32 or zlib.adler32 checksum
#
# KeyboardInterrupt:

# %%
print_trimesh(main_mesh,"./test_meshes/main_mesh_stitched_1.off")

# %%
len(child_facets)
# Out:
# 644

# %%
[i[0] for i in child_facets[indexes_not[0]]]
# Out:
# [5676,
#  5676,
#  5676,
#  6247,
#  6247,
#  6247,
#  10883,
#  10883,
#  10883,
#  6519,
#  6519,
#  6519,
#  11015,
#  11015,
#  11015,
#  11015,
#  11015,
#  7419,
#  7419,
#  7419,
#  11037,
#  11037,
#  11037,
#  6381,
#  6381,
#  6381,
#  7383,
#  7383,
#  7383,
#  6499,
#  6499,
#  6499,
#  6526,
#  6526,
#  6526,
#  8253,
#  8253,
#  6840,
#  6840,
#  6840,
#  8207,
#  8207,
#  8207,
#  8207,
#  8207,
#  6902,
#  6902,
#  6902,
#  10885,
#  10885,
#  10885,
#  7030,
#  7030,
#  7030,
#  7030,
#  7030,
#  7166,
#  7166,
#  7166,
#  7166,
#  7237,
#  7237,
#  7237,
#  7312,
#  7312,
#  7312,
#  7324,
#  7324,
#  7324,
#  7349,
#  7349,
#  7349,
#  7468,
#  7468,
#  7468,
#  8246,
#  8246,
#  8246]

# %%
child_facets[0][0]
# Out:
# 65

# %%
a_b_distance[297,2528]
# Out:
# 322.83217480906654

# %%
check = np.vstack((indexes_not[0],indexes_not[1])).T
check
# Out:
# array([[ 242, 2522],
#        [ 242, 2528],
#        [ 242, 8655],
#        [ 258, 2522],
#        [ 258, 2528],
#        [ 258, 8655],
#        [ 259, 2522],
#        [ 259, 2528],
#        [ 259, 8655],
#        [ 260, 2522],
#        [ 260, 2528],
#        [ 260, 8655],
#        [ 263, 2522],
#        [ 263, 2528],
#        [ 263, 3024],
#        [ 263, 3046],
#        [ 263, 8655],
#        [ 265, 2522],
#        [ 265, 2528],
#        [ 265, 8655],
#        [ 267, 2522],
#        [ 267, 2528],
#        [ 267, 8655],
#        [ 268, 2522],
#        [ 268, 2528],
#        [ 268, 8655],
#        [ 271, 2522],
#        [ 271, 2528],
#        [ 271, 8655],
#        [ 277, 2522],
#        [ 277, 2528],
#        [ 277, 8655],
#        [ 278, 2522],
#        [ 278, 2528],
#        [ 278, 8655],
#        [ 295, 2522],
#        [ 295, 2528],
#        [ 296, 2522],
#        [ 296, 2528],
#        [ 296, 8655],
#        [ 297, 2522],
#        [ 297, 2528],
#        [ 297, 3024],
#        [ 297, 3046],
#        [ 297, 8655],
#        [ 298, 2522],
#        [ 298, 2528],
#        [ 298, 8655],
#        [ 301, 2522],
#        [ 301, 2528],
#        [ 301, 8655],
#        [ 303, 2522],
#        [ 303, 2528],
#        [ 303, 3024],
#        [ 303, 3046],
#        [ 303, 8655],
#        [ 307, 2522],
#        [ 307, 2528],
#        [ 307, 3024],
#        [ 307, 8655],
#        [ 309, 2522],
#        [ 309, 2528],
#        [ 309, 8655],
#        [ 313, 2522],
#        [ 313, 2528],
#        [ 313, 8655],
#        [ 314, 2522],
#        [ 314, 2528],
#        [ 314, 8655],
#        [ 316, 2522],
#        [ 316, 2528],
#        [ 316, 8655],
#        [ 319, 2522],
#        [ 319, 2528],
#        [ 319, 8655],
#        [ 354, 2522],
#        [ 354, 2528],
#        [ 354, 8655]])

# %%
#check the normals of groups
for fac1 in main_mesh_facets[2528]:
    for fac2 in child_meshes_facets[1][0][297]:
        print(np.dot(main_mesh.face_normals[fac1],
             child_meshes[1].face_normals[fac2]) > -.95)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# # Debugging the facets

# %%
# download the facets and make sure they match


# download the facets list and see if the process worked:
index = 1
facets_group = np.zeros(len(child_meshes[index].faces)).astype(int)

for i,facet_group in enumerate(child_meshes_facets[index][0]):
    for face in facet_group:
        facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

np.savez("./test_meshes/" + str(index) + "_facet_piece_" + str(index) + ".npz",
         facets_group=facets_group)

from print_trimesh import print_trimesh
print_trimesh(child_meshes[index],"./test_meshes/piece_" + str(index) + ".off")

# %%
len(child_meshes_facets[1][0])

# %%
"""
Seems like the facets are still good but not picking the right facet?
1) Check that the facet on the child side is getting picked correctly

"""
for ff,facet in enumerate(child_meshes_facets[1][0]):
    if 7269 in facet:
        print(ff)
        print(facet)
# Out:
# 297
# [8207 7269 7252 8203 8204 6896 8236]

# %%
""" downloading main mesh facets """
# download the facets list and see if the process worked:

facets_group = np.zeros(len(main_mesh.faces)).astype(int)

for i,facet_group in enumerate(main_mesh_facets):
    for face in facet_group:
        facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

np.savez("./test_meshes/" + "main_mesh_debug" + ".npz",
         facets_group=facets_group)

# %%
for ff,facet in enumerate(main_mesh_facets):
    if 301445 in facet:
        print(ff)
        print(facet)
# Out:
# 2528
# [301600, 301599, 301601, 301602, 301445, 301527, 301610, 301452, 301596]

# %%
"""
Conclusion: 301445 and 297 should be the ones connected

"""

# %%
np.min(a_b_distance)

# %%
[val for val in child_meshes_stitch_facets.values()]

# %%
#print out total time it took: 
print(f"Total time for neuron stitching: {time.time() - global_timer}")

# %%
# check that stitching went well:
output_flag = True
if output_flag == True:
    from print_trimesh import print_trimesh
    print_trimesh(main_mesh,"./test_meshes/main_stitched_together.off")

# %% [markdown]
# # Debugging

# %%
child_index_new = 0
facet_pair = [17, 14624]

print(f"main mesh facets for {facet_pair[1]} = {main_mesh_facets[facet_pair[1]]}")
print(f"child mesh facets for {facet_pair[0]} = {child_meshes_facets[child_index_new][0][facet_pair[0]]}")

# %%
len(combined_mesh.faces)

# %%
current_main_mesh_facet_faces[0]
new_mesh.face_normals[current_main_mesh_facet_faces[0]]

# %%
new_mesh = combined_mesh
facet_1=current_main_mesh_facet_faces
facet_2=current_child_facet_faces_adjusted
delete_facets=False,
return_added_mesh=False

print(f"facet_1 = {facet_1}")
print(f"facet_2 = {facet_2}")


#how to find the normals of facet groups:
facet_group_1_normal = new_mesh.face_normals[facet_1[0]]
facet_group_2_normal = new_mesh.face_normals[facet_2[0]]

print("facet_group_1_normal = " + str(facet_group_1_normal))
print("facet_group_2_normal = " + str(facet_group_2_normal))

#get the correct version of the normals: (might need to flip them if going in opposite direction)
if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
    print("same direction normals")
    pass
elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
    print("opposite direction normals")
    facet_group_2_normal = facet_group_2_normal*-1
else:
    print("Not correct normals")
    #raise Exception("Not correct normals")

#print(facet_group_1_normal,facet_group_2_normal)

# make each row correspond to a single face 
edges = new_mesh.edges_sorted.reshape((-1, 6))
# get the edges for each facet
edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                           for i in edges_facet])

#the list of boundary edges and unique points in the boundary edges
edge_0 = edges_boundary[0]
edge_1 = edges_boundary[1]



#gets the unique number of points
edge_0_points = np.unique(np.hstack(edge_0))
edge_1_points = np.unique(np.hstack(edge_1))
print("Found boundary edges")
"""
get the dot product of all the points
"""

print("edge_0_points = " + str(edge_0_points))
print("edge_1_points = " + str(edge_1_points))

#get any 2 points on the triangle and make that the reference edge
edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

print("edge_0_anchor_points = " + str(edge_0_anchor_points))
#gets the starting index for the 1st facet (so that the start of the stitching is close)
max_index = 0
max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

for i in range(1,len(edge_0_points)):
    current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

    if current_magnitude > max_magnitude:
        max_index = i
        max_magnitude = current_magnitude

edge_0_starting_point = edge_0_points[max_index]

#gets the starting index for the 2nd facet (so that the start of the stitching is close)
max_index = 0
max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

for i in range(1,len(edge_1_points)):
    
    current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
    if current_magnitude > max_magnitude:
        max_index = i
        max_magnitude = current_magnitude

edge_1_starting_point = edge_1_points[max_index]

print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
#print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

# %%
start_time = time.time()
a = main_mesh.face_normals[:55000]
b = child_meshes[0].face_normals
np.dot(a,b.T)
print(f"Total time = {time.time() - start_time}")

# %%
from itertools import izip, starmap

sum(starmap(operator.mul, izip(a,b)))

# %%
x = np.array([[1,2,3],[4,5,6]])
y = np.array([[1,2,3],[4,5,6],[7,1,2]])

np.dot(x,y.T)

# %% [markdown]
# # testing optomization for pairwise

# %%
child_mesh_optimization = trimesh.load_mesh("test_meshes/big_neuron_child_0.off")
child_mesh_optimization.show()

# %%
main_mesh_optimization = trimesh.load_mesh("./test_meshes/optimization_2.off")

# %%
#generate the facets for both of them

start_time = time.time()
first_pass_size_threshold=6000


example_mesh = main_mesh_optimization

normal_closeness=0.995
total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
print(len(total_normals[:,0]*total_normals[:,1]))
total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
total_normal_dots_facet_mask = total_normal_dots > normal_closeness

#try sending it to the graph function


mesh2 = example_mesh
components = trimesh.graph.connected_components(mesh2.face_adjacency[total_normal_dots_facet_mask],
                                      nodes=np.arange(len(mesh2.faces)),
                                      min_len=2,
                                      engine="None")


#filter by the size
size_filtered_components = [facet_list for facet_list in components if find_polygon_area(mesh2,facet_list) > first_pass_size_threshold]

#filter by the convexity
final_facets_mean_filtered,final_facets_centers = filter_final_facets(mesh2,size_filtered_components)

print(f"Total Time = {time.time() - start_time}")

print(len(final_facets_mean_filtered))

# %%
#get the facets for the child mesh
start_time = time.time()
first_pass_size_threshold=6000


example_mesh = child_mesh_optimization

#switch out with dot product
normal_closeness=0.995
total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
print(len(total_normals[:,0]*total_normals[:,1]))
total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
total_normal_dots_facet_mask = total_normal_dots > normal_closeness

#try sending it to the graph function


mesh2 = example_mesh
components = trimesh.graph.connected_components(mesh2.face_adjacency[total_normal_dots_facet_mask],
                                      nodes=np.arange(len(mesh2.faces)),
                                      min_len=2,
                                      engine="None")


#filter by the size
size_filtered_components = [facet_list for facet_list in components if find_polygon_area(mesh2,facet_list) > first_pass_size_threshold]

#filter by the convexity
child_final_facets_mean_filtered,child_final_facets_centers = filter_final_facets(mesh2,size_filtered_components)

print(f"Total Time = {time.time() - start_time}")

print(len(child_final_facets_mean_filtered))

# %%
print(child_final_facets_centers)

# %% [markdown]
# # Final Optimized Pairwise Facets

# %%
start_time = time.time()
a_New = np.array(child_final_facets_centers).astype("float")
b_New = np.array(final_facets_centers).astype("float")


from scipy.spatial import distance_matrix
a_b_distance = distance_matrix(a_New, b_New)
#print(f"Time = {time.time() - start_time}")

#now get the indexes that are within stitch distance
stitch_distance_threshold=15000
indexes_not = np.where(a_b_distance < stitch_distance_threshold)


child_normals = child_mesh_optimization.face_normals[indexes_not[0]]
main_normals = main_mesh_optimization.face_normals[indexes_not[1]]

#start_time = time.time()
#dot_products = np.dot(child_normals,main_normals.T)
normal_closeness=0.995
total_normal_dots = np.sum(child_normals*main_normals,axis=1)
total_normal_dots_facet_mask = total_normal_dots > normal_closeness

print(f"Total Time = {time.time() - start_time}")

final_pairs = (np.array(indexes_not).T)[total_normal_dots_facet_mask]
final_pairs

# %%
np.array(indexes_not).T

# %%
indexes_not

# %%
total_normal_dots_facet_mask.shape

# %%
child_normals

# %%
child_normals = child_mesh_optimization.face_normals[indexes_not[0]]

# %%
main_normals = main_mesh_optimization.face_normals[indexes_not[1]]

# %%
#start_time = time.time()
dot_products = np.dot(child_normals,main_normals.T)
print(f"Total Time = {time.time() - start_time}")
