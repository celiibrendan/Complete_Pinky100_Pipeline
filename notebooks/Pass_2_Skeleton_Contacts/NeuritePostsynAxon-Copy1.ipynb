# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from meshparty import trimesh_io

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#will take in and populate the soma table based on the key it gets
def axon_verts_faces(query_key):
    
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                   & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).fetch("vertex_indices","triangle_indices")

    if len(vertices_soma) > 0:
        print("Soma found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]
                                       ).fetch("vertex_indices","triangle_indices")
        if len(vertices_soma) > 0:
            print("Soma found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Soma exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
            
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURITES")) == False:
    os.mkdir("pymesh_NEURITES")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURITES"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURITES"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
pinky.Mesh.proj()
# Out:
# *segmentation  *segment_id
# +------------+ +------------+
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
#    ...
#  (217567 tuples)

# %%
# key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
#                                  & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj() )

# %%
#shows that there are no orphans with axons
orphan_key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentOrphan.ComponentOrphan() 
                                 & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj())

# %%
pinky.CompartmentOrphan.ComponentOrphan() & "compartment_type='Axon-Soma'"
# Out:
# *segmentation  *segment_id    *decimation_ra *compartment_t *component_ind n_vertex_indic n_triangle_ind vertex_ind triangle_i
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634135 0.35           Axon-Soma      0              17821          35437          =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      0              30             33             =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      1              1557           3081           =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      2              32006          63769          =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      3              2334           4655           =BLOB=     =BLOB=
#  (5 tuples)

# %%
@schema
class NeuritePostsynAxon(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    vertices  :longblob #vertices for extracted axon
    triangles :longblob #faces for extracted axon
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :tinyint unsigned #the amount of segments the neurite was originally split into
    largest_mesh_perc : float #the percentage of the entire mesh that the largest submesh makes up
     
    """
    
    
    key_source = dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]) 

    
    def make(self, key):
        global_time = time.time()
        
        
        print(str(key["segment_id"])+ ":")
        
        #create return key
        return_key = key.copy()


        #get the vertices and triangles for the Soma
        start_time = time.time()
        vertices_whole, triangles_whole = axon_verts_faces(key)
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")


        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():
            print("Error no axon")


        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])



        #find the bounding box
        # start_time = time.time()
        # mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        # mesh.export(str(key["segment_id"]) + "_axon.off","off")

        #now skeletonize the mesh

        #gets all of the different parts
        mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                            mesh.edges_sparse,
                                                            directed=False,
                                                            return_labels=True)

        new_key["n_bodies"] = count
        values = np.array(labels)
        searchval = 0
        ii = np.where(values == searchval)[0]
        new_key["largest_mesh_perc"] = len(ii)/len(labels)

        print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")



        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        meshfix = pymeshfix.MeshFix(vertices_whole,triangles_whole)
        meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
        print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

        #print("Step 2: Writing Off File")
        start_time = time.time()
        #write the new mesh to off file
        path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
        print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_fix_manifold(key)
        print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

        print(output_mesh[:-4])

        #send to be skeletonized
        start_time = time.time()
        return_value = cm.calcification(output_mesh[:-4])
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



        #read in the skeleton files into an array
        bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


        start_time = time.time()
        new_key["n_edges"] = len(bone_array)
        new_key["edges"] = bone_array
        
        new_key["vertices"] = vertices_whole
        new_key["triangles"] = triangles_whole
        
        self.insert1(new_key,skip_duplicates=True)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
#(schema.jobs & "table_name='__neurite_postsyn_axon'").delete()

# %%
start_time = time.time()
NeuritePostsynAxon.populate(reserve_jobs = True)
print(f"Total time = {time.time() - start_time}")
# Out:
# 648518346349472574:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26352906227111816
# Step 2a: Getting the number of splits: 0.2710127830505371
# Step 2b: Pymesh shrinkwrapping: 0.13039588928222656
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05918240547180176
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7013254165649414
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349472574_mls
# Step 5: Generating and reading Skeleton: 0.3014204502105713
# Step 6: Inserting dictionary: 0.06363224983215332
# Total time: 1.5286681652069092
#
#
#
# 648518346349472601:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2511789798736572
# Step 2a: Getting the number of splits: 0.2593824863433838
# Step 2b: Pymesh shrinkwrapping: 0.1172633171081543
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05185389518737793
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5963895320892334
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349472601_mls
# Step 5: Generating and reading Skeleton: 0.2696261405944824
# Step 6: Inserting dictionary: 0.048601388931274414
# Total time: 1.344357967376709
#
#
#
# 648518346349473160:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6828889846801758
# Step 2a: Getting the number of splits: 0.7824065685272217
# Step 2b: Pymesh shrinkwrapping: 3.474299907684326
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.863213062286377
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.026357412338257
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473160_mls
# Step 5: Generating and reading Skeleton: 4.9146811962127686
# Step 6: Inserting dictionary: 0.5352973937988281
# Total time: 12.597872257232666
#
#
#
# 648518346349473804:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3735654354095459
# Step 2a: Getting the number of splits: 0.39803647994995117
# Step 2b: Pymesh shrinkwrapping: 1.1651384830474854
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.20018959045410156
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8897068500518799
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473804_mls
# Step 5: Generating and reading Skeleton: 1.0206067562103271
# Step 6: Inserting dictionary: 0.14490056037902832
# Total time: 3.819985866546631
#
#
#
# 648518346349473813:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.21042776107788086
# Step 2a: Getting the number of splits: 0.215195894241333
# Step 2b: Pymesh shrinkwrapping: 0.0590207576751709
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.026662111282348633
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6268525123596191
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473813_mls
# Step 5: Generating and reading Skeleton: 0.23597025871276855
# Step 6: Inserting dictionary: 0.04322981834411621
# Total time: 1.2085177898406982
#
#
#
# 648518346349473835:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.07820701599121094
# Step 2a: Getting the number of splits: 0.08442258834838867
# Step 2b: Pymesh shrinkwrapping: 0.09671449661254883
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.038323402404785156
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6103222370147705
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473835_mls
# Step 5: Generating and reading Skeleton: 0.2406916618347168
# Step 6: Inserting dictionary: 0.057584524154663086
# Total time: 1.1299304962158203
#
#
#
# 648518346349474146:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.7794802188873291
# Step 2a: Getting the number of splits: 0.9454705715179443
# Step 2b: Pymesh shrinkwrapping: 5.009594678878784
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.1869847774505615
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.7432098388671875
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349474146_mls
# Step 5: Generating and reading Skeleton: 6.7222747802734375
# Step 6: Inserting dictionary: 0.670168399810791
# Total time: 17.27929663658142
#
#
#
# 648518346349477981:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5123322010040283
# Step 2a: Getting the number of splits: 0.6067101955413818
# Step 2b: Pymesh shrinkwrapping: 13.573546886444092
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7915594577789307
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.106222152709961
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349477981_mls
# Step 5: Generating and reading Skeleton: 4.692785263061523
# Step 6: Inserting dictionary: 0.46952390670776367
# Total time: 22.242180824279785
#
#
#
# 648518346349478183:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3941938877105713
# Step 2a: Getting the number of splits: 0.454451322555542
# Step 2b: Pymesh shrinkwrapping: 1.9533665180206299
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.49527549743652344
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4181461334228516
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478183_mls
# Step 5: Generating and reading Skeleton: 2.606191635131836
# Step 6: Inserting dictionary: 0.297121524810791
# Total time: 7.226322650909424
#
#
#
# 648518346349478330:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3682863712310791
# Step 2a: Getting the number of splits: 0.41507625579833984
# Step 2b: Pymesh shrinkwrapping: 1.3566968441009521
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.37222838401794434
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.162444829940796
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478330_mls
# Step 5: Generating and reading Skeleton: 2.0560145378112793
# Step 6: Inserting dictionary: 0.2441556453704834
# Total time: 5.608084440231323
#
#
#
# 648518346349478348:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.465991735458374
# Step 2a: Getting the number of splits: 0.5358378887176514
# Step 2b: Pymesh shrinkwrapping: 5.509746074676514
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7032296657562256
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.5909831523895264
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478348_mls
# Step 5: Generating and reading Skeleton: 3.4607632160186768
# Step 6: Inserting dictionary: 0.3601722717285156
# Total time: 12.16188907623291
#
#
#
# 648518346349478473:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1749744415283203
# Step 2a: Getting the number of splits: 0.1793346405029297
# Step 2b: Pymesh shrinkwrapping: 0.03042125701904297
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0175626277923584
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6019587516784668
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478473_mls
# Step 5: Generating and reading Skeleton: 0.19106578826904297
# Step 6: Inserting dictionary: 0.041213274002075195
# Total time: 1.0636334419250488
#
#
#
# 648518346349478700:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.450070858001709
# Step 2a: Getting the number of splits: 0.49909520149230957
# Step 2b: Pymesh shrinkwrapping: 1.5484509468078613
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4838552474975586
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2596354484558105
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478700_mls
# Step 5: Generating and reading Skeleton: 2.363297700881958
# Step 6: Inserting dictionary: 0.2553679943084717
# Total time: 6.410964250564575
#
#
#
# 648518346349478785:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3021063804626465
# Step 2a: Getting the number of splits: 0.30908894538879395
# Step 2b: Pymesh shrinkwrapping: 0.2642545700073242
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0551607608795166
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6546709537506104
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478785_mls
# Step 5: Generating and reading Skeleton: 0.26952290534973145
# Step 6: Inserting dictionary: 0.10339665412902832
# Total time: 1.6576130390167236
#
#
#
# 648518346349478830:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0

# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.23828697204589844
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9560375213623047
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349493117_mls
# Step 5: Generating and reading Skeleton: 1.3027937412261963
# Step 6: Inserting dictionary: 0.15956568717956543
# Total time: 3.822150707244873
#
#
#
# 648518346349494087:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2333965301513672
# Step 2a: Getting the number of splits: 0.23885750770568848
# Step 2b: Pymesh shrinkwrapping: 0.04510045051574707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.02050161361694336
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5787353515625
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349494087_mls
# Step 5: Generating and reading Skeleton: 0.2092301845550537
# Step 6: Inserting dictionary: 0.04289674758911133
# Total time: 1.1367862224578857
#
#
#
# 648518346349494539:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2062232494354248
# Step 2a: Getting the number of splits: 0.21810197830200195
# Step 2b: Pymesh shrinkwrapping: 0.22129249572753906
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08730840682983398
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7273681163787842
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349494539_mls
# Step 5: Generating and reading Skeleton: 0.4667482376098633
# Step 6: Inserting dictionary: 0.07783985137939453
# Total time: 1.8001093864440918
#
#
#
# 648518346349495174:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.25707030296325684
# Step 2a: Getting the number of splits: 0.26530981063842773
# Step 2b: Pymesh shrinkwrapping: 0.12924432754516602
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.051059722900390625
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6178882122039795
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495174_mls
# Step 5: Generating and reading Skeleton: 0.30220770835876465
# Step 6: Inserting dictionary: 0.0635383129119873
# Total time: 1.4312846660614014
#
#
#
# 648518346349495243:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20757746696472168
# Step 2a: Getting the number of splits: 0.21453571319580078
# Step 2b: Pymesh shrinkwrapping: 0.10397195816040039
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03945207595825195
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5874981880187988
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495243_mls
# Step 5: Generating and reading Skeleton: 0.24124979972839355
# Step 6: Inserting dictionary: 0.052407026290893555
# Total time: 1.2405595779418945
#
#
#
# 648518346349495660:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3699820041656494
# Step 2a: Getting the number of splits: 0.3798365592956543
# Step 2b: Pymesh shrinkwrapping: 0.17458605766296387
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0719914436340332
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6629002094268799
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495660_mls
# Step 5: Generating and reading Skeleton: 0.3661360740661621
# Step 6: Inserting dictionary: 0.0710446834564209
# Total time: 1.7281711101531982
#
#
#
# 648518346349495846:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10395097732543945
# Step 2a: Getting the number of splits: 0.11191272735595703
# Step 2b: Pymesh shrinkwrapping: 0.28962111473083496
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05501985549926758
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6161582469940186
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495846_mls
# Step 5: Generating and reading Skeleton: 0.32404422760009766
# Step 6: Inserting dictionary: 0.06611776351928711
# Total time: 1.4646453857421875
#
#
#
# 648518346349495971:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2289438247680664
# Step 2a: Getting the number of splits: 0.2618217468261719
# Step 2b: Pymesh shrinkwrapping: 0.8678224086761475
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2612926959991455
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9563040733337402
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495971_mls
# Step 5: Generating and reading Skeleton: 1.3921844959259033
# Step 6: Inserting dictionary: 0.16322040557861328
# Total time: 3.903759241104126
#
#
#
# 648518346349496554:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2998824119567871
# Step 2a: Getting the number of splits: 0.30884861946105957
# Step 2b: Pymesh shrinkwrapping: 0.14366459846496582
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05724024772644043
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6482753753662109
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349496554_mls
# Step 5: Generating and reading Skeleton: 0.3300597667694092
# Step 6: Inserting dictionary: 0.06888270378112793
# Total time: 1.5591049194335938
#
#
#
# 648518346349496672:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.28275012969970703
# Step 2a: Getting the number of splits: 0.2934551239013672
# Step 2b: Pymesh shrinkwrapping: 0.1742565631866455
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06726908683776855
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349498566_mls
# Step 5: Generating and reading Skeleton: 0.3569049835205078
# Step 6: Inserting dictionary: 0.06453227996826172
# Total time: 1.5173296928405762
#
#
#
# 648518346349498835:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2500643730163574
# Step 2a: Getting the number of splits: 0.2582814693450928
# Step 2b: Pymesh shrinkwrapping: 0.13508844375610352
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05618166923522949
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.640383243560791
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349498835_mls
# Step 5: Generating and reading Skeleton: 0.2945444583892822
# Step 6: Inserting dictionary: 0.06599664688110352
# Total time: 1.4519386291503906
#
#
#
# 648518346349499297:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2658202648162842
# Step 2a: Getting the number of splits: 0.27370214462280273
# Step 2b: Pymesh shrinkwrapping: 0.12137866020202637
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05160975456237793
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6293022632598877
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499297_mls
# Step 5: Generating and reading Skeleton: 0.28327345848083496
# Step 6: Inserting dictionary: 0.06405425071716309
# Total time: 1.424813985824585
#
#
#
# 648518346349499581:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42241525650024414
# Step 2a: Getting the number of splits: 0.4450352191925049
# Step 2b: Pymesh shrinkwrapping: 0.5691142082214355
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.17490005493164062
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8503291606903076
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499581_mls
# Step 5: Generating and reading Skeleton: 1.006951093673706
# Step 6: Inserting dictionary: 0.1419370174407959
# Total time: 3.1895699501037598
#
#
#
# 648518346349499679:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3356461524963379
# Step 2a: Getting the number of splits: 0.37746620178222656
# Step 2b: Pymesh shrinkwrapping: 1.1733958721160889
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.38050007820129395
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.110447883605957
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499679_mls
# Step 5: Generating and reading Skeleton: 1.8003242015838623
# Step 6: Inserting dictionary: 0.212874174118042
# Total time: 5.055920124053955
#
#
#
# 648518346349499680:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2737390995025635
# Step 2a: Getting the number of splits: 0.2828793525695801
# Step 2b: Pymesh shrinkwrapping: 0.1464381217956543
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0606687068939209
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6599164009094238
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499680_mls
# Step 5: Generating and reading Skeleton: 0.3225867748260498
# Step 6: Inserting dictionary: 0.07146334648132324
# Total time: 1.545274019241333
#
#
#
# 648518346349499701:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.28482985496520996
# Step 2a: Getting the number of splits: 0.29621219635009766
# Step 2b: Pymesh shrinkwrapping: 0.19709277153015137
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07950615882873535
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7335793972015381
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499701_mls
# Step 5: Generating and reading Skeleton: 0.41379261016845703
# Step 6: Inserting dictionary: 0.07532763481140137
# Total time: 1.7965047359466553
#
#
#
# 648518346349499773:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2892625331878662
# Step 2a: Getting the number of splits: 0.2986292839050293
# Step 2b: Pymesh shrinkwrapping: 0.16074514389038086
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0696871280670166
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6940629482269287
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499773_mls
# Step 5: Generating and reading Skeleton: 0.37642645835876465
# Step 6: Inserting dictionary: 0.06780600547790527
# Total time: 1.668344259262085
#
#
#
# 648518346349499803:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.287869930267334
# Step 2a: Getting the number of splits: 0.31867551803588867
# Step 2b: Pymesh shrinkwrapping: 2.0739290714263916
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2457423210144043
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9761936664581299
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499803_mls
# Step 5: Generating and reading Skeleton: 1.2908036708831787
# Step 6: Inserting dictionary: 0.16223478317260742
# Total time: 5.068750619888306
#
#
#
# 648518346349499828:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.48044824600219727
# Step 2a: Getting the number of splits: 0.566314697265625
# Step 2b: Pymesh shrinkwrapping: 2.502664089202881
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6486060619354248
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.6586277484893799
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499828_mls
# Step 5: Generating and reading Skeleton: 3.419191598892212
# Step 6: Inserting dictionary: 0.3849468231201172
# Total time: 9.183085680007935
#
#
#
# 648518346349499852:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.33423304557800293
# Step 2a: Getting the number of splits: 0.3749401569366455
# Step 2b: Pymesh shrinkwrapping: 1.1360971927642822
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.31633973121643066
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2030189037322998
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499852_mls
# Step 5: Generating and reading Skeleton: 1.8050482273101807
# Step 6: Inserting dictionary: 0.21353864669799805
# Total time: 5.050304412841797
#
#
#
# 648518346349499876:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4902670383453369
# Step 2a: Getting the number of splits: 0.5696291923522949
# Step 2b: Pymesh shrinkwrapping: 5.8833887577056885
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6702768802642822
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.8950724601745605
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499876_mls
# Step 5: Generating and reading Skeleton: 3.662013053894043
# Step 6: Inserting dictionary: 0.40043163299560547
# Total time: 13.081998825073242
#
#
#
# 648518346349499928:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11908507347106934
# Step 2a: Getting the number of splits: 0.13009357452392578
# Step 2b: Pymesh shrinkwrapping: 0.43067169189453125
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07573270797729492
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6956667900085449
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499928_mls
# Step 5: Generating and reading Skeleton: 0.4043905735015869
# Step 6: Inserting dictionary: 0.07450509071350098
# Total time: 1.8126704692840576
#
#
#
# 648518346349499939:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5115046501159668
# Step 2a: Getting the number of splits: 0.5723166465759277
# Step 2b: Pymesh shrinkwrapping: 1.9059150218963623
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4915313720703125
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.5391833782196045
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499939_mls
# Step 5: Generating and reading Skeleton: 2.8274834156036377
# Step 6: Inserting dictionary: 0.30882954597473145
# Total time: 7.646397829055786
#
#
#
# 648518346349500120:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09499645233154297
# Step 2a: Getting the number of splits: 0.09887528419494629
# Step 2b: Pymesh shrinkwrapping: 0.038741350173950195
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.017664432525634766
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6148989200592041
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500120_mls
# Step 5: Generating and reading Skeleton: 0.13485479354858398
# Step 6: Inserting dictionary: 0.03636884689331055
# Total time: 0.9424796104431152
#
#
#
# 648518346349500138:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3523600101470947
# Step 2a: Getting the number of splits: 0.3856632709503174
# Step 2b: Pymesh shrinkwrapping: 0.8882124423980713
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.25722527503967285
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0595531463623047
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500138_mls
# Step 5: Generating and reading Skeleton: 1.3917291164398193
# Step 6: Inserting dictionary: 0.1772763729095459
# Total time: 4.160775661468506
#
#
#
# 648518346349500139:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2179882526397705
# Step 2a: Getting the number of splits: 0.2274317741394043
# Step 2b: Pymesh shrinkwrapping: 0.1721036434173584
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06900262832641602
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6932599544525146
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500139_mls
# Step 5: Generating and reading Skeleton: 0.37617921829223633
# Step 6: Inserting dictionary: 0.09169960021972656
# Total time: 1.6316189765930176
#
#
#
# 648518346349500162:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1964430809020996
# Step 2a: Getting the number of splits: 0.20608162879943848
# Step 2b: Pymesh shrinkwrapping: 0.15910744667053223
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0602414608001709
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6314058303833008
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500162_mls
# Step 5: Generating and reading Skeleton: 0.3100149631500244
# Step 6: Inserting dictionary: 0.05547761917114258
# Total time: 1.423353910446167
#
#
#
# 648518346349500324:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.518294095993042
# Step 2a: Getting the number of splits: 0.584061861038208
# Step 2b: Pymesh shrinkwrapping: 2.1240830421447754
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5523085594177246
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.566580057144165
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500324_mls
# Step 5: Generating and reading Skeleton: 2.9156949520111084
# Step 6: Inserting dictionary: 0.333482027053833
# Total time: 8.077381134033203
#
#
#
# 648518346349500657:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.27478480339050293
# Step 2a: Getting the number of splits: 0.2832474708557129
# Step 2b: Pymesh shrinkwrapping: 0.14362668991088867
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06103372573852539
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7071597576141357
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500657_mls
# Step 5: Generating and reading Skeleton: 0.30808544158935547
# Step 6: Inserting dictionary: 0.06272578239440918
# Total time: 1.567615032196045
#
#
#
# 648518346349500725:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5539345741271973
# Step 2a: Getting the number of splits: 0.6388087272644043
# Step 2b: Pymesh shrinkwrapping: 2.813476085662842
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7142496109008789
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.8847391605377197
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500725_mls
# Step 5: Generating and reading Skeleton: 3.922724485397339
# Step 6: Inserting dictionary: 0.4146568775177002
# Total time: 10.390258073806763
#
#
#
# 648518346349500954:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18233132362365723
# Step 2a: Getting the number of splits: 0.1911001205444336
# Step 2b: Pymesh shrinkwrapping: 0.1347653865814209
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.056566476821899414
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6523988246917725
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500954_mls
# Step 5: Generating and reading Skeleton: 0.29098010063171387
# Step 6: Inserting dictionary: 0.06294846534729004
# Total time: 1.3899726867675781
#
#
#
# 648518346349501175:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.277874231338501
# Step 2a: Getting the number of splits: 0.2839994430541992
# Step 2b: Pymesh shrinkwrapping: 0.17942023277282715
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03720879554748535
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6083860397338867
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501175_mls
# Step 5: Generating and reading Skeleton: 0.22801733016967773
# Step 6: Inserting dictionary: 0.04533672332763672
# Total time: 1.383727788925171
#
#
#
# 648518346349501216:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.23024892807006836
# Step 2a: Getting the number of splits: 0.2342991828918457
# Step 2b: Pymesh shrinkwrapping: 0.026490211486816406
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.013005971908569336
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5846884250640869
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501216_mls
# Step 5: Generating and reading Skeleton: 0.19460773468017578
# Step 6: Inserting dictionary: 0.03954958915710449
# Total time: 1.0936954021453857
#
#
#
# 648518346349501481:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20923781394958496
# Step 2a: Getting the number of splits: 0.21435165405273438
# Step 2b: Pymesh shrinkwrapping: 0.05580282211303711
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.026698589324951172
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5871357917785645
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501481_mls
# Step 5: Generating and reading Skeleton: 0.1869494915008545
# Step 6: Inserting dictionary: 0.03904414176940918
# Total time: 1.1110498905181885
#
#
#
# 648518346349501517:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.16433000564575195
# Step 2a: Getting the number of splits: 0.17476654052734375
# Step 2b: Pymesh shrinkwrapping: 0.17179584503173828
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07159304618835449
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6694808006286621
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501517_mls
# Step 5: Generating and reading Skeleton: 0.3702964782714844
# Step 6: Inserting dictionary: 0.08153009414672852
# Total time: 1.5415072441101074
#
#
#
# 648518346349501597:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.39757633209228516
# Step 2a: Getting the number of splits: 0.4100959300994873
# Step 2b: Pymesh shrinkwrapping: 0.22528910636901855
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08760499954223633
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7412374019622803
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501597_mls
# Step 5: Generating and reading Skeleton: 0.4432835578918457
# Step 6: Inserting dictionary: 0.07521510124206543
# Total time: 1.9842886924743652
#
#
#
# 648518346349501746:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19568800926208496
# Step 2a: Getting the number of splits: 0.20500969886779785
# Step 2b: Pymesh shrinkwrapping: 0.16654014587402344
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06742095947265625
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6584999561309814
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349501746_mls
# Step 5: Generating and reading Skeleton: 0.32418227195739746
# Step 6: Inserting dictionary: 0.06620573997497559
# Total time: 1.4891855716705322
#
#
#
# 648518346349502049:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2716231346130371
# Step 2a: Getting the number of splits: 0.29673027992248535
# Step 2b: Pymesh shrinkwrapping: 0.6152760982513428
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.17892122268676758
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8845546245574951
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349502049_mls
# ...
# Step 6: Inserting dictionary: 0.618220329284668
# Total time: 15.590638399124146
#
#
#
# 648518346349506684:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.46053361892700195
# Step 2a: Getting the number of splits: 0.536036491394043
# Step 2b: Pymesh shrinkwrapping: 2.247645854949951
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5878007411956787
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.621232032775879
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349506684_mls
# Step 5: Generating and reading Skeleton: 3.084357500076294
# Step 6: Inserting dictionary: 0.35230159759521484
# Total time: 8.430963516235352
#
#
#
# 648518346349507015:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20440101623535156
# Step 2a: Getting the number of splits: 0.21025371551513672
# Step 2b: Pymesh shrinkwrapping: 0.0726771354675293
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.034461259841918945
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6172773838043213
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507015_mls
# Step 5: Generating and reading Skeleton: 0.20622682571411133
# Step 6: Inserting dictionary: 0.04564547538757324
# Total time: 1.1880877017974854
#
#
#
# 648518346349507103:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3530299663543701
# Step 2a: Getting the number of splits: 0.3854818344116211
# Step 2b: Pymesh shrinkwrapping: 1.5368525981903076
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2790203094482422
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9938020706176758
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507103_mls
# Step 5: Generating and reading Skeleton: 1.5533056259155273
# Step 6: Inserting dictionary: 0.18771910667419434
# Total time: 4.937465190887451
#
#
#
# 648518346349507537:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1690514087677002
# Step 2a: Getting the number of splits: 0.17383551597595215
# Step 2b: Pymesh shrinkwrapping: 0.13031458854675293
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.026085615158081055
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6308393478393555
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507537_mls
# Step 5: Generating and reading Skeleton: 0.20405912399291992
# Step 6: Inserting dictionary: 0.055136919021606445
# Total time: 1.2239735126495361
#
#
#
# 648518346349507658:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.05136919021606445
# Step 2a: Getting the number of splits: 0.056526899337768555
# Step 2b: Pymesh shrinkwrapping: 0.07016801834106445
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.027086973190307617
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5715177059173584
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507658_mls
# Step 5: Generating and reading Skeleton: 0.24569177627563477
# Step 6: Inserting dictionary: 0.04193830490112305
# Total time: 1.013892650604248
#
#
#
# 648518346349507788:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17607569694519043
# Step 2a: Getting the number of splits: 0.18123340606689453
# Step 2b: Pymesh shrinkwrapping: 0.07304835319519043
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03197503089904785
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6548566818237305
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507788_mls
# Step 5: Generating and reading Skeleton: 0.21909284591674805
# Step 6: Inserting dictionary: 0.0451202392578125
# Total time: 1.2069590091705322
#
#
#
# 648518346349507963:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19115090370178223
# Step 2a: Getting the number of splits: 0.19744420051574707
# Step 2b: Pymesh shrinkwrapping: 0.17626690864562988
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04417586326599121
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.657968282699585
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507963_mls
# Step 5: Generating and reading Skeleton: 0.22174787521362305
# Step 6: Inserting dictionary: 0.050371646881103516
# Total time: 1.3493146896362305
#
#
#
# 648518346349507964:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.40996670722961426
# Step 2a: Getting the number of splits: 0.45244336128234863
# Step 2b: Pymesh shrinkwrapping: 1.7430779933929443
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.31591129302978516
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.083176851272583
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507964_mls
# Step 5: Generating and reading Skeleton: 1.7638626098632812
# Step 6: Inserting dictionary: 0.21659111976623535
# Total time: 5.57646918296814
#
#
#
# 648518346349508925:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.30561351776123047
# Step 2a: Getting the number of splits: 0.31068968772888184
# Step 2b: Pymesh shrinkwrapping: 0.09623932838439941
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.019843339920043945
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5579938888549805
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508925_mls
# Step 5: Generating and reading Skeleton: 0.23083853721618652
# Step 6: Inserting dictionary: 0.04636693000793457
# Total time: 1.2630298137664795
#
#
#
# 648518346349509112:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2927570343017578
# Step 2a: Getting the number of splits: 0.30098485946655273
# Step 2b: Pymesh shrinkwrapping: 0.22464561462402344
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.044891357421875
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6461529731750488
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509112_mls
# Step 5: Generating and reading Skeleton: 0.2484595775604248
# Step 6: Inserting dictionary: 0.05955386161804199
# Total time: 1.525724172592163
#
#
#
# 648518346349509204:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3930933475494385
# Step 2a: Getting the number of splits: 0.4285430908203125
# Step 2b: Pymesh shrinkwrapping: 2.505837917327881
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2854881286621094
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.074739933013916
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509204_mls
# Step 5: Generating and reading Skeleton: 1.437389612197876
# Step 6: Inserting dictionary: 0.1833963394165039
# Total time: 5.916671276092529
#
#
#
# 648518346349509280:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34358692169189453
# Step 2a: Getting the number of splits: 0.35868310928344727
# Step 2b: Pymesh shrinkwrapping: 0.4976308345794678
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07744860649108887
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7168793678283691
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509280_mls
# Step 5: Generating and reading Skeleton: 0.3854970932006836
# Step 6: Inserting dictionary: 0.0721883773803711
# Total time: 2.10963773727417
#
#
#
# 648518346349509300:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.25746607780456543
# Step 2a: Getting the number of splits: 0.26712822914123535
# Step 2b: Pymesh shrinkwrapping: 0.18401002883911133
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07442975044250488
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6912834644317627
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509300_mls
# Step 5: Generating and reading Skeleton: 0.3653066158294678
# Step 6: Inserting dictionary: 0.07076001167297363
# Total time: 1.6540412902832031
#
#
#
# 648518346349509378:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.27280306816101074
# Step 2a: Getting the number of splits: 0.3155183792114258
# Step 2b: Pymesh shrinkwrapping: 1.474170446395874
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.37540459632873535
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2132718563079834
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509378_mls
# Step 5: Generating and reading Skeleton: 1.9596290588378906
# Step 6: Inserting dictionary: 0.23784971237182617
# Total time: 5.577965021133423
#
#
#
# 648518346349509399:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.48752331733703613
# Step 2a: Getting the number of splits: 0.5486652851104736
# Step 2b: Pymesh shrinkwrapping: 2.069485664367676
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5267181396484375
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4440712928771973
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509399_mls
# Step 5: Generating and reading Skeleton: 2.7795464992523193
# Step 6: Inserting dictionary: 0.32077527046203613
# Total time: 7.690225124359131
#
#
#
# 648518346349509487:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.27251505851745605
# Step 2a: Getting the number of splits: 0.2814924716949463
# Step 2b: Pymesh shrinkwrapping: 0.15024733543395996
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0644681453704834
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.660006046295166
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509487_mls
# Step 5: Generating and reading Skeleton: 0.33910083770751953
# Step 6: Inserting dictionary: 0.06865096092224121
# Total time: 1.5651335716247559
#
#
#
# 648518346349509516:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18133997917175293
# Step 2a: Getting the number of splits: 0.19168829917907715
# Step 2b: Pymesh shrinkwrapping: 0.21131229400634766
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10080599784851074
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6544394493103027
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509516_mls
# Step 5: Generating and reading Skeleton: 0.3905177116394043
# Step 6: Inserting dictionary: 0.08742928504943848
# Total time: 1.637460708618164
#
#
#
# 648518346349509524:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5561332702636719
# Step 2a: Getting the number of splits: 0.6093437671661377
# Step 2b: Pymesh shrinkwrapping: 2.6767139434814453
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.272022008895874
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9871971607208252
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509524_mls
# Step 5: Generating and reading Skeleton: 1.3071660995483398
# Step 6: Inserting dictionary: 0.24809050559997559
# Total time: 6.102304458618164
#
#
#
# 648518346349511321:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1651761531829834
# Step 2a: Getting the number of splits: 0.1709733009338379
# Step 2b: Pymesh shrinkwrapping: 0.06988072395324707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03288602828979492
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5581419467926025
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511321_mls
# Step 5: Generating and reading Skeleton: 0.24003386497497559
# Step 6: Inserting dictionary: 0.05300617218017578
# Total time: 1.1259992122650146
#
#
#
# 648518346349511520:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10446786880493164
# Step 2a: Getting the number of splits: 0.10912060737609863
# Step 2b: Pymesh shrinkwrapping: 0.05208396911621094
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.025234699249267578
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5606896877288818
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511520_mls
# Step 5: Generating and reading Skeleton: 0.21670126914978027
# Step 6: Inserting dictionary: 0.04917621612548828
# Total time: 1.0143728256225586
#
#
#
# 648518346349511983:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2165966033935547
# Step 2a: Getting the number of splits: 0.22199749946594238
# Step 2b: Pymesh shrinkwrapping: 0.05677938461303711
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.024191617965698242
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5506687164306641
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511983_mls
# Step 5: Generating and reading Skeleton: 0.25684070587158203
# Step 6: Inserting dictionary: 0.055876731872558594
# Total time: 1.1683590412139893
#
#
#
# 648518346349512375:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15422892570495605
# Step 2a: Getting the number of splits: 0.15820026397705078
# Step 2b: Pymesh shrinkwrapping: 0.02501988410949707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.017496347427368164
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5528287887573242
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349512375_mls
# Step 5: Generating and reading Skeleton: 0.14187908172607422
# Step 6: Inserting dictionary: 0.03850388526916504
# Total time: 0.9349806308746338
#
#
#
# 648518346349512392:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42189860343933105
# Step 2a: Getting the number of splits: 0.47374987602233887
# Step 2b: Pymesh shrinkwrapping: 2.5886592864990234
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.44072628021240234
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3132050037384033
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349512392_mls
# Step 5: Generating and reading Skeleton: 2.3477115631103516
# Step 6: Inserting dictionary: 0.2611982822418213
# Total time: 7.426458358764648
#
#
#
# 648518346349513079:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2803001403808594
# Step 2a: Getting the number of splits: 0.2890784740447998
# Step 2b: Pymesh shrinkwrapping: 0.35468363761901855
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06405138969421387
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6741409301757812
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513079_mls
# Step 5: Generating and reading Skeleton: 0.33547067642211914
# Step 6: Inserting dictionary: 0.07109951972961426
# Total time: 1.7898635864257812
#
#
#
# 648518346349513135:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2316114902496338
# Step 2a: Getting the number of splits: 0.2382357120513916
# Step 2b: Pymesh shrinkwrapping: 0.24473166465759277
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04168510437011719
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6658036708831787
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513135_mls
# Step 5: Generating and reading Skeleton: 0.2409193515777588
# Step 6: Inserting dictionary: 0.059262752532958984
# Total time: 1.4921355247497559
#
#
#
# 648518346349513410:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3937971591949463
# Step 2a: Getting the number of splits: 0.4370722770690918
# Step 2b: Pymesh shrinkwrapping: 1.2590420246124268
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3491973876953125
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2201056480407715
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513410_mls
# Step 5: Generating and reading Skeleton: 2.030329465866089
# Step 6: Inserting dictionary: 0.22485876083374023
# Total time: 5.521684408187866
#
#
#
# Total time = 447.8698573112488
