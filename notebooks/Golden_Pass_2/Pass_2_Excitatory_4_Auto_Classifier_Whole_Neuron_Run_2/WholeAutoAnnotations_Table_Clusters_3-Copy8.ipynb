# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349499297******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08851122856140137
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 942.6775875091553
# 2) Finished: Generating CGAL segmentation for neuron: 962.2833967208862
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.24542689323425293
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [14, 19, 32, 75, 9, 41, 20, 10, 73, 31, 62, 36, 112, 93, 43]
# soma_80_percent = 257935.3265625
# Debugging the axon filter
# [(14, 254650.203125), (19, 260124.109375), (32, 275799.4375), (75, 268533.1875), (9, 265716.90625), (41, 275154.21875), (20, 266534.625), (10, 261572.4375), (73, 256855.8125), (31, 275205.90625), (62, 266518.59375), (36, 262221.59375), (112, 268749.875), (93, 257358.28125), (43, 256859.21875)]
# possible_Axons_filter_1 = [14, 73, 93, 43]
# possible_Axons_filter_2 = [14]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.08246159553527832
# 6) Staring: Classifying Entire Neuron
# 31 = axon
# 36 = stub soma
# 43 = stub soma
# 62 = stub soma
# 73 = stub soma
# 75 = stub soma
# 93 = stub soma
# 112 = stub soma
# 21 = stub apical
# 22 = stub apical
# 28 = stub apical
# 29 = stub apical
# 35 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 76 = stub apical
# 77 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 100 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# Total Labels found = {'apical', 'soma', 'axon', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.399186849594116
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.529843807220459
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.336046695709229
# Finished Auto Labeling: 977.7197058200836
#
#
# *****Starting Auto Labeling for 648518346349499876******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03590583801269531
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 763.8011631965637
# 2) Finished: Generating CGAL segmentation for neuron: 781.729546546936
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2170543670654297
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [11, 10, 13, 61, 15, 53, 22, 19, 32, 46]
# soma_80_percent = 191179.1609375
# Debugging the axon filter
# [(11, 209248.9375), (10, 188089.875), (13, 198373.796875), (61, 196512.140625), (15, 196460.453125), (53, 197337.546875), (22, 211072.734375), (19, 201262.21875), (32, 188257.390625), (46, 196853.328125)]
# possible_Axons_filter_1 = [10, 32]
# possible_Axons_filter_2 = [10]
# possible_Apical = 10
# 5) Finished: Finding Apical Index: 0.05659055709838867
# 6) Staring: Classifying Entire Neuron
# 32 = cilia
# 46 = stub soma
# 53 = cilia
# 7 = stub apical
# 18 = stub apical
# 20 = stub apical
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 34 = error
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 41 = stub apical
# 42 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# Total Labels found = {'apical', 'soma', 'cilia', 'error', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.926614761352539
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4112122058868408
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.655709981918335
# Finished Auto Labeling: 794.573840379715
#
#
# *****Starting Auto Labeling for 648518346349500954******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.02612781524658203
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 525.5979444980621
# 2) Finished: Generating CGAL segmentation for neuron: 539.6471884250641
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.17029213905334473
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [83, 22, 58, 10, 19, 18, 11, 15, 78, 4, 39, 147, 145, 138, 55, 144]
# soma_80_percent = 249104.39375
# Debugging the axon filter
# [(83, 256398.5), (22, 268743.4375), (58, 265595.125), (10, 250995.734375), (19, 248403.515625), (18, 249580.875), (11, 261236.734375), (15, 264609.90625), (78, 253907.0), (4, 247087.015625), (39, 264368.84375), (147, 251521.828125), (145, 254706.421875), (138, 248443.46875), (55, 253058.78125), (144, 250545.15625)]
# possible_Axons_filter_1 = [19, 4, 138]
# possible_Axons_filter_2 = [19, 4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.07790637016296387
# 6) Staring: Classifying Entire Neuron
# 58 = axon
# 55 = stub soma
# 78 = stub soma
# 83 = stub soma
# 138 = stub soma
# 144 = stub soma
# 145 = stub soma
# 147 = stub soma
# 21 = error
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = error
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 126 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 140 = stub apical
# 141 = stub apical
# Total Labels found = {'apical', 'soma', 'axon', 'error', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.745910882949829
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.34629011154174805
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.290211915969849
# Finished Auto Labeling: 549.7520580291748
#
#
# *****Starting Auto Labeling for 648518346349502434******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03366422653198242
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 690.3249163627625
# 2) Finished: Generating CGAL segmentation for neuron: 705.772946357727
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19419050216674805
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [22, 5, 12, 21, 20, 13, 8, 35, 26, 25, 57, 32, 49]
# soma_80_percent = 267676.1
# Debugging the axon filter
# [(22, 279168.25), (5, 284840.34375), (12, 264845.5625), (21, 285754.09375), (20, 283885.625), (13, 271947.25), (8, 282644.03125), (35, 263331.40625), (26, 288150.4375), (25, 272057.34375), (57, 268012.65625), (32, 266920.6875), (49, 269738.625)]
# possible_Axons_filter_1 = [12, 35, 32]
# possible_Axons_filter_2 = [12]
# possible_Apical = 12
# 5) Finished: Finding Apical Index: 0.06561517715454102
# 6) Staring: Classifying Entire Neuron
# 32 = stub soma
# 35 = stub soma
# 49 = stub soma
# 57 = stub soma
# 31 = stub apical
# 33 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = error
# Total Labels found = {'apical', 'soma', 'error', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.020052671432495
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3927438259124756
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.882601737976074
# Finished Auto Labeling: 717.891889333725
#
#
# *****Starting Auto Labeling for 648518346349504442******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0751798152923584
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1939.779990196228
# 2) Finished: Generating CGAL segmentation for neuron: 1969.405348777771
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 19
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3769679069519043
# 5) Staring: Finding Apical Index
# Soma Index = 19
# Soma Connections = [5, 39, 37, 2, 18, 381, 28, 409, 34, 42, 317, 342, 318]
# soma_80_percent = 278639.671875
# Debugging the axon filter
# [(5, 275503.71875), (39, 290347.125), (37, 300019.78125), (2, 283360.65625), (18, 299287.28125), (381, 277689.3125), (28, 287794.6875), (409, 278259.40625), (34, 300608.25), (42, 281138.71875), (317, 279239.40625), (342, 277822.21875), (318, 278722.28125)]
# possible_Axons_filter_1 = [5, 381, 409, 342]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.16225934028625488
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 39
# 317 = stub soma
# 318 = stub soma
# 342 = stub soma
# 381 = cilia
# 409 = stub soma
# 7 = error
# 13 = stub apical
# 15 = stub apical
# 17 = stub apical
# 23 = stub apical
# 26 = stub apical
# 33 = stub apical
# 40 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 79 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 88 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 154 = stub apical
# 155 = stub apical
# 157 = stub apical
# 164 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 207 = stub apical
# 211 = stub apical
# 212 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 231 = stub apical
# 232 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 261 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 297 = stub apical
# 299 = stub apical
# 300 = stub apical
# 304 = stub apical
# 305 = stub apical
# 307 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 347 = stub apical
# 350 = stub apical
# 357 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# 399 = stub apical
# 405 = stub apical
# 406 = stub apical
# 407 = stub apical
# 410 = stub apical
# 411 = stub apical
# 412 = stub apical
# 413 = stub apical
# 414 = stub apical
# 415 = stub apical
# 421 = stub apical
# 422 = stub apical
# 423 = stub apical
# 424 = stub apical
# 425 = stub apical
# 428 = stub apical
# 429 = stub apical
# 430 = stub apical
# 431 = stub apical
# 432 = stub apical
# 433 = stub apical
# 434 = stub apical
# 439 = stub apical
# Total Labels found = {'apical', 'soma', 'cilia', 'error', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 4.396835565567017
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.74820876121521
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 16.25720238685608
# Finished Auto Labeling: 1992.4819495677948
#
#
# *****Starting Auto Labeling for 648518346349508765******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.02277827262878418
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 274.086314201355
# 2) Finished: Generating CGAL segmentation for neuron: 283.70871686935425
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.11322832107543945
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 11, 4, 77, 86, 13, 16, 32, 15, 55, 36, 69, 31, 17]
# soma_80_percent = 176233.5375
# Debugging the axon filter
# [(0, 177416.984375), (11, 185674.09375), (4, 188242.046875), (77, 179602.625), (86, 183791.140625), (13, 174056.953125), (16, 191664.015625), (32, 180517.03125), (15, 198348.171875), (55, 187795.890625), (36, 178341.96875), (69, 176552.4375), (31, 184340.96875), (17, 197111.375)]
# possible_Axons_filter_1 = [13]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.03869891166687012
# 6) Staring: Classifying Entire Neuron
# 17 = axon
# 13 = error
# 31 = stub soma
# 36 = stub soma
# 69 = stub soma
# 77 = stub soma
# Total Labels found = {'axon', 'soma', 'error', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.0885138511657715
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.37349390983581543
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.053853273391724
# Finished Auto Labeling: 290.7717537879944
#
#
# *****Starting Auto Labeling for 648518346349509280******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09612178802490234
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1729.291755437851
# 2) Finished: Generating CGAL segmentation for neuron: 1755.6788880825043
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3381814956665039
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [20, 39, 1, 22, 43, 83, 7, 157, 25, 164]
# soma_80_percent = 223572.959375
# Debugging the axon filter
# [(20, 229865.1875), (39, 247415.265625), (1, 230944.984375), (22, 227012.515625), (43, 232922.390625), (83, 223171.84375), (7, 219954.984375), (157, 222930.171875), (25, 248208.984375), (164, 231254.9375)]
# possible_Axons_filter_1 = [83, 7, 157]
# possible_Axons_filter_2 = [7]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.08872866630554199
# 6) Staring: Classifying Entire Neuron
# 83 = stub soma
# 157 = cilia
# 164 = stub soma
# 5 = stub apical
# 31 = stub apical
# 44 = stub apical
# 49 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 70 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 82 = stub apical
# 88 = stub apical
# 90 = stub apical
# 102 = stub apical
# 104 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 131 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 146 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 167 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# Total Labels found = {'apical', 'soma', 'cilia', 'basal', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.2733845710754395
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.603410005569458
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.306469440460205
# Finished Auto Labeling: 1775.2900304794312
# 7101.593330144882

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
