# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498482******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07749152183532715
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 604.5029056072235
# 2) Finished: Generating CGAL segmentation for neuron: 619.5031771659851
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1853029727935791
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [9, 0, 15, 14, 17, 20, 19, 28, 27]
# soma_80_percent = 242458.5640625
# Debugging the axon filter
# [(9, 247324.46875), (0, 265590.25), (15, 246731.546875), (14, 240538.0), (17, 252666.140625), (20, 256680.078125), (19, 252363.625), (28, 247155.109375), (27, 242551.046875)]
# possible_Axons_filter_1 = [14]
# possible_Axons_filter_2 = [14]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.04004526138305664
# 6) Staring: Classifying Entire Neuron
# 20 = axon
# 27 = stub soma
# Total Labels found = {'axon', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.5895440578460693
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.35080742835998535
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.56673526763916
# Finished Auto Labeling: 629.799473285675
#
#
# *****Starting Auto Labeling for 648518346349499701******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06896066665649414
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 977.318156003952
# 2) Finished: Generating CGAL segmentation for neuron: 998.3389000892639
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.25524210929870605
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [17, 44, 38, 43, 39, 11, 28, 29, 23, 121, 132, 62]
# soma_80_percent = 213505.9171875
# Debugging the axon filter
# [(17, 210054.59375), (44, 231380.25), (38, 226529.875), (43, 227921.90625), (39, 237248.03125), (11, 227676.359375), (28, 241714.109375), (29, 221050.421875), (23, 211729.6875), (121, 216112.78125), (132, 213585.078125), (62, 211647.21875)]
# possible_Axons_filter_1 = [17, 23, 62]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.09785842895507812
# 6) Staring: Classifying Entire Neuron
# 29 = stub soma
# 38 = axon
# 62 = stub soma
# 121 = stub soma
# 132 = stub soma
# 13 = stub apical
# 20 = stub apical
# 26 = stub apical
# 27 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 42 = stub apical
# 45 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 55 = stub apical
# 56 = stub apical
# 59 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 76 = stub apical
# 77 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 83 = stub apical
# 85 = stub apical
# 86 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 96 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 108 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 117 = stub apical
# 118 = stub apical
# 123 = stub apical
# 124 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 147 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 178 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# Total Labels found = {'axon', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.766042709350586
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5501155853271484
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.77340030670166
# Finished Auto Labeling: 1014.621973991394
#
#
# *****Starting Auto Labeling for 648518346349500725******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07661700248718262
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1097.1499469280243
# 2) Finished: Generating CGAL segmentation for neuron: 1119.012773513794
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 13
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.34624361991882324
# 5) Staring: Finding Apical Index
# Soma Index = 13
# Soma Connections = [1, 16, 15, 41, 63, 36, 14, 42, 139, 123, 81]
# soma_80_percent = 201001.115625
# Debugging the axon filter
# [(1, 221697.390625), (16, 201907.984375), (15, 199515.828125), (41, 214461.8125), (63, 208938.65625), (36, 220047.3125), (14, 198744.5625), (42, 218740.078125), (139, 197693.078125), (123, 203692.25), (81, 202280.609375)]
# possible_Axons_filter_1 = [15, 14, 139]
# possible_Axons_filter_2 = [15]
# possible_Apical = 15
# 5) Finished: Finding Apical Index: 0.10598158836364746
# 6) Staring: Classifying Entire Neuron
# 139 = cilia
# 36 = axon
# 81 = stub soma
# 123 = stub soma
# 7 = error
# 24 = stub apical
# 27 = stub apical
# 40 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 64 = stub apical
# 65 = stub apical
# 74 = stub apical
# 79 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 97 = stub apical
# 100 = stub apical
# 101 = stub apical
# 120 = stub apical
# 122 = stub apical
# 126 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 146 = stub apical
# 147 = stub apical
# Total Labels found = {'error', 'axon', 'cilia', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.1703743934631348
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6471655368804932
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.026097536087036
# Finished Auto Labeling: 1136.2035160064697
#
#
# *****Starting Auto Labeling for 648518346349503767******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.054750919342041016
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 884.3408198356628
# 2) Finished: Generating CGAL segmentation for neuron: 902.0859954357147
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.23615431785583496
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [17, 10, 51, 66, 39, 22, 23, 27, 19, 16, 58, 73, 53]
# soma_80_percent = 178078.146875
# Debugging the axon filter
# [(17, 174694.625), (10, 187994.421875), (51, 187035.03125), (66, 182953.421875), (39, 190621.953125), (22, 190230.96875), (23, 183493.984375), (27, 193742.9375), (19, 197981.53125), (16, 177488.296875), (58, 176438.09375), (73, 187914.390625), (53, 176949.703125)]
# possible_Axons_filter_1 = [17, 16, 58, 53]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.08166384696960449
# 6) Staring: Classifying Entire Neuron
# 27 = error
# 16 = cilia
# 51 = stub soma
# 53 = stub soma
# 58 = stub soma
# 66 = stub soma
# 73 = stub soma
# 32 = error
# 34 = stub apical
# 45 = stub apical
# 52 = stub apical
# 56 = stub apical
# 74 = stub apical
# 75 = stub apical
# 84 = stub apical
# 88 = stub apical
# Total Labels found = {'soma', 'error', 'basal', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.9497838020324707
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4457547664642334
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.209718704223633
# Finished Auto Labeling: 915.7424871921539
#
#
# *****Starting Auto Labeling for 648518346349505450******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.050302743911743164
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 888.5490984916687
# 2) Finished: Generating CGAL segmentation for neuron: 905.408771276474
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22634363174438477
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [6, 21, 121, 8, 130, 19, 87, 96, 25, 150, 14, 154]
# soma_80_percent = 160792.709375
# Debugging the axon filter
# [(6, 176824.9375), (21, 190870.265625), (121, 168504.578125), (8, 161629.9375), (130, 160856.890625), (19, 156503.390625), (87, 160535.78125), (96, 171599.8125), (25, 176856.28125), (150, 169975.859375), (14, 159979.515625), (154, 174155.5)]
# possible_Axons_filter_1 = [19, 87, 14]
# possible_Axons_filter_2 = [19]
# possible_Apical = 19
# 5) Finished: Finding Apical Index: 0.061893463134765625
# 6) Staring: Classifying Entire Neuron
# 130 = cilia
# 87 = stub soma
# 121 = stub soma
# 150 = stub soma
# 154 = stub soma
# 24 = error
# 46 = error
# 98 = stub apical
# 105 = stub apical
# 147 = stub apical
# 157 = stub apical
# 165 = stub apical
# Total Labels found = {'soma', 'error', 'basal', 'apical', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.8919413089752197
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.45114731788635254
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.531495571136475
# Finished Auto Labeling: 918.2352735996246
#
#
# *****Starting Auto Labeling for 648518346349506944******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0253751277923584
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 236.44440603256226
# 2) Finished: Generating CGAL segmentation for neuron: 245.23651313781738
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 10
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.10765862464904785
# 5) Staring: Finding Apical Index
# Soma Index = 10
# Soma Connections = [8, 29, 9, 5, 159, 66]
# soma_80_percent = 153196.9078125
# Debugging the axon filter
# [(8, 160525.859375), (29, 169347.734375), (9, 156788.375), (5, 157067.640625), (159, 155152.453125), (66, 154530.59375)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.03282928466796875
# 6) Staring: Classifying Entire Neuron
# 8 = cilia
# 66 = stub soma
# 159 = stub soma
# Total Labels found = {'unsure', 'cilia', 'soma'}
# 6) Finished: Classifying Entire Neuron: 1.0633699893951416
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.394106388092041
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.650014638900757
# Finished Auto Labeling: 251.83514785766602
#
#
# *****Starting Auto Labeling for 648518346349507537******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04581761360168457
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 535.4486067295074
# 2) Finished: Generating CGAL segmentation for neuron: 548.8622970581055
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1850447654724121
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [1, 16, 3, 165, 26, 22, 49, 167, 222, 137, 46, 246, 156]
# soma_80_percent = 242682.625
# Debugging the axon filter
# [(1, 239678.671875), (16, 241803.53125), (3, 265461.78125), (165, 240041.609375), (26, 262740.40625), (22, 260905.1875), (49, 246617.96875), (167, 252631.125), (222, 245044.359375), (137, 248671.515625), (46, 252051.625), (246, 251451.953125), (156, 253331.109375)]
# possible_Axons_filter_1 = [1, 16, 165]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.12515878677368164
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 16
# 156 = stub soma
# 165 = stub soma
# 246 = stub soma
# 0 = stub apical
# 4 = stub apical
# 9 = stub apical
# 10 = stub apical
# 18 = error
# 19 = stub apical
# 23 = stub apical
# 24 = stub apical
# 27 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = error
# 45 = stub apical
# 47 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = error
# 100 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 108 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 185 = stub apical
# 186 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 223 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 245 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# Total Labels found = {'error', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.0422861576080322
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3176231384277344
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.377493381500244
# Finished Auto Labeling: 559.4655590057373
#
#
# *****Starting Auto Labeling for 648518346349509390******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.016753196716308594
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 172.08158445358276
# 2) Finished: Generating CGAL segmentation for neuron: 178.1918385028839
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.08072686195373535
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 4, 21, 58, 3, 2, 19, 8, 7, 28, 57, 64, 56, 50, 46, 63, 33, 65]
# soma_80_percent = 212569.2671875
# Debugging the axon filter
# [(0, 231942.828125), (4, 228683.796875), (21, 237865.78125), (58, 215850.96875), (3, 218565.515625), (2, 214965.28125), (19, 226981.78125), (8, 209470.703125), (7, 216915.40625), (28, 214569.71875), (57, 220464.21875), (64, 218965.515625), (56, 211197.0), (50, 210170.265625), (46, 209633.375), (63, 220100.421875), (33, 210056.203125), (65, 210357.796875)]
# possible_Axons_filter_1 = [8, 56, 50, 46, 33, 65]
# possible_Axons_filter_2 = [8]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.05442357063293457
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 3
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 7
# 33 = cilia
# 46 = stub soma
# 50 = stub soma
# 56 = stub soma
# 57 = stub soma
# 58 = cilia
# 63 = stub soma
# 64 = stub soma
# 65 = stub soma
# 9 = error
# 12 = stub apical
# 17 = stub apical
# 23 = stub apical
# 24 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 43 = stub apical
# 44 = stub apical
# 48 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# Total Labels found = {'error', 'cilia', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 0.8881142139434814
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.18226099014282227
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.163000583648682
# Finished Auto Labeling: 183.80270433425903
#
#
# *****Starting Auto Labeling for 648518346349509516******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04482841491699219
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 453.1522376537323
# 2) Finished: Generating CGAL segmentation for neuron: 466.40488052368164
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1600208282470703
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [25, 11, 36, 10, 13, 14, 9, 6, 29, 24, 32, 12, 22, 8, 30, 34, 35, 39, 31, 19, 26]
# soma_80_percent = 220147.5
# Debugging the axon filter
# [(25, 233196.234375), (11, 229870.90625), (36, 231122.046875), (10, 217204.28125), (13, 236123.40625), (14, 239827.15625), (9, 238847.5625), (6, 223580.609375), (29, 229836.1875), (24, 217223.796875), (32, 222571.515625), (12, 225399.453125), (22, 228170.8125), (8, 223330.96875), (30, 222106.53125), (34, 226626.546875), (35, 231319.484375), (39, 227274.40625), (31, 221837.9375), (19, 225052.796875), (26, 217277.265625)]
# possible_Axons_filter_1 = [10, 24, 26]
# possible_Axons_filter_2 = [10]
# possible_Apical = 10
# 5) Finished: Finding Apical Index: 0.04776263236999512
# 6) Staring: Classifying Entire Neuron
# 12 = stub soma
# 24 = cilia
# 19 = stub soma
# 26 = stub soma
# 29 = cilia
# 31 = stub soma
# 32 = stub soma
# 34 = stub soma
# 35 = stub soma
# 36 = stub soma
# 39 = stub soma
# Total Labels found = {'cilia', 'soma', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.694669246673584
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.30655813217163086
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.070690393447876
# Finished Auto Labeling: 477.2047641277313
#
#
# *****Starting Auto Labeling for 648518346349511823******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.020534038543701172
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 221.49525499343872
# 2) Finished: Generating CGAL segmentation for neuron: 228.87716841697693
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.09873318672180176
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [3]
# soma_80_percent = 284267.0
# Debugging the axon filter
# [(3, 295536.4375)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.011625289916992188
# 6) Staring: Classifying Entire Neuron
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.8629457950592041
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4279062747955322
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.238810062408447
# Finished Auto Labeling: 234.88032937049866
#
#
# *****Starting Auto Labeling for 648518346349512199******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.031000852584838867
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 173.77091240882874
# 2) Finished: Generating CGAL segmentation for neuron: 180.43152904510498
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.09116077423095703
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 13, 19, 16, 251, 24, 163, 206, 151]
# soma_80_percent = 290853.146875
# Debugging the axon filter
# [(0, 307107.4375), (13, 288652.5625), (19, 298994.59375), (16, 304257.84375), (251, 292457.65625), (24, 295369.28125), (163, 292358.46875), (206, 292535.75), (151, 287174.9375)]
# possible_Axons_filter_1 = [13, 151]
# possible_Axons_filter_2 = [13]
# possible_Apical = 13
# 5) Finished: Finding Apical Index: 0.06612062454223633
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 19
# 151 = stub soma
# 163 = stub soma
# 206 = stub soma
# 251 = cilia
# 12 = stub apical
# 18 = stub apical
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 25 = stub apical
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = error
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = error
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = error
# 161 = stub apical
# 162 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 250 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# Total Labels found = {'error', 'cilia', 'basal', 'apical', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.316622257232666
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.21289443969726562
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.6195626258850098
# Finished Auto Labeling: 186.02629137039185
#
#
# *****Starting Auto Labeling for 648518346349513026******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03682422637939453
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 404.3475317955017
# 2) Finished: Generating CGAL segmentation for neuron: 414.47690629959106
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.13454055786132812
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [5, 109, 25, 76, 1, 13, 16, 14, 4, 217, 45, 15, 0, 3, 218, 306, 28]
# soma_80_percent = 187526.1921875
# Debugging the axon filter
# [(5, 186914.84375), (109, 190291.6875), (25, 198925.421875), (76, 190001.40625), (1, 228834.34375), (13, 198912.171875), (16, 200480.765625), (14, 186661.84375), (4, 221443.15625), (217, 191384.265625), (45, 194555.703125), (15, 188980.34375), (0, 196873.671875), (3, 185533.453125), (218, 189437.859375), (306, 185383.171875), (28, 184581.90625)]
# possible_Axons_filter_1 = [5, 14, 3, 306, 28]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.10007977485656738
# 6) Staring: Classifying Entire Neuron
# 16 = cilia
# 25 = error
# 28 = error
# 76 = cilia
# 218 = stub soma
# 306 = stub soma
# Total Labels found = {'error', 'unsure', 'soma', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.5944015979766846
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.42206645011901855
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.287978649139404
# Finished Auto Labeling: 423.5492088794708
# 6933.475165843964

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
