# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotations(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotations.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498116******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.1407911777496338
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 4, smoothness = 0.3
# 1
# Finished CGAL segmentation algorithm: 1527.5147931575775
# 2) Finished: Generating CGAL segmentation for neuron: 1551.0525588989258
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.34743404388427734
# 4) Staring: Finding Soma Extensions
# Found 1 soma caps and replacing labels: [1000]
# done replacing soma cap labels : 13.513332843780518
# 4) Finished: Finding Soma Extensions: 13.994121551513672
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [22, 100, 7, 9, 98, 246, 152, 135, 107, 450, 449, 513]
# soma_80_percent = 243372.703125
# Debugging the axon filter
# [(22, 265915.09375), (100, 249715.921875), (7, 243247.6875), (9, 239990.765625), (98, 259219.21875), (246, 253223.96875), (152, 252867.609375), (135, 260808.265625), (107, 252038.921875), (450, 247072.84375), (449, 248493.3125), (513, 244572.640625)]
# possible_Axons_filter_1 = [7, 9]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.08759927749633789
# 6) Staring: Classifying Entire Neuron
# 449 = stub soma
# 513 = cilia
# 33 = stub apical
# 87 = stub apical
# 126 = stub apical
# 127 = stub apical
# 145 = stub apical
# 147 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 174 = stub apical
# 197 = stub apical
# 265 = stub apical
# 226 = stub apical
# 247 = stub apical
# 282 = stub apical
# 325 = stub apical
# 329 = stub apical
# 358 = stub apical
# 360 = stub apical
# 361 = stub apical
# 385 = error
# 976 = stub apical
# 862 = stub apical
# 462 = stub apical
# 463 = stub apical
# 464 = stub apical
# 466 = stub apical
# 468 = stub apical
# 471 = stub apical
# 472 = stub apical
# 473 = stub apical
# 474 = stub apical
# 475 = stub apical
# 476 = stub apical
# 477 = stub apical
# 478 = stub apical
# 486 = stub apical
# 488 = stub apical
# 497 = stub apical
# 498 = stub apical
# 512 = stub apical
# 515 = stub apical
# 584 = stub apical
# 585 = stub apical
# 588 = stub apical
# 615 = error
# 611 = stub apical
# 612 = stub apical
# 613 = stub apical
# 614 = stub apical
# 616 = stub apical
# 623 = stub apical
# 618 = stub apical
# 619 = stub apical
# 620 = stub apical
# 624 = stub apical
# 643 = stub apical
# 645 = stub apical
# 667 = stub apical
# 668 = stub apical
# 695 = stub apical
# 698 = stub apical
# 767 = stub apical
# 776 = stub apical
# 777 = stub apical
# 782 = stub apical
# 793 = stub apical
# 798 = stub apical
# 799 = stub apical
# 800 = stub apical
# 839 = stub apical
# 856 = stub apical
# 858 = stub apical
# 859 = stub apical
# 860 = stub apical
# 861 = stub apical
# 863 = stub apical
# 888 = stub apical
# 927 = stub apical
# 944 = stub apical
# 953 = stub apical
# 954 = stub apical
# 955 = stub apical
# 959 = stub apical
# 960 = stub apical
# 961 = stub apical
# 974 = stub apical
# 975 = stub apical
# 977 = stub apical
# 978 = stub apical
# 1007 = stub apical
# 1016 = stub apical
# 1033 = stub apical
# 1034 = stub apical
# Total Labels found = {'cilia', 'soma', 'oblique', 'error', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.3170292377471924
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5487439632415771
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.229574918746948
# Finished Auto Labeling: 1583.7643129825592
# 1584.0737760066986

# %%
#(schema.jobs & "table_name='__whole_auto_annotations'").delete()
