# %%
"""
Working version of stitching algorithm 
Where it correctly mates the pieces

Things to add during this iteration: 
1) Translates the labels so don't have to recompute
2) where doesn't delete faces to end
3) Fixes the normals



Changes made: 
1) Made transfer of labels instead of recomputing
2) Made sure the old facet generator doesn't have overlapping arrays
"""
# Out:
# "\nWorking version of stitching algorithm \nWhere it correctly mates the pieces\n\nThings to add during this iteration: \n1) Translates the labels so don't have to recompute\n2) where doesn't delete faces to end\n3) Fixes the normals\n\n\n\nChanges made: \n1) Made transfer of labels instead of recomputing\n2) Made sure the old facet generator doesn't have overlapping arrays\n"

# %%
import trimesh
import numpy as np
from collections import Counter
import time
import math
from tqdm import tqdm

# %%
#pick the mesh to process: 
file_location = "./test_meshes/"
file_location = "./"
file_name ="seperated_mesh.off"

# %%
#visualize the neuron to make sure it is correct
visualize = False
if visualize == True:
    visualize_mesh = trimesh.load_mesh(file_location + file_name )
    visualize_mesh.show()

# %% [markdown]
# # Gets parts that are outside of the main mesh

# %%
def filter_mesh_significant_outside_pieces(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces, including the main one that are not inside of main mesh

    """

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []

    #find piece with largest size
    max_index = 0
    max_face_len = len(significant_pieces[max_index].faces)

    for i in range(1,len(significant_pieces)):
        if max_face_len < len(significant_pieces[i].faces):
            max_index = i
            max_face_len = len(significant_pieces[i].faces)

    print("max_index = " + str(max_index))
    print("max_face_len = " + str(max_face_len))

    final_mesh_pieces = []

    main_mesh = significant_pieces[max_index]

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        if i != max_index:
            #get a random sample of points
            # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
            idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
            points = mesh.vertices[idx,:]
            
            
            start_time = time.time()
            signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
            print(f"Total time = {time.time() - start_time}")

            outside_percentage = sum(signed_distance < 0)/n_sample_points
            if outside_percentage > 0.9:
                final_mesh_pieces.append(mesh)
                print(f"Mesh piece {i} OUTSIDE mesh")
            else:
                print(f"Mesh piece {i} inside mesh :( ")
                
    return main_mesh,final_mesh_pieces

# %%
#Runs the filtering function for inside and outside meshes
global_timer = time.time()

unfiltered_mesh = trimesh.load_mesh(file_location + file_name)

#setting thresholds
significance_threshold=30 #number of faces needed for pieces to be considered to be kept
n_sample_points = 3 #number of points sampled on the mesh for determination of inside or outside
start_time = time.time()

#the main mesh is the first mesh in the piece
main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
                            significance_threshold=significance_threshold,
                                n_sample_points=n_sample_points)
print(f"Total time for Mesh Cleansing: {time.time() - start_time}")
# Out:
# There were 3902 pieces after mesh split
# There were 378 pieces found after size threshold
# max_index = 0
# max_face_len = 1845336
# Total time = 26.88869071006775
# Mesh piece 1 OUTSIDE mesh
# Total time = 0.120361328125
# Mesh piece 2 inside mesh :(
# Total time = 0.32430410385131836
# Mesh piece 3 OUTSIDE mesh
# Total time = 1.434826374053955
# Mesh piece 4 OUTSIDE mesh
# Total time = 0.4488375186920166
# Mesh piece 5 inside mesh :(
# Total time = 0.34423160552978516
# Mesh piece 6 inside mesh :(
# Total time = 0.3300507068634033
# Mesh piece 7 inside mesh :(
# Total time = 0.3342270851135254
# Mesh piece 8 inside mesh :(
# Total time = 0.351229190826416
# Mesh piece 9 inside mesh :(
# Total time = 0.3279838562011719
# Mesh piece 10 inside mesh :(
# Total time = 0.3731999397277832
# Mesh piece 11 inside mesh :(
# Total time = 0.6318912506103516
# Mesh piece 12 inside mesh :(
# Total time = 0.6762332916259766
# Mesh piece 13 inside mesh :(
# Total time = 0.5420873165130615
# Mesh piece 14 inside mesh :(
# Total time = 0.6369805335998535
# Mesh piece 15 inside mesh :(
# Total time = 0.47255778312683105
# Mesh piece 16 inside mesh :(
# Total time = 0.7376320362091064
# Mesh piece 17 inside mesh :(
# Total time = 0.6127278804779053
# Mesh piece 18 inside mesh :(
# Total time = 0.45924830436706543
# Mesh piece 19 inside mesh :(
# Total time = 0.5375535488128662
# Mesh piece 20 inside mesh :(
# Total time = 0.5463392734527588
# Mesh piece 21 inside mesh :(
# Total time = 0.4591813087463379
# Mesh piece 22 inside mesh :(
# Total time = 0.572472095489502
# Mesh piece 23 inside mesh :(
# Total time = 0.6569414138793945
# Mesh piece 24 inside mesh :(
# Total time = 0.5960140228271484
# Mesh piece 25 inside mesh :(
# Total time = 0.6156144142150879
# Mesh piece 26 inside mesh :(
# Total time = 0.5976748466491699
# Mesh piece 27 inside mesh :(
# Total time = 0.5869991779327393
# Mesh piece 28 inside mesh :(
# Total time = 0.6611793041229248
# Mesh piece 29 inside mesh :(
# Total time = 0.8774349689483643
# Mesh piece 30 inside mesh :(
# Total time = 0.7482736110687256
# Mesh piece 31 inside mesh :(
# Total time = 0.4833664894104004
# Mesh piece 32 inside mesh :(
# Total time = 0.36428308486938477
# Mesh piece 33 inside mesh :(
# Total time = 0.39479947090148926
# Mesh piece 34 inside mesh :(
# Total time = 0.42948269844055176
# Mesh piece 35 inside mesh :(
# Total time = 0.32735657691955566
# Mesh piece 36 inside mesh :(
# Total time = 0.4654366970062256
# Mesh piece 37 inside mesh :(
# Total time = 0.44605517387390137
# Mesh piece 38 inside mesh :(
# Total time = 0.5389285087585449
# Mesh piece 39 inside mesh :(
# Total time = 0.48468852043151855
# Mesh piece 40 inside mesh :(
# Total time = 0.39249682426452637
# Mesh piece 41 inside mesh :(
# Total time = 0.505882740020752
# Mesh piece 42 inside mesh :(
# Total time = 0.3783280849456787
# Mesh piece 43 inside mesh :(
# Total time = 0.4507143497467041
# Mesh piece 44 inside mesh :(
# Total time = 0.330106258392334
# Mesh piece 45 inside mesh :(
# Total time = 0.42731189727783203
# Mesh piece 46 inside mesh :(
# Total time = 0.06035184860229492
# Mesh piece 47 OUTSIDE mesh
# Total time = 0.03529977798461914
# Mesh piece 48 OUTSIDE mesh
# Total time = 0.1668243408203125
# Mesh piece 49 OUTSIDE mesh
# Total time = 0.04384326934814453
# Mesh piece 50 OUTSIDE mesh
# Total time = 0.11935639381408691
# Mesh piece 51 OUTSIDE mesh
# Total time = 0.1293487548828125
# Mesh piece 52 OUTSIDE mesh
# Total time = 0.8340604305267334
# Mesh piece 53 OUTSIDE mesh
# Total time = 0.12281179428100586
# Mesh piece 54 OUTSIDE mesh
# Total time = 0.48999547958374023
# Mesh piece 55 inside mesh :(
# Total time = 1.7942655086517334
# Mesh piece 56 OUTSIDE mesh
# Total time = 0.3647181987762451
# Mesh piece 57 inside mesh :(
# Total time = 0.5438542366027832
# Mesh piece 58 inside mesh :(
# Total time = 0.5816800594329834
# Mesh piece 59 inside mesh :(
# Total time = 0.5765645503997803
# Mesh piece 60 inside mesh :(
# Total time = 0.542865514755249
# Mesh piece 61 inside mesh :(
# Total time = 0.5640103816986084
# Mesh piece 62 inside mesh :(
# Total time = 0.17691588401794434
# Mesh piece 63 OUTSIDE mesh
# Total time = 0.08221912384033203
# Mesh piece 64 OUTSIDE mesh
# Total time = 1.6437397003173828
# Mesh piece 65 OUTSIDE mesh
# Total time = 0.6867871284484863
# Mesh piece 66 inside mesh :(
# Total time = 0.6699647903442383
# Mesh piece 67 inside mesh :(
# Total time = 0.7619330883026123
# Mesh piece 68 inside mesh :(
# Total time = 0.5502421855926514
# Mesh piece 69 inside mesh :(
# Total time = 0.5694148540496826
# Mesh piece 70 inside mesh :(
# Total time = 0.5262084007263184
# Mesh piece 71 inside mesh :(
# Total time = 0.5177874565124512
# Mesh piece 72 inside mesh :(
# Total time = 0.5478348731994629
# Mesh piece 73 inside mesh :(
# Total time = 0.5947771072387695
# Mesh piece 74 inside mesh :(
# Total time = 0.5358579158782959
# Mesh piece 75 inside mesh :(
# Total time = 0.5751583576202393
# Mesh piece 76 inside mesh :(
# Total time = 0.5314624309539795
# Mesh piece 77 inside mesh :(
# Total time = 0.548100471496582
# Mesh piece 78 inside mesh :(
# Total time = 0.5607495307922363
# Mesh piece 79 inside mesh :(
# Total time = 0.523735523223877
# Mesh piece 80 inside mesh :(
# Total time = 0.5588531494140625
# Mesh piece 81 inside mesh :(
# Total time = 0.5772812366485596
# Mesh piece 82 inside mesh :(
# Total time = 0.5820553302764893
# Mesh piece 83 inside mesh :(
# Total time = 0.5939905643463135
# Mesh piece 84 inside mesh :(
# Total time = 0.5128269195556641
# Mesh piece 85 inside mesh :(
# Total time = 0.5202746391296387
# Mesh piece 86 inside mesh :(
# Total time = 0.5069189071655273
# Mesh piece 87 inside mesh :(
# Total time = 0.5527634620666504
# Mesh piece 88 inside mesh :(
# Total time = 0.2642827033996582
# Mesh piece 89 inside mesh :(
# Total time = 0.18334197998046875
# Mesh piece 90 inside mesh :(
# Total time = 0.0811305046081543
# Mesh piece 91 OUTSIDE mesh
# Total time = 0.1151895523071289
# Mesh piece 92 OUTSIDE mesh
# Total time = 0.020055770874023438
# Mesh piece 93 OUTSIDE mesh
# Total time = 0.024739503860473633
# Mesh piece 94 OUTSIDE mesh
# Total time = 0.03480100631713867
# Mesh piece 95 OUTSIDE mesh
# Total time = 0.02907705307006836
# Mesh piece 96 OUTSIDE mesh
# Total time = 1.613011121749878
# Mesh piece 97 OUTSIDE mesh
# Total time = 0.7185590267181396
# Mesh piece 98 inside mesh :(
# Total time = 0.8237771987915039
# Mesh piece 99 inside mesh :(
# Total time = 0.5497982501983643
# Mesh piece 100 inside mesh :(
# Total time = 0.4515721797943115
# Mesh piece 101 inside mesh :(
# Total time = 0.3301725387573242
# Mesh piece 102 inside mesh :(
# Total time = 0.34232211112976074
# Mesh piece 103 inside mesh :(
# Total time = 0.44232821464538574
# Mesh piece 104 inside mesh :(
# Total time = 0.5700876712799072
# Mesh piece 105 inside mesh :(
# Total time = 0.6778073310852051
# Mesh piece 106 inside mesh :(
# Total time = 0.501690149307251
# Mesh piece 107 inside mesh :(
# Total time = 0.42485809326171875
# Mesh piece 108 inside mesh :(
# Total time = 0.5729708671569824
# Mesh piece 109 inside mesh :(
# Total time = 0.6897745132446289
# Mesh piece 110 inside mesh :(
# Total time = 0.7042856216430664
# Mesh piece 111 inside mesh :(
# Total time = 0.5106894969940186
# Mesh piece 112 inside mesh :(
# Total time = 0.5823884010314941
# Mesh piece 113 inside mesh :(
# Total time = 0.7083277702331543
# Mesh piece 114 inside mesh :(
# Total time = 0.11386942863464355
# Mesh piece 115 OUTSIDE mesh
# Total time = 0.038177490234375
# Mesh piece 116 OUTSIDE mesh
# Total time = 0.0865323543548584
# Mesh piece 117 OUTSIDE mesh
# Total time = 0.05823516845703125
# Mesh piece 118 OUTSIDE mesh
# Total time = 0.13103771209716797
# Mesh piece 119 OUTSIDE mesh
# Total time = 0.16656279563903809
# Mesh piece 120 OUTSIDE mesh
# Total time = 0.5473771095275879
# Mesh piece 121 inside mesh :(
# Total time = 0.481403112411499
# Mesh piece 122 inside mesh :(
# Total time = 0.38221263885498047
# Mesh piece 123 inside mesh :(
# Total time = 0.49008917808532715
# Mesh piece 124 inside mesh :(
# Total time = 0.48653125762939453
# Mesh piece 125 inside mesh :(
# Total time = 0.596440315246582
# Mesh piece 126 inside mesh :(
# Total time = 0.5343203544616699
# Mesh piece 127 inside mesh :(
# Total time = 0.55596923828125
# Mesh piece 128 inside mesh :(
# Total time = 0.504166841506958
# Mesh piece 129 inside mesh :(
# Total time = 0.504554271697998
# Mesh piece 130 inside mesh :(
# Total time = 0.66481614112854
# Mesh piece 131 inside mesh :(
# Total time = 0.6618106365203857
# Mesh piece 132 inside mesh :(
# Total time = 0.5391385555267334
# Mesh piece 133 inside mesh :(
# Total time = 0.628190279006958
# Mesh piece 134 inside mesh :(
# Total time = 0.6944971084594727
# Mesh piece 135 inside mesh :(
# Total time = 0.6572620868682861
# Mesh piece 136 inside mesh :(
# Total time = 0.5333411693572998
# Mesh piece 137 inside mesh :(
# Total time = 0.5810556411743164
# Mesh piece 138 inside mesh :(
# Total time = 0.4912986755371094
# Mesh piece 139 inside mesh :(
# Total time = 0.5966880321502686
# Mesh piece 140 inside mesh :(
# Total time = 0.7090320587158203
# Mesh piece 141 inside mesh :(
# Total time = 0.5727612972259521
# Mesh piece 142 inside mesh :(
# Total time = 0.6080343723297119
# Mesh piece 143 inside mesh :(
# Total time = 0.02751016616821289
# Mesh piece 144 OUTSIDE mesh
# Total time = 0.48714685440063477
# Mesh piece 145 OUTSIDE mesh
# Total time = 0.5749294757843018
# Mesh piece 146 inside mesh :(
# Total time = 0.6188902854919434
# Mesh piece 147 inside mesh :(
# Total time = 0.7691605091094971
# Mesh piece 148 inside mesh :(
# Total time = 0.7387905120849609
# Mesh piece 149 inside mesh :(
# Total time = 0.5314373970031738
# Mesh piece 150 inside mesh :(
# Total time = 0.7385053634643555
# Mesh piece 151 inside mesh :(
# Total time = 0.8393521308898926
# Mesh piece 152 inside mesh :(
# Total time = 0.8655426502227783
# Mesh piece 153 inside mesh :(
# Total time = 0.8533322811126709
# Mesh piece 154 inside mesh :(
# Total time = 0.7486495971679688
# Mesh piece 155 inside mesh :(
# Total time = 0.8332762718200684
# Mesh piece 156 inside mesh :(
# Total time = 0.7570905685424805
# Mesh piece 157 inside mesh :(
# Total time = 0.8750274181365967
# Mesh piece 158 inside mesh :(
# Total time = 0.9815216064453125
# Mesh piece 159 inside mesh :(
# Total time = 0.9608030319213867
# Mesh piece 160 inside mesh :(
# Total time = 0.8231043815612793
# Mesh piece 161 inside mesh :(
# Total time = 0.950463056564331
# Mesh piece 162 inside mesh :(
# Total time = 0.8031148910522461
# Mesh piece 163 inside mesh :(
# Total time = 0.8158347606658936
# Mesh piece 164 inside mesh :(
# Total time = 0.7658901214599609
# Mesh piece 165 inside mesh :(
# Total time = 0.47285914421081543
# Mesh piece 166 inside mesh :(
# Total time = 0.499096155166626
# Mesh piece 167 inside mesh :(
# Total time = 0.5134353637695312
# Mesh piece 168 inside mesh :(
# Total time = 0.7069094181060791
# Mesh piece 169 inside mesh :(
# Total time = 0.6437439918518066
# Mesh piece 170 inside mesh :(
# Total time = 0.6180393695831299
# Mesh piece 171 inside mesh :(
# Total time = 0.6147491931915283
# Mesh piece 172 inside mesh :(
# Total time = 0.0019419193267822266
# Mesh piece 173 OUTSIDE mesh
# Total time = 0.7257914543151855
# Mesh piece 174 inside mesh :(
# Total time = 0.5647432804107666
# Mesh piece 175 inside mesh :(
# Total time = 0.5684030055999756
# Mesh piece 176 inside mesh :(
# Total time = 0.6592164039611816
# Mesh piece 177 inside mesh :(
# Total time = 0.7956397533416748
# Mesh piece 178 inside mesh :(
# Total time = 0.11402511596679688
# Mesh piece 179 OUTSIDE mesh
# Total time = 0.11398553848266602
# Mesh piece 180 OUTSIDE mesh
# Total time = 0.1435546875
# Mesh piece 181 OUTSIDE mesh
# Total time = 0.027530431747436523
# Mesh piece 182 OUTSIDE mesh
# Total time = 0.8865246772766113
# Mesh piece 183 inside mesh :(
# Total time = 0.8543839454650879
# Mesh piece 184 inside mesh :(
# Total time = 0.8766422271728516
# Mesh piece 185 inside mesh :(
# Total time = 0.8492944240570068
# Mesh piece 186 inside mesh :(
# Total time = 0.8008232116699219
# Mesh piece 187 inside mesh :(
# Total time = 0.9136185646057129
# Mesh piece 188 inside mesh :(
# Total time = 0.79559326171875
# Mesh piece 189 inside mesh :(
# Total time = 0.8650126457214355
# Mesh piece 190 inside mesh :(
# Total time = 0.8784887790679932
# Mesh piece 191 inside mesh :(
# Total time = 0.9132473468780518
# Mesh piece 192 inside mesh :(
# Total time = 0.8080956935882568
# Mesh piece 193 inside mesh :(
# Total time = 0.8738086223602295
# Mesh piece 194 inside mesh :(
# Total time = 0.8201031684875488
# Mesh piece 195 inside mesh :(
# Total time = 0.5630717277526855
# Mesh piece 196 inside mesh :(
# Total time = 0.6951868534088135
# Mesh piece 197 inside mesh :(
# Total time = 0.5665562152862549
# Mesh piece 198 inside mesh :(
# Total time = 0.47309207916259766
# Mesh piece 199 inside mesh :(
# Total time = 0.5228452682495117
# Mesh piece 200 inside mesh :(
# Total time = 0.4609711170196533
# Mesh piece 201 inside mesh :(
# Total time = 0.570275068283081
# Mesh piece 202 inside mesh :(
# Total time = 0.5270209312438965
# Mesh piece 203 inside mesh :(
# Total time = 0.27590394020080566
# Mesh piece 204 inside mesh :(
# Total time = 1.3464317321777344
# Mesh piece 205 OUTSIDE mesh
# Total time = 0.44669246673583984
# Mesh piece 206 inside mesh :(
# Total time = 0.4453909397125244
# Mesh piece 207 inside mesh :(
# Total time = 0.5414650440216064
# Mesh piece 208 inside mesh :(
# Total time = 0.3811812400817871
# Mesh piece 209 inside mesh :(
# Total time = 0.499051570892334
# Mesh piece 210 inside mesh :(
# Total time = 0.4232778549194336
# Mesh piece 211 inside mesh :(
# Total time = 0.5897505283355713
# Mesh piece 212 inside mesh :(
# Total time = 0.5113177299499512
# Mesh piece 213 inside mesh :(
# Total time = 1.776676893234253
# Mesh piece 214 OUTSIDE mesh
# Total time = 0.611189603805542
# Mesh piece 215 inside mesh :(
# Total time = 0.49120545387268066
# Mesh piece 216 inside mesh :(
# Total time = 0.5984971523284912
# Mesh piece 217 inside mesh :(
# Total time = 0.4668142795562744
# Mesh piece 218 inside mesh :(
# Total time = 0.6518926620483398
# Mesh piece 219 inside mesh :(
# Total time = 0.44861793518066406
# Mesh piece 220 inside mesh :(
# Total time = 0.5436348915100098
# Mesh piece 221 inside mesh :(
# Total time = 0.5045166015625
# Mesh piece 222 inside mesh :(
# Total time = 0.5954523086547852
# Mesh piece 223 inside mesh :(
# Total time = 0.48679280281066895
# Mesh piece 224 inside mesh :(
# Total time = 0.5922896862030029
# Mesh piece 225 inside mesh :(
# Total time = 0.5317380428314209
# Mesh piece 226 inside mesh :(
# Total time = 0.5362343788146973
# Mesh piece 227 inside mesh :(
# Total time = 0.3870112895965576
# Mesh piece 228 inside mesh :(
# Total time = 0.42840075492858887
# Mesh piece 229 inside mesh :(
# Total time = 0.43416738510131836
# Mesh piece 230 inside mesh :(
# Total time = 0.4017481803894043
# Mesh piece 231 inside mesh :(
# Total time = 0.5535919666290283
# Mesh piece 232 inside mesh :(
# Total time = 0.043335676193237305
# Mesh piece 233 OUTSIDE mesh
# Total time = 0.6387362480163574
# Mesh piece 234 inside mesh :(
# Total time = 0.5625197887420654
# Mesh piece 235 inside mesh :(
# Total time = 0.5497465133666992
# Mesh piece 236 inside mesh :(
# Total time = 0.5795090198516846
# Mesh piece 237 inside mesh :(
# Total time = 1.3927786350250244
# Mesh piece 238 inside mesh :(
# Total time = 0.8340773582458496
# Mesh piece 239 inside mesh :(
# Total time = 0.8008856773376465
# Mesh piece 240 inside mesh :(
# Total time = 0.7561583518981934
# Mesh piece 241 inside mesh :(
# Total time = 0.630037784576416
# Mesh piece 242 inside mesh :(
# Total time = 0.6375999450683594
# Mesh piece 243 inside mesh :(
# Total time = 0.6857669353485107
# Mesh piece 244 inside mesh :(
# Total time = 0.7449357509613037
# Mesh piece 245 inside mesh :(
# Total time = 0.6456060409545898
# Mesh piece 246 inside mesh :(
# Total time = 0.4016292095184326
# Mesh piece 247 OUTSIDE mesh
# Total time = 0.46419668197631836
# Mesh piece 248 OUTSIDE mesh
# Total time = 0.8170592784881592
# Mesh piece 249 inside mesh :(
# Total time = 0.8720171451568604
# Mesh piece 250 inside mesh :(
# Total time = 0.8455548286437988
# Mesh piece 251 inside mesh :(
# Total time = 0.8230297565460205
# Mesh piece 252 inside mesh :(
# Total time = 0.6716482639312744
# Mesh piece 253 inside mesh :(
# Total time = 0.6868839263916016
# Mesh piece 254 inside mesh :(
# Total time = 0.40302515029907227
# Mesh piece 255 inside mesh :(
# Total time = 0.45243239402770996
# Mesh piece 256 inside mesh :(
# Total time = 0.40576744079589844
# Mesh piece 257 inside mesh :(
# Total time = 0.44163990020751953
# Mesh piece 258 inside mesh :(
# Total time = 0.5288679599761963
# Mesh piece 259 inside mesh :(
# Total time = 0.6499500274658203
# Mesh piece 260 inside mesh :(
# Total time = 0.5339725017547607
# Mesh piece 261 inside mesh :(
# Total time = 0.5874884128570557
# Mesh piece 262 inside mesh :(
# Total time = 0.603621244430542
# Mesh piece 263 inside mesh :(
# Total time = 0.5042815208435059
# Mesh piece 264 inside mesh :(
# Total time = 0.6221654415130615
# Mesh piece 265 inside mesh :(
# Total time = 0.6661856174468994
# Mesh piece 266 inside mesh :(
# Total time = 0.7780635356903076
# Mesh piece 267 inside mesh :(
# Total time = 0.7629082202911377
# Mesh piece 268 inside mesh :(
# Total time = 0.5839006900787354
# Mesh piece 269 inside mesh :(
# Total time = 0.6440811157226562
# Mesh piece 270 inside mesh :(
# Total time = 0.5985801219940186
# Mesh piece 271 inside mesh :(
# Total time = 0.6431839466094971
# Mesh piece 272 inside mesh :(
# Total time = 0.6472282409667969
# Mesh piece 273 inside mesh :(
# Total time = 0.5940618515014648
# Mesh piece 274 inside mesh :(
# Total time = 0.600092887878418
# Mesh piece 275 inside mesh :(
# Total time = 0.510521411895752
# Mesh piece 276 inside mesh :(
# Total time = 0.6451683044433594
# Mesh piece 277 inside mesh :(
# Total time = 0.682218074798584
# Mesh piece 278 inside mesh :(
# Total time = 0.5856449604034424
# Mesh piece 279 inside mesh :(
# Total time = 0.5907607078552246
# Mesh piece 280 inside mesh :(
# Total time = 0.784886360168457
# Mesh piece 281 inside mesh :(
# Total time = 0.915661096572876
# Mesh piece 282 inside mesh :(
# Total time = 0.6156721115112305
# Mesh piece 283 inside mesh :(
# Total time = 0.586745023727417
# Mesh piece 284 inside mesh :(
# Total time = 0.6900930404663086
# Mesh piece 285 inside mesh :(
# Total time = 0.7618656158447266
# Mesh piece 286 inside mesh :(
# Total time = 0.7293338775634766
# Mesh piece 287 inside mesh :(
# Total time = 0.5152039527893066
# Mesh piece 288 OUTSIDE mesh
# Total time = 0.47847628593444824
# Mesh piece 289 OUTSIDE mesh
# Total time = 0.7485823631286621
# Mesh piece 290 inside mesh :(
# Total time = 0.7698624134063721
# Mesh piece 291 inside mesh :(
# Total time = 0.6893839836120605
# Mesh piece 292 inside mesh :(
# Total time = 0.5784125328063965
# Mesh piece 293 inside mesh :(
# Total time = 0.9842963218688965
# Mesh piece 294 inside mesh :(
# Total time = 0.7665877342224121
# Mesh piece 295 inside mesh :(
# Total time = 0.7874159812927246
# Mesh piece 296 inside mesh :(
# Total time = 0.7791991233825684
# Mesh piece 297 inside mesh :(
# Total time = 0.7420260906219482
# Mesh piece 298 inside mesh :(
# Total time = 0.7118828296661377
# Mesh piece 299 inside mesh :(
# Total time = 0.5874736309051514
# Mesh piece 300 inside mesh :(
# Total time = 0.060986995697021484
# Mesh piece 301 OUTSIDE mesh
# Total time = 0.5404925346374512
# Mesh piece 302 inside mesh :(
# Total time = 0.4747457504272461
# Mesh piece 303 inside mesh :(
# Total time = 0.5275769233703613
# Mesh piece 304 inside mesh :(
# Total time = 0.42623257637023926
# Mesh piece 305 inside mesh :(
# Total time = 0.5045807361602783
# Mesh piece 306 inside mesh :(
# Total time = 0.479938268661499
# Mesh piece 307 inside mesh :(
# Total time = 0.682640552520752
# Mesh piece 308 inside mesh :(
# Total time = 0.8787171840667725
# Mesh piece 309 inside mesh :(
# Total time = 0.5424175262451172
# Mesh piece 310 inside mesh :(
# Total time = 0.5261156558990479
# Mesh piece 311 inside mesh :(
# Total time = 0.4447152614593506
# Mesh piece 312 inside mesh :(
# Total time = 0.4454972743988037
# Mesh piece 313 inside mesh :(
# Total time = 0.49192190170288086
# Mesh piece 314 inside mesh :(
# Total time = 0.4438340663909912
# Mesh piece 315 inside mesh :(
# Total time = 0.6351792812347412
# Mesh piece 316 inside mesh :(
# Total time = 0.6216025352478027
# Mesh piece 317 inside mesh :(
# Total time = 0.5940077304840088
# Mesh piece 318 inside mesh :(
# Total time = 0.5764925479888916
# Mesh piece 319 inside mesh :(
# Total time = 0.6102514266967773
# Mesh piece 320 inside mesh :(
# Total time = 0.5730969905853271
# Mesh piece 321 inside mesh :(
# Total time = 0.5496780872344971
# Mesh piece 322 inside mesh :(
# Total time = 0.6952376365661621
# Mesh piece 323 inside mesh :(
# Total time = 0.7033224105834961
# Mesh piece 324 inside mesh :(
# Total time = 0.5528368949890137
# Mesh piece 325 inside mesh :(
# Total time = 0.5626833438873291
# Mesh piece 326 inside mesh :(
# Total time = 0.7225661277770996
# Mesh piece 327 inside mesh :(
# Total time = 0.5076866149902344
# Mesh piece 328 inside mesh :(
# Total time = 0.6089437007904053
# Mesh piece 329 inside mesh :(
# Total time = 0.6279821395874023
# Mesh piece 330 inside mesh :(
# Total time = 0.22467780113220215
# Mesh piece 331 inside mesh :(
# Total time = 0.6969637870788574
# Mesh piece 332 inside mesh :(
# Total time = 0.8244316577911377
# Mesh piece 333 inside mesh :(
# Total time = 0.8402233123779297
# Mesh piece 334 inside mesh :(
# Total time = 0.8020761013031006
# Mesh piece 335 inside mesh :(
# Total time = 0.7082676887512207
# Mesh piece 336 inside mesh :(
# Total time = 0.6369116306304932
# Mesh piece 337 inside mesh :(
# Total time = 0.7180066108703613
# Mesh piece 338 inside mesh :(
# Total time = 0.628929615020752
# Mesh piece 339 inside mesh :(
# Total time = 0.6040143966674805
# Mesh piece 340 inside mesh :(
# Total time = 0.6773238182067871
# Mesh piece 341 inside mesh :(
# Total time = 0.6665356159210205
# Mesh piece 342 inside mesh :(
# Total time = 0.6209094524383545
# Mesh piece 343 inside mesh :(
# Total time = 0.6185202598571777
# Mesh piece 344 inside mesh :(
# Total time = 0.7720568180084229
# Mesh piece 345 inside mesh :(
# Total time = 0.755429744720459
# Mesh piece 346 inside mesh :(
# Total time = 0.609391450881958
# Mesh piece 347 inside mesh :(
# Total time = 0.643230676651001
# Mesh piece 348 inside mesh :(
# Total time = 0.756904125213623
# Mesh piece 349 inside mesh :(
# Total time = 0.7822775840759277
# Mesh piece 350 inside mesh :(
# Total time = 0.7857327461242676
# Mesh piece 351 inside mesh :(
# Total time = 0.7645516395568848
# Mesh piece 352 inside mesh :(
# Total time = 0.7205486297607422
# Mesh piece 353 inside mesh :(
# Total time = 0.6730101108551025
# Mesh piece 354 inside mesh :(
# Total time = 0.6697494983673096
# Mesh piece 355 inside mesh :(
# Total time = 0.7014858722686768
# Mesh piece 356 inside mesh :(
# Total time = 0.6833205223083496
# Mesh piece 357 inside mesh :(
# Total time = 0.6954090595245361
# Mesh piece 358 inside mesh :(
# Total time = 0.42215442657470703
# Mesh piece 359 inside mesh :(
# Total time = 0.36443638801574707
# Mesh piece 360 inside mesh :(
# Total time = 0.29584360122680664
# Mesh piece 361 inside mesh :(
# Total time = 0.42851710319519043
# Mesh piece 362 inside mesh :(
# Total time = 0.4918022155761719
# Mesh piece 363 inside mesh :(
# Total time = 0.4239363670349121
# Mesh piece 364 inside mesh :(
# Total time = 0.4982612133026123
# Mesh piece 365 inside mesh :(
# Total time = 0.5602645874023438
# Mesh piece 366 inside mesh :(
# Total time = 0.7422842979431152
# Mesh piece 367 inside mesh :(
# Total time = 0.7135896682739258
# Mesh piece 368 inside mesh :(
# Total time = 0.6365048885345459
# Mesh piece 369 inside mesh :(
# Total time = 0.6298348903656006
# Mesh piece 370 inside mesh :(
# Total time = 0.6293590068817139
# Mesh piece 371 inside mesh :(
# Total time = 0.7133824825286865
# Mesh piece 372 inside mesh :(
# Total time = 0.8931064605712891
# Mesh piece 373 inside mesh :(
# Total time = 0.6966562271118164
# Mesh piece 374 inside mesh :(
# Total time = 0.5206575393676758
# Mesh piece 375 inside mesh :(
# Total time = 0.6278574466705322
# Mesh piece 376 inside mesh :(
# Total time = 0.6759426593780518
# Mesh piece 377 inside mesh :(
# Total time for Mesh Cleansing: 251.28741836547852

# %% [markdown]
# # FACET GENERATION AND FILTERING FUNCTIONS

# %%
import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# need a way of finding the neighbors that have to share adjacent faces
def create_neighbors_lookup(mesh):
    start_time = time.time()
    neighbors_lookup = dict([(i,[]) for i in range(0,len(mesh.faces))])
    #print(f"Creating empty dictionary : {time.time() - start_time}")
    
    start_time = time.time()
    for adj in mesh.face_adjacency:
        neighbors_lookup[adj[0]].append(adj[1])
        neighbors_lookup[adj[1]].append(adj[0])
    #print(f"Filling in neighbors lookup : {time.time() - start_time}")
    
    return neighbors_lookup

# need a way of finding the neighbors that have to share adjacent faces
def create_facet_lookup(mesh):
    start_time = time.time()
    facets_lookup = np.ones(len(main_mesh.faces))*-1
    
    start_time = time.time()
    for jj,facet in enumerate(mesh.facets):
        for fac in facet:
            facets_lookup[fac] = jj
    
    print(f"Filling in facet lookup : {time.time() - start_time}")
    
    return facets_lookup

def filter_and_expand_facets(new_mesh,
                             first_pass_size_threshold=2000,
                             normal_closeness=0.985):
    
    """
    
    """
    
    #filter the facets that are below a size threshold
    new_facets = new_mesh.facets[np.where(new_mesh.facets_area > first_pass_size_threshold)[0]]

    #is a fast lookup for the neighbors of a certain face
    neighbors_lookup = create_neighbors_lookup(new_mesh)
    
    #generate a normals lookup table and see if works faster than regular lookup
    normal_lookup = {}

    for i in range(0,len(new_mesh.faces)):
        normal_lookup[i] = new_mesh.face_normals[i]
    
    global_start_time = time.time()
    final_facets= [0]*len(new_facets)
    
    #creates entire list of neighbors that have been added in expansion
    #if a neighbor was already added that was already in the current facet
    #then that facet has already been absorbed and need to delete that
    

    #these are facets that need to be deleted at the end
    
    
    
    """
    Other way to optimize

    1) Create lookup dictionary that maps the face back to the facet
    2) when add a neighbor add the set of all their facets to the facet to delete


    """
    print("Total number of facets = " + str(len(new_facets)))
    facet_lookup = create_facet_lookup(new_mesh)
    facets_to_delete = set()
    
    for i,facet in enumerate(new_facets):
#         mini_global_start_time = time.time()
    #     print(facet)
    #     print(type(facet))
    #     start_time = time.time()
    #     print([find_neighbors(k) for k in facet])
    
    

#         new_time = time.time()
#         # make sure that there are no repeats of facets by checking for common elements
#         if not set(total_added_neighbors).isdisjoint(facet):
#             facets_to_delete.append(i)
#             #print("found overlapping neighbor")
#             continue
#         print(f"Time for check = {time.time() - new_time}")
            
        if i in facets_to_delete:
            continue
    
    
    #gets all of the neighbors
        total_neighbors = list(set(np.hstack([neighbors_lookup[k] for k in facet])).difference(set(facet)))
    #     print(total_neighbors)
    #     print(f"time initial neighbors: {(time.time() - start_time)}")
        neighbors_to_add = []
        neighbors_checked = []
        #print(total_neighbors)

        #just get the normal from one of the faces already in the facet
    #     start_time = time.time()
        facet_normal = normal_lookup[facet[0]]

    #     total_dot_time = 0
        while len(total_neighbors) > 0:
            current_neighbor = total_neighbors.pop()
            neighbors_checked.append(current_neighbor)

    #         print("--------------")
    # #         #check to see if neighbor has same normal face
    # #         start_dot_time = time.time()
    # #         dot_result = np.dot(new_mesh.face_normals[current_neighbor],facet_normal) #> normal_closeness
    # #         print(dot_result)
    # #         print((time.time() - start_dot_time) * 1000)

    #         start_dot_time = time.time()
    #         print(current_neighbor)
    #         #a = new_mesh.face_normals[current_neighbor]

    #         print((time.time() - start_dot_time) * 1000)
    #         dot_result = a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness
    #         print(dot_result)
    #         print((time.time() - start_dot_time) * 1000)
    #         print("--------------")

    #         total_dot_time += (time.time() - start_dot_time)*1000

            a = normal_lookup[current_neighbor]
            if a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness:

                neighbors_to_add.append(current_neighbor)
                #get the neighbors of this current face
                for neigh in neighbors_lookup[current_neighbor]:
                    #only add those neighbors that havent already been checked, in original facet group, or already in list to check
                    if neigh not in neighbors_checked and neigh not in facet and neigh not in total_neighbors:
                        total_neighbors.append(neigh)
    #     print(f"Total dot time: {total_dot_time}")
    #     print(f"time loop: {(time.time() - start_time)}")
    #     print("neighbors_to_add = " + str(neighbors_to_add))abs
    #     print("neighbors_checked = " + str(neighbors_checked))
    #     print("adding list = " + str(list(facet) + neighbors_to_add))
    #     start_time = time.time()
        
        #get all the facets of the neighbors to add
        neighbors_to_add_facets = facet_lookup[neighbors_to_add]
        facets_to_delete = facets_to_delete.union(set(neighbors_to_add_facets))
        
        final_facets[i] = np.array(list(facet) + neighbors_to_add)
    #     print(f"Appending to list: {(time.time() - start_time)}")

#         print(f"Total time: {(time.time() - mini_global_start_time)}")
    #     print("------------------------------------------------------")


    print(f"Total Facet building time: {(time.time() - global_start_time)}")
    print(f"Found Total number of overlapping faces: {len(facets_to_delete)}")
    
    #print("facets_to_delete = " + str(facets_to_delete))
    #delete the faces = 
    final_facets = np.delete(final_facets,list(facets_to_delete),axis=0)
    return final_facets

def filter_final_facets(gap_mesh):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """
    
    final_facets = filter_and_expand_facets(gap_mesh,
                                 first_pass_size_threshold=2000,
                                 normal_closeness=0.985)
    
    

    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #print(final_facets_mean_filtered)
    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %% [markdown]
# # DEBUGGING THE FILTER FACETS SPEED

# %%
# start_time = time.time()

# #facets_list, centers_list,neighbors_added = filter_final_facets(main_mesh)
# final_facets,facet_centers = filter_final_facets(main_mesh)

# print(f"Total time for overlapping check = {time.time() - start_time}")

# final_facets_1 = final_facets[0]
# len(total_added_neighbors)


# len(final_facets)

# new_time = time.time()
# # make sure that there are no repeats of facets by checking for common elements
# if not set(total_added_neighbors).isdisjoint(final_facets_1):
#     #facets_to_delete.append(i)
#     print("found overlapping neighbor")
# print(f"Time for check = {(time.time() - new_time)*len(final_facets)/60}")

# """
# Conclusion this method would be too slow
# """

# %% [markdown]
# # FAILED WAY TO OPTIMIZE #1

# %%
# start_time = time.time()
# for ff1,facet1 in enumerate(facets_list):
#     #get the difference of both of them
#     start_time = time.time()
#     for ff2,facet2 in enumerate(facets_list):
#         if ff2>ff1 and (ff2 not in facets_to_delete):
#             common_elements = set(facet1).intersection(set(facet2))
#             #print(common_elements)
#             if (len(common_elements)/len(facet1)) >= 0.75:
#                 print("Found overlapping faces")
#                 facets_to_delete.append(ff2)
#     print(f"Total time for overlapping check = {(time.time() - start_time)*len(facets_list)/60}")
#     break

# %%
# THE OLDER FACET FILTERING METHOD THAT DOESN'T RETURN AS MANY FACETS BUT MISSES OUT ON THE 
#SMALL ONES

def filter_final_facets_working(gap_mesh,final_facets):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """


    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
def filter_final_facets_optimized_with_checks(example_mesh,
                                  normal_closeness=0.99,
                                  first_pass_size_threshold=6000):
    """
    Way of computing facets that uses trimesh grouping function and normals threshold
    instead of the pre-built trimesh.facets
    
    """

    #get the facets for the child mesh
    start_time_total = time.time()

    #switch out with dot product
    
    
    #Old way of computing the dot product manually
    total_normals = example_mesh.face_normals[example_mesh.face_adjacency]
    
    #using manual method
#     print(len(total_normals[:,0]*total_normals[:,1]))
    start_normal = time.time()
    total_normal_dots = np.sum(total_normals[:,0]*total_normals[:,1],axis=1)
    print(f"Total normals took {time.time() - start_normal}")
    ''' DONT HAVE TO DO DOT PRODUCT BECAUSE JUST WANT TO MULTIPLY THE ROWS OF EACH COLUMN'''
#     print("About to do dot product")
#     dot_start = time.time()
#     a = total_normals[:,0]
#     b = total_normals[:,1].T
#     #new way using the dot product
#     total_normal_dots = np.dot(a,b)
    
    
    #get the True/False value if face adjacency is within normal closeness
    start_normal = time.time()
    total_normal_dots_facet_mask = total_normal_dots > normal_closeness
    print(f"Boolean mask finished: {time.time() - start_normal}")

    #getting the grouping of the faces into facets within the threshold
    start_normal = time.time()
    components = trimesh.graph.connected_components(example_mesh.face_adjacency[total_normal_dots_facet_mask],
                                          nodes=np.arange(len(example_mesh.faces)),
                                          min_len=2,
                                          engine="None")
    print(f"Grouping took: {time.time() - start_normal}")
    
    

    #print(f"Lenght of facets BEFORE filtering = {len(components)}")
    
    #filter by the size
    
    start_normal = time.time()
    size_filtered_components = [facet_list for facet_list in components 
                                    if find_polygon_area(example_mesh,facet_list) > first_pass_size_threshold]
    print(f"Filtering edges by size finished: {time.time() - start_normal}")
    


    #filter by the convexity
    #final_facets_mean_filtered,final_facets_centers = filter_final_facets(example_mesh,size_filtered_components)
    
    start_normal = time.time()
    final_facets_mean_filtered,final_facets_centers = filter_final_facets_working(example_mesh,size_filtered_components)
    print(f"Filtering by convexity and getting centers took: {time.time() - start_normal}")

    
    print(f"Total Time = {time.time() - start_time_total}")

    return final_facets_mean_filtered,final_facets_centers

# %% [markdown]
# # ACTUALLY CALCULATING THE FACETS

# %%
"""
Rule: 
1) if mesh size is above a threshold --> run the unoptimized less careful version
2) if mesh is below that size --> run optimized more generous (but with all the filters )

"""
facet_time = time.time()
start_time = time.time()

length_threshold = 60000

if len(main_mesh.faces > length_threshold):
    print(f" face length {len(main_mesh.faces)} using unoptimized facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
    
else:
    print(f" face length {len(main_mesh.faces)} using OPTIMIZED facets")
    main_mesh_facets,main_mesh_facets_centers = filter_final_facets_optimized_with_checks(main_mesh)
    

print(f"Finished { len(main_mesh_facets)} facets for main mesh: {time.time() - start_time}")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    
    start_time = time.time()
    if len(gap_mesh.faces) > length_threshold:
        print(f" face length {len(gap_mesh.faces)} using unoptimized facets")
        child_meshes_facets.append(filter_final_facets(gap_mesh))
    else:
        print(f" face length {len(gap_mesh.faces)} using OPTIMIZED facets")
        child_meshes_facets.append(filter_final_facets_optimized_with_checks(gap_mesh))

    
    print(f"Finished facets for child {jj} : {time.time() - start_time} with facet length = {len(child_meshes_facets[jj][0])}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]
# Out:
#  face length 1845336 using unoptimized facets
# Total number of facets = 59411
# Filling in facet lookup : 0.11599278450012207
# Total Facet building time: 16.507033586502075
# Found Total number of overlapping faces: 17861
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:162: FutureWarning: in the future negative indices will not be ignored by `numpy.delete`.
# Finished 11118 facets for main mesh: 55.251808881759644
#  face length 117018 using unoptimized facets
# Total number of facets = 3693
# Filling in facet lookup : 0.007793903350830078
# Total Facet building time: 0.3681912422180176
# Found Total number of overlapping faces: 1091
# Finished facets for child 0 : 2.4274303913116455 with facet length = 699
#  face length 16458 using OPTIMIZED facets
# Total normals took 0.000545501708984375
# Boolean mask finished: 0.0001308917999267578
# Grouping took: 0.0061550140380859375
# Filtering edges by size finished: 0.444427490234375
# Filtering by convexity and getting centers took: 0.6628556251525879
# Total Time = 1.1227242946624756
# Finished facets for child 1 : 1.1232471466064453 with facet length = 644
#  face length 32560 using OPTIMIZED facets
# Total normals took 0.0010762214660644531
# Boolean mask finished: 0.00014495849609375
# Grouping took: 0.011479616165161133
# Filtering edges by size finished: 0.7998263835906982
# Filtering by convexity and getting centers took: 1.128209114074707
# Total Time = 1.9575982093811035
# Finished facets for child 2 : 1.9583256244659424 with facet length = 485
#  face length 27890 using OPTIMIZED facets
# Total normals took 0.0009014606475830078
# Boolean mask finished: 8.58306884765625e-05
# Grouping took: 0.009083986282348633
# Filtering edges by size finished: 0.6099143028259277
# Filtering by convexity and getting centers took: 1.1719238758087158
# Total Time = 1.8070323467254639
# Finished facets for child 3 : 1.8076817989349365 with facet length = 887
#  face length 17314 using OPTIMIZED facets
# Total normals took 0.000720977783203125
# Boolean mask finished: 0.00010895729064941406
# Grouping took: 0.006140470504760742
# Filtering edges by size finished: 0.4223787784576416
# Filtering by convexity and getting centers took: 0.5967719554901123
# Total Time = 1.0355441570281982
# Finished facets for child 4 : 1.0359265804290771 with facet length = 521
#  face length 5608 using OPTIMIZED facets
# Total normals took 0.0002994537353515625
# Boolean mask finished: 0.00011730194091796875
# Grouping took: 0.0026929378509521484
# Filtering edges by size finished: 0.15126633644104004
# Filtering by convexity and getting centers took: 0.22637438774108887
# Total Time = 0.38469386100769043
# Finished facets for child 5 : 0.3850438594818115 with facet length = 203
#  face length 16714 using OPTIMIZED facets
# Total normals took 0.0005919933319091797
# Boolean mask finished: 0.0001323223114013672
# Grouping took: 0.006069183349609375
# Filtering edges by size finished: 0.40161752700805664
# Filtering by convexity and getting centers took: 0.5980186462402344
# Total Time = 1.0149354934692383
# Finished facets for child 6 : 1.0152721405029297 with facet length = 567
#  face length 8374 using OPTIMIZED facets
# Total normals took 0.0002887248992919922
# Boolean mask finished: 8.916854858398438e-05
# Grouping took: 0.003301382064819336
# Filtering edges by size finished: 0.1972639560699463
# Filtering by convexity and getting centers took: 0.28189921379089355
# Total Time = 0.48728013038635254
# Finished facets for child 7 : 0.48748159408569336 with facet length = 212
#  face length 5420 using OPTIMIZED facets
# Total normals took 0.0002129077911376953
# Boolean mask finished: 7.700920104980469e-05
# Grouping took: 0.0024611949920654297
# Filtering edges by size finished: 0.13501429557800293
# Filtering by convexity and getting centers took: 0.19428372383117676
# Total Time = 0.3353922367095947
# Finished facets for child 8 : 0.33553028106689453 with facet length = 170
#  face length 19204 using OPTIMIZED facets
# Total normals took 0.0007834434509277344
# Boolean mask finished: 9.083747863769531e-05
# Grouping took: 0.0066890716552734375
# Filtering edges by size finished: 0.46649742126464844
# Filtering by convexity and getting centers took: 0.6893296241760254
# Total Time = 1.1731140613555908
# Finished facets for child 9 : 1.1735875606536865 with facet length = 460
#  face length 3524 using OPTIMIZED facets
# Total normals took 0.00014019012451171875
# Boolean mask finished: 1.1205673217773438e-05
# Grouping took: 0.002252817153930664
# Filtering edges by size finished: 0.08594870567321777
# Filtering by convexity and getting centers took: 0.13019990921020508
# Total Time = 0.22161507606506348
# Finished facets for child 10 : 0.22171878814697266 with facet length = 130
#  face length 12664 using OPTIMIZED facets
# Total normals took 0.0004208087921142578
# Boolean mask finished: 9.131431579589844e-05
# Grouping took: 0.0046079158782958984
# Filtering edges by size finished: 0.31954216957092285
# Filtering by convexity and getting centers took: 0.4862556457519531
# Total Time = 0.8179764747619629
# Finished facets for child 11 : 0.8182623386383057 with facet length = 290
#  face length 6432 using OPTIMIZED facets
# Total normals took 0.00023436546325683594
# Boolean mask finished: 0.00012922286987304688
# Grouping took: 0.0028650760650634766
# Filtering edges by size finished: 0.14069533348083496
# Filtering by convexity and getting centers took: 0.2656283378601074
# Total Time = 0.41373586654663086
# Finished facets for child 12 : 0.4138987064361572 with facet length = 191
#  face length 6132 using OPTIMIZED facets
# Total normals took 0.000225067138671875
# Boolean mask finished: 7.82012939453125e-05
# Grouping took: 0.0026128292083740234
# Filtering edges by size finished: 0.1702558994293213
# Filtering by convexity and getting centers took: 0.26738929748535156
# Total Time = 0.4442179203033447
# Finished facets for child 13 : 0.44437360763549805 with facet length = 185
#  face length 8086 using OPTIMIZED facets
# Total normals took 0.00034809112548828125
# Boolean mask finished: 0.00010085105895996094
# Grouping took: 0.0033028125762939453
# Filtering edges by size finished: 0.19536304473876953
# Filtering by convexity and getting centers took: 0.3025965690612793
# Total Time = 0.5062692165374756
# Finished facets for child 14 : 0.5064647197723389 with facet length = 187
#  face length 19179 using OPTIMIZED facets
# Total normals took 0.0006661415100097656
# Boolean mask finished: 0.00010371208190917969
# Grouping took: 0.006528139114379883
# Filtering edges by size finished: 0.44840550422668457
# Filtering by convexity and getting centers took: 0.7144262790679932
# Total Time = 1.1804516315460205
# Finished facets for child 15 : 1.1808586120605469 with facet length = 470
#  face length 8014 using OPTIMIZED facets
# Total normals took 0.000274658203125
# Boolean mask finished: 9.894371032714844e-05
# Grouping took: 0.0031626224517822266
# Filtering edges by size finished: 0.1780710220336914
# Filtering by convexity and getting centers took: 0.28548336029052734
# Total Time = 0.4716005325317383
# Finished facets for child 16 : 0.4717874526977539 with facet length = 261
#  face length 348 using OPTIMIZED facets
# Total normals took 4.315376281738281e-05
# Boolean mask finished: 1.0967254638671875e-05
# Grouping took: 0.0011169910430908203
# Filtering edges by size finished: 0.010178565979003906
# Filtering by convexity and getting centers took: 0.010950326919555664
# Total Time = 0.02400350570678711
# Finished facets for child 17 : 0.024064302444458008 with facet length = 10
#  face length 268 using OPTIMIZED facets
# Total normals took 3.695487976074219e-05
# Boolean mask finished: 7.152557373046875e-06
# Grouping took: 0.0011625289916992188
# Filtering edges by size finished: 0.008385181427001953
# Filtering by convexity and getting centers took: 0.011708974838256836
# Total Time = 0.02269911766052246
# Finished facets for child 18 : 0.022756338119506836 with facet length = 16
#  face length 74 using OPTIMIZED facets
# Total normals took 3.123283386230469e-05
# Boolean mask finished: 6.9141387939453125e-06
# Grouping took: 0.0007352828979492188
# Filtering edges by size finished: 0.0019435882568359375
# Filtering by convexity and getting centers took: 0.0045359134674072266
# Total Time = 0.008425235748291016
# Finished facets for child 19 : 0.008480548858642578 with facet length = 4
#  face length 216 using OPTIMIZED facets
# Total normals took 0.0001304149627685547
# Boolean mask finished: 7.867813110351562e-06
# Grouping took: 0.0012478828430175781
# Filtering edges by size finished: 0.0073795318603515625
# Filtering by convexity and getting centers took: 0.010631799697875977
# Total Time = 0.02103900909423828
# Finished facets for child 20 : 0.021096467971801758 with facet length = 16
#  face length 596 using OPTIMIZED facets
# Total normals took 5.7220458984375e-05
# Boolean mask finished: 1.1682510375976562e-05
# Grouping took: 0.0011324882507324219
# Filtering edges by size finished: 0.023414134979248047
# Filtering by convexity and getting centers took: 0.0157010555267334
# Total Time = 0.04194784164428711
# Finished facets for child 21 : 0.04200911521911621 with facet length = 14
#  face length 32 using OPTIMIZED facets
# Total normals took 2.9802322387695312e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0007174015045166016
# Filtering edges by size finished: 0.0016980171203613281
# Filtering by convexity and getting centers took: 0.0001323223114013672
# Total Time = 0.0036907196044921875
# Finished facets for child 22 : 0.0037429332733154297 with facet length = 0
#  face length 1256 using OPTIMIZED facets
# Total normals took 8.463859558105469e-05
# Boolean mask finished: 1.1444091796875e-05
# Grouping took: 0.0013599395751953125
# Filtering edges by size finished: 0.038872480392456055
# Filtering by convexity and getting centers took: 0.04475045204162598
# Total Time = 0.0874643325805664
# Finished facets for child 23 : 0.08753633499145508 with facet length = 63
#  face length 236 using OPTIMIZED facets
# Total normals took 3.0040740966796875e-05
# Boolean mask finished: 6.9141387939453125e-06
# Grouping took: 0.0010571479797363281
# Filtering edges by size finished: 0.006371736526489258
# Filtering by convexity and getting centers took: 0.00780177116394043
# Total Time = 0.016757488250732422
# Finished facets for child 24 : 0.016810894012451172 with facet length = 8
#  face length 1390 using OPTIMIZED facets
# Total normals took 8.177757263183594e-05
# Boolean mask finished: 1.0967254638671875e-05
# Grouping took: 0.0014388561248779297
# Filtering edges by size finished: 0.04283022880554199
# Filtering by convexity and getting centers took: 0.047350406646728516
# Total Time = 0.0935966968536377
# Finished facets for child 25 : 0.09367227554321289 with facet length = 56
#  face length 54 using OPTIMIZED facets
# Total normals took 3.361701965332031e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0008428096771240234
# Filtering edges by size finished: 0.001988649368286133
# Filtering by convexity and getting centers took: 0.004017829895019531
# Total Time = 0.008013248443603516
# Finished facets for child 26 : 0.00806427001953125 with facet length = 5
#  face length 80 using OPTIMIZED facets
# Total normals took 3.123283386230469e-05
# Boolean mask finished: 6.9141387939453125e-06
# Grouping took: 0.0008597373962402344
# Filtering edges by size finished: 0.001957416534423828
# Filtering by convexity and getting centers took: 0.003687143325805664
# Total Time = 0.0076906681060791016
# Finished facets for child 27 : 0.0077435970306396484 with facet length = 3
#  face length 2672 using OPTIMIZED facets
# Total normals took 0.0001087188720703125
# Boolean mask finished: 9.894371032714844e-05
# Grouping took: 0.0015969276428222656
# Filtering edges by size finished: 0.08419227600097656
# Filtering by convexity and getting centers took: 0.10503149032592773
# Total Time = 0.19396424293518066
# Finished facets for child 28 : 0.19406986236572266 with facet length = 124
#  face length 5268 using OPTIMIZED facets
# Total normals took 0.0002181529998779297
# Boolean mask finished: 0.0002052783966064453
# Grouping took: 0.0025396347045898438
# Filtering edges by size finished: 0.11418032646179199
# Filtering by convexity and getting centers took: 0.27192258834838867
# Total Time = 0.3927178382873535
# Finished facets for child 29 : 0.39287400245666504 with facet length = 184
#  face length 1724 using OPTIMIZED facets
# Total normals took 0.00010657310485839844
# Boolean mask finished: 0.0001842975616455078
# Grouping took: 0.0013425350189208984
# Filtering edges by size finished: 0.05710029602050781
# Filtering by convexity and getting centers took: 0.04328155517578125
# Total Time = 0.10405850410461426
# Finished facets for child 30 : 0.10417366027832031 with facet length = 34
#  face length 3786 using OPTIMIZED facets
# Total normals took 0.0001475811004638672
# Boolean mask finished: 9.846687316894531e-05
# Grouping took: 0.0021131038665771484
# Filtering edges by size finished: 0.11301636695861816
# Filtering by convexity and getting centers took: 0.11639142036437988
# Total Time = 0.23439455032348633
# Finished facets for child 31 : 0.23452353477478027 with facet length = 53
#  face length 802 using OPTIMIZED facets
# Total normals took 7.104873657226562e-05
# Boolean mask finished: 1.0251998901367188e-05
# Grouping took: 0.0012416839599609375
# Filtering edges by size finished: 0.026620864868164062
# Filtering by convexity and getting centers took: 0.028551101684570312
# Total Time = 0.05825352668762207
# Finished facets for child 32 : 0.058316707611083984 with facet length = 27
#  face length 606 using OPTIMIZED facets
# Total normals took 5.7697296142578125e-05
# Boolean mask finished: 8.821487426757812e-06
# Grouping took: 0.0012252330780029297
# Filtering edges by size finished: 0.02500128746032715
# Filtering by convexity and getting centers took: 0.02389240264892578
# Total Time = 0.05172467231750488
# Finished facets for child 33 : 0.05178189277648926 with facet length = 28
#  face length 1456 using OPTIMIZED facets
# Total normals took 9.512901306152344e-05
# Boolean mask finished: 1.1205673217773438e-05
# Grouping took: 0.0013585090637207031
# Filtering edges by size finished: 0.04395270347595215
# Filtering by convexity and getting centers took: 0.050354957580566406
# Total Time = 0.09763455390930176
# Finished facets for child 34 : 0.09770798683166504 with facet length = 63
#  face length 632 using OPTIMIZED facets
# Total normals took 5.8650970458984375e-05
# Boolean mask finished: 9.5367431640625e-06
# Grouping took: 0.0012311935424804688
# Filtering edges by size finished: 0.021529436111450195
# Filtering by convexity and getting centers took: 0.025020837783813477
# Total Time = 0.0495297908782959
# Finished facets for child 35 : 0.04959392547607422 with facet length = 18
#  face length 92 using OPTIMIZED facets
# Total normals took 2.9325485229492188e-05
# Boolean mask finished: 6.67572021484375e-06
# Grouping took: 0.0010609626770019531
# Filtering edges by size finished: 0.004555225372314453
# Filtering by convexity and getting centers took: 0.0036683082580566406
# Total Time = 0.010231971740722656
# Finished facets for child 36 : 0.010283470153808594 with facet length = 5
#  face length 968 using OPTIMIZED facets
# Total normals took 5.841255187988281e-05
# Boolean mask finished: 2.1219253540039062e-05
# Grouping took: 0.0013267993927001953
# Filtering edges by size finished: 0.0418391227722168
# Filtering by convexity and getting centers took: 0.02847576141357422
# Total Time = 0.0739281177520752
# Finished facets for child 37 : 0.07399106025695801 with facet length = 37
#  face length 170 using OPTIMIZED facets
# Total normals took 0.00012230873107910156
# Boolean mask finished: 7.62939453125e-06
# Grouping took: 0.0012106895446777344
# Filtering edges by size finished: 0.0054361820220947266
# Filtering by convexity and getting centers took: 0.008402109146118164
# Total Time = 0.016640663146972656
# Finished facets for child 38 : 0.016693115234375 with facet length = 10
#  face length 260 using OPTIMIZED facets
# Total normals took 4.100799560546875e-05
# Boolean mask finished: 6.9141387939453125e-06
# Grouping took: 0.001245737075805664
# Filtering edges by size finished: 0.009822607040405273
# Filtering by convexity and getting centers took: 0.01054072380065918
# Total Time = 0.023127317428588867
# Finished facets for child 39 : 0.023190975189208984 with facet length = 17
#  face length 66 using OPTIMIZED facets
# Total normals took 3.0279159545898438e-05
# Boolean mask finished: 6.198883056640625e-06
# Grouping took: 0.0008606910705566406
# Filtering edges by size finished: 0.0012636184692382812
# Filtering by convexity and getting centers took: 0.0031609535217285156
# Total Time = 0.006507396697998047
# Finished facets for child 40 : 0.006558418273925781 with facet length = 4
#  face length 124 using OPTIMIZED facets
# Total normals took 0.0001251697540283203
# Boolean mask finished: 7.3909759521484375e-06
# Grouping took: 0.0010135173797607422
# Filtering edges by size finished: 0.0028755664825439453
# Filtering by convexity and getting centers took: 0.005440950393676758
# Total Time = 0.010645389556884766
# Finished facets for child 41 : 0.010698318481445312 with facet length = 6
#  face length 260 using OPTIMIZED facets
# Total normals took 0.00012183189392089844
# Boolean mask finished: 8.106231689453125e-06
# Grouping took: 0.001271963119506836
# Filtering edges by size finished: 0.009965896606445312
# Filtering by convexity and getting centers took: 0.01387786865234375
# Total Time = 0.027040719985961914
# Finished facets for child 42 : 0.027094364166259766 with facet length = 7
# Total time for facets: 72.74826312065125

# %% [markdown]
# # Check that facet extraction for each piece worked

# %%
# # download the facets and make sure they match

# current_facets = main_mesh_facets
# current_mesh = main_mesh
# index = "main"


# facets_group = np.zeros(len(current_mesh.faces)).astype(int)

# for i,facet_group in enumerate(current_facets):
#     for face in facet_group:
#         facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

# np.savez("./test_meshes/" + str(index) + "_debug_june_facet_" + str(index) + ".npz",
#          facets_group=facets_group)

# from print_trimesh import print_trimesh
# print_trimesh(current_mesh,"./test_meshes/piece_debug_june_" + str(index) + ".off")

# %%
# # download the facets and make sure they match
# final_facets_mean_filtered

# # download the facets list and see if the process worked:
# index = 1
# facets_group = np.zeros(len(child_meshes[index].faces)).astype(int)

# for i,facet_group in enumerate(size_filtered_components):
#     for face in facet_group:
#         facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

# np.savez("./test_meshes/" + "1_facet_piece_" + str(index) + ".npz",
#          facets_group=facets_group,facets_group_centers=final_facets_centers)

# from print_trimesh import print_trimesh
# print_trimesh(child_meshes[index],"./test_meshes/piece_" + str(index) + ".off")


# len(final_facets_mean_filtered)

# %% [markdown]
# # START ITERATIVE PROCESS THAT CONNECTS THE MESHES

# %%
def apply_bbox_filter(child,min_bb_zone,max_bb_zone):
    """
    Determines if child is withing the bounding box zone
    designated by the bounding box corners
    
    """
    #get the min and max of the bounding box for the mesh
    min_bb = np.array(child.bounding_box.vertices).min(0)
    max_bb = np.array(child.bounding_box.vertices).max(0)
    
    #print(min_bb,max_bb)
    #print(min_bb_zone,max_bb_zone)
    
    #if fails any of these checks then return false, else return True
    if min(min_bb[0],max_bb[0])>max_bb_zone[0]:
        print("returning x greater max")
        return False
    
    if max(min_bb[0],max_bb[0])<min_bb_zone[0]:
        print("returning x less min")
        return False
    
    if min(min_bb[1],max_bb[1])>max_bb_zone[1]:
        print("returning y greater max")
        return False
    
    if max(min_bb[1],max_bb[1])<min_bb_zone[1]:
        print("returning y less min")
        return False
        
    if min(min_bb[2],max_bb[2])>max_bb_zone[2]:
        print("returning z greater max")
        return False
    
    if max(min_bb[2],max_bb[2])<min_bb_zone[2]:
        print("returning z less mim")
        return False
    return True

import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# restitching functions
import trimesh
import numpy as np
from collections import Counter
import time
import math

#gets the projection of point p onto line a
def ClosestPointOnLine(a, b, p):
    ap = p-a
    ab = b-a
    #base_vector = ab
    result = np.dot(ap,ab)/np.dot(ab,ab) # * ab
    return result




#now have the mesh and the facet faces, can send to function
def stitch_mesh_piece_vp3(new_mesh,facet_1,facet_2,
                          delete_facets=False,
                         return_added_mesh = False,
                         fix_normals = False):
    """
    Changed since last version: 
    1) parameter for deleting facets at end or not
    2) parameter for returning added mesh or not 
    3) Changed normals check to print statement and not exception
    
    
    """
    #how to find the normals of facet groups:
    facet_group_1_normal = new_mesh.face_normals[facet_1[0]]
    facet_group_2_normal = new_mesh.face_normals[facet_2[0]]


    #get the correct version of the normals: (might need to flip them if going in opposite direction)
    if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
        print("same direction normals")
        pass
    elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
        print("opposite direction normals")
        facet_group_2_normal = facet_group_2_normal*-1
    else:
        print("Not correct normals")
        #raise Exception("Not correct normals")

    #print(facet_group_1_normal,facet_group_2_normal)

    # make each row correspond to a single face 
    edges = new_mesh.edges_sorted.reshape((-1, 6))
    # get the edges for each facet
    edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
    edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                               for i in edges_facet])

    #the list of boundary edges and unique points in the boundary edges
    edge_0 = edges_boundary[0]
    edge_1 = edges_boundary[1]

    #gets the unique number of points
    edge_0_points = np.unique(np.hstack(edge_0))
    edge_1_points = np.unique(np.hstack(edge_1))
    print("Found boundary edges")
    """
    get the dot product of all the points
    """

    #get any 2 points on the triangle and make that the reference edge
    edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

    #gets the starting index for the 1st facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_0_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_0_starting_point = edge_0_points[max_index]

    #gets the starting index for the 2nd facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_1_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_1_starting_point = edge_1_points[max_index]

    print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
    #print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

    """
    Need to order the points for restitching

    Pseudocode: 
    1) Get starting piont
    2) Find the two edges corresponding to that point
    3) Need to decide which direction to start....
    - go in direction that make the cross of the (1st and last) point in the same direction of the 
    normal of the first facet
    4) loop through and record the orders of the vertices as you traverse along the edges 
    until you arrive back at the start
    5) Error if:
        a. You arrive back at the start and haven't processed all the edges
        b. Processsed all the edges but haven't arrived back at start

    6) Repeat steps 1 through 5 for 2nd facet group
    """
    start_point_list = [edge_0_starting_point,edge_1_starting_point]
    edge_list = [edge_0,edge_1]
    edge_order_list = []

    #loop that organizes the unique boundary points into the correct order
    for i,start_point in enumerate(start_point_list):
        print(f"Starting Organizing vertices for side {i}")
        #print(f"start_point = {start_point}")
        edge_order = [start_point]
        processed_edges = []

        #find the matching edges
        starting_edges_indices = np.where(np.logical_or(edge_list[i][:,0] == start_point,edge_list[i][:,1] == start_point) == True)[0]
        print(starting_edges_indices)
        starting_edges = edge_list[i][starting_edges_indices]
        #print(f"starting edges = {starting_edges}") #the list of the two possible edges

        if starting_edges.size < 4:
            raise Exception("Not enough edges for 1st facet start point")

        if starting_edges.size > 4:
            raise Exception("Too many edges for 1st facet start point") 

        #np.where(starting_edges[1,:] != start_point)[0][0]
        #gets the vectors that will be used for the cross product
        #print("np.where(starting_edges[0,:] != start_point)[0][0] = " + str(np.where(starting_edges[0,:] != start_point)[0][0]))
        #print("np.where(starting_edges[1,:] != start_point)[0][0] = " + str(np.where(starting_edges[1,:] != start_point)[0][0]))


        #gets the possible starting vectors
        possible_starting_vector_1 = new_mesh.vertices[starting_edges[0,:][np.where(starting_edges[0,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        possible_starting_vector_2 = new_mesh.vertices[starting_edges[1,:][np.where(starting_edges[1,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        

        #find the cross product of the starting vectors
        starting_edges_cross = np.cross(possible_starting_vector_1,possible_starting_vector_2)

        #make sure that the order of the vectors goes so that the cross product is in line with the starting normal
        #this ensures the the circular direction of the stitching will be the same
        if np.dot(starting_edges_cross,facet_group_1_normal) > 0:
            print("Edge 1 picked for direction")
            processed_edges.append(starting_edges_indices[0])
            current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]
        else:
            print("Edge 2 picked for direction")
            processed_edges.append(starting_edges_indices[1])
            #print("np.where(starting_edges[1,:] != start_point) = " + str(np.where(starting_edges[1,:] != start_point)))
            current_vertex = starting_edges[1][np.where(starting_edges[1,:] != start_point)[0][0]]

        #print(f"current_vertex = {current_vertex}" )
        #print("edge_list = " + str(edge_list))

        #now iterate through number of 
        for z in range(1,edge_list[i][:,0].size):
            #print("edge_order_temp = " + str(edge_order))
            if current_vertex == start_point:
                print("Start vertex reached before processed all of edges")
                
                """
                
                These should be ok because the extra loops are created from holes inside and this process should always get the outside loop
                
                
                """
                break

            #get the next edge
            counter = 0
            next_vertex = -1
            for j,edg in enumerate(edge_list[i]):
                #print("edg = " + str(edg))
                #print("processed_edges = " + str(processed_edges))
                if current_vertex in edg and j not in processed_edges:
                    current_edge_index = j
                    if edg[0] != current_vertex:
                        next_vertex = edg[0]
                    else:
                        next_vertex = edg[1]


                    counter += 1
                    if counter >= 2:
                        #raise Exception(f"More than 2 edges possibilities for {current_vertex}")
                        #Don't want to make it an exception anymore put just print out warning
                        print("More than 2 edges possibilities for {current_vertex}") # BAC change

            #make sure the next vertex was found
            if next_vertex <= -1:
                raise Exception(f"No next vertex was found for {current_vertex} ")

            #if found next vertex then add the old vertex and edge index
            #to the processed edges lists and the order of vertices
            processed_edges.append(current_edge_index)
            edge_order.append(current_vertex)

            current_vertex = next_vertex


        edge_order_list.append(edge_order)
        print(f"edge_{i}_order done, len = {len(edge_order)} ")#"= {edge_order}")

    lengths_of_boundaries = [len(x) for x in edge_order_list]
    bigger = lengths_of_boundaries.index(max(lengths_of_boundaries))
    smaller = 1-bigger

    #print(f"index of bigger facets = {bigger}\nindex of smaller facets = {smaller}",)

    #calculates the number of vertices will be stitched to each vertices on smaller side
    dividend = int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])
    remainder = lengths_of_boundaries[bigger] - int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])*lengths_of_boundaries[smaller]

    print(f"dividend = {dividend}, remainder = {remainder}")

    #loop that adds the new faces
    print("About to add faces")
    start_time = time.time()
    new_faces = []
    current_bigger = 0
    for i,current_smaller in enumerate(edge_order_list[smaller]):
        #print("current_smaller =" + str(current_smaller))
        #print("current_bigger=" + str(current_bigger))
        if i == 0:
            new_faces.append([current_smaller,edge_order_list[smaller][-1],edge_order_list[bigger][current_bigger]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])

        for j in range(0,dividend + int(i<remainder)):
            if current_bigger > len(edge_order_list[bigger]):
                raise Exception("Somehow rapped around too much")

            if current_bigger >= len(edge_order_list[bigger])-1:
                next_bigger = 0
            else:
                next_bigger = current_bigger+1

            new_faces.append([current_smaller,edge_order_list[bigger][current_bigger],
                                edge_order_list[bigger][next_bigger]])

            current_bigger += 1

    #print("new_faces = " + str(new_faces))
    print(f"Finished adding faces: {time.time() - start_time}")
    

    print("Starting creating stitch mesh")
    start_time = time.time()
    stitch_mesh = trimesh.Trimesh()

    stitch_mesh.vertices = new_mesh.vertices
    stitch_mesh.faces = np.vstack([new_mesh.faces, new_faces])
    print(f"Finished creating stitch mesh: {time.time() - start_time}")
    



    if delete_facets == True:
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(stitch_mesh.faces)-1,len(stitch_mesh.faces)).astype("int")
        facet_faces = np.hstack([facet_1 ,facet_2])
        faces_to_keep = set(total_faces).difference(set(facet_faces))
        faces_to_keep

        stitch_mesh = stitch_mesh.submesh([list(faces_to_keep)])[0]

    if fix_normals == True:
        trimesh.repair.fix_inversion(stitch_mesh)
        trimesh.repair.fix_winding(stitch_mesh)
        trimesh.repair.fix_normals(stitch_mesh)
    
    #print("Finished stitching")

    if return_added_mesh == True:
        added_mesh = trimesh.Trimesh()
        added_mesh.vertices = new_mesh.vertices
        added_mesh.faces = new_faces
        trimesh.repair.fix_inversion(added_mesh)
        trimesh.repair.fix_winding(added_mesh)
        trimesh.repair.fix_normals(added_mesh)

        return stitch_mesh,added_mesh
    
    else:
        return stitch_mesh

# %%
# restitching functions
import trimesh
import numpy as np
from collections import Counter
import time
import math

#gets the projection of point p onto line a
def ClosestPointOnLine(a, b, p):
    ap = p-a
    ab = b-a
    #base_vector = ab
    result = np.dot(ap,ab)/np.dot(ab,ab) # * ab
    return result



#now have the mesh and the facet faces, can send to function
def stitch_mesh_piece_vp4(new_mesh,facet_1,facet_2,
                          delete_facets=False,
                         return_added_mesh = False,
                         fix_normals = False):

    """
    Changed since last version: 
    1) parameter for deleting facets at end or not
    2) parameter for returning added mesh or not 
    3) Changed normals check to print statement and not exception


    """
    #how to find the normals of facet groups:
    facet_group_1_normal = new_mesh.face_normals[facet_1[0]] #main_mesh_normals
    facet_group_2_normal = new_mesh.face_normals[facet_2[0]] #child_mesh_normals


    #get the correct version of the normals: (might need to flip them if going in opposite direction)
    if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
        raise Exception("same direction normals")
    elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
        print("opposite direction normals")
    else:
        print("Not correct normals")
        #raise Exception("Not correct normals")

    # make each row correspond to a single face 
    edges = new_mesh.edges_sorted.reshape((-1, 6))
    # get the edges for each facet
    edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
    edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                               for i in edges_facet])

    #the list of boundary edges and unique points in the boundary edges
    edge_0 = edges_boundary[0]
    edge_1 = edges_boundary[1]

    #gets the unique number of points
    edge_0_points = np.unique(np.hstack(edge_0))
    edge_1_points = np.unique(np.hstack(edge_1))
    print("Found boundary edges")
    """
    get the dot product of all the points
    """

    #get any 2 points on the triangle and make that the reference edge
    edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

    #gets the starting index for the 1st facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_0_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_0_starting_point = edge_0_points[max_index]

    #gets the starting index for the 2nd facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_1_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_1_starting_point = edge_1_points[max_index]

    print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
    #print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

    """
    Need to order the points for restitching

    Pseudocode: 
    1) Get starting piont
    2) Find the two edges corresponding to that point
    3) Need to decide which direction to start....
    - go in direction that make the cross of the (1st and last) point in the same direction of the 
    normal of the first facet
    4) loop through and record the orders of the vertices as you traverse along the edges 
    until you arrive back at the start
    5) Error if:
        a. You arrive back at the start and haven't processed all the edges
        b. Processsed all the edges but haven't arrived back at start

    6) Repeat steps 1 through 5 for 2nd facet group
    """
    start_point_list = [edge_0_starting_point,edge_1_starting_point]
    edge_list = [edge_0,edge_1]
    edge_order_list = []



    #loop that organizes the unique boundary points into the correct order
    for i,start_point in enumerate(start_point_list):
        print(f"Starting Organizing vertices for side {i}")
        #print(f"start_point = {start_point}")
        edge_order = [start_point]
        processed_edges = []

        #find the matching edges to the starting point
        starting_edges_indices = np.where(np.logical_or(edge_list[i][:,0] == start_point,edge_list[i][:,1] == start_point) == True)[0]

        starting_edges = edge_list[i][starting_edges_indices]
        #print(f"starting edges = {starting_edges}") #the list of the two possible edges

        if starting_edges.size < 4:
            raise Exception("Not enough edges for 1st facet start point")

        if starting_edges.size > 4:
            raise Exception("Too many edges for 1st facet start point") 

        #np.where(starting_edges[1,:] != start_point)[0][0]
        #gets the vectors that will be used for the cross product
        #print("np.where(starting_edges[0,:] != start_point)[0][0] = " + str(np.where(starting_edges[0,:] != start_point)[0][0]))
        #print("np.where(starting_edges[1,:] != start_point)[0][0] = " + str(np.where(starting_edges[1,:] != start_point)[0][0]))

        """*************** where pick the starting edge starts ************
        The way it works: 
        1) Gets the two possible starting edges
        2) Generates the vectors for the edges where origin is the starting point
        3) Gets the cross porduct of both vectors
        4) Chooses the cross product that is in the direction of the face normals

        Why that doesn't work:
        1) they are opposite normals


        """

        """
        Possible other solution:
        1) Get the starting points on the child edge
        2) Pick the first edge as the default edge

        """
        processed_edges.append(starting_edges_indices[0])
        current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]




    #         #gets the possible starting vectors from the two possible edges
    #         possible_starting_vector_1 = new_mesh.vertices[starting_edges[0,:][np.where(starting_edges[0,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
    #         #just start with a random edge
    #         possible_starting_vector_2 = new_mesh.vertices[starting_edges[1,:][np.where(starting_edges[1,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]


    #         #find the cross product of the starting vectors
    #         starting_edges_cross = np.cross(possible_starting_vector_1,possible_starting_vector_2)

    #         #make sure that the order of the vectors goes so that the cross product is in line with the starting normal
    #         #this ensures the the circular direction of the stitching will be the same
    #         if np.dot(starting_edges_cross,facet_group_1_normal) > 0:
    #             print("Edge 1 picked for direction")
    #             processed_edges.append(starting_edges_indices[0])
    #             current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]
    #         else:
    #             print("Edge 2 picked for direction")
    #             processed_edges.append(starting_edges_indices[1])
    #             #print("np.where(starting_edges[1,:] != start_point) = " + str(np.where(starting_edges[1,:] != start_point)))
    #             current_vertex = starting_edges[1][np.where(starting_edges[1,:] != start_point)[0][0]]

        #print(f"current_vertex = {current_vertex}" )
        #print("edge_list = " + str(edge_list))



        """*************** where pick the starting edge ends ************"""
        #now iterate through number of 
        for z in range(1,edge_list[i][:,0].size):
            #print("edge_order_temp = " + str(edge_order))
            if current_vertex == start_point:
                print("Start vertex reached before processed all of edges")

                """

                These should be ok because the extra loops are created from holes inside and this process should always get the outside loop


                """
                break

            #get the next edge
            counter = 0
            next_vertex = -1
            for j,edg in enumerate(edge_list[i]):
                #print("edg = " + str(edg))
                #print("processed_edges = " + str(processed_edges))
                if current_vertex in edg and j not in processed_edges:
                    current_edge_index = j
                    if edg[0] != current_vertex:
                        next_vertex = edg[0]
                    else:
                        next_vertex = edg[1]


                    counter += 1
                    if counter >= 2:
                        #raise Exception(f"More than 2 edges possibilities for {current_vertex}")
                        #Don't want to make it an exception anymore put just print out warning
                        print("More than 2 edges possibilities for {current_vertex}") # BAC change

            #make sure the next vertex was found
            if next_vertex <= -1:
                raise Exception(f"No next vertex was found for {current_vertex} ")

            #if found next vertex then add the old vertex and edge index
            #to the processed edges lists and the order of vertices
            processed_edges.append(current_edge_index)
            edge_order.append(current_vertex)

            current_vertex = next_vertex


        edge_order_list.append(edge_order)
        print(f"edge_{i}_order done, len = {len(edge_order)} ")#"= {edge_order}")

    #     #print the edge orders
    #     for e in edge_order_list:
    #         print(type(e))
    lengths_of_boundaries = [len(x) for x in edge_order_list]



    """ ************ PROCESS OF ORDERING THE EDGE PATHS SO THAT *********
    main mesh loop goes in counter clockwise in reference to the gap
    child goes clockwise in reference to gap




    """

    """
    1) Pick the starting point as your P point
    2) For each point in ordered list calculate point - P and store that vector
    3) Do the cross product of list[0:n-2] x list[1:n-1]
    4) Take the sum of these lists of cross products
    5) Do the dot product to compare the direction with the normal vector 
    Result: 
    - if positive --> conuter-clockwise according to normal
    - if negative --> clockwise according to normal

    """

    starter_point = np.array([0,0,0])

    #     list_of_points = [1,2,3,4,0]

    #     list_of_points = [list_of_points[len(list_of_points) - x -1] for x in range(0,len(list_of_points))]
    #     print(list_of_points)

    #print("facet_group_2_normal = " + str(facet_group_2_normal))

    for ed,e_loop in enumerate(edge_order_list):

        #get the vertices according to the points
        vertices_list = new_mesh.vertices[e_loop]

        #get the cross product of the offsetted list
        #vertices_list[0:len(vertices_list)-1,:]
        """ Wrong earlier previous way

        cross_products = np.cross(vertices_list[0:len(vertices_list)-1,:],vertices_list[1:len(vertices_list)])
        """

        cross_products = np.cross(vertices_list[0:len(vertices_list),:],
                             np.vstack([vertices_list[1:len(vertices_list),:],vertices_list[0,:]]))

        sum_cross_products = np.sum(cross_products,axis=0)

        #print("cross_products = " + str(cross_products))
        #print("sum_cross_products = " + str(sum_cross_products))

        #print("Before edge list = " + str(edge_order_list[ed]))
        if ed == 0:
            #get the dot product
            normals_dot = np.dot(sum_cross_products,facet_group_1_normal)
            #print(' normals_dot = ' + str(normals_dot))
            if normals_dot > 0:
                print("Main originally was counter-clockwise --> keeping")


            else:
                print("Main originally was clockwise --> flipping")
                edge_order_list[ed] = [e_loop[len(e_loop) - x -1] for x in range(0,len(e_loop))]


        else: 
            # for the children want the cross product to be counter clockwise
            normals_dot = np.dot(sum_cross_products,facet_group_2_normal)
            #print(' normals_dot = ' + str(normals_dot))
            if normals_dot > 0:
                print("Child originally was counter-clockwise --> flipping")
                edge_order_list[ed] = [e_loop[len(e_loop) - x -1] for x in range(0,len(e_loop))]
            else:
                print("Child originally was clockwise --> keeping")


        #print("After edge list = " + str(edge_order_list[ed]))
    """  SHOWS THAT DOING THE CROSS PRODUCT THAT WAY WORKS
    #do the cross products manually
    for jj in range(0,len(vertices_list)-1):
        print(np.cross(vertices_list[jj],vertices_list[jj+1]))

    """




    #getting which one is the bigger one
    bigger = lengths_of_boundaries.index(max(lengths_of_boundaries))
    smaller = 1-bigger

    if bigger == 0:
        starter_face = "child" #if the bigger one was the main, then child is the smaller one you start from
    else:
        starter_face = "main" #if the bigger one was the child, then main is the smaller one you start from


    print("smaller_face = " + str(starter_face))    

    """ The rules that have to be following in order for normals to be correctly aligned
    1) if the smaller is the child (will be traveling in clockwise direction
    --> need to stitch points as:
    Regular: other_2, other_1,current_point
    Neighbor: current,other_1,current-1


    1) if the smaller is the main mesh (
    --> need to stitch points as:
    Regular: current_point,other_1,other_2
    Neighbor: current,current-1,other
    """


    #print(f"index of bigger facets = {bigger}\nindex of smaller facets = {smaller}",)

    #calculates the number of vertices will be stitched to each vertices on smaller side
    dividend = int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])
    remainder = lengths_of_boundaries[bigger] - int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])*lengths_of_boundaries[smaller]

    print(f"dividend = {dividend}, remainder = {remainder}")

    #loop that adds the new faces
    print("About to add faces")
    start_time = time.time()
    new_faces = []
    current_bigger = 0
    total_counter= 0
    end_number = 1000
    for i,current_smaller in enumerate(edge_order_list[smaller]):
        #print("current_smaller =" + str(current_smaller))
        #print("current_bigger=" + str(edge_order_list[bigger][current_bigger]))

        #connecting to the neighbor on the shorter side
        """
        if i == 0:

            new_faces.append([current_smaller,edge_order_list[smaller][-1],edge_order_list[bigger][current_bigger]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])
        """


        if starter_face == "main":
            new_faces.append([current_smaller,edge_order_list[bigger][current_bigger],edge_order_list[smaller][i-1]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])

        total_counter += 1
        if total_counter > end_number:
            break
        for j in range(0,dividend + int(i<remainder)):
            if current_bigger > len(edge_order_list[bigger]):
                raise Exception("Somehow rapped around too much")

            if current_bigger >= len(edge_order_list[bigger])-1:
                next_bigger = 0
            else:
                next_bigger = current_bigger+1

            if starter_face == "main":
                new_faces.append([edge_order_list[bigger][next_bigger],
                                  edge_order_list[bigger][current_bigger],
                                  current_smaller,
                                ])
            else:
                new_faces.append([
                                current_smaller,
                                  edge_order_list[bigger][current_bigger],
                                  edge_order_list[bigger][next_bigger],

                                ])

            current_bigger += 1

            total_counter += 1
            if total_counter > end_number:
                break
        if total_counter > end_number:
                break


    #print("new_faces = " + str(new_faces))
    print(f"Finished adding faces: {time.time() - start_time}")


    print("Starting creating stitch mesh")
    start_time = time.time()
    stitch_mesh = trimesh.Trimesh()

    stitch_mesh.vertices = new_mesh.vertices
    stitch_mesh.faces = np.vstack([new_mesh.faces, new_faces])
    print(f"Finished creating stitch mesh: {time.time() - start_time}")




    if delete_facets == True:
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(stitch_mesh.faces)-1,len(stitch_mesh.faces)).astype("int")
        facet_faces = np.hstack([facet_1 ,facet_2])
        faces_to_keep = set(total_faces).difference(set(facet_faces))
        faces_to_keep

        stitch_mesh = stitch_mesh.submesh([list(faces_to_keep)])[0]

    if fix_normals == True:
        trimesh.repair.fix_inversion(stitch_mesh)
        trimesh.repair.fix_winding(stitch_mesh)
        trimesh.repair.fix_normals(stitch_mesh)

    #print("Finished stitching")

    if return_added_mesh == True:
        added_mesh = trimesh.Trimesh()
        added_mesh.vertices = new_mesh.vertices
        added_mesh.faces = new_faces
        trimesh.repair.fix_inversion(added_mesh)
        trimesh.repair.fix_winding(added_mesh)
        trimesh.repair.fix_normals(added_mesh)

        return stitch_mesh,added_mesh

    else:
        return stitch_mesh

# %%
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh_saved = main_mesh.copy()
main_mesh_facets_centers_saved = main_mesh_facets_centers.copy()
main_mesh_facets_saved = main_mesh_facets.copy()

#save off the child information as well
from copy import deepcopy

child_meshes_saved = deepcopy(child_meshes)
child_meshes_facets_saved = deepcopy(child_meshes_facets) #has both the centers and the facet lists

# %%
restitch_time = time.time()

# %%
"""

Pseudocode for loop at the end that will keep everything going:
1) When process a child, will add that index to a list
2) Have no_new_children_processed counter set at end of loop 
    if no children were added to main mesh
    --> this will prompt the expansion of the initial parameters
3) If this gets too high



Things that still need to add:
1) Better way of making sure that the normals are good
- Can sample one of the neighboring points and flip normals if the dot product is negative


Change list: 
1) Reduced the stitch distance
2) Added the copy features that allows this cell to be rerun without rerunning whole notebook
3) added the new tie_breaker for childs that want to connect to same parent is just the one with closest facet
    Uses the added feature of child_meshes_stitch_distances that is saved along the way
4) Iterates through the repeated faces instead of just doing so once which was incorrect before
5) Fixed bug that was adding to current_main_mesh but then was using main mesh also in the loop
6) Made changes to the stitching mechanism that not error if find a vertices with more than 2 edges
--> because did observe some facets with cut out faces along the boundary
7) Changed the consider_same_direction normal as False 
8) Changed the max index error that was used for finding the starting point in stitch meshes

"""
total_stitch_processing_time = time.time()
#load our main mesh stuff from the copies
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh = main_mesh_saved.copy()
main_mesh_facets_centers = main_mesh_facets_centers_saved.copy()
main_mesh_facets = main_mesh_facets_saved.copy()

#load the child info from the saved copies
child_meshes_facets_saved = deepcopy(child_meshes_facets_saved)
child_meshes  = deepcopy(child_meshes_saved)


#sets 
initial_parameters = dict(bounding_box_threshold=4000,
                         stitch_distance_threshold=1200,
                         size_ratio_threshold=0.15,
                         normal_closeness= 0.95)

bounding_box_threshold = initial_parameters["bounding_box_threshold"]
stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]
size_ratio_threshold = initial_parameters["size_ratio_threshold"]
normal_closeness=initial_parameters["normal_closeness"]

no_new_children_multiplier = 0
bbox_expansion_percentage = 0.10
stitch_expansion_percentage = 0.20
size_ratio_expansion_percentage = 0.10

no_new_children_limit = 4

consider_same_direction_normals = False
children_processed = []

#lists to store the faces that need to be removed later from main mesh
child_faces_to_remove = []
main_faces_to_remove = []

while len(children_processed) < len(child_meshes):
    stitch_loop_time = time.time()
    if no_new_children_multiplier >= no_new_children_limit:
        print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
        print(f"total_stitch_processing_time = {time.time() - total_stitch_processing_time}")
        raise Exception("Finished the mesh stitiching")
    
    #update the thresholds
    bounding_box_threshold = initial_parameters["bounding_box_threshold"]*(1 + bbox_expansion_percentage*no_new_children_multiplier)
    stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]*(1 + stitch_expansion_percentage*no_new_children_multiplier)
    #reduces the 
    size_ratio_threshold = initial_parameters["size_ratio_threshold"]*(1 - size_ratio_expansion_percentage*no_new_children_multiplier)
    
    #print thresholds
#     print(f"bounding_box_threshold = {bounding_box_threshold}")
#     print(f"stitch_distance_threshold = {stitch_distance_threshold}" )
#     print(f"size_ratio_threshold = {size_ratio_threshold}")

    #get the main mesh facets normals
    main_mesh_normals = [main_mesh.face_normals[fac[0]] for fac in main_mesh_facets]
    hit_indexes_list= []
    
    
    #dictionary to save the stitch points
    child_meshes_stitch_facets = dict()
    child_meshes_stitch_face_ratios = dict()
    child_meshes_stitch_distances = dict()
    for i,child in enumerate(child_meshes):
        
        if i in children_processed:
            #print(f"Child {i} already processed")
            continue
        
        print(f"Starting Child {i}")

        #initialize the stitch index
        #child_meshes_stitch_facets[i] = [-1,-1]

        #two highest points for the bounding box
        min_bb = np.array(main_mesh.bounding_box.vertices).min(0)
        max_bb = np.array(main_mesh.bounding_box.vertices).max(0)

        min_bb_zone = min_bb - bounding_box_threshold
        max_bb_zone = max_bb + bounding_box_threshold



        #then send mesh to function that decides if with
        pass_bbox_filter = apply_bbox_filter(child,min_bb_zone,max_bb_zone)

        if not pass_bbox_filter:
            print("skipped by bounding box filter")
            continue

        #### used for validation to make sure that bounding box was correctly filtering
    #     #add the following to main mesh just to visualize
    #     final_mesh = final_mesh + child
    #     print("just added")

        #
        """

        Do pairwise calculation of distances between centers of facets on child piece and main piece
            Filter the pairs for stitch distance threshold
            Filter the pairs for matching or opposite normals
            Filter for those that are reasonable in size matching (within 50% of each other)

        If there are still ties after this point then pitch the best matching size

        If None remaining then keep going (might loosen up the parameters later), BUT WITH GLOBAL CHECK SO DOESN’T KEEP ITERATING


        """
 
        """ OLD WAY OF COMPUTING PAIRWISE ***************************************************************
        
        child_facets,child_facets_centers = child_meshes_facets[i]

        facet_distances = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))
        facet_normals = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))

        start_time = time.time()
        #do the pairwise comparison
        for cc,child_center in enumerate(child_facets_centers):

            #get the normal of the child
            child_normal = child.face_normals[child_facets[cc][0]]
            for mm, main_center in enumerate(main_mesh_facets_centers):
                #get the euclidean distance
    #             facet_distances[cc,mm] = math.sqrt((child_center[0] - main_center[0])**2 + 
    #                                                  (child_center[1] - main_center[1])**2 + 
    #                                                  (child_center[2] - main_center[2])**2 )



                facet_distances[cc,mm] = np.linalg.norm(np.array(child_center) - np.array(main_center))

                main_normal = main_mesh_normals[mm]
    #             print("main_normal = " + str(main_normal))
    #             print("child_normal = " + str(child_normal))
                #get whether the normals are line up (or possibly opposite)
                normals_dot = np.dot(child_normal,main_normal)
                #print(normals_dot)
                if consider_same_direction_normals == True:
                    facet_normals[cc,mm] =  normals_dot < -0.95  or normals_dot > 0.95
                else:
                    facet_normals[cc,mm] =  normals_dot < -0.95 # or normals_dot > 0.95


        
        print(f"Total pairwise : {time.time() - start_time}")

    #     if i == 1:
    #         4,12
    #         print("4,12 facet distance = " + str(facet_distances[4,12]))

        #apply the filters
        #stitch_distance_booleans = facet_distances < stitch_distance_threshold

        
        #how to debug certain faces that have been filtered
#         main_facet_bebug = 124
#         piece_facet_debug = 11
        
#         if i == 2 and (0 in children_processed):
#             print("**********" + str(facet_normals[piece_facet_debug,main_facet_bebug]) + "**********")
#             print("**********" + str((facet_distances < stitch_distance_threshold)[piece_facet_debug,main_facet_bebug]) + "**********")
        
        
        #get the indexes that make it through the first two filters
        hit_indexes = np.where(np.logical_and(facet_distances < stitch_distance_threshold,facet_normals)== True) 

        possible_stitch_pairs = np.vstack(hit_indexes).T
        
        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        
        face_0_unique_facets = np.unique(hit_indexes[0])
        face_1_unique_facets = np.unique(hit_indexes[1])
        
        if len(hit_indexes[0]) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(hit_indexes[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

            

         *************************************************************** """
        
        """  NEW WAY OF COMPUTING THE PAIRWISE CALCULATIONS  *************************************************************** """
        
        child_facets,child_facets_centers = child_meshes_facets[i]
        pairs_start_time = time.time()

        
        if len(child_facets_centers) == 0:
            print("child_facets_centers for child {i} was 0, so skipping")
            continue
        
        start_time = time.time()
        a_New = np.array(child_facets_centers).astype("float")
        b_New = np.array(main_mesh_facets_centers).astype("float")

        print(len(a_New),len(b_New))
#         print("starting distance matrix")
        start_time = time.time()
        from scipy.spatial import distance_matrix
        a_b_distance = distance_matrix(a_New, b_New)
        
        #print(f"Time = {time.time() - start_time}")

        #now get the indexes that are within stitch distance

#         print("min(a_b_distance) = " + str(np.amin(a_b_distance.shape)))
        indexes_not = np.where(a_b_distance < stitch_distance_threshold)
        print(f"Done distance matrix: {time.time() - start_time}")
        
        
#         print("(indexes_not) = " + str((indexes_not)))
#         print("starting normals")
        start_time = time.time()

#         #old way to do it
#         child_normals = child.face_normals[indexes_not[0]]
#         main_normals = main_mesh.face_normals[indexes_not[1]]

        if not indexes_not[0].any():
            print(f"Child {i} There were no points close enough")
            continue

        #old way to do it
#         print(indexes_not[0])
#         print(child_facets[indexes_not[0]])
 
        
        child_normals = child.face_normals[[p[0] for p in child_facets[indexes_not[0]]]]
        main_normals = main_mesh.face_normals[[p[0] for p in main_mesh_facets[indexes_not[1]]]]
                                           
                                           
                                           
#         print(child_facets[indexes_not[0]][0])
#         print('child_normals = ' + str(child_normals))
#         print(main_mesh_facets[indexes_not[1]][0])
#         print('main_normals = ' + str(main_normals))
        #start_time = time.time()
        #dot_products = np.dot(child_normals,main_normals.T)
        
        total_normal_dots = np.sum(child_normals*main_normals,axis=1)
#         print("total_normal_dots = " + str(total_normal_dots))
        total_normal_dots_facet_mask = total_normal_dots < -normal_closeness
        
#         print(f"Done Normals generation: {time.time() - start_time}")
#         print("starting pair generation")
        
        
        start_time = time.time()
        final_pairs = (np.array(indexes_not).T)[total_normal_dots_facet_mask]
        #print(final_pairs)
        
        
        #get the sizes of all the unique ones
        face_0_unique_facets = np.unique(final_pairs[:,0])
        face_1_unique_facets = np.unique(final_pairs[:,1])
        #print("final_pairs = " + str(final_pairs))
#         print("face_0_unique_facets = " + str(face_0_unique_facets))
#         print("face_1_unique_facets = " + str(face_1_unique_facets))
        
        
        if len(final_pairs) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(final_pairs[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

        
        possible_stitch_pairs = final_pairs
        print(f"Done Generating final pairs: {time.time() - pairs_start_time}")
        
        
        """  NEW WAY OF COMPUTING THE PAIRWISE  *************************************************************** """
        




    #     print("possible_stitch_pairs = " + str(possible_stitch_pairs))
    #     print("len(hit_indexes) = " + str(len(hit_indexes)))
    #     print("hit_indexes[0].any() = " + str(hit_indexes[0].any()))
    #     print("hit_indexes = " + str(hit_indexes))
    #     print("hit_indexes[0] = " + str(hit_indexes[0]))
    #     print("len(hit_indexes[0]) = " + str(len(hit_indexes[0])))

        #find the sizes of all of them
        face_pair_sizes = np.zeros(len(possible_stitch_pairs[:,0]))
        face_size_ratios = np.zeros(len(possible_stitch_pairs[:,0]))

        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        for numba,pair in enumerate(possible_stitch_pairs):
            #print("pair = " + str(pair))
            sizes = [face_0_facet_sizes[pair[0]],face_1_facet_sizes[pair[1]]]
            min_area = min(sizes)
            max_area = max(sizes)

            ratio = min_area/max_area

            #print(f"ratio = {ratio}")
            #print(f"Total size  = {min_area + max_area}")
            if ratio >= size_ratio_threshold:
                face_pair_sizes[numba] = min_area + max_area
                face_size_ratios[numba] = ratio
            
                #print(f"face_pair_sizes[numba] = {face_pair_sizes[numba]}, face_size_ratios[numba] = {face_size_ratios[numba]}")


        #check that made it past stitch ratio threshold

        #best possible stitch pair is just the maximum sized matching ones
        best_index = np.where(face_pair_sizes == max(face_pair_sizes))
        best_stitch_pair = possible_stitch_pairs[best_index][0]
        best_stitch_pair_size = face_pair_sizes[best_index][0]
        best_stitch_pair_size_ratio = face_size_ratios[best_index][0]
        
        #get the distance of the best_stitch_pair
        best_stitch_pair_distance = a_b_distance[possible_stitch_pairs[best_index][0][0],
                                                   possible_stitch_pairs[best_index][0][1]]
        
        print("best_stitch_pair = " + str(best_stitch_pair))
        print("best_stitch_pair_size = " + str(best_stitch_pair_size))
        print("best_stitch_pair_distance = " + str(best_stitch_pair_distance))
        print("best_stitch_pair_size_ratio = " + str(best_stitch_pair_size_ratio))

        child_meshes_stitch_facets[i] = [best_stitch_pair[0],best_stitch_pair[1]]
        child_meshes_stitch_face_ratios[i] = best_stitch_pair_size_ratio
        child_meshes_stitch_distances[i] = best_stitch_pair_distance
        
#         if i == 1:
#             print("Just processed piece 1")
#             raise Exception("stoping")

    
#     if 1 in child_meshes_stitch_facets.keys():
#         print("Just processed piece 1")
#         raise Exception("stoping")
    
    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
        
    # makes sure that no two child branches try to connect to the same main branch
    from collections import Counter
    mesh_stitch_counter = Counter(np.array([val for val in child_meshes_stitch_facets.values()])[:,1])

    repeat_main_facets = [key for key,val in mesh_stitch_counter.items() if (key != -1 and val > 1)] #gets the main mesh facet with multiples
    print("repeat_main_facets = " + str(repeat_main_facets))


    #how to fix that some faces are trying to branch to same main facet
    #make it iterate through all of the repeats
    if len(repeat_main_facets)>0:
        for repeat_main in repeat_main_facets:
            child_mesh_double_indexes = [key for key,val in child_meshes_stitch_facets.items() if val[1] == repeat_main]
            print("child_mesh_double_indexes = " + str(child_mesh_double_indexes))


            #decide which one to keep and then ditch all the rest --> pick the CLOSEST ONE, and not the best matching area:

            ###### picks the closest area
            min_distance = 10000000000
            min_child = -1


            for child_index in child_mesh_double_indexes:
                current_distance = child_meshes_stitch_distances[child_index]

                if current_distance < min_distance:
                    min_child = child_index
                    min_distance = current_distance

            print(f"min_child = {min_child}, max_ratio = {min_distance}")

    #         ###### picks the maximum area
    #         max_ratio = -1
    #         max_child = -1


    #         for child_index in child_mesh_double_indexes:
    #             current_ratio = child_meshes_stitch_face_ratios[child_index]

    #             if current_ratio > max_ratio:
    #                 max_child = child_index
    #                 max_ratio = current_ratio

    #         print(f"max_child = {max_child}, max_ratio = {max_ratio}")



            #remove the others from the stitch facets
            for double_index in child_mesh_double_indexes:
                if double_index != min_child:
                    del child_meshes_stitch_facets[double_index]
    
    """
    Pseudocode for stitching:
    1) For each pair in the child_meshes_stitch_facets:
    a. Get the child mesh for that pair
    b. Get the list of faces for the child facet (from the facet number)
    c. Get the list of faces for the main facet (from the main number)

    d. Get the original number of faces and vertices in the main mesh
    d2. Use the orignal number of faces and add to list of faces for child facet to offset them correctly
        - Save this number list in a dictionary (to use for later and creating the submesh)
    e. Add the two meshes together to get big mesh
    f. Send the two meshes and the two facet lists to the restitching function to get a main mesh that is stitched up
     - but send it to function that doesnt delete the original facet faces 
         (because this would remove meshes from original and screw up facet number)
    g. reassign the main_mesh to this newly stitched up mesh
    h. recompute the facets for the main mesh



    """
    

    current_main_mesh = main_mesh.copy()
    
    main_mesh_facet_index_to_delete = []

    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
    else: #if there were stitch points found
        print("child_meshes_stitch_facets = " + str(child_meshes_stitch_facets))
        for child_key,pair in child_meshes_stitch_facets.items():
            """
            child_key has the child that is currently being processed
            
            pair has the facet ids that are to be stitched together
            
            """
            
            child_used_facet_index = pair[0]
            main_used_faceet_index = pair[1]
            
            stitch_time = time.time()
            print(f"---Stitching child {child_key} with pair: {pair}---")
            current_child_mesh = child_meshes[child_key]
            current_child_facet_faces = child_meshes_facets[child_key][0][pair[0]]


            current_main_mesh_facet_faces = main_mesh_facets[pair[1]]

            #Get the original number of faces and vertices in the main mesh
            original_mesh_faces_len = len(current_main_mesh.faces)
            current_child_facet_faces_adjusted = current_child_facet_faces + original_mesh_faces_len

            #Save the faces number for deletion later
            child_faces_to_remove += current_child_facet_faces_adjusted.tolist()
            main_faces_to_remove += current_main_mesh_facet_faces.tolist()

            combined_mesh = current_main_mesh + current_child_mesh

            #how to stitch up the mesh
            start_time = time.time()
            current_main_mesh = stitch_mesh_piece_vp4(new_mesh=combined_mesh,
                                                           facet_1=current_main_mesh_facet_faces,
                                                           facet_2=current_child_facet_faces_adjusted,
                                                          delete_facets=False,
                                                          return_added_mesh=False,
                                                           fix_normals = False)
            
            print(f"returned from stitch mesh: {time.time() - start_time}")
            
            
            #Don't need to do any deletion now 
            
            #add the child to processed child
            children_processed.append(child_key)
            print(f"Finished stitching child {child_key} : {time.time() - stitch_time}")
            
            """
            Add all of the child facets that weren't the ones used to the main mesh facets (with adjusted facet numbers)
            """
            original_mesh_faces_len #the original number of faces in the main mesh (including all those stitched before)
            
            #remove certian rows from array of the child facets and cetners
            current_child_facet_faces_with_deletion = np.delete(child_meshes_facets[child_key][0],(child_used_facet_index),axis=0)
            current_child_facet_centers_with_deletion = np.delete(child_meshes_facets[child_key][1],(child_used_facet_index),axis=0)

            #have to adjust the faces of the child_facets list to account for the faces off set
            current_child_facet_faces_with_deletion = current_child_facet_faces_with_deletion + original_mesh_faces_len

            #append this list to the main mesh list
            main_mesh_facets = np.concatenate([main_mesh_facets,current_child_facet_faces_with_deletion])
            main_mesh_facets_centers = np.concatenate([main_mesh_facets_centers,current_child_facet_centers_with_deletion])

            #save off the facets to delete for the main mesh at the end of the loop
            main_mesh_facet_index_to_delete.append(pair[1])
            



        #reset the no_new_children_multiplier because there were successful stitching
        no_new_children_multiplier = 0
        """recompute the main mesh facets  ###Not going to recompute anymore
        #main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
        
        Now we just remove the main mesh facets that are used and reassign
        """
        main_mesh = current_main_mesh
    
    
        #at the end of the big loop have to delete the facets used from main mesh
        #remove certian rows from array
        main_mesh_facets = np.delete(main_mesh_facets,(main_mesh_facet_index_to_delete),axis=0)
        main_mesh_facets_centers = np.delete(main_mesh_facets_centers,(main_mesh_facet_index_to_delete),axis=0)

        
        print(f"***************Finished big stitching iteration: {time.time() - stitch_loop_time}***************")
        
#         if 0 in children_processed and 1 in children_processed:
#             print("Exiting before does piece 2")
#             break

        if len(np.unique(children_processed)) == len(child_meshes):
            print("All children have been processed")
            break
# Out:
# Starting Child 0
# 699 11118
# Done distance matrix: 0.22433257102966309
# Child 0 There were no points close enough
# Starting Child 1
# 644 11118
# Done distance matrix: 0.22945070266723633
# Done Generating final pairs: 0.23956942558288574
# best_stitch_pair = [ 297 2053]
# best_stitch_pair_size = 126407.37080777145
# best_stitch_pair_distance = 322.83217480906654
# best_stitch_pair_size_ratio = 0.4329072487180667
# Starting Child 2
# 485 11118
# Done distance matrix: 0.17730927467346191
# Done Generating final pairs: 0.25577569007873535
# best_stitch_pair = [  11 7052]
# best_stitch_pair_size = 3722036.954014628
# best_stitch_pair_distance = 134.73286075380463
# best_stitch_pair_size_ratio = 0.936193249947911
# Starting Child 3
# 887 11118
# Done distance matrix: 0.28705525398254395
# Child 3 There were no points close enough
# Starting Child 4
# 521 11118
# Done distance matrix: 0.16857337951660156
# Child 4 There were no points close enough
# Starting Child 5
# 203 11118
# Done distance matrix: 0.06521773338317871
# Child 5 There were no points close enough
# Starting Child 6
# 567 11118
# Done distance matrix: 0.17950773239135742
# Child 6 There were no points close enough
# Starting Child 7
# 212 11118
# Done distance matrix: 0.06766271591186523
# Child 7 There were no points close enough
# Starting Child 8
# 170 11118
# Done distance matrix: 0.05384087562561035
# Child 8 There were no points close enough
# Starting Child 9
# 460 11118
# Done distance matrix: 0.15612411499023438
# Done Generating final pairs: 0.16452741622924805
# best_stitch_pair = [   44 10708]
# best_stitch_pair_size = 72414.98861585
# best_stitch_pair_distance = 1186.273607894109
# best_stitch_pair_size_ratio = 0.24388270030076303
# Starting Child 10
# 130 11118
# Done distance matrix: 0.04050779342651367
# Child 10 There were no points close enough
# Starting Child 11
# 290 11118
# Done distance matrix: 0.09152007102966309
# Child 11 There were no points close enough
# Starting Child 12
# 191 11118
# Done distance matrix: 0.06781005859375
# Child 12 There were no points close enough
# Starting Child 13
# 185 11118
# Done distance matrix: 0.06571412086486816
# Child 13 There were no points close enough
# Starting Child 14
# 187 11118
# Done distance matrix: 0.061260223388671875
# Child 14 There were no points close enough
# Starting Child 15
# 470 11118
# Done distance matrix: 0.15593481063842773
# Child 15 There were no points close enough
# Starting Child 16
# 261 11118
# Done distance matrix: 0.08457112312316895
# Child 16 There were no points close enough
# Starting Child 17
# 10 11118
# Done distance matrix: 0.0037660598754882812
# Child 17 There were no points close enough
# Starting Child 18
# 16 11118
# Done distance matrix: 0.005753040313720703
# Child 18 There were no points close enough
# Starting Child 19
# 4 11118
# Done distance matrix: 0.0014410018920898438
# Child 19 There were no points close enough
# Starting Child 20
# 16 11118
# Done distance matrix: 0.0054171085357666016
# Done Generating final pairs: 0.011080026626586914
# best_stitch_pair = [  4 779]
# best_stitch_pair_size = 50211.06086490778
# best_stitch_pair_distance = 948.9592577469143
# best_stitch_pair_size_ratio = 0.5692394550069745
# Starting Child 21
# 14 11118
# Done distance matrix: 0.005157470703125
# Child 21 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 11118
# Done distance matrix: 0.02118992805480957
# Child 23 There were no points close enough
# Starting Child 24
# 8 11118
# Done distance matrix: 0.0028781890869140625
# Done Generating final pairs: 0.008200407028198242
# best_stitch_pair = [   2 8006]
# best_stitch_pair_size = 75520.57459223573
# best_stitch_pair_distance = 170.50810536391745
# best_stitch_pair_size_ratio = 0.47765958862343944
# Starting Child 25
# 56 11118
# Done distance matrix: 0.018882036209106445
# Child 25 There were no points close enough
# Starting Child 26
# 5 11118
# Done distance matrix: 0.0020856857299804688
# Child 26 There were no points close enough
# Starting Child 27
# 3 11118
# Done distance matrix: 0.0010423660278320312
# Child 27 There were no points close enough
# Starting Child 28
# 124 11118
# Done distance matrix: 0.04095125198364258
# Child 28 There were no points close enough
# Starting Child 29
# 184 11118
# Done distance matrix: 0.06055474281311035
# Done Generating final pairs: 0.06586122512817383
# best_stitch_pair = [ 122 2269]
# best_stitch_pair_size = 44775.11831009884
# best_stitch_pair_distance = 446.8338762966404
# best_stitch_pair_size_ratio = 0.36436845554798764
# Starting Child 30
# 34 11118
# Done distance matrix: 0.011460304260253906
# Child 30 There were no points close enough
# Starting Child 31
# 53 11118
# Done distance matrix: 0.017338275909423828
# Child 31 There were no points close enough
# Starting Child 32
# 27 11118
# Done distance matrix: 0.009721755981445312
# Done Generating final pairs: 0.016144990921020508
# best_stitch_pair = [  2 662]
# best_stitch_pair_size = 676419.9238749678
# best_stitch_pair_distance = 200.96274019074056
# best_stitch_pair_size_ratio = 0.45746294362954565
# Starting Child 33
# 28 11118
# Done distance matrix: 0.009841442108154297
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# 63 11118
# Done distance matrix: 0.019442319869995117
# Child 34 There were no points close enough
# Starting Child 35
# 18 11118
# Done distance matrix: 0.00600123405456543
# Child 35 There were no points close enough
# Starting Child 36
# 5 11118
# Done distance matrix: 0.0017709732055664062
# Child 36 There were no points close enough
# Starting Child 37
# 37 11118
# Done distance matrix: 0.011357307434082031
# Child 37 There were no points close enough
# Starting Child 38
# 10 11118
# Done distance matrix: 0.003294706344604492
# Child 38 There were no points close enough
# Starting Child 39
# 17 11118
# Done distance matrix: 0.005493879318237305
# Child 39 There were no points close enough
# Starting Child 40
# 4 11118
# Done distance matrix: 0.0014371871948242188
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 11118
# Done distance matrix: 0.0020999908447265625
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 11118
# Done distance matrix: 0.002267122268676758
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [297, 2053], 2: [11, 7052], 9: [44, 10708], 20: [4, 779], 24: [2, 8006], 29: [122, 2269], 32: [2, 662]}
# ---Stitching child 1 with pair: [297, 2053]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 82661, starting edge 2nd facet= 928098,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004809856414794922
# returned from stitch mesh: 0.6619381904602051
# Finished stitching child 1 : 0.7457995414733887
# ---Stitching child 2 with pair: [11, 7052]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 28330, starting edge 2nd facet= 935417,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 48
# Starting Organizing vertices for side 1
# edge_1_order done, len = 42
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 7.200241088867188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0049440860748291016
# returned from stitch mesh: 0.7491424083709717
# Finished stitching child 2 : 0.8546891212463379
# ---Stitching child 9 with pair: [44, 10708]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 756198, starting edge 2nd facet= 957662,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.3589859008789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02648019790649414
# returned from stitch mesh: 0.8341681957244873
# Finished stitching child 9 : 0.9751625061035156
# ---Stitching child 20 with pair: [4, 779]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 74451, starting edge 2nd facet= 960232,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028423309326171875
# returned from stitch mesh: 0.8976998329162598
# Finished stitching child 20 : 1.0440573692321777
# ---Stitching child 24 with pair: [2, 8006]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 837126, starting edge 2nd facet= 960413,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02818584442138672
# returned from stitch mesh: 0.8963906764984131
# Finished stitching child 24 : 1.0459518432617188
# ---Stitching child 29 with pair: [122, 2269]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 421339, starting edge 2nd facet= 961841,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026519060134887695
# returned from stitch mesh: 0.871319055557251
# Finished stitching child 29 : 1.0209922790527344
# ---Stitching child 32 with pair: [2, 662]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 94575, starting edge 2nd facet= 963122,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 2.5272369384765625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026562213897705078
# returned from stitch mesh: 0.809687614440918
# Finished stitching child 32 : 0.9514148235321045
# ***************Finished big stitching iteration: 10.514962673187256***************
# Starting Child 0
# 699 12928
# Done distance matrix: 0.2766544818878174
# Done Generating final pairs: 0.3031344413757324
# best_stitch_pair = [  295 11776]
# best_stitch_pair_size = 2781600.2288127085
# best_stitch_pair_distance = 160.7360024620024
# best_stitch_pair_size_ratio = 0.5732400896866683
# Starting Child 3
# 887 12928
# Done distance matrix: 0.35794711112976074
# Child 3 There were no points close enough
# Starting Child 4
# 521 12928
# Done distance matrix: 0.20972275733947754
# Child 4 There were no points close enough
# Starting Child 5
# 203 12928
# Done distance matrix: 0.07607889175415039
# Done Generating final pairs: 0.07899188995361328
# best_stitch_pair = [  153 12714]
# best_stitch_pair_size = 59248.422708488375
# best_stitch_pair_distance = 692.5219206272919
# best_stitch_pair_size_ratio = 0.8272948027230579
# Starting Child 6
# 567 12928
# Done distance matrix: 0.22822356224060059
# Child 6 There were no points close enough
# Starting Child 7
# 212 12928
# Done distance matrix: 0.08200573921203613
# Child 7 There were no points close enough
# Starting Child 8
# 170 12928
# Done distance matrix: 0.06483221054077148
# Child 8 There were no points close enough
# Starting Child 10
# 130 12928
# Done distance matrix: 0.050657033920288086
# Child 10 There were no points close enough
# Starting Child 11
# 290 12928
# Done distance matrix: 0.11488890647888184
# Child 11 There were no points close enough
# Starting Child 12
# 191 12928
# Done distance matrix: 0.0705559253692627
# Child 12 There were no points close enough
# Starting Child 13
# 185 12928
# Done distance matrix: 0.07097339630126953
# Child 13 There were no points close enough
# Starting Child 14
# 187 12928
# Done distance matrix: 0.06893777847290039
# Done Generating final pairs: 0.09165763854980469
# best_stitch_pair = [   30 11881]
# best_stitch_pair_size = 2883036.8729235698
# best_stitch_pair_distance = 390.2646613688339
# best_stitch_pair_size_ratio = 0.756428523739565
# Starting Child 15
# 470 12928
# Done distance matrix: 0.18949484825134277
# Child 15 There were no points close enough
# Starting Child 16
# 261 12928
# Done distance matrix: 0.09925079345703125
# Child 16 There were no points close enough
# Starting Child 17
# 10 12928
# Done distance matrix: 0.004123687744140625
# Child 17 There were no points close enough
# Starting Child 18
# 16 12928
# Done distance matrix: 0.006833314895629883
# Child 18 There were no points close enough
# Starting Child 19
# 4 12928
# Done distance matrix: 0.0018646717071533203
# Child 19 There were no points close enough
# Starting Child 21
# 14 12928
# Done distance matrix: 0.005364656448364258
# Done Generating final pairs: 0.011324405670166016
# best_stitch_pair = [    5 11820]
# best_stitch_pair_size = 445825.1688913071
# best_stitch_pair_distance = 417.2369812716303
# best_stitch_pair_size_ratio = 0.7097850609379541
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 12928
# Done distance matrix: 0.0247347354888916
# Child 23 There were no points close enough
# Starting Child 25
# 56 12928
# Done distance matrix: 0.02167034149169922
# Child 25 There were no points close enough
# Starting Child 26
# 5 12928
# Done distance matrix: 0.002376079559326172
# Child 26 There were no points close enough
# Starting Child 27
# 3 12928
# Done distance matrix: 0.0014281272888183594
# Child 27 There were no points close enough
# Starting Child 28
# 124 12928
# Done distance matrix: 0.046186208724975586
# Child 28 There were no points close enough
# Starting Child 30
# 34 12928
# Done distance matrix: 0.013143777847290039
# Child 30 There were no points close enough
# Starting Child 31
# 53 12928
# Done distance matrix: 0.020069599151611328
# Child 31 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 33
# 28 12928
# Done distance matrix: 0.010738849639892578
# Done Generating final pairs: 0.016725540161132812
# best_stitch_pair = [    0 12902]
# best_stitch_pair_size = 883352.4059815214
# best_stitch_pair_distance = 646.9399508826754
# best_stitch_pair_size_ratio = 0.6418572978661629
# Starting Child 34
# 63 12928
# Done distance matrix: 0.022910118103027344
# Child 34 There were no points close enough
# Starting Child 35
# 18 12928
# Done distance matrix: 0.00749969482421875
# Done Generating final pairs: 0.01171875
# best_stitch_pair = [   10 11894]
# best_stitch_pair_size = 49539.48505496704
# best_stitch_pair_distance = 1038.3593901764734
# best_stitch_pair_size_ratio = 0.24150447343617576
# Starting Child 36
# 5 12928
# Done distance matrix: 0.002321481704711914
# Child 36 There were no points close enough
# Starting Child 37
# 37 12928
# Done distance matrix: 0.015058517456054688
# Child 37 There were no points close enough
# Starting Child 38
# 10 12928
# Done distance matrix: 0.0039980411529541016
# Child 38 There were no points close enough
# Starting Child 39
# 17 12928
# Done distance matrix: 0.0064852237701416016
# Child 39 There were no points close enough
# Starting Child 40
# 4 12928
# Done distance matrix: 0.0015931129455566406
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 12928
# Done distance matrix: 0.002177715301513672
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 12928
# Done distance matrix: 0.002823352813720703
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [295, 11776], 5: [153, 12714], 14: [30, 11881], 21: [5, 11820], 33: [0, 12902], 35: [10, 11894]}
# ---Stitching child 0 with pair: [295, 11776]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 938420, starting edge 2nd facet= 1005592,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 40
# Starting Organizing vertices for side 1
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_1_order done, len = 51
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 11
# About to add faces
# Finished adding faces: 6.723403930664062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0052127838134765625
# returned from stitch mesh: 1.0727941989898682
# Finished stitching child 0 : 1.2217276096343994
# ---Stitching child 5 with pair: [153, 12714]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 960323, starting edge 2nd facet= 1022663,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.430511474609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029703378677368164
# returned from stitch mesh: 0.9042489528656006
# Finished stitching child 5 : 0.9879167079925537
# ---Stitching child 14 with pair: [30, 11881]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934312, starting edge 2nd facet= 1025191,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 31
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.650520324707031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030427932739257812
# returned from stitch mesh: 0.9831974506378174
# Finished stitching child 14 : 1.1367425918579102
# ---Stitching child 21 with pair: [5, 11820]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 934536, starting edge 2nd facet= 1029137,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.2874603271484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029262542724609375
# returned from stitch mesh: 0.954749584197998
# Finished stitching child 21 : 1.1163032054901123
# ---Stitching child 33 with pair: [0, 12902]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 963123, starting edge 2nd facet= 1029391,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.504753112792969e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029262065887451172
# returned from stitch mesh: 0.8737447261810303
# Finished stitching child 33 : 1.0208804607391357
# ---Stitching child 35 with pair: [10, 11894]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 946377, starting edge 2nd facet= 1029836,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.5497207641601562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028580904006958008
# returned from stitch mesh: 0.8876378536224365
# Finished stitching child 35 : 1.0430357456207275
# ***************Finished big stitching iteration: 9.829126596450806***************
# Starting Child 3
# 887 14065
# Done distance matrix: 0.38365674018859863
# Child 3 There were no points close enough
# Starting Child 4
# 521 14065
# Done distance matrix: 0.22948074340820312
# Child 4 There were no points close enough
# Starting Child 6
# 567 14065
# Done distance matrix: 0.24738430976867676
# Child 6 There were no points close enough
# Starting Child 7
# 212 14065
# Done distance matrix: 0.08545279502868652
# Child 7 There were no points close enough
# Starting Child 8
# 170 14065
# Done distance matrix: 0.07124090194702148
# Child 8 There were no points close enough
# Starting Child 10
# 130 14065
# Done distance matrix: 0.0519561767578125
# Child 10 There were no points close enough
# Starting Child 11
# 290 14065
# Done distance matrix: 0.11696648597717285
# Done Generating final pairs: 0.12480688095092773
# best_stitch_pair = [  206 13861]
# best_stitch_pair_size = 2134758.3459845064
# best_stitch_pair_distance = 252.54897008950022
# best_stitch_pair_size_ratio = 0.9143665334861354
# Starting Child 12
# 191 14065
# Done distance matrix: 0.08453154563903809
# Done Generating final pairs: 0.08805441856384277
# best_stitch_pair = [  165 13814]
# best_stitch_pair_size = 75763.34031957734
# best_stitch_pair_distance = 133.59897154753196
# best_stitch_pair_size_ratio = 0.8622937409390152
# Starting Child 13
# 185 14065
# Done distance matrix: 0.09405970573425293
# Child 13 There were no points close enough
# Starting Child 15
# 470 14065
# Done distance matrix: 0.205949068069458
# Child 15 There were no points close enough
# Starting Child 16
# 261 14065
# Done distance matrix: 0.1065680980682373
# Child 16 There were no points close enough
# Starting Child 17
# 10 14065
# Done distance matrix: 0.004398822784423828
# Child 17 There were no points close enough
# Starting Child 18
# 16 14065
# Done distance matrix: 0.007092714309692383
# Child 18 There were no points close enough
# Starting Child 19
# 4 14065
# Done distance matrix: 0.0020258426666259766
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 14065
# Done distance matrix: 0.024106264114379883
# Done Generating final pairs: 0.027034521102905273
# best_stitch_pair = [    4 13643]
# best_stitch_pair_size = 142549.35198714465
# best_stitch_pair_distance = 301.4510828666649
# best_stitch_pair_size_ratio = 0.501101426366464
# Starting Child 25
# 56 14065
# Done distance matrix: 0.022164106369018555
# Child 25 There were no points close enough
# Starting Child 26
# 5 14065
# Done distance matrix: 0.0025157928466796875
# Child 26 There were no points close enough
# Starting Child 27
# 3 14065
# Done distance matrix: 0.0016682147979736328
# Child 27 There were no points close enough
# Starting Child 28
# 124 14065
# Done distance matrix: 0.04843854904174805
# Child 28 There were no points close enough
# Starting Child 30
# 34 14065
# Done distance matrix: 0.013399362564086914
# Child 30 There were no points close enough
# Starting Child 31
# 53 14065
# Done distance matrix: 0.02071976661682129
# Done Generating final pairs: 0.027411937713623047
# best_stitch_pair = [   29 14024]
# best_stitch_pair_size = 611219.884607617
# best_stitch_pair_distance = 156.93980186490012
# best_stitch_pair_size_ratio = 0.982445965311448
# Starting Child 34
# 63 14065
# Done distance matrix: 0.0245058536529541
# Child 34 There were no points close enough
# Starting Child 36
# 5 14065
# Done distance matrix: 0.002376079559326172
# Done Generating final pairs: 0.00892329216003418
# best_stitch_pair = [    0 13944]
# best_stitch_pair_size = 103024.45109182096
# best_stitch_pair_distance = 1084.6227998231022
# best_stitch_pair_size_ratio = 0.3489954733097541
# Starting Child 37
# 37 14065
# Done distance matrix: 0.014618158340454102
# Child 37 There were no points close enough
# Starting Child 38
# 10 14065
# Done distance matrix: 0.004442453384399414
# Child 38 There were no points close enough
# Starting Child 39
# 17 14065
# Done distance matrix: 0.007203817367553711
# Child 39 There were no points close enough
# Starting Child 40
# 4 14065
# Done distance matrix: 0.0020046234130859375
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 14065
# Done distance matrix: 0.002558469772338867
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 14065
# Done distance matrix: 0.0029554367065429688
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [206, 13861], 12: [165, 13814], 23: [4, 13643], 31: [29, 14024], 36: [0, 13944]}
# ---Stitching child 11 with pair: [206, 13861]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1025013, starting edge 2nd facet= 1030030,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 4.8160552978515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027993440628051758
# returned from stitch mesh: 0.8655898571014404
# Finished stitching child 11 : 1.0119807720184326
# ---Stitching child 12 with pair: [165, 13814]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1022787, starting edge 2nd facet= 1037567,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02994513511657715
# returned from stitch mesh: 0.9573349952697754
# Finished stitching child 12 : 1.1351101398468018
# ---Stitching child 23 with pair: [4, 13643]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1022369, starting edge 2nd facet= 1039716,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.19032597541809082
# returned from stitch mesh: 1.0574467182159424
# Finished stitching child 23 : 1.2282350063323975
# ---Stitching child 31 with pair: [29, 14024]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1029618, starting edge 2nd facet= 1040546,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.337860107421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02900838851928711
# returned from stitch mesh: 0.7286832332611084
# Finished stitching child 31 : 0.8608057498931885
# ---Stitching child 36 with pair: [0, 13944]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1025533, starting edge 2nd facet= 1042081,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02907538414001465
# returned from stitch mesh: 0.908228874206543
# Finished stitching child 36 : 1.0561842918395996
# ***************Finished big stitching iteration: 8.263612747192383***************
# Starting Child 3
# 887 14657
# Done distance matrix: 0.3957700729370117
# Child 3 There were no points close enough
# Starting Child 4
# 521 14657
# Done distance matrix: 0.23889851570129395
# Child 4 There were no points close enough
# Starting Child 6
# 567 14657
# Done distance matrix: 0.2562239170074463
# Child 6 There were no points close enough
# Starting Child 7
# 212 14657
# Done distance matrix: 0.10457444190979004
# Child 7 There were no points close enough
# Starting Child 8
# 170 14657
# Done distance matrix: 0.09862327575683594
# Child 8 There were no points close enough
# Starting Child 10
# 130 14657
# Done distance matrix: 0.05961036682128906
# Child 10 There were no points close enough
# Starting Child 13
# 185 14657
# Done distance matrix: 0.07646489143371582
# Child 13 There were no points close enough
# Starting Child 15
# 470 14657
# Done distance matrix: 0.2144489288330078
# Done Generating final pairs: 0.21996641159057617
# best_stitch_pair = [  221 14614]
# best_stitch_pair_size = 859620.1038684781
# best_stitch_pair_distance = 737.0193281922791
# best_stitch_pair_size_ratio = 0.3821383730413649
# Starting Child 16
# 261 14657
# Done distance matrix: 0.11614513397216797
# Child 16 There were no points close enough
# Starting Child 17
# 10 14657
# Done distance matrix: 0.0047702789306640625
# Child 17 There were no points close enough
# Starting Child 18
# 16 14657
# Done distance matrix: 0.007277488708496094
# Child 18 There were no points close enough
# Starting Child 19
# 4 14657
# Done distance matrix: 0.0019142627716064453
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 14657
# Done distance matrix: 0.02273392677307129
# Child 25 There were no points close enough
# Starting Child 26
# 5 14657
# Done distance matrix: 0.0023736953735351562
# Child 26 There were no points close enough
# Starting Child 27
# 3 14657
# Done distance matrix: 0.0015676021575927734
# Child 27 There were no points close enough
# Starting Child 28
# 124 14657
# Done distance matrix: 0.05201268196105957
# Child 28 There were no points close enough
# Starting Child 30
# 34 14657
# Done distance matrix: 0.01434183120727539
# Child 30 There were no points close enough
# Starting Child 34
# 63 14657
# Done distance matrix: 0.025618553161621094
# Done Generating final pairs: 0.02720475196838379
# best_stitch_pair = [    3 14591]
# best_stitch_pair_size = 49084.28270166188
# best_stitch_pair_distance = 297.5936887733172
# best_stitch_pair_size_ratio = 0.48412922201830955
# Starting Child 37
# 37 14657
# Done distance matrix: 0.015595674514770508
# Child 37 There were no points close enough
# Starting Child 38
# 10 14657
# Done distance matrix: 0.004798173904418945
# Child 38 There were no points close enough
# Starting Child 39
# 17 14657
# Done distance matrix: 0.007466316223144531
# Child 39 There were no points close enough
# Starting Child 40
# 4 14657
# Done distance matrix: 0.0019481182098388672
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 14657
# Done distance matrix: 0.002740144729614258
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 14657
# Done distance matrix: 0.003152608871459961
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {15: [221, 14614], 34: [3, 14591]}
# ---Stitching child 15 with pair: [221, 14614]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1040202, starting edge 2nd facet= 1045418,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 7.82012939453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04799151420593262
# returned from stitch mesh: 0.9249022006988525
# Finished stitching child 15 : 1.0868191719055176
# ---Stitching child 34 with pair: [3, 14591]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1040051, starting edge 2nd facet= 1052382,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.5735626220703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.031117916107177734
# returned from stitch mesh: 0.977200984954834
# Finished stitching child 34 : 1.1393351554870605
# ***************Finished big stitching iteration: 4.943333387374878***************
# Starting Child 3
# 887 15186
# Done distance matrix: 0.4292259216308594
# Done Generating final pairs: 0.434520959854126
# best_stitch_pair = [  232 14775]
# best_stitch_pair_size = 690856.3646172398
# best_stitch_pair_distance = 270.2210230377153
# best_stitch_pair_size_ratio = 0.7589459759005658
# Starting Child 4
# 521 15186
# Done distance matrix: 0.2532196044921875
# Child 4 There were no points close enough
# Starting Child 6
# 567 15186
# Done distance matrix: 0.2686035633087158
# Child 6 There were no points close enough
# Starting Child 7
# 212 15186
# Done distance matrix: 0.09440279006958008
# Child 7 There were no points close enough
# Starting Child 8
# 170 15186
# Done distance matrix: 0.07214212417602539
# Child 8 There were no points close enough
# Starting Child 10
# 130 15186
# Done distance matrix: 0.056139469146728516
# Child 10 There were no points close enough
# Starting Child 13
# 185 15186
# Done distance matrix: 0.07958745956420898
# Child 13 There were no points close enough
# Starting Child 16
# 261 15186
# Done distance matrix: 0.11213517189025879
# Child 16 There were no points close enough
# Starting Child 17
# 10 15186
# Done distance matrix: 0.004784822463989258
# Child 17 There were no points close enough
# Starting Child 18
# 16 15186
# Done distance matrix: 0.007827520370483398
# Child 18 There were no points close enough
# Starting Child 19
# 4 15186
# Done distance matrix: 0.002052783966064453
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 15186
# Done distance matrix: 0.023146390914916992
# Child 25 There were no points close enough
# Starting Child 26
# 5 15186
# Done distance matrix: 0.0024509429931640625
# Child 26 There were no points close enough
# Starting Child 27
# 3 15186
# Done distance matrix: 0.0015363693237304688
# Child 27 There were no points close enough
# Starting Child 28
# 124 15186
# Done distance matrix: 0.05167055130004883
# Done Generating final pairs: 0.05301094055175781
# best_stitch_pair = [   90 15132]
# best_stitch_pair_size = 28857.48103081534
# best_stitch_pair_distance = 410.16058459605557
# best_stitch_pair_size_ratio = 0.7328099769970607
# Starting Child 30
# 34 15186
# Done distance matrix: 0.014716863632202148
# Child 30 There were no points close enough
# Starting Child 37
# 37 15186
# Done distance matrix: 0.01604771614074707
# Child 37 There were no points close enough
# Starting Child 38
# 10 15186
# Done distance matrix: 0.004792213439941406
# Child 38 There were no points close enough
# Starting Child 39
# 17 15186
# Done distance matrix: 0.00814676284790039
# Child 39 There were no points close enough
# Starting Child 40
# 4 15186
# Done distance matrix: 0.0020148754119873047
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 15186
# Done distance matrix: 0.0027697086334228516
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 15186
# Done distance matrix: 0.0032384395599365234
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [232, 14775], 28: [90, 15132]}
# ---Stitching child 3 with pair: [232, 14775]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1050897, starting edge 2nd facet= 1060686,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 3.0517578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028907060623168945
# returned from stitch mesh: 0.9198050498962402
# Finished stitching child 3 : 1.0743212699890137
# ---Stitching child 28 with pair: [90, 15132]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1052008, starting edge 2nd facet= 1067422,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.3589859008789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028848886489868164
# returned from stitch mesh: 0.9056346416473389
# Finished stitching child 28 : 1.0630946159362793
# ***************Finished big stitching iteration: 4.749648571014404***************
# Starting Child 4
# 521 16193
# Done distance matrix: 0.29148125648498535
# Child 4 There were no points close enough
# Starting Child 6
# 567 16193
# Done distance matrix: 0.2884664535522461
# Child 6 There were no points close enough
# Starting Child 7
# 212 16193
# Done distance matrix: 0.09733414649963379
# Child 7 There were no points close enough
# Starting Child 8
# 170 16193
# Done distance matrix: 0.07476401329040527
# Child 8 There were no points close enough
# Starting Child 10
# 130 16193
# Done distance matrix: 0.05777907371520996
# Child 10 There were no points close enough
# Starting Child 13
# 185 16193
# Done distance matrix: 0.08349847793579102
# Child 13 There were no points close enough
# Starting Child 16
# 261 16193
# Done distance matrix: 0.12143492698669434
# Child 16 There were no points close enough
# Starting Child 17
# 10 16193
# Done distance matrix: 0.005217552185058594
# Child 17 There were no points close enough
# Starting Child 18
# 16 16193
# Done distance matrix: 0.008068561553955078
# Child 18 There were no points close enough
# Starting Child 19
# 4 16193
# Done distance matrix: 0.0022089481353759766
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 16193
# Done distance matrix: 0.02609705924987793
# Child 25 There were no points close enough
# Starting Child 26
# 5 16193
# Done distance matrix: 0.0027642250061035156
# Child 26 There were no points close enough
# Starting Child 27
# 3 16193
# Done distance matrix: 0.0016415119171142578
# Child 27 There were no points close enough
# Starting Child 30
# 34 16193
# Done distance matrix: 0.015319585800170898
# Child 30 There were no points close enough
# Starting Child 37
# 37 16193
# Done distance matrix: 0.016360044479370117
# Child 37 There were no points close enough
# Starting Child 38
# 10 16193
# Done distance matrix: 0.0048923492431640625
# Child 38 There were no points close enough
# Starting Child 39
# 17 16193
# Done distance matrix: 0.008293867111206055
# Child 39 There were no points close enough
# Starting Child 40
# 4 16193
# Done distance matrix: 0.0022263526916503906
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 16193
# Done distance matrix: 0.002918243408203125
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 16193
# Done distance matrix: 0.0033648014068603516
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 4
# 521 16193
# Done distance matrix: 0.2378065586090088
# Child 4 There were no points close enough
# Starting Child 6
# 567 16193
# Done distance matrix: 0.26614975929260254
# Child 6 There were no points close enough
# Starting Child 7
# 212 16193
# Done distance matrix: 0.09377622604370117
# Child 7 There were no points close enough
# Starting Child 8
# 170 16193
# Done distance matrix: 0.07577896118164062
# Child 8 There were no points close enough
# Starting Child 10
# 130 16193
# Done distance matrix: 0.06505131721496582
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 16193
# Done distance matrix: 0.09021949768066406
# Child 13 There were no points close enough
# Starting Child 16
# 261 16193
# Done distance matrix: 0.1411428451538086
# Child 16 There were no points close enough
# Starting Child 17
# 10 16193
# Done distance matrix: 0.005705833435058594
# Child 17 There were no points close enough
# Starting Child 18
# 16 16193
# Done distance matrix: 0.009044170379638672
# Child 18 There were no points close enough
# Starting Child 19
# 4 16193
# Done distance matrix: 0.0023956298828125
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 16193
# Done distance matrix: 0.025809288024902344
# Child 25 There were no points close enough
# Starting Child 26
# 5 16193
# Done distance matrix: 0.0025572776794433594
# Child 26 There were no points close enough
# Starting Child 27
# 3 16193
# Done distance matrix: 0.0016658306121826172
# Child 27 There were no points close enough
# Starting Child 30
# 34 16193
# Done distance matrix: 0.015213727951049805
# Child 30 There were no points close enough
# Starting Child 37
# 37 16193
# Done distance matrix: 0.016237974166870117
# Child 37 There were no points close enough
# Starting Child 38
# 10 16193
# Done distance matrix: 0.004785060882568359
# Child 38 There were no points close enough
# Starting Child 39
# 17 16193
# Done distance matrix: 0.007888317108154297
# Child 39 There were no points close enough
# Starting Child 40
# 4 16193
# Done distance matrix: 0.002166271209716797
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 16193
# Done distance matrix: 0.0029366016387939453
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 16193
# Done distance matrix: 0.0034046173095703125
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 4
# 521 16193
# Done distance matrix: 0.26790356636047363
# Child 4 There were no points close enough
# Starting Child 6
# 567 16193
# Done distance matrix: 0.2911860942840576
# Child 6 There were no points close enough
# Starting Child 7
# 212 16193
# Done distance matrix: 0.10743141174316406
# Child 7 There were no points close enough
# Starting Child 8
# 170 16193
# Done distance matrix: 0.08674144744873047
# Child 8 There were no points close enough
# Starting Child 10
# 130 16193
# Done distance matrix: 0.06662416458129883
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 16193
# Done distance matrix: 0.09219169616699219
# Child 13 There were no points close enough
# Starting Child 16
# 261 16193
# Done distance matrix: 0.12516117095947266
# Child 16 There were no points close enough
# Starting Child 17
# 10 16193
# Done distance matrix: 0.0053174495697021484
# Child 17 There were no points close enough
# Starting Child 18
# 16 16193
# Done distance matrix: 0.008529424667358398
# Child 18 There were no points close enough
# Starting Child 19
# 4 16193
# Done distance matrix: 0.002205371856689453
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 16193
# Done distance matrix: 0.026001691818237305
# Child 25 There were no points close enough
# Starting Child 26
# 5 16193
# Done distance matrix: 0.0026772022247314453
# Child 26 There were no points close enough
# Starting Child 27
# 3 16193
# Done distance matrix: 0.0017409324645996094
# Child 27 There were no points close enough
# Starting Child 30
# 34 16193
# Done distance matrix: 0.015375375747680664
# Child 30 There were no points close enough
# Starting Child 37
# 37 16193
# Done distance matrix: 0.016498565673828125
# Child 37 There were no points close enough
# Starting Child 38
# 10 16193
# Done distance matrix: 0.00473475456237793
# Child 38 There were no points close enough
# Starting Child 39
# 17 16193
# Done distance matrix: 0.007855415344238281
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 16193
# Done distance matrix: 0.0020797252655029297
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 16193
# Done distance matrix: 0.0028848648071289062
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 7 16193
# Done distance matrix: 0.003447294235229492
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 4
# 521 16193
# Done distance matrix: 0.23525261878967285
# Child 4 There were no points close enough
# Starting Child 6
# 567 16193
# Done distance matrix: 0.2559952735900879
# Child 6 There were no points close enough
# Starting Child 7
# 212 16193
# Done distance matrix: 0.09514570236206055
# Child 7 There were no points close enough
# Starting Child 8
# 170 16193
# Done distance matrix: 0.07826375961303711
# Child 8 There were no points close enough
# Starting Child 10
# 130 16193
# Done distance matrix: 0.05868124961853027
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 16193
# Done distance matrix: 0.08138728141784668
# Child 13 There were no points close enough
# Starting Child 16
# 261 16193
# Done distance matrix: 0.11583900451660156
# Child 16 There were no points close enough
# Starting Child 17
# 10 16193
# Done distance matrix: 0.0053386688232421875
# Child 17 There were no points close enough
# Starting Child 18
# 16 16193
# Done distance matrix: 0.008008241653442383
# Child 18 There were no points close enough
# Starting Child 19
# 4 16193
# Done distance matrix: 0.002098560333251953
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 16193
# Done distance matrix: 0.02458930015563965
# Child 25 There were no points close enough
# Starting Child 26
# 5 16193
# Done distance matrix: 0.002560138702392578
# Child 26 There were no points close enough
# Starting Child 27
# 3 16193
# Done distance matrix: 0.0016632080078125
# Child 27 There were no points close enough
# Starting Child 30
# 34 16193
# Done distance matrix: 0.015085458755493164
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 37
# 37 16193
# Done distance matrix: 0.016176223754882812
# ...
# smaller_face = child
# dividend = 1, remainder = 13
# About to add faces
# Finished adding faces: 4.8160552978515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0056765079498291016
# returned from stitch mesh: 1.0193533897399902
# Finished stitching child 8 : 1.1966261863708496
# ***************Finished big stitching iteration: 3.015413522720337***************
# Starting Child 6
# 567 17130
# Done distance matrix: 0.2747519016265869
# Child 6 There were no points close enough
# Starting Child 10
# 130 17130
# Done distance matrix: 0.0631263256072998
# Child 10 There were no points close enough
# Starting Child 13
# 185 17130
# Done distance matrix: 0.0888526439666748
# Done Generating final pairs: 0.09750533103942871
# best_stitch_pair = [   10 17037]
# best_stitch_pair_size = 565439.4542677687
# best_stitch_pair_distance = 166.73005403878216
# best_stitch_pair_size_ratio = 0.7934527462267268
# Starting Child 16
# 261 17130
# Done distance matrix: 0.12862062454223633
# Child 16 There were no points close enough
# Starting Child 17
# 10 17130
# Done distance matrix: 0.0059185028076171875
# Child 17 There were no points close enough
# Starting Child 18
# 16 17130
# Done distance matrix: 0.008826017379760742
# Child 18 There were no points close enough
# Starting Child 19
# 4 17130
# Done distance matrix: 0.0020847320556640625
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 17130
# Done distance matrix: 0.027344226837158203
# Child 25 There were no points close enough
# Starting Child 26
# 5 17130
# Done distance matrix: 0.0026445388793945312
# Child 26 There were no points close enough
# Starting Child 27
# 3 17130
# Done distance matrix: 0.001767873764038086
# Child 27 There were no points close enough
# Starting Child 30
# 34 17130
# Done distance matrix: 0.016453266143798828
# Child 30 There were no points close enough
# Starting Child 38
# 10 17130
# Done distance matrix: 0.0049893856048583984
# Child 38 There were no points close enough
# Starting Child 39
# 17 17130
# Done distance matrix: 0.009195566177368164
# Child 39 There were no points close enough
# Starting Child 40
# 4 17130
# Done distance matrix: 0.002125978469848633
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 17130
# Done distance matrix: 0.0031805038452148438
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {13: [10, 17037]}
# ---Stitching child 13 with pair: [10, 17037]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1082138, starting edge 2nd facet= 1086239,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 23
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 4.220008850097656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030262470245361328
# returned from stitch mesh: 0.7903690338134766
# Finished stitching child 13 : 0.875241756439209
# ***************Finished big stitching iteration: 2.359572649002075***************
# Starting Child 6
# 567 17313
# Done distance matrix: 0.3013002872467041
# Child 6 There were no points close enough
# Starting Child 10
# 130 17313
# Done distance matrix: 0.06752276420593262
# Child 10 There were no points close enough
# Starting Child 16
# 261 17313
# Done distance matrix: 0.12820768356323242
# Done Generating final pairs: 0.13988685607910156
# best_stitch_pair = [  109 17162]
# best_stitch_pair_size = 536771.560976783
# best_stitch_pair_distance = 528.1250266820249
# best_stitch_pair_size_ratio = 0.692701891757998
# Starting Child 17
# 10 17313
# Done distance matrix: 0.005383729934692383
# Child 17 There were no points close enough
# Starting Child 18
# 16 17313
# Done distance matrix: 0.008491277694702148
# Child 18 There were no points close enough
# Starting Child 19
# 4 17313
# Done distance matrix: 0.002156496047973633
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 17313
# Done distance matrix: 0.02692270278930664
# Child 25 There were no points close enough
# Starting Child 26
# 5 17313
# Done distance matrix: 0.0025587081909179688
# Child 26 There were no points close enough
# Starting Child 27
# 3 17313
# Done distance matrix: 0.0016417503356933594
# Child 27 There were no points close enough
# Starting Child 30
# 34 17313
# Done distance matrix: 0.016412019729614258
# Child 30 There were no points close enough
# Starting Child 38
# 10 17313
# Done distance matrix: 0.004992246627807617
# Child 38 There were no points close enough
# Starting Child 39
# 17 17313
# Done distance matrix: 0.008459091186523438
# Child 39 There were no points close enough
# Starting Child 40
# 4 17313
# Done distance matrix: 0.002117156982421875
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 17313
# Done distance matrix: 0.003004312515258789
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {16: [109, 17162]}
# ---Stitching child 16 with pair: [109, 17162]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1084099, starting edge 2nd facet= 1087293,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0323944091796875
# returned from stitch mesh: 1.081191062927246
# Finished stitching child 16 : 1.2606067657470703
# ***************Finished big stitching iteration: 2.8537702560424805***************
# Starting Child 6
# 567 17572
# Done distance matrix: 0.30495238304138184
# Done Generating final pairs: 0.3128676414489746
# best_stitch_pair = [  272 17314]
# best_stitch_pair_size = 971158.7440135763
# best_stitch_pair_distance = 141.32416466752377
# best_stitch_pair_size_ratio = 0.7238766679503226
# Starting Child 10
# 130 17572
# Done distance matrix: 0.0681159496307373
# Child 10 There were no points close enough
# Starting Child 17
# 10 17572
# Done distance matrix: 0.005554914474487305
# Child 17 There were no points close enough
# Starting Child 18
# 16 17572
# Done distance matrix: 0.00921320915222168
# Child 18 There were no points close enough
# Starting Child 19
# 4 17572
# Done distance matrix: 0.0022437572479248047
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 17572
# Done distance matrix: 0.02803325653076172
# Child 25 There were no points close enough
# Starting Child 26
# 5 17572
# Done distance matrix: 0.0027337074279785156
# Child 26 There were no points close enough
# Starting Child 27
# 3 17572
# Done distance matrix: 0.0017879009246826172
# Child 27 There were no points close enough
# Starting Child 30
# 34 17572
# Done distance matrix: 0.017263412475585938
# Child 30 There were no points close enough
# Starting Child 38
# 10 17572
# Done distance matrix: 0.005536794662475586
# Child 38 There were no points close enough
# Starting Child 39
# 17 17572
# Done distance matrix: 0.009373664855957031
# Child 39 There were no points close enough
# Starting Child 40
# 4 17572
# Done distance matrix: 0.0020978450775146484
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 17572
# Done distance matrix: 0.0031867027282714844
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [272, 17314]}
# ---Stitching child 6 with pair: [272, 17314]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1089153, starting edge 2nd facet= 1099123,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 4.601478576660156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030434846878051758
# returned from stitch mesh: 0.9733402729034424
# Finished stitching child 6 : 1.1335341930389404
# ***************Finished big stitching iteration: 2.691072940826416***************
# Starting Child 10
# 130 18137
# Done distance matrix: 0.06789207458496094
# Child 10 There were no points close enough
# Starting Child 17
# 10 18137
# Done distance matrix: 0.005972623825073242
# Child 17 There were no points close enough
# Starting Child 18
# 16 18137
# Done distance matrix: 0.011224746704101562
# Child 18 There were no points close enough
# Starting Child 19
# 4 18137
# Done distance matrix: 0.0023789405822753906
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 18137
# Done distance matrix: 0.029251575469970703
# Child 25 There were no points close enough
# Starting Child 26
# 5 18137
# Done distance matrix: 0.002874135971069336
# Child 26 There were no points close enough
# Starting Child 27
# 3 18137
# Done distance matrix: 0.0019407272338867188
# Child 27 There were no points close enough
# Starting Child 30
# 34 18137
# Done distance matrix: 0.017928600311279297
# Child 30 There were no points close enough
# Starting Child 38
# 10 18137
# Done distance matrix: 0.0055696964263916016
# Child 38 There were no points close enough
# Starting Child 39
# 17 18137
# Done distance matrix: 0.01016378402709961
# Child 39 There were no points close enough
# Starting Child 40
# 4 18137
# Done distance matrix: 0.002328157424926758
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 18137
# Done distance matrix: 0.0032510757446289062
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 10
# 130 18137
# Done distance matrix: 0.06473946571350098
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 10 18137
# Done distance matrix: 0.005421638488769531
# Child 17 There were no points close enough
# Starting Child 18
# 16 18137
# Done distance matrix: 0.008942365646362305
# Child 18 There were no points close enough
# Starting Child 19
# 4 18137
# Done distance matrix: 0.002223968505859375
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 18137
# Done distance matrix: 0.026898622512817383
# Child 25 There were no points close enough
# Starting Child 26
# 5 18137
# Done distance matrix: 0.0025811195373535156
# Child 26 There were no points close enough
# Starting Child 27
# 3 18137
# Done distance matrix: 0.0017292499542236328
# Child 27 There were no points close enough
# Starting Child 30
# 34 18137
# Done distance matrix: 0.016681194305419922
# Child 30 There were no points close enough
# Starting Child 38
# 10 18137
# Done distance matrix: 0.005150556564331055
# Child 38 There were no points close enough
# Starting Child 39
# 17 18137
# Done distance matrix: 0.009166479110717773
# Child 39 There were no points close enough
# Starting Child 40
# 4 18137
# Done distance matrix: 0.0022687911987304688
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 18137
# Done distance matrix: 0.003129243850708008
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 10
# 130 18137
# Done distance matrix: 0.06674885749816895
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 10 18137
# Done distance matrix: 0.005762577056884766
# Child 17 There were no points close enough
# Starting Child 18
# 16 18137
# Done distance matrix: 0.009337902069091797
# Child 18 There were no points close enough
# Starting Child 19
# 4 18137
# Done distance matrix: 0.0023801326751708984
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 18137
# Done distance matrix: 0.02835369110107422
# Child 25 There were no points close enough
# Starting Child 26
# 5 18137
# Done distance matrix: 0.0027780532836914062
# Child 26 There were no points close enough
# Starting Child 27
# 3 18137
# Done distance matrix: 0.0018873214721679688
# Child 27 There were no points close enough
# Starting Child 30
# 34 18137
# Done distance matrix: 0.01741647720336914
# Child 30 There were no points close enough
# Starting Child 38
# 10 18137
# Done distance matrix: 0.005405426025390625
# Child 38 There were no points close enough
# Starting Child 39
# 17 18137
# Done distance matrix: 0.00974130630493164
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 18137
# Done distance matrix: 0.0022432804107666016
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 18137
# Done distance matrix: 0.0033483505249023438
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 10
# 130 18137
# Done distance matrix: 0.06729888916015625
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 10 18137
# Done distance matrix: 0.005719661712646484
# Child 17 There were no points close enough
# Starting Child 18
# 16 18137
# Done distance matrix: 0.00926065444946289
# Child 18 There were no points close enough
# Starting Child 19
# 4 18137
# Done distance matrix: 0.002299785614013672
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 18137
# Done distance matrix: 0.028204917907714844
# Child 25 There were no points close enough
# Starting Child 26
# 5 18137
# Done distance matrix: 0.0027692317962646484
# Child 26 There were no points close enough
# Starting Child 27
# 3 18137
# Done distance matrix: 0.0017888545989990234
# Child 27 There were no points close enough
# Starting Child 30
# 34 18137
# Done distance matrix: 0.017395973205566406
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# 10 18137
# Done distance matrix: 0.005334138870239258
# Child 38 There were no points close enough
# Starting Child 39
# 17 18137
# Done distance matrix: 0.009724855422973633
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# 4 18137
# Done distance matrix: 0.002336740493774414
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# 6 18137
# Done distance matrix: 0.0032851696014404297
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 65.58170485496521
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-40-929266b6ae0c> in <module>
#      70         print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
#      71         print(f"total_stitch_processing_time = {time.time() - total_stitch_processing_time}")
# ---> 72         raise Exception("Finished the mesh stitiching")
#      73
#      74     #update the thresholds
#
# Exception: Finished the mesh stitiching

# %%
"""
There is a potential problem where delete facet from facet list but 
there are facets that are overlapping on the old way of calculating facets
which is used for the big pieces --> 

So potential problem where could have connecting to same mesh faces because 
multiple facets for that main mesh face exist

Possible solutions: 
1) Make the way of generating them check for overlaps and resolve
2) Add a face DO NOT CONNNECT LIST that checks if any faces currently processed
have been connected to already --> not great solution
3) Just leave it be and may create some self intersecting faces

"""

# %%
len(child_faces_to_remove),len(main_faces_to_remove)
# Out:
# (837, 739)

# %%
#now to extract the full mesh after it's done so don't screw up all the facets numbers:


#remove all of the processed facets from the main mesh
#now take away the original facet faces:
total_faces = np.linspace(0,len(main_mesh.faces)-1,len(main_mesh.faces)).astype("int")


#these are the faces that need to be removed
facet_faces = np.hstack([child_faces_to_remove ,main_faces_to_remove])
faces_to_keep = set(total_faces).difference(set(facet_faces))


main_mesh = main_mesh.submesh([list(faces_to_keep)])[0]

# %%
from print_trimesh import print_trimesh

print_trimesh(main_mesh,"./test_meshes/entire_neuron_facets_optimized.off")

# %%
print(f"Total time for restitching = {time.time() - restitch_time}")
# Out:
# Total time for restitching = 183.9891858100891

# %%
#try and compress the file:
import bz2
from shutil import copyfileobj

with open('./test_meshes/entire_neuron_facets_optimized.off', 'rb') as input:
    with bz2.BZ2File('./test_meshes/entire_neuron_facets_optimized.off.bz2', 'wb', compresslevel=9) as output:
        copyfileobj(input, output)

# %%
filepath = './test_meshes/entire_neuron_facets_optimized.off.bz2'
newfilepath = './test_meshes/entire_neuron_facets_optimized.off.bz2.off'

with open(newfilepath, 'wb') as new_file, bz2.BZ2File(filepath, 'rb') as file:
    for data in iter(lambda : file.read(100 * 1024), b''):
        new_file.write(data)

# %%
import os
num = os.path.getsize('./test_meshes/entire_neuron_facets_optimized.off.bz2')
num/1000/1000
# Out:
# 26.149690999999997

# %%
#check that it can be loaded into trimesh so uncompressed right
reloaded_mesh = trimesh.load_mesh("./test_meshes/entire_neuron_facets_optimized.off.bz2.off")

# %%
"""
Conclusion after observations: 
1) For some of neurons connecting from very far away (need to reduce size)
2) Seems like it is working just as good as other neuron stitcher i had
3) the stitching doesn't always work the best but it should do for now

"""

"""
Things still need to do:
1) Investigate those that aren't getting added and have reason why not
2) Make sure the normals can be flipped (and better if can just fix normals as make them)
"""

# %%
#main_mesh_fixed = trimesh.fix_normals(main_mesh)

# %% [markdown]
# # Exploring How to Transfer Labels

# %%
# """
# Copies to practice on

# """

# %%
# #copying the data to be used in the test
# child_meshes_facets_test= deepcopy(child_meshes_facets)
# pair_test = deepcopy(pair)

# main_mesh_facets_test = deepcopy(main_mesh_facets)
# main_mesh_facets_centers_test = deepcopy(main_mesh_facets_centers)

# %%
# """ Child data """
# child_key #the current child we are processing
# pair #has the child mesh and the main mesh facet index
# current_child_facet_faces = child_meshes_facets_test[child_key][0] #all of the child facets 
# current_child_facet_centers = child_meshes_facets_test[child_key][1]
# child_used_facet_index = pair_test[0]
# child_used_facet_faces = current_child_facet_faces[child_used_facet_index] #current facet that is being used
# child_used_facet_centers = current_child_facet_centers[child_used_facet_index] #current facet that is being used

# """ Main mesh data """
# main_used_faceet_index = pair[1]

# main_used_facet_faces = main_mesh_facets_test[main_used_faceet_index]
# main_used_facet_centers = main_mesh_facets_centers_test[main_used_faceet_index]

# #checking right now
# child_used_facet_centers

# %%
# """ Check how to apply the operations
# """

# #make a copy
# current_child_facet_faces_copy = current_child_facet_faces.copy()
# current_child_facet_centers_copy = current_child_facet_centers.copy()
# print("before deletion facets len = " + str(len(current_child_facet_faces_copy)) + ", centers len = " + str(len(current_child_facet_centers_copy)))

# print("NO COPIES before deletion facets len = " + str(len(current_child_facet_faces)) + ", centers len = " + str(len(current_child_facet_centers)))

# #delete a certain row from array
# current_child_facet_faces_copy_with_deletion = np.delete(current_child_facet_faces_copy,(child_used_facet_index),axis=0)
# current_child_facet_centers_copy_with_deletion = np.delete(current_child_facet_centers_copy,(child_used_facet_index),axis=0)

# #delete without making the copies

# current_child_facet_faces_with_deletion = np.delete(current_child_facet_faces,(child_used_facet_index),axis=0)
# current_child_facet_centers_with_deletion = np.delete(current_child_facet_centers,(child_used_facet_index),axis=0)

# print("AFTER deletion facets len = " + str(len(current_child_facet_faces_copy_with_deletion)) + ", centers len = " + str(len(current_child_facet_centers_copy_with_deletion)))

# print("NO COPIES AFTER deletion facets len = " + str(len(current_child_facet_faces_with_deletion)) + ", centers len = " + str(len(current_child_facet_centers_with_deletion)))

# print("NO COPIES AFTER deletion ORIGINALS facets len = " + str(len(current_child_facet_faces)) + ", centers len = " + str(len(current_child_facet_centers)))


# """
# CONCLUSION: so don't need to make copies and remains unchanged

# """
# current_child_facet_faces_with_deletion[0] = [None]
# print(current_child_facet_faces_with_deletion[0])
# print(current_child_facet_faces[0])

# """
# CONCLUSION: so don't need to make copies and remains unchanged and altering doesnt affect it

# """

# %%
# #remove certian rows from array
# current_child_facet_faces_with_deletion = np.delete(current_child_facet_faces,(child_used_facet_index),axis=0)
# current_child_facet_centers_with_deletion = np.delete(current_child_facet_centers,(child_used_facet_index),axis=0)

# ##### DON'T WANT TO DELETE THE MAIN MESH FACETS JUST YET ####

# #have to adjust the faces of the child_facets list to account for the faces off set
# current_child_facet_faces_with_deletion = current_child_facet_faces_with_deletion + original_mesh_faces_len

# #append this list to the main mesh list
# main_mesh_facets_test_new = np.concatenate([main_mesh_facets_test,current_child_facet_faces_with_deletion])
# main_mesh_centers_test_new = np.concatenate([main_mesh_facets_centers_test,current_child_facet_centers_with_deletion])

# print(len(main_mesh_facets_test) + len(current_child_facet_faces) -1 ,len(main_mesh_facets_test_new))
# print(len(main_mesh_facets_centers_test) + len(current_child_facet_centers) -1 ,len(main_mesh_centers_test_new))

# #save off the facets to delete for the main mesh at the end of the loop
# main_mesh_facet_index_to_delete = []
# main_mesh_facet_index_to_delete.append(pair[1])
# main_mesh_facet_index_to_delete.append(0)


# #at the end of the big loop have to delete the facets used from main mesh
# #remove certian rows from array
# main_mesh_facets_test_new_with_deletion = np.delete(main_mesh_facets_test_new,(main_mesh_facet_index_to_delete),axis=0)
# main_mesh_centers_test_new_with_deletion = np.delete(main_mesh_centers_test_new,(main_mesh_facet_index_to_delete),axis=0)

# print(len(main_mesh_facets_test_new),len(main_mesh_facets_test_new_with_deletion))
# print(len(main_mesh_centers_test_new),len(main_mesh_centers_test_new_with_deletion))

# %%
# len(main_mesh_facets_test_new),len(main_mesh_facets_test_new_with_deletion)

# %%
# original_mesh_faces_len

# %%
# current_child_facet_faces_with_deletion[0]

# %%
# (current_child_facet_faces_with_deletion + original_mesh_faces_len)[0] - current_child_facet_faces_with_deletion[0]

# %%
# # EXPORT THE MAIN MESH
# """
# Pseudocode for mapping labels
# 1) Get the child index and the pair of child facet and main facet to stitch
# 2) Create combined mesh (that just adds faces on top of each other)
#     main facet faces to remove 
# 3) Adjusts the child facets so now they correspond to the combined mesh face numbers
# 4) Add the current_child_facet_faces_adjusted and current_main_mesh_facet_faces to the list to delete
# -- will know which faces to delete at the end (currently doing this)

# How to transfer the labels: SO DON'T HAVE TO RECOMPUTE
# 1) at the very end of each stitch loop need to add the children facets and their faces list to the main facets list (this won't interfere with any stitching)
#     but don't add the one that was just used 
#     --> have to add the same center points as well (based on the )
# 2) At the very end have to delete the main mesh facets that were used and their center points

# --> then rerun the loop and everything should run fine with the new main mesh facets being different
# """
