# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341353058: Dendrite-0
# Component found in Orphans
# len of vertices = 38766
# Step 1: extracted Soma Mesh = 1.33292555809021
# Mesh successfully extracted
# Total time = 1.9278881549835205
#
#
# 648518346341353574: Basal-0
# Component found in Orphans
# len of vertices = 45208
# Step 1: extracted Soma Mesh = 1.4084727764129639
# Mesh successfully extracted
# Total time = 2.24190616607666
#
#
# 648518346341353607: Dendrite-0
# Component found in Orphans
# len of vertices = 68095
# Step 1: extracted Soma Mesh = 1.7498245239257812
# Mesh successfully extracted
# Total time = 2.2729251384735107
#
#
# 648518346341354313: Dendrite-0
# Component found in Orphans
# len of vertices = 45794
# Step 1: extracted Soma Mesh = 1.3231925964355469
# Mesh successfully extracted
# Total time = 1.7311265468597412
#
#
# 648518346341354496: Dendrite-0
# Component found in Orphans
# len of vertices = 61171
# Step 1: extracted Soma Mesh = 1.6157963275909424
# Mesh successfully extracted
# Total time = 2.051596164703369
#
#
# 648518346341355048: Dendrite-0
# Component found in Orphans
# len of vertices = 97057
# Step 1: extracted Soma Mesh = 2.2964212894439697
# Mesh successfully extracted
# Total time = 3.0450191497802734
#
#
# 648518346341355198: Dendrite-0
# Component found in Orphans
# len of vertices = 15943
# Step 1: extracted Soma Mesh = 1.0302801132202148
# Mesh successfully extracted
# Total time = 1.3609085083007812
#
#
# 648518346341355736: Dendrite-0
# Component found in Orphans
# len of vertices = 65437
# Step 1: extracted Soma Mesh = 1.566864252090454
# Mesh successfully extracted
# Total time = 2.1246349811553955
#
#
# 648518346341356241: Dendrite-0
# Component found in Orphans
# len of vertices = 20526
# Step 1: extracted Soma Mesh = 0.9311702251434326
# Mesh successfully extracted
# Total time = 1.2929186820983887
#
#
# 648518346341356256: Dendrite-0
# Component found in Orphans
# len of vertices = 298887
# Step 1: extracted Soma Mesh = 6.48598575592041
# Mesh successfully extracted
# Total time = 8.676777124404907
#
#
# 648518346341357855: Dendrite-0
# Component found in Orphans
# len of vertices = 82771
# Step 1: extracted Soma Mesh = 1.9118030071258545
# Mesh successfully extracted
# Total time = 2.5467960834503174
#
#
# 648518346341357933: Dendrite-0
# Component found in Orphans
# len of vertices = 33878
# Step 1: extracted Soma Mesh = 1.229034423828125
# Mesh successfully extracted
# Total time = 1.8083760738372803
#
#
# 648518346341358332: Dendrite-0
# Component found in Orphans
# len of vertices = 11106
# Step 1: extracted Soma Mesh = 0.7865180969238281
# Mesh successfully extracted
# Total time = 1.1415421962738037
#
#
# 648518346341358846: Dendrite-0
# Component found in Orphans
# len of vertices = 34648
# Step 1: extracted Soma Mesh = 1.1273596286773682
# Mesh successfully extracted
# Total time = 1.6015756130218506
#
#
# 648518346341359123: Dendrite-0
# Component found in Orphans
# len of vertices = 73533
# Step 1: extracted Soma Mesh = 2.0761523246765137
# Mesh successfully extracted
# Total time = 2.701460599899292
#
#
# 648518346341360400: Dendrite-0
# Component found in Orphans
# len of vertices = 35368
# Step 1: extracted Soma Mesh = 1.2535903453826904
# Mesh successfully extracted
# Total time = 1.6467046737670898
#
#
# 648518346341360660: Dendrite-0
# Component found in Orphans
# len of vertices = 11864
# Step 1: extracted Soma Mesh = 0.8182618618011475
# Mesh successfully extracted
# Total time = 1.1310107707977295
#
#
# 648518346341360739: Dendrite-0
# Component found in Orphans
# len of vertices = 90631
# Step 1: extracted Soma Mesh = 2.566235065460205
# Mesh successfully extracted
# Total time = 3.3088059425354004
#
#
# 648518346341361018: Dendrite-0
# Component found in Orphans
# len of vertices = 49038
# Step 1: extracted Soma Mesh = 1.832705020904541
# Mesh successfully extracted
# Total time = 2.5953445434570312
#
#
# 648518346341361837: Dendrite-0
# Component found in Orphans
# len of vertices = 21454
# Step 1: extracted Soma Mesh = 1.373248815536499
# Mesh successfully extracted
# Total time = 1.9038915634155273
#
#
# 648518346341361981: Dendrite-0
# Component found in Orphans
# len of vertices = 254688
# Step 1: extracted Soma Mesh = 7.5169358253479
# Mesh successfully extracted
# Total time = 10.009055614471436
#
#
# 648518346341362267: Dendrite-0
# Component found in Orphans
# len of vertices = 59024
# Step 1: extracted Soma Mesh = 2.070737361907959
# Mesh successfully extracted
# Total time = 2.8368802070617676
#
#
# 648518346341362477: Dendrite-0
# Component found in Orphans
# len of vertices = 16465
# Step 1: extracted Soma Mesh = 1.1685001850128174
# Mesh successfully extracted
# Total time = 1.6163818836212158
#
#
# 648518346341362771: Dendrite-0
# Component found in Orphans
# len of vertices = 13741
# Step 1: extracted Soma Mesh = 0.8809685707092285
# Mesh successfully extracted
# Total time = 1.2821276187896729
#
#
# 648518346341362995: Dendrite-0
# Component found in Orphans
# len of vertices = 176844
# Step 1: extracted Soma Mesh = 5.021852254867554
# Mesh successfully extracted
# Total time = 6.960584402084351
#
#
# 648518346341363175: Dendrite-0
# Component found in Orphans
# len of vertices = 135544
# Step 1: extracted Soma Mesh = 4.075038194656372
# Mesh successfully extracted
# Total time = 5.121776342391968
#
#
# 648518346341363182: Dendrite-0
# Component found in Orphans
# len of vertices = 40461
# Step 1: extracted Soma Mesh = 1.5598862171173096
# Mesh successfully extracted
# Total time = 2.236323595046997
#
#
# 648518346341363677: Dendrite-0
# Component found in Orphans
# len of vertices = 72377
# Step 1: extracted Soma Mesh = 2.422150135040283
# Mesh successfully extracted
# Total time = 3.202367067337036
#
#
# 648518346341365659: Dendrite-0
# Component found in Orphans
# len of vertices = 25072
# Step 1: extracted Soma Mesh = 1.314136028289795
# Mesh successfully extracted
# Total time = 1.9032416343688965
#
#
# 648518346341366161: Dendrite-0
# Component found in Orphans
# len of vertices = 44791
# Step 1: extracted Soma Mesh = 1.6018364429473877
# Mesh successfully extracted
# Total time = 2.6513302326202393
#
#
# 648518346341366450: Dendrite-0
# Component found in Orphans
# len of vertices = 18435
# Step 1: extracted Soma Mesh = 1.282256841659546
# Mesh successfully extracted
# Total time = 1.7160077095031738
#
#
# 648518346341366757: Dendrite-0
# Component found in Orphans
# len of vertices = 75775
# Step 1: extracted Soma Mesh = 2.0409350395202637
# Mesh successfully extracted
# Total time = 2.803563117980957
#
#
# 648518346341366913: Dendrite-0
# Component found in Orphans
# len of vertices = 16495
# Step 1: extracted Soma Mesh = 1.0457518100738525
# Mesh successfully extracted
# Total time = 1.4523906707763672
#
#
# 648518346341367107: Dendrite-0
# Component found in Orphans
# len of vertices = 15500
# Step 1: extracted Soma Mesh = 0.9399654865264893
# Mesh successfully extracted
# Total time = 1.3527462482452393
#
#
# 648518346341367133: Dendrite-0
# Component found in Orphans
# len of vertices = 44351
# Step 1: extracted Soma Mesh = 1.4513304233551025
# Mesh successfully extracted
# Total time = 2.2185792922973633
#
#
# 648518346341367433: Dendrite-0
# Component found in Orphans
# len of vertices = 16580
# Step 1: extracted Soma Mesh = 0.952033519744873
# Mesh successfully extracted
# Total time = 1.3379936218261719
#
#
# 648518346341367466: Dendrite-0
# Component found in Orphans
# len of vertices = 60185
# Step 1: extracted Soma Mesh = 2.0809597969055176
# Mesh successfully extracted
# Total time = 2.671616315841675
#
#
# 648518346341367927: Dendrite-0
# Component found in Orphans
# len of vertices = 75270
# Step 1: extracted Soma Mesh = 2.097907304763794
# Mesh successfully extracted
# Total time = 2.856445074081421
#
#
# 648518346341368307: Dendrite-0
# Component found in Orphans
# len of vertices = 28867
# Step 1: extracted Soma Mesh = 1.2519299983978271
# Mesh successfully extracted
# Total time = 1.7256276607513428
#
#
# 648518346341368678: Dendrite-0
# Component found in Orphans
# len of vertices = 53324
# Step 1: extracted Soma Mesh = 1.7011487483978271
# Mesh successfully extracted
# Total time = 2.6421639919281006
#
#
# 648518346341368711: Dendrite-0
# Component found in Orphans
# len of vertices = 47798
# Step 1: extracted Soma Mesh = 1.602306604385376
# Mesh successfully extracted
# Total time = 2.3374805450439453
#
#
# 648518346341368824: Dendrite-0
# Component found in Orphans
# len of vertices = 19239
# Step 1: extracted Soma Mesh = 1.1399519443511963
# Mesh successfully extracted
# Total time = 1.6226112842559814
#
#
# 648518346341369015: Dendrite-0
# Component found in Orphans
# len of vertices = 19400
# Step 1: extracted Soma Mesh = 0.9320645332336426
# Mesh successfully extracted
# Total time = 1.418755292892456
#
#
# 648518346341369029: Dendrite-0
# Component found in Orphans
# len of vertices = 32547
# Step 1: extracted Soma Mesh = 1.2126753330230713
# Mesh successfully extracted
# Total time = 1.6819496154785156
#
#
# 648518346341369370: Dendrite-0
# Component found in Orphans
# len of vertices = 46320
# Step 1: extracted Soma Mesh = 1.427908182144165
# Mesh successfully extracted
# Total time = 2.1333510875701904
#
#
# 648518346341369387: Dendrite-0
# Component found in Orphans
# len of vertices = 42280
# Step 1: extracted Soma Mesh = 1.6548173427581787
# Mesh successfully extracted
# Total time = 2.8908042907714844
#
#
# 648518346341370042: Dendrite-0
# Component found in Orphans
# len of vertices = 14086
# Step 1: extracted Soma Mesh = 0.9995346069335938
# Mesh successfully extracted
# Total time = 1.3731260299682617
#
#
# 648518346341371141: Dendrite-0
# Component found in Orphans
# len of vertices = 23104
# Step 1: extracted Soma Mesh = 1.1692078113555908
# Mesh successfully extracted
# Total time = 1.6375689506530762
#
#
# 648518346341371997: Dendrite-0
# Component found in Orphans
# len of vertices = 83598
# Step 1: extracted Soma Mesh = 2.562380313873291
# Mesh successfully extracted
# Total time = 3.7755110263824463
#
#
# 648518346341372248: Dendrite-0
# Component found in Orphans
# len of vertices = 125267
# Step 1: extracted Soma Mesh = 3.3500609397888184
# Mesh successfully extracted
# Total time = 4.944132089614868
#
#
# 648518346341372268: Dendrite-0
# Component found in Orphans
# len of vertices = 35561
# Step 1: extracted Soma Mesh = 1.589756965637207
# Mesh successfully extracted
# Total time = 2.0344011783599854
#
#
# 648518346341372326: Dendrite-0
# Component found in Orphans
# len of vertices = 28777
# Step 1: extracted Soma Mesh = 1.0946252346038818
# Mesh successfully extracted
# Total time = 1.5103814601898193
#
#
# 648518346341373380: Dendrite-0
# Component found in Orphans
# len of vertices = 66210
# Step 1: extracted Soma Mesh = 2.2881951332092285
# Mesh successfully extracted
# Total time = 3.048771381378174
#
#
# 648518346341373381: Dendrite-0
# Component found in Orphans
# len of vertices = 55286
# Step 1: extracted Soma Mesh = 1.5000827312469482
# Mesh successfully extracted
# Total time = 1.961599588394165
#
#
# 648518346341373475: Dendrite-0
# Component found in Orphans
# len of vertices = 192461
# Step 1: extracted Soma Mesh = 3.909672737121582
# Mesh successfully extracted
# Total time = 5.264368057250977
#
#
# 648518346341374332: Dendrite-0
# Component found in Orphans
# len of vertices = 50109
# Step 1: extracted Soma Mesh = 1.585341215133667
# Mesh successfully extracted
# Total time = 2.1869871616363525
#
#
# 648518346341374333: Dendrite-0
# Component found in Orphans
# len of vertices = 42925
# Step 1: extracted Soma Mesh = 1.2532291412353516
# Mesh successfully extracted
# Total time = 1.719057559967041
#
#
# 648518346341375623: Dendrite-0
# Component found in Orphans
# len of vertices = 102640
# Step 1: extracted Soma Mesh = 2.27561354637146
# Mesh successfully extracted
# Total time = 3.2011077404022217
#
#
# 648518346341375951: Dendrite-0
# Component found in Orphans
# len of vertices = 35356
# Step 1: extracted Soma Mesh = 1.2780508995056152
# Mesh successfully extracted
# Total time = 1.7791144847869873
#
#
# 648518346341376363: Dendrite-0
# Component found in Orphans
# len of vertices = 121778
# Step 1: extracted Soma Mesh = 3.108649969100952
# Mesh successfully extracted
# Total time = 4.567033529281616
#
#
# 648518346341376492: Dendrite-0
# Component found in Orphans
# len of vertices = 46192
# Step 1: extracted Soma Mesh = 1.6083273887634277
# Mesh successfully extracted
# Total time = 2.188913345336914
#
#
# 648518346341376611: Dendrite-0
# Component found in Orphans
# len of vertices = 32729
# Step 1: extracted Soma Mesh = 1.3383204936981201
# Mesh successfully extracted
# Total time = 2.0138814449310303
#
#
# 648518346341376756: Dendrite-0
# Component found in Orphans
# len of vertices = 71328
# Step 1: extracted Soma Mesh = 1.8303956985473633
# Mesh successfully extracted
# Total time = 2.388103723526001
#
#
# 648518346341376757: Dendrite-0
# Component found in Orphans
# len of vertices = 48954
# Step 1: extracted Soma Mesh = 1.7695763111114502
# Mesh successfully extracted
# Total time = 2.5233399868011475
#
#
# 648518346341377165: Dendrite-0
# Component found in Orphans
# len of vertices = 25337
# Step 1: extracted Soma Mesh = 0.9895029067993164
# Mesh successfully extracted
# Total time = 1.3674380779266357
#
#
# 648518346341377469: Dendrite-0
# Component found in Orphans
# len of vertices = 90623
# Step 1: extracted Soma Mesh = 2.5024044513702393
# Mesh successfully extracted
# Total time = 3.211555004119873
#
#
# 648518346341378999: Dendrite-0
# Component found in Orphans
# len of vertices = 136748
# Step 1: extracted Soma Mesh = 4.00056266784668
# Mesh successfully extracted
# Total time = 4.985281467437744
#
#
# 648518346341379591: Dendrite-0
# Component found in Orphans
# len of vertices = 113319
# Step 1: extracted Soma Mesh = 3.1420795917510986
# Mesh successfully extracted
# Total time = 4.501266241073608
#
#
# 648518346341382069: Dendrite-0
# Component found in Orphans
# len of vertices = 165080
# Step 1: extracted Soma Mesh = 9.906088590621948
# Mesh successfully extracted
# Total time = 11.397120952606201
#
#
# 648518346341395182: Dendrite-0
# Component found in Orphans
# len of vertices = 14290
# Step 1: extracted Soma Mesh = 1.0752034187316895
# Mesh successfully extracted
# Total time = 1.5485820770263672
#
#
# 648518346341395530: Dendrite-0
# Component found in Orphans
# len of vertices = 97003
# Step 1: extracted Soma Mesh = 4.019545078277588
# Mesh successfully extracted
# Total time = 5.118457317352295
#
#
# 648518346341398089: Dendrite-0
# Component found in Orphans
# len of vertices = 12854
# Step 1: extracted Soma Mesh = 1.2333755493164062
# Mesh successfully extracted
# Total time = 1.7274730205535889
#
#
# 648518346341398503: Dendrite-0
# Component found in Orphans
# len of vertices = 83167
# Step 1: extracted Soma Mesh = 2.9414010047912598
# Mesh successfully extracted
# Total time = 3.87749981880188
#
#
# 648518346341399321: Dendrite-0
# Component found in Orphans
# len of vertices = 10284
# Step 1: extracted Soma Mesh = 1.5097973346710205
# Mesh successfully extracted
# Total time = 1.9893193244934082
#
#
# 648518346341399743: Dendrite-0
# Component found in Orphans
# len of vertices = 82222
# Step 1: extracted Soma Mesh = 2.3181400299072266
# Mesh successfully extracted
# Total time = 3.165905237197876
#
#
# 648518346341401351: Dendrite-0
# Component found in Orphans
# len of vertices = 13679
# Step 1: extracted Soma Mesh = 1.1484439373016357
# Mesh successfully extracted
# Total time = 1.558265209197998
#
#
# 648518346341401564: Dendrite-0
# Component found in Orphans
# len of vertices = 18723
# Step 1: extracted Soma Mesh = 0.9563734531402588
# Mesh successfully extracted
# Total time = 1.4587478637695312
#
#
# 648518346341402108: Dendrite-0
# Component found in Orphans
# len of vertices = 15068
# Step 1: extracted Soma Mesh = 0.8869748115539551
# Mesh successfully extracted
# Total time = 1.300684928894043
#
#
# 648518346341402454: Dendrite-0
# Component found in Orphans
# len of vertices = 223568
# Step 1: extracted Soma Mesh = 4.9485673904418945
# Mesh successfully extracted
# Total time = 6.676025629043579
#
#
# 648518346341403972: Dendrite-0
# Component found in Orphans
# len of vertices = 16259
# Step 1: extracted Soma Mesh = 1.127802848815918
# Mesh successfully extracted
# Total time = 1.6915664672851562
#
#
# 648518346341404190: Dendrite-0
# Component found in Orphans
# len of vertices = 56667
# Step 1: extracted Soma Mesh = 1.9370832443237305
# Mesh successfully extracted
# Total time = 2.8751063346862793
#
#
# 648518346341404630: Dendrite-0
# Component found in Orphans
# len of vertices = 20050
# Step 1: extracted Soma Mesh = 2.2195019721984863
# Mesh successfully extracted
# Total time = 2.999177932739258
#
#
# 648518346341405383: Dendrite-0
# Component found in Orphans
# len of vertices = 42341
# Step 1: extracted Soma Mesh = 1.3106019496917725
# Mesh successfully extracted
# Total time = 1.9619052410125732
#
#
# 648518346341406029: Dendrite-0
# Component found in Orphans
# len of vertices = 55902
# Step 1: extracted Soma Mesh = 1.5027201175689697
# Mesh successfully extracted
# Total time = 2.3802878856658936
#
#
# 648518346341407256: Dendrite-0
# Component found in Orphans
# len of vertices = 19684
# Step 1: extracted Soma Mesh = 1.1589038372039795
# Mesh successfully extracted
# Total time = 1.7066149711608887
#
#
# 648518346341408329: Dendrite-0
# Component found in Orphans
# len of vertices = 68354
# Step 1: extracted Soma Mesh = 2.220977544784546
# Mesh successfully extracted
# Total time = 2.9316999912261963
#
#
# 648518346341408477: Dendrite-0
# Component found in Orphans
# len of vertices = 48239
# Step 1: extracted Soma Mesh = 1.5588679313659668
# Mesh successfully extracted
# Total time = 2.356592893600464
#
#
# 648518346341409422: Dendrite-0
# Component found in Orphans
# len of vertices = 14674
# Step 1: extracted Soma Mesh = 1.0253994464874268
# Mesh successfully extracted
# Total time = 1.4052414894104004
#
#
# 648518346341409819: Dendrite-0
# Component found in Orphans
# len of vertices = 40315
# Step 1: extracted Soma Mesh = 1.3770136833190918
# Mesh successfully extracted
# Total time = 1.8783652782440186
#
#
# 648518346341410176: Dendrite-0
# Component found in Orphans
# len of vertices = 53166
# Step 1: extracted Soma Mesh = 1.5248548984527588
# Mesh successfully extracted
# Total time = 2.3318932056427
#
#
# 648518346341410558: Dendrite-0
# Component found in Orphans
# len of vertices = 47512
# Step 1: extracted Soma Mesh = 1.568622350692749
# Mesh successfully extracted
# Total time = 2.3868796825408936
#
#
# 648518346341410889: Dendrite-0
# Component found in Orphans
# len of vertices = 30920
# Step 1: extracted Soma Mesh = 1.2249341011047363
# Mesh successfully extracted
# Total time = 1.760603666305542
#
#
# 648518346341411808: Dendrite-0
# Component found in Orphans
# len of vertices = 35318
# Step 1: extracted Soma Mesh = 1.52951979637146
# Mesh successfully extracted
# Total time = 2.123960018157959
#
#
# 648518346341413916: Dendrite-0
# Component found in Orphans
# len of vertices = 33294
# Step 1: extracted Soma Mesh = 1.3619370460510254
# Mesh successfully extracted
# Total time = 1.8727166652679443
#
#
# 648518346341414523: Dendrite-0
# Component found in Orphans
# len of vertices = 53758
# Step 1: extracted Soma Mesh = 1.8266398906707764
# Mesh successfully extracted
# Total time = 2.3921003341674805
#
#
# 648518346341416332: Dendrite-0
# Component found in Orphans
# len of vertices = 14454
# Step 1: extracted Soma Mesh = 1.085197925567627
# Mesh successfully extracted
# Total time = 1.4606454372406006
#
#
# 648518346341417088: Dendrite-0
# Component found in Orphans
# len of vertices = 18334
# Step 1: extracted Soma Mesh = 0.9239330291748047
# Mesh successfully extracted
# Total time = 1.4000012874603271
#
#
# 648518346341420204: Dendrite-0
# Component found in Orphans
# len of vertices = 14726
# Step 1: extracted Soma Mesh = 0.913581371307373
# Mesh successfully extracted
# Total time = 1.3034436702728271
#
#
# 648518346342410869: Dendrite-0
# Component found in Orphans
# len of vertices = 14083
# Step 1: extracted Soma Mesh = 0.835808515548706
# Mesh successfully extracted
# Total time = 1.1528310775756836
#
#
# 648518346342416145: Dendrite-0
# Component found in Orphans
# len of vertices = 16193
# Step 1: extracted Soma Mesh = 0.8305056095123291
# Mesh successfully extracted
# Total time = 1.1384921073913574
#
#
# 648518346342789316: Dendrite-0
# Component found in Orphans
# len of vertices = 122447
# Step 1: extracted Soma Mesh = 2.9113070964813232
# Mesh successfully extracted
# Total time = 4.351318359375
#
#
# 648518346342791621: Dendrite-0
# Component found in Orphans
# len of vertices = 16974
# Step 1: extracted Soma Mesh = 1.2487316131591797
# Mesh successfully extracted
# Total time = 1.6349821090698242
#
#
# 648518346342791878: Dendrite-0
# Component found in Orphans
# len of vertices = 27951
# Step 1: extracted Soma Mesh = 1.169956922531128
# Mesh successfully extracted
# Total time = 1.7352049350738525
#
#
# 648518346342791929: Dendrite-0
# Component found in Orphans
# len of vertices = 25281
# Step 1: extracted Soma Mesh = 1.1657867431640625
# Mesh successfully extracted
# Total time = 1.5563418865203857
#
#
# 648518346342792341: Dendrite-0
# Component found in Orphans
# len of vertices = 102586
# Step 1: extracted Soma Mesh = 2.5796215534210205
# Mesh successfully extracted
# Total time = 3.6765143871307373
#
#
# 648518346342793468: Dendrite-0
# Component found in Orphans
# len of vertices = 22948
# Step 1: extracted Soma Mesh = 1.8533849716186523
# Mesh successfully extracted
# Total time = 2.410994529724121
#
#
# 648518346342793875: Dendrite-0
# Component found in Orphans
# len of vertices = 54789
# Step 1: extracted Soma Mesh = 1.624948263168335
# Mesh successfully extracted
# Total time = 2.33103346824646
#
#
# 648518346342793994: Basal-0
# Component found in Orphans
# len of vertices = 79977
# Step 1: extracted Soma Mesh = 2.0842349529266357
# Mesh successfully extracted
# Total time = 3.3828351497650146
#
#
# 648518346342795557: Dendrite-0
# Component found in Orphans
# len of vertices = 26804
# Step 1: extracted Soma Mesh = 1.2457902431488037
# Mesh successfully extracted
# Total time = 1.8017711639404297
#
#
# 648518346342796517: Dendrite-0
# Component found in Orphans
# len of vertices = 66450
# Step 1: extracted Soma Mesh = 1.9425177574157715
# Mesh successfully extracted
# Total time = 2.6619367599487305
#
#
# 648518346342797159: Dendrite-0
# Component found in Orphans
# len of vertices = 111865
# Step 1: extracted Soma Mesh = 2.721663236618042
# Mesh successfully extracted
# Total time = 3.8286914825439453
#
#
# 648518346342797936: Dendrite-0
# Component found in Orphans
# len of vertices = 46215
# Step 1: extracted Soma Mesh = 1.7081186771392822
# Mesh successfully extracted
# Total time = 2.504620313644409
#
#
# 648518346342798923: Dendrite-0
# Component found in Orphans
# len of vertices = 240203
# Step 1: extracted Soma Mesh = 6.305950164794922
# Mesh successfully extracted
# Total time = 8.328064680099487
#
#
# 648518346342801725: Dendrite-0
# Component found in Orphans
# len of vertices = 26247
# Step 1: extracted Soma Mesh = 2.927719831466675
# Mesh successfully extracted
# Total time = 3.788621187210083
#
#
# 648518346342802113: Dendrite-0
# Component found in Orphans
# len of vertices = 57698
# Step 1: extracted Soma Mesh = 2.5678539276123047
# Mesh successfully extracted
# Total time = 3.2980310916900635
#
#
# 648518346342803184: Dendrite-0
# Component found in Orphans
# len of vertices = 69924
# Step 1: extracted Soma Mesh = 3.0669314861297607
# Mesh successfully extracted
# Total time = 3.7769107818603516
#
#
# 648518346342803480: Dendrite-0
# Component found in Orphans
# len of vertices = 82507
# Step 1: extracted Soma Mesh = 3.0293734073638916
# Mesh successfully extracted
# Total time = 3.8338420391082764
#
#
# 648518346342805371: Dendrite-0
# Component found in Orphans
# len of vertices = 17566
# Step 1: extracted Soma Mesh = 1.0822443962097168
# Mesh successfully extracted
# Total time = 1.4899334907531738
#
#
# 648518346342805497: Dendrite-0
# Component found in Orphans
# len of vertices = 37471
# Step 1: extracted Soma Mesh = 1.6262304782867432
# Mesh successfully extracted
# Total time = 2.243753671646118
#
#
# 648518346342806329: Dendrite-0
# Component found in Orphans
# len of vertices = 126430
# Step 1: extracted Soma Mesh = 6.081274032592773
# Mesh successfully extracted
# Total time = 8.494394540786743
#
#
# 648518346342914599: Dendrite-0
# Component found in Orphans
# len of vertices = 29470
# Step 1: extracted Soma Mesh = 3.268718719482422
# Mesh successfully extracted
# Total time = 4.057950973510742
#
#
# 648518346342919838: Dendrite-0
# Component found in Orphans
# len of vertices = 23138
# Step 1: extracted Soma Mesh = 2.0461790561676025
# Mesh successfully extracted
# Total time = 2.9131858348846436
#
#
# 648518346342921511: Dendrite-0
# Component found in Orphans
# len of vertices = 145457
# Step 1: extracted Soma Mesh = 7.415208101272583
# Mesh successfully extracted
# Total time = 9.53053069114685
#
#
# 648518346344456709: Dendrite-0
# Component found in Orphans
# len of vertices = 14982
# Step 1: extracted Soma Mesh = 2.003037929534912
# Mesh successfully extracted
# Total time = 2.3646132946014404
#
#
# 648518346344517719: Dendrite-0
# Component found in Orphans
# len of vertices = 21579
# Step 1: extracted Soma Mesh = 1.8611705303192139
# Mesh successfully extracted
# Total time = 2.295616865158081
#
#
# 648518346346300372: Dendrite-0
# Component found in Orphans
# len of vertices = 73884
# Step 1: extracted Soma Mesh = 5.0461297035217285
# Mesh successfully extracted
# Total time = 5.705691814422607
#
#
# 648518346346594840: Dendrite-0
# Component found in Orphans
# len of vertices = 17684
# Step 1: extracted Soma Mesh = 1.2274541854858398
# Mesh successfully extracted
# Total time = 1.5895495414733887
#
#
# 648518346346598297: Dendrite-0
# Component found in Orphans
# len of vertices = 15102
# Step 1: extracted Soma Mesh = 1.604339361190796
# Mesh successfully extracted
# Total time = 2.1009297370910645
#
#
# 648518346348198836: Dendrite-0
# Component found in Orphans
# len of vertices = 16687
# Step 1: extracted Soma Mesh = 1.2795755863189697
# Mesh successfully extracted
# Total time = 1.724670648574829
#
#
# 648518346348209958: Dendrite-0
# Component found in Orphans
# len of vertices = 16051
# Step 1: extracted Soma Mesh = 1.6167054176330566
# Mesh successfully extracted
# Total time = 2.0564208030700684
#
#
# 648518346349370583: Dendrite-1
# Component found in Orphans
# len of vertices = 11723
# Step 1: extracted Soma Mesh = 1.5122478008270264
# Mesh successfully extracted
# Total time = 1.8849809169769287
#
#
# 648518346349378034: Dendrite-0
# Component found in Orphans
# len of vertices = 50878
# Step 1: extracted Soma Mesh = 2.899583578109741
# Mesh successfully extracted
# Total time = 3.7222166061401367
#
#
# 648518346349386619: Dendrite-0
# Component found in Orphans
# len of vertices = 15245
# Step 1: extracted Soma Mesh = 1.235543966293335
# Mesh successfully extracted
# Total time = 1.7676422595977783
#
#
# 648518346349468622: Dendrite-0
# Component found in Orphans
# len of vertices = 71055
# Step 1: extracted Soma Mesh = 4.334183216094971
# Mesh successfully extracted
# Total time = 5.954740285873413
#
#
# 648518346349476140: Dendrite-0
# Component found in Orphans
# len of vertices = 72593
# Step 1: extracted Soma Mesh = 11.250245094299316
# Mesh successfully extracted
# Total time = 11.903998613357544
#
#
# 648518346349484055: Dendrite-0
# Component found in Orphans
# len of vertices = 13886
# Step 1: extracted Soma Mesh = 1.9957144260406494
# Mesh successfully extracted
# Total time = 2.577562093734741
#
#
# 648518346349492682: Basal-3
# Component found in Orphans
# len of vertices = 147167
# Step 1: extracted Soma Mesh = 13.101819515228271
# Mesh successfully extracted
# Total time = 17.331174612045288
#
#
# 648518346349497305: Dendrite-0
# Component found in Orphans
# len of vertices = 50075
# Step 1: extracted Soma Mesh = 2.6671576499938965
# Mesh successfully extracted
# Total time = 4.114557266235352
#
#
# 648518346349502209: Dendrite-0
# Component found in Orphans
# len of vertices = 12627
# Step 1: extracted Soma Mesh = 1.027634859085083
# Mesh successfully extracted
# Total time = 1.508866786956787
#
#
# 648518346349504464: Dendrite-0
# Component found in Orphans
# len of vertices = 80042
# Step 1: extracted Soma Mesh = 4.136089086532593
# Mesh successfully extracted
# Total time = 6.418256521224976
#
#
# 648518346349505858: Oblique-1
# Component found in Orphans
# len of vertices = 34042
# Step 1: extracted Soma Mesh = 10.097328186035156
# Mesh successfully extracted
# Total time = 14.001039505004883
#
#
# 648518346349509521: Dendrite-0
# Component found in Orphans
# len of vertices = 38164
# Step 1: extracted Soma Mesh = 3.101057529449463
# Mesh successfully extracted
# Total time = 4.297346591949463
#
#
# 648518346349509533: Dendrite-0
# Component found in Orphans
# len of vertices = 75102
# Step 1: extracted Soma Mesh = 5.330001354217529
# Mesh successfully extracted
# Total time = 7.404623985290527
#
#
# 648518346349509593: Dendrite-0
# Component found in Orphans
# len of vertices = 56953
# Step 1: extracted Soma Mesh = 1.8555278778076172
# Mesh successfully extracted
# Total time = 2.6476974487304688
#
#
# 648518346349511381: Dendrite-0
# Component found in Orphans
# len of vertices = 14140
# Step 1: extracted Soma Mesh = 2.053873062133789
# Mesh successfully extracted
# Total time = 2.5542349815368652
# Total time = 719.8185126781464
