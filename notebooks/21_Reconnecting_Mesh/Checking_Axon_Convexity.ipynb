# %%
import trimesh
import numpy as np
from collections import Counter
import time
import math
from tqdm import tqdm

# %%
#pick the mesh to process: 
file_location = "./test_meshes/"
file_location = "./"
file_name ="seperated_mesh.off"

# %%
def filter_mesh_significant_outside_pieces(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces, including the main one that are not inside of main mesh

    """

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []

    #find piece with largest size
    max_index = 0
    max_face_len = len(significant_pieces[max_index].faces)

    for i in range(1,len(significant_pieces)):
        if max_face_len < len(significant_pieces[i].faces):
            max_index = i
            max_face_len = len(significant_pieces[i].faces)

    print("max_index = " + str(max_index))
    print("max_face_len = " + str(max_face_len))

    final_mesh_pieces = []

    main_mesh = significant_pieces[max_index]

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        if i != max_index:
            #get a random sample of points
            # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
            idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
            points = mesh.vertices[idx,:]
            
            
            start_time = time.time()
            signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
            print(f"Total time = {time.time() - start_time}")

            outside_percentage = sum(signed_distance < 0)/n_sample_points
            if outside_percentage > 0.9:
                final_mesh_pieces.append(mesh)
                print(f"Mesh piece {i} OUTSIDE mesh")
            else:
                print(f"Mesh piece {i} inside mesh :( ")
                
    return main_mesh,final_mesh_pieces

# %%
#start the global timer
global_timer = time.time()

unfiltered_mesh = trimesh.load_mesh(file_location + file_name)

#setting thresholds
significance_threshold=30 #number of faces needed for pieces to be considered to be kept
n_sample_points = 2 #number of points sampled on the mesh for determination of inside or outside
start_time = time.time()

#the main mesh is the first mesh in the piece
main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
                            significance_threshold=significance_threshold,
                                n_sample_points=n_sample_points)
print(f"Total time for Mesh Cleansing: {time.time() - start_time}")
# Out:
# There were 3902 pieces after mesh split
# There were 378 pieces found after size threshold
# max_index = 0
# max_face_len = 1845336
# Total time = 24.6003897190094
# Mesh piece 1 OUTSIDE mesh
# Total time = 0.15836024284362793
# Mesh piece 2 inside mesh :(
# Total time = 0.18016314506530762
# Mesh piece 3 OUTSIDE mesh
# Total time = 1.0256867408752441
# Mesh piece 4 OUTSIDE mesh
# Total time = 0.29471683502197266
# Mesh piece 5 inside mesh :(
# Total time = 0.2189648151397705
# Mesh piece 6 inside mesh :(
# Total time = 0.22297024726867676
# Mesh piece 7 inside mesh :(
# Total time = 0.26123547554016113
# Mesh piece 8 inside mesh :(
# Total time = 0.32075023651123047
# Mesh piece 9 inside mesh :(
# Total time = 0.21797633171081543
# Mesh piece 10 inside mesh :(
# Total time = 0.25991272926330566
# Mesh piece 11 inside mesh :(
# Total time = 0.5279772281646729
# Mesh piece 12 inside mesh :(
# Total time = 0.4516720771789551
# Mesh piece 13 inside mesh :(
# Total time = 0.32538509368896484
# Mesh piece 14 inside mesh :(
# Total time = 0.4063706398010254
# Mesh piece 15 inside mesh :(
# Total time = 0.2765328884124756
# Mesh piece 16 inside mesh :(
# Total time = 0.38161349296569824
# Mesh piece 17 inside mesh :(
# Total time = 0.3993189334869385
# Mesh piece 18 inside mesh :(
# Total time = 0.3579857349395752
# Mesh piece 19 inside mesh :(
# Total time = 0.4179677963256836
# Mesh piece 20 inside mesh :(
# Total time = 0.4057943820953369
# Mesh piece 21 inside mesh :(
# Total time = 0.31942081451416016
# Mesh piece 22 inside mesh :(
# Total time = 0.3640024662017822
# Mesh piece 23 inside mesh :(
# Total time = 0.3595614433288574
# Mesh piece 24 inside mesh :(
# Total time = 0.35358428955078125
# Mesh piece 25 inside mesh :(
# Total time = 0.39923954010009766
# Mesh piece 26 inside mesh :(
# Total time = 0.40933871269226074
# Mesh piece 27 inside mesh :(
# Total time = 0.5028030872344971
# Mesh piece 28 inside mesh :(
# Total time = 0.5146081447601318
# Mesh piece 29 inside mesh :(
# Total time = 0.48089075088500977
# Mesh piece 30 inside mesh :(
# Total time = 0.433027982711792
# Mesh piece 31 inside mesh :(
# Total time = 0.3202176094055176
# Mesh piece 32 inside mesh :(
# Total time = 0.2901322841644287
# Mesh piece 33 inside mesh :(
# Total time = 0.30575990676879883
# Mesh piece 34 inside mesh :(
# Total time = 0.32982444763183594
# Mesh piece 35 inside mesh :(
# Total time = 0.2575366497039795
# Mesh piece 36 inside mesh :(
# Total time = 0.29153895378112793
# Mesh piece 37 inside mesh :(
# Total time = 0.295443058013916
# Mesh piece 38 inside mesh :(
# Total time = 0.34271740913391113
# Mesh piece 39 inside mesh :(
# Total time = 0.3533604145050049
# Mesh piece 40 inside mesh :(
# Total time = 0.3007545471191406
# Mesh piece 41 inside mesh :(
# Total time = 0.46692776679992676
# Mesh piece 42 inside mesh :(
# Total time = 0.33577442169189453
# Mesh piece 43 inside mesh :(
# Total time = 0.3816859722137451
# Mesh piece 44 inside mesh :(
# Total time = 0.27357959747314453
# Mesh piece 45 inside mesh :(
# Total time = 0.33666372299194336
# Mesh piece 46 inside mesh :(
# Total time = 0.08965921401977539
# Mesh piece 47 OUTSIDE mesh
# Total time = 0.03907632827758789
# Mesh piece 48 OUTSIDE mesh
# Total time = 0.13534808158874512
# Mesh piece 49 OUTSIDE mesh
# Total time = 0.02983379364013672
# Mesh piece 50 OUTSIDE mesh
# Total time = 0.05017542839050293
# Mesh piece 51 OUTSIDE mesh
# Total time = 0.08061504364013672
# Mesh piece 52 OUTSIDE mesh
# Total time = 0.5560996532440186
# Mesh piece 53 OUTSIDE mesh
# Total time = 0.1016845703125
# Mesh piece 54 OUTSIDE mesh
# Total time = 0.4694209098815918
# Mesh piece 55 inside mesh :(
# Total time = 1.1519100666046143
# Mesh piece 56 OUTSIDE mesh
# Total time = 0.2812931537628174
# Mesh piece 57 inside mesh :(
# Total time = 0.4333515167236328
# Mesh piece 58 inside mesh :(
# Total time = 0.48180532455444336
# Mesh piece 59 inside mesh :(
# Total time = 0.4527857303619385
# Mesh piece 60 inside mesh :(
# Total time = 0.42662882804870605
# Mesh piece 61 inside mesh :(
# Total time = 0.43621015548706055
# Mesh piece 62 inside mesh :(
# Total time = 0.16194939613342285
# Mesh piece 63 OUTSIDE mesh
# Total time = 0.07874011993408203
# Mesh piece 64 OUTSIDE mesh
# Total time = 1.0619263648986816
# Mesh piece 65 OUTSIDE mesh
# Total time = 0.5342719554901123
# Mesh piece 66 inside mesh :(
# Total time = 0.511202335357666
# Mesh piece 67 inside mesh :(
# Total time = 0.5922074317932129
# Mesh piece 68 inside mesh :(
# Total time = 0.3444516658782959
# Mesh piece 69 inside mesh :(
# Total time = 0.3644216060638428
# Mesh piece 70 inside mesh :(
# Total time = 0.4059183597564697
# Mesh piece 71 inside mesh :(
# Total time = 0.3768279552459717
# Mesh piece 72 inside mesh :(
# Total time = 0.41065406799316406
# Mesh piece 73 inside mesh :(
# Total time = 0.4013381004333496
# Mesh piece 74 inside mesh :(
# Total time = 0.3667266368865967
# Mesh piece 75 inside mesh :(
# Total time = 0.401461124420166
# Mesh piece 76 inside mesh :(
# Total time = 0.369098424911499
# Mesh piece 77 inside mesh :(
# Total time = 0.3716306686401367
# Mesh piece 78 inside mesh :(
# Total time = 0.37215542793273926
# Mesh piece 79 inside mesh :(
# Total time = 0.35662150382995605
# Mesh piece 80 inside mesh :(
# Total time = 0.38092637062072754
# Mesh piece 81 inside mesh :(
# Total time = 0.3571317195892334
# Mesh piece 82 inside mesh :(
# Total time = 0.36969494819641113
# Mesh piece 83 inside mesh :(
# Total time = 0.35561656951904297
# Mesh piece 84 inside mesh :(
# Total time = 0.3041524887084961
# Mesh piece 85 inside mesh :(
# Total time = 0.30713534355163574
# Mesh piece 86 inside mesh :(
# Total time = 0.3002638816833496
# Mesh piece 87 inside mesh :(
# Total time = 0.3510856628417969
# Mesh piece 88 inside mesh :(
# Total time = 0.17041230201721191
# Mesh piece 89 inside mesh :(
# Total time = 0.16002368927001953
# Mesh piece 90 inside mesh :(
# Total time = 0.10499310493469238
# Mesh piece 91 OUTSIDE mesh
# Total time = 0.05636167526245117
# Mesh piece 92 OUTSIDE mesh
# Total time = 0.01138615608215332
# Mesh piece 93 OUTSIDE mesh
# Total time = 0.019153833389282227
# Mesh piece 94 OUTSIDE mesh
# Total time = 0.026212215423583984
# Mesh piece 95 OUTSIDE mesh
# Total time = 0.015844106674194336
# Mesh piece 96 OUTSIDE mesh
# Total time = 1.0447144508361816
# Mesh piece 97 OUTSIDE mesh
# Total time = 0.5069222450256348
# Mesh piece 98 inside mesh :(
# Total time = 0.510242223739624
# Mesh piece 99 inside mesh :(
# Total time = 0.3724637031555176
# Mesh piece 100 inside mesh :(
# Total time = 0.31921863555908203
# Mesh piece 101 inside mesh :(
# Total time = 0.26151299476623535
# Mesh piece 102 inside mesh :(
# Total time = 0.24164485931396484
# Mesh piece 103 inside mesh :(
# Total time = 0.3403892517089844
# Mesh piece 104 inside mesh :(
# Total time = 0.3351151943206787
# Mesh piece 105 inside mesh :(
# Total time = 0.38758063316345215
# Mesh piece 106 inside mesh :(
# Total time = 0.3024444580078125
# Mesh piece 107 inside mesh :(
# Total time = 0.3580152988433838
# Mesh piece 108 inside mesh :(
# Total time = 0.4323270320892334
# Mesh piece 109 inside mesh :(
# Total time = 0.44219517707824707
# Mesh piece 110 inside mesh :(
# Total time = 0.5677037239074707
# Mesh piece 111 inside mesh :(
# Total time = 0.4311542510986328
# Mesh piece 112 inside mesh :(
# Total time = 0.3933908939361572
# Mesh piece 113 inside mesh :(
# Total time = 0.40637874603271484
# Mesh piece 114 inside mesh :(
# Total time = 0.05126190185546875
# Mesh piece 115 OUTSIDE mesh
# Total time = 0.03000926971435547
# Mesh piece 116 OUTSIDE mesh
# Total time = 0.054308414459228516
# Mesh piece 117 OUTSIDE mesh
# Total time = 0.04353904724121094
# Mesh piece 118 OUTSIDE mesh
# Total time = 0.07373905181884766
# Mesh piece 119 OUTSIDE mesh
# Total time = 0.0980532169342041
# Mesh piece 120 OUTSIDE mesh
# Total time = 0.3369576930999756
# Mesh piece 121 inside mesh :(
# Total time = 0.28803491592407227
# Mesh piece 122 inside mesh :(
# Total time = 0.2795257568359375
# Mesh piece 123 inside mesh :(
# Total time = 0.34398555755615234
# Mesh piece 124 inside mesh :(
# Total time = 0.33968639373779297
# Mesh piece 125 inside mesh :(
# Total time = 0.37192463874816895
# Mesh piece 126 inside mesh :(
# Total time = 0.38149523735046387
# Mesh piece 127 inside mesh :(
# Total time = 0.3891303539276123
# Mesh piece 128 inside mesh :(
# Total time = 0.34435486793518066
# Mesh piece 129 inside mesh :(
# Total time = 0.2913997173309326
# Mesh piece 130 inside mesh :(
# Total time = 0.388744592666626
# Mesh piece 131 inside mesh :(
# Total time = 0.38419508934020996
# Mesh piece 132 inside mesh :(
# Total time = 0.3579087257385254
# Mesh piece 133 inside mesh :(
# Total time = 0.6075751781463623
# Mesh piece 134 inside mesh :(
# Total time = 0.6033058166503906
# Mesh piece 135 inside mesh :(
# Total time = 0.4975771903991699
# Mesh piece 136 inside mesh :(
# Total time = 0.3477346897125244
# Mesh piece 137 inside mesh :(
# Total time = 0.3853447437286377
# Mesh piece 138 inside mesh :(
# Total time = 0.357912540435791
# Mesh piece 139 inside mesh :(
# Total time = 0.4516947269439697
# Mesh piece 140 inside mesh :(
# Total time = 0.5158984661102295
# Mesh piece 141 inside mesh :(
# Total time = 0.5387554168701172
# Mesh piece 142 inside mesh :(
# Total time = 0.6305978298187256
# Mesh piece 143 inside mesh :(
# Total time = 0.02760601043701172
# Mesh piece 144 OUTSIDE mesh
# Total time = 0.370220422744751
# Mesh piece 145 OUTSIDE mesh
# Total time = 0.472275972366333
# Mesh piece 146 inside mesh :(
# Total time = 0.4460744857788086
# Mesh piece 147 inside mesh :(
# Total time = 0.5101423263549805
# Mesh piece 148 inside mesh :(
# Total time = 0.5210506916046143
# Mesh piece 149 inside mesh :(
# Total time = 0.402573823928833
# Mesh piece 150 inside mesh :(
# Total time = 0.5574016571044922
# Mesh piece 151 inside mesh :(
# Total time = 0.6183516979217529
# Mesh piece 152 inside mesh :(
# Total time = 0.6260151863098145
# Mesh piece 153 inside mesh :(
# Total time = 0.6175487041473389
# Mesh piece 154 inside mesh :(
# Total time = 0.5620419979095459
# Mesh piece 155 inside mesh :(
# Total time = 0.6683974266052246
# Mesh piece 156 inside mesh :(
# Total time = 0.5168383121490479
# Mesh piece 157 inside mesh :(
# Total time = 0.6019272804260254
# Mesh piece 158 inside mesh :(
# Total time = 0.613837718963623
# Mesh piece 159 inside mesh :(
# Total time = 0.6036520004272461
# Mesh piece 160 inside mesh :(
# Total time = 0.5774950981140137
# Mesh piece 161 inside mesh :(
# Total time = 0.6018798351287842
# Mesh piece 162 inside mesh :(
# Total time = 0.5819873809814453
# Mesh piece 163 inside mesh :(
# Total time = 0.5755124092102051
# Mesh piece 164 inside mesh :(
# Total time = 0.5690491199493408
# Mesh piece 165 inside mesh :(
# Total time = 0.35828280448913574
# Mesh piece 166 inside mesh :(
# Total time = 0.38487720489501953
# Mesh piece 167 inside mesh :(
# Total time = 0.3536100387573242
# Mesh piece 168 inside mesh :(
# Total time = 0.47223997116088867
# Mesh piece 169 inside mesh :(
# Total time = 0.5456905364990234
# Mesh piece 170 inside mesh :(
# Total time = 0.5278799533843994
# Mesh piece 171 inside mesh :(
# Total time = 0.46908020973205566
# Mesh piece 172 inside mesh :(
# Total time = 0.0023598670959472656
# Mesh piece 173 OUTSIDE mesh
# Total time = 0.5544147491455078
# Mesh piece 174 inside mesh :(
# Total time = 0.44586682319641113
# Mesh piece 175 inside mesh :(
# Total time = 0.45779871940612793
# Mesh piece 176 inside mesh :(
# Total time = 0.436201810836792
# Mesh piece 177 inside mesh :(
# Total time = 0.44843101501464844
# Mesh piece 178 inside mesh :(
# Total time = 0.10027265548706055
# Mesh piece 179 OUTSIDE mesh
# Total time = 0.09412598609924316
# Mesh piece 180 OUTSIDE mesh
# Total time = 0.09893202781677246
# Mesh piece 181 OUTSIDE mesh
# Total time = 0.020157337188720703
# Mesh piece 182 OUTSIDE mesh
# Total time = 0.6315433979034424
# Mesh piece 183 inside mesh :(
# Total time = 0.5906169414520264
# Mesh piece 184 inside mesh :(
# Total time = 0.6010301113128662
# Mesh piece 185 inside mesh :(
# Total time = 0.6052789688110352
# Mesh piece 186 inside mesh :(
# Total time = 0.5709364414215088
# Mesh piece 187 inside mesh :(
# Total time = 0.6193468570709229
# Mesh piece 188 inside mesh :(
# Total time = 0.5716862678527832
# Mesh piece 189 inside mesh :(
# Total time = 0.6177914142608643
# Mesh piece 190 inside mesh :(
# Total time = 0.6033320426940918
# Mesh piece 191 inside mesh :(
# Total time = 0.6554279327392578
# Mesh piece 192 inside mesh :(
# Total time = 0.5680902004241943
# Mesh piece 193 inside mesh :(
# Total time = 0.6314821243286133
# Mesh piece 194 inside mesh :(
# Total time = 0.5881726741790771
# Mesh piece 195 inside mesh :(
# Total time = 0.4583616256713867
# Mesh piece 196 inside mesh :(
# Total time = 0.5397415161132812
# Mesh piece 197 inside mesh :(
# Total time = 0.36640501022338867
# Mesh piece 198 inside mesh :(
# Total time = 0.33248066902160645
# Mesh piece 199 inside mesh :(
# Total time = 0.31165003776550293
# Mesh piece 200 inside mesh :(
# Total time = 0.3149905204772949
# Mesh piece 201 inside mesh :(
# Total time = 0.4197671413421631
# Mesh piece 202 inside mesh :(
# Total time = 0.45655107498168945
# Mesh piece 203 inside mesh :(
# Total time = 0.26234912872314453
# Mesh piece 204 inside mesh :(
# Total time = 1.0863690376281738
# Mesh piece 205 OUTSIDE mesh
# Total time = 0.2613651752471924
# Mesh piece 206 inside mesh :(
# Total time = 0.32029199600219727
# Mesh piece 207 inside mesh :(
# Total time = 0.38885021209716797
# Mesh piece 208 inside mesh :(
# Total time = 0.30466341972351074
# Mesh piece 209 inside mesh :(
# Total time = 0.3903803825378418
# Mesh piece 210 inside mesh :(
# Total time = 0.2402503490447998
# Mesh piece 211 inside mesh :(
# Total time = 0.3257296085357666
# Mesh piece 212 inside mesh :(
# Total time = 0.3094770908355713
# Mesh piece 213 inside mesh :(
# Total time = 1.1309094429016113
# Mesh piece 214 OUTSIDE mesh
# Total time = 0.3742077350616455
# Mesh piece 215 inside mesh :(
# Total time = 0.2509768009185791
# Mesh piece 216 inside mesh :(
# Total time = 0.3588089942932129
# Mesh piece 217 inside mesh :(
# Total time = 0.32085204124450684
# Mesh piece 218 inside mesh :(
# Total time = 0.4908938407897949
# Mesh piece 219 inside mesh :(
# Total time = 0.3535647392272949
# Mesh piece 220 inside mesh :(
# Total time = 0.4315378665924072
# Mesh piece 221 inside mesh :(
# Total time = 0.4445230960845947
# Mesh piece 222 inside mesh :(
# Total time = 0.5123026371002197
# Mesh piece 223 inside mesh :(
# Total time = 0.597830057144165
# Mesh piece 224 inside mesh :(
# Total time = 0.5758111476898193
# Mesh piece 225 inside mesh :(
# Total time = 0.5886218547821045
# Mesh piece 226 inside mesh :(
# Total time = 0.4566051959991455
# Mesh piece 227 inside mesh :(
# Total time = 0.36011624336242676
# Mesh piece 228 inside mesh :(
# Total time = 0.33382105827331543
# Mesh piece 229 inside mesh :(
# Total time = 0.2580840587615967
# Mesh piece 230 inside mesh :(
# Total time = 0.30573344230651855
# Mesh piece 231 inside mesh :(
# Total time = 0.3758525848388672
# Mesh piece 232 inside mesh :(
# Total time = 0.04683852195739746
# Mesh piece 233 OUTSIDE mesh
# Total time = 0.6155619621276855
# Mesh piece 234 inside mesh :(
# Total time = 0.43804097175598145
# Mesh piece 235 inside mesh :(
# Total time = 0.3965744972229004
# Mesh piece 236 inside mesh :(
# Total time = 0.40064072608947754
# Mesh piece 237 inside mesh :(
# Total time = 0.7898452281951904
# Mesh piece 238 inside mesh :(
# Total time = 0.5173931121826172
# Mesh piece 239 inside mesh :(
# Total time = 0.5058155059814453
# Mesh piece 240 inside mesh :(
# Total time = 0.4958231449127197
# Mesh piece 241 inside mesh :(
# Total time = 0.41167545318603516
# Mesh piece 242 inside mesh :(
# Total time = 0.4450368881225586
# Mesh piece 243 inside mesh :(
# Total time = 0.4802083969116211
# Mesh piece 244 inside mesh :(
# Total time = 0.47977375984191895
# Mesh piece 245 inside mesh :(
# Total time = 0.46550893783569336
# Mesh piece 246 inside mesh :(
# Total time = 0.27863574028015137
# Mesh piece 247 OUTSIDE mesh
# Total time = 0.32302165031433105
# Mesh piece 248 OUTSIDE mesh
# Total time = 0.6196193695068359
# Mesh piece 249 inside mesh :(
# Total time = 0.5518419742584229
# Mesh piece 250 inside mesh :(
# Total time = 0.5458531379699707
# Mesh piece 251 inside mesh :(
# Total time = 0.5485422611236572
# Mesh piece 252 inside mesh :(
# Total time = 0.4634220600128174
# Mesh piece 253 inside mesh :(
# Total time = 0.44396352767944336
# Mesh piece 254 inside mesh :(
# Total time = 0.24807262420654297
# Mesh piece 255 inside mesh :(
# Total time = 0.286715030670166
# Mesh piece 256 inside mesh :(
# Total time = 0.27957701683044434
# Mesh piece 257 inside mesh :(
# Total time = 0.328411340713501
# Mesh piece 258 inside mesh :(
# Total time = 0.34267616271972656
# Mesh piece 259 inside mesh :(
# Total time = 0.43068957328796387
# Mesh piece 260 inside mesh :(
# Total time = 0.4426863193511963
# Mesh piece 261 inside mesh :(
# Total time = 0.4590787887573242
# Mesh piece 262 inside mesh :(
# Total time = 0.47046470642089844
# Mesh piece 263 inside mesh :(
# Total time = 0.4252042770385742
# Mesh piece 264 inside mesh :(
# Total time = 0.4526360034942627
# Mesh piece 265 inside mesh :(
# Total time = 0.440079927444458
# Mesh piece 266 inside mesh :(
# Total time = 0.5560204982757568
# Mesh piece 267 inside mesh :(
# Total time = 0.5447885990142822
# Mesh piece 268 inside mesh :(
# Total time = 0.48347902297973633
# Mesh piece 269 inside mesh :(
# Total time = 0.41057467460632324
# Mesh piece 270 inside mesh :(
# Total time = 0.4056222438812256
# Mesh piece 271 inside mesh :(
# Total time = 0.42684364318847656
# Mesh piece 272 inside mesh :(
# Total time = 0.44553351402282715
# Mesh piece 273 inside mesh :(
# Total time = 0.40856361389160156
# Mesh piece 274 inside mesh :(
# Total time = 0.5496129989624023
# Mesh piece 275 inside mesh :(
# Total time = 0.4163093566894531
# Mesh piece 276 inside mesh :(
# Total time = 0.48202943801879883
# Mesh piece 277 inside mesh :(
# Total time = 0.5273818969726562
# Mesh piece 278 inside mesh :(
# Total time = 0.456392765045166
# Mesh piece 279 inside mesh :(
# Total time = 0.47063326835632324
# Mesh piece 280 inside mesh :(
# Total time = 0.44384288787841797
# Mesh piece 281 inside mesh :(
# Total time = 0.4989619255065918
# Mesh piece 282 inside mesh :(
# Total time = 0.435443639755249
# Mesh piece 283 inside mesh :(
# Total time = 0.40354204177856445
# Mesh piece 284 inside mesh :(
# Total time = 0.4717221260070801
# Mesh piece 285 inside mesh :(
# Total time = 0.45100831985473633
# Mesh piece 286 inside mesh :(
# Total time = 0.428006649017334
# Mesh piece 287 inside mesh :(
# Total time = 0.43369054794311523
# Mesh piece 288 OUTSIDE mesh
# Total time = 0.3385927677154541
# Mesh piece 289 OUTSIDE mesh
# Total time = 0.5827035903930664
# Mesh piece 290 inside mesh :(
# Total time = 0.6582512855529785
# Mesh piece 291 inside mesh :(
# Total time = 0.5457508563995361
# Mesh piece 292 inside mesh :(
# Total time = 0.41364073753356934
# Mesh piece 293 inside mesh :(
# Total time = 0.5242769718170166
# Mesh piece 294 inside mesh :(
# Total time = 0.46425843238830566
# Mesh piece 295 inside mesh :(
# Total time = 0.6366398334503174
# Mesh piece 296 inside mesh :(
# Total time = 0.5750155448913574
# Mesh piece 297 inside mesh :(
# Total time = 0.4233837127685547
# Mesh piece 298 inside mesh :(
# Total time = 0.4302811622619629
# Mesh piece 299 inside mesh :(
# Total time = 0.41007137298583984
# Mesh piece 300 inside mesh :(
# Total time = 0.048806190490722656
# Mesh piece 301 OUTSIDE mesh
# Total time = 0.3431224822998047
# Mesh piece 302 inside mesh :(
# Total time = 0.33805370330810547
# Mesh piece 303 inside mesh :(
# Total time = 0.3929147720336914
# Mesh piece 304 inside mesh :(
# Total time = 0.3348722457885742
# Mesh piece 305 inside mesh :(
# Total time = 0.3914151191711426
# Mesh piece 306 inside mesh :(
# Total time = 0.39617133140563965
# Mesh piece 307 inside mesh :(
# Total time = 0.39919161796569824
# Mesh piece 308 inside mesh :(
# Total time = 0.5299620628356934
# Mesh piece 309 inside mesh :(
# Total time = 0.42172670364379883
# Mesh piece 310 inside mesh :(
# Total time = 0.3795766830444336
# Mesh piece 311 inside mesh :(
# Total time = 0.3490903377532959
# Mesh piece 312 inside mesh :(
# Total time = 0.33673667907714844
# Mesh piece 313 inside mesh :(
# Total time = 0.38495969772338867
# Mesh piece 314 inside mesh :(
# Total time = 0.3289206027984619
# Mesh piece 315 inside mesh :(
# Total time = 0.5125548839569092
# Mesh piece 316 inside mesh :(
# Total time = 0.5153779983520508
# Mesh piece 317 inside mesh :(
# Total time = 0.48790669441223145
# Mesh piece 318 inside mesh :(
# Total time = 0.42988061904907227
# Mesh piece 319 inside mesh :(
# Total time = 0.42940378189086914
# Mesh piece 320 inside mesh :(
# Total time = 0.3837101459503174
# Mesh piece 321 inside mesh :(
# Total time = 0.377671480178833
# Mesh piece 322 inside mesh :(
# Total time = 0.40468859672546387
# Mesh piece 323 inside mesh :(
# Total time = 0.39064860343933105
# Mesh piece 324 inside mesh :(
# Total time = 0.38225674629211426
# Mesh piece 325 inside mesh :(
# Total time = 0.3896329402923584
# Mesh piece 326 inside mesh :(
# Total time = 0.4239187240600586
# Mesh piece 327 inside mesh :(
# Total time = 0.4430696964263916
# Mesh piece 328 inside mesh :(
# Total time = 0.5438351631164551
# Mesh piece 329 inside mesh :(
# Total time = 0.5177114009857178
# Mesh piece 330 inside mesh :(
# Total time = 0.16590213775634766
# Mesh piece 331 inside mesh :(
# Total time = 0.4774179458618164
# Mesh piece 332 inside mesh :(
# Total time = 0.5746934413909912
# Mesh piece 333 inside mesh :(
# Total time = 0.6167833805084229
# Mesh piece 334 inside mesh :(
# Total time = 0.5223984718322754
# Mesh piece 335 inside mesh :(
# Total time = 0.48673057556152344
# Mesh piece 336 inside mesh :(
# Total time = 0.4433903694152832
# Mesh piece 337 inside mesh :(
# Total time = 0.5274684429168701
# Mesh piece 338 inside mesh :(
# Total time = 0.46205925941467285
# Mesh piece 339 inside mesh :(
# Total time = 0.41566038131713867
# Mesh piece 340 inside mesh :(
# Total time = 0.47092437744140625
# Mesh piece 341 inside mesh :(
# Total time = 0.45786428451538086
# Mesh piece 342 inside mesh :(
# Total time = 0.4826810359954834
# Mesh piece 343 inside mesh :(
# Total time = 0.41460537910461426
# Mesh piece 344 inside mesh :(
# Total time = 0.5609097480773926
# Mesh piece 345 inside mesh :(
# Total time = 0.5461947917938232
# Mesh piece 346 inside mesh :(
# Total time = 0.44431519508361816
# Mesh piece 347 inside mesh :(
# Total time = 0.45560622215270996
# Mesh piece 348 inside mesh :(
# Total time = 0.5377712249755859
# Mesh piece 349 inside mesh :(
# Total time = 0.5411868095397949
# Mesh piece 350 inside mesh :(
# Total time = 0.5509305000305176
# Mesh piece 351 inside mesh :(
# Total time = 0.547004222869873
# Mesh piece 352 inside mesh :(
# Total time = 0.5049214363098145
# Mesh piece 353 inside mesh :(
# Total time = 0.43610596656799316
# Mesh piece 354 inside mesh :(
# Total time = 0.41794395446777344
# Mesh piece 355 inside mesh :(
# Total time = 0.467043399810791
# Mesh piece 356 inside mesh :(
# Total time = 0.46878600120544434
# Mesh piece 357 inside mesh :(
# Total time = 0.46976399421691895
# Mesh piece 358 inside mesh :(
# Total time = 0.27747535705566406
# Mesh piece 359 inside mesh :(
# Total time = 0.2782869338989258
# Mesh piece 360 inside mesh :(
# Total time = 0.20966267585754395
# Mesh piece 361 inside mesh :(
# Total time = 0.2917468547821045
# Mesh piece 362 inside mesh :(
# Total time = 0.3511686325073242
# Mesh piece 363 inside mesh :(
# Total time = 0.31374430656433105
# Mesh piece 364 inside mesh :(
# Total time = 0.4180781841278076
# Mesh piece 365 inside mesh :(
# Total time = 0.6019659042358398
# Mesh piece 366 inside mesh :(
# Total time = 0.6589541435241699
# Mesh piece 367 inside mesh :(
# Total time = 0.5311441421508789
# Mesh piece 368 inside mesh :(
# Total time = 0.47072386741638184
# Mesh piece 369 inside mesh :(
# Total time = 0.48757076263427734
# Mesh piece 370 inside mesh :(
# Total time = 0.4804344177246094
# Mesh piece 371 inside mesh :(
# Total time = 0.49391770362854004
# Mesh piece 372 inside mesh :(
# Total time = 0.47735595703125
# Mesh piece 373 inside mesh :(
# Total time = 0.5259554386138916
# Mesh piece 374 inside mesh :(
# Total time = 0.458587646484375
# Mesh piece 375 inside mesh :(
# Total time = 0.5202665328979492
# Mesh piece 376 inside mesh :(
# Total time = 0.48317480087280273
# Mesh piece 377 inside mesh :(
# Total time for Mesh Cleansing: 185.97680282592773

# %% [markdown]
# # checking who are axons or not

# %%
child_meshes_adding = main_mesh.copy()

faces_list = (np.ones(len(main_mesh.faces))).astype("int").tolist()

for jj,child_mesh_individual in enumerate(child_meshes):
    child_meshes_adding = child_meshes_adding + child_mesh_individual
    faces_list += (np.ones(len(child_mesh_individual.faces))*(jj+1)).astype("int").tolist()


len(faces_list)
# Out:
# 2199363

# %%
len(child_meshes_adding.faces)
print_trimesh(child_meshes_adding,"./test_meshes/child_and_main_mesh.off")
np.savez("./test_meshes/child_mesh_faces.npz",faces_list=faces_list)

# %%
child_faces = np.load("./test_meshes/child_mesh_faces.npz")
child_faces["faces_list"]

# %%
child_meshes[35].show()

len(child_meshes[35].faces)
child_meshes[42].show()
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <title>trimesh: threejs viewer</title>
#     <meta charset=&quot;utf-8&quot;>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,
# 		   user-scalable=no,
# 		   minimum-scale=1.0,
# 		   maximum-scale=1.0&quot;>
#     <style>
#       body {
#       margin: 0px;
#       overflow: hidden;
#       }
#     </style>
#   </head>
#   <body>
#     <div id=&quot;container&quot;></div>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/three.js/101/three.min.js&quot;></script>
#     <script>THREE.TrackballControls=function(object,domElement){var _this=this;var STATE={NONE:-1,ROTATE:0,ZOOM:1,PAN:2,TOUCH_ROTATE:3,TOUCH_ZOOM_PAN:4};this.object=object;this.domElement=(domElement!==undefined)?domElement:document;this.enabled=true;this.screen={left:0,top:0,width:0,height:0};this.rotateSpeed=1.0;this.zoomSpeed=1.2;this.panSpeed=0.3;this.noRotate=false;this.noZoom=false;this.noPan=false;this.staticMoving=false;this.dynamicDampingFactor=0.2;this.minDistance=0;this.maxDistance=Infinity;this.keys=[65 ,83 ,68 ];this.target=new THREE.Vector3();var EPS=0.000001;var lastPosition=new THREE.Vector3();var _state=STATE.NONE,_prevState=STATE.NONE,_eye=new THREE.Vector3(),_movePrev=new THREE.Vector2(),_moveCurr=new THREE.Vector2(),_lastAxis=new THREE.Vector3(),_lastAngle=0,_zoomStart=new THREE.Vector2(),_zoomEnd=new THREE.Vector2(),_touchZoomDistanceStart=0,_touchZoomDistanceEnd=0,_panStart=new THREE.Vector2(),_panEnd=new THREE.Vector2();this.target0=this.target.clone();this.position0=this.object.position.clone();this.up0=this.object.up.clone();var changeEvent={type:'change'};var startEvent={type:'start'};var endEvent={type:'end'};this.handleResize=function(){if(this.domElement===document){this.screen.left=0;this.screen.top=0;this.screen.width=window.innerWidth;this.screen.height=window.innerHeight;}else{var box=this.domElement.getBoundingClientRect();var d=this.domElement.ownerDocument.documentElement;this.screen.left=box.left+window.pageXOffset-d.clientLeft;this.screen.top=box.top+window.pageYOffset-d.clientTop;this.screen.width=box.width;this.screen.height=box.height;}};var getMouseOnScreen=(function(){var vector=new THREE.Vector2();return function getMouseOnScreen(pageX,pageY){vector.set((pageX-_this.screen.left)/_this.screen.width,(pageY-_this.screen.top)/_this.screen.height);return vector;};}());var getMouseOnCircle=(function(){var vector=new THREE.Vector2();return function getMouseOnCircle(pageX,pageY){vector.set(((pageX-_this.screen.width*0.5-_this.screen.left)/(_this.screen.width*0.5)),((_this.screen.height+2*(_this.screen.top-pageY))/_this.screen.width));return vector;};}());this.rotateCamera=(function(){var axis=new THREE.Vector3(),quaternion=new THREE.Quaternion(),eyeDirection=new THREE.Vector3(),objectUpDirection=new THREE.Vector3(),objectSidewaysDirection=new THREE.Vector3(),moveDirection=new THREE.Vector3(),angle;return function rotateCamera(){moveDirection.set(_moveCurr.x-_movePrev.x,_moveCurr.y-_movePrev.y,0);angle=moveDirection.length();if(angle){_eye.copy(_this.object.position).sub(_this.target);eyeDirection.copy(_eye).normalize();objectUpDirection.copy(_this.object.up).normalize();objectSidewaysDirection.crossVectors(objectUpDirection,eyeDirection).normalize();objectUpDirection.setLength(_moveCurr.y-_movePrev.y);objectSidewaysDirection.setLength(_moveCurr.x-_movePrev.x);moveDirection.copy(objectUpDirection.add(objectSidewaysDirection));axis.crossVectors(moveDirection,_eye).normalize();angle*=_this.rotateSpeed;quaternion.setFromAxisAngle(axis,angle);_eye.applyQuaternion(quaternion);_this.object.up.applyQuaternion(quaternion);_lastAxis.copy(axis);_lastAngle=angle;}else if(!_this.staticMoving&&_lastAngle){_lastAngle*=Math.sqrt(1.0-_this.dynamicDampingFactor);_eye.copy(_this.object.position).sub(_this.target);quaternion.setFromAxisAngle(_lastAxis,_lastAngle);_eye.applyQuaternion(quaternion);_this.object.up.applyQuaternion(quaternion);}
# _movePrev.copy(_moveCurr);};}());this.zoomCamera=function(){var factor;if(_state===STATE.TOUCH_ZOOM_PAN){factor=_touchZoomDistanceStart/_touchZoomDistanceEnd;_touchZoomDistanceStart=_touchZoomDistanceEnd;_eye.multiplyScalar(factor);}else{factor=1.0+(_zoomEnd.y-_zoomStart.y)*_this.zoomSpeed;if(factor!==1.0&&factor>0.0){_eye.multiplyScalar(factor);}
# if(_this.staticMoving){_zoomStart.copy(_zoomEnd);}else{_zoomStart.y+=(_zoomEnd.y-_zoomStart.y)*this.dynamicDampingFactor;}}};this.panCamera=(function(){var mouseChange=new THREE.Vector2(),objectUp=new THREE.Vector3(),pan=new THREE.Vector3();return function panCamera(){mouseChange.copy(_panEnd).sub(_panStart);if(mouseChange.lengthSq()){mouseChange.multiplyScalar(_eye.length()*_this.panSpeed);pan.copy(_eye).cross(_this.object.up).setLength(mouseChange.x);pan.add(objectUp.copy(_this.object.up).setLength(mouseChange.y));_this.object.position.add(pan);_this.target.add(pan);if(_this.staticMoving){_panStart.copy(_panEnd);}else{_panStart.add(mouseChange.subVectors(_panEnd,_panStart).multiplyScalar(_this.dynamicDampingFactor));}}};}());this.checkDistances=function(){if(!_this.noZoom||!_this.noPan){if(_eye.lengthSq()>_this.maxDistance*_this.maxDistance){_this.object.position.addVectors(_this.target,_eye.setLength(_this.maxDistance));_zoomStart.copy(_zoomEnd);}
# if(_eye.lengthSq()<_this.minDistance*_this.minDistance){_this.object.position.addVectors(_this.target,_eye.setLength(_this.minDistance));_zoomStart.copy(_zoomEnd);}}};this.update=function(){_eye.subVectors(_this.object.position,_this.target);if(!_this.noRotate){_this.rotateCamera();}
# if(!_this.noZoom){_this.zoomCamera();}
# if(!_this.noPan){_this.panCamera();}
# _this.object.position.addVectors(_this.target,_eye);_this.checkDistances();_this.object.lookAt(_this.target);if(lastPosition.distanceToSquared(_this.object.position)>EPS){_this.dispatchEvent(changeEvent);lastPosition.copy(_this.object.position);}};this.reset=function(){_state=STATE.NONE;_prevState=STATE.NONE;_this.target.copy(_this.target0);_this.object.position.copy(_this.position0);_this.object.up.copy(_this.up0);_eye.subVectors(_this.object.position,_this.target);_this.object.lookAt(_this.target);_this.dispatchEvent(changeEvent);lastPosition.copy(_this.object.position);};function keydown(event){if(_this.enabled===false)return;window.removeEventListener('keydown',keydown);_prevState=_state;if(_state!==STATE.NONE){return;}else if(event.keyCode===_this.keys[STATE.ROTATE]&&!_this.noRotate){_state=STATE.ROTATE;}else if(event.keyCode===_this.keys[STATE.ZOOM]&&!_this.noZoom){_state=STATE.ZOOM;}else if(event.keyCode===_this.keys[STATE.PAN]&&!_this.noPan){_state=STATE.PAN;}}
# function keyup(event){if(_this.enabled===false)return;_state=_prevState;window.addEventListener('keydown',keydown,false);}
# function mousedown(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();if(_state===STATE.NONE){_state=event.button;}
# if(_state===STATE.ROTATE&&!_this.noRotate){_moveCurr.copy(getMouseOnCircle(event.pageX,event.pageY));_movePrev.copy(_moveCurr);}else if(_state===STATE.ZOOM&&!_this.noZoom){_zoomStart.copy(getMouseOnScreen(event.pageX,event.pageY));_zoomEnd.copy(_zoomStart);}else if(_state===STATE.PAN&&!_this.noPan){_panStart.copy(getMouseOnScreen(event.pageX,event.pageY));_panEnd.copy(_panStart);}
# document.addEventListener('mousemove',mousemove,false);document.addEventListener('mouseup',mouseup,false);_this.dispatchEvent(startEvent);}
# function mousemove(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();if(_state===STATE.ROTATE&&!_this.noRotate){_movePrev.copy(_moveCurr);_moveCurr.copy(getMouseOnCircle(event.pageX,event.pageY));}else if(_state===STATE.ZOOM&&!_this.noZoom){_zoomEnd.copy(getMouseOnScreen(event.pageX,event.pageY));}else if(_state===STATE.PAN&&!_this.noPan){_panEnd.copy(getMouseOnScreen(event.pageX,event.pageY));}}
# function mouseup(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();_state=STATE.NONE;document.removeE

# %%
axons_groups = [
    1,5,10,12,17,18,23,24,25,27,28,29,30,34,37,38,39,40,41
]

unsure = [19,20,22,21]

non_axon_group = [
    0,2,3,4,6,7,8,9,11,13,14,15,16,31,33,35,26,42
]

# %%
std_dev_convex = np.std((trimesh.convex.adjacency_projections(submesh)))
if std_dev_convex < classifier_axon_std_dev_threshold:
mean_convex = abs(np.mean(trimesh.convex.adjacency_projections(submesh)))
                #print(f"total_faces  = {mean_convex}")
                if mean_convex > non_dendrite_convex_threshold:

# %%
#classifier_non_dendrite_convex_threshold (float) : Segment must be above this mean convex value to be considered a possible axon, cilia or error(default = 26.5) 
#classifier_axon_std_dev_threshold (float): standard deviation of convex measurements for which axon branches are under this threshold (default = 69.0) 
classifier_axon_std_dev_threshold = 69.0
classifier_non_dendrite_convex_threshold = 12

 
for i,ax in enumerate(axons_groups):
    current_mesh = child_meshes[ax]
    std_convex = np.std((trimesh.convex.adjacency_projections(current_mesh)))
    mean_convex = abs(np.mean(trimesh.convex.adjacency_projections(current_mesh)))
    print(f"{ax}: std_convex  = {std_convex}, mean_convex = {mean_convex}, num_faces = {len(current_mesh.faces)}")
    print(f"         convex_threshold  = {(std_convex < classifier_axon_std_dev_threshold)}, mean_threshold = {(mean_convex > classifier_non_dendrite_convex_threshold)}")
    

#the only ones that don't obey that rule is the really small ones don't follow the mean rule
# Out:
# 1: std_convex  = 48.4240255897393, mean_convex = 12.457645468313999, num_faces = 16458
#          convex_threshold  = True, mean_threshold = True
# 5: std_convex  = 46.294462245796666, mean_convex = 14.455115519208963, num_faces = 5608
#          convex_threshold  = True, mean_threshold = True
# 10: std_convex  = 44.67788976117355, mean_convex = 9.936791841877042, num_faces = 3524
#          convex_threshold  = True, mean_threshold = False
# 12: std_convex  = 46.323662254441125, mean_convex = 13.677988468752154, num_faces = 6432
#          convex_threshold  = True, mean_threshold = True
# 17: std_convex  = 47.01093252049029, mean_convex = 20.807372684576098, num_faces = 348
#          convex_threshold  = True, mean_threshold = True
# 18: std_convex  = 50.00154406836818, mean_convex = 21.707065194176323, num_faces = 268
#          convex_threshold  = True, mean_threshold = True
# 23: std_convex  = 45.899212727683235, mean_convex = 18.58115673362776, num_faces = 1256
#          convex_threshold  = True, mean_threshold = True
# 24: std_convex  = 43.09199996020333, mean_convex = 19.72208623205188, num_faces = 236
#          convex_threshold  = True, mean_threshold = True
# 25: std_convex  = 49.395790426825585, mean_convex = 17.23237266631063, num_faces = 1390
#          convex_threshold  = True, mean_threshold = True
# 27: std_convex  = 45.35374350463766, mean_convex = 34.042839214837585, num_faces = 80
#          convex_threshold  = True, mean_threshold = True
# 28: std_convex  = 45.55588338537956, mean_convex = 16.070557194559868, num_faces = 2672
#          convex_threshold  = True, mean_threshold = True
# 29: std_convex  = 46.89845021529566, mean_convex = 12.045734563839135, num_faces = 5268
#          convex_threshold  = True, mean_threshold = True
# 30: std_convex  = 41.72119582785366, mean_convex = 10.27953615343152, num_faces = 1724
#          convex_threshold  = True, mean_threshold = False
# 34: std_convex  = 48.43237062041458, mean_convex = 15.32878905575372, num_faces = 1456
#          convex_threshold  = True, mean_threshold = True
# 37: std_convex  = 41.73082981830209, mean_convex = 13.171628949378968, num_faces = 968
#          convex_threshold  = True, mean_threshold = True
# 38: std_convex  = 58.32332288301835, mean_convex = 26.876609828069515, num_faces = 170
#          convex_threshold  = True, mean_threshold = True
# 39: std_convex  = 51.25534331763197, mean_convex = 23.07719481420006, num_faces = 260
#          convex_threshold  = True, mean_threshold = True

# %%
for i,ax in enumerate(non_axon_group):
    current_mesh = child_meshes[ax]
    std_convex = np.std((trimesh.convex.adjacency_projections(current_mesh)))
    mean_convex = abs(np.mean(trimesh.convex.adjacency_projections(current_mesh)))
    print(f"{ax}: std_convex  = {std_convex}, mean_convex = {mean_convex}, num_faces = {len(current_mesh.faces)}")
    print(f"         convex_threshold  = {(std_convex < classifier_axon_std_dev_threshold)}, mean_threshold = {(mean_convex > classifier_non_dendrite_convex_threshold)}")
    

#the only ones that don't obey that rule is the really small ones don't follow the mean rule
# Out:
# 0: std_convex  = 44.616039810724146, mean_convex = 10.190789955818586, num_faces = 117018
#          convex_threshold  = True, mean_threshold = False
# 2: std_convex  = 42.11559274636262, mean_convex = 5.168460961383823, num_faces = 32560
#          convex_threshold  = True, mean_threshold = False
# 3: std_convex  = 46.0326559699901, mean_convex = 12.573475117428487, num_faces = 27890
#          convex_threshold  = True, mean_threshold = True
# 4: std_convex  = 44.22952270939172, mean_convex = 10.457317731661124, num_faces = 17314
#          convex_threshold  = True, mean_threshold = False
# 6: std_convex  = 46.30503494275779, mean_convex = 11.354257034586862, num_faces = 16714
#          convex_threshold  = True, mean_threshold = False
# 7: std_convex  = 44.34407522310204, mean_convex = 9.237599731207027, num_faces = 8374
#          convex_threshold  = True, mean_threshold = False
# 8: std_convex  = 45.26274991177284, mean_convex = 11.516189191973027, num_faces = 5420
#          convex_threshold  = True, mean_threshold = False
# 9: std_convex  = 46.802896072439644, mean_convex = 9.423999594664334, num_faces = 19204
#          convex_threshold  = True, mean_threshold = False
# 11: std_convex  = 47.82420664107942, mean_convex = 8.356172370503934, num_faces = 12664
#          convex_threshold  = True, mean_threshold = False
# 13: std_convex  = 47.538318737621296, mean_convex = 11.005530476470593, num_faces = 6132
#          convex_threshold  = True, mean_threshold = False
# 14: std_convex  = 48.25996317255687, mean_convex = 7.418798478540262, num_faces = 8086
#          convex_threshold  = True, mean_threshold = False
# 15: std_convex  = 43.401191886825195, mean_convex = 9.70453561073326, num_faces = 19179
#          convex_threshold  = True, mean_threshold = False
# 16: std_convex  = 46.810585612217984, mean_convex = 13.077864274594, num_faces = 8014
#          convex_threshold  = True, mean_threshold = True
# 31: std_convex  = 40.55016526482917, mean_convex = 8.184369510685508, num_faces = 3786
#          convex_threshold  = True, mean_threshold = False
# 33: std_convex  = 55.309840890696435, mean_convex = 14.7669741371345, num_faces = 606
#          convex_threshold  = True, mean_threshold = True
# 35: std_convex  = 46.843665950581084, mean_convex = 13.518501734214402, num_faces = 632
#          convex_threshold  = True, mean_threshold = True
# 26: std_convex  = 55.402750341707375, mean_convex = 40.74623407242539, num_faces = 54
#          convex_threshold  = True, mean_threshold = True

# %%
"""
Final rule: Will do the easier facet finding for those meshes with 
mean_convex > 12
face_num less than 7000

THIS COULD CHANGE IF SEE THE OTHER DENDRITES ARE NOT BEING ADEQUATELY CONNECTED
"""
# Out:
# '\nFinal rule: Will do the easier facet finding for those meshes with \nmean_convex > 12\nface_num less than 7000\n\nTHIS COULD CHANGE IF SEE THE OTHER DENDRITES ARE NOT BEING ADEQUATELY CONNECTED\n'
