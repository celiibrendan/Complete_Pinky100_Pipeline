# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473583**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473583_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.7752025127410889
# Number of outside child meshes =  24
# Main mesh and outside child meshes make up 0.9537191017099518% of original mesh
#  face length 1021303 using optimized facets with 3 neighbors
# Filtering edges by size finished: 15.450427055358887, facet # = 55301
# Filtering by convexity and getting centers took: 21.996052265167236, facet # = 10420
# Finished facets for main mesh: 39.013429403305054 with facet length = 10420
# Finished 10420 facets for main mesh: 39.01367521286011
# Filtering edges by size finished: 1.8657004833221436, facet # = 6180
# Filtering by convexity and getting centers took: 2.7365963459014893, facet # = 1799
# Filtering edges by size finished: 0.32962608337402344, facet # = 984
# Filtering by convexity and getting centers took: 0.5637903213500977, facet # = 232
# Filtering edges by size finished: 0.02496170997619629, facet # = 66
# Filtering by convexity and getting centers took: 0.05320382118225098, facet # = 17
# Filtering edges by size finished: 0.2822694778442383, facet # = 494
# Filtering by convexity and getting centers took: 0.3077406883239746, facet # = 98
# Filtering edges by size finished: 0.03752303123474121, facet # = 241
# Filtering by convexity and getting centers took: 0.06918764114379883, facet # = 93
# Filtering edges by size finished: 0.020395517349243164, facet # = 114
# Filtering by convexity and getting centers took: 0.06202507019042969, facet # = 34
# Filtering edges by size finished: 0.01568603515625, facet # = 43
# Filtering by convexity and getting centers took: 0.02535414695739746, facet # = 17
# Filtering edges by size finished: 0.09182524681091309, facet # = 109
# Filtering by convexity and getting centers took: 0.09439802169799805, facet # = 34
# Filtering edges by size finished: 0.05917191505432129, facet # = 133
# Filtering by convexity and getting centers took: 0.07341337203979492, facet # = 52
# Filtering edges by size finished: 0.03625845909118652, facet # = 20
# Filtering by convexity and getting centers took: 0.01612687110900879, facet # = 19
# Filtering edges by size finished: 0.04526400566101074, facet # = 120
# Filtering by convexity and getting centers took: 0.03534698486328125, facet # = 33
# Filtering edges by size finished: 0.005133628845214844, facet # = 31
# Filtering by convexity and getting centers took: 0.017676830291748047, facet # = 12
# Filtering edges by size finished: 0.0021085739135742188, facet # = 10
# Filtering by convexity and getting centers took: 0.004307746887207031, facet # = 6
# Filtering edges by size finished: 0.008116483688354492, facet # = 39
# Filtering by convexity and getting centers took: 0.013722658157348633, facet # = 11
# Filtering edges by size finished: 0.002177000045776367, facet # = 11
# Filtering by convexity and getting centers took: 0.003838062286376953, facet # = 8
# Filtering edges by size finished: 0.002398967742919922, facet # = 10
# Filtering by convexity and getting centers took: 0.004996061325073242, facet # = 10
# Filtering edges by size finished: 0.28402185440063477, facet # = 343
# Filtering by convexity and getting centers took: 0.1955547332763672, facet # = 79
# Filtering edges by size finished: 0.020011425018310547, facet # = 115
# Filtering by convexity and getting centers took: 0.034375667572021484, facet # = 40
# Filtering edges by size finished: 0.023540019989013672, facet # = 71
# Filtering by convexity and getting centers took: 0.03131699562072754, facet # = 28
# Filtering edges by size finished: 0.004885435104370117, facet # = 13
# Filtering by convexity and getting centers took: 0.0074956417083740234, facet # = 13
# Filtering edges by size finished: 0.003184080123901367, facet # = 13
# Filtering by convexity and getting centers took: 0.006909847259521484, facet # = 12
# Filtering edges by size finished: 0.028223276138305664, facet # = 112
# Filtering by convexity and getting centers took: 0.04361367225646973, facet # = 15
# Filtering edges by size finished: 0.02913689613342285, facet # = 28
# Filtering by convexity and getting centers took: 0.012547492980957031, facet # = 27
# Filtering edges by size finished: 0.005890369415283203, facet # = 12
# Filtering by convexity and getting centers took: 0.009926080703735352, facet # = 11
# Total time for facets: 46.90924000740051
# Zero faceted faces = []
# Starting Child 0
# 1799 10420
# Done distance matrix: 0.980952262878418
# Done Generating final pairs: 1.0363566875457764
# best_stitch_pair = [1080 1182]
# best_stitch_pair_size = 135037.52773945595
# best_stitch_pair_distance = 1792.7474511088262
# best_stitch_pair_size_ratio = 0.21534949607735376
# Starting Child 1
# 232 10420
# Done distance matrix: 0.17739582061767578
# Done Generating final pairs: 0.21077656745910645
# best_stitch_pair = [ 114 7658]
# best_stitch_pair_size = 725791.1315923162
# best_stitch_pair_distance = 105.83742746168916
# best_stitch_pair_size_ratio = 0.9564778242534697
# Starting Child 2
# 17 10420
# Done distance matrix: 0.011615753173828125
# Child 2 There were no points close enough
# Starting Child 3
# returning y greater max
# skipped by bounding box filter
# Starting Child 4
# returning y greater max
# skipped by bounding box filter
# Starting Child 5
# returning y greater max
# skipped by bounding box filter
# Starting Child 6
# returning y greater max
# skipped by bounding box filter
# Starting Child 7
# returning y greater max
# skipped by bounding box filter
# Starting Child 8
# returning y greater max
# skipped by bounding box filter
# Starting Child 9
# returning y greater max
# skipped by bounding box filter
# Starting Child 10
# returning y greater max
# skipped by bounding box filter
# Starting Child 11
# returning y greater max
# skipped by bounding box filter
# Starting Child 12
# returning y greater max
# skipped by bounding box filter
# Starting Child 13
# 11 10420
# Done distance matrix: 0.006566047668457031
# Child 13 There were no points close enough
# Starting Child 14
# 8 10420
# Done distance matrix: 0.0041658878326416016
# Child 14 There were no points close enough
# Starting Child 15
# returning y greater max
# skipped by bounding box filter
# Starting Child 16
# returning y greater max
# skipped by bounding box filter
# Starting Child 17
# returning y greater max
# skipped by bounding box filter
# Starting Child 18
# returning y greater max
# skipped by bounding box filter
# Starting Child 19
# returning y greater max
# skipped by bounding box filter
# Starting Child 20
# returning y greater max
# skipped by bounding box filter
# Starting Child 21
# 15 10420
# Done distance matrix: 0.00857090950012207
# Child 21 There were no points close enough
# Starting Child 22
# returning y greater max
# skipped by bounding box filter
# Starting Child 23
# returning y greater max
# skipped by bounding box filter
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1080, 1182], 1: [114, 7658]}
# ---Stitching child 0 with pair: [1080, 1182]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 262980, starting edge 2nd facet= 522700,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.7894973754882812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023633480072021484
# returned from stitch mesh: 0.9961097240447998
# Finished stitching child 0 : 1.2542519569396973
# ---Stitching child 1 with pair: [114, 7658]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 214227, starting edge 2nd facet= 536102,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.14984130859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.017579317092895508
# returned from stitch mesh: 0.6585209369659424
# Finished stitching child 1 : 0.7638981342315674
# ***************Finished big stitching iteration: 3.6614439487457275***************
# Starting Child 2
# 17 12447
# Done distance matrix: 0.007472038269042969
# Done Generating final pairs: 0.01109004020690918
# best_stitch_pair = [   12 12318]
# best_stitch_pair_size = 93337.52546032626
# best_stitch_pair_distance = 1759.5179809658546
# best_stitch_pair_size_ratio = 0.5635807229706619
# Starting Child 3
# 98 12447
# Done distance matrix: 0.03965258598327637
# Child 3 There were no points close enough
# Starting Child 4
# 93 12447
# Done distance matrix: 0.22304773330688477
# Child 4 There were no points close enough
# Starting Child 5
# 34 12447
# Done distance matrix: 0.06691217422485352
# Child 5 There were no points close enough
# Starting Child 6
# 17 12447
# Done distance matrix: 0.011493921279907227
# Child 6 There were no points close enough
# Starting Child 7
# 34 12447
# Done distance matrix: 0.0209197998046875
# Child 7 There were no points close enough
# Starting Child 8
# 52 12447
# Done distance matrix: 0.03195619583129883
# Child 8 There were no points close enough
# Starting Child 9
# returning y greater max
# skipped by bounding box filter
# Starting Child 10
# 33 12447
# Done distance matrix: 0.01792454719543457
# Child 10 There were no points close enough
# Starting Child 11
# 12 12447
# Done distance matrix: 0.005884408950805664
# Child 11 There were no points close enough
# Starting Child 12
# 6 12447
# Done distance matrix: 0.002938508987426758
# Child 12 There were no points close enough
# Starting Child 13
# 11 12447
# Done distance matrix: 0.005310535430908203
# Done Generating final pairs: 0.008661508560180664
# best_stitch_pair = [    8 11483]
# best_stitch_pair_size = 191494.58947884687
# best_stitch_pair_distance = 594.2145712913541
# best_stitch_pair_size_ratio = 0.3134854869708606
# Starting Child 14
# 8 12447
# Done distance matrix: 0.004143238067626953
# Done Generating final pairs: 0.006468534469604492
# best_stitch_pair = [    7 11483]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1812.300653041626
# best_stitch_pair_size_ratio = 0.0
# Starting Child 15
# 10 12447
# Done distance matrix: 0.0050623416900634766
# Child 15 There were no points close enough
# Starting Child 16
# 79 12447
# Done distance matrix: 0.035268545150756836
# Done Generating final pairs: 0.048653364181518555
# best_stitch_pair = [    0 12358]
# best_stitch_pair_size = 812224.889335514
# best_stitch_pair_distance = 549.9480667544022
# best_stitch_pair_size_ratio = 0.8628353124111687
# Starting Child 17
# 40 12447
# Done distance matrix: 0.0182492733001709
# Child 17 There were no points close enough
# Starting Child 18
# returning y greater max
# skipped by bounding box filter
# Starting Child 19
# returning y greater max
# skipped by bounding box filter
# Starting Child 20
# returning y greater max
# skipped by bounding box filter
# Starting Child 21
# 15 12447
# Done distance matrix: 0.0075168609619140625
# Done Generating final pairs: 0.010049819946289062
# best_stitch_pair = [    1 12127]
# best_stitch_pair_size = 51779.98697099519
# best_stitch_pair_distance = 119.4351264480211
# best_stitch_pair_size_ratio = 0.7814846020245338
# Starting Child 22
# 27 12447
# Done distance matrix: 0.012475967407226562
# Child 22 There were no points close enough
# Starting Child 23
# returning y greater max
# skipped by bounding box filter
# repeat_main_facets = [11483]
# child_mesh_double_indexes = [13, 14]
# min_child = 13, max_ratio = 594.2145712913541
# child_meshes_stitch_facets = {2: [12, 12318], 13: [8, 11483], 16: [0, 12358], 21: [1, 12127]}
# ---Stitching child 2 with pair: [12, 12318]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 535179, starting edge 2nd facet= 537739,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.147125244140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.017625093460083008
# returned from stitch mesh: 0.6017825603485107
# Finished stitching child 2 : 0.6999404430389404
# ---Stitching child 13 with pair: [8, 11483]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 513884, starting edge 2nd facet= 538002,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 2.6702880859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04190516471862793
# returned from stitch mesh: 1.183699607849121
# Finished stitching child 13 : 1.2872765064239502
# ---Stitching child 16 with pair: [0, 12358]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 536118, starting edge 2nd facet= 538228,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 36
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 15
# About to add faces
# Finished adding faces: 7.748603820800781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.006280660629272461
# returned from stitch mesh: 0.5104126930236816
# Finished stitching child 16 : 0.6086456775665283
# ---Stitching child 21 with pair: [1, 12127]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 518876, starting edge 2nd facet= 540136,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.014795780181884766
# returned from stitch mesh: 0.7393741607666016
# Finished stitching child 21 : 0.8242802619934082
# ***************Finished big stitching iteration: 4.866754055023193***************
# Starting Child 3
# 98 12561
# Done distance matrix: 0.1194605827331543
# Done Generating final pairs: 0.135603666305542
# best_stitch_pair = [   56 12483]
# best_stitch_pair_size = 734803.1919100853
# best_stitch_pair_distance = 1786.1823680688465
# best_stitch_pair_size_ratio = 0.3560118412007278
# Starting Child 4
# 93 12561
# Done distance matrix: 0.036806344985961914
# Child 4 There were no points close enough
# Starting Child 5
# 34 12561
# Done distance matrix: 0.0137939453125
# Child 5 There were no points close enough
# Starting Child 6
# 17 12561
# Done distance matrix: 0.007401466369628906
# Child 6 There were no points close enough
# Starting Child 7
# 34 12561
# Done distance matrix: 0.014012575149536133
# Done Generating final pairs: 0.020872116088867188
# best_stitch_pair = [    6 12483]
# best_stitch_pair_size = 258617.31498669134
# best_stitch_pair_distance = 1214.4423245710375
# best_stitch_pair_size_ratio = 0.3405579827113215
# Starting Child 8
# 52 12561
# Done distance matrix: 0.020797252655029297
# Child 8 There were no points close enough
# Starting Child 9
# returning y greater max
# skipped by bounding box filter
# Starting Child 10
# 33 12561
# Done distance matrix: 0.013627290725708008
# Child 10 There were no points close enough
# Starting Child 11
# 12 12561
# Done distance matrix: 0.005280733108520508
# Child 11 There were no points close enough
# Starting Child 12
# 6 12561
# Done distance matrix: 0.0025260448455810547
# Child 12 There were no points close enough
# Starting Child 14
# 8 12561
# Done distance matrix: 0.0032858848571777344
# Done Generating final pairs: 0.004847288131713867
# best_stitch_pair = [    0 12467]
# best_stitch_pair_size = 43649.15245519997
# best_stitch_pair_distance = 1671.025978829336
# best_stitch_pair_size_ratio = 0.6100418888101611
# Starting Child 15
# 10 12561
# Done distance matrix: 0.004441022872924805
# Child 15 There were no points close enough
# Starting Child 17
# 40 12561
# Done distance matrix: 0.015608072280883789
# Child 17 There were no points close enough
# Starting Child 18
# returning y greater max
# skipped by bounding box filter
# Starting Child 19
# returning y greater max
# skipped by bounding box filter
# Starting Child 20
# returning y greater max
# skipped by bounding box filter
# Starting Child 22
# 27 12561
# Done distance matrix: 0.010565042495727539
# Done Generating final pairs: 0.028192996978759766
# best_stitch_pair = [    0 12483]
# best_stitch_pair_size = 1058569.4699700011
# best_stitch_pair_distance = 1008.46037052335
# best_stitch_pair_size_ratio = 0.2228582706471896
# Starting Child 23
# returning y greater max
# skipped by bounding box filter
# repeat_main_facets = [12483]
# child_mesh_double_indexes = [3, 7, 22]
# min_child = 22, max_ratio = 1008.46037052335
# child_meshes_stitch_facets = {14: [0, 12467], 22: [0, 12483]}
# ---Stitching child 14 with pair: [0, 12467]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 538040, starting edge 2nd facet= 540277,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.52587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02683401107788086
# returned from stitch mesh: 0.854581356048584
# Finished stitching child 14 : 1.0024852752685547
# ---Stitching child 22 with pair: [0, 12483]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 539250, starting edge 2nd facet= 540455,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 9
# About to add faces
# Finished adding faces: 3.0279159545898438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023789405822753906
# returned from stitch mesh: 0.5313374996185303
# Finished stitching child 22 : 0.6405866146087646
# ***************Finished big stitching iteration: 3.0756475925445557***************
# Starting Child 3
# 98 12592
# Done distance matrix: 0.06161808967590332
# Done Generating final pairs: 0.10055947303771973
# best_stitch_pair = [   56 12566]
# best_stitch_pair_size = 1441017.5419416013
# best_stitch_pair_distance = 736.7337443776008
# best_stitch_pair_size_ratio = 0.6026762687228554
# Starting Child 4
# 93 12592
# Done distance matrix: 0.05862283706665039
# Child 4 There were no points close enough
# Starting Child 5
# 34 12592
# Done distance matrix: 0.02399587631225586
# Child 5 There were no points close enough
# Starting Child 6
# 17 12592
# Done distance matrix: 0.010192394256591797
# Child 6 There were no points close enough
# Starting Child 7
# 34 12592
# Done distance matrix: 0.01837301254272461
# Done Generating final pairs: 0.04035592079162598
# best_stitch_pair = [    2 12570]
# best_stitch_pair_size = 465458.81805799063
# best_stitch_pair_distance = 707.3063097923994
# best_stitch_pair_size_ratio = 0.7497773503237655
# Starting Child 8
# 52 12592
# Done distance matrix: 0.027893781661987305
# Child 8 There were no points close enough
# Starting Child 9
# returning y greater max
# skipped by bounding box filter
# Starting Child 10
# 33 12592
# Done distance matrix: 0.017663002014160156
# Child 10 There were no points close enough
# Starting Child 11
# 12 12592
# Done distance matrix: 0.00705409049987793
# Child 11 There were no points close enough
# Starting Child 12
# 6 12592
# Done distance matrix: 0.003445148468017578
# Child 12 There were no points close enough
# Starting Child 15
# 10 12592
# Done distance matrix: 0.005623817443847656
# Child 15 There were no points close enough
# Starting Child 17
# 40 12592
# Done distance matrix: 0.020888328552246094
# Child 17 There were no points close enough
# Starting Child 18
# returning y greater max
# skipped by bounding box filter
# Starting Child 19
# returning y greater max
# skipped by bounding box filter
# Starting Child 20
# returning y greater max
# skipped by bounding box filter
# Starting Child 23
# returning y greater max
# skipped by bounding box filter
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [56, 12566], 7: [2, 12570]}
# ---Stitching child 3 with pair: [56, 12566]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 540476, starting edge 2nd facet= 541259,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 26
# Starting Organizing vertices for side 1
# edge_1_order done, len = 27
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 4.458427429199219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.015232324600219727
# returned from stitch mesh: 0.6624255180358887
# Finished stitching child 3 : 0.75933837890625
# ---Stitching child 7 with pair: [2, 12570]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 540459, starting edge 2nd facet= 543174,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 11
# About to add faces
# Finished adding faces: 5.841255187988281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02841329574584961
# returned from stitch mesh: 1.0416910648345947
# Finished stitching child 7 : 1.1413230895996094
# ***************Finished big stitching iteration: 3.2657310962677***************
# Starting Child 4
# 93 12720
# Done distance matrix: 0.10522174835205078
# Child 4 There were no points close enough
# Starting Child 5
# 34 12720
# Done distance matrix: 0.08197760581970215
# Done Generating final pairs: 0.10229897499084473
# best_stitch_pair = [    0 12688]
# best_stitch_pair_size = 235350.54632774583
# best_stitch_pair_distance = 157.88697032430784
# best_stitch_pair_size_ratio = 0.8780685261116813
# Starting Child 6
# 17 12720
# Done distance matrix: 0.015532493591308594
# Child 6 There were no points close enough
# Starting Child 8
# 52 12720
# Done distance matrix: 0.027966976165771484
# Child 8 There were no points close enough
# Starting Child 9
# 19 12720
# Done distance matrix: 0.012470006942749023
# Done Generating final pairs: 0.016854524612426758
# best_stitch_pair = [    1 12645]
# best_stitch_pair_size = 381386.4422330023
# best_stitch_pair_distance = 1994.826245046514
# best_stitch_pair_size_ratio = 0.19475827823435826
# Starting Child 10
# 33 12720
# Done distance matrix: 0.019440174102783203
# Child 10 There were no points close enough
# Starting Child 11
# 12 12720
# Done distance matrix: 0.007168769836425781
# Child 11 There were no points close enough
# Starting Child 12
# 6 12720
# Done distance matrix: 0.003527402877807617
# Child 12 There were no points close enough
# Starting Child 15
# 10 12720
# Done distance matrix: 0.0056073665618896484
# Child 15 There were no points close enough
# Starting Child 17
# 40 12720
# Done distance matrix: 0.02138495445251465
# Child 17 There were no points close enough
# Starting Child 18
# 28 12720
# Done distance matrix: 0.014895439147949219
# Done Generating final pairs: 0.02846217155456543
# best_stitch_pair = [    5 12645]
# best_stitch_pair_size = 617367.3930312096
# best_stitch_pair_distance = 1337.661268732048
# best_stitch_pair_size_ratio = 0.9340089784454735
# Starting Child 19
# 13 12720
# Done distance matrix: 0.018227338790893555
# Child 19 There were no points close enough
# Starting Child 20
# 12 12720
# Done distance matrix: 0.0075299739837646484
# Child 20 There were no points close enough
# Starting Child 23
# 11 12720
# Done distance matrix: 0.006974220275878906
# Done Generating final pairs: 0.07729220390319824
# best_stitch_pair = [    0 12645]
# best_stitch_pair_size = 640857.7683413137
# best_stitch_pair_distance = 722.6606901052947
# best_stitch_pair_size_ratio = 0.9924606753582812
# repeat_main_facets = [12645]
# child_mesh_double_indexes = [9, 18, 23]
# min_child = 23, max_ratio = 722.6606901052947
# child_meshes_stitch_facets = {5: [0, 12688], 23: [0, 12645]}
# ---Stitching child 5 with pair: [0, 12688]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543085, starting edge 2nd facet= 543489,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 4.315376281738281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.014676094055175781
# returned from stitch mesh: 0.9453184604644775
# Finished stitching child 5 : 1.0457024574279785
# ---Stitching child 23 with pair: [0, 12645]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 541959, starting edge 2nd facet= 543841,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 4.887580871582031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.041069984436035156
# returned from stitch mesh: 1.0074846744537354
# Finished stitching child 23 : 1.1292715072631836
# ***************Finished big stitching iteration: 3.725407361984253***************
# Starting Child 4
# 93 12761
# Done distance matrix: 0.05264735221862793
# Done Generating final pairs: 0.05504894256591797
# best_stitch_pair = [   50 12747]
# best_stitch_pair_size = 94550.88683454275
# best_stitch_pair_distance = 1904.7484637867867
# best_stitch_pair_size_ratio = 0.5918540738853985
# Starting Child 6
# 17 12761
# Done distance matrix: 0.011497974395751953
# Done Generating final pairs: 0.015887737274169922
# best_stitch_pair = [    9 12747]
# best_stitch_pair_size = 45275.47294539648
# best_stitch_pair_distance = 1774.8933555508718
# best_stitch_pair_size_ratio = 0.2879114400236713
# Starting Child 8
# 52 12761
# Done distance matrix: 0.029346942901611328
# Child 8 There were no points close enough
# Starting Child 9
# 19 12761
# Done distance matrix: 0.01155710220336914
# Done Generating final pairs: 0.01892256736755371
# best_stitch_pair = [    1 12757]
# best_stitch_pair_size = 188144.1361223022
# best_stitch_pair_distance = 1238.5862080596012
# best_stitch_pair_size_ratio = 0.49351444477363593
# Starting Child 10
# 33 12761
# Done distance matrix: 0.04090595245361328
# Child 10 There were no points close enough
# Starting Child 11
# 12 12761
# Done distance matrix: 0.007394313812255859
# Child 11 There were no points close enough
# Starting Child 12
# 6 12761
# Done distance matrix: 0.0035779476165771484
# Child 12 There were no points close enough
# Starting Child 15
# 10 12761
# Done distance matrix: 0.005757570266723633
# Done Generating final pairs: 0.011323690414428711
# best_stitch_pair = [    3 12747]
# best_stitch_pair_size = 262294.73024927045
# best_stitch_pair_distance = 1135.6360459508414
# best_stitch_pair_size_ratio = 0.15476841134848524
# Starting Child 17
# 40 12761
# Done distance matrix: 0.016572237014770508
# Child 17 There were no points close enough
# Starting Child 18
# 28 12761
# Done distance matrix: 0.015132665634155273
# Done Generating final pairs: 0.024145126342773438
# best_stitch_pair = [    5 12757]
# best_stitch_pair_size = 424125.0869205095
# best_stitch_pair_distance = 535.6626265487934
# best_stitch_pair_size_ratio = 0.4225177970939082
# Starting Child 19
# 13 12761
# Done distance matrix: 0.007962465286254883
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# 12 12761
# Done distance matrix: 0.006955623626708984
# Child 20 There were no points close enough
# repeat_main_facets = [12747, 12757]
# child_mesh_double_indexes = [4, 6, 15]
# min_child = 15, max_ratio = 1135.6360459508414
# child_mesh_double_indexes = [9, 18]
# min_child = 18, max_ratio = 535.6626265487934
# child_meshes_stitch_facets = {15: [3, 12747], 18: [5, 12757]}
# ---Stitching child 15 with pair: [3, 12747]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543558, starting edge 2nd facet= 543907,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 0
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05961775779724121
# returned from stitch mesh: 0.8050718307495117
# Finished stitching child 15 : 0.8915786743164062
# ---Stitching child 18 with pair: [5, 12757]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543840, starting edge 2nd facet= 544032,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.9087066650390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02286529541015625
# returned from stitch mesh: 0.8957898616790771
# Finished stitching child 18 : 1.124640703201294
# ***************Finished big stitching iteration: 3.1679205894470215***************
# Starting Child 4
# 93 12795
# Done distance matrix: 0.06159520149230957
# Done Generating final pairs: 0.06683754920959473
# best_stitch_pair = [   50 12761]
# best_stitch_pair_size = 283630.380331146
# best_stitch_pair_distance = 757.8835965736857
# best_stitch_pair_size_ratio = 0.2648875326874779
# Starting Child 6
# 17 12795
# Done distance matrix: 0.01243734359741211
# Done Generating final pairs: 0.015460491180419922
# best_stitch_pair = [    9 12733]
# best_stitch_pair_size = 35784.11147807725
# best_stitch_pair_distance = 817.307883008006
# best_stitch_pair_size_ratio = 0.3943951198790849
# Starting Child 8
# 52 12795
# Done distance matrix: 0.06322193145751953
# Child 8 There were no points close enough
# Starting Child 9
# 19 12795
# Done distance matrix: 0.04560351371765137
# Done Generating final pairs: 0.10662245750427246
# best_stitch_pair = [    6 12777]
# best_stitch_pair_size = 1149716.5772295413
# best_stitch_pair_distance = 1146.0286058305378
# best_stitch_pair_size_ratio = 0.5027726410684703
# Starting Child 10
# 33 12795
# Done distance matrix: 0.013946771621704102
# Child 10 There were no points close enough
# Starting Child 11
# 12 12795
# Done distance matrix: 0.007359743118286133
# Child 11 There were no points close enough
# Starting Child 12
# 6 12795
# Done distance matrix: 0.0040705204010009766
# Child 12 There were no points close enough
# Starting Child 17
# 40 12795
# Done distance matrix: 0.024893999099731445
# Child 17 There were no points close enough
# Starting Child 19
# 13 12795
# Done distance matrix: 0.008856773376464844
# Done Generating final pairs: 0.025636911392211914
# best_stitch_pair = [    6 12777]
# best_stitch_pair_size = 850585.9459665387
# best_stitch_pair_distance = 1767.1179021784872
# best_stitch_pair_size_ratio = 0.8255545056920292
# Starting Child 20
# 12 12795
# Done distance matrix: 0.008248090744018555
# Done Generating final pairs: 0.01129293441772461
# best_stitch_pair = [    0 12779]
# best_stitch_pair_size = 261162.89597601275
# best_stitch_pair_distance = 1695.9961820842682
# best_stitch_pair_size_ratio = 0.21507644680624619
# repeat_main_facets = [12777]
# child_mesh_double_indexes = [9, 19]
# min_child = 9, max_ratio = 1146.0286058305378
# child_meshes_stitch_facets = {4: [50, 12761], 6: [9, 12733], 9: [6, 12777], 20: [0, 12779]}
# ---Stitching child 4 with pair: [50, 12761]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543905, starting edge 2nd facet= 544662,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 3.337860107421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02219676971435547
# returned from stitch mesh: 0.8852627277374268
# Finished stitching child 4 : 0.9994955062866211
# ---Stitching child 6 with pair: [9, 12733]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543554, starting edge 2nd facet= 545124,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03290700912475586
# returned from stitch mesh: 0.8558952808380127
# Finished stitching child 6 : 1.0391905307769775
# ---Stitching child 9 with pair: [6, 12777]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 543992, starting edge 2nd facet= 545192,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.984306335449219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.10315227508544922
# returned from stitch mesh: 0.9599959850311279
# Finished stitching child 9 : 1.235767126083374
# ---Stitching child 20 with pair: [0, 12779]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 544022, starting edge 2nd facet= 545252,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.7418136596679688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.006188869476318359
# returned from stitch mesh: 0.7723064422607422
# Finished stitching child 20 : 0.9297828674316406
# ***************Finished big stitching iteration: 6.003127098083496***************
# Starting Child 8
# 52 12928
# Done distance matrix: 0.023671865463256836
# Done Generating final pairs: 0.026479482650756836
# best_stitch_pair = [   34 12885]
# best_stitch_pair_size = 46971.99437742552
# best_stitch_pair_distance = 327.4346204304991
# best_stitch_pair_size_ratio = 0.7507465402684157
# Starting Child 10
# 33 12928
# Done distance matrix: 0.014082908630371094
# Child 10 There were no points close enough
# Starting Child 11
# 12 12928
# Done distance matrix: 0.006119728088378906
# Child 11 There were no points close enough
# Starting Child 12
# 6 12928
# Done distance matrix: 0.0029735565185546875
# Child 12 There were no points close enough
# Starting Child 17
# 40 12928
# Done distance matrix: 0.01648879051208496
# Done Generating final pairs: 0.020258665084838867
# best_stitch_pair = [   32 12833]
# best_stitch_pair_size = 96387.67611075682
# best_stitch_pair_distance = 1681.1649455456634
# best_stitch_pair_size_ratio = 0.770582920730106
# Starting Child 19
# 13 12928
# Done distance matrix: 0.0059931278228759766
# Done Generating final pairs: 0.01665520668029785
# best_stitch_pair = [    6 12912]
# best_stitch_pair_size = 987203.3283603563
# best_stitch_pair_distance = 443.6480516035068
# best_stitch_pair_size_ratio = 0.8938411181724047
# repeat_main_facets = []
# child_meshes_stitch_facets = {8: [34, 12885], 17: [32, 12833], 19: [6, 12912]}
# ---Stitching child 8 with pair: [34, 12885]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 545087, starting edge 2nd facet= 545376,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026569366455078125
# returned from stitch mesh: 0.8185458183288574
# Finished stitching child 8 : 0.915036678314209
# ---Stitching child 17 with pair: [32, 12833]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 544563, starting edge 2nd facet= 546153,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.218650817871094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.015613317489624023
# returned from stitch mesh: 0.9288914203643799
# Finished stitching child 17 : 1.0360310077667236
# ---Stitching child 19 with pair: [6, 12912]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 545191, starting edge 2nd facet= 546231,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 5.9604644775390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01524972915649414
# returned from stitch mesh: 0.7767760753631592
# Finished stitching child 19 : 0.8986754417419434
# ***************Finished big stitching iteration: 4.261748790740967***************
# Starting Child 10
# 33 13027
# Done distance matrix: 0.015480995178222656
# Done Generating final pairs: 0.0186464786529541
# best_stitch_pair = [   12 12957]
# best_stitch_pair_size = 36920.59371911906
# best_stitch_pair_distance = 1765.0959717903972
# best_stitch_pair_size_ratio = 0.3982472859435649
# Starting Child 11
# 12 13027
# Done distance matrix: 0.008381366729736328
# Child 11 There were no points close enough
# Starting Child 12
# 6 13027
# Done distance matrix: 0.00404047966003418
# Child 12 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {10: [12, 12957]}
# ---Stitching child 10 with pair: [12, 12957]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 545509, starting edge 2nd facet= 546662,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027746915817260742
# returned from stitch mesh: 0.9888415336608887
# Finished stitching child 10 : 1.143934726715088
# ***************Finished big stitching iteration: 2.2894275188446045***************
# Starting Child 11
# 12 13058
# Done distance matrix: 0.00862741470336914
# Done Generating final pairs: 0.011823892593383789
# best_stitch_pair = [    9 13027]
# best_stitch_pair_size = 40437.21542388458
# best_stitch_pair_distance = 218.37676515759523
# best_stitch_pair_size_ratio = 0.6551687382826484
# Starting Child 12
# 6 13058
# Done distance matrix: 0.0038175582885742188
# Done Generating final pairs: 0.005544900894165039
# best_stitch_pair = [    3 13027]
# best_stitch_pair_size = 31403.068002563832
# best_stitch_pair_distance = 1533.9397748535866
# best_stitch_pair_size_ratio = 0.9619139101216924
# repeat_main_facets = [13027]
# child_mesh_double_indexes = [11, 12]
# min_child = 11, max_ratio = 218.37676515759523
# child_meshes_stitch_facets = {11: [9, 13027]}
# ---Stitching child 11 with pair: [9, 13027]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 546790, starting edge 2nd facet= 546978,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.017079830169677734
# returned from stitch mesh: 1.077214241027832
# Finished stitching child 11 : 1.2438850402832031
# ***************Finished big stitching iteration: 2.35231614112854***************
# Starting Child 12
# 6 13068
# Done distance matrix: 0.004322052001953125
# Done Generating final pairs: 0.03518509864807129
# best_stitch_pair = [    2 13061]
# best_stitch_pair_size = 26321.080532520034
# best_stitch_pair_distance = 1057.2919224945708
# best_stitch_pair_size_ratio = 0.9432078162556575
# repeat_main_facets = []
# child_meshes_stitch_facets = {12: [2, 13061]}
# ---Stitching child 12 with pair: [2, 13061]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 546992, starting edge 2nd facet= 547009,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.5974044799804688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03953814506530762
# returned from stitch mesh: 1.1868433952331543
# Finished stitching child 12 : 1.2849540710449219
# ***************Finished big stitching iteration: 2.4595749378204346***************
# All children have been processed
# total_stitch_processing_time = 39.14330077171326
# Total time for restitching = 39.14689779281616
# missed_children = []
# Whole stitching function complete: 89.70548892021179
#
#
#
# *****Running Neuron Stitcher for 648518346349475035**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349475035_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.601767301559448
# Number of outside child meshes =  21
# Main mesh and outside child meshes make up 0.9526792821159048% of original mesh
#  face length 3268876 using optimized facets with 3 neighbors
# Filtering edges by size finished: 67.74945425987244, facet # = 167846
# Filtering by convexity and getting centers took: 115.59036993980408, facet # = 37210
# Finished facets for main mesh: 189.62139534950256 with facet length = 37210
# Finished 37210 facets for main mesh: 189.6218180656433
# Filtering edges by size finished: 1.938722848892212, facet # = 3818
# Filtering by convexity and getting centers took: 2.7199532985687256, facet # = 1375
# Filtering edges by size finished: 0.12775397300720215, facet # = 109
# Filtering by convexity and getting centers took: 0.07196593284606934, facet # = 32
# Filtering edges by size finished: 0.5912888050079346, facet # = 1020
# Filtering by convexity and getting centers took: 1.0590472221374512, facet # = 327
# Filtering edges by size finished: 0.007911443710327148, facet # = 29
# Filtering by convexity and getting centers took: 0.014664888381958008, facet # = 20
# Filtering edges by size finished: 0.5851068496704102, facet # = 700
# Filtering by convexity and getting centers took: 0.6167941093444824, facet # = 231
# Filtering edges by size finished: 0.002051115036010742, facet # = 8
# Filtering by convexity and getting centers took: 0.0031070709228515625, facet # = 5
# Filtering edges by size finished: 0.0020933151245117188, facet # = 13
# Filtering by convexity and getting centers took: 0.00528264045715332, facet # = 11
# Filtering edges by size finished: 0.98337721824646, facet # = 2106
# Filtering by convexity and getting centers took: 1.5391936302185059, facet # = 636
# Filtering edges by size finished: 0.4140284061431885, facet # = 1109
# Filtering by convexity and getting centers took: 0.7148780822753906, facet # = 284
# Filtering edges by size finished: 0.5850269794464111, facet # = 1095
# Filtering by convexity and getting centers took: 0.9557349681854248, facet # = 353
# Filtering edges by size finished: 0.02979898452758789, facet # = 22
# Filtering by convexity and getting centers took: 0.01136922836303711, facet # = 10
# Filtering edges by size finished: 0.12121915817260742, facet # = 151
# Filtering by convexity and getting centers took: 0.280958890914917, facet # = 67
# Filtering edges by size finished: 0.0058133602142333984, facet # = 18
# Filtering by convexity and getting centers took: 0.020646333694458008, facet # = 13
# Filtering edges by size finished: 0.005980014801025391, facet # = 22
# Filtering by convexity and getting centers took: 0.011059761047363281, facet # = 3
# Filtering edges by size finished: 0.04721522331237793, facet # = 114
# Filtering by convexity and getting centers took: 0.06724047660827637, facet # = 45
# Filtering edges by size finished: 0.023447513580322266, facet # = 77
# Filtering by convexity and getting centers took: 0.0358281135559082, facet # = 23
# Filtering edges by size finished: 0.002395153045654297, facet # = 12
# Filtering by convexity and getting centers took: 0.0057942867279052734, facet # = 7
# Filtering edges by size finished: 0.005690574645996094, facet # = 24
# Filtering by convexity and getting centers took: 0.011462211608886719, facet # = 12
# Filtering edges by size finished: 0.003242015838623047, facet # = 10
# Filtering by convexity and getting centers took: 0.00788259506225586, facet # = 4
# Filtering edges by size finished: 0.0020067691802978516, facet # = 9
# Filtering by convexity and getting centers took: 0.006280422210693359, facet # = 5
# Filtering edges by size finished: 0.00470423698425293, facet # = 17
# Filtering by convexity and getting centers took: 0.008756160736083984, facet # = 6
# Total time for facets: 203.6884002685547
# Zero faceted faces = []
# Starting Child 0
# 1375 37210
# Done distance matrix: 3.906557321548462
# Done Generating final pairs: 3.9572508335113525
# best_stitch_pair = [ 116 7583]
# best_stitch_pair_size = 35958.96830530766
# best_stitch_pair_distance = 1751.6695320717033
# best_stitch_pair_size_ratio = 0.7070019123628813
# Starting Child 1
# returning x less min
# skipped by bounding box filter
# Starting Child 2
# 327 37210
# Done distance matrix: 0.6405630111694336
# Child 2 There were no points close enough
# Starting Child 3
# 20 37210
# Done distance matrix: 0.0333704948425293
# Child 3 There were no points close enough
# Starting Child 4
# 231 37210
# Done distance matrix: 0.4536769390106201
# Child 4 There were no points close enough
# Starting Child 5
# 5 37210
# Done distance matrix: 0.011687755584716797
# Child 5 There were no points close enough
# Starting Child 6
# 11 37210
# Done distance matrix: 0.017198562622070312
# Child 6 There were no points close enough
# Starting Child 7
# 636 37210
# Done distance matrix: 1.4348571300506592
# Done Generating final pairs: 1.4699742794036865
# best_stitch_pair = [ 265 7206]
# best_stitch_pair_size = 60931.875857846666
# best_stitch_pair_distance = 1592.4133046294428
# best_stitch_pair_size_ratio = 0.7431309461628449
# Starting Child 8
# 284 37210
# Done distance matrix: 0.7228434085845947
# Done Generating final pairs: 0.7902994155883789
# best_stitch_pair = [  157 27858]
# best_stitch_pair_size = 49475.7869713486
# best_stitch_pair_distance = 92.2313470045642
# ...
# Done distance matrix: 1.2493741512298584
# Done Generating final pairs: 1.278205394744873
# best_stitch_pair = [  722 19984]
# best_stitch_pair_size = 215077.06621852252
# best_stitch_pair_distance = 1115.9282897658027
# best_stitch_pair_size_ratio = 0.17404213191783113
# Starting Child 1
# 3088 31530
# Done distance matrix: 3.8617215156555176
# Done Generating final pairs: 3.8842697143554688
# best_stitch_pair = [ 1872 27719]
# best_stitch_pair_size = 912871.8562278833
# best_stitch_pair_distance = 146.28520297329075
# best_stitch_pair_size_ratio = 0.6915177789512404
# Starting Child 2
# 632 31530
# Done distance matrix: 0.9097447395324707
# Done Generating final pairs: 1.1205005645751953
# best_stitch_pair = [  10 2720]
# best_stitch_pair_size = 10222862.99898908
# best_stitch_pair_distance = 397.9129248079701
# best_stitch_pair_size_ratio = 0.9175205129523054
# Starting Child 3
# 259 31530
# Done distance matrix: 0.2945537567138672
# Child 3 There were no points close enough
# Starting Child 4
# 210 31530
# Done distance matrix: 0.25135254859924316
# Child 4 There were no points close enough
# Starting Child 5
# 185 31530
# Done distance matrix: 0.2965993881225586
# Child 5 There were no points close enough
# Starting Child 6
# 344 31530
# Done distance matrix: 0.35535717010498047
# Child 6 There were no points close enough
# Starting Child 7
# 21 31530
# Done distance matrix: 0.027100801467895508
# Child 7 There were no points close enough
# Starting Child 8
# 15 31530
# Done distance matrix: 0.03922104835510254
# Done Generating final pairs: 0.07206153869628906
# best_stitch_pair = [    2 26246]
# best_stitch_pair_size = 368195.3996877526
# best_stitch_pair_distance = 573.3801613596527
# best_stitch_pair_size_ratio = 0.6149528454375757
# Starting Child 9
# 130 31530
# Done distance matrix: 0.13397479057312012
# Child 9 There were no points close enough
# Starting Child 10
# 47 31530
# Done distance matrix: 0.047449350357055664
# Child 10 There were no points close enough
# Starting Child 11
# 32 31530
# Done distance matrix: 0.04003572463989258
# Child 11 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [722, 19984], 1: [1872, 27719], 2: [10, 2720], 8: [2, 26246]}
# ---Stitching child 0 with pair: [722, 19984]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1213262, starting edge 2nd facet= 1449295,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 2.2649765014648438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.007580280303955078
# returned from stitch mesh: 1.1095879077911377
# Finished stitching child 0 : 1.3898532390594482
# ---Stitching child 1 with pair: [1872, 27719]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 812974, starting edge 2nd facet= 1528431,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 4.887580871582031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.048407554626464844
# returned from stitch mesh: 1.6165752410888672
# Finished stitching child 1 : 1.8221676349639893
# ---Stitching child 2 with pair: [10, 2720]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 215181, starting edge 2nd facet= 1614502,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 82
# Starting Organizing vertices for side 1
# edge_1_order done, len = 109
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 27
# About to add faces
# Finished adding faces: 0.03426241874694824
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010624170303344727
# returned from stitch mesh: 2.3266043663024902
# Finished stitching child 2 : 2.5845932960510254
# ---Stitching child 8 with pair: [2, 26246]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 767965, starting edge 2nd facet= 1617981,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.009002208709716797
# returned from stitch mesh: 1.2013585567474365
# Finished stitching child 8 : 1.3658061027526855
# ***************Finished big stitching iteration: 15.788500785827637***************
# Starting Child 3
# 259 36212
# Done distance matrix: 0.36124348640441895
# Child 3 There were no points close enough
# Starting Child 4
# 210 36212
# Done distance matrix: 0.2867114543914795
# Child 4 There were no points close enough
# Starting Child 5
# 185 36212
# Done distance matrix: 0.278576135635376
# Child 5 There were no points close enough
# Starting Child 6
# 344 36212
# Done distance matrix: 0.4558274745941162
# Done Generating final pairs: 0.4927840232849121
# best_stitch_pair = [   42 35833]
# best_stitch_pair_size = 3204579.579960119
# best_stitch_pair_distance = 616.4262862335873
# best_stitch_pair_size_ratio = 0.6282105469325792
# Starting Child 7
# 21 36212
# Done distance matrix: 0.032450199127197266
# Done Generating final pairs: 0.0653066635131836
# best_stitch_pair = [    7 35833]
# best_stitch_pair_size = 3220747.976265929
# best_stitch_pair_distance = 224.40790233657052
# best_stitch_pair_size_ratio = 0.6364255257574876
# Starting Child 9
# 130 36212
# Done distance matrix: 0.22068071365356445
# Child 9 There were no points close enough
# Starting Child 10
# 47 36212
# Done distance matrix: 0.07354474067687988
# Child 10 There were no points close enough
# Starting Child 11
# 32 36212
# Done distance matrix: 0.056006431579589844
# Child 11 There were no points close enough
# repeat_main_facets = [35833]
# child_mesh_double_indexes = [6, 7]
# min_child = 7, max_ratio = 224.40790233657052
# child_meshes_stitch_facets = {7: [7, 35833]}
# ---Stitching child 7 with pair: [7, 35833]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1613050, starting edge 2nd facet= 1618182,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 37
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 8.273124694824219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05683732032775879
# returned from stitch mesh: 1.9221570491790771
# Finished stitching child 7 : 2.191417932510376
# ***************Finished big stitching iteration: 6.399242401123047***************
# Starting Child 3
# 259 36231
# Done distance matrix: 0.35023927688598633
# Child 3 There were no points close enough
# Starting Child 4
# 210 36231
# Done distance matrix: 0.2416999340057373
# Child 4 There were no points close enough
# Starting Child 5
# 185 36231
# Done distance matrix: 0.21239471435546875
# Child 5 There were no points close enough
# Starting Child 6
# 344 36231
# Done distance matrix: 0.4666481018066406
# Done Generating final pairs: 0.5491538047790527
# best_stitch_pair = [   42 36213]
# best_stitch_pair_size = 2364236.737207519
# best_stitch_pair_distance = 395.2693832895957
# best_stitch_pair_size_ratio = 0.9121644539134779
# Starting Child 9
# 130 36231
# Done distance matrix: 0.18355464935302734
# Child 9 There were no points close enough
# Starting Child 10
# 47 36231
# Done distance matrix: 0.056638479232788086
# Child 10 There were no points close enough
# Starting Child 11
# 32 36231
# Done distance matrix: 0.035195112228393555
# Child 11 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [42, 36213]}
# ---Stitching child 6 with pair: [42, 36213]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1618139, starting edge 2nd facet= 1622322,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 36
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 12
# About to add faces
# Finished adding faces: 4.601478576660156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0490267276763916
# returned from stitch mesh: 1.8445825576782227
# Finished stitching child 6 : 2.1202306747436523
# ***************Finished big stitching iteration: 6.000773906707764***************
# Starting Child 3
# 259 36573
# Done distance matrix: 0.32672762870788574
# Child 3 There were no points close enough
# Starting Child 4
# 210 36573
# Done distance matrix: 0.25904130935668945
# Child 4 There were no points close enough
# Starting Child 5
# 185 36573
# Done distance matrix: 0.2263932228088379
# Done Generating final pairs: 0.27083921432495117
# best_stitch_pair = [   39 36347]
# best_stitch_pair_size = 352164.30722884653
# best_stitch_pair_distance = 1969.3170854422503
# best_stitch_pair_size_ratio = 0.32765110922308643
# Starting Child 9
# 130 36573
# Done distance matrix: 0.1774921417236328
# Child 9 There were no points close enough
# Starting Child 10
# 47 36573
# Done distance matrix: 0.06247282028198242
# Done Generating final pairs: 0.08822154998779297
# best_stitch_pair = [   15 36236]
# best_stitch_pair_size = 3027043.913377246
# best_stitch_pair_distance = 1030.7441745397543
# best_stitch_pair_size_ratio = 0.6133444534927401
# Starting Child 11
# 32 36573
# Done distance matrix: 0.048612356185913086
# Done Generating final pairs: 0.06971001625061035
# best_stitch_pair = [   13 36356]
# best_stitch_pair_size = 850658.5448373914
# best_stitch_pair_distance = 1960.1168280838144
# best_stitch_pair_size_ratio = 0.18666205812330935
# repeat_main_facets = []
# child_meshes_stitch_facets = {5: [39, 36347], 10: [15, 36236], 11: [13, 36356]}
# ---Stitching child 5 with pair: [39, 36347]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1620805, starting edge 2nd facet= 1623867,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.047762393951416016
# returned from stitch mesh: 1.6691639423370361
# Finished stitching child 5 : 1.9413447380065918
# ---Stitching child 10 with pair: [15, 36236]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1621168, starting edge 2nd facet= 1625069,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 49
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 20
# About to add faces
# Finished adding faces: 5.817413330078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.033548593521118164
# returned from stitch mesh: 2.105755090713501
# Finished stitching child 10 : 2.4152724742889404
# ---Stitching child 11 with pair: [13, 36356]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1620807, starting edge 2nd facet= 1625532,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00881338119506836
# returned from stitch mesh: 1.1879379749298096
# Finished stitching child 11 : 1.36515474319458
# ***************Finished big stitching iteration: 8.88063907623291***************
# Starting Child 3
# 259 36831
# Done distance matrix: 0.3229405879974365
# Done Generating final pairs: 0.3340637683868408
# best_stitch_pair = [    9 36742]
# best_stitch_pair_size = 160798.86329724966
# best_stitch_pair_distance = 1590.5593605472977
# best_stitch_pair_size_ratio = 0.9746133468481784
# Starting Child 4
# 210 36831
# Done distance matrix: 0.2501218318939209
# Child 4 There were no points close enough
# Starting Child 9
# 130 36831
# Done distance matrix: 0.1995532512664795
# Done Generating final pairs: 0.23614144325256348
# best_stitch_pair = [   12 36583]
# best_stitch_pair_size = 2591376.5879824786
# best_stitch_pair_distance = 1133.0885986576056
# best_stitch_pair_size_ratio = 0.40731808113887563
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [9, 36742], 9: [12, 36583]}
# ---Stitching child 3 with pair: [9, 36742]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1624593, starting edge 2nd facet= 1627918,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06012463569641113
# returned from stitch mesh: 1.6909472942352295
# Finished stitching child 3 : 2.0023553371429443
# ---Stitching child 9 with pair: [12, 36583]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1624048, starting edge 2nd facet= 1630126,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 53
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 7
# About to add faces
# Finished adding faces: 5.626678466796875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05470991134643555
# returned from stitch mesh: 1.7509949207305908
# Finished stitching child 9 : 2.080979824066162
# ***************Finished big stitching iteration: 6.801331996917725***************
# Starting Child 4
# 210 37216
# Done distance matrix: 0.36757516860961914
# Done Generating final pairs: 0.4118201732635498
# best_stitch_pair = [    4 36830]
# best_stitch_pair_size = 2661836.2948122076
# best_stitch_pair_distance = 926.535724796259
# best_stitch_pair_size_ratio = 0.8130244949777413
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [4, 36830]}
# ---Stitching child 4 with pair: [4, 36830]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1629495, starting edge 2nd facet= 1634146,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 46
# Starting Organizing vertices for side 1
# edge_1_order done, len = 33
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 13
# About to add faces
# Finished adding faces: 0.00011539459228515625
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0975499153137207
# returned from stitch mesh: 2.134807825088501
# Finished stitching child 4 : 2.4220991134643555
# ***************Finished big stitching iteration: 5.109460830688477***************
# All children have been processed
# total_stitch_processing_time = 48.98634600639343
# Total time for restitching = 49.01315975189209
# missed_children = []
# Whole stitching function complete: 190.09553933143616
# 6045.021549940109

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
