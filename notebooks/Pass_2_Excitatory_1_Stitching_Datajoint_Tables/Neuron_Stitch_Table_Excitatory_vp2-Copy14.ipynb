# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473830**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1239 pieces after mesh split
# There were 145 pieces found after size threshold
# max_index = 0
# max_face_len = 573979
# Total time for Mesh Cleansing: 101.74171614646912
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9395552499979538% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349475118**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349475118_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 0.15380215644836426
# Number of outside child meshes =  8
# Main mesh and outside child meshes make up 0.7381847964569557% of original mesh
#  face length 97008 using optimized facets with 3 neighbors
# Filtering edges by size finished: 3.5610551834106445, facet # = 5002
# Filtering by convexity and getting centers took: 2.8101978302001953, facet # = 684
# Finished 684 facets for main mesh: 6.514491319656372
# Filtering edges by size finished: 0.005849123001098633, facet # = 3
# Filtering by convexity and getting centers took: 0.0044252872467041016, facet # = 3
# Filtering edges by size finished: 0.001392364501953125, facet # = 2
# Filtering by convexity and getting centers took: 0.003012418746948242, facet # = 2
# Filtering edges by size finished: 0.0032682418823242188, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0038003921508789062, facet # = 2
# Filtering edges by size finished: 0.0028090476989746094, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0034415721893310547, facet # = 2
# Filtering edges by size finished: 0.004021167755126953, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0037767887115478516, facet # = 2
# Filtering edges by size finished: 0.0031452178955078125, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0033538341522216797, facet # = 2
# Filtering edges by size finished: 0.0032525062561035156, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0032944679260253906, facet # = 2
# Filtering edges by size finished: 0.0022923946380615234, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003015756607055664, facet # = 2
# Total time for facets: 6.589621543884277
# Zero faceted faces = []
# Starting Child 0
# 3 684
# Done distance matrix: 0.0009584426879882812
# Done Generating final pairs: 0.006745338439941406
# best_stitch_pair = [  0 570]
# best_stitch_pair_size = 24615.85586697633
# best_stitch_pair_distance = 1759.5916919916542
# best_stitch_pair_size_ratio = 0.789632892623504
# Starting Child 1
# 2 684
# Done distance matrix: 0.0008127689361572266
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# 2 684
# Done distance matrix: 0.0006554126739501953
# Done Generating final pairs: 0.0036818981170654297
# best_stitch_pair = [  0 314]
# best_stitch_pair_size = 37510.4973279368
# best_stitch_pair_distance = 1682.3490001991513
# best_stitch_pair_size_ratio = 0.4075583602768088
# Starting Child 3
# 2 684
# Done distance matrix: 0.0007429122924804688
# Done Generating final pairs: 0.0046422481536865234
# best_stitch_pair = [  1 254]
# best_stitch_pair_size = 27749.445965338964
# best_stitch_pair_distance = 1388.2728979028836
# best_stitch_pair_size_ratio = 0.5595374284125072
# Starting Child 4
# 2 684
# Done distance matrix: 0.0005891323089599609
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 684
# Done distance matrix: 0.0005817413330078125
# Done Generating final pairs: 0.006814479827880859
# best_stitch_pair = [  1 430]
# best_stitch_pair_size = 35768.22078813377
# best_stitch_pair_distance = 661.645921688681
# best_stitch_pair_size_ratio = 0.6117785935159182
# Starting Child 6
# 2 684
# Done distance matrix: 0.0005707740783691406
# Done Generating final pairs: 0.003390789031982422
# best_stitch_pair = [  1 127]
# best_stitch_pair_size = 29379.83210776945
# best_stitch_pair_distance = 1945.447614528882
# best_stitch_pair_size_ratio = 0.8590851171584039
# Starting Child 7
# 2 684
# Done distance matrix: 0.00026226043701171875
# Done Generating final pairs: 0.00426483154296875
# best_stitch_pair = [  1 511]
# best_stitch_pair_size = 21245.09145733095
# best_stitch_pair_distance = 752.9865436289956
# best_stitch_pair_size_ratio = 0.8819238909063772
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 570], 2: [0, 314], 3: [1, 254], 5: [1, 430], 6: [1, 127], 7: [1, 511]}
# ---Stitching child 0 with pair: [0, 570]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 11101, starting edge 2nd facet= 48858,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.7220458984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002335071563720703
# returned from stitch mesh: 0.11938595771789551
# Finished stitching child 0 : 0.1280961036682129
# ---Stitching child 2 with pair: [0, 314]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 23685, starting edge 2nd facet= 48931,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 2
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0037813186645507812
# returned from stitch mesh: 0.3188045024871826
# Finished stitching child 2 : 0.3297111988067627
# ---Stitching child 3 with pair: [1, 254]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 21813, starting edge 2nd facet= 48959,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 3.4332275390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010123729705810547
# returned from stitch mesh: 0.1610243320465088
# Finished stitching child 3 : 0.17352056503295898
# ---Stitching child 5 with pair: [1, 430]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 43509, starting edge 2nd facet= 48987,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 32
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 12
# About to add faces
# Finished adding faces: 6.508827209472656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0024383068084716797
# returned from stitch mesh: 0.15034961700439453
# Finished stitching child 5 : 0.16734075546264648
# ---Stitching child 6 with pair: [1, 127]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 21817, starting edge 2nd facet= 49037,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 3.814697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0007126331329345703
# returned from stitch mesh: 0.16344404220581055
# Finished stitching child 6 : 0.16997098922729492
# ---Stitching child 7 with pair: [1, 511]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 9364, starting edge 2nd facet= 49056,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 5.125999450683594e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0008478164672851562
# returned from stitch mesh: 0.13431262969970703
# Finished stitching child 7 : 0.14119315147399902
# ***************Finished big stitching iteration: 1.2023303508758545***************
# Starting Child 1
# 2 685
# Done distance matrix: 0.0006115436553955078
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 2 685
# Done distance matrix: 0.00015282630920410156
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# 2 685
# Done distance matrix: 0.0011076927185058594
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 2 685
# Done distance matrix: 0.0007188320159912109
# Done Generating final pairs: 0.0054798126220703125
# best_stitch_pair = [  0 278]
# best_stitch_pair_size = 31057.469544934178
# best_stitch_pair_distance = 2382.5893806182885
# best_stitch_pair_size_ratio = 0.906332232787988
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [0, 278]}
# ---Stitching child 4 with pair: [0, 278]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 21562, starting edge 2nd facet= 49094,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 0
# About to add faces
# Finished adding faces: 4.673004150390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0008106231689453125
# returned from stitch mesh: 0.08910179138183594
# Finished stitching child 4 : 0.09857821464538574
# ***************Finished big stitching iteration: 0.11453080177307129***************
# Starting Child 1
# 2 685
# Done distance matrix: 0.0002818107604980469
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# 2 685
# Done distance matrix: 0.00018024444580078125
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 1
# 2 685
# Done distance matrix: 0.00044155120849609375
# Done Generating final pairs: 0.4121978282928467
# best_stitch_pair = [  1 274]
# best_stitch_pair_size = 87352.28571981957
# best_stitch_pair_distance = 3945.3297497373137
# best_stitch_pair_size_ratio = 0.9529693316118448
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [1, 274]}
# ---Stitching child 1 with pair: [1, 274]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 19677, starting edge 2nd facet= 49135,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.3126602172851562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0012552738189697266
# returned from stitch mesh: 0.033814430236816406
# Finished stitching child 1 : 0.03896379470825195
# ***************Finished big stitching iteration: 0.4599111080169678***************
# All children have been processed
# total_stitch_processing_time = 2.0458638668060303
# Total time for restitching = 2.0461509227752686
# missed_children = []
# Whole stitching function complete: 8.906100749969482
#
#
#
# *****Running Neuron Stitcher for 648518346349475132**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2975 pieces after mesh split
# There were 293 pieces found after size threshold
# max_index = 0
# max_face_len = 1690753
# Total time for Mesh Cleansing: 437.293420791626
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9563396310512449% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349478830**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478830_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 3.534437656402588
# Number of outside child meshes =  34
# Main mesh and outside child meshes make up 0.9561101954320697% of original mesh
#  face length 1637887 using optimized facets with 3 neighbors
# Filtering edges by size finished: 37.6143262386322, facet # = 83222
# Filtering by convexity and getting centers took: 50.19064402580261, facet # = 17614
# Finished facets for main mesh: 92.94261479377747 with facet length = 17614
# Finished 17614 facets for main mesh: 92.94300937652588
# Filtering edges by size finished: 0.002271890640258789, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.009543657302856445, facet # = 2
# Filtering edges by size finished: 0.0033025741577148438, facet # = 2
# Filtering by convexity and getting centers took: 0.0027561187744140625, facet # = 2
# Filtering edges by size finished: 2.841796875, facet # = 6967
# Filtering by convexity and getting centers took: 3.5798351764678955, facet # = 2261
# Filtering edges by size finished: 0.14048051834106445, facet # = 741
# Filtering by convexity and getting centers took: 0.2929260730743408, facet # = 243
# Filtering edges by size finished: 0.2592775821685791, facet # = 764
# Filtering by convexity and getting centers took: 0.41116952896118164, facet # = 257
# Filtering edges by size finished: 0.024585962295532227, facet # = 124
# Filtering by convexity and getting centers took: 0.03637957572937012, facet # = 30
# Filtering edges by size finished: 0.45293331146240234, facet # = 830
# Filtering by convexity and getting centers took: 0.47415804862976074, facet # = 257
# Filtering edges by size finished: 0.10422992706298828, facet # = 481
# Filtering by convexity and getting centers took: 0.2927830219268799, facet # = 49
# Filtering edges by size finished: 0.009654998779296875, facet # = 36
# Filtering by convexity and getting centers took: 0.02994704246520996, facet # = 19
# Filtering edges by size finished: 0.0012776851654052734, facet # = 4
# Filtering by convexity and getting centers took: 0.0025701522827148438, facet # = 4
# Filtering edges by size finished: 0.0008389949798583984, facet # = 5
# Filtering by convexity and getting centers took: 0.0027923583984375, facet # = 5
# Filtering edges by size finished: 0.0016870498657226562, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0021886825561523438, facet # = 2
# Filtering edges by size finished: 0.001957416534423828, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002358675003051758, facet # = 2
# Filtering edges by size finished: 0.0018634796142578125, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002313375473022461, facet # = 2
# Filtering edges by size finished: 0.0266721248626709, facet # = 70
# Filtering by convexity and getting centers took: 0.03535890579223633, facet # = 10
# Filtering edges by size finished: 0.07858514785766602, facet # = 187
# Filtering by convexity and getting centers took: 0.09018206596374512, facet # = 19
# Filtering edges by size finished: 0.0032210350036621094, facet # = 5
# Filtering by convexity and getting centers took: 0.0032689571380615234, facet # = 3
# Filtering edges by size finished: 0.005057096481323242, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003371000289916992, facet # = 2
# Filtering edges by size finished: 0.0018405914306640625, facet # = 6
# Filtering by convexity and getting centers took: 0.0035190582275390625, facet # = 3
# Filtering edges by size finished: 0.0025453567504882812, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002511739730834961, facet # = 2
# Filtering edges by size finished: 0.0025720596313476562, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0024862289428710938, facet # = 2
# Filtering edges by size finished: 0.03542470932006836, facet # = 118
# Filtering by convexity and getting centers took: 0.06799197196960449, facet # = 64
# Filtering edges by size finished: 0.023145198822021484, facet # = 94
# Filtering by convexity and getting centers took: 0.0361330509185791, facet # = 36
# Filtering edges by size finished: 0.0016663074493408203, facet # = 2
# Filtering by convexity and getting centers took: 0.0017769336700439453, facet # = 2
# Filtering edges by size finished: 0.0013725757598876953, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017521381378173828, facet # = 2
# Filtering edges by size finished: 0.0016667842864990234, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017685890197753906, facet # = 2
# Filtering edges by size finished: 0.00157928466796875, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017857551574707031, facet # = 2
# Filtering edges by size finished: 0.001161813735961914, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0008358955383300781, facet # = 1
# Filtering edges by size finished: 0.0026373863220214844, facet # = 2
# Filtering by convexity and getting centers took: 0.0013937950134277344, facet # = 2
# Filtering edges by size finished: 0.0014514923095703125, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017421245574951172, facet # = 2
# Filtering edges by size finished: 0.0013475418090820312, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0014140605926513672, facet # = 2
# Filtering edges by size finished: 0.001714944839477539, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018312931060791016, facet # = 2
# Filtering edges by size finished: 0.0018208026885986328, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018482208251953125, facet # = 2
# Filtering edges by size finished: 0.0013773441314697266, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.001712799072265625, facet # = 2
# Total time for facets: 102.64573240280151
# Zero faceted faces = []
# Starting Child 0
# 2 17614
# Done distance matrix: 0.0019211769104003906
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 2 17614
# Done distance matrix: 0.0019083023071289062
# Done Generating final pairs: 0.01834273338317871
# best_stitch_pair = [    1 12615]
# best_stitch_pair_size = 21397.424285591987
# best_stitch_pair_distance = 1830.6006035187215
# best_stitch_pair_size_ratio = 0.970596798541912
# Starting Child 2
# 2261 17614
# Done distance matrix: 2.211090087890625
# Done Generating final pairs: 2.248567581176758
# best_stitch_pair = [1716  407]
# best_stitch_pair_size = 116158.43623664955
# best_stitch_pair_distance = 1555.9532094427752
# best_stitch_pair_size_ratio = 0.2580232985377832
# Starting Child 3
# 243 17614
# Done distance matrix: 0.18644976615905762
# Done Generating final pairs: 0.20391273498535156
# best_stitch_pair = [ 77 747]
# best_stitch_pair_size = 78299.98968714286
# best_stitch_pair_distance = 110.29249426517069
# best_stitch_pair_size_ratio = 0.3937556506704619
# Starting Child 4
# returning x greater max
# skipped by bounding box filter
# Starting Child 5
# returning x less min
# skipped by bounding box filter
# Starting Child 6
# 257 17614
# Done distance matrix: 0.15955328941345215
# Done Generating final pairs: 0.17386245727539062
# best_stitch_pair = [ 179 4734]
# best_stitch_pair_size = 31653.945786101358
# best_stitch_pair_distance = 1438.6061887187045
# best_stitch_pair_size_ratio = 0.4603222172758324
# Starting Child 7
# 49 17614
# Done distance matrix: 0.041008949279785156
# Done Generating final pairs: 0.07516098022460938
# best_stitch_pair = [   15 15060]
# best_stitch_pair_size = 105020.46907611631
# best_stitch_pair_distance = 1895.774855360134
# best_stitch_pair_size_ratio = 0.7328664309161257
# Starting Child 8
# 19 17614
# Done distance matrix: 0.015577316284179688
# Done Generating final pairs: 0.18985676765441895
# best_stitch_pair = [   2 3376]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1209.2630423545868
# best_stitch_pair_size_ratio = 0.0
# Starting Child 9
# 4 17614
# Done distance matrix: 0.003871917724609375
# Done Generating final pairs: 0.2512953281402588
# best_stitch_pair = [   1 3376]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1467.0499788143643
# best_stitch_pair_size_ratio = 0.0
# Starting Child 10
# 5 17614
# Done distance matrix: 0.015741586685180664
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 2 17614
# Done distance matrix: 0.0016169548034667969
# Child 11 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 2 17614
# Done distance matrix: 0.001508474349975586
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 2 17614
# Done distance matrix: 0.001863718032836914
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 10 17614
# Done distance matrix: 0.008971452713012695
# Done Generating final pairs: 0.026381492614746094
# best_stitch_pair = [   6 5368]
# best_stitch_pair_size = 52167.14495263912
# best_stitch_pair_distance = 1786.564712248887
# best_stitch_pair_size_ratio = 0.7440189520598607
# Starting Child 15
# 19 17614
# Done distance matrix: 0.022232532501220703
# Done Generating final pairs: 0.09372401237487793
# best_stitch_pair = [   1 3696]
# best_stitch_pair_size = 77148.30988531095
# best_stitch_pair_distance = 1177.8220502280337
# best_stitch_pair_size_ratio = 0.1957464750081874
# Starting Child 16
# 3 17614
# Done distance matrix: 0.003715038299560547
# Done Generating final pairs: 0.10543990135192871
# best_stitch_pair = [   0 8848]
# best_stitch_pair_size = 223152.4587833064
# best_stitch_pair_distance = 1511.613155454323
# best_stitch_pair_size_ratio = 0.1712696532598348
# Starting Child 17
# 2 17614
# Done distance matrix: 0.0020439624786376953
# Done Generating final pairs: 0.034446001052856445
# best_stitch_pair = [   0 8878]
# best_stitch_pair_size = 40335.46844272116
# best_stitch_pair_distance = 1765.757998482713
# best_stitch_pair_size_ratio = 0.7825927036365035
# Starting Child 18
# 3 17614
# Done distance matrix: 0.0029909610748291016
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# 2 17614
# Done distance matrix: 0.0014753341674804688
# Child 19 There were no points close enough
# Starting Child 20
# 2 17614
# Done distance matrix: 0.0015416145324707031
# Done Generating final pairs: 0.012631416320800781
# best_stitch_pair = [   0 3809]
# best_stitch_pair_size = 17743.2325298102
# best_stitch_pair_distance = 674.8885244495615
# best_stitch_pair_size_ratio = 0.6336406304685579
# Starting Child 21
# 64 17614
# Done distance matrix: 0.04893636703491211
# Done Generating final pairs: 0.09552121162414551
# best_stitch_pair = [  35 8852]
# best_stitch_pair_size = 215051.0518209675
# best_stitch_pair_distance = 1375.6072771694007
# best_stitch_pair_size_ratio = 0.43926843657501635
# Starting Child 22
# returning x greater max
# skipped by bounding box filter
# Starting Child 23
# 2 17614
# Done distance matrix: 0.0014722347259521484
# Done Generating final pairs: 0.012729883193969727
# best_stitch_pair = [   1 3809]
# best_stitch_pair_size = 21227.29479430911
# best_stitch_pair_distance = 1500.1572995645015
# best_stitch_pair_size_ratio = 0.4797466478804208
# Starting Child 24
# 2 17614
# Done distance matrix: 0.003913164138793945
# Done Generating final pairs: 0.04208111763000488
# best_stitch_pair = [   1 3809]
# best_stitch_pair_size = 17743.232529810208
# best_stitch_pair_distance = 1505.2729868508668
# best_stitch_pair_size_ratio = 0.6336406304685576
# Starting Child 25
# 2 17614
# Done distance matrix: 0.0019114017486572266
# Done Generating final pairs: 0.06513762474060059
# best_stitch_pair = [   0 8878]
# best_stitch_pair_size = 31284.501643533313
# best_stitch_pair_distance = 1968.1086292193272
# best_stitch_pair_size_ratio = 0.7666823332391884
# Starting Child 26
# 2 17614
# Done distance matrix: 0.0016570091247558594
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 1 17614
# Done distance matrix: 0.0010077953338623047
# Child 27 There were no points close enough
# Starting Child 28
# 2 17614
# Done distance matrix: 0.0016570091247558594
# Child 28 There were no points close enough
# Starting Child 29
# 2 17614
# Done distance matrix: 0.001867532730102539
# Child 29 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# 2 17614
# Done distance matrix: 0.0019042491912841797
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 31
# 2 17614
# Done distance matrix: 0.0019335746765136719
# Child 31 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 32
# 2 17614
# Done distance matrix: 0.0019464492797851562
# Child 32 There were no points close enough
# Starting Child 33
# 2 17614
# Done distance matrix: 0.0018749237060546875
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [3376, 8878, 3809]
# child_mesh_double_indexes = [8, 9]
# min_child = 8, max_ratio = 1209.2630423545868
# child_mesh_double_indexes = [17, 25]
# min_child = 17, max_ratio = 1765.757998482713
# child_mesh_double_indexes = [20, 23, 24]
# min_child = 20, max_ratio = 674.8885244495615
# child_meshes_stitch_facets = {1: [1, 12615], 2: [1716, 407], 3: [77, 747], 6: [179, 4734], 7: [15, 15060], 8: [2, 3376], 14: [6, 5368], 15: [1, 3696], 16: [0, 8848], 17: [0, 8878], 20: [0, 3809], 21: [35, 8852]}
# ---Stitching child 1 with pair: [1, 12615]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 431664, starting edge 2nd facet= 822203,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.024695396423339844
# returned from stitch mesh: 1.024794340133667
# Finished stitching child 1 : 1.214644432067871
# ---Stitching child 2 with pair: [1716, 407]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 447755, starting edge 2nd facet= 849940,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.5974044799804688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02599477767944336
# returned from stitch mesh: 1.144754409790039
# Finished stitching child 2 : 1.2968716621398926
# ---Stitching child 3 with pair: [77, 747]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 521206, starting edge 2nd facet= 853954,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02522420883178711
# returned from stitch mesh: 1.0679841041564941
# Finished stitching child 3 : 1.2329633235931396
# ---Stitching child 6 with pair: [179, 4734]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 107206, starting edge 2nd facet= 857621,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.743171691894531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06415367126464844
# returned from stitch mesh: 1.396711826324463
# Finished stitching child 6 : 1.5589170455932617
# ---Stitching child 7 with pair: [15, 15060]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 94158, starting edge 2nd facet= 859234,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 3, remainder = 0
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026088237762451172
# returned from stitch mesh: 1.5197498798370361
# Finished stitching child 7 : 1.7179203033447266
# ---Stitching child 8 with pair: [2, 3376]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 546791, starting edge 2nd facet= 860344,
# Starting Organizing vertices for side 0
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_0_order done, len = 464
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 77, remainder = 2
# About to add faces
# Finished adding faces: 0.17512130737304688
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.025479555130004883
# returned from stitch mesh: 3.3751771450042725
# Finished stitching child 8 : 3.5522360801696777
# ---Stitching child 14 with pair: [6, 5368]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 595180, starting edge 2nd facet= 860845,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04484128952026367
# returned from stitch mesh: 1.4847838878631592
# Finished stitching child 14 : 1.712026834487915
# ---Stitching child 15 with pair: [1, 3696]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 169640, starting edge 2nd facet= 861018,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.218650817871094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.036557674407958984
# returned from stitch mesh: 1.4202051162719727
# Finished stitching child 15 : 1.5969877243041992
# ---Stitching child 16 with pair: [0, 8848]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 405502, starting edge 2nd facet= 861920,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 3.981590270996094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03623604774475098
# returned from stitch mesh: 1.6650006771087646
# Finished stitching child 16 : 2.026710271835327
# ---Stitching child 17 with pair: [0, 8878]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 705500, starting edge 2nd facet= 861952,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 32
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 5, remainder = 2
# About to add faces
# Finished adding faces: 5.173683166503906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030164718627929688
# returned from stitch mesh: 1.1099507808685303
# Finished stitching child 17 : 1.366926908493042
# ---Stitching child 20 with pair: [0, 3809]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 771874, starting edge 2nd facet= 861988,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 5
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03180980682373047
# returned from stitch mesh: 1.607013463973999
# Finished stitching child 20 : 1.8434233665466309
# ---Stitching child 21 with pair: [35, 8852]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 711913, starting edge 2nd facet= 862513,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.647804260253906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03667759895324707
# returned from stitch mesh: 1.189310073852539
# Finished stitching child 21 : 1.3475289344787598
# ***************Finished big stitching iteration: 25.62961745262146***************
# Starting Child 0
# 2 20521
# Done distance matrix: 0.0024182796478271484
# Done Generating final pairs: 0.004778146743774414
# best_stitch_pair = [    1 20437]
# best_stitch_pair_size = 17224.67486946455
# best_stitch_pair_distance = 669.3749940265866
# best_stitch_pair_size_ratio = 0.5858964067619673
# Starting Child 4
# 257 20521
# Done distance matrix: 0.24892854690551758
# Done Generating final pairs: 0.2554898262023926
# best_stitch_pair = [  176 20113]
# best_stitch_pair_size = 166973.94569341152
# best_stitch_pair_distance = 668.6861727011141
# best_stitch_pair_size_ratio = 0.5124705677204444
# Starting Child 5
# 30 20521
# Done distance matrix: 0.029929399490356445
# Done Generating final pairs: 0.0496525764465332
# best_stitch_pair = [   10 18456]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1345.2775902898888
# best_stitch_pair_size_ratio = 0.0
# Starting Child 9
# 4 20521
# Done distance matrix: 0.029148340225219727
# Done Generating final pairs: 0.03468036651611328
# best_stitch_pair = [    1 20415]
# best_stitch_pair_size = 104585.22019447913
# best_stitch_pair_distance = 1470.6096418742409
# best_stitch_pair_size_ratio = 0.9035256327671604
# Starting Child 10
# 5 20521
# Done distance matrix: 0.007001638412475586
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 2 20521
# Done distance matrix: 0.0028667449951171875
# Child 11 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 2 20521
# Done distance matrix: 0.002375364303588867
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 2 20521
# Done distance matrix: 0.0020172595977783203
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 3 20521
# Done distance matrix: 0.0030601024627685547
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# 2 20521
# Done distance matrix: 0.0019524097442626953
# Child 19 There were no points close enough
# Starting Child 22
# returning x greater max
# skipped by bounding box filter
# Starting Child 23
# 2 20521
# Done distance matrix: 0.0019683837890625
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 20521
# Done distance matrix: 0.002151966094970703
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# 2 20521
# Done distance matrix: 0.0019676685333251953
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# 2 20521
# Done distance matrix: 0.0019626617431640625
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 1 20521
# Done distance matrix: 0.0009367465972900391
# Child 27 There were no points close enough
# Starting Child 28
# 2 20521
# Done distance matrix: 0.0019605159759521484
# Child 28 There were no points close enough
# Starting Child 29
# 2 20521
# Done distance matrix: 0.0020210742950439453
# Child 29 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# 2 20521
# Done distance matrix: 0.0015571117401123047
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 31
# 2 20521
# Done distance matrix: 0.0014438629150390625
# Child 31 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 32
# 2 20521
# Done distance matrix: 0.001459360122680664
# Child 32 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 33
# 2 20521
# Done distance matrix: 0.0014538764953613281
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1, 20437], 4: [176, 20113], 5: [10, 18456], 9: [1, 20415]}
# ---Stitching child 0 with pair: [1, 20437]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 861815, starting edge 2nd facet= 862627,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 2.6941299438476562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02758312225341797
# returned from stitch mesh: 1.1635892391204834
# Finished stitching child 0 : 1.4730024337768555
# ---Stitching child 4 with pair: [176, 20113]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 856793, starting edge 2nd facet= 863568,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027055025100708008
# returned from stitch mesh: 1.2568998336791992
# Finished stitching child 4 : 1.4449260234832764
# ---Stitching child 5 with pair: [10, 18456]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 827307, starting edge 2nd facet= 866119,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 3.0279159545898438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02714395523071289
# returned from stitch mesh: 1.4997437000274658
# Finished stitching child 5 : 1.711761713027954
# ---Stitching child 9 with pair: [1, 20415]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 860351, starting edge 2nd facet= 866214,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.86102294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004861354827880859
# returned from stitch mesh: 1.3053371906280518
# Finished stitching child 9 : 1.8593707084655762
# ***************Finished big stitching iteration: 8.710677146911621***************
# Starting Child 10
# 5 20806
# Done distance matrix: 0.022945642471313477
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 2 20806
# Done distance matrix: 0.00481104850769043
# Child 11 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 2 20806
# Done distance matrix: 0.0035185813903808594
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 2 20806
# Done distance matrix: 0.003191709518432617
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 3 20806
# Done distance matrix: 0.005221843719482422
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# 2 20806
# Done distance matrix: 0.0029120445251464844
# Child 19 There were no points close enough
# Starting Child 22
# 36 20806
# Done distance matrix: 0.04388093948364258
# Done Generating final pairs: 0.05550885200500488
# best_stitch_pair = [    9 20733]
# best_stitch_pair_size = 296136.46187962254
# best_stitch_pair_distance = 556.3662998389984
# best_stitch_pair_size_ratio = 0.7299056012959322
# Starting Child 23
# 2 20806
# Done distance matrix: 0.002179861068725586
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 20806
# Done distance matrix: 0.0019965171813964844
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# 2 20806
# Done distance matrix: 0.0020439624786376953
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# 2 20806
# Done distance matrix: 0.0021514892578125
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 1 20806
# Done distance matrix: 0.001016378402709961
# Child 27 There were no points close enough
# Starting Child 28
# 2 20806
# Done distance matrix: 0.00220489501953125
# Child 28 There were no points close enough
# Starting Child 29
# 2 20806
# Done distance matrix: 0.002109527587890625
# Child 29 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# 2 20806
# Done distance matrix: 0.0021932125091552734
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 31
# 2 20806
# Done distance matrix: 0.0023539066314697266
# Child 31 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 32
# 2 20806
# Done distance matrix: 0.002559185028076172
# Child 32 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 33
# 2 20806
# Done distance matrix: 0.0020194053649902344
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {22: [9, 20733]}
# ---Stitching child 22 with pair: [9, 20733]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 865011, starting edge 2nd facet= 866441,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.6226043701171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026198863983154297
# returned from stitch mesh: 1.1405434608459473
# Finished stitching child 22 : 1.3970701694488525
# ***************Finished big stitching iteration: 3.0445985794067383***************
# Starting Child 10
# 5 20840
# Done distance matrix: 0.005124807357788086
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 2 20840
# Done distance matrix: 0.002255678176879883
# Child 11 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# 2 20840
# Done distance matrix: 0.0020017623901367188
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 2 20840
# Done distance matrix: 0.0020487308502197266
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 3 20840
# Done distance matrix: 0.003192901611328125
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# 2 20840
# Done distance matrix: 0.0021467208862304688
# Child 19 There were no points close enough
# Starting Child 23
# 2 20840
# Done distance matrix: 0.0020308494567871094
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 20840
# Done distance matrix: 0.001959562301635742
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# 2 20840
# Done distance matrix: 0.0021440982818603516
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# 2 20840
# Done distance matrix: 0.002027750015258789
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 1 20840
# Done distance matrix: 0.0009253025054931641
# Child 27 There were no points close enough
# Starting Child 28
# 2 20840
# Done distance matrix: 0.001978158950805664
# Child 28 There were no points close enough
# Starting Child 29
# 2 20840
# Done distance matrix: 0.0022182464599609375
# Child 29 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# 2 20840
# Done distance matrix: 0.002196788787841797
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 31
# 2 20840
# ...
# 1 42751
# Done distance matrix: 0.001478433609008789
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.0014247894287109375
# Child 40 There were no points close enough
# Starting Child 47
# 2 42751
# Done distance matrix: 0.0030918121337890625
# Done Generating final pairs: 0.0045092105865478516
# best_stitch_pair = [    0 35414]
# best_stitch_pair_size = 39931.008123582345
# best_stitch_pair_distance = 2576.960136614849
# best_stitch_pair_size_ratio = 0.18418220684430597
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0014178752899169922
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.001394510269165039
# Child 75 There were no points close enough
# Starting Child 79
# 2 42751
# Done distance matrix: 0.003032684326171875
# Child 79 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0014417171478271484
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0014023780822753906
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.0013470649719238281
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.00152587890625
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {47: [0, 35414]}
# ---Stitching child 47 with pair: [0, 35414]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1595289, starting edge 2nd facet= 1864320,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.8835067749023438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01091456413269043
# returned from stitch mesh: 1.3864655494689941
# Finished stitching child 47 : 1.5775418281555176
# ***************Finished big stitching iteration: 1.8674988746643066***************
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.0017800331115722656
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.001584768295288086
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.001560211181640625
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0015668869018554688
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0015723705291748047
# Child 75 There were no points close enough
# Starting Child 79
# 2 42751
# Done distance matrix: 0.00428462028503418
# Child 79 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0015723705291748047
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0015730857849121094
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.001607656478881836
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0016903877258300781
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.002568960189819336
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.0024225711822509766
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.002306699752807617
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.002284526824951172
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0022039413452148438
# Child 75 There were no points close enough
# Starting Child 79
# 2 42751
# Done distance matrix: 0.004293203353881836
# Child 79 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0021409988403320312
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0020797252655029297
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.002033710479736328
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0020151138305664062
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.0017995834350585938
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.001726388931274414
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.001608133316040039
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0015456676483154297
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0015261173248291016
# Child 75 There were no points close enough
# Starting Child 79
# 2 42751
# Done distance matrix: 0.003692150115966797
# Done Generating final pairs: 0.005909919738769531
# best_stitch_pair = [    0 30618]
# best_stitch_pair_size = 24334.069882092343
# best_stitch_pair_distance = 4170.612785702165
# best_stitch_pair_size_ratio = 0.3994769817648705
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0016980171203613281
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0016024112701416016
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.001562356948852539
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0021703243255615234
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {79: [0, 30618]}
# ---Stitching child 79 with pair: [0, 30618]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1418591, starting edge 2nd facet= 1864336,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.621246337890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010687112808227539
# returned from stitch mesh: 1.9616646766662598
# Finished stitching child 79 : 2.1916239261627197
# ***************Finished big stitching iteration: 2.573167085647583***************
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.002263784408569336
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.0022821426391601562
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.0019092559814453125
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0018601417541503906
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0019404888153076172
# Child 75 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0019757747650146484
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.001956462860107422
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.002183675765991211
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0017783641815185547
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.0013980865478515625
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.0014040470123291016
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.0012764930725097656
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0012385845184326172
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0012362003326416016
# Child 75 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0013072490692138672
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0012464523315429688
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.0012509822845458984
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0014820098876953125
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.0015833377838134766
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.001615762710571289
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.0014047622680664062
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0015194416046142578
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0014104843139648438
# Child 75 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0016148090362548828
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0015344619750976562
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.0015027523040771484
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0016703605651855469
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 10
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 1 42751
# Done distance matrix: 0.0019207000732421875
# Child 25 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 34
# 1 42751
# Done distance matrix: 0.0021016597747802734
# Child 34 There were no points close enough
# Starting Child 40
# 1 42751
# Done distance matrix: 0.0017642974853515625
# Child 40 There were no points close enough
# Starting Child 52
# 1 42751
# Done distance matrix: 0.0017681121826171875
# Child 52 There were no points close enough
# Starting Child 75
# 1 42751
# Done distance matrix: 0.0017681121826171875
# Child 75 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 89
# 1 42751
# Done distance matrix: 0.0017764568328857422
# Child 89 There were no points close enough
# Starting Child 91
# 1 42751
# Done distance matrix: 0.0017626285552978516
# Child 91 There were no points close enough
# Starting Child 93
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 100
# 1 42751
# Done distance matrix: 0.0017690658569335938
# Child 100 There were no points close enough
# Starting Child 102
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 103
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 105
# 1 42751
# Done distance matrix: 0.0017502307891845703
# Child 105 There were no points close enough
# Starting Child 107
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 255.40973258018494
# Total time for restitching = 255.4194884300232
# missed_children = [89.0, 33.0, 34.0, 100.0, 102.0, 103.0, 40.0, 105.0, 10.0, 75.0, 107.0, 82.0, 52.0, 23.0, 25.0, 91.0, 93.0]
# Whole stitching function complete: 417.66872000694275
# 6243.75598359108

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
