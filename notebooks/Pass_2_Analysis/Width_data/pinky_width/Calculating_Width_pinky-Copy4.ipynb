# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341377360: Dendrite-0
# Component found in Orphans
# len of vertices = 65671
# Step 1: extracted Soma Mesh = 2.3531103134155273
# Mesh successfully extracted
# Total time = 3.173398971557617
#
#
# 648518346341378749: Basal-0
# Component found in Orphans
# len of vertices = 18966
# Step 1: extracted Soma Mesh = 1.3929271697998047
# Mesh successfully extracted
# Total time = 2.339900016784668
#
#
# 648518346341379312: Dendrite-0
# Component found in Orphans
# len of vertices = 46114
# Step 1: extracted Soma Mesh = 2.136636734008789
# Mesh successfully extracted
# Total time = 3.2689614295959473
#
#
# 648518346341379581: Dendrite-0
# Component found in Orphans
# len of vertices = 16450
# Step 1: extracted Soma Mesh = 1.0418686866760254
# Mesh successfully extracted
# Total time = 1.4964072704315186
#
#
# 648518346341379850: Dendrite-0
# Component found in Orphans
# len of vertices = 125653
# Step 1: extracted Soma Mesh = 3.254239320755005
# Mesh successfully extracted
# Total time = 4.428087472915649
#
#
# 648518346341382445: Dendrite-0
# Component found in Orphans
# len of vertices = 19817
# Step 1: extracted Soma Mesh = 1.0030269622802734
# Mesh successfully extracted
# Total time = 1.4009466171264648
#
#
# 648518346341383070: Dendrite-0
# Component found in Orphans
# len of vertices = 17992
# Step 1: extracted Soma Mesh = 2.628415584564209
# Mesh successfully extracted
# Total time = 3.0537965297698975
#
#
# 648518346341384926: Dendrite-0
# Component found in Orphans
# len of vertices = 17286
# Step 1: extracted Soma Mesh = 1.0985350608825684
# Mesh successfully extracted
# Total time = 1.532459020614624
#
#
# 648518346341385375: Dendrite-0
# Component found in Orphans
# len of vertices = 39646
# Step 1: extracted Soma Mesh = 4.2729651927948
# Mesh successfully extracted
# Total time = 5.028615951538086
#
#
# 648518346341391113: Dendrite-0
# Component found in Orphans
# len of vertices = 11579
# Step 1: extracted Soma Mesh = 1.156818151473999
# Mesh successfully extracted
# Total time = 1.5471649169921875
#
#
# 648518346341392485: Dendrite-0
# Component found in Orphans
# len of vertices = 30469
# Step 1: extracted Soma Mesh = 1.7524592876434326
# Mesh successfully extracted
# Total time = 2.2627573013305664
#
#
# 648518346341393145: Dendrite-0
# Component found in Orphans
# len of vertices = 19438
# Step 1: extracted Soma Mesh = 1.275726556777954
# Mesh successfully extracted
# Total time = 1.7224314212799072
#
#
# 648518346341394310: Dendrite-0
# Component found in Orphans
# len of vertices = 20722
# Step 1: extracted Soma Mesh = 1.2846927642822266
# Mesh successfully extracted
# Total time = 1.8643426895141602
#
#
# 648518346341394638: Dendrite-0
# Component found in Orphans
# len of vertices = 64366
# Step 1: extracted Soma Mesh = 2.989079236984253
# Mesh successfully extracted
# Total time = 3.8416411876678467
#
#
# 648518346341396532: Dendrite-0
# Component found in Orphans
# len of vertices = 30719
# Step 1: extracted Soma Mesh = 1.6309783458709717
# Mesh successfully extracted
# Total time = 2.0917513370513916
#
#
# 648518346341397811: Dendrite-0
# Component found in Orphans
# len of vertices = 81406
# Step 1: extracted Soma Mesh = 3.025097608566284
# Mesh successfully extracted
# Total time = 4.665180921554565
#
#
# 648518346341398948: Dendrite-0
# Component found in Orphans
# len of vertices = 19848
# Step 1: extracted Soma Mesh = 1.2476496696472168
# Mesh successfully extracted
# Total time = 1.9421849250793457
#
#
# 648518346341399130: Dendrite-0
# Component found in Orphans
# len of vertices = 91249
# Step 1: extracted Soma Mesh = 2.877304792404175
# Mesh successfully extracted
# Total time = 3.6571085453033447
#
#
# 648518346341400173: Dendrite-0
# Component found in Orphans
# len of vertices = 91711
# Step 1: extracted Soma Mesh = 5.860103130340576
# Mesh successfully extracted
# Total time = 7.139641523361206
#
#
# 648518346341404064: Dendrite-0
# Component found in Orphans
# len of vertices = 43162
# Step 1: extracted Soma Mesh = 4.165999889373779
# Mesh successfully extracted
# Total time = 5.4088311195373535
#
#
# 648518346341404885: Dendrite-0
# Component found in Orphans
# len of vertices = 17491
# Step 1: extracted Soma Mesh = 1.2472026348114014
# Mesh successfully extracted
# Total time = 2.0775699615478516
#
#
# 648518346341405768: Dendrite-0
# Component found in Orphans
# len of vertices = 37427
# Step 1: extracted Soma Mesh = 1.8664464950561523
# Mesh successfully extracted
# Total time = 2.49283504486084
#
#
# 648518346341407162: Dendrite-0
# Component found in Orphans
# len of vertices = 13253
# Step 1: extracted Soma Mesh = 1.4616835117340088
# Mesh successfully extracted
# Total time = 1.9137558937072754
#
#
# 648518346341407729: Dendrite-0
# Component found in Orphans
# len of vertices = 26911
# Step 1: extracted Soma Mesh = 2.1235921382904053
# Mesh successfully extracted
# Total time = 2.7300593852996826
#
#
# 648518346341408348: Dendrite-0
# Component found in Orphans
# len of vertices = 22414
# Step 1: extracted Soma Mesh = 1.5542948246002197
# Mesh successfully extracted
# Total time = 2.201927423477173
#
#
# 648518346341409408: Dendrite-0
# Component found in Orphans
# len of vertices = 24985
# Step 1: extracted Soma Mesh = 1.4750213623046875
# Mesh successfully extracted
# Total time = 1.9975018501281738
#
#
# 648518346341409969: Dendrite-0
# Component found in Orphans
# len of vertices = 24301
# Step 1: extracted Soma Mesh = 2.5048024654388428
# Mesh successfully extracted
# Total time = 3.0234289169311523
#
#
# 648518346341410336: Dendrite-0
# Component found in Orphans
# len of vertices = 11324
# Step 1: extracted Soma Mesh = 1.0965907573699951
# Mesh successfully extracted
# Total time = 1.4849119186401367
#
#
# 648518346341410780: Dendrite-0
# Component found in Orphans
# len of vertices = 46227
# Step 1: extracted Soma Mesh = 2.651996374130249
# Mesh successfully extracted
# Total time = 3.354079246520996
#
#
# 648518346341413745: Dendrite-0
# Component found in Orphans
# len of vertices = 15979
# Step 1: extracted Soma Mesh = 1.2848598957061768
# Mesh successfully extracted
# Total time = 1.7700965404510498
#
#
# 648518346341413929: Dendrite-0
# Component found in Orphans
# len of vertices = 79154
# Step 1: extracted Soma Mesh = 3.450141191482544
# Mesh successfully extracted
# Total time = 4.309133052825928
#
#
# 648518346342790310: Dendrite-0
# Component found in Orphans
# len of vertices = 12544
# Step 1: extracted Soma Mesh = 1.6207246780395508
# Mesh successfully extracted
# Total time = 1.9919912815093994
#
#
# 648518346342790990: Dendrite-0
# Component found in Orphans
# len of vertices = 40469
# Step 1: extracted Soma Mesh = 1.7352190017700195
# Mesh successfully extracted
# Total time = 2.448112964630127
#
#
# 648518346342791340: Dendrite-0
# Component found in Orphans
# len of vertices = 16720
# Step 1: extracted Soma Mesh = 1.222541332244873
# Mesh successfully extracted
# Total time = 1.8651626110076904
#
#
# 648518346342791815: Dendrite-0
# Component found in Orphans
# len of vertices = 14480
# Step 1: extracted Soma Mesh = 1.018310308456421
# Mesh successfully extracted
# Total time = 1.3500645160675049
#
#
# 648518346342791924: Dendrite-0
# Component found in Orphans
# len of vertices = 96065
# Step 1: extracted Soma Mesh = 2.3999109268188477
# Mesh successfully extracted
# Total time = 3.030831813812256
#
#
# 648518346342792438: Dendrite-0
# Component found in Orphans
# len of vertices = 30456
# Step 1: extracted Soma Mesh = 1.484929084777832
# Mesh successfully extracted
# Total time = 2.115574359893799
#
#
# 648518346342793052: Dendrite-0
# Component found in Orphans
# len of vertices = 26741
# Step 1: extracted Soma Mesh = 1.81290602684021
# Mesh successfully extracted
# Total time = 2.5487959384918213
#
#
# 648518346342793450: Dendrite-0
# Component found in Orphans
# len of vertices = 41277
# Step 1: extracted Soma Mesh = 2.4678468704223633
# Mesh successfully extracted
# Total time = 3.6077401638031006
#
#
# 648518346342793912: Dendrite-0
# Component found in Orphans
# len of vertices = 116528
# Step 1: extracted Soma Mesh = 2.9968340396881104
# Mesh successfully extracted
# Total time = 3.8267059326171875
#
#
# 648518346342794202: Dendrite-0
# Component found in Orphans
# len of vertices = 16974
# Step 1: extracted Soma Mesh = 1.2296056747436523
# Mesh successfully extracted
# Total time = 1.7338824272155762
#
#
# 648518346342795782: Dendrite-0
# Component found in Orphans
# len of vertices = 12076
# Step 1: extracted Soma Mesh = 0.8503553867340088
# Mesh successfully extracted
# Total time = 1.3617467880249023
#
#
# 648518346342796769: Dendrite-0
# Component found in Orphans
# len of vertices = 34190
# Step 1: extracted Soma Mesh = 1.41204833984375
# Mesh successfully extracted
# Total time = 1.889425277709961
#
#
# 648518346342796857: Dendrite-0
# Component found in Orphans
# len of vertices = 21452
# Step 1: extracted Soma Mesh = 1.4139902591705322
# Mesh successfully extracted
# Total time = 1.85383939743042
#
#
# 648518346342797189: Dendrite-0
# Component found in Orphans
# len of vertices = 14014
# Step 1: extracted Soma Mesh = 1.0962989330291748
# Mesh successfully extracted
# Total time = 1.7257609367370605
#
#
# 648518346342797727: Dendrite-0
# Component found in Orphans
# len of vertices = 11680
# Step 1: extracted Soma Mesh = 2.0648374557495117
# Mesh successfully extracted
# Total time = 2.571502685546875
#
#
# 648518346342797982: Dendrite-0
# Component found in Orphans
# len of vertices = 23371
# Step 1: extracted Soma Mesh = 1.3353617191314697
# Mesh successfully extracted
# Total time = 2.1393892765045166
#
#
# 648518346342798732: Dendrite-0
# Component found in Orphans
# len of vertices = 149655
# Step 1: extracted Soma Mesh = 5.651701211929321
# Mesh successfully extracted
# Total time = 7.081508636474609
#
#
# 648518346342800184: Dendrite-0
# Component found in Orphans
# len of vertices = 14120
# Step 1: extracted Soma Mesh = 1.0507726669311523
# Mesh successfully extracted
# Total time = 1.4364612102508545
#
#
# 648518346342800526: Dendrite-0
# Component found in Orphans
# len of vertices = 38265
# Step 1: extracted Soma Mesh = 1.4490017890930176
# Mesh successfully extracted
# Total time = 3.946938991546631
#
#
# 648518346342801949: Dendrite-0
# Component found in Orphans
# len of vertices = 188291
# Step 1: extracted Soma Mesh = 6.524731397628784
# Mesh successfully extracted
# Total time = 8.479521751403809
#
#
# 648518346342803997: Dendrite-0
# Component found in Orphans
# len of vertices = 21655
# Step 1: extracted Soma Mesh = 1.0567116737365723
# Mesh successfully extracted
# Total time = 1.4894986152648926
#
#
# 648518346342804367: Dendrite-0
# Component found in Orphans
# len of vertices = 40214
# Step 1: extracted Soma Mesh = 1.444399118423462
# Mesh successfully extracted
# Total time = 1.9013290405273438
#
#
# 648518346342805011: Dendrite-0
# Component found in Orphans
# len of vertices = 28322
# Step 1: extracted Soma Mesh = 1.4657776355743408
# Mesh successfully extracted
# Total time = 1.9095816612243652
#
#
# 648518346342805374: Dendrite-0
# Component found in Orphans
# len of vertices = 18879
# Step 1: extracted Soma Mesh = 1.3638241291046143
# Mesh successfully extracted
# Total time = 1.7733497619628906
#
#
# 648518346342806273: Dendrite-0
# Component found in Orphans
# len of vertices = 55559
# Step 1: extracted Soma Mesh = 1.5796480178833008
# Mesh successfully extracted
# Total time = 2.296478033065796
#
#
# 648518346342806342: Dendrite-0
# Component found in Orphans
# len of vertices = 10153
# Step 1: extracted Soma Mesh = 2.7007315158843994
# Mesh successfully extracted
# Total time = 3.7257943153381348
#
#
# 648518346342807490: Dendrite-0
# Component found in Orphans
# len of vertices = 60102
# Step 1: extracted Soma Mesh = 7.425757169723511
# Mesh successfully extracted
# Total time = 8.04934048652649
#
#
# 648518346342808014: Dendrite-0
# Component found in Orphans
# len of vertices = 16020
# Step 1: extracted Soma Mesh = 1.3108243942260742
# Mesh successfully extracted
# Total time = 1.7282729148864746
#
#
# 648518346342808453: Dendrite-0
# Component found in Orphans
# len of vertices = 44620
# Step 1: extracted Soma Mesh = 3.0502305030822754
# Mesh successfully extracted
# Total time = 3.8659231662750244
#
#
# 648518346342914598: Dendrite-0
# Component found in Orphans
# len of vertices = 46386
# Step 1: extracted Soma Mesh = 1.742722988128662
# Mesh successfully extracted
# Total time = 2.3082704544067383
#
#
# 648518346342915230: Dendrite-0
# Component found in Orphans
# len of vertices = 55376
# Step 1: extracted Soma Mesh = 2.3701629638671875
# Mesh successfully extracted
# Total time = 3.1831891536712646
#
#
# 648518346342919717: Dendrite-0
# Component found in Orphans
# len of vertices = 30827
# Step 1: extracted Soma Mesh = 2.0546772480010986
# Mesh successfully extracted
# Total time = 3.3276302814483643
#
#
# 648518346342920983: Dendrite-0
# Component found in Orphans
# len of vertices = 26410
# Step 1: extracted Soma Mesh = 1.6941204071044922
# Mesh successfully extracted
# Total time = 2.2082364559173584
#
#
# 648518346342924673: Dendrite-0
# Component found in Orphans
# len of vertices = 33077
# Step 1: extracted Soma Mesh = 2.381253719329834
# Mesh successfully extracted
# Total time = 3.6076107025146484
#
#
# 648518346342926115: Dendrite-0
# Component found in Orphans
# len of vertices = 16001
# Step 1: extracted Soma Mesh = 1.4430489540100098
# Mesh successfully extracted
# Total time = 2.0626702308654785
#
#
# 648518346342928174: Dendrite-0
# Component found in Orphans
# len of vertices = 42459
# Step 1: extracted Soma Mesh = 2.127194404602051
# Mesh successfully extracted
# Total time = 3.345613956451416
#
#
# 648518346342930883: Dendrite-0
# Component found in Orphans
# len of vertices = 88474
# Step 1: extracted Soma Mesh = 4.0766119956970215
# Mesh successfully extracted
# Total time = 5.196098804473877
#
#
# 648518346344077004: Dendrite-0
# Component found in Orphans
# len of vertices = 24958
# Step 1: extracted Soma Mesh = 1.4267339706420898
# Mesh successfully extracted
# Total time = 1.9658656120300293
#
#
# 648518346344081708: Dendrite-0
# Component found in Orphans
# len of vertices = 18876
# Step 1: extracted Soma Mesh = 1.4996259212493896
# Mesh successfully extracted
# Total time = 2.0158650875091553
#
#
# 648518346344416888: Dendrite-0
# Component found in Orphans
# len of vertices = 13991
# Step 1: extracted Soma Mesh = 1.0729212760925293
# Mesh successfully extracted
# Total time = 1.4327659606933594
#
#
# 648518346344428722: Dendrite-0
# Component found in Orphans
# len of vertices = 16478
# Step 1: extracted Soma Mesh = 1.1233935356140137
# Mesh successfully extracted
# Total time = 1.56011962890625
#
#
# 648518346344463635: Dendrite-0
# Component found in Orphans
# len of vertices = 11748
# Step 1: extracted Soma Mesh = 1.3811745643615723
# Mesh successfully extracted
# Total time = 1.7724697589874268
#
#
# 648518346344501022: Dendrite-0
# Component found in Orphans
# len of vertices = 76471
# Step 1: extracted Soma Mesh = 3.7270145416259766
# Mesh successfully extracted
# Total time = 4.55561375617981
#
#
# 648518346346311974: Dendrite-0
# Component found in Orphans
# len of vertices = 29146
# Step 1: extracted Soma Mesh = 3.258336067199707
# Mesh successfully extracted
# Total time = 3.8683831691741943
#
#
# 648518346349376861: Dendrite-0
# Component found in Orphans
# len of vertices = 38897
# Step 1: extracted Soma Mesh = 2.1490066051483154
# Mesh successfully extracted
# Total time = 2.71479868888855
#
#
# 648518346349380492: Dendrite-0
# Component found in Orphans
# len of vertices = 58206
# Step 1: extracted Soma Mesh = 3.1897926330566406
# Mesh successfully extracted
# Total time = 4.26676082611084
#
#
# 648518346349472082: Dendrite-0
# Component found in Orphans
# len of vertices = 67531
# Step 1: extracted Soma Mesh = 5.859230041503906
# Mesh successfully extracted
# Total time = 6.591256141662598
#
#
# 648518346349483668: Dendrite-0
# Component found in Orphans
# len of vertices = 54000
# Step 1: extracted Soma Mesh = 8.826873779296875
# Mesh successfully extracted
# Total time = 9.855899095535278
#
#
# 648518346349492682: Basal-1
# Component found in Orphans
# len of vertices = 65895
# Step 1: extracted Soma Mesh = 7.949695348739624
# Mesh successfully extracted
# Total time = 12.825948476791382
#
#
# 648518346349494801: Oblique-1
# Component found in Orphans
# len of vertices = 18008
# Step 1: extracted Soma Mesh = 6.997819662094116
# Mesh successfully extracted
# Total time = 11.878899812698364
#
#
# 648518346349502858: Dendrite-0
# Component found in Orphans
# len of vertices = 75886
# Step 1: extracted Soma Mesh = 2.485337495803833
# Mesh successfully extracted
# Total time = 3.3487136363983154
#
#
# 648518346349505858: Basal-0
# Component found in Orphans
# len of vertices = 43050
# Step 1: extracted Soma Mesh = 10.026185274124146
# Mesh successfully extracted
# Total time = 20.561977863311768
#
#
# 648518346349509107: Dendrite-0
# Component found in Orphans
# len of vertices = 63194
# Step 1: extracted Soma Mesh = 1.9292445182800293
# Mesh successfully extracted
# Total time = 2.5526750087738037
#
#
# 648518346349509479: Dendrite-0
# Component found in Orphans
# len of vertices = 106555
# Step 1: extracted Soma Mesh = 11.723443984985352
# Mesh successfully extracted
# Total time = 15.000839471817017
#
#
# 648518346349509595: Dendrite-0
# Component found in Orphans
# len of vertices = 84969
# Step 1: extracted Soma Mesh = 3.2588441371917725
# Mesh successfully extracted
# Total time = 4.0589759349823
# Total time = 514.85133934021
