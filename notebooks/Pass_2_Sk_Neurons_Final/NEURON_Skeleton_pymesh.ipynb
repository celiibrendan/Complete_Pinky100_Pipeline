# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[:-4]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #check to see if the face_indexes is empty
    if not face_indexes.any():
        #create an empty mesh
        current_mesh = trimesh.Trimesh(np.array([]),np.array([]),process=False)
        return current_mesh,np.array([])
    
    
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
import warnings
from pymeshfix import _meshfix
import pymeshfix

def clean_from_arrays_celii(v, f, verbose=False, joincomp=False,
                      remove_smallest_components=True,clean=True):
    """
    Performs default cleaning procedure on vertex and face arrays
    Returns cleaned vertex and face arrays
    
    Parameters
    ----------
    v : numpy.ndarray
        Numpy n x 3 array of vertices
    f : numpy.ndarray
        Numpy n x 3 array of faces.
    verbose : bool, optional
        Prints progress to stdout.  Default True.
    joincomp : bool, optional
        Attempts to join nearby open components.  Default False
    remove_smallest_components : bool, optional
        Remove all but the largest isolated component from the mesh
        before beginning the repair process.  Default True.
    Examples
    --------
    >>>
    >>> CleanFromFile('inmesh.ply', 'outmesh.ply')
    """
    # Create mesh object and load from file
    tin = _meshfix.PyTMesh(verbose)
    tin.load_array(v, f)

    # repari and return vertex and face arrays
    repair_celii(tin, verbose, joincomp, remove_smallest_components,clean)
    return tin.return_arrays()

#what the repair function does: 
def repair_celii(tin, verbose=False, joincomp=True, remove_smallest_components=True,clean=True):
    """
    Performs mesh repair using default cleaning procedure using a tin object.
    Internal function.  Use CleanFromFile or CleanFromVF.
    """

    # Keep only the largest component (i.e. with most triangles)
    if remove_smallest_components:
        sc = tin.remove_smallest_components()
        if sc and verbose:
            print('Removed %d small components' % sc)

    # join closest components
    if joincomp:
        tin.join_closest_components()
    
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
    
        
    tin.boundaries()
    if clean == True:
        # Perform mesh cleaning
        if verbose:
            print('Fixing degeneracies and intersections')
        result = tin.clean()
    else:
        print("Skipping the degenerative cleaning")
        result = False

    # Check boundaries again
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
        if verbose:
            print('Performing final check...')
        if clean == True:
            if verbose:
                print('Fixing degeneracies and intersections')
            result = tin.clean()
        else:
            print("Skipping the degenerative cleaning")
            result = False

    if result:
        warnings.warn('MeshFix could not fix everything')

# %%
@schema
class NeuronSkeletonStitched(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """
    
    
    key_source = ((dj.U("segmentation","segment_id") & pinky.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & pinky.CoarseLabelOrphan.proj()))
    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        mesh,face_indexes = get_mesh_minus_errors_and_spines(key)
        
        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])
        
        """
        Handle the poosibility that there is no mesh
        """
        if len(mesh.faces) < 50:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
        
                #send the data through the hole patching function from pymesh:
                cleaned_verts, cleaned_triangles= clean_from_arrays_celii(m.vertices,m.faces,verbose=True,joincomp=True,remove_smallest_components=False,clean=False)
                #cleaned_mesh = make_trimesh_object(m.vertices,m.faces)
            
            
        
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),cleaned_verts, cleaned_triangles)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                
                
                meshlab_script_2 = str(pathlib.Path.cwd()) + "/" + "remove_intersecting_faces.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(output_mesh,key["segment_id"],meshlab_script_2)
                
                print("About to run pymeshfix")
                start_time_py = time.time()
                loaded_mesh = trimesh.load_mesh(output_mesh,process=False)
                meshfix = pymeshfix.MeshFix(loaded_mesh.vertices,loaded_mesh.faces)
                meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                print(f"Total time for pymeshfix = {time.time() - start_time_py}")
                
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v, meshfix.f)
                
                
                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(path_and_filename)

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(path_and_filename + ".off")

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(path_and_filename)
                if return_value > 0:
                    raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                    

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(path_and_filename+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'" & "status='error'").delete()

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'")#.delete()

# %%
#NeuronSkeletonStitched & "segment_id=neuron648518346349487734"

# %%
start = time.time()
NeuronSkeletonStitched.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346349495660:----------
# Step 1: Retrieving Mesh and removing error segments: 4.047901153564453
# There were 3872 after split and significance threshold
# There were 67 after split and significance threshold
# Mesh piece 0 with number of faces 776
# Mesh piece 1 with number of faces 7961
# Mesh piece 2 with number of faces 2061641
# Mesh piece 3 with number of faces 4216
# Mesh piece 4 with number of faces 7916
# Mesh piece 5 with number of faces 866
# Mesh piece 6 with number of faces 4559
# Mesh piece 7 with number of faces 5069
# Mesh piece 8 with number of faces 1045
# Mesh piece 9 with number of faces 43180
# Mesh piece 10 with number of faces 15148
# Mesh piece 11 with number of faces 14054
# Mesh piece 12 with number of faces 18048
# Mesh piece 13 with number of faces 25579
# Mesh piece 14 with number of faces 4498
# Mesh piece 15 with number of faces 9823
# Mesh piece 16 with number of faces 1710
# Mesh piece 17 with number of faces 1020
# Mesh piece 18 with number of faces 2510
# Mesh piece 19 with number of faces 11276
# Mesh piece 20 with number of faces 48142
# Mesh piece 21 with number of faces 1770
# Mesh piece 22 with number of faces 646
# Mesh piece 23 with number of faces 15439
# Mesh piece 24 with number of faces 705
# Mesh piece 25 with number of faces 420
# Mesh piece 26 with number of faces 4284
# Mesh piece 27 with number of faces 2170
# Mesh piece 28 with number of faces 535
# Mesh piece 29 with number of faces 760
# Mesh piece 30 with number of faces 733
# Mesh piece 31 with number of faces 1913
# Mesh piece 32 with number of faces 1078
# Mesh piece 33 with number of faces 1023
# Mesh piece 34 with number of faces 760
# Mesh piece 35 with number of faces 1426
# Mesh piece 36 with number of faces 1324
# Mesh piece 37 with number of faces 1473
# Mesh piece 38 with number of faces 2145
# Mesh piece 39 with number of faces 737
# Mesh piece 40 with number of faces 444
# Mesh piece 41 with number of faces 855
# Mesh piece 42 with number of faces 255
# Mesh piece 43 with number of faces 878
# Mesh piece 44 with number of faces 1397
# Mesh piece 45 with number of faces 756
# Mesh piece 46 with number of faces 1682
# Mesh piece 47 with number of faces 1546
# Mesh piece 48 with number of faces 1740
# Mesh piece 49 with number of faces 4261
# Mesh piece 50 with number of faces 705
# Mesh piece 51 with number of faces 2344
# Mesh piece 52 with number of faces 267
# Mesh piece 53 with number of faces 1964
# Mesh piece 54 with number of faces 1567
# Mesh piece 55 with number of faces 397
# Mesh piece 56 with number of faces 335
# Mesh piece 57 with number of faces 907
# Mesh piece 58 with number of faces 299
# Mesh piece 59 with number of faces 1635
# Mesh piece 60 with number of faces 428
# Mesh piece 61 with number of faces 717
# Mesh piece 62 with number of faces 929
# Mesh piece 63 with number of faces 1737
# Mesh piece 64 with number of faces 640
# Mesh piece 65 with number of faces 1601
# Mesh piece 66 with number of faces 427
# Step 2a: Getting the number of splits: 5.291381597518921
# largest mesh perc = 0.8700261770714512
# Working on split 0 with face total = 776
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.0137786865234375
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5781581401824951
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_0
# Step 5: Generating Skeleton: 0.08831620216369629
# Step 5: Generating and reading Skeleton: 0.08977270126342773
# Working on split 1 with face total = 7961
# Patching holes...
# Patched 7 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.25324559211730957
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.213271141052246
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_1
# Step 5: Generating Skeleton: 0.4068779945373535
# Step 5: Generating and reading Skeleton: 0.40932607650756836
# Working on split 2 with face total = 2061641
# Patching holes...
# Patched 3569 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 885.5749080181122
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1215.0331840515137
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_2
# Step 5: Generating Skeleton: 83.12863826751709
# Step 5: Generating and reading Skeleton: 83.13802361488342
# Working on split 3 with face total = 4216
# Patching holes...
# Patched 17 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.08975338935852051
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.193018913269043
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_3
# Step 5: Generating Skeleton: 0.23003125190734863
# Step 5: Generating and reading Skeleton: 0.23151850700378418
# Working on split 4 with face total = 7916
# Patching holes...
# Patched 22 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.2825355529785156
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.592507839202881
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_4
# Step 5: Generating Skeleton: 0.2668900489807129
# Step 5: Generating and reading Skeleton: 0.26873278617858887
# Working on split 5 with face total = 866
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.022861242294311523
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8268396854400635
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_5
# Step 5: Generating Skeleton: 0.09426736831665039
# Step 5: Generating and reading Skeleton: 0.09498810768127441
# Working on split 6 with face total = 4559
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.14046573638916016
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.247622013092041
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_6
# Step 5: Generating Skeleton: 0.27997660636901855
# Step 5: Generating and reading Skeleton: 0.2829153537750244
# Working on split 7 with face total = 5069
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.18233203887939453
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.3151259422302246
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_7
# Step 5: Generating Skeleton: 0.26465749740600586
# Step 5: Generating and reading Skeleton: 0.2663567066192627
# Working on split 8 with face total = 1045
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.024261951446533203
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9766027927398682
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_8
# Step 5: Generating Skeleton: 0.0695643424987793
# Step 5: Generating and reading Skeleton: 0.07016992568969727
# Working on split 9 with face total = 43180
# Patching holes...
# Patched 125 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.4145827293395996
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 8.550734519958496
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_9
# Step 5: Generating Skeleton: 1.1810739040374756
# Step 5: Generating and reading Skeleton: 1.1824851036071777
# Working on split 10 with face total = 15148
# Patching holes...
# Patched 27 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.3372232913970947
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.996032953262329
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_10
# Step 5: Generating Skeleton: 0.591282844543457
# Step 5: Generating and reading Skeleton: 0.5929920673370361
# Working on split 11 with face total = 14054
# Patching holes...
# Patched 21 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.4221615791320801
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.1966254711151123
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_11
# Step 5: Generating Skeleton: 0.8654534816741943
# Step 5: Generating and reading Skeleton: 0.8704180717468262
# Working on split 12 with face total = 18048
# Patching holes...
# Patched 46 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.6698026657104492
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.964002847671509
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_12
# Step 5: Generating Skeleton: 0.6708865165710449
# Step 5: Generating and reading Skeleton: 0.6755037307739258
# Working on split 13 with face total = 25579
# Patching holes...
# Patched 69 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.8739428520202637
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.097527265548706
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_13
# Step 5: Generating Skeleton: 0.83270263671875
# Step 5: Generating and reading Skeleton: 0.835071325302124
# Working on split 14 with face total = 4498
# Patching holes...
# Patched 11 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_14_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_14_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.021962642669677734
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9487240314483643
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_14
# Step 5: Generating Skeleton: 0.03746318817138672
# Step 5: Generating and reading Skeleton: 0.03841972351074219
# Working on split 15 with face total = 9823
# Patching holes...
# Patched 38 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_15.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_15_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_15_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.21669292449951172
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.675387144088745
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_15
# Step 5: Generating Skeleton: 0.33791017532348633
# Step 5: Generating and reading Skeleton: 0.33945679664611816
# Working on split 16 with face total = 1710
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_16.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_16_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_16_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_16_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.06341123580932617
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9796600341796875
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_16
# Step 5: Generating Skeleton: 0.10804080963134766
# Step 5: Generating and reading Skeleton: 0.10881829261779785
# Working on split 17 with face total = 1020
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_17.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_17_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_17_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_17_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.028996706008911133
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9252560138702393
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_17
# Step 5: Generating Skeleton: 0.13425898551940918
# Step 5: Generating and reading Skeleton: 0.13595914840698242
# Working on split 18 with face total = 2510
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_18.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_18_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_18_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_18_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.05961251258850098
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.0316262245178223
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_18
# Step 5: Generating Skeleton: 0.22567152976989746
# Step 5: Generating and reading Skeleton: 0.22718501091003418
# Working on split 19 with face total = 11276
# Patching holes...
# Patched 32 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_19.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_19_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_19_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_19_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.35109591484069824
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.8802883625030518
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_19
# Step 5: Generating Skeleton: 0.38697052001953125
# Step 5: Generating and reading Skeleton: 0.38948512077331543
# Working on split 20 with face total = 48142
# Patching holes...
# Patched 144 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_20.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_20_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_20_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_20_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 1.5438787937164307
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 8.502118825912476
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_20
# Step 5: Generating Skeleton: 1.3670830726623535
# Step 5: Generating and reading Skeleton: 1.3687481880187988
# Working on split 21 with face total = 1770
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_21.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_21_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_21_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_21_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.760413408279419
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 4.072313547134399
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_21
# Step 5: Generating Skeleton: 4.275783538818359
# Step 5: Generating and reading Skeleton: 4.2787556648254395
# Working on split 22 with face total = 646
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_22.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_22_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_22_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_22_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.039055585861206055
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9315803050994873
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_22
# Step 5: Generating Skeleton: 0.07330560684204102
# Step 5: Generating and reading Skeleton: 0.07392740249633789
# Working on split 23 with face total = 15439
# Patching holes...
# Patched 42 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_23.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_23_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_23_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_23_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.36000943183898926
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.0879061222076416
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_23
# Step 5: Generating Skeleton: 0.5531089305877686
# Step 5: Generating and reading Skeleton: 0.5553808212280273
# Working on split 24 with face total = 705
# Patching holes...
# Patched 7 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_24.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_24_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_24_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_24_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.02396702766418457
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7228577136993408
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_24
# Step 5: Generating Skeleton: 0.05145835876464844
# Step 5: Generating and reading Skeleton: 0.052198171615600586
# Working on split 25 with face total = 420
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_25.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_25_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_25_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_25_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.015026330947875977
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6254169940948486
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_25
# Step 5: Generating Skeleton: 0.021535396575927734
# Step 5: Generating and reading Skeleton: 0.022182703018188477
# Working on split 26 with face total = 4284
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_26.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_26_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_26_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_26_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.094482421875
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.0310556888580322
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_26
# Step 5: Generating Skeleton: 0.23311161994934082
# Step 5: Generating and reading Skeleton: 0.23491621017456055
# Working on split 27 with face total = 2170
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_27.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_27_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_27_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_27_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.04977893829345703
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8991799354553223
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_27
# Step 5: Generating Skeleton: 0.21794891357421875
# Step 5: Generating and reading Skeleton: 0.2195281982421875
# Working on split 28 with face total = 535
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_28.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_28_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_28_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_28_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01569390296936035
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8105480670928955
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_28
# Step 5: Generating Skeleton: 0.037265777587890625
# Step 5: Generating and reading Skeleton: 0.03808283805847168
# Working on split 29 with face total = 760
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_29.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_29_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_29_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_29_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03005528450012207
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8551898002624512
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_29
# Step 5: Generating Skeleton: 0.07958984375
# Step 5: Generating and reading Skeleton: 0.08082199096679688
# Working on split 30 with face total = 733
# Patching holes...
# Patched 6 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_30.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_30_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_30_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_30_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.02002239227294922
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8569402694702148
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_30
# Step 5: Generating Skeleton: 0.03325700759887695
# Step 5: Generating and reading Skeleton: 0.03406047821044922
# Working on split 31 with face total = 1913
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_31.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_31_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_31_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_31_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.04709982872009277
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8727953433990479
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_31
# Step 5: Generating Skeleton: 0.11307859420776367
# Step 5: Generating and reading Skeleton: 0.11383819580078125
# Working on split 32 with face total = 1078
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_32.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_32_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_32_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_32_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.028441429138183594
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.770667552947998
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_32
# Step 5: Generating Skeleton: 0.14904999732971191
# Step 5: Generating and reading Skeleton: 0.15018153190612793
# Working on split 33 with face total = 1023
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_33.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_33_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_33_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_33_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.04054594039916992
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.784341812133789
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_33
# Step 5: Generating Skeleton: 0.0705714225769043
# Step 5: Generating and reading Skeleton: 0.0718696117401123
# Working on split 34 with face total = 760
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_34.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_34_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_34_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_34_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.017843246459960938
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8167860507965088
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_34
# Step 5: Generating Skeleton: 0.08195066452026367
# Step 5: Generating and reading Skeleton: 0.08277177810668945
# Working on split 35 with face total = 1426
# Patching holes...
# Patched 6 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_35.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_35_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# ...
# Patched 11 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_53.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_53_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_53_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_53_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.041678428649902344
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8083429336547852
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_53
# Step 5: Generating Skeleton: 0.12607502937316895
# Step 5: Generating and reading Skeleton: 0.12715911865234375
# Working on split 54 with face total = 1567
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_54.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_54_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_54_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_54_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.037026166915893555
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8179936408996582
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_54
# Step 5: Generating Skeleton: 0.10807132720947266
# Step 5: Generating and reading Skeleton: 0.10890316963195801
# Working on split 55 with face total = 397
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_55.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_55_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_55_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_55_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.016564607620239258
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7133069038391113
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_55
# Step 5: Generating Skeleton: 0.027468204498291016
# Step 5: Generating and reading Skeleton: 0.02809762954711914
# Working on split 56 with face total = 335
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_56.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_56_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_56_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_56_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.011550426483154297
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.761347770690918
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_56
# Step 5: Generating Skeleton: 0.012550115585327148
# Step 5: Generating and reading Skeleton: 0.013218879699707031
# Working on split 57 with face total = 907
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_57.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_57_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_57_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_57_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.02322530746459961
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8349981307983398
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_57
# Step 5: Generating Skeleton: 0.0642235279083252
# Step 5: Generating and reading Skeleton: 0.0648348331451416
# Working on split 58 with face total = 299
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_58.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_58_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_58_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_58_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.0028417110443115234
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6845619678497314
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_58
# Number of faces are less than 20 so not generating skeleton
# Working on split 59 with face total = 1635
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_59.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_59_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_59_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_59_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.05484580993652344
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.1055307388305664
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_59
# Step 5: Generating Skeleton: 0.13143587112426758
# Step 5: Generating and reading Skeleton: 0.13231444358825684
# Working on split 60 with face total = 428
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_60.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_60_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_60_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_60_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.018541336059570312
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7706053256988525
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_60
# Step 5: Generating Skeleton: 0.007458209991455078
# Step 5: Generating and reading Skeleton: 0.008152246475219727
# Working on split 61 with face total = 717
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_61.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_61_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_61_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_61_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.022687673568725586
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7371923923492432
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_61
# Step 5: Generating Skeleton: 0.04636096954345703
# Step 5: Generating and reading Skeleton: 0.04714059829711914
# Working on split 62 with face total = 929
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_62.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_62_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_62_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_62_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.04103970527648926
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7588441371917725
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_62
# Step 5: Generating Skeleton: 0.1093454360961914
# Step 5: Generating and reading Skeleton: 0.11055898666381836
# Working on split 63 with face total = 1737
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_63.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_63_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_63_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_63_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.1684589385986328
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.2903435230255127
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_63
# Step 5: Generating Skeleton: 0.6549324989318848
# Step 5: Generating and reading Skeleton: 0.6561112403869629
# Working on split 64 with face total = 640
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_64.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495660_piece_64_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-1c75e0c54da0> in <module>
#       1 start = time.time()
# ----> 2 NeuronSkeletonStitched.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-12-fe3a0673addf> in make(self, key)
#     158                 #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
#     159                 meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
# --> 160                 output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
#     161
#     162
#
# <ipython-input-8-59f77b91c34d> in meshlab_fix_manifold_path_specific_mls(path_and_filename, segment_id, meshlab_script)
#      71     if str(subprocess_result_1)[-13:] != "returncode=0)":
#      72         raise Exception('neuron' + str(segment_id) +
# ---> 73                          ' did not fix the manifold edges')
#      74
#      75     return output_mesh
#
# Exception: neuron648518346349495660 did not fix the manifold edges
