# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.CoarseLabelFinal() #ta3p100.CoarseLabelOrphan()

# %%
#function that will filter out error triangles
def generate_neighborhood(triangles, num_vertices):
    neighborhood = dict()
    for i in range(num_vertices):
        neighborhood[i] = set()
    for node1, node2, node3 in triangles:
        neighborhood[node1].update([node2, node3])
        neighborhood[node2].update([node1, node3])
        neighborhood[node3].update([node1, node2])
    return neighborhood

def set_search_first(starting_node, neighborhood):
    """
    Modified Depth-First-Search utilizing sets to reduce duplicate checks:

    Neighborhood must be a dict with the keys being the vertex indices!
    """    
    visited_nodes = set()
    temp_stack = set()
    temp_stack.add(starting_node)
    while len(temp_stack) > 0:
        starting_node = temp_stack.pop()
        if starting_node not in visited_nodes:
            visited_nodes.add(starting_node)
            temp_stack.update(neighborhood[starting_node])
    return list(visited_nodes)
def get_connected_portions(neighborhood):
    neighborhood_copy = neighborhood.copy()
    portions = []
    while len(neighborhood_copy) > 0:
        starting_node = next(iter(neighborhood_copy))
        portion = set_search_first(starting_node, neighborhood_copy)
        for node in portion:
            neighborhood_copy.pop(node)
        portions.append(portion)
    return portions

def get_largest_portion_index(portions):
    portion_lengths = [len(portion) for portion in portions]
    return portion_lengths.index(max(portion_lengths))

def get_largest_portion(portions):
    return portions[get_largest_portion_index(portions)]

def remove_floating_artifacts(mesh,key,mesh_labels):    
    mesh_copy = mesh.copy()
    
#     #get the labels for the mesh
#     #find out if in Orphan Table or Regular Neuron Table
#     if len(ta3p100.CoarseLabelFinal() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
#     elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
#     else:
#         raise Exception('neuron' + str(key["segment_id"]) + 
#                         'not present in any labels!')

    
    #look for errors
    not_errors = [i for i,k in enumerate(mesh_labels["triangles"]) if k != 10]
    original_triangles = mesh["triangles"]
    """
    print(type(not_errors))
    print(len(not_errors))
    print("not_errors = "+ str(not_errors[:100]))
    print(type(original_triangles))
    print(len(original_triangles))
    #print(original_triangles)
    print("not_errors = " + str(original_triangles[not_errors]))
    """
    
    mesh_copy['triangles'] = np.array(original_triangles[not_errors])
    
    return mesh_copy


def remove_isolated_vertices(mesh):
    mesh_copy = mesh.copy()

    neighborhood = generate_neighborhood(mesh_copy['triangles'], len(mesh_copy['vertices']))
    isolated_nodes = [portion.pop() for portion in get_connected_portions(neighborhood) if len(portion) == 1]

    vertices = mesh_copy['vertices']
    triangles = mesh_copy['triangles']
    vertex_list = list(vertices)

    if len(isolated_nodes) > 0:
        num_isolated_nodes_passed = 0
        isolated_nodes_set = set(isolated_nodes)
        count_to_decrement = np.zeros(len(vertices))
        for i in range(len(vertices)):
            if i in isolated_nodes_set:
                num_isolated_nodes_passed += 1
            else:
                count_to_decrement[i] = num_isolated_nodes_passed

        for i, triangle in enumerate(triangles):
            start = time.time()
            node1, node2, node3 = triangle
            triangles[i][0] -= count_to_decrement[node1]
            triangles[i][1] -= count_to_decrement[node2]
            triangles[i][2] -= count_to_decrement[node3]
        for i, isolated_node in enumerate(isolated_nodes):
            vertex_list.pop(isolated_node - i)

    mesh_copy['vertices'] = np.array(vertex_list)

    return mesh_copy


def remove_error_segments(key):

    full_start = time.time()

    print(str(key['segment_id']) +  ":")
    start = time.time()

    #find out if in Orphan Table or Regular Neuron Table
    if len(ta3p100.CoarseLabelFinal() & key) > 0:
        mesh = (ta3p100.CleansedMesh & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
    elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
        mesh = (ta3p100.CleansedMeshOrphan & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
    else:
        raise Exception('neuron' + str(key["segment_id"]) + 
                        'not present in any labels!')
    
    print(key['segment_id'], "mesh fetched.", time.time() - start)
    start = time.time()
    
    #print(mesh['triangles'])
    myCounter = Counter(mesh_labels['triangles'])#.tolist())
    print(myCounter)
    
    keys = list(myCounter.keys())
    #print(len(keys))
    
    if len(keys) < 2 and keys[0] == 10:
        print("only error segments")
        key['n_vertices'] = 0
        key['n_triangles'] = 0
        key['vertices'] = np.ndarray([])
        key['triangles'] = np.ndarray([])
        
        print("This took ", time.time() - full_start, "seconds.")
        print()
        return key
    
    neighborhood = generate_neighborhood(mesh['triangles'], len(mesh['vertices']))
    print(key['segment_id'] , "neighborhood generated.", time.time() - start)
    start = time.time()
    
    mesh = remove_floating_artifacts(mesh,key,mesh_labels)
    print(key['segment_id'], "floating artifacts removed.", time.time() - start)
    start = time.time()

    mesh = remove_isolated_vertices(mesh)
    print(key['segment_id'], "isolated nodes removed.", time.time() - start)
    start = time.time()

    key['n_vertices'] = len(mesh['vertices'])
    key['n_triangles'] = len(mesh['triangles'])
    key['vertices'] = mesh['vertices']
    key['triangles'] = mesh['triangles']

    #self.insert1(key, skip_duplicates=True)
    print(key['segment_id'], "key successfully filtered.", time.time() - start)
    start = time.time()

    print("This took ", time.time() - full_start, "seconds.")
    print()
    return key

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY, this is outdated for one below"""
#
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_neurons")) == False:
    os.mkdir("pymesh_neurons")

# %%
#keysource for neuron table
ta3p100.CoarseLabelFinal()
print(len(ta3p100.CoarseLabelFinal()))
# Out:
# 322

# %%
ta3p100.CoarseLabelOrphan()
print(len(ta3p100.CoarseLabelOrphan()))
# Out:
# 702

# %%
ns_table = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
print(len(ns_table))
ns_table
# Out:
# 1024
# *segmentation  *segment_id
# +------------+ +------------+
# 2              64851834634136
# 2              64851834634137
# 2              64851834634138
# 2              64851834634139
# 2              64851834634279
# 2              64851834634280
# 2              64851834634938
# 2              64851834634946
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
#    ...
#  (1024 tuples)

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_neurons"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_neurons"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting remeshing_remove_non_man_edges")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuronRawSkeleton(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the component labels were updated
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_vertices   :int unsigned #number of vertices in mesh filtered of error segments
    n_triangles  :int unsigned #number of faces in mesh filtered of error segments
    vertices     :longblob #mesh data for vertices in mesh filtered of error segments
    triangles    :longblob #mesh data for faces in mesh filtered of error segments
     
    """
    
    key_source = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        new_key = remove_error_segments(key)
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        
        #where i deal with the error segments
        if new_key["vertices"].size<2:
            start_time = time.time()
            print("All faces were error segments, inserting dummy entry")
            #create the key with None
            new_key["n_vertices"] = 0
            new_key["n_triangles"] = 0
            new_key["vertices"] = np.array([]).astype(float)
            new_key["triangles"] = np.array([]).astype(float)
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["time_updated"]=str(datetime.datetime.now())
            self.insert1(new_key,skip_duplicates=True)
            
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = 0,
                                           correspondence=np.array([]).astype(float))
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            print(f"Step 2: Inserting dummy dictionary: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")
        
        else:
        
            #print("Step 2: Remove all error semgents")
            start_time = time.time()
            #pass the vertices and faces to pymeshfix to become watertight
            meshfix = pymeshfix.MeshFix(new_key["vertices"],new_key["triangles"])
            meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
            print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")

            #print("Step 2: Writing Off File")
            start_time = time.time()
            #write the new mesh to off file
            path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
            print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

            #Run the meshlabserver scripts
            start_time = time.time()
            output_mesh = meshlab_fix_manifold(key)
            print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

            print(output_mesh[:-4])

            #send to be skeletonized
            start_time = time.time()
            return_value = cm.calcification(output_mesh[:-4])
            if return_value > 0:
                raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                ' did not finish... exited with error code: ' + str(return_value))
            #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



            #read in the skeleton files into an array
            #start_time = time.time()
            
            ##****** this needs to be changed for reading them in******
            bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            correspondence_array = read_raw_skeleton(output_mesh[:-4]+"_correspondance.cgal")
            #print(bone_array)
            if len(bone_array) <= 0:
                raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
            
            if len(correspondence_array) <= 0:
                raise Exception('No CORRESPONDENCE generated for ' + str(new_key["segment_id"]))
                
            print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


            start_time = time.time()
            
            new_key["n_edges"] = bone_array.shape[0]
            new_key["edges"] = bone_array
            #new_key["branches"] = []

            time_updated = str(datetime.datetime.now())
            new_key["time_updated"]=time_updated
            #print(key)
            #if all goes well then write to database
            self.insert1(new_key,skip_duplicates=True)
            
            #create a new dictionary key to be inserted into correspondence table
            """
            time_updated      :timestamp    # the time at which the component labels were updated
            ---
            n_correspondence   :int unsigned #number of mappings from skeleton vert to original surface vert 
            correspondence     :longblob #array storing mapping of every skeleton vert to original surface vert  
            """
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = correspondence_array.shape[0],
                                           correspondence=correspondence_array)
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            os.system("rm "+str(path_and_filename)+"*")
            print(f"Step 6: Inserting both dictionaries: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#ta3p100.NeuronSkeletons()#.delete()
#(schema.jobs & "table_name='__neuron_skeletons'").delete()

# %%
start = time.time()
NeuronRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346349473597:
# 648518346349473597 mesh fetched. 0.560901403427124
# Counter({3: 659526, 8: 163491, 7: 86320, 5: 54558})
# 648518346349473597 neighborhood generated. 7.726286172866821
# 648518346349473597 floating artifacts removed. 1.7833919525146484
# 648518346349473597 isolated nodes removed. 10.888039588928223
# 648518346349473597 key successfully filtered. 7.3909759521484375e-06
# This took  20.960601806640625 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 21.320224285125732
# Step 2: Pymesh shrinkwrapping: 81.98956227302551
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 5.811616897583008
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 12.946070909500122
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349473597_mls
# Step 5: Generating and reading Skeleton: 46.154484033584595
# Step 6: Inserting both dictionaries: 5.1532301902771
# Total time: 173.3769211769104
#
#
#
# 648518346349473833:
# 648518346349473833 mesh fetched. 0.1642141342163086
# Counter({3: 278503, 5: 70364})
# 648518346349473833 neighborhood generated. 3.3588624000549316
# 648518346349473833 floating artifacts removed. 0.6598467826843262
# 648518346349473833 isolated nodes removed. 4.160518407821655
# 648518346349473833 key successfully filtered. 7.3909759521484375e-06
# This took  8.345896244049072 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 8.51343822479248
# Step 2: Pymesh shrinkwrapping: 70.71274495124817
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.5781805515289307
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 4.7701897621154785
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349473833_mls
# Step 5: Generating and reading Skeleton: 13.243129968643188
# Step 6: Inserting both dictionaries: 1.9057707786560059
# Total time: 100.72642278671265
#
#
#
# 648518346349474146:
# 648518346349474146 mesh fetched. 0.4483661651611328
# Counter({3: 613970, 6: 207419, 5: 157326, 2: 10496, 10: 26, 12: 3})
# 648518346349474146 neighborhood generated. 8.327324390411377
# 648518346349474146 floating artifacts removed. 1.9480206966400146
# 648518346349474146 isolated nodes removed. 22.46843194961548
# 648518346349474146 key successfully filtered. 7.152557373046875e-06
# This took  33.193583726882935 seconds.
#
# Step 1: Retrieving Mesh and removing error segments:
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349479478_mls
# Step 5: Generating and reading Skeleton: 43.07828068733215
# Step 6: Inserting both dictionaries: 4.148106575012207
# Total time: 383.9345099925995
#
#
#
# 648518346349484832:
# 648518346349484832 mesh fetched. 0.12297248840332031
# Counter({3: 156644, 10: 50550, 5: 42080})
# 648518346349484832 neighborhood generated. 2.0789811611175537
# 648518346349484832 floating artifacts removed. 0.42596888542175293
# 648518346349484832 isolated nodes removed. 6.567474365234375
# 648518346349484832 key successfully filtered. 5.0067901611328125e-06
# This took  9.196994543075562 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 9.276589393615723
# Step 2: Pymesh shrinkwrapping: 44.3562331199646
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.8599228858947754
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.489118814468384
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349484832_mls
# Step 5: Generating and reading Skeleton: 7.75606369972229
# Step 6: Inserting both dictionaries: 0.985029935836792
# Total time: 65.7243299484253
#
#
#
# 648518346349486885:
# 648518346349486885 mesh fetched. 0.2532081604003906
# Counter({3: 522224, 5: 171791, 8: 11829, 6: 5374, 12: 2})
# 648518346349486885 neighborhood generated. 5.965563774108887
# 648518346349486885 floating artifacts removed. 1.2186627388000488
# 648518346349486885 isolated nodes removed. 8.239479780197144
# 648518346349486885 key successfully filtered. 6.4373016357421875e-06
# This took  15.677768230438232 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 15.916088104248047
# Step 2: Pymesh shrinkwrapping: 292.9922626018524
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.362755298614502
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 8.173266172409058
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349486885_mls
# Step 5: Generating and reading Skeleton: 36.18262839317322
# Step 6: Inserting both dictionaries: 3.1878960132598877
# Total time: 359.81660413742065
#
#
#
# 648518346349491953:
# 648518346349491953 mesh fetched. 0.39104461669921875
# Counter({3: 849429, 2: 332359, 5: 143037, 6: 4707, 10: 1055})
# 648518346349491953 neighborhood generated. 10.824163436889648
# 648518346349491953 floating artifacts removed. 2.2849583625793457
# 648518346349491953 isolated nodes removed. 30.79990243911743
# 648518346349491953 key successfully filtered. 6.67572021484375e-06
# This took  44.30128526687622 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 44.76453924179077
# Step 2: Pymesh shrinkwrapping: 690.4194493293762
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 6.712944746017456
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 17.275277376174927
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349491953_mls
# Step 5: Generating and reading Skeleton: 66.07732963562012
# Step 6: Inserting both dictionaries: 6.192588806152344
# Total time: 831.4430902004242
#
#
#
# 648518346349498239:
# 648518346349498239 mesh fetched. 0.460965633392334
# Counter({3: 936844, 2: 317813, 5: 158021, 6: 12594})
# 648518346349498239 neighborhood generated. 11.928038358688354
# 648518346349498239 floating artifacts removed. 2.469756841659546
# 648518346349498239 isolated nodes removed. 18.354969263076782
# 648518346349498239 key successfully filtered. 7.62939453125e-06
# This took  33.21509671211243 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 33.9746208190918
# Step 2: Pymesh shrinkwrapping: 480.80898690223694
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 5.385927677154541
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 13.165966510772705
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349498239_mls
# Step 5: Generating and reading Skeleton: 41.93077373504639
# Step 6: Inserting both dictionaries: 5.797095060348511
# Total time: 581.0647966861725
#
#
#
# 648518346349499803:
# 648518346349499803 mesh fetched. 0.28797459602355957
# Counter({3: 641394, 5: 65344, 6: 48843, 2: 5035, 12: 484})
# 648518346349499803 neighborhood generated. 6.086776971817017
# 648518346349499803 floating artifacts removed. 1.2965567111968994
# 648518346349499803 isolated nodes removed. 8.817170143127441
# 648518346349499803 key successfully filtered. 5.9604644775390625e-06
# This took  16.48997402191162 seconds.
#
# Step 1: Retrieving Mesh and removing error segments:
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 4.177337884902954
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 12.002398490905762
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349507226_mls
# Step 5: Generating and reading Skeleton: 34.74031662940979
# Step 6: Inserting both dictionaries: 3.9603190422058105
# Total time: 204.7567036151886
#
#
#
# 648518346349507984:
# 648518346349507984 mesh fetched. 0.2671010494232178
# Counter({3: 480143, 4: 150985, 2: 147501, 5: 83137})
# 648518346349507984 neighborhood generated. 7.122125864028931
# 648518346349507984 floating artifacts removed. 1.5139782428741455
# 648518346349507984 isolated nodes removed. 10.411805152893066
# 648518346349507984 key successfully filtered. 7.62939453125e-06
# This took  19.316476821899414 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 19.6989107131958
# Step 2: Pymesh shrinkwrapping: 192.53806710243225
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 4.41897177696228
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 10.742003679275513
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349507984_mls
# Step 5: Generating and reading Skeleton: 36.28527116775513
# Step 6: Inserting both dictionaries: 4.486351013183594
# Total time: 268.17093658447266
#
#
#
# 648518346341375544:
# 648518346341375544 mesh fetched. 0.31325364112854004
# Counter({10: 517957})
# only error segments
# This took  0.4218921661376953 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4219822883605957
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.05230116844177246
# Total time: 0.47440552711486816
#
#
#
# 648518346341375671:
# 648518346341375671 mesh fetched. 0.23842883110046387
# Counter({8: 122532, 10: 87590})
# 648518346341375671 neighborhood generated. 1.8067054748535156
# 648518346341375671 floating artifacts removed. 0.35005950927734375
# 648518346341375671 isolated nodes removed. 6.320406436920166
# 648518346341375671 key successfully filtered. 5.4836273193359375e-06
# This took  8.716582298278809 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 8.7883780002594
# Step 2: Pymesh shrinkwrapping: 4.246968507766724
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.45618629455566406
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.5565714836120605
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341375671_mls
# Step 5: Generating and reading Skeleton: 3.7162981033325195
# Step 6: Inserting both dictionaries: 0.6790244579315186
# Total time: 19.44438099861145
#
#
#
# 648518346341377443:
# 648518346341377443 mesh fetched. 0.11263418197631836
# Counter({8: 31844})
# 648518346341377443 neighborhood generated. 0.3477787971496582
# 648518346341377443 floating artifacts removed. 0.07067441940307617
# 648518346341377443 isolated nodes removed. 0.4039030075073242
# 648518346341377443 key successfully filtered. 5.4836273193359375e-06
# This took  0.936112642288208 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9476323127746582
# Step 2: Pymesh shrinkwrapping: 0.8137338161468506
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15773844718933105
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9103467464447021
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341377443_mls
# Step 5: Generating and reading Skeleton: 1.8848800659179688
# Step 6: Inserting both dictionaries: 0.3237454891204834
# Total time: 5.039151430130005
#
#
#
# 648518346341378470:
# 648518346341378470 mesh fetched. 0.18635272979736328
# Counter({10: 213766})
# only error segments
# This took  0.24539518356323242 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.24548912048339844
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.03362870216369629
# Total time: 0.2792394161224365
#
#
#
# 648518346341378749:
# 648518346341378749 mesh fetched. 0.11573266983032227
# Counter({3: 39230, 5: 31209, 11: 3340, 8: 1})
# 648518346341378749 neighborhood generated. 0.7010765075683594
# 648518346341378749 floating artifacts removed. 0.1545543670654297
# 648518346341378749 isolated nodes removed. 0.9650132656097412
# 648518346341378749 key successfully filtered. 5.9604644775390625e-06
# This took  1.9374780654907227 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.9683151245117188
# Step 2: Pymesh shrinkwrapping: 4.046569108963013
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3957955837249756
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 3.41582989692688
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.0199449062347412
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.29101824760437
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341394683_mls
# Step 5: Generating and reading Skeleton: 10.667689800262451
# Step 6: Inserting both dictionaries: 1.0800526142120361
# Total time: 28.24362087249756
#
#
#
# 648518346341396962:
# 648518346341396962 mesh fetched. 0.11006450653076172
# Counter({8: 124374, 10: 18717})
# 648518346341396962 neighborhood generated. 1.3860230445861816
# 648518346341396962 floating artifacts removed. 0.25424933433532715
# 648518346341396962 isolated nodes removed. 3.2556467056274414
# 648518346341396962 key successfully filtered. 5.7220458984375e-06
# This took  5.007287263870239 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.0536932945251465
# Step 2: Pymesh shrinkwrapping: 6.9016242027282715
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7252345085144043
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.4131405353546143
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341396962_mls
# Step 5: Generating and reading Skeleton: 6.424558877944946
# Step 6: Inserting both dictionaries: 0.8177127838134766
# Total time: 22.338379383087158
#
#
#
# 648518346341399382:
# 648518346341399382 mesh fetched. 0.06586027145385742
# Counter({8: 67218})
# 648518346341399382 neighborhood generated. 0.6668581962585449
# 648518346341399382 floating artifacts removed. 0.1443636417388916
# 648518346341399382 isolated nodes removed. 0.8393833637237549
# 648518346341399382 key successfully filtered. 7.3909759521484375e-06
# This took  1.7173466682434082 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.7460558414459229
# Step 2: Pymesh shrinkwrapping: 2.1360552310943604
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.35642433166503906
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.3269364833831787
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341399382_mls
# Step 5: Generating and reading Skeleton: 3.0966644287109375
# Step 6: Inserting both dictionaries: 0.4577498435974121
# Total time: 9.121435403823853
#
#
#
# 648518346341400604:
# 648518346341400604 mesh fetched. 0.22201085090637207
# Counter({10: 353178})
# only error segments
# This took  0.30428266525268555 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3043696880340576
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.00950002670288086
# Total time: 0.3139665126800537
#
#
#
# 648518346341400619:
# 648518346341400619 mesh fetched. 0.0464169979095459
# Counter({8: 16072})
# 648518346341400619 neighborhood generated. 0.1930394172668457
# 648518346341400619 floating artifacts removed. 0.03418111801147461
# 648518346341400619 isolated nodes removed. 0.20348525047302246
# 648518346341400619 key successfully filtered. 4.5299530029296875e-06
# This took  0.47849535942077637 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.48401665687561035
# Step 2: Pymesh shrinkwrapping: 0.4025251865386963
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08531928062438965
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7647855281829834
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341400619_mls
# Step 5: Generating and reading Skeleton: 2.1090550422668457
# Step 6: Inserting both dictionaries: 0.2521193027496338
# Total time: 4.099050998687744
#
#
#
# 648518346341401448:
# 648518346341401448 mesh fetched. 0.10100555419921875
# Counter({8: 80430})
# 648518346341401448 neighborhood generated. 0.8451976776123047
# 648518346341401448 floating artifacts removed. 0.1478748321533203
# 648518346341401448 isolated nodes removed. 0.8510417938232422
# 648518346341401448 key successfully filtered. 5.0067901611328125e-06
# This took  1.9464137554168701 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.9726932048797607
# Step 2: Pymesh shrinkwrapping: 3.7516391277313232
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4196140766143799
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.3869893550872803
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341401448_mls
# Step 5: Generating and reading Skeleton: 3.6194257736206055
# Step 6: Inserting both dictionaries: 0.6322391033172607
# Total time: 11.783722639083862
#
#
#
# 648518346341402112:
# 648518346341402112 mesh fetched. 0.21200084686279297
# Counter({8: 90479})
# 648518346341402112 neighborhood generated. 0.915245771408081
# 648518346341402112 floating artifacts removed. 0.16017723083496094
# 648518346341402112 isolated nodes removed. 0.9693679809570312
# 648518346341402112 key successfully filtered. 5.245208740234375e-06
# This took  2.2578420639038086 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.2874209880828857
# Step 2: Pymesh shrinkwrapping: 2.7337186336517334
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.47060346603393555
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.910752296447754
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341402112_mls
# Step 5: Generating and reading Skeleton: 4.177579164505005
# Step 6: Inserting both dictionaries: 0.6288597583770752
# Total time: 12.210152626037598
#
#
#
# 648518346341403967:
# 648518346341403967 mesh fetched. 0.23946928977966309
# Counter({2: 132884, 4: 104270, 3: 101042, 5: 63597, 10: 15468})
# 648518346341403967 neighborhood generated. 3.365452766418457
# 648518346341403967 floating artifacts removed. 0.7396814823150635
# 648518346341403967 isolated nodes removed. 10.061947584152222
# 648518346341403967 key successfully filtered. 9.5367431640625e-06
# This took  14.408138751983643 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 14.58590292930603
# Step 2: Pymesh shrinkwrapping: 23.246004104614258
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.1283490657806396
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 5.546367883682251
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341403967_mls
# Step 5: Generating and reading Skeleton: 26.187402486801147
# Step 6: Inserting both dictionaries: 2.187469482421875
# Total time: 73.88268446922302
#
#
#
# 648518346342161001:
# 648518346342161001 mesh fetched. 0.13970375061035156
# Counter({8: 16315})
# 648518346342161001 neighborhood generated. 0.12709283828735352
# 648518346342161001 floating artifacts removed. 0.028954267501831055
# 648518346342161001 isolated nodes removed. 0.16888737678527832
# 648518346342161001 key successfully filtered. 3.814697265625e-06
# This took  0.4655025005340576 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.47040534019470215
# Step 2: Pymesh shrinkwrapping: 0.324526309967041
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08358907699584961
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7323157787322998
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342161001_mls
# Step 5: Generating and reading Skeleton: 1.096893548965454
# Step 6: Inserting both dictionaries: 0.19964337348937988
# Total time: 2.907881259918213
#
#
#
# 648518346342407380:
# 648518346342407380 mesh fetched. 0.06686282157897949
# Counter({10: 17906})
# only error segments
# This took  0.07040953636169434 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.07049107551574707
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.037564992904663086
# Total time: 0.10824012756347656
#
#
#
# 648518346342407655:
# 648518346342407655 mesh fetched. 0.09311819076538086
# Counter({8: 13972})
# 648518346342407655 neighborhood generated. 0.1678617000579834
# 648518346342407655 floating artifacts removed. 0.030542612075805664
# 648518346342407655 isolated nodes removed. 0.2816429138183594
# 648518346342407655 key successfully filtered. 3.5762786865234375e-06
# This took  0.5742440223693848 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5796413421630859
# Step 2: Pymesh shrinkwrapping: 0.305023193359375
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08325934410095215
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7987632751464844
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342407655_mls
# Step 5: Generating and reading Skeleton: 1.2772643566131592
# Step 6: Inserting both dictionaries: 0.13455891609191895
# Total time: 3.1798605918884277
#
#
#
# 648518346342771094:
# 648518346342771094 mesh fetched. 0.21799421310424805
# Counter({5: 38691, 8: 9140, 11: 2079})
# 648518346342771094 neighborhood generated. 0.5204813480377197
# 648518346342771094 floating artifacts removed. 0.10406827926635742
# 648518346342771094 isolated nodes removed. 0.5764906406402588
# 648518346342771094 key successfully filtered. 4.5299530029296875e-06
# This took  1.420942783355713 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.4370167255401611
# Step 2: Pymesh shrinkwrapping: 3.273287534713745
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.24773025512695312
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0670466423034668
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342771094_mls
# Step 5: Generating and reading Skeleton: 4.936517715454102
# Step 6: Inserting both dictionaries: 0.4330008029937744
# Total time: 11.396020412445068
#
#
#
# 648518346342791284:
# 648518346342791284 mesh fetched. 0.07532000541687012
# Counter({10: 43227, 8: 20208})
# 648518346342791284 neighborhood generated. 0.6692008972167969
# 648518346342791284 floating artifacts removed. 0.1295456886291504
# 648518346342791284 isolated nodes removed. 1.0708298683166504
# 648518346342791284 key successfully filtered. 6.198883056640625e-06
# This took  1.9459059238433838 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.9655864238739014
# Step 2: Pymesh shrinkwrapping: 0.36154794692993164
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10343408584594727
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8014287948608398
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342791284_mls
# Step 5: Generating and reading Skeleton: 1.5222620964050293
# Step 6: Inserting both dictionaries: 0.2250525951385498
# Total time: 4.980886459350586
#
#
#
# 648518346342791878:
# 648518346342791878 mesh fetched. 0.08185076713562012
# Counter({8: 55820})
# 648518346342791878 neighborhood generated. 0.5188565254211426
# 648518346342791878 floating artifacts removed. 0.11650943756103516
# 648518346342791878 isolated nodes removed. 0.6950056552886963
# 648518346342791878 key successfully filtered. 4.76837158203125e-06
# This took  1.4132702350616455 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.431281566619873
# Step 2: Pymesh shrinkwrapping: 2.808485746383667
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2964193820953369
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1859850883483887
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342791878_mls
# Step 5: Generating and reading Skeleton: 3.0597732067108154
# Step 6: Inserting both dictionaries: 0.4814465045928955
# Total time: 9.26448392868042
#
#
#
# 648518346342792507:
# 648518346342792507 mesh fetched. 0.3979032039642334
# Counter({2: 471516, 3: 108455, 5: 52646, 10: 14285, 8: 93})
# 648518346342792507 neighborhood generated. 5.512436389923096
# 648518346342792507 floating artifacts removed. 1.101217269897461
# 648518346342792507 isolated nodes removed. 16.06099557876587
# 648518346342792507 key successfully filtered. 5.4836273193359375e-06
# This took  23.07401156425476 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 23.29309892654419
# Step 2: Pymesh shrinkwrapping: 95.21752309799194
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.430687665939331
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 10.064061641693115
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342792507_mls
# Step 5: Generating and reading Skeleton: 34.26451516151428
# Step 6: Inserting both dictionaries: 3.321068525314331
# Total time: 169.59219121932983
#
#
#
# 648518346342934077:
# 648518346342934077 mesh fetched. 0.17131876945495605
# Counter({8: 44096, 10: 11498})
# 648518346342934077 neighborhood generated. 0.5566635131835938
# 648518346342934077 floating artifacts removed. 0.11348795890808105
# 648518346342934077 isolated nodes removed. 1.2239384651184082
# 648518346342934077 key successfully filtered. 7.152557373046875e-06
# This took  2.0667564868927 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.083667278289795
# Step 2: Pymesh shrinkwrapping: 1.966956615447998
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.22810697555541992
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9896960258483887
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342934077_mls
# Step 5: Generating and reading Skeleton: 2.390111207962036
# Step 6: Inserting both dictionaries: 0.30397534370422363
# Total time: 7.964788198471069
#
#
#
# 648518346343498589:
# 648518346343498589 mesh fetched. 0.036473989486694336
# Counter({8: 6550})
# 648518346343498589 neighborhood generated. 0.09160566329956055
# 648518346343498589 floating artifacts removed. 0.02744126319885254
# 648518346343498589 isolated nodes removed. 0.11776423454284668
# 648518346343498589 key successfully filtered. 3.5762786865234375e-06
# This took  0.2746758460998535 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.27672600746154785
# Step 2: Pymesh shrinkwrapping: 0.13163471221923828
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04062628746032715
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6487083435058594
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346343498589_mls
# Step 5: Generating and reading Skeleton: 0.8086838722229004
# Step 6: Inserting both dictionaries: 0.1252894401550293
# Total time: 2.032933235168457
#
#
#
# 648518346343786855:
# 648518346343786855 mesh fetched. 0.049733877182006836
# Counter({8: 8629})
# 648518346343786855 neighborhood generated. 0.07792210578918457
# 648518346343786855 floating artifacts removed. 0.019147157669067383
# 648518346343786855 isolated nodes removed. 0.10694122314453125
# 648518346343786855 key successfully filtered. 6.9141387939453125e-06
# This took  0.25464606285095215 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.25887274742126465
# Step 2: Pymesh shrinkwrapping: 0.20238590240478516
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.053468942642211914
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6265480518341064
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346343786855_mls
# Step 5: Generating and reading Skeleton: 1.1690046787261963
# Step 6: Inserting both dictionaries: 0.21508312225341797
# Total time: 2.52608323097229
#
#
#
# 648518346343907030:
# 648518346343907030 mesh fetched. 0.25942277908325195
# Counter({10: 266891})
# only error segments
# This took  0.31545400619506836 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.31569957733154297
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.032712459564208984
# Total time: 0.34851884841918945
#
#
#
# 648518346344072312:
# 648518346344072312 mesh fetched. 0.12184739112854004
# Counter({8: 19074, 10: 3734})
# 648518346344072312 neighborhood generated. 0.20926880836486816
# 648518346344072312 floating artifacts removed. 0.04840397834777832
# 648518346344072312 isolated nodes removed. 0.47170352935791016
# 648518346344072312 key successfully filtered. 5.245208740234375e-06
# This took  0.8525936603546143 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8593540191650391
# Step 2: Pymesh shrinkwrapping: 0.4081907272338867
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09659290313720703
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7769589424133301
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346344072312_mls
# Step 5: Generating and reading Skeleton: 1.2086098194122314
# Step 6: Inserting both dictionaries: 0.22704029083251953
# Total time: 3.578516721725464
#
#
#
# 648518346344080380:
# 648518346344080380 mesh fetched. 0.17506790161132812
# Counter({8: 42769})
# 648518346344080380 neighborhood generated. 0.35247111320495605
# 648518346344080380 floating artifacts removed. 0.07662820816040039
# 648518346344080380 isolated nodes removed. 0.4510343074798584
# 648518346344080380 key successfully filtered. 5.4836273193359375e-06
# This took  1.0563504695892334 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.0700013637542725
# Step 2: Pymesh shrinkwrapping: 0.9573142528533936
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.21663355827331543
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.273414134979248
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346344080380_mls
# Step 5: Generating and reading Skeleton: 3.0168347358703613
# Step 6: Inserting both dictionaries: 0.34027528762817383
# Total time: 6.875855207443237
#
#
#
# 648518346344142091:
# 648518346344142091 mesh fetched. 0.07974696159362793
# Counter({8: 28716})
# 648518346344142091 neighborhood generated. 0.3680911064147949
# 648518346344142091 floating artifacts removed. 0.10181283950805664
# 648518346344142091 isolated nodes removed. 0.4152708053588867
# 648518346344142091 key successfully filtered. 4.0531158447265625e-06
# This took  0.9667489528656006 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9763331413269043
# Step 2: Pymesh shrinkwrapping: 0.6804399490356445
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.14275217056274414
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.236337423324585
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346344142091_mls
# Step 5: Generating and reading Skeleton: 2.9171700477600098
# Step 6: Inserting both dictionaries: 0.26464223861694336
# Total time: 6.218632221221924
#
#
#
# 648518346344543072:
# 648518346344543072 mesh fetched. 0.07985782623291016
# Counter({8: 15020})
# 648518346344543072 neighborhood generated. 0.15749382972717285
# 648518346344543072 floating artifacts removed. 0.03460550308227539
# 648518346344543072 isolated nodes removed. 0.1856062412261963
# 648518346344543072 key successfully filtered. 5.0067901611328125e-06
# This took  0.4586367607116699 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.46376609802246094
# Step 2: Pymesh shrinkwrapping: 0.37648582458496094
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07856345176696777
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.709531307220459
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346344543072_mls
# Step 5: Generating and reading Skeleton: 1.215308666229248
# Step 6: Inserting both dictionaries: 0.16207122802734375
# Total time: 3.0064659118652344
#
#
#
# 648518346345765793:
# 648518346345765793 mesh fetched. 0.08799028396606445
# Counter({8: 16268})
# 648518346345765793 neighborhood generated. 0.22271156311035156
# 648518346345765793 floating artifacts removed. 0.034273624420166016
# 648518346345765793 isolated nodes removed. 0.2821521759033203
# 648518346345765793 key successfully filtered. 5.4836273193359375e-06
# This took  0.6284694671630859 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.63433837890625
# Step 2: Pymesh shrinkwrapping: 0.8314752578735352
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0815117359161377
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7029836177825928
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346345765793_mls
# Step 5: Generating and reading Skeleton: 1.9791982173919678
# ...
# Step 5: Generating and reading Skeleton: 4.0326478481292725
# Step 6: Inserting both dictionaries: 0.4935343265533447
# Total time: 11.91667127609253
#
#
#
# 648518346346315272:
# 648518346346315272 mesh fetched. 0.09235954284667969
# Counter({8: 38330})
# 648518346346315272 neighborhood generated. 0.30700063705444336
# 648518346346315272 floating artifacts removed. 0.06909346580505371
# 648518346346315272 isolated nodes removed. 0.40782594680786133
# 648518346346315272 key successfully filtered. 4.5299530029296875e-06
# This took  0.8772227764129639 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8924024105072021
# Step 2: Pymesh shrinkwrapping: 1.1197755336761475
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.20066118240356445
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9697220325469971
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346315272_mls
# Step 5: Generating and reading Skeleton: 2.2021191120147705
# Step 6: Inserting both dictionaries: 0.3681201934814453
# Total time: 5.753894329071045
#
#
#
# 648518346346953540:
# 648518346346953540 mesh fetched. 0.04889798164367676
# Counter({8: 14632})
# 648518346346953540 neighborhood generated. 0.14612889289855957
# 648518346346953540 floating artifacts removed. 0.030358076095581055
# 648518346346953540 isolated nodes removed. 0.25763535499572754
# 648518346346953540 key successfully filtered. 5.9604644775390625e-06
# This took  0.4836745262145996 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.48865771293640137
# Step 2: Pymesh shrinkwrapping: 0.47971606254577637
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07750225067138672
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6443755626678467
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346953540_mls
# Step 5: Generating and reading Skeleton: 1.6025893688201904
# Step 6: Inserting both dictionaries: 0.20324397087097168
# Total time: 3.496903657913208
#
#
#
# 648518346347002377:
# 648518346347002377 mesh fetched. 0.09958887100219727
# Counter({8: 14892})
# 648518346347002377 neighborhood generated. 0.1829051971435547
# 648518346347002377 floating artifacts removed. 0.03248119354248047
# 648518346347002377 isolated nodes removed. 0.2644622325897217
# 648518346347002377 key successfully filtered. 7.62939453125e-06
# This took  0.5802857875823975 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5896041393280029
# Step 2: Pymesh shrinkwrapping: 0.3947584629058838
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12616610527038574
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7221269607543945
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346347002377_mls
# Step 5: Generating and reading Skeleton: 0.9969291687011719
# Step 6: Inserting both dictionaries: 0.1886734962463379
# Total time: 3.0192766189575195
#
#
#
# 648518346348107845:
# 648518346348107845 mesh fetched. 0.13035011291503906
# Counter({8: 8777})
# 648518346348107845 neighborhood generated. 0.0853264331817627
# 648518346348107845 floating artifacts removed. 0.0197598934173584
# 648518346348107845 isolated nodes removed. 0.1073455810546875
# 648518346348107845 key successfully filtered. 3.337860107421875e-06
# This took  0.3435676097869873 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3465747833251953
# Step 2: Pymesh shrinkwrapping: 0.23769497871398926
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05423283576965332
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6247618198394775
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348107845_mls
# Step 5: Generating and reading Skeleton: 1.2500572204589844
# Step 6: Inserting both dictionaries: 0.2106029987335205
# Total time: 2.7250609397888184
#
#
#
# 648518346348114181:
# 648518346348114181 mesh fetched. 0.0937507152557373
# Counter({8: 11863})
# 648518346348114181 neighborhood generated. 0.15001988410949707
# 648518346348114181 floating artifacts removed. 0.02625298500061035
# 648518346348114181 isolated nodes removed. 0.14980077743530273
# 648518346348114181 key successfully filtered. 4.5299530029296875e-06
# This took  0.4205505847930908 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4249002933502197
# Step 2: Pymesh shrinkwrapping: 0.2717442512512207
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0711362361907959
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7222955226898193
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348114181_mls
# Step 5: Generating and reading Skeleton: 1.6386613845825195
# Step 6: Inserting both dictionaries: 0.20816516876220703
# Total time: 3.3376834392547607
#
#
#
# 648518346348123146:
# 648518346348123146 mesh fetched. 0.08924412727355957
# Counter({8: 57140})
# 648518346348123146 neighborhood generated. 0.6201086044311523
# 648518346348123146 floating artifacts removed. 0.12070322036743164
# 648518346348123146 isolated nodes removed. 0.6276495456695557
# 648518346348123146 key successfully filtered. 4.5299530029296875e-06
# This took  1.4587535858154297 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.477459192276001
# Step 2: Pymesh shrinkwrapping: 1.6625733375549316
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2997920513153076
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9950766563415527
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348123146_mls
# Step 5: Generating and reading Skeleton: 2.8684732913970947
# Step 6: Inserting both dictionaries: 0.4195115566253662
# Total time: 7.723725318908691
#
#
#
# 648518346348197349:
# 648518346348197349 mesh fetched. 0.09649896621704102
# Counter({8: 48792})
# 648518346348197349 neighborhood generated. 0.42239832878112793
# 648518346348197349 floating artifacts removed. 0.15055418014526367
# 648518346348197349 isolated nodes removed. 0.690216064453125
# 648518346348197349 key successfully filtered. 7.62939453125e-06
# This took  1.3606843948364258 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.378873348236084
# Step 2: Pymesh shrinkwrapping: 1.3866043090820312
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.25652027130126953
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1191132068634033
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348197349_mls
# Step 5: Generating and reading Skeleton: 2.72589373588562
# Step 6: Inserting both dictionaries: 0.4308338165283203
# Total time: 7.2995991706848145
#
#
#
# 648518346348210989:
# 648518346348210989 mesh fetched. 0.10225701332092285
# Counter({8: 10916})
# 648518346348210989 neighborhood generated. 0.16393351554870605
# 648518346348210989 floating artifacts removed. 0.031003952026367188
# 648518346348210989 isolated nodes removed. 0.14278888702392578
# 648518346348210989 key successfully filtered. 5.245208740234375e-06
# This took  0.44103002548217773 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4451289176940918
# Step 2: Pymesh shrinkwrapping: 0.4113130569458008
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06460261344909668
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6884369850158691
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348210989_mls
# Step 5: Generating and reading Skeleton: 1.7070839405059814
# Step 6: Inserting both dictionaries: 0.14955949783325195
# Total time: 3.4667961597442627
#
#
#
# 648518346348464169:
# 648518346348464169 mesh fetched. 0.09857749938964844
# Counter({8: 11751, 10: 9332})
# 648518346348464169 neighborhood generated. 0.19401121139526367
# 648518346348464169 floating artifacts removed. 0.04505133628845215
# 648518346348464169 isolated nodes removed. 0.30007386207580566
# 648518346348464169 key successfully filtered. 6.198883056640625e-06
# This took  0.6389100551605225 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6456451416015625
# Step 2: Pymesh shrinkwrapping: 0.34976673126220703
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.060194969177246094
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.708590030670166
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348464169_mls
# Step 5: Generating and reading Skeleton: 1.1652734279632568
# Step 6: Inserting both dictionaries: 0.18495750427246094
# Total time: 3.1153910160064697
#
#
#
# 648518346349094845:
# 648518346349094845 mesh fetched. 0.15915369987487793
# Counter({8: 13646})
# 648518346349094845 neighborhood generated. 0.14862871170043945
# 648518346349094845 floating artifacts removed. 0.02975606918334961
# 648518346349094845 isolated nodes removed. 0.2550785541534424
# 648518346349094845 key successfully filtered. 5.245208740234375e-06
# This took  0.5937931537628174 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5982885360717773
# Step 2: Pymesh shrinkwrapping: 0.3175661563873291
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07273721694946289
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7167043685913086
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349094845_mls
# Step 5: Generating and reading Skeleton: 1.1492834091186523
# Step 6: Inserting both dictionaries: 0.1841747760772705
# Total time: 3.0397446155548096
#
#
#
# 648518346349371065:
# 648518346349371065 mesh fetched. 0.16582441329956055
# Counter({8: 53075})
# 648518346349371065 neighborhood generated. 0.5184497833251953
# 648518346349371065 floating artifacts removed. 0.11256980895996094
# 648518346349371065 isolated nodes removed. 0.577014684677124
# 648518346349371065 key successfully filtered. 5.0067901611328125e-06
# This took  1.3748981952667236 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.3906848430633545
# Step 2: Pymesh shrinkwrapping: 1.3386461734771729
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2724027633666992
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1748507022857666
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349371065_mls
# Step 5: Generating and reading Skeleton: 2.5000956058502197
# Step 6: Inserting both dictionaries: 0.4046001434326172
# Total time: 7.082068204879761
#
#
#
# 648518346349383336:
# 648518346349383336 mesh fetched. 0.19195055961608887
# Counter({8: 42305})
# 648518346349383336 neighborhood generated. 0.4283006191253662
# 648518346349383336 floating artifacts removed. 0.09092831611633301
# 648518346349383336 isolated nodes removed. 0.5017445087432861
# 648518346349383336 key successfully filtered. 4.76837158203125e-06
# This took  1.2143495082855225 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.2275309562683105
# Step 2: Pymesh shrinkwrapping: 1.1703391075134277
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2907407283782959
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9213211536407471
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349383336_mls
# Step 5: Generating and reading Skeleton: 2.7219386100769043
# Step 6: Inserting both dictionaries: 0.36838507652282715
# Total time: 6.702042818069458
#
#
#
# 648518346349386250:
# 648518346349386250 mesh fetched. 0.17075204849243164
# Counter({8: 29184})
# 648518346349386250 neighborhood generated. 0.3601551055908203
# 648518346349386250 floating artifacts removed. 0.06186342239379883
# 648518346349386250 isolated nodes removed. 0.36225461959838867
# 648518346349386250 key successfully filtered. 5.4836273193359375e-06
# This took  0.9560940265655518 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9666879177093506
# Step 2: Pymesh shrinkwrapping: 0.7208237648010254
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15538382530212402
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9076921939849854
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349386250_mls
# Step 5: Generating and reading Skeleton: 1.867290735244751
# Step 6: Inserting both dictionaries: 0.2878732681274414
# Total time: 4.906601190567017
#
#
#
# 648518346349388180:
# 648518346349388180 mesh fetched. 0.1633436679840088
# Counter({8: 20273})
# 648518346349388180 neighborhood generated. 0.2391188144683838
# 648518346349388180 floating artifacts removed. 0.043540000915527344
# 648518346349388180 isolated nodes removed. 0.2578613758087158
# 648518346349388180 key successfully filtered. 5.245208740234375e-06
# This took  0.7046160697937012 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.7117934226989746
# Step 2: Pymesh shrinkwrapping: 0.5264480113983154
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10884475708007812
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7416143417358398
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349388180_mls
# Step 5: Generating and reading Skeleton: 1.5032951831817627
# Step 6: Inserting both dictionaries: 0.2112288475036621
# Total time: 3.804213285446167
#
#
#
# 648518346349472082:
# 648518346349472082 mesh fetched. 0.17667150497436523
# Counter({8: 138696, 10: 3150})
# 648518346349472082 neighborhood generated. 1.4673511981964111
# 648518346349472082 floating artifacts removed. 0.4169907569885254
# 648518346349472082 isolated nodes removed. 3.280332565307617
# 648518346349472082 key successfully filtered. 5.0067901611328125e-06
# This took  5.34275221824646 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.390357255935669
# Step 2: Pymesh shrinkwrapping: 7.644918203353882
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7514784336090088
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.5775227546691895
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349472082_mls
# Step 5: Generating and reading Skeleton: 7.566172361373901
# Step 6: Inserting both dictionaries: 0.7977709770202637
# Total time: 24.729467630386353
#
#
#
# 648518346349483668:
# 648518346349483668 mesh fetched. 0.1570756435394287
# Counter({8: 108228})
# 648518346349483668 neighborhood generated. 1.2121267318725586
# 648518346349483668 floating artifacts removed. 0.22750353813171387
# 648518346349483668 isolated nodes removed. 1.1810736656188965
# 648518346349483668 key successfully filtered. 5.4836273193359375e-06
# This took  2.778810501098633 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.8175711631774902
# Step 2: Pymesh shrinkwrapping: 5.626564025878906
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5754845142364502
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.5763318538665771
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349483668_mls
# Step 5: Generating and reading Skeleton: 11.631715774536133
# Step 6: Inserting both dictionaries: 0.7664704322814941
# Total time: 22.995187997817993
#
#
#
# 648518346349502704:
# 648518346349502704 mesh fetched. 0.3022956848144531
# Counter({10: 857937})
# only error segments
# This took  0.47316408157348633 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.473254919052124
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.021051883697509766
# Total time: 0.49439358711242676
#
#
#
# 648518346349502858:
# 648518346349502858 mesh fetched. 0.1135249137878418
# Counter({8: 151621})
# 648518346349502858 neighborhood generated. 1.3660681247711182
# 648518346349502858 floating artifacts removed. 0.34947824478149414
# 648518346349502858 isolated nodes removed. 1.7978615760803223
# 648518346349502858 key successfully filtered. 5.245208740234375e-06
# This took  3.6278185844421387 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.678676128387451
# Step 2: Pymesh shrinkwrapping: 14.099990844726562
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.8154811859130859
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.3548483848571777
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349502858_mls
# Step 5: Generating and reading Skeleton: 7.3935933113098145
# Step 6: Inserting both dictionaries: 0.860508918762207
# Total time: 29.20542597770691
#
#
#
# 7073.683137893677
