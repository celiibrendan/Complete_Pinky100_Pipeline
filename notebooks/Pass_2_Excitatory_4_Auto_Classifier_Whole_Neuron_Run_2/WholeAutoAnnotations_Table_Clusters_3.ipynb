# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349495971******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05331540107727051
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 283.4390461444855
# 2) Finished: Generating CGAL segmentation for neuron: 292.6200735569
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.11817765235900879
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [11, 13, 15, 141, 3, 174, 140, 17, 152, 4]
# soma_80_percent = 221792.6890625
# Debugging the axon filter
# [(11, 232950.453125), (13, 257568.984375), (15, 266394.34375), (141, 221293.78125), (3, 222944.578125), (174, 221971.71875), (140, 226385.9375), (17, 241243.640625), (152, 216936.1875), (4, 228061.390625)]
# possible_Axons_filter_1 = [141, 152]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.03758502006530762
# 6) Staring: Classifying Entire Neuron
# 140 = stub soma
# 141 = stub soma
# 174 = cilia
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.0103950500488281
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4196591377258301
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.0101282596588135
# Finished Auto Labeling: 299.6692488193512
#
#
# *****Starting Auto Labeling for 648518346349496058******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.016317129135131836
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 126.48746657371521
# 2) Finished: Generating CGAL segmentation for neuron: 132.3606641292572
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06506824493408203
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [16, 0, 14, 40, 25, 46, 12, 4, 19, 18, 48, 5, 49, 38, 24, 20, 42, 21, 32, 30, 31]
# soma_80_percent = 228046.4125
# Debugging the axon filter
# [(16, 234818.53125), (0, 237719.140625), (14, 237703.796875), (40, 228458.65625), (25, 230710.328125), (46, 235741.6875), (12, 241057.828125), (4, 238275.0), (19, 229289.34375), (18, 237920.40625), (48, 235622.59375), (5, 231533.875), (49, 235072.765625), (38, 228597.875), (24, 234892.921875), (20, 226136.71875), (42, 225117.515625), (21, 237249.375), (32, 230921.046875), (30, 231962.546875), (31, 233625.640625)]
# possible_Axons_filter_1 = [20, 42]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.03278994560241699
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 0
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 16
# 14 = stub soma
# 18 = stub soma
# 19 = stub soma
# 20 = stub soma
# 21 = stub soma
# 24 = stub soma
# 25 = stub soma
# 30 = stub soma
# 31 = stub soma
# 32 = stub soma
# 38 = stub soma
# 40 = stub soma
# 42 = stub soma
# 46 = stub soma
# 48 = stub soma
# 49 = stub soma
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 0.7034037113189697
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.27653050422668457
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.9171266555786133
# Finished Auto Labeling: 136.56900191307068
#
#
# *****Starting Auto Labeling for 648518346349496554******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08307123184204102
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1286.8116042613983
# 2) Finished: Generating CGAL segmentation for neuron: 1309.9396975040436
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 13
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2868030071258545
# 5) Staring: Finding Apical Index
# Soma Index = 13
# Soma Connections = [5, 12, 23, 28, 32, 36, 16, 54, 30, 72, 63, 155, 51]
# soma_80_percent = 208567.3859375
# Debugging the axon filter
# [(5, 205049.5625), (12, 233005.65625), (23, 214551.921875), (28, 220004.4375), (32, 229533.28125), (36, 214893.0625), (16, 213694.578125), (54, 208760.0), (30, 216012.890625), (72, 225413.90625), (63, 215600.546875), (155, 212629.171875), (51, 209588.75)]
# possible_Axons_filter_1 = [5]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.09726619720458984
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 16
# 32 = axon
# 36 = stub soma
# 51 = cilia
# 54 = stub soma
# 155 = stub soma
# 9 = stub apical
# 18 = stub apical
# 21 = stub apical
# 24 = stub apical
# 25 = error
# 27 = stub apical
# 31 = stub apical
# 37 = error
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 48 = stub apical
# 49 = stub apical
# 52 = stub apical
# 53 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 87 = stub apical
# 88 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = error
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 156 = stub apical
# 157 = stub apical
# 159 = stub apical
# Total Labels found = {'apical', 'basal', 'error', 'axon', 'cilia', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.3982717990875244
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5662641525268555
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.143354415893555
# Finished Auto Labeling: 1328.360030889511
#
#
# *****Starting Auto Labeling for 648518346349500277******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04099535942077637
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 828.8036150932312
# 2) Finished: Generating CGAL segmentation for neuron: 846.0227773189545
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22585248947143555
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 2, 3, 4, 26, 50, 12, 30, 25, 225, 192, 22, 260, 259, 253, 252]
# soma_80_percent = 244927.5921875
# Debugging the axon filter
# [(1, 244494.59375), (2, 244479.96875), (3, 245304.75), (4, 241732.6875), (26, 247724.8125), (50, 254934.90625), (12, 268629.1875), (30, 272005.71875), (25, 265555.84375), (225, 242253.328125), (192, 245816.0625), (22, 261269.1875), (260, 243490.203125), (259, 245761.359375), (253, 251628.96875), (252, 250911.859375)]
# possible_Axons_filter_1 = [1, 2, 4, 225, 260]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.11283016204833984
# 6) Staring: Classifying Entire Neuron
# 260 = cilia
# 192 = stub soma
# 225 = stub soma
# 252 = stub soma
# 253 = stub soma
# 259 = stub soma
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 2.206786632537842
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.7009623050689697
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.36873173713684
# Finished Auto Labeling: 859.377147436142
#
#
# *****Starting Auto Labeling for 648518346349501787******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03647637367248535
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 587.342869758606
# 2) Finished: Generating CGAL segmentation for neuron: 601.9420473575592
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19170880317687988
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 14, 12, 173, 64, 8, 23, 530, 288, 105, 440]
# soma_80_percent = 205009.6515625
# Debugging the axon filter
# [(0, 209337.125), (14, 245549.484375), (12, 296347.78125), (173, 216663.09375), (64, 215792.4375), (8, 233325.6875), (23, 223220.640625), (530, 213962.625), (288, 215912.90625), (105, 205219.890625), (440, 212577.890625)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.0691535472869873
# 6) Staring: Classifying Entire Neuron
# 105 = stub soma
# 288 = cilia
# 440 = stub soma
# 530 = stub soma
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 2.202545166015625
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6289815902709961
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.094667196273804
# Finished Auto Labeling: 617.3687736988068
#
#
# *****Starting Auto Labeling for 648518346349503766******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03950643539428711
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1103.5040650367737
# 2) Finished: Generating CGAL segmentation for neuron: 1124.204077720642
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.26412463188171387
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [334, 8, 269, 28, 45, 38, 35, 77, 55, 16, 15, 413, 145, 202, 243, 212, 343, 405]
# soma_80_percent = 252736.6484375
# Debugging the axon filter
# [(334, 249538.890625), (8, 248077.828125), (269, 250403.578125), (28, 278328.15625), (45, 255715.171875), (38, 277052.09375), (35, 261537.09375), (77, 264026.1875), (55, 283738.84375), (16, 269462.75), (15, 272800.875), (413, 250084.1875), (145, 263348.15625), (202, 257521.640625), (243, 258792.59375), (212, 264092.3125), (343, 262043.8125), (405, 250566.921875)]
# possible_Axons_filter_1 = [334, 8, 269, 413, 405]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.14871835708618164
# 6) Staring: Classifying Entire Neuron
# 269 = cilia
# 145 = cilia
# 202 = stub soma
# 212 = stub soma
# 243 = stub soma
# 334 = stub soma
# 343 = stub soma
# 405 = stub soma
# 413 = stub soma
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 2.6782400608062744
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.8326997756958008
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.06442666053772
# Finished Auto Labeling: 1141.039546251297
#
#
# *****Starting Auto Labeling for 648518346349505739******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.031214475631713867
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 383.39754152297974
# 2) Finished: Generating CGAL segmentation for neuron: 394.74959444999695
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.16703391075134277
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [5, 1, 14, 2, 305, 412]
# soma_80_percent = 301167.61875
# Debugging the axon filter
# [(5, 308454.09375), (1, 309470.0625), (14, 304489.78125), (2, 298441.84375), (305, 305678.40625), (412, 300904.28125)]
# possible_Axons_filter_1 = [2, 412]
# possible_Axons_filter_2 = [2]
# possible_Apical = 2
# 5) Finished: Finding Apical Index: 0.099945068359375
# 6) Staring: Classifying Entire Neuron
# 5 = error
# 305 = stub soma
# 412 = stub soma
# 11 = error
# 13 = stub apical
# 15 = stub apical
# 16 = stub apical
# 17 = stub apical
# 19 = stub apical
# 20 = stub apical
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 26 = error
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 38 = stub apical
# 42 = stub apical
# 43 = error
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = error
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = error
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 396 = stub apical
# 398 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 403 = stub apical
# 404 = stub apical
# 405 = stub apical
# 406 = stub apical
# 407 = stub apical
# 408 = stub apical
# 409 = stub apical
# 410 = stub apical
# 411 = stub apical
# 413 = stub apical
# 414 = stub apical
# 415 = stub apical
# 416 = stub apical
# 417 = stub apical
# 418 = stub apical
# 419 = stub apical
# 420 = stub apical
# 421 = stub apical
# 422 = stub apical
# 423 = stub apical
# 424 = stub apical
# 425 = stub apical
# 426 = stub apical
# 427 = stub apical
# 428 = stub apical
# 429 = stub apical
# 430 = stub apical
# 432 = stub apical
# 433 = stub apical
# 434 = stub apical
# 435 = stub apical
# 436 = stub apical
# 437 = stub apical
# 438 = stub apical
# 439 = stub apical
# 440 = stub apical
# 441 = stub apical
# 442 = stub apical
# 443 = stub apical
# 444 = stub apical
# 445 = stub apical
# 446 = stub apical
# 447 = stub apical
# 448 = stub apical
# 449 = stub apical
# 450 = stub apical
# 451 = stub apical
# 452 = stub apical
# 453 = stub apical
# 454 = stub apical
# 455 = stub apical
# 456 = stub apical
# 457 = stub apical
# 458 = stub apical
# 459 = stub apical
# 460 = stub apical
# 461 = stub apical
# 462 = stub apical
# 463 = stub apical
# 464 = stub apical
# 465 = stub apical
# 466 = stub apical
# 467 = stub apical
# 468 = stub apical
# 469 = stub apical
# 471 = stub apical
# 472 = stub apical
# 473 = stub apical
# Total Labels found = {'apical', 'basal', 'error', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.7269401550292969
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.32975196838378906
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.220132350921631
# Finished Auto Labeling: 403.71417570114136
#
#
# *****Starting Auto Labeling for 648518346349506513******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.050443172454833984
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 796.167078256607
# 2) Finished: Generating CGAL segmentation for neuron: 813.2557208538055
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21387767791748047
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [18, 17, 21, 10, 27, 9, 39, 13, 42, 60, 53, 41, 35, 61, 62, 56, 44, 57, 52, 32, 40]
# soma_80_percent = 267025.271875
# Debugging the axon filter
# [(18, 276110.8125), (17, 266877.125), (21, 282833.84375), (10, 262910.4375), (27, 266506.34375), (9, 290370.9375), (39, 273500.09375), (13, 290804.53125), (42, 278115.40625), (60, 276178.53125), (53, 275499.5625), (41, 273564.875), (35, 265372.0625), (61, 276263.09375), (62, 275982.46875), (56, 270965.9375), (44, 267223.53125), (57, 270348.1875), (52, 270512.96875), (32, 262689.5), (40, 274002.28125)]
# possible_Axons_filter_1 = [17, 10, 27, 35, 32]
# possible_Axons_filter_2 = [10]
# possible_Apical = 10
# 5) Finished: Finding Apical Index: 0.09490251541137695
# 6) Staring: Classifying Entire Neuron
# 35 = cilia
# 32 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 39
# 40 = stub soma
# 41 = stub soma
# 42 = axon
# 44 = stub soma
# 52 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 53
# 56 = stub soma
# 57 = stub soma
# 60 = stub soma
# 61 = stub soma
# 62 = stub soma
# 36 = stub apical
# 43 = stub apical
# 45 = stub apical
# 46 = stub apical
# 48 = stub apical
# 63 = stub apical
# Total Labels found = {'apical', 'basal', 'axon', 'cilia', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.016450881958008
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5303316116333008
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.028518915176392
# Finished Auto Labeling: 826.7379655838013
#
#
# *****Starting Auto Labeling for 648518346349508969******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03812241554260254
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 625.2132079601288
# 2) Finished: Generating CGAL segmentation for neuron: 640.962150812149
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19549012184143066
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [12, 5, 59, 28, 4, 14, 61, 17, 25, 31, 32, 23, 53, 62, 96, 78, 27, 65]
# soma_80_percent = 182330.903125
# Debugging the axon filter
# [(12, 194769.140625), (5, 199603.796875), (59, 194489.375), (28, 196056.984375), (4, 177744.375), (14, 188597.15625), (61, 195722.5), (17, 179359.609375), (25, 180654.65625), (31, 206504.5625), (32, 195098.078125), (23, 189770.25), (53, 193217.015625), (62, 196697.203125), (96, 190841.578125), (78, 181885.625), (27, 192581.296875), (65, 179171.546875)]
# possible_Axons_filter_1 = [4, 17, 25, 78, 65]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.0796971321105957
# 6) Staring: Classifying Entire Neuron
# 31 = error
# 25 = stub soma
# 27 = stub soma
# 53 = stub soma
# 78 = cilia
# 59 = stub soma
# 61 = stub soma
# 62 = stub soma
# 65 = stub soma
# 96 = stub soma
# Total Labels found = {'apical', 'basal', 'error', 'cilia', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.6708896160125732
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4132399559020996
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.886544466018677
# Finished Auto Labeling: 652.7871537208557
#
#
# *****Starting Auto Labeling for 648518346349510800******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.01716136932373047
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 127.55176782608032
# 2) Finished: Generating CGAL segmentation for neuron: 132.9329583644867
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06856775283813477
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [3, 13, 22, 16, 4, 17, 2, 7, 11, 6, 33]
# soma_80_percent = 254373.2015625
# Debugging the axon filter
# [(3, 264067.78125), (13, 263248.875), (22, 251317.375), (16, 275041.84375), (4, 262996.03125), (17, 264214.40625), (2, 262211.25), (7, 264452.59375), (11, 272057.0), (6, 265137.3125), (33, 259564.0625)]
# possible_Axons_filter_1 = [22]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.02819514274597168
# 6) Staring: Classifying Entire Neuron
# 3 = cilia
# 6 = cilia
# 22 = stub soma
# 33 = stub soma
# Total Labels found = {'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 0.6356923580169678
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.27154970169067383
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.065406560897827
# Finished Auto Labeling: 137.22698259353638
#
#
# *****Starting Auto Labeling for 648518346349511212******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.015787839889526367
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 133.3743975162506
# 2) Finished: Generating CGAL segmentation for neuron: 138.80658507347107
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06766915321350098
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 11, 21, 15, 6, 9, 2, 39, 7, 59, 67, 43, 19, 57, 69, 38, 20, 26, 66, 44, 29, 13, 17, 46, 37, 52, 31, 58, 33]
# soma_80_percent = 284828.853125
# Debugging the axon filter
# [(1, 299470.59375), (11, 282762.40625), (21, 282626.5625), (15, 288232.03125), (6, 282820.34375), (9, 293943.90625), (2, 295654.96875), (39, 291180.96875), (7, 281609.375), (59, 285863.96875), (67, 291435.03125), (43, 283852.25), (19, 284055.96875), (57, 281747.53125), (69, 291219.3125), (38, 282190.21875), (20, 289724.15625), (26, 291250.71875), (66, 290587.8125), (44, 285317.75), (29, 284512.1875), (13, 292812.90625), (17, 283296.0), (46, 292904.78125), (37, 285599.65625), (52, 288006.0), (31, 282998.375), (58, 285312.59375), (33, 286314.9375)]
# possible_Axons_filter_1 = [11, 21, 6, 7, 43, 19, 57, 38, 29, 17, 31]
# possible_Axons_filter_2 = [6, 7]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.05145621299743652
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 6
# 11 = stub soma
# 17 = stub soma
# 20 = stub soma
# 21 = stub soma
# 26 = stub soma
# 29 = stub soma
# 31 = stub soma
# 33 = stub soma
# 37 = stub soma
# 38 = stub soma
# 39 = stub soma
# 43 = stub soma
# 44 = stub soma
# 46 = stub soma
# 52 = stub soma
# 57 = stub soma
# 58 = stub soma
# 59 = stub soma
# 66 = stub soma
# 67 = stub soma
# 69 = stub soma
# 14 = stub apical
# 16 = stub apical
# 23 = stub apical
# 24 = stub apical
# 34 = stub apical
# 40 = stub apical
# 41 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 54 = stub apical
# 61 = stub apical
# 62 = stub apical
# Total Labels found = {'apical', 'basal', 'error', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 0.6189603805541992
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.16770410537719727
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.8911707401275635
# Finished Auto Labeling: 142.83526730537415
#
#
# *****Starting Auto Labeling for 648518346349511528******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0433192253112793
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 464.35488748550415
# 2) Finished: Generating CGAL segmentation for neuron: 476.78268122673035
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1597435474395752
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 8, 11, 3, 73, 38, 169, 15, 25, 116, 95, 64, 143, 176, 174, 118, 168, 160]
# soma_80_percent = 283119.828125
# Debugging the axon filter
# [(1, 298005.125), (8, 298875.8125), (11, 299658.0), (3, 278910.0), (73, 281363.34375), (38, 292298.28125), (169, 286378.59375), (15, 282246.5625), (25, 300676.90625), (116, 288173.75), (95, 288247.71875), (64, 290379.0625), (143, 288157.53125), (176, 292356.4375), (174, 291546.0), (118, 288536.5), (168, 284721.71875), (160, 290519.71875)]
# possible_Axons_filter_1 = [3, 73, 15]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.08693265914916992
# 6) Staring: Classifying Entire Neuron
# 11 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 15
# 160 = cilia
# 64 = stub soma
# 73 = cilia
# 95 = stub soma
# 116 = stub soma
# 118 = stub soma
# 143 = stub soma
# 168 = stub soma
# 169 = stub soma
# 174 = stub soma
# 176 = stub soma
# 18 = stub apical
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 28 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = error
# 42 = stub apical
# 43 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 58 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 94 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 133 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 161 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 173 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# Total Labels found = {'apical', 'basal', 'error', 'axon', 'cilia', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 1.6629884243011475
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.37649989128112793
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.281774044036865
# Finished Auto Labeling: 486.8285663127899
#
#
# *****Starting Auto Labeling for 648518346349513079******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06507325172424316
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1217.0401859283447
# 2) Finished: Generating CGAL segmentation for neuron: 1237.270757675171
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2644388675689697
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [13, 1, 15, 27, 26, 30, 116, 204, 199, 237]
# soma_80_percent = 239016.9015625
# Debugging the axon filter
# [(13, 257361.109375), (1, 235422.140625), (15, 269481.8125), (27, 254298.8125), (26, 251966.015625), (30, 245904.078125), (116, 236375.90625), (204, 236201.21875), (199, 248934.21875), (237, 251020.9375)]
# possible_Axons_filter_1 = [1, 116, 204]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.10517311096191406
# 6) Staring: Classifying Entire Neuron
# 116 = cilia
# 199 = stub soma
# 204 = stub soma
# 237 = stub soma
# 22 = stub apical
# 29 = stub apical
# 31 = stub apical
# 32 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 143 = stub apical
# 144 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 156 = stub apical
# 157 = stub apical
# 159 = stub apical
# 160 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 205 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# Total Labels found = {'apical', 'basal', 'cilia', 'soma', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.309986114501953
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5003261566162109
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.235349655151367
# Finished Auto Labeling: 1252.4901876449585
# 8288.023094177246

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
