# %%
import datajoint as dj
import numpy as np
import time
from tqdm import tqdm

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

pinky = dj.create_virtual_module('pinky', 'microns_pinky')
schema = dj.schema('microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.ProofreadLabelOrphan() & "segment_id=648518346341352006"

# %%
#ta3p100.CleansedMeshOrphan()

# %%
@schema
class CoarseLabelOrphan(dj.Computed):
    definition = """
    # Vertex labels for pinky.ProofreadLabelOrphan did not correctly match the triangle labels, so these are regenerated from the correct triangle labels.
    -> pinky.ProofreadLabelOrphan
    ---
    vertices  : longblob # Corrected vertex labels
    triangles : longblob # Same triangle labels as pinky.ProofreadLabelOrphan
    """
    
    key_source = pinky.ProofreadLabelOrphan & 'status="complete"'
    
    def make(self, key):
        start = time.time()
        
        print(key["segment_id"])
        labels = (pinky.ProofreadLabelOrphan & key).fetch1()
        corrected_vertex_labels = np.zeros(labels['vertices'].shape, np.uint8)
        
        mesh = (pinky.Decimation35OrphanStitched & 'decimation_ratio=0.35' & dict(segment_id=key['segment_id'])).fetch1()
        mesh_triangles = mesh['triangles']
        
        vertex_label_dict = dict()
        for i, label in enumerate(labels['triangles']):
            triangle = mesh_triangles[i]
            for node in triangle:
                if node in vertex_label_dict:
                    if vertex_label_dict[node] < label:
                        vertex_label_dict[node] = label
                else:
                    vertex_label_dict[node] = label
                
        for node, label in vertex_label_dict.items():
            corrected_vertex_labels[node] = label
            
        self.insert1(dict(key,
                          vertices=corrected_vertex_labels,
                          triangles=labels['triangles']))
        
        print("Segment {} vertex labels regenerated in: {} seconds.".format(key['segment_id'], time.time() - start))

# %%
start = time.time()
CoarseLabelOrphan.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341404207
# Segment 648518346341404207 vertex labels regenerated in: 0.4723787307739258 seconds.
# 648518346341405293
# Segment 648518346341405293 vertex labels regenerated in: 0.6489119529724121 seconds.
# 648518346341406029
# Segment 648518346341406029 vertex labels regenerated in: 0.63423752784729 seconds.
# 648518346341407729
# Segment 648518346341407729 vertex labels regenerated in: 0.6044681072235107 seconds.
# 648518346341409056
# Segment 648518346341409056 vertex labels regenerated in: 0.6151261329650879 seconds.
# 648518346341409422
# Segment 648518346341409422 vertex labels regenerated in: 0.6705441474914551 seconds.
# 648518346341410186
# Segment 648518346341410186 vertex labels regenerated in: 0.6391470432281494 seconds.
# 648518346341410882
# Segment 648518346341410882 vertex labels regenerated in: 0.8797216415405273 seconds.
# 648518346341412995
# Segment 648518346341412995 vertex labels regenerated in: 0.6518006324768066 seconds.
# 648518346341414670
# Segment 648518346341414670 vertex labels regenerated in: 0.7235088348388672 seconds.
# 648518346341419781
# Segment 648518346341419781 vertex labels regenerated in: 0.8339893817901611 seconds.
# 648518346342104641
# Segment 648518346342104641 vertex labels regenerated in: 0.6014595031738281 seconds.
# 648518346342157584
# Segment 648518346342157584 vertex labels regenerated in: 0.6916134357452393 seconds.
# 648518346342410869
# Segment 648518346342410869 vertex labels regenerated in: 0.6829128265380859 seconds.
# 648518346342467480
# Segment 648518346342467480 vertex labels regenerated in: 0.7405054569244385 seconds.
# 648518346342790164
# Segment 648518346342790164 vertex labels regenerated in: 0.6966662406921387 seconds.
# 648518346342791293
# Segment 648518346342791293 vertex labels regenerated in: 0.6197202205657959 seconds.
# 648518346342791905
# Segment 648518346342791905 vertex labels regenerated in: 0.7938461303710938 seconds.
# 648518346342792341
# Segment 648518346342792341 vertex labels regenerated in: 0.8674373626708984 seconds.
# 648518346342793875
# Segment 648518346342793875 vertex labels regenerated in: 0.8351595401763916 seconds.
# Segment 648518346347001783 vertex labels regenerated in: 0.8718140125274658 seconds.
# 648518346348109921
# Segment 648518346348109921 vertex labels regenerated in: 0.4811747074127197 seconds.
# 648518346348117121
# Segment 648518346348117121 vertex labels regenerated in: 0.6918923854827881 seconds.
# 648518346348189549
# Segment 648518346348189549 vertex labels regenerated in: 0.5860254764556885 seconds.
# 648518346348192292
# Segment 648518346348192292 vertex labels regenerated in: 0.7069015502929688 seconds.
# 648518346348206299
# Segment 648518346348206299 vertex labels regenerated in: 0.5633761882781982 seconds.
# 648518346348213904
# Segment 648518346348213904 vertex labels regenerated in: 0.768406867980957 seconds.
# 648518346348463462
# Segment 648518346348463462 vertex labels regenerated in: 0.5738661289215088 seconds.
# 648518346348499075
# Segment 648518346348499075 vertex labels regenerated in: 0.49719929695129395 seconds.
# 648518346349301817
# Segment 648518346349301817 vertex labels regenerated in: 0.503819465637207 seconds.
# 648518346349373319
# Segment 648518346349373319 vertex labels regenerated in: 0.708249568939209 seconds.
# 648518346349379849
# Segment 648518346349379849 vertex labels regenerated in: 0.5385663509368896 seconds.
# 648518346349386102
# Segment 648518346349386102 vertex labels regenerated in: 0.60455322265625 seconds.
# 648518346349469130
# Segment 648518346349469130 vertex labels regenerated in: 0.548356294631958 seconds.
# 648518346349476140
# Segment 648518346349476140 vertex labels regenerated in: 0.7775764465332031 seconds.
# 648518346349490009
# Segment 648518346349490009 vertex labels regenerated in: 0.8285567760467529 seconds.
# 648518346349500257
# Segment 648518346349500257 vertex labels regenerated in: 0.8641002178192139 seconds.
# 648518346349505858
# Segment 648518346349505858 vertex labels regenerated in: 1.6201632022857666 seconds.
# 648518346349509533
# Segment 648518346349509533 vertex labels regenerated in: 0.8277342319488525 seconds.
# 648518346349511381
# Segment 648518346349511381 vertex labels regenerated in: 0.7861063480377197 seconds.
# 648518346349512609
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# <ipython-input-6-30731291f93f> in <module>
#       1 start = time.time()
# ----> 2 CoarseLabelOrphan.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-5-ae2acaf9c19e> in make(self, key)
#      36         self.insert1(dict(key,
#      37                           vertices=corrected_vertex_labels,
# ---> 38                           triangles=labels['triangles']))
#      39
#      40         print("Segment {} vertex labels regenerated in: {} seconds.".format(key['segment_id'], time.time() - start))
#
# /usr/local/lib/python3.6/dist-packages/datajoint/table.py in insert1(self, row, **kwargs)
#     146         For kwargs, see insert()
#     147         """
# --> 148         self.insert((row,), **kwargs)
#     149
#     150     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, ignore_errors=False,
#
# /usr/local/lib/python3.6/dist-packages/datajoint/table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, ignore_errors, allow_direct_insert)
#     309                     raise DuplicateError(
#     310                         '{} : To ignore duplicate entries, set skip_duplicates=True in insert.'.format(err.args[1])
# --> 311                     ) from None
#     312                 else:
#     313                     raise
#
# DuplicateError: Duplicate entry '3-648518346349512609-0.35-computer_Auto-celiib-2019-06-27 21:26:' for key 'PRIMARY' : To ignore duplicate entries, set skip_duplicates=True in insert.

# %%
(schema.jobs & "table_name='__coarse_label_orphan'").delete()

# %%
ta3p100.CoarseLabelOrphan()

# %%
ta3p100.SegmentExclude()
