# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349472601**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2240 pieces after mesh split
# There were 399 pieces found after size threshold
# max_index = 0
# max_face_len = 2937009
# Total time for Mesh Cleansing: 1614.95276927948
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9656318951478872% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349493260**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349493260_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 2.0246922969818115
# Number of outside child meshes =  60
# Main mesh and outside child meshes make up 0.9758176012407049% of original mesh
#  face length 988285 using optimized facets with 3 neighbors
# Filtering edges by size finished: 19.586211919784546, facet # = 50393
# Filtering by convexity and getting centers took: 22.684048414230347, facet # = 10478
# Finished facets for main mesh: 44.12320375442505 with facet length = 10478
# Finished 10478 facets for main mesh: 44.12359666824341
# Filtering edges by size finished: 6.839853286743164, facet # = 18424
# Filtering by convexity and getting centers took: 8.897080659866333, facet # = 3990
# Filtering edges by size finished: 0.5210058689117432, facet # = 2170
# Filtering by convexity and getting centers took: 1.0045180320739746, facet # = 505
# Filtering edges by size finished: 0.15605664253234863, facet # = 320
# Filtering by convexity and getting centers took: 0.2853255271911621, facet # = 86
# Filtering edges by size finished: 0.006743431091308594, facet # = 7
# Filtering by convexity and getting centers took: 0.005680561065673828, facet # = 5
# Filtering edges by size finished: 0.21400904655456543, facet # = 809
# Filtering by convexity and getting centers took: 0.35959577560424805, facet # = 150
# Filtering edges by size finished: 1.037942886352539, facet # = 3658
# Filtering by convexity and getting centers took: 1.6281583309173584, facet # = 959
# Filtering edges by size finished: 0.552100419998169, facet # = 2305
# Filtering by convexity and getting centers took: 0.9501206874847412, facet # = 540
# Filtering edges by size finished: 1.3680860996246338, facet # = 5295
# Filtering by convexity and getting centers took: 2.108125686645508, facet # = 1210
# Filtering edges by size finished: 0.8769869804382324, facet # = 2498
# Filtering by convexity and getting centers took: 1.3985931873321533, facet # = 513
# Filtering edges by size finished: 0.5627377033233643, facet # = 1613
# Filtering by convexity and getting centers took: 0.9179573059082031, facet # = 416
# Filtering edges by size finished: 0.013679027557373047, facet # = 93
# Filtering by convexity and getting centers took: 0.026435375213623047, facet # = 17
# Filtering edges by size finished: 0.005368471145629883, facet # = 28
# Filtering by convexity and getting centers took: 0.011320829391479492, facet # = 20
# Filtering edges by size finished: 0.005289793014526367, facet # = 22
# Filtering by convexity and getting centers took: 0.008493900299072266, facet # = 7
# Filtering edges by size finished: 0.11733317375183105, facet # = 409
# Filtering by convexity and getting centers took: 0.18636059761047363, facet # = 91
# Filtering edges by size finished: 0.029469966888427734, facet # = 47
# Filtering by convexity and getting centers took: 0.019194602966308594, facet # = 15
# Filtering edges by size finished: 0.0320591926574707, facet # = 14
# Filtering by convexity and getting centers took: 0.024572372436523438, facet # = 10
# Filtering edges by size finished: 0.36540865898132324, facet # = 862
# Filtering by convexity and getting centers took: 0.36034560203552246, facet # = 291
# Filtering edges by size finished: 0.015458822250366211, facet # = 39
# Filtering by convexity and getting centers took: 0.013650178909301758, facet # = 14
# Filtering edges by size finished: 0.016522645950317383, facet # = 87
# Filtering by convexity and getting centers took: 0.026900529861450195, facet # = 29
# Filtering edges by size finished: 0.22888565063476562, facet # = 1024
# Filtering by convexity and getting centers took: 0.5107793807983398, facet # = 220
# Filtering edges by size finished: 0.08945298194885254, facet # = 491
# Filtering by convexity and getting centers took: 0.2564845085144043, facet # = 113
# Filtering edges by size finished: 0.10040521621704102, facet # = 379
# Filtering by convexity and getting centers took: 0.22993206977844238, facet # = 89
# Filtering edges by size finished: 0.008214712142944336, facet # = 56
# Filtering by convexity and getting centers took: 0.01694774627685547, facet # = 21
# Filtering edges by size finished: 0.005272865295410156, facet # = 20
# Filtering by convexity and getting centers took: 0.017867088317871094, facet # = 8
# Filtering edges by size finished: 0.005613088607788086, facet # = 3
# Filtering by convexity and getting centers took: 0.010888338088989258, facet # = 0
# Filtering edges by size finished: 0.0022923946380615234, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.00817561149597168, facet # = 2
# Filtering edges by size finished: 0.0058133602142333984, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.014205217361450195, facet # = 2
# Filtering edges by size finished: 0.40314626693725586, facet # = 1233
# Filtering by convexity and getting centers took: 0.5809533596038818, facet # = 273
# Filtering edges by size finished: 0.016941547393798828, facet # = 52
# Filtering by convexity and getting centers took: 0.029952526092529297, facet # = 25
# Filtering edges by size finished: 0.002599477767944336, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0028839111328125, facet # = 2
# Filtering edges by size finished: 0.024318933486938477, facet # = 33
# Filtering by convexity and getting centers took: 0.04834556579589844, facet # = 20
# Filtering edges by size finished: 0.18093156814575195, facet # = 224
# Filtering by convexity and getting centers took: 0.07279372215270996, facet # = 73
# Filtering edges by size finished: 0.012330055236816406, facet # = 60
# Filtering by convexity and getting centers took: 0.020658254623413086, facet # = 26
# Filtering edges by size finished: 0.0030431747436523438, facet # = 18
# Filtering by convexity and getting centers took: 0.008095979690551758, facet # = 13
# Filtering edges by size finished: 0.02361583709716797, facet # = 42
# Filtering by convexity and getting centers took: 0.01845693588256836, facet # = 23
# Filtering edges by size finished: 0.0017638206481933594, facet # = 8
# Filtering by convexity and getting centers took: 0.004225254058837891, facet # = 7
# Filtering edges by size finished: 0.001737356185913086, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002120494842529297, facet # = 2
# Filtering edges by size finished: 0.0015439987182617188, facet # = 10
# Filtering by convexity and getting centers took: 0.005016326904296875, facet # = 9
# Filtering edges by size finished: 0.006430625915527344, facet # = 10
# Filtering by convexity and getting centers took: 0.005178928375244141, facet # = 9
# Filtering edges by size finished: 0.004555702209472656, facet # = 15
# Filtering by convexity and getting centers took: 0.006730079650878906, facet # = 6
# Filtering edges by size finished: 0.0027284622192382812, facet # = 17
# Filtering by convexity and getting centers took: 0.006957530975341797, facet # = 8
# Filtering edges by size finished: 0.0012602806091308594, facet # = 6
# Filtering by convexity and getting centers took: 0.0031571388244628906, facet # = 6
# Filtering edges by size finished: 0.005550861358642578, facet # = 18
# Filtering by convexity and getting centers took: 0.0072078704833984375, facet # = 7
# Filtering edges by size finished: 0.016901016235351562, facet # = 61
# Filtering by convexity and getting centers took: 0.019504785537719727, facet # = 15
# Filtering edges by size finished: 0.01479482650756836, facet # = 29
# Filtering by convexity and getting centers took: 0.013214349746704102, facet # = 23
# Filtering edges by size finished: 0.0018405914306640625, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0020554065704345703, facet # = 2
# Filtering edges by size finished: 0.0025229454040527344, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018765926361083984, facet # = 2
# Filtering edges by size finished: 0.0018887519836425781, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017719268798828125, facet # = 2
# Filtering edges by size finished: 0.0029549598693847656, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0022733211517333984, facet # = 2
# Filtering edges by size finished: 0.018381834030151367, facet # = 34
# Filtering by convexity and getting centers took: 0.015012264251708984, facet # = 17
# Filtering edges by size finished: 0.08338713645935059, facet # = 158
# Filtering by convexity and getting centers took: 0.06399917602539062, facet # = 61
# Filtering edges by size finished: 0.023320436477661133, facet # = 144
# Filtering by convexity and getting centers took: 0.043378591537475586, facet # = 41
# Filtering edges by size finished: 0.002480745315551758, facet # = 11
# Filtering by convexity and getting centers took: 0.0047566890716552734, facet # = 10
# Filtering edges by size finished: 0.0017852783203125, facet # = 7
# Filtering by convexity and getting centers took: 0.0033254623413085938, facet # = 7
# Filtering edges by size finished: 0.0028531551361083984, facet # = 14
# Filtering by convexity and getting centers took: 0.005490779876708984, facet # = 11
# Filtering edges by size finished: 0.00106048583984375, facet # = 8
# Filtering by convexity and getting centers took: 0.0035071372985839844, facet # = 8
# Filtering edges by size finished: 0.0012936592102050781, facet # = 6
# Filtering by convexity and getting centers took: 0.0028564929962158203, facet # = 6
# Filtering edges by size finished: 0.0062983036041259766, facet # = 39
# Filtering by convexity and getting centers took: 0.011729001998901367, facet # = 12
# Filtering edges by size finished: 0.006161928176879883, facet # = 11
# Filtering by convexity and getting centers took: 0.013001441955566406, facet # = 10
# Filtering edges by size finished: 0.013621807098388672, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.008407115936279297, facet # = 2
# Total time for facets: 79.7222535610199
# Zero faceted faces = [24]
# Starting Child 0
# 3990 10478
# Done distance matrix: 2.125380277633667
# Done Generating final pairs: 2.143134832382202
# best_stitch_pair = [ 456 6119]
# best_stitch_pair_size = 53634.244727837024
# best_stitch_pair_distance = 1741.7303426207284
# best_stitch_pair_size_ratio = 0.38301005912711383
# Starting Child 1
# 505 10478
# Done distance matrix: 0.2769646644592285
# Child 1 There were no points close enough
# Starting Child 2
# 86 10478
# Done distance matrix: 0.11550641059875488
# Done Generating final pairs: 0.2710542678833008
# best_stitch_pair = [   0 1466]
# best_stitch_pair_size = 5421481.278528827
# best_stitch_pair_distance = 555.4317800583938
# best_stitch_pair_size_ratio = 0.9451459342338052
# Starting Child 3
# 5 10478
# Done distance matrix: 0.002386331558227539
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 150 10478
# Done distance matrix: 0.06140470504760742
# Child 4 There were no points close enough
# Starting Child 5
# 959 10478
# Done distance matrix: 0.557145357131958
# Child 5 There were no points close enough
# Starting Child 6
# 540 10478
# Done distance matrix: 0.2596440315246582
# Child 6 There were no points close enough
# Starting Child 7
# 1210 10478
# Done distance matrix: 0.8846075534820557
# Child 7 There were no points close enough
# Starting Child 8
# 513 10478
# Done distance matrix: 0.33510541915893555
# Child 8 There were no points close enough
# Starting Child 9
# 416 10478
# Done distance matrix: 0.3094601631164551
# Done Generating final pairs: 0.3330862522125244
# best_stitch_pair = [ 175 5415]
# best_stitch_pair_size = 504821.4219527383
# best_stitch_pair_distance = 179.56356490020767
# best_stitch_pair_size_ratio = 0.9862001297499787
# Starting Child 10
# returning x less min
# skipped by bounding box filter
# Starting Child 11
# returning x less min
# skipped by bounding box filter
# Starting Child 12
# returning x less min
# skipped by bounding box filter
# Starting Child 13
# 91 10478
# Done distance matrix: 0.038756608963012695
# Child 13 There were no points close enough
# Starting Child 14
# 15 10478
# Done distance matrix: 0.007899045944213867
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 15
# 10 10478
# Done distance matrix: 0.0040476322174072266
# Child 15 There were no points close enough
# Starting Child 16
# 291 10478
# Done distance matrix: 0.12436246871948242
# Child 16 There were no points close enough
# Starting Child 17
# returning x less min
# skipped by bounding box filter
# Starting Child 18
# 29 10478
# Done distance matrix: 0.049453020095825195
# Child 18 There were no points close enough
# Starting Child 19
# 220 10478
# Done distance matrix: 0.09281754493713379
# Done Generating final pairs: 0.11191439628601074
# best_stitch_pair = [ 144 9360]
# best_stitch_pair_size = 563994.6102477666
# best_stitch_pair_distance = 198.92375577949983
# best_stitch_pair_size_ratio = 0.5602491530871152
# Starting Child 20
# 113 10478
# Done distance matrix: 0.052272796630859375
# Child 20 There were no points close enough
# Starting Child 21
# 89 10478
# Done distance matrix: 0.04911613464355469
# Child 21 There were no points close enough
# Starting Child 22
# 21 10478
# Done distance matrix: 0.008346080780029297
# Child 22 There were no points close enough
# Starting Child 23
# 8 10478
# Done distance matrix: 0.0034139156341552734
# Child 23 There were no points close enough
# Starting Child 24
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 2 10478
# Done distance matrix: 0.0013301372528076172
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# 2 10478
# Done distance matrix: 0.0014455318450927734
# Done Generating final pairs: 0.035959720611572266
# best_stitch_pair = [   1 5273]
# best_stitch_pair_size = 63356.7675943146
# best_stitch_pair_distance = 1519.8184315070869
# best_stitch_pair_size_ratio = 0.707317073170732
# Starting Child 27
# 273 10478
# Done distance matrix: 0.11527085304260254
# Child 27 There were no points close enough
# Starting Child 28
# 25 10478
# Done distance matrix: 0.010071039199829102
# Child 28 There were no points close enough
# Starting Child 29
# 2 10478
# Done distance matrix: 0.0013227462768554688
# Child 29 There were no points close enough
# Starting Child 30
# 20 10478
# Done distance matrix: 0.010492563247680664
# Done Generating final pairs: 0.035994768142700195
# best_stitch_pair = [   5 6451]
# best_stitch_pair_size = 2390634.718792605
# best_stitch_pair_distance = 975.3292235331073
# best_stitch_pair_size_ratio = 0.583259363809606
# Starting Child 31
# 73 10478
# Done distance matrix: 0.0914461612701416
# Done Generating final pairs: 0.1272282600402832
# best_stitch_pair = [  21 6451]
# best_stitch_pair_size = 3434756.3482864117
# best_stitch_pair_distance = 1886.1600331907903
# best_stitch_pair_size_ratio = 0.3448185626086131
# Starting Child 32
# 26 10478
# Done distance matrix: 0.012890338897705078
# Done Generating final pairs: 0.05736041069030762
# best_stitch_pair = [   0 6451]
# best_stitch_pair_size = 2389235.412968873
# best_stitch_pair_distance = 657.1996550428036
# best_stitch_pair_size_ratio = 0.5838003869774451
# Starting Child 33
# returning x less min
# skipped by bounding box filter
# Starting Child 34
# 23 10478
# Done distance matrix: 0.011349916458129883
# Child 34 There were no points close enough
# Starting Child 35
# 7 10478
# Done distance matrix: 0.003224611282348633
# Child 35 There were no points close enough
# Starting Child 36
# 2 10478
# Done distance matrix: 0.0012478828430175781
# Child 36 There were no points close enough
# Starting Child 37
# 9 10478
# Done distance matrix: 0.00519871711730957
# Child 37 There were no points close enough
# Starting Child 38
# 9 10478
# Done distance matrix: 0.004796504974365234
# Child 38 There were no points close enough
# Starting Child 39
# 6 10478
# Done distance matrix: 0.0033919811248779297
# Child 39 There were no points close enough
# Starting Child 40
# 8 10478
# Done distance matrix: 0.004230976104736328
# Child 40 There were no points close enough
# Starting Child 41
# 6 10478
# Done distance matrix: 0.004224538803100586
# Child 41 There were no points close enough
# Starting Child 42
# 7 10478
# Done distance matrix: 0.0044803619384765625
# Child 42 There were no points close enough
# Starting Child 43
# 15 10478
# Done distance matrix: 0.008166074752807617
# Child 43 There were no points close enough
# Starting Child 44
# 23 10478
# Done distance matrix: 0.01177525520324707
# Child 44 There were no points close enough
# Starting Child 45
# 2 10478
# Done distance matrix: 0.0016529560089111328
# Child 45 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 46
# 2 10478
# Done distance matrix: 0.0012810230255126953
# Child 46 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 47
# 2 10478
# Done distance matrix: 0.001264810562133789
# Child 47 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 48
# 2 10478
# Done distance matrix: 0.0012788772583007812
# Done Generating final pairs: 0.017095088958740234
# best_stitch_pair = [   0 2954]
# best_stitch_pair_size = 42468.627995449366
# best_stitch_pair_distance = 1765.5505270848225
# best_stitch_pair_size_ratio = 0.5681505206721204
# Starting Child 49
# 17 10478
# Done distance matrix: 0.009111166000366211
# Child 49 There were no points close enough
# Starting Child 50
# 61 10478
# Done distance matrix: 0.03388261795043945
# Child 50 There were no points close enough
# Starting Child 51
# 41 10478
# Done distance matrix: 0.02429342269897461
# Child 51 There were no points close enough
# Starting Child 52
# 10 10478
# Done distance matrix: 0.0058252811431884766
# Child 52 There were no points close enough
# Starting Child 53
# 7 10478
# Done distance matrix: 0.0037097930908203125
# Child 53 There were no points close enough
# Starting Child 54
# 11 10478
# Done distance matrix: 0.029108047485351562
# Child 54 There were no points close enough
# Starting Child 55
# 8 10478
# Done distance matrix: 0.004281282424926758
# Child 55 There were no points close enough
# Starting Child 56
# 6 10478
# Done distance matrix: 0.002519845962524414
# Child 56 There were no points close enough
# Starting Child 57
# 12 10478
# Done distance matrix: 0.004720211029052734
# Child 57 There were no points close enough
# Starting Child 58
# 10 10478
# Done distance matrix: 0.004026889801025391
# Child 58 There were no points close enough
# Starting Child 59
# 2 10478
# Done distance matrix: 0.0012159347534179688
# Done Generating final pairs: 0.012211084365844727
# best_stitch_pair = [   0 7072]
# best_stitch_pair_size = 26622.253630684878
# best_stitch_pair_distance = 1886.483368586294
# best_stitch_pair_size_ratio = 0.9609141742422355
# repeat_main_facets = [6451]
# child_mesh_double_indexes = [30, 31, 32]
# min_child = 32, max_ratio = 657.1996550428036
# child_meshes_stitch_facets = {0: [456, 6119], 2: [0, 1466], 9: [175, 5415], 19: [144, 9360], 26: [1, 5273], 32: [0, 6451], 48: [0, 2954], 59: [0, 7072]}
# ---Stitching child 0 with pair: [456, 6119]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 245531, starting edge 2nd facet= 651596,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004728555679321289
# returned from stitch mesh: 0.8056106567382812
# Finished stitching child 0 : 0.9846293926239014
# ---Stitching child 2 with pair: [0, 1466]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 439829, starting edge 2nd facet= 678654,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 61
# Starting Organizing vertices for side 1
# edge_1_order done, len = 51
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 0.00014257431030273438
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023301362991333008
# returned from stitch mesh: 1.058943510055542
# Finished stitching child 2 : 1.2261290550231934
# ---Stitching child 9 with pair: [175, 5415]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 370897, starting edge 2nd facet= 682962,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 4.124641418457031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02616143226623535
# returned from stitch mesh: 0.9733171463012695
# Finished stitching child 9 : 1.1203842163085938
# ---Stitching child 19 with pair: [144, 9360]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 199785, starting edge 2nd facet= 689488,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 5.888938903808594e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0354619026184082
# returned from stitch mesh: 0.7588422298431396
# Finished stitching child 19 : 0.8787462711334229
# ---Stitching child 26 with pair: [1, 5273]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 29199, starting edge 2nd facet= 691141,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 52
# Starting Organizing vertices for side 1
# edge_1_order done, len = 38
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 6.222724914550781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.009044647216796875
# returned from stitch mesh: 1.0274319648742676
# Finished stitching child 26 : 1.1714041233062744
# ---Stitching child 32 with pair: [0, 6451]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 433070, starting edge 2nd facet= 691224,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 34
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 7.939338684082031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004200458526611328
# returned from stitch mesh: 0.8602335453033447
# Finished stitching child 32 : 0.9449257850646973
# ---Stitching child 48 with pair: [0, 2954]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 197381, starting edge 2nd facet= 691391,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 0
# About to add faces
# Finished adding faces: 2.3126602172851562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02073216438293457
# returned from stitch mesh: 0.8177244663238525
# Finished stitching child 48 : 0.9394521713256836
# ---Stitching child 59 with pair: [0, 7072]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 166645, starting edge 2nd facet= 691451,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 19
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 5.269050598144531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03157353401184082
# returned from stitch mesh: 0.8983073234558105
# Finished stitching child 59 : 1.0727148056030273
# ***************Finished big stitching iteration: 15.922433853149414***************
# Starting Child 1
# 505 15206
# Done distance matrix: 0.3470621109008789
# Done Generating final pairs: 0.3606579303741455
# best_stitch_pair = [  150 13748]
# best_stitch_pair_size = 685708.3115790281
# best_stitch_pair_distance = 185.92103002731307
# best_stitch_pair_size_ratio = 0.8852594197941065
# Starting Child 3
# 5 15206
# Done distance matrix: 0.004019975662231445
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 150 15206
# Done distance matrix: 0.09552574157714844
# Done Generating final pairs: 0.10984683036804199
# best_stitch_pair = [   77 12936]
# best_stitch_pair_size = 1719335.4291696828
# best_stitch_pair_distance = 267.896690073685
# best_stitch_pair_size_ratio = 0.8444420134298068
# Starting Child 5
# 959 15206
# Done distance matrix: 0.7031307220458984
# Done Generating final pairs: 0.7063424587249756
# best_stitch_pair = [  517 13641]
# best_stitch_pair_size = 33873.425473846015
# best_stitch_pair_distance = 1985.9247899982936
# best_stitch_pair_size_ratio = 0.29245577881068524
# Starting Child 6
# 540 15206
# Done distance matrix: 0.5238142013549805
# Child 6 There were no points close enough
# Starting Child 7
# 1210 15206
# Done distance matrix: 0.9033153057098389
# Child 7 There were no points close enough
# Starting Child 8
# 513 15206
# Done distance matrix: 0.40842199325561523
# Child 8 There were no points close enough
# Starting Child 10
# 17 15206
# Done distance matrix: 0.011491060256958008
# Done Generating final pairs: 0.01388406753540039
# best_stitch_pair = [    7 14346]
# best_stitch_pair_size = 368392.54565100657
# best_stitch_pair_distance = 1607.181383256407
# best_stitch_pair_size_ratio = 0.4243847427315384
# Starting Child 11
# 20 15206
# Done distance matrix: 0.011734962463378906
# Done Generating final pairs: 0.019200563430786133
# best_stitch_pair = [    6 12199]
# best_stitch_pair_size = 488388.4223790179
# best_stitch_pair_distance = 1934.9454809155595
# best_stitch_pair_size_ratio = 0.5071277846805416
# Starting Child 12
# 7 15206
# Done distance matrix: 0.0043599605560302734
# Child 12 There were no points close enough
# Starting Child 13
# 91 15206
# Done distance matrix: 0.05164694786071777
# Done Generating final pairs: 0.06148648262023926
# best_stitch_pair = [   77 10474]
# best_stitch_pair_size = 270413.16989827587
# best_stitch_pair_distance = 255.75252403651086
# best_stitch_pair_size_ratio = 0.8741146348447281
# Starting Child 14
# 15 15206
# Done distance matrix: 0.01104116439819336
# Done Generating final pairs: 0.23973774909973145
# best_stitch_pair = [    0 14466]
# best_stitch_pair_size = 3250060.084760299
# best_stitch_pair_distance = 1010.7054075972386
# best_stitch_pair_size_ratio = 0.45996635548626935
# Starting Child 15
# 10 15206
# Done distance matrix: 0.007630109786987305
# Child 15 There were no points close enough
# Starting Child 16
# 291 15206
# Done distance matrix: 0.2740914821624756
# Done Generating final pairs: 0.283705472946167
# best_stitch_pair = [   80 14612]
# best_stitch_pair_size = 49257.9603474767
# best_stitch_pair_distance = 1964.1161934363497
# best_stitch_pair_size_ratio = 0.2490015502090013
# Starting Child 17
# 14 15206
# Done distance matrix: 0.009450435638427734
# Child 17 There were no points close enough
# Starting Child 18
# 29 15206
# Done distance matrix: 0.021620512008666992
# Child 18 There were no points close enough
# Starting Child 20
# 113 15206
# Done distance matrix: 0.10314512252807617
# Child 20 There were no points close enough
# Starting Child 21
# 89 15206
# Done distance matrix: 0.05999922752380371
# Child 21 There were no points close enough
# Starting Child 22
# 21 15206
# Done distance matrix: 0.013985157012939453
# Child 22 There were no points close enough
# Starting Child 23
# 8 15206
# Done distance matrix: 0.004853487014770508
# Child 23 There were no points close enough
# Starting Child 24
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 2 15206
# Done distance matrix: 0.0020563602447509766
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 273 15206
# Done distance matrix: 0.24251842498779297
# Child 27 There were no points close enough
# Starting Child 28
# 25 15206
# Done distance matrix: 0.017666339874267578
# Child 28 There were no points close enough
# Starting Child 29
# 2 15206
# Done distance matrix: 0.001703023910522461
# Done Generating final pairs: 0.006107330322265625
# best_stitch_pair = [    0 11706]
# best_stitch_pair_size = 37655.270465759415
# best_stitch_pair_distance = 1952.9135276574539
# best_stitch_pair_size_ratio = 0.4544884176953331
# Starting Child 30
# 20 15206
# Done distance matrix: 0.015144586563110352
# Done Generating final pairs: 0.04223513603210449
# best_stitch_pair = [    5 15183]
# best_stitch_pair_size = 3036429.090457894
# best_stitch_pair_distance = 411.0155862370719
# best_stitch_pair_size_ratio = 0.9891653695126216
# Starting Child 31
# 73 15206
# Done distance matrix: 0.09632658958435059
# Done Generating final pairs: 0.1346604824066162
# best_stitch_pair = [   21 15183]
# best_stitch_pair_size = 4080550.7199517004
# best_stitch_pair_distance = 1087.484332807433
# best_stitch_pair_size_ratio = 0.5976680140921006
# Starting Child 33
# 13 15206
# Done distance matrix: 0.007349491119384766
# Child 33 There were no points close enough
# Starting Child 34
# 23 15206
# Done distance matrix: 0.0122528076171875
# Child 34 There were no points close enough
# Starting Child 35
# 7 15206
# Done distance matrix: 0.0039577484130859375
# Child 35 There were no points close enough
# Starting Child 36
# 2 15206
# Done distance matrix: 0.001237630844116211
# Done Generating final pairs: 0.0036237239837646484
# best_stitch_pair = [    1 13592]
# best_stitch_pair_size = 22079.099183998307
# best_stitch_pair_distance = 1796.1342288653511
# best_stitch_pair_size_ratio = 0.8764760523432144
# Starting Child 37
# 9 15206
# Done distance matrix: 0.0050313472747802734
# Child 37 There were no points close enough
# Starting Child 38
# 9 15206
# Done distance matrix: 0.004781961441040039
# Done Generating final pairs: 0.013814926147460938
# best_stitch_pair = [    0 14641]
# best_stitch_pair_size = 197940.71552540164
# best_stitch_pair_distance = 1870.5643157686811
# best_stitch_pair_size_ratio = 0.22107238753072553
# Starting Child 39
# 6 15206
# Done distance matrix: 0.0034720897674560547
# Child 39 There were no points close enough
# Starting Child 40
# 8 15206
# Done distance matrix: 0.004284858703613281
# Child 40 There were no points close enough
# Starting Child 41
# 6 15206
# Done distance matrix: 0.0031898021697998047
# Child 41 There were no points close enough
# Starting Child 42
# 7 15206
# Done distance matrix: 0.0039081573486328125
# Child 42 There were no points close enough
# Starting Child 43
# 15 15206
# Done distance matrix: 0.008337736129760742
# Child 43 There were no points close enough
# Starting Child 44
# 23 15206
# Done distance matrix: 0.012609481811523438
# Child 44 There were no points close enough
# Starting Child 45
# 2 15206
# Done distance matrix: 0.001478433609008789
# Child 45 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 46
# 2 15206
# Done distance matrix: 0.001302957534790039
# Child 46 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 47
# 2 15206
# Done distance matrix: 0.0012331008911132812
# Done Generating final pairs: 0.004164218902587891
# best_stitch_pair = [    0 15204]
# best_stitch_pair_size = 25342.70703772588
# best_stitch_pair_distance = 1967.0697592952922
# best_stitch_pair_size_ratio = 0.6470588235294119
# Starting Child 49
# 17 15206
# Done distance matrix: 0.00960540771484375
# Done Generating final pairs: 0.05470442771911621
# best_stitch_pair = [    2 14480]
# best_stitch_pair_size = 1905327.713092829
# best_stitch_pair_distance = 1935.0807962436236
# best_stitch_pair_size_ratio = 0.187007989282269
# Starting Child 50
# 61 15206
# Done distance matrix: 0.04341411590576172
# Child 50 There were no points close enough
# Starting Child 51
# 41 15206
# Done distance matrix: 0.029644250869750977
# Done Generating final pairs: 0.03723597526550293
# best_stitch_pair = [    3 15183]
# best_stitch_pair_size = 2289089.393694713
# best_stitch_pair_distance = 1973.3207735600781
# best_stitch_pair_size_ratio = 0.49958296868033103
# Starting Child 52
# 10 15206
# Done distance matrix: 0.00835418701171875
# Child 52 There were no points close enough
# Starting Child 53
# 7 15206
# Done distance matrix: 0.005382061004638672
# Child 53 There were no points close enough
# Starting Child 54
# 11 15206
# Done distance matrix: 0.007965564727783203
# Child 54 There were no points close enough
# Starting Child 55
# 8 15206
# Done distance matrix: 0.005951881408691406
# Child 55 There were no points close enough
# Starting Child 56
# 6 15206
# Done distance matrix: 0.004523515701293945
# Child 56 There were no points close enough
# Starting Child 57
# 12 15206
# Done distance matrix: 0.008834362030029297
# Child 57 There were no points close enough
# Starting Child 58
# 10 15206
# Done distance matrix: 0.0073621273040771484
# Child 58 There were no points close enough
# repeat_main_facets = [15183]
# child_mesh_double_indexes = [30, 31, 51]
# min_child = 30, max_ratio = 411.0155862370719
# child_meshes_stitch_facets = {1: [150, 13748], 4: [77, 12936], 5: [517, 13641], 10: [7, 14346], 11: [6, 12199], 13: [77, 10474], 14: [0, 14466], 16: [80, 14612], 29: [0, 11706], 30: [5, 15183], 36: [1, 13592], 38: [0, 14641], 47: [0, 15204], 49: [2, 14480]}
# ---Stitching child 1 with pair: [150, 13748]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 639423, starting edge 2nd facet= 699684,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 3.647804260253906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0515897274017334
# returned from stitch mesh: 0.9059500694274902
# Finished stitching child 1 : 1.029914379119873
# ---Stitching child 4 with pair: [77, 12936]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 553279, starting edge 2nd facet= 700897,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 6.890296936035156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026530981063842773
# returned from stitch mesh: 0.8787870407104492
# Finished stitching child 4 : 1.0622832775115967
# ---Stitching child 5 with pair: [517, 13641]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 594307, starting edge 2nd facet= 707955,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.025359153747558594
# returned from stitch mesh: 0.8920168876647949
# Finished stitching child 5 : 1.0780589580535889
# ---Stitching child 10 with pair: [7, 14346]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 613941, starting edge 2nd facet= 717606,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.8133392333984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02560877799987793
# returned from stitch mesh: 0.9008121490478516
# Finished stitching child 10 : 1.0203962326049805
# ---Stitching child 11 with pair: [6, 12199]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 660007, starting edge 2nd facet= 717749,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022140026092529297
# returned from stitch mesh: 0.8608884811401367
# Finished stitching child 11 : 1.0127010345458984
# ---Stitching child 13 with pair: [77, 10474]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 518010, starting edge 2nd facet= 719439,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013358592987060547
# returned from stitch mesh: 1.0993812084197998
# Finished stitching child 13 : 1.231541633605957
# ---Stitching child 14 with pair: [0, 14466]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 678927, starting edge 2nd facet= 719735,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 46
# Starting Organizing vertices for side 1
# edge_1_order done, len = 30
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 16
# About to add faces
# Finished adding faces: 5.936622619628906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013036489486694336
# returned from stitch mesh: 0.8220553398132324
# Finished stitching child 14 : 0.9169025421142578
# ---Stitching child 16 with pair: [80, 14612]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 685797, starting edge 2nd facet= 720482,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.86102294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027406692504882812
# returned from stitch mesh: 0.8288791179656982
# Finished stitching child 16 : 0.9252920150756836
# ---Stitching child 29 with pair: [0, 11706]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 560598, starting edge 2nd facet= 723468,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 0
# About to add faces
# Finished adding faces: 2.3603439331054688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023697614669799805
# returned from stitch mesh: 1.0100798606872559
# Finished stitching child 29 : 1.266817331314087
# ---Stitching child 30 with pair: [5, 15183]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 691302, starting edge 2nd facet= 723501,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 4.744529724121094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022610187530517578
# returned from stitch mesh: 0.9985373020172119
# Finished stitching child 30 : 1.150390386581421
# ---Stitching child 36 with pair: [1, 13592]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 669209, starting edge 2nd facet= 723620,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 2.86102294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022075176239013672
# returned from stitch mesh: 0.9812963008880615
# Finished stitching child 36 : 1.114638090133667
# ---Stitching child 38 with pair: [0, 14641]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 684745, starting edge 2nd facet= 723720,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 4.5299530029296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02655935287475586
# returned from stitch mesh: 0.9883711338043213
# Finished stitching child 38 : 1.1049609184265137
# ---Stitching child 47 with pair: [0, 15204]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 691413, starting edge 2nd facet= 723772,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 0.00013184547424316406
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.047730207443237305
# returned from stitch mesh: 1.2220566272735596
# Finished stitching child 47 : 1.427222728729248
# ---Stitching child 49 with pair: [2, 14480]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 679063, starting edge 2nd facet= 723898,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 30
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 7.033348083496094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.033866167068481445
# returned from stitch mesh: 1.2369749546051025
# Finished stitching child 49 : 1.388500690460205
# ***************Finished big stitching iteration: 21.85540223121643***************
# Starting Child 3
# 5 17278
# Done distance matrix: 0.004581451416015625
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# 540 17278
# Done distance matrix: 0.4060525894165039
# Done Generating final pairs: 0.4232325553894043
# best_stitch_pair = [  113 15891]
# best_stitch_pair_size = 570364.2038220733
# best_stitch_pair_distance = 158.43276746152722
# best_stitch_pair_size_ratio = 0.8301743993023349
# Starting Child 7
# 1210 17278
# Done distance matrix: 1.032235860824585
# Child 7 There were no points close enough
# Starting Child 8
# 513 17278
# Done distance matrix: 0.5538101196289062
# Child 8 There were no points close enough
# Starting Child 12
# 7 17278
# Done distance matrix: 0.011494159698486328
# Done Generating final pairs: 0.017365694046020508
# best_stitch_pair = [    2 16822]
# best_stitch_pair_size = 524814.045446788
# best_stitch_pair_distance = 1910.7740071882486
# best_stitch_pair_size_ratio = 0.8873384730816792
# Starting Child 15
# 10 17278
# Done distance matrix: 0.007521152496337891
# Done Generating final pairs: 0.017009973526000977
# best_stitch_pair = [    0 15606]
# best_stitch_pair_size = 484041.7000157629
# best_stitch_pair_distance = 1512.8926376448728
# best_stitch_pair_size_ratio = 0.49063287264707567
# Starting Child 17
# 14 17278
# Done distance matrix: 0.010706424713134766
# Done Generating final pairs: 0.015295982360839844
# best_stitch_pair = [    0 16810]
# best_stitch_pair_size = 470527.3490341031
# best_stitch_pair_distance = 1281.5462048515146
# best_stitch_pair_size_ratio = 0.7505373629754781
# Starting Child 18
# 29 17278
# Done distance matrix: 0.0265047550201416
# Done Generating final pairs: 0.050394535064697266
# best_stitch_pair = [   25 15606]
# best_stitch_pair_size = 302760.56132020603
# best_stitch_pair_distance = 563.264794492585
# best_stitch_pair_size_ratio = 0.9003367880308277
# Starting Child 20
# 113 17278
# Done distance matrix: 0.08353924751281738
# Child 20 There were no points close enough
# Starting Child 21
# 89 17278
# Done distance matrix: 0.08204340934753418
# Child 21 There were no points close enough
# Starting Child 22
# 21 17278
# Done distance matrix: 0.01625537872314453
# Child 22 There were no points close enough
# Starting Child 23
# 8 17278
# Done distance matrix: 0.00655674934387207
# Child 23 There were no points close enough
# Starting Child 24
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 2 17278
# Done distance matrix: 0.0017659664154052734
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# 273 17278
# Done distance matrix: 0.1748030185699463
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# 25 17278
# Done distance matrix: 0.03193855285644531
# Child 28 There were no points close enough
# Starting Child 31
# 73 17278
# Done distance matrix: 0.0838918685913086
# Done Generating final pairs: 0.12146544456481934
# best_stitch_pair = [   21 15174]
# best_stitch_pair_size = 3782351.224559938
# best_stitch_pair_distance = 1212.1542304819388
# best_stitch_pair_size_ratio = 0.48091323555782894
# Starting Child 33
# 13 17278
# Done distance matrix: 0.012738704681396484
# Done Generating final pairs: 0.016004562377929688
# best_stitch_pair = [    5 16810]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1993.5722671048318
# best_stitch_pair_size_ratio = 0.0
# Starting Child 34
# 23 17278
# Done distance matrix: 0.01795220375061035
# Done Generating final pairs: 0.06385374069213867
# best_stitch_pair = [    2 17265]
# best_stitch_pair_size = 2327527.915491613
# best_stitch_pair_distance = 1771.0073170048124
# best_stitch_pair_size_ratio = 0.47746301108795747
# Starting Child 35
# 7 17278
# Done distance matrix: 0.006134033203125
# Child 35 There were no points close enough
# Starting Child 37
# 9 17278
# Done distance matrix: 0.008011817932128906
# Done Generating final pairs: 0.04339289665222168
# best_stitch_pair = [    1 15606]
# best_stitch_pair_size = 374247.8194083439
# best_stitch_pair_distance = 382.84276657377995
# ...
# Finished stitching child 26 : 2.4170565605163574
# ---Stitching child 128 with pair: [2, 10737]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 372455, starting edge 2nd facet= 1750390,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.052086830139160156
# returned from stitch mesh: 1.9621689319610596
# Finished stitching child 128 : 2.282916307449341
# ***************Finished big stitching iteration: 5.101464033126831***************
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0019047260284423828
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0018491744995117188
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0017004013061523438
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0015168190002441406
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 137
# 2 45232
# Done distance matrix: 0.004606723785400391
# Child 137 There were no points close enough
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0016243457794189453
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0016336441040039062
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 167
# 2 45232
# Done distance matrix: 0.0034372806549072266
# Child 167 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0017926692962646484
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0016107559204101562
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0018076896667480469
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0016469955444335938
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0015592575073242188
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 137
# 2 45232
# Done distance matrix: 0.0036323070526123047
# Child 137 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0017886161804199219
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0017709732055664062
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 167
# 2 45232
# Done distance matrix: 0.0033082962036132812
# Child 167 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0016145706176757812
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0017518997192382812
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0016438961029052734
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.001483917236328125
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0015223026275634766
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 137
# 2 45232
# Done distance matrix: 0.0035457611083984375
# Done Generating final pairs: 0.011162757873535156
# best_stitch_pair = [    1 16197]
# best_stitch_pair_size = 32067.20840769495
# best_stitch_pair_distance = 2937.3250680813226
# best_stitch_pair_size_ratio = 0.5121727552283007
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0015642642974853516
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0016205310821533203
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 167
# 2 45232
# Done distance matrix: 0.005423545837402344
# Child 167 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0017583370208740234
# Child 184 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {137: [1, 16197]}
# ---Stitching child 137 with pair: [1, 16197]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 141455, starting edge 2nd facet= 1750464,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 4.6253204345703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.009408235549926758
# returned from stitch mesh: 2.2991085052490234
# Finished stitching child 137 : 2.6167361736297607
# ***************Finished big stitching iteration: 2.9554855823516846***************
# Starting Child 18
# 1 45232
# Done distance matrix: 0.002413511276245117
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0022735595703125
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0019600391387939453
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.001967191696166992
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.001962900161743164
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.001964569091796875
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 167
# 2 45232
# Done distance matrix: 0.004716634750366211
# Child 167 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0015401840209960938
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0014941692352294922
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.001706838607788086
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0015797615051269531
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0016393661499023438
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0019593238830566406
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0016798973083496094
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 167
# 2 45232
# Done distance matrix: 0.003268718719482422
# Done Generating final pairs: 0.0058231353759765625
# best_stitch_pair = [    1 17094]
# best_stitch_pair_size = 27123.485482941447
# best_stitch_pair_distance = 4723.4056709409415
# best_stitch_pair_size_ratio = 0.62095759075883
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0017032623291015625
# Child 184 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {167: [1, 17094]}
# ---Stitching child 167 with pair: [1, 17094]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 811666, starting edge 2nd facet= 1750469,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.430511474609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05920863151550293
# returned from stitch mesh: 1.7289435863494873
# Finished stitching child 167 : 1.9279050827026367
# ***************Finished big stitching iteration: 2.2689175605773926***************
# Starting Child 18
# 1 45232
# Done distance matrix: 0.001802206039428711
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0018157958984375
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0016586780548095703
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0015382766723632812
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0018544197082519531
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0015125274658203125
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0016393661499023438
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0028111934661865234
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0026655197143554688
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0026667118072509766
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.002671480178833008
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0026388168334960938
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.002528667449951172
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0024094581604003906
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0020503997802734375
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.0019903182983398438
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.001964092254638672
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0019459724426269531
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0027451515197753906
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.0019936561584472656
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.002440929412841797
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 18
# 1 45232
# Done distance matrix: 0.0019812583923339844
# Child 18 There were no points close enough
# Starting Child 25
# 1 45232
# Done distance matrix: 0.002249479293823242
# Child 25 There were no points close enough
# Starting Child 37
# 1 45232
# Done distance matrix: 0.0021257400512695312
# Child 37 There were no points close enough
# Starting Child 58
# 1 45232
# Done distance matrix: 0.0020873546600341797
# Child 58 There were no points close enough
# Starting Child 63
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 98
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 112
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 138
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 145
# 1 45232
# Done distance matrix: 0.0025730133056640625
# Child 145 There were no points close enough
# Starting Child 158
# 1 45232
# Done distance matrix: 0.002310514450073242
# Child 158 There were no points close enough
# Starting Child 163
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 172
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 184
# 1 45232
# Done distance matrix: 0.0026082992553710938
# Child 184 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 537.9722263813019
# Total time for restitching = 537.9826335906982
# missed_children = [98.0, 163.0, 37.0, 138.0, 172.0, 112.0, 145.0, 18.0, 184.0, 25.0, 58.0, 158.0, 63.0]
# Whole stitching function complete: 722.8095321655273
# 6134.248486280441

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
