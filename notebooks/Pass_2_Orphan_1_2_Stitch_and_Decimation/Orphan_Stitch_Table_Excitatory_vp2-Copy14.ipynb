# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346342806333**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 80 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 254158
# Total time for Mesh Cleansing: 5.524962425231934
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976918185172682% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342915230**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 365406
# Total time for Mesh Cleansing: 8.947910070419312
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987481687184309% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344419150**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 168675
# Total time for Mesh Cleansing: 5.476832389831543
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998981326289481% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344465852**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 54750
# Total time for Mesh Cleansing: 2.2722327709198
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9975221367926247% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344501838**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 40630
# Total time for Mesh Cleansing: 0.298764705657959
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999803139918303% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344503678**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 33878
# Total time for Mesh Cleansing: 0.12653112411499023
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992331288343558% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344504833**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 13324
# Total time for Mesh Cleansing: 0.11505317687988281
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986508769299955% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344509876**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 72090
# Total time for Mesh Cleansing: 0.3937814235687256
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996671936101174% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344515629**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 81390
# Total time for Mesh Cleansing: 0.2984311580657959
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997543299348974% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344517858**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 12 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 81466
# Total time for Mesh Cleansing: 0.32619643211364746
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994847131569907% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344518919**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 18 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 97732
# Total time for Mesh Cleansing: 2.6686460971832275
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998508347126014% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346345883620**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 34702
# Total time for Mesh Cleansing: 0.1443028450012207
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998847461534028% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346345883978**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 64090
# Total time for Mesh Cleansing: 0.29777097702026367
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990958408679927% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346296733**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 121674
# Total time for Mesh Cleansing: 0.5839571952819824
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996385086840073% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346302170**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 18 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 79594
# Total time for Mesh Cleansing: 0.18130278587341309
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988454684637201% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346311974**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 166228
# Total time for Mesh Cleansing: 0.5888192653656006
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995550263977583% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346319111**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 18452
# Total time for Mesh Cleansing: 0.053800106048583984
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996749376963918% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346584570**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 69760
# Total time for Mesh Cleansing: 0.3832974433898926
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999713384924047% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346587006**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 50456
# Total time for Mesh Cleansing: 0.14948773384094238
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992870157648737% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346589334**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 105524
# Total time for Mesh Cleansing: 4.456040859222412
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991478402484519% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346998356**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 32622
# Total time for Mesh Cleansing: 0.3273591995239258
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999877398393919% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346998597**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 14638
# Total time for Mesh Cleansing: 0.1778576374053955
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995902758809069% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346347001783**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 71934
# Total time for Mesh Cleansing: 2.343937873840332
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998584041312677% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348194427**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 32896
# Total time for Mesh Cleansing: 1.63881254196167
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9964861262571186% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348464873**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 25530
# Total time for Mesh Cleansing: 0.08752322196960449
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999843346126733% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348497670**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 36958
# Total time for Mesh Cleansing: 0.1976313591003418
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995672634824472% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348719136**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 70300
# Total time for Mesh Cleansing: 0.4076559543609619
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993745024451268% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349375068**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 95436
# Total time for Mesh Cleansing: 3.560256242752075
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9923057727499585% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349468622**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 143 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 404869
# Total time for Mesh Cleansing: 15.035689115524292
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.997959067974375% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349501064**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 226 pieces after mesh split
# There were 13 pieces found after size threshold
# max_index = 0
# max_face_len = 563312
# Total time for Mesh Cleansing: 21.774667739868164
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9959934792371697% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509479**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 386 pieces after mesh split
# There were 54 pieces found after size threshold
# max_index = 0
# max_face_len = 526248
# Total time for Mesh Cleansing: 83.75292301177979
# Number of outside child meshes =  13
# Main mesh and outside child meshes make up 0.9906263788341804% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509479_30_main_and_child_meshes_array.npz
#  face length 526248 using optimized facets with 3 neighbors
# Filtering edges by size finished: 17.686061143875122, facet # = 29889
# Filtering by convexity and getting centers took: 19.278186321258545, facet # = 4579
# Finished 4579 facets for main mesh: 38.27604293823242
# Filtering edges by size finished: 2.3821990489959717, facet # = 4336
# Filtering by convexity and getting centers took: 2.2314484119415283, facet # = 747
# Filtering edges by size finished: 0.08100390434265137, facet # = 55
# Filtering by convexity and getting centers took: 0.06273460388183594, facet # = 13
# Filtering edges by size finished: 0.0016014575958251953, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0010845661163330078, facet # = 1
# Filtering edges by size finished: 0.006293296813964844, facet # = 23
# Filtering by convexity and getting centers took: 0.008930444717407227, facet # = 5
# Filtering edges by size finished: 0.0012691020965576172, facet # = 6
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003231525421142578, facet # = 4
# Filtering edges by size finished: 0.0008616447448730469, facet # = 5
# Filtering by convexity and getting centers took: 0.002296924591064453, facet # = 2
# Filtering edges by size finished: 0.0015332698822021484, facet # = 6
# Filtering by convexity and getting centers took: 0.0021486282348632812, facet # = 4
# Filtering edges by size finished: 0.004198789596557617, facet # = 15
# Filtering by convexity and getting centers took: 0.004849672317504883, facet # = 2
# Filtering edges by size finished: 0.0011835098266601562, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0008103847503662109, facet # = 1
# Filtering edges by size finished: 0.0009446144104003906, facet # = 6
# Filtering by convexity and getting centers took: 0.002372264862060547, facet # = 6
# Filtering edges by size finished: 0.0003161430358886719, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0012507438659667969, facet # = 2
# Filtering edges by size finished: 0.0007274150848388672, facet # = 7
# Filtering by convexity and getting centers took: 0.002404451370239258, facet # = 3
# Filtering edges by size finished: 0.0013120174407958984, facet # = 12
# Filtering by convexity and getting centers took: 0.0032494068145751953, facet # = 1
# Total time for facets: 43.23503828048706
# Zero faceted faces = []
# Starting Child 0
# 747 4579
# Done distance matrix: 0.2781705856323242
# Done Generating final pairs: 0.31159186363220215
# best_stitch_pair = [ 311 2249]
# best_stitch_pair_size = 344590.42386213783
# best_stitch_pair_distance = 1797.763377721973
# best_stitch_pair_size_ratio = 0.36082732541306717
# Starting Child 1
# 13 4579
# Done distance matrix: 0.003032684326171875
# Done Generating final pairs: 0.05303645133972168
# best_stitch_pair = [  9 477]
# best_stitch_pair_size = 81600.23584432504
# best_stitch_pair_distance = 1764.4406763663776
# best_stitch_pair_size_ratio = 0.2922550287342839
# Starting Child 2
# 1 4579
# Done distance matrix: 0.0003082752227783203
# Child 2 There were no points close enough
# Starting Child 3
# 5 4579
# Done distance matrix: 0.0015528202056884766
# Child 3 There were no points close enough
# Starting Child 4
# 4 4579
# Done distance matrix: 0.0009410381317138672
# Child 4 There were no points close enough
# Starting Child 5
# 2 4579
# Done distance matrix: 0.0006933212280273438
# Child 5 There were no points close enough
# Starting Child 6
# returning x less min
# skipped by bounding box filter
# Starting Child 7
# returning x less min
# skipped by bounding box filter
# Starting Child 8
# 1 4579
# Done distance matrix: 0.000370025634765625
# Child 8 There were no points close enough
# Starting Child 9
# 6 4579
# Done distance matrix: 0.0010457038879394531
# Child 9 There were no points close enough
# Starting Child 10
# 2 4579
# Done distance matrix: 0.0007305145263671875
# Child 10 There were no points close enough
# Starting Child 11
# 3 4579
# Done distance matrix: 0.0007762908935546875
# Child 11 There were no points close enough
# Starting Child 12
# 1 4579
# Done distance matrix: 0.0006144046783447266
# Child 12 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [311, 2249], 1: [9, 477]}
# ---Stitching child 0 with pair: [311, 2249]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 76081, starting edge 2nd facet= 270906,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.266334533691406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010375499725341797
# returned from stitch mesh: 0.45871424674987793
# Finished stitching child 0 : 0.5075719356536865
# ---Stitching child 1 with pair: [9, 477]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 83717, starting edge 2nd facet= 304484,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010162591934204102
# returned from stitch mesh: 0.4821200370788574
# Finished stitching child 1 : 0.542015790939331
# ***************Finished big stitching iteration: 1.6535959243774414***************
# Starting Child 2
# 1 5335
# Done distance matrix: 0.0006299018859863281
# Child 2 There were no points close enough
# Starting Child 3
# 5 5335
# Done distance matrix: 0.0010416507720947266
# Done Generating final pairs: 0.028840303421020508
# best_stitch_pair = [   0 4967]
# best_stitch_pair_size = 58788.79155246555
# best_stitch_pair_distance = 1043.805818928266
# best_stitch_pair_size_ratio = 0.152364430783476
# Starting Child 4
# 4 5335
# Done distance matrix: 0.0009024143218994141
# Done Generating final pairs: 0.0027434825897216797
# best_stitch_pair = [   1 4809]
# best_stitch_pair_size = 35503.20072731341
# best_stitch_pair_distance = 1284.3964595907473
# best_stitch_pair_size_ratio = 0.523050525143031
# Starting Child 5
# 2 5335
# Done distance matrix: 0.0008249282836914062
# Done Generating final pairs: 0.0023076534271240234
# best_stitch_pair = [   0 5052]
# best_stitch_pair_size = 54833.65223857151
# best_stitch_pair_distance = 1908.365408976526
# best_stitch_pair_size_ratio = 0.22177467440191165
# Starting Child 6
# 4 5335
# Done distance matrix: 0.0008363723754882812
# Done Generating final pairs: 0.0035626888275146484
# best_stitch_pair = [   0 5029]
# best_stitch_pair_size = 54871.15474673538
# best_stitch_pair_distance = 1095.451928309228
# best_stitch_pair_size_ratio = 0.933657025278253
# Starting Child 7
# 2 5335
# Done distance matrix: 0.0005865097045898438
# Done Generating final pairs: 0.0024154186248779297
# best_stitch_pair = [   0 5015]
# best_stitch_pair_size = 30273.07898830201
# best_stitch_pair_distance = 1435.826137306839
# best_stitch_pair_size_ratio = 0.6280018682987183
# Starting Child 8
# 1 5335
# Done distance matrix: 0.0003235340118408203
# Child 8 There were no points close enough
# Starting Child 9
# 6 5335
# Done distance matrix: 0.001638650894165039
# Done Generating final pairs: 0.005224943161010742
# best_stitch_pair = [   3 5186]
# best_stitch_pair_size = 59046.328682967694
# best_stitch_pair_distance = 1515.8511668351973
# best_stitch_pair_size_ratio = 0.18695931811388258
# Starting Child 10
# 2 5335
# Done distance matrix: 0.0006392002105712891
# Done Generating final pairs: 0.007208347320556641
# best_stitch_pair = [   1 5207]
# best_stitch_pair_size = 54421.49962058282
# best_stitch_pair_distance = 1447.4741907837513
# best_stitch_pair_size_ratio = 0.269520575590555
# Starting Child 11
# 3 5335
# Done distance matrix: 0.0009527206420898438
# Done Generating final pairs: 0.0033044815063476562
# best_stitch_pair = [   0 5186]
# best_stitch_pair_size = 59481.768275100796
# best_stitch_pair_distance = 1305.8283452621865
# best_stitch_pair_size_ratio = 0.1957125986799473
# Starting Child 12
# 1 5335
# Done distance matrix: 0.0003650188446044922
# Child 12 There were no points close enough
# repeat_main_facets = [5186]
# child_mesh_double_indexes = [9, 11]
# min_child = 11, max_ratio = 1305.8283452621865
# child_meshes_stitch_facets = {3: [0, 4967], 4: [1, 4809], 5: [0, 5052], 6: [0, 5029], 7: [0, 5015], 10: [1, 5207], 11: [0, 5186]}
# ---Stitching child 3 with pair: [0, 4967]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 276265, starting edge 2nd facet= 304581,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011944770812988281
# returned from stitch mesh: 0.5044019222259521
# Finished stitching child 3 : 0.5477302074432373
# ---Stitching child 4 with pair: [1, 4809]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 280468, starting edge 2nd facet= 304653,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010456323623657227
# returned from stitch mesh: 0.5054886341094971
# Finished stitching child 4 : 0.5607092380523682
# ---Stitching child 5 with pair: [0, 5052]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 302759, starting edge 2nd facet= 304684,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 3, remainder = 0
# About to add faces
# Finished adding faces: 1.4066696166992188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0033266544342041016
# returned from stitch mesh: 0.5440530776977539
# Finished stitching child 5 : 0.6832833290100098
# ---Stitching child 6 with pair: [0, 5029]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 290646, starting edge 2nd facet= 304724,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.2649765014648438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0035796165466308594
# returned from stitch mesh: 0.4338095188140869
# Finished stitching child 6 : 0.4631690979003906
# ---Stitching child 7 with pair: [0, 5015]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 275873, starting edge 2nd facet= 304794,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0044498443603515625
# returned from stitch mesh: 0.5219721794128418
# Finished stitching child 7 : 0.560600757598877
# ---Stitching child 10 with pair: [1, 5207]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 281939, starting edge 2nd facet= 304804,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0036644935607910156
# returned from stitch mesh: 0.3623189926147461
# Finished stitching child 10 : 0.3993527889251709
# ---Stitching child 11 with pair: [0, 5186]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 288651, starting edge 2nd facet= 304822,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011011123657226562
# returned from stitch mesh: 0.37731170654296875
# Finished stitching child 11 : 0.4576127529144287
# ***************Finished big stitching iteration: 4.3551716804504395***************
# Starting Child 2
# 1 5343
# Done distance matrix: 0.0009183883666992188
# Child 2 There were no points close enough
# Starting Child 8
# 1 5343
# Done distance matrix: 0.0007040500640869141
# Child 8 There were no points close enough
# Starting Child 9
# 6 5343
# Done distance matrix: 0.0016760826110839844
# Done Generating final pairs: 0.004001140594482422
# best_stitch_pair = [   0 5266]
# best_stitch_pair_size = 27898.954540771636
# best_stitch_pair_distance = 1149.7665836108058
# best_stitch_pair_size_ratio = 0.3556610382706454
# Starting Child 12
# 1 5343
# Done distance matrix: 0.0007200241088867188
# Child 12 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {9: [0, 5266]}
# ---Stitching child 9 with pair: [0, 5266]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 298686, starting edge 2nd facet= 304860,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.71661376953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011090517044067383
# returned from stitch mesh: 0.31539297103881836
# Finished stitching child 9 : 0.35680079460144043
# ***************Finished big stitching iteration: 0.890714168548584***************
# Starting Child 2
# 1 5347
# Done distance matrix: 0.006699800491333008
# Child 2 There were no points close enough
# Starting Child 8
# 1 5347
# Done distance matrix: 0.00039267539978027344
# Child 8 There were no points close enough
# Starting Child 12
# 1 5347
# Done distance matrix: 0.00033211708068847656
# Child 12 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 2
# 1 5347
# Done distance matrix: 0.0003924369812011719
# Child 2 There were no points close enough
# Starting Child 8
# 1 5347
# Done distance matrix: 0.000308990478515625
# Child 8 There were no points close enough
# Starting Child 12
# 1 5347
# Done distance matrix: 0.00033164024353027344
# Child 12 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 2
# 1 5347
# Done distance matrix: 0.0003497600555419922
# Child 2 There were no points close enough
# Starting Child 8
# 1 5347
# Done distance matrix: 0.0002949237823486328
# Child 8 There were no points close enough
# Starting Child 12
# 1 5347
# Done distance matrix: 0.0002968311309814453
# Child 12 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 2
# 1 5347
# Done distance matrix: 0.0003612041473388672
# Child 2 There were no points close enough
# Starting Child 8
# 1 5347
# Done distance matrix: 0.00032329559326171875
# Child 8 There were no points close enough
# Starting Child 12
# 1 5347
# Done distance matrix: 0.0002963542938232422
# Child 12 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 7.7451958656311035
# Total time for restitching = 7.747190713882446
# missed_children = [8.0, 2.0, 12.0]
# Whole stitching function complete: 136.4891197681427
#
#
#
# *****Running Neuron Stitcher for 648518346349093654**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 15734
# Total time for Mesh Cleansing: 0.2082996368408203
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999364837398374% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349094007**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 18942
# Total time for Mesh Cleansing: 0.7967445850372314
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9863570089564674% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509588**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 53 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 171852
# Total time for Mesh Cleansing: 5.578949689865112
# Number of outside child meshes =  7
# Main mesh and outside child meshes make up 0.9988563504070312% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509588_30_main_and_child_meshes_array.npz
#  face length 171852 using optimized facets with 3 neighbors
# Filtering edges by size finished: 3.5566184520721436, facet # = 8922
# Filtering by convexity and getting centers took: 7.686305284500122, facet # = 1916
# Finished 1916 facets for main mesh: 11.472035884857178
# Filtering edges by size finished: 1.3239104747772217, facet # = 5339
# Filtering by convexity and getting centers took: 1.84135103225708, facet # = 1119
# Filtering edges by size finished: 0.23955631256103516, facet # = 699
# Filtering by convexity and getting centers took: 0.59761643409729, facet # = 213
# Filtering edges by size finished: 0.016305923461914062, facet # = 8
# Filtering by convexity and getting centers took: 0.0033173561096191406, facet # = 0
# Filtering edges by size finished: 0.028769969940185547, facet # = 127
# Filtering by convexity and getting centers took: 0.03247475624084473, facet # = 9
# Filtering edges by size finished: 0.01065373420715332, facet # = 73
# Filtering by convexity and getting centers took: 0.02060532569885254, facet # = 28
# Filtering edges by size finished: 0.013612508773803711, facet # = 87
# Filtering by convexity and getting centers took: 0.024875640869140625, facet # = 36
# Filtering edges by size finished: 0.001817464828491211, facet # = 6
# Filtering by convexity and getting centers took: 0.002016305923461914, facet # = 0
# Total time for facets: 15.724611520767212
# Zero faceted faces = [2, 6]
# Starting Child 0
# 1119 1916
# Done distance matrix: 0.13251447677612305
# Done Generating final pairs: 0.13875317573547363
# best_stitch_pair = [577 863]
# best_stitch_pair_size = 62852.55054866971
# best_stitch_pair_distance = 1752.4270458266387
# best_stitch_pair_size_ratio = 0.8888237965134936
# Starting Child 1
# 213 1916
# Done distance matrix: 0.025234699249267578
# Done Generating final pairs: 0.04806184768676758
# best_stitch_pair = [43 34]
# best_stitch_pair_size = 208157.86242219625
# best_stitch_pair_distance = 1908.779569463285
# best_stitch_pair_size_ratio = 0.25850117554791247
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 3
# 9 1916
# Done distance matrix: 0.0011355876922607422
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 28 1916
# Done distance matrix: 0.0033576488494873047
# Child 4 There were no points close enough
# Starting Child 5
# 36 1916
# Done distance matrix: 0.004293680191040039
# Child 5 There were no points close enough
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [577, 863], 1: [43, 34]}
# ---Stitching child 0 with pair: [577, 863]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 67764, starting edge 2nd facet= 97437,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0012323856353759766
# returned from stitch mesh: 0.1721484661102295
# Finished stitching child 0 : 0.1914079189300537
# ---Stitching child 1 with pair: [43, 34]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 38066, starting edge 2nd facet= 109616,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.814697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.007424354553222656
# returned from stitch mesh: 0.17972588539123535
# Finished stitching child 1 : 0.19361329078674316
# ***************Finished big stitching iteration: 0.6506671905517578***************
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 3
# 9 3244
# Done distance matrix: 0.0019507408142089844
# Done Generating final pairs: 0.010335922241210938
# best_stitch_pair = [   6 2932]
# best_stitch_pair_size = 42938.75452602524
# best_stitch_pair_distance = 1298.7463328525955
# best_stitch_pair_size_ratio = 0.5686159747541089
# Starting Child 4
# 28 3244
# Done distance matrix: 0.013900995254516602
# Done Generating final pairs: 0.11867380142211914
# best_stitch_pair = [  16 2496]
# best_stitch_pair_size = 158274.20352474652
# best_stitch_pair_distance = 1046.912257820823
# best_stitch_pair_size_ratio = 0.2059369317412008
# Starting Child 5
# 36 3244
# Done distance matrix: 0.007352590560913086
# Done Generating final pairs: 0.025883913040161133
# best_stitch_pair = [  20 3150]
# best_stitch_pair_size = 39892.68592985615
# best_stitch_pair_distance = 1808.9318227143879
# best_stitch_pair_size_ratio = 0.8740555646651671
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [6, 2932], 4: [16, 2496], 5: [20, 3150]}
# ---Stitching child 3 with pair: [6, 2932]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 90687, starting edge 2nd facet= 111042,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003033161163330078
# returned from stitch mesh: 0.18482065200805664
# Finished stitching child 3 : 0.20479536056518555
# ---Stitching child 4 with pair: [16, 2496]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 94106, starting edge 2nd facet= 111238,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.0265579223632812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0030164718627929688
# returned from stitch mesh: 0.22401952743530273
# Finished stitching child 4 : 0.24161529541015625
# ---Stitching child 5 with pair: [20, 3150]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 110301, starting edge 2nd facet= 111638,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0013566017150878906
# returned from stitch mesh: 0.3397698402404785
# Finished stitching child 5 : 0.3561215400695801
# ***************Finished big stitching iteration: 1.1883025169372559***************
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 2
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 6
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 2.2738475799560547
# Total time for restitching = 2.2751030921936035
# missed_children = [2.0, 6.0]
# Whole stitching function complete: 24.33753728866577
#
#
#
# *****Running Neuron Stitcher for 648518346341360660**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 67758
# Total time for Mesh Cleansing: 0.2731170654296875
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992331514525881% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341361018**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 63 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 279128
# Total time for Mesh Cleansing: 0.88187575340271
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988405880079584% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341361112**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 62404
# Total time for Mesh Cleansing: 0.3021523952484131
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999679610406254% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362114**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 13362
# Total time for Mesh Cleansing: 0.06114077568054199
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362477**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 93856
# Total time for Mesh Cleansing: 0.3903069496154785
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.99880810488677% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341366161**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 68 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 254852
# Total time for Mesh Cleansing: 7.778696298599243
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985581067314474% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341371031**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 29024
# Total time for Mesh Cleansing: 2.004183530807495
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9839311139738287% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341372326**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 23 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 164132
# Total time for Mesh Cleansing: 0.4746532440185547
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992450808494058% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341373475**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 325 pieces after mesh split
# There were 22 pieces found after size threshold
# max_index = 0
# max_face_len = 1146734
# Total time for Mesh Cleansing: 58.47133994102478
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.997283142788066% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341404207**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 14986
# Total time for Mesh Cleansing: 0.9371650218963623
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9872200263504611% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341405847**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 167 pieces after mesh split
# There were 23 pieces found after size threshold
# max_index = 0
# max_face_len = 203662
# Total time for Mesh Cleansing: 13.133771657943726
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9856266212396918% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409362**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 31946
# Total time for Mesh Cleansing: 0.10055923461914062
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409969**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 19 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 138776
# Total time for Mesh Cleansing: 0.5255084037780762
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993806800996673% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410336**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 12 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 64680
# Total time for Mesh Cleansing: 0.14166259765625
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990732159406858% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410757**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 53 pieces after mesh split
# There were 16 pieces found after size threshold
# max_index = 0
# max_face_len = 70696
# Total time for Mesh Cleansing: 4.631860256195068
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9822708831212138% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410882**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 78 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 318278
# ...
# max_index = 0
# max_face_len = 48438
# Total time for Mesh Cleansing: 0.40782761573791504
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983511274166289% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342788606**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 89 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 250808
# Total time for Mesh Cleansing: 13.773390769958496
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976451869530628% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342791924**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 109 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 547484
# Total time for Mesh Cleansing: 1.4226784706115723
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989927668985249% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793052**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 29 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 152568
# Total time for Mesh Cleansing: 0.745206356048584
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990963026993045% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793468**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 130808
# Total time for Mesh Cleansing: 3.8374457359313965
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9971489991004864% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793923**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 97 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 319506
# Total time for Mesh Cleansing: 11.270070314407349
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9942431446744421% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797719**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 64 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 422908
# Total time for Mesh Cleansing: 10.885939359664917
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992108533652142% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342803868**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 657 pieces after mesh split
# There were 174 pieces found after size threshold
# max_index = 0
# max_face_len = 666272
# Total time for Mesh Cleansing: 156.15806984901428
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.976789463190364% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341357847**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 101251
# Total time for Mesh Cleansing: 0.2852911949157715
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984419528838663% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341358846**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 29 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 197514
# Total time for Mesh Cleansing: 0.6263844966888428
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992411364740165% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341359309**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 56 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 380378
# Total time for Mesh Cleansing: 12.10080599784851
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989442722832081% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341368301**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 14228
# Total time for Mesh Cleansing: 0.7548022270202637
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9948258984757377% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341368711**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 72 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 272180
# Total time for Mesh Cleansing: 0.8549437522888184
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986571074240679% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341369015**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 111972
# Total time for Mesh Cleansing: 4.612210750579834
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984840648463555% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341380191**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 31854
# Total time for Mesh Cleansing: 1.2508440017700195
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9959977487336626% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341385375**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 291926
# Total time for Mesh Cleansing: 10.789930820465088
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987683296497266% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341395959**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 76404
# Total time for Mesh Cleansing: 0.22092890739440918
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992414532709059% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341396536**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 136492
# Total time for Mesh Cleansing: 5.907610177993774
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981571403498508% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399296**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 142 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 397751
# Total time for Mesh Cleansing: 10.943989276885986
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.997017102779609% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409682**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 27512
# Total time for Mesh Cleansing: 0.13154196739196777
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999781960898321% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410176**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 46 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 302944
# Total time for Mesh Cleansing: 9.530821800231934
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983522495089704% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342789316**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 188 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 732070
# Total time for Mesh Cleansing: 34.39677715301514
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9971314780107222% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342798654**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 30 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 190180
# Total time for Mesh Cleansing: 7.696662187576294
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987710987637464% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342805497**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 24 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 222362
# Total time for Mesh Cleansing: 5.200042247772217
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991372880289727% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342807789**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 134 pieces after mesh split
# There were 30 pieces found after size threshold
# max_index = 0
# max_face_len = 320262
# Total time for Mesh Cleansing: 20.680351972579956
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9911917996459388% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344073148**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 55808
# Total time for Mesh Cleansing: 2.336463689804077
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9967850253625777% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344077004**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 146594
# Total time for Mesh Cleansing: 0.4217536449432373
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994682011563216% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344082166**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 72738
# Total time for Mesh Cleansing: 2.816624402999878
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976409271704841% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349475163**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 604 pieces after mesh split
# There were 67 pieces found after size threshold
# max_index = 0
# max_face_len = 325716
# Total time for Mesh Cleansing: 47.473713397979736
# Number of outside child meshes =  2
# Main mesh and outside child meshes make up 0.8442144414917039% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349475163_30_main_and_child_meshes_array.npz
#  face length 325716 using optimized facets with 3 neighbors
# Filtering edges by size finished: 9.81692624092102, facet # = 17024
# Filtering by convexity and getting centers took: 9.861159801483154, facet # = 3401
# Finished 3401 facets for main mesh: 20.291263103485107
# Filtering edges by size finished: 0.002529621124267578, facet # = 18
# Filtering by convexity and getting centers took: 0.009804248809814453, facet # = 12
# Filtering edges by size finished: 0.0006325244903564453, facet # = 2
# Filtering by convexity and getting centers took: 0.0014731884002685547, facet # = 1
# Total time for facets: 20.31002974510193
# Zero faceted faces = []
# Starting Child 0
# 12 3401
# Done distance matrix: 0.002814769744873047
# Done Generating final pairs: 0.008431196212768555
# best_stitch_pair = [   2 3330]
# best_stitch_pair_size = 28964.42157666976
# best_stitch_pair_distance = 1827.701698469509
# best_stitch_pair_size_ratio = 0.8200228856834157
# Starting Child 1
# 1 3401
# Done distance matrix: 0.0006844997406005859
# Child 1 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [2, 3330]}
# ---Stitching child 0 with pair: [2, 3330]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 73887, starting edge 2nd facet= 163751,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.001974821090698242
# returned from stitch mesh: 0.2382810115814209
# Finished stitching child 0 : 0.2845315933227539
# ***************Finished big stitching iteration: 0.34799814224243164***************
# Starting Child 1
# 1 3411
# Done distance matrix: 0.0007266998291015625
# Child 1 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# 1 3411
# Done distance matrix: 0.0007491111755371094
# Child 1 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 1
# 1 3411
# Done distance matrix: 0.0006949901580810547
# Child 1 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 1
# 1 3411
# Done distance matrix: 0.0005903244018554688
# Child 1 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 0.6612484455108643
# Total time for restitching = 0.6617531776428223
# missed_children = [1.0]
# Whole stitching function complete: 69.13014364242554
# 867.6747009754181

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
