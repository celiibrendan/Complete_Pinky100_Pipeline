# %%
import numpy as np
import datajoint as dj
import trimesh
from collections import Counter
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
pinky.SpineValidationStatistics()
# Out:
# *segmentation  *segment_id    *decimation_ra *compartment_t *component_ind *author_origin *author_proofr *starting_inde *n_triangles   *date_time     n_auto_spine   n_auto_shaft   n_false_negati n_false_positi true_positives n_merged_spine perc_spines_wi n_spines_with_ average_percen avg_spine_size
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 3              64851834634137 0.35           Oblique        0              computer_Auto  js48           17292          20142          2019-08-22 13: 7572           12570          0              2              43             5              0.10256        2              0.20838        187.97436
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           108090         30000          2019-08-12 17: 14534          15466          3              0              75             11             0.10000        0              None           205.70000
# 3              64851834634947 0.35           Basal          2              computer_Auto  js48           31952          30000          2019-08-16 12: 16408          13592          8              1              84             23             0.19737        0              None           213.28947
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           7895           30000          2019-08-12 18: 16234          13766          0              0              90             14             0.15789        3              0.55761        197.94737
# 3              64851834634947 0.35           Basal          1              computer_Auto  js48           119413         30000          2019-08-12 17: 14215          15785          10             1              88             17             0.17284        0              None           171.67901
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           78047          30000          2019-08-27 16: 4236           25764          1              1              28             0              0.00000        0              None           162.84000
# 3              64851834634947 0.35           Basal          2              computer_Auto  js48           102954         30000          2019-08-12 17: 12450          17550          6              0              60             13             0.16364        0              None           224.70909
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           144601         30000          2019-08-12 17: 18618          11382          1              0              87             16             0.15663        1              0.19072        221.65060
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           18050          30000          2019-08-12 17: 16059          13941          2              0              84             20             0.19753        0              None           196.66667
# 3              64851834634947 0.35           Basal          3              computer_Auto  js48           11184          20963          2019-08-14 12: 7307           13656          1              0              39             1              0.02857        1              0.73622        192.97143
# 3              64851834634947 0.35           Apical         2              computer_Auto  js48           36744          30000          2019-08-27 17: 15366          13014          5              0              94             11             0.10989        0              None           167.34066
# 3              64851834634947 0.35           Apical         0              computer_Auto  js48           88647          30000          2019-08-14 15: 15729          14271          0              0              82             15             0.19737        0              None           201.39474
#    ...
#  (Total: 108)

# %%
@schema
class SpineValidationStatisticsOrphan(dj.Computed):
    definition="""
    -> pinky.ProofreadLabelSpineWithInterestSlicesOrphan
    ---
    n_auto_spine      : int unsigned                 # number of faces classified as spine,spine-head or spine-neck by auto-classifier
    n_auto_shaft      : int unsigned                 # number of faces classified as shaft by auto-classifier
    n_false_negatives :  int unsigned                # number of spines incorrectly autoclassified as shaft (merged spines would add 2,3,4...etc)
    n_false_positive  : int unsigned                 # number of sections of the shaft that were incorrectly classified as spine
    true_positives    : int unsigned                 # number of spines correctly classified as spines
    n_merged_spines   : int unsigned                 # total number of additional spines that resulted from being merged with others
    perc_spines_with_merges=null : decimal(6,5)           # percentage of the true positive count that also had other spines merged onto it
    n_spines_with_overspined: int unsigned           # total number out of the true positives that had overspining occuring on their labeling
    average_percentage_overspined=null: decimal(6,5)      # for those that had overspining, the average face percentage that were labeled as overspined
    avg_spine_size=null    : decimal(10,5)                # average number of faces for the true positive spines
    
    """
    
    key_source = pinky.ProofreadLabelSpineWithInterestSlicesOrphan() & dict(author_proofreader="js48",status="complete")
    
    def make(self,key):
        print("key  = " + str(key))
        significant_size = 50
        search_key = dict(author_proofreader="js48",status="complete")
        search_dict = dict(search_key,segmentation=key["segmentation"],
                          segment_id=key["segment_id"],
                          compartment_type=key["compartment_type"],
                          component_index=key["component_index"])
        
        # get the mesh and the original and proofread labels
        """
        way to get the entire mesh:
        1) get the id, compartment type and component index, starting index, number of faces, and triangle indices
        from the validation proofing table
        2) Get the whole mesh from: 
        a. pinky.PymeshfixDecimatedExcitatoryStitchedMesh
        b. pinky.Decimation35OrphanStitched

        3) Use the triangle indices to restrict to the actual portion of submesh

        """

        #Example
        verts,faces = (pinky.Decimation35OrphanStitched() & search_dict).fetch1("vertices","triangles")

        #get compartment verts and faces
        verts_comp,faces_comp = (pinky.CompartmentOrphan.ComponentOrphan & search_dict).fetch1("vertex_indices","triangle_indices")

        #build the trimesh object
        new_mesh = trimesh.Trimesh(verts,faces)
        #new_mesh.show()
        compartment_mesh = new_mesh.submesh([faces_comp],append=True)

        #now get the submesh according to the triangle indices
        tri_indices = (pinky.ProofreadLabelSpineWithInterestSlicesOrphan & search_dict).fetch1("triangle_indices")
        random_mesh = compartment_mesh.submesh([tri_indices],append=True)
        #random_mesh.show()

        # how to get the automatic labels: 
        verts_labels,triangles_labels = (pinky.ComponentLabelOrphanWithStats & search_dict).fetch1("labeled_vertices","labeled_triangles")

        verts_labels = verts_labels.astype("int")
        triangles_labels = triangles_labels.astype("int")


        #get the new triangle lables based on the submesh indexes
        auto_labels = triangles_labels[tri_indices]
        auto_labels[auto_labels == 0] = 17
        auto_labels[auto_labels == 12] = 14
        auto_labels[auto_labels == 13] = 14
        auto_labels[auto_labels == 15] = 14
        auto_labels = auto_labels
        auto_labels

        #how to get the proofread labels
        tri_labels_proofread = (pinky.ProofreadLabelSpineWithInterestSlicesOrphan & search_dict).fetch1("triangles")
        tri_labels_proofread
        
        #get rid of all of the error and no_label sections: 
        labels_dict = dict(
        spine_1=12,
            shaft=2,
            shaft_over_spined=18,
            shaft_3=5,
            remove_label=0,
            error=10,
            spine_2=3,
            spine_3=4,
            spine_4=6,
            spine_5=9,
            all_one_spine=11,
            auto_shaft=17,
            auto_spine=14,
            spine_head_manual=13,
            spine_neck_manual=15,
            label_removed=1
        )

        labels_dict_flipped = dict([(v,k) for k,v in labels_dict.items()])
        labels_dict_flipped
        
        """
        1) Handle the all-one-spine pieces: get the submesh and split pieces, count the number of pieces as false negatives (SIGNIFICANT SIZED) 
         Eliminate any mesh pieces that are error or no label
        """
        all_one_spine_n_faces = 0
        all_one_spine_n_bodies = 0

        x = np.where(tri_labels_proofread == labels_dict["all_one_spine"])[0]
        if len(x) > 0:
            all_one_spine_n_faces = len(x)
            #get the submesh
            all_one_spine_mesh = random_mesh.submesh([x],append=True)
            #get the number of splits
            all_one_spine_mesh_split = all_one_spine_mesh.split(only_watertight=False)
            all_one_spine_n_bodies = len(all_one_spine_mesh_split)

        print("all_one_spine_n_bodies = " + str(all_one_spine_n_bodies)) 
        print("all_one_spine_n_faces = " + str(all_one_spine_n_faces))

        print("Done finding all in one spines")

        
        """
        For Shaft: 
        1) From original mesh extract the indices that were auto-shaft (get the number of faces in submesh to store later)
        2) Use the shaft indices to extract the new proofread labels for the autoshaft

        --- set size threshold for the spine counting (50)
        4) *** DON'T HAVE TO DO ANYMORE **** Get all the all_one_spine label indices --> create submesh from those. Count the number of all_one_spine as a missed spine
        5) Get the submesh of anything that is spine_1,spine_2,spine_3,spine_4,spine_5
        6) Split the submesh into disjointed parts (using connected_components to get the indices)
        7) Loop through the list (with indices)
        - if not meet desired threshold then put as 0
        - count the number of different spine labels that exist
        - store in array
        8) Sum the array and add on the all-one-spine number to count the total number missed
        """

        #extract the indices that were auto-shaft

        auto_shaft_indices = np.where(auto_labels==labels_dict["auto_shaft"])[0]
        #random_mesh_auto_shaft_indices = clean_indices[auto_shaft_indices]
        n_auto_shaft = len(auto_shaft_indices)
        n_auto_shaft

        #extract teh proofread shaft labels
        tri_labels_proofread_shaft = tri_labels_proofread[auto_shaft_indices]
        total_Counter = Counter(tri_labels_proofread_shaft)
        shaft_counts = dict([(labels_dict_flipped[k],total_Counter[k]) for k in dict(total_Counter).keys() ])
        print("After extracting the shaft after cleaning Distribution is:" + str(shaft_counts) )


        #get the indexes of all of the spines
        spine_numbers = [labels_dict["spine_" + str(k)] for k in range(1,6)] 
        print(spine_numbers)
        # np.where(tri_labels_proofread_clean_shaft 
        spine_indexes = np.array([])

        for iy in spine_numbers: 
            print("Working on spine "+ str(labels_dict_flipped[iy]))
            spine_indexes = np.hstack((spine_indexes, np.where(tri_labels_proofread_shaft==iy)[0]))
            print(f"Len of spine indexes = {len(spine_indexes)}")
        spine_indexes = spine_indexes.astype("int")
        #check to see if there were any spines: 
        total_spine_count_list = []

        if (spine_indexes.any()):
            #get the spines only submesh
            spine_submesh = random_mesh.submesh([auto_shaft_indices[spine_indexes]],append=True)
            #divide the spine submesh into disconnected portions
            spine_disconnected_groups = trimesh.graph.connected_components(edges=spine_submesh.face_adjacency,
                                          nodes=np.arange(len(spine_submesh.faces)),
                                          min_len=1,
                                          engine=None)
            #REMINDER: these indices correspond to the spine mesh vertices (which are spine indexes of auto_shaft of random mesh)
            print(len(spine_disconnected_groups))

            if len(spine_disconnected_groups)>0:
                for i,spine_group in enumerate(spine_disconnected_groups):
                    if len(spine_group) < significant_size:
                        print("Size of group too small for a spine")
                        continue
                    print("Working on shaft spine #" + str(i))
                    #iterate through and see what spine labels are present
                    original_labels_for_spine = tri_labels_proofread_shaft[spine_indexes[spine_group]]
                    print(Counter(original_labels_for_spine))

                    #see how many spine labels are in the proofread version labels for this spine
                    current_spine_count = 0
                    for iy in spine_numbers: 

                        #print("Working on spine "+ str(labels_dict_flipped[iy]))
                        if len(np.where(original_labels_for_spine==iy)[0]) > 0: 
                            print(f"Found {iy} in spine group")
                            current_spine_count += 1

                    total_spine_count_list.append(current_spine_count)

        print(total_spine_count_list)
        total_false_negative = sum(total_spine_count_list)
        print("total_false_negative = " + str(total_false_negative))
        
        """
        For spines: 
        1) From original mesh extract indices that were auto-spine (get the number of faces in submesh)
        2) Use auto-spine indices to extract the proofread labels for autoshaft
        --- set size threshold
        4) Dividee the submesh into all disjointed pieces (count the number of pieces and save off)
        5) Calculate the number of shaft and over-spine and percentage there are (WILL CALCULATE THIS AS ITERATING THROUGH)
        5) Count the number of pieces that are 70% or greater as false positives and remove those indices from the list (FALSE POSITIVES)
        6) For each piece still left in the list
        - count the number of different spine labels that exist (if only auto-spine then tally that as perfect)
        - store in array
        6) Sum up the array and tally up the number that got perfect
        """

        #extract the indices that were auto-shaft

        auto_spine_indices = np.where(auto_labels==labels_dict["auto_spine"])[0]
        #random_mesh_auto_shaft_indices = clean_indices[auto_shaft_indices]
        n_auto_spine = len(auto_spine_indices)
        print("n_auto_spine = " + str(n_auto_spine))

        #extract teh proofread spine labels
        tri_labels_proofread_spine = tri_labels_proofread[auto_spine_indices]
        total_Counter = Counter(tri_labels_proofread_spine)
        spine_counts = dict([(labels_dict_flipped[k],total_Counter[k]) for k in dict(total_Counter).keys() ])
        print("After extracting the shaft after cleaning Distribution is:" + str(spine_counts) )


        #get the indexes of all of the spines
        spine_numbers = [labels_dict["spine_" + str(k)] for k in range(1,6)]
        spine_numbers_and_spine_overspine = spine_numbers + [labels_dict["auto_spine"],labels_dict["shaft_over_spined"],
                                                             labels_dict["shaft"],
                                                             labels_dict["shaft_3"]
                                                            ]
        #print(spine_numbers_and_spine_overspine)
        # np.where(tri_labels_proofread_clean_shaft 
        spine_indexes = np.array([])

        for iy in spine_numbers_and_spine_overspine: 
            #print("Working on spine "+ str(labels_dict_flipped[iy]))
            spine_indexes = np.hstack((spine_indexes, np.where(tri_labels_proofread_spine==iy)[0]))
            print(f"Len of spine indexes = {len(spine_indexes)}")
        spine_indexes = spine_indexes.astype("int")
        #check to see if there were any spines: 
        additional_spine_count_list = []
        overspined_list = []
        overspined_list_perc = []
        spine_size_list = []
        false_positive_count = 0
        auto_distinct_spines = 0

        #
        if (spine_indexes.any()):
            #get the spines only submesh
            spine_submesh = random_mesh.submesh([auto_spine_indices[spine_indexes]],append=True)
            #divide the spine submesh into disconnected portions
            spine_disconnected_groups = trimesh.graph.connected_components(edges=spine_submesh.face_adjacency,
                                          nodes=np.arange(len(spine_submesh.faces)),
                                          min_len=1,
                                          engine=None)
            #REMINDER: these indices correspond to the spine mesh vertices (which are spine indexes of auto_shaft of random mesh)
            #print(len(spine_disconnected_groups))


            if len(spine_disconnected_groups)>0:
                auto_distinct_spines = len(spine_disconnected_groups)
                for i,spine_group in enumerate(spine_disconnected_groups):

                    if len(spine_group) < significant_size:
                        print("Size of group too small for a spine")
                        continue




                    #print("Working on shaft spine #" + str(i))
                    #iterate through and see what spine labels are present
                    original_labels_for_spine = tri_labels_proofread_spine[spine_indexes[spine_group]]
                    original_labels_counter = Counter(original_labels_for_spine)
                    #print(original_labels_counter)

                    #get the number of shaft faces
                    current_shaft_counter = 0
                    if labels_dict["shaft_3"] in original_labels_counter.keys():
                        current_shaft_counter += original_labels_counter[labels_dict["shaft_3"]]
                    if labels_dict["shaft"] in original_labels_counter.keys():
                        current_shaft_counter += original_labels_counter[labels_dict["shaft"]]

                    #count the amount it was labeled as a shaft
                    if current_shaft_counter/len(spine_group) > 0.70:
                        print("Found false positive for spine " + str(i))
                        false_positive_count += 1
                        continue

                    spine_size_list.append(len(spine_group))


                    if labels_dict["shaft_over_spined"] in original_labels_counter.keys(): 
                        overspined_list.append(original_labels_counter[labels_dict["shaft_over_spined"]])
                        overspined_list_perc.append(original_labels_counter[labels_dict["shaft_over_spined"]]/len(spine_group))
                    else:
                        overspined_list.append(0)
                        overspined_list_perc.append(0)

                    #see how many spine labels are in the proofread version labels for this spine
                    current_spine_count = 0
                    for iy in spine_numbers: 

                        #print("Working on spine "+ str(labels_dict_flipped[iy]))
                        if len(np.where(original_labels_for_spine==iy)[0]) > 0: 
                            #print(f"Found {iy} in spine group")
                            current_spine_count += 1

                    additional_spine_count_list.append(current_spine_count)

#         print("additional_spine_count_list = " + str(additional_spine_count_list))

#         print("overspined_list = " + str(overspined_list))

#         print("overspined_list_perc = " + str(overspined_list_perc))

#         print("false_positive_count = " + str(false_positive_count))

#         print("auto_distinct_spines = " + str(auto_distinct_spines))

#         print("spine_size_list = " + str(spine_size_list))
                                                               
        #the final stats that wanted
        #print("additional_spine_count_list = " + str(additional_spine_count_list))

        #stats want to keep from the shaft

        #stats we want to keep from the spine

        total_false_negative = sum(total_spine_count_list)
        print("total_false_negative = " + str(total_false_negative))

        n_merged_spines = sum(additional_spine_count_list)
        print("n_merged_spines = " + str(n_merged_spines))
        perc_spines_with_merges = len(np.where(np.array(additional_spine_count_list)>0)[0])/len(additional_spine_count_list)
        print("perc_spines_with_merges = " + str(perc_spines_with_merges))

        #print("overspined_list = " + str(overspined_list))
        overspined_faces = np.where(np.array(overspined_list)>0)[0]
        n_spines_with_overspined = len(overspined_faces)
        print("n_spines_with_overspined = " + str(n_spines_with_overspined))

        #print("overspined_list_perc = " + str(overspined_list_perc))
        #average percentage of overspined 
        average_percentage_overspined = np.mean(np.array(overspined_list_perc)[overspined_faces])
        print("average_percentage_overspined = " + str(average_percentage_overspined))

        print("false_positive_count = " + str(false_positive_count))

        print("auto_distinct_spines = " + str(auto_distinct_spines))
        avg_spine_size = np.mean(spine_size_list)
        print("avg_spine_size = " + str(avg_spine_size))

        print('n_auto_spine = ' + str(n_auto_spine))
        print('n_auto_shaft = ' + str(n_auto_shaft))

        """
        n_auto_spine      : int unsigned                 # number of faces classified as spine,spine-head or spine-neck by auto-classifier
        n_auto_shaft      : int unsigned                 # number of faces classified as shaft by auto-classifier
        n_false_negatives :  int unsigned                # number of spines incorrectly autoclassified as shaft (merged spines would add 2,3,4...etc)
        n_false_positive  : int unsigned                 # number of sections of the shaft that were incorrectly classified as spine
        true_positives    : int unsigned                 # number of spines correctly classified as spines
        n_merged_spines   : int unsigned                 # total number of additional spines that resulted from being merged with others
        perc_spines_with_merges : decimal(6,5)           # percentage of the true positive count that also had other spines merged onto it
        n_spines_with_overspined: int unsigned           # total number out of the true positives that had overspining occuring on their labeling
        average_percentage_overspined: decimal(6,5)      # for those that had overspining, the average face percentage that were labeled as overspined
        avg_spine_size    : decimal(10,5)                # average number of faces for the true positive spines
        """
        
        
        #insert into the table
        new_dict = dict(key,
                       n_auto_spine=n_auto_spine,
                       n_auto_shaft=n_auto_shaft,
                       n_false_negatives=total_false_negative,
                       n_false_positive=false_positive_count,
                       true_positives=auto_distinct_spines,
                       n_merged_spines=n_merged_spines,
                       perc_spines_with_merges=perc_spines_with_merges,
                       n_spines_with_overspined=n_spines_with_overspined,
                       average_percentage_overspined=average_percentage_overspined,
                       avg_spine_size=avg_spine_size)

        self.insert1(new_dict,skip_duplicates=True)

# %%
#(schema.jobs & "table_name='__spine_validation_statistics_orphan'").delete()

# %%
# key  = {'segmentation': 3, 'segment_id': 648518346341371119, 'decimation_ratio': 0.35, 'compartment_type': 'Oblique', 'component_index': 0}

# %%
import time
start_time = time.time()
SpineValidationStatisticsOrphan.populate(reserve_jobs=True)
print(f"Total time = {time.time() - start_time}")
# Out:
# key  = {'segmentation': 3, 'segment_id': 648518346341357855, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 58577, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 12, 52, 4)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 12689, 'spine_1': 392}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 392
# Working on spine spine_2
# Len of spine indexes = 392
# Working on spine spine_3
# Len of spine indexes = 392
# Working on spine spine_4
# Len of spine indexes = 392
# Working on spine spine_5
# Len of spine indexes = 392
# 1
# Working on shaft spine #0
# Counter({12: 392})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 16919
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15103, 'spine_1': 1114, 'spine_3': 249, 'spine_2': 383, 'shaft_over_spined': 70}
# Len of spine indexes = 1114
# Len of spine indexes = 1497
# Len of spine indexes = 1746
# Len of spine indexes = 1746
# Len of spine indexes = 1746
# Len of spine indexes = 16849
# Len of spine indexes = 16919
# Len of spine indexes = 16919
# Len of spine indexes = 16919
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 14
# perc_spines_with_merges = 0.13432835820895522
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.4
# false_positive_count = 0
# auto_distinct_spines = 73
# avg_spine_size = 250.19402985074626
# n_auto_spine = 16919
# n_auto_shaft = 13081
# key  = {'segmentation': 3, 'segment_id': 648518346341359123, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 101618, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 23, 13, 44, 41)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 10135, 'spine_1': 1604, 'label_removed': 321}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 1604
# Working on spine spine_2
# Len of spine indexes = 1604
# Working on spine spine_3
# Len of spine indexes = 1604
# Working on spine spine_4
# Len of spine indexes = 1604
# Working on spine spine_5
# Len of spine indexes = 1604
# 10
# Working on shaft spine #0
# Counter({12: 67})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 164})
# Found 12 in spine group
# Size of group too small for a spine
# Working on shaft spine #3
# Counter({12: 196})
# Found 12 in spine group
# Working on shaft spine #4
# Counter({12: 146})
# Found 12 in spine group
# Working on shaft spine #5
# Counter({12: 565})
# Found 12 in spine group
# Size of group too small for a spine
# Working on shaft spine #7
# Counter({12: 128})
# Found 12 in spine group
# Working on shaft spine #8
# Counter({12: 249})
# Found 12 in spine group
# Size of group too small for a spine
# [1, 1, 1, 1, 1, 1, 1]
# total_false_negative = 7
# n_auto_spine = 17940
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15482, 'spine_2': 550, 'spine_1': 1312, 'label_removed': 246, 'spine_3': 139, 'shaft_over_spined': 185, 'spine_4': 26}
# Len of spine indexes = 1312
# Len of spine indexes = 1862
# Len of spine indexes = 2001
# Len of spine indexes = 2027
# Len of spine indexes = 2027
# Len of spine indexes = 17509
# Len of spine indexes = 17694
# Len of spine indexes = 17694
# Len of spine indexes = 17694
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 7
# n_merged_spines = 24
# perc_spines_with_merges = 0.2073170731707317
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.14773250091724952
# false_positive_count = 0
# auto_distinct_spines = 91
# avg_spine_size = 213.0609756097561
# n_auto_spine = 17940
# n_auto_shaft = 12060
# key  = {'segmentation': 3, 'segment_id': 648518346341360739, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 57690, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 12, 12, 0, 10)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 14173, 'label_removed': 43}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 15784
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15234, 'spine_1': 497, 'label_removed': 53}
# Len of spine indexes = 497
# Len of spine indexes = 497
# Len of spine indexes = 497
# Len of spine indexes = 497
# Len of spine indexes = 497
# Len of spine indexes = 15731
# Len of spine indexes = 15731
# Len of spine indexes = 15731
# Len of spine indexes = 15731
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 6
# perc_spines_with_merges = 0.07692307692307693
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 83
# avg_spine_size = 200.94871794871796
# n_auto_spine = 15784
# n_auto_shaft = 14216
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341361018, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 65851, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 20, 13, 8, 18)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 15876}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 14124
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 13590, 'spine_2': 87, 'spine_1': 447}
# Len of spine indexes = 447
# Len of spine indexes = 534
# Len of spine indexes = 534
# Len of spine indexes = 534
# Len of spine indexes = 534
# Len of spine indexes = 14124
# Len of spine indexes = 14124
# Len of spine indexes = 14124
# Len of spine indexes = 14124
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 5
# perc_spines_with_merges = 0.06060606060606061
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 68
# avg_spine_size = 212.83333333333334
# n_auto_spine = 14124
# n_auto_shaft = 15876
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341366161, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 3257, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 14, 11, 9, 9)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 18060, 'shaft': 1}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 11939
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 10937, 'shaft': 133, 'spine_1': 509, 'spine_2': 145, 'spine_3': 215}
# Len of spine indexes = 509
# Len of spine indexes = 654
# Len of spine indexes = 869
# Len of spine indexes = 869
# Len of spine indexes = 869
# Len of spine indexes = 11806
# Len of spine indexes = 11806
# Len of spine indexes = 11939
# Len of spine indexes = 11939
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 50
# Found false positive for spine 51
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 7
# perc_spines_with_merges = 0.08695652173913043
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 2
# auto_distinct_spines = 54
# avg_spine_size = 253.8695652173913
# n_auto_spine = 11939
# n_auto_shaft = 18061
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341366450, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 25323, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 23, 15, 18, 50)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 12873, 'spine_1': 99}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 99
# Working on spine spine_2
# Len of spine indexes = 99
# Working on spine spine_3
# Len of spine indexes = 99
# Working on spine spine_4
# Len of spine indexes = 99
# Working on spine spine_5
# Len of spine indexes = 99
# 1
# Working on shaft spine #0
# Counter({12: 99})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 17028
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15457, 'spine_1': 1219, 'spine_2': 72, 'shaft': 107, 'spine_4': 78, 'spine_3': 95}
# Len of spine indexes = 1219
# Len of spine indexes = 1291
# Len of spine indexes = 1386
# Len of spine indexes = 1464
# Len of spine indexes = 1464
# Len of spine indexes = 16921
# Len of spine indexes = 16921
# Len of spine indexes = 17028
# Len of spine indexes = 17028
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 66
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 12
# perc_spines_with_merges = 0.140625
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 1
# auto_distinct_spines = 68
# avg_spine_size = 263.03125
# n_auto_spine = 17028
# n_auto_shaft = 12972
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341372326, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 4401, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 23, 17, 53, 12)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13178}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 16822
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15371, 'spine_2': 540, 'spine_1': 779, 'spine_3': 86, 'shaft': 46}
# Len of spine indexes = 779
# Len of spine indexes = 1319
# Len of spine indexes = 1405
# Len of spine indexes = 1405
# Len of spine indexes = 1405
# Len of spine indexes = 16776
# Len of spine indexes = 16776
# Len of spine indexes = 16822
# Len of spine indexes = 16822
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 11
# perc_spines_with_merges = 0.1076923076923077
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 67
# avg_spine_size = 257.9076923076923
# n_auto_spine = 16822
# n_auto_shaft = 13178
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341377469, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 29716, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 10, 52, 56)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 11823}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 16505
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 13909, 'spine_1': 2196, 'spine_3': 143, 'spine_2': 257}
# Len of spine indexes = 2196
# Len of spine indexes = 2453
# Len of spine indexes = 2596
# Len of spine indexes = 2596
# Len of spine indexes = 2596
# Len of spine indexes = 16505
# Len of spine indexes = 16505
# Len of spine indexes = 16505
# Len of spine indexes = 16505
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 22
# perc_spines_with_merges = 0.3157894736842105
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 65
# avg_spine_size = 287.12280701754383
# n_auto_spine = 16505
# n_auto_shaft = 11823
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341381313, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 2394, 'n_triangles': 11315, 'date_time': datetime.datetime(2019, 8, 14, 11, 57, 49)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 4004, 'shaft': 9}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 7302
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 6509, 'spine_2': 100, 'spine_1': 633, 'shaft': 52, 'shaft_over_spined': 8}
# Len of spine indexes = 633
# Len of spine indexes = 733
# Len of spine indexes = 733
# Len of spine indexes = 733
# Len of spine indexes = 733
# Len of spine indexes = 7242
# Len of spine indexes = 7250
# Len of spine indexes = 7302
# Len of spine indexes = 7302
# Found false positive for spine 10
# total_false_negative = 0
# n_merged_spines = 11
# perc_spines_with_merges = 0.2571428571428571
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.07692307692307693
# false_positive_count = 1
# auto_distinct_spines = 36
# avg_spine_size = 207.11428571428573
# n_auto_spine = 7302
# n_auto_shaft = 4013
# key  = {'segmentation': 3, 'segment_id': 648518346341382699, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 119431, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 23, 16, 10, 53)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13182, 'spine_1': 324}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 324
# Working on spine spine_2
# Len of spine indexes = 324
# Working on spine spine_3
# Len of spine indexes = 324
# Working on spine spine_4
# Len of spine indexes = 324
# Working on spine spine_5
# Len of spine indexes = 324
# 1
# Working on shaft spine #0
# Counter({12: 324})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 16494
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15747, 'spine_1': 747}
# Len of spine indexes = 747
# Len of spine indexes = 747
# Len of spine indexes = 747
# Len of spine indexes = 747
# Len of spine indexes = 747
# Len of spine indexes = 16494
# Len of spine indexes = 16494
# Len of spine indexes = 16494
# Len of spine indexes = 16494
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 8
# perc_spines_with_merges = 0.0963855421686747
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 86
# avg_spine_size = 197.86746987951807
# n_auto_spine = 16494
# n_auto_shaft = 13506
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341382814, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 11470, 'n_triangles': 15105, 'date_time': datetime.datetime(2019, 8, 12, 12, 1, 23)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 6499, 'spine_1': 135}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 135
# Working on spine spine_2
# Len of spine indexes = 135
# Working on spine spine_3
# Len of spine indexes = 135
# Working on spine spine_4
# Len of spine indexes = 135
# Working on spine spine_5
# Len of spine indexes = 135
# 3
# Working on shaft spine #0
# Counter({12: 94})
# Found 12 in spine group
# Size of group too small for a spine
# Size of group too small for a spine
# [1]
# total_false_negative = 1
# n_auto_spine = 8471
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 7706, 'spine_1': 448, 'spine_2': 63, 'shaft': 146, 'spine_3': 80, 'spine_4': 28}
# Len of spine indexes = 448
# Len of spine indexes = 511
# Len of spine indexes = 591
# Len of spine indexes = 619
# Len of spine indexes = 619
# Len of spine indexes = 8325
# Len of spine indexes = 8325
# Len of spine indexes = 8471
# Len of spine indexes = 8471
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 43
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 11
# perc_spines_with_merges = 0.17073170731707318
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 1
# auto_distinct_spines = 45
# avg_spine_size = 200.6829268292683
# n_auto_spine = 8471
# n_auto_shaft = 6634
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341385454, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 116434, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 20, 13, 24)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 9652, 'spine_1': 517, 'shaft_over_spined': 2}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 517
# Working on spine spine_2
# Len of spine indexes = 517
# Working on spine spine_3
# Len of spine indexes = 517
# Working on spine spine_4
# Len of spine indexes = 517
# Working on spine spine_5
# Len of spine indexes = 517
# 2
# Working on shaft spine #0
# Counter({12: 353})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 164})
# Found 12 in spine group
# [1, 1]
# total_false_negative = 2
# n_auto_spine = 19829
# After extracting the shaft after cleaning Distribution is:{'spine_2': 616, 'auto_spine': 15867, 'spine_1': 2689, 'shaft_over_spined': 154, 'spine_3': 176, 'spine_4': 139, 'spine_5': 188}
# Len of spine indexes = 2689
# Len of spine indexes = 3305
# Len of spine indexes = 3481
# Len of spine indexes = 3620
# Len of spine indexes = 3808
# Len of spine indexes = 19675
# Len of spine indexes = 19829
# Len of spine indexes = 19829
# Len of spine indexes = 19829
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 2
# n_merged_spines = 32
# perc_spines_with_merges = 0.31645569620253167
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.1425925925925926
# false_positive_count = 0
# auto_distinct_spines = 82
# avg_spine_size = 250.59493670886076
# n_auto_spine = 19829
# n_auto_shaft = 10171
# key  = {'segmentation': 3, 'segment_id': 648518346341392729, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 44894, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 12, 12, 20, 28)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 9866, 'spine_1': 39, 'shaft_over_spined': 1}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 39
# Working on spine spine_2
# Len of spine indexes = 39
# Working on spine spine_3
# Len of spine indexes = 39
# Working on spine spine_4
# Len of spine indexes = 39
# Working on spine spine_5
# Len of spine indexes = 39
# 1
# Size of group too small for a spine
# []
# total_false_negative = 0
# n_auto_spine = 20094
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 17107, 'spine_3': 182, 'spine_2': 705, 'spine_1': 1876, 'shaft': 18, 'spine_4': 89, 'shaft_over_spined': 117}
# Len of spine indexes = 1876
# Len of spine indexes = 2581
# Len of spine indexes = 2763
# Len of spine indexes = 2852
# Len of spine indexes = 2852
# Len of spine indexes = 19959
# Len of spine indexes = 20076
# Len of spine indexes = 20094
# Len of spine indexes = 20094
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 28
# perc_spines_with_merges = 0.2111111111111111
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.06073025129317383
# false_positive_count = 0
# auto_distinct_spines = 94
# avg_spine_size = 222.0888888888889
# n_auto_spine = 20094
# n_auto_shaft = 9906
# key  = {'segmentation': 3, 'segment_id': 648518346341394638, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 56087, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 14, 11, 23, 4)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 12710, 'shaft': 1}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 17289
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 16154, 'spine_1': 1071, 'shaft': 64}
# Len of spine indexes = 1071
# Len of spine indexes = 1071
# Len of spine indexes = 1071
# Len of spine indexes = 1071
# Len of spine indexes = 1071
# Len of spine indexes = 17225
# Len of spine indexes = 17225
# Len of spine indexes = 17289
# Len of spine indexes = 17289
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 10
# perc_spines_with_merges = 0.15151515151515152
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 72
# avg_spine_size = 260.1666666666667
# n_auto_spine = 17289
# n_auto_shaft = 12711
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341398948, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 14892, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 15, 13, 6)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 9091, 'spine_1': 1425, 'shaft': 6}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 1425
# Working on spine spine_2
# Len of spine indexes = 1425
# Working on spine spine_3
# Len of spine indexes = 1425
# Working on spine spine_4
# Len of spine indexes = 1425
# Working on spine spine_5
# Len of spine indexes = 1425
# 5
# Working on shaft spine #0
# Counter({12: 360})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 226})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 357})
# Found 12 in spine group
# Working on shaft spine #3
# Counter({12: 266})
# Found 12 in spine group
# Working on shaft spine #4
# Counter({12: 216})
# Found 12 in spine group
# [1, 1, 1, 1, 1]
# total_false_negative = 5
# n_auto_spine = 19478
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15870, 'spine_2': 915, 'spine_3': 236, 'spine_1': 1766, 'shaft_over_spined': 340, 'spine_4': 212, 'spine_5': 79, 'shaft': 60}
# Len of spine indexes = 1766
# Len of spine indexes = 2681
# Len of spine indexes = 2917
# Len of spine indexes = 3129
# Len of spine indexes = 3208
# Len of spine indexes = 19078
# Len of spine indexes = 19418
# Len of spine indexes = 19478
# Len of spine indexes = 19478
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 5
# n_merged_spines = 32
# perc_spines_with_merges = 0.22727272727272727
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.23019634394041977
# false_positive_count = 0
# auto_distinct_spines = 93
# avg_spine_size = 220.2840909090909
# n_auto_spine = 19478
# n_auto_shaft = 10522
# key  = {'segmentation': 3, 'segment_id': 648518346341400173, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 80431, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 14, 11, 48, 14)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13188, 'spine_1': 96}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 96
# Working on spine spine_2
# Len of spine indexes = 96
# Working on spine spine_3
# Len of spine indexes = 96
# Working on spine spine_4
# Len of spine indexes = 96
# Working on spine spine_5
# Len of spine indexes = 96
# 1
# Working on shaft spine #0
# Counter({12: 96})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 16716
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15700, 'spine_1': 932, 'spine_2': 84}
# Len of spine indexes = 932
# Len of spine indexes = 1016
# Len of spine indexes = 1016
# Len of spine indexes = 1016
# Len of spine indexes = 1016
# Len of spine indexes = 16716
# Len of spine indexes = 16716
# Len of spine indexes = 16716
# Len of spine indexes = 16716
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 12
# perc_spines_with_merges = 0.13924050632911392
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 89
# avg_spine_size = 209.0379746835443
# n_auto_spine = 16716
# n_auto_shaft = 13284
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341401158, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 5609, 'n_triangles': 17054, 'date_time': datetime.datetime(2019, 8, 12, 12, 21, 39)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 6474, 'label_removed': 20}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 10560
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 9552, 'spine_1': 579, 'spine_2': 35, 'label_removed': 346, 'shaft': 48}
# Len of spine indexes = 579
# Len of spine indexes = 614
# Len of spine indexes = 614
# Len of spine indexes = 614
# Len of spine indexes = 614
# Len of spine indexes = 10166
# Len of spine indexes = 10166
# Len of spine indexes = 10214
# Len of spine indexes = 10214
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 10
# perc_spines_with_merges = 0.14754098360655737
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 62
# avg_spine_size = 166.65573770491804
# n_auto_spine = 10560
# n_auto_shaft = 6494
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341403533, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 7490, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 12, 12, 26, 18)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 11471, 'spine_1': 1103, 'shaft_over_spined': 1}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 1103
# Working on spine spine_2
# Len of spine indexes = 1103
# Working on spine spine_3
# Len of spine indexes = 1103
# Working on spine spine_4
# Len of spine indexes = 1103
# Working on spine spine_5
# Len of spine indexes = 1103
# 6
# Size of group too small for a spine
# Working on shaft spine #1
# Counter({12: 280})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 120})
# Found 12 in spine group
# Working on shaft spine #3
# Counter({12: 327})
# Found 12 in spine group
# Working on shaft spine #4
# Counter({12: 304})
# Found 12 in spine group
# Size of group too small for a spine
# [1, 1, 1, 1]
# total_false_negative = 4
# n_auto_spine = 17425
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15578, 'spine_1': 1273, 'shaft_over_spined': 180, 'spine_2': 394}
# Len of spine indexes = 1273
# Len of spine indexes = 1667
# Len of spine indexes = 1667
# Len of spine indexes = 1667
# Len of spine indexes = 1667
# Len of spine indexes = 17245
# Len of spine indexes = 17425
# Len of spine indexes = 17425
# Len of spine indexes = 17425
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 4
# n_merged_spines = 21
# perc_spines_with_merges = 0.2073170731707317
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.1305501569150797
# false_positive_count = 0
# auto_distinct_spines = 87
# avg_spine_size = 210.1951219512195
# n_auto_spine = 17425
# n_auto_shaft = 12575
# key  = {'segmentation': 3, 'segment_id': 648518346341407152, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 4103, 'n_triangles': 17429, 'date_time': datetime.datetime(2019, 8, 27, 13, 14, 28)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 6198, 'spine_1': 525, 'shaft_over_spined': 6}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 525
# Working on spine spine_2
# Len of spine indexes = 525
# Working on spine spine_3
# Len of spine indexes = 525
# Working on spine spine_4
# Len of spine indexes = 525
# Working on spine spine_5
# Len of spine indexes = 525
# 3
# Working on shaft spine #0
# Counter({12: 197})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 168})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 160})
# Found 12 in spine group
# [1, 1, 1]
# total_false_negative = 3
# n_auto_spine = 10700
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 9145, 'spine_1': 1014, 'spine_2': 93, 'shaft_over_spined': 352, 'spine_3': 96}
# Len of spine indexes = 1014
# Len of spine indexes = 1107
# Len of spine indexes = 1203
# Len of spine indexes = 1203
# Len of spine indexes = 1203
# Len of spine indexes = 10348
# Len of spine indexes = 10700
# Len of spine indexes = 10700
# Len of spine indexes = 10700
# Size of group too small for a spine
# total_false_negative = 3
# n_merged_spines = 13
# perc_spines_with_merges = 0.16129032258064516
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.35585443269013145
# false_positive_count = 0
# auto_distinct_spines = 63
# avg_spine_size = 171.90322580645162
# n_auto_spine = 10700
# n_auto_shaft = 6729
# key  = {'segmentation': 3, 'segment_id': 648518346341407642, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 49167, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 12, 46, 38)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13169, 'label_removed': 47, 'spine_1': 505}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 505
# Working on spine spine_2
# Len of spine indexes = 505
# Working on spine spine_3
# Len of spine indexes = 505
# Working on spine spine_4
# Len of spine indexes = 505
# Working on spine spine_5
# Len of spine indexes = 505
# 1
# Working on shaft spine #0
# Counter({12: 505})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 16279
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 14615, 'spine_1': 1046, 'label_removed': 63, 'spine_2': 431, 'shaft_over_spined': 44, 'spine_3': 80}
# Len of spine indexes = 1046
# Len of spine indexes = 1477
# Len of spine indexes = 1557
# Len of spine indexes = 1557
# Len of spine indexes = 1557
# Len of spine indexes = 16172
# Len of spine indexes = 16216
# Len of spine indexes = 16216
# Len of spine indexes = 16216
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 15
# perc_spines_with_merges = 0.16666666666666666
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.11764705882352941
# false_positive_count = 0
# auto_distinct_spines = 74
# avg_spine_size = 242.13636363636363
# n_auto_spine = 16279
# n_auto_shaft = 13721
# key  = {'segmentation': 3, 'segment_id': 648518346341408346, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 35378, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 14, 10, 58, 10)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 14789, 'shaft': 2}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 15209
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 14332, 'spine_1': 644, 'shaft': 162, 'shaft_over_spined': 8, 'spine_2': 63}
# Len of spine indexes = 644
# Len of spine indexes = 707
# Len of spine indexes = 707
# Len of spine indexes = 707
# Len of spine indexes = 707
# Len of spine indexes = 15039
# Len of spine indexes = 15047
# Len of spine indexes = 15209
# Len of spine indexes = 15209
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 79
# total_false_negative = 0
# n_merged_spines = 8
# perc_spines_with_merges = 0.09090909090909091
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.08163265306122448
# false_positive_count = 1
# auto_distinct_spines = 80
# avg_spine_size = 195.0
# n_auto_spine = 15209
# n_auto_shaft = 14791
# key  = {'segmentation': 3, 'segment_id': 648518346341408477, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 19879, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 22, 16, 52, 14)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 16151, 'spine_1': 282}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 282
# Working on spine spine_2
# Len of spine indexes = 282
# Working on spine spine_3
# Len of spine indexes = 282
# Working on spine spine_4
# Len of spine indexes = 282
# Working on spine spine_5
# Len of spine indexes = 282
# 1
# Working on shaft spine #0
# Counter({12: 282})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 13567
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 12843, 'spine_2': 172, 'spine_3': 85, 'spine_1': 333, 'shaft': 134}
# Len of spine indexes = 333
# Len of spine indexes = 505
# Len of spine indexes = 590
# Len of spine indexes = 590
# Len of spine indexes = 590
# Len of spine indexes = 13433
# Len of spine indexes = 13433
# Len of spine indexes = 13567
# Len of spine indexes = 13567
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 78
# total_false_negative = 1
# n_merged_spines = 6
# perc_spines_with_merges = 0.05333333333333334
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 1
# auto_distinct_spines = 79
# avg_spine_size = 178.2
# n_auto_spine = 13567
# n_auto_shaft = 16433
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346341409422, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 19342, 'n_triangles': 29285, 'date_time': datetime.datetime(2019, 8, 27, 13, 30, 38)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'spine_1': 712, 'auto_shaft': 9890}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 712
# Working on spine spine_2
# Len of spine indexes = 712
# Working on spine spine_3
# Len of spine indexes = 712
# Working on spine spine_4
# Len of spine indexes = 712
# Working on spine spine_5
# Len of spine indexes = 712
# 3
# Working on shaft spine #0
# Counter({12: 240})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 256})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 216})
# Found 12 in spine group
# [1, 1, 1]
# total_false_negative = 3
# n_auto_spine = 18683
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15920, 'spine_1': 1599, 'spine_4': 72, 'shaft': 97, 'spine_2': 382, 'shaft_over_spined': 447, 'spine_3': 109, 'spine_5': 57}
# Len of spine indexes = 1599
# Len of spine indexes = 1981
# Len of spine indexes = 2090
# Len of spine indexes = 2162
# Len of spine indexes = 2219
# Len of spine indexes = 18139
# Len of spine indexes = 18586
# Len of spine indexes = 18683
# Len of spine indexes = 18683
# Size of group too small for a spine
# Found false positive for spine 96
# Size of group too small for a spine
# total_false_negative = 3
# n_merged_spines = 26
# perc_spines_with_merges = 0.2
# n_spines_with_overspined = 6
# average_percentage_overspined = 0.207486826431766
# false_positive_count = 1
# auto_distinct_spines = 98
# avg_spine_size = 195.17894736842106
# n_auto_spine = 18683
# n_auto_shaft = 10602
# key  = {'segmentation': 3, 'segment_id': 648518346341410558, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 80076, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 10, 3, 7)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 11222, 'spine_1': 795}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 795
# Working on spine spine_2
# Len of spine indexes = 795
# Working on spine spine_3
# Len of spine indexes = 795
# Working on spine spine_4
# Len of spine indexes = 795
# Working on spine spine_5
# Len of spine indexes = 795
# 3
# Working on shaft spine #0
# Counter({12: 235})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 220})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 340})
# Found 12 in spine group
# [1, 1, 1]
# total_false_negative = 3
# n_auto_spine = 17983
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 15932, 'spine_3': 283, 'spine_1': 1387, 'spine_2': 142, 'spine_4': 99, 'shaft_over_spined': 25, 'shaft': 115}
# Len of spine indexes = 1387
# Len of spine indexes = 1529
# Len of spine indexes = 1812
# Len of spine indexes = 1911
# Len of spine indexes = 1911
# Len of spine indexes = 17843
# Len of spine indexes = 17868
# Len of spine indexes = 17983
# Len of spine indexes = 17983
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 89
# total_false_negative = 3
# n_merged_spines = 21
# perc_spines_with_merges = 0.18823529411764706
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.11574074074074074
# false_positive_count = 1
# auto_distinct_spines = 90
# avg_spine_size = 209.25882352941176
# n_auto_spine = 17983
# n_auto_shaft = 12017
# key  = {'segmentation': 3, 'segment_id': 648518346341410817, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 15639, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 12, 1, 43)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 9779, 'spine_1': 1177}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 1177
# Working on spine spine_2
# Len of spine indexes = 1177
# Working on spine spine_3
# Len of spine indexes = 1177
# Working on spine spine_4
# Len of spine indexes = 1177
# Working on spine spine_5
# Len of spine indexes = 1177
# 4
# Working on shaft spine #0
# Counter({12: 226})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 232})
# Found 12 in spine group
# Working on shaft spine #2
# Counter({12: 309})
# Found 12 in spine group
# Working on shaft spine #3
# Counter({12: 410})
# Found 12 in spine group
# [1, 1, 1, 1]
# total_false_negative = 4
# n_auto_spine = 19044
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 16417, 'spine_2': 430, 'spine_1': 1945, 'shaft': 44, 'spine_3': 208}
# Len of spine indexes = 1945
# ...
# Len of spine indexes = 1758
# Len of spine indexes = 1864
# Len of spine indexes = 1987
# Len of spine indexes = 1987
# Len of spine indexes = 16754
# Len of spine indexes = 17644
# Len of spine indexes = 17644
# Len of spine indexes = 17644
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 1
# n_merged_spines = 18
# perc_spines_with_merges = 0.14285714285714285
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.2843577990636814
# false_positive_count = 0
# auto_distinct_spines = 94
# avg_spine_size = 192.85714285714286
# n_auto_spine = 17644
# n_auto_shaft = 12356
# key  = {'segmentation': 3, 'segment_id': 648518346349376861, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 30888, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 12, 27, 49)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'spine_1': 514, 'auto_shaft': 9763}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 514
# Working on spine spine_2
# Len of spine indexes = 514
# Working on spine spine_3
# Len of spine indexes = 514
# Working on spine spine_4
# Len of spine indexes = 514
# Working on spine spine_5
# Len of spine indexes = 514
# 1
# Working on shaft spine #0
# Counter({12: 514})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 19723
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 16230, 'spine_1': 2266, 'spine_2': 734, 'spine_3': 406, 'shaft_over_spined': 32, 'shaft': 55}
# Len of spine indexes = 2266
# Len of spine indexes = 3000
# Len of spine indexes = 3406
# Len of spine indexes = 3406
# Len of spine indexes = 3406
# Len of spine indexes = 19636
# Len of spine indexes = 19668
# Len of spine indexes = 19723
# Len of spine indexes = 19723
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 98
# total_false_negative = 1
# n_merged_spines = 31
# perc_spines_with_merges = 0.25274725274725274
# n_spines_with_overspined = 1
# average_percentage_overspined = 0.1693121693121693
# false_positive_count = 1
# auto_distinct_spines = 99
# avg_spine_size = 214.1868131868132
# n_auto_spine = 19723
# n_auto_shaft = 10277
# key  = {'segmentation': 3, 'segment_id': 648518346349381502, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 539, 'n_triangles': 11265, 'date_time': datetime.datetime(2019, 8, 27, 13, 2, 40)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 3457, 'spine_1': 130}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 130
# Working on spine spine_2
# Len of spine indexes = 130
# Working on spine spine_3
# Len of spine indexes = 130
# Working on spine spine_4
# Len of spine indexes = 130
# Working on spine spine_5
# Len of spine indexes = 130
# 1
# Working on shaft spine #0
# Counter({12: 130})
# Found 12 in spine group
# [1]
# total_false_negative = 1
# n_auto_spine = 5392
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 4358, 'shaft_over_spined': 129, 'spine_1': 731, 'shaft': 89, 'spine_2': 85}
# Len of spine indexes = 731
# Len of spine indexes = 816
# Len of spine indexes = 816
# Len of spine indexes = 816
# Len of spine indexes = 816
# Len of spine indexes = 5174
# Len of spine indexes = 5303
# Len of spine indexes = 5392
# Len of spine indexes = 5392
# Found false positive for spine 28
# total_false_negative = 1
# n_merged_spines = 9
# perc_spines_with_merges = 0.2857142857142857
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.15287445965053717
# false_positive_count = 1
# auto_distinct_spines = 29
# avg_spine_size = 189.39285714285714
# n_auto_spine = 5392
# n_auto_shaft = 3587
# key  = {'segmentation': 3, 'segment_id': 648518346349462805, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 101508, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 27, 12, 38, 46)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13814, 'shaft': 3}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 16183
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 14780, 'spine_1': 988, 'spine_2': 410, 'shaft': 5}
# Len of spine indexes = 988
# Len of spine indexes = 1398
# Len of spine indexes = 1398
# Len of spine indexes = 1398
# Len of spine indexes = 1398
# Len of spine indexes = 16178
# Len of spine indexes = 16178
# Len of spine indexes = 16183
# Len of spine indexes = 16183
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 13
# perc_spines_with_merges = 0.14492753623188406
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 76
# avg_spine_size = 233.02898550724638
# n_auto_spine = 16183
# n_auto_shaft = 13817
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346349471277, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 1911, 'n_triangles': 17581, 'date_time': datetime.datetime(2019, 8, 23, 14, 46, 54)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 8441, 'label_removed': 86, 'spine_1': 553}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 553
# Working on spine spine_2
# Len of spine indexes = 553
# Working on spine spine_3
# Len of spine indexes = 553
# Working on spine spine_4
# Len of spine indexes = 553
# Working on spine spine_5
# Len of spine indexes = 553
# 2
# Working on shaft spine #0
# Counter({12: 158})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 395})
# Found 12 in spine group
# [1, 1]
# total_false_negative = 2
# n_auto_spine = 8501
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 7509, 'label_removed': 384, 'spine_1': 221, 'spine_3': 127, 'spine_2': 187, 'spine_4': 73}
# Len of spine indexes = 221
# Len of spine indexes = 408
# Len of spine indexes = 535
# Len of spine indexes = 608
# Len of spine indexes = 608
# Len of spine indexes = 8117
# Len of spine indexes = 8117
# Len of spine indexes = 8117
# Len of spine indexes = 8117
# Size of group too small for a spine
# total_false_negative = 2
# n_merged_spines = 10
# perc_spines_with_merges = 0.11428571428571428
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 36
# avg_spine_size = 230.71428571428572
# n_auto_spine = 8501
# n_auto_shaft = 9080
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346349496702, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 7792, 'n_triangles': 16252, 'date_time': datetime.datetime(2019, 8, 23, 14, 29, 38)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 5420, 'spine_1': 372}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 372
# Working on spine spine_2
# Len of spine indexes = 372
# Working on spine spine_3
# Len of spine indexes = 372
# Working on spine spine_4
# Len of spine indexes = 372
# Working on spine spine_5
# Len of spine indexes = 372
# 2
# Working on shaft spine #0
# Counter({12: 209})
# Found 12 in spine group
# Working on shaft spine #1
# Counter({12: 163})
# Found 12 in spine group
# [1, 1]
# total_false_negative = 2
# n_auto_spine = 8675
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 7721, 'shaft_over_spined': 369, 'spine_2': 229, 'spine_1': 309, 'shaft': 47}
# Len of spine indexes = 309
# Len of spine indexes = 538
# Len of spine indexes = 538
# Len of spine indexes = 538
# Len of spine indexes = 538
# Len of spine indexes = 8259
# Len of spine indexes = 8628
# Len of spine indexes = 8675
# Len of spine indexes = 8675
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 2
# n_merged_spines = 8
# perc_spines_with_merges = 0.13043478260869565
# n_spines_with_overspined = 2
# average_percentage_overspined = 0.23333202339916687
# false_positive_count = 0
# auto_distinct_spines = 50
# avg_spine_size = 184.7608695652174
# n_auto_spine = 8675
# n_auto_shaft = 5792
# key  = {'segmentation': 3, 'segment_id': 648518346349506970, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 10478, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 9, 13, 47, 6)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 11928, 'spine_1': 922}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 922
# Working on spine spine_2
# Len of spine indexes = 922
# Working on spine spine_3
# Len of spine indexes = 922
# Working on spine spine_4
# Len of spine indexes = 922
# Working on spine spine_5
# Len of spine indexes = 922
# 6
# Working on shaft spine #0
# Counter({12: 295})
# Found 12 in spine group
# Size of group too small for a spine
# Working on shaft spine #2
# Counter({12: 142})
# Found 12 in spine group
# Size of group too small for a spine
# Working on shaft spine #4
# Counter({12: 271})
# Found 12 in spine group
# Working on shaft spine #5
# Counter({12: 174})
# Found 12 in spine group
# [1, 1, 1, 1]
# total_false_negative = 4
# n_auto_spine = 17150
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 16319, 'shaft_over_spined': 131, 'shaft': 43, 'spine_1': 590, 'spine_2': 67}
# Len of spine indexes = 590
# Len of spine indexes = 657
# Len of spine indexes = 657
# Len of spine indexes = 657
# Len of spine indexes = 657
# Len of spine indexes = 16976
# Len of spine indexes = 17107
# Len of spine indexes = 17150
# Len of spine indexes = 17150
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 4
# n_merged_spines = 12
# perc_spines_with_merges = 0.125
# n_spines_with_overspined = 3
# average_percentage_overspined = 0.15416162431087804
# false_positive_count = 0
# auto_distinct_spines = 94
# avg_spine_size = 192.67045454545453
# n_auto_spine = 17150
# n_auto_shaft = 12850
# key  = {'segmentation': 3, 'segment_id': 648518346349508581, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 3, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 4759, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 12, 14, 34, 29)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 18730, 'shaft': 48}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 11222
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 10444, 'shaft': 261, 'spine_1': 517}
# Len of spine indexes = 517
# Len of spine indexes = 517
# Len of spine indexes = 517
# Len of spine indexes = 517
# Len of spine indexes = 517
# Len of spine indexes = 10961
# Len of spine indexes = 10961
# Len of spine indexes = 11222
# Len of spine indexes = 11222
# Size of group too small for a spine
# Size of group too small for a spine
# Size of group too small for a spine
# Found false positive for spine 52
# Found false positive for spine 53
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 6
# perc_spines_with_merges = 0.12244897959183673
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 2
# auto_distinct_spines = 56
# avg_spine_size = 223.53061224489795
# n_auto_spine = 11222
# n_auto_shaft = 18778
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# key  = {'segmentation': 3, 'segment_id': 648518346349509521, 'decimation_ratio': Decimal('0.35'), 'compartment_type': 'Dendrite', 'component_index': 0, 'author_original': 'computer_Auto', 'author_proofreader': 'js48', 'starting_index': 46277, 'n_triangles': 30000, 'date_time': datetime.datetime(2019, 8, 22, 16, 43, 21)}
# all_one_spine_n_bodies = 0
# all_one_spine_n_faces = 0
# Done finding all in one spines
# After extracting the shaft after cleaning Distribution is:{'auto_shaft': 13538, 'error': 721}
# [12, 3, 4, 6, 9]
# Working on spine spine_1
# Len of spine indexes = 0
# Working on spine spine_2
# Len of spine indexes = 0
# Working on spine spine_3
# Len of spine indexes = 0
# Working on spine spine_4
# Len of spine indexes = 0
# Working on spine spine_5
# Len of spine indexes = 0
# []
# total_false_negative = 0
# n_auto_spine = 15741
# After extracting the shaft after cleaning Distribution is:{'auto_spine': 14356, 'error': 198, 'spine_1': 1021, 'spine_2': 166}
# Len of spine indexes = 1021
# Len of spine indexes = 1187
# Len of spine indexes = 1187
# Len of spine indexes = 1187
# Len of spine indexes = 1187
# Len of spine indexes = 15543
# Len of spine indexes = 15543
# Len of spine indexes = 15543
# Len of spine indexes = 15543
# Size of group too small for a spine
# Size of group too small for a spine
# total_false_negative = 0
# n_merged_spines = 13
# perc_spines_with_merges = 0.1527777777777778
# n_spines_with_overspined = 0
# average_percentage_overspined = nan
# false_positive_count = 0
# auto_distinct_spines = 74
# avg_spine_size = 215.58333333333334
# n_auto_spine = 15741
# n_auto_shaft = 14259
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Total time = 134.58749556541443

# %%
fc = dj.create_virtual_module("pinky_fc","microns_pinky_fc")

# %%
fc.ContactCorrelation.describe()
