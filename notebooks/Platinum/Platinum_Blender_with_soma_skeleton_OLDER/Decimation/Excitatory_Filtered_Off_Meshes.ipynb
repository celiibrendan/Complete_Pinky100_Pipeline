# %%
from boolean import neuron_boolean_difference
import datajoint as dj
import numpy as np
import trimesh
import time

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')

# %%
"""
Could have put these in the table but decided not to:
significan_threshold : int              # number of faces needed for seperated submesh to be considered significant and then recovered
distance_threshold   : int              # distance away for vertices to be considered part of filtered mesh (used in KDTree)
    

"""
# Out:
# '\nCould have put these in the table but decided not to:\nsignifican_threshold : int              # number of faces needed for seperated submesh to be considered significant and then recovered\ndistance_threshold   : int              # distance away for vertices to be considered part of filtered mesh (used in KDTree)\n    \n\n'

# %%
pinky.ProofreadLabel & "segment_id=648518346349479478"
# Out:
# *segmentation  *segment_id    *decimation_ra *author_origin *author_proofr *date_time     vertices   triangles  edges      status
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +----------+
# 3              64851834634947 0.35           computer_Auto  celiib         2019-06-13 16: =BLOB=     =BLOB=     =BLOB=     complete
#  (1 tuples)

# %%
pinky.LeftoverProofreadLabel()
# Out:
# *segmentation  *segment_id    *decimation_ra *author_origin *author_proofr *date_time     vertices   triangles  edges      status
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +----------+
# 3              64851834634137 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634938 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-11 20: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 13: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
# 3              64851834634947 0.35           computer_Auto  celiib         2019-07-12 12: =BLOB=     =BLOB=     =BLOB=     complete
#    ...
#  (105 tuples)

# %%
ExcitatoryLeftoverMeshes()
# Out:
# *segmentation  *segment_id    *decimation_ra n_vertices     n_triangles    vertices   triangles  recovered_perc
# +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +------------+
# 3              64851834634137 0.35           287            489            =BLOB=     =BLOB=     0.00109
# 3              64851834634938 0.35           66             100            =BLOB=     =BLOB=     0.00178
# 3              64851834634947 0.35           31607          62878          =BLOB=     =BLOB=     0.08902
# 3              64851834634947 0.35           2220           4339           =BLOB=     =BLOB=     0.00842
# 3              64851834634947 0.35           128            235            =BLOB=     =BLOB=     0.00051
# 3              64851834634947 0.35           3969           7687           =BLOB=     =BLOB=     0.00857
# 3              64851834634947 0.35           335            543            =BLOB=     =BLOB=     0.00036
# 3              64851834634947 0.35           1034           1988           =BLOB=     =BLOB=     0.00151
# 3              64851834634947 0.35           649            1208           =BLOB=     =BLOB=     0.00115
# 3              64851834634947 0.35           106            199            =BLOB=     =BLOB=     0.00019
# 3              64851834634947 0.35           5685           11107          =BLOB=     =BLOB=     0.01107
# 3              64851834634947 0.35           5763           11392          =BLOB=     =BLOB=     0.00886
# 3              64851834634947 0.35           12537          24875          =BLOB=     =BLOB=     0.08107
# 3              64851834634947 0.35           12442          24598          =BLOB=     =BLOB=     0.02586
# 3              64851834634947 0.35           620            1043           =BLOB=     =BLOB=     0.00085
# 3              64851834634947 0.35           336            529            =BLOB=     =BLOB=     0.00093
# 3              64851834634947 0.35           628            1072           =BLOB=     =BLOB=     0.00105
# 3              64851834634947 0.35           367            691            =BLOB=     =BLOB=     0.00145
# 3              64851834634947 0.35           72             91             =BLOB=     =BLOB=     0.00061
# 3              64851834634947 0.35           223            325            =BLOB=     =BLOB=     0.00104
#    ...
#  (259 tuples)

# %%
@schema
class ExcitatoryLeftoverMeshes(dj.Computed):
    definition="""
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh pieces that were filtered away
    n_triangles          : bigint           # number of triangles in this mesh pieces that were filtered away
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    
    recovered_perc       : decimal(6,5)     # number of faces of this recovered mesh  / number of faces in filtered pymeshfix mesh
    """
    

    def make(self, key):
        print("\n\n------Working on segment " + str(key["segment_id"]) + "-------")
        global_time = time.time()
        #get the pymeshfixed mesh
        start_time = time.time()
        verts_fixed, faces_fixed = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & key).fetch1("vertices","triangles")

        #Step 2: get the fully decimated mesh
        verts_original, faces_original = (pinky.Decimation35 & key).fetch1("vertices","triangles")
        print(f"Retrieving Meshes: {time.time() - start_time}")
        
        #do the boolean mesh difference to get the leftover mesh
        start_time = time.time()
        verts_diff, faces_diff = neuron_boolean_difference(verts_fixed,
                                                   faces_fixed,
                                                   verts_original,
                                                   faces_original,
                                                   distance_threshold = 5,
                                                   significance_threshold=90,
                                                   n_sample_points=3)
        print(f"Boolean Mesh Difference: {time.time() - start_time}")
        new_key = dict(key,
                      n_vertices = len(verts_diff),
                      n_triangles = len(faces_diff),
                      vertices = verts_diff,
                      triangles = faces_diff,
                      recovered_perc = len(faces_diff) / len(faces_fixed))
        
        #insert the key
        self.insert1(new_key,skip_duplicates=True)
        print(f"Total time for processing leftover mesh: {time.time() - global_time}")

# %%
#schema = dj.schema("microns_pinky")
#(schema.jobs & "table_name='__excitatory_leftover_meshes'").delete()

# %%
start = time.time()
ExcitatoryLeftoverMeshes.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# Working on segment 648518346341371119
# Retrieving Meshes: 0.2254927158355713
# Total time for KDTree creation and queries: 0.0727996826171875
# Original number vertices in child mesh = 234870
# Number of vertices after distance threshold applied =  17439
# Total time for finding faces after distance threshold applied: 0.6365811824798584
# ------Starting the mesh filter for significant outside pieces-------
# There were 3701 pieces after mesh split
# There were 25 pieces found after size threshold
# Total time for filtering: 10.1398286819458
# Boolean Mesh Difference: 10.926184892654419
# Total time for processing leftover mesh: 11.159440994262695
# Working on segment 648518346349386137
# Retrieving Meshes: 0.06198239326477051
# Total time for KDTree creation and queries: 0.008179664611816406
# Original number vertices in child mesh = 30072
# Number of vertices after distance threshold applied =  2687
# Total time for finding faces after distance threshold applied: 0.08158445358276367
# ------Starting the mesh filter for significant outside pieces-------
# There were 504 pieces after mesh split
# There were 6 pieces found after size threshold
# Total time for filtering: 1.290801763534546
# Boolean Mesh Difference: 1.384347915649414
# Total time for processing leftover mesh: 1.4493978023529053
# Working on segment 648518346349470171
# Retrieving Meshes: 0.29259824752807617
# Total time for KDTree creation and queries: 0.09898829460144043
# Original number vertices in child mesh = 433104
# Number of vertices after distance threshold applied =  102507
# Total time for finding faces after distance threshold applied: 1.2714004516601562
# ------Starting the mesh filter for significant outside pieces-------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-78cb826ea553> in <module>
#       1 start = time.time()
# ----> 2 ExcitatoryLeftoverMeshes.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-3-184dde92613e> in make(self, key)
#      32                                                    distance_threshold = 5,
#      33                                                    significance_threshold=90,
# ---> 34                                                    n_sample_points=3)
#      35         print(f"Boolean Mesh Difference: {time.time() - start_time}")
#      36         new_key = dict(key,
#
# /notebooks/Pass_2_Excitatory_3b_Leftover_Mesh_after_Pymeshfix/boolean.py in neuron_boolean_difference(main_mesh_verts, main_mesh_faces, child_mesh_verts, child_mesh_faces, distance_threshold, significance_threshold, n_sample_points)
#     127
#     128     #filter the mesh for only significant pieces on the outside
# --> 129     returned_mesh = filter_mesh_significant_outside_pieces(new_submesh,pymesh_mesh,significance_threshold,n_sample_points=n_sample_points)
#     130
#     131     total_returned_mesh = trimesh.Trimesh()
#
# /notebooks/Pass_2_Excitatory_3b_Leftover_Mesh_after_Pymeshfix/boolean.py in filter_mesh_significant_outside_pieces(unfiltered_mesh, main_mesh, significance_threshold, n_sample_points)
#      24     print("------Starting the mesh filter for significant outside pieces-------")
#      25
# ---> 26     mesh_pieces = unfiltered_mesh.split(only_watertight=False)
#      27
#      28     print(f"There were {len(mesh_pieces)} pieces after mesh split")
#
# /usr/local/lib/python3.6/dist-packages/trimesh/constants.py in timed(*args, **kwargs)
#     126     def timed(*args, **kwargs):
#     127         tic = time_function()
# --> 128         result = method(*args, **kwargs)
#     129         log.debug('%s executed in %.4f seconds.',
#     130                   method.__name__,
#
# /usr/local/lib/python3.6/dist-packages/trimesh/base.py in split(self, only_watertight, adjacency, **kwargs)
#    1150                              only_watertight=only_watertight,
#    1151                              adjacency=adjacency,
# -> 1152                              **kwargs)
#    1153         return meshes
#    1154
#
# /usr/local/lib/python3.6/dist-packages/trimesh/graph.py in split(mesh, only_watertight, adjacency, engine)
#     331                                       engine=engine)
#     332     meshes = mesh.submesh(components,
# --> 333                           only_watertight=only_watertight)
#     334     return meshes
#     335
#
# /usr/local/lib/python3.6/dist-packages/trimesh/base.py in submesh(self, faces_sequence, **kwargs)
#    2303         return util.submesh(mesh=self,
#    2304                             faces_sequence=faces_sequence,
# -> 2305                             **kwargs)
#    2306
#    2307     @caching.cache_decorator
#
# /usr/local/lib/python3.6/dist-packages/trimesh/util.py in submesh(mesh, faces_sequence, only_watertight, append)
#    1373                                              faces,
#    1374                                              normals,
# -> 1375                                              visuals)]
#    1376     result = np.array(result)
#    1377     if len(result) > 0 and only_watertight:
#
# /usr/local/lib/python3.6/dist-packages/trimesh/util.py in <listcomp>(.0)
#    1370         visual=c,
#    1371         metadata=copy.deepcopy(mesh.metadata),
# -> 1372         process=False) for v, f, n, c in zip(vertices,
#    1373                                              faces,
#    1374                                              normals,
#
# KeyboardInterrupt:

# %%
pinky
# Out:
# <module 'pinky'>
