# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Stitcher_vp2_without_edges_check import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
pinky.NeuriteStitched()
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles  n_pieces     largest_piece_ outside_perc   n_stitched     stitched_addon n_unstitched   unstitched_per
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 3              64851834634135 28696          57266          =BLOB=     =BLOB=     0            0.99854        0.99854        0              0.00000        0              0.00000
# 3              64851834634135 11185          22272          =BLOB=     =BLOB=     0            0.99955        0.99955        0              0.00000        0              0.00000
# 3              64851834634135 56461          112482         =BLOB=     =BLOB=     0            0.96880        0.96880        0              0.00000        0              0.00000
# 3              64851834634135 24880          49518          =BLOB=     =BLOB=     0            0.99879        0.99879        0              0.00000        0              0.00000
# 3              64851834634135 37747          75320          =BLOB=     =BLOB=     0            0.99928        0.99928        0              0.00000        0              0.00000
# 3              64851834634135 20186          40264          =BLOB=     =BLOB=     0            0.99965        0.99965        0              0.00000        0              0.00000
# 3              64851834634135 15522          30788          =BLOB=     =BLOB=     0            1.00000        1.00000        0              0.00000        0              0.00000
# 3              64851834634135 45886          91544          =BLOB=     =BLOB=     0            0.99891        0.99891        0              0.00000        0              0.00000
# 3              64851834634135 17077          34042          =BLOB=     =BLOB=     0            0.99971        0.99971        0              0.00000        0              0.00000
# 3              64851834634135 21508          42872          =BLOB=     =BLOB=     0            0.99977        0.99977        0              0.00000        0              0.00000
# 3              64851834634135 12319          24624          =BLOB=     =BLOB=     0            0.99992        0.99992        0              0.00000        0              0.00000
# 3              64851834634135 75391          150222         =BLOB=     =BLOB=     0            0.99774        0.99774        0              0.00000        0              0.00000
# 3              64851834634135 33189          66228          =BLOB=     =BLOB=     0            0.99828        0.99828        0              0.00000        0              0.00000
# 3              64851834634135 18381          36734          =BLOB=     =BLOB=     0            0.99799        0.99799        0              0.00000        0              0.00000
# 3              64851834634135 15254          30436          =BLOB=     =BLOB=     0            0.99849        0.99849        0              0.00000        0              0.00000
# 3              64851834634135 26033          51854          =BLOB=     =BLOB=     0            1.00000        1.00000        0              0.00000        0              0.00000
# 3              64851834634135 29720          59118          =BLOB=     =BLOB=     0            0.99966        0.99966        0              0.00000        0              0.00000
# 3              64851834634135 23514          46922          =BLOB=     =BLOB=     0            0.99987        0.99987        0              0.00000        0              0.00000
# 3              64851834634135 29914          59350          =BLOB=     =BLOB=     0            0.99879        0.99879        0              0.00000        0              0.00000
# 3              64851834634135 15521          30930          =BLOB=     =BLOB=     0            0.99511        0.99511        0              0.00000        0              0.00000
#    ...
#  (16232 tuples)

# %%
@schema
class NeuriteStitched(dj.Computed):
    definition=""" 
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    
    key_source = pinky.Mesh() & pinky.Neurite() & pinky.CurrentSegmentation

    def make(self, key):
        
        
        
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        print(str(key['segment_id']) +  ":")
        my_dict = (pinky.Mesh & pinky.Neurite.proj() & pinky.CurrentSegmentation
                           & key).fetch1()
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        
        segment_id = my_dict["segment_id"]
        verts = my_dict["vertices"]
        faces = my_dict["triangles"]

        
        print("NOT Using a load file for meshes")

        [n_vertices,
         n_triangles,
         vertices,
         triangles,
         n_pieces,
         largest_piece_perc,
         outside_perc,
         n_stitched,
         stitched_addon_perc,
         n_unstitched,
         unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                      vertices=verts,
                                                      faces=faces,
                                                    import_from_off=False,
                                                     load_meshes_flag = False,
                                                 save_meshes_flag = False,
                                                    pymeshfix_flag = False
                                                   )
        
        
        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
NeuriteStitched.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341351467:
# Step 1: Retrieving Mesh and removing error segments: 0.02395153045654297
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 57266
# Total time for Mesh Cleansing: 0.8522601127624512
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985353095030515% of original mesh
# 648518346341355189:
# Step 1: Retrieving Mesh and removing error segments: 0.05332326889038086
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 77868
# Total time for Mesh Cleansing: 0.11785292625427246
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995892169448011% of original mesh
# 648518346341355190:
# Step 1: Retrieving Mesh and removing error segments: 0.021563291549682617
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 30278
# Total time for Mesh Cleansing: 0.055815696716308594
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994718426090975% of original mesh
# 648518346341355192:
# Step 1: Retrieving Mesh and removing error segments: 0.018149614334106445
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 24872
# Total time for Mesh Cleansing: 0.03824806213378906
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
# 648518346341355195:
# Step 1: Retrieving Mesh and removing error segments: 0.0365753173828125
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 85834
# Total time for Mesh Cleansing: 1.3193697929382324
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9949691658552418% of original mesh
# 648518346341355200:
# Step 1: Retrieving Mesh and removing error segments: 0.029187917709350586
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 44220
# Total time for Mesh Cleansing: 0.5802433490753174
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9930830039525692% of original mesh
# 648518346341355202:
# Step 1: Retrieving Mesh and removing error segments: 0.021275758743286133
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 34368
# Total time for Mesh Cleansing: 0.049364328384399414
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992440541954992% of original mesh
# 648518346341355205:
# Step 1: Retrieving Mesh and removing error segments: 0.020917415618896484
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 22094
# Total time for Mesh Cleansing: 0.03390979766845703
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997285067873303% of original mesh
# 648518346341355206:
# Step 1: Retrieving Mesh and removing error segments: 0.028438568115234375
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 60462
# Total time for Mesh Cleansing: 0.7501754760742188
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981839793964208% of original mesh
# 648518346341355207:
# Step 1: Retrieving Mesh and removing error segments: 0.030698060989379883
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 72256
# Total time for Mesh Cleansing: 0.9818840026855469
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983144049296747% of original mesh
# 648518346341355208:
# Step 1: Retrieving Mesh and removing error segments: 0.0413966178894043
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 30902
# Total time for Mesh Cleansing: 0.05622100830078125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999935283458452% of original mesh
# 648518346341355210:
# Step 1: Retrieving Mesh and removing error segments: 0.030362844467163086
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 48678
# Total time for Mesh Cleansing: 0.07501864433288574
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994661629434954% of original mesh
# 648518346341355216:
# Step 1: Retrieving Mesh and removing error segments: 0.03303647041320801
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 37874
# Total time for Mesh Cleansing: 0.5808219909667969
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.997419150953334% of original mesh
# 648518346341355220:
# Step 1: Retrieving Mesh and removing error segments: 0.050928592681884766
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 168256
# Total time for Mesh Cleansing: 0.21711254119873047
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998454974388229% of original mesh
# 648518346341355237:
# Step 1: Retrieving Mesh and removing error segments: 0.026345252990722656
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 36998
# Total time for Mesh Cleansing: 0.05612754821777344
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976271369249852% of original mesh
# 648518346341355240:
# Step 1: Retrieving Mesh and removing error segments: 0.0328669548034668
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 91638
# Total time for Mesh Cleansing: 0.11612057685852051
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996945432330417% of original mesh
# 648518346341355246:
# Step 1: Retrieving Mesh and removing error segments: 0.032387495040893555
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 34346
# Total time for Mesh Cleansing: 0.46241164207458496
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9972127054178038% of original mesh
# 648518346341355247:
# Step 1: Retrieving Mesh and removing error segments: 0.04818248748779297
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 145344
# Total time for Mesh Cleansing: 1.7069129943847656
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993949062104627% of original mesh
# 648518346341355250:
# Step 1: Retrieving Mesh and removing error segments: 0.03339648246765137
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 36176
# Total time for Mesh Cleansing: 0.05107927322387695
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992266047950503% of original mesh
# 648518346341355252:
# Step 1: Retrieving Mesh and removing error segments: 0.02525615692138672
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 35108
# Total time for Mesh Cleansing: 0.038820505142211914
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997721836200023% of original mesh
# 648518346341355253:
# Step 1: Retrieving Mesh and removing error segments: 0.03098440170288086
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 54098
# Total time for Mesh Cleansing: 0.6698446273803711
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981549134654415% of original mesh
# 648518346341355254:
# Step 1: Retrieving Mesh and removing error segments: 0.029705286026000977
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 28736
# Total time for Mesh Cleansing: 0.050384521484375
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
# 648518346341355258:
# Step 1: Retrieving Mesh and removing error segments: 0.024538040161132812
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 62174
# Total time for Mesh Cleansing: 0.07719826698303223
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990680035994344% of original mesh
# 648518346341355260:
# Step 1: Retrieving Mesh and removing error segments: 0.035924673080444336
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 62996
# Total time for Mesh Cleansing: 0.8760781288146973
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988900516918784% of original mesh
# 648518346341355265:
# Step 1: Retrieving Mesh and removing error segments: 0.04076266288757324
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 51246
# Total time for Mesh Cleansing: 0.061339616775512695
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998829313977992% of original mesh
# 648518346341355267:
# Step 1: Retrieving Mesh and removing error segments: 0.024306297302246094
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 44474
# Total time for Mesh Cleansing: 0.06762909889221191
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995954328868111% of original mesh
# 648518346341355269:
# Step 1: Retrieving Mesh and removing error segments: 0.025295019149780273
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 51282
# Total time for Mesh Cleansing: 0.8038163185119629
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9971610795675507% of original mesh
# 648518346341355270:
# Step 1: Retrieving Mesh and removing error segments: 0.031897783279418945
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 52662
# Total time for Mesh Cleansing: 0.060591697692871094
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9999240496715148% of original mesh
# 648518346341355272:
# Step 1: Retrieving Mesh and removing error segments: 0.02429962158203125
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 33568
# Total time for Mesh Cleansing: 0.5272018909454346
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979783565227732% of original mesh
# 648518346341355275:
# Step 1: Retrieving Mesh and removing error segments: 0.035330772399902344
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 69124
# Total time for Mesh Cleansing: 0.07721281051635742
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998553533717129% of original mesh
# 648518346341355277:
# Step 1: Retrieving Mesh and removing error segments: 0.03364229202270508
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 51528
# Total time for Mesh Cleansing: 0.7700822353363037
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9945954292773317% of original mesh
# 648518346341355280:
# Step 1: Retrieving Mesh and removing error segments: 0.03434038162231445
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 55548
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-275c07a299f4> in <module>
#       1 start = time.time()
# ----> 2 NeuriteStitched.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-3-a28aee49b5f0> in make(self, key)
#      59                                                      load_meshes_flag = False,
#      60                                                  save_meshes_flag = False,
# ---> 61                                                     pymeshfix_flag = False
#      62                                                    )
#      63
#
# /notebooks/Pass_2_Skeleton_Neurite_Stitching/Stitcher_vp2_without_edges_check.py in stitch_neuron(segment_id, vertices, faces, **kwargs)
#    1492         main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
#    1493                                     significance_threshold=outisde_size_threshold,
# -> 1494                                         n_sample_points=n_sample_points)
#    1495
#    1496     else: #load them from a saved location
#
# /notebooks/Pass_2_Skeleton_Neurite_Stitching/Stitcher_vp2_without_edges_check.py in filter_mesh_significant_outside_pieces(unfiltered_mesh, significance_threshold, n_sample_points)
#      74
#      75             start_time = time.time()
# ---> 76             signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
#      77             #print(f"Total time = {time.time() - start_time}")
#      78
#
# /usr/local/lib/python3.6/dist-packages/trimesh/proximity.py in signed_distance(mesh, points)
#     232         return distance
#     233
# --> 234     inside = mesh.ray.contains_points(points[nonzero])
#     235     sign = (inside.astype(int) * 2) - 1
#     236
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in contains_points(self, points)
#     138         """
#     139
# --> 140         return contains_points(self, points)
#     141
#     142
#
# /usr/local/lib/python3.6/dist-packages/trimesh/constants.py in timed(*args, **kwargs)
#     126     def timed(*args, **kwargs):
#     127         tic = time_function()
# --> 128         result = method(*args, **kwargs)
#     129         log.debug('%s executed in %.4f seconds.',
#     130                   method.__name__,
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_util.py in contains_points(intersector, points, check_direction)
#      66         np.vstack(
#      67             (ray_directions,
# ---> 68              -ray_directions)))
#      69
#      70     # if we hit nothing in either direction just return with no hits
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in intersects_location(self, ray_origins, ray_directions, **kwargs)
#      96              ray_directions=ray_directions,
#      97              return_locations=True,
# ---> 98              **kwargs)
#      99         return locations, index_ray, index_tri
#     100
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in intersects_id(self, ray_origins, ray_directions, return_locations, multiple_hits, **kwargs)
#      55                                       tree=self.mesh.triangles_tree,
#      56                                       multiple_hits=multiple_hits,
# ---> 57                                       triangles_normal=self.mesh.face_normals)
#      58         if return_locations:
#      59             if len(index_tri) == 0:
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in ray_triangle_id(triangles, ray_origins, ray_directions, triangles_normal, tree, multiple_hits)
#     186         ray_origins=ray_origins,
#     187         ray_directions=ray_directions,
# --> 188         tree=tree)
#     189
#     190     # get subsets which are corresponding rays and triangles
#
# /usr/local/lib/python3.6/dist-packages/trimesh/ray/ray_triangle.py in ray_triangle_candidates(ray_origins, ray_directions, tree)
#     290
#     291     for i, bounds in enumerate(ray_bounding):
# --> 292         ray_candidates[i] = np.array(list(tree.intersection(bounds)),
#     293                                      dtype=np.int)
#     294         ray_id[i] = np.ones(len(ray_candidates[i]), dtype=np.int) * i
#
# /usr/local/lib/python3.6/dist-packages/rtree/index.py in intersection(self, coordinates, objects)
#     463                                     self.properties.dimension,
#     464                                     ctypes.byref(it),
# --> 465                                     ctypes.byref(p_num_results))
#     466         return self._get_ids(it, p_num_results.value)
#     467
#
# /usr/local/lib/python3.6/dist-packages/rtree/core.py in check_return(result, func, cargs)
#       9
#      10
# ---> 11 def check_return(result, func, cargs):
#      12     "Error checking for Error calls"
#      13     if result != 0:
#
# KeyboardInterrupt:

# %%
(schema.jobs & "table_name='__neurite_stitched'").delete()
#schema.jobs
