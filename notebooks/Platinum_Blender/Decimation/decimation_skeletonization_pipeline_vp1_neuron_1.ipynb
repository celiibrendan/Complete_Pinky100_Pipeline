# %%
from pykdtree.kdtree import KDTree
import time
import trimesh
import numpy as np

def filter_mesh_significant_outside_pieces(unfiltered_mesh,main_mesh,
                                           significance_threshold=2000,
                                           n_sample_points=3,
                                          print_flag=False):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces that are not inside of main mesh

    """
    if print_flag:
        print("------Starting the mesh filter for significant outside pieces-------")

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    if print_flag:
        print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    if print_flag:
        print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []



    final_mesh_pieces = []

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        #get a random sample of points
        # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
        idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
        points = mesh.vertices[idx,:]


        start_time = time.time()
        signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
        #print(f"Total time = {time.time() - start_time}")

        outside_percentage = sum(signed_distance <= 0)/n_sample_points
        if outside_percentage > 0.9:
            final_mesh_pieces.append(mesh)
            #print(f"Mesh piece {i} OUTSIDE mesh")
        else:
            #print(f"Mesh piece {i} inside mesh :( ")
            pass
                
    return final_mesh_pieces
    
def neuron_boolean_difference(main_mesh_verts,
                             main_mesh_faces,
                             child_mesh_verts,
                             child_mesh_faces,
                             distance_threshold=5,
                             significance_threshold=1000,
                             n_sample_points=3,
                             print_flag=False):
    """
    returns the boolean difference of two meshes passed. Only returns meshes pieces that 
    are greater than the size threshold and outside of the main mesh
    
    Function operation: child_mesh - main_mesh
  

    Parameters: 
    main_mesh_verts (np.array): array of the reference mesh vertices
    main_mesh_faces (np.array): array of the reference mesh faces
    child_mesh_verts (np.array): array of the child mesh vertices that is to be compared to the main mesh
    child_mesh_faces (np.array): array of the child mesh faces that is to be compared to the main mesh
    
    Optional parameters:
    -- for controlling the mesh returned --
    distance_threshold (int) : distance away from the reference mesh that vertices from the child
                                mesh will considered distinct and part of the difference mesh 
                                (default=5)
    significance_threshold (int) : number of faces necessary for any distinct/unconnected part of the 
                                    difference mesh to be considered relevant and included in the difference mesh
                                (default=1000)
    n_sample_points (int) : number of vertices to check to see if submesh is a mesh located inside of the main mesh.
                            The less there are the quicker the speed for filtering the difference mesh
                            (default=3)
    
    
    Returns:
    difference_mesh_verts (np.array): array of vertices from the mesh boolean operation of child - main mesh
    difference_mesh_faces (np.array): array of faces from the mesh boolean operation of child - main mesh
    """
    
    #Create the kdtree from main mesh and run the queries
    
    import time
    global_time = time.time()
    start_time = time.time()
    mesh_tree = KDTree(main_mesh_verts)
    distances,closest_node = mesh_tree.query(child_mesh_verts)
    if print_flag:
        print(f"Total time for KDTree creation and queries: {time.time() - start_time}")
    
    if print_flag:
        print("Original number vertices in child mesh = " + str(len(child_mesh_verts)))
    vertex_indices = np.where(distances > distance_threshold)[0]
    if print_flag:
        print("Number of vertices after distance threshold applied =  " + str(len(vertex_indices)))
    
    start_time = time.time()
    set_vertex_indices = set(list(vertex_indices))
    face_indices_lookup = np.linspace(0,len(child_mesh_faces)-1,len(child_mesh_faces)).astype('int')
    face_indices_lookup_bool = [len(set_vertex_indices.intersection(set(tri))) > 0 for tri in child_mesh_faces]
    face_indices_lookup = face_indices_lookup[face_indices_lookup_bool]

    if print_flag:
        print(f"Total time for finding faces after distance threshold applied: {time.time() - start_time}")
    
    start_time = time.time()
    trimesh_original = trimesh.Trimesh(child_mesh_verts,child_mesh_faces,process=False) 
    new_submesh = trimesh_original.submesh([face_indices_lookup],only_watertight=False,append=True)
    
    pymesh_mesh = trimesh.Trimesh(main_mesh_verts,main_mesh_faces)
    #return new_submesh
    #filter the mesh for only significant pieces on the outside
    returned_mesh = filter_mesh_significant_outside_pieces(new_submesh,pymesh_mesh,
                                                           significance_threshold,
                                                           n_sample_points=n_sample_points,
                                                          print_flag=print_flag)
    
    return returned_mesh
    
    total_returned_mesh = trimesh.Trimesh(vertices = np.array([]),
                                     faces = np.array([]))
    for r in returned_mesh:
        total_returned_mesh = total_returned_mesh + r

    if print_flag:
        print(f"Total time for filtering: {time.time() - start_time}")
    
    if print_flag:
        print(f"Total time for boolean difference: {time.time() - global_time}")
    return total_returned_mesh.vertices,total_returned_mesh.faces

# %% [markdown]
# # Example of Neuron Boolean Difference Parameters that work

# %%
#largest_mesh = trimesh.load_mesh("temp/96631955273149705_decimated_poisson_largest_piece.off")
original_mesh = trimesh.load_mesh("temp/neuron_96631955273149705_decimated_bac.off")

# %%
# mesh_pieces =neuron_boolean_difference( largest_mesh.vertices,
#                                                largest_mesh.faces,
#                                                 original_mesh.vertices,
#                                                original_mesh.faces,
                                       
#                                                distance_threshold=1000,
#                                                significance_threshold=1000,
#                                                n_sample_points=10,
#                                       print_flag = False)

# significant_leftovers = trimesh.Trimesh(vertices = mesh_pieces[0],
#                                         faces = mesh_pieces[1]
#                                        )

# %% [markdown]
# # Other Helper Functions

# %%
import os, contextlib
import pathlib
import subprocess

def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    command_to_run = 'xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command
    #command_to_run = 'meshlabserver ' + script_command
    
    print(command_to_run)
    subprocess_result = subprocess.run(command_to_run,shell=True)
    
    return subprocess_result

def meshlab_fix_manifold_path_specific_mls(input_path_and_filename,
                                           output_path_and_filename="",
                                           segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if input_path_and_filename[-4:] == ".off":
        path_and_filename = input_path_and_filename[:-4]
        input_mesh = input_path_and_filename
    else:
        raise Exception("Not passed off file")
    
    
    if output_path_and_filename == "":
        output_mesh = path_and_filename+"_mls.off"
    else:
        output_mesh = output_path_and_filename
    
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    #print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(vertices=[], 
                                triangles=[],
                                neuron_ID="None",
                                folder="pymesh_NEURONS",
                               path_and_filename="-1"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    if path_and_filename == "-1":
        #get the current file location
        file_loc = pathlib.Path.cwd() / folder
        filename = "neuron_" + str(neuron_ID)
        path_and_filename = file_loc / filename
    
    #print("path_and_filename = " + str(path_and_filename))
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    #print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename)#,str(filename),str(file_loc)

# %% [markdown]
# # Whole Pipeline for One neuron

# %%
"""
Pseudocode For whole run: 

1) Do Poisson Surface Reconstruction 
2) Filter away for largest_poisson_piece:
3) **** Do a check that the reconstruction wasn’t too far away from mesh points on the original mesh ******
4) If not of a significant size then return (Add the largest_poisson_piece to the Surface_Reconstruction_list and say that it was returned)
5) If significant size (add largest_poisson_piece to the Surface_Reconstruction_list)
6) Run skeletonization on it:
    If error then return
7) Subtract the largest_poisson_piece from leftover
8) Find still leftover pieces:
    Divide leftover into separate pieces
    Only keep the significant pieces
9) If no significant leftover pieces
    Return
    Write to log
10) For Each of these significant pieces send to skeleton function (so recursive function)
    Write to log which pieces sent


"""
# Out:
# '\nPseudocode For whole run: \n\n1) Do Poisson Surface Reconstruction \n2) Filter away for largest_poisson_piece:\n3) **** Do a check that the reconstruction wasn’t too far away from mesh points on the original mesh ******\n4) If not of a significant size then return (Add the largest_poisson_piece to the Surface_Reconstruction_list and say that it was returned)\n5) If significant size (add largest_poisson_piece to the Surface_Reconstruction_list)\n6) Run skeletonization on it:\n    If error then return\n7) Subtract the largest_poisson_piece from leftover\n8) Find still leftover pieces:\n    Divide leftover into separate pieces\n    Only keep the significant pieces\n9) If no significant leftover pieces\n    Return\n    Write to log\n10) For Each of these significant pieces send to skeleton function (so recursive function)\n    Write to log which pieces sent\n\n\n'

# %%
distance_threshold=1000
significance_threshold=1000
n_sample_points=10
print_flag = False
name2 = "96631955273149705"

import calcification_Module as cm
import time


original_mesh = trimesh.load_mesh("temp/neuron_96631955273149705_decimated_bac.off")

# create a folder to store the skeletons of that neuron
import os
directory = "./" + name2
if not os.path.exists(directory):
    os.makedirs(directory)
    

current_base_path = str(pathlib.Path.cwd()) + "/"
mesh_base_path = current_base_path + str(name2) + "/"
folder_name = str(name2)

current_layer = 1

def recursive_skeletonizing(verts,faces,current_name,
                           boolean_distance_threshold=1000,
                            boolean_significance_threshold=1000,
                            boolean_n_sample_points=10,
                            boolean_print_flag = False,
                           largest_mesh_significant=3000):
    
    print(f"\n----------Starting {current_name}----------")
    global_time = time.time()
    #print out the off file
    initial_output_path = mesh_base_path + current_name
    
    write_Whole_Neuron_Off_file(vertices=verts, 
                                triangles=faces,
                               path_and_filename=initial_output_path)
    
    
    # do the poisson surface reconstruction
    
    script_name = "poisson_working_meshlab.mls"
    
    input_file_base = initial_output_path
    output_file = input_file_base + "_poisson"
    meshlab_script_path_and_name =current_base_path + script_name

    start_time = time.time()
    print("     Starting Screened Poisson")
    meshlab_fix_manifold_path_specific_mls(input_path_and_filename=input_file_base + ".off",
                                                       output_path_and_filename=output_file + ".off",
                                                     meshlab_script=meshlab_script_path_and_name)
    print(f"     Total_time for Screended Poisson = {time.time() - start_time}")
    
    #2) Filter away for largest_poisson_piece:
    
    new_mesh = trimesh.load_mesh(output_file + ".off")
    mesh_splits = new_mesh.split(only_watertight=True)
    mesh_lengths = np.array([len(split.faces) for split in mesh_splits])
    largest_index = np.where(mesh_lengths == np.max(mesh_lengths))
    largest_mesh = mesh_splits[largest_index][0]
    
    print("len(largest_mesh.vertices) = " + str(len(largest_mesh.vertices)))
    #4) If not of a significant size then return (Add the largest_poisson_piece to the Surface_Reconstruction_list and say that it was returned)
    if len(largest_mesh.vertices) < largest_mesh_significant:
        print(current_name + " returned because largest mesh not significant")
        return
    
    #5) If significant size output the mesh
    largest_mesh_path = mesh_base_path + current_name + "-0"
    write_Whole_Neuron_Off_file(vertices=largest_mesh.vertices, 
                                triangles=largest_mesh.faces,
                               path_and_filename=largest_mesh_path)
    
    
    #6) Run skeletonization on it:
    start_time = time.time()
    print("     Starting Calcification")
    cm.calcification(largest_mesh_path)
    print(f"     Total_time for Calcification = {time.time() - start_time}")
    
    
    #7) Subtract the largest_poisson_piece from leftover
    start_time = time.time()
    print("     Starting Mesh boolean difference")
    mesh_pieces =neuron_boolean_difference( largest_mesh.vertices,
                                               largest_mesh.faces,
                                                verts,
                                               faces,
                                               distance_threshold=boolean_distance_threshold,
                                               significance_threshold=boolean_significance_threshold,
                                               n_sample_points=boolean_n_sample_points,
                                              print_flag = boolean_print_flag)
    print(f"     Total_time for Mesh boolean difference = {time.time() - start_time}")
    
    print(f"Total time for one mesh piece skeleton = {time.time() - global_time}")

    print(f"{current_name} there were {len(mesh_pieces)} significant pieces leftover after largest mesh")
    
    if len(mesh_pieces) <= 0:
        print(f"{current_name} returning because 0 significant pieces")
        return 
    
    for j,piece in enumerate(mesh_pieces):
        new_current_name = current_name + "-" + str(j)
        recursive_skeletonizing(verts = piece.vertices,faces=piece.faces,current_name=new_current_name)
    
    return

    
recursive_skeletonizing(verts = original_mesh.vertices,faces=original_mesh.faces,current_name=name2)
# Out:
# ----------Starting 96631955273149705----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 37.847874879837036
# len(largest_mesh.vertices) = 84701
#      Starting Calcification
#      Total_time for Calcification = 5.4120192527771
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 13.15565037727356
# Total time for one mesh piece skeleton = 67.19925022125244
# 96631955273149705 there were 37 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.59799337387085
# len(largest_mesh.vertices) = 13497
#      Starting Calcification
#      Total_time for Calcification = 0.6436324119567871
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.09261941909790039
# Total time for one mesh piece skeleton = 9.246885299682617
# 96631955273149705-0 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-0 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-1----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-1.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-1_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.575139045715332
# len(largest_mesh.vertices) = 9880
#      Starting Calcification
#      Total_time for Calcification = 0.547478199005127
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.39911627769470215
# Total time for one mesh piece skeleton = 9.103505611419678
# 96631955273149705-1 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-1-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-1-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-1-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.000643491744995
# len(largest_mesh.vertices) = 2737
# 96631955273149705-1-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-2----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.625970363616943
# len(largest_mesh.vertices) = 3863
#      Starting Calcification
#      Total_time for Calcification = 0.23366260528564453
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.18832063674926758
# Total time for one mesh piece skeleton = 7.484519004821777
# 96631955273149705-2 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-2-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.124710321426392
# len(largest_mesh.vertices) = 4495
#      Starting Calcification
#      Total_time for Calcification = 0.3809521198272705
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.2619004249572754
# Total time for one mesh piece skeleton = 7.124861478805542
# 96631955273149705-2-0 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-2-0-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2-0-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-2-0-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.1443727016448975
# len(largest_mesh.vertices) = 1293
# 96631955273149705-2-0-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-3----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-3.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-3_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.61016845703125
# len(largest_mesh.vertices) = 18649
#      Starting Calcification
#      Total_time for Calcification = 0.9596860408782959
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.124969482421875
# Total time for one mesh piece skeleton = 9.452998399734497
# 96631955273149705-3 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-3 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-4----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-4.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-4_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.287996292114258
# len(largest_mesh.vertices) = 19230
#      Starting Calcification
#      Total_time for Calcification = 1.0264256000518799
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.12610673904418945
# Total time for one mesh piece skeleton = 9.294482231140137
# 96631955273149705-4 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-4 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-5----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.970168590545654
# len(largest_mesh.vertices) = 3776
#      Starting Calcification
#      Total_time for Calcification = 0.2573986053466797
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.3046910762786865
# Total time for one mesh piece skeleton = 9.059086561203003
# 96631955273149705-5 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-5-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.700896501541138
# len(largest_mesh.vertices) = 4075
#      Starting Calcification
#      Total_time for Calcification = 0.2689208984375
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.30843496322631836
# Total time for one mesh piece skeleton = 8.635091066360474
# 96631955273149705-5-0 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-5-0-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5-0-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-5-0-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.766618013381958
# len(largest_mesh.vertices) = 1286
# 96631955273149705-5-0-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-6----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-6.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-6_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.087289571762085
# len(largest_mesh.vertices) = 764
# 96631955273149705-6 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-7----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-7.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-7_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.207460641860962
# len(largest_mesh.vertices) = 10017
#      Starting Calcification
#      Total_time for Calcification = 0.6256425380706787
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.09710931777954102
# Total time for one mesh piece skeleton = 8.46714186668396
# 96631955273149705-7 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-7 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-8----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-8.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-8_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.574371814727783
# len(largest_mesh.vertices) = 5055
#      Starting Calcification
#      Total_time for Calcification = 0.2362957000732422
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.2572448253631592
# Total time for one mesh piece skeleton = 7.422898530960083
# 96631955273149705-8 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-8-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-8-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-8-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.870400667190552
# len(largest_mesh.vertices) = 2632
# 96631955273149705-8-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-9----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-9.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-9_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.393927097320557
# len(largest_mesh.vertices) = 11049
#      Starting Calcification
#      Total_time for Calcification = 0.5284786224365234
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.45448732376098633
# Total time for one mesh piece skeleton = 8.976955652236938
# 96631955273149705-9 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-9-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-9-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-9-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.770812511444092
# len(largest_mesh.vertices) = 1238
# 96631955273149705-9-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-10----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-10.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-10_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.674855470657349
# len(largest_mesh.vertices) = 2128
# 96631955273149705-10 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-11----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-11.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-11_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.06506872177124
# len(largest_mesh.vertices) = 14352
#      Starting Calcification
#      Total_time for Calcification = 0.9051575660705566
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.6117324829101562
# Total time for one mesh piece skeleton = 9.220581769943237
# 96631955273149705-11 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-11-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-11-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-11-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.852705240249634
# len(largest_mesh.vertices) = 1004
# 96631955273149705-11-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-12----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-12.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-12_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.776048183441162
# len(largest_mesh.vertices) = 786
# 96631955273149705-12 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-13----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-13.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-13_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.753908634185791
# len(largest_mesh.vertices) = 6788
#      Starting Calcification
#      Total_time for Calcification = 0.37245798110961914
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.09286284446716309
# Total time for one mesh piece skeleton = 7.632094383239746
# 96631955273149705-13 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-13 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-14----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.73539662361145
# len(largest_mesh.vertices) = 10335
#      Starting Calcification
#      Total_time for Calcification = 0.4809763431549072
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.4423561096191406
# Total time for one mesh piece skeleton = 9.297803163528442
# 96631955273149705-14 there were 2 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-14-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.9989542961120605
# len(largest_mesh.vertices) = 6894
#      Starting Calcification
#      Total_time for Calcification = 0.4833369255065918
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.0337519645690918
# Total time for one mesh piece skeleton = 6.795754432678223
# 96631955273149705-14-0 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-14-0 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-14-1----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14-1.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-14-1_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.745196580886841
# len(largest_mesh.vertices) = 315
# 96631955273149705-14-1 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-15----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-15.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-15_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.165372371673584
# len(largest_mesh.vertices) = 14697
#      Starting Calcification
#      Total_time for Calcification = 0.7296903133392334
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.06766104698181152
# Total time for one mesh piece skeleton = 8.646093130111694
# 96631955273149705-15 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-15 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-16----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-16.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-16_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.550772666931152
# len(largest_mesh.vertices) = 2003
# 96631955273149705-16 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-17----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-17.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-17_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.3570897579193115
# len(largest_mesh.vertices) = 5586
#      Starting Calcification
#      Total_time for Calcification = 0.25542545318603516
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.05275893211364746
# Total time for one mesh piece skeleton = 7.123732566833496
# 96631955273149705-17 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-17 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-18----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-18.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-18_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.83263373374939
# len(largest_mesh.vertices) = 1746
# 96631955273149705-18 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-19----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-19.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-19_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.834314584732056
# len(largest_mesh.vertices) = 14903
#      Starting Calcification
#      Total_time for Calcification = 0.7058868408203125
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.1405794620513916
# Total time for one mesh piece skeleton = 9.393456220626831
# 96631955273149705-19 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-19 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-20----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 9.388940572738647
# len(largest_mesh.vertices) = 26060
#      Starting Calcification
#      Total_time for Calcification = 1.288975477218628
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 1.0407183170318604
# Total time for one mesh piece skeleton = 13.023709774017334
# 96631955273149705-20 there were 2 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-20-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.862172603607178
# len(largest_mesh.vertices) = 486
# 96631955273149705-20-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-20-1----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20-1.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-20-1_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.8675127029418945
# len(largest_mesh.vertices) = 789
# 96631955273149705-20-1 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-21----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-21.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-21_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.707884073257446
# len(largest_mesh.vertices) = 3365
#      Starting Calcification
#      Total_time for Calcification = 0.23897194862365723
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.022205352783203125
# Total time for one mesh piece skeleton = 6.171750068664551
# 96631955273149705-21 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-21 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-22----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-22.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-22_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.7257208824157715
# len(largest_mesh.vertices) = 2325
# 96631955273149705-22 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-23----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-23.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-23_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.852019309997559
# len(largest_mesh.vertices) = 1056
# 96631955273149705-23 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-24----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-24.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-24_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.320009708404541
# len(largest_mesh.vertices) = 6186
#      Starting Calcification
#      Total_time for Calcification = 0.3780369758605957
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.056413888931274414
# Total time for one mesh piece skeleton = 8.130522727966309
# 96631955273149705-24 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-24 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-25----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-25.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-25_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 8.384779691696167
# len(largest_mesh.vertices) = 17875
#      Starting Calcification
#      Total_time for Calcification = 0.9333477020263672
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.13463306427001953
# Total time for one mesh piece skeleton = 10.26935625076294
# 96631955273149705-25 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-25 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-26----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-26.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-26_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.299121141433716
# len(largest_mesh.vertices) = 886
# 96631955273149705-26 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-27----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-27.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-27_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.248234510421753
# len(largest_mesh.vertices) = 4028
#      Starting Calcification
#      Total_time for Calcification = 0.239365816116333
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.038356781005859375
# Total time for one mesh piece skeleton = 6.753098249435425
# 96631955273149705-27 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-27 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-28----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-28.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-28_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 8.70136046409607
# len(largest_mesh.vertices) = 24543
#      Starting Calcification
#      Total_time for Calcification = 1.2550241947174072
#      Starting Mesh boolean difference
#      Total_time for Mesh boolean difference = 0.9321990013122559
# Total time for one mesh piece skeleton = 11.81594967842102
# 96631955273149705-28 there were 1 significant pieces leftover after largest mesh
#
# ----------Starting 96631955273149705-28-0----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-28-0.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-28-0_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.774630308151245
# len(largest_mesh.vertices) = 426
# 96631955273149705-28-0 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-29----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-29.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-29_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.889104604721069
# len(largest_mesh.vertices) = 1996
# 96631955273149705-29 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-30----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-30.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-30_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.127178192138672
# len(largest_mesh.vertices) = 14698
#      Starting Calcification
#      Total_time for Calcification = 0.7593626976013184
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.08147883415222168
# Total time for one mesh piece skeleton = 8.71851372718811
# 96631955273149705-30 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-30 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-31----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-31.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-31_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.255526304244995
# len(largest_mesh.vertices) = 5552
#      Starting Calcification
#      Total_time for Calcification = 0.3405609130859375
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.03723502159118652
# Total time for one mesh piece skeleton = 7.0138258934021
# 96631955273149705-31 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-31 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-32----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-32.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-32_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 5.751475811004639
# len(largest_mesh.vertices) = 559
# 96631955273149705-32 returned because largest mesh not significant
#
# ----------Starting 96631955273149705-33----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-33.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-33_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.955881595611572
# len(largest_mesh.vertices) = 7420
#      Starting Calcification
#      Total_time for Calcification = 0.4032907485961914
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.06101584434509277
# Total time for one mesh piece skeleton = 7.874868154525757
# 96631955273149705-33 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-33 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-34----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-34.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-34_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 6.254129886627197
# len(largest_mesh.vertices) = 3439
#      Starting Calcification
#      Total_time for Calcification = 0.21749186515808105
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.05293869972229004
# Total time for one mesh piece skeleton = 6.773157358169556
# 96631955273149705-34 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-34 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-35----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-35.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-35_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.731487035751343
# len(largest_mesh.vertices) = 13974
#      Starting Calcification
#      Total_time for Calcification = 0.6362001895904541
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.10426712036132812
# Total time for one mesh piece skeleton = 9.162832975387573
# 96631955273149705-35 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-35 returning because 0 significant pieces
#
# ----------Starting 96631955273149705-36----------
#      Starting Screened Poisson
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-36.off -o /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/96631955273149705/96631955273149705-36_poisson.off -s /notebooks/Users/celii/Documents/Complete_Pinky100_Pipeline/notebooks/Platinum_Blender/Decimation/poisson_working_meshlab.mls
#      Total_time for Screended Poisson = 7.243967771530151
# len(largest_mesh.vertices) = 17081
#      Starting Calcification
#      Total_time for Calcification = 0.8630201816558838
#      Starting Mesh boolean difference
# THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold
#      Total_time for Mesh boolean difference = 0.1135098934173584
# Total time for one mesh piece skeleton = 8.884222507476807
# 96631955273149705-36 there were 0 significant pieces leftover after largest mesh
# 96631955273149705-36 returning because 0 significant pieces

# %% [markdown]
# # Assemble all of the skeleton files into one

# %%
#read in the skeleton files into an array
def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
cgal_skeleton_file_list = []
import os
for file in os.listdir(name2):
    if file.endswith(".cgal"):
        cgal_skeleton_file_list.append(str(os.path.join(name2, file)))
cgal_skeleton_file_list

bone_array_total = np.vstack([read_skeleton_revised(k) 
                              for k in cgal_skeleton_file_list])

unique_skeleton_verts = bone_array_total.reshape(-1,3)
edges = np.arange(0,len(unique_skeleton_verts)).astype("int").reshape(-1,2)

# %%
from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance
total_edges = np.array([])

for k in cgal_skeleton_file_list:
    bone_array = read_skeleton_revised(k) 

    #add the skeleton edges to the total edges
    if not total_edges.any():
        total_edges = bone_array
    else:
        total_edges = np.vstack([total_edges,bone_array])


total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)
# Out:
# len_subgraphs AT BEGINNING = 31
# min_dist = 3321.9015638636856
# min_dist_subgraph_index = 6
# min_dist_edge_index = [1964, 2162]
# min_dist_edge = [array([ 911766.,  792472., 1053440.]), array([ 913965.,  793495., 1055710.])]
# len_subgraphs AT END= 30
# min_dist = 2034.6881824987336
# min_dist_subgraph_index = 25
# min_dist_edge_index = [9141, 9160]
# min_dist_edge = [array([1005860.,  812704., 1048820.]), array([1006700.,  814188., 1049930.])]
# len_subgraphs AT END= 29
# min_dist = 2184.01648345428
# min_dist_subgraph_index = 13
# min_dist_edge_index = [6191, 5952]
# min_dist_edge = [array([958739., 833957., 999307.]), array([956961., 835069., 999917.])]
# len_subgraphs AT END= 28
# min_dist = 2440.776106077737
# min_dist_subgraph_index = 5
# min_dist_edge_index = [3752, 3667]
# min_dist_edge = [array([ 933171.,  825651., 1086220.]), array([ 931553.,  824593., 1084730.])]
# len_subgraphs AT END= 27
# min_dist = 2532.567471954104
# min_dist_subgraph_index = 12
# min_dist_edge_index = [4046, 4186]
# min_dist_edge = [array([ 939541.,  496166., 1061820.]), array([ 941174.,  494769., 1060480.])]
# len_subgraphs AT END= 26
# min_dist = 2558.2394336730877
# min_dist_subgraph_index = 16
# min_dist_edge_index = [6914, 6878]
# min_dist_edge = [array([ 963366.,  819323., 1032390.]), array([ 963091.,  817131., 1033680.])]
# len_subgraphs AT END= 25
# min_dist = 2565.538539956085
# min_dist_subgraph_index = 6
# min_dist_edge_index = [2931, 3167]
# min_dist_edge = [array([ 925787.,  831995., 1005090.]), array([ 926875.,  833557., 1003370.])]
# len_subgraphs AT END= 24
# min_dist = 1759.1739538772167
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2771, 2656]
# min_dist_edge = [array([ 924638.,  833976., 1001560.]), array([ 923261.,  833118., 1002240.])]
# len_subgraphs AT END= 23
# min_dist = 3123.706132144956
# min_dist_subgraph_index = 13
# min_dist_edge_index = [6463, 6694]
# min_dist_edge = [array([ 960521.,  833150., 1024700.]), array([ 961843.,  830534., 1025780.])]
# len_subgraphs AT END= 22
# min_dist = 3164.91405886479
# min_dist_subgraph_index = 9
# min_dist_edge_index = [5325, 5263]
# min_dist_edge = [array([ 953767.,  804878., 1076070.]), array([ 952822.,  804144., 1079000.])]
# len_subgraphs AT END= 21
# min_dist = 3198.927789119348
# min_dist_subgraph_index = 10
# min_dist_edge_index = [5424, 5542]
# min_dist_edge = [array([954587., 832721., 954103.]), array([955296., 833684., 951136.])]
# len_subgraphs AT END= 20
# min_dist = 3445.134685320735
# min_dist_subgraph_index = 4
# min_dist_edge_index = [3877, 3824]
# min_dist_edge = [array([ 937016.,  482592., 1066360.]), array([ 935343.,  479910., 1067730.])]
# len_subgraphs AT END= 19
# min_dist = 2950.2076198125446
# min_dist_subgraph_index = 7
# min_dist_edge_index = [3814, 3895]
# min_dist_edge = [array([ 934936.,  479039., 1068000.]), array([ 937381.,  477799., 1066910.])]
# len_subgraphs AT END= 18
# min_dist = 1777.7632013291309
# min_dist_subgraph_index = 10
# min_dist_edge_index = [7422, 7552]
# min_dist_edge = [array([ 966325.,  429897., 1063410.]), array([ 967594.,  428656., 1063310.])]
# len_subgraphs AT END= 17
# min_dist = 3625.8011528488432
# min_dist_subgraph_index = 9
# min_dist_edge_index = [7249, 7180]
# min_dist_edge = [array([965429., 821386., 970524.]), array([965242., 821802., 966927.])]
# len_subgraphs AT END= 16
# min_dist = 1452.8268995307046
# min_dist_subgraph_index = 8
# min_dist_edge_index = [6879, 6854]
# min_dist_edge = [array([963099., 814472., 940723.]), array([962810., 813145., 940207.])]
# len_subgraphs AT END= 15
# min_dist = 3906.7998413023415
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1616, 1561]
# min_dist_edge = [array([ 900873.,  829103., 1089550.]), array([ 898340.,  830667., 1092080.])]
# len_subgraphs AT END= 14
# min_dist = 2013.8363885877125
# min_dist_subgraph_index = 2
# min_dist_edge_index = [552, 516]
# min_dist_edge = [array([ 873505.,  833319., 1102730.]), array([ 872559.,  831780., 1103620.])]
# len_subgraphs AT END= 13
# min_dist = 3909.568902065802
# min_dist_subgraph_index = 9
# min_dist_edge_index = [9350, 9359]
# min_dist_edge = [array([1013210.,  808847., 1079910.]), array([1014510.,  806570., 1082810.])]
# len_subgraphs AT END= 12
# min_dist = 4172.001917545101
# min_dist_subgraph_index = 9
# min_dist_edge_index = [9345, 9413]
# min_dist_edge = [array([1012740.,  848464.,  997568.]), array([1015160.,  849652.,  994384.])]
# len_subgraphs AT END= 11
# min_dist = 4263.989211993858
# min_dist_subgraph_index = 2
# min_dist_edge_index = [3796, 3777]
# min_dist_edge = [array([ 934369.,  485909., 1039830.]), array([ 933649.,  481711., 1040030.])]
# len_subgraphs AT END= 10
# min_dist = 4327.24219336057
# min_dist_subgraph_index = 8
# min_dist_edge_index = [9923, 10029]
# min_dist_edge = [array([1027710.,  815885., 1026950.]), array([1031330.,  816460., 1024650.])]
# len_subgraphs AT END= 9
# min_dist = 4462.793855871006
# min_dist_subgraph_index = 3
# min_dist_edge_index = [6328, 6132]
# min_dist_edge = [array([959758., 877554., 996864.]), array([958014., 879787., 993416.])]
# len_subgraphs AT END= 8
# min_dist = 4600.345747875914
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1232, 1246]
# min_dist_edge = [array([890475., 828048., 956343.]), array([890846., 830466., 952447.])]
# len_subgraphs AT END= 7
# min_dist = 5026.716423272751
# min_dist_subgraph_index = 1
# min_dist_edge_index = [3766, 3685]
# min_dist_edge = [array([ 933389.,  741571., 1099980.]), array([ 931792.,  738734., 1103810.])]
# len_subgraphs AT END= 6
# min_dist = 5485.475822569998
# min_dist_subgraph_index = 4
# min_dist_edge_index = [8949, 8978]
# min_dist_edge = [array([ 996533.,  890544., 1004220.]), array([ 998984.,  893256., 1000130.])]
# len_subgraphs AT END= 5
# min_dist = 5491.1165531246925
# min_dist_subgraph_index = 4
# min_dist_edge_index = [9943, 10043]
# min_dist_edge = [array([1028260.,  788055., 1073170.]), array([1032050.,  785686., 1076360.])]
# len_subgraphs AT END= 4
# min_dist = 5750.030086877807
# min_dist_subgraph_index = 3
# min_dist_edge_index = [8630, 8553]
# min_dist_edge = [array([ 986146.,  891462., 1064350.]), array([ 985071.,  897101., 1064680.])]
# len_subgraphs AT END= 3
# min_dist = 6071.309990438637
# min_dist_subgraph_index = 1
# min_dist_edge_index = [4403, 4516]
# min_dist_edge = [array([944149., 807115., 983423.]), array([946054., 808219., 977765.])]
# len_subgraphs AT END= 2
# min_dist = 6833.360739782439
# min_dist_subgraph_index = 1
# min_dist_edge_index = [8104, 8277]
# min_dist_edge = [array([ 977641.,  833595., 1005330.]), array([981158., 834594., 999557.])]
# len_subgraphs AT END= 1

# %%
unique_skeleton_verts = total_edges_stitched.reshape(-1,3)
edges = np.arange(0,len(unique_skeleton_verts)).astype("int").reshape(-1,2)

# %%
import ipyvolume as ipv
ipv.figure()
# we draw the tetrahedron
original_mesh = trimesh.load_mesh("temp/neuron_96631955273149705_decimated_bac.off")


mesh = ipv.plot_trisurf(original_mesh.vertices[:,0], 
                        original_mesh.vertices[:,1],
                        original_mesh.vertices[:,2], 
                        triangles=original_mesh.faces, color='orange')

mesh.color = [0., 1., 0., 0.5]
mesh.material.transparent = True
# and also mark the vertices
mesh2 = ipv.plot_trisurf(unique_skeleton_verts[:,0], 
                        unique_skeleton_verts[:,1], 
                        unique_skeleton_verts[:,2], 
                        lines=edges, color='blue')

volume_maxs = np.max(original_mesh.vertices,axis=0)
volume_mins = np.min(original_mesh.vertices,axis=0)
ranges = volume_maxs - volume_mins
index = [0,1,2]
max_index = np.argmax(ranges)
min_limits = [0,0,0]
max_limits = [0,0,0]

buffer = 10000
for i in index:
    if i == max_index:
        min_limits[i] = volume_mins[i] - buffer
        max_limits[i] = volume_maxs[i] + buffer 
        continue
    else:
        difference = ranges[max_index] - ranges[i]
        min_limits[i] = volume_mins[i] - difference/2  - buffer
        max_limits[i] = volume_maxs[i] + difference/2 + buffer

#ipv.xyzlim(-2, 2)
ipv.xlim(min_limits[0],max_limits[0])
ipv.ylim(min_limits[1],max_limits[1])
ipv.zlim(min_limits[2],max_limits[2])
ipv.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %% [markdown]
# # Saving Data for offline visualization

# %%
np.savez("96631955273149705_neuron_1_visualizations.npz",
        original_mesh_verts = original_mesh.vertices,
        original_mesh_faces = original_mesh.faces,
        unique_skeleton_verts = unique_skeleton_verts,
        edges=edges)

# %% [markdown]
# # Offline Visualization

# %%
import ipyvolume as ipv
import numpy as np
ipv.figure()
# we draw the tetrahedron
original_mesh = trimesh.load_mesh("temp/neuron_96631955273149705_decimated_bac.off")


mesh = ipv.plot_trisurf(original_mesh.vertices[:,0], 
                        original_mesh.vertices[:,1],
                        original_mesh.vertices[:,2], 
                        triangles=original_mesh.faces, color='orange')

mesh.color = [0., 1., 0., 0.5]
mesh.material.transparent = True
# and also mark the vertices
mesh2 = ipv.plot_trisurf(unique_skeleton_verts[:,0], 
                        unique_skeleton_verts[:,1], 
                        unique_skeleton_verts[:,2], 
                        lines=edges, color='blue')

volume_maxs = np.max(original_mesh.vertices,axis=0)
volume_mins = np.min(original_mesh.vertices,axis=0)
ranges = volume_maxs - volume_mins
index = [0,1,2]
max_index = np.argmax(ranges)
min_limits = [0,0,0]
max_limits = [0,0,0]

buffer = 10000
for i in index:
    if i == max_index:
        min_limits[i] = volume_mins[i] - buffer
        max_limits[i] = volume_maxs[i] + buffer 
        continue
    else:
        difference = ranges[max_index] - ranges[i]
        min_limits[i] = volume_mins[i] - difference/2  - buffer
        max_limits[i] = volume_maxs[i] + difference/2 + buffer

#ipv.xyzlim(-2, 2)
ipv.xlim(min_limits[0],max_limits[0])
ipv.ylim(min_limits[1],max_limits[1])
ipv.zlim(min_limits[2],max_limits[2])
ipv.show()
