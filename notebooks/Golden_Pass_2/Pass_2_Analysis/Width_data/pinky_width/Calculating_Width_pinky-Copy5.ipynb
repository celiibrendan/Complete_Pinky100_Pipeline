# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import os
import datetime
import trimesh as trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    

def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""
# Out:
# '\nKeysource = \na. All orphan dendritic components of significant length that have a filtered skeleton\nb. All excitatory dendritic components of significant length that have a filtered skeleton\n'

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> pinky.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (pinky.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & pinky.FilteredNeuronSkeleton()).proj() 
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Trimesh()
            mesh.vertices = vertices_whole
            mesh.faces = triangles_whole
            
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346342801155: Dendrite-0
# Component found in Orphans
# len of vertices = 55287
# Step 1: extracted Soma Mesh = 4.691295862197876
# Mesh successfully extracted
# Total time = 5.482646465301514
#
#
# 648518346342802390: Dendrite-0
# Component found in Orphans
# len of vertices = 82278
# Step 1: extracted Soma Mesh = 3.3168232440948486
# Mesh successfully extracted
# Total time = 5.409771680831909
#
#
# 648518346342803877: Dendrite-0
# Component found in Orphans
# len of vertices = 18356
# Step 1: extracted Soma Mesh = 1.1219062805175781
# Mesh successfully extracted
# Total time = 2.2386772632598877
#
#
# 648518346342804152: Dendrite-0
# Component found in Orphans
# len of vertices = 24810
# Step 1: extracted Soma Mesh = 1.0380363464355469
# Mesh successfully extracted
# Total time = 1.503753662109375
#
#
# 648518346342804481: Dendrite-0
# Component found in Orphans
# len of vertices = 34841
# Step 1: extracted Soma Mesh = 1.258786678314209
# Mesh successfully extracted
# Total time = 1.8565397262573242
#
#
# 648518346342805163: Dendrite-0
# Component found in Orphans
# len of vertices = 14275
# Step 1: extracted Soma Mesh = 0.9307453632354736
# Mesh successfully extracted
# Total time = 1.3121614456176758
#
#
# 648518346342805465: Dendrite-0
# Component found in Orphans
# len of vertices = 38253
# Step 1: extracted Soma Mesh = 1.5374343395233154
# Mesh successfully extracted
# Total time = 2.6403145790100098
#
#
# 648518346342806337: Dendrite-0
# Component found in Orphans
# len of vertices = 33840
# Step 1: extracted Soma Mesh = 2.715094804763794
# Mesh successfully extracted
# Total time = 4.0614094734191895
#
#
# 648518346342806991: Dendrite-0
# Component found in Orphans
# len of vertices = 22190
# Step 1: extracted Soma Mesh = 1.1428468227386475
# Mesh successfully extracted
# Total time = 1.6835706233978271
#
#
# 648518346342807745: Dendrite-0
# Component found in Orphans
# len of vertices = 47059
# Step 1: extracted Soma Mesh = 4.365482330322266
# Mesh successfully extracted
# Total time = 5.815039873123169
#
#
# 648518346342807789: Basal-0
# Component found in Orphans
# len of vertices = 46477
# Step 1: extracted Soma Mesh = 1.7256989479064941
# Mesh successfully extracted
# Total time = 2.3113527297973633
#
#
# 648518346342807971: Dendrite-0
# Component found in Orphans
# len of vertices = 19279
# Step 1: extracted Soma Mesh = 1.075998067855835
# Mesh successfully extracted
# Total time = 1.593698501586914
#
#
# 648518346342808119: Dendrite-0
# Component found in Orphans
# len of vertices = 17213
# Step 1: extracted Soma Mesh = 1.049607276916504
# Mesh successfully extracted
# Total time = 1.5561037063598633
#
#
# 648518346342808743: Dendrite-0
# Component found in Orphans
# len of vertices = 76736
# Step 1: extracted Soma Mesh = 2.219552516937256
# Mesh successfully extracted
# Total time = 3.07593035697937
#
#
# 648518346342916316: Dendrite-0
# Component found in Orphans
# len of vertices = 26915
# Step 1: extracted Soma Mesh = 1.9966285228729248
# Mesh successfully extracted
# Total time = 2.7073376178741455
#
#
# 648518346342917593: Dendrite-0
# Component found in Orphans
# len of vertices = 26975
# Step 1: extracted Soma Mesh = 1.1055796146392822
# Mesh successfully extracted
# Total time = 1.65207839012146
#
#
# 648518346342918961: Dendrite-0
# Component found in Orphans
# len of vertices = 64169
# Step 1: extracted Soma Mesh = 2.498234272003174
# Mesh successfully extracted
# Total time = 3.3126626014709473
#
#
# 648518346342919879: Dendrite-0
# Component found in Orphans
# len of vertices = 25760
# Step 1: extracted Soma Mesh = 1.5348007678985596
# Mesh successfully extracted
# Total time = 3.043059825897217
#
#
# 648518346342922006: Dendrite-0
# Component found in Orphans
# len of vertices = 39830
# Step 1: extracted Soma Mesh = 2.6291940212249756
# Mesh successfully extracted
# Total time = 3.8905043601989746
#
#
# 648518346342926748: Dendrite-0
# Component found in Orphans
# len of vertices = 37131
# Step 1: extracted Soma Mesh = 1.5403728485107422
# Mesh successfully extracted
# Total time = 2.2642788887023926
#
#
# 648518346342929283: Dendrite-0
# Component found in Orphans
# len of vertices = 57409
# Step 1: extracted Soma Mesh = 2.5833206176757812
# Mesh successfully extracted
# Total time = 3.144343614578247
#
#
# 648518346342932609: Dendrite-0
# Component found in Orphans
# len of vertices = 25052
# Step 1: extracted Soma Mesh = 1.553018569946289
# Mesh successfully extracted
# Total time = 2.1467173099517822
#
#
# 648518346342935565: Dendrite-0
# Component found in Orphans
# len of vertices = 17115
# Step 1: extracted Soma Mesh = 1.1430127620697021
# Mesh successfully extracted
# Total time = 1.5396127700805664
#
#
# 648518346343454272: Dendrite-0
# Component found in Orphans
# len of vertices = 11769
# Step 1: extracted Soma Mesh = 0.8314218521118164
# Mesh successfully extracted
# Total time = 1.3640568256378174
#
#
# 648518346343786119: Dendrite-0
# Component found in Orphans
# len of vertices = 13138
# Step 1: extracted Soma Mesh = 0.8665158748626709
# Mesh successfully extracted
# Total time = 1.2295842170715332
#
#
# 648518346344072795: Dendrite-0
# Component found in Orphans
# len of vertices = 18597
# Step 1: extracted Soma Mesh = 1.448206901550293
# Mesh successfully extracted
# Total time = 2.248629570007324
#
#
# 648518346344072981: Dendrite-0
# Component found in Orphans
# len of vertices = 13502
# Step 1: extracted Soma Mesh = 0.8271849155426025
# Mesh successfully extracted
# Total time = 1.292818546295166
#
#
# 648518346344079907: Dendrite-0
# Component found in Orphans
# len of vertices = 10401
# Step 1: extracted Soma Mesh = 0.8158628940582275
# Mesh successfully extracted
# Total time = 1.3053803443908691
#
#
# 648518346344081602: Dendrite-0
# Component found in Orphans
# len of vertices = 11353
# Step 1: extracted Soma Mesh = 0.9183549880981445
# Mesh successfully extracted
# Total time = 1.289888620376587
#
#
# 648518346344140814: Dendrite-0
# Component found in Orphans
# len of vertices = 10737
# Step 1: extracted Soma Mesh = 0.829120397567749
# Mesh successfully extracted
# Total time = 1.1286380290985107
#
#
# 648518346344419150: Dendrite-0
# Component found in Orphans
# len of vertices = 26559
# Step 1: extracted Soma Mesh = 1.044039011001587
# Mesh successfully extracted
# Total time = 1.45509672164917
#
#
# 648518346344456499: Dendrite-0
# Component found in Orphans
# len of vertices = 12754
# Step 1: extracted Soma Mesh = 0.7840325832366943
# Mesh successfully extracted
# Total time = 1.1698076725006104
#
#
# 648518346344462185: Dendrite-0
# Component found in Orphans
# len of vertices = 20360
# Step 1: extracted Soma Mesh = 0.9183824062347412
# Mesh successfully extracted
# Total time = 1.3239035606384277
#
#
# 648518346344499416: Dendrite-0
# Component found in Orphans
# len of vertices = 28488
# Step 1: extracted Soma Mesh = 1.0692284107208252
# Mesh successfully extracted
# Total time = 1.6260454654693604
#
#
# 648518346344506020: Dendrite-0
# Component found in Orphans
# len of vertices = 10617
# Step 1: extracted Soma Mesh = 0.8160123825073242
# Mesh successfully extracted
# Total time = 1.1857988834381104
#
#
# 648518346344517531: Dendrite-0
# Component found in Orphans
# len of vertices = 33468
# Step 1: extracted Soma Mesh = 1.1343023777008057
# Mesh successfully extracted
# Total time = 1.5792484283447266
#
#
# 648518346345768000: Dendrite-0
# Component found in Orphans
# len of vertices = 11985
# Step 1: extracted Soma Mesh = 0.7940595149993896
# Mesh successfully extracted
# Total time = 1.1252152919769287
#
#
# 648518346345770568: Dendrite-0
# Component found in Orphans
# len of vertices = 24274
# Step 1: extracted Soma Mesh = 0.9615466594696045
# Mesh successfully extracted
# Total time = 1.3409771919250488
#
#
# 648518346345880323: Dendrite-0
# Component found in Orphans
# len of vertices = 10206
# Step 1: extracted Soma Mesh = 0.7760493755340576
# Mesh successfully extracted
# Total time = 1.1376371383666992
#
#
# 648518346346296124: Dendrite-0
# Component found in Orphans
# len of vertices = 37525
# Step 1: extracted Soma Mesh = 1.4061212539672852
# Mesh successfully extracted
# Total time = 2.417132616043091
#
#
# 648518346346300777: Dendrite-0
# Component found in Orphans
# len of vertices = 83687
# Step 1: extracted Soma Mesh = 2.1924283504486084
# Mesh successfully extracted
# Total time = 3.8257343769073486
#
#
# 648518346346307118: Dendrite-0
# Component found in Orphans
# len of vertices = 25844
# Step 1: extracted Soma Mesh = 1.2229948043823242
# Mesh successfully extracted
# Total time = 1.6636383533477783
#
#
# 648518346346314148: Dendrite-0
# Component found in Orphans
# len of vertices = 22383
# Step 1: extracted Soma Mesh = 1.2507977485656738
# Mesh successfully extracted
# Total time = 1.8107693195343018
#
#
# 648518346346584676: Dendrite-0
# Component found in Orphans
# len of vertices = 31415
# Step 1: extracted Soma Mesh = 1.26558518409729
# Mesh successfully extracted
# Total time = 1.763059139251709
#
#
# 648518346347001492: Dendrite-0
# Component found in Orphans
# len of vertices = 10984
# Step 1: extracted Soma Mesh = 0.979788064956665
# Mesh successfully extracted
# Total time = 1.4272270202636719
#
#
# 648518346348119340: Dendrite-0
# Component found in Orphans
# len of vertices = 14137
# Step 1: extracted Soma Mesh = 1.1023542881011963
# Mesh successfully extracted
# Total time = 1.8145644664764404
#
#
# 648518346348191367: Dendrite-0
# Component found in Orphans
# len of vertices = 14808
# Step 1: extracted Soma Mesh = 1.092824935913086
# Mesh successfully extracted
# Total time = 1.7774851322174072
#
#
# 648518346348199139: Dendrite-0
# Component found in Orphans
# len of vertices = 18302
# Step 1: extracted Soma Mesh = 1.1661548614501953
# Mesh successfully extracted
# Total time = 1.5939862728118896
#
#
# 648518346348206299: Dendrite-0
# Component found in Orphans
# len of vertices = 24866
# Step 1: extracted Soma Mesh = 1.34071946144104
# Mesh successfully extracted
# Total time = 1.8240878582000732
#
#
# 648518346348463462: Dendrite-0
# Component found in Orphans
# len of vertices = 12876
# Step 1: extracted Soma Mesh = 0.963810920715332
# Mesh successfully extracted
# Total time = 1.4561138153076172
#
#
# 648518346349369491: Dendrite-0
# Component found in Orphans
# len of vertices = 32308
# Step 1: extracted Soma Mesh = 1.177863359451294
# Mesh successfully extracted
# Total time = 1.7171175479888916
#
#
# 648518346349375068: Dendrite-0
# Component found in Orphans
# len of vertices = 16731
# Step 1: extracted Soma Mesh = 0.9391460418701172
# Mesh successfully extracted
# Total time = 1.3793907165527344
#
#
# 648518346349378042: Dendrite-0
# Component found in Orphans
# len of vertices = 31076
# Step 1: extracted Soma Mesh = 1.3276252746582031
# Mesh successfully extracted
# Total time = 1.9622769355773926
#
#
# 648518346349384659: Dendrite-0
# Component found in Orphans
# len of vertices = 11526
# Step 1: extracted Soma Mesh = 1.1554384231567383
# Mesh successfully extracted
# Total time = 1.894350528717041
#
#
# 648518346349387039: Dendrite-0
# Component found in Orphans
# len of vertices = 32933
# Step 1: extracted Soma Mesh = 1.4004883766174316
# Mesh successfully extracted
# Total time = 1.9478917121887207
#
#
# 648518346349469130: Dendrite-0
# Component found in Orphans
# len of vertices = 18053
# Step 1: extracted Soma Mesh = 2.1088902950286865
# Mesh successfully extracted
# Total time = 2.994770050048828
#
#
# 648518346349475163: Basal-0
# Component found in Orphans
# len of vertices = 14737
# Step 1: extracted Soma Mesh = 2.40374493598938
# Mesh successfully extracted
# Total time = 3.088683843612671
#
#
# 648518346349477155: Apical-0
# Component found in Orphans
# len of vertices = 133162
# Step 1: extracted Soma Mesh = 14.824288129806519
# Mesh successfully extracted
# Total time = 16.731127977371216
#
#
# 648518346349494371: Dendrite-0
# Component found in Orphans
# len of vertices = 34327
# Step 1: extracted Soma Mesh = 1.8904223442077637
# Mesh successfully extracted
# Total time = 3.0462453365325928
#
#
# 648518346349494801: Oblique-0
# Component found in Orphans
# len of vertices = 42515
# Step 1: extracted Soma Mesh = 11.399803400039673
# Mesh successfully extracted
# Total time = 14.248198747634888
#
#
# 648518346349506970: Dendrite-0
# Component found in Orphans
# len of vertices = 17367
# Step 1: extracted Soma Mesh = 3.1432950496673584
# Mesh successfully extracted
# Total time = 6.091495990753174
#
#
# 648518346349508581: Dendrite-0
# Component found in Orphans
# len of vertices = 18557
# Step 1: extracted Soma Mesh = 2.8850502967834473
# Mesh successfully extracted
# Total time = 3.746212959289551
#
#
# 648518346349508673: Dendrite-0
# Component found in Orphans
# len of vertices = 13509
# Step 1: extracted Soma Mesh = 1.2713096141815186
# Mesh successfully extracted
# Total time = 1.7120561599731445
#
#
# 648518346349508870: Dendrite-0
# Component found in Orphans
# len of vertices = 57856
# Step 1: extracted Soma Mesh = 1.5399384498596191
# Mesh successfully extracted
# Total time = 2.1461870670318604
#
#
# 648518346349509415: Basal-0
# Component found in Orphans
# len of vertices = 116609
# Step 1: extracted Soma Mesh = 6.586595773696899
# Mesh successfully extracted
# Total time = 10.342894554138184
#
#
# 648518346349509557: Dendrite-0
# Component found in Orphans
# len of vertices = 47780
# Step 1: extracted Soma Mesh = 3.247466564178467
# Mesh successfully extracted
# Total time = 3.9466471672058105
#
#
# 648518346349509560: Dendrite-0
# Component found in Orphans
# len of vertices = 63609
# Step 1: extracted Soma Mesh = 1.8050940036773682
# Mesh successfully extracted
# Total time = 2.3849732875823975
#
#
# 648518346349509594: Dendrite-0
# Component found in Orphans
# len of vertices = 11189
# Step 1: extracted Soma Mesh = 0.8059985637664795
# Mesh successfully extracted
# Total time = 1.1443896293640137
#
#
# 648518346349511899: Basal-0
# Component found in Orphans
# len of vertices = 37114
# Step 1: extracted Soma Mesh = 1.6175243854522705
# Mesh successfully extracted
# Total time = 2.2346389293670654
# Total time = 287.77395582199097
