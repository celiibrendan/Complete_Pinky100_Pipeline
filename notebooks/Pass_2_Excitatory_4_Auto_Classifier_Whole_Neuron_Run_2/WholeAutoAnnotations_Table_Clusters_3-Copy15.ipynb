# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349497151******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09157514572143555
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 962.624746799469
# 2) Finished: Generating CGAL segmentation for neuron: 982.2533226013184
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2387409210205078
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [25, 44, 6, 14, 23, 2, 16, 28, 31, 32, 50, 54]
# soma_80_percent = 244563.2140625
# Debugging the axon filter
# [(25, 263924.125), (44, 241707.15625), (6, 241178.71875), (14, 263275.15625), (23, 259311.921875), (2, 270026.0), (16, 249464.59375), (28, 253618.71875), (31, 241719.625), (32, 241582.796875), (50, 250061.125), (54, 249726.78125)]
# possible_Axons_filter_1 = [44, 6, 31, 32]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.0790872573852539
# 6) Staring: Classifying Entire Neuron
# 25 = axon
# 31 = stub soma
# 32 = cilia
# 44 = stub soma
# 50 = stub soma
# 54 = stub soma
# 24 = stub apical
# 26 = stub apical
# 29 = stub apical
# 34 = stub apical
# 40 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = stub apical
# 53 = stub apical
# 55 = stub apical
# 58 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 68 = stub apical
# Total Labels found = {'axon', 'oblique', 'basal', 'soma', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.6529202461242676
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4358639717102051
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.047911167144775
# Finished Auto Labeling: 997.5830864906311
#
#
# *****Starting Auto Labeling for 648518346349499851******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07372045516967773
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1337.9233133792877
# 2) Finished: Generating CGAL segmentation for neuron: 1362.2937684059143
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2986011505126953
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [15, 42, 9, 16, 5, 3, 109, 98, 1, 123]
# soma_80_percent = 186232.7234375
# Debugging the axon filter
# [(15, 214103.25), (42, 186710.40625), (9, 200853.375), (16, 191402.796875), (5, 190792.34375), (3, 215395.1875), (109, 184428.078125), (98, 197008.265625), (1, 181719.28125), (123, 183878.859375)]
# possible_Axons_filter_1 = [109, 1, 123]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.09307432174682617
# 6) Staring: Classifying Entire Neuron
# 109 = cilia
# 98 = stub soma
# 123 = stub soma
# 17 = stub apical
# 27 = stub apical
# 29 = stub apical
# 36 = stub apical
# 40 = stub apical
# 44 = error
# 45 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 63 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 77 = stub apical
# 79 = stub apical
# 82 = stub apical
# 83 = stub apical
# 88 = stub apical
# 95 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 105 = stub apical
# 106 = stub apical
# 116 = stub apical
# 118 = stub apical
# 119 = stub apical
# 124 = stub apical
# Total Labels found = {'oblique', 'basal', 'soma', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.487245798110962
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.7097525596618652
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.470070600509644
# Finished Auto Labeling: 1382.2340729236603
#
#
# *****Starting Auto Labeling for 648518346349502203******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.057596683502197266
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 699.5872931480408
# 2) Finished: Generating CGAL segmentation for neuron: 716.976678609848
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.20984101295471191
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [0, 101, 17, 32, 23, 48, 84, 10, 63, 118, 114, 83, 109, 65, 100, 111, 98, 113]
# soma_80_percent = 253756.815625
# Debugging the axon filter
# [(0, 263691.9375), (101, 252277.140625), (17, 249228.625), (32, 261169.203125), (23, 277584.4375), (48, 256154.96875), (84, 264279.0625), (10, 271198.6875), (63, 252640.421875), (118, 256670.015625), (114, 252483.203125), (83, 265872.1875), (109, 250706.4375), (65, 251367.234375), (100, 251831.640625), (111, 253428.8125), (98, 256830.46875), (113, 252441.953125)]
# possible_Axons_filter_1 = [101, 17, 63, 114, 109, 65, 100, 111, 113]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.09665775299072266
# 6) Staring: Classifying Entire Neuron
# 10 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 63
# 65 = stub soma
# 83 = stub soma
# 98 = stub soma
# 100 = stub soma
# 101 = cilia
# 109 = stub soma
# 111 = stub soma
# 114 = stub soma
# 113 = stub soma
# 118 = stub soma
# 22 = stub apical
# 24 = stub apical
# 28 = stub apical
# 29 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 64 = stub apical
# 67 = stub apical
# 68 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 81 = stub apical
# 82 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 96 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 119 = stub apical
# 120 = stub apical
# 122 = stub apical
# 123 = stub apical
# Total Labels found = {'axon', 'oblique', 'basal', 'soma', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.9585034847259521
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.41863155364990234
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.804816007614136
# Finished Auto Labeling: 729.1220154762268
#
#
# *****Starting Auto Labeling for 648518346349504521******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07784008979797363
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1385.766316652298
# 2) Finished: Generating CGAL segmentation for neuron: 1409.8708457946777
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3078937530517578
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [34, 20, 31, 257, 6, 9, 143, 390, 108]
# soma_80_percent = 262887.9046875
# Debugging the axon filter
# [(34, 279371.78125), (20, 284031.03125), (31, 271359.4375), (257, 268388.96875), (6, 258896.46875), (9, 277291.59375), (143, 281972.09375), (390, 268614.96875), (108, 260399.625)]
# possible_Axons_filter_1 = [6, 108]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.15328073501586914
# 6) Staring: Classifying Entire Neuron
# 143 = axon
# 108 = cilia
# 257 = stub soma
# 390 = stub soma
# 10 = stub apical
# 14 = error
# 17 = error
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 32 = stub apical
# 33 = error
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = error
# 49 = stub apical
# 50 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = error
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 75 = stub apical
# 77 = stub apical
# 79 = error
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 98 = stub apical
# 99 = error
# 100 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 110 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 118 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 310 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 338 = error
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 367 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# Total Labels found = {'axon', 'oblique', 'basal', 'soma', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.1307942867279053
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5525426864624023
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.590474367141724
# Finished Auto Labeling: 1428.6416366100311
#
#
# *****Starting Auto Labeling for 648518346349506803******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03630208969116211
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 311.4276325702667
# 2) Finished: Generating CGAL segmentation for neuron: 321.5431594848633
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.12625360488891602
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [27, 18, 11, 5, 19, 10, 22, 13, 29, 20, 16, 23, 30, 28, 25, 24]
# soma_80_percent = 174095.1359375
# Debugging the axon filter
# [(27, 179203.09375), (18, 179336.96875), (11, 183047.015625), (5, 177771.234375), (19, 180525.84375), (10, 171342.765625), (22, 184591.96875), (13, 181799.90625), (29, 173917.1875), (20, 188030.84375), (16, 191135.890625), (23, 184430.484375), (30, 170368.25), (28, 180176.21875), (25, 181674.59375), (24, 184003.484375)]
# possible_Axons_filter_1 = [10, 29, 30]
# possible_Axons_filter_2 = [10]
# possible_Apical = 10
# 5) Finished: Finding Apical Index: 0.0356595516204834
# 6) Staring: Classifying Entire Neuron
# 20 = axon
# 18 = stub soma
# 24 = stub soma
# 25 = stub soma
# 27 = stub soma
# 28 = stub soma
# 29 = stub soma
# 30 = stub soma
# 2 = error
# 14 = error
# 21 = stub apical
# Total Labels found = {'axon', 'basal', 'soma', 'error', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.7766244411468506
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3576619625091553
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.609267234802246
# Finished Auto Labeling: 329.8636009693146
#
#
# *****Starting Auto Labeling for 648518346349507351******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.053647756576538086
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 543.6396925449371
# 2) Finished: Generating CGAL segmentation for neuron: 557.6266179084778
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.18131637573242188
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [0, 352, 8, 353, 35, 11, 247, 299, 164, 326, 16]
# soma_80_percent = 289923.08125
# Debugging the axon filter
# [(0, 286189.0625), (352, 297074.875), (8, 311534.5625), (353, 287561.59375), (35, 306717.1875), (11, 289260.0625), (247, 298063.96875), (299, 289830.125), (164, 298391.3125), (326, 292018.75), (16, 296024.125)]
# possible_Axons_filter_1 = [0, 353, 11, 299]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.11284446716308594
# 6) Staring: Classifying Entire Neuron
# 16 = stub soma
# 353 = cilia
# 164 = stub soma
# 299 = stub soma
# 326 = stub soma
# 352 = stub soma
# 9 = stub apical
# 14 = stub apical
# 17 = stub apical
# 18 = stub apical
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = error
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = error
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = error
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 114 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = error
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 142 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 194 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# Total Labels found = {'oblique', 'basal', 'soma', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.9636409282684326
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3129913806915283
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.992052316665649
# Finished Auto Labeling: 568.7207238674164
#
#
# *****Starting Auto Labeling for 648518346349509347******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0059278011322021484
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 14.66632342338562
# 2) Finished: Generating CGAL segmentation for neuron: 15.72282338142395
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.01245880126953125
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 5, 2, 33, 10, 34, 9, 36, 8, 35]
# soma_80_percent = 233894.6109375
# Debugging the axon filter
# [(0, 243397.609375), (5, 234856.34375), (2, 244480.203125), (33, 240623.75), (10, 242200.734375), (34, 235315.640625), (9, 242249.90625), (36, 236518.171875), (8, 241994.859375), (35, 233750.96875)]
# possible_Axons_filter_1 = [35]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.011776924133300781
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 5
# 8 = stub soma
# 9 = stub soma
# 10 = stub soma
# 33 = stub soma
# 34 = stub soma
# 35 = stub soma
# 36 = stub soma
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 0.28533005714416504
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.08878660202026367
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 0.45265960693359375
# Finished Auto Labeling: 16.62896203994751
#
#
# *****Starting Auto Labeling for 648518346349509378******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.027641773223876953
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 253.36778330802917
# 2) Finished: Generating CGAL segmentation for neuron: 262.92219161987305
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.11070632934570312
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [14, 1, 9, 70, 38, 5, 11, 19, 56, 31, 66, 30]
# soma_80_percent = 179722.7515625
# Debugging the axon filter
# [(14, 178715.78125), (1, 189441.234375), (9, 176627.84375), (70, 188012.609375), (38, 178123.0625), (5, 186285.96875), (11, 200489.84375), (19, 199639.65625), (56, 180203.5), (31, 177848.875), (66, 188831.765625), (30, 177768.0)]
# possible_Axons_filter_1 = [14, 9, 38, 31, 30]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.0410761833190918
# 6) Staring: Classifying Entire Neuron
# 30 = stub soma
# 31 = cilia
# 38 = stub soma
# 56 = stub soma
# 66 = stub soma
# 70 = stub soma
# 15 = stub apical
# 24 = error
# 27 = stub apical
# 33 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 54 = stub apical
# 55 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# Total Labels found = {'oblique', 'basal', 'soma', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.4715797901153564
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.25305795669555664
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.917114734649658
# Finished Auto Labeling: 270.0410158634186
#
#
# *****Starting Auto Labeling for 648518346349509855******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03429722785949707
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 300.01968598365784
# 2) Finished: Generating CGAL segmentation for neuron: 310.2855393886566
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.12096571922302246
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [4, 0, 23, 22, 9, 8, 38, 42, 37]
# soma_80_percent = 207286.865625
# Debugging the axon filter
# [(4, 218168.1875), (0, 217209.125), (23, 226959.578125), (22, 226697.390625), (9, 203635.953125), (8, 207220.625), (38, 220090.671875), (42, 215387.859375), (37, 203830.4375)]
# possible_Axons_filter_1 = [9, 8, 37]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.0389249324798584
# 6) Staring: Classifying Entire Neuron
# 22 = axon
# 37 = stub soma
# 38 = stub soma
# 42 = stub soma
# 18 = error
# 19 = error
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 35 = stub apical
# 36 = stub apical
# Total Labels found = {'axon', 'oblique', 'basal', 'soma', 'error', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.1149320602416992
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.2614731788635254
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.745757818222046
# Finished Auto Labeling: 317.94161891937256
#
#
# *****Starting Auto Labeling for 648518346349511382******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04009842872619629
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 465.8069086074829
# 2) Finished: Generating CGAL segmentation for neuron: 478.8859248161316
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.15723013877868652
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [17, 47, 1, 14, 11, 20, 13, 35, 12, 40, 28, 23, 29]
# soma_80_percent = 270108.76875
# Debugging the axon filter
# [(17, 276227.5625), (47, 268321.375), (1, 279683.0), (14, 266716.5625), (11, 272083.6875), (20, 269116.53125), (13, 279808.78125), (35, 269971.65625), (12, 294933.78125), (40, 272235.9375), (28, 278514.0), (23, 291900.15625), (29, 278373.28125)]
# possible_Axons_filter_1 = [47, 14, 20, 35]
# possible_Axons_filter_2 = [14, 20]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.06325697898864746
# 6) Staring: Classifying Entire Neuron
# 13 = axon
# 23 = axon
# 28 = cilia
# 29 = stub soma
# 35 = stub soma
# 40 = stub soma
# 47 = stub soma
# 46 = stub apical
# 50 = stub apical
# 53 = stub apical
# 54 = stub apical
# Total Labels found = {'axon', 'oblique', 'basal', 'soma', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.4524385929107666
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.32190537452697754
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.091952800750732
# Finished Auto Labeling: 488.44385385513306
#
#
# *****Starting Auto Labeling for 648518346349513012******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.037766456604003906
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 479.88600611686707
# 2) Finished: Generating CGAL segmentation for neuron: 493.56947207450867
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19398999214172363
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [3, 22, 8, 10, 119, 156, 14, 692, 187, 9, 927, 722, 564]
# soma_80_percent = 255613.903125
# Debugging the axon filter
# [(3, 294414.90625), (22, 251084.40625), (8, 273398.96875), (10, 285195.3125), (119, 259193.046875), (156, 255432.890625), (14, 273528.40625), (692, 258662.46875), (187, 265218.1875), (9, 290786.5625), (927, 264147.5625), (722, 267502.28125), (564, 253064.84375)]
# possible_Axons_filter_1 = [22, 156, 564]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.1383833885192871
# 6) Staring: Classifying Entire Neuron
# 156 = error
# 564 = stub soma
# 692 = stub soma
# 722 = stub soma
# 927 = stub soma
# Total Labels found = {'error', 'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 2.155923843383789
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6448113918304443
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.650505781173706
# Finished Auto Labeling: 505.19155836105347
# 7037.069530010223

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
