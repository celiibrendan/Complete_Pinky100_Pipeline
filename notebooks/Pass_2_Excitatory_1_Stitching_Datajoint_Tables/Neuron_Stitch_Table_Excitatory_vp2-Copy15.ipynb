# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473833**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 852 pieces after mesh split
# There were 45 pieces found after size threshold
# max_index = 0
# max_face_len = 994865
# Total time for Mesh Cleansing: 51.196404457092285
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9907267344302847% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349474146**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349474146_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.452117443084717
# Number of outside child meshes =  13
# Main mesh and outside child meshes make up 0.9368818713068637% of original mesh
#  face length 2685244 using optimized facets with 3 neighbors
# Filtering edges by size finished: 57.90936827659607, facet # = 138958
# Filtering by convexity and getting centers took: 93.80264282226562, facet # = 30115
# Finished facets for main mesh: 158.3313112258911 with facet length = 30115
# Finished 30115 facets for main mesh: 158.33143782615662
# Filtering edges by size finished: 0.7461926937103271, facet # = 2769
# Filtering by convexity and getting centers took: 1.4162015914916992, facet # = 892
# Filtering edges by size finished: 0.3845486640930176, facet # = 1285
# Filtering by convexity and getting centers took: 0.6067206859588623, facet # = 371
# Filtering edges by size finished: 0.02379775047302246, facet # = 69
# Filtering by convexity and getting centers took: 0.03231358528137207, facet # = 20
# Filtering edges by size finished: 0.16664624214172363, facet # = 693
# Filtering by convexity and getting centers took: 0.5328629016876221, facet # = 213
# Filtering edges by size finished: 0.7532558441162109, facet # = 1646
# Filtering by convexity and getting centers took: 1.1316521167755127, facet # = 485
# Filtering edges by size finished: 0.3668944835662842, facet # = 893
# Filtering by convexity and getting centers took: 0.4979424476623535, facet # = 203
# Filtering edges by size finished: 0.05864429473876953, facet # = 267
# Filtering by convexity and getting centers took: 0.10182356834411621, facet # = 86
# Filtering edges by size finished: 0.012613773345947266, facet # = 54
# Filtering by convexity and getting centers took: 0.028855085372924805, facet # = 24
# Filtering edges by size finished: 0.22249770164489746, facet # = 618
# Filtering by convexity and getting centers took: 0.46976256370544434, facet # = 234
# Filtering edges by size finished: 0.033448219299316406, facet # = 34
# Filtering by convexity and getting centers took: 0.0460512638092041, facet # = 16
# Filtering edges by size finished: 0.008255720138549805, facet # = 30
# Filtering by convexity and getting centers took: 0.01837611198425293, facet # = 16
# Filtering edges by size finished: 0.11773419380187988, facet # = 362
# Filtering by convexity and getting centers took: 0.38994908332824707, facet # = 142
# Filtering edges by size finished: 0.026334047317504883, facet # = 55
# Filtering by convexity and getting centers took: 0.030160903930664062, facet # = 20
# Total time for facets: 166.71697688102722
# Zero faceted faces = []
# Starting Child 0
# 892 30115
# Done distance matrix: 1.3455007076263428
# Done Generating final pairs: 1.384667158126831
# best_stitch_pair = [  102 12821]
# best_stitch_pair_size = 155852.76402544312
# best_stitch_pair_distance = 1630.7802302188327
# best_stitch_pair_size_ratio = 0.34124029321336025
# Starting Child 1
# 371 30115
# Done distance matrix: 0.5022101402282715
# Child 1 There were no points close enough
# Starting Child 2
# 20 30115
# Done distance matrix: 0.03407645225524902
# Child 2 There were no points close enough
# Starting Child 3
# 213 30115
# Done distance matrix: 0.2640860080718994
# Done Generating final pairs: 0.29435062408447266
# best_stitch_pair = [ 143 6518]
# best_stitch_pair_size = 147435.0422641063
# best_stitch_pair_distance = 1297.7921206867657
# best_stitch_pair_size_ratio = 0.4355158553273192
# Starting Child 4
# 485 30115
# Done distance matrix: 0.7888906002044678
# Done Generating final pairs: 0.8302292823791504
# best_stitch_pair = [  458 10071]
# best_stitch_pair_size = 119167.07039806496
# best_stitch_pair_distance = 255.36990493480755
# best_stitch_pair_size_ratio = 0.8030605399649806
# Starting Child 5
# 203 30115
# Done distance matrix: 0.219970703125
# Done Generating final pairs: 0.24974536895751953
# best_stitch_pair = [ 156 3620]
# best_stitch_pair_size = 55699.644642131396
# best_stitch_pair_distance = 1791.077891115683
# best_stitch_pair_size_ratio = 0.18150884121709415
# Starting Child 6
# 86 30115
# Done distance matrix: 0.1405777931213379
# Done Generating final pairs: 0.19045257568359375
# best_stitch_pair = [   58 22931]
# best_stitch_pair_size = 285738.2277161964
# best_stitch_pair_distance = 1333.7532150925042
# best_stitch_pair_size_ratio = 0.2545100532624251
# Starting Child 7
# 24 30115
# Done distance matrix: 0.05008745193481445
# Done Generating final pairs: 0.11363387107849121
# best_stitch_pair = [    7 22614]
# best_stitch_pair_size = 111344.78256291794
# best_stitch_pair_distance = 1221.2963657966804
# best_stitch_pair_size_ratio = 0.6441699264524884
# Starting Child 8
# 234 30115
# Done distance matrix: 0.3611764907836914
# Child 8 There were no points close enough
# Starting Child 9
# 16 30115
# Done distance matrix: 0.04616665840148926
# Child 9 There were no points close enough
# Starting Child 10
# 16 30115
# Done distance matrix: 0.021084308624267578
# Done Generating final pairs: 0.046949148178100586
# best_stitch_pair = [    4 20458]
# best_stitch_pair_size = 96637.27454939416
# best_stitch_pair_distance = 493.62309176410156
# best_stitch_pair_size_ratio = 0.8092389904617805
# Starting Child 11
# 142 30115
# Done distance matrix: 0.1884162425994873
# Child 11 There were no points close enough
# Starting Child 12
# 20 30115
# Done distance matrix: 0.02448105812072754
# Done Generating final pairs: 0.056633949279785156
# best_stitch_pair = [    4 27389]
# best_stitch_pair_size = 48047.591252287515
# best_stitch_pair_distance = 1732.7647418452493
# best_stitch_pair_size_ratio = 0.34155379558147037
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [102, 12821], 3: [143, 6518], 4: [458, 10071], 5: [156, 3620], 6: [58, 22931], 7: [7, 22614], 10: [4, 20458], 12: [4, 27389]}
# ---Stitching child 0 with pair: [102, 12821]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1075510, starting edge 2nd facet= 1349921,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.8835067749023438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03992629051208496
# returned from stitch mesh: 1.878603458404541
# Finished stitching child 0 : 2.2006633281707764
# ---Stitching child 3 with pair: [143, 6518]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 957512, starting edge 2nd facet= 1357861,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 2.8848648071289062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06750726699829102
# returned from stitch mesh: 2.0220258235931396
# Finished stitching child 3 : 2.299344539642334
# ---Stitching child 4 with pair: [458, 10071]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1217764, starting edge 2nd facet= 1361922,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.193450927734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0444493293762207
# returned from stitch mesh: 2.683509349822998
# Finished stitching child 4 : 3.027672052383423
# ---Stitching child 5 with pair: [156, 3620]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1020982, starting edge 2nd facet= 1368119,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 5, remainder = 1
# About to add faces
# Finished adding faces: 3.0040740966796875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07844972610473633
# returned from stitch mesh: 2.294013261795044
# Finished stitching child 5 : 2.590197801589966
# ---Stitching child 6 with pair: [58, 22931]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 580299, starting edge 2nd facet= 1370839,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 2.1219253540039062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06719756126403809
# returned from stitch mesh: 2.4880197048187256
# Finished stitching child 6 : 2.8156917095184326
# ---Stitching child 7 with pair: [7, 22614]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 898772, starting edge 2nd facet= 1370998,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0469202995300293
# returned from stitch mesh: 2.3226940631866455
# Finished stitching child 7 : 2.6751139163970947
# ---Stitching child 10 with pair: [4, 20458]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1284027, starting edge 2nd facet= 1371056,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05978083610534668
# returned from stitch mesh: 2.1034657955169678
# Finished stitching child 10 : 2.424961805343628
# ---Stitching child 12 with pair: [4, 27389]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 529628, starting edge 2nd facet= 1371393,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12375187873840332
# returned from stitch mesh: 2.58695125579834
# Finished stitching child 12 : 3.1259663105010986
# ***************Finished big stitching iteration: 26.60221242904663***************
# Starting Child 1
# 371 32038
# Done distance matrix: 0.6804125308990479
# Done Generating final pairs: 0.7011094093322754
# best_stitch_pair = [  143 30194]
# best_stitch_pair_size = 176993.91080569607
# best_stitch_pair_distance = 474.22983365968014
# best_stitch_pair_size_ratio = 0.17472523682117538
# Starting Child 2
# 20 32038
# Done distance matrix: 0.13671112060546875
# Child 2 There were no points close enough
# Starting Child 8
# 234 32038
# Done distance matrix: 0.5201668739318848
# Done Generating final pairs: 0.5289623737335205
# best_stitch_pair = [  149 31913]
# best_stitch_pair_size = 22762.46397469256
# best_stitch_pair_distance = 1341.3282805139715
# best_stitch_pair_size_ratio = 0.6749095491089799
# Starting Child 9
# 16 32038
# Done distance matrix: 0.026615381240844727
# Done Generating final pairs: 0.029789447784423828
# best_stitch_pair = [    2 31954]
# best_stitch_pair_size = 65362.432560196605
# best_stitch_pair_distance = 967.992387956574
# best_stitch_pair_size_ratio = 0.20674953529625037
# Starting Child 11
# 142 32038
# Done distance matrix: 0.26670408248901367
# Child 11 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [143, 30194], 8: [149, 31913], 9: [2, 31954]}
# ---Stitching child 1 with pair: [143, 30194]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1355827, starting edge 2nd facet= 1376243,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 2
# About to add faces
# Finished adding faces: 3.552436828613281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05494213104248047
# returned from stitch mesh: 2.319553852081299
# Finished stitching child 1 : 2.873408079147339
# ---Stitching child 8 with pair: [149, 31913]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1370361, starting edge 2nd facet= 1377355,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.3603439331054688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07764601707458496
# returned from stitch mesh: 2.8364620208740234
# Finished stitching child 8 : 3.1563549041748047
# ---Stitching child 9 with pair: [2, 31954]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1370666, starting edge 2nd facet= 1379310,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.2411346435546875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06981086730957031
# returned from stitch mesh: 2.6497621536254883
# Finished stitching child 9 : 3.238750457763672
# ***************Finished big stitching iteration: 13.809585094451904***************
# Starting Child 2
# 20 32653
# Done distance matrix: 0.04950857162475586
# Done Generating final pairs: 0.07028698921203613
# best_stitch_pair = [   14 32229]
# best_stitch_pair_size = 31448.750196975136
# best_stitch_pair_distance = 1950.0736038098746
# best_stitch_pair_size_ratio = 0.4716072703197428
# Starting Child 11
# 142 32653
# Done distance matrix: 0.3281831741333008
# Done Generating final pairs: 0.34995579719543457
# best_stitch_pair = [    6 32565]
# best_stitch_pair_size = 211397.15305064042
# best_stitch_pair_distance = 1867.8934956792566
# best_stitch_pair_size_ratio = 0.39636886179211367
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [14, 32229], 11: [6, 32565]}
# ---Stitching child 2 with pair: [14, 32229]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1372282, starting edge 2nd facet= 1379456,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.621246337890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0849156379699707
# returned from stitch mesh: 2.5445404052734375
# Finished stitching child 2 : 2.8321986198425293
# ---Stitching child 11 with pair: [6, 32565]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1377632, starting edge 2nd facet= 1379959,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04646801948547363
# returned from stitch mesh: 3.1808438301086426
# Finished stitching child 11 : 3.564244508743286
# ***************Finished big stitching iteration: 11.306899309158325***************
# All children have been processed
# total_stitch_processing_time = 51.745654821395874
# Total time for restitching = 51.76073694229126
# missed_children = []
# Whole stitching function complete: 229.76515889167786
#
#
#
# *****Running Neuron Stitcher for 648518346349478118**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478118_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 3.897465705871582
# Number of outside child meshes =  12
# Main mesh and outside child meshes make up 0.8255349000350755% of original mesh
#  face length 1266866 using optimized facets with 3 neighbors
# Filtering edges by size finished: 37.078246116638184, facet # = 69463
# Filtering by convexity and getting centers took: 47.10248374938965, facet # = 12724
# Finished facets for main mesh: 87.17764544487 with facet length = 12724
# Finished 12724 facets for main mesh: 87.17806005477905
# Filtering edges by size finished: 0.019316434860229492, facet # = 73
# Filtering by convexity and getting centers took: 0.024200439453125, facet # = 29
# Filtering edges by size finished: 0.0010232925415039062, facet # = 8
# Filtering by convexity and getting centers took: 0.0038299560546875, facet # = 4
# Filtering edges by size finished: 0.005800962448120117, facet # = 16
# Filtering by convexity and getting centers took: 0.007911205291748047, facet # = 10
# Filtering edges by size finished: 0.00039315223693847656, facet # = 3
# Filtering by convexity and getting centers took: 0.0018935203552246094, facet # = 3
# Filtering edges by size finished: 0.005780696868896484, facet # = 15
# Filtering by convexity and getting centers took: 0.0067272186279296875, facet # = 13
# Filtering edges by size finished: 0.003970623016357422, facet # = 4
# Filtering by convexity and getting centers took: 0.0036902427673339844, facet # = 4
# Filtering edges by size finished: 0.06355738639831543, facet # = 155
# Filtering by convexity and getting centers took: 0.17589449882507324, facet # = 51
# Filtering edges by size finished: 0.0017061233520507812, facet # = 7
# Filtering by convexity and getting centers took: 0.0041925907135009766, facet # = 6
# Filtering edges by size finished: 0.007010936737060547, facet # = 16
# Filtering by convexity and getting centers took: 0.010133981704711914, facet # = 11
# Filtering edges by size finished: 0.004964590072631836, facet # = 7
# Filtering by convexity and getting centers took: 0.027497529983520508, facet # = 7
# Filtering edges by size finished: 0.07948565483093262, facet # = 192
# Filtering by convexity and getting centers took: 0.05785679817199707, facet # = 53
# Filtering edges by size finished: 0.0016548633575439453, facet # = 8
# Filtering by convexity and getting centers took: 0.0036649703979492188, facet # = 6
# Total time for facets: 87.73322367668152
# Zero faceted faces = []
# Starting Child 0
# 29 12724
# Done distance matrix: 0.01539158821105957
# Done Generating final pairs: 0.028819799423217773
# best_stitch_pair = [  17 3253]
# best_stitch_pair_size = 213465.41369998295
# best_stitch_pair_distance = 490.83894056579135
# best_stitch_pair_size_ratio = 0.15720508113023085
# Starting Child 1
# 4 12724
# Done distance matrix: 0.0034313201904296875
# Done Generating final pairs: 0.022208213806152344
# best_stitch_pair = [    2 12063]
# best_stitch_pair_size = 43906.939696362606
# best_stitch_pair_distance = 1825.055105685468
# best_stitch_pair_size_ratio = 0.16234462086810658
# Starting Child 2
# 10 12724
# Done distance matrix: 0.007930517196655273
# Done Generating final pairs: 0.024188756942749023
# best_stitch_pair = [    2 11371]
# best_stitch_pair_size = 229558.21229611046
# best_stitch_pair_distance = 1920.9782419722062
# best_stitch_pair_size_ratio = 0.2171259610222303
# Starting Child 3
# 3 12724
# Done distance matrix: 0.0020966529846191406
# Done Generating final pairs: 0.03697395324707031
# best_stitch_pair = [    2 11408]
# best_stitch_pair_size = 76356.57739821522
# best_stitch_pair_distance = 1675.3511532926343
# best_stitch_pair_size_ratio = 0.4708369797286555
# Starting Child 4
# 13 12724
# Done distance matrix: 0.009556770324707031
# Done Generating final pairs: 0.047028303146362305
# best_stitch_pair = [    1 11333]
# best_stitch_pair_size = 1532478.809222154
# best_stitch_pair_distance = 1662.1982912640872
# best_stitch_pair_size_ratio = 0.15756353191681677
# Starting Child 5
# 4 12724
# Done distance matrix: 0.0026483535766601562
# Done Generating final pairs: 0.017470598220825195
# best_stitch_pair = [    2 12217]
# best_stitch_pair_size = 128996.31592520533
# best_stitch_pair_distance = 547.6775787901521
# best_stitch_pair_size_ratio = 0.25186411718750884
# Starting Child 6
# 51 12724
# Done distance matrix: 0.05391812324523926
# Child 6 There were no points close enough
# Starting Child 7
# 6 12724
# Done distance matrix: 0.003862142562866211
# Child 7 There were no points close enough
# Starting Child 8
# 11 12724
# Done distance matrix: 0.006913423538208008
# Done Generating final pairs: 0.04438614845275879
# best_stitch_pair = [   6 1869]
# best_stitch_pair_size = 328520.2514342984
# best_stitch_pair_distance = 482.27201254564704
# best_stitch_pair_size_ratio = 0.43354841052725723
# Starting Child 9
# 7 12724
# Done distance matrix: 0.004956960678100586
# Done Generating final pairs: 0.04570794105529785
# best_stitch_pair = [    3 11406]
# best_stitch_pair_size = 621754.9814025292
# best_stitch_pair_distance = 1555.2429438943702
# best_stitch_pair_size_ratio = 0.19013264692701867
# Starting Child 10
# 53 12724
# Done distance matrix: 0.030780792236328125
# Child 10 There were no points close enough
# Starting Child 11
# 6 12724
# Done distance matrix: 0.0037097930908203125
# Child 11 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [17, 3253], 1: [2, 12063], 2: [2, 11371], 3: [2, 11408], 4: [1, 11333], 5: [2, 12217], 8: [6, 1869], 9: [3, 11406]}
# ---Stitching child 0 with pair: [17, 3253]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 552219, starting edge 2nd facet= 636150,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 3.147125244140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022793054580688477
# returned from stitch mesh: 0.985755443572998
# Finished stitching child 0 : 1.1035432815551758
# ---Stitching child 1 with pair: [2, 12063]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 409606, starting edge 2nd facet= 636289,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.020961523056030273
# returned from stitch mesh: 0.7767274379730225
# Finished stitching child 1 : 0.9565482139587402
# ---Stitching child 2 with pair: [2, 11371]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 474665, starting edge 2nd facet= 636408,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.574920654296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03516960144042969
# returned from stitch mesh: 0.8462028503417969
# Finished stitching child 2 : 1.0054035186767578
# ---Stitching child 3 with pair: [2, 11408]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 375360, starting edge 2nd facet= 636426,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06564021110534668
# returned from stitch mesh: 0.79429030418396
# Finished stitching child 3 : 0.9289524555206299
# ---Stitching child 4 with pair: [1, 11333]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 545131, starting edge 2nd facet= 636503,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 28
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 13
# About to add faces
# Finished adding faces: 5.435943603515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004759788513183594
# returned from stitch mesh: 0.529346227645874
# Finished stitching child 4 : 0.684851884841919
# ---Stitching child 5 with pair: [2, 12217]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 579919, starting edge 2nd facet= 636519,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.6941299438476562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003270864486694336
# returned from stitch mesh: 0.8131494522094727
# Finished stitching child 5 : 0.9330503940582275
# ---Stitching child 8 with pair: [6, 1869]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 589835, starting edge 2nd facet= 636580,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 3.337860107421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04230999946594238
# returned from stitch mesh: 1.2200782299041748
# Finished stitching child 8 : 1.336646318435669
# ---Stitching child 9 with pair: [3, 11406]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 633171, starting edge 2nd facet= 636662,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.021172523498535156
# returned from stitch mesh: 0.9307637214660645
# Finished stitching child 9 : 1.0929486751556396
# ***************Finished big stitching iteration: 8.866304636001587***************
# Starting Child 6
# 51 12789
# Done distance matrix: 0.03604865074157715
# Done Generating final pairs: 0.04236912727355957
# best_stitch_pair = [   45 12725]
# best_stitch_pair_size = 55962.94048362704
# best_stitch_pair_distance = 552.7556158346592
# best_stitch_pair_size_ratio = 0.667890087642709
# Starting Child 7
# 6 12789
# Done distance matrix: 0.015243291854858398
# Done Generating final pairs: 0.020321130752563477
# best_stitch_pair = [    5 12725]
# best_stitch_pair_size = 52878.05612458066
# best_stitch_pair_distance = 127.70324881120914
# best_stitch_pair_size_ratio = 0.5759498143205303
# Starting Child 10
# 53 12789
# Done distance matrix: 0.11996603012084961
# Child 10 There were no points close enough
# Starting Child 11
# 6 12789
# Done distance matrix: 0.004503488540649414
# Child 11 There were no points close enough
# repeat_main_facets = [12725]
# child_mesh_double_indexes = [6, 7]
# min_child = 7, max_ratio = 127.70324881120914
# child_meshes_stitch_facets = {7: [5, 12725]}
# ---Stitching child 7 with pair: [5, 12725]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 636067, starting edge 2nd facet= 636693,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.019803524017333984
# returned from stitch mesh: 0.962395429611206
# Finished stitching child 7 : 1.2274549007415771
# ***************Finished big stitching iteration: 2.458698272705078***************
# Starting Child 6
# 51 12793
# Done distance matrix: 0.028763294219970703
# Done Generating final pairs: 0.03381681442260742
# best_stitch_pair = [   45 12791]
# best_stitch_pair_size = 51048.77866399702
# best_stitch_pair_distance = 159.8444949928105
# best_stitch_pair_size_ratio = 0.7824933592811911
# Starting Child 10
# 53 12793
# Done distance matrix: 0.03314495086669922
# Child 10 There were no points close enough
# Starting Child 11
# 6 12793
# Done distance matrix: 0.004029512405395508
# Child 11 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [45, 12791]}
# ---Stitching child 6 with pair: [45, 12791]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 636680, starting edge 2nd facet= 636927,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.021791458129882812
# returned from stitch mesh: 1.0788800716400146
# Finished stitching child 6 : 1.187958002090454
# ***************Finished big stitching iteration: 2.2998108863830566***************
# Starting Child 10
# 53 12842
# Done distance matrix: 0.0940244197845459
# Done Generating final pairs: 0.10507750511169434
# best_stitch_pair = [   48 12801]
# best_stitch_pair_size = 135543.44804117677
# best_stitch_pair_distance = 600.0807735954198
# best_stitch_pair_size_ratio = 0.30585781843147736
# Starting Child 11
# 6 12842
# Done distance matrix: 0.003815174102783203
# Done Generating final pairs: 0.01846623420715332
# best_stitch_pair = [    2 12801]
# best_stitch_pair_size = 171089.74441926536
# best_stitch_pair_distance = 169.5971130996661
# best_stitch_pair_size_ratio = 0.6483192926851651
# repeat_main_facets = [12801]
# child_mesh_double_indexes = [10, 11]
# min_child = 11, max_ratio = 169.5971130996661
# child_meshes_stitch_facets = {11: [2, 12801]}
# ---Stitching child 11 with pair: [2, 12801]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 637028, starting edge 2nd facet= 637246,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0033686161041259766
# returned from stitch mesh: 0.7223067283630371
# Finished stitching child 11 : 0.789900541305542
# ***************Finished big stitching iteration: 2.1697983741760254***************
# Starting Child 10
# 53 12846
# Done distance matrix: 0.02580857276916504
# Done Generating final pairs: 0.02858734130859375
# best_stitch_pair = [   48 12842]
# best_stitch_pair_size = 107059.6986705112
# best_stitch_pair_distance = 301.5079353201784
# best_stitch_pair_size_ratio = 0.42153516932802704
# repeat_main_facets = []
# child_meshes_stitch_facets = {10: [48, 12842]}
# ---Stitching child 10 with pair: [48, 12842]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 637260, starting edge 2nd facet= 637728,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0033180713653564453
# returned from stitch mesh: 0.7354493141174316
# Finished stitching child 10 : 0.79490065574646
# ***************Finished big stitching iteration: 1.7601959705352783***************
# All children have been processed
# total_stitch_processing_time = 17.555891036987305
# Total time for restitching = 17.559829235076904
# missed_children = []
# Whole stitching function complete: 111.08910703659058
#
#
#
# *****Running Neuron Stitcher for 648518346349478700**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478700_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 7.639328479766846
# Number of outside child meshes =  5
# Main mesh and outside child meshes make up 0.9351069134678481% of original mesh
#  face length 3914875 using optimized facets with 3 neighbors
# Filtering edges by size finished: 97.77997994422913, facet # = 204540
# Filtering by convexity and getting centers took: 134.57132005691528, facet # = 41496
# Finished facets for main mesh: 243.9867103099823 with facet length = 41496
# Finished 41496 facets for main mesh: 243.98708391189575
# Filtering edges by size finished: 0.019483089447021484, facet # = 23
# Filtering by convexity and getting centers took: 0.021233320236206055, facet # = 10
# Filtering edges by size finished: 0.0027570724487304688, facet # = 9
# Filtering by convexity and getting centers took: 0.004651546478271484, facet # = 8
# Filtering edges by size finished: 0.0008518695831298828, facet # = 6
# Filtering by convexity and getting centers took: 0.002905130386352539, facet # = 4
# Filtering edges by size finished: 0.04178929328918457, facet # = 258
# Filtering by convexity and getting centers took: 0.16425323486328125, facet # = 82
# Filtering edges by size finished: 0.002187967300415039, facet # = 0
# Filtering by convexity and getting centers took: 0.0002682209014892578, facet # = 0
# Total time for facets: 244.27117204666138
# Zero faceted faces = [4]
# Starting Child 0
# 10 41496
# Done distance matrix: 0.018247127532958984
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 8 41496
# Done distance matrix: 0.020270824432373047
# Child 1 There were no points close enough
# Starting Child 2
# 4 41496
# Done distance matrix: 0.008030176162719727
# Child 2 There were no points close enough
# Starting Child 3
# 82 41496
# Done distance matrix: 0.1611309051513672
# Done Generating final pairs: 0.21047019958496094
# best_stitch_pair = [   78 33012]
# best_stitch_pair_size = 74476.4275301511
# best_stitch_pair_distance = 1021.0998059892147
# best_stitch_pair_size_ratio = 0.25915410995699195
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [78, 33012]}
# ---Stitching child 3 with pair: [78, 33012]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1243589, starting edge 2nd facet= 1964210,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03741955757141113
# returned from stitch mesh: 2.029364824295044
# Finished stitching child 3 : 2.304191827774048
# ***************Finished big stitching iteration: 3.395261526107788***************
# Starting Child 0
# 10 41576
# Done distance matrix: 0.0188748836517334
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 8 41576
# Done distance matrix: 0.03741145133972168
# Child 1 There were no points close enough
# Starting Child 2
# 4 41576
# Done distance matrix: 0.009077787399291992
# Child 2 There were no points close enough
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# 10 41576
# Done distance matrix: 0.017577409744262695
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 1
# 8 41576
# Done distance matrix: 0.012212276458740234
# Child 1 There were no points close enough
# Starting Child 2
# 4 41576
# Done distance matrix: 0.006384372711181641
# Child 2 There were no points close enough
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# 10 41576
# Done distance matrix: 0.017340898513793945
# Done Generating final pairs: 0.020520687103271484
# best_stitch_pair = [    2 32830]
# best_stitch_pair_size = 83523.18016664544
# best_stitch_pair_distance = 2932.784516369491
# best_stitch_pair_size_ratio = 0.7247234385670854
# Starting Child 1
# 8 41576
# Done distance matrix: 0.016527891159057617
# Done Generating final pairs: 0.02058100700378418
# best_stitch_pair = [    7 32828]
# best_stitch_pair_size = 190543.2805568265
# best_stitch_pair_distance = 3151.5068465674567
# best_stitch_pair_size_ratio = 0.18368051749607803
# Starting Child 2
# 4 41576
# Done distance matrix: 0.007876396179199219
# Done Generating final pairs: 0.011058807373046875
# best_stitch_pair = [    0 32828]
# best_stitch_pair_size = 60275.54446274874
# best_stitch_pair_distance = 3054.973943824473
# best_stitch_pair_size_ratio = 0.9628916407154382
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = [32828]
# child_mesh_double_indexes = [1, 2]
# min_child = 2, max_ratio = 3054.973943824473
# child_meshes_stitch_facets = {0: [2, 32830], 2: [0, 32828]}
# ---Stitching child 0 with pair: [2, 32830]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1309820, starting edge 2nd facet= 1965179,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.9325485229492188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011277914047241211
# returned from stitch mesh: 2.342998743057251
# Finished stitching child 0 : 2.8279623985290527
# ---Stitching child 2 with pair: [0, 32828]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1633249, starting edge 2nd facet= 1965220,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.765655517578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07479739189147949
# returned from stitch mesh: 3.0457956790924072
# Finished stitching child 2 : 3.70592999458313
# ***************Finished big stitching iteration: 7.192203521728516***************
# Starting Child 1
# 8 41586
# Done distance matrix: 0.02044081687927246
# Done Generating final pairs: 0.023792266845703125
# best_stitch_pair = [    7 41580]
# best_stitch_pair_size = 198805.79287899303
# best_stitch_pair_distance = 2034.5939913027985
# best_stitch_pair_size_ratio = 0.23500835667644213
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [7, 41580]}
# ---Stitching child 1 with pair: [7, 41580]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1965194, starting edge 2nd facet= 1965276,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09488105773925781
# returned from stitch mesh: 2.8423879146575928
# Finished stitching child 1 : 3.30679988861084
# ***************Finished big stitching iteration: 7.161846160888672***************
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 4
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 25.550823211669922
# Total time for restitching = 25.583075046539307
# missed_children = [4.0]
# Whole stitching function complete: 281.6684150695801
#
#
#
# *****Running Neuron Stitcher for 648518346349481014**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349481014_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 7.103128433227539
# Number of outside child meshes =  15
# Main mesh and outside child meshes make up 0.9862466372293879% of original mesh
#  face length 3711485 using optimized facets with 3 neighbors
# Filtering edges by size finished: 84.30530333518982, facet # = 191000
# Filtering by convexity and getting centers took: 118.53384017944336, facet # = 40177
# Finished facets for main mesh: 210.69615745544434 with facet length = 40177
# Finished 40177 facets for main mesh: 210.69640398025513
# Filtering edges by size finished: 1.2882866859436035, facet # = 2949
# Filtering by convexity and getting centers took: 1.2494869232177734, facet # = 950
# Filtering edges by size finished: 0.35425806045532227, facet # = 1212
# Filtering by convexity and getting centers took: 0.9396944046020508, facet # = 340
# Filtering edges by size finished: 0.26404309272766113, facet # = 614
# Filtering by convexity and getting centers took: 0.38155627250671387, facet # = 185
# Filtering edges by size finished: 0.6011366844177246, facet # = 2068
# Filtering by convexity and getting centers took: 1.1737565994262695, facet # = 527
# Filtering edges by size finished: 0.033696651458740234, facet # = 116
# Filtering by convexity and getting centers took: 0.06224393844604492, facet # = 29
# Filtering edges by size finished: 0.02844524383544922, facet # = 72
# Filtering by convexity and getting centers took: 0.033533334732055664, facet # = 28
# Filtering edges by size finished: 0.002731800079345703, facet # = 10
# Filtering by convexity and getting centers took: 0.004645109176635742, facet # = 10
# Filtering edges by size finished: 0.06872320175170898, facet # = 207
# Filtering by convexity and getting centers took: 0.10399484634399414, facet # = 63
# Filtering edges by size finished: 0.026213645935058594, facet # = 145
# Filtering by convexity and getting centers took: 0.07645487785339355, facet # = 42
# Filtering edges by size finished: 0.06556844711303711, facet # = 196
# Filtering by convexity and getting centers took: 0.14615416526794434, facet # = 68
# Filtering edges by size finished: 0.014603614807128906, facet # = 53
# Filtering by convexity and getting centers took: 0.02789926528930664, facet # = 26
# Filtering edges by size finished: 0.026148319244384766, facet # = 81
# Filtering by convexity and getting centers took: 0.03856396675109863, facet # = 20
# Filtering edges by size finished: 0.010581731796264648, facet # = 28
# Filtering by convexity and getting centers took: 0.016843080520629883, facet # = 10
# Filtering edges by size finished: 0.05418062210083008, facet # = 97
# Filtering by convexity and getting centers took: 0.05796504020690918, facet # = 26
# Filtering edges by size finished: 0.010048389434814453, facet # = 27
# Filtering by convexity and getting centers took: 0.01830911636352539, facet # = 18
# Total time for facets: 218.0199601650238
# Zero faceted faces = []
# Starting Child 0
# 950 40177
# Done distance matrix: 2.187375783920288
# Done Generating final pairs: 2.238274097442627
# best_stitch_pair = [    3 29633]
# best_stitch_pair_size = 54820.46296145455
# best_stitch_pair_distance = 729.4483539080264
# best_stitch_pair_size_ratio = 0.6768087001142226
# Starting Child 1
# 340 40177
# Done distance matrix: 0.54119873046875
# Child 1 There were no points close enough
# Starting Child 2
# 185 40177
# Done distance matrix: 0.5906226634979248
# Child 2 There were no points close enough
# Starting Child 3
# 527 40177
# Done distance matrix: 1.2330665588378906
# Done Generating final pairs: 1.28928804397583
# best_stitch_pair = [  207 25319]
# best_stitch_pair_size = 144047.47260469728
# best_stitch_pair_distance = 1940.3390247627933
# best_stitch_pair_size_ratio = 0.40236782799630805
# Starting Child 4
# 29 40177
# Done distance matrix: 0.03581595420837402
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 28 40177
# Done distance matrix: 0.03398776054382324
# Done Generating final pairs: 0.05698275566101074
# best_stitch_pair = [   6 8686]
# best_stitch_pair_size = 32757.55533336541
# best_stitch_pair_distance = 1968.049970124536
# best_stitch_pair_size_ratio = 0.846270545512823
# Starting Child 6
# 10 40177
# Done distance matrix: 0.013031244277954102
# Done Generating final pairs: 0.03671622276306152
# best_stitch_pair = [    0 11343]
# best_stitch_pair_size = 195859.20038409793
# best_stitch_pair_distance = 918.4041985455049
# best_stitch_pair_size_ratio = 0.25478569741749535
# Starting Child 7
# 63 40177
# Done distance matrix: 0.08994245529174805
# Child 7 There were no points close enough
# Starting Child 8
# 42 40177
# Done distance matrix: 0.06856083869934082
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# ...
# smaller_face = main
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030867815017700195
# returned from stitch mesh: 1.1836977005004883
# Finished stitching child 32 : 1.3631670475006104
# ***************Finished big stitching iteration: 1.5270936489105225***************
# Starting Child 22
# 1 24226
# Done distance matrix: 0.0015840530395507812
# Child 22 There were no points close enough
# Starting Child 26
# 1 24226
# Done distance matrix: 0.0013837814331054688
# Child 26 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 22
# 1 24226
# Done distance matrix: 0.0013287067413330078
# Child 22 There were no points close enough
# Starting Child 26
# 1 24226
# Done distance matrix: 0.00128936767578125
# Child 26 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 22
# 1 24226
# Done distance matrix: 0.0010814666748046875
# Child 22 There were no points close enough
# Starting Child 26
# 1 24226
# Done distance matrix: 0.001049041748046875
# Child 26 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 22
# 1 24226
# Done distance matrix: 0.0015959739685058594
# Child 22 There were no points close enough
# Starting Child 26
# 1 24226
# Done distance matrix: 0.0016477108001708984
# Child 26 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 76.8811707496643
# Total time for restitching = 76.89038562774658
# missed_children = [26.0, 22.0]
# Whole stitching function complete: 176.70997643470764
#
#
#
# *****Running Neuron Stitcher for 648518346349513079**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349513079_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 6.055750131607056
# Number of outside child meshes =  10
# Main mesh and outside child meshes make up 0.9795511174711692% of original mesh
#  face length 3511444 using optimized facets with 3 neighbors
# Filtering edges by size finished: 62.360589265823364, facet # = 183529
# Filtering by convexity and getting centers took: 83.36438846588135, facet # = 37278
# Finished facets for main mesh: 153.90294098854065 with facet length = 37278
# Finished 37278 facets for main mesh: 153.9031844139099
# Filtering edges by size finished: 1.4211945533752441, facet # = 4594
# Filtering by convexity and getting centers took: 1.8808274269104004, facet # = 963
# Filtering edges by size finished: 1.4318156242370605, facet # = 3847
# Filtering by convexity and getting centers took: 2.0378146171569824, facet # = 923
# Filtering edges by size finished: 0.853323221206665, facet # = 2957
# Filtering by convexity and getting centers took: 1.0571441650390625, facet # = 651
# Filtering edges by size finished: 1.3492794036865234, facet # = 3636
# Filtering by convexity and getting centers took: 2.1083176136016846, facet # = 868
# Filtering edges by size finished: 1.252389669418335, facet # = 4311
# Filtering by convexity and getting centers took: 1.85422945022583, facet # = 1076
# Filtering edges by size finished: 1.2910034656524658, facet # = 4040
# Filtering by convexity and getting centers took: 1.9433043003082275, facet # = 1051
# Filtering edges by size finished: 0.027317523956298828, facet # = 34
# Filtering by convexity and getting centers took: 0.012694120407104492, facet # = 4
# Filtering edges by size finished: 1.0847856998443604, facet # = 4095
# Filtering by convexity and getting centers took: 1.8429827690124512, facet # = 965
# Filtering edges by size finished: 0.0022559165954589844, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0017459392547607422, facet # = 2
# Filtering edges by size finished: 0.0016100406646728516, facet # = 0
# Filtering by convexity and getting centers took: 0.00012946128845214844, facet # = 0
# Total time for facets: 175.9998471736908
# Zero faceted faces = [9]
# Starting Child 0
# 963 37278
# Done distance matrix: 1.6198604106903076
# Done Generating final pairs: 1.6604771614074707
# best_stitch_pair = [  462 27712]
# best_stitch_pair_size = 1717086.9530443202
# best_stitch_pair_distance = 270.52961384603975
# best_stitch_pair_size_ratio = 0.8833405644139894
# Starting Child 1
# 923 37278
# Done distance matrix: 1.3931756019592285
# Done Generating final pairs: 1.4680988788604736
# best_stitch_pair = [  21 9867]
# best_stitch_pair_size = 953791.0795021506
# best_stitch_pair_distance = 224.92795456931066
# best_stitch_pair_size_ratio = 0.9485835629205461
# Starting Child 2
# 651 37278
# Done distance matrix: 0.8792147636413574
# Done Generating final pairs: 0.9241340160369873
# best_stitch_pair = [  22 4316]
# best_stitch_pair_size = 1386789.0722151552
# best_stitch_pair_distance = 417.002711995255
# best_stitch_pair_size_ratio = 0.9906806633937874
# Starting Child 3
# 868 37278
# Done distance matrix: 1.074950933456421
# Done Generating final pairs: 1.1089544296264648
# best_stitch_pair = [  217 31587]
# best_stitch_pair_size = 2034335.2430267888
# best_stitch_pair_distance = 436.21008299929224
# best_stitch_pair_size_ratio = 0.9463747401933058
# Starting Child 4
# 1076 37278
# Done distance matrix: 1.3556323051452637
# Done Generating final pairs: 1.383866310119629
# best_stitch_pair = [  655 25189]
# best_stitch_pair_size = 95284.43939898477
# best_stitch_pair_distance = 1182.76841421413
# best_stitch_pair_size_ratio = 0.9639670908694191
# Starting Child 5
# 1051 37278
# Done distance matrix: 1.4513804912567139
# Done Generating final pairs: 1.4808893203735352
# best_stitch_pair = [  623 14482]
# best_stitch_pair_size = 1762765.6167933843
# best_stitch_pair_distance = 1395.9030483695394
# best_stitch_pair_size_ratio = 0.8108304381308984
# Starting Child 6
# 4 37278
# Done distance matrix: 0.009644508361816406
# Child 6 There were no points close enough
# Starting Child 7
# 965 37278
# Done distance matrix: 1.268660068511963
# Child 7 There were no points close enough
# Starting Child 8
# 2 37278
# Done distance matrix: 0.0035016536712646484
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [462, 27712], 1: [21, 9867], 2: [22, 4316], 3: [217, 31587], 4: [655, 25189], 5: [623, 14482]}
# ---Stitching child 0 with pair: [462, 27712]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129030, starting edge 2nd facet= 1783487,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 28
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 11
# About to add faces
# Finished adding faces: 4.458427429199219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010160684585571289
# returned from stitch mesh: 1.4891023635864258
# Finished stitching child 0 : 1.7438297271728516
# ---Stitching child 1 with pair: [21, 9867]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1309465, starting edge 2nd facet= 1846623,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 22
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 3.3855438232421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.029620647430419922
# returned from stitch mesh: 1.6017043590545654
# Finished stitching child 1 : 1.80306077003479
# ---Stitching child 2 with pair: [22, 4316]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1303514, starting edge 2nd facet= 1852216,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 24
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 4.5299530029296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030533552169799805
# returned from stitch mesh: 1.9837627410888672
# Finished stitching child 2 : 2.217438220977783
# ---Stitching child 3 with pair: [217, 31587]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1689599, starting edge 2nd facet= 1878795,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 30
# Starting Organizing vertices for side 1
# edge_1_order done, len = 33
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 4.8160552978515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.057428598403930664
# returned from stitch mesh: 2.398240804672241
# Finished stitching child 3 : 2.792836904525757
# ---Stitching child 4 with pair: [655, 25189]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1695302, starting edge 2nd facet= 1914756,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.170967102050781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09402203559875488
# returned from stitch mesh: 2.7094357013702393
# Finished stitching child 4 : 3.038362979888916
# ---Stitching child 5 with pair: [623, 14482]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1165560, starting edge 2nd facet= 1943975,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 38
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 6.103515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.032312631607055664
# returned from stitch mesh: 2.464747667312622
# Finished stitching child 5 : 2.8910279273986816
# ***************Finished big stitching iteration: 24.805895566940308***************
# Starting Child 6
# 4 42798
# Done distance matrix: 0.013850212097167969
# Done Generating final pairs: 0.022685527801513672
# best_stitch_pair = [    0 37458]
# best_stitch_pair_size = 83790.283871098
# best_stitch_pair_distance = 1831.4526809345132
# best_stitch_pair_size_ratio = 0.3274602460075979
# Starting Child 7
# 965 42798
# Done distance matrix: 1.9807300567626953
# Done Generating final pairs: 2.0400431156158447
# best_stitch_pair = [  290 39182]
# best_stitch_pair_size = 633231.2486957895
# best_stitch_pair_distance = 169.2957724902396
# best_stitch_pair_size_ratio = 0.8127856957937982
# Starting Child 8
# 2 42798
# Done distance matrix: 0.005015373229980469
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [0, 37458], 7: [290, 39182]}
# ---Stitching child 6 with pair: [0, 37458]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1781952, starting edge 2nd facet= 1956417,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09107565879821777
# returned from stitch mesh: 1.9524881839752197
# Finished stitching child 6 : 2.30849289894104
# ---Stitching child 7 with pair: [290, 39182]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1857029, starting edge 2nd facet= 1959950,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 22
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 3.62396240234375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03424429893493652
# returned from stitch mesh: 1.8151051998138428
# Finished stitching child 7 : 2.2281150817871094
# ***************Finished big stitching iteration: 9.424633026123047***************
# Starting Child 8
# 2 43763
# Done distance matrix: 0.00468134880065918
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 8
# 2 43763
# Done distance matrix: 0.004495143890380859
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 8
# 2 43763
# Done distance matrix: 0.003683328628540039
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 8
# 2 43763
# Done distance matrix: 0.00481104850769043
# Done Generating final pairs: 0.007949113845825195
# best_stitch_pair = [   1 2193]
# best_stitch_pair_size = 29838.603544979378
# best_stitch_pair_distance = 3945.69815308779
# best_stitch_pair_size_ratio = 0.7381120155870078
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {8: [1, 2193]}
# ---Stitching child 8 with pair: [1, 2193]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 699488, starting edge 2nd facet= 1972327,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 4
# About to add faces
# Finished adding faces: 2.1219253540039062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0596470832824707
# returned from stitch mesh: 2.363640546798706
# Finished stitching child 8 : 2.8283567428588867
# ***************Finished big stitching iteration: 3.2291524410247803***************
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 9
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 43.725935220718384
# Total time for restitching = 43.7340190410614
# missed_children = [9.0]
# Whole stitching function complete: 228.64547729492188
# 5930.4602663517

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
