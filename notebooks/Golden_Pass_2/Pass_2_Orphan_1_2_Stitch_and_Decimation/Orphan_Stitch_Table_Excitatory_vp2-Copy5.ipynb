# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341376363**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 112 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 720728
# Total time for Mesh Cleansing: 1.5833899974822998
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992249964299925% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341379850**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 193 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 849950
# Total time for Mesh Cleansing: 16.43059277534485
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982570580925826% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341391767**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 244 pieces after mesh split
# There were 34 pieces found after size threshold
# max_index = 0
# max_face_len = 440726
# Total time for Mesh Cleansing: 31.254339456558228
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.991161707027455% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341405275**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 61 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 462446
# Total time for Mesh Cleansing: 13.352514505386353
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993149841279445% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409710**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 29 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 290978
# Total time for Mesh Cleansing: 0.6006350517272949
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994435666689565% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410558**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 19 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 270648
# Total time for Mesh Cleansing: 0.6389331817626953
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996601905887568% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341411808**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 35 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 338140
# Total time for Mesh Cleansing: 0.7966277599334717
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993438979554442% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341417088**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 104380
# Total time for Mesh Cleansing: 0.3486495018005371
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992150255595336% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341420070**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 57558
# Total time for Mesh Cleansing: 1.3916292190551758
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989933351846709% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342788540**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 276 pieces after mesh split
# There were 88 pieces found after size threshold
# max_index = 0
# max_face_len = 568073
# Total time for Mesh Cleansing: 82.20106792449951
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9868649176386385% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348125038**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 10460
# Total time for Mesh Cleansing: 0.5091404914855957
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.996760053363827% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348198836**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 82 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 0
# max_face_len = 95388
# Total time for Mesh Cleansing: 5.1141602993011475
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9858205870194295% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349378759**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 12094
# Total time for Mesh Cleansing: 0.1373286247253418
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349379849**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 61816
# Total time for Mesh Cleansing: 0.23563504219055176
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989011699308383% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349386619**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 86934
# Total time for Mesh Cleansing: 0.2970900535583496
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991265371796345% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349462805**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 94 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 320942
# Total time for Mesh Cleansing: 8.249826669692993
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983575450275298% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349483668**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 108 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 308828
# Total time for Mesh Cleansing: 11.169487237930298
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9966437321698272% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509107**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 108 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 2
# max_face_len = 267042
# Total time for Mesh Cleansing: 9.097530126571655
# Number of outside child meshes =  7
# Main mesh and outside child meshes make up 0.9982387791841535% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509107_30_main_and_child_meshes_array.npz
#  face length 267042 using optimized facets with 3 neighbors
# Filtering edges by size finished: 7.544588565826416, facet # = 13960
# Filtering by convexity and getting centers took: 10.569936752319336, facet # = 3016
# Finished 3016 facets for main mesh: 18.540862560272217
# Filtering edges by size finished: 2.5698130130767822, facet # = 6337
# Filtering by convexity and getting centers took: 4.732280492782593, facet # = 1442
# Filtering edges by size finished: 1.5229644775390625, facet # = 5062
# Filtering by convexity and getting centers took: 2.8435630798339844, facet # = 991
# Filtering edges by size finished: 0.1168813705444336, facet # = 406
# Filtering by convexity and getting centers took: 0.26046037673950195, facet # = 93
# Filtering edges by size finished: 0.010158538818359375, facet # = 33
# Filtering by convexity and getting centers took: 0.021184682846069336, facet # = 5
# Filtering edges by size finished: 0.014978408813476562, facet # = 10
# Filtering by convexity and getting centers took: 0.00494384765625, facet # = 5
# Filtering edges by size finished: 0.0046384334564208984, facet # = 9
# Filtering by convexity and getting centers took: 0.004578590393066406, facet # = 3
# Filtering edges by size finished: 0.00695037841796875, facet # = 19
# Filtering by convexity and getting centers took: 0.016476154327392578, facet # = 8
# Total time for facets: 30.858442306518555
# Zero faceted faces = []
# Starting Child 0
# 1442 3016
# Done distance matrix: 0.6900773048400879
# Done Generating final pairs: 0.7868549823760986
# best_stitch_pair = [736  48]
# best_stitch_pair_size = 265433.3236815482
# best_stitch_pair_distance = 1492.0148433883292
# best_stitch_pair_size_ratio = 0.967417024540645
# Starting Child 1
# 991 3016
# Done distance matrix: 0.21434307098388672
# Done Generating final pairs: 0.22985363006591797
# best_stitch_pair = [ 861 1848]
# best_stitch_pair_size = 125767.99853915916
# best_stitch_pair_distance = 1645.7163613935768
# best_stitch_pair_size_ratio = 0.7459177610560666
# Starting Child 2
# 93 3016
# Done distance matrix: 0.018461942672729492
# Done Generating final pairs: 0.03577828407287598
# best_stitch_pair = [   1 1848]
# best_stitch_pair_size = 76091.3872318916
# best_stitch_pair_distance = 1859.811869899178
# best_stitch_pair_size_ratio = 0.4161139042655218
# Starting Child 3
# 5 3016
# Done distance matrix: 0.0011699199676513672
# Child 3 There were no points close enough
# Starting Child 4
# 5 3016
# Done distance matrix: 0.0012691020965576172
# Done Generating final pairs: 0.0066683292388916016
# best_stitch_pair = [   2 2497]
# best_stitch_pair_size = 37310.22697764578
# best_stitch_pair_distance = 923.3331352324461
# best_stitch_pair_size_ratio = 0.715780268703437
# Starting Child 5
# 3 3016
# Done distance matrix: 0.0011255741119384766
# Done Generating final pairs: 0.010356664657592773
# best_stitch_pair = [ 1 48]
# best_stitch_pair_size = 198349.87409573531
# best_stitch_pair_distance = 1129.941072042368
# best_stitch_pair_size_ratio = 0.47018811993488513
# Starting Child 6
# 8 3016
# Done distance matrix: 0.0018742084503173828
# Done Generating final pairs: 0.007020473480224609
# best_stitch_pair = [   1 2299]
# best_stitch_pair_size = 22907.936735684765
# best_stitch_pair_distance = 1998.655509246526
# best_stitch_pair_size_ratio = 0.49631819281178885
# repeat_main_facets = [48, 1848]
# child_mesh_double_indexes = [0, 5]
# min_child = 5, max_ratio = 1129.941072042368
# child_mesh_double_indexes = [1, 2]
# min_child = 1, max_ratio = 1645.7163613935768
# child_meshes_stitch_facets = {1: [861, 1848], 4: [2, 2497], 5: [1, 48], 6: [1, 2299]}
# ---Stitching child 1 with pair: [861, 1848]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 133631, starting edge 2nd facet= 153160,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0016124248504638672
# returned from stitch mesh: 0.3393106460571289
# Finished stitching child 1 : 0.3637256622314453
# ---Stitching child 4 with pair: [2, 2497]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 79260, starting edge 2nd facet= 154381,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0019888877868652344
# returned from stitch mesh: 0.1830906867980957
# Finished stitching child 4 : 0.19997429847717285
# ---Stitching child 5 with pair: [1, 48]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 44746, starting edge 2nd facet= 154402,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0022437572479248047
# returned from stitch mesh: 0.30961132049560547
# Finished stitching child 5 : 0.3366556167602539
# ---Stitching child 6 with pair: [1, 2299]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 57246, starting edge 2nd facet= 154552,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.5974044799804688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004088401794433594
# returned from stitch mesh: 0.31603407859802246
# Finished stitching child 6 : 0.34476733207702637
# ***************Finished big stitching iteration: 2.5697693824768066***************
# Starting Child 0
# 1442 4015
# Done distance matrix: 0.435758113861084
# Done Generating final pairs: 0.634624719619751
# best_stitch_pair = [587  19]
# best_stitch_pair_size = 198395.49737575924
# best_stitch_pair_distance = 1858.364399429534
# best_stitch_pair_size_ratio = 0.4546132678571542
# Starting Child 2
# 93 4015
# Done distance matrix: 0.031638145446777344
# Done Generating final pairs: 0.10105371475219727
# best_stitch_pair = [   5 3874]
# best_stitch_pair_size = 178606.8106667744
# best_stitch_pair_distance = 1348.468891379055
# best_stitch_pair_size_ratio = 0.6818684110901174
# Starting Child 3
# 5 4015
# Done distance matrix: 0.0033648014068603516
# Child 3 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [587, 19], 2: [5, 3874]}
# ---Stitching child 0 with pair: [587, 19]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1995, starting edge 2nd facet= 155634,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 7
# About to add faces
# Finished adding faces: 5.269050598144531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.001949310302734375
# returned from stitch mesh: 0.2843742370605469
# Finished stitching child 0 : 0.3262765407562256
# ---Stitching child 2 with pair: [5, 3874]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 148967, starting edge 2nd facet= 179333,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.695487976074219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0020096302032470703
# returned from stitch mesh: 0.3545393943786621
# Finished stitching child 2 : 0.3730008602142334
# ***************Finished big stitching iteration: 1.7393543720245361***************
# Starting Child 3
# 5 5546
# Done distance matrix: 0.0020666122436523438
# Done Generating final pairs: 0.004839897155761719
# best_stitch_pair = [   0 5440]
# best_stitch_pair_size = 25153.3870468178
# best_stitch_pair_distance = 1716.522781791296
# best_stitch_pair_size_ratio = 0.6615155225824662
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [0, 5440]}
# ---Stitching child 3 with pair: [0, 5440]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 167107, starting edge 2nd facet= 181016,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004597187042236328
# returned from stitch mesh: 0.2296907901763916
# Finished stitching child 3 : 0.25165438652038574
# ***************Finished big stitching iteration: 0.6266188621520996***************
# All children have been processed
# total_stitch_processing_time = 4.936282634735107
# Total time for restitching = 4.937396049499512
# missed_children = []
# Whole stitching function complete: 46.15227508544922
#
#
#
# *****Running Neuron Stitcher for 648518346341353607**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 181 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 388334
# Total time for Mesh Cleansing: 20.975079774856567
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9962339854592844% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341367466**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 129 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 363936
# Total time for Mesh Cleansing: 15.405917882919312
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9975112650886406% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341383573**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 27892
# Total time for Mesh Cleansing: 0.289825439453125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9998566102667049% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341389516**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 41800
# Total time for Mesh Cleansing: 2.286795139312744
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985666507405638% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399321**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 28 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 98861
# Total time for Mesh Cleansing: 4.088077783584595
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9980112661269156% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341400173**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 116 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 524020
# Total time for Mesh Cleansing: 20.673534393310547
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986754714464042% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341412652**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 50 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 447436
# Total time for Mesh Cleansing: 16.70987296104431
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979836731052326% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342807966**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 35 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 157644
# Total time for Mesh Cleansing: 4.530364036560059
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9980753159267607% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342922006**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 69 pieces after mesh split
# There were 20 pieces found after size threshold
# max_index = 0
# max_face_len = 343584
# Total time for Mesh Cleansing: 20.88750386238098
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9847578976331463% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341355048**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 122 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 552860
# Total time for Mesh Cleansing: 17.378109455108643
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9986777265567421% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362623**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 29308
# Total time for Mesh Cleansing: 0.3392477035522461
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9999317639031048% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341363677**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 115 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 479006
# Total time for Mesh Cleansing: 20.466601848602295
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9984576585589529% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341363677_30_main_and_child_meshes_array.npz
#  face length 479006 using optimized facets with 3 neighbors
# Filtering edges by size finished: 10.048124551773071, facet # = 24865
# Filtering by convexity and getting centers took: 18.181636810302734, facet # = 5382
# Finished 5382 facets for main mesh: 28.945598125457764
# Filtering edges by size finished: 0.0007529258728027344, facet # = 5
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002730131149291992, facet # = 3
# Total time for facets: 28.95566463470459
# Zero faceted faces = []
# Starting Child 0
# 3 5382
# Done distance matrix: 0.0012857913970947266
# Done Generating final pairs: 0.006861686706542969
# best_stitch_pair = [   2 4844]
# best_stitch_pair_size = 29763.72065827372
# best_stitch_pair_distance = 817.8852149698921
# best_stitch_pair_size_ratio = 0.36498474548146365
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [2, 4844]}
# ---Stitching child 0 with pair: [2, 4844]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 132845, starting edge 2nd facet= 240328,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.8835067749023438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0031442642211914062
# returned from stitch mesh: 0.4935140609741211
# Finished stitching child 0 : 0.5520014762878418
# ***************Finished big stitching iteration: 0.616539478302002***************
# All children have been processed
# total_stitch_processing_time = 0.6237132549285889
# Total time for restitching = 0.6258599758148193
# missed_children = []
# Whole stitching function complete: 51.58262801170349
#
#
#
# *****Running Neuron Stitcher for 648518346341398948**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 113302
# Total time for Mesh Cleansing: 0.4576733112335205
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997529339098209% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399130**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 278 pieces after mesh split
# There were 40 pieces found after size threshold
# max_index = 0
# max_face_len = 521370
# Total time for Mesh Cleansing: 30.953802824020386
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9897263004430675% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341408346**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 30 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 186371
# Total time for Mesh Cleansing: 6.186673641204834
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9987077688721813% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341408346_30_main_and_child_meshes_array.npz
#  face length 186371 using optimized facets with 3 neighbors
# Filtering edges by size finished: 3.4544177055358887, facet # = 10003
# Filtering by convexity and getting centers took: 6.655200481414795, facet # = 1978
# Finished 1978 facets for main mesh: 10.35396122932434
# Filtering edges by size finished: 0.02597498893737793, facet # = 115
# Filtering by convexity and getting centers took: 0.04616808891296387, facet # = 19
# Total time for facets: 10.431898832321167
# Zero faceted faces = []
# Starting Child 0
# 19 1978
# Done distance matrix: 0.0021834373474121094
# Done Generating final pairs: 0.00989079475402832
# best_stitch_pair = [  12 1153]
# best_stitch_pair_size = 70768.12945571204
# best_stitch_pair_distance = 1065.7915222430256
# best_stitch_pair_size_ratio = 0.2570150211800698
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [12, 1153]}
# ---Stitching child 0 with pair: [12, 1153]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 30192, starting edge 2nd facet= 93988,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.001306295394897461
# returned from stitch mesh: 0.20090222358703613
# Finished stitching child 0 : 0.21544981002807617
# ***************Finished big stitching iteration: 0.2568068504333496***************
# All children have been processed
# total_stitch_processing_time = 0.25737452507019043
# Total time for restitching = 0.25830793380737305
# missed_children = []
# Whole stitching function complete: 17.702725648880005
#
#
#
# *****Running Neuron Stitcher for 648518346341413745**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 31 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 90936
# Total time for Mesh Cleansing: 0.32078981399536133
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998331284033023% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341413929**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 251 pieces after mesh split
# There were 26 pieces found after size threshold
# max_index = 0
# max_face_len = 496290
# Total time for Mesh Cleansing: 42.56004071235657
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9900909114486182% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342794202**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 96910
# Total time for Mesh Cleansing: 0.25064992904663086
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993194192377496% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342795782**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 68844
# Total time for Mesh Cleansing: 0.29617929458618164
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989262601932731% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342796044**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 51164
# Total time for Mesh Cleansing: 0.26251816749572754
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994530395374277% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342796444**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 30182
# Total time for Mesh Cleansing: 0.1549537181854248
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994701635869925% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342796829**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 72 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 242050
# Total time for Mesh Cleansing: 9.334343910217285
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976670953275959% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342799285**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 304 pieces after mesh split
# There were 19 pieces found after size threshold
# max_index = 0
# max_face_len = 633863
# Total time for Mesh Cleansing: 35.098589181900024
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9944118915950896% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808119**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 98276
# Total time for Mesh Cleansing: 0.38162946701049805
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991866281670666% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808335**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 21850
# Total time for Mesh Cleansing: 0.23276901245117188
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808453**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 47 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 253850
# Total time for Mesh Cleansing: 0.4515841007232666
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991812893118894% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808743**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 272 pieces after mesh split
# There were 37 pieces found after size threshold
# max_index = 0
# max_face_len = 437193
# Total time for Mesh Cleansing: 40.87506031990051
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9869428886827082% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348212893**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 51126
# Total time for Mesh Cleansing: 0.37647247314453125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987107360525082% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348213908**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 184 pieces after mesh split
# There were 44 pieces found after size threshold
# max_index = 0
# max_face_len = 192264
# Total time for Mesh Cleansing: 17.364625215530396
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9780147111187979% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349508870**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 107 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 279786
# Total time for Mesh Cleansing: 10.524248123168945
# Number of outside child meshes =  3
# Main mesh and outside child meshes make up 0.9970467215290683% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349508870_30_main_and_child_meshes_array.npz
#  face length 279786 using optimized facets with 3 neighbors
# Filtering edges by size finished: 9.050801992416382, facet # = 14258
# Filtering by convexity and getting centers took: 13.50750470161438, facet # = 3180
# Finished 3180 facets for main mesh: 23.382039546966553
# Filtering edges by size finished: 2.7944419384002686, facet # = 4123
# Filtering by convexity and getting centers took: 4.027993440628052, facet # = 971
# Filtering edges by size finished: 0.15524888038635254, facet # = 297
# Filtering by convexity and getting centers took: 0.3311629295349121, facet # = 91
# Filtering edges by size finished: 0.002892017364501953, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0030014514923095703, facet # = 2
# Total time for facets: 31.002156972885132
# Zero faceted faces = []
# Starting Child 0
# 971 3180
# Done distance matrix: 0.2953526973724365
# Done Generating final pairs: 0.3411407470703125
# best_stitch_pair = [  26 1523]
# best_stitch_pair_size = 3004957.5019910373
# best_stitch_pair_distance = 378.6678077844264
# best_stitch_pair_size_ratio = 0.9432940415306768
# Starting Child 1
# 91 3180
# Done distance matrix: 0.018715858459472656
# Done Generating final pairs: 0.060701847076416016
# best_stitch_pair = [   0 1523]
# best_stitch_pair_size = 2408867.7383013917
# best_stitch_pair_distance = 391.8406073491545
# best_stitch_pair_size_ratio = 0.6514523555054985
# Starting Child 2
# returning y greater max
# skipped by bounding box filter
# repeat_main_facets = [1523]
# child_mesh_double_indexes = [0, 1]
# min_child = 0, max_ratio = 378.6678077844264
# child_meshes_stitch_facets = {0: [26, 1523]}
# ---Stitching child 0 with pair: [26, 1523]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 15580, starting edge 2nd facet= 153320,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 97
# Starting Organizing vertices for side 1
# edge_1_order done, len = 89
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 0.00023126602172851562
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0021991729736328125
# returned from stitch mesh: 0.5656743049621582
# Finished stitching child 0 : 0.5951566696166992
# ***************Finished big stitching iteration: 1.110762596130371***************
# Starting Child 1
# 91 4149
# Done distance matrix: 0.02154994010925293
# Done Generating final pairs: 0.09340119361877441
# best_stitch_pair = [   0 2391]
# best_stitch_pair_size = 2137005.8196132425
# best_stitch_pair_distance = 294.15765686428426
# best_stitch_pair_size_ratio = 0.8006847164992784
# Starting Child 2
# 2 4149
# Done distance matrix: 0.0006935596466064453
# Done Generating final pairs: 0.0053746700286865234
# best_stitch_pair = [   0 3222]
# best_stitch_pair_size = 34177.88630266985
# best_stitch_pair_distance = 1204.4265049044766
# best_stitch_pair_size_ratio = 0.7352405219559344
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [0, 2391], 2: [0, 3222]}
# ---Stitching child 1 with pair: [0, 2391]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 101293, starting edge 2nd facet= 180202,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 98
# Starting Organizing vertices for side 1
# edge_1_order done, len = 92
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 0.0002334117889404297
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0023229122161865234
# returned from stitch mesh: 0.6942214965820312
# Finished stitching child 1 : 0.7223281860351562
# ---Stitching child 2 with pair: [0, 3222]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 152158, starting edge 2nd facet= 181207,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 3.5762786865234375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002014636993408203
# returned from stitch mesh: 0.36161279678344727
# Finished stitching child 2 : 0.40302109718322754
# ***************Finished big stitching iteration: 1.7158424854278564***************
# All children have been processed
# total_stitch_processing_time = 2.8302488327026367
# Total time for restitching = 2.8316073417663574
# missed_children = []
# Whole stitching function complete: 45.852102279663086
#
#
#
# *****Running Neuron Stitcher for 648518346349511899**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 95 pieces after mesh split
# There were 11 pieces found after size threshold
# max_index = 1
# max_face_len = 169658
# Total time for Mesh Cleansing: 12.388813495635986
# Number of outside child meshes =  6
# Main mesh and outside child meshes make up 0.9967593315633297% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349511899_30_main_and_child_meshes_array.npz
#  face length 169658 using optimized facets with 3 neighbors
# Filtering edges by size finished: 5.68932318687439, facet # = 8970
# Filtering by convexity and getting centers took: 7.673283338546753, facet # = 1585
# Finished 1585 facets for main mesh: 13.815877676010132
# Filtering edges by size finished: 2.487077474594116, facet # = 6479
# Filtering by convexity and getting centers took: 4.1300647258758545, facet # = 1510
# Filtering edges by size finished: 2.246652126312256, facet # = 4016
# Filtering by convexity and getting centers took: 2.7310917377471924, facet # = 1236
# Filtering edges by size finished: 0.22333288192749023, facet # = 376
# Filtering by convexity and getting centers took: 0.27536463737487793, facet # = 72
# Filtering edges by size finished: 0.03232145309448242, facet # = 48
# Filtering by convexity and getting centers took: 0.0534818172454834, facet # = 17
# Filtering edges by size finished: 0.002092123031616211, facet # = 10
# Filtering by convexity and getting centers took: 0.00442051887512207, facet # = 2
# Filtering edges by size finished: 0.007340908050537109, facet # = 15
# Filtering by convexity and getting centers took: 0.007437229156494141, facet # = 3
# Total time for facets: 26.313653469085693
# Zero faceted faces = []
# Starting Child 0
# 1510 1585
# Done distance matrix: 0.15042519569396973
# Done Generating final pairs: 0.1624457836151123
# best_stitch_pair = [1210  421]
# best_stitch_pair_size = 45351.90845145569
# best_stitch_pair_distance = 1764.6642942399947
# best_stitch_pair_size_ratio = 0.755880305140755
# Starting Child 1
# 1236 1585
# Done distance matrix: 0.41138195991516113
# Child 1 There were no points close enough
# Starting Child 2
# 72 1585
# Done distance matrix: 0.0075948238372802734
# Done Generating final pairs: 0.014488458633422852
# best_stitch_pair = [ 19 329]
# best_stitch_pair_size = 152421.8728390652
# best_stitch_pair_distance = 1475.9750955463437
# best_stitch_pair_size_ratio = 0.16665713949654531
# Starting Child 3
# 17 1585
# Done distance matrix: 0.0020792484283447266
# Done Generating final pairs: 0.008884191513061523
# best_stitch_pair = [  3 248]
# best_stitch_pair_size = 90502.68040536428
# best_stitch_pair_distance = 1933.852705100828
# best_stitch_pair_size_ratio = 0.2133455774537524
# Starting Child 4
# 2 1585
# Done distance matrix: 0.0004990100860595703
# Child 4 There were no points close enough
# Starting Child 5
# 3 1585
# Done distance matrix: 0.00046634674072265625
# Child 5 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1210, 421], 2: [19, 329], 3: [3, 248]}
# ---Stitching child 0 with pair: [1210, 421]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 48053, starting edge 2nd facet= 89930,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0012845993041992188
# returned from stitch mesh: 0.26052021980285645
# Finished stitching child 0 : 0.2796187400817871
# ---Stitching child 2 with pair: [19, 329]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 83621, starting edge 2nd facet= 111370,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 2.7894973754882812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0013744831085205078
# returned from stitch mesh: 0.5477776527404785
# Finished stitching child 2 : 0.5957551002502441
# ---Stitching child 3 with pair: [3, 248]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 26606, starting edge 2nd facet= 112337,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.384185791015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003336191177368164
# returned from stitch mesh: 0.1903228759765625
# Finished stitching child 3 : 0.208390474319458
# ***************Finished big stitching iteration: 1.81064772605896***************
# Starting Child 1
# 1236 3178
# Done distance matrix: 0.22890019416809082
# Done Generating final pairs: 0.2498950958251953
# best_stitch_pair = [ 191 2740]
# best_stitch_pair_size = 173403.75879937597
# best_stitch_pair_distance = 1941.2916889818755
# best_stitch_pair_size_ratio = 0.22603664029508327
# Starting Child 4
# 2 3178
# Done distance matrix: 0.0010952949523925781
# Child 4 There were no points close enough
# Starting Child 5
# 3 3178
# Done distance matrix: 0.0009205341339111328
# Done Generating final pairs: 0.016939640045166016
# best_stitch_pair = [   0 3123]
# best_stitch_pair_size = 86699.13748846643
# best_stitch_pair_distance = 1923.30555757946
# best_stitch_pair_size_ratio = 0.9815834971352487
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [191, 2740], 5: [0, 3123]}
# ---Stitching child 1 with pair: [191, 2740]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 90136, starting edge 2nd facet= 116029,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 4.4345855712890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003827810287475586
# returned from stitch mesh: 0.30849337577819824
# Finished stitching child 1 : 0.3266901969909668
# ---Stitching child 5 with pair: [0, 3123]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 111020, starting edge 2nd facet= 128777,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.2172927856445312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004717588424682617
# returned from stitch mesh: 0.26367688179016113
# Finished stitching child 5 : 0.316631555557251
# ***************Finished big stitching iteration: 1.1660187244415283***************
# Starting Child 4
# 2 4413
# Done distance matrix: 0.0010495185852050781
# ...
# max_index = 0
# max_face_len = 53758
# Total time for Mesh Cleansing: 0.27148985862731934
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991079061814667% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349496069**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 81 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 264468
# Total time for Mesh Cleansing: 10.11527395248413
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979999849055464% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349511381**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 69 pieces after mesh split
# There were 16 pieces found after size threshold
# max_index = 0
# max_face_len = 226836
# Total time for Mesh Cleansing: 11.557931423187256
# Number of outside child meshes =  11
# Main mesh and outside child meshes make up 0.9978119452455516% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349511381_30_main_and_child_meshes_array.npz
#  face length 226836 using optimized facets with 3 neighbors
# Filtering edges by size finished: 7.944401979446411, facet # = 10904
# Filtering by convexity and getting centers took: 11.73223328590393, facet # = 2710
# Finished 2710 facets for main mesh: 20.349369525909424
# Filtering edges by size finished: 2.5284557342529297, facet # = 6967
# Filtering by convexity and getting centers took: 4.8654701709747314, facet # = 1486
# Filtering edges by size finished: 2.6049695014953613, facet # = 6798
# Filtering by convexity and getting centers took: 3.922797441482544, facet # = 1685
# Filtering edges by size finished: 0.3273136615753174, facet # = 488
# Filtering by convexity and getting centers took: 0.5142238140106201, facet # = 79
# Filtering edges by size finished: 0.10864734649658203, facet # = 302
# Filtering by convexity and getting centers took: 0.38761067390441895, facet # = 63
# Filtering edges by size finished: 0.03653526306152344, facet # = 41
# Filtering by convexity and getting centers took: 0.04132270812988281, facet # = 14
# Filtering edges by size finished: 0.0027120113372802734, facet # = 2
# Filtering by convexity and getting centers took: 0.0016472339630126953, facet # = 1
# Filtering edges by size finished: 0.1435246467590332, facet # = 152
# Filtering by convexity and getting centers took: 0.06143450736999512, facet # = 36
# Filtering edges by size finished: 0.008210420608520508, facet # = 58
# Filtering by convexity and getting centers took: 0.017429113388061523, facet # = 32
# Filtering edges by size finished: 0.003492116928100586, facet # = 13
# Filtering by convexity and getting centers took: 0.004547595977783203, facet # = 4
# Filtering edges by size finished: 0.0014281272888183594, facet # = 12
# Filtering by convexity and getting centers took: 0.004098176956176758, facet # = 4
# Filtering edges by size finished: 0.010445594787597656, facet # = 70
# Filtering by convexity and getting centers took: 0.019343137741088867, facet # = 15
# Total time for facets: 36.4773633480072
# Zero faceted faces = []
# Starting Child 0
# 1486 2710
# Done distance matrix: 0.6271097660064697
# Child 0 There were no points close enough
# Starting Child 1
# 1685 2710
# Done distance matrix: 0.29019832611083984
# Done Generating final pairs: 0.32045960426330566
# best_stitch_pair = [936 640]
# best_stitch_pair_size = 135951.3056433101
# best_stitch_pair_distance = 1891.493358861387
# best_stitch_pair_size_ratio = 0.4441835706615119
# Starting Child 2
# 79 2710
# Done distance matrix: 0.010636329650878906
# Child 2 There were no points close enough
# Starting Child 3
# 63 2710
# Done distance matrix: 0.007490396499633789
# Done Generating final pairs: 0.012816429138183594
# best_stitch_pair = [  20 2071]
# best_stitch_pair_size = 62100.71376701412
# best_stitch_pair_distance = 1652.8303449979974
# best_stitch_pair_size_ratio = 0.3221956692992773
# Starting Child 4
# 14 2710
# Done distance matrix: 0.002044677734375
# Done Generating final pairs: 0.006900787353515625
# best_stitch_pair = [  0 640]
# best_stitch_pair_size = 118219.52641746156
# best_stitch_pair_distance = 886.4765840624943
# best_stitch_pair_size_ratio = 0.25582242094402335
# Starting Child 5
# 1 2710
# Done distance matrix: 0.0006480216979980469
# Child 5 There were no points close enough
# Starting Child 6
# 36 2710
# Done distance matrix: 0.0038344860076904297
# Done Generating final pairs: 0.0065762996673583984
# best_stitch_pair = [ 31 971]
# best_stitch_pair_size = 27623.000773882974
# best_stitch_pair_distance = 1298.5058020778074
# best_stitch_pair_size_ratio = 0.8828510047825645
# Starting Child 7
# 32 2710
# Done distance matrix: 0.0035119056701660156
# Done Generating final pairs: 0.010030984878540039
# best_stitch_pair = [   9 2284]
# best_stitch_pair_size = 48912.98030465218
# best_stitch_pair_distance = 1958.5049330443505
# best_stitch_pair_size_ratio = 0.7284337490180008
# Starting Child 8
# 4 2710
# Done distance matrix: 0.0012481212615966797
# Child 8 There were no points close enough
# Starting Child 9
# 4 2710
# Done distance matrix: 0.0008096694946289062
# Child 9 There were no points close enough
# Starting Child 10
# 15 2710
# Done distance matrix: 0.0028488636016845703
# Done Generating final pairs: 0.019473552703857422
# best_stitch_pair = [  9 669]
# best_stitch_pair_size = 49398.77204668457
# best_stitch_pair_distance = 1890.2647095808381
# best_stitch_pair_size_ratio = 0.18519087603529066
# repeat_main_facets = [640]
# child_mesh_double_indexes = [1, 4]
# min_child = 4, max_ratio = 886.4765840624943
# child_meshes_stitch_facets = {3: [20, 2071], 4: [0, 640], 6: [31, 971], 7: [9, 2284], 10: [9, 669]}
# ---Stitching child 3 with pair: [20, 2071]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 67670, starting edge 2nd facet= 114829,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0013070106506347656
# returned from stitch mesh: 0.3594818115234375
# Finished stitching child 3 : 0.4000589847564697
# ---Stitching child 4 with pair: [0, 640]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 3849, starting edge 2nd facet= 115253,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.9325485229492188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0013327598571777344
# returned from stitch mesh: 0.20047712326049805
# Finished stitching child 4 : 0.21709108352661133
# ---Stitching child 6 with pair: [31, 971]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 97196, starting edge 2nd facet= 115389,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0022439956665039062
# returned from stitch mesh: 0.26079344749450684
# Finished stitching child 6 : 0.3023695945739746
# ---Stitching child 7 with pair: [9, 2284]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 87080, starting edge 2nd facet= 116119,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.001291513442993164
# returned from stitch mesh: 0.17657899856567383
# Finished stitching child 7 : 0.18830132484436035
# ---Stitching child 10 with pair: [9, 669]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 70691, starting edge 2nd facet= 116325,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003172636032104492
# returned from stitch mesh: 0.22071361541748047
# Finished stitching child 10 : 0.2395174503326416
# ***************Finished big stitching iteration: 2.537391424179077***************
# Starting Child 0
# 1486 2860
# Done distance matrix: 0.23090147972106934
# Child 0 There were no points close enough
# Starting Child 1
# 1685 2860
# Done distance matrix: 0.23636841773986816
# Done Generating final pairs: 0.3717830181121826
# best_stitch_pair = [747 969]
# best_stitch_pair_size = 81794.25335555278
# best_stitch_pair_distance = 1345.26919297365
# best_stitch_pair_size_ratio = 0.6018465963834808
# Starting Child 2
# 79 2860
# Done distance matrix: 0.011056661605834961
# Done Generating final pairs: 0.013984203338623047
# best_stitch_pair = [  35 2794]
# best_stitch_pair_size = 34113.81976088465
# best_stitch_pair_distance = 957.2310816406803
# best_stitch_pair_size_ratio = 0.6443409824161561
# Starting Child 5
# 1 2860
# Done distance matrix: 0.0003349781036376953
# Child 5 There were no points close enough
# Starting Child 8
# 4 2860
# Done distance matrix: 0.0009267330169677734
# Child 8 There were no points close enough
# Starting Child 9
# 4 2860
# Done distance matrix: 0.0006847381591796875
# Child 9 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [747, 969], 2: [35, 2794]}
# ---Stitching child 1 with pair: [747, 969]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 56158, starting edge 2nd facet= 127205,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.47955322265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0018651485443115234
# returned from stitch mesh: 0.13907074928283691
# Finished stitching child 1 : 0.15587353706359863
# ---Stitching child 2 with pair: [35, 2794]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 115590, starting edge 2nd facet= 142990,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0020017623901367188
# returned from stitch mesh: 0.15531635284423828
# Finished stitching child 2 : 0.1740422248840332
# ***************Finished big stitching iteration: 1.1932687759399414***************
# Starting Child 0
# 1486 4620
# Done distance matrix: 0.4851522445678711
# Done Generating final pairs: 0.503227949142456
# best_stitch_pair = [ 243 3181]
# best_stitch_pair_size = 130577.15602098468
# best_stitch_pair_distance = 1742.080422446791
# best_stitch_pair_size_ratio = 0.2748952053947794
# Starting Child 5
# 1 4620
# Done distance matrix: 0.0004553794860839844
# Child 5 There were no points close enough
# Starting Child 8
# 4 4620
# Done distance matrix: 0.0016331672668457031
# Done Generating final pairs: 0.006354808807373047
# best_stitch_pair = [   3 3234]
# best_stitch_pair_size = 52139.55255704438
# best_stitch_pair_distance = 413.22839368916306
# best_stitch_pair_size_ratio = 0.6610156675095812
# Starting Child 9
# 4 4620
# Done distance matrix: 0.0012252330780029297
# Done Generating final pairs: 0.002258777618408203
# best_stitch_pair = [   2 4614]
# best_stitch_pair_size = 13018.267576813092
# best_stitch_pair_distance = 1609.2463180122963
# best_stitch_pair_size_ratio = 0.8792043797166154
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [243, 3181], 8: [3, 3234], 9: [2, 4614]}
# ---Stitching child 0 with pair: [243, 3181]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 130930, starting edge 2nd facet= 164660,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 3.314018249511719e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002114534378051758
# returned from stitch mesh: 0.3697164058685303
# Finished stitching child 0 : 0.3890397548675537
# ---Stitching child 8 with pair: [3, 3234]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 122082, starting edge 2nd facet= 170446,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0040590763092041016
# returned from stitch mesh: 0.2568533420562744
# Finished stitching child 8 : 0.32342004776000977
# ---Stitching child 9 with pair: [2, 4614]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 144175, starting edge 2nd facet= 170534,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.621246337890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004567623138427734
# returned from stitch mesh: 0.24771428108215332
# Finished stitching child 9 : 0.2706313133239746
# ***************Finished big stitching iteration: 1.7883477210998535***************
# Starting Child 5
# 1 6108
# Done distance matrix: 0.0005738735198974609
# Child 5 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 5
# 1 6108
# Done distance matrix: 0.0005202293395996094
# Child 5 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 5
# 1 6108
# Done distance matrix: 0.001012563705444336
# Child 5 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 5
# 1 6108
# Done distance matrix: 0.0005390644073486328
# Child 5 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 6.148303747177124
# Total time for restitching = 6.150827884674072
# missed_children = [5.0]
# Whole stitching function complete: 54.8981614112854
# 987.2232248783112

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
