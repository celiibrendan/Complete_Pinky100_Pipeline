# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349497752******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08281660079956055
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 853.395238161087
# 2) Finished: Generating CGAL segmentation for neuron: 873.5334796905518
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.36392831802368164
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [28, 41, 72, 141, 29, 60, 34, 55, 1, 21, 168, 36, 190, 183, 209]
# soma_80_percent = 240193.2484375
# Debugging the axon filter
# [(28, 243632.828125), (41, 255381.421875), (72, 250122.796875), (141, 246639.03125), (29, 264521.875), (60, 246090.625), (34, 239642.5), (55, 236630.96875), (1, 237683.265625), (21, 270222.75), (168, 241739.09375), (36, 242537.265625), (190, 247119.15625), (183, 239694.015625), (209, 241339.859375)]
# possible_Axons_filter_1 = [34, 55, 1, 183]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.18203020095825195
# 6) Staring: Classifying Entire Neuron
# 36 = stub soma
# 141 = stub soma
# 168 = cilia
# 183 = cilia
# 190 = stub soma
# 209 = stub soma
# 6 = stub apical
# 11 = error
# 19 = stub apical
# 20 = stub apical
# 25 = error
# 33 = stub apical
# 35 = stub apical
# 38 = stub apical
# 39 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 61 = error
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 143 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 156 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 184 = stub apical
# 185 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 207 = stub apical
# 208 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 280 = stub apical
# Total Labels found = {'basal', 'soma', 'error', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.311342239379883
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.420548677444458
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.121413469314575
# Finished Auto Labeling: 888.8454949855804
#
#
# *****Starting Auto Labeling for 648518346349499783******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05341601371765137
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 626.3344507217407
# 2) Finished: Generating CGAL segmentation for neuron: 643.84952044487
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.25140857696533203
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [28, 17, 18, 14, 19, 22, 2, 77, 60, 88, 52]
# soma_80_percent = 210648.809375
# Debugging the axon filter
# [(28, 228029.515625), (17, 215981.6875), (18, 229085.5625), (14, 208221.828125), (19, 226368.1875), (22, 220825.328125), (2, 228582.59375), (77, 218991.953125), (60, 220874.1875), (88, 215646.8125), (52, 220307.234375)]
# possible_Axons_filter_1 = [14]
# possible_Axons_filter_2 = [14]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.10316610336303711
# 6) Staring: Classifying Entire Neuron
# 18 = axon
# 22 = cilia
# 52 = stub soma
# 60 = stub soma
# 77 = stub soma
# 88 = stub soma
# 20 = stub apical
# 21 = stub apical
# 23 = stub apical
# 24 = stub apical
# 27 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = error
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 90 = error
# 91 = stub apical
# 92 = stub apical
# Total Labels found = {'basal', 'soma', 'error', 'axon', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.0040366649627686
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.36479949951171875
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.326717376708984
# Finished Auto Labeling: 656.6462564468384
#
#
# *****Starting Auto Labeling for 648518346349500486******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08596515655517578
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1321.1717729568481
# 2) Finished: Generating CGAL segmentation for neuron: 1344.4230709075928
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.33214616775512695
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [5, 53, 30, 14, 25, 1, 3, 276, 11, 193, 47, 328, 286, 357, 150, 99]
# soma_80_percent = 249204.60625
# Debugging the axon filter
# [(5, 256380.046875), (53, 263071.65625), (30, 280658.5), (14, 274131.84375), (25, 264169.5), (1, 245846.515625), (3, 277133.0625), (276, 253699.921875), (11, 257619.359375), (193, 250107.3125), (47, 246043.484375), (328, 245046.296875), (286, 248318.46875), (357, 251781.046875), (150, 253142.6875), (99, 251595.21875)]
# possible_Axons_filter_1 = [1, 47, 328, 286]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.18725109100341797
# 6) Staring: Classifying Entire Neuron
# 47 = cilia
# 99 = stub soma
# 150 = stub soma
# 193 = stub soma
# 276 = stub soma
# 286 = stub soma
# 328 = stub soma
# 357 = stub soma
# Total Labels found = {'unsure', 'cilia', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.781062602996826
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 1.0583202838897705
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.944824934005737
# Finished Auto Labeling: 1365.058268070221
#
#
# *****Starting Auto Labeling for 648518346349504065******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09177660942077637
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1750.3847148418427
# 2) Finished: Generating CGAL segmentation for neuron: 1780.7510330677032
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 10
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.35282206535339355
# 5) Staring: Finding Apical Index
# Soma Index = 10
# Soma Connections = [13, 7, 15, 27, 83, 36, 42, 39, 197, 164]
# soma_80_percent = 242789.1890625
# Debugging the axon filter
# [(13, 265344.96875), (7, 238590.09375), (15, 242094.96875), (27, 262594.375), (83, 262714.28125), (36, 256048.328125), (42, 252727.078125), (39, 247702.8125), (197, 243370.984375), (164, 250478.203125)]
# possible_Axons_filter_1 = [7, 15]
# possible_Axons_filter_2 = [7, 15]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.1528782844543457
# 6) Staring: Classifying Entire Neuron
# 83 = axon
# 197 = cilia
# 164 = stub soma
# 28 = stub apical
# 29 = stub apical
# 33 = stub apical
# 34 = error
# 35 = stub apical
# 37 = stub apical
# 38 = stub apical
# 45 = stub apical
# 47 = stub apical
# 50 = stub apical
# 51 = error
# 52 = stub apical
# 55 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 62 = stub apical
# 68 = stub apical
# 71 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 81 = stub apical
# 82 = stub apical
# 85 = stub apical
# 87 = stub apical
# 88 = stub apical
# 93 = stub apical
# 94 = error
# 99 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 109 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 116 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 166 = stub apical
# 167 = stub apical
# 170 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 198 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 232 = stub apical
# 249 = stub apical
# 250 = stub apical
# 253 = stub apical
# 255 = stub apical
# 257 = stub apical
# 258 = stub apical
# Total Labels found = {'basal', 'soma', 'error', 'axon', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 3.4968371391296387
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5962867736816406
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 15.016274690628052
# Finished Auto Labeling: 1801.418785572052
#
#
# *****Starting Auto Labeling for 648518346349507087******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06794500350952148
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1036.9761810302734
# 2) Finished: Generating CGAL segmentation for neuron: 1056.0083138942719
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.24446415901184082
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [8, 24, 19, 152, 44, 33, 22, 2, 6, 41, 84]
# soma_80_percent = 276384.1375
# Debugging the axon filter
# [(8, 273351.59375), (24, 277915.21875), (19, 279758.6875), (152, 278726.21875), (44, 285977.03125), (33, 294753.34375), (22, 291995.75), (2, 283963.875), (6, 294472.5), (41, 282808.34375), (84, 287178.40625)]
# possible_Axons_filter_1 = [8]
# possible_Axons_filter_2 = [8]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.10519671440124512
# 6) Staring: Classifying Entire Neuron
# 19 = cilia
# 33 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 24
# 41 = stub soma
# 84 = axon
# 152 = stub soma
# 13 = stub apical
# 23 = stub apical
# 25 = stub apical
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 42 = stub apical
# 43 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 54 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 185 = stub apical
# 186 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# Total Labels found = {'basal', 'soma', 'axon', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.6096503734588623
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.47190093994140625
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.64685583114624
# Finished Auto Labeling: 1070.9388620853424
#
#
# *****Starting Auto Labeling for 648518346349510792******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.014500617980957031
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 110.89019894599915
# 2) Finished: Generating CGAL segmentation for neuron: 115.72832417488098
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06290793418884277
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [6, 13, 79, 3, 1, 2, 133, 164, 120, 98, 78, 36, 89, 84, 128, 136, 94, 170, 83, 91]
# soma_80_percent = 276713.365625
# Debugging the axon filter
# [(6, 277613.96875), (13, 292840.75), (79, 275032.25), (3, 272982.28125), (1, 290600.3125), (2, 286953.96875), (133, 279894.4375), (164, 279196.03125), (120, 276116.5), (98, 290229.59375), (78, 277354.40625), (36, 283635.46875), (89, 283606.90625), (84, 280943.65625), (128, 278305.3125), (136, 287149.5), (94, 290179.53125), (170, 286753.125), (83, 281777.8125), (91, 284426.25)]
# possible_Axons_filter_1 = [79, 3, 120]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.049596309661865234
# 6) Staring: Classifying Entire Neuron
# 36 = stub soma
# 164 = stub soma
# 78 = stub soma
# 79 = stub soma
# 83 = stub soma
# 84 = stub soma
# 89 = stub soma
# 91 = stub soma
# 94 = stub soma
# 98 = stub soma
# 133 = cilia
# 120 = stub soma
# 128 = stub soma
# 136 = stub soma
# 170 = stub soma
# 9 = stub apical
# 11 = stub apical
# 12 = stub apical
# 15 = stub apical
# 16 = stub apical
# 17 = stub apical
# 18 = stub apical
# 19 = stub apical
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 23 = stub apical
# 24 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = error
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 92 = stub apical
# 93 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 134 = stub apical
# 135 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# Total Labels found = {'basal', 'soma', 'error', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 0.6575429439544678
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.1418931484222412
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.600198268890381
# Finished Auto Labeling: 119.43364071846008
#
#
# *****Starting Auto Labeling for 648518346349511076******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.013846158981323242
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 125.28743577003479
# 2) Finished: Generating CGAL segmentation for neuron: 130.36068964004517
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.060699462890625
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 5, 3, 4, 7, 29, 21, 16, 33, 32, 20, 22, 17, 27, 35, 31, 37, 15, 18, 26, 25]
# soma_80_percent = 283143.159375
# Debugging the axon filter
# [(0, 279664.25), (5, 291813.40625), (3, 291892.84375), (4, 302093.78125), (7, 288169.0625), (29, 280020.34375), (21, 291110.0), (16, 290988.53125), (33, 291606.09375), (32, 289434.09375), (20, 294292.125), (22, 293320.1875), (17, 294783.4375), (27, 280513.71875), (35, 278767.625), (31, 294581.71875), (37, 278859.875), (15, 279993.0625), (18, 294692.34375), (26, 291284.9375), (25, 286430.46875)]
# possible_Axons_filter_1 = [0, 29, 27, 35, 37, 15]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.042135000228881836
# 6) Staring: Classifying Entire Neuron
# 7 = stub soma
# 15 = stub soma
# 16 = stub soma
# 17 = stub soma
# 18 = stub soma
# 20 = stub soma
# 21 = stub soma
# 22 = stub soma
# 25 = stub soma
# 26 = stub soma
# 27 = stub soma
# 29 = stub soma
# 31 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 32
# 33 = stub soma
# 35 = stub soma
# 37 = stub soma
# Total Labels found = {'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.4844181537628174
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.14743876457214355
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.629138708114624
# Finished Auto Labeling: 133.89443397521973
#
#
# *****Starting Auto Labeling for 648518346349511480******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.01580524444580078
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 191.12586379051208
# 2) Finished: Generating CGAL segmentation for neuron: 197.49512124061584
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.08138394355773926
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [2, 4, 32, 15, 40, 46, 23, 47, 35, 49, 30, 36, 37, 38, 48]
# soma_80_percent = 286290.3125
# Debugging the axon filter
# [(2, 298473.125), (4, 286515.5), (32, 290999.21875), (15, 286711.90625), (40, 293741.375), (46, 294641.84375), (23, 291336.15625), (47, 288879.78125), (35, 284015.71875), (49, 294122.65625), (30, 294823.625), (36, 285531.375), (37, 291554.03125), (38, 292111.0625), (48, 294489.0625)]
# possible_Axons_filter_1 = [35, 36]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.038602352142333984
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 4
# 35 = cilia
# 30 = stub soma
# 32 = stub soma
# 36 = stub soma
# 37 = stub soma
# 38 = stub soma
# 40 = stub soma
# 46 = stub soma
# 47 = stub soma
# 48 = stub soma
# 49 = stub soma
# Total Labels found = {'unsure', 'cilia', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.7809858322143555
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.27459144592285156
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.5516574382781982
# Finished Auto Labeling: 202.49360704421997
#
#
# *****Starting Auto Labeling for 648518346349511983******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04412841796875
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 595.5710873603821
# 2) Finished: Generating CGAL segmentation for neuron: 609.8815321922302
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19881057739257812
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [3, 12, 29, 500, 335, 21, 242, 533, 22, 450, 18, 505, 518, 353, 398, 314]
# soma_80_percent = 285327.9
# Debugging the axon filter
# [(3, 282479.28125), (12, 299380.5625), (29, 309100.25), (500, 295470.875), (335, 290848.875), (21, 303950.40625), (242, 285269.21875), (533, 286345.625), (22, 304509.5), (450, 290020.40625), (18, 302623.65625), (505, 281927.9375), (518, 294410.9375), (353, 290309.96875), (398, 282592.5), (314, 291660.21875)]
# possible_Axons_filter_1 = [3, 242, 505, 398]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.13608503341674805
# 6) Staring: Classifying Entire Neuron
# 22 = axon
# 505 = cilia
# 242 = stub soma
# 314 = stub soma
# 353 = stub soma
# 398 = stub soma
# 450 = stub soma
# 518 = stub soma
# 533 = stub soma
# 7 = stub apical
# 8 = stub apical
# 9 = stub apical
# 13 = error
# 14 = stub apical
# 24 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 34 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = error
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 146 = stub apical
# 150 = stub apical
# 152 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 213 = stub apical
# 214 = stub apical
# 220 = stub apical
# 222 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 291 = stub apical
# 292 = stub apical
# 295 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 351 = stub apical
# 352 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 392 = stub apical
# 393 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 402 = stub apical
# 403 = stub apical
# 404 = stub apical
# 405 = stub apical
# 406 = stub apical
# 407 = stub apical
# 408 = stub apical
# 413 = stub apical
# 414 = stub apical
# 415 = stub apical
# 416 = stub apical
# 417 = stub apical
# 418 = stub apical
# 419 = stub apical
# 420 = stub apical
# 421 = stub apical
# 422 = stub apical
# 423 = stub apical
# 424 = stub apical
# 425 = stub apical
# 426 = stub apical
# 427 = stub apical
# 428 = stub apical
# 429 = stub apical
# 430 = stub apical
# 431 = stub apical
# 432 = stub apical
# 433 = stub apical
# 434 = stub apical
# 435 = stub apical
# 437 = stub apical
# 438 = stub apical
# 439 = stub apical
# 440 = stub apical
# 441 = stub apical
# 442 = stub apical
# 443 = stub apical
# 446 = stub apical
# 447 = stub apical
# 448 = stub apical
# 449 = stub apical
# 451 = stub apical
# 452 = stub apical
# 453 = stub apical
# 454 = stub apical
# 455 = stub apical
# 456 = stub apical
# 457 = stub apical
# 458 = stub apical
# 459 = stub apical
# 460 = stub apical
# 461 = stub apical
# 462 = stub apical
# 463 = stub apical
# 464 = stub apical
# 465 = stub apical
# 466 = stub apical
# 467 = stub apical
# 468 = stub apical
# 469 = stub apical
# 470 = stub apical
# 471 = stub apical
# 472 = stub apical
# 473 = stub apical
# 475 = stub apical
# 476 = stub apical
# 477 = stub apical
# 478 = stub apical
# 479 = stub apical
# 480 = stub apical
# 481 = stub apical
# 482 = stub apical
# 483 = stub apical
# 484 = stub apical
# 485 = stub apical
# 486 = stub apical
# 487 = stub apical
# 488 = stub apical
# 489 = stub apical
# 490 = stub apical
# 491 = stub apical
# 492 = stub apical
# 493 = stub apical
# 494 = stub apical
# 495 = stub apical
# 496 = stub apical
# 497 = stub apical
# 498 = stub apical
# 499 = stub apical
# 501 = stub apical
# 502 = stub apical
# 503 = stub apical
# 504 = stub apical
# 507 = stub apical
# 508 = stub apical
# 509 = stub apical
# 510 = stub apical
# 511 = stub apical
# 512 = stub apical
# 513 = stub apical
# 514 = stub apical
# 515 = stub apical
# 516 = stub apical
# 517 = stub apical
# 519 = stub apical
# 520 = stub apical
# 521 = stub apical
# 524 = stub apical
# 525 = stub apical
# 526 = stub apical
# 527 = stub apical
# 528 = stub apical
# 529 = stub apical
# 530 = stub apical
# 531 = stub apical
# 532 = stub apical
# 534 = stub apical
# 535 = stub apical
# 536 = stub apical
# 537 = stub apical
# 538 = stub apical
# 539 = stub apical
# 540 = stub apical
# 541 = stub apical
# 542 = stub apical
# 543 = stub apical
# 545 = stub apical
# 546 = stub apical
# 547 = stub apical
# 548 = stub apical
# 549 = stub apical
# 550 = stub apical
# 551 = stub apical
# 552 = stub apical
# 553 = stub apical
# 554 = stub apical
# 555 = stub apical
# 556 = stub apical
# Total Labels found = {'basal', 'soma', 'error', 'axon', 'apical', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.162738084793091
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.36447596549987793
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.783202409744263
# Finished Auto Labeling: 622.1148204803467
# 6863.445960044861

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
