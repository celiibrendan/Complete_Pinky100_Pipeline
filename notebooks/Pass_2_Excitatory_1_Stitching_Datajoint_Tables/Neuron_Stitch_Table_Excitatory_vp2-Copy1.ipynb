# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349471156**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349471156_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.5749082565307617
# Number of outside child meshes =  16
# Main mesh and outside child meshes make up 0.9091623556691989% of original mesh
#  face length 1551161 using optimized facets with 3 neighbors
# Filtering edges by size finished: 19.543758869171143, facet # = 80603
# Filtering by convexity and getting centers took: 28.320800065994263, facet # = 17857
# Finished facets for main mesh: 50.250219106674194 with facet length = 17857
# Finished 17857 facets for main mesh: 50.25028085708618
# Filtering edges by size finished: 0.015682458877563477, facet # = 83
# Filtering by convexity and getting centers took: 0.02355813980102539, facet # = 30
# Filtering edges by size finished: 0.021681547164916992, facet # = 129
# Filtering by convexity and getting centers took: 0.03734540939331055, facet # = 44
# Filtering edges by size finished: 0.08089017868041992, facet # = 536
# Filtering by convexity and getting centers took: 0.17546558380126953, facet # = 161
# Filtering edges by size finished: 0.06290674209594727, facet # = 367
# Filtering by convexity and getting centers took: 0.14287495613098145, facet # = 105
# Filtering edges by size finished: 0.08707404136657715, facet # = 458
# Filtering by convexity and getting centers took: 0.17111587524414062, facet # = 157
# Filtering edges by size finished: 0.0013241767883300781, facet # = 10
# Filtering by convexity and getting centers took: 0.0037508010864257812, facet # = 6
# Filtering edges by size finished: 0.0008096694946289062, facet # = 2
# Filtering by convexity and getting centers took: 0.0011284351348876953, facet # = 2
# Filtering edges by size finished: 0.0014541149139404297, facet # = 11
# Filtering by convexity and getting centers took: 0.003756284713745117, facet # = 4
# Filtering edges by size finished: 0.016364574432373047, facet # = 123
# Filtering by convexity and getting centers took: 0.03243112564086914, facet # = 29
# Filtering edges by size finished: 0.0015761852264404297, facet # = 14
# Filtering by convexity and getting centers took: 0.005204916000366211, facet # = 11
# Filtering edges by size finished: 0.0018568038940429688, facet # = 16
# Filtering by convexity and getting centers took: 0.0054454803466796875, facet # = 7
# Filtering edges by size finished: 0.0010843276977539062, facet # = 6
# Filtering by convexity and getting centers took: 0.0027327537536621094, facet # = 6
# Filtering edges by size finished: 0.0019278526306152344, facet # = 12
# Filtering by convexity and getting centers took: 0.00481414794921875, facet # = 12
# Filtering edges by size finished: 0.0034105777740478516, facet # = 27
# Filtering by convexity and getting centers took: 0.0077397823333740234, facet # = 8
# Filtering edges by size finished: 0.0014317035675048828, facet # = 8
# Filtering by convexity and getting centers took: 0.0032765865325927734, facet # = 7
# Filtering edges by size finished: 0.0008254051208496094, facet # = 4
# Filtering by convexity and getting centers took: 0.0020051002502441406, facet # = 4
# Total time for facets: 51.21028161048889
# Zero faceted faces = []
# Starting Child 0
# 30 17857
# Done distance matrix: 0.01818537712097168
# Done Generating final pairs: 0.0310823917388916
# best_stitch_pair = [    4 12267]
# best_stitch_pair_size = 156560.9839119391
# best_stitch_pair_distance = 246.14279593358984
# best_stitch_pair_size_ratio = 0.36015529567488974
# Starting Child 1
# 44 17857
# Done distance matrix: 0.025794506072998047
# Child 1 There were no points close enough
# Starting Child 2
# 161 17857
# Done distance matrix: 0.09419989585876465
# Child 2 There were no points close enough
# Starting Child 3
# 105 17857
# Done distance matrix: 0.062018394470214844
# Done Generating final pairs: 0.07180309295654297
# best_stitch_pair = [  59 8285]
# best_stitch_pair_size = 37997.51669594228
# best_stitch_pair_distance = 1652.0254300812862
# best_stitch_pair_size_ratio = 0.6479381683240787
# Starting Child 4
# 157 17857
# Done distance matrix: 0.0895688533782959
# Child 4 There were no points close enough
# Starting Child 5
# 6 17857
# Done distance matrix: 0.004236936569213867
# Done Generating final pairs: 0.01473855972290039
# best_stitch_pair = [    0 12256]
# best_stitch_pair_size = 144646.36498421727
# best_stitch_pair_distance = 646.3181433832783
# best_stitch_pair_size_ratio = 0.6712034744321982
# Starting Child 6
# 2 17857
# Done distance matrix: 0.0013885498046875
# Child 6 There were no points close enough
# Starting Child 7
# 4 17857
# Done distance matrix: 0.0026166439056396484
# Child 7 There were no points close enough
# Starting Child 8
# 29 17857
# Done distance matrix: 0.016217947006225586
# Done Generating final pairs: 0.02557969093322754
# best_stitch_pair = [    5 11853]
# best_stitch_pair_size = 37419.98899146877
# best_stitch_pair_distance = 1572.9922764080663
# best_stitch_pair_size_ratio = 0.6012791262670371
# Starting Child 9
# 11 17857
# Done distance matrix: 0.00685882568359375
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 7 17857
# Done distance matrix: 0.006413936614990234
# Done Generating final pairs: 0.01767897605895996
# best_stitch_pair = [   2 3776]
# best_stitch_pair_size = 68234.16725037713
# best_stitch_pair_distance = 1928.6212862702591
# best_stitch_pair_size_ratio = 0.35058777785176015
# Starting Child 11
# 6 17857
# Done distance matrix: 0.005257129669189453
# Child 11 There were no points close enough
# Starting Child 12
# 12 17857
# Done distance matrix: 0.010224103927612305
# Done Generating final pairs: 0.03089737892150879
# best_stitch_pair = [   1 4605]
# best_stitch_pair_size = 228261.52011690458
# best_stitch_pair_distance = 699.3050435242407
# best_stitch_pair_size_ratio = 0.5397551111463933
# Starting Child 13
# 8 17857
# Done distance matrix: 0.005057573318481445
# Done Generating final pairs: 0.014013290405273438
# best_stitch_pair = [   0 4440]
# best_stitch_pair_size = 65914.72407522351
# best_stitch_pair_distance = 297.4528892181922
# best_stitch_pair_size_ratio = 0.8299432323747085
# Starting Child 14
# 7 17857
# Done distance matrix: 0.004428386688232422
# Done Generating final pairs: 0.01401662826538086
# best_stitch_pair = [   3 6204]
# best_stitch_pair_size = 61997.11989806198
# best_stitch_pair_distance = 648.0548355571992
# best_stitch_pair_size_ratio = 0.28675355358049714
# Starting Child 15
# 4 17857
# Done distance matrix: 0.002570629119873047
# Done Generating final pairs: 0.011461973190307617
# best_stitch_pair = [   0 6204]
# best_stitch_pair_size = 85604.18655606585
# best_stitch_pair_distance = 1715.5664325826483
# best_stitch_pair_size_ratio = 0.7767194900908432
# repeat_main_facets = [6204]
# child_mesh_double_indexes = [14, 15]
# min_child = 14, max_ratio = 648.0548355571992
# child_meshes_stitch_facets = {0: [4, 12267], 3: [59, 8285], 5: [0, 12256], 8: [5, 11853], 10: [2, 3776], 12: [1, 4605], 13: [0, 4440], 14: [3, 6204]}
# ---Stitching child 0 with pair: [4, 12267]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 734195, starting edge 2nd facet= 777081,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022217750549316406
# returned from stitch mesh: 0.7420847415924072
# Finished stitching child 0 : 0.8724117279052734
# ---Stitching child 3 with pair: [59, 8285]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 168894, starting edge 2nd facet= 777324,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004221677780151367
# returned from stitch mesh: 0.762406587600708
# Finished stitching child 3 : 0.893258810043335
# ---Stitching child 5 with pair: [0, 12256]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 486231, starting edge 2nd facet= 778606,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023328065872192383
# returned from stitch mesh: 0.7640635967254639
# Finished stitching child 5 : 0.9008169174194336
# ---Stitching child 8 with pair: [5, 11853]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 471203, starting edge 2nd facet= 778973,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02345752716064453
# returned from stitch mesh: 0.7663583755493164
# Finished stitching child 8 : 0.9000527858734131
# ---Stitching child 10 with pair: [2, 3776]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 614255, starting edge 2nd facet= 779122,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6927719116210938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023363351821899414
# returned from stitch mesh: 0.7729249000549316
# Finished stitching child 10 : 0.91068434715271
# ---Stitching child 12 with pair: [1, 4605]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 496539, starting edge 2nd facet= 779134,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02369379997253418
# returned from stitch mesh: 0.7842156887054443
# Finished stitching child 12 : 0.9167907238006592
# ---Stitching child 13 with pair: [0, 4440]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 690387, starting edge 2nd facet= 779222,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.430511474609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.024007558822631836
# returned from stitch mesh: 0.7748470306396484
# Finished stitching child 13 : 0.9362137317657471
# ---Stitching child 14 with pair: [3, 6204]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 325541, starting edge 2nd facet= 779288,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02519392967224121
# returned from stitch mesh: 0.8633425235748291
# Finished stitching child 14 : 1.0221452713012695
# ***************Finished big stitching iteration: 8.22855520248413***************
# Starting Child 1
# 44 18045
# Done distance matrix: 0.026939868927001953
# Done Generating final pairs: 0.03225135803222656
# best_stitch_pair = [   12 17851]
# best_stitch_pair_size = 236097.75069403264
# best_stitch_pair_distance = 426.6109767899908
# best_stitch_pair_size_ratio = 0.6734185517286417
# Starting Child 2
# 161 18045
# Done distance matrix: 0.0990748405456543
# Done Generating final pairs: 0.10145282745361328
# best_stitch_pair = [   53 17920]
# best_stitch_pair_size = 93187.30701634835
# best_stitch_pair_distance = 1462.6303075981539
# best_stitch_pair_size_ratio = 0.25048174897882497
# Starting Child 4
# 157 18045
# Done distance matrix: 0.09926080703735352
# Child 4 There were no points close enough
# Starting Child 6
# 2 18045
# Done distance matrix: 0.0032846927642822266
# Child 6 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 7
# 4 18045
# Done distance matrix: 0.0026717185974121094
# Child 7 There were no points close enough
# Starting Child 9
# 11 18045
# Done distance matrix: 0.0075414180755615234
# Done Generating final pairs: 0.009005308151245117
# best_stitch_pair = [   10 18019]
# best_stitch_pair_size = 32299.114973522606
# best_stitch_pair_distance = 733.2855680301902
# best_stitch_pair_size_ratio = 0.7886989976192894
# Starting Child 11
# 6 18045
# Done distance matrix: 0.004065275192260742
# Done Generating final pairs: 0.005644798278808594
# best_stitch_pair = [    3 18019]
# best_stitch_pair_size = 63137.97977584103
# best_stitch_pair_distance = 1852.2829231307553
# best_stitch_pair_size_ratio = 0.40055588893860006
# Starting Child 15
# 4 18045
# Done distance matrix: 0.002744913101196289
# Done Generating final pairs: 0.004121303558349609
# best_stitch_pair = [    0 18042]
# best_stitch_pair_size = 58080.30444153187
# best_stitch_pair_distance = 1126.0719056899395
# best_stitch_pair_size_ratio = 0.5519886571308783
# repeat_main_facets = [18019]
# child_mesh_double_indexes = [9, 11]
# min_child = 9, max_ratio = 733.2855680301902
# child_meshes_stitch_facets = {1: [12, 17851], 2: [53, 17920], 9: [10, 18019], 15: [0, 18042]}
# ---Stitching child 1 with pair: [12, 17851]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 777068, starting edge 2nd facet= 779634,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02533888816833496
# returned from stitch mesh: 0.7733299732208252
# Finished stitching child 1 : 0.9083325862884521
# ---Stitching child 2 with pair: [53, 17920]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 778506, starting edge 2nd facet= 779988,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0265579223632812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.16626286506652832
# returned from stitch mesh: 0.9986286163330078
# Finished stitching child 2 : 1.146118402481079
# ---Stitching child 9 with pair: [10, 18019]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 779109, starting edge 2nd facet= 781784,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.0728836059570312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0042073726654052734
# returned from stitch mesh: 0.6541287899017334
# Finished stitching child 9 : 0.7238621711730957
# ---Stitching child 15 with pair: [0, 18042]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 779277, starting edge 2nd facet= 781815,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02251887321472168
# returned from stitch mesh: 0.7886440753936768
# Finished stitching child 15 : 0.9094359874725342
# ***************Finished big stitching iteration: 4.90748143196106***************
# Starting Child 4
# 157 18257
# Done distance matrix: 0.10006117820739746
# Done Generating final pairs: 0.10307478904724121
# best_stitch_pair = [   49 18238]
# best_stitch_pair_size = 24127.17395928808
# best_stitch_pair_distance = 1901.8317949801876
# best_stitch_pair_size_ratio = 0.9640063540681695
# Starting Child 6
# 2 18257
# Done distance matrix: 0.0014693737030029297
# Child 6 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 7
# 4 18257
# Done distance matrix: 0.0028879642486572266
# Done Generating final pairs: 0.006978511810302734
# best_stitch_pair = [    1 18148]
# best_stitch_pair_size = 83599.66778866976
# best_stitch_pair_distance = 181.74714422553652
# best_stitch_pair_size_ratio = 0.31781305467139015
# Starting Child 11
# 6 18257
# Done distance matrix: 0.004410505294799805
# Done Generating final pairs: 0.007089376449584961
# best_stitch_pair = [    3 18246]
# best_stitch_pair_size = 78889.35642976053
# best_stitch_pair_distance = 1336.215479386267
# best_stitch_pair_size_ratio = 0.7499602159357429
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [49, 18238], 7: [1, 18148], 11: [3, 18246]}
# ---Stitching child 4 with pair: [49, 18238]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 780460, starting edge 2nd facet= 783048,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.3589859008789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028534889221191406
# returned from stitch mesh: 0.9040446281433105
# Finished stitching child 4 : 1.0568351745605469
# ---Stitching child 7 with pair: [1, 18148]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 781170, starting edge 2nd facet= 783946,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028254032135009766
# returned from stitch mesh: 1.010450839996338
# Finished stitching child 7 : 1.176309585571289
# ---Stitching child 11 with pair: [3, 18246]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 781776, starting edge 2nd facet= 783970,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.5497207641601562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02749943733215332
# returned from stitch mesh: 0.8613481521606445
# Finished stitching child 11 : 1.0186562538146973
# ***************Finished big stitching iteration: 4.375239610671997***************
# Starting Child 6
# 2 18418
# Done distance matrix: 0.0019407272338867188
# Child 6 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 6
# 2 18418
# Done distance matrix: 0.0015301704406738281
# Child 6 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 6
# 2 18418
# Done distance matrix: 0.0017306804656982422
# Done Generating final pairs: 0.0028836727142333984
# best_stitch_pair = [   1 7909]
# best_stitch_pair_size = 52501.08230253985
# best_stitch_pair_distance = 3035.0803851173905
# best_stitch_pair_size_ratio = 0.8571144840820261
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [1, 7909]}
# ---Stitching child 6 with pair: [1, 7909]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 438550, starting edge 2nd facet= 783997,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.430511474609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.025565624237060547
# returned from stitch mesh: 0.8461809158325195
# Finished stitching child 6 : 0.9871091842651367
# ***************Finished big stitching iteration: 1.0966770648956299***************
# All children have been processed
# total_stitch_processing_time = 19.526691913604736
# Total time for restitching = 19.52959394454956
# missed_children = []
# Whole stitching function complete: 74.0187873840332
#
#
#
# *****Running Neuron Stitcher for 648518346349473804**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473804_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 6.254246950149536
# Number of outside child meshes =  25
# Main mesh and outside child meshes make up 0.9515716295595719% of original mesh
#  face length 3573241 using optimized facets with 3 neighbors
# Filtering edges by size finished: 72.43618583679199, facet # = 189590
# Filtering by convexity and getting centers took: 114.16170907020569, facet # = 38551
# Finished facets for main mesh: 192.5499906539917 with facet length = 38551
# Finished 38551 facets for main mesh: 192.55044293403625
# Filtering edges by size finished: 0.04916739463806152, facet # = 36
# Filtering by convexity and getting centers took: 0.04287266731262207, facet # = 15
# Filtering edges by size finished: 0.023365259170532227, facet # = 28
# Filtering by convexity and getting centers took: 0.04040861129760742, facet # = 12
# Filtering edges by size finished: 0.022015094757080078, facet # = 69
# Filtering by convexity and getting centers took: 0.03380274772644043, facet # = 41
# Filtering edges by size finished: 0.4795076847076416, facet # = 1163
# Filtering by convexity and getting centers took: 0.6661772727966309, facet # = 330
# Filtering edges by size finished: 0.02100062370300293, facet # = 61
# Filtering by convexity and getting centers took: 0.026314496994018555, facet # = 19
# Filtering edges by size finished: 0.008713722229003906, facet # = 37
# Filtering by convexity and getting centers took: 0.012630224227905273, facet # = 10
# Filtering edges by size finished: 0.0028846263885498047, facet # = 16
# Filtering by convexity and getting centers took: 0.005894660949707031, facet # = 10
# Filtering edges by size finished: 0.7600533962249756, facet # = 2429
# Filtering by convexity and getting centers took: 1.0071299076080322, facet # = 289
# Filtering edges by size finished: 0.002904653549194336, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0024213790893554688, facet # = 2
# Filtering edges by size finished: 0.0038843154907226562, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0027785301208496094, facet # = 2
# Filtering edges by size finished: 0.0020627975463867188, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002144336700439453, facet # = 2
# Filtering edges by size finished: 0.0024085044860839844, facet # = 11
# Filtering by convexity and getting centers took: 0.00574946403503418, facet # = 7
# Filtering edges by size finished: 0.0027811527252197266, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002310037612915039, facet # = 2
# Filtering edges by size finished: 0.004697084426879883, facet # = 24
# Filtering by convexity and getting centers took: 0.009297370910644531, facet # = 10
# Filtering edges by size finished: 0.0020439624786376953, facet # = 10
# Filtering by convexity and getting centers took: 0.0038487911224365234, facet # = 5
# Filtering edges by size finished: 0.0021605491638183594, facet # = 20
# Filtering by convexity and getting centers took: 0.006232261657714844, facet # = 13
# Filtering edges by size finished: 0.001378774642944336, facet # = 7
# Filtering by convexity and getting centers took: 0.003567934036254883, facet # = 7
# Filtering edges by size finished: 0.0005755424499511719, facet # = 5
# Filtering by convexity and getting centers took: 0.0022192001342773438, facet # = 4
# Filtering edges by size finished: 0.006034135818481445, facet # = 24
# Filtering by convexity and getting centers took: 0.010588407516479492, facet # = 1
# Filtering edges by size finished: 0.0024802684783935547, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002664804458618164, facet # = 2
# Filtering edges by size finished: 0.0019421577453613281, facet # = 2
# Filtering by convexity and getting centers took: 0.0022385120391845703, facet # = 2
# Filtering edges by size finished: 0.002356290817260742, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0026569366455078125, facet # = 2
# Filtering edges by size finished: 0.00238037109375, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0025599002838134766, facet # = 2
# Filtering edges by size finished: 0.002483844757080078, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002701282501220703, facet # = 2
# Filtering edges by size finished: 0.0042150020599365234, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003499746322631836, facet # = 2
# Total time for facets: 196.06447553634644
# Zero faceted faces = []
# Starting Child 0
# 15 38551
# Done distance matrix: 0.06249094009399414
# Child 0 There were no points close enough
# Starting Child 1
# 12 38551
# Done distance matrix: 0.020833969116210938
# Child 1 There were no points close enough
# Starting Child 2
# 41 38551
# Done distance matrix: 0.19278740882873535
# Child 2 There were no points close enough
# Starting Child 3
# 330 38551
# Done distance matrix: 0.8051602840423584
# Done Generating final pairs: 0.8849661350250244
# best_stitch_pair = [  291 19143]
# best_stitch_pair_size = 98124.59310013101
# best_stitch_pair_distance = 237.35534318475422
# best_stitch_pair_size_ratio = 0.8080573859985348
# Starting Child 4
# 19 38551
# Done distance matrix: 0.03994321823120117
# Child 4 There were no points close enough
# Starting Child 5
# 10 38551
# Done distance matrix: 0.03165435791015625
# Done Generating final pairs: 0.13199234008789062
# best_stitch_pair = [    9 26406]
# best_stitch_pair_size = 487588.54338328255
# best_stitch_pair_distance = 467.1209977653434
# best_stitch_pair_size_ratio = 0.45593090904712213
# Starting Child 6
# 10 38551
# Done distance matrix: 0.014930248260498047
# Done Generating final pairs: 0.051613807678222656
# best_stitch_pair = [    3 26406]
# best_stitch_pair_size = 580134.2193309644
# best_stitch_pair_distance = 736.3194541182538
# best_stitch_pair_size_ratio = 0.7322706876152429
# Starting Child 7
# 289 38551
# Done distance matrix: 0.8570778369903564
# Done Generating final pairs: 1.0495152473449707
# best_stitch_pair = [   31 32135]
# best_stitch_pair_size = 570916.8003322248
# best_stitch_pair_distance = 1044.15855439402
# best_stitch_pair_size_ratio = 0.8403363947875828
# Starting Child 8
# 2 38551
# Done distance matrix: 0.01081991195678711
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# 2 38551
# Done distance matrix: 0.002966642379760742
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 2 38551
# Done distance matrix: 0.004061460494995117
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 7 38551
# Done distance matrix: 0.03308463096618652
# Done Generating final pairs: 0.07586073875427246
# best_stitch_pair = [    2 35345]
# best_stitch_pair_size = 112917.650466757
# best_stitch_pair_distance = 1655.0316052133826
# best_stitch_pair_size_ratio = 0.9505668979082901
# Starting Child 12
# 2 38551
# Done distance matrix: 0.0037331581115722656
# Done Generating final pairs: 0.04165339469909668
# best_stitch_pair = [    0 38421]
# best_stitch_pair_size = 33488.57715699496
# best_stitch_pair_distance = 993.1175106343959
# best_stitch_pair_size_ratio = 0.6818181818181807
# Starting Child 13
# 10 38551
# Done distance matrix: 0.04554009437561035
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 5 38551
# Done distance matrix: 0.011771917343139648
# Child 14 There were no points close enough
# Starting Child 15
# 13 38551
# Done distance matrix: 0.022657394409179688
# Child 15 There were no points close enough
# Starting Child 16
# 7 38551
# Done distance matrix: 0.009638071060180664
# Child 16 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 4 38551
# Done distance matrix: 0.0055844783782958984
# Done Generating final pairs: 0.03591656684875488
# best_stitch_pair = [    1 36257]
# best_stitch_pair_size = 56695.09029114919
# best_stitch_pair_distance = 1975.181385174855
# best_stitch_pair_size_ratio = 0.7031890119638233
# Starting Child 18
# 1 38551
# Done distance matrix: 0.0014646053314208984
# Child 18 There were no points close enough
# Starting Child 19
# 2 38551
# Done distance matrix: 0.0038089752197265625
# Child 19 There were no points close enough
# Starting Child 20
# 2 38551
# Done distance matrix: 0.0030448436737060547
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 2 38551
# Done distance matrix: 0.0037043094635009766
# Child 21 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 22
# 2 38551
# Done distance matrix: 0.003766775131225586
# Done Generating final pairs: 0.08172035217285156
# best_stitch_pair = [    1 32243]
# best_stitch_pair_size = 21269.672509839525
# best_stitch_pair_distance = 938.5108214388032
# best_stitch_pair_size_ratio = 0.8076838540053645
# Starting Child 23
# 2 38551
# Done distance matrix: 0.0029036998748779297
# Done Generating final pairs: 0.02573108673095703
# best_stitch_pair = [    0 32188]
# best_stitch_pair_size = 23137.328960049523
# best_stitch_pair_distance = 1236.1197031978124
# best_stitch_pair_size_ratio = 0.8259556033699696
# Starting Child 24
# 2 38551
# Done distance matrix: 0.0037834644317626953
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [26406]
# child_mesh_double_indexes = [5, 6]
# min_child = 5, max_ratio = 467.1209977653434
# child_meshes_stitch_facets = {3: [291, 19143], 5: [9, 26406], 7: [31, 32135], 11: [2, 35345], 12: [0, 38421], 17: [1, 36257], 22: [1, 32243], 23: [0, 32188]}
# ---Stitching child 3 with pair: [291, 19143]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 598955, starting edge 2nd facet= 1793132,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11941218376159668
# returned from stitch mesh: 2.3921027183532715
# Finished stitching child 3 : 3.0566561222076416
# ---Stitching child 5 with pair: [9, 26406]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 767212, starting edge 2nd facet= 1796387,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 3.218650817871094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06112408638000488
# returned from stitch mesh: 2.9252657890319824
# Finished stitching child 5 : 3.4447147846221924
# ---Stitching child 7 with pair: [31, 32135]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1049896, starting edge 2nd facet= 1802446,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 35
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 13
# About to add faces
# Finished adding faces: 6.985664367675781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07467103004455566
# returned from stitch mesh: 3.04994797706604
# Finished stitching child 7 : 3.4345669746398926
# ---Stitching child 11 with pair: [2, 35345]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 819724, starting edge 2nd facet= 1805998,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06893301010131836
# returned from stitch mesh: 3.064377784729004
# Finished stitching child 11 : 3.49589204788208
# ---Stitching child 12 with pair: [0, 38421]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 221932, starting edge 2nd facet= 1806048,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 9
# About to add faces
# Finished adding faces: 3.695487976074219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06254243850708008
# returned from stitch mesh: 2.732597589492798
# Finished stitching child 12 : 3.1567726135253906
# ---Stitching child 17 with pair: [1, 36257]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1325441, starting edge 2nd facet= 1806092,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0584263801574707
# returned from stitch mesh: 2.3179688453674316
# Finished stitching child 17 : 2.901676654815674
# ---Stitching child 22 with pair: [1, 32243]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 3279, starting edge 2nd facet= 1806100,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 4.482269287109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.18611526489257812
# returned from stitch mesh: 4.0747857093811035
# Finished stitching child 22 : 4.463802337646484
# ---Stitching child 23 with pair: [0, 32188]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1542901, starting edge 2nd facet= 1806162,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 4
# About to add faces
# Finished adding faces: 3.361701965332031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.2781994342803955
# returned from stitch mesh: 4.098323345184326
# Finished stitching child 23 : 4.595142364501953
# ***************Finished big stitching iteration: 33.62945771217346***************
# Starting Child 0
# 15 39181
# Done distance matrix: 0.02635502815246582
# Child 0 There were no points close enough
# Starting Child 1
# 12 39181
# Done distance matrix: 0.02110767364501953
# Done Generating final pairs: 0.023278236389160156
# best_stitch_pair = [    1 39170]
# best_stitch_pair_size = 213494.099682147
# best_stitch_pair_distance = 1998.0727015827074
# best_stitch_pair_size_ratio = 0.21050981625007512
# Starting Child 2
# 41 39181
# Done distance matrix: 0.07567119598388672
# Child 2 There were no points close enough
# Starting Child 4
# 19 39181
# Done distance matrix: 0.030971050262451172
# Child 4 There were no points close enough
# Starting Child 6
# 10 39181
# Done distance matrix: 0.016359567642211914
# Done Generating final pairs: 0.021659374237060547
# best_stitch_pair = [    3 38878]
# best_stitch_pair_size = 462993.4202409012
# best_stitch_pair_distance = 117.07356331132964
# best_stitch_pair_size_ratio = 0.8879498012859491
# Starting Child 8
# 2 39181
# Done distance matrix: 0.00394749641418457
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# 2 39181
# Done distance matrix: 0.0038161277770996094
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 2 39181
# Done distance matrix: 0.003736257553100586
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 10 39181
# Done distance matrix: 0.015892744064331055
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 5 39181
# Done distance matrix: 0.011189937591552734
# Child 14 There were no points close enough
# Starting Child 15
# 13 39181
# Done distance matrix: 0.02176833152770996
# Child 15 There were no points close enough
# Starting Child 16
# 7 39181
# Done distance matrix: 0.015229463577270508
# Done Generating final pairs: 0.019256591796875
# best_stitch_pair = [    1 39170]
# best_stitch_pair_size = 119234.79730609496
# best_stitch_pair_distance = 1032.7216333684041
# best_stitch_pair_size_ratio = 0.4521739482973859
# Starting Child 18
# 1 39181
# Done distance matrix: 0.00177764892578125
# Child 18 There were no points close enough
# Starting Child 19
# 2 39181
# Done distance matrix: 0.0038475990295410156
# Child 19 There were no points close enough
# Starting Child 20
# 2 39181
# Done distance matrix: 0.0038928985595703125
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 2 39181
# Done distance matrix: 0.003882884979248047
# Child 21 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 39181
# Done distance matrix: 0.0038900375366210938
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [39170]
# child_mesh_double_indexes = [1, 16]
# min_child = 16, max_ratio = 1032.7216333684041
# child_meshes_stitch_facets = {6: [3, 38878], 16: [1, 39170]}
# ---Stitching child 6 with pair: [3, 38878]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1796427, starting edge 2nd facet= 1806169,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 3.5762786865234375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08762383460998535
# returned from stitch mesh: 2.7205660343170166
# Finished stitching child 6 : 3.4195570945739746
# ---Stitching child 16 with pair: [1, 39170]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1805996, starting edge 2nd facet= 1806217,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12631440162658691
# returned from stitch mesh: 3.973440170288086
# Finished stitching child 16 : 4.472171783447266
# ***************Finished big stitching iteration: 12.72640323638916***************
# Starting Child 0
# 15 39194
# Done distance matrix: 0.024155139923095703
# Child 0 There were no points close enough
# Starting Child 1
# 12 39194
# Done distance matrix: 0.021810293197631836
# Done Generating final pairs: 0.025716543197631836
# best_stitch_pair = [    1 39188]
# best_stitch_pair_size = 263809.9877476784
# best_stitch_pair_distance = 1130.2752454409997
# best_stitch_pair_size_ratio = 0.4958004941064947
# Starting Child 2
# 41 39194
# Done distance matrix: 0.06626725196838379
# Child 2 There were no points close enough
# Starting Child 4
# 19 39194
# Done distance matrix: 0.03564047813415527
# Child 4 There were no points close enough
# Starting Child 8
# 2 39194
# Done distance matrix: 0.0038106441497802734
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# 2 39194
# Done distance matrix: 0.003728151321411133
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 2 39194
# Done distance matrix: 0.003573179244995117
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 10 39194
# Done distance matrix: 0.012445211410522461
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 5 39194
# Done distance matrix: 0.007245302200317383
# Child 14 There were no points close enough
# Starting Child 15
# 13 39194
# Done distance matrix: 0.017055034637451172
# Child 15 There were no points close enough
# Starting Child 18
# 1 39194
# Done distance matrix: 0.0016903877258300781
# Child 18 There were no points close enough
# Starting Child 19
# 2 39194
# Done distance matrix: 0.003719329833984375
# Child 19 There were no points close enough
# Starting Child 20
# 2 39194
# Done distance matrix: 0.003711223602294922
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 2 39194
# Done distance matrix: 0.003702402114868164
# Child 21 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 39194
# Done distance matrix: 0.0037810802459716797
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [1, 39188]}
# ---Stitching child 1 with pair: [1, 39188]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1806231, starting edge 2nd facet= 1806326,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0619659423828125
# returned from stitch mesh: 2.7767789363861084
# Finished stitching child 1 : 3.4621899127960205
# ***************Finished big stitching iteration: 7.214565277099609***************
# Starting Child 0
# 15 39204
# Done distance matrix: 0.07129597663879395
# Child 0 There were no points close enough
# Starting Child 2
# 41 39204
# Done distance matrix: 0.06484055519104004
# Done Generating final pairs: 0.07026290893554688
# best_stitch_pair = [   30 39202]
# best_stitch_pair_size = 165566.91222643584
# best_stitch_pair_distance = 1957.573803560799
# best_stitch_pair_size_ratio = 0.16872036114195244
# Starting Child 4
# 19 39204
# Done distance matrix: 0.030073165893554688
# Child 4 There were no points close enough
# Starting Child 8
# 2 39204
# Done distance matrix: 0.0037543773651123047
# Child 8 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# 2 39204
# Done distance matrix: 0.003701925277709961
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 2 39204
# Done distance matrix: 0.003634929656982422
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 10 39204
# Done distance matrix: 0.015339851379394531
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 5 39204
# Done distance matrix: 0.008828401565551758
# Child 14 There were no points close enough
# Starting Child 15
# 13 39204
# Done distance matrix: 0.020146608352661133
# Child 15 There were no points close enough
# Starting Child 18
# 1 39204
# Done distance matrix: 0.0015773773193359375
# Child 18 There were no points close enough
# Starting Child 19
# 2 39204
# Done distance matrix: 0.003490447998046875
# Child 19 There were no points close enough
# Starting Child 20
# 2 39204
# Done distance matrix: 0.00341796875
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 2 39204
# Done distance matrix: 0.0034580230712890625
# Child 21 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# 2 39204
# Done distance matrix: 0.003407716751098633
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [30, 39202]}
# ---Stitching child 2 with pair: [30, 39202]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1806241, starting edge 2nd facet= 1806428,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# ...
# best_stitch_pair_size = 942899.670407396
# best_stitch_pair_distance = 1729.728070388922
# best_stitch_pair_size_ratio = 0.32671828853355545
# Starting Child 27
# 13 45624
# Done distance matrix: 0.018233299255371094
# Done Generating final pairs: 0.06424570083618164
# best_stitch_pair = [   1 1725]
# best_stitch_pair_size = 753666.627406013
# best_stitch_pair_distance = 1283.469122947377
# best_stitch_pair_size_ratio = 0.24500421752868162
# Starting Child 28
# 57 45624
# Done distance matrix: 0.13845467567443848
# Done Generating final pairs: 0.18485808372497559
# best_stitch_pair = [    4 21764]
# best_stitch_pair_size = 671870.6180309497
# best_stitch_pair_distance = 225.7551453980212
# best_stitch_pair_size_ratio = 0.9101620446488751
# Starting Child 29
# 13 45624
# Done distance matrix: 0.018229961395263672
# Child 29 There were no points close enough
# Starting Child 30
# 35 45624
# Done distance matrix: 0.05962514877319336
# Done Generating final pairs: 0.10488724708557129
# best_stitch_pair = [  2 476]
# best_stitch_pair_size = 879115.7752985044
# best_stitch_pair_distance = 1362.1840603550374
# best_stitch_pair_size_ratio = 0.2966612041842626
# Starting Child 31
# 19 45624
# Done distance matrix: 0.027587413787841797
# Done Generating final pairs: 0.06523728370666504
# best_stitch_pair = [    9 18035]
# best_stitch_pair_size = 76503.4510303109
# best_stitch_pair_distance = 1729.2344918520112
# best_stitch_pair_size_ratio = 0.45953774287290683
# Starting Child 32
# 80 45624
# Done distance matrix: 0.15059423446655273
# Done Generating final pairs: 0.2124190330505371
# best_stitch_pair = [   49 34746]
# best_stitch_pair_size = 1662649.8410636592
# best_stitch_pair_distance = 1416.5675673346361
# best_stitch_pair_size_ratio = 0.3180713641655808
# Starting Child 33
# 13 45624
# Done distance matrix: 0.01849532127380371
# Done Generating final pairs: 0.06197166442871094
# best_stitch_pair = [    1 34746]
# best_stitch_pair_size = 2294940.867149127
# best_stitch_pair_distance = 1791.9727897985047
# best_stitch_pair_size_ratio = 0.8193222437668848
# Starting Child 34
# 12 45624
# Done distance matrix: 0.018606901168823242
# Done Generating final pairs: 0.048258304595947266
# best_stitch_pair = [    0 34753]
# best_stitch_pair_size = 1320220.0955411564
# best_stitch_pair_distance = 1568.4145327044703
# best_stitch_pair_size_ratio = 0.9656876863412562
# Starting Child 35
# 9 45624
# Done distance matrix: 0.016678333282470703
# Done Generating final pairs: 0.05946826934814453
# best_stitch_pair = [    1 22914]
# best_stitch_pair_size = 1791281.5213165455
# best_stitch_pair_distance = 1549.9133227585303
# best_stitch_pair_size_ratio = 0.7173253550180869
# Starting Child 36
# 3 45624
# Done distance matrix: 0.00760960578918457
# Done Generating final pairs: 0.04953312873840332
# best_stitch_pair = [    0 24858]
# best_stitch_pair_size = 34275.75829152346
# best_stitch_pair_distance = 1316.438195456468
# best_stitch_pair_size_ratio = 0.4370875611766026
# Starting Child 37
# 5 45624
# Done distance matrix: 0.008621692657470703
# Child 37 There were no points close enough
# Starting Child 38
# 13 45624
# Done distance matrix: 0.018278837203979492
# Child 38 There were no points close enough
# repeat_main_facets = [476, 22914, 34746]
# child_mesh_double_indexes = [9, 30]
# min_child = 9, max_ratio = 127.89389644381305
# child_mesh_double_indexes = [13, 35]
# min_child = 13, max_ratio = 1307.1463708601682
# child_mesh_double_indexes = [32, 33]
# min_child = 32, max_ratio = 1416.5675673346361
# child_meshes_stitch_facets = {5: [319, 21100], 6: [364, 34037], 7: [561, 3496], 8: [323, 19013], 9: [11, 476], 12: [0, 19024], 13: [7, 22914], 18: [105, 40668], 20: [51, 21739], 21: [0, 10807], 22: [76, 8422], 24: [5, 8403], 26: [23, 1723], 27: [1, 1725], 28: [4, 21764], 31: [9, 18035], 32: [49, 34746], 34: [0, 34753], 36: [0, 24858]}
# ---Stitching child 5 with pair: [319, 21100]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 360167, starting edge 2nd facet= 2147436,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 4.1961669921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012394189834594727
# returned from stitch mesh: 1.9560754299163818
# Finished stitching child 5 : 2.2506277561187744
# ---Stitching child 6 with pair: [364, 34037]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 290529, starting edge 2nd facet= 2166911,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06642961502075195
# returned from stitch mesh: 2.6422462463378906
# Finished stitching child 6 : 3.043098211288452
# ---Stitching child 7 with pair: [561, 3496]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 431593, starting edge 2nd facet= 2196926,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06448698043823242
# returned from stitch mesh: 2.4916579723358154
# Finished stitching child 7 : 2.8745434284210205
# ---Stitching child 8 with pair: [323, 19013]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 571869, starting edge 2nd facet= 2207092,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 27
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 4.100799560546875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0735161304473877
# returned from stitch mesh: 3.7386815547943115
# Finished stitching child 8 : 4.228203296661377
# ---Stitching child 9 with pair: [11, 476]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1484126, starting edge 2nd facet= 2212181,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 28
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 4.410743713378906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12643742561340332
# returned from stitch mesh: 3.41379976272583
# Finished stitching child 9 : 4.047089338302612
# ---Stitching child 12 with pair: [0, 19024]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1283043, starting edge 2nd facet= 2213751,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.4318695068359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.15829896926879883
# returned from stitch mesh: 2.9928219318389893
# Finished stitching child 12 : 3.4493138790130615
# ---Stitching child 13 with pair: [7, 22914]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 482499, starting edge 2nd facet= 2214426,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 4.57763671875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07041621208190918
# returned from stitch mesh: 2.8021721839904785
# Finished stitching child 13 : 3.3303418159484863
# ---Stitching child 18 with pair: [105, 40668]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1211879, starting edge 2nd facet= 2215334,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 5.936622619628906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1868581771850586
# returned from stitch mesh: 3.1366777420043945
# Finished stitching child 18 : 3.639955759048462
# ---Stitching child 20 with pair: [51, 21739]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 619183, starting edge 2nd facet= 2216790,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.4080276489257812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.10352444648742676
# returned from stitch mesh: 3.0461719036102295
# Finished stitching child 20 : 3.5370101928710938
# ---Stitching child 21 with pair: [0, 10807]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 560082, starting edge 2nd facet= 2217235,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 4.363059997558594e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0712730884552002
# returned from stitch mesh: 3.6630499362945557
# Finished stitching child 21 : 4.097972631454468
# ---Stitching child 22 with pair: [76, 8422]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 510367, starting edge 2nd facet= 2217517,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07008743286132812
# returned from stitch mesh: 2.2798662185668945
# Finished stitching child 22 : 2.7006983757019043
# ---Stitching child 24 with pair: [5, 8403]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 667531, starting edge 2nd facet= 2218403,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0663306713104248
# returned from stitch mesh: 2.5190649032592773
# Finished stitching child 24 : 2.8894803524017334
# ---Stitching child 26 with pair: [23, 1723]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 462705, starting edge 2nd facet= 2218550,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 34
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 4, remainder = 2
# About to add faces
# Finished adding faces: 5.5789947509765625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08381009101867676
# returned from stitch mesh: 2.8053290843963623
# Finished stitching child 26 : 3.186455488204956
# ---Stitching child 27 with pair: [1, 1725]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2043330, starting edge 2nd facet= 2218595,
# Starting Organizing vertices for side 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-6bcb73d94cc0> in <module>
#       1 start = time.time()
# ----> 2 ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-5-9cd9be709079> in make(self, key)
#      55                                                          load_meshes_flag = True,
#      56                                                      save_meshes_flag = False,
# ---> 57                                                         pymeshfix_flag = False
#      58                                                        )
#      59         else:
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_neuron(segment_id, vertices, faces, **kwargs)
#    1643                                                                                                 size_ratio_expansion_percentage = size_ratio_expansion_percentage,
#    1644                                                                                                 no_new_children_limit = no_new_children_limit,
# -> 1645                                                                                                 consider_same_direction_normals = consider_same_direction_normals
#    1646                                                                                                                                                       )
#    1647
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_iteration(main_mesh, main_mesh_facets_centers, main_mesh_facets, child_meshes, child_meshes_facets, bounding_box_threshold, stitch_distance_threshold, size_ratio_threshold, normal_closeness, bbox_expansion_percentage, stitch_expansion_percentage, size_ratio_expansion_percentage, no_new_children_limit, consider_same_direction_normals)
#    1209                                                               delete_facets=False,
#    1210                                                               return_added_mesh=False,
# -> 1211                                                                fix_normals = False)
#    1212
#    1213                 print(f"returned from stitch mesh: {time.time() - start_time}")
#
# /notebooks/22_Stitching_Datajoint_Tables/Stitcher_vp2.py in stitch_mesh_piece_vp4(new_mesh, facet_1, facet_2, delete_facets, return_added_mesh, fix_normals)
#     454
#     455         if starting_edges.size > 4:
# --> 456             raise Exception("Too many edges for 1st facet start point")
#     457
#     458         #np.where(starting_edges[1,:] != start_point)[0][0]
#
# Exception: Too many edges for 1st facet start point

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
