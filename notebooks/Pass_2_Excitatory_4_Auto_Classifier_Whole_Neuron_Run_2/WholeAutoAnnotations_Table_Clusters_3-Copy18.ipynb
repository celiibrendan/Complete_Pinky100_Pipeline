# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498239******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.10349631309509277
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1177.700757741928
# 2) Finished: Generating CGAL segmentation for neuron: 1200.4926619529724
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.32137012481689453
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [18, 42, 36, 50, 12, 346, 39, 17, 28, 333, 77, 334, 410, 378, 71, 76, 265, 534, 1, 259, 23, 483, 522, 22, 56, 532, 350, 542, 482, 258, 460, 11, 54, 533, 32, 14, 46, 127, 59, 136, 332, 298, 408, 475, 273, 289, 390, 263, 352, 481, 280, 434, 456, 89, 343, 123, 494, 130, 120, 339, 484, 486]
# soma_80_percent = 194090.1828125
# Debugging the axon filter
# [(18, 197568.515625), (42, 237004.359375), (36, 177170.421875), (50, 250138.046875), (12, 259215.21875), (346, 199083.015625), (39, 189681.109375), (17, 184411.796875), (28, 260218.453125), (333, 187325.625), (77, 173978.921875), (334, 184466.921875), (410, 195994.125), (378, 176215.609375), (71, 242624.65625), (76, 243106.984375), (265, 205576.734375), (534, 187748.25), (1, 247016.28125), (259, 176185.84375), (23, 252171.71875), (483, 174998.921875), (522, 185587.15625), (22, 275144.84375), (56, 190657.65625), (532, 177788.921875), (350, 213065.453125), (542, 195241.296875), (482, 175173.234375), (258, 184782.609375), (460, 186570.15625), (11, 198158.5), (54, 191113.46875), (533, 178699.140625), (32, 266130.0625), (14, 234289.34375), (46, 180180.796875), (127, 188663.6875), (59, 179336.171875), (136, 174653.71875), (332, 188575.40625), (298, 179254.203125), (408, 207571.09375), (475, 201061.109375), (273, 175835.09375), (289, 182118.984375), (390, 178125.65625), (263, 187480.109375), (352, 198730.953125), (481, 174308.390625), (280, 200731.96875), (434, 189855.96875), (456, 198220.171875), (89, 205355.234375), (343, 179154.546875), (123, 237583.53125), (494, 232313.09375), (130, 180831.203125), (120, 202235.234375), (339, 231477.765625), (484, 183189.8125), (486, 180586.984375)]
# possible_Axons_filter_1 = [36, 39, 17, 333, 77, 334, 378, 534, 259, 483, 522, 56, 532, 482, 258, 460, 54, 533, 46, 127, 59, 136, 332, 298, 273, 289, 390, 263, 481, 434, 343, 130, 484, 486]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.3047020435333252
# 6) Staring: Classifying Entire Neuron
# 14 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 36
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 39
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 46
# 56 = cilia
# 59 = stub soma
# 76 = cilia
# 89 = cilia
# 120 = cilia
# 123 = stub soma
# 127 = stub soma
# 130 = cilia
# 136 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 258
# 259 = stub soma
# 263 = cilia
# 265 = cilia
# 273 = cilia
# 280 = stub soma
# 289 = cilia
# 298 = cilia
# 332 = cilia
# 333 = stub soma
# 334 = stub soma
# 339 = stub soma
# 343 = stub soma
# 350 = stub soma
# 378 = cilia
# 390 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 408
# 410 = cilia
# 434 = stub soma
# 456 = stub soma
# 460 = stub soma
# 475 = stub soma
# 481 = cilia
# 482 = cilia
# 483 = stub soma
# 484 = stub soma
# 486 = stub soma
# 494 = stub soma
# 522 = cilia
# 532 = stub soma
# 533 = cilia
# 534 = stub soma
# 542 = cilia
# 37 = stub apical
# 63 = stub apical
# 84 = stub apical
# 112 = stub apical
# 118 = stub apical
# 180 = stub apical
# 182 = stub apical
# 222 = stub apical
# 281 = stub apical
# 282 = stub apical
# 327 = stub apical
# 342 = stub apical
# 371 = stub apical
# 372 = stub apical
# 397 = stub apical
# 416 = stub apical
# 433 = stub apical
# 452 = stub apical
# 459 = stub apical
# 493 = stub apical
# 517 = stub apical
# 518 = stub apical
# 519 = stub apical
# Total Labels found = {'basal', 'cilia', 'soma', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.2123470306396484
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.46216559410095215
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.985457420349121
# Finished Auto Labeling: 1219.830311536789
#
#
# *****Starting Auto Labeling for 648518346349500138******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07164478302001953
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1152.107491493225
# 2) Finished: Generating CGAL segmentation for neuron: 1177.4796254634857
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2807023525238037
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [8, 31, 35, 10, 43, 14, 26, 151, 191, 190, 106]
# soma_80_percent = 222673.115625
# Debugging the axon filter
# [(8, 220003.21875), (31, 242702.234375), (35, 244035.46875), (10, 244924.453125), (43, 251186.65625), (14, 224177.109375), (26, 225053.734375), (151, 219926.03125), (191, 220074.640625), (190, 231148.140625), (106, 234399.1875)]
# possible_Axons_filter_1 = [8, 151, 191]
# possible_Axons_filter_2 = [8]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.11870503425598145
# 6) Staring: Classifying Entire Neuron
# 151 = cilia
# 106 = stub soma
# 190 = stub soma
# 191 = stub soma
# 1 = stub apical
# 20 = stub apical
# 22 = error
# 25 = stub apical
# 29 = stub apical
# 30 = error
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 40 = stub apical
# 41 = stub apical
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 67 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 90 = stub apical
# 91 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 111 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 126 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 149 = stub apical
# 150 = stub apical
# 152 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 186 = stub apical
# 188 = stub apical
# 189 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# Total Labels found = {'oblique', 'apical', 'cilia', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.436443567276001
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6063640117645264
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.744563341140747
# Finished Auto Labeling: 1195.5542068481445
#
#
# *****Starting Auto Labeling for 648518346349502920******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03543901443481445
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 399.15867590904236
# 2) Finished: Generating CGAL segmentation for neuron: 412.09311056137085
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 5
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.15285181999206543
# 5) Staring: Finding Apical Index
# Soma Index = 5
# Soma Connections = [6, 4, 34, 78, 237, 20, 278, 124, 70, 461, 355, 402]
# soma_80_percent = 286144.95
# Debugging the axon filter
# [(6, 298730.0), (4, 283279.15625), (34, 296209.65625), (78, 300272.375), (237, 289681.71875), (20, 292181.21875), (278, 294907.9375), (124, 284613.0), (70, 291378.0), (461, 290502.78125), (355, 285481.84375), (402, 294662.65625)]
# possible_Axons_filter_1 = [4, 124, 355]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.10797333717346191
# 6) Staring: Classifying Entire Neuron
# 78 = error
# 124 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 237
# 355 = cilia
# 278 = stub soma
# 402 = stub soma
# 461 = stub soma
# 10 = stub apical
# 11 = stub apical
# 15 = stub apical
# 17 = stub apical
# 22 = stub apical
# 23 = stub apical
# 24 = stub apical
# 26 = stub apical
# 27 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 33 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = error
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 72 = stub apical
# 75 = stub apical
# 77 = stub apical
# 79 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 85 = stub apical
# 87 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 97 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 125 = stub apical
# 126 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 154 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 189 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 198 = stub apical
# 199 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 246 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 295 = stub apical
# 296 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 356 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 409 = stub apical
# 410 = stub apical
# 411 = stub apical
# 412 = stub apical
# 413 = stub apical
# 414 = stub apical
# 415 = stub apical
# 418 = stub apical
# 419 = stub apical
# 420 = stub apical
# 421 = stub apical
# 422 = stub apical
# 423 = stub apical
# 424 = stub apical
# 425 = stub apical
# 426 = stub apical
# 427 = stub apical
# 428 = stub apical
# 429 = stub apical
# 430 = stub apical
# 431 = stub apical
# 432 = stub apical
# 433 = stub apical
# 434 = stub apical
# 435 = stub apical
# 436 = stub apical
# 437 = stub apical
# 438 = stub apical
# 440 = stub apical
# 444 = stub apical
# 445 = stub apical
# 446 = stub apical
# 447 = stub apical
# 449 = stub apical
# 452 = stub apical
# 453 = stub apical
# 454 = stub apical
# 455 = stub apical
# 456 = stub apical
# 457 = stub apical
# 458 = stub apical
# 459 = stub apical
# 460 = stub apical
# 462 = stub apical
# 463 = stub apical
# 464 = stub apical
# 465 = stub apical
# 466 = stub apical
# 467 = stub apical
# 468 = stub apical
# 469 = stub apical
# 470 = stub apical
# 471 = stub apical
# 472 = stub apical
# 473 = stub apical
# 474 = stub apical
# 475 = stub apical
# 476 = stub apical
# 477 = stub apical
# 478 = stub apical
# 479 = stub apical
# 480 = stub apical
# Total Labels found = {'oblique', 'apical', 'cilia', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.038551092147827
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.28451108932495117
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.929230451583862
# Finished Auto Labeling: 422.0422327518463
#
#
# *****Starting Auto Labeling for 648518346349503924******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06784272193908691
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 957.9088454246521
# 2) Finished: Generating CGAL segmentation for neuron: 976.822963476181
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.23619604110717773
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [8, 6, 24, 38, 26, 205, 194, 101, 163, 138, 173, 102, 217, 126, 257, 307, 308, 216, 153]
# soma_80_percent = 245960.9796875
# Debugging the axon filter
# [(8, 281396.0625), (6, 240444.84375), (24, 289138.0), (38, 258660.90625), (26, 258859.84375), (205, 254098.65625), (194, 250050.0625), (101, 258917.328125), (163, 253670.984375), (138, 251857.25), (173, 241340.8125), (102, 260998.671875), (217, 241894.796875), (126, 249335.59375), (257, 251228.5625), (307, 244406.46875), (308, 250366.421875), (216, 242532.375), (153, 246130.453125)]
# possible_Axons_filter_1 = [6, 173, 217, 307, 216]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.11856603622436523
# 6) Staring: Classifying Entire Neuron
# 101 = stub soma
# 126 = stub soma
# 138 = stub soma
# 153 = stub soma
# 163 = stub soma
# 173 = stub soma
# 216 = cilia
# 194 = stub soma
# 205 = stub soma
# 217 = stub soma
# 257 = stub soma
# 307 = stub soma
# 308 = stub soma
# 10 = stub apical
# 28 = stub apical
# 37 = stub apical
# 39 = stub apical
# 43 = stub apical
# 46 = stub apical
# 49 = stub apical
# 51 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 66 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 88 = stub apical
# 89 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 100 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = error
# 132 = stub apical
# 136 = stub apical
# 137 = stub apical
# 139 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 188 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 215 = stub apical
# 218 = stub apical
# 220 = error
# 221 = stub apical
# 222 = stub apical
# 225 = stub apical
# 227 = stub apical
# 230 = stub apical
# 235 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 249 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 271 = stub apical
# 272 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 311 = stub apical
# 312 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# Total Labels found = {'oblique', 'apical', 'cilia', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.617802143096924
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.47229480743408203
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.19066834449768
# Finished Auto Labeling: 993.2207214832306
#
#
# *****Starting Auto Labeling for 648518346349505592******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05059480667114258
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 891.1852185726166
# 2) Finished: Generating CGAL segmentation for neuron: 909.9426307678223
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.272385835647583
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [351, 35, 536, 696, 7, 999, 1002, 705, 515, 739, 531, 1000, 937, 138, 1225, 706, 214, 524, 133, 381, 136, 106, 821, 606, 832, 85, 86, 3, 63, 248, 5, 4, 1107, 740, 812, 246, 945, 757, 824, 997, 578, 914, 1140, 124, 371, 14, 15, 987, 811, 519, 1014, 184, 47, 92, 1095, 227, 88, 160, 876, 0, 695, 668, 103, 132, 37, 504, 506, 813, 49, 913, 8, 322, 1142, 126, 219, 754, 809, 61, 698, 990, 1270, 1139, 518, 135, 1271, 17, 646, 532, 823, 334, 1004, 520, 510, 942, 675, 1114, 702, 333, 336, 1249, 327, 139, 564, 1173, 988, 104, 1250, 915, 191, 703, 389, 255, 328, 986, 701, 931, 664, 547, 736, 105, 737, 634, 1162, 1154, 602, 509, 1268, 1040, 540, 604, 260, 230, 363, 221, 928, 1097, 331, 364, 1264, 373, 186, 546, 825, 699, 1077, 1191, 247, 944, 1118, 671, 1132, 932, 330, 1131, 644, 162, 534, 511, 1155, 525, 755, 167, 707, 700, 1133, 1119, 828, 1161, 507, 989, 329, 991, 681, 661, 936, 508, 387, 362, 463, 521, 530, 938, 744, 753, 1098, 1172, 1163, 1158, 137, 827, 74, 563, 523, 240, 1189, 941, 503, 87, 743, 251, 1103, 670, 651, 666, 665, 140, 807, 261, 1226, 1041, 211, 1164, 940, 1141, 123, 367, 326, 55, 1044, 1273, 386, 929, 538, 599, 1160, 822, 1269, 195, 163, 1159, 930, 1272, 505, 1045, 1157, 1105, 826, 745, 815, 541, 128, 1003, 1263, 97, 933, 460, 1096, 68]
# soma_80_percent = 216666.68125
# Debugging the axon filter
# [(351, 240830.84375), (35, 183062.25), (536, 180856.09375), (696, 242517.484375), (7, 284404.15625), (999, 204794.609375), (1002, 217763.03125), (705, 195419.5), (515, 269265.40625), (739, 203685.5), (531, 213844.859375), (1000, 202871.828125), (937, 190761.875), (138, 198246.46875), (1225, 195917.015625), (706, 193004.640625), (214, 192913.078125), (524, 189079.34375), (133, 270528.25), (381, 253993.875), (136, 224813.421875), (106, 305642.5), (821, 221365.140625), (606, 220000.375), (832, 222809.9375), (85, 304100.46875), (86, 201630.234375), (3, 296355.0), (63, 285666.25), (248, 233679.578125), (5, 251972.375), (4, 239402.03125), (1107, 192013.484375), (740, 184648.59375), (812, 187030.265625), (246, 237742.109375), (945, 213293.953125), (757, 206193.921875), (824, 220115.375), (997, 189972.46875), (578, 182546.25), (914, 230520.09375), (1140, 208516.609375), (124, 180297.828125), (371, 231228.53125), (14, 239725.828125), (15, 240280.390625), (987, 235974.0), (811, 188222.65625), (519, 221228.375), (1014, 181380.84375), (184, 185141.765625), (47, 232545.453125), (92, 185010.59375), (1095, 186987.375), (227, 202821.03125), (88, 188424.625), (160, 196786.28125), (876, 278867.59375), (0, 222895.765625), (695, 237370.3125), (668, 232019.5), (103, 234029.71875), (132, 228176.953125), (37, 306281.9375), (504, 239589.296875), (506, 214971.640625), (813, 186870.421875), (49, 299396.65625), (913, 230328.4375), (8, 301642.96875), (322, 211499.90625), (1142, 225689.625), (126, 237552.765625), (219, 208475.0), (754, 268282.0625), (809, 185466.625), (61, 191475.78125), (698, 195034.46875), (990, 234787.65625), (1270, 219087.265625), (1139, 206130.546875), (518, 219236.734375), (135, 193765.15625), (1271, 218231.890625), (17, 293775.34375), (646, 235012.828125), (532, 205616.5625), (823, 222096.84375), (334, 231155.90625), (1004, 240582.734375), (520, 220679.625), (510, 211384.71875), (942, 216481.828125), (675, 241934.359375), (1114, 183953.703125), (702, 193665.484375), (333, 254040.78125), (336, 202114.625), (1249, 223709.40625), (327, 199987.5), (139, 188304.203125), (564, 240636.125), (1173, 254379.625), (988, 234305.796875), (104, 221866.9375), (1250, 224421.921875), (915, 259795.203125), (191, 192855.890625), (703, 195080.828125), (389, 185955.203125), (255, 199248.515625), (328, 200515.5), (986, 236182.140625), (701, 193720.03125), (931, 194801.234375), (664, 249970.765625), (547, 298366.28125), (736, 194546.015625), (105, 254987.8125), (737, 226484.703125), (634, 277493.96875), (1162, 180877.71875), (1154, 182616.9375), (602, 200622.71875), (509, 212399.453125), (1268, 219959.109375), (1040, 233037.828125), (540, 251118.765625), (604, 198599.78125), (260, 282017.03125), (230, 229959.53125), (363, 214396.90625), (221, 181371.140625), (928, 226766.296875), (1097, 245114.421875), (331, 200606.34375), (364, 225673.421875), (1264, 257352.296875), (373, 246455.546875), (186, 197121.09375), (546, 296416.3125), (825, 221015.921875), (699, 193025.78125), (1077, 245036.140625), (1191, 200965.6875), (247, 262205.53125), (944, 216971.4375), (1118, 210227.5), (671, 232015.59375), (1132, 235208.671875), (932, 243092.015625), (330, 199024.40625), (1131, 237217.390625), (644, 191895.5625), (162, 226684.296875), (534, 255642.09375), (511, 210710.046875), (1155, 182795.625), (525, 204759.0), (755, 248426.0625), (167, 223938.40625), (707, 221715.203125), (700, 194179.84375), (1133, 236550.296875), (1119, 238421.9375), (828, 209935.703125), (1161, 182237.703125), (507, 212131.578125), (989, 233908.703125), (329, 200264.96875), (991, 234084.078125), (681, 245025.796875), (661, 184768.078125), (936, 187407.0625), (508, 209233.671875), (387, 216206.0), (362, 199839.65625), (463, 183716.046875), (521, 184675.671875), (530, 235165.03125), (938, 257109.109375), (744, 189553.359375), (753, 236585.546875), (1098, 244332.046875), (1172, 252823.984375), (1163, 183180.203125), (1158, 183022.9375), (137, 264264.59375), (827, 237079.890625), (74, 197160.1875),  ...
# possible_Axons_filter_1 = [35, 536, 999, 705, 739, 531, 1000, 937, 138, 1225, 706, 214, 524, 86, 1107, 740, 812, 945, 757, 997, 578, 1140, 124, 811, 1014, 184, 92, 1095, 227, 88, 160, 506, 813, 322, 219, 809, 61, 698, 1139, 135, 532, 510, 942, 1114, 702, 336, 327, 139, 191, 703, 389, 255, 328, 701, 931, 736, 1162, 1154, 602, 509, 604, 363, 221, 331, 186, 699, 1191, 1118, 330, 644, 511, 1155, 525, 700, 828, 1161, 507, 329, 661, 936, 508, 387, 362, 463, 521, 744, 1163, 1158, 74, 523, 240, 1189, 503, 87, 743, 251, 651, 140, 807, 261, 1226, 1164, 940, 123, 367, 326, 55, 1044, 1273, 538, 599, 1160, 163, 1159, 1272, 505, 1045, 1157, 745, 128, 1003, 97, 1096]
# possible_Axons_filter_2 = [35, 124]
# possible_Apical = 124
# 5) Finished: Finding Apical Index: 0.4658675193786621
# 6) Staring: Classifying Entire Neuron
# 14 = cilia
# 15 = cilia
# 55 = cilia
# 61 = stub soma
# 68 = stub soma
# 74 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 86
# 87 = stub soma
# 88 = cilia
# 92 = stub soma
# 97 = cilia
# 103 = error
# 104 = stub soma
# 105 = stub soma
# 106 = cilia
# 123 = cilia
# 126 = stub soma
# 128 = cilia
# 132 = cilia
# 133 = axon
# 135 = cilia
# 136 = cilia
# 137 = stub soma
# 139 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 140
# 160 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 162
# 163 = stub soma
# 167 = stub soma
# 184 = cilia
# 186 = cilia
# 191 = cilia
# 195 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 214
# 219 = stub soma
# 221 = stub soma
# 227 = cilia
# 230 = stub soma
# 825 = cilia
# 525 = cilia
# 240 = cilia
# 246 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 247
# 251 = stub soma
# 255 = cilia
# 260 = cilia
# 261 = stub soma
# 322 = stub soma
# 326 = stub soma
# 327 = stub soma
# 328 = stub soma
# 329 = stub soma
# 330 = stub soma
# 331 = stub soma
# 333 = stub soma
# 334 = stub soma
# 336 = cilia
# 351 = stub soma
# 362 = cilia
# 363 = stub soma
# 364 = stub soma
# 367 = cilia
# 373 = stub soma
# 381 = stub soma
# 386 = cilia
# 387 = cilia
# 389 = stub soma
# 942 = cilia
# 460 = stub soma
# 463 = cilia
# 503 = stub soma
# 504 = stub soma
# 505 = cilia
# 506 = cilia
# 509 = stub soma
# 510 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 511
# 515 = stub soma
# 671 = cilia
# 518 = stub soma
# 520 = stub soma
# 521 = stub soma
# 523 = stub soma
# 524 = stub soma
# 530 = stub soma
# 531 = cilia
# 532 = stub soma
# 534 = stub soma
# 536 = cilia
# 538 = stub soma
# 540 = stub soma
# 541 = stub soma
# 546 = cilia
# 547 = cilia
# 563 = stub soma
# 564 = cilia
# 578 = stub soma
# 599 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 602
# 604 = cilia
# 606 = cilia
# 1158 = cilia
# 634 = stub soma
# 644 = cilia
# 646 = cilia
# 651 = stub soma
# 661 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 664
# 666 = stub soma
# 668 = stub soma
# 670 = stub soma
# 675 = stub soma
# 681 = stub soma
# 695 = cilia
# 696 = cilia
# 698 = stub soma
# 699 = cilia
# 700 = cilia
# 701 = stub soma
# 702 = stub soma
# 703 = cilia
# 705 = stub soma
# 706 = stub soma
# 707 = stub soma
# 736 = stub soma
# 737 = stub soma
# 1226 = cilia
# 739 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 740
# 743 = stub soma
# 744 = stub soma
# 745 = stub soma
# 753 = stub soma
# 754 = stub soma
# 755 = stub soma
# 757 = stub soma
# 807 = cilia
# 809 = stub soma
# 811 = stub soma
# 812 = stub soma
# 813 = cilia
# 815 = stub soma
# 822 = stub soma
# 823 = stub soma
# 824 = stub soma
# 826 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 827
# 828 = stub soma
# 832 = stub soma
# 913 = cilia
# 914 = stub soma
# 915 = stub soma
# 928 = cilia
# 929 = stub soma
# 930 = stub soma
# 931 = stub soma
# 932 = stub soma
# 936 = cilia
# 937 = cilia
# 938 = stub soma
# 940 = stub soma
# 941 = stub soma
# 944 = stub soma
# 945 = cilia
# 1157 = stub soma
# 986 = stub soma
# 988 = stub soma
# 989 = stub soma
# 990 = cilia
# 991 = stub soma
# 997 = cilia
# 999 = stub soma
# 1000 = stub soma
# 1002 = stub soma
# 1003 = cilia
# 1004 = cilia
# 1014 = cilia
# 1040 = stub soma
# 1041 = stub soma
# 1044 = stub soma
# 1045 = stub soma
# 1077 = cilia
# 1095 = stub soma
# 1096 = stub soma
# 1097 = stub soma
# 1098 = stub soma
# 1103 = stub soma
# 1107 = stub soma
# 1114 = stub soma
# 1118 = stub soma
# 1119 = cilia
# 1131 = stub soma
# 1132 = stub soma
# 1133 = stub soma
# 1139 = stub soma
# 1140 = cilia
# 1142 = stub soma
# 1154 = stub soma
# 1155 = cilia
# 1159 = stub soma
# 1160 = stub soma
# 1161 = cilia
# 1162 = cilia
# 1163 = stub soma
# 1164 = stub soma
# 1172 = stub soma
# 1189 = stub soma
# 1191 = stub soma
# 1225 = stub soma
# 1249 = stub soma
# 1250 = stub soma
# 1263 = stub soma
# 1264 = stub soma
# 1268 = cilia
# 1269 = stub soma
# 1270 = stub soma
# 1271 = stub soma
# 1272 = stub soma
# 1273 = stub soma
# 78 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = error
# 149 = stub apical
# 212 = stub apical
# 225 = stub apical
# 350 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 611 = stub apical
# 613 = stub apical
# 652 = stub apical
# 659 = stub apical
# 685 = stub apical
# 993 = stub apical
# 994 = stub apical
# 995 = stub apical
# 996 = stub apical
# 1043 = stub apical
# 1221 = stub apical
# Total Labels found = {'oblique', 'apical', 'cilia', 'axon', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.234727621078491
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.411665678024292
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.172257423400879
# Finished Auto Labeling: 926.1850552558899
#
#
# *****Starting Auto Labeling for 648518346349507175******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03511834144592285
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 259.7461462020874
# 2) Finished: Generating CGAL segmentation for neuron: 271.40390610694885
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.12708806991577148
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [29, 79, 34]
# soma_80_percent = 253303.8453125
# Debugging the axon filter
# [(29, 255575.453125), (79, 253679.40625), (34, 261887.34375)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.00852823257446289
# 6) Staring: Classifying Entire Neuron
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 1.1907553672790527
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4169745445251465
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.7832396030426025
# Finished Auto Labeling: 279.50182032585144
#
#
# *****Starting Auto Labeling for 648518346349507964******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08098435401916504
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1292.7373468875885
# 2) Finished: Generating CGAL segmentation for neuron: 1318.2185623645782
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2966628074645996
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [13, 132, 14, 20, 53, 44, 21, 36, 27, 35, 121, 32, 183, 243]
# soma_80_percent = 196943.9703125
# Debugging the axon filter
# [(13, 213156.4375), (132, 194107.515625), (14, 196382.8125), (20, 193821.96875), (53, 214893.671875), (44, 199086.171875), (21, 208213.453125), (36, 213277.9375), (27, 204892.65625), (35, 199095.734375), (121, 205501.265625), (32, 196237.5), (183, 198575.25), (243, 205591.453125)]
# possible_Axons_filter_1 = [132, 14, 20, 32]
# possible_Axons_filter_2 = [20]
# possible_Apical = 20
# 5) Finished: Finding Apical Index: 0.12966585159301758
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 27
# 53 = axon
# 183 = stub soma
# 132 = cilia
# 243 = stub soma
# 22 = stub apical
# 28 = stub apical
# 34 = stub apical
# 45 = stub apical
# 48 = stub apical
# 59 = stub apical
# 61 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = error
# 98 = stub apical
# 108 = stub apical
# 109 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 150 = stub apical
# 175 = stub apical
# 178 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 211 = stub apical
# 212 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 228 = stub apical
# 235 = stub apical
# 238 = stub apical
# 242 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# Total Labels found = {'oblique', 'apical', 'axon', 'cilia', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.4155588150024414
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.616396427154541
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.963041543960571
# Finished Auto Labeling: 1338.541268825531
#
#
# *****Starting Auto Labeling for 648518346349512392******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05015730857849121
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 803.0316233634949
# 2) Finished: Generating CGAL segmentation for neuron: 822.057642698288
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2269885540008545
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [15, 3, 42, 50, 25, 33, 40, 16, 36, 125, 24, 30]
# soma_80_percent = 200363.046875
# Debugging the axon filter
# [(15, 213193.203125), (3, 198008.109375), (42, 214053.5625), (50, 206386.515625), (25, 203721.46875), (33, 212734.078125), (40, 218804.546875), (16, 212224.109375), (36, 200685.671875), (125, 202973.46875), (24, 207410.171875), (30, 206226.375)]
# possible_Axons_filter_1 = [3]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.07756376266479492
# 6) Staring: Classifying Entire Neuron
# 40 = error
# 24 = stub soma
# 30 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 36
# 125 = stub soma
# 20 = stub apical
# 23 = stub apical
# 29 = stub apical
# 31 = stub apical
# 32 = stub apical
# 34 = stub apical
# 35 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = error
# 52 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 89 = stub apical
# 90 = stub apical
# 92 = stub apical
# 93 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 127 = stub apical
# Total Labels found = {'oblique', 'apical', 'error', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.551609516143799
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4237029552459717
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.904407024383545
# Finished Auto Labeling: 836.1339333057404
# 7213.766858577728

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
