# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341361981**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 342 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 1453345
# Total time for Mesh Cleansing: 37.07526659965515
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981847377863005% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341379581**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 134085
# Total time for Mesh Cleansing: 2.092487335205078
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994037193008609% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341380003**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 91 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 370012
# Total time for Mesh Cleansing: 0.713986873626709
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987960848463253% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341381784**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 181 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 833995
# Total time for Mesh Cleansing: 15.137251138687134
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987019192196187% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341393799**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 69 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 477785
# Total time for Mesh Cleansing: 7.7073259353637695
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992387310231747% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341397381**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 150 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 643496
# Total time for Mesh Cleansing: 16.838364124298096
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984081226086929% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341402446**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 99 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 360784
# Total time for Mesh Cleansing: 14.8828763961792
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9967124710614574% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341407729**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 153518
# Total time for Mesh Cleansing: 3.6745777130126953
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995312194804349% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341411405**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 34 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 228332
# Total time for Mesh Cleansing: 0.6137735843658447
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993522408963585% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341411468**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 34 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 122078
# Total time for Mesh Cleansing: 2.6462647914886475
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9964086909678578% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341420202**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 21 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 146288
# Total time for Mesh Cleansing: 0.5491633415222168
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993305370732174% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341421804**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 48 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 82754
# Total time for Mesh Cleansing: 3.842717170715332
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9875414687701377% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793104**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 36778
# Total time for Mesh Cleansing: 0.07473945617675781
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992935550483643% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793875**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 51 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 312648
# Total time for Mesh Cleansing: 0.6165862083435059
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990669137853901% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342795557**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 25 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 152722
# Total time for Mesh Cleansing: 0.23742341995239258
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990057171265225% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342796857**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 44 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 122328
# Total time for Mesh Cleansing: 2.4243152141571045
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979279176388051% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342798732**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 163 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 0
# max_face_len = 852759
# Total time for Mesh Cleansing: 24.531492471694946
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979777340088264% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342914598**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 119 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 264206
# Total time for Mesh Cleansing: 6.989017009735107
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9965149172104251% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342926115**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 91292
# Total time for Mesh Cleansing: 0.27025294303894043
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996058163980378% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342928174**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 39 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 285820
# Total time for Mesh Cleansing: 7.784748077392578
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988956300500461% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344465416**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 33 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 100912
# Total time for Mesh Cleansing: 3.3845033645629883
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9978443587461683% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344502405**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 123028
# Total time for Mesh Cleansing: 3.5233359336853027
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991553779683592% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346345537526**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 18 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 34706
# Total time for Mesh Cleansing: 0.7546741962432861
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9955252136997303% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346345770568**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 37 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 138356
# Total time for Mesh Cleansing: 0.43259406089782715
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982971600092357% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346345771930**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 100084
# Total time for Mesh Cleansing: 0.28087735176086426
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989619515311214% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346295977**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 194672
# Total time for Mesh Cleansing: 6.987331390380859
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991377540546089% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346595427**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 95024
# Total time for Mesh Cleansing: 0.32608747482299805
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994110222970131% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346598297**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 171038
# Total time for Mesh Cleansing: 7.783324241638184
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998109265764872% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349373319**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 149822
# Total time for Mesh Cleansing: 0.5901832580566406
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991463821273758% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349378042**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 196214
# Total time for Mesh Cleansing: 0.42201900482177734
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992564677123651% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349387039**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 28 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 187854
# Total time for Mesh Cleansing: 0.5430800914764404
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992446647801017% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349472082**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 123 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 404842
# Total time for Mesh Cleansing: 9.863636016845703
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9978654598874067% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349494371**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 58 pieces after mesh split
# There were 13 pieces found after size threshold
# max_index = 0
# max_face_len = 81950
# Total time for Mesh Cleansing: 3.0403826236724854
# Number of outside child meshes =  10
# Main mesh and outside child meshes make up 0.9976903314425254% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349494371_30_main_and_child_meshes_array.npz
#  face length 81950 using optimized facets with 3 neighbors
# Filtering edges by size finished: 2.2997634410858154, facet # = 4189
# Filtering by convexity and getting centers took: 3.019812822341919, facet # = 879
# Finished 879 facets for main mesh: 5.465162754058838
# Filtering edges by size finished: 0.6798851490020752, facet # = 2442
# Filtering by convexity and getting centers took: 1.1010549068450928, facet # = 583
# Filtering edges by size finished: 1.221222162246704, facet # = 3347
# Filtering by convexity and getting centers took: 1.7478594779968262, facet # = 788
# Filtering edges by size finished: 0.3785974979400635, facet # = 1309
# Filtering by convexity and getting centers took: 1.3451826572418213, facet # = 279
# Filtering edges by size finished: 0.905461311340332, facet # = 2035
# Filtering by convexity and getting centers took: 1.7462654113769531, facet # = 449
# Filtering edges by size finished: 0.022693872451782227, facet # = 43
# Filtering by convexity and getting centers took: 0.022113800048828125, facet # = 15
# Filtering edges by size finished: 0.004865169525146484, facet # = 18
# Filtering by convexity and getting centers took: 0.009765148162841797, facet # = 11
# Filtering edges by size finished: 0.02549123764038086, facet # = 88
# Filtering by convexity and getting centers took: 0.24648618698120117, facet # = 20
# Filtering edges by size finished: 0.034296512603759766, facet # = 70
# Filtering by convexity and getting centers took: 0.06580352783203125, facet # = 33
# Filtering edges by size finished: 0.060390472412109375, facet # = 118
# Filtering by convexity and getting centers took: 0.05698704719543457, facet # = 35
# Filtering edges by size finished: 0.004479169845581055, facet # = 18
# Filtering by convexity and getting centers took: 0.009984731674194336, facet # = 9
# Total time for facets: 15.408867835998535
# Zero faceted faces = []
# Starting Child 0
# 583 879
# Done distance matrix: 0.046723365783691406
# Done Generating final pairs: 0.13921451568603516
# best_stitch_pair = [338 746]
# best_stitch_pair_size = 3796268.3369987407
# best_stitch_pair_distance = 807.7774348786552
# best_stitch_pair_size_ratio = 0.6714694284829816
# Starting Child 1
# 788 879
# Done distance matrix: 0.09990382194519043
# Child 1 There were no points close enough
# Starting Child 2
# 279 879
# Done distance matrix: 0.012437820434570312
# Done Generating final pairs: 0.020519018173217773
# best_stitch_pair = [197 587]
# best_stitch_pair_size = 557602.6848261148
# best_stitch_pair_distance = 1083.3315976454412
# best_stitch_pair_size_ratio = 0.7359869665906379
# Starting Child 3
# 449 879
# Done distance matrix: 0.024506092071533203
# Done Generating final pairs: 0.03907132148742676
# best_stitch_pair = [ 46 283]
# best_stitch_pair_size = 802334.3446233282
# best_stitch_pair_distance = 139.11100141770686
# best_stitch_pair_size_ratio = 0.811855466735686
# Starting Child 4
# 15 879
# Done distance matrix: 0.0013430118560791016
# Done Generating final pairs: 0.010408639907836914
# best_stitch_pair = [  1 283]
# best_stitch_pair_size = 702864.9408050082
# best_stitch_pair_distance = 1163.4563742533928
# best_stitch_pair_size_ratio = 0.9550655781780215
# Starting Child 5
# 11 879
# Done distance matrix: 0.0010480880737304688
# Done Generating final pairs: 0.0054852962493896484
# best_stitch_pair = [  7 587]
# best_stitch_pair_size = 437819.73824348743
# best_stitch_pair_distance = 1915.5949783772223
# best_stitch_pair_size_ratio = 0.8520248833573703
# Starting Child 6
# 20 879
# Done distance matrix: 0.0016400814056396484
# Done Generating final pairs: 0.004243373870849609
# best_stitch_pair = [ 10 231]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1692.3643157288564
# best_stitch_pair_size_ratio = 0.0
# Starting Child 7
# 33 879
# Done distance matrix: 0.0016379356384277344
# Done Generating final pairs: 0.009908914566040039
# best_stitch_pair = [ 11 246]
# best_stitch_pair_size = 100534.71910321915
# best_stitch_pair_distance = 113.57088536280499
# best_stitch_pair_size_ratio = 0.5309408873964689
# Starting Child 8
# 35 879
# Done distance matrix: 0.0016629695892333984
# Done Generating final pairs: 0.019264936447143555
# best_stitch_pair = [ 10 587]
# best_stitch_pair_size = 480737.7657354922
# best_stitch_pair_distance = 148.33119237869167
# best_stitch_pair_size_ratio = 0.9675177349163862
# Starting Child 9
# 9 879
# Done distance matrix: 0.0010979175567626953
# Child 9 There were no points close enough
# repeat_main_facets = [587, 283]
# child_mesh_double_indexes = [2, 5, 8]
# min_child = 8, max_ratio = 148.33119237869167
# child_mesh_double_indexes = [3, 4]
# min_child = 3, max_ratio = 139.11100141770686
# child_meshes_stitch_facets = {0: [338, 746], 3: [46, 283], 6: [10, 231], 7: [11, 246], 8: [10, 587]}
# ---Stitching child 0 with pair: [338, 746]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 20329, starting edge 2nd facet= 48120,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 35
# Starting Organizing vertices for side 1
# edge_1_order done, len = 48
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 13
# About to add faces
# Finished adding faces: 6.246566772460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002195119857788086
# returned from stitch mesh: 0.14780187606811523
# Finished stitching child 0 : 0.15700984001159668
# ---Stitching child 3 with pair: [46, 283]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 13670, starting edge 2nd facet= 52322,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 4.839897155761719e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0017232894897460938
# returned from stitch mesh: 0.13881993293762207
# Finished stitching child 3 : 0.1452481746673584
# ---Stitching child 6 with pair: [10, 231]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 14059, starting edge 2nd facet= 58330,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 2
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0017852783203125
# returned from stitch mesh: 0.21452832221984863
# Finished stitching child 6 : 0.23205971717834473
# ---Stitching child 7 with pair: [11, 246]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 28188, starting edge 2nd facet= 58386,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.574920654296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0007889270782470703
# returned from stitch mesh: 0.10460829734802246
# Finished stitching child 7 : 0.11298894882202148
# ---Stitching child 8 with pair: [10, 587]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 13734, starting edge 2nd facet= 58814,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 4.601478576660156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0009450912475585938
# returned from stitch mesh: 0.17290449142456055
# Finished stitching child 8 : 0.19742608070373535
# ***************Finished big stitching iteration: 1.3347194194793701***************
# Starting Child 1
# 788 1989
# Done distance matrix: 0.1952831745147705
# Done Generating final pairs: 0.21154236793518066
# best_stitch_pair = [ 269 1005]
# best_stitch_pair_size = 1478827.4515894349
# best_stitch_pair_distance = 319.68386616070734
# best_stitch_pair_size_ratio = 0.7645268838824163
# Starting Child 2
# 279 1989
# Done distance matrix: 0.05099749565124512
# Done Generating final pairs: 0.07416391372680664
# best_stitch_pair = [ 197 1955]
# best_stitch_pair_size = 631985.1831418921
# best_stitch_pair_distance = 115.66454425518464
# best_stitch_pair_size_ratio = 0.9675623358141685
# Starting Child 4
# 15 1989
# Done distance matrix: 0.002153635025024414
# Done Generating final pairs: 0.022452354431152344
# best_stitch_pair = [   1 1649]
# best_stitch_pair_size = 813576.8312021501
# best_stitch_pair_distance = 137.0898579307191
# best_stitch_pair_size_ratio = 0.73019898522842
# Starting Child 5
# 11 1989
# Done distance matrix: 0.001804351806640625
# Done Generating final pairs: 0.008037328720092773
# best_stitch_pair = [  7 782]
# best_stitch_pair_size = 419943.75683148595
# best_stitch_pair_distance = 214.29886872774526
# best_stitch_pair_size_ratio = 0.9217231313655943
# Starting Child 9
# 9 1989
# Done distance matrix: 0.0015411376953125
# Done Generating final pairs: 0.016551733016967773
# best_stitch_pair = [   0 1013]
# best_stitch_pair_size = 395143.6141564788
# best_stitch_pair_distance = 195.88156565942478
# best_stitch_pair_size_ratio = 0.20696693463823812
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [269, 1005], 2: [197, 1955], 4: [1, 1649], 5: [7, 782], 9: [0, 1013]}
# ---Stitching child 1 with pair: [269, 1005]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 49518, starting edge 2nd facet= 69466,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 24
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 7.152557373046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003339529037475586
# returned from stitch mesh: 0.17724394798278809
# Finished stitching child 1 : 0.19228172302246094
# ---Stitching child 2 with pair: [197, 1955]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 58734, starting edge 2nd facet= 95967,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.838539123535156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0029387474060058594
# returned from stitch mesh: 0.33969759941101074
# Finished stitching child 2 : 0.35825228691101074
# ---Stitching child 4 with pair: [1, 1649]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 54071, starting edge 2nd facet= 98249,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 26
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 3.409385681152344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0013551712036132812
# returned from stitch mesh: 0.26467132568359375
# Finished stitching child 4 : 0.29302215576171875
# ---Stitching child 5 with pair: [7, 782]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 34427, starting edge 2nd facet= 98297,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.647804260253906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002874135971069336
# returned from stitch mesh: 0.3818526268005371
# Finished stitching child 5 : 0.39516425132751465
# ---Stitching child 9 with pair: [0, 1013]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 49389, starting edge 2nd facet= 98345,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 3.2901763916015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0028047561645507812
# returned from stitch mesh: 0.3373239040374756
# Finished stitching child 9 : 0.3549468517303467
# ***************Finished big stitching iteration: 2.1832926273345947***************
# All children have been processed
# total_stitch_processing_time = 3.521596908569336
# Total time for restitching = 3.522921562194824
# missed_children = []
# Whole stitching function complete: 22.462121963500977
#
#
#
# *****Running Neuron Stitcher for 648518346349509323**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 727 pieces after mesh split
# There were 148 pieces found after size threshold
# max_index = 0
# max_face_len = 804955
# Total time for Mesh Cleansing: 198.66520023345947
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9741125701430513% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341377165**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 37 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 144396
# Total time for Mesh Cleansing: 3.583441972732544
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984787298777452% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341379423**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 68 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 325598
# Total time for Mesh Cleansing: 9.207483768463135
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9984977527607626% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341379423_30_main_and_child_meshes_array.npz
#  face length 325598 using optimized facets with 3 neighbors
# Filtering edges by size finished: 8.88108491897583, facet # = 16880
# Filtering by convexity and getting centers took: 12.15071153640747, facet # = 3479
# Finished 3479 facets for main mesh: 21.63582420349121
# Filtering edges by size finished: 0.00436091423034668, facet # = 15
# Filtering by convexity and getting centers took: 0.008404970169067383, facet # = 9
# Total time for facets: 21.654281616210938
# Zero faceted faces = []
# Starting Child 0
# 9 3479
# Done distance matrix: 0.0023260116577148438
# Done Generating final pairs: 0.01714468002319336
# best_stitch_pair = [   3 1154]
# best_stitch_pair_size = 95101.65587570386
# best_stitch_pair_distance = 1531.448323194018
# best_stitch_pair_size_ratio = 0.22504078668148197
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [3, 1154]}
# ---Stitching child 0 with pair: [3, 1154]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 154658, starting edge 2nd facet= 163338,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0017242431640625
# returned from stitch mesh: 0.26977038383483887
# Finished stitching child 0 : 0.29939985275268555
# ***************Finished big stitching iteration: 0.36657285690307617***************
# All children have been processed
# total_stitch_processing_time = 0.370929479598999
# Total time for restitching = 0.3722226619720459
# missed_children = []
# Whole stitching function complete: 32.39564609527588
#
#
#
# *****Running Neuron Stitcher for 648518346341400285**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 150278
# Total time for Mesh Cleansing: 4.672283887863159
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990559765988566% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341402597**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 36 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 138204
# Total time for Mesh Cleansing: 0.596196174621582
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984972401236887% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341403397**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 154 pieces after mesh split
# There were 37 pieces found after size threshold
# max_index = 0
# max_face_len = 193505
# Total time for Mesh Cleansing: 16.904126405715942
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9824633553176042% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341408329**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 46 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 389970
# Total time for Mesh Cleansing: 8.977386713027954
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999354213755247% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410780**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 68 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 263369
# Total time for Mesh Cleansing: 9.49977970123291
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9839794961461871% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341414522**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 47 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 245050
# Total time for Mesh Cleansing: 6.702904462814331
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988261092859647% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342015924**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 55247
# Total time for Mesh Cleansing: 2.346564769744873
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9962851423728202% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342410869**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 80376
# Total time for Mesh Cleansing: 3.352052927017212
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984100168935705% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342790310**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 28 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 198222
# Total time for Mesh Cleansing: 0.710209846496582
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999223696414889% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342790997**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 59 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 389196
# Total time for Mesh Cleansing: 14.236085891723633
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982046494449802% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342792438**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 38 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 173279
# Total time for Mesh Cleansing: 0.7476859092712402
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988931867574408% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793061**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 31 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 119918
# Total time for Mesh Cleansing: 0.4443790912628174
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987174362049437% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342793450**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 42 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 254276
# Total time for Mesh Cleansing: 7.923518419265747
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988294169868094% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342796836**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 19940
# Total time for Mesh Cleansing: 0.11862683296203613
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997994384275972% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797189**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 85766
# Total time for Mesh Cleansing: 2.5398366451263428
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981843998044738% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797399**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 34 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 155614
# Total time for Mesh Cleansing: 6.357880353927612
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998396037571216% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342800184**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 80490
# Total time for Mesh Cleansing: 0.22412419319152832
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991310824230387% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342800676**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 26 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 152310
# Total time for Mesh Cleansing: 4.445183753967285
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990161353797717% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342802094**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 75518
# Total time for Mesh Cleansing: 2.1655960083007812
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983606990825203% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342802113**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 87 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 351684
# Total time for Mesh Cleansing: 14.458854675292969
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9972098404164823% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342805374**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 107454
# Total time for Mesh Cleansing: 0.29366159439086914
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995349010269385% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342805834**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 36 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 163810
# Total time for Mesh Cleansing: 6.094715118408203
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9988593063611872% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346342805834_30_main_and_child_meshes_array.npz
#  face length 163810 using optimized facets with 3 neighbors
# Filtering edges by size finished: 4.998526096343994, facet # = 8281
# Filtering by convexity and getting centers took: 5.315786838531494, facet # = 1740
# Finished 1740 facets for main mesh: 10.643052816390991
# Filtering edges by size finished: 0.04064536094665527, facet # = 122
# Filtering by convexity and getting centers took: 0.06460189819335938, facet # = 33
# Total time for facets: 10.756619930267334
# Zero faceted faces = []
# Starting Child 0
# 33 1740
# Done distance matrix: 0.0035767555236816406
# Done Generating final pairs: 0.01268458366394043
# best_stitch_pair = [  28 1224]
# best_stitch_pair_size = 41663.18023065678
# best_stitch_pair_distance = 1267.4339890333026
# best_stitch_pair_size_ratio = 0.44928769943128255
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [28, 1224]}
# ---Stitching child 0 with pair: [28, 1224]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 50121, starting edge 2nd facet= 82311,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0010030269622802734
# returned from stitch mesh: 0.21140217781066895
# Finished stitching child 0 : 0.2230055332183838
# ***************Finished big stitching iteration: 0.2660696506500244***************
# All children have been processed
# total_stitch_processing_time = 0.26653265953063965
# Total time for restitching = 0.2672581672668457
# missed_children = []
# Whole stitching function complete: 17.596864223480225
#
#
#
# *****Running Neuron Stitcher for 648518346342808805**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 93026
# Total time for Mesh Cleansing: 0.4428377151489258
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999591678844666% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342916426**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 33922
# Total time for Mesh Cleansing: 1.0833039283752441
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984106428066871% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342918937**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 427 pieces after mesh split
# There were 50 pieces found after size threshold
# max_index = 0
# max_face_len = 821868
# Total time for Mesh Cleansing: 121.052081823349
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9923089739905679% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341358706**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 96 pieces after mesh split
# There were 15 pieces found after size threshold
# max_index = 0
# max_face_len = 112192
# Total time for Mesh Cleansing: 7.709146738052368
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9824340181088986% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341363175**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 204 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 773220
# Total time for Mesh Cleansing: 33.76674461364746
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983576331324274% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341400883**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 111 pieces after mesh split
# There were 23 pieces found after size threshold
# max_index = 0
# max_face_len = 190454
# Total time for Mesh Cleansing: 10.807429552078247
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9897621918263834% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409422**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 107412
# Total time for Mesh Cleansing: 3.2335667610168457
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991628062733716% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342104641**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 18400
# Total time for Mesh Cleansing: 0.21972012519836426
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985889503961793% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342106944**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 55354
# Total time for Mesh Cleansing: 0.2966623306274414
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999747146366132% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342152326**********
# ...
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 63 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 209573
# Total time for Mesh Cleansing: 6.226229190826416
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9982189373627891% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346342793555_30_main_and_child_meshes_array.npz
#  face length 209573 using optimized facets with 3 neighbors
# Filtering edges by size finished: 8.102939128875732, facet # = 10733
# Filtering by convexity and getting centers took: 8.554995059967041, facet # = 2327
# Finished 2327 facets for main mesh: 17.01755118370056
# Filtering edges by size finished: 0.0024442672729492188, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.001302957534790039, facet # = 1
# Total time for facets: 17.027199506759644
# Zero faceted faces = []
# Starting Child 0
# 1 2327
# Done distance matrix: 0.0002963542938232422
# Child 0 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# 1 2327
# Done distance matrix: 0.0003337860107421875
# Child 0 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# 1 2327
# Done distance matrix: 0.00041484832763671875
# Child 0 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 0
# 1 2327
# Done distance matrix: 0.00043129920959472656
# Child 0 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 0.2599039077758789
# Total time for restitching = 0.26092982292175293
# missed_children = [0.0]
# Whole stitching function complete: 24.264815092086792
#
#
#
# *****Running Neuron Stitcher for 648518346342800079**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 130614
# Total time for Mesh Cleansing: 0.887359619140625
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991891064871481% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342803414**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 91 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 325042
# Total time for Mesh Cleansing: 11.78512716293335
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981268347806861% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808000**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 28252
# Total time for Mesh Cleansing: 1.037949800491333
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9956301099520721% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342808014**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 91362
# Total time for Mesh Cleansing: 0.46162986755371094
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993655655217677% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342899284**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 10134
# Total time for Mesh Cleansing: 0.06982779502868652
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9980303328737443% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342916868**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 22176
# Total time for Mesh Cleansing: 0.1897120475769043
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342917417**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 99730
# Total time for Mesh Cleansing: 0.2762472629547119
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994588310751222% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342918233**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 76218
# Total time for Mesh Cleansing: 0.3623528480529785
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990824244966443% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342919817**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 19740
# Total time for Mesh Cleansing: 1.050560712814331
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9962652669829414% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342930214**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 145552
# Total time for Mesh Cleansing: 5.432011604309082
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983401237362306% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343624383**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 36564
# Total time for Mesh Cleansing: 0.23287653923034668
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996719160104987% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343625250**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 11272
# Total time for Mesh Cleansing: 0.2160799503326416
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343785995**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 14788
# Total time for Mesh Cleansing: 0.16200661659240723
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343788850**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 18 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 34842
# Total time for Mesh Cleansing: 1.1296889781951904
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9949740133645554% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343971439**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 38 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 77398
# Total time for Mesh Cleansing: 5.169639348983765
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9859366640340373% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344072981**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 77066
# Total time for Mesh Cleansing: 0.464097261428833
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987299777098129% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344073324**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 21304
# Total time for Mesh Cleansing: 0.14536190032958984
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996246246246246% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344075999**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 50268
# Total time for Mesh Cleansing: 2.6844394207000732
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987681303397576% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344081602**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 64790
# Total time for Mesh Cleansing: 0.1445920467376709
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989515557063122% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344140948**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 13412
# Total time for Mesh Cleansing: 0.11939239501953125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344142845**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 17 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 43248
# Total time for Mesh Cleansing: 1.9352915287017822
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9953967961701344% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344146358**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 49098
# Total time for Mesh Cleansing: 0.42023134231567383
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999226636274829% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349496702**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 80536
# Total time for Mesh Cleansing: 3.2821907997131348
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.992874226397416% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509529**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 431 pieces after mesh split
# There were 70 pieces found after size threshold
# max_index = 0
# max_face_len = 565530
# Total time for Mesh Cleansing: 49.76460552215576
# Number of outside child meshes =  2
# Main mesh and outside child meshes make up 0.9840610852648488% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509529_30_main_and_child_meshes_array.npz
#  face length 565530 using optimized facets with 3 neighbors
# Filtering edges by size finished: 19.890432119369507, facet # = 31848
# Filtering by convexity and getting centers took: 18.1571626663208, facet # = 5107
# Finished 5107 facets for main mesh: 39.24768257141113
# Filtering edges by size finished: 0.007698535919189453, facet # = 29
# Filtering by convexity and getting centers took: 0.008985519409179688, facet # = 8
# Filtering edges by size finished: 0.0046062469482421875, facet # = 28
# Filtering by convexity and getting centers took: 0.008744955062866211, facet # = 5
# Total time for facets: 39.284420013427734
# Zero faceted faces = []
# Starting Child 0
# 8 5107
# Done distance matrix: 0.00312042236328125
# Done Generating final pairs: 0.010187387466430664
# best_stitch_pair = [   4 4993]
# best_stitch_pair_size = 99978.8250793313
# best_stitch_pair_distance = 1015.956735883169
# best_stitch_pair_size_ratio = 0.32963973391039614
# Starting Child 1
# 5 5107
# Done distance matrix: 0.0015866756439208984
# Done Generating final pairs: 0.006083250045776367
# best_stitch_pair = [   2 3905]
# best_stitch_pair_size = 34344.97933397659
# best_stitch_pair_distance = 1250.1891732720337
# best_stitch_pair_size_ratio = 0.5569535139933917
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [4, 4993], 1: [2, 3905]}
# ---Stitching child 0 with pair: [4, 4993]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 163871, starting edge 2nd facet= 284203,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002995014190673828
# returned from stitch mesh: 0.47649478912353516
# Finished stitching child 0 : 0.5341677665710449
# ---Stitching child 1 with pair: [2, 3905]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 12910, starting edge 2nd facet= 284342,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4781951904296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0035254955291748047
# returned from stitch mesh: 0.3544745445251465
# Finished stitching child 1 : 0.40068697929382324
# ***************Finished big stitching iteration: 1.0142312049865723***************
# All children have been processed
# total_stitch_processing_time = 1.0145583152770996
# Total time for restitching = 1.0157487392425537
# missed_children = []
# Whole stitching function complete: 91.82890152931213
# 1059.0108294487

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
