# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349499186******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.060552120208740234
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 682.7855110168457
# 2) Finished: Generating CGAL segmentation for neuron: 698.3692848682404
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2221364974975586
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 3, 6, 5, 24]
# soma_80_percent = 161681.74375
# Debugging the axon filter
# [(2, 160450.0), (3, 161413.484375), (6, 169147.765625), (5, 182673.015625), (24, 163666.28125)]
# possible_Axons_filter_1 = [2, 3]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.07276153564453125
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 2
# 3 = error
# 24 = stub soma
# Total Labels found = {'unsure', 'soma', 'error'}
# 6) Finished: Classifying Entire Neuron: 1.791489601135254
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6130285263061523
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.599051237106323
# Finished Auto Labeling: 710.3370978832245
#
#
# *****Starting Auto Labeling for 648518346349499759******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.048780202865600586
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 517.628561258316
# 2) Finished: Generating CGAL segmentation for neuron: 533.0995986461639
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1753528118133545
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [14, 11, 8, 65, 13, 31, 17, 108, 49, 63]
# soma_80_percent = 230135.7984375
# Debugging the axon filter
# [(14, 236471.625), (11, 227792.140625), (8, 231263.90625), (65, 236635.15625), (13, 245292.71875), (31, 243158.984375), (17, 245254.453125), (108, 231703.171875), (49, 235743.890625), (63, 229399.296875)]
# possible_Axons_filter_1 = [11, 63]
# possible_Axons_filter_2 = [11]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.07044458389282227
# 6) Staring: Classifying Entire Neuron
# 49 = stub soma
# 63 = stub soma
# 108 = cilia
# 15 = stub apical
# 23 = stub apical
# 27 = stub apical
# 30 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 38 = stub apical
# 47 = stub apical
# 48 = stub apical
# 51 = error
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 64 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 83 = stub apical
# 85 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 116 = stub apical
# 117 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 143 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'oblique', 'cilia', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.0178489685058594
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.32891368865966797
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.701505184173584
# Finished Auto Labeling: 543.9524190425873
#
#
# *****Starting Auto Labeling for 648518346349500162******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04065394401550293
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 472.01268434524536
# 2) Finished: Generating CGAL segmentation for neuron: 484.51828479766846
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1650257110595703
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [6, 25, 1, 24, 118, 26, 126, 3, 131, 127, 20, 22, 138, 125, 117]
# soma_80_percent = 237206.8046875
# Debugging the axon filter
# [(6, 245003.46875), (25, 247818.40625), (1, 234626.265625), (24, 248633.0625), (118, 246539.828125), (26, 260463.625), (126, 236641.359375), (3, 256665.84375), (131, 244242.125), (127, 248471.828125), (20, 241094.328125), (22, 253882.75), (138, 246821.9375), (125, 240182.765625), (117, 244827.71875)]
# possible_Axons_filter_1 = [1, 126]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.06500840187072754
# 6) Staring: Classifying Entire Neuron
# 117 = stub soma
# 118 = stub soma
# 126 = cilia
# 125 = stub soma
# 127 = stub soma
# 131 = stub soma
# 138 = stub soma
# 23 = stub apical
# 30 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = error
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 137 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'oblique', 'cilia', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.2656409740448
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.322354793548584
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.902176380157471
# Finished Auto Labeling: 494.6848928928375
#
#
# *****Starting Auto Labeling for 648518346349500939******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06150197982788086
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 774.0802602767944
# 2) Finished: Generating CGAL segmentation for neuron: 791.1922242641449
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21773600578308105
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 12, 136, 9, 28, 15, 8, 20, 27, 90, 58, 100, 89, 152, 144, 94]
# soma_80_percent = 197768.4046875
# Debugging the axon filter
# [(2, 195626.640625), (12, 199408.09375), (136, 197755.328125), (9, 215584.328125), (28, 226679.34375), (15, 212466.421875), (8, 210487.796875), (20, 223026.671875), (27, 210339.28125), (90, 203335.96875), (58, 211790.3125), (100, 209420.5), (89, 201296.390625), (152, 207875.578125), (144, 194426.15625), (94, 197155.546875)]
# possible_Axons_filter_1 = [2, 136, 144, 94]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.07268476486206055
# 6) Staring: Classifying Entire Neuron
# 2 = cilia
# 20 = error
# 90 = stub soma
# 89 = stub soma
# 94 = stub soma
# 100 = stub soma
# 136 = stub soma
# 144 = stub soma
# 152 = stub soma
# Total Labels found = {'unsure', 'soma', 'cilia', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.3920037746429443
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6720459461212158
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.685718297958374
# Finished Auto Labeling: 805.0471494197845
#
#
# *****Starting Auto Labeling for 648518346349503453******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06035280227661133
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 985.2227058410645
# 2) Finished: Generating CGAL segmentation for neuron: 1003.6594853401184
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 16
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.386690616607666
# 5) Staring: Finding Apical Index
# Soma Index = 16
# Soma Connections = [57, 33, 13, 3, 38, 55, 23, 343, 67, 90, 274, 208, 218, 122, 344]
# soma_80_percent = 257374.2296875
# Debugging the axon filter
# [(57, 265527.28125), (33, 281261.28125), (13, 284113.84375), (3, 253836.890625), (38, 281027.15625), (55, 280848.4375), (23, 259786.734375), (343, 260684.515625), (67, 265394.8125), (90, 266182.84375), (274, 267972.5625), (208, 255895.46875), (218, 267640.28125), (122, 261444.84375), (344, 267829.125)]
# possible_Axons_filter_1 = [3, 208]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.14291810989379883
# 6) Staring: Classifying Entire Neuron
# 55 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 57
# 90 = stub soma
# 343 = cilia
# 122 = stub soma
# 208 = stub soma
# 218 = stub soma
# 274 = stub soma
# 344 = stub soma
# 2 = stub apical
# 4 = stub apical
# 15 = stub apical
# 18 = stub apical
# 24 = stub apical
# 27 = stub apical
# 28 = stub apical
# 31 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 41 = stub apical
# 43 = stub apical
# 44 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = error
# 54 = stub apical
# 56 = stub apical
# 58 = stub apical
# 60 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 107 = stub apical
# 109 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 117 = stub apical
# 118 = stub apical
# 120 = stub apical
# 121 = stub apical
# 123 = stub apical
# 124 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 154 = stub apical
# 157 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 204 = stub apical
# 205 = stub apical
# 209 = stub apical
# 213 = stub apical
# 214 = stub apical
# 216 = stub apical
# 217 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 255 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 272 = stub apical
# 273 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 292 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 308 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 324 = stub apical
# 327 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# Total Labels found = {'axon', 'basal', 'apical', 'soma', 'oblique', 'cilia', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.2164199352264404
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4407002925872803
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.964375495910645
# Finished Auto Labeling: 1019.6225666999817
#
#
# *****Starting Auto Labeling for 648518346349505250******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.10063886642456055
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1979.330017566681
# 2) Finished: Generating CGAL segmentation for neuron: 2006.7574534416199
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.35999488830566406
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [69, 126, 34, 49, 89, 37, 11, 41, 36, 43, 40, 14, 68, 184]
# soma_80_percent = 260823.8015625
# Debugging the axon filter
# [(69, 258316.65625), (126, 281380.40625), (34, 276287.25), (49, 271831.96875), (89, 272527.96875), (37, 277146.59375), (11, 257667.734375), (41, 267668.09375), (36, 278980.28125), (43, 258678.96875), (40, 278717.71875), (14, 268125.375), (68, 260945.5625), (184, 273664.25)]
# possible_Axons_filter_1 = [69, 11, 43]
# possible_Axons_filter_2 = [11]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.1477808952331543
# 6) Staring: Classifying Entire Neuron
# 14 = stub soma
# 126 = axon
# 68 = stub soma
# 69 = stub soma
# 89 = stub soma
# 184 = stub soma
# 25 = stub apical
# 29 = stub apical
# 33 = stub apical
# 35 = stub apical
# 42 = stub apical
# 45 = stub apical
# 46 = stub apical
# 48 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 57 = stub apical
# 59 = stub apical
# 60 = stub apical
# 63 = stub apical
# 71 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = error
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 117 = stub apical
# 121 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 132 = stub apical
# 133 = stub apical
# 135 = stub apical
# 137 = stub apical
# 138 = stub apical
# 140 = stub apical
# 146 = stub apical
# 148 = stub apical
# 153 = stub apical
# 154 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 176 = stub apical
# 179 = stub apical
# 182 = stub apical
# 187 = stub apical
# 189 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# Total Labels found = {'axon', 'basal', 'apical', 'soma', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 4.500391244888306
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6111829280853271
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.75647258758545
# Finished Auto Labeling: 2028.3254158496857
#
#
# *****Starting Auto Labeling for 648518346349509523******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0822000503540039
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 2043.530772447586
# 2) Finished: Generating CGAL segmentation for neuron: 2069.2899367809296
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.32911086082458496
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 5, 6, 36, 22, 50, 16, 40, 41, 305, 466, 403]
# soma_80_percent = 260415.2921875
# Debugging the axon filter
# [(1, 287943.59375), (5, 262381.34375), (6, 267772.25), (36, 282116.90625), (22, 255978.296875), (50, 289197.125), (16, 268808.96875), (40, 270643.6875), (41, 262795.28125), (305, 262729.5), (466, 269275.75), (403, 261037.09375)]
# possible_Axons_filter_1 = [22]
# possible_Axons_filter_2 = [22]
# possible_Apical = 22
# 5) Finished: Finding Apical Index: 0.11469507217407227
# 6) Staring: Classifying Entire Neuron
# 305 = stub soma
# 403 = stub soma
# 34 = stub apical
# 42 = stub apical
# 55 = stub apical
# 63 = stub apical
# 76 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 102 = stub apical
# 107 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 174 = stub apical
# 179 = stub apical
# 180 = stub apical
# 186 = stub apical
# 187 = stub apical
# 189 = stub apical
# 193 = stub apical
# 199 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 217 = stub apical
# 219 = stub apical
# 220 = stub apical
# 232 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 307 = stub apical
# 308 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 334 = stub apical
# 335 = stub apical
# 341 = stub apical
# 342 = stub apical
# 360 = stub apical
# 361 = stub apical
# 368 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 383 = stub apical
# 407 = stub apical
# 408 = stub apical
# 409 = stub apical
# 410 = stub apical
# 411 = stub apical
# 412 = stub apical
# 413 = stub apical
# 414 = stub apical
# 417 = stub apical
# 418 = stub apical
# 425 = stub apical
# 438 = stub apical
# 439 = stub apical
# 440 = stub apical
# 441 = stub apical
# 442 = stub apical
# 443 = stub apical
# 446 = stub apical
# 453 = stub apical
# 456 = stub apical
# 457 = stub apical
# 458 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.4729905128479004
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5570359230041504
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.97601056098938
# Finished Auto Labeling: 2087.758543729782
# 7692.675512313843

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
