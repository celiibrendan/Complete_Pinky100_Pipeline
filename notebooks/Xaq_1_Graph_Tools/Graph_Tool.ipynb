# %%
# how to install graph tools
"""
https://git.skewed.de/count0/graph-tool/-/wikis/installation-instructions#gnulinux

"""
# Out:
# '\nhttps://git.skewed.de/count0/graph-tool/-/wikis/installation-instructions#gnulinux\n\n'

# %%
from graph_tool.all import *

# %% [markdown]
# # Example that shows the library is properly working

# %%
#%matplotlib inline

# %%
#import matplotlib.pyplot as plt
g = Graph()

ug = Graph(directed=False)

ug = Graph()
ug.set_directed(False)
assert ug.is_directed() == False

g1 = Graph()
# ... construct g1 ...
g2 = Graph(g1) 

v1 = g.add_vertex()
v2 = g.add_vertex()

e = g.add_edge(v1, v2)

graph_draw(g, vertex_text=g.vertex_index, vertex_font_size=18)
           #output_size=(200, 200), output="two-nodes.png")
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fdb640fa358, at 0x7fdb640fabe0>
