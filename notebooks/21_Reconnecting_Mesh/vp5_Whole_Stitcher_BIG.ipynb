# %%
"""
First attempt to combine all functionality in one function
that can be run from top to bottom

"""
# Out:
# '\nFirst attempt to combine all functionality in one function\nthat can be run from top to bottom\n\n'

# %%
import trimesh
import numpy as np
from collections import Counter
import time
import math
from tqdm import tqdm

# %%
#pick the mesh to process: 
file_location = "./test_meshes/"
file_location = "./"
file_name ="seperated_mesh.off"

# %%
#visualize the neuron to make sure it is correct
visualize = False
if visualize == True:
    visualize_mesh = trimesh.load_mesh(file_location + file_name )
    visualize_mesh.show()

# %% [markdown]
# # Gets parts that are outside of the main mesh

# %%
def filter_mesh_significant_outside_pieces(unfiltered_mesh,significance_threshold=2000,n_sample_points=1000):
    """
    Purpose; will take in a full, unfiltered mesh and find the biggest mesh piece, and then return a list of that mesh 
    with all of the other mesh fragments that are both above the significance_threshold AND outside of the biggest mesh piece

    Pseudocode: 
    1) split the meshes to unconnected pieces
    2) Filter the meshes for only those above the significance_threshold
    3) find the biggest mesh piece
    4) Iterate through all of the remaining pieces:
        a. Determine if mesh inside or outside main mesh
        b. If outside add to final list to return

    Returns: 
    1) list of significant mesh pieces, including the main one that are not inside of main mesh

    """

    mesh_pieces = unfiltered_mesh.split(only_watertight=False)
    
    print(f"There were {len(mesh_pieces)} pieces after mesh split")

    significant_pieces = [m for m in mesh_pieces if len(m.faces) > significance_threshold]

    print(f"There were {len(significant_pieces)} pieces found after size threshold")
    if len(significant_pieces) <=0:
        print("THERE WERE NO MESH PIECES GREATER THAN THE significance_threshold")
        return []

    #find piece with largest size
    max_index = 0
    max_face_len = len(significant_pieces[max_index].faces)

    for i in range(1,len(significant_pieces)):
        if max_face_len < len(significant_pieces[i].faces):
            max_index = i
            max_face_len = len(significant_pieces[i].faces)

    print("max_index = " + str(max_index))
    print("max_face_len = " + str(max_face_len))

    final_mesh_pieces = []

    main_mesh = significant_pieces[max_index]

    #final_mesh_pieces.append(main_mesh)
    for i,mesh in enumerate(significant_pieces):
        if i != max_index:
            #get a random sample of points
            # points = np.array(mesh.vertices[:n_sample_points,:]) # OLD WAY OF DOING THIS
            idx = np.random.randint(len(mesh.vertices), size=n_sample_points)
            points = mesh.vertices[idx,:]
            
            
            start_time = time.time()
            signed_distance = trimesh.proximity.signed_distance(main_mesh,points)
            print(f"Total time = {time.time() - start_time}")

            outside_percentage = sum(signed_distance < 0)/n_sample_points
            if outside_percentage > 0.9:
                final_mesh_pieces.append(mesh)
                print(f"Mesh piece {i} OUTSIDE mesh")
            else:
                print(f"Mesh piece {i} inside mesh :( ")
                
    return main_mesh,final_mesh_pieces

# %%
#start the global timer
global_timer = time.time()

unfiltered_mesh = trimesh.load_mesh(file_location + file_name)

#setting thresholds
significance_threshold=30 #number of faces needed for pieces to be considered to be kept
n_sample_points = 2 #number of points sampled on the mesh for determination of inside or outside
start_time = time.time()

#the main mesh is the first mesh in the piece
main_mesh,child_meshes = filter_mesh_significant_outside_pieces(unfiltered_mesh,
                            significance_threshold=significance_threshold,
                                n_sample_points=n_sample_points)
print(f"Total time for Mesh Cleansing: {time.time() - start_time}")
# Out:
# There were 3902 pieces after mesh split
# There were 378 pieces found after size threshold
# max_index = 0
# max_face_len = 1845336
# Total time = 25.640546321868896
# Mesh piece 1 OUTSIDE mesh
# Total time = 0.07565093040466309
# Mesh piece 2 inside mesh :(
# Total time = 0.26896023750305176
# Mesh piece 3 OUTSIDE mesh
# Total time = 0.807488203048706
# Mesh piece 4 OUTSIDE mesh
# Total time = 0.3158299922943115
# Mesh piece 5 inside mesh :(
# Total time = 0.22599339485168457
# Mesh piece 6 inside mesh :(
# Total time = 0.22240424156188965
# Mesh piece 7 inside mesh :(
# Total time = 0.22249293327331543
# Mesh piece 8 inside mesh :(
# Total time = 0.2547459602355957
# Mesh piece 9 inside mesh :(
# Total time = 0.2192707061767578
# Mesh piece 10 inside mesh :(
# Total time = 0.2913045883178711
# Mesh piece 11 inside mesh :(
# Total time = 0.4082212448120117
# Mesh piece 12 inside mesh :(
# Total time = 0.40895652770996094
# Mesh piece 13 inside mesh :(
# Total time = 0.45026302337646484
# Mesh piece 14 inside mesh :(
# Total time = 0.5501854419708252
# Mesh piece 15 inside mesh :(
# Total time = 0.44408249855041504
# Mesh piece 16 inside mesh :(
# Total time = 0.40350341796875
# Mesh piece 17 inside mesh :(
# Total time = 0.3978242874145508
# Mesh piece 18 inside mesh :(
# Total time = 0.3567237854003906
# Mesh piece 19 inside mesh :(
# Total time = 0.4245178699493408
# Mesh piece 20 inside mesh :(
# Total time = 0.45215868949890137
# Mesh piece 21 inside mesh :(
# Total time = 0.41888856887817383
# Mesh piece 22 inside mesh :(
# Total time = 0.4383065700531006
# Mesh piece 23 inside mesh :(
# Total time = 0.37020349502563477
# Mesh piece 24 inside mesh :(
# Total time = 0.36535072326660156
# Mesh piece 25 inside mesh :(
# Total time = 0.5430805683135986
# Mesh piece 26 inside mesh :(
# Total time = 0.5268564224243164
# Mesh piece 27 inside mesh :(
# Total time = 0.46031999588012695
# Mesh piece 28 inside mesh :(
# Total time = 0.43210315704345703
# Mesh piece 29 inside mesh :(
# Total time = 0.40425705909729004
# Mesh piece 30 inside mesh :(
# Total time = 0.4248993396759033
# Mesh piece 31 inside mesh :(
# Total time = 0.3112204074859619
# Mesh piece 32 inside mesh :(
# Total time = 0.29333972930908203
# Mesh piece 33 inside mesh :(
# Total time = 0.30760765075683594
# Mesh piece 34 inside mesh :(
# Total time = 0.38411664962768555
# Mesh piece 35 inside mesh :(
# Total time = 0.3201887607574463
# Mesh piece 36 inside mesh :(
# Total time = 0.3481893539428711
# Mesh piece 37 inside mesh :(
# Total time = 0.37970614433288574
# Mesh piece 38 inside mesh :(
# Total time = 0.3334939479827881
# Mesh piece 39 inside mesh :(
# Total time = 0.4752767086029053
# Mesh piece 40 inside mesh :(
# Total time = 0.3834691047668457
# Mesh piece 41 inside mesh :(
# Total time = 0.35025477409362793
# Mesh piece 42 inside mesh :(
# Total time = 0.2550196647644043
# Mesh piece 43 inside mesh :(
# Total time = 0.29053664207458496
# Mesh piece 44 inside mesh :(
# Total time = 0.22088098526000977
# Mesh piece 45 inside mesh :(
# Total time = 0.29780125617980957
# Mesh piece 46 inside mesh :(
# Total time = 0.05275607109069824
# Mesh piece 47 OUTSIDE mesh
# Total time = 0.041779279708862305
# Mesh piece 48 OUTSIDE mesh
# Total time = 0.05515170097351074
# Mesh piece 49 OUTSIDE mesh
# Total time = 0.03805899620056152
# Mesh piece 50 OUTSIDE mesh
# Total time = 0.04967141151428223
# Mesh piece 51 OUTSIDE mesh
# Total time = 0.06899452209472656
# Mesh piece 52 OUTSIDE mesh
# Total time = 0.4670524597167969
# Mesh piece 53 OUTSIDE mesh
# Total time = 0.07826447486877441
# Mesh piece 54 OUTSIDE mesh
# Total time = 0.37192273139953613
# Mesh piece 55 inside mesh :(
# Total time = 1.1023974418640137
# Mesh piece 56 OUTSIDE mesh
# Total time = 0.2833983898162842
# Mesh piece 57 inside mesh :(
# Total time = 0.5187699794769287
# Mesh piece 58 inside mesh :(
# Total time = 0.38849329948425293
# Mesh piece 59 inside mesh :(
# Total time = 0.4779684543609619
# Mesh piece 60 inside mesh :(
# Total time = 0.4647042751312256
# Mesh piece 61 inside mesh :(
# Total time = 0.45487308502197266
# Mesh piece 62 inside mesh :(
# Total time = 0.11740803718566895
# Mesh piece 63 OUTSIDE mesh
# Total time = 0.0583038330078125
# Mesh piece 64 OUTSIDE mesh
# Total time = 1.052384853363037
# Mesh piece 65 OUTSIDE mesh
# Total time = 0.4866466522216797
# Mesh piece 66 inside mesh :(
# Total time = 0.4573533535003662
# Mesh piece 67 inside mesh :(
# Total time = 0.472597599029541
# Mesh piece 68 inside mesh :(
# Total time = 0.2979459762573242
# Mesh piece 69 inside mesh :(
# Total time = 0.35838747024536133
# Mesh piece 70 inside mesh :(
# Total time = 0.35871362686157227
# Mesh piece 71 inside mesh :(
# Total time = 0.34818243980407715
# Mesh piece 72 inside mesh :(
# Total time = 0.41895008087158203
# Mesh piece 73 inside mesh :(
# Total time = 0.5078163146972656
# Mesh piece 74 inside mesh :(
# Total time = 0.40407681465148926
# Mesh piece 75 inside mesh :(
# Total time = 0.3933296203613281
# Mesh piece 76 inside mesh :(
# Total time = 0.3747119903564453
# Mesh piece 77 inside mesh :(
# Total time = 0.38271403312683105
# Mesh piece 78 inside mesh :(
# Total time = 0.44190263748168945
# Mesh piece 79 inside mesh :(
# Total time = 0.3749074935913086
# Mesh piece 80 inside mesh :(
# Total time = 0.38217735290527344
# Mesh piece 81 inside mesh :(
# Total time = 0.37913084030151367
# Mesh piece 82 inside mesh :(
# Total time = 0.3857870101928711
# Mesh piece 83 inside mesh :(
# Total time = 0.372739315032959
# Mesh piece 84 inside mesh :(
# Total time = 0.3071866035461426
# Mesh piece 85 inside mesh :(
# Total time = 0.32836127281188965
# Mesh piece 86 inside mesh :(
# Total time = 0.2623481750488281
# Mesh piece 87 inside mesh :(
# Total time = 0.4180576801300049
# Mesh piece 88 inside mesh :(
# Total time = 0.2458477020263672
# Mesh piece 89 inside mesh :(
# Total time = 0.13837122917175293
# Mesh piece 90 inside mesh :(
# Total time = 0.05765128135681152
# Mesh piece 91 OUTSIDE mesh
# Total time = 0.08616948127746582
# Mesh piece 92 OUTSIDE mesh
# Total time = 0.01527094841003418
# Mesh piece 93 OUTSIDE mesh
# Total time = 0.01931595802307129
# Mesh piece 94 OUTSIDE mesh
# Total time = 0.023723363876342773
# Mesh piece 95 OUTSIDE mesh
# Total time = 0.017960786819458008
# Mesh piece 96 OUTSIDE mesh
# Total time = 1.0237946510314941
# Mesh piece 97 OUTSIDE mesh
# Total time = 0.5089781284332275
# Mesh piece 98 inside mesh :(
# Total time = 0.5288958549499512
# Mesh piece 99 inside mesh :(
# Total time = 0.306276798248291
# Mesh piece 100 inside mesh :(
# Total time = 0.279616117477417
# Mesh piece 101 inside mesh :(
# Total time = 0.23558545112609863
# Mesh piece 102 inside mesh :(
# Total time = 0.27780580520629883
# Mesh piece 103 inside mesh :(
# Total time = 0.3376274108886719
# Mesh piece 104 inside mesh :(
# Total time = 0.29938721656799316
# Mesh piece 105 inside mesh :(
# Total time = 0.3467597961425781
# Mesh piece 106 inside mesh :(
# Total time = 0.2644309997558594
# Mesh piece 107 inside mesh :(
# Total time = 0.31162261962890625
# Mesh piece 108 inside mesh :(
# Total time = 0.37646913528442383
# Mesh piece 109 inside mesh :(
# Total time = 0.32178735733032227
# Mesh piece 110 inside mesh :(
# Total time = 0.34444499015808105
# Mesh piece 111 inside mesh :(
# Total time = 0.419100284576416
# Mesh piece 112 inside mesh :(
# Total time = 0.3517262935638428
# Mesh piece 113 inside mesh :(
# Total time = 0.4342045783996582
# Mesh piece 114 inside mesh :(
# Total time = 0.05481457710266113
# Mesh piece 115 OUTSIDE mesh
# Total time = 0.020679712295532227
# Mesh piece 116 OUTSIDE mesh
# Total time = 0.035474300384521484
# Mesh piece 117 OUTSIDE mesh
# Total time = 0.02507925033569336
# Mesh piece 118 OUTSIDE mesh
# Total time = 0.08753466606140137
# Mesh piece 119 OUTSIDE mesh
# Total time = 0.09994149208068848
# Mesh piece 120 OUTSIDE mesh
# Total time = 0.34390997886657715
# Mesh piece 121 inside mesh :(
# Total time = 0.29723572731018066
# Mesh piece 122 inside mesh :(
# Total time = 0.2553102970123291
# Mesh piece 123 inside mesh :(
# Total time = 0.33826780319213867
# Mesh piece 124 inside mesh :(
# Total time = 0.335374116897583
# Mesh piece 125 inside mesh :(
# Total time = 0.3789660930633545
# Mesh piece 126 inside mesh :(
# Total time = 0.3869030475616455
# Mesh piece 127 inside mesh :(
# Total time = 0.3871879577636719
# Mesh piece 128 inside mesh :(
# Total time = 0.29970240592956543
# Mesh piece 129 inside mesh :(
# Total time = 0.24397683143615723
# Mesh piece 130 inside mesh :(
# Total time = 0.33661794662475586
# Mesh piece 131 inside mesh :(
# Total time = 0.33628249168395996
# Mesh piece 132 inside mesh :(
# Total time = 0.3125588893890381
# Mesh piece 133 inside mesh :(
# Total time = 0.4156970977783203
# Mesh piece 134 inside mesh :(
# Total time = 0.4240148067474365
# Mesh piece 135 inside mesh :(
# Total time = 0.46693944931030273
# Mesh piece 136 inside mesh :(
# Total time = 0.30333447456359863
# Mesh piece 137 inside mesh :(
# Total time = 0.34536218643188477
# Mesh piece 138 inside mesh :(
# Total time = 0.345721960067749
# Mesh piece 139 inside mesh :(
# Total time = 0.5146269798278809
# Mesh piece 140 inside mesh :(
# Total time = 0.45846080780029297
# Mesh piece 141 inside mesh :(
# Total time = 0.3594937324523926
# Mesh piece 142 inside mesh :(
# Total time = 0.35362887382507324
# Mesh piece 143 inside mesh :(
# Total time = 0.015880346298217773
# Mesh piece 144 OUTSIDE mesh
# Total time = 0.2553253173828125
# Mesh piece 145 OUTSIDE mesh
# Total time = 0.46961188316345215
# Mesh piece 146 inside mesh :(
# Total time = 0.3779714107513428
# Mesh piece 147 inside mesh :(
# Total time = 0.4954349994659424
# Mesh piece 148 inside mesh :(
# Total time = 0.6417772769927979
# Mesh piece 149 inside mesh :(
# Total time = 0.4954657554626465
# Mesh piece 150 inside mesh :(
# Total time = 0.530980110168457
# Mesh piece 151 inside mesh :(
# Total time = 0.5389237403869629
# Mesh piece 152 inside mesh :(
# Total time = 0.5468168258666992
# Mesh piece 153 inside mesh :(
# Total time = 0.5665247440338135
# Mesh piece 154 inside mesh :(
# Total time = 0.4921910762786865
# Mesh piece 155 inside mesh :(
# Total time = 0.5599210262298584
# Mesh piece 156 inside mesh :(
# Total time = 0.47910380363464355
# Mesh piece 157 inside mesh :(
# Total time = 0.5422649383544922
# Mesh piece 158 inside mesh :(
# Total time = 0.6006183624267578
# Mesh piece 159 inside mesh :(
# Total time = 0.613837718963623
# Mesh piece 160 inside mesh :(
# Total time = 0.5287723541259766
# Mesh piece 161 inside mesh :(
# Total time = 0.5540049076080322
# Mesh piece 162 inside mesh :(
# Total time = 0.5603115558624268
# Mesh piece 163 inside mesh :(
# Total time = 0.5278134346008301
# Mesh piece 164 inside mesh :(
# Total time = 0.5239567756652832
# Mesh piece 165 inside mesh :(
# Total time = 0.3976433277130127
# Mesh piece 166 inside mesh :(
# Total time = 0.3649463653564453
# Mesh piece 167 inside mesh :(
# Total time = 0.31359243392944336
# Mesh piece 168 inside mesh :(
# Total time = 0.47322988510131836
# Mesh piece 169 inside mesh :(
# Total time = 0.4142594337463379
# Mesh piece 170 inside mesh :(
# Total time = 0.41980624198913574
# Mesh piece 171 inside mesh :(
# Total time = 0.4285862445831299
# Mesh piece 172 inside mesh :(
# Total time = 0.002137899398803711
# Mesh piece 173 OUTSIDE mesh
# Total time = 0.5508608818054199
# Mesh piece 174 inside mesh :(
# Total time = 0.5031354427337646
# Mesh piece 175 inside mesh :(
# Total time = 0.5051395893096924
# Mesh piece 176 inside mesh :(
# Total time = 0.38126468658447266
# Mesh piece 177 inside mesh :(
# Total time = 0.39135265350341797
# Mesh piece 178 inside mesh :(
# Total time = 0.06478190422058105
# Mesh piece 179 OUTSIDE mesh
# Total time = 0.054436445236206055
# Mesh piece 180 OUTSIDE mesh
# Total time = 0.10806393623352051
# Mesh piece 181 OUTSIDE mesh
# Total time = 0.018184423446655273
# Mesh piece 182 OUTSIDE mesh
# Total time = 0.6062130928039551
# Mesh piece 183 inside mesh :(
# Total time = 0.540320634841919
# Mesh piece 184 inside mesh :(
# Total time = 0.5881798267364502
# Mesh piece 185 inside mesh :(
# Total time = 0.7451674938201904
# Mesh piece 186 inside mesh :(
# Total time = 0.6407113075256348
# Mesh piece 187 inside mesh :(
# Total time = 0.5352075099945068
# Mesh piece 188 inside mesh :(
# Total time = 0.5198643207550049
# Mesh piece 189 inside mesh :(
# Total time = 0.5810778141021729
# Mesh piece 190 inside mesh :(
# Total time = 0.6084010601043701
# Mesh piece 191 inside mesh :(
# Total time = 0.7545526027679443
# Mesh piece 192 inside mesh :(
# Total time = 0.5936563014984131
# Mesh piece 193 inside mesh :(
# Total time = 0.5604763031005859
# Mesh piece 194 inside mesh :(
# Total time = 0.5215864181518555
# Mesh piece 195 inside mesh :(
# Total time = 0.4779167175292969
# Mesh piece 196 inside mesh :(
# Total time = 0.5389444828033447
# Mesh piece 197 inside mesh :(
# Total time = 0.345508337020874
# Mesh piece 198 inside mesh :(
# Total time = 0.3040642738342285
# Mesh piece 199 inside mesh :(
# Total time = 0.255673885345459
# Mesh piece 200 inside mesh :(
# Total time = 0.251323938369751
# Mesh piece 201 inside mesh :(
# Total time = 0.34339356422424316
# Mesh piece 202 inside mesh :(
# Total time = 0.4381399154663086
# Mesh piece 203 inside mesh :(
# Total time = 0.18753814697265625
# Mesh piece 204 inside mesh :(
# Total time = 0.9507038593292236
# Mesh piece 205 OUTSIDE mesh
# Total time = 0.2930750846862793
# Mesh piece 206 inside mesh :(
# Total time = 0.3558216094970703
# Mesh piece 207 inside mesh :(
# Total time = 0.3767077922821045
# Mesh piece 208 inside mesh :(
# Total time = 0.26021671295166016
# Mesh piece 209 inside mesh :(
# Total time = 0.31438612937927246
# Mesh piece 210 inside mesh :(
# Total time = 0.19460272789001465
# Mesh piece 211 inside mesh :(
# Total time = 0.2909848690032959
# Mesh piece 212 inside mesh :(
# Total time = 0.2639007568359375
# Mesh piece 213 inside mesh :(
# Total time = 1.1176562309265137
# Mesh piece 214 OUTSIDE mesh
# Total time = 0.40427684783935547
# Mesh piece 215 inside mesh :(
# Total time = 0.24468231201171875
# Mesh piece 216 inside mesh :(
# Total time = 0.2968168258666992
# Mesh piece 217 inside mesh :(
# Total time = 0.28296923637390137
# Mesh piece 218 inside mesh :(
# Total time = 0.40207386016845703
# Mesh piece 219 inside mesh :(
# Total time = 0.30306243896484375
# Mesh piece 220 inside mesh :(
# Total time = 0.4200315475463867
# Mesh piece 221 inside mesh :(
# Total time = 0.32846975326538086
# Mesh piece 222 inside mesh :(
# Total time = 0.33005285263061523
# Mesh piece 223 inside mesh :(
# Total time = 0.32788515090942383
# Mesh piece 224 inside mesh :(
# Total time = 0.4742422103881836
# Mesh piece 225 inside mesh :(
# Total time = 0.379335880279541
# Mesh piece 226 inside mesh :(
# Total time = 0.3266739845275879
# Mesh piece 227 inside mesh :(
# Total time = 0.26468896865844727
# Mesh piece 228 inside mesh :(
# Total time = 0.3252136707305908
# Mesh piece 229 inside mesh :(
# Total time = 0.26332902908325195
# Mesh piece 230 inside mesh :(
# Total time = 0.28937840461730957
# Mesh piece 231 inside mesh :(
# Total time = 0.37349963188171387
# Mesh piece 232 inside mesh :(
# Total time = 0.04389309883117676
# Mesh piece 233 OUTSIDE mesh
# Total time = 0.4465749263763428
# Mesh piece 234 inside mesh :(
# Total time = 0.3276658058166504
# Mesh piece 235 inside mesh :(
# Total time = 0.36225104331970215
# Mesh piece 236 inside mesh :(
# Total time = 0.3922743797302246
# Mesh piece 237 inside mesh :(
# Total time = 0.8248155117034912
# Mesh piece 238 inside mesh :(
# Total time = 0.4421706199645996
# Mesh piece 239 inside mesh :(
# Total time = 0.45564818382263184
# Mesh piece 240 inside mesh :(
# Total time = 0.48415684700012207
# Mesh piece 241 inside mesh :(
# Total time = 0.38427019119262695
# Mesh piece 242 inside mesh :(
# Total time = 0.38055968284606934
# Mesh piece 243 inside mesh :(
# Total time = 0.5517051219940186
# Mesh piece 244 inside mesh :(
# Total time = 0.5317232608795166
# Mesh piece 245 inside mesh :(
# Total time = 0.4919853210449219
# Mesh piece 246 inside mesh :(
# Total time = 0.2583026885986328
# Mesh piece 247 OUTSIDE mesh
# Total time = 0.30185961723327637
# Mesh piece 248 OUTSIDE mesh
# Total time = 0.5056655406951904
# Mesh piece 249 inside mesh :(
# Total time = 0.5109665393829346
# Mesh piece 250 inside mesh :(
# Total time = 0.5023272037506104
# Mesh piece 251 inside mesh :(
# Total time = 0.5616865158081055
# Mesh piece 252 inside mesh :(
# Total time = 0.49035120010375977
# Mesh piece 253 inside mesh :(
# Total time = 0.5935583114624023
# Mesh piece 254 inside mesh :(
# Total time = 0.34974241256713867
# Mesh piece 255 inside mesh :(
# Total time = 0.383760929107666
# Mesh piece 256 inside mesh :(
# Total time = 0.3957796096801758
# Mesh piece 257 inside mesh :(
# Total time = 0.4549570083618164
# Mesh piece 258 inside mesh :(
# Total time = 0.3034703731536865
# Mesh piece 259 inside mesh :(
# Total time = 0.3939182758331299
# Mesh piece 260 inside mesh :(
# Total time = 0.3552567958831787
# Mesh piece 261 inside mesh :(
# Total time = 0.3913736343383789
# Mesh piece 262 inside mesh :(
# Total time = 0.40683794021606445
# Mesh piece 263 inside mesh :(
# Total time = 0.34445953369140625
# Mesh piece 264 inside mesh :(
# Total time = 0.38462400436401367
# Mesh piece 265 inside mesh :(
# Total time = 0.36403727531433105
# Mesh piece 266 inside mesh :(
# Total time = 0.5403056144714355
# Mesh piece 267 inside mesh :(
# Total time = 0.5767335891723633
# Mesh piece 268 inside mesh :(
# Total time = 0.44760608673095703
# Mesh piece 269 inside mesh :(
# Total time = 0.4072914123535156
# Mesh piece 270 inside mesh :(
# Total time = 0.3997976779937744
# Mesh piece 271 inside mesh :(
# Total time = 0.4230329990386963
# Mesh piece 272 inside mesh :(
# Total time = 0.4723217487335205
# Mesh piece 273 inside mesh :(
# Total time = 0.5272712707519531
# Mesh piece 274 inside mesh :(
# Total time = 0.5168490409851074
# Mesh piece 275 inside mesh :(
# Total time = 0.38721776008605957
# Mesh piece 276 inside mesh :(
# Total time = 0.5427947044372559
# Mesh piece 277 inside mesh :(
# Total time = 0.6208219528198242
# Mesh piece 278 inside mesh :(
# Total time = 0.46893835067749023
# Mesh piece 279 inside mesh :(
# Total time = 0.5044214725494385
# Mesh piece 280 inside mesh :(
# Total time = 0.369673490524292
# Mesh piece 281 inside mesh :(
# Total time = 0.4263646602630615
# Mesh piece 282 inside mesh :(
# Total time = 0.35462498664855957
# Mesh piece 283 inside mesh :(
# Total time = 0.36660003662109375
# Mesh piece 284 inside mesh :(
# Total time = 0.43504929542541504
# Mesh piece 285 inside mesh :(
# Total time = 0.39615416526794434
# Mesh piece 286 inside mesh :(
# Total time = 0.33580970764160156
# Mesh piece 287 inside mesh :(
# Total time = 0.2772510051727295
# Mesh piece 288 OUTSIDE mesh
# Total time = 0.30831217765808105
# Mesh piece 289 OUTSIDE mesh
# Total time = 0.4606475830078125
# Mesh piece 290 inside mesh :(
# Total time = 0.46085548400878906
# Mesh piece 291 inside mesh :(
# Total time = 0.45212483406066895
# Mesh piece 292 inside mesh :(
# Total time = 0.3572227954864502
# Mesh piece 293 inside mesh :(
# Total time = 0.6874375343322754
# Mesh piece 294 inside mesh :(
# Total time = 0.6808350086212158
# Mesh piece 295 inside mesh :(
# Total time = 0.6474771499633789
# Mesh piece 296 inside mesh :(
# Total time = 0.5151090621948242
# Mesh piece 297 inside mesh :(
# Total time = 0.3537178039550781
# Mesh piece 298 inside mesh :(
# Total time = 0.37232279777526855
# Mesh piece 299 inside mesh :(
# Total time = 0.35248422622680664
# Mesh piece 300 inside mesh :(
# Total time = 0.030133962631225586
# Mesh piece 301 OUTSIDE mesh
# Total time = 0.2741820812225342
# Mesh piece 302 inside mesh :(
# Total time = 0.31938719749450684
# Mesh piece 303 inside mesh :(
# Total time = 0.3353133201599121
# Mesh piece 304 inside mesh :(
# Total time = 0.2956516742706299
# Mesh piece 305 inside mesh :(
# Total time = 0.39745473861694336
# Mesh piece 306 inside mesh :(
# Total time = 0.36587977409362793
# Mesh piece 307 inside mesh :(
# Total time = 0.34223294258117676
# Mesh piece 308 inside mesh :(
# Total time = 0.47603631019592285
# Mesh piece 309 inside mesh :(
# Total time = 0.5081162452697754
# Mesh piece 310 inside mesh :(
# Total time = 0.447676420211792
# Mesh piece 311 inside mesh :(
# Total time = 0.45432329177856445
# Mesh piece 312 inside mesh :(
# Total time = 0.39339709281921387
# Mesh piece 313 inside mesh :(
# Total time = 0.3185746669769287
# Mesh piece 314 inside mesh :(
# Total time = 0.32579946517944336
# Mesh piece 315 inside mesh :(
# Total time = 0.3871791362762451
# Mesh piece 316 inside mesh :(
# Total time = 0.37549400329589844
# Mesh piece 317 inside mesh :(
# Total time = 0.3618464469909668
# Mesh piece 318 inside mesh :(
# Total time = 0.35846590995788574
# Mesh piece 319 inside mesh :(
# Total time = 0.3589177131652832
# Mesh piece 320 inside mesh :(
# Total time = 0.3943934440612793
# Mesh piece 321 inside mesh :(
# Total time = 0.33551740646362305
# Mesh piece 322 inside mesh :(
# Total time = 0.36051177978515625
# Mesh piece 323 inside mesh :(
# Total time = 0.38162803649902344
# Mesh piece 324 inside mesh :(
# Total time = 0.371478796005249
# Mesh piece 325 inside mesh :(
# Total time = 0.36045408248901367
# Mesh piece 326 inside mesh :(
# Total time = 0.3772597312927246
# Mesh piece 327 inside mesh :(
# Total time = 0.34578800201416016
# Mesh piece 328 inside mesh :(
# Total time = 0.3848898410797119
# Mesh piece 329 inside mesh :(
# Total time = 0.38541507720947266
# Mesh piece 330 inside mesh :(
# Total time = 0.12971782684326172
# Mesh piece 331 inside mesh :(
# Total time = 0.4370133876800537
# Mesh piece 332 inside mesh :(
# Total time = 0.48674702644348145
# Mesh piece 333 inside mesh :(
# Total time = 0.477522611618042
# Mesh piece 334 inside mesh :(
# Total time = 0.4469413757324219
# Mesh piece 335 inside mesh :(
# Total time = 0.40842223167419434
# Mesh piece 336 inside mesh :(
# Total time = 0.422285795211792
# Mesh piece 337 inside mesh :(
# Total time = 0.45545029640197754
# Mesh piece 338 inside mesh :(
# Total time = 0.3610658645629883
# Mesh piece 339 inside mesh :(
# Total time = 0.33751845359802246
# Mesh piece 340 inside mesh :(
# Total time = 0.4395577907562256
# Mesh piece 341 inside mesh :(
# Total time = 0.3717377185821533
# Mesh piece 342 inside mesh :(
# Total time = 0.38829660415649414
# Mesh piece 343 inside mesh :(
# Total time = 0.37732720375061035
# Mesh piece 344 inside mesh :(
# Total time = 0.4796910285949707
# Mesh piece 345 inside mesh :(
# Total time = 0.5712447166442871
# Mesh piece 346 inside mesh :(
# Total time = 0.45529723167419434
# Mesh piece 347 inside mesh :(
# Total time = 0.44537973403930664
# Mesh piece 348 inside mesh :(
# Total time = 0.5438535213470459
# Mesh piece 349 inside mesh :(
# Total time = 0.4471471309661865
# Mesh piece 350 inside mesh :(
# Total time = 0.44766950607299805
# Mesh piece 351 inside mesh :(
# Total time = 0.45635032653808594
# Mesh piece 352 inside mesh :(
# Total time = 0.4443380832672119
# Mesh piece 353 inside mesh :(
# Total time = 0.45093774795532227
# Mesh piece 354 inside mesh :(
# Total time = 0.41176462173461914
# Mesh piece 355 inside mesh :(
# Total time = 0.40599966049194336
# Mesh piece 356 inside mesh :(
# Total time = 0.4026319980621338
# Mesh piece 357 inside mesh :(
# Total time = 0.4302976131439209
# Mesh piece 358 inside mesh :(
# Total time = 0.25286316871643066
# Mesh piece 359 inside mesh :(
# Total time = 0.24158811569213867
# Mesh piece 360 inside mesh :(
# Total time = 0.16658949851989746
# Mesh piece 361 inside mesh :(
# Total time = 0.23332667350769043
# Mesh piece 362 inside mesh :(
# Total time = 0.31745290756225586
# Mesh piece 363 inside mesh :(
# Total time = 0.24226117134094238
# Mesh piece 364 inside mesh :(
# Total time = 0.29607152938842773
# Mesh piece 365 inside mesh :(
# Total time = 0.422760009765625
# Mesh piece 366 inside mesh :(
# Total time = 0.4800703525543213
# Mesh piece 367 inside mesh :(
# Total time = 0.4597949981689453
# Mesh piece 368 inside mesh :(
# Total time = 0.39234185218811035
# Mesh piece 369 inside mesh :(
# Total time = 0.4222390651702881
# Mesh piece 370 inside mesh :(
# Total time = 0.41979050636291504
# Mesh piece 371 inside mesh :(
# Total time = 0.427689790725708
# Mesh piece 372 inside mesh :(
# Total time = 0.41729307174682617
# Mesh piece 373 inside mesh :(
# Total time = 0.38271045684814453
# Mesh piece 374 inside mesh :(
# Total time = 0.3202090263366699
# Mesh piece 375 inside mesh :(
# Total time = 0.3738558292388916
# Mesh piece 376 inside mesh :(
# Total time = 0.41651439666748047
# Mesh piece 377 inside mesh :(
# Total time for Mesh Cleansing: 176.28450679779053

# %% [markdown]
# # Calculates the facets for all the children and the main mesh

# %%
# need a way of finding the neighbors that have to share adjacent faces
def create_neighbors_lookup(mesh):
    start_time = time.time()
    neighbors_lookup = dict([(i,[]) for i in range(0,len(mesh.faces))])
    #print(f"Creating empty dictionary : {time.time() - start_time}")
    
    start_time = time.time()
    for adj in mesh.face_adjacency:
        neighbors_lookup[adj[0]].append(adj[1])
        neighbors_lookup[adj[1]].append(adj[0])
    #print(f"Filling in neighbors lookup : {time.time() - start_time}")
    
    return neighbors_lookup

def filter_and_expand_facets(new_mesh,
                             first_pass_size_threshold=2000,
                             normal_closeness=0.985):
    
    """
    
    """
    
    #filter the facets that are below a size threshold
    new_facets = new_mesh.facets[np.where(new_mesh.facets_area > first_pass_size_threshold)[0]]

    neighbors_lookup = create_neighbors_lookup(new_mesh)
    
    #generate a normals lookup table and see if works faster than regular lookup
    normal_lookup = {}

    for i in range(0,len(new_mesh.faces)):
        normal_lookup[i] = new_mesh.face_normals[i]
    
    global_start_time = time.time()
    final_facets= [0]*len(new_facets)
    
    for i,facet in enumerate(new_facets):
    #     mini_global_start_time = time.time()
    #     print(facet)
    #     print(type(facet))
    #     start_time = time.time()
    #     print([find_neighbors(k) for k in facet])
        total_neighbors = list(set(np.hstack([neighbors_lookup[k] for k in facet])).difference(set(facet)))
    #     print(total_neighbors)
    #     print(f"time initial neighbors: {(time.time() - start_time)}")
        neighbors_to_add = []
        neighbors_checked = []
        #print(total_neighbors)

        #just get the normal from one of the faces already in the facet
    #     start_time = time.time()
        facet_normal = normal_lookup[facet[0]]

    #     total_dot_time = 0
        while len(total_neighbors) > 0:
            current_neighbor = total_neighbors.pop()
            neighbors_checked.append(current_neighbor)

    #         print("--------------")
    # #         #check to see if neighbor has same normal face
    # #         start_dot_time = time.time()
    # #         dot_result = np.dot(new_mesh.face_normals[current_neighbor],facet_normal) #> normal_closeness
    # #         print(dot_result)
    # #         print((time.time() - start_dot_time) * 1000)

    #         start_dot_time = time.time()
    #         print(current_neighbor)
    #         #a = new_mesh.face_normals[current_neighbor]

    #         print((time.time() - start_dot_time) * 1000)
    #         dot_result = a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness
    #         print(dot_result)
    #         print((time.time() - start_dot_time) * 1000)
    #         print("--------------")

    #         total_dot_time += (time.time() - start_dot_time)*1000

            a = normal_lookup[current_neighbor]
            if a[0]*facet_normal[0] + a[1]*facet_normal[1] + a[2]*facet_normal[2]  > normal_closeness:

                neighbors_to_add.append(current_neighbor)
                #get the neighbors of this current face
                for neigh in neighbors_lookup[current_neighbor]:
                    #only add those neighbors that havent already been checked, in original facet group, or already in list to check
                    if neigh not in neighbors_checked and neigh not in facet and neigh not in total_neighbors:
                        total_neighbors.append(neigh)
    #     print(f"Total dot time: {total_dot_time}")
    #     print(f"time loop: {(time.time() - start_time)}")
    #     print("neighbors_to_add = " + str(neighbors_to_add))abs
    #     print("neighbors_checked = " + str(neighbors_checked))
    #     print("adding list = " + str(list(facet) + neighbors_to_add))
    #     start_time = time.time()
        final_facets[i] = list(facet) + neighbors_to_add
    #     print(f"Appending to list: {(time.time() - start_time)}")

    #     print(f"Total time: {(time.time() - mini_global_start_time)}")
    #     print("------------------------------------------------------")


    print(f"Total Facet building time: {(time.time() - global_start_time)}")
    return final_facets

def filter_final_facets(gap_mesh):
    """
    Gets the facets faces list and the center points of these facets from mesh
    Filters:
    1) Only lets facets greater than first_pass_size_threshold exist
      **** might need to look at this because area is that of facets before expansion
    2) Has to have a high convex border
    
    Expansions:
    1) Expands the facet group to neighbors that are within the normal_closeness
    for their normals when doing the dot product
    
    Order:
    1) Size filtering
    2) Expansion
    3) Convex Border filtering
    """
    
    final_facets = filter_and_expand_facets(gap_mesh,
                                 first_pass_size_threshold=2000,
                                 normal_closeness=0.985)

    # after computing final faces, filter for convexity
    edges = gap_mesh.edges_sorted.reshape((-1, 6)) #groups all the edges belonging to the corresponding face in one row
    final_facets_mean = np.zeros(len(final_facets))
    
    
    #make lookup table for face number to spot in the adjacency edges
    face_adjacency_index_lookup = [[] for i in gap_mesh.faces]
    for i,faces in enumerate(gap_mesh.face_adjacency):
        for f in faces:
            face_adjacency_index_lookup[f].append(i)


    for j,facet in enumerate(final_facets):
        # get the edges for each facet
        edges_facet = [edges[i].reshape((-1, 2)) for i in [facet]][0] #stores all the edges belonging to that face

        #get the indexes of the boundary edges:
        indexes = trimesh.grouping.group_rows(edges_facet, require_count=1)
        edge_0 = edges_facet[indexes]

        #find the faces that correspond to the boundary edges
        edge_0_faces = [facet[int(k/3)] for k in indexes]


        #2) Find the indexes of the edges int he face_adajacency_edges and store the projections
        adjacency_values = []
        for edge,edge_face in zip(edge_0,edge_0_faces):
            possible_adj_indexes = face_adjacency_index_lookup[edge_face]

            for index in possible_adj_indexes:
                if len(set(edge).intersection(set(gap_mesh.face_adjacency_edges[index]))) >= 2:
                    #print(f"adj edge = {e} and boundary edge = {edge}")
                    adjacency_values.append(gap_mesh.face_adjacency_angles[index]) # the metric we actually want to measure
                    break


        final_facets_mean[j] = np.mean(adjacency_values)
        
        

    #filter the final facets and output them so they can be plotted
    adjacency_threshold =  0.8
    final_facets_mean_filtered = np.array(final_facets)[final_facets_mean > adjacency_threshold]

    #Compute the centers
    final_facets_centers = []
    
    for filt in final_facets_mean_filtered: 
        #print("filt = " + str(filt))
        unique_vertices = gap_mesh.vertices[np.unique(gap_mesh.faces[filt].ravel())].astype("float")
        final_facets_centers.append((np.mean(unique_vertices[:,0]),
                          np.mean(unique_vertices[:,1]),
                          np.mean(unique_vertices[:,2])))
    
    return final_facets_mean_filtered,final_facets_centers

# %%
facet_time = time.time()
main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
print("Finished facets for main mesh")
child_meshes_facets= []
for jj,gap_mesh in enumerate(child_meshes):
    start_time = time.time()
    child_meshes_facets.append(filter_final_facets(gap_mesh))
    print(f"Finished facets for child {jj} : {time.time() - start_time}")


print(f"Total time for facets: {time.time() - facet_time}")
#child_meshes_facets = [filter_final_facets(gap_mesh) for gap_mesh in child_meshes]
# Out:
# Total Facet building time: 6.642851829528809
# Finished facets for main mesh
# Total Facet building time: 0.3320026397705078
# Finished facets for child 0 : 2.8415918350219727
# Total Facet building time: 0.04359936714172363
# Finished facets for child 1 : 0.5206010341644287
# Total Facet building time: 0.14060044288635254
# Finished facets for child 2 : 1.083897352218628
# Total Facet building time: 0.055624961853027344
# Finished facets for child 3 : 0.6682987213134766
# Total Facet building time: 0.05357170104980469
# Finished facets for child 4 : 0.43063783645629883
# Total Facet building time: 0.01761603355407715
# Finished facets for child 5 : 0.14690041542053223
# Total Facet building time: 0.030818462371826172
# Finished facets for child 6 : 0.38648343086242676
# Total Facet building time: 0.03309965133666992
# Finished facets for child 7 : 0.2339310646057129
# Total Facet building time: 0.05725717544555664
# Finished facets for child 8 : 0.22388386726379395
# Total Facet building time: 0.07395339012145996
# Finished facets for child 9 : 0.5319530963897705
# Total Facet building time: 0.011158466339111328
# Finished facets for child 10 : 0.08647608757019043
# Total Facet building time: 0.04190492630004883
# Finished facets for child 11 : 0.27010536193847656
# Total Facet building time: 0.010599374771118164
# Finished facets for child 12 : 0.159498929977417
# Total Facet building time: 0.015766620635986328
# Finished facets for child 13 : 0.12868070602416992
# Total Facet building time: 0.0485844612121582
# Finished facets for child 14 : 0.21631407737731934
# Total Facet building time: 0.04507780075073242
# Finished facets for child 15 : 0.4755535125732422
# Total Facet building time: 0.02183389663696289
# Finished facets for child 16 : 0.1786189079284668
# Total Facet building time: 0.0004761219024658203
# Finished facets for child 17 : 0.008260965347290039
# Total Facet building time: 0.00017881393432617188
# Finished facets for child 18 : 0.006198883056640625
# Total Facet building time: 4.100799560546875e-05
# Finished facets for child 19 : 0.0028264522552490234
# Total Facet building time: 0.0004813671112060547
# Finished facets for child 20 : 0.0064373016357421875
# Total Facet building time: 0.002521991729736328
# Finished facets for child 21 : 0.022844314575195312
# Total Facet building time: 0.00022172927856445312
# Finished facets for child 22 : 0.004080772399902344
# Total Facet building time: 0.0014066696166992188
# Finished facets for child 23 : 0.02284836769104004
# Total Facet building time: 0.0002853870391845703
# Finished facets for child 24 : 0.006002902984619141
# Total Facet building time: 0.0019459724426269531
# Finished facets for child 25 : 0.025089025497436523
# Total Facet building time: 3.337860107421875e-06
# Finished facets for child 26 : 0.0018382072448730469
# Total Facet building time: 4.553794860839844e-05
# Finished facets for child 27 : 0.0030891895294189453
# Total Facet building time: 0.0043621063232421875
# Finished facets for child 28 : 0.05323934555053711
# Total Facet building time: 0.008188486099243164
# Finished facets for child 29 : 0.10135054588317871
# Total Facet building time: 0.005660057067871094
# Finished facets for child 30 : 0.04430747032165527
# Total Facet building time: 0.02642512321472168
# Finished facets for child 31 : 0.12178277969360352
# Total Facet building time: 0.0022096633911132812
# Finished facets for child 32 : 0.018505096435546875
# Total Facet building time: 0.005780696868896484
# Finished facets for child 33 : 0.021711111068725586
# Total Facet building time: 0.0019207000732421875
# Finished facets for child 34 : 0.027675390243530273
# Total Facet building time: 0.0006754398345947266
# Finished facets for child 35 : 0.011619091033935547
# Total Facet building time: 0.000988006591796875
# Finished facets for child 36 : 0.0065691471099853516
# Total Facet building time: 0.015035867691040039
# Finished facets for child 37 : 0.04074525833129883
# Total Facet building time: 0.0007815361022949219
# Finished facets for child 38 : 0.0071260929107666016
# Total Facet building time: 0.0007266998291015625
# Finished facets for child 39 : 0.007010221481323242
# Total Facet building time: 7.62939453125e-05
# Finished facets for child 40 : 0.0029685497283935547
# Total Facet building time: 3.337860107421875e-06
# Finished facets for child 41 : 0.0028960704803466797
# Total Facet building time: 0.0008633136749267578
# Finished facets for child 42 : 0.008512735366821289
# Total time for facets: 59.648226499557495

# %% [markdown]
# # Check that facet extraction for each piece worked

# %%
# # download the facets list and see if the process worked:
# index = 2
# facets_group = np.zeros(len(child_meshes[index].faces)).astype(int)

# for i,facet_group in enumerate(child_meshes_facets[index][0]):
#     for face in facet_group:
#         facets_group[face] = i + 1 #so that you reserve the label 0 for blenders none

# np.savez("./test_meshes/" + file_name[:-4] + "_facet_piece_" + str(index) + ".npz",
#          facets_group=facets_group,
#         facets_group_centers=child_meshes_facets[index][1])

# from print_trimesh import print_trimesh
# print_trimesh(child_meshes[index],"./test_meshes/piece_" + str(index) + ".off")


# len(facets_group)

# %% [markdown]
# # START ITERATIVE PROCESS THAT CONNECTS THE MESHES

# %%
def apply_bbox_filter(child,min_bb_zone,max_bb_zone):
    """
    Determines if child is withing the bounding box zone
    designated by the bounding box corners
    
    """
    #get the min and max of the bounding box for the mesh
    min_bb = np.array(child.bounding_box.vertices).min(0)
    max_bb = np.array(child.bounding_box.vertices).max(0)
    
    #print(min_bb,max_bb)
    #print(min_bb_zone,max_bb_zone)
    
    #if fails any of these checks then return false, else return True
    if min(min_bb[0],max_bb[0])>max_bb_zone[0]:
        print("returning x greater max")
        return False
    
    if max(min_bb[0],max_bb[0])<min_bb_zone[0]:
        print("returning x less min")
        return False
    
    if min(min_bb[1],max_bb[1])>max_bb_zone[1]:
        print("returning y greater max")
        return False
    
    if max(min_bb[1],max_bb[1])<min_bb_zone[1]:
        print("returning y less min")
        return False
        
    if min(min_bb[2],max_bb[2])>max_bb_zone[2]:
        print("returning z greater max")
        return False
    
    if max(min_bb[2],max_bb[2])<min_bb_zone[2]:
        print("returning z less mim")
        return False
    return True

import math
def area(vertices):
    """
    Calculates the area of a 3D triangle from it's coordinates
    """
    side_a = np.linalg.norm(vertices[0]-vertices[1])
    side_b = np.linalg.norm(vertices[1]-vertices[2])
    side_c = np.linalg.norm(vertices[2]-vertices[0])
    s = 0.5 * ( side_a + side_b + side_c)
    return math.sqrt(s * (s - side_a) * (s - side_b) * (s - side_c))

def find_polygon_area(mesh,list_of_faces):
    "Calculates the area of a 3D polygon that is created from connected traingles"
    return(sum([area(mesh.vertices[mesh.faces[r]]) for r in list_of_faces]))

# %%
# restitching functions
import trimesh
import numpy as np
from collections import Counter
import time
import math

#gets the projection of point p onto line a
def ClosestPointOnLine(a, b, p):
    ap = p-a
    ab = b-a
    #base_vector = ab
    result = np.dot(ap,ab)/np.dot(ab,ab) # * ab
    return result




#now have the mesh and the facet faces, can send to function
def stitch_mesh_piece_vp3(new_mesh,facet_1,facet_2,
                          delete_facets=False,
                         return_added_mesh = True,
                         fix_normals = True):
    """
    Changed since last version: 
    1) parameter for deleting facets at end or not
    2) parameter for returning added mesh or not 
    3) Changed normals check to print statement and not exception
    
    
    """
    start_time = time.time()
    #how to find the normals of facet groups:
    facet_group_1_normal = new_mesh.face_normals[facet_1[0]]
    facet_group_2_normal = new_mesh.face_normals[facet_2[0]]


    #get the correct version of the normals: (might need to flip them if going in opposite direction)
    if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
        print("same direction normals")
        pass
    elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
        print("opposite direction normals")
        facet_group_2_normal = facet_group_2_normal*-1
    else:
        print("Not correct normals")
        #raise Exception("Not correct normals")

    #print(facet_group_1_normal,facet_group_2_normal)

    # make each row correspond to a single face 
    edges = new_mesh.edges_sorted.reshape((-1, 6))
    # get the edges for each facet
    edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
    edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                               for i in edges_facet])

    #the list of boundary edges and unique points in the boundary edges
    edge_0 = edges_boundary[0]
    edge_1 = edges_boundary[1]

    #gets the unique number of points
    edge_0_points = np.unique(np.hstack(edge_0))
    edge_1_points = np.unique(np.hstack(edge_1))
    print("Found boundary edges")
    """
    get the dot product of all the points
    """

    #get any 2 points on the triangle and make that the reference edge
    edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

    #gets the starting index for the 1st facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_0_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_0_starting_point = edge_0_points[max_index]

    #gets the starting index for the 2nd facet (so that the start of the stitching is close)
    max_index = 0
    max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

    for i in range(1,len(edge_1_points)):
        current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
        if current_magnitude > max_magnitude:
            max_index = i
            max_magnitude = current_magnitude

    edge_1_starting_point = edge_1_points[max_index]

    print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
    #print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])
    print(f"Time at beginning finding 1st facet and direction = {time.time() - start_time}")

    """
    Need to order the points for restitching

    Pseudocode: 
    1) Get starting piont
    2) Find the two edges corresponding to that point
    3) Need to decide which direction to start....
    - go in direction that make the cross of the (1st and last) point in the same direction of the 
    normal of the first facet
    4) loop through and record the orders of the vertices as you traverse along the edges 
    until you arrive back at the start
    5) Error if:
        a. You arrive back at the start and haven't processed all the edges
        b. Processsed all the edges but haven't arrived back at start

    6) Repeat steps 1 through 5 for 2nd facet group
    """
    start_point_list = [edge_0_starting_point,edge_1_starting_point]
    edge_list = [edge_0,edge_1]
    edge_order_list = []

    #loop that organizes the unique boundary points into the correct order
    for i,start_point in enumerate(start_point_list):
        start_time = time.time()
        print(f"Starting Organizing vertices for side {i}")
        #print(f"start_point = {start_point}")
        edge_order = [start_point]
        processed_edges = []

        #find the matching edges
        starting_edges_indices = np.where(np.logical_or(edge_list[i][:,0] == start_point,edge_list[i][:,1] == start_point) == True)[0]
        print(starting_edges_indices)
        starting_edges = edge_list[i][starting_edges_indices]
        #print(f"starting edges = {starting_edges}") #the list of the two possible edges

        if starting_edges.size < 4:
            raise Exception("Not enough edges for 1st facet start point")

        if starting_edges.size > 4:
            raise Exception("Too many edges for 1st facet start point") 

        #np.where(starting_edges[1,:] != start_point)[0][0]
        #gets the vectors that will be used for the cross product
        #print("np.where(starting_edges[0,:] != start_point)[0][0] = " + str(np.where(starting_edges[0,:] != start_point)[0][0]))
        #print("np.where(starting_edges[1,:] != start_point)[0][0] = " + str(np.where(starting_edges[1,:] != start_point)[0][0]))


        #gets the possible starting vectors
        possible_starting_vector_1 = new_mesh.vertices[starting_edges[0,:][np.where(starting_edges[0,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        possible_starting_vector_2 = new_mesh.vertices[starting_edges[1,:][np.where(starting_edges[1,:] != start_point)[0][0]]] - new_mesh.vertices[start_point]
        

        #find the cross product of the starting vectors
        starting_edges_cross = np.cross(possible_starting_vector_1,possible_starting_vector_2)

        #make sure that the order of the vectors goes so that the cross product is in line with the starting normal
        #this ensures the the circular direction of the stitching will be the same
        if np.dot(starting_edges_cross,facet_group_1_normal) > 0:
            print("Edge 1 picked for direction")
            processed_edges.append(starting_edges_indices[0])
            current_vertex = starting_edges[0][np.where(starting_edges[0,:] != start_point)[0][0]]
        else:
            print("Edge 2 picked for direction")
            processed_edges.append(starting_edges_indices[1])
            #print("np.where(starting_edges[1,:] != start_point) = " + str(np.where(starting_edges[1,:] != start_point)))
            current_vertex = starting_edges[1][np.where(starting_edges[1,:] != start_point)[0][0]]

        #print(f"current_vertex = {current_vertex}" )
        #print("edge_list = " + str(edge_list))

        
        #now iterate through number of 
        for z in range(1,edge_list[i][:,0].size):
            #print("edge_order_temp = " + str(edge_order))
            if current_vertex == start_point:
                print("Start vertex reached before processed all of edges")
                
                """
                
                These should be ok because the extra loops are created from holes inside and this process should always get the outside loop
                
                
                """
                break

            #get the next edge
            counter = 0
            next_vertex = -1
            for j,edg in enumerate(edge_list[i]):
                #print("edg = " + str(edg))
                #print("processed_edges = " + str(processed_edges))
                if current_vertex in edg and j not in processed_edges:
                    current_edge_index = j
                    if edg[0] != current_vertex:
                        next_vertex = edg[0]
                    else:
                        next_vertex = edg[1]


                    counter += 1
                    if counter >= 2:
                        #raise Exception(f"More than 2 edges possibilities for {current_vertex}")
                        #Don't want to make it an exception anymore put just print out warning
                        print("More than 2 edges possibilities for {current_vertex}") # BAC change

            #make sure the next vertex was found
            if next_vertex <= -1:
                raise Exception(f"No next vertex was found for {current_vertex} ")

            #if found next vertex then add the old vertex and edge index
            #to the processed edges lists and the order of vertices
            processed_edges.append(current_edge_index)
            edge_order.append(current_vertex)

            current_vertex = next_vertex


        edge_order_list.append(edge_order)
        print(f"edge_{i}_order done, len = {len(edge_order)} ")#"= {edge_order}")
        print(f"Total time finding edge order: {time.time() - start_time}")

    start_time = time.time()
    lengths_of_boundaries = [len(x) for x in edge_order_list]
    bigger = lengths_of_boundaries.index(max(lengths_of_boundaries))
    smaller = 1-bigger

    #print(f"index of bigger facets = {bigger}\nindex of smaller facets = {smaller}",)

    #calculates the number of vertices will be stitched to each vertices on smaller side
    dividend = int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])
    remainder = lengths_of_boundaries[bigger] - int(lengths_of_boundaries[bigger]/lengths_of_boundaries[smaller])*lengths_of_boundaries[smaller]

    print(f"dividend = {dividend}, remainder = {remainder}")
    print(f"Time finding boundary and divisor = {time.time() - start_time}")
    #loop that adds the new faces
    print("About to add faces")
    start_time = time.time()
    new_faces = []
    current_bigger = 0
    for i,current_smaller in enumerate(edge_order_list[smaller]):
        #print("current_smaller =" + str(current_smaller))
        #print("current_bigger=" + str(current_bigger))
        if i == 0:
            new_faces.append([current_smaller,edge_order_list[smaller][-1],edge_order_list[bigger][current_bigger]])
        else:
            new_faces.append([current_smaller,edge_order_list[smaller][i-1],edge_order_list[bigger][current_bigger]])

        for j in range(0,dividend + int(i<remainder)):
            if current_bigger > len(edge_order_list[bigger]):
                raise Exception("Somehow rapped around too much")

            if current_bigger >= len(edge_order_list[bigger])-1:
                next_bigger = 0
            else:
                next_bigger = current_bigger+1

            new_faces.append([current_smaller,edge_order_list[bigger][current_bigger],
                                edge_order_list[bigger][next_bigger]])

            current_bigger += 1

    #print("new_faces = " + str(new_faces))
    print(f"Finished adding faces: {time.time() - start_time}")
    

    print("Starting creating stitch mesh")
    start_time = time.time()
    stitch_mesh = trimesh.Trimesh()

    stitch_mesh.vertices = new_mesh.vertices
    stitch_mesh.faces = np.vstack([new_mesh.faces, new_faces])
    print(f"Finished creating stitch mesh: {time.time() - start_time}")
    


    #print the parameters
    print(f"delete_facets = {delete_facets}, fix_normals = {fix_normals}, return_added_mesh = {return_added_mesh}")
    start_time = time.time()
    if delete_facets == True:
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(stitch_mesh.faces)-1,len(stitch_mesh.faces)).astype("int")
        facet_faces = np.hstack([facet_1 ,facet_2])
        faces_to_keep = set(total_faces).difference(set(facet_faces))
        faces_to_keep

        stitch_mesh = stitch_mesh.submesh([list(faces_to_keep)])[0]

    if fix_normals == True:
        trimesh.repair.fix_inversion(stitch_mesh)
        trimesh.repair.fix_winding(stitch_mesh)
        trimesh.repair.fix_normals(stitch_mesh)
    
    #print("Finished stitching")

    if return_added_mesh == True:
        added_mesh = trimesh.Trimesh()
        added_mesh.vertices = new_mesh.vertices
        added_mesh.faces = new_faces
        trimesh.repair.fix_inversion(added_mesh)
        trimesh.repair.fix_winding(added_mesh)
        trimesh.repair.fix_normals(added_mesh)

        return stitch_mesh,added_mesh
    
    
    else:
        print(f"Done checking and performing Boolean conditions {time.time() - start_time}")
        return stitch_mesh

# %%
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh_saved = main_mesh.copy()
main_mesh_facets_centers_saved = main_mesh_facets_centers.copy()
main_mesh_facets_saved = main_mesh_facets.copy()

# %%
"""

Pseudocode for loop at the end that will keep everything going:
1) When process a child, will add that index to a list
2) Have no_new_children_processed counter set at end of loop 
    if no children were added to main mesh
    --> this will prompt the expansion of the initial parameters
3) If this gets too high



Things that still need to add:
1) Better way of making sure that the normals are good
- Can sample one of the neighboring points and flip normals if the dot product is negative


Change list: 
1) Reduced the stitch distance
2) Added the copy features that allows this cell to be rerun without rerunning whole notebook
3) added the new tie_breaker for childs that want to connect to same parent is just the one with closest facet
    Uses the added feature of child_meshes_stitch_distances that is saved along the way
4) Iterates through the repeated faces instead of just doing so once which was incorrect before
5) Fixed bug that was adding to current_main_mesh but then was using main mesh also in the loop
6) Made changes to the stitching mechanism that not error if find a vertices with more than 2 edges
--> because did observe some facets with cut out faces along the boundary
7) Changed the consider_same_direction normal as False 
8) Changed the max index error that was used for finding the starting point in stitch meshes

"""

#load our main mesh stuff from the copies
#makes a copy of the main mesh and the main mesh facets so can just run this cell again if errors:
main_mesh = main_mesh_saved.copy()
main_mesh_facets_centers = main_mesh_facets_centers_saved.copy()
main_mesh_facets = main_mesh_facets_saved.copy()



#sets 
initial_parameters = dict(bounding_box_threshold=4000,
                         stitch_distance_threshold=1000,
                         size_ratio_threshold=0.30)

bounding_box_threshold = initial_parameters["bounding_box_threshold"]
stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]
size_ratio_threshold = initial_parameters["size_ratio_threshold"]

no_new_children_multiplier = 0
bbox_expansion_percentage = 0.10
stitch_expansion_percentage = 1
size_ratio_expansion_percentage = 0.10

no_new_children_limit = 4

consider_same_direction_normals = False
children_processed = []

while len(children_processed) < len(child_meshes):
    stitch_loop_time = time.time()
    if no_new_children_multiplier >= no_new_children_limit:
        print("The number of times expanding the thresholds has exceed the limit /n Just returning main mesh")
        
    
    #update the thresholds
    bounding_box_threshold = initial_parameters["bounding_box_threshold"]*(1 + bbox_expansion_percentage*no_new_children_multiplier)
    stitch_distance_threshold = initial_parameters["stitch_distance_threshold"]*(1 + stitch_expansion_percentage*no_new_children_multiplier)
    #reduces the 
    size_ratio_threshold = initial_parameters["size_ratio_threshold"]*(1 - size_ratio_expansion_percentage*no_new_children_multiplier)
    
    #print thresholds
#     print(f"bounding_box_threshold = {bounding_box_threshold}")
#     print(f"stitch_distance_threshold = {stitch_distance_threshold}" )
#     print(f"size_ratio_threshold = {size_ratio_threshold}")

    #get the main mesh facets normals
    main_mesh_normals = [main_mesh.face_normals[fac[0]] for fac in main_mesh_facets]
    hit_indexes_list= []
    
    
    #dictionary to save the stitch points
    child_meshes_stitch_facets = dict()
    child_meshes_stitch_face_ratios = dict()
    child_meshes_stitch_distances = dict()
    for i,child in enumerate(child_meshes):
        
        if i in children_processed:
            #print(f"Child {i} already processed")
            continue
        
        print(f"Starting Child {i}")

        #initialize the stitch index
        #child_meshes_stitch_facets[i] = [-1,-1]

        #two highest points for the bounding box
        min_bb = np.array(main_mesh.bounding_box.vertices).min(0)
        max_bb = np.array(main_mesh.bounding_box.vertices).max(0)

        min_bb_zone = min_bb - bounding_box_threshold
        max_bb_zone = max_bb + bounding_box_threshold



        #then send mesh to function that decides if with
        pass_bbox_filter = apply_bbox_filter(child,min_bb_zone,max_bb_zone)

        if not pass_bbox_filter:
            print("skipped by bounding box filter")
            continue

        #### used for validation to make sure that bounding box was correctly filtering
    #     #add the following to main mesh just to visualize
    #     final_mesh = final_mesh + child
    #     print("just added")

        #
        """

        Do pairwise calculation of distances between centers of facets on child piece and main piece
            Filter the pairs for stitch distance threshold
            Filter the pairs for matching or opposite normals
            Filter for those that are reasonable in size matching (within 50% of each other)

        If there are still ties after this point then pitch the best matching size

        If None remaining then keep going (might loosen up the parameters later), BUT WITH GLOBAL CHECK SO DOESN’T KEEP ITERATING


        """

        child_facets,child_facets_centers = child_meshes_facets[i]

        facet_distances = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))
        facet_normals = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))

        start_time = time.time()
        #do the pairwise comparison
        for cc,child_center in enumerate(child_facets_centers):

            #get the normal of the child
            child_normal = child.face_normals[child_facets[cc][0]]
            for mm, main_center in enumerate(main_mesh_facets_centers):
                #get the euclidean distance
    #             facet_distances[cc,mm] = math.sqrt((child_center[0] - main_center[0])**2 + 
    #                                                  (child_center[1] - main_center[1])**2 + 
    #                                                  (child_center[2] - main_center[2])**2 )



                facet_distances[cc,mm] = np.linalg.norm(np.array(child_center) - np.array(main_center))

                main_normal = main_mesh_normals[mm]
    #             print("main_normal = " + str(main_normal))
    #             print("child_normal = " + str(child_normal))
                #get whether the normals are line up (or possibly opposite)
                normals_dot = np.dot(child_normal,main_normal)
                #print(normals_dot)
                if consider_same_direction_normals == True:
                    facet_normals[cc,mm] =  normals_dot < -0.95  or normals_dot > 0.95
                else:
                    facet_normals[cc,mm] =  normals_dot < -0.95 # or normals_dot > 0.95


        
        print(f"Total pairwise : {time.time() - start_time}")

    #     if i == 1:
    #         4,12
    #         print("4,12 facet distance = " + str(facet_distances[4,12]))

        #apply the filters
        #stitch_distance_booleans = facet_distances < stitch_distance_threshold

        
        #how to debug certain faces that have been filtered
#         main_facet_bebug = 124
#         piece_facet_debug = 11
        
#         if i == 2 and (0 in children_processed):
#             print("**********" + str(facet_normals[piece_facet_debug,main_facet_bebug]) + "**********")
#             print("**********" + str((facet_distances < stitch_distance_threshold)[piece_facet_debug,main_facet_bebug]) + "**********")
        
        
        #get the indexes that make it through the first two filters
        hit_indexes = np.where(np.logical_and(facet_distances < stitch_distance_threshold,facet_normals)== True) 

        possible_stitch_pairs = np.vstack(hit_indexes).T
        
        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
            

        face_0_unique_facets = np.unique(hit_indexes[0])
        face_1_unique_facets = np.unique(hit_indexes[1])
        #get the sizes of all the unique ones

        if len(hit_indexes[0]) <= 0:
            print(f"Child {i} There was no possible stitch found after stitch distance and face normal filters")
            continue

        if len(hit_indexes[0]) > 0:
            face_0_facet_sizes = dict([(u,find_polygon_area(child,child_facets[u])) for u in face_0_unique_facets])
            face_1_facet_sizes = dict([(u,find_polygon_area(main_mesh,main_mesh_facets[u])) for u in face_1_unique_facets])

    #     print("possible_stitch_pairs = " + str(possible_stitch_pairs))
    #     print("len(hit_indexes) = " + str(len(hit_indexes)))
    #     print("hit_indexes[0].any() = " + str(hit_indexes[0].any()))
    #     print("hit_indexes = " + str(hit_indexes))
    #     print("hit_indexes[0] = " + str(hit_indexes[0]))
    #     print("len(hit_indexes[0]) = " + str(len(hit_indexes[0])))

        #find the sizes of all of them
        face_pair_sizes = np.zeros(len(possible_stitch_pairs[:,0]))
        face_size_ratios = np.zeros(len(possible_stitch_pairs[:,0]))

        #print("possible_stitch_pairs = " + str(possible_stitch_pairs))
        for numba,pair in enumerate(possible_stitch_pairs):
            #print("pair = " + str(pair))
            sizes = [face_0_facet_sizes[pair[0]],face_1_facet_sizes[pair[1]]]
            min_area = min(sizes)
            max_area = max(sizes)

            ratio = min_area/max_area

            #print(f"ratio = {ratio}")
            #print(f"Total size  = {min_area + max_area}")
            if ratio >= size_ratio_threshold:
                face_pair_sizes[numba] = min_area + max_area
                face_size_ratios[numba] = ratio
            
                #print(f"face_pair_sizes[numba] = {face_pair_sizes[numba]}, face_size_ratios[numba] = {face_size_ratios[numba]}")


        #check that made it past stitch ratio threshold

        #best possible stitch pair is just the maximum sized matching ones
        best_index = np.where(face_pair_sizes == max(face_pair_sizes))
        best_stitch_pair = possible_stitch_pairs[best_index][0]
        best_stitch_pair_size = face_pair_sizes[best_index][0]
        best_stitch_pair_size_ratio = face_size_ratios[best_index][0]
        
        #get the distance of the best_stitch_pair
        best_stitch_pair_distance = facet_distances[possible_stitch_pairs[best_index][0][0],
                                                   possible_stitch_pairs[best_index][0][1]]
        
        print("best_stitch_pair = " + str(best_stitch_pair))
        print("best_stitch_pair_size = " + str(best_stitch_pair_size))
        print("best_stitch_pair_distance = " + str(best_stitch_pair_distance))
        print("best_stitch_pair_size_ratio = " + str(best_stitch_pair_size_ratio))

        child_meshes_stitch_facets[i] = [best_stitch_pair[0],best_stitch_pair[1]]
        child_meshes_stitch_face_ratios[i] = best_stitch_pair_size_ratio
        child_meshes_stitch_distances[i] = best_stitch_pair_distance

    
#     if 0 in child_meshes_stitch_facets.keys():
#         print("Just processed piece 1")
#         break
    
    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
        
    # makes sure that no two child branches try to connect to the same main branch
    from collections import Counter
    mesh_stitch_counter = Counter(np.array([val for val in child_meshes_stitch_facets.values()])[:,1])

    repeat_main_facets = [key for key,val in mesh_stitch_counter.items() if (key != -1 and val > 1)] #gets the main mesh facet with multiples
    print("repeat_main_facets = " + str(repeat_main_facets))


    #how to fix that some faces are trying to branch to same main facet
    #make it iterate through all of the repeats
    if len(repeat_main_facets)>0:
        for repeat_main in repeat_main_facets:
            child_mesh_double_indexes = [key for key,val in child_meshes_stitch_facets.items() if val[1] == repeat_main]
            print("child_mesh_double_indexes = " + str(child_mesh_double_indexes))


            #decide which one to keep and then ditch all the rest --> pick the CLOSEST ONE, and not the best matching area:

            ###### picks the closest area
            min_distance = 10000000000
            min_child = -1


            for child_index in child_mesh_double_indexes:
                current_distance = child_meshes_stitch_distances[child_index]

                if current_distance < min_distance:
                    min_child = child_index
                    min_distance = current_distance

            print(f"min_child = {min_child}, max_ratio = {min_distance}")

    #         ###### picks the maximum area
    #         max_ratio = -1
    #         max_child = -1


    #         for child_index in child_mesh_double_indexes:
    #             current_ratio = child_meshes_stitch_face_ratios[child_index]

    #             if current_ratio > max_ratio:
    #                 max_child = child_index
    #                 max_ratio = current_ratio

    #         print(f"max_child = {max_child}, max_ratio = {max_ratio}")



            #remove the others from the stitch facets
            for double_index in child_mesh_double_indexes:
                if double_index != min_child:
                    del child_meshes_stitch_facets[double_index]
    
    """
    Pseudocode for stitching:
    1) For each pair in the child_meshes_stitch_facets:
    a. Get the child mesh for that pair
    b. Get the list of faces for the child facet (from the facet number)
    c. Get the list of faces for the main facet (from the main number)

    d. Get the original number of faces and vertices in the main mesh
    d2. Use the orignal number of faces and add to list of faces for child facet to offset them correctly
        - Save this number list in a dictionary (to use for later and creating the submesh)
    e. Add the two meshes together to get big mesh
    f. Send the two meshes and the two facet lists to the restitching function to get a main mesh that is stitched up
     - but send it to function that doesnt delete the original facet faces 
         (because this would remove meshes from original and screw up facet number)
    g. reassign the main_mesh to this newly stitched up mesh
    h. recompute the facets for the main mesh



    """
    
    #lists to store the faces that need to be removed later
    child_faces_to_remove = []
    main_faces_to_remove = []
    current_main_mesh = main_mesh.copy()

    
    #if there were no possible stitch points found
    if len(child_meshes_stitch_facets.keys()) == 0:
        #increment the no children flag multiplier
        
        no_new_children_multiplier += 1
        print(f"no stitch points found IN ALL CHILDREN --> relaxing the parameters time {no_new_children_multiplier}")
        continue
    else: #if there were stitch points found
        print("child_meshes_stitch_facets = " + str(child_meshes_stitch_facets))
        for child_key,pair in child_meshes_stitch_facets.items():
            stitch_time = time.time()
            print(f"---Stitching child {child_key} with pair: {pair}---")
            current_child_mesh = child_meshes[child_key]
            current_child_facet_faces = child_meshes_facets[child_key][0][pair[0]]


            current_main_mesh_facet_faces = main_mesh_facets[pair[1]]

            #Get the original number of faces and vertices in the main mesh
            original_mesh_faces_len = len(current_main_mesh.faces)
            current_child_facet_faces_adjusted = [k + original_mesh_faces_len 
                                                              for k in current_child_facet_faces]

            #Save the faces number for deletion later
            child_faces_to_remove += current_child_facet_faces_adjusted
            main_faces_to_remove += current_main_mesh_facet_faces

            combined_mesh = current_main_mesh + current_child_mesh

            #how to stitch up the mesh
            start_time = time.time()
            current_main_mesh = stitch_mesh_piece_vp3(new_mesh=combined_mesh,
                                                           facet_1=current_main_mesh_facet_faces,
                                                           facet_2=current_child_facet_faces_adjusted,
                                                          delete_facets=False,
                                                          return_added_mesh=False,
                                                           fix_normals = False) #fix normals does take a while warning
            
            print(f"returned from stitch mesh: {time.time() - start_time}")
            
            #add the child to processed child
            children_processed.append(child_key)
            print(f"Finished stitching child {child_key} : {time.time() - stitch_time}")

        #remove all of the processed facets from the main mesh
        #now take away the original facet faces:
        total_faces = np.linspace(0,len(current_main_mesh.faces)-1,len(current_main_mesh.faces)).astype("int")
        facet_faces = np.hstack([child_faces_to_remove ,main_faces_to_remove])
        faces_to_keep = set(total_faces).difference(set(facet_faces))


        main_mesh = current_main_mesh.submesh([list(faces_to_keep)])[0]


        #reset the no_new_children_multiplier because there were successful stitching
        no_new_children_multiplier = 0
        #recompute the main mesh facets
        main_mesh_facets,main_mesh_facets_centers = filter_final_facets(main_mesh)
        print(f"***************Finished big stitching iteration: {time.time() - stitch_loop_time}***************")
        
#         if 0 in children_processed and 1 in children_processed:
#             print("Exiting before does piece 2")
#             break

        if len(np.unique(children_processed)) == len(child_meshes):
            print("All children have been processed")
            break
# Out:
# Starting Child 0
# Total pairwise : 117.68715858459473
# best_stitch_pair = [  124 13838]
# best_stitch_pair_size = 350273.93945606693
# best_stitch_pair_distance = 877.7738707539703
# best_stitch_pair_size_ratio = 0.7439740004750592
# Starting Child 1
# Total pairwise : 19.778017044067383
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# Total pairwise : 18.681751251220703
# best_stitch_pair = [   79 13584]
# best_stitch_pair_size = 1776862.2480577263
# best_stitch_pair_distance = 404.4770976768906
# best_stitch_pair_size_ratio = 0.4998954915344754
# Starting Child 3
# Total pairwise : 23.759477376937866
# best_stitch_pair = [    9 15028]
# best_stitch_pair_size = 592769.3640522734
# best_stitch_pair_distance = 0.0
# best_stitch_pair_size_ratio = 1.0
# Starting Child 4
# Total pairwise : 19.272172451019287
# best_stitch_pair = [   13 14728]
# best_stitch_pair_size = 145840.09978948106
# best_stitch_pair_distance = 532.3891836663047
# best_stitch_pair_size_ratio = 0.6643203600740906
# Starting Child 5
# Total pairwise : 4.0949976444244385
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# Total pairwise : 17.721324682235718
# best_stitch_pair = [   65 15430]
# best_stitch_pair_size = 46986.92560171055
# best_stitch_pair_distance = 806.4715967013957
# best_stitch_pair_size_ratio = 0.9343815766729817
# Starting Child 7
# Total pairwise : 8.999370813369751
# best_stitch_pair = [   22 14905]
# best_stitch_pair_size = 174730.59200483188
# best_stitch_pair_distance = 595.6205517292968
# best_stitch_pair_size_ratio = 0.5068452312641576
# Starting Child 8
# Total pairwise : 7.039124488830566
# best_stitch_pair = [    7 15214]
# best_stitch_pair_size = 84613.33744726243
# best_stitch_pair_distance = 912.5624031963468
# best_stitch_pair_size_ratio = 0.9484200697271549
# Starting Child 9
# Total pairwise : 23.213524103164673
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# Total pairwise : 3.8116650581359863
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# Total pairwise : 10.734892129898071
# best_stitch_pair = [    1 14773]
# best_stitch_pair_size = 4938365.830267138
# best_stitch_pair_distance = 12.946819003339987
# best_stitch_pair_size_ratio = 0.9948435371662899
# Starting Child 12
# Total pairwise : 5.546962261199951
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# Total pairwise : 6.488715648651123
# best_stitch_pair = [    8 15335]
# best_stitch_pair_size = 331283.98077708716
# best_stitch_pair_distance = 138.45468222376968
# best_stitch_pair_size_ratio = 0.5081517550503717
# Starting Child 14
# Total pairwise : 6.807733774185181
# best_stitch_pair = [   48 13641]
# best_stitch_pair_size = 2374751.6051846836
# best_stitch_pair_distance = 434.3800351906496
# best_stitch_pair_size_ratio = 0.9105354998149997
# Starting Child 15
# Total pairwise : 12.417563915252686
# best_stitch_pair = [   45 14996]
# best_stitch_pair_size = 313272.9238818296
# best_stitch_pair_distance = 0.0
# best_stitch_pair_size_ratio = 0.9999999999999998
# Starting Child 16
# Total pairwise : 8.305948495864868
# best_stitch_pair = [   17 15246]
# best_stitch_pair_size = 437100.03247127926
# best_stitch_pair_distance = 401.974320488883
# best_stitch_pair_size_ratio = 0.32490696625520615
# Starting Child 17
# Total pairwise : 0.2899134159088135
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.14525413513183594
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# Total pairwise : 0.5749828815460205
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# Total pairwise : 2.505990505218506
# best_stitch_pair = [    2 13562]
# best_stitch_pair_size = 46344.908476495926
# best_stitch_pair_distance = 662.2898618974324
# best_stitch_pair_size_ratio = 0.3470049954473875
# Starting Child 22
# Total pairwise : 0.5561909675598145
# best_stitch_pair = [    2 15275]
# best_stitch_pair_size = 9050.966799187809
# best_stitch_pair_distance = 0.0
# best_stitch_pair_size_ratio = 1.0
# Starting Child 23
# Total pairwise : 1.4044110774993896
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.1377096176147461
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.0974788665771484
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.9073486328125e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.14574003219604492
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.153262138366699
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 29
# Total pairwise : 4.603135824203491
# best_stitch_pair = [   17 13686]
# best_stitch_pair_size = 27262.366658465486
# best_stitch_pair_distance = 331.61981864300765
# best_stitch_pair_size_ratio = 0.34158416364198957
# Starting Child 30
# Total pairwise : 2.592440605163574
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 31
# Total pairwise : 4.853014707565308
# best_stitch_pair = [    9 14857]
# best_stitch_pair_size = 55080.06039914882
# best_stitch_pair_distance = 0.0
# best_stitch_pair_size_ratio = 1.0
# Starting Child 32
# Total pairwise : 1.516953945159912
# best_stitch_pair = [    0 13700]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 774.3175589454987
# best_stitch_pair_size_ratio = 0.0
# Starting Child 33
# Total pairwise : 1.645338773727417
# best_stitch_pair = [    9 13694]
# best_stitch_pair_size = 453556.6644384513
# best_stitch_pair_distance = 971.2536693902705
# best_stitch_pair_size_ratio = 0.31505757211004826
# Starting Child 34
# Total pairwise : 1.0129046440124512
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 35
# Total pairwise : 0.2902836799621582
# Child 35 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 36
# Total pairwise : 0.5755960941314697
# best_stitch_pair = [    1 14826]
# best_stitch_pair_size = 294494.2637057405
# best_stitch_pair_distance = 655.4165875011884
# best_stitch_pair_size_ratio = 0.350129173611626
# Starting Child 37
# Total pairwise : 2.866041660308838
# best_stitch_pair = [    0 14631]
# best_stitch_pair_size = 467382.3342470528
# best_stitch_pair_distance = 837.7584339388646
# best_stitch_pair_size_ratio = 0.49561141507293344
# Starting Child 38
# Total pairwise : 0.7168335914611816
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.7212145328521729
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# Total pairwise : 0.14242863655090332
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# Total pairwise : 0.7008862495422363
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [124, 13838], 2: [79, 13584], 3: [9, 15028], 4: [13, 14728], 6: [65, 15430], 7: [22, 14905], 8: [7, 15214], 11: [1, 14773], 13: [8, 15335], 14: [48, 13641], 15: [45, 14996], 16: [17, 15246], 21: [2, 13562], 22: [2, 15275], 29: [17, 13686], 31: [9, 14857], 32: [0, 13700], 33: [9, 13694], 36: [1, 14826], 37: [0, 14631]}
# ---Stitching child 0 with pair: [124, 13838]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 951467, starting edge 2nd facet= 1071622,
# Time at beginning finding 1st facet and direction = 0.9433605670928955
# Starting Organizing vertices for side 0
# [1 3]
# Edge 1 picked for direction
# edge_0_order done, len = 15
# Total time finding edge order: 0.0013699531555175781
# Starting Organizing vertices for side 1
# [12 18]
# Edge 2 picked for direction
# edge_1_order done, len = 20
# Total time finding edge order: 0.0017092227935791016
# dividend = 1, remainder = 5
# Time finding boundary and divisor = 2.6702880859375e-05
# About to add faces
# Finished adding faces: 2.9802322387695312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03062891960144043
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 330.84255170822144
# returned from stitch mesh: 331.82026410102844
# Finished stitching child 0 : 331.99583768844604
# ---Stitching child 2 with pair: [79, 13584]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 926710, starting edge 2nd facet= 1130417,
# Time at beginning finding 1st facet and direction = 0.7595746517181396
# Starting Organizing vertices for side 0
# [1 3]
# Edge 2 picked for direction
# edge_0_order done, len = 23
# Total time finding edge order: 0.002366781234741211
# Starting Organizing vertices for side 1
# [10 12]
# Edge 1 picked for direction
# edge_1_order done, len = 16
# Total time finding edge order: 0.0013666152954101562
# dividend = 1, remainder = 7
# Time finding boundary and divisor = 2.5510787963867188e-05
# About to add faces
# Finished adding faces: 3.337860107421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030890226364135742
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.466670989990234
# returned from stitch mesh: 5.2613232135772705
# Finished stitching child 2 : 5.374576807022095
# ---Stitching child 3 with pair: [9, 15028]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1049160, starting edge 2nd facet= 1156261,
# Time at beginning finding 1st facet and direction = 0.9482238292694092
# Starting Organizing vertices for side 0
# [5 6]
# Edge 1 picked for direction
# edge_0_order done, len = 13
# Total time finding edge order: 0.0011000633239746094
# Starting Organizing vertices for side 1
# [5 6]
# Edge 1 picked for direction
# edge_1_order done, len = 13
# Total time finding edge order: 0.0008709430694580078
# dividend = 1, remainder = 0
# Time finding boundary and divisor = 2.2172927856445312e-05
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0316309928894043
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.558457136154175
# returned from stitch mesh: 5.540695428848267
# Finished stitching child 3 : 5.705869913101196
# ---Stitching child 4 with pair: [13, 14728]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1016733, starting edge 2nd facet= 1162925,
# Time at beginning finding 1st facet and direction = 1.0071589946746826
# Starting Organizing vertices for side 0
# [6 7]
# Edge 2 picked for direction
# edge_0_order done, len = 8
# Total time finding edge order: 0.0006146430969238281
# Starting Organizing vertices for side 1
# [6 7]
# Edge 1 picked for direction
# edge_1_order done, len = 14
# Total time finding edge order: 0.001104116439819336
# dividend = 1, remainder = 6
# Time finding boundary and divisor = 2.1696090698242188e-05
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03233814239501953
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.561948537826538
# returned from stitch mesh: 5.6037209033966064
# Finished stitching child 4 : 5.762667417526245
# ---Stitching child 6 with pair: [65, 15430]---
# same direction normals
# Found boundary edges
# starting edge 1st facet = 1066704, starting edge 2nd facet= 1170142,
# Time at beginning finding 1st facet and direction = 1.012866497039795
# Starting Organizing vertices for side 0
# [0 3]
# Edge 1 picked for direction
# edge_0_order done, len = 5
# Total time finding edge order: 0.0004553794860839844
# Starting Organizing vertices for side 1
# [0 1]
# Edge 1 picked for direction
# edge_1_order done, len = 9
# Total time finding edge order: 0.0008215904235839844
# dividend = 1, remainder = 4
# Time finding boundary and divisor = 2.0742416381835938e-05
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.038420915603637695
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.3395538330078125
# returned from stitch mesh: 6.392741441726685
# Finished stitching child 6 : 6.549669981002808
# ---Stitching child 7 with pair: [22, 14905]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1027446, starting edge 2nd facet= 1178917,
# Time at beginning finding 1st facet and direction = 1.2007088661193848
# Starting Organizing vertices for side 0
# [2 9]
# Edge 2 picked for direction
# edge_0_order done, len = 10
# Total time finding edge order: 0.000732421875
# Starting Organizing vertices for side 1
# [0 4]
# Edge 2 picked for direction
# edge_1_order done, len = 8
# Total time finding edge order: 0.0005154609680175781
# dividend = 1, remainder = 2
# Time finding boundary and divisor = 2.193450927734375e-05
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03981804847717285
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.313738822937012
# returned from stitch mesh: 6.555937051773071
# Finished stitching child 7 : 6.720909595489502
# ---Stitching child 8 with pair: [7, 15214]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1053579, starting edge 2nd facet= 1182279,
# Time at beginning finding 1st facet and direction = 1.1417179107666016
# Starting Organizing vertices for side 0
# [0 3]
# Edge 1 picked for direction
# edge_0_order done, len = 9
# Total time finding edge order: 0.0006890296936035156
# Starting Organizing vertices for side 1
# [0 6]
# Edge 1 picked for direction
# edge_1_order done, len = 8
# Total time finding edge order: 0.0007777214050292969
# dividend = 1, remainder = 1
# Time finding boundary and divisor = 2.1219253540039062e-05
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.039627790451049805
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.259893178939819
# returned from stitch mesh: 6.443230390548706
# Finished stitching child 8 : 6.625497102737427
# ---Stitching child 11 with pair: [1, 14773]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1017843, starting edge 2nd facet= 1184898,
# Time at beginning finding 1st facet and direction = 1.173875331878662
# Starting Organizing vertices for side 0
# [ 0 37]
# Edge 2 picked for direction
# edge_0_order done, len = 56
# Total time finding edge order: 0.011521100997924805
# Starting Organizing vertices for side 1
# [ 0 36]
# Edge 2 picked for direction
# edge_1_order done, len = 55
# Total time finding edge order: 0.010292768478393555
# dividend = 1, remainder = 1
# Time finding boundary and divisor = 2.288818359375e-05
# About to add faces
# Finished adding faces: 0.0001354217529296875
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03899383544921875
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.345001220703125
# returned from stitch mesh: 6.580332040786743
# Finished stitching child 11 : 6.745461940765381
# ---Stitching child 13 with pair: [8, 15335]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1061612, starting edge 2nd facet= 1191889,
# Time at beginning finding 1st facet and direction = 1.1809444427490234
# Starting Organizing vertices for side 0
# [2 3]
# Edge 2 picked for direction
# edge_0_order done, len = 4
# Total time finding edge order: 0.0004482269287109375
# Starting Organizing vertices for side 1
# [5 7]
# Edge 1 picked for direction
# edge_1_order done, len = 18
# Total time finding edge order: 0.0017948150634765625
# dividend = 4, remainder = 2
# Time finding boundary and divisor = 2.1457672119140625e-05
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03900003433227539
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.352243900299072
# returned from stitch mesh: 6.574946403503418
# Finished stitching child 13 : 6.757519960403442
# ---Stitching child 14 with pair: [48, 13641]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1006270, starting edge 2nd facet= 1197067,
# Time at beginning finding 1st facet and direction = 1.1843504905700684
# Starting Organizing vertices for side 0
# [5 8]
# Edge 2 picked for direction
# edge_0_order done, len = 11
# Total time finding edge order: 0.0010602474212646484
# Starting Organizing vertices for side 1
# [15 25]
# Edge 1 picked for direction
# edge_1_order done, len = 28
# Total time finding edge order: 0.003027200698852539
# dividend = 2, remainder = 6
# Time finding boundary and divisor = 2.1457672119140625e-05
# About to add faces
# Finished adding faces: 4.124641418457031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05810880661010742
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.413668155670166
# returned from stitch mesh: 6.660664796829224
# Finished stitching child 14 : 6.854889154434204
# ---Stitching child 15 with pair: [45, 14996]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1031385, starting edge 2nd facet= 1199472,
# Time at beginning finding 1st facet and direction = 1.1922900676727295
# Starting Organizing vertices for side 0
# [ 2 13]
# Edge 1 picked for direction
# edge_0_order done, len = 15
# Total time finding edge order: 0.5230734348297119
# Starting Organizing vertices for side 1
# [ 2 13]
# Edge 1 picked for direction
# edge_1_order done, len = 15
# Total time finding edge order: 0.0012273788452148438
# dividend = 1, remainder = 0
# Time finding boundary and divisor = 2.193450927734375e-05
# About to add faces
# Finished adding faces: 2.7179718017578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022712230682373047
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.66351842880249
# returned from stitch mesh: 6.403348207473755
# Finished stitching child 15 : 6.587403059005737
# ---Stitching child 16 with pair: [17, 15246]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1056731, starting edge 2nd facet= 1211199,
# Time at beginning finding 1st facet and direction = 1.0475451946258545
# Starting Organizing vertices for side 0
# [1 2]
# Edge 2 picked for direction
# edge_0_order done, len = 9
# Total time finding edge order: 0.0006597042083740234
# Starting Organizing vertices for side 1
# [12 13]
# Edge 2 picked for direction
# edge_1_order done, len = 18
# Total time finding edge order: 0.0014045238494873047
# dividend = 2, remainder = 0
# Time finding boundary and divisor = 0.0002338886260986328
# About to add faces
# Finished adding faces: 2.7418136596679688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.033857107162475586
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.753231048583984
# returned from stitch mesh: 5.837504863739014
# Finished stitching child 16 : 5.972943067550659
# ---Stitching child 21 with pair: [2, 13562]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 926653, starting edge 2nd facet= 1211645,
# Time at beginning finding 1st facet and direction = 1.0287563800811768
# Starting Organizing vertices for side 0
# [4 7]
# Edge 1 picked for direction
# edge_0_order done, len = 11
# Total time finding edge order: 0.0009279251098632812
# Starting Organizing vertices for side 1
# [ 0 13]
# Edge 1 picked for direction
# edge_1_order done, len = 15
# Total time finding edge order: 0.0011928081512451172
# dividend = 1, remainder = 4
# Time finding boundary and divisor = 2.2172927856445312e-05
# About to add faces
# Finished adding faces: 2.8133392333984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03262186050415039
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.716416358947754
# returned from stitch mesh: 5.7805774211883545
# Finished stitching child 21 : 5.943206787109375
# ---Stitching child 22 with pair: [2, 15275]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1059225, starting edge 2nd facet= 1211941,
# Time at beginning finding 1st facet and direction = 1.0304007530212402
# Starting Organizing vertices for side 0
# [0 3]
# Edge 2 picked for direction
# edge_0_order done, len = 9
# Total time finding edge order: 0.0007340908050537109
# Starting Organizing vertices for side 1
# [0 3]
# Edge 2 picked for direction
# edge_1_order done, len = 9
# Total time finding edge order: 0.0006155967712402344
# dividend = 1, remainder = 0
# Time finding boundary and divisor = 2.5987625122070312e-05
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03332710266113281
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.184816598892212
# returned from stitch mesh: 6.250388860702515
# Finished stitching child 22 : 6.412429094314575
# ---Stitching child 29 with pair: [17, 13686]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 944668, starting edge 2nd facet= 1213214,
# Time at beginning finding 1st facet and direction = 1.2295026779174805
# Starting Organizing vertices for side 0
# [4 5]
# Edge 1 picked for direction
# edge_0_order done, len = 6
# Total time finding edge order: 0.0005280971527099609
# Starting Organizing vertices for side 1
# [0 1]
# Edge 1 picked for direction
# edge_1_order done, len = 4
# Total time finding edge order: 0.00035500526428222656
# dividend = 1, remainder = 2
# Time finding boundary and divisor = 2.2649765014648438e-05
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.041492462158203125
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.579898357391357
# returned from stitch mesh: 6.852329730987549
# Finished stitching child 29 : 7.045121669769287
# ---Stitching child 31 with pair: [9, 14857]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1024032, starting edge 2nd facet= 1214838,
# Time at beginning finding 1st facet and direction = 1.166844129562378
# Starting Organizing vertices for side 0
# [1 4]
# Edge 1 picked for direction
# edge_0_order done, len = 6
# Total time finding edge order: 0.0007369518280029297
# Starting Organizing vertices for side 1
# [1 4]
# Edge 1 picked for direction
# edge_1_order done, len = 6
# Total time finding edge order: 0.0005211830139160156
# dividend = 1, remainder = 0
# Time finding boundary and divisor = 2.1457672119140625e-05
# About to add faces
# Finished adding faces: 1.2874603271484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0399782657623291
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.402402400970459
# returned from stitch mesh: 6.610874652862549
# Finished stitching child 31 : 6.804541826248169
# ---Stitching child 32 with pair: [0, 13700]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 297400, starting edge 2nd facet= 1216544,
# Time at beginning finding 1st facet and direction = 1.2002694606781006
# Starting Organizing vertices for side 0
# [0 2]
# Edge 1 picked for direction
# edge_0_order done, len = 4
# Total time finding edge order: 0.0005369186401367188
# Starting Organizing vertices for side 1
# [14 21]
# Edge 2 picked for direction
# edge_1_order done, len = 23
# Total time finding edge order: 0.0021326541900634766
# dividend = 5, remainder = 3
# Time finding boundary and divisor = 2.2172927856445312e-05
# About to add faces
# Finished adding faces: 2.8848648071289062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03993725776672363
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.502826929092407
# returned from stitch mesh: 6.746093988418579
# Finished stitching child 32 : 6.938830614089966
# ---Stitching child 33 with pair: [9, 13694]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 945050, starting edge 2nd facet= 1217071,
# Time at beginning finding 1st facet and direction = 1.19374680519104
# Starting Organizing vertices for side 0
# [8 9]
# Edge 1 picked for direction
# edge_0_order done, len = 10
# Total time finding edge order: 0.0007271766662597656
# Starting Organizing vertices for side 1
# [ 5 11]
# Edge 2 picked for direction
# edge_1_order done, len = 19
# Total time finding edge order: 0.0015404224395751953
# dividend = 1, remainder = 9
# Time finding boundary and divisor = 2.1457672119140625e-05
# About to add faces
# Finished adding faces: 3.1948089599609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04023480415344238
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.467599153518677
# returned from stitch mesh: 6.704252243041992
# Finished stitching child 33 : 6.908346652984619
# ---Stitching child 36 with pair: [1, 14826]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1022810, starting edge 2nd facet= 1217237,
# Time at beginning finding 1st facet and direction = 1.2103989124298096
# Starting Organizing vertices for side 0
# [ 8 10]
# Edge 1 picked for direction
# edge_0_order done, len = 11
# Total time finding edge order: 0.000881195068359375
# Starting Organizing vertices for side 1
# [5 7]
# Edge 1 picked for direction
# edge_1_order done, len = 9
# Total time finding edge order: 0.0006914138793945312
# dividend = 1, remainder = 2
# Time finding boundary and divisor = 2.384185791015625e-05
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04163813591003418
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.479003429412842
# returned from stitch mesh: 6.73317551612854
# Finished stitching child 36 : 6.951877593994141
# ---Stitching child 37 with pair: [0, 14631]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1008417, starting edge 2nd facet= 1217249,
# Time at beginning finding 1st facet and direction = 1.2247166633605957
# Starting Organizing vertices for side 0
# [0 2]
# Edge 1 picked for direction
# edge_0_order done, len = 13
# Total time finding edge order: 0.0009937286376953125
# Starting Organizing vertices for side 1
# [ 2 11]
# Edge 2 picked for direction
# edge_1_order done, len = 21
# Total time finding edge order: 0.0018532276153564453
# dividend = 1, remainder = 8
# Time finding boundary and divisor = 2.2649765014648438e-05
# About to add faces
# Finished adding faces: 4.00543212890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.041005849838256836
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.428140640258789
# returned from stitch mesh: 6.697166681289673
# Finished stitching child 37 : 6.923072814941406
# Total Facet building time: 7.109212636947632
# ***************Finished big stitching iteration: 866.9533491134644***************
# Starting Child 1
# Total pairwise : 22.264895915985107
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# Total pairwise : 4.604089736938477
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# Total pairwise : 26.026690006256104
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# Total pairwise : 4.2497148513793945
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# Total pairwise : 6.03257155418396
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3163595199584961
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.1632065773010254
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# Total pairwise : 0.6514115333557129
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 23
# Total pairwise : 1.5457518100738525
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.15119600296020508
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2120468616485596
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.15472030639648438
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.414759874343872
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# Total pairwise : 2.9122118949890137
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# Total pairwise : 1.0973231792449951
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 35
# Total pairwise : 0.3323988914489746
# Child 35 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# Total pairwise : 0.8216936588287354
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.8097107410430908
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# Total pairwise : 0.16084861755371094
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# Total pairwise : 0.817777156829834
# best_stitch_pair = [    0 17433]
# best_stitch_pair_size = 549313.4553362781
# best_stitch_pair_distance = 904.2882921255829
# best_stitch_pair_size_ratio = 0.5920059370671655
# repeat_main_facets = []
# child_meshes_stitch_facets = {42: [0, 17433]}
# ---Stitching child 42 with pair: [0, 17433]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1217042, starting edge 2nd facet= 1217513,
# Time at beginning finding 1st facet and direction = 0.8874809741973877
# Starting Organizing vertices for side 0
# [14 20]
# Edge 1 picked for direction
# edge_0_order done, len = 22
# Total time finding edge order: 0.002227306365966797
# Starting Organizing vertices for side 1
# [2 7]
# Edge 2 picked for direction
# edge_1_order done, len = 13
# Total time finding edge order: 0.0009102821350097656
# dividend = 1, remainder = 9
# Time finding boundary and divisor = 2.47955322265625e-05
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.018274784088134766
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 362.1680474281311
# returned from stitch mesh: 363.07769536972046
# Finished stitching child 42 : 363.2871172428131
# Total Facet building time: 7.0187132358551025
# ***************Finished big stitching iteration: 501.1400361061096***************
# Starting Child 1
# Total pairwise : 23.004788637161255
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# Total pairwise : 4.745791912078857
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# Total pairwise : 26.83976650238037
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# Total pairwise : 4.365072965621948
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# Total pairwise : 6.241847991943359
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3344142436981201
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.17515349388122559
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# Total pairwise : 0.6448168754577637
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 23
# Total pairwise : 1.5960054397583008
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.16431975364685059
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2492766380310059
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.9073486328125e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.15819025039672852
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.496455669403076
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# Total pairwise : 2.9935734272003174
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# Total pairwise : 1.0820393562316895
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 35
# Total pairwise : 0.3267815113067627
# Child 35 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# Total pairwise : 0.7943840026855469
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.7904758453369141
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# Total pairwise : 0.15282106399536133
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# Total pairwise : 22.35627055168152
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# Total pairwise : 4.688493013381958
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 9
# Total pairwise : 26.22416114807129
# best_stitch_pair = [   38 13049]
# best_stitch_pair_size = 104565.14624507955
# best_stitch_pair_distance = 1913.659841069676
# best_stitch_pair_size_ratio = 0.7961305933314072
# Starting Child 10
# Total pairwise : 4.306688070297241
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# Total pairwise : 6.326752424240112
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3236277103424072
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.16270756721496582
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# Total pairwise : 0.6391100883483887
# best_stitch_pair = [  0 940]
# best_stitch_pair_size = 0.0
# best_stitch_pair_distance = 1611.825160400705
# best_stitch_pair_size_ratio = 0.0
# Starting Child 23
# Total pairwise : 1.629929780960083
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.1667041778564453
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2853331565856934
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16599678993225098
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.556974172592163
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# Total pairwise : 2.9430010318756104
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# Total pairwise : 1.1133215427398682
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 35
# Total pairwise : 0.3344845771789551
# best_stitch_pair = [    1 13560]
# best_stitch_pair_size = 95170.04553797239
# best_stitch_pair_distance = 1974.146539600966
# best_stitch_pair_size_ratio = 0.27609727021656366
# Starting Child 38
# Total pairwise : 0.8193557262420654
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.8044428825378418
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# Total pairwise : 0.16388320922851562
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {9: [38, 13049], 20: [0, 940], 35: [1, 13560]}
# ---Stitching child 9 with pair: [38, 13049]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 756116, starting edge 2nd facet= 1221663,
# Time at beginning finding 1st facet and direction = 1.0537688732147217
# Starting Organizing vertices for side 0
# [5 6]
# Edge 1 picked for direction
# edge_0_order done, len = 9
# Total time finding edge order: 0.0006551742553710938
# Starting Organizing vertices for side 1
# [0 3]
# Edge 2 picked for direction
# edge_1_order done, len = 6
# Total time finding edge order: 0.0004191398620605469
# dividend = 1, remainder = 3
# Time finding boundary and divisor = 0.0001685619354248047
# About to add faces
# Finished adding faces: 1.5735626220703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.033504486083984375
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 364.72385120391846
# returned from stitch mesh: 365.8129699230194
# Finished stitching child 9 : 365.98195242881775
# ---Stitching child 20 with pair: [0, 940]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 237106, starting edge 2nd facet= 1227289,
# Time at beginning finding 1st facet and direction = 1.1661903858184814
# Starting Organizing vertices for side 0
# [1 2]
# Edge 1 picked for direction
# edge_0_order done, len = 9
# Total time finding edge order: 0.0012235641479492188
# Starting Organizing vertices for side 1
# [4 5]
# Edge 2 picked for direction
# edge_1_order done, len = 13
# Total time finding edge order: 0.0013997554779052734
# dividend = 1, remainder = 4
# Time finding boundary and divisor = 2.9087066650390625e-05
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.008291482925415039
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 5.032657861709595
# returned from stitch mesh: 6.2106032371521
# Finished stitching child 20 : 6.298600673675537
# ---Stitching child 35 with pair: [1, 13560]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 927921, starting edge 2nd facet= 1227345,
# Time at beginning finding 1st facet and direction = 1.0851726531982422
# Starting Organizing vertices for side 0
# [0 4]
# Edge 2 picked for direction
# edge_0_order done, len = 6
# Total time finding edge order: 0.0007393360137939453
# Starting Organizing vertices for side 1
# [1 8]
# Edge 1 picked for direction
# edge_1_order done, len = 11
# Total time finding edge order: 0.0008900165557861328
# dividend = 1, remainder = 5
# Time finding boundary and divisor = 2.574920654296875e-05
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03448748588562012
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 4.909170627593994
# returned from stitch mesh: 6.030900955200195
# Finished stitching child 35 : 6.197118520736694
# Total Facet building time: 7.34852147102356
# ***************Finished big stitching iteration: 518.5396068096161***************
# Starting Child 1
# Total pairwise : 23.098875522613525
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# Total pairwise : 4.758296966552734
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# Total pairwise : 4.324289798736572
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# Total pairwise : 6.159502029418945
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.32555317878723145
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.16267776489257812
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 23
# Total pairwise : 1.5863678455352783
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.15646123886108398
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.273008108139038
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.430511474609375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16600918769836426
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.5045065879821777
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# Total pairwise : 2.964935541152954
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# Total pairwise : 1.1270129680633545
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# Total pairwise : 0.7735474109649658
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.8174006938934326
# Child 39 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 40
# Total pairwise : 0.15616822242736816
# Child 40 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 1
# Total pairwise : 22.62134623527527
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# Total pairwise : 4.6813201904296875
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# Total pairwise : 4.327993154525757
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 12
# Total pairwise : 6.215936660766602
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.31487202644348145
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.1561429500579834
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.1920928955078125e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 23
# Total pairwise : 1.529175043106079
# Child 23 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 24
# Total pairwise : 0.15523409843444824
# Child 24 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2354705333709717
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.430511474609375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.15988922119140625
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 28
# Total pairwise : 2.5110275745391846
# Child 28 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 30
# Total pairwise : 2.9613709449768066
# Child 30 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# Total pairwise : 1.08445143699646
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 38
# Total pairwise : 0.7858912944793701
# Child 38 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 39
# Total pairwise : 0.7829103469848633
# ...
# Starting Child 18
# Total pairwise : 0.17389941215515137
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2828972339630127
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.9073486328125e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16215109825134277
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 10
# Total pairwise : 4.607710361480713
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.33152174949645996
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.1651928424835205
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.8084917068481445
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 4.5299530029296875e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.3796379566192627
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 2.1457672119140625e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 10
# Total pairwise : 4.61480975151062
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.36658692359924316
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.17885637283325195
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2977204322814941
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.430511474609375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16366147994995117
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.441245079040527
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3371567726135254
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.17148375511169434
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.3149333000183105
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.17479252815246582
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.1920928955078125e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 5
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.548563241958618
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.339449405670166
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.16199827194213867
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.3026819229125977
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.1658189296722412
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.9073486328125e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 6
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.461694955825806
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3259928226470947
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.1617600917816162
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.6689300537109375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2628190517425537
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.9073486328125e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.1806488037109375
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 7
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.463996648788452
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.32267141342163086
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.18605279922485352
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 2.1457672119140625e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.266216516494751
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.9073486328125e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16004228591918945
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 8
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.40123724937439
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3314828872680664
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.15773248672485352
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.260169506072998
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16184687614440918
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 9
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.450599193572998
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# Total pairwise : 0.3239569664001465
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.1693582534790039
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.9073486328125e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2637856006622314
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.6689300537109375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.16351795196533203
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.430511474609375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 10
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# Starting Child 10
# Total pairwise : 4.407268285751343
# best_stitch_pair = [   0 2427]
# best_stitch_pair_size = 57415.12543571833
# best_stitch_pair_distance = 10010.290199908526
# best_stitch_pair_size_ratio = 0.1494831771294509
# Starting Child 17
# Total pairwise : 0.33599162101745605
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.16452240943908691
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.2797753810882568
# Child 25 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 26
# Total pairwise : 1.430511474609375e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.15685534477233887
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.6689300537109375e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {10: [0, 2427]}
# ---Stitching child 10 with pair: [0, 2427]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 370337, starting edge 2nd facet= 1246296,
# Time at beginning finding 1st facet and direction = 1.0629751682281494
# Starting Organizing vertices for side 0
# [2 4]
# Edge 1 picked for direction
# edge_0_order done, len = 5
# Total time finding edge order: 0.0011365413665771484
# Starting Organizing vertices for side 1
# [0 2]
# Edge 1 picked for direction
# edge_1_order done, len = 8
# Total time finding edge order: 0.0007109642028808594
# dividend = 1, remainder = 3
# Time finding boundary and divisor = 0.00023889541625976562
# About to add faces
# Finished adding faces: 1.8835067749023438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.024990081787109375
# delete_facets = False, fix_normals = True, return_added_mesh = False
# Done checking and performing Boolean conditions 369.6928997039795
# returned from stitch mesh: 370.783727645874
# Finished stitching child 10 : 370.92567324638367
# Total Facet building time: 7.185405254364014
# ***************Finished big stitching iteration: 439.3838322162628***************
# Starting Child 17
# Total pairwise : 0.33800721168518066
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# Total pairwise : 0.15914273262023926
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 19
# Total pairwise : 1.430511474609375e-06
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 25
# Total pairwise : 1.3405852317810059
# best_stitch_pair = [    4 17875]
# best_stitch_pair_size = 107343.83241416639
# best_stitch_pair_distance = 823.7917272615958
# best_stitch_pair_size_ratio = 0.3226789244655729
# Starting Child 26
# Total pairwise : 3.814697265625e-06
# Child 26 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 27
# Total pairwise : 0.17835617065429688
# Child 27 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 41
# Total pairwise : 1.9073486328125e-06
# Child 41 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {25: [4, 17875]}
# ---Stitching child 25 with pair: [4, 17875]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1246407, starting edge 2nd facet= 1247746,
# Time at beginning finding 1st facet and direction = 1.1062049865722656
# Starting Organizing vertices for side 0
# [0 3]
# Edge 1 picked for direction
# edge_0_order done, len = 5
# Total time finding edge order: 0.00045609474182128906
# Starting Organizing vertices for side 1
# [0 3]
# Edge 1 picked for direction
# edge_1_order done, len = 7
# Total time finding edge order: 0.0007300376892089844
# dividend = 1, remainder = 2
# Time finding boundary and divisor = 2.2172927856445312e-05
# About to add faces
# Finished adding faces: 1.4066696166992188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03437471389770508
# delete_facets = False, fix_normals = True, return_added_mesh = False

# %%
[val for val in child_meshes_stitch_facets.values()]
# Out:
# []

# %%
#print out total time it took: 
print(f"Total time for neuron stitching: {time.time() - global_timer}")

# %%
# check that stitching went well:
output_flag = True
if output_flag == True:
    from print_trimesh import print_trimesh
    print_trimesh(main_mesh,"./test_meshes/main_stitched_together.off")

# %% [markdown]
# # Debugging

# %%
child_index_new = 0
facet_pair = [17, 14624]

print(f"main mesh facets for {facet_pair[1]} = {main_mesh_facets[facet_pair[1]]}")
print(f"child mesh facets for {facet_pair[0]} = {child_meshes_facets[child_index_new][0][facet_pair[0]]}")

# %%
len(combined_mesh.faces)

# %%
current_main_mesh_facet_faces[0]
new_mesh.face_normals[current_main_mesh_facet_faces[0]]

# %%
new_mesh = combined_mesh
facet_1=current_main_mesh_facet_faces
facet_2=current_child_facet_faces_adjusted
delete_facets=False,
return_added_mesh=False

print(f"facet_1 = {facet_1}")
print(f"facet_2 = {facet_2}")


#how to find the normals of facet groups:
facet_group_1_normal = new_mesh.face_normals[facet_1[0]]
facet_group_2_normal = new_mesh.face_normals[facet_2[0]]

print("facet_group_1_normal = " + str(facet_group_1_normal))
print("facet_group_2_normal = " + str(facet_group_2_normal))

#get the correct version of the normals: (might need to flip them if going in opposite direction)
if np.dot(facet_group_1_normal,facet_group_2_normal) > 0.8:
    print("same direction normals")
    pass
elif np.dot(facet_group_1_normal,facet_group_2_normal) < -0.8:
    print("opposite direction normals")
    facet_group_2_normal = facet_group_2_normal*-1
else:
    print("Not correct normals")
    #raise Exception("Not correct normals")

#print(facet_group_1_normal,facet_group_2_normal)

# make each row correspond to a single face 
edges = new_mesh.edges_sorted.reshape((-1, 6))
# get the edges for each facet
edges_facet = [edges[i].reshape((-1, 2)) for i in [facet_1,facet_2]]
edges_boundary = np.array([i[trimesh.grouping.group_rows(i, require_count=1)]
                           for i in edges_facet])

#the list of boundary edges and unique points in the boundary edges
edge_0 = edges_boundary[0]
edge_1 = edges_boundary[1]



#gets the unique number of points
edge_0_points = np.unique(np.hstack(edge_0))
edge_1_points = np.unique(np.hstack(edge_1))
print("Found boundary edges")
"""
get the dot product of all the points
"""

print("edge_0_points = " + str(edge_0_points))
print("edge_1_points = " + str(edge_1_points))

#get any 2 points on the triangle and make that the reference edge
edge_0_anchor_points = new_mesh.vertices[[edge_0_points[0],edge_0_points[1]]]

print("edge_0_anchor_points = " + str(edge_0_anchor_points))
#gets the starting index for the 1st facet (so that the start of the stitching is close)
max_index = 0
max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

for i in range(1,len(edge_0_points)):
    current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_0_points[i]])

    if current_magnitude > max_magnitude:
        max_index = i
        max_magnitude = current_magnitude

edge_0_starting_point = edge_0_points[max_index]

#gets the starting index for the 2nd facet (so that the start of the stitching is close)
max_index = 0
max_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[max_index])

for i in range(1,len(edge_1_points)):
    
    current_magnitude = ClosestPointOnLine(edge_0_anchor_points[0],edge_0_anchor_points[1],new_mesh.vertices[edge_1_points[i]])
    if current_magnitude > max_magnitude:
        max_index = i
        max_magnitude = current_magnitude

edge_1_starting_point = edge_1_points[max_index]

print(f"starting edge 1st facet = {edge_0_starting_point}, starting edge 2nd facet= {edge_1_starting_point}, ")
#print(new_mesh.vertices[edge_0_starting_point],new_mesh.vertices[edge_1_starting_point])

# %% [markdown]
# # OPTIMIZING PAIRWISE COMPUTATION

# %%
        child_facets,child_facets_centers = child_meshes_facets[i]

        facet_distances = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))
        facet_normals = np.zeros((len(child_facets_centers),len(main_mesh_facets_centers)))

        start_time = time.time()
        #do the pairwise comparison
        for cc,child_center in enumerate(child_facets_centers):

            #get the normal of the child
            child_normal = child.face_normals[child_facets[cc][0]]
            for mm, main_center in enumerate(main_mesh_facets_centers):
                #get the euclidean distance
    #             facet_distances[cc,mm] = math.sqrt((child_center[0] - main_center[0])**2 + 
    #                                                  (child_center[1] - main_center[1])**2 + 
    #                                                  (child_center[2] - main_center[2])**2 )


                #finding distance between two points
                facet_distances[cc,mm] = np.linalg.norm(np.array(child_center) - np.array(main_center))

                main_normal = main_mesh_normals[mm]
    #             print("main_normal = " + str(main_normal))
    #             print("child_normal = " + str(child_normal))
                #get whether the normals are line up (or possibly opposite)
                normals_dot = np.dot(child_normal,main_normal)
                #print(normals_dot)
                
                
                #finding the normal dot product
                if consider_same_direction_normals == True:
                    facet_normals[cc,mm] =  normals_dot < -0.95  or normals_dot > 0.95
                else:
                    facet_normals[cc,mm] =  normals_dot < -0.95 # or normals_dot > 0.95


        
        print(f"Total pairwise : {time.time() - start_time}")

# %%
main_mesh
