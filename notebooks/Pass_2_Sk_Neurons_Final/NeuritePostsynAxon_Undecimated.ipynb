# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#pinky.NeuritePostsynAxon.drop()

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[:-4]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #check to see if the face_indexes is empty
    if not face_indexes.any():
        #create an empty mesh
        current_mesh = trimesh.Trimesh(np.array([]),np.array([]),process=False)
        return current_mesh,np.array([])
    
    
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
import warnings
from pymeshfix import _meshfix
import pymeshfix

def clean_from_arrays_celii(v, f, verbose=False, joincomp=False,
                      remove_smallest_components=True,clean=True):
    """
    Performs default cleaning procedure on vertex and face arrays
    Returns cleaned vertex and face arrays
    
    Parameters
    ----------
    v : numpy.ndarray
        Numpy n x 3 array of vertices
    f : numpy.ndarray
        Numpy n x 3 array of faces.
    verbose : bool, optional
        Prints progress to stdout.  Default True.
    joincomp : bool, optional
        Attempts to join nearby open components.  Default False
    remove_smallest_components : bool, optional
        Remove all but the largest isolated component from the mesh
        before beginning the repair process.  Default True.
    Examples
    --------
    >>>
    >>> CleanFromFile('inmesh.ply', 'outmesh.ply')
    """
    # Create mesh object and load from file
    tin = _meshfix.PyTMesh(verbose)
    tin.load_array(v, f)

    # repari and return vertex and face arrays
    repair_celii(tin, verbose, joincomp, remove_smallest_components,clean)
    return tin.return_arrays()

#what the repair function does: 
def repair_celii(tin, verbose=False, joincomp=True, remove_smallest_components=True,clean=True):
    """
    Performs mesh repair using default cleaning procedure using a tin object.
    Internal function.  Use CleanFromFile or CleanFromVF.
    """

    # Keep only the largest component (i.e. with most triangles)
    if remove_smallest_components:
        sc = tin.remove_smallest_components()
        if sc and verbose:
            print('Removed %d small components' % sc)

    # join closest components
    if joincomp:
        tin.join_closest_components()
    
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
    
        
    tin.boundaries()
    if clean == True:
        # Perform mesh cleaning
        if verbose:
            print('Fixing degeneracies and intersections')
        result = tin.clean()
    else:
        print("Skipping the degenerative cleaning")
        result = False

    # Check boundaries again
    if tin.boundaries():
        if verbose:
            print('Patching holes...')
        holespatched = tin.fill_small_boundaries()
        if verbose:
            print('Patched %d holes' % holespatched)
    
        if verbose:
            print('Performing final check...')
        if clean == True:
            if verbose:
                print('Fixing degeneracies and intersections')
            result = tin.clean()
        else:
            print("Skipping the degenerative cleaning")
            result = False

    if result:
        warnings.warn('MeshFix could not fix everything')

# %%
def get_axon_mesh(key):
    """
    Will return a trimesh object representing the mesh for that soma
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    
    #get the labels for the mesh
    face_labels = (pinky.UndecimatedNeuronLabels & key).fetch1("coarse_triangles_labels")
    
    y = np.where(face_labels==6)
    z = np.where(face_labels==7)
    axon_indexes = np.hstack((y,z))
    
    print("axon_indexes = " + str(axon_indexes))
    
    if not axon_indexes.any():
        return trimesh.Trimesh(np.array([]),np.array([])),axon_indexes
    
    #get a submesh
    axon_mesh = current_mesh.submesh(axon_indexes,append=True)
    return axon_mesh,axon_indexes

# %%
@schema
class NeuritePostsynAxon(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """

    
    key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]))  + (dj.U("segment_id","segmentation") & (pinky.CompartmentOrphan.ComponentOrphan() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]])) 

    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        #gets the axons
        mesh,face_indexes = get_axon_mesh(key)
        
        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])
        
        """
        Handle the poosibility that there is no mesh
        """
        print("mesh.faces = " + str(len(mesh.faces)))
        
        if len(mesh.faces) < 5:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
        
                #send the data through the hole patching function from pymesh:
                cleaned_verts, cleaned_triangles= clean_from_arrays_celii(m.vertices,m.faces,verbose=True,joincomp=True,remove_smallest_components=False,clean=False)
                #cleaned_mesh = make_trimesh_object(m.vertices,m.faces)
            
            
        
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),cleaned_verts, cleaned_triangles)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                
                
                meshlab_script_2 = str(pathlib.Path.cwd()) + "/" + "remove_intersecting_faces.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(output_mesh,key["segment_id"],meshlab_script_2)
                
                print("About to run pymeshfix")
                start_time_py = time.time()
                loaded_mesh = trimesh.load_mesh(output_mesh,process=False)
                meshfix = pymeshfix.MeshFix(loaded_mesh.vertices,loaded_mesh.faces)
                meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                print(f"Total time for pymeshfix = {time.time() - start_time_py}")
                
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v, meshfix.f)
                
                
                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(path_and_filename)

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(path_and_filename + ".off")

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(path_and_filename)
                if return_value > 0:
                    raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute_2.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)
                    

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(path_and_filename+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neurite_postsyn_axon'" & "status='error'").delete()

# %%
#NeuronSkeletonStitched & "segment_id=neuron648518346349487734"

# %%
start = time.time()
NeuritePostsynAxon.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346349475518:----------
# axon_indexes = [[ 123349  123350  123351 ... 3241663 3241664 3241665]]
# mesh.faces = 26835
# Step 1: Retrieving Mesh and removing error segments: 2.1806163787841797
# There were 9 after split and significance threshold
# There were 1 after split and significance threshold
# Mesh piece 0 with number of faces 26734
# Step 2a: Getting the number of splits: 0.025181055068969727
# largest mesh perc = 0.9962362586174772
# Working on split 0 with face total = 26734
# Patching holes...
# Patched 12 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.8758218288421631
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 4.25213360786438
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349475518_piece_0
# Step 5: Generating Skeleton: 0.796942949295044
# Step 5: Generating and reading Skeleton: 0.8012938499450684
# len_subgraphs AT BEGINNING = 1
# Step 6: Inserting dictionary: 0.020775318145751953
# Total time: 7.646974563598633
#
#
#
# ----------Working on 648518346349478248:----------
# axon_indexes = [[   2253    2254    2255 ... 3431200 3431201 3431202]]
# mesh.faces = 467327
# Step 1: Retrieving Mesh and removing error segments: 2.3368122577667236
# There were 49 after split and significance threshold
# There were 14 after split and significance threshold
# Mesh piece 0 with number of faces 11852
# Mesh piece 1 with number of faces 31628
# Mesh piece 2 with number of faces 396256
# Mesh piece 3 with number of faces 8570
# Mesh piece 4 with number of faces 7240
# Mesh piece 5 with number of faces 1042
# Mesh piece 6 with number of faces 2868
# Mesh piece 7 with number of faces 4641
# Mesh piece 8 with number of faces 388
# Mesh piece 9 with number of faces 358
# Mesh piece 10 with number of faces 822
# Mesh piece 11 with number of faces 478
# Mesh piece 12 with number of faces 394
# Mesh piece 13 with number of faces 428
# Step 2a: Getting the number of splits: 0.5820765495300293
# largest mesh perc = 0.8479201929270083
# Working on split 0 with face total = 11852
# Patching holes...
# Patched 11 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.45709657669067383
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.0048999786376953
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_0
# Step 5: Generating Skeleton: 0.33363890647888184
# Step 5: Generating and reading Skeleton: 0.3365628719329834
# Working on split 1 with face total = 31628
# Patching holes...
# Patched 7 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.735375165939331
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.683192253112793
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_1
# Step 5: Generating Skeleton: 1.0640084743499756
# Step 5: Generating and reading Skeleton: 1.068009376525879
# Working on split 2 with face total = 396256
# Patching holes...
# Patched 167 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 42.31153964996338
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 100.606290102005
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_2
# Step 5: Generating Skeleton: 12.85202932357788
# Step 5: Generating and reading Skeleton: 12.882215023040771
# Working on split 3 with face total = 8570
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.19025897979736328
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.324333667755127
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_3
# Step 5: Generating Skeleton: 0.2930443286895752
# Step 5: Generating and reading Skeleton: 0.2947883605957031
# Working on split 4 with face total = 7240
# Patching holes...
# Patched 3 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.1376502513885498
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.3516125679016113
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_4
# Step 5: Generating Skeleton: 0.3024170398712158
# Step 5: Generating and reading Skeleton: 0.30422496795654297
# Working on split 5 with face total = 1042
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.029722213745117188
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7004094123840332
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_5
# Step 5: Generating Skeleton: 0.06575441360473633
# Step 5: Generating and reading Skeleton: 0.06662106513977051
# Working on split 6 with face total = 2868
# Patching holes...
# Patched 4 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.07077932357788086
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8789572715759277
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_6
# Step 5: Generating Skeleton: 0.11205339431762695
# Step 5: Generating and reading Skeleton: 0.11318683624267578
# Working on split 7 with face total = 4641
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.09790849685668945
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9845287799835205
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_7
# Step 5: Generating Skeleton: 0.14667439460754395
# Step 5: Generating and reading Skeleton: 0.14810681343078613
# Working on split 8 with face total = 388
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.011605024337768555
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.654296875
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_8
# Step 5: Generating Skeleton: 0.028118133544921875
# Step 5: Generating and reading Skeleton: 0.02882981300354004
# Working on split 9 with face total = 358
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.014021158218383789
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6680607795715332
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_9
# Step 5: Generating Skeleton: 0.016783475875854492
# Step 5: Generating and reading Skeleton: 0.017783403396606445
# Working on split 10 with face total = 822
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.02081608772277832
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6282284259796143
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_10
# Step 5: Generating Skeleton: 0.047759294509887695
# Step 5: Generating and reading Skeleton: 0.048310041427612305
# Working on split 11 with face total = 478
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.012618303298950195
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6107804775238037
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_11
# Step 5: Generating Skeleton: 0.035562753677368164
# Step 5: Generating and reading Skeleton: 0.036527395248413086
# Working on split 12 with face total = 394
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.012938499450683594
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.5964257717132568
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_12
# Step 5: Generating Skeleton: 0.02472662925720215
# Step 5: Generating and reading Skeleton: 0.025393009185791016
# Working on split 13 with face total = 428
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.013780832290649414
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6910295486450195
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478248_piece_13
# Step 5: Generating Skeleton: 0.03576469421386719
# Step 5: Generating and reading Skeleton: 0.03643393516540527
# len_subgraphs AT BEGINNING = 14
# min_dist = 539.0244985156053
# min_dist_subgraph_index = 1
# min_dist_edge_index = [73, 74]
# min_dist_edge = [array([263240. , 153606. ,  16402.5]), array([263299. , 154070. ,  16134.6])]
# len_subgraphs AT END= 13
# min_dist = 900.7313694992531
# min_dist_subgraph_index = 1
# min_dist_edge_index = [129, 130]
# min_dist_edge = [array([264239. , 154738. ,  15590.4]), array([264846. , 155030. ,  14992.4])]
# len_subgraphs AT END= 12
# min_dist = 17567.143894498047
# min_dist_subgraph_index = 1
# min_dist_edge_index = [440, 441]
# min_dist_edge = [array([294775. , 178296. ,  15349.6]), array([307513. , 189469. ,  19987.7])]
# len_subgraphs AT END= 11
# min_dist = 1580.4623405826553
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1490, 1458]
# min_dist_edge = [array([397758. , 264906. ,  31510.7]), array([396777. , 264501. ,  30339.6])]
# len_subgraphs AT END= 10
# min_dist = 1711.0985827824172
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2754, 2769]
# min_dist_edge = [array([445649. , 263509. ,  18454.6]), array([446668., 264196.,  17264.])]
# len_subgraphs AT END= 9
# min_dist = 496.2267223759729
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2865, 2871]
# min_dist_edge = [array([448180. , 265062. ,  15918.2]), array([448514. , 265264. ,  15611.8])]
# len_subgraphs AT END= 8
# min_dist = 736.3966933657421
# min_dist_subgraph_index = 4
# min_dist_edge_index = [2900, 2907]
# min_dist_edge = [array([448776. , 265374. ,  15395.3]), array([449159. , 265547. ,  14790.6])]
# len_subgraphs AT END= 7
# min_dist = 495.60847450381533
# min_dist_subgraph_index = 4
# min_dist_edge_index = [3039, 3042]
# min_dist_edge = [array([451405. , 267435. ,  12784.3]), array([451634. , 267704. ,  12436.7])]
# len_subgraphs AT END= 6
# min_dist = 594.6465252568113
# min_dist_subgraph_index = 4
# min_dist_edge_index = [3165, 3172]
# min_dist_edge = [array([453710. , 268634. ,  11708.8]), array([454175. , 268907. ,  11458.1])]
# len_subgraphs AT END= 5
# min_dist = 593.8089133719701
# min_dist_subgraph_index = 4
# min_dist_edge_index = [3335, 3339]
# min_dist_edge = [array([456950.  , 269986.  ,   7613.44]), array([457139.  , 270324.  ,   7163.28])]
# len_subgraphs AT END= 4
# min_dist = 2766.8910368859824
# min_dist_subgraph_index = 3
# min_dist_edge_index = [2744, 2756]
# min_dist_edge = [array([444090. , 267520. ,  78881.8]), array([445863. , 265757. ,  80066.7])]
# len_subgraphs AT END= 3
# min_dist = 2874.8047324992353
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1905, 1869]
# min_dist_edge = [array([414118. , 284386. ,  36622.9]), array([413503. , 282325. ,  34715.4])]
# len_subgraphs AT END= 2
# min_dist = 1163.8383736584738
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2121, 2129]
# min_dist_edge = [array([417601. , 270597. ,  15052.5]), array([417758. , 270441. ,  13909.9])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.33838701248168945
# Total time: 159.56488132476807
#
#
#
# ----------Working on 648518346349478700:----------
# axon_indexes = [[  85226   85227   85228 ... 4189226 4189227 4189228]]
# mesh.faces = 213867
# Step 1: Retrieving Mesh and removing error segments: 2.647479772567749
# There were 48 after split and significance threshold
# There were 3 after split and significance threshold
# Mesh piece 0 with number of faces 211151
# Mesh piece 1 with number of faces 258
# Mesh piece 2 with number of faces 2084
# Step 2a: Getting the number of splits: 0.33888959884643555
# largest mesh perc = 0.9873005185465733
# Working on split 0 with face total = 211151
# Patching holes...
# Patched 80 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 13.835323095321655
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 43.84228301048279
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_0
# Step 5: Generating Skeleton: 7.38729190826416
# Step 5: Generating and reading Skeleton: 7.3984129428863525
# Working on split 1 with face total = 258
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.010009765625
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.521665096282959
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_1
# Step 5: Generating Skeleton: 0.012499570846557617
# Step 5: Generating and reading Skeleton: 0.013068914413452148
# Working on split 2 with face total = 2084
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03943300247192383
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6277008056640625
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349478700_piece_2
# Step 5: Generating Skeleton: 0.09551000595092773
# Step 5: Generating and reading Skeleton: 0.09639620780944824
# len_subgraphs AT BEGINNING = 3
# min_dist = 1479.5487690508885
# min_dist_subgraph_index = 1
# min_dist_edge_index = [720, 670]
# min_dist_edge = [array([423698. , 203570. ,  64005.7]), array([422221. , 203564. ,  63919.1])]
# len_subgraphs AT END= 2
# min_dist = 1523.102754248708
# min_dist_subgraph_index = 1
# min_dist_edge_index = [719, 689]
# min_dist_edge = [array([423679. , 157451. ,  69535.4]), array([422964. , 156382. ,  70351.4])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.1524364948272705
# Total time: 60.92773461341858
#
#
#
# ----------Working on 648518346349482676:----------
# axon_indexes = [[   1632    1633    1634 ... 2693315 2693316 2693317]]
# mesh.faces = 385211
# Step 1: Retrieving Mesh and removing error segments: 1.8561556339263916
# There were 68 after split and significance threshold
# There were 15 after split and significance threshold
# Mesh piece 0 with number of faces 196211
# Mesh piece 1 with number of faces 11508
# Mesh piece 2 with number of faces 20534
# Mesh piece 3 with number of faces 21642
# Mesh piece 4 with number of faces 22284
# Mesh piece 5 with number of faces 14248
# Mesh piece 6 with number of faces 654
# Mesh piece 7 with number of faces 30460
# Mesh piece 8 with number of faces 19234
# Mesh piece 9 with number of faces 16790
# Mesh piece 10 with number of faces 21821
# Mesh piece 11 with number of faces 446
# Mesh piece 12 with number of faces 5100
# Mesh piece 13 with number of faces 3332
# Mesh piece 14 with number of faces 460
# Step 2a: Getting the number of splits: 0.4848356246948242
# largest mesh perc = 0.5093598054053493
# Working on split 0 with face total = 196211
# Patching holes...
# Patched 115 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_0.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_0_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_0_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 12.09880018234253
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 38.415313482284546
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_0
# Step 5: Generating Skeleton: 5.019724369049072
# Step 5: Generating and reading Skeleton: 5.032816171646118
# Working on split 1 with face total = 11508
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_1.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_1_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_1_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.23873066902160645
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.563565492630005
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_1
# Step 5: Generating Skeleton: 0.3556694984436035
# Step 5: Generating and reading Skeleton: 0.3576197624206543
# Working on split 2 with face total = 20534
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_2.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_2_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_2_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.6581785678863525
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.9112050533294678
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_2
# Step 5: Generating Skeleton: 0.6097719669342041
# Step 5: Generating and reading Skeleton: 0.6123147010803223
# Working on split 3 with face total = 21642
# Patching holes...
# Patched 10 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_3.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_3_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_3_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.716372013092041
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.967373847961426
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_3
# Step 5: Generating Skeleton: 0.6326942443847656
# Step 5: Generating and reading Skeleton: 0.6340491771697998
# Working on split 4 with face total = 22284
# Patching holes...
# Patched 16 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_4.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_4_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_4_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.46120405197143555
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.9997947216033936
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_4
# Step 5: Generating Skeleton: 0.6402690410614014
# Step 5: Generating and reading Skeleton: 0.6417379379272461
# Working on split 5 with face total = 14248
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_5.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_5_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_5_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.33594369888305664
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.0752675533294678
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_5
# Step 5: Generating Skeleton: 0.389493465423584
# Step 5: Generating and reading Skeleton: 0.39096784591674805
# Working on split 6 with face total = 654
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_6.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_6_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_6_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01924729347229004
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.654496431350708
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_6
# Step 5: Generating Skeleton: 0.039662837982177734
# Step 5: Generating and reading Skeleton: 0.040697574615478516
# Working on split 7 with face total = 30460
# Patching holes...
# Patched 15 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.972907543182373
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 5.423539638519287
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_7
# Step 5: Generating Skeleton: 0.6400022506713867
# Step 5: Generating and reading Skeleton: 0.6423959732055664
# Working on split 8 with face total = 19234
# Patching holes...
# Patched 5 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.627361536026001
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.6116068363189697
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_8
# Step 5: Generating Skeleton: 0.5450091361999512
# Step 5: Generating and reading Skeleton: 0.5474643707275391
# Working on split 9 with face total = 16790
# Patching holes...
# Patched 7 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.515082597732544
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.7359793186187744
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_9
# Step 5: Generating Skeleton: 0.4095304012298584
# Step 5: Generating and reading Skeleton: 0.4116668701171875
# Working on split 10 with face total = 21821
# Patching holes...
# Patched 14 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.9572765827178955
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 3.8840293884277344
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_10
# Step 5: Generating Skeleton: 0.7285563945770264
# Step 5: Generating and reading Skeleton: 0.7308542728424072
# Working on split 11 with face total = 446
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.012357950210571289
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7069730758666992
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_11
# Step 5: Generating Skeleton: 0.02173471450805664
# Step 5: Generating and reading Skeleton: 0.02225804328918457
# Working on split 12 with face total = 5100
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.10602593421936035
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9805734157562256
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_12
# Step 5: Generating Skeleton: 0.21353578567504883
# Step 5: Generating and reading Skeleton: 0.21508455276489258
# Working on split 13 with face total = 3332
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.06067323684692383
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9239118099212646
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_13
# Step 5: Generating Skeleton: 0.13797307014465332
# Step 5: Generating and reading Skeleton: 0.13991975784301758
# Working on split 14 with face total = 460
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_14_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_14_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01670098304748535
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.626483678817749
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349482676_piece_14
# Step 5: Generating Skeleton: 0.054795265197753906
# Step 5: Generating and reading Skeleton: 0.05592203140258789
# len_subgraphs AT BEGINNING = 15
# min_dist = 544.5603731451638
# ...
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_7.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_7_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_7_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.018303871154785156
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6912510395050049
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_7
# Step 5: Generating Skeleton: 0.04259467124938965
# Step 5: Generating and reading Skeleton: 0.04343008995056152
# Working on split 8 with face total = 854
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_8.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_8_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_8_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.026592731475830078
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6754035949707031
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_8
# Step 5: Generating Skeleton: 0.0637049674987793
# Step 5: Generating and reading Skeleton: 0.06485152244567871
# Working on split 9 with face total = 4082
# Patching holes...
# Patched 1 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_9.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_9_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_9_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.08659982681274414
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 2.1464595794677734
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_9
# Step 5: Generating Skeleton: 0.14539337158203125
# Step 5: Generating and reading Skeleton: 0.14717388153076172
# Working on split 10 with face total = 548
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_10.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_10_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_10_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01699686050415039
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6640987396240234
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_10
# Step 5: Generating Skeleton: 0.032073259353637695
# Step 5: Generating and reading Skeleton: 0.03298544883728027
# Working on split 11 with face total = 1476
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_11.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_11_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_11_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.03598904609680176
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7722485065460205
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_11
# Step 5: Generating Skeleton: 0.0822458267211914
# Step 5: Generating and reading Skeleton: 0.08307313919067383
# Working on split 12 with face total = 472
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_12.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_12_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_12_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.014129638671875
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.7102553844451904
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_12
# Step 5: Generating Skeleton: 0.0472722053527832
# Step 5: Generating and reading Skeleton: 0.048471689224243164
# Working on split 13 with face total = 402
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_13.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_13_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_13_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01361227035522461
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6526391506195068
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_13
# Step 5: Generating Skeleton: 0.023780345916748047
# Step 5: Generating and reading Skeleton: 0.024775028228759766
# Working on split 14 with face total = 2774
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_14.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_14_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_14_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.06335210800170898
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.9123716354370117
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_14
# Step 5: Generating Skeleton: 0.14683747291564941
# Step 5: Generating and reading Skeleton: 0.14869356155395508
# Working on split 15 with face total = 432
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_15.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_15_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_15_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.013344764709472656
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.8533504009246826
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_15
# Step 5: Generating Skeleton: 0.03176474571228027
# Step 5: Generating and reading Skeleton: 0.03267931938171387
# Working on split 16 with face total = 738
# Patching holes...
# Patched 2 holes
# Skipping the degenerative cleaning
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_16.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_16_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/pymesh_fix_substitute_2.mls
# meshlab_script = /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_16_mls.off -o /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_16_mls_mls.off -s /notebooks/Pass_2_Sk_Neurons_Final/remove_intersecting_faces.mls
# About to run pymeshfix
# Total time for pymeshfix = 0.01902461051940918
# Done writing OFF file
# Step 4: Meshlab fixing non-manifolds: 1.6436262130737305
# /notebooks/Pass_2_Sk_Neurons_Final/pymesh_NEURONS/neuron_648518346349495971_piece_16
# Step 5: Generating Skeleton: 0.05160236358642578
# Step 5: Generating and reading Skeleton: 0.052538394927978516
# len_subgraphs AT BEGINNING = 17
# min_dist = 797.9346361701565
# min_dist_subgraph_index = 1
# min_dist_edge_index = [117, 118]
# min_dist_edge = [array([228985.  , 281819.  ,   2580.44]), array([229667.  , 281871.  ,   2991.38])]
# len_subgraphs AT END= 16
# min_dist = 1042.1519164210179
# min_dist_subgraph_index = 1
# min_dist_edge_index = [276, 277]
# min_dist_edge = [array([240740.  , 282696.  ,   2963.42]), array([241638.  , 282875.  ,   2465.79])]
# len_subgraphs AT END= 15
# min_dist = 1934.9518142837562
# min_dist_subgraph_index = 1
# min_dist_edge_index = [390, 391]
# min_dist_edge = [array([245256.  , 282758.  ,   2690.44]), array([247069.  , 283006.  ,   3319.38])]
# len_subgraphs AT END= 14
# min_dist = 295.1708149529695
# min_dist_subgraph_index = 5
# min_dist_edge_index = [1493, 1486]
# min_dist_edge = [array([326995. , 289219. ,  15322.4]), array([326947. , 289086. ,  15581.5])]
# len_subgraphs AT END= 13
# min_dist = 362.3429452880244
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1108, 1102]
# min_dist_edge = [array([317818. , 286271. ,  13095.1]), array([317756., 286435.,  12778.])]
# len_subgraphs AT END= 12
# min_dist = 407.50618400215643
# min_dist_subgraph_index = 3
# min_dist_edge_index = [1293, 1298]
# min_dist_edge = [array([323867. , 288091. ,  14713.7]), array([323948. , 287814. ,  15001.4])]
# len_subgraphs AT END= 11
# min_dist = 769.8525118488609
# min_dist_subgraph_index = 8
# min_dist_edge_index = [2357, 2358]
# min_dist_edge = [array([449214. , 210089. ,  11358.4]), array([449864. , 210063. ,  11770.1])]
# len_subgraphs AT END= 10
# min_dist = 682.3405967696784
# min_dist_subgraph_index = 8
# min_dist_edge_index = [2498, 2505]
# min_dist_edge = [array([457292. , 207580. ,  12664.1]), array([457623. , 207416. ,  12090.4])]
# len_subgraphs AT END= 9
# min_dist = 1060.8928126818466
# min_dist_subgraph_index = 8
# min_dist_edge_index = [2551, 2555]
# min_dist_edge = [array([457931. , 206578. ,  11802.6]), array([458124. , 205583. ,  11489.2])]
# len_subgraphs AT END= 8
# min_dist = 1350.25808273826
# min_dist_subgraph_index = 1
# min_dist_edge_index = [614, 553]
# min_dist_edge = [array([277761. , 281085. ,  13096.1]), array([277494. , 280172. ,  12137.8])]
# len_subgraphs AT END= 7
# min_dist = 1557.2610217943554
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1504, 1515]
# min_dist_edge = [array([327037. , 289404. ,  15675.2]), array([328539. , 289815. ,  15663.5])]
# len_subgraphs AT END= 6
# min_dist = 1115.432064269268
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1874, 1877]
# min_dist_edge = [array([359148. , 300759. ,  18183.9]), array([360152. , 301014. ,  17770.2])]
# len_subgraphs AT END= 5
# min_dist = 900.6998612190412
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1936, 1940]
# min_dist_edge = [array([361704. , 301135. ,  17777.5]), array([362603. , 301175. ,  17739.3])]
# len_subgraphs AT END= 4
# min_dist = 2273.45955759059
# min_dist_subgraph_index = 2
# min_dist_edge_index = [2001, 2006]
# min_dist_edge = [array([364942. , 301506. ,  17744.1]), array([367141. , 300977. ,  17974.7])]
# len_subgraphs AT END= 3
# min_dist = 466.61868800981387
# min_dist_subgraph_index = 2
# min_dist_edge_index = [2100, 2099]
# min_dist_edge = [array([369839. , 301417. ,  19320.1]), array([369838. , 301441. ,  19786.1])]
# len_subgraphs AT END= 2
# min_dist = 3215.44122166772
# min_dist_subgraph_index = 1
# min_dist_edge_index = [891, 895]
# min_dist_edge = [array([314442., 295763.,  18567.]), array([316011. , 297926. ,  20355.5])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.1290900707244873
# Total time: 76.2667384147644
#
#
#
# 501.0790355205536
