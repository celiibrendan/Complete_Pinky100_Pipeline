# %%
"""
Will generate the skeletons for all of the
Neurites

Process: 
1) Pull from ta3p100.Mesh
-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS
2) Voxelize the mesh 
3) Export the mesh to an off file
4) Clean up the mesh using:
a. smoothing normals
b. Poisson surface reconstruction
c. Extra remove duplicate filters
5) Send through skeletonization
6) Reading in skeleton segments
7) Write key to database

"""
# Out:
# "\nWill generate the skeletons for all of the\nNeurites\n\nProcess: \n1) Pull from ta3p100.Mesh\n-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS\n2) Voxelize the mesh \n3) Export the mesh to an off file\n4) Clean up the mesh using:\na. smoothing normals\nb. Poisson surface reconstruction\nc. Extra remove duplicate filters\n5) Send through skeletonization\n6) Reading in skeleton segments\n7) Write key to database\n\n"

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/temp_meshlab")) == False:
    os.mkdir("temp_meshlab")

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
#get keysource:
ta3p100.Mesh() & ta3p100.Neurite() #32207 tuples
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 2              64851834634135 28754          57350          =BLOB=     =BLOB=
# 2              64851834634135 11192          22282          =BLOB=     =BLOB=
# 2              64851834634135 58449          116104         =BLOB=     =BLOB=
# 2              64851834634135 24919          49578          =BLOB=     =BLOB=
# 2              64851834634135 37179          74128          =BLOB=     =BLOB=
# 2              64851834634135 37788          75374          =BLOB=     =BLOB=
# 2              64851834634135 20204          40278          =BLOB=     =BLOB=
# 2              64851834634135 15522          30788          =BLOB=     =BLOB=
# 2              64851834634135 45964          91650          =BLOB=     =BLOB=
# 2              64851834634135 21520          42882          =BLOB=     =BLOB=
# 2              64851834634135 12322          24626          =BLOB=     =BLOB=
# 2              64851834634135 75579          150562         =BLOB=     =BLOB=
# 2              64851834634135 16502          32932          =BLOB=     =BLOB=
# 2              64851834634135 26033          51854          =BLOB=     =BLOB=
# 2              64851834634135 29746          59138          =BLOB=     =BLOB=
# 2              64851834634135 23521          46928          =BLOB=     =BLOB=
# 2              64851834634135 29968          59422          =BLOB=     =BLOB=
# 2              64851834634135 15603          31082          =BLOB=     =BLOB=
# 2              64851834634135 42781          85094          =BLOB=     =BLOB=
# 2              64851834634135 18804          37506          =BLOB=     =BLOB=
#    ...
#  (32207 tuples)

# %%
def meshlab_shrinkwrap(key):
    
    file_loc = pathlib.Path.cwd() / "temp_meshlab"
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    midoutput_mesh = path_and_filename + "_mid.off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_script.mlx"
    meshlab_script_rem_dupl = str(pathlib.Path.cwd()) + "/" + "remeshing_script-Remove.mlx"
    #send to meshlabserver
    print("starting meshlabserver Poisson surface reconstruction")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      midoutput_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass Poisson')
    #print(type)
     
    
    #do another call to remove the final duplicate vertices
    print("starting meshlabserver cleaning")
    subprocess_result_2 = run_meshlab_script(meshlab_script_rem_dupl,
                      midoutput_mesh,
                      output_mesh)
    #print("Cleaning subprocess_result= "+ str(subprocess_result_2))
    
    if str(subprocess_result_2)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass cleaning')
    
    
    return output_mesh

# %%
#don't need the vertices for this one because not doing any filtering

@schema
class NeuriteSkeletons(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the skeleton was generated
    ---
    n_branches   :int unsigned #number of edges stored
    branches     :longblob #array storing vertices of edges and each seperated by Nan
    """
    
    key_source = ta3p100.Mesh() & ta3p100.Neurite() 
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        print("Starting on "+str(key["segment_id"]))
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        file_loc = pathlib.Path.cwd() / "temp_meshlab"
        filename = "neuron_" + str(key["segment_id"])
        path_and_filename = str(file_loc / filename)
        
        #get the mesh of the neurite
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        mesh = (ta3p100.Mesh & new_key).fetch1()
        print(f"Step 1: Retrieving Mesh: {time.time() - start_time}")
        
        #Do voxelization
        start_time = time.time()
        mesh = trimesh_io.Mesh(vertices=mesh["vertices"], faces=mesh["triangles"])
        voxels = mesh.voxelized(500)
        voxel_mesh = voxels.as_boxes()
        print(f"Step 2: Voxelization: {time.time() - start_time}")
        
        #Exporting the Voxelization as an off file for meshlabserver
        start_time = time.time()
        #try the inline printing method:
        with open(os.devnull, 'w') as devnull:
            with contextlib.redirect_stdout(devnull):
                voxel_mesh.export(str(path_and_filename) + ".off")
        print(f"Step 3: Exporting Voxel Off function: {time.time() - start_time}")
        
        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_shrinkwrap(key)
        print(f"Step 4: Meshlab shrinkwrapping: {time.time() - start_time}")
        
        #Create the skeleton and retrieve it from the generated file
        #skeletonize the mesh
        start_time = time.time()
        #print("starting creating skeleton")
        return_value = cm.calcification(output_mesh[:-4])
        #print("calcif_return_value = " + str(return_value))
        
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
        
        #read in the skeleton files into an array
        start_time = time.time()
        bone_array = read_skeleton_flat(output_mesh[:-4]+"_skeleton.cgal")
        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Reading in Skeleton: {time.time() - start_time}")
        
              
        start_time = time.time()
        new_key["n_branches"] = len(bone_array)
        new_key["branches"] = bone_array
        #new_key["branches"] = []
        
        
        new_key["time_updated"]=str(datetime.datetime.now())
        #print(new_key)
        #if all goes well then write to database
        self.insert1(new_key)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary and erased files: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
start = time.time()
NeuriteSkeletons.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# Starting on 648518346341352231
# Step 1: Retrieving Mesh: 0.044104814529418945
# Step 2: Voxelization: 0.0647575855255127
# Step 3: Exporting Voxel Off function: 0.03365921974182129
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.155111074447632
# Step 4: Generating Skeleton: 0.2836589813232422
# Step 5: Reading in Skeleton: 0.0023207664489746094
# Step 6: Inserting dictionary and erased files: 0.02428889274597168
# Total time: 4.609567642211914
#
#
#
# Starting on 648518346341352243
# Step 1: Retrieving Mesh: 0.04898571968078613
# Step 2: Voxelization: 0.09301400184631348
# Step 3: Exporting Voxel Off function: 0.04716324806213379
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.347262382507324
# Step 4: Generating Skeleton: 0.3858180046081543
# Step 5: Reading in Skeleton: 0.002794981002807617
# Step 6: Inserting dictionary and erased files: 0.018191099166870117
# Total time: 4.945417881011963
#
#
#
# Starting on 648518346341352299
# Step 1: Retrieving Mesh: 0.04244494438171387
# Step 2: Voxelization: 0.10267758369445801
# Step 3: Exporting Voxel Off function: 0.054724931716918945
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.572360277175903
# Step 4: Generating Skeleton: 0.9677944183349609
# Step 5: Reading in Skeleton: 0.00465703010559082
# Step 6: Inserting dictionary and erased files: 0.02344036102294922
# Total time: 5.771768093109131
#
#
#
# Starting on 648518346341352365
# Step 1: Retrieving Mesh: 0.04661059379577637
# Step 2: Voxelization: 0.04483747482299805
# Step 3: Exporting Voxel Off function: 0.025638341903686523
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.673701763153076
# Step 4: Generating Skeleton: 0.2939445972442627
# Step 5: Reading in Skeleton: 0.001279592514038086
# Step 6: Inserting dictionary and erased files: 0.019898653030395508
# Total time: 4.108057022094727
#
#
#
# Starting on 648518346341352403
# Step 1: Retrieving Mesh: 0.061907291412353516
# Step 2: Voxelization: 0.3196403980255127
# Step 3: Exporting Voxel Off function: 0.15455126762390137
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 8.3527250289917
# Step 4: Generating Skeleton: 1.7740724086761475
# Step 5: Reading in Skeleton: 0.006159305572509766
# Step 6: Inserting dictionary and erased files: 0.03010249137878418
# Total time: 10.70211911201477
#
#
#
# Starting on 648518346341352450
# Step 1: Retrieving Mesh: 0.055350542068481445
# Step 2: Voxelization: 0.11404538154602051
# Step 3: Exporting Voxel Off function: 0.05662178993225098
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.802802085876465
# Step 4: Generating Skeleton: 0.4282491207122803
# Step 5: Reading in Skeleton: 0.0026047229766845703
# Step 6: Inserting dictionary and erased files: 0.022915363311767578
# Total time: 5.485541582107544
#
#
#
# Starting on 648518346341352553
# Step 1: Retrieving Mesh: 0.02976226806640625
# Step 2: Voxelization: 0.12068367004394531
# Step 3: Exporting Voxel Off function: 0.06226181983947754
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.302015066146851
# Step 4: Generating Skeleton: 0.6384003162384033
# Step 5: Reading in Skeleton: 0.003139495849609375
# Step 6: Inserting dictionary and erased files: 0.028217554092407227
# Total time: 6.186498165130615
#
#
#
# Starting on 648518346341352671
# Step 1: Retrieving Mesh: 0.029683589935302734
# Step 2: Voxelization: 0.09861874580383301
# Step 3: Exporting Voxel Off function: 0.048127174377441406
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.0751261711120605
# Step 4: Generating Skeleton: 0.666567325592041
# Step 5: Reading in Skeleton: 0.002196788787841797
# Step 6: Inserting dictionary and erased files: 0.0239713191986084
# Total time: 5.945948362350464
#
#
#
# Starting on 648518346341352768
# Step 1: Retrieving Mesh: 0.054048776626586914
# Step 2: Voxelization: 0.10833406448364258
# Step 3: Exporting Voxel Off function: 0.06244039535522461
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.068483352661133
# Step 4: Generating Skeleton: 0.6242797374725342
# Step 5: Reading in Skeleton: 0.0034842491149902344
# Step 6: Inserting dictionary and erased files: 0.02682805061340332
# Total time: 5.949607610702515
#
#
#
# Starting on 648518346341352809
# Step 1: Retrieving Mesh: 0.03941988945007324
# Step 2: Voxelization: 0.07940006256103516
# Step 3: Exporting Voxel Off function: 0.04097795486450195
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.498226642608643
# Step 4: Generating Skeleton: 0.421525239944458
# Step 5: Reading in Skeleton: 0.0015997886657714844
# Step 6: Inserting dictionary and erased files: 0.02302408218383789
# Total time: 5.107428789138794
#
#
#
# Starting on 648518346341352880
# Step 1: Retrieving Mesh: 0.06436419486999512
# Step 2: Voxelization: 0.14149737358093262
# Step 3: Exporting Voxel Off function: 0.07487869262695312
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.434070825576782
# Step 4: Generating Skeleton: 1.7386014461517334
# Step 5: Reading in Skeleton: 0.008559703826904297
# Step 6: Inserting dictionary and erased files: 0.032143592834472656
# Total time: 8.495410919189453
#
#
#
# Starting on 648518346341353053
# Step 1: Retrieving Mesh: 0.039350032806396484
# Step 2: Voxelization: 0.06713175773620605
# Step 3: Exporting Voxel Off function: 0.03973674774169922
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.510555267333984
# Step 4: Generating Skeleton: 0.5403473377227783
# Step 5: Reading in Skeleton: 0.0026769638061523438
# Step 6: Inserting dictionary and erased files: 0.022445201873779297
# Total time: 5.226611137390137
#
#
#
# Starting on 648518346341353165
# Step 1: Retrieving Mesh: 0.030671119689941406
# Step 2: Voxelization: 0.09106588363647461
# Step 3: Exporting Voxel Off function: 0.06255483627319336
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.720633506774902
# Step 4: Generating Skeleton: 0.612027645111084
# Step 5: Reading in Skeleton: 0.0037221908569335938
# Step 6: Inserting dictionary and erased files: 0.02799534797668457
# Total time: 5.551126003265381
#
#
#
# Starting on 648518346341353221
# Step 1: Retrieving Mesh: 0.0571591854095459
# Step 2: Voxelization: 0.15244722366333008
# Step 3: Exporting Voxel Off function: 0.08825325965881348
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.4433159828186035
# Step 4: Generating Skeleton: 1.2004022598266602
# Step 5: Reading in Skeleton: 0.0048067569732666016
# Step 6: Inserting dictionary and erased files: 0.029416561126708984
# Total time: 7.978514194488525
#
#
#
# Starting on 648518346341353384
# Step 1: Retrieving Mesh: 0.0373842716217041
# Step 2: Voxelization: 0.07575321197509766
# Step 3: Exporting Voxel Off function: 0.04725480079650879
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.27506422996521
# Step 4: Generating Skeleton: 0.3728196620941162
# Step 5: Reading in Skeleton: 0.0017325878143310547
# Step 6: Inserting dictionary and erased files: 0.02292943000793457
# Total time: 4.836045503616333
#
#
#
# Starting on 648518346341353470
# Step 1: Retrieving Mesh: 0.04532146453857422
# Step 2: Voxelization: 0.06288528442382812
# Step 3: Exporting Voxel Off function: 0.044576406478881836
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.236640453338623
# Step 4: Generating Skeleton: 0.3666398525238037
# Step 5: Reading in Skeleton: 0.003791332244873047
# Step 6: Inserting dictionary and erased files: 0.027869224548339844
# Total time: 4.790436267852783
#
#
#
# Starting on 648518346341353581
# Step 1: Retrieving Mesh: 0.08155441284179688
# Step 2: Voxelization: 0.0847015380859375
# Step 3: Exporting Voxel Off function: 0.048506736755371094
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.180184364318848
# Step 4: Generating Skeleton: 0.3711388111114502
# Step 5: Reading in Skeleton: 0.003939628601074219
# Step 6: Inserting dictionary and erased files: 0.04279828071594238
# Total time: 4.815898180007935
#
#
#
# Starting on 648518346341353713
# Step 1: Retrieving Mesh: 0.029182910919189453
# Step 2: Voxelization: 0.05349445343017578
# Step 3: Exporting Voxel Off function: 0.03774142265319824
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.202818393707275
# Step 4: Generating Skeleton: 0.4507431983947754
# Step 5: Reading in Skeleton: 0.002756834030151367
# Step 6: Inserting dictionary and erased files: 0.03357553482055664
# Total time: 4.811686277389526
#
#
#
# Starting on 648518346341353756
# Step 1: Retrieving Mesh: 0.060468196868896484
# Step 2: Voxelization: 0.1853656768798828
# Step 3: Exporting Voxel Off function: 0.1015465259552002
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.8648552894592285
# Step 4: Generating Skeleton: 1.4075839519500732
# Step 5: Reading in Skeleton: 0.005940914154052734
# Step 6: Inserting dictionary and erased files: 0.021950483322143555
# Total time: 8.649669885635376
#
#
#
# Starting on 648518346341353873
# Step 1: Retrieving Mesh: 0.08199405670166016
# Step 2: Voxelization: 0.23270320892333984
# Step 3: Exporting Voxel Off function: 0.13215970993041992
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 8.26150393486023
# Step 4: Generating Skeleton: 2.636434316635132
# Step 5: Reading in Skeleton: 0.009484291076660156
# Step 6: Inserting dictionary and erased files: 0.026156187057495117
# Total time: 11.382706642150879
#
#
#
# Starting on 648518346341354183
# Step 1: Retrieving Mesh: 0.07393765449523926
# Step 2: Voxelization: 0.1894233226776123
# Step 3: Exporting Voxel Off function: 0.11814045906066895
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.6468186378479
# Step 4: Generating Skeleton: 0.8725883960723877
# Step 5: Reading in Skeleton: 0.002614259719848633
# Step 6: Inserting dictionary and erased files: 0.02929377555847168
# Total time: 6.934840202331543
#
#
#
# Starting on 648518346341354299
# Step 1: Retrieving Mesh: 0.06343984603881836
# Step 2: Voxelization: 0.1973261833190918
# Step 3: Exporting Voxel Off function: 0.113922119140625
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.735024929046631
# Step 4: Generating Skeleton: 1.1048197746276855
# Step 5: Reading in Skeleton: 0.0045375823974609375
# Step 6: Inserting dictionary and erased files: 0.026024580001831055
# Total time: 8.24723196029663
#
#
#
# Starting on 648518346341354528
# Step 1: Retrieving Mesh: 0.06882143020629883
# Step 2: Voxelization: 0.12195587158203125
# Step 3: Exporting Voxel Off function: 0.07430696487426758
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.972662448883057
# Step 4: Generating Skeleton: 0.695584774017334
# Step 5: Reading in Skeleton: 0.0021376609802246094
# Step 6: Inserting dictionary and erased files: 0.028884410858154297
# Total time: 5.966235637664795
#
#
#
# Starting on 648518346341354582
# Step 1: Retrieving Mesh: 0.036522865295410156
# Step 2: Voxelization: 0.08753466606140137
# Step 3: Exporting Voxel Off function: 0.061481475830078125
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.857537508010864
# Step 4: Generating Skeleton: 0.5312850475311279
# Step 5: Reading in Skeleton: 0.0025267601013183594
# Step 6: Inserting dictionary and erased files: 0.02745985984802246
# Total time: 5.606820583343506
#
#
#
# Starting on 648518346341354594
# Step 1: Retrieving Mesh: 0.07757019996643066
# Step 2: Voxelization: 0.16121482849121094
# Step 3: Exporting Voxel Off function: 0.09255456924438477
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.307760000228882
# Step 4: Generating Skeleton: 0.8371963500976562
# Step 5: Reading in Skeleton: 0.004578828811645508
# Step 6: Inserting dictionary and erased files: 0.02425074577331543
# Total time: 6.506418943405151
#
#
#
# Starting on 648518346341354695
# Step 1: Retrieving Mesh: 0.046596527099609375
# Step 2: Voxelization: 0.18288183212280273
# Step 3: Exporting Voxel Off function: 0.0940556526184082
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.372304677963257
# Step 4: Generating Skeleton: 1.450993299484253
# Step 5: Reading in Skeleton: 0.0023305416107177734
# Step 6: Inserting dictionary and erased files: 0.028390169143676758
# Total time: 8.179261684417725
#
#
#
# Starting on 648518346341354845
# Step 1: Retrieving Mesh: 0.03566765785217285
# Step 2: Voxelization: 0.11972188949584961
# Step 3: Exporting Voxel Off function: 0.06126117706298828
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.396807670593262
# Step 4: Generating Skeleton: 0.48354339599609375
# Step 5: Reading in Skeleton: 0.0023412704467773438
# Step 6: Inserting dictionary and erased files: 0.02630925178527832
# Total time: 5.127626419067383
#
#
#
# Starting on 648518346341354882
# Step 1: Retrieving Mesh: 0.03267264366149902
# Step 2: Voxelization: 0.09530305862426758
# Step 3: Exporting Voxel Off function: 0.06123185157775879
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.5472259521484375
# Step 4: Generating Skeleton: 1.1192855834960938
# Step 5: Reading in Skeleton: 0.003889322280883789
# Step 6: Inserting dictionary and erased files: 0.024503469467163086
# Total time: 6.886301517486572
#
#
#
# Starting on 648518346341355052
# Step 1: Retrieving Mesh: 0.05229473114013672
# Step 2: Voxelization: 0.17432951927185059
# Step 3: Exporting Voxel Off function: 0.09750127792358398
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 8.015591144561768
# Step 4: Generating Skeleton: 2.1211726665496826
# Step 5: Reading in Skeleton: 0.007802724838256836
# Step 6: Inserting dictionary and erased files: 0.021944761276245117
# Total time: 10.49299669265747
#
#
#
# Starting on 648518346341355195
# Step 1: Retrieving Mesh: 0.05436372756958008
# Step 2: Voxelization: 0.16046881675720215
# Step 3: Exporting Voxel Off function: 0.0828089714050293
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.393761873245239
# Step 4: Generating Skeleton: 0.8354454040527344
# Step 5: Reading in Skeleton: 0.002807140350341797
# Step 6: Inserting dictionary and erased files: 0.029253721237182617
# Total time: 6.56044602394104
#
#
#
# Starting on 648518346341355246
# Step 1: Retrieving Mesh: 0.039011478424072266
# Step 2: Voxelization: 0.06712961196899414
# Step 3: Exporting Voxel Off function: 0.04672670364379883
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.088543176651001
# Step 4: Generating Skeleton: 0.8660261631011963
# Step 5: Reading in Skeleton: 0.003635406494140625
# Step 6: Inserting dictionary and erased files: 0.0253448486328125
# Total time: 5.138556718826294
#
#
#
# Starting on 648518346341355265
# Step 1: Retrieving Mesh: 0.02812337875366211
# Step 2: Voxelization: 0.09774303436279297
# Step 3: Exporting Voxel Off function: 0.068084716796875
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.70145058631897
# Step 4: Generating Skeleton: 0.5637195110321045
# Step 5: Reading in Skeleton: 0.0034151077270507812
# Step 6: Inserting dictionary and erased files: 0.031154632568359375
# Total time: 5.502225399017334
#
#
#
# Starting on 648518346341355316
# Step 1: Retrieving Mesh: 0.04098701477050781
# Step 2: Voxelization: 0.11658787727355957
# Step 3: Exporting Voxel Off function: 0.0646672248840332
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.675552606582642
# Step 4: Generating Skeleton: 0.576775074005127
# Step 5: Reading in Skeleton: 0.003540515899658203
# Step 6: Inserting dictionary and erased files: 0.03721022605895996
# Total time: 5.517435550689697
#
#
#
# Starting on 648518346341355437
# Step 1: Retrieving Mesh: 0.01922011375427246
# Step 2: Voxelization: 0.08320045471191406
# Step 3: Exporting Voxel Off function: 0.041483163833618164
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.0506508350372314
# Step 4: Generating Skeleton: 0.42508721351623535
# Step 5: Reading in Skeleton: 0.0031385421752929688
# Step 6: Inserting dictionary and erased files: 0.023846864700317383
# Total time: 4.649162530899048
#
#
#
# Starting on 648518346341355509
# Step 1: Retrieving Mesh: 0.04757547378540039
# Step 2: Voxelization: 0.16876506805419922
# Step 3: Exporting Voxel Off function: 0.07888245582580566
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.328023910522461
# Step 4: Generating Skeleton: 0.600231409072876
# Step 5: Reading in Skeleton: 0.0031137466430664062
# Step 6: Inserting dictionary and erased files: 0.022878646850585938
# Total time: 5.251314640045166
#
#
#
# Starting on 648518346341355583
# Step 1: Retrieving Mesh: 0.0316157341003418
# Step 2: Voxelization: 0.10528063774108887
# Step 3: Exporting Voxel Off function: 0.06524348258972168
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.534881114959717
# Step 4: Generating Skeleton: 0.43536829948425293
# Step 5: Reading in Skeleton: 0.002912282943725586
# Step 6: Inserting dictionary and erased files: 0.0261538028717041
# Total time: 5.203327178955078
#
#
#
# Starting on 648518346341355680
# Step 1: Retrieving Mesh: 0.03626513481140137
# Step 2: Voxelization: 0.10135269165039062
# Step 3: Exporting Voxel Off function: 0.04816317558288574
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.856959104537964
# Step 4: Generating Skeleton: 0.3188323974609375
# Step 5: Reading in Skeleton: 0.0020780563354492188
# Step 6: Inserting dictionary and erased files: 0.02409839630126953
# Total time: 4.397313356399536
#
#
#
# Starting on 648518346341355748
# Step 1: Retrieving Mesh: 0.04519176483154297
# Step 2: Voxelization: 0.12136101722717285
# Step 3: Exporting Voxel Off function: 0.06248188018798828
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.260180711746216
# Step 4: Generating Skeleton: 0.3392598628997803
# Step 5: Reading in Skeleton: 0.0023872852325439453
# Step 6: Inserting dictionary and erased files: 0.03309035301208496
# Total time: 4.865266799926758
#
#
#
# Starting on 648518346341355843
# Step 1: Retrieving Mesh: 0.04081439971923828
# Step 2: Voxelization: 0.11526632308959961
# Step 3: Exporting Voxel Off function: 0.06694817543029785
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.661242961883545
# Step 4: Generating Skeleton: 0.7360696792602539
# Step 5: Reading in Skeleton: 0.011212825775146484
# Step 6: Inserting dictionary and erased files: 0.02906060218811035
# Total time: 5.662626504898071
#
#
#
# Starting on 648518346341355873
# Step 1: Retrieving Mesh: 0.0484464168548584
# Step 2: Voxelization: 0.12601208686828613
# Step 3: Exporting Voxel Off function: 0.07255029678344727
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.408032655715942
# Step 4: Generating Skeleton: 1.2546262741088867
# Step 5: Reading in Skeleton: 0.0016787052154541016
# Step 6: Inserting dictionary and erased files: 0.03350186347961426
# Total time: 6.947080612182617
#
#
#
# Starting on 648518346341356061
# Step 1: Retrieving Mesh: 0.01926255226135254
# Step 2: Voxelization: 0.04826521873474121
# Step 3: Exporting Voxel Off function: 0.03358125686645508
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8586912155151367
# Step 4: Generating Skeleton: 0.35788440704345703
# Step 5: Reading in Skeleton: 0.001435995101928711
# Step 6: Inserting dictionary and erased files: 0.024643659591674805
# Total time: 4.346285104751587
#
#
#
# Starting on 648518346341356134
# Step 1: Retrieving Mesh: 0.026869535446166992
# Step 2: Voxelization: 0.12021374702453613
# Step 3: Exporting Voxel Off function: 0.07258367538452148
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.311325311660767
# Step 4: Generating Skeleton: 1.2622928619384766
# Step 5: Reading in Skeleton: 0.00632023811340332
# Step 6: Inserting dictionary and erased files: 0.02647089958190918
# Total time: 6.828245401382446
#
#
#
# Starting on 648518346341356193
# Step 1: Retrieving Mesh: 0.03316473960876465
# Step 2: Voxelization: 0.07739663124084473
# Step 3: Exporting Voxel Off function: 0.04513692855834961
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.25826358795166
# Step 4: Generating Skeleton: 0.5683681964874268
# Step 5: Reading in Skeleton: 0.011556863784790039
# Step 6: Inserting dictionary and erased files: 0.022897720336914062
# Total time: 5.020054817199707
#
#
#
# Starting on 648518346341356293
# Step 1: Retrieving Mesh: 0.05032801628112793
# Step 2: Voxelization: 0.12110161781311035
# Step 3: Exporting Voxel Off function: 0.07252073287963867
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.11948037147522
# Step 4: Generating Skeleton: 0.8658220767974854
# Step 5: Reading in Skeleton: 0.005101203918457031
# Step 6: Inserting dictionary and erased files: 0.029396533966064453
# Total time: 6.266505002975464
#
#
#
# Starting on 648518346341356308
# Step 1: Retrieving Mesh: 0.04941558837890625
# Step 2: Voxelization: 0.1947016716003418
# Step 3: Exporting Voxel Off function: 0.08349418640136719
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.0963850021362305
# Step 4: Generating Skeleton: 0.7588109970092773
# Step 5: Reading in Skeleton: 0.005106449127197266
# Step 6: Inserting dictionary and erased files: 0.03748893737792969
# Total time: 6.227619409561157
#
#
#
# Starting on 648518346341356343
# Step 1: Retrieving Mesh: 0.03972339630126953
# Step 2: Voxelization: 0.060021400451660156
# Step 3: Exporting Voxel Off function: 0.036768436431884766
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.5608067512512207
# Step 4: Generating Skeleton: 0.2810640335083008
# Step 5: Reading in Skeleton: 0.0022346973419189453
# Step 6: Inserting dictionary and erased files: 0.026960134506225586
# Total time: 4.009373426437378
#
#
#
# Starting on 648518346341356384
# Step 1: Retrieving Mesh: 0.016434669494628906
# Step 2: Voxelization: 0.06207394599914551
# Step 3: Exporting Voxel Off function: 0.034089088439941406
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.071990013122559
# Step 4: Generating Skeleton: 0.6777536869049072
# Step 5: Reading in Skeleton: 0.0026116371154785156
# Step 6: Inserting dictionary and erased files: 0.029659032821655273
# Total time: 4.897893667221069
#
#
#
# Starting on 648518346341356577
# Step 1: Retrieving Mesh: 0.02877497673034668
# Step 2: Voxelization: 0.12419962882995605
# Step 3: Exporting Voxel Off function: 0.06603002548217773
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.4619059562683105
# Step 4: Generating Skeleton: 0.8878614902496338
# Step 5: Reading in Skeleton: 0.0032105445861816406
# Step 6: Inserting dictionary and erased files: 0.02846550941467285
# Total time: 6.602434158325195
#
#
#
# Starting on 648518346341356621
# Step 1: Retrieving Mesh: 0.0387110710144043
# Step 2: Voxelization: 0.18376946449279785
# Step 3: Exporting Voxel Off function: 0.11067938804626465
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.71224045753479
# Step 4: Generating Skeleton: 1.7387607097625732
# Step 5: Reading in Skeleton: 0.007266998291015625
# Step 6: Inserting dictionary and erased files: 0.031652212142944336
# Total time: 8.825539350509644
#
#
#
# Starting on 648518346341356752
# Step 1: Retrieving Mesh: 0.07952618598937988
# Step 2: Voxelization: 0.3608055114746094
# Step 3: Exporting Voxel Off function: 0.16626262664794922
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 7.141518592834473
# Step 4: Generating Skeleton: 1.8238472938537598
# Step 5: Reading in Skeleton: 0.007683992385864258
# Step 6: Inserting dictionary and erased files: 0.03203296661376953
# Total time: 9.613344669342041
#
#
#
# Starting on 648518346341356920
# Step 1: Retrieving Mesh: 0.05125164985656738
# Step 2: Voxelization: 0.05092668533325195
# Step 3: Exporting Voxel Off function: 0.026047468185424805
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.134629964828491
# Step 4: Generating Skeleton: 0.28943657875061035
# Step 5: Reading in Skeleton: 0.0011472702026367188
# Step 6: Inserting dictionary and erased files: 0.02213430404663086
# Total time: 3.577846050262451
#
#
#
# Starting on 648518346341357002
# Step 1: Retrieving Mesh: 0.01566028594970703
# Step 2: Voxelization: 0.05435371398925781
# Step 3: Exporting Voxel Off function: 0.032262563705444336
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.6163628101348877
# Step 4: Generating Skeleton: 0.34615492820739746
# Step 5: Reading in Skeleton: 0.0024237632751464844
# Step 6: Inserting dictionary and erased files: 0.022240161895751953
# Total time: 4.090832233428955
#
#
#
# Starting on 648518346341357010
# Step 1: Retrieving Mesh: 0.04437398910522461
# Step 2: Voxelization: 0.13634276390075684
# Step 3: Exporting Voxel Off function: 0.0926823616027832
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.708200216293335
# Step 4: Generating Skeleton: 1.736426830291748
# Step 5: Reading in Skeleton: 0.007034778594970703
# Step 6: Inserting dictionary and erased files: 0.026758670806884766
# Total time: 7.753631830215454
#
#
#
# Starting on 648518346341357130
# Step 1: Retrieving Mesh: 0.03674435615539551
# Step 2: Voxelization: 0.06856107711791992
# Step 3: Exporting Voxel Off function: 0.03738522529602051
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.1392018795013428
# Step 4: Generating Skeleton: 0.2621619701385498
# Step 5: Reading in Skeleton: 0.0019974708557128906
# Step 6: Inserting dictionary and erased files: 0.026734590530395508
# Total time: 3.5754928588867188
#
#
#
# Starting on 648518346341357171
# Step 1: Retrieving Mesh: 0.05520963668823242
# Step 2: Voxelization: 0.23852062225341797
# Step 3: Exporting Voxel Off function: 0.10496878623962402
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.619081020355225
# Step 4: Generating Skeleton: 1.3516309261322021
# Step 5: Reading in Skeleton: 0.006577014923095703
# Step 6: Inserting dictionary and erased files: 0.02912139892578125
# Total time: 7.406455993652344
#
#
#
# Starting on 648518346341357259
# Step 1: Retrieving Mesh: 0.051514387130737305
# Step 2: Voxelization: 0.10552859306335449
# Step 3: Exporting Voxel Off function: 0.06295418739318848
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.9146153926849365
# Step 4: Generating Skeleton: 1.191338300704956
# Step 5: Reading in Skeleton: 0.0016434192657470703
# Step 6: Inserting dictionary and erased files: 0.023957014083862305
# Total time: 6.352964878082275
#
#
#
# Starting on 648518346341357278
# Step 1: Retrieving Mesh: 0.03465914726257324
# Step 2: Voxelization: 0.12827253341674805
# Step 3: Exporting Voxel Off function: 0.08191990852355957
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.285769701004028
# Step 4: Generating Skeleton: 1.2233798503875732
# Step 5: Reading in Skeleton: 0.002137899398803711
# Step 6: Inserting dictionary and erased files: 0.028107404708862305
# Total time: 6.786410331726074
#
#
#
# Starting on 648518346341357302
# Step 1: Retrieving Mesh: 0.03962540626525879
# Step 2: Voxelization: 0.08103775978088379
# Step 3: Exporting Voxel Off function: 0.047306060791015625
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.9727718830108643
# Step 4: Generating Skeleton: 0.4805171489715576
# Step 5: Reading in Skeleton: 0.0024640560150146484
# Step 6: Inserting dictionary and erased files: 0.02424454689025879
# Total time: 4.649380683898926
#
#
#
# Starting on 648518346341357368
# Step 1: Retrieving Mesh: 0.045053958892822266
# Step 2: Voxelization: 0.04241776466369629
# Step 3: Exporting Voxel Off function: 0.023388385772705078
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.167917013168335
# Step 4: Generating Skeleton: 0.2123713493347168
# Step 5: Reading in Skeleton: 0.0014150142669677734
# Step 6: Inserting dictionary and erased files: 0.027974367141723633
# Total time: 3.521660566329956
#
#
#
# Starting on 648518346341357395
# Step 1: Retrieving Mesh: 0.039314985275268555
# Step 2: Voxelization: 0.15602636337280273
# Step 3: Exporting Voxel Off function: 0.09183907508850098
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.889306545257568
# Step 4: Generating Skeleton: 0.8122410774230957
# Step 5: Reading in Skeleton: 0.004362583160400391
# Step 6: Inserting dictionary and erased files: 0.022396326065063477
# Total time: 6.01675271987915
#
#
#
# Starting on 648518346341357428
# Step 1: Retrieving Mesh: 0.031134605407714844
# Step 2: Voxelization: 0.0609135627746582
# Step 3: Exporting Voxel Off function: 0.045812129974365234
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.84759783744812
# Step 4: Generating Skeleton: 0.5513975620269775
# Step 5: Reading in Skeleton: 0.003196239471435547
# Step 6: Inserting dictionary and erased files: 0.02508544921875
# Total time: 4.566713333129883
#
#
#
# Starting on 648518346341357451
# Step 1: Retrieving Mesh: 0.020416975021362305
# Step 2: Voxelization: 0.0728769302368164
# Step 3: Exporting Voxel Off function: 0.05284380912780762
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.6514179706573486
# Step 4: Generating Skeleton: 0.3051018714904785
# Step 5: Reading in Skeleton: 0.0016820430755615234
# Step 6: Inserting dictionary and erased files: 0.028278112411499023
# Total time: 4.134347438812256
#
#
#
# Starting on 648518346341357495
# Step 1: Retrieving Mesh: 0.07520937919616699
# Step 2: Voxelization: 0.19785428047180176
# Step 3: Exporting Voxel Off function: 0.09923267364501953
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.762841463088989
# Step 4: Generating Skeleton: 1.6903722286224365
# Step 5: Reading in Skeleton: 0.008416414260864258
# Step 6: Inserting dictionary and erased files: 0.027338027954101562
# Total time: 8.862723588943481
#
#
#
# Starting on 648518346341357529
# Step 1: Retrieving Mesh: 0.04236292839050293
# Step 2: Voxelization: 0.07126975059509277
# Step 3: Exporting Voxel Off function: 0.04689311981201172
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.77512788772583
# Step 4: Generating Skeleton: 0.5998644828796387
# Step 5: Reading in Skeleton: 0.0014483928680419922
# Step 6: Inserting dictionary and erased files: 0.02496623992919922
# Total time: 4.563431024551392
#
#
#
# Starting on 648518346341357548
# Step 1: Retrieving Mesh: 0.03432941436767578
# Step 2: Voxelization: 0.05306100845336914
# Step 3: Exporting Voxel Off function: 0.03346395492553711
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.4280457496643066
# Step 4: Generating Skeleton: 0.25287890434265137
# Step 5: Reading in Skeleton: 0.0018482208251953125
# Step 6: Inserting dictionary and erased files: 0.027034759521484375
# Total time: 3.8325424194335938
#
#
#
# Starting on 648518346341357580
# Step 1: Retrieving Mesh: 0.029663801193237305
# Step 2: Voxelization: 0.04557061195373535
# Step 3: Exporting Voxel Off function: 0.03418254852294922
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.2746243476867676
# Step 4: Generating Skeleton: 0.21395325660705566
# Step 5: Reading in Skeleton: 0.0019245147705078125
# Step 6: Inserting dictionary and erased files: 0.023527860641479492
# Total time: 3.62459135055542
#
#
#
# Starting on 648518346341357593
# Step 1: Retrieving Mesh: 0.07788825035095215
# Step 2: Voxelization: 0.27053165435791016
# Step 3: Exporting Voxel Off function: 0.1517963409423828
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.64337158203125
# Step 4: Generating Skeleton: 1.2667491436004639
# Step 5: Reading in Skeleton: 0.00442814826965332
# Step 6: Inserting dictionary and erased files: 0.02778172492980957
# Total time: 7.444968223571777
#
#
#
# Starting on 648518346341357693
# Step 1: Retrieving Mesh: 0.024898529052734375
# Step 2: Voxelization: 0.09958314895629883
# Step 3: Exporting Voxel Off function: 0.060471534729003906
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.870680809020996
# Step 4: Generating Skeleton: 1.0356864929199219
# Step 5: Reading in Skeleton: 0.003152608871459961
# Step 6: Inserting dictionary and erased files: 0.029426097869873047
# Total time: 6.126385450363159
#
#
#
# Starting on 648518346341357726
# Step 1: Retrieving Mesh: 0.022270679473876953
# Step 2: Voxelization: 0.07500696182250977
# Step 3: Exporting Voxel Off function: 0.048544883728027344
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.727228879928589
# Step 4: Generating Skeleton: 0.38886165618896484
# Step 5: Reading in Skeleton: 0.0024242401123046875
# Step 6: Inserting dictionary and erased files: 0.023426294326782227
# Total time: 4.290060043334961
#
#
#
# Starting on 648518346341357745
# Step 1: Retrieving Mesh: 0.04891180992126465
# Step 2: Voxelization: 0.11268115043640137
# Step 3: Exporting Voxel Off function: 0.06620383262634277
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.95829439163208
# Step 4: Generating Skeleton: 0.848646879196167
# Step 5: Reading in Skeleton: 0.003644227981567383
# Step 6: Inserting dictionary and erased files: 0.025057315826416016
# Total time: 6.065202951431274
#
#
#
# Starting on 648518346341357843
# Step 1: Retrieving Mesh: 0.052018165588378906
# Step 2: Voxelization: 0.12391924858093262
# Step 3: Exporting Voxel Off function: 0.06773161888122559
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.917482614517212
# Step 4: Generating Skeleton: 0.8913905620574951
# Step 5: Reading in Skeleton: 0.0031557083129882812
# Step 6: Inserting dictionary and erased files: 0.02418828010559082
# Total time: 6.082160949707031
#
#
#
# Starting on 648518346341357860
# Step 1: Retrieving Mesh: 0.024074316024780273
# Step 2: Voxelization: 0.05127763748168945
# Step 3: Exporting Voxel Off function: 0.021020889282226562
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.185225009918213
# Step 4: Generating Skeleton: 0.41555094718933105
# Step 5: Reading in Skeleton: 0.00247955322265625
# Step 6: Inserting dictionary and erased files: 0.021553516387939453
# Total time: 3.722705602645874
#
#
#
# Starting on 648518346341357936
# Step 1: Retrieving Mesh: 0.06041097640991211
# Step 2: Voxelization: 0.14696192741394043
# Step 3: Exporting Voxel Off function: 0.08710670471191406
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.664062738418579
# Step 4: Generating Skeleton: 1.725409984588623
# Step 5: Reading in Skeleton: 0.0022962093353271484
# Step 6: Inserting dictionary and erased files: 0.024493932723999023
# Total time: 7.711827278137207
#
#
#
# Starting on 648518346341357955
# Step 1: Retrieving Mesh: 0.04228973388671875
# Step 2: Voxelization: 0.0855722427368164
# Step 3: Exporting Voxel Off function: 0.055761098861694336
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7783071994781494
# Step 4: Generating Skeleton: 0.37111949920654297
# Step 5: Reading in Skeleton: 0.0030558109283447266
# Step 6: Inserting dictionary and erased files: 0.021094799041748047
# Total time: 4.358183860778809
#
#
#
# Starting on 648518346341357981
# Step 1: Retrieving Mesh: 0.05515003204345703
# Step 2: Voxelization: 0.12696123123168945
# Step 3: Exporting Voxel Off function: 0.07347345352172852
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.120776891708374
# Step 4: Generating Skeleton: 1.008009910583496
# Step 5: Reading in Skeleton: 0.0032618045806884766
# Step 6: Inserting dictionary and erased files: 0.023146390914916992
# Total time: 6.412848949432373
#
#
#
# Starting on 648518346341358000
# Step 1: Retrieving Mesh: 0.03969883918762207
# Step 2: Voxelization: 0.06250882148742676
# Step 3: Exporting Voxel Off function: 0.037904977798461914
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8406386375427246
# Step 4: Generating Skeleton: 0.556159257888794
# Step 5: Reading in Skeleton: 0.0009999275207519531
# Step 6: Inserting dictionary and erased files: 0.022422313690185547
# Total time: 4.56189227104187
#
#
#
# Starting on 648518346341358023
# Step 1: Retrieving Mesh: 0.026621341705322266
# Step 2: Voxelization: 0.04913496971130371
# Step 3: Exporting Voxel Off function: 0.035214900970458984
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.936692476272583
# Step 4: Generating Skeleton: 0.6674215793609619
# Step 5: Reading in Skeleton: 0.002882242202758789
# Step 6: Inserting dictionary and erased files: 0.024407386779785156
# Total time: 4.74349570274353
#
#
#
# Starting on 648518346341358030
# Step 1: Retrieving Mesh: 0.03860807418823242
# Step 2: Voxelization: 0.11255598068237305
# Step 3: Exporting Voxel Off function: 0.05247831344604492
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.4161927700042725
# Step 4: Generating Skeleton: 0.593966007232666
# Step 5: Reading in Skeleton: 0.003135204315185547
# Step 6: Inserting dictionary and erased files: 0.02747488021850586
# Total time: 5.2460808753967285
#
#
#
# Starting on 648518346341358075
# Step 1: Retrieving Mesh: 0.03939962387084961
# Step 2: Voxelization: 0.07105135917663574
# Step 3: Exporting Voxel Off function: 0.03777503967285156
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7534191608428955
# Step 4: Generating Skeleton: 0.4896416664123535
# Step 5: Reading in Skeleton: 0.0024759769439697266
# Step 6: Inserting dictionary and erased files: 0.026920318603515625
# Total time: 4.422320365905762
#
#
#
# Starting on 648518346341358172
# Step 1: Retrieving Mesh: 0.027706623077392578
# Step 2: Voxelization: 0.09429621696472168
# Step 3: Exporting Voxel Off function: 0.0640265941619873
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.731342077255249
# Step 4: Generating Skeleton: 0.7411737442016602
# Step 5: Reading in Skeleton: 0.002801179885864258
# Step 6: Inserting dictionary and erased files: 0.023729801177978516
# Total time: 5.686475038528442
#
#
#
# Starting on 648518346341358186
# Step 1: Retrieving Mesh: 0.03749275207519531
# Step 2: Voxelization: 0.055361270904541016
# Step 3: Exporting Voxel Off function: 0.035323143005371094
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.5851027965545654
# Step 4: Generating Skeleton: 0.30777907371520996
# Step 5: Reading in Skeleton: 0.002014636993408203
# Step 6: Inserting dictionary and erased files: 0.023381710052490234
# Total time: 4.047580003738403
#
#
#
# Starting on 648518346341358200
# Step 1: Retrieving Mesh: 0.062441110610961914
# Step 2: Voxelization: 0.07666873931884766
# Step 3: Exporting Voxel Off function: 0.036873817443847656
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8899807929992676
# Step 4: Generating Skeleton: 0.7478582859039307
# Step 5: Reading in Skeleton: 0.002420186996459961
# Step 6: Inserting dictionary and erased files: 0.027013063430786133
# Total time: 4.845629692077637
#
#
#
# Starting on 648518346341358256
# Step 1: Retrieving Mesh: 0.05873584747314453
# Step 2: Voxelization: 0.04945945739746094
# Step 3: Exporting Voxel Off function: 0.03549623489379883
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.6006131172180176
# Step 4: Generating Skeleton: 0.33998680114746094
# Step 5: Reading in Skeleton: 0.002395153045654297
# Step 6: Inserting dictionary and erased files: 0.024727582931518555
# Total time: 4.112828016281128
#
#
#
# Starting on 648518346341358274
# Step 1: Retrieving Mesh: 0.02849864959716797
# Step 2: Voxelization: 0.04411578178405762
# Step 3: Exporting Voxel Off function: 0.023174524307250977
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.498811721801758
# Step 4: Generating Skeleton: 0.49643731117248535
# Step 5: Reading in Skeleton: 0.0030808448791503906
# Step 6: Inserting dictionary and erased files: 0.025507450103759766
# Total time: 4.1217076778411865
#
#
#
# Starting on 648518346341358299
# Step 1: Retrieving Mesh: 0.03467750549316406
# Step 2: Voxelization: 0.05100131034851074
# Step 3: Exporting Voxel Off function: 0.030432701110839844
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.5835189819335938
# Step 4: Generating Skeleton: 0.5890347957611084
# Step 5: Reading in Skeleton: 0.0022780895233154297
# Step 6: Inserting dictionary and erased files: 0.0204010009765625
# Total time: 4.314533472061157
#
#
#
# Starting on 648518346341358355
# Step 1: Retrieving Mesh: 0.036374807357788086
# Step 2: Voxelization: 0.07806277275085449
# Step 3: Exporting Voxel Off function: 0.05181574821472168
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.560356616973877
# Step 4: Generating Skeleton: 0.29678893089294434
# Step 5: Reading in Skeleton: 0.002491474151611328
# Step 6: Inserting dictionary and erased files: 0.02254462242126465
# Total time: 4.050180435180664
#
#
#
# Starting on 648518346341358363
# Step 1: Retrieving Mesh: 0.038053035736083984
# Step 2: Voxelization: 0.14077520370483398
# Step 3: Exporting Voxel Off function: 0.08078646659851074
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.294797897338867
# Step 4: Generating Skeleton: 1.3947579860687256
# Step 5: Reading in Skeleton: 0.005885124206542969
# Step 6: Inserting dictionary and erased files: 0.024066925048828125
# Total time: 6.980987071990967
#
#
#
# Starting on 648518346341358374
# Step 1: Retrieving Mesh: 0.06768202781677246
# Step 2: Voxelization: 0.11319947242736816
# Step 3: Exporting Voxel Off function: 0.08338689804077148
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.030039310455322
# Step 4: Generating Skeleton: 0.6084671020507812
# Step 5: Reading in Skeleton: 0.0022530555725097656
# Step 6: Inserting dictionary and erased files: 0.02574944496154785
# Total time: 4.932347536087036
#
#
#
# Starting on 648518346341358380
# Step 1: Retrieving Mesh: 0.033674001693725586
# Step 2: Voxelization: 0.10195589065551758
# Step 3: Exporting Voxel Off function: 0.06334662437438965
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.6164891719818115
# Step 4: Generating Skeleton: 0.9088082313537598
# Step 5: Reading in Skeleton: 0.0013954639434814453
# Step 6: Inserting dictionary and erased files: 0.0363621711730957
# Total time: 5.767754316329956
#
#
#
# Starting on 648518346341358485
# Step 1: Retrieving Mesh: 0.06642699241638184
# Step 2: Voxelization: 0.08324503898620605
# Step 3: Exporting Voxel Off function: 0.05032849311828613
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.0978922843933105
# Step 4: Generating Skeleton: 0.9689528942108154
# Step 5: Reading in Skeleton: 0.001336812973022461
# Step 6: Inserting dictionary and erased files: 0.025475025177001953
# Total time: 5.295652627944946
#
#
#
# Starting on 648518346341358537
# Step 1: Retrieving Mesh: 0.07277560234069824
# Step 2: Voxelization: 0.23200178146362305
# Step 3: Exporting Voxel Off function: 0.13887524604797363
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.454815149307251
# Step 4: Generating Skeleton: 1.6534357070922852
# Step 5: Reading in Skeleton: 0.004043102264404297
# Step 6: Inserting dictionary and erased files: 0.026126623153686523
# Total time: 8.584620714187622
#
#
#
# Starting on 648518346341358602
# Step 1: Retrieving Mesh: 0.026447296142578125
# Step 2: Voxelization: 0.050226688385009766
# Step 3: Exporting Voxel Off function: 0.029570341110229492
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.1980879306793213
# Step 4: Generating Skeleton: 0.29509973526000977
# Step 5: Reading in Skeleton: 0.001622915267944336
# Step 6: Inserting dictionary and erased files: 0.022885560989379883
# Total time: 3.6259336471557617
#
#
#
# Starting on 648518346341358612
# Step 1: Retrieving Mesh: 0.04309844970703125
# Step 2: Voxelization: 0.08374643325805664
# Step 3: Exporting Voxel Off function: 0.052802324295043945
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.460082769393921
# Step 4: Generating Skeleton: 0.31679296493530273
# Step 5: Reading in Skeleton: 0.0024404525756835938
# Step 6: Inserting dictionary and erased files: 0.028548240661621094
# Total time: 3.9885501861572266
#
#
#
# Starting on 648518346341358639
# Step 1: Retrieving Mesh: 0.03654670715332031
# Step 2: Voxelization: 0.08088994026184082
# Step 3: Exporting Voxel Off function: 0.04650092124938965
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.348184108734131
# Step 4: Generating Skeleton: 0.2908618450164795
# Step 5: Reading in Skeleton: 0.002654552459716797
# ...
# Step 6: Inserting dictionary and erased files: 0.027800798416137695
# Total time: 5.357682943344116
#
#
#
# Starting on 648518346341361153
# Step 1: Retrieving Mesh: 0.07659792900085449
# Step 2: Voxelization: 0.15630221366882324
# Step 3: Exporting Voxel Off function: 0.08151388168334961
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.950960397720337
# Step 4: Generating Skeleton: 1.6714198589324951
# Step 5: Reading in Skeleton: 0.0054705142974853516
# Step 6: Inserting dictionary and erased files: 0.029689311981201172
# Total time: 7.974456787109375
#
#
#
# Starting on 648518346341361163
# Step 1: Retrieving Mesh: 0.0497438907623291
# Step 2: Voxelization: 0.12836050987243652
# Step 3: Exporting Voxel Off function: 0.06574749946594238
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.068739891052246
# Step 4: Generating Skeleton: 0.8498311042785645
# Step 5: Reading in Skeleton: 0.003271341323852539
# Step 6: Inserting dictionary and erased files: 0.03148984909057617
# Total time: 6.1982855796813965
#
#
#
# Starting on 648518346341361199
# Step 1: Retrieving Mesh: 0.04149007797241211
# Step 2: Voxelization: 0.12235260009765625
# Step 3: Exporting Voxel Off function: 0.07526445388793945
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.373858213424683
# Step 4: Generating Skeleton: 0.6369383335113525
# Step 5: Reading in Skeleton: 0.004284858703613281
# Step 6: Inserting dictionary and erased files: 0.030082225799560547
# Total time: 5.286241054534912
#
#
#
# Starting on 648518346341361207
# Step 1: Retrieving Mesh: 0.04635930061340332
# Step 2: Voxelization: 0.10592246055603027
# Step 3: Exporting Voxel Off function: 0.06779146194458008
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.029954195022583
# Step 4: Generating Skeleton: 1.1511785984039307
# Step 5: Reading in Skeleton: 0.0025815963745117188
# Step 6: Inserting dictionary and erased files: 0.026349544525146484
# Total time: 6.432940483093262
#
#
#
# Starting on 648518346341361220
# Step 1: Retrieving Mesh: 0.035639286041259766
# Step 2: Voxelization: 0.12361502647399902
# Step 3: Exporting Voxel Off function: 0.07436060905456543
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.068056106567383
# Step 4: Generating Skeleton: 1.6331658363342285
# Step 5: Reading in Skeleton: 0.009553670883178711
# Step 6: Inserting dictionary and erased files: 0.029709577560424805
# Total time: 7.976025581359863
#
#
#
# Starting on 648518346341361232
# Step 1: Retrieving Mesh: 0.03727078437805176
# Step 2: Voxelization: 0.07913732528686523
# Step 3: Exporting Voxel Off function: 0.0451054573059082
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.9801218509674072
# Step 4: Generating Skeleton: 0.4221153259277344
# Step 5: Reading in Skeleton: 0.0019426345825195312
# Step 6: Inserting dictionary and erased files: 0.025575637817382812
# Total time: 4.594364166259766
#
#
#
# Starting on 648518346341361278
# Step 1: Retrieving Mesh: 0.03706932067871094
# Step 2: Voxelization: 0.07732748985290527
# Step 3: Exporting Voxel Off function: 0.047557830810546875
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7323098182678223
# Step 4: Generating Skeleton: 0.32409095764160156
# Step 5: Reading in Skeleton: 0.003003358840942383
# Step 6: Inserting dictionary and erased files: 0.03726053237915039
# Total time: 4.260071754455566
#
#
#
# Starting on 648518346341361346
# Step 1: Retrieving Mesh: 0.03745579719543457
# Step 2: Voxelization: 0.060965538024902344
# Step 3: Exporting Voxel Off function: 0.029589414596557617
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.138249158859253
# Step 4: Generating Skeleton: 0.3429751396179199
# Step 5: Reading in Skeleton: 0.004671573638916016
# Step 6: Inserting dictionary and erased files: 0.03058457374572754
# Total time: 4.647202014923096
#
#
#
# Starting on 648518346341361390
# Step 1: Retrieving Mesh: 0.02806258201599121
# Step 2: Voxelization: 0.09336304664611816
# Step 3: Exporting Voxel Off function: 0.05152153968811035
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.673102855682373
# Step 4: Generating Skeleton: 0.938549280166626
# Step 5: Reading in Skeleton: 0.0068361759185791016
# Step 6: Inserting dictionary and erased files: 0.03482484817504883
# Total time: 5.827657461166382
#
#
#
# Starting on 648518346341361397
# Step 1: Retrieving Mesh: 0.08001494407653809
# Step 2: Voxelization: 0.2262425422668457
# Step 3: Exporting Voxel Off function: 0.11044168472290039
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.774920701980591
# Step 4: Generating Skeleton: 1.9942328929901123
# Step 5: Reading in Skeleton: 0.007786273956298828
# Step 6: Inserting dictionary and erased files: 0.03135323524475098
# Total time: 9.227617263793945
#
#
#
# Starting on 648518346341361438
# Step 1: Retrieving Mesh: 0.049008846282958984
# Step 2: Voxelization: 0.07288479804992676
# Step 3: Exporting Voxel Off function: 0.037560462951660156
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.4621315002441406
# Step 4: Generating Skeleton: 0.21904325485229492
# Step 5: Reading in Skeleton: 0.0013399124145507812
# Step 6: Inserting dictionary and erased files: 0.03183126449584961
# Total time: 3.8747799396514893
#
#
#
# Starting on 648518346341361484
# Step 1: Retrieving Mesh: 0.05545544624328613
# Step 2: Voxelization: 0.05045962333679199
# Step 3: Exporting Voxel Off function: 0.03550219535827637
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.652009963989258
# Step 4: Generating Skeleton: 0.4878253936767578
# Step 5: Reading in Skeleton: 0.002716064453125
# Step 6: Inserting dictionary and erased files: 0.04045987129211426
# Total time: 4.325632095336914
#
#
#
# Starting on 648518346341361490
# Step 1: Retrieving Mesh: 0.0357823371887207
# Step 2: Voxelization: 0.08913397789001465
# Step 3: Exporting Voxel Off function: 0.04552483558654785
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.181139945983887
# Step 4: Generating Skeleton: 0.4736979007720947
# Step 5: Reading in Skeleton: 0.003573894500732422
# Step 6: Inserting dictionary and erased files: 0.031569719314575195
# Total time: 4.86181902885437
#
#
#
# Starting on 648518346341361494
# Step 1: Retrieving Mesh: 0.06566452980041504
# Step 2: Voxelization: 0.09731507301330566
# Step 3: Exporting Voxel Off function: 0.06292557716369629
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.023839473724365
# Step 4: Generating Skeleton: 0.5963711738586426
# Step 5: Reading in Skeleton: 0.0035161972045898438
# Step 6: Inserting dictionary and erased files: 0.03165006637573242
# Total time: 4.883316993713379
#
#
#
# Starting on 648518346341361570
# Step 1: Retrieving Mesh: 0.05440831184387207
# Step 2: Voxelization: 0.08904838562011719
# Step 3: Exporting Voxel Off function: 0.05352640151977539
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.830279111862183
# Step 4: Generating Skeleton: 0.8203952312469482
# Step 5: Reading in Skeleton: 0.004783153533935547
# Step 6: Inserting dictionary and erased files: 0.03107595443725586
# Total time: 5.885509252548218
#
#
#
# Starting on 648518346341361582
# Step 1: Retrieving Mesh: 0.0528409481048584
# Step 2: Voxelization: 0.05965113639831543
# Step 3: Exporting Voxel Off function: 0.03572368621826172
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.964704751968384
# Step 4: Generating Skeleton: 0.5697140693664551
# Step 5: Reading in Skeleton: 0.0031824111938476562
# Step 6: Inserting dictionary and erased files: 0.029249191284179688
# Total time: 4.716217994689941
#
#
#
# Starting on 648518346341361604
# Step 1: Retrieving Mesh: 0.06038212776184082
# Step 2: Voxelization: 0.09732913970947266
# Step 3: Exporting Voxel Off function: 0.04957699775695801
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.865039110183716
# Step 4: Generating Skeleton: 0.6808104515075684
# Step 5: Reading in Skeleton: 0.003869771957397461
# Step 6: Inserting dictionary and erased files: 0.030452251434326172
# Total time: 4.789928436279297
#
#
#
# Starting on 648518346341361629
# Step 1: Retrieving Mesh: 0.059552669525146484
# Step 2: Voxelization: 0.11800003051757812
# Step 3: Exporting Voxel Off function: 0.07537221908569336
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.021773099899292
# Step 4: Generating Skeleton: 0.5246133804321289
# Step 5: Reading in Skeleton: 0.0043430328369140625
# Step 6: Inserting dictionary and erased files: 0.028214216232299805
# Total time: 4.833108901977539
#
#
#
# Starting on 648518346341361655
# Step 1: Retrieving Mesh: 0.031032323837280273
# Step 2: Voxelization: 0.08305501937866211
# Step 3: Exporting Voxel Off function: 0.046452999114990234
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.008803606033325
# Step 4: Generating Skeleton: 0.7375195026397705
# Step 5: Reading in Skeleton: 0.0029706954956054688
# Step 6: Inserting dictionary and erased files: 0.03308916091918945
# Total time: 4.9446187019348145
#
#
#
# Starting on 648518346341361659
# Step 1: Retrieving Mesh: 0.06088829040527344
# Step 2: Voxelization: 0.15841412544250488
# Step 3: Exporting Voxel Off function: 0.1015467643737793
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.957123517990112
# Step 4: Generating Skeleton: 1.7755837440490723
# Step 5: Reading in Skeleton: 0.0039288997650146484
# Step 6: Inserting dictionary and erased files: 0.032166242599487305
# Total time: 8.093213319778442
#
#
#
# Starting on 648518346341361740
# Step 1: Retrieving Mesh: 0.08640170097351074
# Step 2: Voxelization: 0.2705113887786865
# Step 3: Exporting Voxel Off function: 0.1431574821472168
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 7.450201034545898
# Step 4: Generating Skeleton: 1.9848182201385498
# Step 5: Reading in Skeleton: 0.002533435821533203
# Step 6: Inserting dictionary and erased files: 0.03040599822998047
# Total time: 9.969530820846558
#
#
#
# Starting on 648518346341361759
# Step 1: Retrieving Mesh: 0.03531289100646973
# Step 2: Voxelization: 0.09960627555847168
# Step 3: Exporting Voxel Off function: 0.055150508880615234
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.190462827682495
# Step 4: Generating Skeleton: 0.4099271297454834
# Step 5: Reading in Skeleton: 0.002109050750732422
# Step 6: Inserting dictionary and erased files: 0.03196907043457031
# Total time: 4.826185941696167
#
#
#
# Starting on 648518346341361782
# Step 1: Retrieving Mesh: 0.030042648315429688
# Step 2: Voxelization: 0.08277058601379395
# Step 3: Exporting Voxel Off function: 0.05280137062072754
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8040645122528076
# Step 4: Generating Skeleton: 0.3595438003540039
# Step 5: Reading in Skeleton: 0.002184152603149414
# Step 6: Inserting dictionary and erased files: 0.028226375579833984
# Total time: 4.362059116363525
#
#
#
# Starting on 648518346341361790
# Step 1: Retrieving Mesh: 0.022431373596191406
# Step 2: Voxelization: 0.0691523551940918
# Step 3: Exporting Voxel Off function: 0.03117656707763672
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.306746006011963
# Step 4: Generating Skeleton: 0.3036060333251953
# Step 5: Reading in Skeleton: 0.002142190933227539
# Step 6: Inserting dictionary and erased files: 0.0342562198638916
# Total time: 3.7711405754089355
#
#
#
# Starting on 648518346341361800
# Step 1: Retrieving Mesh: 0.02195596694946289
# Step 2: Voxelization: 0.04167485237121582
# Step 3: Exporting Voxel Off function: 0.022609710693359375
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.3761019706726074
# Step 4: Generating Skeleton: 0.20833206176757812
# Step 5: Reading in Skeleton: 0.0017595291137695312
# Step 6: Inserting dictionary and erased files: 0.026421308517456055
# Total time: 3.7000744342803955
#
#
#
# Starting on 648518346341361805
# Step 1: Retrieving Mesh: 0.019170761108398438
# Step 2: Voxelization: 0.05186200141906738
# Step 3: Exporting Voxel Off function: 0.03151392936706543
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7662816047668457
# Step 4: Generating Skeleton: 0.2776987552642822
# Step 5: Reading in Skeleton: 0.0023310184478759766
# Step 6: Inserting dictionary and erased files: 0.028758525848388672
# Total time: 4.179510116577148
#
#
#
# Starting on 648518346341361816
# Step 1: Retrieving Mesh: 0.04107069969177246
# Step 2: Voxelization: 0.059749603271484375
# Step 3: Exporting Voxel Off function: 0.03534340858459473
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.22770357131958
# Step 4: Generating Skeleton: 0.5931243896484375
# Step 5: Reading in Skeleton: 0.0029020309448242188
# Step 6: Inserting dictionary and erased files: 0.028534412384033203
# Total time: 4.9907543659210205
#
#
#
# Starting on 648518346341361822
# Step 1: Retrieving Mesh: 0.059827327728271484
# Step 2: Voxelization: 0.1292860507965088
# Step 3: Exporting Voxel Off function: 0.06882619857788086
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.698544025421143
# Step 4: Generating Skeleton: 0.7317061424255371
# Step 5: Reading in Skeleton: 0.004121065139770508
# Step 6: Inserting dictionary and erased files: 0.027348995208740234
# Total time: 5.721933841705322
#
#
#
# Starting on 648518346341361824
# Step 1: Retrieving Mesh: 0.042806148529052734
# Step 2: Voxelization: 0.07124876976013184
# Step 3: Exporting Voxel Off function: 0.045575857162475586
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.328222036361694
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-a4b23312f459> in <module>
#       1 start = time.time()
# ----> 2 NeuriteSkeletons.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-9-cc4a9e57f3f1> in make(self, key)
#      60         if return_value > 0:
#      61             raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) +
# ---> 62                             ' did not finish... exited with error code: ' + str(return_value))
#      63         print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
#      64
#
# Exception: skeletonization for neuron 648518346341361824 did not finish... exited with error code: 4

# %%
ta3p100.NeuriteSkeletons().delete()
