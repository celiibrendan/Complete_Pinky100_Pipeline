# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349496245******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08481073379516602
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 886.1043632030487
# 2) Finished: Generating CGAL segmentation for neuron: 905.2350499629974
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.23237037658691406
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 42, 6, 23, 12, 9, 19, 58]
# soma_80_percent = 183319.125
# Debugging the axon filter
# [(0, 193227.71875), (42, 194711.765625), (6, 214339.21875), (23, 183507.6875), (12, 182131.109375), (9, 200316.25), (19, 202066.46875), (58, 180075.84375)]
# possible_Axons_filter_1 = [12, 58]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.04894709587097168
# 6) Staring: Classifying Entire Neuron
# 19 = error
# 58 = cilia
# Total Labels found = {'error', 'cilia', 'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 2.102858543395996
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 1.0608165264129639
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.097784042358398
# Finished Auto Labeling: 920.5488693714142
#
#
# *****Starting Auto Labeling for 648518346349499773******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06815934181213379
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1152.6450769901276
# 2) Finished: Generating CGAL segmentation for neuron: 1175.9778707027435
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 13
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.28505730628967285
# 5) Staring: Finding Apical Index
# Soma Index = 13
# Soma Connections = [9, 4, 21, 29, 32, 18, 11, 33, 81, 79, 70, 157, 153, 126, 115, 141, 113, 82, 83]
# soma_80_percent = 233236.415625
# Debugging the axon filter
# [(9, 249618.140625), (4, 229964.71875), (21, 242997.109375), (29, 259290.734375), (32, 233838.09375), (18, 254747.921875), (11, 238343.03125), (33, 240279.609375), (81, 241685.515625), (79, 237047.4375), (70, 232905.828125), (157, 240585.328125), (153, 233226.09375), (126, 240967.6875), (115, 244528.4375), (141, 231370.1875), (113, 230352.90625), (82, 239888.0), (83, 241209.78125)]
# possible_Axons_filter_1 = [4, 70, 153, 141, 113]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.12473893165588379
# 6) Staring: Classifying Entire Neuron
# 18 = axon
# 32 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 33
# 70 = stub soma
# 115 = cilia
# 79 = stub soma
# 81 = stub soma
# 82 = stub soma
# 83 = stub soma
# 113 = stub soma
# 126 = stub soma
# 141 = stub soma
# 153 = stub soma
# 157 = stub soma
# 8 = stub apical
# 24 = error
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 34 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 106 = stub apical
# 107 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 116 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 131 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# Total Labels found = {'cilia', 'error', 'axon', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.3762099742889404
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5144782066345215
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.819166898727417
# Finished Auto Labeling: 1193.99165725708
#
#
# *****Starting Auto Labeling for 648518346349501625******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.08985018730163574
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1503.2720124721527
# 2) Finished: Generating CGAL segmentation for neuron: 1528.9251692295074
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 22
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3234384059906006
# 5) Staring: Finding Apical Index
# Soma Index = 22
# Soma Connections = [38, 16, 9, 46, 14, 19, 1, 29, 176, 132, 148, 48, 124, 184, 113]
# soma_80_percent = 255704.178125
# Debugging the axon filter
# [(38, 282633.9375), (16, 258601.6875), (9, 254572.296875), (46, 285055.03125), (14, 261650.125), (19, 277491.125), (1, 278130.5), (29, 275919.0), (176, 252835.78125), (132, 264033.625), (148, 262522.0), (48, 257910.03125), (124, 258616.6875), (184, 256535.8125), (113, 255379.140625)]
# possible_Axons_filter_1 = [9, 176, 113]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.12301468849182129
# 6) Staring: Classifying Entire Neuron
# 46 = axon
# 113 = stub soma
# 124 = stub soma
# 132 = stub soma
# 148 = stub soma
# 176 = stub soma
# 184 = stub soma
# 24 = stub apical
# 28 = stub apical
# 32 = stub apical
# 34 = stub apical
# 35 = stub apical
# 39 = stub apical
# 41 = stub apical
# 45 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = error
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 95 = stub apical
# 99 = stub apical
# 100 = stub apical
# 106 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 141 = stub apical
# 142 = stub apical
# 144 = stub apical
# 145 = stub apical
# 150 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 159 = stub apical
# 160 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 182 = stub apical
# 183 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# Total Labels found = {'error', 'axon', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 3.5828349590301514
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6579821109771729
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 14.34326457977295
# Finished Auto Labeling: 1549.02219581604
#
#
# *****Starting Auto Labeling for 648518346349505261******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.022307395935058594
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 126.7327139377594
# 2) Finished: Generating CGAL segmentation for neuron: 132.96407389640808
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.07345438003540039
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [2, 12, 0, 11, 8, 26, 31, 23, 19, 29, 20, 43, 34, 3, 44, 30, 32, 37]
# soma_80_percent = 247965.740625
# Debugging the axon filter
# [(2, 254809.1875), (12, 261004.265625), (0, 245309.765625), (11, 251467.90625), (8, 270061.125), (26, 250982.1875), (31, 247441.96875), (23, 263736.75), (19, 250055.3125), (29, 256993.453125), (20, 258826.84375), (43, 247883.21875), (34, 250368.203125), (3, 252385.984375), (44, 248163.21875), (30, 256256.125), (32, 245134.640625), (37, 244643.578125)]
# possible_Axons_filter_1 = [0, 31, 43, 32, 37]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.03756284713745117
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 11
# 26 = stub soma
# 29 = stub soma
# 30 = stub soma
# 32 = stub soma
# 34 = stub soma
# 37 = stub soma
# 43 = stub soma
# 44 = stub soma
# 10 = stub apical
# 13 = stub apical
# 14 = stub apical
# 15 = stub apical
# 18 = stub apical
# 21 = stub apical
# 22 = stub apical
# 24 = stub apical
# 25 = stub apical
# 36 = stub apical
# 39 = stub apical
# 40 = stub apical
# Total Labels found = {'oblique', 'basal', 'apical', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.7119896411895752
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.1836860179901123
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.2252485752105713
# Finished Auto Labeling: 137.42191243171692
#
#
# *****Starting Auto Labeling for 648518346349505512******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05035281181335449
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 690.849588394165
# 2) Finished: Generating CGAL segmentation for neuron: 705.7237522602081
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1990814208984375
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [6, 3, 45, 4, 73, 41, 336, 318, 269, 317]
# soma_80_percent = 279621.93125
# Debugging the axon filter
# [(6, 275853.46875), (3, 294732.5), (45, 302768.09375), (4, 294978.59375), (73, 283956.09375), (41, 298407.90625), (336, 281610.5), (318, 277092.96875), (269, 284333.40625), (317, 277591.5)]
# possible_Axons_filter_1 = [6, 318, 317]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.10839700698852539
# 6) Staring: Classifying Entire Neuron
# 73 = stub soma
# 269 = stub soma
# 318 = cilia
# 317 = stub soma
# 336 = stub soma
# 14 = stub apical
# 16 = stub apical
# 17 = stub apical
# 18 = stub apical
# 19 = stub apical
# 20 = stub apical
# 21 = stub apical
# 22 = stub apical
# 25 = error
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = error
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = error
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = error
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = error
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = error
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 196 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# Total Labels found = {'cilia', 'error', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.011969566345215
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.45705270767211914
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.634087562561035
# Finished Auto Labeling: 717.812070608139
#
#
# *****Starting Auto Labeling for 648518346349506778******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04372429847717285
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 553.7324864864349
# 2) Finished: Generating CGAL segmentation for neuron: 568.2595407962799
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.18496227264404297
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [7, 23, 25, 94, 3, 20, 19, 88, 65, 83, 64]
# soma_80_percent = 249618.965625
# Debugging the axon filter
# [(7, 247889.515625), (23, 270028.96875), (25, 250384.984375), (94, 246261.078125), (3, 250697.828125), (20, 281590.0625), (19, 249590.828125), (88, 253266.734375), (65, 250759.671875), (83, 261495.3125), (64, 253278.765625)]
# possible_Axons_filter_1 = [7, 94, 19]
# possible_Axons_filter_2 = [7]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.07299280166625977
# 6) Staring: Classifying Entire Neuron
# 25 = cilia
# 64 = stub soma
# 65 = stub soma
# 83 = stub soma
# 88 = stub soma
# 94 = stub soma
# 9 = stub apical
# 22 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 80 = stub apical
# 91 = stub apical
# 102 = stub apical
# 106 = stub apical
# 107 = stub apical
# Total Labels found = {'cilia', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.6190414428710938
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3606901168823242
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.768923044204712
# Finished Auto Labeling: 580.8686764240265
#
#
# *****Starting Auto Labeling for 648518346349508447******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04213213920593262
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 408.4076302051544
# 2) Finished: Generating CGAL segmentation for neuron: 420.046183347702
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.14798426628112793
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 3, 28, 5, 27, 13, 24, 182, 7, 161, 232, 196, 96]
# soma_80_percent = 278790.609375
# Debugging the axon filter
# [(2, 282548.40625), (3, 284655.0625), (28, 298161.5), (5, 275295.5625), (27, 299369.53125), (13, 300188.6875), (24, 304091.125), (182, 287397.03125), (7, 279405.3125), (161, 284324.03125), (232, 287981.875), (196, 289827.09375), (96, 282396.25)]
# possible_Axons_filter_1 = [5]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.08075261116027832
# 6) Staring: Classifying Entire Neuron
# 7 = stub soma
# 28 = axon
# 96 = stub soma
# 161 = stub soma
# 182 = stub soma
# 196 = stub soma
# 232 = stub soma
# 17 = error
# 18 = stub apical
# 20 = stub apical
# 25 = stub apical
# 33 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 60 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 131 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 140 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 157 = stub apical
# 158 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 183 = stub apical
# 185 = stub apical
# 187 = stub apical
# 188 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 233 = stub apical
# Total Labels found = {'error', 'axon', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.8325483798980713
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3145902156829834
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.4597485065460205
# Finished Auto Labeling: 429.383177280426
#
#
# *****Starting Auto Labeling for 648518346349509399******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0637505054473877
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 833.4314460754395
# 2) Finished: Generating CGAL segmentation for neuron: 852.8695063591003
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.23776030540466309
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [0, 16, 22, 11, 23, 27, 101, 123, 75, 25, 80]
# soma_80_percent = 207059.5671875
# Debugging the axon filter
# [(0, 231036.375), (16, 222424.453125), (22, 216742.515625), (11, 234794.03125), (23, 204107.953125), (27, 222827.65625), (101, 210288.0), (123, 216212.0), (75, 205086.328125), (25, 212278.546875), (80, 215488.046875)]
# possible_Axons_filter_1 = [23, 75]
# possible_Axons_filter_2 = [23]
# possible_Apical = 23
# 5) Finished: Finding Apical Index: 0.09551811218261719
# 6) Staring: Classifying Entire Neuron
# 11 = axon
# 75 = stub soma
# 80 = stub soma
# 101 = stub soma
# 123 = stub soma
# 13 = stub apical
# 26 = error
# 28 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = error
# 34 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = error
# 49 = stub apical
# 50 = stub apical
# 56 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 83 = stub apical
# 84 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 93 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 99 = stub apical
# 100 = stub apical
# 105 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 122 = stub apical
# 124 = stub apical
# Total Labels found = {'error', 'axon', 'basal', 'soma', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.3053388595581055
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4177219867706299
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.692496538162231
# Finished Auto Labeling: 868.4571626186371
#
#
# *****Starting Auto Labeling for 648518346349512375******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05902838706970215
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 366.1811373233795
# 2) Finished: Generating CGAL segmentation for neuron: 378.60416626930237
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1645340919494629
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [7, 11, 6, 14, 19, 10, 21, 31, 25, 43]
# soma_80_percent = 158927.759375
# Debugging the axon filter
# [(7, 179464.921875), (11, 155118.65625), (6, 165986.15625), (14, 157693.34375), (19, 171885.703125), (10, 186391.90625), (21, 159862.21875), (31, 157883.90625), (25, 154521.375), (43, 156888.953125)]
# possible_Axons_filter_1 = [11, 14, 31, 25, 43]
# possible_Axons_filter_2 = [14]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.04651451110839844
# 6) Staring: Classifying Entire Neuron
# 21 = cilia
# 25 = stub soma
# 31 = stub soma
# 43 = stub soma
# Total Labels found = {'basal', 'apical', 'soma', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 1.3041882514953613
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.26637816429138184
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.757126331329346
# Finished Auto Labeling: 387.6579222679138
#
#
# *****Starting Auto Labeling for 648518346349513769******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03145956993103027
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 458.27095437049866
# 2) Finished: Generating CGAL segmentation for neuron: 470.1768181324005
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.15364623069763184
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 5, 2, 18, 41, 7, 16, 12, 33, 3, 43, 14, 42, 13, 28, 23, 31, 27, 24]
# soma_80_percent = 289157.8875
# Debugging the axon filter
# [(0, 301542.65625), (5, 291580.875), (2, 291655.1875), (18, 289608.5625), (41, 298257.96875), (7, 296497.75), (16, 299179.34375), (12, 291590.03125), (33, 292727.09375), (3, 288218.21875), (43, 295095.0), (14, 287375.34375), (42, 294571.3125), (13, 294305.5625), (28, 291918.6875), (23, 288666.4375), (31, 290692.5625), (27, 294981.96875), (24, 296569.6875)]
# possible_Axons_filter_1 = [3, 14, 23]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.04454541206359863
# 6) Staring: Classifying Entire Neuron
# 0 = error
# 3 = stub soma
# 5 = stub soma
# 14 = cilia
# 23 = stub soma
# 24 = stub soma
# 27 = stub soma
# 28 = stub soma
# 31 = stub soma
# 33 = stub soma
# 43 = stub soma
# 42 = stub soma
# Total Labels found = {'error', 'cilia', 'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.224973440170288
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4688553810119629
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.497004747390747
# Finished Auto Labeling: 479.02951741218567
# 7266.992991685867

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
