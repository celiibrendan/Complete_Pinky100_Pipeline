# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341373381**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 68 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 314826
# Total time for Mesh Cleansing: 6.328343868255615
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983890097483937% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341375623**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 138 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 584916
# Total time for Mesh Cleansing: 8.957993507385254
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987535132144675% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341382445**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 12 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 113074
# Total time for Mesh Cleansing: 0.221787691116333
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995403355550448% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341382699**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 135 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 509304
# Total time for Mesh Cleansing: 9.3630530834198
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984277777559958% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341386441**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 324 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 1238095
# Total time for Mesh Cleansing: 44.609811782836914
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9977275565995544% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341386441_30_main_and_child_meshes_array.npz
#  face length 1238095 using optimized facets with 3 neighbors
# Filtering edges by size finished: 25.387200832366943, facet # = 65090
# Filtering by convexity and getting centers took: 38.44464683532715, facet # = 12907
# Finished facets for main mesh: 66.49912190437317 with facet length = 12907
# Finished 12907 facets for main mesh: 66.49962139129639
# Filtering edges by size finished: 0.0028905868530273438, facet # = 0
# Filtering by convexity and getting centers took: 0.0002727508544921875, facet # = 0
# Total time for facets: 66.51050448417664
# Zero faceted faces = [0]
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 0.4690523147583008
# Total time for restitching = 0.4727950096130371
# missed_children = [0.0]
# Whole stitching function complete: 115.73210644721985
#
#
#
# *****Running Neuron Stitcher for 648518346344512331**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 69920
# Total time for Mesh Cleansing: 0.12307620048522949
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996568683518243% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344517531**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 82 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 190616
# Total time for Mesh Cleansing: 6.624067306518555
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9974255394855265% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346307265**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 17566
# Total time for Mesh Cleansing: 0.11042070388793945
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994310423304507% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346310958**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 60 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 192360
# Total time for Mesh Cleansing: 9.552672147750854
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9909334432309911% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348117070**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 28848
# Total time for Mesh Cleansing: 0.17029523849487305
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997227612974772% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348119782**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 17094
# Total time for Mesh Cleansing: 0.49182796478271484
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9932597327135386% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348191367**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 84370
# Total time for Mesh Cleansing: 0.22938871383666992
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993130241152225% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348209332**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 65424
# Total time for Mesh Cleansing: 2.292165994644165
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984738416458092% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349373749**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 25180
# Total time for Mesh Cleansing: 1.190603256225586
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9968329374505146% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349378034**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 52 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 350724
# Total time for Mesh Cleansing: 0.8153085708618164
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991965949300012% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349470217**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 68 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 440306
# Total time for Mesh Cleansing: 11.248914241790771
# Number of outside child meshes =  2
# Main mesh and outside child meshes make up 0.9991203603428385% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349470217_30_main_and_child_meshes_array.npz
#  face length 440306 using optimized facets with 3 neighbors
# Filtering edges by size finished: 10.751948595046997, facet # = 22097
# Filtering by convexity and getting centers took: 15.131365776062012, facet # = 5074
# Finished 5074 facets for main mesh: 26.814258098602295
# Filtering edges by size finished: 0.587367057800293, facet # = 1542
# Filtering by convexity and getting centers took: 1.0539941787719727, facet # = 502
# Filtering edges by size finished: 0.0010788440704345703, facet # = 4
# Filtering by convexity and getting centers took: 0.0021822452545166016, facet # = 2
# Total time for facets: 28.47740626335144
# Zero faceted faces = []
# Starting Child 0
# 502 5074
# Done distance matrix: 0.10058093070983887
# Done Generating final pairs: 0.10871529579162598
# best_stitch_pair = [  63 1224]
# best_stitch_pair_size = 70745.69829994778
# best_stitch_pair_distance = 1634.612563982759
# best_stitch_pair_size_ratio = 0.543344765159364
# Starting Child 1
# 2 5074
# Done distance matrix: 0.0009455680847167969
# Child 1 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [63, 1224]}
# ---Stitching child 0 with pair: [63, 1224]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 115969, starting edge 2nd facet= 226236,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.6226043701171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.002553224563598633
# returned from stitch mesh: 0.40382814407348633
# Finished stitching child 0 : 0.4412045478820801
# ***************Finished big stitching iteration: 0.6368768215179443***************
# Starting Child 1
# 2 5574
# Done distance matrix: 0.001262664794921875
# Done Generating final pairs: 0.023099660873413086
# best_stitch_pair = [   0 5174]
# best_stitch_pair_size = 53257.759393805536
# best_stitch_pair_distance = 1080.7406883366093
# best_stitch_pair_size_ratio = 0.9403935247444425
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [0, 5174]}
# ---Stitching child 1 with pair: [0, 5174]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 226076, starting edge 2nd facet= 226607,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0030829906463623047
# returned from stitch mesh: 0.43043971061706543
# Finished stitching child 1 : 0.46658754348754883
# ***************Finished big stitching iteration: 0.9374823570251465***************
# All children have been processed
# total_stitch_processing_time = 1.5750346183776855
# Total time for restitching = 1.5760164260864258
# missed_children = []
# Whole stitching function complete: 43.104671239852905
#
#
#
# *****Running Neuron Stitcher for 648518346349509539**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 53 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 214624
# Total time for Mesh Cleansing: 8.231993198394775
# Number of outside child meshes =  2
# Main mesh and outside child meshes make up 0.9985885805019825% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509539_30_main_and_child_meshes_array.npz
#  face length 214624 using optimized facets with 3 neighbors
# Filtering edges by size finished: 6.189384698867798, facet # = 11381
# Filtering by convexity and getting centers took: 9.695816278457642, facet # = 2388
# Finished 2388 facets for main mesh: 16.318909168243408
# Filtering edges by size finished: 0.006223440170288086, facet # = 11
# Filtering by convexity and getting centers took: 0.0066106319427490234, facet # = 7
# Filtering edges by size finished: 0.020563602447509766, facet # = 25
# Filtering by convexity and getting centers took: 0.025160789489746094, facet # = 12
# Total time for facets: 16.38376235961914
# Zero faceted faces = []
# Starting Child 0
# 7 2388
# Done distance matrix: 0.001232147216796875
# Done Generating final pairs: 0.015474796295166016
# best_stitch_pair = [   0 1249]
# best_stitch_pair_size = 27612.485014129394
# best_stitch_pair_distance = 1170.2276534911355
# best_stitch_pair_size_ratio = 0.6257033121981685
# Starting Child 1
# 12 2388
# Done distance matrix: 0.0020873546600341797
# Done Generating final pairs: 0.030164003372192383
# best_stitch_pair = [   4 1284]
# best_stitch_pair_size = 26042.445124884478
# best_stitch_pair_distance = 1615.2952186835932
# best_stitch_pair_size_ratio = 0.4864599226020947
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 1249], 1: [4, 1284]}
# ---Stitching child 0 with pair: [0, 1249]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 72686, starting edge 2nd facet= 107746,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.2172927856445312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0030412673950195312
# returned from stitch mesh: 0.4256007671356201
# Finished stitching child 0 : 0.4510800838470459
# ---Stitching child 1 with pair: [4, 1284]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 102723, starting edge 2nd facet= 107947,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0031723976135253906
# returned from stitch mesh: 0.21857023239135742
# Finished stitching child 1 : 0.23755216598510742
# ***************Finished big stitching iteration: 0.9108419418334961***************
# All children have been processed
# total_stitch_processing_time = 0.9113352298736572
# Total time for restitching = 0.912280797958374
# missed_children = []
# Whole stitching function complete: 26.181220769882202
#
#
#
# *****Running Neuron Stitcher for 648518346341359611**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 52584
# Total time for Mesh Cleansing: 0.4126558303833008
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996958174904943% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341361714**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 86 pieces after mesh split
# There were 16 pieces found after size threshold
# max_index = 0
# max_face_len = 87514
# Total time for Mesh Cleansing: 10.356528043746948
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9812746681019017% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362771**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 78396
# Total time for Mesh Cleansing: 0.2959892749786377
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995664924136173% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362995**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 204 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 1008241
# Total time for Mesh Cleansing: 52.011468172073364
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989101800085403% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410186**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 133352
# Total time for Mesh Cleansing: 0.4902973175048828
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992656425627576% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341412995**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 54196
# Total time for Mesh Cleansing: 0.2902069091796875
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996311052087945% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341414026**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 18594
# Total time for Mesh Cleansing: 0.16257596015930176
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992476354256233% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341416332**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 82386
# Total time for Mesh Cleansing: 0.2004072666168213
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.99922377198302% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341418253**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 34228
# Total time for Mesh Cleansing: 0.7476963996887207
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9948264837528338% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342792029**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 87 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 480332
# Total time for Mesh Cleansing: 15.953073501586914
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9988396514795483% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342917593**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 34 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 156578
# Total time for Mesh Cleansing: 5.664143800735474
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9978095428828919% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346342917593_30_main_and_child_meshes_array.npz
#  face length 156578 using optimized facets with 3 neighbors
# Filtering edges by size finished: 4.842047214508057, facet # = 8021
# Filtering by convexity and getting centers took: 6.926087379455566, facet # = 1629
# Finished 1629 facets for main mesh: 11.956328868865967
# Filtering edges by size finished: 0.2599458694458008, facet # = 337
# Filtering by convexity and getting centers took: 0.27852916717529297, facet # = 135
# Total time for facets: 12.503222942352295
# Zero faceted faces = []
# Starting Child 0
# 135 1629
# Done distance matrix: 0.028872013092041016
# Done Generating final pairs: 0.0818023681640625
# best_stitch_pair = [  87 1294]
# best_stitch_pair_size = 109711.54712327238
# best_stitch_pair_distance = 1790.7784197030571
# best_stitch_pair_size_ratio = 0.6273494505517574
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [87, 1294]}
# ---Stitching child 0 with pair: [87, 1294]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 50216, starting edge 2nd facet= 79655,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003514528274536133
# returned from stitch mesh: 0.22313237190246582
# Finished stitching child 0 : 0.2611963748931885
# ***************Finished big stitching iteration: 0.4465789794921875***************
# All children have been processed
# total_stitch_processing_time = 0.45189476013183594
# Total time for restitching = 0.4528534412384033
# missed_children = []
# Whole stitching function complete: 19.22817850112915
#
#
#
# *****Running Neuron Stitcher for 648518346341352891**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 169 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 122634
# Total time for Mesh Cleansing: 7.818241596221924
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9849730285127152% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341352891_30_main_and_child_meshes_array.npz
#  face length 122634 using optimized facets with 3 neighbors
# Filtering edges by size finished: 4.672421216964722, facet # = 6829
# Filtering by convexity and getting centers took: 4.244190454483032, facet # = 1174
# Finished 1174 facets for main mesh: 9.217152833938599
# Filtering edges by size finished: 0.0014586448669433594, facet # = 8
# Filtering by convexity and getting centers took: 0.0036203861236572266, facet # = 8
# Total time for facets: 9.224874019622803
# Zero faceted faces = []
# Starting Child 0
# 8 1174
# Done distance matrix: 0.0008656978607177734
# Done Generating final pairs: 0.01854252815246582
# best_stitch_pair = [ 0 87]
# best_stitch_pair_size = 96644.21192175646
# best_stitch_pair_distance = 1006.8822113941885
# best_stitch_pair_size_ratio = 0.49298656544324837
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 87]}
# ---Stitching child 0 with pair: [0, 87]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 50863, starting edge 2nd facet= 61394,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.33514404296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.000978231430053711
# returned from stitch mesh: 0.12415909767150879
# Finished stitching child 0 : 0.1304326057434082
# ***************Finished big stitching iteration: 0.16429877281188965***************
# All children have been processed
# total_stitch_processing_time = 0.1643989086151123
# Total time for restitching = 0.16472864151000977
# missed_children = []
# Whole stitching function complete: 17.73672389984131
#
#
#
# *****Running Neuron Stitcher for 648518346341360400**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 55 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 202118
# Total time for Mesh Cleansing: 9.353309631347656
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982023093410772% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341366450**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 23 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 136118
# Total time for Mesh Cleansing: 0.50962233543396
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992365403532469% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341367133**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 252960
# Total time for Mesh Cleansing: 0.9261729717254639
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999541639665555% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341369156**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 32 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 107756
# Total time for Mesh Cleansing: 0.4299194812774658
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981843782421818% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341369610**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 38864
# Total time for Mesh Cleansing: 0.2942323684692383
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992800575953924% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341370001**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 31030
# Total time for Mesh Cleansing: 1.6259307861328125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9976850363320687% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341371141**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 131558
# Total time for Mesh Cleansing: 0.6077275276184082
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992859964147905% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341372248**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 123 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 713853
# Total time for Mesh Cleansing: 23.411696434020996
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982436243985182% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341384400**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 34574
# Total time for Mesh Cleansing: 0.17599844932556152
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9974036464343411% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341384946**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 90948
# Total time for Mesh Cleansing: 0.5115904808044434
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990991980665714% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341386109**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 78 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 379430
# Total time for Mesh Cleansing: 11.011327028274536
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989205981465881% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341398089**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 13 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 73374
# Total time for Mesh Cleansing: 0.30864953994750977
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991013071895425% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341398705**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 35 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 252548
# Total time for Mesh Cleansing: 7.954588174819946
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993194048749604% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399912**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 23 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 173254
# Total time for Mesh Cleansing: 0.5441572666168213
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999434676265633% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341401061**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 43898
# Total time for Mesh Cleansing: 0.25861215591430664
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 1.0% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341401733**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 113116
# Total time for Mesh Cleansing: 3.4571194648742676
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9969856687056003% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341402272**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 933 pieces after mesh split
# There were 262 pieces found after size threshold
# max_index = 0
# max_face_len = 985671
# Total time for Mesh Cleansing: 556.6628251075745
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9771463750242881% of original mesh
# 1057.1348814964294

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
