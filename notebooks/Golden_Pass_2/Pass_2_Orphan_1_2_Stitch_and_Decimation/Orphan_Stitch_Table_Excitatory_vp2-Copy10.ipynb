# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341406928**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 30 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 210360
# Total time for Mesh Cleansing: 4.729475736618042
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991877680721604% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341409551**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 16 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 241960
# Total time for Mesh Cleansing: 4.924398183822632
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993804469042997% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341416360**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 111632
# Total time for Mesh Cleansing: 0.2652730941772461
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995881015061158% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341418926**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 8 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 71456
# Total time for Mesh Cleansing: 2.055180549621582
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9977379988271105% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341420204**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 84014
# Total time for Mesh Cleansing: 0.32901597023010254
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990486836159536% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342790258**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 134 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 1
# max_face_len = 394328
# Total time for Mesh Cleansing: 8.179850816726685
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9981575328271887% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346342790258_30_main_and_child_meshes_array.npz
#  face length 394328 using optimized facets with 3 neighbors
# Filtering edges by size finished: 7.421472549438477, facet # = 21098
# Filtering by convexity and getting centers took: 11.45156717300415, facet # = 4179
# Finished 4179 facets for main mesh: 19.29542326927185
# Filtering edges by size finished: 2.623527765274048, facet # = 6641
# Filtering by convexity and getting centers took: 3.4953272342681885, facet # = 1529
# Total time for facets: 25.61016082763672
# Zero faceted faces = []
# Starting Child 0
# 1529 4179
# Done distance matrix: 0.2715275287628174
# Done Generating final pairs: 0.294170618057251
# best_stitch_pair = [ 397 2703]
# best_stitch_pair_size = 118503.79523296459
# best_stitch_pair_distance = 1810.1790650798725
# best_stitch_pair_size_ratio = 0.6108670508473932
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [397, 2703]}
# ---Stitching child 0 with pair: [397, 2703]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 67176, starting edge 2nd facet= 259398,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00765681266784668
# returned from stitch mesh: 0.3552863597869873
# Finished stitching child 0 : 0.41678285598754883
# ***************Finished big stitching iteration: 0.7851505279541016***************
# All children have been processed
# total_stitch_processing_time = 0.7852914333343506
# Total time for restitching = 0.7894678115844727
# missed_children = []
# Whole stitching function complete: 35.79018020629883
#
#
#
# *****Running Neuron Stitcher for 648518346342807807**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 115 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 486704
# Total time for Mesh Cleansing: 11.033093452453613
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983958513680393% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344416888**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 79634
# Total time for Mesh Cleansing: 0.3838677406311035
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989713482864168% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344419601**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 51 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 204360
# Total time for Mesh Cleansing: 0.7766640186309814
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9985243963217403% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344461704**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 86990
# Total time for Mesh Cleansing: 0.25156283378601074
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997012043762067% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344462185**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 31 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 116214
# Total time for Mesh Cleansing: 3.9181954860687256
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9980762294096429% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344499416**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 24 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 162622
# Total time for Mesh Cleansing: 0.3637278079986572
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993731717509402% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344501022**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 159 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 435836
# Total time for Mesh Cleansing: 19.537647247314453
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9963241009134883% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348199740**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 10 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 100802
# Total time for Mesh Cleansing: 0.4450681209564209
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9996429917293084% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348210263**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 2 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 18668
# Total time for Mesh Cleansing: 0.14007806777954102
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995716427500535% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348458383**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 43350
# Total time for Mesh Cleansing: 0.18705296516418457
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995388517408347% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348466740**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 33896
# Total time for Mesh Cleansing: 0.1708540916442871
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992335357585048% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349369491**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 184588
# Total time for Mesh Cleansing: 0.6147229671478271
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.99962092083744% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349377627**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 34 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 169050
# Total time for Mesh Cleansing: 0.529778242111206
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990662380029313% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349378789**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 13912
# Total time for Mesh Cleansing: 0.10286426544189453
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994252873563219% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349380492**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 57 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 331722
# Total time for Mesh Cleansing: 9.745919942855835
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989640613612957% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349483683**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 20 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 125638
# Total time for Mesh Cleansing: 0.6801471710205078
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991888022904406% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349492682**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1874 pieces after mesh split
# There were 228 pieces found after size threshold
# max_index = 1
# max_face_len = 710801
# Total time for Mesh Cleansing: 147.60351061820984
# Number of outside child meshes =  85
# Main mesh and outside child meshes make up 0.9831255300130641% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349492682_30_main_and_child_meshes_array.npz
#  face length 710801 using optimized facets with 3 neighbors
# Filtering edges by size finished: 23.608033657073975, facet # = 34471
# Filtering by convexity and getting centers took: 23.388222455978394, facet # = 7725
# Finished 7725 facets for main mesh: 48.25842595100403
# Filtering edges by size finished: 3.9171905517578125, facet # = 6678
# Filtering by convexity and getting centers took: 5.1486828327178955, facet # = 1909
# Filtering edges by size finished: 2.838580369949341, facet # = 6671
# Filtering by convexity and getting centers took: 4.6849305629730225, facet # = 1384
# Filtering edges by size finished: 8.127784490585327, facet # = 13015
# Filtering by convexity and getting centers took: 10.94346833229065, facet # = 3039
# Filtering edges by size finished: 1.4345316886901855, facet # = 6028
# Filtering by convexity and getting centers took: 2.447580575942993, facet # = 1150
# Filtering edges by size finished: 3.1242051124572754, facet # = 8219
# Filtering by convexity and getting centers took: 5.148321866989136, facet # = 1336
# Filtering edges by size finished: 2.3990461826324463, facet # = 5010
# Filtering by convexity and getting centers took: 3.4207754135131836, facet # = 1233
# Filtering edges by size finished: 0.019826650619506836, facet # = 47
# Filtering by convexity and getting centers took: 0.014448881149291992, facet # = 9
# Filtering edges by size finished: 0.06326699256896973, facet # = 373
# Filtering by convexity and getting centers took: 0.3792266845703125, facet # = 108
# Filtering edges by size finished: 2.8821158409118652, facet # = 4752
# Filtering by convexity and getting centers took: 2.7432968616485596, facet # = 822
# Filtering edges by size finished: 0.11105155944824219, facet # = 45
# Filtering by convexity and getting centers took: 0.03718757629394531, facet # = 38
# Filtering edges by size finished: 3.011195182800293, facet # = 5522
# Filtering by convexity and getting centers took: 4.730046510696411, facet # = 1195
# Filtering edges by size finished: 1.2217037677764893, facet # = 2322
# Filtering by convexity and getting centers took: 1.412062644958496, facet # = 345
# Filtering edges by size finished: 0.8115205764770508, facet # = 1929
# Filtering by convexity and getting centers took: 1.2558894157409668, facet # = 549
# Filtering edges by size finished: 1.0670666694641113, facet # = 1166
# Filtering by convexity and getting centers took: 0.9655451774597168, facet # = 339
# Filtering edges by size finished: 0.10108470916748047, facet # = 139
# Filtering by convexity and getting centers took: 0.18903541564941406, facet # = 32
# Filtering edges by size finished: 0.8450741767883301, facet # = 1084
# Filtering by convexity and getting centers took: 0.4730076789855957, facet # = 199
# Filtering edges by size finished: 0.02065873146057129, facet # = 29
# Filtering by convexity and getting centers took: 0.013889551162719727, facet # = 29
# Filtering edges by size finished: 0.0008571147918701172, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.001138448715209961, facet # = 1
# Filtering edges by size finished: 0.5031788349151611, facet # = 662
# Filtering by convexity and getting centers took: 0.3350718021392822, facet # = 116
# Filtering edges by size finished: 0.0036933422088623047, facet # = 29
# Filtering by convexity and getting centers took: 0.008705854415893555, facet # = 8
# Filtering edges by size finished: 0.0069730281829833984, facet # = 22
# Filtering by convexity and getting centers took: 0.011936664581298828, facet # = 16
# Filtering edges by size finished: 0.023103952407836914, facet # = 46
# Filtering by convexity and getting centers took: 0.023429393768310547, facet # = 18
# Filtering edges by size finished: 1.0666191577911377, facet # = 1714
# Filtering by convexity and getting centers took: 1.3882725238800049, facet # = 239
# Filtering edges by size finished: 1.1403799057006836, facet # = 1610
# Filtering by convexity and getting centers took: 1.250779390335083, facet # = 354
# Filtering edges by size finished: 0.0056819915771484375, facet # = 28
# Filtering by convexity and getting centers took: 0.011785507202148438, facet # = 5
# Filtering edges by size finished: 0.0040607452392578125, facet # = 8
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.004868984222412109, facet # = 7
# Filtering edges by size finished: 0.17496418952941895, facet # = 227
# Filtering by convexity and getting centers took: 0.2539553642272949, facet # = 62
# Filtering edges by size finished: 0.08767247200012207, facet # = 265
# Filtering by convexity and getting centers took: 0.20699548721313477, facet # = 73
# Filtering edges by size finished: 0.005130767822265625, facet # = 10
# Filtering by convexity and getting centers took: 0.005340099334716797, facet # = 7
# Filtering edges by size finished: 0.0012927055358886719, facet # = 5
# Filtering by convexity and getting centers took: 0.002934694290161133, facet # = 5
# Filtering edges by size finished: 0.002101898193359375, facet # = 7
# Filtering by convexity and getting centers took: 0.0032205581665039062, facet # = 7
# Filtering edges by size finished: 0.43291711807250977, facet # = 955
# Filtering by convexity and getting centers took: 0.7959306240081787, facet # = 87
# Filtering edges by size finished: 0.022741317749023438, facet # = 90
# Filtering by convexity and getting centers took: 0.058158159255981445, facet # = 22
# Filtering edges by size finished: 0.01334691047668457, facet # = 20
# Filtering by convexity and getting centers took: 0.007005214691162109, facet # = 4
# Filtering edges by size finished: 0.5413339138031006, facet # = 989
# Filtering by convexity and getting centers took: 0.7638611793518066, facet # = 105
# Filtering edges by size finished: 0.6339857578277588, facet # = 1420
# Filtering by convexity and getting centers took: 0.8313314914703369, facet # = 281
# Filtering edges by size finished: 0.0041272640228271484, facet # = 8
# Filtering by convexity and getting centers took: 0.0047760009765625, facet # = 6
# Filtering edges by size finished: 0.05864429473876953, facet # = 170
# Filtering by convexity and getting centers took: 0.18240022659301758, facet # = 45
# Filtering edges by size finished: 0.043224334716796875, facet # = 75
# Filtering by convexity and getting centers took: 0.06062030792236328, facet # = 21
# Filtering edges by size finished: 0.0017037391662597656, facet # = 7
# Filtering by convexity and getting centers took: 0.0040438175201416016, facet # = 6
# Filtering edges by size finished: 0.023378849029541016, facet # = 75
# Filtering by convexity and getting centers took: 0.09772086143493652, facet # = 33
# Filtering edges by size finished: 0.01787853240966797, facet # = 32
# Filtering by convexity and getting centers took: 0.03007054328918457, facet # = 18
# Filtering edges by size finished: 0.0648796558380127, facet # = 133
# Filtering by convexity and getting centers took: 0.06670880317687988, facet # = 57
# Filtering edges by size finished: 0.055748939514160156, facet # = 119
# Filtering by convexity and getting centers took: 0.03429269790649414, facet # = 17
# Filtering edges by size finished: 0.48108983039855957, facet # = 897
# Filtering by convexity and getting centers took: 0.4939894676208496, facet # = 139
# Filtering edges by size finished: 0.0852670669555664, facet # = 49
# Filtering by convexity and getting centers took: 0.20649099349975586, facet # = 36
# Filtering edges by size finished: 0.018522024154663086, facet # = 32
# Filtering by convexity and getting centers took: 0.06235551834106445, facet # = 9
# Filtering edges by size finished: 0.022243738174438477, facet # = 40
# Filtering by convexity and getting centers took: 0.027544260025024414, facet # = 14
# Filtering edges by size finished: 0.0018761157989501953, facet # = 7
# Filtering by convexity and getting centers took: 0.0038483142852783203, facet # = 5
# Filtering edges by size finished: 0.0020155906677246094, facet # = 8
# Filtering by convexity and getting centers took: 0.011420249938964844, facet # = 5
# Filtering edges by size finished: 0.03317713737487793, facet # = 25
# Filtering by convexity and getting centers took: 0.030308961868286133, facet # = 3
# Filtering edges by size finished: 0.003894805908203125, facet # = 7
# Filtering by convexity and getting centers took: 0.011113643646240234, facet # = 6
# Filtering edges by size finished: 0.002779722213745117, facet # = 7
# Filtering by convexity and getting centers took: 0.005488157272338867, facet # = 7
# Filtering edges by size finished: 0.029996633529663086, facet # = 66
# Filtering by convexity and getting centers took: 0.05342745780944824, facet # = 22
# Filtering edges by size finished: 0.011253595352172852, facet # = 22
# Filtering by convexity and getting centers took: 0.01031041145324707, facet # = 7
# Filtering edges by size finished: 0.46182870864868164, facet # = 856
# Filtering by convexity and getting centers took: 0.8403511047363281, facet # = 242
# Filtering edges by size finished: 0.003529787063598633, facet # = 14
# Filtering by convexity and getting centers took: 0.007352590560913086, facet # = 5
# Filtering edges by size finished: 0.0024242401123046875, facet # = 6
# Filtering by convexity and getting centers took: 0.005082845687866211, facet # = 4
# Filtering edges by size finished: 0.0049817562103271484, facet # = 5
# Filtering by convexity and getting centers took: 0.0033648014068603516, facet # = 2
# Filtering edges by size finished: 0.07645106315612793, facet # = 168
# Filtering by convexity and getting centers took: 0.08648467063903809, facet # = 78
# Filtering edges by size finished: 0.3365206718444824, facet # = 875
# Filtering by convexity and getting centers took: 0.6670429706573486, facet # = 104
# Filtering edges by size finished: 0.03621029853820801, facet # = 26
# Filtering by convexity and getting centers took: 0.019388198852539062, facet # = 24
# Filtering edges by size finished: 0.002657651901245117, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0023522377014160156, facet # = 2
# Filtering edges by size finished: 0.0009462833404541016, facet # = 4
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0032303333282470703, facet # = 4
# Filtering edges by size finished: 0.07433462142944336, facet # = 89
# Filtering by convexity and getting centers took: 0.05001020431518555, facet # = 36
# Filtering edges by size finished: 0.007818460464477539, facet # = 39
# Filtering by convexity and getting centers took: 0.027301549911499023, facet # = 13
# Filtering edges by size finished: 0.03679776191711426, facet # = 22
# Filtering by convexity and getting centers took: 0.03730177879333496, facet # = 8
# Filtering edges by size finished: 0.08253335952758789, facet # = 47
# Filtering by convexity and getting centers took: 0.07367348670959473, facet # = 11
# Filtering edges by size finished: 0.054937124252319336, facet # = 29
# Filtering by convexity and getting centers took: 0.06274938583374023, facet # = 12
# Filtering edges by size finished: 0.006875753402709961, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.007155895233154297, facet # = 2
# Filtering edges by size finished: 0.003928184509277344, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.005212545394897461, facet # = 2
# Filtering edges by size finished: 0.003487825393676758, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0032913684844970703, facet # = 2
# Filtering edges by size finished: 0.016820192337036133, facet # = 21
# Filtering by convexity and getting centers took: 0.01733088493347168, facet # = 19
# Filtering edges by size finished: 0.003958702087402344, facet # = 12
# Filtering by convexity and getting centers took: 0.006888151168823242, facet # = 3
# Filtering edges by size finished: 0.0017604827880859375, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0018877983093261719, facet # = 2
# Filtering edges by size finished: 0.003416299819946289, facet # = 4
# Filtering by convexity and getting centers took: 0.0032835006713867188, facet # = 1
# Filtering edges by size finished: 0.009277820587158203, facet # = 33
# Filtering by convexity and getting centers took: 0.0167083740234375, facet # = 7
# Filtering edges by size finished: 0.015496253967285156, facet # = 72
# Filtering by convexity and getting centers took: 0.13826704025268555, facet # = 27
# Filtering edges by size finished: 0.024631738662719727, facet # = 52
# Filtering by convexity and getting centers took: 0.04236316680908203, facet # = 8
# Filtering edges by size finished: 0.005545616149902344, facet # = 18
# Filtering by convexity and getting centers took: 0.008427143096923828, facet # = 5
# Filtering edges by size finished: 0.017635583877563477, facet # = 34
# Filtering by convexity and getting centers took: 0.024270296096801758, facet # = 12
# Filtering edges by size finished: 0.004570960998535156, facet # = 5
# Filtering by convexity and getting centers took: 0.0035529136657714844, facet # = 1
# Filtering edges by size finished: 0.0029642581939697266, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.010688543319702148, facet # = 2
# Filtering edges by size finished: 0.006269693374633789, facet # = 26
# Filtering by convexity and getting centers took: 0.06788110733032227, facet # = 4
# Filtering edges by size finished: 0.009296894073486328, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.013569116592407227, facet # = 2
# Total time for facets: 143.49717545509338
# Zero faceted faces = []
# Starting Child 0
# returning z greater max
# skipped by bounding box filter
# Starting Child 1
# 1384 7725
# Done distance matrix: 0.9585971832275391
# Done Generating final pairs: 1.0180132389068604
# best_stitch_pair = [1036 6389]
# best_stitch_pair_size = 1350741.412385528
# best_stitch_pair_distance = 968.853367363781
# best_stitch_pair_size_ratio = 0.4493450526933117
# Starting Child 2
# 3039 7725
# Done distance matrix: 1.8313648700714111
# Done Generating final pairs: 1.8901910781860352
# best_stitch_pair = [2319 5750]
# best_stitch_pair_size = 2865700.427316786
# best_stitch_pair_distance = 1369.1330602839078
# best_stitch_pair_size_ratio = 0.9758526575049651
# Starting Child 3
# 1150 7725
# Done distance matrix: 0.5544564723968506
# Done Generating final pairs: 0.7013359069824219
# best_stitch_pair = [ 596 1527]
# best_stitch_pair_size = 1137951.1918804038
# best_stitch_pair_distance = 143.3827052422153
# best_stitch_pair_size_ratio = 0.7529729684279329
# Starting Child 4
# returning z greater max
# skipped by bounding box filter
# Starting Child 5
# 1233 7725
# Done distance matrix: 0.6489694118499756
# Child 5 There were no points close enough
# Starting Child 6
# returning y less min
# skipped by bounding box filter
# Starting Child 7
# returning y less min
# skipped by bounding box filter
# Starting Child 8
# 822 7725
# Done distance matrix: 0.6587870121002197
# Child 8 There were no points close enough
# Starting Child 9
# 38 7725
# Done distance matrix: 0.014650821685791016
# Child 9 There were no points close enough
# Starting Child 10
# returning z greater max
# skipped by bounding box filter
# Starting Child 11
# returning y less min
# skipped by bounding box filter
# Starting Child 12
# 549 7725
# Done distance matrix: 0.3167083263397217
# Child 12 There were no points close enough
# Starting Child 13
# 339 7725
# Done distance matrix: 0.21688628196716309
# Done Generating final pairs: 2.2805888652801514
# best_stitch_pair = [   0 1202]
# best_stitch_pair_size = 58516287.38574508
# best_stitch_pair_distance = 1740.1756877562254
# best_stitch_pair_size_ratio = 0.5738331415463886
# Starting Child 14
# returning z greater max
# skipped by bounding box filter
# Starting Child 15
# returning z greater max
# skipped by bounding box filter
# Starting Child 16
# returning z greater max
# skipped by bounding box filter
# Starting Child 17
# returning y less min
# skipped by bounding box filter
# Starting Child 18
# 116 7725
# Done distance matrix: 0.0714714527130127
# Child 18 There were no points close enough
# Starting Child 19
# 8 7725
# Done distance matrix: 0.0031023025512695312
# Done Generating final pairs: 0.0300753116607666
# best_stitch_pair = [   4 6962]
# best_stitch_pair_size = 79986.00606424994
# best_stitch_pair_distance = 1605.2522430336953
# best_stitch_pair_size_ratio = 0.2476010605926527
# Starting Child 20
# 16 7725
# Done distance matrix: 0.005906581878662109
# Done Generating final pairs: 0.02735590934753418
# best_stitch_pair = [   9 3290]
# best_stitch_pair_size = 144236.23182018183
# best_stitch_pair_distance = 1420.1730895856952
# best_stitch_pair_size_ratio = 0.5152583849202444
# Starting Child 21
# returning y less min
# skipped by bounding box filter
# Starting Child 22
# 239 7725
# Done distance matrix: 0.22309398651123047
# Done Generating final pairs: 0.7172741889953613
# best_stitch_pair = [  16 3861]
# best_stitch_pair_size = 13933944.602610793
# best_stitch_pair_distance = 1478.134465506731
# best_stitch_pair_size_ratio = 0.9868316307512386
# Starting Child 23
# 354 7725
# Done distance matrix: 0.2604963779449463
# Child 23 There were no points close enough
# Starting Child 24
# 5 7725
# Done distance matrix: 0.002087831497192383
# Child 24 There were no points close enough
# Starting Child 25
# 7 7725
# Done distance matrix: 0.003429889678955078
# Child 25 There were no points close enough
# Starting Child 26
# 62 7725
# Done distance matrix: 0.021908044815063477
# Child 26 There were no points close enough
# Starting Child 27
# 73 7725
# Done distance matrix: 0.03485751152038574
# Child 27 There were no points close enough
# Starting Child 28
# returning y less min
# skipped by bounding box filter
# Starting Child 29
# returning y less min
# skipped by bounding box filter
# Starting Child 30
# returning y less min
# skipped by bounding box filter
# Starting Child 31
# returning y less min
# skipped by bounding box filter
# Starting Child 32
# returning y less min
# skipped by bounding box filter
# Starting Child 33
# returning y less min
# skipped by bounding box filter
# Starting Child 34
# 105 7725
# Done distance matrix: 0.08854389190673828
# Done Generating final pairs: 0.1285393238067627
# best_stitch_pair = [  13 2340]
# best_stitch_pair_size = 48800.473965467805
# best_stitch_pair_distance = 1631.4957929760044
# best_stitch_pair_size_ratio = 0.9498910733033709
# Starting Child 35
# 281 7725
# Done distance matrix: 0.2501211166381836
# Child 35 There were no points close enough
# Starting Child 36
# returning x greater max
# skipped by bounding box filter
# Starting Child 37
# 45 7725
# Done distance matrix: 0.03552865982055664
# Child 37 There were no points close enough
# Starting Child 38
# returning z greater max
# skipped by bounding box filter
# Starting Child 39
# returning z greater max
# skipped by bounding box filter
# Starting Child 40
# 33 7725
# Done distance matrix: 0.011584997177124023
# Done Generating final pairs: 0.029646873474121094
# best_stitch_pair = [  17 5909]
# best_stitch_pair_size = 28734.679688984324
# best_stitch_pair_distance = 1489.6255432557914
# best_stitch_pair_size_ratio = 0.46237143086296745
# Starting Child 41
# 18 7725
# Done distance matrix: 0.004904985427856445
# Done Generating final pairs: 0.010182857513427734
# best_stitch_pair = [  12 1213]
# best_stitch_pair_size = 12419.791523096103
# best_stitch_pair_distance = 1884.7939726927675
# best_stitch_pair_size_ratio = 0.9785744417048706
# Starting Child 42
# returning y less min
# skipped by bounding box filter
# Starting Child 43
# 17 7725
# Done distance matrix: 0.0045926570892333984
# Child 43 There were no points close enough
# Starting Child 44
# 139 7725
# Done distance matrix: 0.034696102142333984
# Done Generating final pairs: 0.0610661506652832
# best_stitch_pair = [   2 4173]
# best_stitch_pair_size = 3192296.509882763
# best_stitch_pair_distance = 1067.3086331820762
# best_stitch_pair_size_ratio = 0.6007152787626288
# Starting Child 45
# returning y less min
# skipped by bounding box filter
# Starting Child 46
# 9 7725
# Done distance matrix: 0.0026688575744628906
# Child 46 There were no points close enough
# Starting Child 47
# returning z greater max
# skipped by bounding box filter
# Starting Child 48
# 5 7725
# Done distance matrix: 0.0014810562133789062
# Child 48 There were no points close enough
# Starting Child 49
# 5 7725
# Done distance matrix: 0.0013511180877685547
# Child 49 There were no points close enough
# Starting Child 50
# 3 7725
# Done distance matrix: 0.0008535385131835938
# Child 50 There were no points close enough
# Starting Child 51
# 6 7725
# Done distance matrix: 0.0017032623291015625
# Child 51 There were no points close enough
# Starting Child 52
# 7 7725
# Done distance matrix: 0.0020079612731933594
# Child 52 There were no points close enough
# Starting Child 53
# 22 7725
# Done distance matrix: 0.007993221282958984
# Child 53 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 54
# returning y less min
# skipped by bounding box filter
# Starting Child 55
# returning y less min
# skipped by bounding box filter
# Starting Child 56
# returning y less min
# skipped by bounding box filter
# Starting Child 57
# returning z greater max
# skipped by bounding box filter
# Starting Child 58
# 2 7725
# Done distance matrix: 0.0012269020080566406
# Done Generating final pairs: 0.1000828742980957
# best_stitch_pair = [   1 6941]
# best_stitch_pair_size = 208858.57683651673
# best_stitch_pair_distance = 1061.7307606860606
# best_stitch_pair_size_ratio = 0.8552613591231922
# Starting Child 59
# 78 7725
# Done distance matrix: 0.04688715934753418
# Done Generating final pairs: 1.0340681076049805
# best_stitch_pair = [  3 356]
# best_stitch_pair_size = 14385067.205845986
# best_stitch_pair_distance = 1657.302805601014
# best_stitch_pair_size_ratio = 0.28178248147552576
# Starting Child 60
# 104 7725
# Done distance matrix: 0.030125856399536133
# Child 60 There were no points close enough
# Starting Child 61
# returning z greater max
# skipped by bounding box filter
# Starting Child 62
# returning y less min
# skipped by bounding box filter
# Starting Child 63
# returning z greater max
# skipped by bounding box filter
# Starting Child 64
# returning y less min
# skipped by bounding box filter
# Starting Child 65
# returning z greater max
# skipped by bounding box filter
# Starting Child 66
# returning z greater max
# skipped by bounding box filter
# Starting Child 67
# 11 7725
# Done distance matrix: 0.003159046173095703
# Child 67 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 68
# returning z greater max
# skipped by bounding box filter
# Starting Child 69
# 2 7725
# Done distance matrix: 0.0006771087646484375
# Child 69 There were no points close enough
# Starting Child 70
# 2 7725
# Done distance matrix: 0.0008606910705566406
# Child 70 There were no points close enough
# Starting Child 71
# returning y less min
# skipped by bounding box filter
# Starting Child 72
# 19 7725
# Done distance matrix: 0.0055332183837890625
# Done Generating final pairs: 0.019351720809936523
# best_stitch_pair = [   2 5750]
# best_stitch_pair_size = 3165260.2470193654
# best_stitch_pair_distance = 479.1203501814818
# best_stitch_pair_size_ratio = 0.84574166182068
# Starting Child 73
# returning y less min
# skipped by bounding box filter
# Starting Child 74
# 2 7725
# Done distance matrix: 0.0011439323425292969
# Child 74 There were no points close enough
# Starting Child 75
# 1 7725
# Done distance matrix: 0.0006499290466308594
# Child 75 There were no points close enough
# Starting Child 76
# 7 7725
# Done distance matrix: 0.0022385120391845703
# Done Generating final pairs: 0.3289499282836914
# best_stitch_pair = [   1 1588]
# best_stitch_pair_size = 5767036.5706277555
# best_stitch_pair_distance = 1566.4869467110034
# best_stitch_pair_size_ratio = 0.17126652221996394
# Starting Child 77
# 27 7725
# Done distance matrix: 0.010060787200927734
# Done Generating final pairs: 0.05488252639770508
# best_stitch_pair = [   7 3343]
# best_stitch_pair_size = 720391.0199642496
# best_stitch_pair_distance = 1903.6821052490732
# best_stitch_pair_size_ratio = 0.24160071124124408
# Starting Child 78
# returning y less min
# skipped by bounding box filter
# Starting Child 79
# returning y less min
# skipped by bounding box filter
# Starting Child 80
# 12 7725
# Done distance matrix: 0.0074498653411865234
# Child 80 There were no points close enough
# Starting Child 81
# 1 7725
# Done distance matrix: 0.00045990943908691406
# Child 81 There were no points close enough
# Starting Child 82
# 2 7725
# Done distance matrix: 0.0008375644683837891
# Child 82 There were no points close enough
# Starting Child 83
# 4 7725
# Done distance matrix: 0.0016217231750488281
# Child 83 There were no points close enough
# Starting Child 84
# 2 7725
# Done distance matrix: 0.00091552734375
# Child 84 There were no points close enough
# repeat_main_facets = [5750]
# child_mesh_double_indexes = [2, 72]
# min_child = 72, max_ratio = 479.1203501814818
# child_meshes_stitch_facets = {1: [1036, 6389], 3: [596, 1527], 13: [0, 1202], 19: [4, 6962], 20: [9, 3290], 22: [16, 3861], 34: [13, 2340], 40: [17, 5909], 41: [12, 1213], 44: [2, 4173], 58: [1, 6941], 59: [3, 356], 72: [2, 5750], 76: [1, 1588], 77: [7, 3343]}
# ---Stitching child 1 with pair: [1036, 6389]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 136054, starting edge 2nd facet= 371820,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 3.457069396972656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.009617328643798828
# returned from stitch mesh: 0.6042084693908691
# Finished stitching child 1 : 0.6829156875610352
# ---Stitching child 3 with pair: [596, 1527]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 348012, starting edge 2nd facet= 438048,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 28
# Starting Organizing vertices for side 1
# edge_1_order done, len = 23
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 6.747245788574219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.014813423156738281
# returned from stitch mesh: 0.473848819732666
# Finished stitching child 3 : 0.618588924407959
# ---Stitching child 13 with pair: [0, 1202]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 165404, starting edge 2nd facet= 446515,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 138
# Starting Organizing vertices for side 1
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_1_order done, len = 248
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 110
# About to add faces
# Finished adding faces: 0.0002696514129638672
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012909889221191406
# returned from stitch mesh: 1.3999392986297607
# Finished stitching child 13 : 1.4839427471160889
# ---Stitching child 19 with pair: [4, 6962]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 309448, starting edge 2nd facet= 450147,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01481771469116211
# returned from stitch mesh: 0.5584578514099121
# Finished stitching child 19 : 0.625187873840332
# ---Stitching child 20 with pair: [9, 3290]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 117768, starting edge 2nd facet= 450276,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.574920654296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.014333963394165039
# returned from stitch mesh: 0.9437658786773682
# Finished stitching child 20 : 1.0391390323638916
# ---Stitching child 22 with pair: [16, 3861]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 301914, starting edge 2nd facet= 456445,
# Starting Organizing vertices for side 0
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_0_order done, len = 81
# Starting Organizing vertices for side 1
# edge_1_order done, len = 60
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 21
# About to add faces
# Finished adding faces: 0.00019431114196777344
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.042099952697753906
# returned from stitch mesh: 1.4194979667663574
# Finished stitching child 22 : 1.6144468784332275
# ---Stitching child 34 with pair: [13, 2340]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 241086, starting edge 2nd facet= 461564,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.2649765014648438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02749180793762207
# returned from stitch mesh: 1.1154394149780273
# Finished stitching child 34 : 1.3274040222167969
# ---Stitching child 40 with pair: [17, 5909]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 174825, starting edge 2nd facet= 462870,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01509857177734375
# returned from stitch mesh: 0.806302547454834
# Finished stitching child 40 : 0.943528413772583
# ---Stitching child 41 with pair: [12, 1213]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 349175, starting edge 2nd facet= 463236,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027853012084960938
# returned from stitch mesh: 0.906651496887207
# Finished stitching child 41 : 1.006636381149292
# ---Stitching child 44 with pair: [2, 4173]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 228139, starting edge 2nd facet= 463775,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 37
# Starting Organizing vertices for side 1
# edge_1_order done, len = 27
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 4.696846008300781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013898134231567383
# returned from stitch mesh: 0.776503324508667
# Finished stitching child 44 : 0.9042954444885254
# ---Stitching child 58 with pair: [1, 6941]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 141694, starting edge 2nd facet= 466719,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.0279159545898438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01138448715209961
# returned from stitch mesh: 1.1032483577728271
# Finished stitching child 58 : 1.178396224975586
# ---Stitching child 59 with pair: [3, 356]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 127148, starting edge 2nd facet= 467391,
# Starting Organizing vertices for side 0
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_0_order done, len = 98
# Starting Organizing vertices for side 1
# edge_1_order done, len = 82
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 16
# About to add faces
# Finished adding faces: 0.00014638900756835938
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013202428817749023
# returned from stitch mesh: 0.8243114948272705
# Finished stitching child 59 : 0.9247734546661377
# ---Stitching child 72 with pair: [2, 5750]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 238600, starting edge 2nd facet= 467600,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 31
# Starting Organizing vertices for side 1
# edge_1_order done, len = 32
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 7.772445678710938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01181483268737793
# returned from stitch mesh: 1.0371057987213135
# Finished stitching child 72 : 1.3422095775604248
# ---Stitching child 76 with pair: [1, 1588]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 220985, starting edge 2nd facet= 467652,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 41
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 7.009506225585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026378154754638672
# returned from stitch mesh: 0.7720324993133545
# Finished stitching child 76 : 0.9190845489501953
# ---Stitching child 77 with pair: [7, 3343]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 285981, starting edge 2nd facet= 467964,
# ...
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 945750, starting edge 2nd facet= 946480,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 3.886222839355469e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012863397598266602
# returned from stitch mesh: 1.598825454711914
# Finished stitching child 14 : 1.9878144264221191
# ***************Finished big stitching iteration: 6.507421493530273***************
# Starting Child 17
# 1 23789
# Done distance matrix: 0.0011701583862304688
# Child 17 There were no points close enough
# Starting Child 57
# 4 23789
# Done distance matrix: 0.005583763122558594
# Done Generating final pairs: 0.007172107696533203
# best_stitch_pair = [    3 23762]
# best_stitch_pair_size = 49967.29839167454
# best_stitch_pair_distance = 426.1726342992787
# best_stitch_pair_size_ratio = 0.3360246955057536
# Starting Child 75
# 1 23789
# Done distance matrix: 0.0014355182647705078
# Child 75 There were no points close enough
# Starting Child 81
# 1 23789
# Done distance matrix: 0.001191854476928711
# Child 81 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {57: [3, 23762]}
# ---Stitching child 57 with pair: [3, 23762]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 946451, starting edge 2nd facet= 946621,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.1696090698242188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03543710708618164
# returned from stitch mesh: 2.045398473739624
# Finished stitching child 57 : 2.3034489154815674
# ***************Finished big stitching iteration: 4.7913806438446045***************
# Starting Child 17
# 1 23791
# Done distance matrix: 0.0016014575958251953
# Child 17 There were no points close enough
# Starting Child 75
# 1 23791
# Done distance matrix: 0.0011441707611083984
# Child 75 There were no points close enough
# Starting Child 81
# 1 23791
# Done distance matrix: 0.001132965087890625
# Child 81 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 17
# 1 23791
# Done distance matrix: 0.0011248588562011719
# Child 17 There were no points close enough
# Starting Child 75
# 1 23791
# Done distance matrix: 0.001050710678100586
# Child 75 There were no points close enough
# Starting Child 81
# 1 23791
# Done distance matrix: 0.0010366439819335938
# Child 81 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 17
# 1 23791
# Done distance matrix: 0.00125885009765625
# Child 17 There were no points close enough
# Starting Child 75
# 1 23791
# Done distance matrix: 0.0011143684387207031
# Child 75 There were no points close enough
# Starting Child 81
# 1 23791
# Done distance matrix: 0.0010459423065185547
# Child 81 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 17
# 1 23791
# Done distance matrix: 0.0011260509490966797
# Child 17 There were no points close enough
# Starting Child 75
# 1 23791
# Done distance matrix: 0.0010273456573486328
# Child 75 There were no points close enough
# Starting Child 81
# 1 23791
# Done distance matrix: 0.0010306835174560547
# Child 81 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 224.14160418510437
# Total time for restitching = 224.15041780471802
# missed_children = [81.0, 17.0, 75.0]
# Whole stitching function complete: 519.5105447769165
#
#
#
# *****Running Neuron Stitcher for 648518346349512609**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 200 pieces after mesh split
# There were 18 pieces found after size threshold
# max_index = 0
# max_face_len = 807534
# Total time for Mesh Cleansing: 39.4068603515625
# Number of outside child meshes =  4
# Main mesh and outside child meshes make up 0.9974801953711534% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349512609_30_main_and_child_meshes_array.npz
#  face length 807534 using optimized facets with 3 neighbors
# Filtering edges by size finished: 21.681183338165283, facet # = 42025
# Filtering by convexity and getting centers took: 29.252037048339844, facet # = 8782
# Finished 8782 facets for main mesh: 52.7658212184906
# Filtering edges by size finished: 0.02891397476196289, facet # = 86
# Filtering by convexity and getting centers took: 0.03718996047973633, facet # = 13
# Filtering edges by size finished: 0.0052356719970703125, facet # = 21
# Filtering by convexity and getting centers took: 0.00848078727722168, facet # = 4
# Filtering edges by size finished: 0.016665935516357422, facet # = 34
# Filtering by convexity and getting centers took: 0.023222684860229492, facet # = 8
# Filtering edges by size finished: 0.01753997802734375, facet # = 37
# Filtering by convexity and getting centers took: 0.02837824821472168, facet # = 10
# Total time for facets: 52.949196338653564
# Zero faceted faces = []
# Starting Child 0
# 13 8782
# Done distance matrix: 0.006655454635620117
# Done Generating final pairs: 0.019598007202148438
# best_stitch_pair = [  12 7049]
# best_stitch_pair_size = 108319.22477588482
# best_stitch_pair_distance = 1649.6930767566053
# best_stitch_pair_size_ratio = 0.8839827856156494
# Starting Child 1
# 4 8782
# Done distance matrix: 0.0024564266204833984
# Done Generating final pairs: 0.023236989974975586
# best_stitch_pair = [   2 7064]
# best_stitch_pair_size = 25232.958819162435
# best_stitch_pair_distance = 1376.4549257094159
# best_stitch_pair_size_ratio = 0.9417944470355935
# Starting Child 2
# 8 8782
# Done distance matrix: 0.013406515121459961
# Done Generating final pairs: 0.03236818313598633
# best_stitch_pair = [   3 7035]
# best_stitch_pair_size = 94764.64134807236
# best_stitch_pair_distance = 1964.1441008332426
# best_stitch_pair_size_ratio = 0.7580940683829374
# Starting Child 3
# 10 8782
# Done distance matrix: 0.005224943161010742
# Done Generating final pairs: 0.03285646438598633
# best_stitch_pair = [   6 7049]
# best_stitch_pair_size = 79606.43202983079
# best_stitch_pair_distance = 1372.1342412362526
# best_stitch_pair_size_ratio = 0.3845847574960948
# repeat_main_facets = [7049]
# child_mesh_double_indexes = [0, 3]
# min_child = 3, max_ratio = 1372.1342412362526
# child_meshes_stitch_facets = {1: [2, 7064], 2: [3, 7035], 3: [6, 7049]}
# ---Stitching child 1 with pair: [2, 7064]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 231656, starting edge 2nd facet= 404941,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.9073486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004570960998535156
# returned from stitch mesh: 0.6981289386749268
# Finished stitching child 1 : 0.8420164585113525
# ---Stitching child 2 with pair: [3, 7035]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 337404, starting edge 2nd facet= 405172,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# Start vertex reached before processed all of edges
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 2.7418136596679688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01058650016784668
# returned from stitch mesh: 0.7441818714141846
# Finished stitching child 2 : 0.9332146644592285
# ---Stitching child 3 with pair: [6, 7049]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 403477, starting edge 2nd facet= 405235,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.4080276489257812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010643243789672852
# returned from stitch mesh: 0.7850911617279053
# Finished stitching child 3 : 1.005098819732666
# ***************Finished big stitching iteration: 3.092801570892334***************
# Starting Child 0
# 13 8798
# Done distance matrix: 0.00627899169921875
# Done Generating final pairs: 0.015811681747436523
# best_stitch_pair = [  12 7008]
# best_stitch_pair_size = 89190.60993654277
# best_stitch_pair_distance = 1346.9611993857955
# best_stitch_pair_size_ratio = 0.7548771258704362
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [12, 7008]}
# ---Stitching child 0 with pair: [12, 7008]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 195232, starting edge 2nd facet= 405784,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.528594970703125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013991594314575195
# returned from stitch mesh: 0.6517360210418701
# Finished stitching child 0 : 0.7247562408447266
# ***************Finished big stitching iteration: 1.5211365222930908***************
# All children have been processed
# total_stitch_processing_time = 4.614546060562134
# Total time for restitching = 4.617332696914673
# missed_children = []
# Whole stitching function complete: 99.3973274230957
#
#
#
# *****Running Neuron Stitcher for 648518346342796842**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 133 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 472678
# Total time for Mesh Cleansing: 19.819292068481445
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9973961410557234% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342803480**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 127 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 485532
# Total time for Mesh Cleansing: 16.395952701568604
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982565072576998% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342927984**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 21 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 107444
# Total time for Mesh Cleansing: 4.941594123840332
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9978083209509658% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343164555**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 46482
# Total time for Mesh Cleansing: 0.20226240158081055
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994409563945987% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343455381**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 9 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 69028
# Total time for Mesh Cleansing: 0.4332602024078369
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993051132086398% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346343784612**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 126 pieces after mesh split
# There were 27 pieces found after size threshold
# max_index = 0
# max_face_len = 85506
# Total time for Mesh Cleansing: 6.999581575393677
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9628186649851365% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344072937**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 14 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 83040
# Total time for Mesh Cleansing: 0.37264275550842285
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991577427505716% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344073173**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 35 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 46168
# Total time for Mesh Cleansing: 1.9643070697784424
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9945713054717794% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344079623**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 51 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 119404
# Total time for Mesh Cleansing: 3.9283676147460938
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9964948591267192% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349493110**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 30088
# Total time for Mesh Cleansing: 0.8496909141540527
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9972820682797481% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349506970**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 101446
# Total time for Mesh Cleansing: 0.3047981262207031
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994679802955665% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349508581**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 167 pieces after mesh split
# There were 14 pieces found after size threshold
# max_index = 0
# max_face_len = 526499
# Total time for Mesh Cleansing: 36.23977327346802
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9929128705514496% of original mesh
# 891.1540670394897

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
