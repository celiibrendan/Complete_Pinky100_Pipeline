# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from meshparty import trimesh_io

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.FilteredSkeleton.describe()
#ta3p100.FilteredSkeletonMinusSoma.describe()
#ta3p100.FilteredSkeletonMinusSoma.drop()

# %%
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#will take in and populate the soma table based on the key it gets
def soma_verts_faces(query_key):
    
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                    & "compartment_type='Soma'").fetch("vertex_indices","triangle_indices")

    if len(vertices_soma) > 0:
        print("Soma found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key & "compartment_type='Soma'").fetch("vertex_indices","triangle_indices")
        if len(vertices_soma) > 0:
            print("Soma found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Soma exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
            
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            filtered_remaining.append(e)
            continue

        #filtered_edges.append(e)

    return np.array(filtered_remaining)

# %%
exhitatory_with_somas = dj.U("segment_id","segmentation") & ((pinky.CompartmentFinal.ComponentFinal() & "compartment_type='Soma'").proj("segment_id"))
#exhitatory_with_somas

# %%
orphans_with_somas = dj.U("segment_id","segmentation") & ((pinky.CompartmentOrphan.ComponentOrphan() & "compartment_type='Soma'").proj("segment_id"))
#orphans_with_somas

# %%
total_soma = ((dj.U("segment_id","segmentation") & ((pinky.CompartmentOrphan.ComponentOrphan() & "compartment_type='Soma'").proj("segment_id")).proj()) + 
(dj.U("segment_id","segmentation") & ((pinky.CompartmentFinal.ComponentFinal() & "compartment_type='Soma'").proj("segment_id"))
.proj()))
    
#total_soma

# %%
#(ta3p100.FilteredSkeleton & total_soma)

# %%
total_neurons_with_somas = exhitatory_with_somas.proj() + orphans_with_somas.proj()
print((len(total_neurons_with_somas),35 +318))
# Out:
# (332, 353)

# %%
@schema
class FilteredSkeletonMinusSoma(dj.Computed):
    definition="""
    -> pinky.FilteredNeuronSkeleton
    ---
    vertices              :longblob #vertex coordinates of soma mesh
    triangles             :longblob #faces for soma mesh
    edges                  :longblob #edges of skeelton after soma edges removed
    n_edges               :int unsigned #number of edges of skeelton after soma edges removed
    soma_bounding_corners :blob #bounding box corners for the soma mesh
    """
    
    key_source = pinky.FilteredNeuronSkeleton & ((dj.U("segment_id","segmentation") & ((pinky.CompartmentOrphan.ComponentOrphan() & "compartment_type='Soma'").proj("segment_id")).proj()) + 
                (dj.U("segment_id","segmentation") & ((pinky.CompartmentFinal.ComponentFinal() & "compartment_type='Soma'").proj("segment_id")).proj()))
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        print()
        print()
        print(str(key["segment_id"])+ ":")
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #pull down the skeleton for the mesh
        skeleton_data = (pinky.FilteredNeuronSkeleton() & key).fetch(as_dict=True)[0]
        
        #get the vertices and triangles for the Soma
        start_time = time.time()
        vertices_whole, triangles_whole = soma_verts_faces(key)
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():
            
            print("No Soma Found")

            #return_key["soma_exist"] = False
            return_key["vertices"] = vertices_whole
            return_key["triangles"] = triangles_whole
            return_key["edges"] = skeleton_data["edges"]
            return_key["n_edges"] = skeleton_data["n_edges"]
            return_key["soma_bounding_corners"] = np.array([])

            self.insert(return_key,skip_duplicates=True)

        #just need to strip the portions of the skeleton that are inside of the mesh

        #find the bounding box
        start_time = time.time()
        mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        min_bb = np.array(mesh.bounding_box.vertices).min(0)
        max_bb = np.array(mesh.bounding_box.vertices).max(0)
        print(f"Step 2: Calculated Bounding Box = {time.time()-start_time}")

        start_time = time.time()
        #get the filtered edges according to bounding box:
        filtered_edges_postsyn = filter_edges_by_bounding_box(skeleton_data["edges"],max_bb,min_bb)

        print(f"Step 3: filtering edges = {time.time()-start_time}")

        

        #write off the new data to the table
        #return_key["soma_exist"] = True
        
        start_time = time.time()
        
        return_key["vertices"] = vertices_whole
        return_key["triangles"] = triangles_whole
        return_key["edges"] = filtered_edges_postsyn
        return_key["n_edges"] = filtered_edges_postsyn.shape[0]
        return_key["soma_bounding_corners"] = np.array((min_bb,max_bb))
        
#         print(return_key)
#         print(return_key.keys())
#         print("len(return_key.keys()) = " + str(len(return_key.keys())))
        
#         for k in return_key.keys():
#             print("type(return_key["+k+"])=" + str(type(return_key[k])))
        
        self.insert1(return_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Step 4: Inserted Key = {time.time()-start_time}")
        print(f"Total time = {time.time()-global_start_time}")

# %%
notebook_start_time = time.time()
FilteredSkeletonMinusSoma.populate(reserve_jobs=True)
print(f"Entire Notebook = {time.time()-notebook_start_time}")
# Out:
# 648518346341353574:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.11462926864624023
# Step 2: Calculated Bounding Box = 0.01708054542541504
# Step 3: filtering edges = 0.0056531429290771484
# Step 4: Inserted Key = 0.18959879875183105
# Total time = 0.3331611156463623
#
#
# 648518346341371119:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.27196812629699707
# Step 2: Calculated Bounding Box = 0.028213977813720703
# Step 3: filtering edges = 0.003659963607788086
# Step 4: Inserted Key = 0.32228612899780273
# Total time = 0.6359713077545166
#
#
# 648518346341378749:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.13154339790344238
# Step 2: Calculated Bounding Box = 0.019963979721069336
# Step 3: filtering edges = 0.0032989978790283203
# Step 4: Inserted Key = 0.11322546005249023
# Total time = 0.2766225337982178
#
#
# 648518346341403967:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.2968747615814209
# Step 2: Calculated Bounding Box = 0.032529592514038086
# Step 3: filtering edges = 0.0033249855041503906
# Step 4: Inserted Key = 0.22850584983825684
# Total time = 0.5703575611114502
#
#
# 648518346342792507:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.30079054832458496
# Step 2: Calculated Bounding Box = 0.027714014053344727
# Step 3: filtering edges = 0.00407099723815918
# Step 4: Inserted Key = 0.2302408218383789
# Total time = 0.5719163417816162
#
#
# 648518346342793994:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.11254620552062988
# Step 2: Calculated Bounding Box = 0.013088703155517578
# Step 3: filtering edges = 0.002096891403198242
# Step 4: Inserted Key = 0.09530973434448242
# Total time = 0.2316133975982666
#
#
# 648518346342807789:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.08756160736083984
# Step 2: Calculated Bounding Box = 0.010878562927246094
# Step 3: filtering edges = 0.002289295196533203
# Step 4: Inserted Key = 0.05870985984802246
# Total time = 0.16712164878845215
#
#
# 648518346349386137:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08129382133483887
# Step 2: Calculated Bounding Box = 0.012428045272827148
# Step 3: filtering edges = 0.002241373062133789
# Step 4: Inserted Key = 0.0751333236694336
# Total time = 0.17926478385925293
#
#
# 648518346349470171:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34749794006347656
# Step 2: Calculated Bounding Box = 0.03550839424133301
# Step 3: filtering edges = 0.008043527603149414
# Step 4: Inserted Key = 0.2412254810333252
# Total time = 0.6419501304626465
#
#
# 648518346349471156:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2722911834716797
# Step 2: Calculated Bounding Box = 0.028449535369873047
# Step 3: filtering edges = 0.005925655364990234
# Step 4: Inserted Key = 0.19876360893249512
# Total time = 0.514432430267334
#
#
# 648518346349471500:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2723712921142578
# Step 2: Calculated Bounding Box = 0.031055450439453125
# Step 3: filtering edges = 0.0036160945892333984
# Step 4: Inserted Key = 0.21465539932250977
# Total time = 0.5306892395019531
#
#
# 648518346349471562:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3498995304107666
# Step 2: Calculated Bounding Box = 0.03024125099182129
# Step 3: filtering edges = 0.006845712661743164
# Step 4: Inserted Key = 0.21937203407287598
# Total time = 0.6161847114562988
#
#
# 648518346349471565:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4968256950378418
# Step 2: Calculated Bounding Box = 0.03366708755493164
# Step 3: filtering edges = 0.0165097713470459
# Step 4: Inserted Key = 0.2235865592956543
# Total time = 0.780585765838623
#
#
# 648518346349471910:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4398050308227539
# Step 2: Calculated Bounding Box = 0.03847217559814453
# Step 3: filtering edges = 0.00661158561706543
# Step 4: Inserted Key = 0.27303075790405273
# Total time = 0.7666020393371582
#
#
# 648518346349472574:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.37007880210876465
# Step 2: Calculated Bounding Box = 0.03537130355834961
# Step 3: filtering edges = 0.010123014450073242
# Step 4: Inserted Key = 0.27020978927612305
# Total time = 0.6931347846984863
#
#
# 648518346349472601:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3675811290740967
# Step 2: Calculated Bounding Box = 0.03152132034301758
# Step 3: filtering edges = 0.004606962203979492
# Step 4: Inserted Key = 0.21262574195861816
# Total time = 0.6253697872161865
#
#
# 648518346349473044:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35459184646606445
# Step 2: Calculated Bounding Box = 0.029082775115966797
# Step 3: filtering edges = 0.008194208145141602
# Step 4: Inserted Key = 0.20230340957641602
# Total time = 0.603874921798706
#
#
# 648518346349473160:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42086052894592285
# Step 2: Calculated Bounding Box = 0.03490161895751953
# Step 3: filtering edges = 0.008202075958251953
# Step 4: Inserted Key = 0.27040934562683105
# Total time = 0.7430775165557861
#
#
# 648518346349473583:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2196953296661377
# Step 2: Calculated Bounding Box = 0.02761387825012207
# Step 3: filtering edges = 0.006186962127685547
# Step 4: Inserted Key = 0.1737828254699707
# Total time = 0.4361989498138428
#
#
# 648518346349473597:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3624410629272461
# Step 2: Calculated Bounding Box = 0.03274345397949219
# Step 3: filtering edges = 0.006696939468383789
# Step 4: Inserted Key = 0.22387218475341797
# Total time = 0.6343836784362793
#
#
# 648518346349473804:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.39010000228881836
# Step 2: Calculated Bounding Box = 0.032607316970825195
# Step 3: filtering edges = 0.0073282718658447266
# Step 4: Inserted Key = 0.23167943954467773
# Total time = 0.6716828346252441
#
#
# 648518346349473811:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18031716346740723
# Step 2: Calculated Bounding Box = 0.01703047752380371
# Step 3: filtering edges = 0.002821207046508789
# Step 4: Inserted Key = 0.10785555839538574
# Total time = 0.31739234924316406
#
#
# 648518346349473813:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34812402725219727
# Step 2: Calculated Bounding Box = 0.03271341323852539
# Step 3: filtering edges = 0.004293203353881836
# Step 4: Inserted Key = 0.23461246490478516
# Total time = 0.628563642501831
#
#
# 648518346349473821:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17395448684692383
# Step 2: Calculated Bounding Box = 0.017195940017700195
# Step 3: filtering edges = 0.0028905868530273438
# Step 4: Inserted Key = 0.1289963722229004
# Total time = 0.3306727409362793
#
#
# 648518346349473830:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12060976028442383
# Step 2: Calculated Bounding Box = 0.017762184143066406
# Step 3: filtering edges = 0.0028367042541503906
# Step 4: Inserted Key = 0.11496925354003906
# Total time = 0.2647542953491211
#
#
# 648518346349473833:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.14273929595947266
# Step 2: Calculated Bounding Box = 0.01736140251159668
# Step 3: filtering edges = 0.0034415721893310547
# Step 4: Inserted Key = 0.11483335494995117
# Total time = 0.28717756271362305
#
#
# 648518346349473835:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3458998203277588
# Step 2: Calculated Bounding Box = 0.04945635795593262
# Step 3: filtering edges = 0.0037081241607666016
# Step 4: Inserted Key = 0.3370823860168457
# Total time = 0.74526047706604
#
#
# 648518346349473838:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32167696952819824
# Step 2: Calculated Bounding Box = 0.030225753784179688
# Step 3: filtering edges = 0.005197763442993164
# Step 4: Inserted Key = 0.2180483341217041
# Total time = 0.5828442573547363
#
#
# 648518346349474146:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.40105271339416504
# Step 2: Calculated Bounding Box = 0.03637433052062988
# Step 3: filtering edges = 0.009847879409790039
# Step 4: Inserted Key = 0.23837614059448242
# Total time = 0.6955671310424805
#
#
# 648518346349475035:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3644540309906006
# Step 2: Calculated Bounding Box = 0.028902053833007812
# Step 3: filtering edges = 0.008823156356811523
# Step 4: Inserted Key = 0.2096729278564453
# Total time = 0.6203641891479492
#
#
# 648518346349475101:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.263979434967041
# Step 2: Calculated Bounding Box = 0.03044581413269043
# Step 3: filtering edges = 0.007355451583862305
# Step 4: Inserted Key = 0.2283005714416504
# Total time = 0.5387313365936279
#
#
# 648518346349475132:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2811245918273926
# Step 2: Calculated Bounding Box = 0.038733720779418945
# Step 3: filtering edges = 0.0030486583709716797
# Step 4: Inserted Key = 0.2356123924255371
# Total time = 0.5673172473907471
#
#
# 648518346349475138:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08717656135559082
# Step 2: Calculated Bounding Box = 0.012132406234741211
# Step 3: filtering edges = 0.0019562244415283203
# Step 4: Inserted Key = 0.08528900146484375
# Total time = 0.19518232345581055
#
#
# 648518346349475163:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.15717625617980957
# Step 2: Calculated Bounding Box = 0.025079965591430664
# Step 3: filtering edges = 0.006733894348144531
# Step 4: Inserted Key = 0.18084287643432617
# Total time = 0.3785743713378906
#
#
# 648518346349475412:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.24271750450134277
# Step 2: Calculated Bounding Box = 0.04090261459350586
# Step 3: filtering edges = 0.002831697463989258
# Step 4: Inserted Key = 0.29974913597106934
# Total time = 0.5939111709594727
#
#
# 648518346349475425:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20409011840820312
# Step 2: Calculated Bounding Box = 0.031473398208618164
# Step 3: filtering edges = 0.0034351348876953125
# Step 4: Inserted Key = 0.23203325271606445
# Total time = 0.4796278476715088
#
#
# 648518346349475510:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.14937973022460938
# Step 2: Calculated Bounding Box = 0.021448850631713867
# Step 3: filtering edges = 0.0027878284454345703
# Step 4: Inserted Key = 0.1468489170074463
# Total time = 0.3292241096496582
#
#
# 648518346349475518:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3927621841430664
# Step 2: Calculated Bounding Box = 0.03816866874694824
# Step 3: filtering edges = 0.005331993103027344
# Step 4: Inserted Key = 0.2623903751373291
# Total time = 0.7075438499450684
#
#
# 648518346349475522:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32923102378845215
# Step 2: Calculated Bounding Box = 0.05284881591796875
# Step 3: filtering edges = 0.0037126541137695312
# Step 4: Inserted Key = 0.3818390369415283
# Total time = 0.774620771408081
#
#
# 648518346349475523:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17756390571594238
# Step 2: Calculated Bounding Box = 0.022713184356689453
# Step 3: filtering edges = 0.002300262451171875
# Step 4: Inserted Key = 0.15129733085632324
# Total time = 0.3627052307128906
#
#
# 648518346349475525:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3258349895477295
# Step 2: Calculated Bounding Box = 0.031147480010986328
# Step 3: filtering edges = 0.004452943801879883
# Step 4: Inserted Key = 0.22984671592712402
# Total time = 0.5994470119476318
#
#
# 648518346349475526:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1473526954650879
# Step 2: Calculated Bounding Box = 0.01887226104736328
# Step 3: filtering edges = 0.002128124237060547
# Step 4: Inserted Key = 0.12152791023254395
# Total time = 0.29880809783935547
#
#
# 648518346349475529:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08257699012756348
# Step 2: Calculated Bounding Box = 0.014674186706542969
# Step 3: filtering edges = 0.0022945404052734375
# Step 4: Inserted Key = 0.08639907836914062
# Total time = 0.19405364990234375
#
#
# 648518346349475536:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22794556617736816
# Step 2: Calculated Bounding Box = 0.015990018844604492
# Step 3: filtering edges = 0.0044100284576416016
# Step 4: Inserted Key = 0.10589814186096191
# Total time = 0.3624753952026367
#
#
# 648518346349475540:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12384915351867676
# Step 2: Calculated Bounding Box = 0.007977724075317383
# Step 3: filtering edges = 0.0030481815338134766
# Step 4: Inserted Key = 0.041852712631225586
# Total time = 0.1856067180633545
#
#
# 648518346349475573:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11059308052062988
# Step 2: Calculated Bounding Box = 0.018454551696777344
# Step 3: filtering edges = 0.002658367156982422
# Step 4: Inserted Key = 0.12150025367736816
# Total time = 0.26162123680114746
#
#
# 648518346349476159:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20107102394104004
# Step 2: Calculated Bounding Box = 0.02687239646911621
# Step 3: filtering edges = 0.002657651901245117
# Step 4: Inserted Key = 0.18619585037231445
# Total time = 0.42465639114379883
#
#
# 648518346349476961:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35437536239624023
# Step 2: Calculated Bounding Box = 0.041249990463256836
# Step 3: filtering edges = 0.00545811653137207
# Step 4: Inserted Key = 0.279710054397583
# Total time = 0.6878957748413086
#
#
# 648518346349477155:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.14245867729187012
# Step 2: Calculated Bounding Box = 0.010999441146850586
# Step 3: filtering edges = 0.002471923828125
# Step 4: Inserted Key = 0.06057310104370117
# Total time = 0.22490596771240234
#
#
# 648518346349477981:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26157116889953613
# Step 2: Calculated Bounding Box = 0.024388551712036133
# Step 3: filtering edges = 0.01435542106628418
# Step 4: Inserted Key = 0.19776248931884766
# Total time = 0.506805419921875
#
#
# 648518346349478054:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32666540145874023
# Step 2: Calculated Bounding Box = 0.02995443344116211
# Step 3: filtering edges = 0.008796930313110352
# Step 4: Inserted Key = 0.21737027168273926
# Total time = 0.5918481349945068
#
#
# 648518346349478118:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3132028579711914
# Step 2: Calculated Bounding Box = 0.046330928802490234
# Step 3: filtering edges = 0.004216909408569336
# Step 4: Inserted Key = 0.2475285530090332
# Total time = 0.6185898780822754
#
#
# 648518346349478183:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3286449909210205
# Step 2: Calculated Bounding Box = 0.028128623962402344
# Step 3: filtering edges = 0.006659746170043945
# Step 4: Inserted Key = 0.20006990432739258
# Total time = 0.5722084045410156
#
#
# 648518346349478248:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4208838939666748
# Step 2: Calculated Bounding Box = 0.03530240058898926
# Step 3: filtering edges = 0.009285211563110352
# Step 4: Inserted Key = 0.2578096389770508
# Total time = 0.733189582824707
#
#
# 648518346349478330:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.29006242752075195
# Step 2: Calculated Bounding Box = 0.029204130172729492
# Step 3: filtering edges = 0.006276130676269531
# Step 4: Inserted Key = 0.21536922454833984
# Total time = 0.5495338439941406
#
#
# 648518346349478348:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26224613189697266
# Step 2: Calculated Bounding Box = 0.029474973678588867
# Step 3: filtering edges = 0.007526874542236328
# Step 4: Inserted Key = 0.22993803024291992
# Total time = 0.5378017425537109
#
#
# 648518346349478399:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.28222084045410156
# Step 2: Calculated Bounding Box = 0.026135921478271484
# Step 3: filtering edges = 0.007584810256958008
# Step 4: Inserted Key = 0.19461846351623535
# Total time = 0.518923282623291
#
#
# 648518346349478431:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.37697792053222656
# Step 2: Calculated Bounding Box = 0.03204083442687988
# Step 3: filtering edges = 0.007842302322387695
# Step 4: Inserted Key = 0.22953462600708008
# Total time = 0.656221866607666
#
#
# 648518346349478473:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2900502681732178
# Step 2: Calculated Bounding Box = 0.02940654754638672
# Step 3: filtering edges = 0.005930185317993164
# Step 4: Inserted Key = 0.2120048999786377
# Total time = 0.5466177463531494
#
#
# 648518346349478700:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.404341459274292
# Step 2: Calculated Bounding Box = 0.03148078918457031
# Step 3: filtering edges = 0.008756160736083984
# Step 4: Inserted Key = 0.2357017993927002
# Total time = 0.6900627613067627
#
#
# 648518346349478785:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4467296600341797
# Step 2: Calculated Bounding Box = 0.03322458267211914
# Step 3: filtering edges = 0.00549006462097168
# Step 4: Inserted Key = 0.23695826530456543
# Total time = 0.7309293746948242
#
#
# 648518346349478830:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2452704906463623
# Step 2: Calculated Bounding Box = 0.024135828018188477
# Step 3: filtering edges = 0.005055427551269531
# Step 4: Inserted Key = 0.18503665924072266
# Total time = 0.46805715560913086
#
#
# 648518346349478860:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18353509902954102
# Step 2: Calculated Bounding Box = 0.020597457885742188
# Step 3: filtering edges = 0.005249977111816406
# Step 4: Inserted Key = 0.14893531799316406
# Total time = 0.36586952209472656
#
#
# 648518346349479056:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3193531036376953
# Step 2: Calculated Bounding Box = 0.029578685760498047
# Step 3: filtering edges = 0.006166696548461914
# Step 4: Inserted Key = 0.20490717887878418
# Total time = 0.5695891380310059
#
#
# 648518346349479254:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5176148414611816
# Step 2: Calculated Bounding Box = 0.05276036262512207
# Step 3: filtering edges = 0.005248308181762695
# Step 4: Inserted Key = 0.4006054401397705
# Total time = 0.9855015277862549
#
#
# 648518346349479478:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3935885429382324
# Step 2: Calculated Bounding Box = 0.0448150634765625
# Step 3: filtering edges = 0.006775379180908203
# Step 4: Inserted Key = 0.32830357551574707
# Total time = 0.7825253009796143
#
#
# 648518346349479573:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34511733055114746
# Step 2: Calculated Bounding Box = 0.027083635330200195
# Step 3: filtering edges = 0.009560108184814453
# Step 4: Inserted Key = 0.20091652870178223
# Total time = 0.5917873382568359
#
#
# 648518346349479706:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24028277397155762
# Step 2: Calculated Bounding Box = 0.036217451095581055
# Step 3: filtering edges = 0.004756450653076172
# Step 4: Inserted Key = 0.27301931381225586
# Total time = 0.5619466304779053
#
#
# 648518346349479776:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10229635238647461
# Step 2: Calculated Bounding Box = 0.014971494674682617
# Step 3: filtering edges = 0.0018346309661865234
# Step 4: Inserted Key = 0.09808135032653809
# Total time = 0.22505712509155273
#
#
# 648518346349479837:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.40624237060546875
# Step 2: Calculated Bounding Box = 0.033136844635009766
# Step 3: filtering edges = 0.005526304244995117
# Step 4: Inserted Key = 0.2377927303314209
# Total time = 0.69169020652771
#
#
# 648518346349479929:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.0873863697052002
# Step 2: Calculated Bounding Box = 0.012378931045532227
# Step 3: filtering edges = 0.0013425350189208984
# Step 4: Inserted Key = 0.07624959945678711
# Total time = 0.18525123596191406
#
#
# 648518346349479981:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3644392490386963
# Step 2: Calculated Bounding Box = 0.04004549980163574
# Step 3: filtering edges = 0.007342338562011719
# Step 4: Inserted Key = 0.27008819580078125
# Total time = 0.6908292770385742
#
#
# 648518346349480499:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32346439361572266
# Step 2: Calculated Bounding Box = 0.03418922424316406
# Step 3: filtering edges = 0.004698276519775391
# Step 4: Inserted Key = 0.24589824676513672
# Total time = 0.6163351535797119
#
#
# 648518346349481014:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.41901636123657227
# Step 2: Calculated Bounding Box = 0.03485250473022461
# Step 3: filtering edges = 0.008202552795410156
# Step 4: Inserted Key = 0.26023030281066895
# Total time = 0.730992317199707
#
#
# 648518346349481574:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4071691036224365
# Step 2: Calculated Bounding Box = 0.04630470275878906
# Step 3: filtering edges = 0.004795551300048828
# Step 4: Inserted Key = 0.3431992530822754
# Total time = 0.8098740577697754
#
#
# 648518346349482020:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.13259100914001465
# Step 2: Calculated Bounding Box = 0.015922069549560547
# Step 3: filtering edges = 0.004499197006225586
# Step 4: Inserted Key = 0.10691142082214355
# Total time = 0.26820802688598633
#
#
# 648518346349482196:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2916860580444336
# Step 2: Calculated Bounding Box = 0.02985835075378418
# Step 3: filtering edges = 0.004329681396484375
# Step 4: Inserted Key = 0.21339035034179688
# Total time = 0.54746413230896
#
#
# 648518346349482312:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35039329528808594
# Step 2: Calculated Bounding Box = 0.028563499450683594
# Step 3: filtering edges = 0.0078887939453125
# Step 4: Inserted Key = 0.21233463287353516
# Total time = 0.6079726219177246
#
#
# 648518346349482676:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4293062686920166
# Step 2: Calculated Bounding Box = 0.05476498603820801
# Step 3: filtering edges = 0.006426334381103516
# Step 4: Inserted Key = 0.4109790325164795
# Total time = 0.9108083248138428
#
#
# 648518346349483124:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.37880420684814453
# Step 2: Calculated Bounding Box = 0.03679656982421875
# Step 3: filtering edges = 0.005484819412231445
# Step 4: Inserted Key = 0.26741552352905273
# Total time = 0.6971657276153564
#
#
# 648518346349483228:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.25859904289245605
# Step 2: Calculated Bounding Box = 0.029998302459716797
# Step 3: filtering edges = 0.004182338714599609
# Step 4: Inserted Key = 0.22083067893981934
# Total time = 0.5208783149719238
#
#
# 648518346349483956:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4377925395965576
# Step 2: Calculated Bounding Box = 0.033719539642333984
# Step 3: filtering edges = 0.006165266036987305
# Step 4: Inserted Key = 0.2445664405822754
# Total time = 0.7296085357666016
#
#
# 648518346349484607:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3153116703033447
# Step 2: Calculated Bounding Box = 0.030174970626831055
# Step 3: filtering edges = 0.006487607955932617
# Step 4: Inserted Key = 0.2219395637512207
# Total time = 0.5819165706634521
#
#
# 648518346349484832:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09997105598449707
# Step 2: Calculated Bounding Box = 0.010332584381103516
# Step 3: filtering edges = 0.0016357898712158203
# Step 4: Inserted Key = 0.06261849403381348
# Total time = 0.18072772026062012
#
#
# 648518346349485007:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17504358291625977
# Step 2: Calculated Bounding Box = 0.016765117645263672
# Step 3: filtering edges = 0.0036783218383789062
# Step 4: Inserted Key = 0.11831307411193848
# Total time = 0.32150721549987793
#
#
# 648518346349485701:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2944810390472412
# Step 2: Calculated Bounding Box = 0.02874898910522461
# Step 3: filtering edges = 0.004861116409301758
# Step 4: Inserted Key = 0.2088918685913086
# Total time = 0.5442888736724854
#
#
# 648518346349485870:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35277366638183594
# Step 2: Calculated Bounding Box = 0.032404422760009766
# Step 3: filtering edges = 0.006045341491699219
# Step 4: Inserted Key = 0.24290704727172852
# Total time = 0.6416463851928711
#
#
# 648518346349486491:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3320283889770508
# Step 2: Calculated Bounding Box = 0.028150320053100586
# Step 3: filtering edges = 0.005085468292236328
# Step 4: Inserted Key = 0.20409727096557617
# Total time = 0.5779557228088379
#
#
# 648518346349486885:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34970712661743164
# Step 2: Calculated Bounding Box = 0.034221649169921875
# Step 3: filtering edges = 0.0052030086517333984
# Step 4: Inserted Key = 0.25776100158691406
# Total time = 0.6534531116485596
#
#
# 648518346349486929:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32801342010498047
# Step 2: Calculated Bounding Box = 0.030556678771972656
# Step 3: filtering edges = 0.004874229431152344
# Step 4: Inserted Key = 0.22139716148376465
# Total time = 0.5926449298858643
#
#
# 648518346349487499:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.14645600318908691
# Step 2: Calculated Bounding Box = 0.01981520652770996
# Step 3: filtering edges = 0.003026247024536133
# Step 4: Inserted Key = 0.13385868072509766
# Total time = 0.30887675285339355
#
#
# 648518346349487734:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4836702346801758
# Step 2: Calculated Bounding Box = 0.03541898727416992
# Step 3: filtering edges = 0.007587432861328125
# Step 4: Inserted Key = 0.2510833740234375
# Total time = 0.7864189147949219
#
#
# 648518346349488659:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.312915563583374
# Step 2: Calculated Bounding Box = 0.02746748924255371
# Step 3: filtering edges = 0.003712177276611328
# Step 4: Inserted Key = 0.20410585403442383
# Total time = 0.5555455684661865
#
#
# 648518346349490614:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2511582374572754
# Step 2: Calculated Bounding Box = 0.02224111557006836
# Step 3: filtering edges = 0.0044291019439697266
# Step 4: Inserted Key = 0.1567091941833496
# Total time = 0.4435102939605713
#
#
# 648518346349490654:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.23627400398254395
# Step 2: Calculated Bounding Box = 0.02658677101135254
# Step 3: filtering edges = 0.00550079345703125
# Step 4: Inserted Key = 0.19181084632873535
# Total time = 0.4685394763946533
#
#
# 648518346349490749:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3184220790863037
# Step 2: Calculated Bounding Box = 0.027349233627319336
# Step 3: filtering edges = 0.0067136287689208984
# Step 4: Inserted Key = 0.20215702056884766
# Total time = 0.5623886585235596
#
#
# 648518346349490796:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3454432487487793
# Step 2: Calculated Bounding Box = 0.030022621154785156
# Step 3: filtering edges = 0.006043672561645508
# Step 4: Inserted Key = 0.22278070449829102
# Total time = 0.6127064228057861
#
#
# 648518346349491045:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.29019975662231445
# Step 2: Calculated Bounding Box = 0.02632284164428711
# Step 3: filtering edges = 0.0037207603454589844
# Step 4: Inserted Key = 0.18993330001831055
# Total time = 0.5179433822631836
#
#
# 648518346349491311:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24458026885986328
# Step 2: Calculated Bounding Box = 0.0273745059967041
# Step 3: filtering edges = 0.004019737243652344
# Step 4: Inserted Key = 0.2032783031463623
# Total time = 0.48629188537597656
#
#
# 648518346349491736:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19626402854919434
# Step 2: Calculated Bounding Box = 0.01782536506652832
# Step 3: filtering edges = 0.0041561126708984375
# Step 4: Inserted Key = 0.11869645118713379
# Total time = 0.34317445755004883
#
#
# 648518346349491811:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2400798797607422
# Step 2: Calculated Bounding Box = 0.03139162063598633
# Step 3: filtering edges = 0.002094745635986328
# Step 4: Inserted Key = 0.22121143341064453
# Total time = 0.5019917488098145
#
#
# 648518346349491953:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.41078639030456543
# Step 2: Calculated Bounding Box = 0.030300617218017578
# Step 3: filtering edges = 0.005690336227416992
# Step 4: Inserted Key = 0.2190704345703125
# Total time = 0.6730496883392334
#
#
# 648518346349491984:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2602109909057617
# Step 2: Calculated Bounding Box = 0.024208784103393555
# Step 3: filtering edges = 0.003920555114746094
# Step 4: Inserted Key = 0.16960883140563965
# Total time = 0.46478939056396484
#
#
# 648518346349492078:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18389225006103516
# Step 2: Calculated Bounding Box = 0.017976760864257812
# Step 3: filtering edges = 0.004167079925537109
# Step 4: Inserted Key = 0.12067246437072754
# Total time = 0.33473920822143555
#
#
# 648518346349492097:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34047555923461914
# Step 2: Calculated Bounding Box = 0.02742934226989746
# Step 3: filtering edges = 0.004630088806152344
# Step 4: Inserted Key = 0.23984718322753906
# Total time = 0.6200671195983887
#
#
# 648518346349492197:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12952470779418945
# Step 2: Calculated Bounding Box = 0.010573148727416992
# Step 3: filtering edges = 0.002682209014892578
# Step 4: Inserted Key = 0.06708025932312012
# Total time = 0.2182154655456543
#
#
# 648518346349492662:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26941967010498047
# Step 2: Calculated Bounding Box = 0.03426504135131836
# Step 3: filtering edges = 0.0030770301818847656
# Step 4: Inserted Key = 0.24553704261779785
# Total time = 0.5606040954589844
#
#
# 648518346349492682:
# Soma found in Orphans
# Step 1: extracted Soma Mesh = 0.30951690673828125
# Step 2: Calculated Bounding Box = 0.03645944595336914
# Step 3: filtering edges = 0.0030324459075927734
# Step 4: Inserted Key = 0.26155543327331543
# Total time = 0.6182606220245361
#
#
# 648518346349493106:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2891874313354492
# Step 2: Calculated Bounding Box = 0.03493618965148926
# Step 3: filtering edges = 0.004210710525512695
# Step 4: Inserted Key = 0.24773573875427246
# Total time = 0.5825371742248535
#
#
# 648518346349493117:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3245415687561035
# Step 2: Calculated Bounding Box = 0.028963088989257812
# Step 3: filtering edges = 0.0071392059326171875
# Step 4: Inserted Key = 0.21505331993103027
# Total time = 0.5840082168579102
#
#
# 648518346349493260:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15139555931091309
# Step 2: Calculated Bounding Box = 0.01814103126525879
# Step 3: filtering edges = 0.0032885074615478516
# Step 4: Inserted Key = 0.13595318794250488
# Total time = 0.3150930404663086
#
#
# 648518346349493354:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09866905212402344
# Step 2: Calculated Bounding Box = 0.008472681045532227
# Step 3: filtering edges = 0.002982616424560547
# Step 4: Inserted Key = 0.04370403289794922
# Total time = 0.1607975959777832
#
#
# 648518346349493487:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1039438247680664
# Step 2: Calculated Bounding Box = 0.012221097946166992
# Step 3: filtering edges = 0.0018889904022216797
# Step 4: Inserted Key = 0.07694864273071289
# Total time = 0.20292448997497559
#
#
# 648518346349493606:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08648252487182617
# Step 2: Calculated Bounding Box = 0.012724637985229492
# Step 3: filtering edges = 0.002583742141723633
# Step 4: Inserted Key = 0.07853889465332031
# Total time = 0.18779993057250977
#
#
# 648518346349493653:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32877326011657715
# Step 2: Calculated Bounding Box = 0.021291017532348633
# Step 3: filtering edges = 0.004760265350341797
# Step 4: Inserted Key = 0.1381058692932129
# Total time = 0.5011615753173828
#
#
# 648518346349493733:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3161962032318115
# Step 2: Calculated Bounding Box = 0.021277904510498047
# Step 3: filtering edges = 0.0047223567962646484
# Step 4: Inserted Key = 0.14718866348266602
# Total time = 0.498842716217041
#
#
# 648518346349493856:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19014859199523926
# Step 2: Calculated Bounding Box = 0.013654470443725586
# Step 3: filtering edges = 0.004696846008300781
# Step 4: Inserted Key = 0.08648276329040527
# Total time = 0.30231332778930664
#
#
# 648518346349493881:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3054637908935547
# Step 2: Calculated Bounding Box = 0.027857065200805664
# Step 3: filtering edges = 0.003431558609008789
# Step 4: Inserted Key = 0.191483736038208
# Total time = 0.5358386039733887
#
#
# 648518346349493911:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10907840728759766
# Step 2: Calculated Bounding Box = 0.010219097137451172
# Step 3: filtering edges = 0.0033881664276123047
# Step 4: Inserted Key = 0.06284618377685547
# Total time = 0.19289183616638184
#
#
# 648518346349493981:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15485382080078125
# Step 2: Calculated Bounding Box = 0.010549068450927734
# Step 3: filtering edges = 0.004095554351806641
# Step 4: Inserted Key = 0.06760954856872559
# Total time = 0.24585270881652832
#
#
# 648518346349494004:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09025073051452637
# Step 2: Calculated Bounding Box = 0.009312629699707031
# Step 3: filtering edges = 0.0025544166564941406
# Step 4: Inserted Key = 0.054686546325683594
# Total time = 0.1647331714630127
#
#
# 648518346349494087:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.36511945724487305
# Step 2: Calculated Bounding Box = 0.033490657806396484
# Step 3: filtering edges = 0.0049021244049072266
# Step 4: Inserted Key = 0.23649239540100098
# Total time = 0.6480648517608643
#
#
# 648518346349494194:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.13735437393188477
# Step 2: Calculated Bounding Box = 0.016233444213867188
# Step 3: filtering edges = 0.0035123825073242188
# Step 4: Inserted Key = 0.11680459976196289
# Total time = 0.2818417549133301
#
#
# 648518346349494515:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2732861042022705
# Step 2: Calculated Bounding Box = 0.0369267463684082
# Step 3: filtering edges = 0.0030944347381591797
# Step 4: Inserted Key = 0.2536492347717285
# Total time = 0.5755131244659424
#
#
# 648518346349494539:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.29248476028442383
# Step 2: Calculated Bounding Box = 0.029223203659057617
# Step 3: filtering edges = 0.004880189895629883
# Step 4: Inserted Key = 0.21221208572387695
# Total time = 0.5474624633789062
#
#
# 648518346349494577:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12556695938110352
# Step 2: Calculated Bounding Box = 0.014754772186279297
# Step 3: filtering edges = 0.0028908252716064453
# Step 4: Inserted Key = 0.09547281265258789
# Total time = 0.24577808380126953
#
#
# 648518346349494969:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3733546733856201
# Step 2: Calculated Bounding Box = 0.044972896575927734
# Step 3: filtering edges = 0.004424571990966797
# Step 4: Inserted Key = 0.3102304935455322
# Total time = 0.7411603927612305
#
#
# 648518346349495174:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34870266914367676
# Step 2: Calculated Bounding Box = 0.031685590744018555
# Step 3: filtering edges = 0.006241798400878906
# Step 4: Inserted Key = 0.2219257354736328
# Total time = 0.6176033020019531
#
#
# 648518346349495243:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2629718780517578
# Step 2: Calculated Bounding Box = 0.02463841438293457
# Step 3: filtering edges = 0.005379676818847656
# Step 4: Inserted Key = 0.17803525924682617
# Total time = 0.47948145866394043
#
#
# 648518346349495481:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4144022464752197
# Step 2: Calculated Bounding Box = 0.031185150146484375
# Step 3: filtering edges = 0.009590864181518555
# Step 4: Inserted Key = 0.26792430877685547
# Total time = 0.7311649322509766
#
#
# 648518346349495660:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6323468685150146
# Step 2: Calculated Bounding Box = 0.05286526679992676
# Step 3: filtering edges = 0.007000446319580078
# Step 4: Inserted Key = 0.4190049171447754
# Total time = 1.120316982269287
#
#
# 648518346349495846:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22112083435058594
# Step 2: Calculated Bounding Box = 0.029426097869873047
# Step 3: filtering edges = 0.00436711311340332
# Step 4: Inserted Key = 0.20153260231018066
# Total time = 0.46396374702453613
#
#
# 648518346349495935:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.13566160202026367
# Step 2: Calculated Bounding Box = 0.018409252166748047
# Step 3: filtering edges = 0.0023849010467529297
# Step 4: Inserted Key = 0.13239669799804688
# Total time = 0.2971045970916748
#
#
# 648518346349495971:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.21827459335327148
# Step 2: Calculated Bounding Box = 0.024292707443237305
# Step 3: filtering edges = 0.0037708282470703125
# Step 4: Inserted Key = 0.16736936569213867
# Total time = 0.42177510261535645
#
#
# 648518346349496058:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22986793518066406
# Step 2: Calculated Bounding Box = 0.03262758255004883
# Step 3: filtering edges = 0.0030851364135742188
# Step 4: Inserted Key = 0.24439692497253418
# Total time = 0.5178248882293701
#
#
# 648518346349496103:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.37444257736206055
# Step 2: Calculated Bounding Box = 0.031815290451049805
# Step 3: filtering edges = 0.005089282989501953
# Step 4: Inserted Key = 0.22517943382263184
# Total time = 0.6441786289215088
#
#
# 648518346349496245:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3572237491607666
# Step 2: Calculated Bounding Box = 0.03431200981140137
# Step 3: filtering edges = 0.008879423141479492
# Step 4: Inserted Key = 0.28951120376586914
# Total time = 0.6994028091430664
#
#
# 648518346349496405:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.16429567337036133
# Step 2: Calculated Bounding Box = 0.01849961280822754
# Step 3: filtering edges = 0.0043430328369140625
# Step 4: Inserted Key = 0.11756396293640137
# Total time = 0.3138597011566162
#
#
# 648518346349496554:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.41348862648010254
# Step 2: Calculated Bounding Box = 0.03199052810668945
# Step 3: filtering edges = 0.006658792495727539
# Step 4: Inserted Key = 0.21703863143920898
# Total time = 0.6777453422546387
#
#
# 648518346349496672:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.37215161323547363
# Step 2: Calculated Bounding Box = 0.03266429901123047
# Step 3: filtering edges = 0.005543231964111328
# Step 4: Inserted Key = 0.23249077796936035
# Total time = 0.6520321369171143
#
#
# 648518346349496925:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34561872482299805
# Step 2: Calculated Bounding Box = 0.02926039695739746
# Step 3: filtering edges = 0.00836491584777832
# Step 4: Inserted Key = 0.21350836753845215
# Total time = 0.605398416519165
#
#
# 648518346349497094:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.38079166412353516
# Step 2: Calculated Bounding Box = 0.034604787826538086
# Step 3: filtering edges = 0.005103349685668945
# Step 4: Inserted Key = 0.24723148345947266
# Total time = 0.6760632991790771
#
#
# 648518346349497151:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3814406394958496
# Step 2: Calculated Bounding Box = 0.03184652328491211
# Step 3: filtering edges = 0.004853963851928711
# Step 4: Inserted Key = 0.22897672653198242
# Total time = 0.656423807144165
#
#
# 648518346349497184:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32015490531921387
# Step 2: Calculated Bounding Box = 0.03510642051696777
# Step 3: filtering edges = 0.003669261932373047
# Step 4: Inserted Key = 0.22970890998840332
# Total time = 0.5955140590667725
#
#
# 648518346349497752:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3767867088317871
# Step 2: Calculated Bounding Box = 0.03239750862121582
# Step 3: filtering edges = 0.00627446174621582
# Step 4: Inserted Key = 0.22339797019958496
# Total time = 0.6459310054779053
#
#
# 648518346349498116:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4951481819152832
# Step 2: Calculated Bounding Box = 0.03588104248046875
# Step 3: filtering edges = 0.00655364990234375
# Step 4: Inserted Key = 0.2363271713256836
# Total time = 0.7840771675109863
#
#
# 648518346349498239:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4629065990447998
# Step 2: Calculated Bounding Box = 0.04689645767211914
# Step 3: filtering edges = 0.00558924674987793
# Step 4: Inserted Key = 0.34674549102783203
# Total time = 0.8716142177581787
#
#
# 648518346349498286:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24715542793273926
# Step 2: Calculated Bounding Box = 0.025977611541748047
# Step 3: filtering edges = 0.0036230087280273438
# Step 4: Inserted Key = 0.17927813529968262
# Total time = 0.4643700122833252
#
#
# 648518346349498406:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.13048982620239258
# Step 2: Calculated Bounding Box = 0.01663994789123535
# Step 3: filtering edges = 0.0023479461669921875
# Step 4: Inserted Key = 0.09968090057373047
# Total time = 0.25805187225341797
#
#
# 648518346349498482:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2611091136932373
# Step 2: Calculated Bounding Box = 0.024364948272705078
# Step 3: filtering edges = 0.004460573196411133
# Step 4: Inserted Key = 0.1727755069732666
# Total time = 0.4708242416381836
#
#
# 648518346349498566:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24964499473571777
# Step 2: Calculated Bounding Box = 0.030336856842041016
# Step 3: filtering edges = 0.004641056060791016
# Step 4: Inserted Key = 0.21318650245666504
# Total time = 0.505645751953125
#
#
# 648518346349498632:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.41357874870300293
# Step 2: Calculated Bounding Box = 0.030419111251831055
# Step 3: filtering edges = 0.005881309509277344
# Step 4: Inserted Key = 0.21339797973632812
# Total time = 0.6717917919158936
#
#
# 648518346349498835:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42730236053466797
# Step 2: Calculated Bounding Box = 0.03836822509765625
# Step 3: filtering edges = 0.0061266422271728516
# Step 4: Inserted Key = 0.2638974189758301
# Total time = 0.7442471981048584
#
#
# 648518346349499085:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.36713385581970215
# Step 2: Calculated Bounding Box = 0.028637170791625977
# Step 3: filtering edges = 0.005582332611083984
# Step 4: Inserted Key = 0.20656776428222656
# Total time = 0.6171624660491943
#
#
# 648518346349499186:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.46395206451416016
# Step 2: Calculated Bounding Box = 0.052031517028808594
# Step 3: filtering edges = 0.004376888275146484
# Step 4: Inserted Key = 0.3820991516113281
# Total time = 0.9089150428771973
#
#
# 648518346349499297:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3517162799835205
# Step 2: Calculated Bounding Box = 0.029914140701293945
# Step 3: filtering edges = 0.00590062141418457
# Step 4: Inserted Key = 0.21822404861450195
# Total time = 0.6151959896087646
#
#
# 648518346349499369:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3453102111816406
# Step 2: Calculated Bounding Box = 0.03216862678527832
# Step 3: filtering edges = 0.00572657585144043
# Step 4: Inserted Key = 0.23328804969787598
# Total time = 0.6252377033233643
#
#
# 648518346349499581:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4564692974090576
# Step 2: Calculated Bounding Box = 0.03192734718322754
# Step 3: filtering edges = 0.011003732681274414
# Step 4: Inserted Key = 0.27069997787475586
# Total time = 0.7794220447540283
#
#
# 648518346349499624:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5005462169647217
# Step 2: Calculated Bounding Box = 0.03333330154418945
# Step 3: filtering edges = 0.007523298263549805
# Step 4: Inserted Key = 0.24577069282531738
# Total time = 0.7972564697265625
#
#
# 648518346349499636:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35415029525756836
# Step 2: Calculated Bounding Box = 0.037520408630371094
# Step 3: filtering edges = 0.00708317756652832
# Step 4: Inserted Key = 0.22785186767578125
# Total time = 0.6374726295471191
#
#
# 648518346349499679:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.33914685249328613
# Step 2: Calculated Bounding Box = 0.030544281005859375
# Step 3: filtering edges = 0.0064849853515625
# Step 4: Inserted Key = 0.2220766544342041
# Total time = 0.6089072227478027
#
#
# 648518346349499680:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34921813011169434
# Step 2: Calculated Bounding Box = 0.029864788055419922
# Step 3: filtering edges = 0.005845785140991211
# Step 4: Inserted Key = 0.21274566650390625
# Total time = 0.6068167686462402
#
#
# 648518346349499689:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3121006488800049
# Step 2: Calculated Bounding Box = 0.034128427505493164
# Step 3: filtering edges = 0.004530429840087891
# Step 4: Inserted Key = 0.24104666709899902
# Total time = 0.599468469619751
#
#
# 648518346349499701:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35869312286376953
# Step 2: Calculated Bounding Box = 0.031008005142211914
# Step 3: filtering edges = 0.0059168338775634766
# Step 4: Inserted Key = 0.21526002883911133
# Total time = 0.6188375949859619
#
#
# 648518346349499759:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26728320121765137
# Step 2: Calculated Bounding Box = 0.025685548782348633
# Step 3: filtering edges = 0.005224704742431641
# Step 4: Inserted Key = 0.1855630874633789
# Total time = 0.49102354049682617
#
#
# 648518346349499773:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4020195007324219
# Step 2: Calculated Bounding Box = 0.0333096981048584
# Step 3: filtering edges = 0.006308555603027344
# Step 4: Inserted Key = 0.23895001411437988
# Total time = 0.6893458366394043
#
#
# 648518346349499783:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3207998275756836
# Step 2: Calculated Bounding Box = 0.03127169609069824
# Step 3: filtering edges = 0.003935813903808594
# Step 4: Inserted Key = 0.22211933135986328
# Total time = 0.584916353225708
#
#
# 648518346349499824:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3124406337738037
# Step 2: Calculated Bounding Box = 0.030063867568969727
# Step 3: filtering edges = 0.007813453674316406
# Step 4: Inserted Key = 0.21843624114990234
# Total time = 0.5780200958251953
#
#
# 648518346349499828:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.30346131324768066
# Step 2: Calculated Bounding Box = 0.031148195266723633
# Step 3: filtering edges = 0.007529735565185547
# Step 4: Inserted Key = 0.21967387199401855
# Total time = 0.5695130825042725
#
#
# 648518346349499851:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4180150032043457
# Step 2: Calculated Bounding Box = 0.035538673400878906
# Step 3: filtering edges = 0.009239912033081055
# Step 4: Inserted Key = 0.26670336723327637
# Total time = 0.7383010387420654
#
#
# 648518346349499852:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.23715758323669434
# Step 2: Calculated Bounding Box = 0.023697376251220703
# Step 3: filtering edges = 0.006104230880737305
# Step 4: Inserted Key = 0.18054795265197754
# Total time = 0.4558987617492676
#
#
# 648518346349499876:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2892181873321533
# Step 2: Calculated Bounding Box = 0.02336406707763672
# Step 3: filtering edges = 0.007282733917236328
# Step 4: Inserted Key = 0.17433381080627441
# Total time = 0.5034432411193848
#
#
# 648518346349499896:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20609354972839355
# Step 2: Calculated Bounding Box = 0.01687479019165039
# Step 3: filtering edges = 0.003844022750854492
# Step 4: Inserted Key = 0.11467361450195312
# Total time = 0.34937310218811035
#
#
# 648518346349499910:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2680954933166504
# Step 2: Calculated Bounding Box = 0.03078484535217285
# Step 3: filtering edges = 0.005074501037597656
# Step 4: Inserted Key = 0.22176551818847656
# Total time = 0.5344195365905762
#
#
# 648518346349499928:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.23848676681518555
# Step 2: Calculated Bounding Box = 0.03300356864929199
# Step 3: filtering edges = 0.0036439895629882812
# Step 4: Inserted Key = 0.23702239990234375
# Total time = 0.5202243328094482
#
#
# 648518346349499939:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4169654846191406
# Step 2: Calculated Bounding Box = 0.03756260871887207
# Step 3: filtering edges = 0.008821964263916016
# Step 4: Inserted Key = 0.26966094970703125
# Total time = 0.7414021492004395
#
#
# 648518346349500049:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.36331772804260254
# Step 2: Calculated Bounding Box = 0.03560161590576172
# Step 3: filtering edges = 0.009103775024414062
# Step 4: Inserted Key = 0.26717305183410645
# Total time = 0.6834859848022461
#
#
# 648518346349500120:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2192692756652832
# Step 2: Calculated Bounding Box = 0.028870105743408203
# Step 3: filtering edges = 0.0036308765411376953
# Step 4: Inserted Key = 0.20448899269104004
# Total time = 0.4651200771331787
#
#
# 648518346349500138:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3753068447113037
# Step 2: Calculated Bounding Box = 0.031206846237182617
# Step 3: filtering edges = 0.006654977798461914
# Step 4: Inserted Key = 0.22797155380249023
# Total time = 0.6493732929229736
#
#
# 648518346349500139:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35390782356262207
# Step 2: Calculated Bounding Box = 0.03487753868103027
# Step 3: filtering edges = 0.004737138748168945
# Step 4: Inserted Key = 0.25863027572631836
# Total time = 0.6606552600860596
#
#
# 648518346349500155:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3401033878326416
# Step 2: Calculated Bounding Box = 0.03383231163024902
# Step 3: filtering edges = 0.005751371383666992
# Step 4: Inserted Key = 0.250272274017334
# Total time = 0.6383252143859863
#
#
# 648518346349500162:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.25609612464904785
# Step 2: Calculated Bounding Box = 0.02590203285217285
# Step 3: filtering edges = 0.005135536193847656
# Step 4: Inserted Key = 0.18308568000793457
# Total time = 0.4778122901916504
#
#
# 648518346349500277:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.33370518684387207
# Step 2: Calculated Bounding Box = 0.03223371505737305
# Step 3: filtering edges = 0.006329774856567383
# Step 4: Inserted Key = 0.23876714706420898
# Total time = 0.6188318729400635
#
#
# 648518346349500324:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4178140163421631
# Step 2: Calculated Bounding Box = 0.03421592712402344
# Step 3: filtering edges = 0.008928060531616211
# Step 4: Inserted Key = 0.24639201164245605
# Total time = 0.7162063121795654
#
#
# 648518346349500341:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.30472302436828613
# Step 2: Calculated Bounding Box = 0.02961134910583496
# Step 3: filtering edges = 0.003998517990112305
# Step 4: Inserted Key = 0.21819853782653809
# Total time = 0.5651204586029053
#
#
# 648518346349500431:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.45368194580078125
# Step 2: Calculated Bounding Box = 0.03413510322570801
# Step 3: filtering edges = 0.007010221481323242
# Step 4: Inserted Key = 0.23807096481323242
# Total time = 0.7401022911071777
#
#
# 648518346349500440:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.32611083984375
# Step 2: Calculated Bounding Box = 0.02881026268005371
# Step 3: filtering edges = 0.004225969314575195
# Step 4: Inserted Key = 0.20232629776000977
# Total time = 0.570232629776001
#
#
# 648518346349500486:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.412081241607666
# Step 2: Calculated Bounding Box = 0.03444814682006836
# Step 3: filtering edges = 0.005288600921630859
# Step 4: Inserted Key = 0.24647760391235352
# Total time = 0.7074036598205566
#
#
# 648518346349500627:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5834228992462158
# Step 2: Calculated Bounding Box = 0.03206014633178711
# Step 3: filtering edges = 0.00803995132446289
# Step 4: Inserted Key = 0.24874663352966309
# Total time = 0.8796689510345459
#
#
# 648518346349500657:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4258594512939453
# Step 2: Calculated Bounding Box = 0.035214900970458984
# Step 3: filtering edges = 0.007075071334838867
# Step 4: Inserted Key = 0.25001096725463867
# Total time = 0.7263262271881104
#
#
# 648518346349500672:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09859919548034668
# Step 2: Calculated Bounding Box = 0.011137723922729492
# Step 3: filtering edges = 0.004698038101196289
# Step 4: Inserted Key = 0.07008099555969238
# Total time = 0.19263005256652832
#
#
# 648518346349500725:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.40679359436035156
# Step 2: Calculated Bounding Box = 0.030451297760009766
# Step 3: filtering edges = 0.008762359619140625
# Step 4: Inserted Key = 0.22337985038757324
# Total time = 0.6780836582183838
#
#
# 648518346349500742:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20933175086975098
# Step 2: Calculated Bounding Box = 0.023051977157592773
# Step 3: filtering edges = 0.003453969955444336
# Step 4: Inserted Key = 0.18049216270446777
# Total time = 0.42553019523620605
#
#
# 648518346349500886:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08613824844360352
# Step 2: Calculated Bounding Box = 0.015625953674316406
# Step 3: filtering edges = 0.004150867462158203
# Step 4: Inserted Key = 0.06436634063720703
# Total time = 0.17937850952148438
#
#
# 648518346349500939:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3812227249145508
# Step 2: Calculated Bounding Box = 0.03268313407897949
# Step 3: filtering edges = 0.00799703598022461
# Step 4: Inserted Key = 0.23116064071655273
# Total time = 0.6619999408721924
#
#
# 648518346349500954:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2724485397338867
# Step 2: Calculated Bounding Box = 0.028964519500732422
# Step 3: filtering edges = 0.005445003509521484
# Step 4: Inserted Key = 0.19929242134094238
# Total time = 0.5144689083099365
#
#
# 648518346349501175:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.41513872146606445
# Step 2: Calculated Bounding Box = 0.04610419273376465
# Step 3: filtering edges = 0.007208585739135742
# Step 4: Inserted Key = 0.2653524875640869
# Total time = 0.7430620193481445
#
#
# 648518346349501216:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3914308547973633
# Step 2: Calculated Bounding Box = 0.03531193733215332
# Step 3: filtering edges = 0.00470280647277832
# Step 4: Inserted Key = 0.243910551071167
# Total time = 0.6842997074127197
#
#
# 648518346349501481:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34053611755371094
# Step 2: Calculated Bounding Box = 0.03421449661254883
# Step 3: filtering edges = 0.005099058151245117
# Step 4: Inserted Key = 0.2244565486907959
# Total time = 0.6131885051727295
#
#
# 648518346349501517:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2698018550872803
# Step 2: Calculated Bounding Box = 0.03153204917907715
# Step 3: filtering edges = 0.0042111873626708984
# Step 4: Inserted Key = 0.22301125526428223
# Total time = 0.5355732440948486
#
#
# 648518346349501587:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.27466559410095215
# Step 2: Calculated Bounding Box = 0.028042078018188477
# Step 3: filtering edges = 0.003940582275390625
# Step 4: Inserted Key = 0.19346046447753906
# Total time = 0.5087411403656006
#
#
# 648518346349501597:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.448758602142334
# Step 2: Calculated Bounding Box = 0.035314083099365234
# Step 3: filtering edges = 0.00793313980102539
# Step 4: Inserted Key = 0.24678492546081543
# Total time = 0.7482705116271973
#
#
# 648518346349501625:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4225459098815918
# Step 2: Calculated Bounding Box = 0.033325910568237305
# Step 3: filtering edges = 0.006133317947387695
# Step 4: Inserted Key = 0.2418050765991211
# Total time = 0.7118337154388428
#
#
# 648518346349501746:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2984187602996826
# Step 2: Calculated Bounding Box = 0.02897167205810547
# Step 3: filtering edges = 0.0056803226470947266
# Step 4: Inserted Key = 0.1954813003540039
# Total time = 0.5377366542816162
#
#
# 648518346349501787:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.25922346115112305
# Step 2: Calculated Bounding Box = 0.02441263198852539
# Step 3: filtering edges = 0.006163835525512695
# Step 4: Inserted Key = 0.16215801239013672
# Total time = 0.46027159690856934
#
#
# 648518346349502049:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3267662525177002
# Step 2: Calculated Bounding Box = 0.0337529182434082
# Step 3: filtering edges = 0.012236595153808594
# Step 4: Inserted Key = 0.2745168209075928
# Total time = 0.6559150218963623
#
#
# 648518346349502203:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.306563138961792
# Step 2: Calculated Bounding Box = 0.03203392028808594
# Step 3: filtering edges = 0.0056896209716796875
# Step 4: Inserted Key = 0.22610068321228027
# Total time = 0.578993558883667
#
#
# 648518346349502434:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3248023986816406
# Step 2: Calculated Bounding Box = 0.034357547760009766
# Step 3: filtering edges = 0.004342317581176758
# Step 4: Inserted Key = 0.24534368515014648
# Total time = 0.6169173717498779
#
#
# 648518346349502920:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2718045711517334
# Step 2: Calculated Bounding Box = 0.028450965881347656
# Step 3: filtering edges = 0.003682851791381836
# Step 4: Inserted Key = 0.20070719718933105
# Total time = 0.512772798538208
#
#
# 648518346349503011:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2986268997192383
# Step 2: Calculated Bounding Box = 0.02942681312561035
# Step 3: filtering edges = 0.004353523254394531
# Step 4: Inserted Key = 0.20788121223449707
# Total time = 0.548738956451416
#
#
# 648518346349503086:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19589924812316895
# Step 2: Calculated Bounding Box = 0.016818523406982422
# Step 3: filtering edges = 0.0027861595153808594
# Step 4: Inserted Key = 0.11352419853210449
# Total time = 0.33690571784973145
#
#
# 648518346349503140:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3980693817138672
# Step 2: Calculated Bounding Box = 0.034689903259277344
# Step 3: filtering edges = 0.0046732425689697266
# Step 4: Inserted Key = 0.25488829612731934
# Total time = 0.7000563144683838
#
#
# 648518346349503453:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.36793065071105957
# Step 2: Calculated Bounding Box = 0.03394937515258789
# Step 3: filtering edges = 0.005007505416870117
# Step 4: Inserted Key = 0.2554283142089844
# Total time = 0.6707394123077393
#
#
# 648518346349503473:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3344447612762451
# Step 2: Calculated Bounding Box = 0.03056502342224121
# Step 3: filtering edges = 0.004828453063964844
# Step 4: Inserted Key = 0.22210383415222168
# Total time = 0.6010017395019531
#
#
# 648518346349503591:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.35573697090148926
# Step 2: Calculated Bounding Box = 0.026308059692382812
# Step 3: filtering edges = 0.007501840591430664
# Step 4: Inserted Key = 0.19831299781799316
# Total time = 0.5968174934387207
#
#
# 648518346349503643:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.48630714416503906
# Step 2: Calculated Bounding Box = 0.04801797866821289
# Step 3: filtering edges = 0.005789518356323242
# Step 4: Inserted Key = 0.3403513431549072
# Total time = 0.8898236751556396
#
#
# 648518346349503766:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42624902725219727
# Step 2: Calculated Bounding Box = 0.037158966064453125
# Step 3: filtering edges = 0.004919290542602539
# Step 4: Inserted Key = 0.2552492618560791
# Total time = 0.7325735092163086
#
#
# 648518346349503767:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.340559720993042
# Step 2: Calculated Bounding Box = 0.030209064483642578
# Step 3: filtering edges = 0.007391691207885742
# Step 4: Inserted Key = 0.20850133895874023
# Total time = 0.5955438613891602
#
#
# 648518346349503924:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3784174919128418
# Step 2: Calculated Bounding Box = 0.03973126411437988
# Step 3: filtering edges = 0.00473475456237793
# Step 4: Inserted Key = 0.28346824645996094
# Total time = 0.7141284942626953
#
#
# 648518346349504065:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.464555025100708
# Step 2: Calculated Bounding Box = 0.03543424606323242
# Step 3: filtering edges = 0.0064318180084228516
# Step 4: Inserted Key = 0.24856805801391602
# Total time = 0.7630023956298828
#
#
# 648518346349504130:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.33575940132141113
# Step 2: Calculated Bounding Box = 0.030789852142333984
# Step 3: filtering edges = 0.005259037017822266
# Step 4: Inserted Key = 0.21074891090393066
# Total time = 0.591019868850708
#
#
# 648518346349504185:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4648735523223877
# Step 2: Calculated Bounding Box = 0.03635358810424805
# Step 3: filtering edges = 0.005163431167602539
# Step 4: Inserted Key = 0.2504081726074219
# Total time = 0.7655277252197266
#
#
# 648518346349504324:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.474285364151001
# Step 2: Calculated Bounding Box = 0.03138566017150879
# Step 3: filtering edges = 0.0053558349609375
# Step 4: Inserted Key = 0.22275400161743164
# Total time = 0.7430322170257568
#
#
# 648518346349504442:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.47141456604003906
# Step 2: Calculated Bounding Box = 0.032004594802856445
# Step 3: filtering edges = 0.0058362483978271484
# Step 4: Inserted Key = 0.2279064655303955
# Total time = 0.7464897632598877
#
#
# 648518346349504521:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.38745641708374023
# Step 2: Calculated Bounding Box = 0.029495716094970703
# Step 3: filtering edges = 0.005609750747680664
# Step 4: Inserted Key = 0.21863102912902832
# Total time = 0.6492340564727783
#
#
# 648518346349504565:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1495816707611084
# Step 2: Calculated Bounding Box = 0.015176534652709961
# Step 3: filtering edges = 0.0037741661071777344
# Step 4: Inserted Key = 0.10073161125183105
# Total time = 0.2759077548980713
#
#
# 648518346349504618:
# Soma found in Exhitatory

# %% [markdown]
# # debugging

# %%
#(schema.jobs & "table_name='__filtered_skeleton_minus_soma'").delete()

# %%
#FilteredSkeletonMinusSoma.drop()

# %%
notebook_start_time = time.time()
FilteredSkeletonMinusSoma.populate(reserve_jobs=True)
print(f"Entire Notebook = {time.time()-notebook_start_time}")

# %%
# ta3p100.CleansedMeshOrphan & (FilteredSkeletonMinusSoma() & "n_edges=0").proj()

# %%
# #investigating the error: arrays used as indices must be of integer (or boolean) type
# query_key = dict(segmentation=2,segment_id=648518346341378749)

# table=""
# vertices_soma,triangles_soma = (ta3p100.CompartmentFinal.ComponentFinal() & query_key
#                                 & "compartment_type='Soma'").fetch("vertex_indices","triangle_indices")

# if len(vertices_soma) > 0:
#     print("Soma found in Exhitatory")
#     #get the regular mesh from CleansedMesh
#     vertices_mesh,triangles_mesh = (ta3p100.CleansedMesh & query_key).fetch("vertices","triangles")
# else:
#     vertices_soma,triangles_soma = (ta3p100.CompartmentOrphan.ComponentOrphan() & query_key).fetch("vertex_indices","triangle_indices")
#     if len(vertices_soma) > 0:
#         print("Soma found in Orphans")
#         vertices_mesh,triangles_mesh = (ta3p100.CleansedMeshOrphan & query_key).fetch("vertices","triangles")
#     else:
#         print("No Soma exists for " + str(query_key["segment_id"]))
#         #return np.array([]),np.array([])

# ts_flatten = np.hstack(triangles_soma).astype("int64")
# type(ts_flatten[0])

# vertices_real = vertices_mesh[0]
# triangles_real = triangles_mesh[0]

# ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

# vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
# #return vertices_whole, triangles_whole
