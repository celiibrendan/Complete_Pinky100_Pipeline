# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.CoarseLabelFinal() #ta3p100.CoarseLabelOrphan()

# %%
#function that will filter out error triangles
def generate_neighborhood(triangles, num_vertices):
    neighborhood = dict()
    for i in range(num_vertices):
        neighborhood[i] = set()
    for node1, node2, node3 in triangles:
        neighborhood[node1].update([node2, node3])
        neighborhood[node2].update([node1, node3])
        neighborhood[node3].update([node1, node2])
    return neighborhood

def set_search_first(starting_node, neighborhood):
    """
    Modified Depth-First-Search utilizing sets to reduce duplicate checks:

    Neighborhood must be a dict with the keys being the vertex indices!
    """    
    visited_nodes = set()
    temp_stack = set()
    temp_stack.add(starting_node)
    while len(temp_stack) > 0:
        starting_node = temp_stack.pop()
        if starting_node not in visited_nodes:
            visited_nodes.add(starting_node)
            temp_stack.update(neighborhood[starting_node])
    return list(visited_nodes)
def get_connected_portions(neighborhood):
    neighborhood_copy = neighborhood.copy()
    portions = []
    while len(neighborhood_copy) > 0:
        starting_node = next(iter(neighborhood_copy))
        portion = set_search_first(starting_node, neighborhood_copy)
        for node in portion:
            neighborhood_copy.pop(node)
        portions.append(portion)
    return portions

def get_largest_portion_index(portions):
    portion_lengths = [len(portion) for portion in portions]
    return portion_lengths.index(max(portion_lengths))

def get_largest_portion(portions):
    return portions[get_largest_portion_index(portions)]

def remove_floating_artifacts(mesh,key,mesh_labels):    
    mesh_copy = mesh.copy()
    
#     #get the labels for the mesh
#     #find out if in Orphan Table or Regular Neuron Table
#     if len(ta3p100.CoarseLabelFinal() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
#     elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
#     else:
#         raise Exception('neuron' + str(key["segment_id"]) + 
#                         'not present in any labels!')

    
    #look for errors
    not_errors = [i for i,k in enumerate(mesh_labels["triangles"]) if k != 10]
    original_triangles = mesh["triangles"]
    """
    print(type(not_errors))
    print(len(not_errors))
    print("not_errors = "+ str(not_errors[:100]))
    print(type(original_triangles))
    print(len(original_triangles))
    #print(original_triangles)
    print("not_errors = " + str(original_triangles[not_errors]))
    """
    
    mesh_copy['triangles'] = np.array(original_triangles[not_errors])
    
    return mesh_copy


def remove_isolated_vertices(mesh):
    mesh_copy = mesh.copy()

    neighborhood = generate_neighborhood(mesh_copy['triangles'], len(mesh_copy['vertices']))
    isolated_nodes = [portion.pop() for portion in get_connected_portions(neighborhood) if len(portion) == 1]

    vertices = mesh_copy['vertices']
    triangles = mesh_copy['triangles']
    vertex_list = list(vertices)

    if len(isolated_nodes) > 0:
        num_isolated_nodes_passed = 0
        isolated_nodes_set = set(isolated_nodes)
        count_to_decrement = np.zeros(len(vertices))
        for i in range(len(vertices)):
            if i in isolated_nodes_set:
                num_isolated_nodes_passed += 1
            else:
                count_to_decrement[i] = num_isolated_nodes_passed

        for i, triangle in enumerate(triangles):
            start = time.time()
            node1, node2, node3 = triangle
            triangles[i][0] -= count_to_decrement[node1]
            triangles[i][1] -= count_to_decrement[node2]
            triangles[i][2] -= count_to_decrement[node3]
        for i, isolated_node in enumerate(isolated_nodes):
            vertex_list.pop(isolated_node - i)

    mesh_copy['vertices'] = np.array(vertex_list)

    return mesh_copy


def remove_error_segments(key):

    full_start = time.time()

    print(str(key['segment_id']) +  ":")
    start = time.time()

    #find out if in Orphan Table or Regular Neuron Table
    if len(ta3p100.CoarseLabelFinal() & key) > 0:
        mesh = (ta3p100.CleansedMesh & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
    elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
        mesh = (ta3p100.CleansedMeshOrphan & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
    else:
        raise Exception('neuron' + str(key["segment_id"]) + 
                        'not present in any labels!')
    
    print(key['segment_id'], "mesh fetched.", time.time() - start)
    start = time.time()
    
    #print(mesh['triangles'])
    myCounter = Counter(mesh_labels['triangles'])#.tolist())
    print(myCounter)
    
    keys = list(myCounter.keys())
    #print(len(keys))
    
    if len(keys) < 2 and keys[0] == 10:
        print("only error segments")
        key['n_vertices'] = 0
        key['n_triangles'] = 0
        key['vertices'] = np.ndarray([])
        key['triangles'] = np.ndarray([])
        
        print("This took ", time.time() - full_start, "seconds.")
        print()
        return key
    
    neighborhood = generate_neighborhood(mesh['triangles'], len(mesh['vertices']))
    print(key['segment_id'] , "neighborhood generated.", time.time() - start)
    start = time.time()
    
    mesh = remove_floating_artifacts(mesh,key,mesh_labels)
    print(key['segment_id'], "floating artifacts removed.", time.time() - start)
    start = time.time()

    mesh = remove_isolated_vertices(mesh)
    print(key['segment_id'], "isolated nodes removed.", time.time() - start)
    start = time.time()

    key['n_vertices'] = len(mesh['vertices'])
    key['n_triangles'] = len(mesh['triangles'])
    key['vertices'] = mesh['vertices']
    key['triangles'] = mesh['triangles']

    #self.insert1(key, skip_duplicates=True)
    print(key['segment_id'], "key successfully filtered.", time.time() - start)
    start = time.time()

    print("This took ", time.time() - full_start, "seconds.")
    print()
    return key

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY, this is outdated for one below"""
#
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_neurons")) == False:
    os.mkdir("pymesh_neurons")

# %%
#keysource for neuron table
ta3p100.CoarseLabelFinal()
print(len(ta3p100.CoarseLabelFinal()))
# Out:
# 322

# %%
ta3p100.CoarseLabelOrphan()
print(len(ta3p100.CoarseLabelOrphan()))
# Out:
# 702

# %%
ns_table = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
print(len(ns_table))
ns_table
# Out:
# 1024
# *segmentation  *segment_id
# +------------+ +------------+
# 2              64851834634136
# 2              64851834634137
# 2              64851834634138
# 2              64851834634139
# 2              64851834634279
# 2              64851834634280
# 2              64851834634938
# 2              64851834634946
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
#    ...
#  (1024 tuples)

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_neurons"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_neurons"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting remeshing_remove_non_man_edges")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuronRawSkeleton(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the component labels were updated
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_vertices   :int unsigned #number of vertices in mesh filtered of error segments
    n_triangles  :int unsigned #number of faces in mesh filtered of error segments
    vertices     :longblob #mesh data for vertices in mesh filtered of error segments
    triangles    :longblob #mesh data for faces in mesh filtered of error segments
     
    """
    
    key_source = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        new_key = remove_error_segments(key)
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        
        #where i deal with the error segments
        if new_key["vertices"].size<2:
            start_time = time.time()
            print("All faces were error segments, inserting dummy entry")
            #create the key with None
            new_key["n_vertices"] = 0
            new_key["n_triangles"] = 0
            new_key["vertices"] = np.array([]).astype(float)
            new_key["triangles"] = np.array([]).astype(float)
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["time_updated"]=str(datetime.datetime.now())
            self.insert1(new_key,skip_duplicates=True)
            
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = 0,
                                           correspondence=np.array([]).astype(float))
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            print(f"Step 2: Inserting dummy dictionary: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")
        
        else:
        
            #print("Step 2: Remove all error semgents")
            start_time = time.time()
            #pass the vertices and faces to pymeshfix to become watertight
            meshfix = pymeshfix.MeshFix(new_key["vertices"],new_key["triangles"])
            meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
            print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")

            #print("Step 2: Writing Off File")
            start_time = time.time()
            #write the new mesh to off file
            path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
            print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

            #Run the meshlabserver scripts
            start_time = time.time()
            output_mesh = meshlab_fix_manifold(key)
            print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

            print(output_mesh[:-4])

            #send to be skeletonized
            start_time = time.time()
            return_value = cm.calcification(output_mesh[:-4])
            if return_value > 0:
                raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                ' did not finish... exited with error code: ' + str(return_value))
            #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



            #read in the skeleton files into an array
            #start_time = time.time()
            
            ##****** this needs to be changed for reading them in******
            bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            correspondence_array = read_raw_skeleton(output_mesh[:-4]+"_correspondance.cgal")
            #print(bone_array)
            if len(bone_array) <= 0:
                raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
            
            if len(correspondence_array) <= 0:
                raise Exception('No CORRESPONDENCE generated for ' + str(new_key["segment_id"]))
                
            print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


            start_time = time.time()
            
            new_key["n_edges"] = bone_array.shape[0]
            new_key["edges"] = bone_array
            #new_key["branches"] = []

            time_updated = str(datetime.datetime.now())
            new_key["time_updated"]=time_updated
            #print(key)
            #if all goes well then write to database
            self.insert1(new_key,skip_duplicates=True)
            
            #create a new dictionary key to be inserted into correspondence table
            """
            time_updated      :timestamp    # the time at which the component labels were updated
            ---
            n_correspondence   :int unsigned #number of mappings from skeleton vert to original surface vert 
            correspondence     :longblob #array storing mapping of every skeleton vert to original surface vert  
            """
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = correspondence_array.shape[0],
                                           correspondence=correspondence_array)
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            os.system("rm "+str(path_and_filename)+"*")
            print(f"Step 6: Inserting both dictionaries: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#ta3p100.NeuronSkeletons()#.delete()
#(schema.jobs & "table_name='__neuron_skeletons'").delete()

# %%
start = time.time()
NeuronRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341366885:
# 648518346341366885 mesh fetched. 0.2574336528778076
# Counter({2: 320197, 4: 181581, 3: 110905, 10: 37892, 5: 19377})
# 648518346341366885 neighborhood generated. 4.493498802185059
# 648518346341366885 floating artifacts removed. 0.8022661209106445
# 648518346341366885 isolated nodes removed. 15.96192455291748
# 648518346341366885 key successfully filtered. 8.106231689453125e-06
# This took  21.517112255096436 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 21.69676375389099
# Step 2: Pymesh shrinkwrapping: 34.892839431762695
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.9085237979888916
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 7.681416034698486
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341366885_mls
# Step 5: Generating and reading Skeleton: 20.78913187980652
# Step 6: Inserting both dictionaries: 3.028934955596924
# Total time: 91.00106763839722
#
#
#
# 648518346341371119:
# 648518346341371119 mesh fetched. 0.20423364639282227
# Counter({2: 233189, 3: 135151, 5: 54489, 4: 20311, 6: 3141, 10: 2591, 12: 107})
# 648518346341371119 neighborhood generated. 3.450544595718384
# 648518346341371119 floating artifacts removed. 0.6844000816345215
# 648518346341371119 isolated nodes removed. 9.005055904388428
# 648518346341371119 key successfully filtered. 5.0067901611328125e-06
# This took  13.345484972000122 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 13.477358341217041
# Step 2: Pymesh shrinkwrapping: 31.24226951599121
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.041501998901367
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 5.449601411819458
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341371119_mls
# Step 5: Generating and reading Skeleton: 17.240833282470703
# Step 6: Inserting both dictionaries: 2.1981303691864014
# Total time: 71.65227460861206
#
#
#
# 648518346341388820:
# 648518346341388820 mesh fetched. 0.22747349739074707
# Counter({10: 132782, 2: 90894, 4: 81046, 5: 38338, 3: 12630})
# 648518346341388820 neighborhood generated. 2.808760166168213
# 648518346341388820 floating artifacts removed. 0.5227565765380859
# 648518346341388820 isolated nodes removed. 13.290676355361938
# 648518346341388820 key successfully filtered. 5.4836273193359375e-06
# This took  16.85051155090332 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 16.958836317062378
# Step 2: Pymesh shrinkwrapping: 17.46170735359192
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.0096909999847412
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.7787935733795166
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341388820_mls
# Step 5: Generating and reading Skeleton: 9.004510641098022
# Step 6: Inserting both dictionaries: 1.2146778106689453
# Total time: 48.4296875
#
#
#
# 648518346341393609:
# 648518346341393609 mesh fetched. 0.42481017112731934
# Counter({3: 551923, 10: 279336, 5: 66395, 2: 19358, 4: 8034, 6: 6019, 12: 229})
# 648518346341393609 neighborhood generated. 6.943431615829468
# 648518346341393609 floating artifacts removed. 1.3663272857666016
# 648518346341393609 isolated nodes removed. 44.74116611480713
# 648518346341393609 key successfully filtered. 7.3909759521484375e-06
# This took  53.47649788856506 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 53.77011728286743
# Step 2: Pymesh shrinkwrapping: 37.93228793144226
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.994157552719116
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 8.114940881729126
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341393609_mls
# Step 5: Generating and reading Skeleton: 25.61444640159607
# Step 6: Inserting both dictionaries: 3.16485333442688
# Total time: 131.59226322174072
#
#
#
# 648518346342797556:
# 648518346342797556 mesh fetched. 0.2741122245788574
# Counter({3: 445940, 2: 73627, 4: 65953, 5: 37077, 10: 12565, 12: 291})
# 648518346342797556 neighborhood generated. 4.803183555603027
# 648518346342797556 floating artifacts removed. 0.9563443660736084
# 648518346342797556 isolated nodes removed. 13.485183238983154
# 648518346342797556 key successfully filtered. 5.7220458984375e-06
# This took  19.519609451293945 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 19.714627742767334
# Step 2: Pymesh shrinkwrapping: 85.73661422729492
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.82010555267334
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 7.879521369934082
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342797556_mls
# Step 5: Generating and reading Skeleton: 24.57057499885559
# Step 6: Inserting both dictionaries: 2.9709982872009277
# Total time: 143.69333791732788
#
#
#
# 648518346342806978:
# 648518346342806978 mesh fetched. 0.2579152584075928
# Counter({10: 228854, 4: 125212, 3: 74345, 5: 49605, 2: 17632, 6: 2503, 12: 129})
# 648518346342806978 neighborhood generated. 3.671786308288574
# 648518346342806978 floating artifacts removed. 0.717461109161377
# 648518346342806978 isolated nodes removed. 22.607563734054565
# 648518346342806978 key successfully filtered. 8.106231689453125e-06
# This took  27.256150245666504 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 27.450145959854126
# Step 2: Pymesh shrinkwrapping: 12.329725503921509
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.1683075428009033
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 3.360633611679077
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342806978_mls
# Step 5: Generating and reading Skeleton: 11.796348810195923
# Step 6: Inserting both dictionaries: 1.2265715599060059
# Total time: 57.33311486244202
#
#
#
# 648518346349386137:
# 648518346349386137 mesh fetched. 0.10593676567077637
# Counter({3: 33521, 5: 23161})
# 648518346349386137 neighborhood generated. 0.5554342269897461
# 648518346349386137 floating artifacts removed. 0.11675429344177246
# 648518346349386137 isolated nodes removed. 0.5592584609985352
# 648518346349386137 key successfully filtered. 3.5762786865234375e-06
# This took  1.338179111480713 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.3547492027282715
# Step 2: Pymesh shrinkwrapping: 1.884566307067871
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.23851990699768066
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.3760929107666016
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349386137_mls
# Step 5: Generating and reading Skeleton: 6.342684507369995
# Step 6: Inserting both dictionaries: 0.41379642486572266
# Total time: 11.612708330154419
#
#
#
# 648518346349468264:
# 648518346349468264 mesh fetched. 0.22225165367126465
# Counter({2: 182399, 3: 165067, 4: 140826, 5: 57117, 6: 6773, 12: 114})
# 648518346349468264 neighborhood generated. 4.236335277557373
# 648518346349468264 floating artifacts removed. 0.8169035911560059
# 648518346349468264 isolated nodes removed. 5.54944920539856
# 648518346349468264 key successfully filtered. 4.76837158203125e-06
# This took  10.826044797897339 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 10.992831707000732
# Step 2: Pymesh shrinkwrapping: 28.213831424713135
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.5957744121551514
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 6.930109739303589
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349468264_mls
# Step 5: Generating and reading Skeleton: 23.100821495056152
# Step 6: Inserting both dictionaries: 2.4796688556671143
# Total time: 74.31615376472473
#
#
#
# 648518346349470171:
# 648518346349470171 mesh fetched. 0.2829434871673584
# Counter({3: 426152, 6: 110216, 5: 64321, 2: 30413, 12: 176})
# 648518346349470171 neighborhood generated. 4.762242317199707
# 648518346349470171 floating artifacts removed. 0.9268412590026855
# 648518346349470171 isolated nodes removed. 6.387372970581055
# 648518346349470171 key successfully filtered. 6.198883056640625e-06
# This took  12.360390663146973 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 12.548369884490967
# Step 2: Pymesh shrinkwrapping: 35.37773251533508
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.9481465816497803
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 7.761170148849487
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349470171_mls
# Step 5: Generating and reading Skeleton: 25.85899519920349
# Step 6: Inserting both dictionaries: 2.66017484664917
# Total time: 87.15561699867249
#
#
#
# 648518346349471156:
# 648518346349471156 mesh fetched. 0.22986125946044922
# Counter({3: 327936, 5: 138039, 6: 118183, 2: 2201, 12: 907, 10: 4})
# 648518346349471156 neighborhood generated. 4.578111171722412
# 648518346349471156 floating artifacts removed. 0.9137804508209229
# 648518346349471156 isolated nodes removed. 11.705778121948242
# 648518346349471156 key successfully filtered. 5.0067901611328125e-06
# This took  17.428756713867188 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 17.605661153793335
# Step 2: Pymesh shrinkwrapping: 141.40444588661194
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.3209667205810547
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 5.838705778121948
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349471156_mls
# Step 5: Generating and reading Skeleton: 18.202933311462402
# Step 6: Inserting both dictionaries: 2.531078577041626
# Total time: 187.90472054481506
#
#
#
# 648518346349471500:
# 648518346349471500 mesh fetched. 0.2842104434967041
# Counter({3: 329243, 5: 140768, 2: 47654, 10: 17565, 6: 9908, 12: 366})
# 648518346349471500 neighborhood generated. 4.20449686050415
# 648518346349471500 floating artifacts removed. 0.8061516284942627
# 648518346349471500 isolated nodes removed. 11.736088037490845
# 648518346349471500 key successfully filtered. 5.245208740234375e-06
# This took  17.03188943862915 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 17.19247269630432
# Step 2: Pymesh shrinkwrapping: 172.87543630599976
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.0125341415405273
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 5.119901657104492
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349471500_mls
# Step 5: Generating and reading Skeleton: 15.64911699295044
# Step 6: Inserting both dictionaries: 2.4382781982421875
# Total time: 215.28931164741516
#
#
#
# 648518346349471562:
# 648518346349471562 mesh fetched. 0.34942173957824707
# Counter({3: 545681, 2: 203138, 6: 88142, 5: 59724, 12: 2399})
# 648518346349471562 neighborhood generated. 6.77440333366394
# 648518346349471562 floating artifacts removed. 1.3105669021606445
# 648518346349471562 isolated nodes removed. 9.123893022537231
# 648518346349471562 key successfully filtered. 5.0067901611328125e-06
# This took  17.5593843460083 seconds.
#
# Step 1: Retrieving Mesh and removing error segments:
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500440_mls
# Step 5: Generating and reading Skeleton: 38.80279350280762
# Step 6: Inserting both dictionaries: 4.275750160217285
# Total time: 190.63403725624084
#
#
#
# 648518346349500742:
# 648518346349500742 mesh fetched. 0.11199522018432617
# Counter({3: 172284, 5: 44025, 2: 20166, 6: 2124, 12: 403})
# 648518346349500742 neighborhood generated. 2.0867159366607666
# 648518346349500742 floating artifacts removed. 0.4163377285003662
# 648518346349500742 isolated nodes removed. 2.8610899448394775
# 648518346349500742 key successfully filtered. 4.76837158203125e-06
# This took  5.477595806121826 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.5535523891448975
# Step 2: Pymesh shrinkwrapping: 18.62593102455139
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.268888235092163
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 3.037754774093628
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500742_mls
# Step 5: Generating and reading Skeleton: 13.815441608428955
# Step 6: Inserting both dictionaries: 1.3011021614074707
# Total time: 43.60427403450012
#
#
#
# 648518346349500886:
# 648518346349500886 mesh fetched. 0.1110072135925293
# Counter({5: 45342, 3: 32765, 6: 14498})
# 648518346349500886 neighborhood generated. 0.8897199630737305
# 648518346349500886 floating artifacts removed. 0.16391801834106445
# 648518346349500886 isolated nodes removed. 1.10495924949646
# 648518346349500886 key successfully filtered. 5.245208740234375e-06
# This took  2.2710275650024414 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.3012704849243164
# Step 2: Pymesh shrinkwrapping: 12.076940774917603
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.37001752853393555
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.477640151977539
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500886_mls
# Step 5: Generating and reading Skeleton: 4.872724294662476
# Step 6: Inserting both dictionaries: 0.5903050899505615
# Total time: 21.69080376625061
#
#
#
# 648518346349500939:
# 648518346349500939 mesh fetched. 0.3607330322265625
# Counter({3: 582264, 2: 140918, 6: 114859, 5: 61709, 12: 435, 10: 124})
# 648518346349500939 neighborhood generated. 7.606147527694702
# 648518346349500939 floating artifacts removed. 1.5697622299194336
# 648518346349500939 isolated nodes removed. 21.108487129211426
# 648518346349500939 key successfully filtered. 5.7220458984375e-06
# This took  30.645928859710693 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 30.964251279830933
# Step 2: Pymesh shrinkwrapping: 161.05339789390564
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 5.0007243156433105
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 12.040222644805908
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349500939_mls
# Step 5: Generating and reading Skeleton: 49.02736234664917
# Step 6: Inserting both dictionaries: 4.106686353683472
# Total time: 262.1940529346466
#
#
#
# 648518346349501746:
# 648518346349501746 mesh fetched. 0.21433115005493164
# Counter({3: 589331, 5: 133546, 2: 132191, 6: 12677, 12: 3})
# 648518346349501746 neighborhood generated. 7.27178955078125
# 648518346349501746 floating artifacts removed. 1.533930778503418
# 648518346349501746 isolated nodes removed. 11.207183599472046
# 648518346349501746 key successfully filtered. 5.9604644775390625e-06
# This took  20.22793960571289 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 20.55891466140747
# Step 2: Pymesh shrinkwrapping: 297.7863132953644
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 4.373147249221802
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 11.702175855636597
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349501746_mls
# Step 5: Generating and reading Skeleton: 40.87657332420349
# Step 6: Inserting both dictionaries: 4.522350549697876
# Total time: 379.82081604003906
#
#
#
# 648518346349503591:
# 648518346349503591 mesh fetched. 0.4062075614929199
# Counter({3: 705052, 2: 149144, 5: 145728, 6: 77463, 12: 1})
# 648518346349503591 neighborhood generated. 9.241927146911621
# 648518346349503591 floating artifacts removed. 1.8747055530548096
# 648518346349503591 isolated nodes removed. 13.686132669448853
# 648518346349503591 key successfully filtered. 1.4781951904296875e-05
# This took  25.212039470672607 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 25.824187517166138
# Step 2: Pymesh shrinkwrapping: 418.1537630558014
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 5
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346345537526_mls
# Step 5: Generating and reading Skeleton: 1.676079511642456
# Step 6: Inserting both dictionaries: 0.20285534858703613
# Total time: 3.232994556427002
#
#
#
# 648518346345768511:
# 648518346345768511 mesh fetched. 0.12227678298950195
# Counter({10: 115950})
# only error segments
# This took  0.17305660247802734 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.17317628860473633
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.029255390167236328
# Total time: 0.20288634300231934
#
#
#
# 648518346345770568:
# 648518346345770568 mesh fetched. 0.1223142147064209
# Counter({8: 48475})
# 648518346345770568 neighborhood generated. 0.518850564956665
# 648518346345770568 floating artifacts removed. 0.10328888893127441
# 648518346345770568 isolated nodes removed. 0.6438448429107666
# 648518346345770568 key successfully filtered. 4.76837158203125e-06
# This took  1.3893914222717285 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.4052915573120117
# Step 2: Pymesh shrinkwrapping: 1.9798989295959473
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2647519111633301
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0687010288238525
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346345770568_mls
# Step 5: Generating and reading Skeleton: 5.012359142303467
# Step 6: Inserting both dictionaries: 0.38399243354797363
# Total time: 10.11605715751648
#
#
#
# 648518346346307304:
# 648518346346307304 mesh fetched. 0.06511926651000977
# Counter({8: 22337})
# 648518346346307304 neighborhood generated. 0.22765493392944336
# 648518346346307304 floating artifacts removed. 0.04807281494140625
# 648518346346307304 isolated nodes removed. 0.2888662815093994
# 648518346346307304 key successfully filtered. 5.4836273193359375e-06
# This took  0.631101131439209 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6392934322357178
# Step 2: Pymesh shrinkwrapping: 0.6344537734985352
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12947893142700195
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9941682815551758
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346307304_mls
# Step 5: Generating and reading Skeleton: 1.268104076385498
# Step 6: Inserting both dictionaries: 0.21123051643371582
# Total time: 3.8777949810028076
#
#
#
# 648518346346584676:
# 648518346346584676 mesh fetched. 0.05988883972167969
# Counter({8: 62748})
# 648518346346584676 neighborhood generated. 0.703779935836792
# 648518346346584676 floating artifacts removed. 0.1303112506866455
# 648518346346584676 isolated nodes removed. 0.7410407066345215
# 648518346346584676 key successfully filtered. 5.245208740234375e-06
# This took  1.6358540058135986 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.6563670635223389
# Step 2: Pymesh shrinkwrapping: 2.5603246688842773
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4037799835205078
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.374114990234375
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346584676_mls
# Step 5: Generating and reading Skeleton: 3.732337713241577
# Step 6: Inserting both dictionaries: 0.474484920501709
# Total time: 10.202718257904053
#
#
#
# 648518346348106858:
# 648518346348106858 mesh fetched. 0.1318223476409912
# Counter({10: 32155})
# only error segments
# This took  0.14876174926757812 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.14895200729370117
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.021066904067993164
# Total time: 0.17019987106323242
#
#
#
# 648518346348107593:
# 648518346348107593 mesh fetched. 0.12446284294128418
# Counter({8: 11414})
# 648518346348107593 neighborhood generated. 0.1502516269683838
# 648518346348107593 floating artifacts removed. 0.025224685668945312
# 648518346348107593 isolated nodes removed. 0.21799755096435547
# 648518346348107593 key successfully filtered. 4.0531158447265625e-06
# This took  0.519556999206543 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.523125410079956
# Step 2: Pymesh shrinkwrapping: 0.30733156204223633
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06824111938476562
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6871979236602783
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348107593_mls
# Step 5: Generating and reading Skeleton: 1.0060441493988037
# Step 6: Inserting both dictionaries: 0.19141507148742676
# Total time: 2.7839646339416504
#
#
#
# 648518346348110498:
# 648518346348110498 mesh fetched. 0.13127827644348145
# Counter({8: 17682})
# 648518346348110498 neighborhood generated. 0.21463489532470703
# 648518346348110498 floating artifacts removed. 0.03760337829589844
# 648518346348110498 isolated nodes removed. 0.26965951919555664
# 648518346348110498 key successfully filtered. 5.245208740234375e-06
# This took  0.6544275283813477 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.66080641746521
# Step 2: Pymesh shrinkwrapping: 0.4243607521057129
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08885073661804199
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6785118579864502
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348110498_mls
# Step 5: Generating and reading Skeleton: 1.5348448753356934
# Step 6: Inserting both dictionaries: 0.22397351264953613
# Total time: 3.6121678352355957
#
#
#
# 648518346348120088:
# 648518346348120088 mesh fetched. 0.10604262351989746
# Counter({8: 26120, 10: 2636})
# 648518346348120088 neighborhood generated. 0.3468177318572998
# 648518346348120088 floating artifacts removed. 0.05914926528930664
# 648518346348120088 isolated nodes removed. 0.6653635501861572
# 648518346348120088 key successfully filtered. 3.5762786865234375e-06
# This took  1.1787035465240479 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.1873855590820312
# Step 2: Pymesh shrinkwrapping: 0.5946731567382812
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.13244056701660156
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8357865810394287
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348120088_mls
# Step 5: Generating and reading Skeleton: 1.765549898147583
# Step 6: Inserting both dictionaries: 0.27935004234313965
# Total time: 4.79593300819397
#
#
#
# 648518346348194828:
# 648518346348194828 mesh fetched. 0.0825796127319336
# Counter({8: 17813})
# 648518346348194828 neighborhood generated. 0.18621158599853516
# 648518346348194828 floating artifacts removed. 0.03809499740600586
# 648518346348194828 isolated nodes removed. 0.29712963104248047
# 648518346348194828 key successfully filtered. 5.4836273193359375e-06
# This took  0.6048860549926758 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6131591796875
# Step 2: Pymesh shrinkwrapping: 0.4458773136138916
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09238529205322266
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9015533924102783
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348194828_mls
# Step 5: Generating and reading Skeleton: 1.693434715270996
# Step 6: Inserting both dictionaries: 0.2077782154083252
# Total time: 3.954988479614258
#
#
#
# 648518346348199123:
# 648518346348199123 mesh fetched. 0.11747455596923828
# Counter({8: 73906})
# 648518346348199123 neighborhood generated. 0.7218143939971924
# 648518346348199123 floating artifacts removed. 0.13094258308410645
# 648518346348199123 isolated nodes removed. 0.8739001750946045
# 648518346348199123 key successfully filtered. 5.7220458984375e-06
# This took  1.845167636871338 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.868119239807129
# Step 2: Pymesh shrinkwrapping: 3.5222175121307373
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3915390968322754
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.3847832679748535
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348199123_mls
# Step 5: Generating and reading Skeleton: 4.081307649612427
# Step 6: Inserting both dictionaries: 0.5633029937744141
# Total time: 11.81244444847107
#
#
#
# 648518346348464469:
# 648518346348464469 mesh fetched. 0.156815767288208
# Counter({8: 24742})
# 648518346348464469 neighborhood generated. 0.2675185203552246
# 648518346348464469 floating artifacts removed. 0.0523533821105957
# 648518346348464469 isolated nodes removed. 0.30165600776672363
# 648518346348464469 key successfully filtered. 4.5299530029296875e-06
# This took  0.7791121006011963 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.7863965034484863
# Step 2: Pymesh shrinkwrapping: 0.5873703956604004
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12982392311096191
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9381084442138672
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348464469_mls
# Step 5: Generating and reading Skeleton: 1.6055521965026855
# Step 6: Inserting both dictionaries: 0.31111812591552734
# Total time: 4.359308958053589
#
#
#
# 648518346349377026:
# 648518346349377026 mesh fetched. 0.20869946479797363
# Counter({10: 48959})
# only error segments
# This took  0.2296140193939209 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.2297382354736328
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.05260872840881348
# Total time: 0.28250789642333984
#
#
#
# 648518346349377300:
# 648518346349377300 mesh fetched. 0.15860772132873535
# Counter({8: 79539})
# 648518346349377300 neighborhood generated. 0.8287532329559326
# 648518346349377300 floating artifacts removed. 0.14359641075134277
# 648518346349377300 isolated nodes removed. 0.8626973628997803
# 648518346349377300 key successfully filtered. 5.245208740234375e-06
# This took  1.994682788848877 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.0233333110809326
# Step 2: Pymesh shrinkwrapping: 2.5731191635131836
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5006732940673828
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.4753224849700928
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349377300_mls
# Step 5: Generating and reading Skeleton: 4.846979379653931
# Step 6: Inserting both dictionaries: 0.6421291828155518
# Total time: 12.064276218414307
#
#
#
# 648518346349383777:
# 648518346349383777 mesh fetched. 0.1718733310699463
# Counter({10: 91288})
# only error segments
# This took  0.2094724178314209 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.20961880683898926
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.031662702560424805
# Total time: 0.2414536476135254
#
#
#
# 648518346349384653:
# 648518346349384653 mesh fetched. 0.15264248847961426
# Counter({8: 42157})
# 648518346349384653 neighborhood generated. 0.3860447406768799
# 648518346349384653 floating artifacts removed. 0.07893872261047363
# 648518346349384653 isolated nodes removed. 0.4544868469238281
# 648518346349384653 key successfully filtered. 4.5299530029296875e-06
# This took  1.0734848976135254 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.0866646766662598
# Step 2: Pymesh shrinkwrapping: 1.0135748386383057
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.21918320655822754
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0338857173919678
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349384653_mls
# Step 5: Generating and reading Skeleton: 2.4929044246673584
# Step 6: Inserting both dictionaries: 0.41755151748657227
# Total time: 6.264689207077026
#
#
#
# 648518346349462807:
# 648518346349462807 mesh fetched. 0.30745506286621094
# Counter({8: 464459})
# 648518346349462807 neighborhood generated. 4.340089321136475
# 648518346349462807 floating artifacts removed. 0.882723331451416
# 648518346349462807 isolated nodes removed. 5.536564350128174
# 648518346349462807 key successfully filtered. 7.152557373046875e-06
# This took  11.068197011947632 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 11.279526233673096
# Step 2: Pymesh shrinkwrapping: 28.46675133705139
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.17498779296875
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 6.909843683242798
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349462807_mls
# Step 5: Generating and reading Skeleton: 23.705342054367065
# Step 6: Inserting both dictionaries: 2.5764644145965576
# Total time: 76.11450624465942
#
#
#
# 648518346349506558:
# 648518346349506558 mesh fetched. 0.1913468837738037
# Counter({10: 262458})
# only error segments
# This took  0.2570819854736328 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.2571849822998047
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.021820545196533203
# Total time: 0.27912163734436035
#
#
#
# 648518346349506571:
# 648518346349506571 mesh fetched. 0.0477900505065918
# Counter({8: 59084})
# 648518346349506571 neighborhood generated. 0.5502018928527832
# 648518346349506571 floating artifacts removed. 0.1255779266357422
# 648518346349506571 isolated nodes removed. 0.7530512809753418
# 648518346349506571 key successfully filtered. 5.7220458984375e-06
# This took  1.4776568412780762 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.5026869773864746
# Step 2: Pymesh shrinkwrapping: 2.8425443172454834
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3204357624053955
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.307671070098877
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349506571_mls
# Step 5: Generating and reading Skeleton: 3.1121978759765625
# Step 6: Inserting both dictionaries: 0.47865772247314453
# Total time: 9.565556287765503
#
#
#
# 9862.144878387451
