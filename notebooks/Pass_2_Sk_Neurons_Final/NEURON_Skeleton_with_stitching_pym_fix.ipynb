# %%
"""
Purpose: To create the skeletons for the neurons
-- adapted from the Neurite Skeleton that was run successfully on the Neurites

Labels will have to pull from: 
UndecimatedNeuronLabels


"""
# Out:
# '\nPurpose: To create the skeletons for the neurons\n-- adapted from the Neurite Skeleton that was run successfully on the Neurites\n\nLabels will have to pull from: \nUndecimatedNeuronLabels\n\n\n'

# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io
import trimesh

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from Skeleton_Stitcher import stitch_skeleton_with_degree_check, find_skeleton_distance

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 100

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURONS")) == False:
    os.mkdir("pymesh_NEURONS")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURONS"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURONS"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path(path_and_filename,segment_id=-1):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

def meshlab_fix_manifold_path_specific_mls(path_and_filename,segment_id=-1,meshlab_script=""):
    #fix the path if it comes with the extension
    if path_and_filename[-4:] == ".off":
        path_and_filename = path_and_filename[-4:]
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    #print("input_mesh = " + str(input_mesh))
    #print("output_mesh = " + str(output_mesh))
    if meshlab_script == "":
        meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("meshlab_script = " + str(meshlab_script))
    #print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(segment_id) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    print('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + script_command)
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %% [markdown]
# # Debugging the skeleton stitching function

# %%
# key = dict(segmentation=3,segment_id=648518346341395072)

# split_significance_threshold = 100

# global_time = time.time()
# #get the mesh with the error segments filtered away
# start_time = time.time()
# print(str(key['segment_id']) +  ":")
# my_dict = (pinky.Mesh & pinky.Neurite.proj() & pinky.CurrentSegmentation
#                    & key).fetch1()
# print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
# new_key = dict(segmentation=key["segmentation"],
#                segment_id=key["segment_id"])


# # Don't need these attributes      
# #vertices=key["vertices"],
# #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
# #                       n_triangles=key["n_triangles"])


# start_time = time.time()
# #pass the vertices and faces to pymeshfix to become watertight

# mesh = trimesh_io.Mesh(vertices=my_dict["vertices"], faces=my_dict["triangles"])

# """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
# count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
#                                                     mesh.edges_sparse,
#                                                     directed=False,
#                                                     return_labels=True)


# label_counter = Counter(labels)


# new_key["n_bodies"] = count
# values = np.array(labels)


# list_counter = Counter(labels)
# max_counter = max(list_counter.values())

# max_label = -1
# for label_key,label_number in list_counter.items():
#     if label_number==max_counter:
#         max_label = label_key
# print("max label = " + str(max_label))

# searchval = max_label

# ii = np.where(values == searchval)[0]
# new_key["largest_mesh_perc"] = len(ii)/len(labels)

# print("n_bodies = " + str(new_key["n_bodies"]))
# print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
# """



# total_splits = mesh.split(only_watertight=False)
# print(f"There were {len(total_splits)} after split and significance threshold")
# mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
# print(f"There were {len(mesh_pieces)} after split and significance threshold")
# for g,mh in enumerate(mesh_pieces):
#     print(f"Mesh piece {g} with number of faces {len(mh.faces)}")
    
# print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

# #get the largest mesh piece
# largest_mesh_index = -1
# largest_mesh_size = 0

# for t,msh in enumerate(mesh_pieces):
#     if len(msh.faces) > largest_mesh_size:
#         largest_mesh_index = t
#         largest_mesh_size = len(msh.faces) 

# #largest mesh piece
# largest_mesh_perc = largest_mesh_size/len(mesh.faces)
# new_key["largest_mesh_perc"] = largest_mesh_perc
# print("largest mesh perc = " + str(largest_mesh_perc))

# largest_mesh_skeleton_distance = -1

# paths_used = []
# total_edges = np.array([])
# for h,m in enumerate(mesh_pieces): 
    
#     print(f"Working on split {h} with face total = {len(m.faces)}")


#     start_time = time.time()
#     #pass the vertices and faces to pymeshfix to become watertight
#     meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
#     meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
#     print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

#     #print("Step 2: Writing Off File")
#     start_time = time.time()
#     #write the new mesh to off file
#     path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
#     print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
#     #add the path to be deleted later
#     paths_used.append(path_and_filename)


#     #Run the meshlabserver scripts
#     start_time = time.time()
#     output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
#     print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

#     print(output_mesh[:-4])

#     #send to be skeletonized
#     start_time = time.time()
#     return_value = cm.calcification(output_mesh[:-4])
#     if return_value > 0:
#         raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
#                         ' did not finish... exited with error code: ' + str(return_value))
#     #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



#     #read in the skeleton files into an array
#     bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

#     #print(bone_array)
#     if len(bone_array) <= 0:
#         raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
#     print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

#     #get the largest mesh skeleton distance
#     if h == largest_mesh_index:
#         largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

#     #add the skeleton edges to the total edges
#     if not total_edges.any():
#         total_edges = bone_array
#     else:
#         total_edges = np.vstack([total_edges,bone_array])

    

# total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

# #get the total skeleton distance for the stitched skeleton
# total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

# largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


# start_time = time.time()
# new_key["n_edges"] = len(total_edges_stitched)
# new_key["edges"] = bone_array
# new_key["n_bodies"] = len(total_splits)
# new_key["n_bodies_stitched"] = len(mesh_pieces)
# new_key["largest_mesh_perc"] = largest_mesh_perc
# new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc

# #self.insert1(new_key,skip_duplicates=True)
# print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
# #raise Exception("done with one neuron")
# for path_and_filename in paths_used:
#     os.system("rm "+str(path_and_filename)+"*")

# print(f"Total time: {time.time() - global_time}")
# print("\n\n")

# %%
pinky.UndecimatedNeuronLabels.describe()
# Out:
# # Undecimated Mesh Coarse and Overlayed Labels
# -> pinky.Mesh
# ---
# coarse_vertices_labels : longblob                     # vertex labels for the base compartments
# coarse_triangles_labels : longblob                     # traingle labels for the base compartments
# overlay_vertices_labels : longblob                     # vertex labels for the spine compartments overlayed over the base compartments
# overlay_triangles_labels : longblob                     # triangles labels for the spine compartments overlayed over the base compartments
# '# Undecimated Mesh Coarse and Overlayed Labels\n-> pinky.Mesh\n---\ncoarse_vertices_labels : longblob                     # vertex labels for the base compartments\ncoarse_triangles_labels : longblob                     # traingle labels for the base compartments\noverlay_vertices_labels : longblob                     # vertex labels for the spine compartments overlayed over the base compartments\noverlay_triangles_labels : longblob                     # triangles labels for the spine compartments overlayed over the base compartments\n'

# %%
coarse_test = np.array([4,5,5,5,5,6,7,1,2,10])
spine_test = np.array([12,13,5,5,14,15,2,3,10,2])

non_errors = coarse_test != 10
non_spines = spine_test<12

total_mesh_mask = np.logical_and(non_errors,non_spines)
total_mesh_mask

#get the indices 
total_indices = np.linspace(0,len(coarse_test)-1,len(coarse_test)).astype("int")
face_indexes = total_indices[total_mesh_mask]

print(coarse_test[face_indexes])
print(spine_test[face_indexes])
# Out:
# [5 5 7 1 2]
# [ 5  5  2  3 10]

# %%
help(trimesh.Trimesh.submesh)
# Out:
# Help on function submesh in module trimesh.base:
#
# submesh(self, faces_sequence, **kwargs)
#     Return a subset of the mesh.
#
#     Parameters
#     ----------
#     faces_sequence : sequence (m,) int
#       Face indices of mesh
#     only_watertight : bool
#       Only return submeshes which are watertight
#     append : bool
#       Return a single mesh which has the faces appended.
#       if this flag is set, only_watertight is ignored
#
#     Returns
#     ---------
#     if append : trimesh.Trimesh object
#     else :      list of trimesh.Trimesh objects

# %%
def get_mesh_minus_errors_and_spines(key):
    """
    Will retrieve the mesh from the database
    Retrieve the labels and then subtract the spines and error segments
    from the mesh to get a suitable submesh
    """
    
    #get the mesh
    verts,faces = (pinky.Mesh & key).fetch1("vertices","triangles")
    
    coarse_triangles_labels,overlay_triangles_labels = (pinky.UndecimatedNeuronLabels &
                                                           key).fetch1("coarse_triangles_labels","overlay_triangles_labels")
    
    #get the mask that will filter out errors and 
    non_errors = coarse_triangles_labels != 10
    non_spines = overlay_triangles_labels<12
    
    total_mesh_mask = np.logical_and(non_errors,non_spines)
    
    total_indices = np.linspace(0,len(coarse_triangles_labels)-1,len(coarse_triangles_labels)).astype("int")
    face_indexes = total_indices[total_mesh_mask]
    
    #get a trimesh object of this mesh and return the submesh
    current_mesh = trimesh.Trimesh(verts,faces,process=False)
    new_mesh = current_mesh.submesh([face_indexes],only_watertight=False,append=True)
    return new_mesh,face_indexes

# %%
@schema
class NeuronSkeletonStitched(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :int unsigned #the amount of segments the neurite was originally split into
    n_bodies_stitched  :int unsigned #the amount of segments whose skeletons were stitched back together (aka above the significance threshold)
    largest_mesh_perc : float #number of faces of largest submesh / number of faces of entire skeletal mesh
    largest_mesh_distance_perc : float #skeleton length of largest submesh / skeleton length of entire stitched mesh
    n_faces_in_filtered : int unsigned #number of faces in the mesh after spines and errors filtered away
    faces_in_filtered : longblob #array storing face indices used for submesh once errors and spines removed
    """
    
    
    key_source = ((dj.U("segmentation","segment_id") & pinky.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & pinky.CoarseLabelOrphan.proj()))
    
    def make(self, key):
        print("----------Working on " + str(key['segment_id']) +  ":----------")
        
        split_significance_threshold = 200

        global_time = time.time()
        
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        
        mesh,face_indexes = get_mesh_minus_errors_and_spines(key)
        
        
        """
        Handle the poosibility that there is no mesh
        """
        if len(mesh.faces) < 50:
            print(f"There were only {len(mesh.faces)} faces in mesh so not doing skeletonization")
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["n_bodies"] = 0
            new_key["n_bodies_stitched"] = 0
            new_key["largest_mesh_perc"] = 0
            new_key["largest_mesh_distance_perc"] = 0
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            self.insert1(new_key,skip_duplicates=True)
        else:


            print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
            new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])


            # Don't need these attributes      
            #vertices=key["vertices"],
            #                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
            #                       n_triangles=key["n_triangles"])


            start_time = time.time()
            
            """ OLDER WAY OF JUST GETTING THE LARGEST MESH PIECE
            count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                                mesh.edges_sparse,
                                                                directed=False,
                                                                return_labels=True)


            label_counter = Counter(labels)


            new_key["n_bodies"] = count
            values = np.array(labels)


            list_counter = Counter(labels)
            max_counter = max(list_counter.values())

            max_label = -1
            for label_key,label_number in list_counter.items():
                if label_number==max_counter:
                    max_label = label_key
            print("max label = " + str(max_label))

            searchval = max_label

            ii = np.where(values == searchval)[0]
            new_key["largest_mesh_perc"] = len(ii)/len(labels)

            print("n_bodies = " + str(new_key["n_bodies"]))
            print("largest mesh perc = " + str(new_key["largest_mesh_perc"]))
            """



            total_splits = mesh.split(only_watertight=False)
            print(f"There were {len(total_splits)} after split and significance threshold")
            mesh_pieces = [k for k in total_splits if len(k.faces) > split_significance_threshold]
            print(f"There were {len(mesh_pieces)} after split and significance threshold")
            for g,mh in enumerate(mesh_pieces):
                print(f"Mesh piece {g} with number of faces {len(mh.faces)}")

            print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")

            #get the largest mesh piece
            largest_mesh_index = -1
            largest_mesh_size = 0

            for t,msh in enumerate(mesh_pieces):
                if len(msh.faces) > largest_mesh_size:
                    largest_mesh_index = t
                    largest_mesh_size = len(msh.faces) 

            #largest mesh piece
            largest_mesh_perc = largest_mesh_size/len(mesh.faces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            print("largest mesh perc = " + str(largest_mesh_perc))

            largest_mesh_skeleton_distance = -1

            paths_used = []
            total_edges = np.array([])
            for h,m in enumerate(mesh_pieces): 
                print(f"Working on split {h} with face total = {len(m.faces)}")


    #             start_time = time.time()
    #             #pass the vertices and faces to pymeshfix to become watertight
    #             meshfix = pymeshfix.MeshFix(m.vertices,m.faces)
    #             meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
    #             print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

    #             #print("Step 2: Writing Off File")
    #             start_time = time.time()
    #             #write the new mesh to off file
    #             path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
    #             print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                #add the path to be deleted later
                path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),m.vertices,m.faces)

                paths_used.append(path_and_filename)


                #Run the meshlabserver scripts
                start_time = time.time()

                #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute.mls"
                output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)

                print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                print(output_mesh[:-4])

                #send to be skeletonized
                start_time = time.time()

                mls_mesh = trimesh.load_mesh(output_mesh)

                if len(mls_mesh.faces) < 20:
                    print("Number of faces are less than 20 so not generating skeleton")
                    continue

                return_value = cm.calcification(output_mesh[:-4])
                if return_value > 0:
                    print('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish... exited with error code: ' + str(return_value))

                    print("Trying skeletonization with pymesh")

                    #try to run the same skeletonization but now with skeletonization

                    #             start_time = time.time()
                    #pass the vertices and faces to pymeshfix to become watertight


                    meshfix = pymeshfix.MeshFix(mls_mesh.vertices,mls_mesh.faces)
                    meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
                    print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

                    if len(meshfix.f) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    #print("Step 2: Writing Off File")
                    start_time = time.time()
                    #write the new mesh to off file
                    path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]) + "_piece_" + str(h),meshfix.v,meshfix.f)
                    print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
                    #add the path to be deleted later
                    paths_used.append(path_and_filename)

                    #Run the meshlabserver scripts
                    start_time = time.time()

                    #output_mesh = meshlab_fix_manifold_path(path_and_filename,key["segment_id"])
                    meshlab_script = str(pathlib.Path.cwd()) + "/" + "pymesh_fix_substitute.mls"
                    output_mesh = meshlab_fix_manifold_path_specific_mls(path_and_filename,key["segment_id"],meshlab_script)

                    print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

                    #print(output_mesh[:-4])

                    #send to be skeletonized
                    start_time = time.time()

                    mls_mesh = trimesh.load_mesh(output_mesh)

                    if len(mls_mesh.faces) < 20:
                        print("Number of faces are less than 20 so not generating skeleton")
                        continue

                    return_value = cm.calcification(output_mesh[:-4])

                    if return_value > 0:
                        raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                    ' did not finish EVEN AFTER TRYING PYMESH... exited with error code: ' + str(return_value))



                print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



                #read in the skeleton files into an array
                bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

                #print(bone_array)
                if len(bone_array) <= 0:
                    raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
                print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")

                #get the largest mesh skeleton distance
                if h == largest_mesh_index:
                    largest_mesh_skeleton_distance = find_skeleton_distance(bone_array)

                #add the skeleton edges to the total edges
                if not total_edges.any():
                    total_edges = bone_array
                else:
                    total_edges = np.vstack([total_edges,bone_array])


            total_edges_stitched = stitch_skeleton_with_degree_check(total_edges)

            #get the total skeleton distance for the stitched skeleton
            total_skeleton_distance = find_skeleton_distance(total_edges_stitched)

            largest_mesh_distance_perc = largest_mesh_skeleton_distance/total_skeleton_distance


            start_time = time.time()
            new_key["n_edges"] = len(total_edges_stitched)
            new_key["edges"] = total_edges_stitched
            new_key["n_bodies"] = len(total_splits)
            new_key["n_bodies_stitched"] = len(mesh_pieces)
            new_key["largest_mesh_perc"] = largest_mesh_perc
            new_key["largest_mesh_distance_perc"] = largest_mesh_distance_perc
            new_key["n_faces_in_filtered"] = len(face_indexes)
            new_key["faces_in_filtered"] = face_indexes
            
            #print("new_key=" + str(new_key))

            self.insert1(new_key,skip_duplicates=True)
            print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
            #raise Exception("done with one neuron")
            for path_and_filename in paths_used:
                os.system("rm "+str(path_and_filename)+"*")

            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#(schema.jobs & "table_name='__neuron_skeleton_stitched'").delete()

# %%
NeuronSkeletonStitched()
# Out:
# *segmentation  *segment_id    n_edges     edges      n_bodies     n_bodies_stitc largest_mesh_p largest_mesh_d n_faces_in_fil faces_in_f
# +------------+ +------------+ +---------+ +--------+ +----------+ +------------+ +------------+ +------------+ +------------+ +--------+
# 3              64851834634137 968         =BLOB=     566          2              0.996315       0.991702       755588         =BLOB=
# 3              64851834634938 710         =BLOB=     227          6              0.854281       0.679992       114199         =BLOB=
# 3              64851834634947 7423        =BLOB=     918          35             0.844941       0.805346       1404154        =BLOB=
# 3              64851834634947 3145        =BLOB=     561          10             0.959784       0.94443        1030479        =BLOB=
# 3              64851834634947 958         =BLOB=     675          4              0.993288       0.981383       807086         =BLOB=
# 3              64851834634947 1252        =BLOB=     536          4              0.920257       0.860231       649811         =BLOB=
# 3              64851834634947 569         =BLOB=     188          1              0.993869       0.969544       222461         =BLOB=
# 3              64851834634947 1372        =BLOB=     406          4              0.912305       0.791954       541116         =BLOB=
# 3              64851834634947 894         =BLOB=     292          3              0.874951       0.798684       293526         =BLOB=
# 3              64851834634949 3053        =BLOB=     614          15             0.606554       0.481438       467818         =BLOB=
# 3              64851834634949 4668        =BLOB=     251          27             0.661819       0.438818       315393         =BLOB=
# 3              64851834634949 2936        =BLOB=     735          15             0.48161        0.416079       520396         =BLOB=
#  (12 tuples)

# %%
start = time.time()
NeuronSkeletonStitched.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# ----------Working on 648518346341371119:----------
# Step 1: Retrieving Mesh and removing error segments: 1.1353261470794678
# There were 566 after split and significance threshold
# There were 2 after split and significance threshold
# Mesh piece 0 with number of faces 752804
# Mesh piece 1 with number of faces 469
# Step 2a: Getting the number of splits: 1.030064582824707
# largest mesh perc = 0.9963154523364585
# Working on split 0 with face total = 752804
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 42.153817892074585
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_0_mls
# Step 5: Generating Skeleton: 33.13654088973999
# Step 5: Generating and reading Skeleton: 33.19877862930298
# Working on split 1 with face total = 469
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_1.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9725899696350098
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346341371119_piece_1_mls
# Step 5: Generating Skeleton: 0.022470951080322266
# Step 5: Generating and reading Skeleton: 0.023130416870117188
# len_subgraphs AT BEGINNING = 5
# min_dist = 628.2917236443599
# min_dist_subgraph_index = 2
# min_dist_edge_index = [480, 485]
# min_dist_edge = [array([384006. , 290960. ,  19060.8]), array([384358. , 291030. ,  18545.1])]
# len_subgraphs AT END= 4
# min_dist = 840.095167228095
# min_dist_subgraph_index = 1
# min_dist_edge_index = [270, 275]
# min_dist_edge = [array([369459. , 218669. ,  21160.7]), array([369742., 218133.,  20579.])]
# len_subgraphs AT END= 3
# min_dist = 1416.5236355246604
# min_dist_subgraph_index = 2
# min_dist_edge_index = [840, 872]
# min_dist_edge = [array([423358. , 283726. ,  30071.6]), array([424699. , 283851. ,  30510.5])]
# len_subgraphs AT END= 2
# min_dist = 4127.738108213746
# min_dist_subgraph_index = 1
# min_dist_edge_index = [805, 830]
# min_dist_edge = [array([418720., 284351.,  23029.]), array([422068. , 286188. ,  21462.3])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.7118031978607178
# Total time: 83.8091893196106
#
#
#
# ----------Working on 648518346349386137:----------
# Step 1: Retrieving Mesh and removing error segments: 0.25586962699890137
# There were 227 after split and significance threshold
# There were 6 after split and significance threshold
# Mesh piece 0 with number of faces 97558
# Mesh piece 1 with number of faces 12086
# Mesh piece 2 with number of faces 207
# Mesh piece 3 with number of faces 355
# Mesh piece 4 with number of faces 1238
# Mesh piece 5 with number of faces 232
# Step 2a: Getting the number of splits: 0.22008919715881348
# largest mesh perc = 0.8542806854701004
# Working on split 0 with face total = 97558
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 5.778308391571045
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_0_mls
# skeletonization for neuron 648518346349386137 did not finish... exited with error code: 4
# Trying skeletonization with pymesh
# Step 2b: Pymesh shrinkwrapping: 19.266601085662842
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.34259772300720215
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.934572458267212
# Step 5: Generating Skeleton: 2.935995578765869
# Step 5: Generating and reading Skeleton: 2.9404592514038086
# Working on split 1 with face total = 12086
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_1.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.260730266571045
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_1_mls
# Step 5: Generating Skeleton: 0.4050595760345459
# Step 5: Generating and reading Skeleton: 0.40735626220703125
# Working on split 2 with face total = 207
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_2.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9418535232543945
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_2_mls
# Step 5: Generating Skeleton: 0.012915611267089844
# Step 5: Generating and reading Skeleton: 0.013758659362792969
# Working on split 3 with face total = 355
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_3.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9449265003204346
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_3_mls
# Step 5: Generating Skeleton: 0.00632786750793457
# Step 5: Generating and reading Skeleton: 0.007459878921508789
# Working on split 4 with face total = 1238
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_4.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9721927642822266
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_4_mls
# Step 5: Generating Skeleton: 0.11830544471740723
# Step 5: Generating and reading Skeleton: 0.11905097961425781
# Working on split 5 with face total = 232
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_5.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0129165649414062
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349386137_piece_5_mls
# Step 5: Generating Skeleton: 0.010459423065185547
# Step 5: Generating and reading Skeleton: 0.011099815368652344
# len_subgraphs AT BEGINNING = 9
# min_dist = 1193.844734460893
# min_dist_subgraph_index = 7
# min_dist_edge_index = [236, 221]
# min_dist_edge = [array([411716. , 172376. ,  11839.2]), array([411346. , 172041. ,  12923.7])]
# len_subgraphs AT END= 8
# min_dist = 984.7532482810096
# min_dist_subgraph_index = 7
# min_dist_edge_index = [425, 488]
# min_dist_edge = [array([417497., 175922.,  20123.]), array([418008. , 175086. ,  20221.6])]
# len_subgraphs AT END= 7
# min_dist = 1676.4006168276126
# min_dist_subgraph_index = 6
# min_dist_edge_index = [134, 138]
# min_dist_edge = [array([397113.  , 164893.  ,   9929.09]), array([397315., 163345.,  10540.])]
# len_subgraphs AT END= 6
# min_dist = 498.44293555029964
# min_dist_subgraph_index = 5
# min_dist_edge_index = [138, 137]
# min_dist_edge = [array([397315., 163345.,  10540.]), array([397296. , 162896. ,  10324.4])]
# len_subgraphs AT END= 5
# min_dist = 1995.2179133117265
# min_dist_subgraph_index = 4
# min_dist_edge_index = [108, 111]
# min_dist_edge = [array([393905.  , 161727.  ,   6218.96]), array([394149., 159747.,   6188.])]
# len_subgraphs AT END= 4
# min_dist = 1045.1142008890702
# min_dist_subgraph_index = 1
# min_dist_edge_index = [110, 89]
# min_dist_edge = [array([394149., 159746.,   6188.]), array([393105.  , 159734.  ,   6234.73])]
# len_subgraphs AT END= 3
# min_dist = 1035.4695186725683
# min_dist_subgraph_index = 1
# min_dist_edge_index = [89, 91]
# min_dist_edge = [array([393105.  , 159734.  ,   6234.73]), array([393343.  , 158744.  ,   6423.02])]
# len_subgraphs AT END= 2
# min_dist = 2383.9510067323104
# min_dist_subgraph_index = 1
# min_dist_edge_index = [112, 97]
# min_dist_edge = [array([394270.  , 164000.  ,   8291.45]), array([393401. , 163735. ,  10495.5])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.07770562171936035
# Total time: 39.2186496257782
#
#
#
# ----------Working on 648518346349470171:----------
# Step 1: Retrieving Mesh and removing error segments: 2.0630874633789062
# There were 918 after split and significance threshold
# There were 35 after split and significance threshold
# Mesh piece 0 with number of faces 1186428
# Mesh piece 1 with number of faces 54028
# Mesh piece 2 with number of faces 16458
# Mesh piece 3 with number of faces 25424
# Mesh piece 4 with number of faces 8481
# Mesh piece 5 with number of faces 6988
# Mesh piece 6 with number of faces 5608
# Mesh piece 7 with number of faces 8374
# Mesh piece 8 with number of faces 5420
# Mesh piece 9 with number of faces 3524
# Mesh piece 10 with number of faces 6432
# Mesh piece 11 with number of faces 5897
# Mesh piece 12 with number of faces 6510
# Mesh piece 13 with number of faces 8959
# Mesh piece 14 with number of faces 348
# Mesh piece 15 with number of faces 268
# Mesh piece 16 with number of faces 9077
# Mesh piece 17 with number of faces 1256
# Mesh piece 18 with number of faces 236
# Mesh piece 19 with number of faces 1390
# Mesh piece 20 with number of faces 7649
# Mesh piece 21 with number of faces 12177
# Mesh piece 22 with number of faces 2672
# Mesh piece 23 with number of faces 5268
# Mesh piece 24 with number of faces 1724
# Mesh piece 25 with number of faces 327
# Mesh piece 26 with number of faces 1456
# Mesh piece 27 with number of faces 2511
# Mesh piece 28 with number of faces 1526
# Mesh piece 29 with number of faces 2184
# Mesh piece 30 with number of faces 625
# Mesh piece 31 with number of faces 318
# Mesh piece 32 with number of faces 260
# Mesh piece 33 with number of faces 260
# Mesh piece 34 with number of faces 396
# Step 2a: Getting the number of splits: 1.960341453552246
# largest mesh perc = 0.8449415092646533
# Working on split 0 with face total = 1186428
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 70.21137475967407
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_0_mls
# Step 5: Generating Skeleton: 54.938769578933716
# Step 5: Generating and reading Skeleton: 54.947479009628296
# Working on split 1 with face total = 54028
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_1.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 2.773001194000244
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_1_mls
# Step 5: Generating Skeleton: 1.5740442276000977
# Step 5: Generating and reading Skeleton: 1.5772490501403809
# Working on split 2 with face total = 16458
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_2.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.4758760929107666
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_2_mls
# Step 5: Generating Skeleton: 0.4296243190765381
# Step 5: Generating and reading Skeleton: 0.43178415298461914
# Working on split 3 with face total = 25424
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_3.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.6384694576263428
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_3_mls
# Step 5: Generating Skeleton: 1.308037281036377
# Step 5: Generating and reading Skeleton: 1.3102717399597168
# Working on split 4 with face total = 8481
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_4.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1551852226257324
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_4_mls
# Step 5: Generating Skeleton: 0.3815779685974121
# Step 5: Generating and reading Skeleton: 0.383786678314209
# Working on split 5 with face total = 6988
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_5.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.171867847442627
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_5_mls
# Step 5: Generating Skeleton: 0.30994105339050293
# Step 5: Generating and reading Skeleton: 0.31160521507263184
# Working on split 6 with face total = 5608
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_6.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1528346538543701
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_6_mls
# Step 5: Generating Skeleton: 0.22222256660461426
# Step 5: Generating and reading Skeleton: 0.22475886344909668
# Working on split 7 with face total = 8374
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_7.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1617558002471924
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_7_mls
# Step 5: Generating Skeleton: 0.47473740577697754
# Step 5: Generating and reading Skeleton: 0.47612714767456055
# Working on split 8 with face total = 5420
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_8.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.093341588973999
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_8_mls
# Step 5: Generating Skeleton: 0.300368070602417
# Step 5: Generating and reading Skeleton: 0.30222344398498535
# Working on split 9 with face total = 3524
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_9.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0748894214630127
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_9_mls
# Step 5: Generating Skeleton: 0.14054656028747559
# Step 5: Generating and reading Skeleton: 0.1414179801940918
# Working on split 10 with face total = 6432
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_10.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_10_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1999764442443848
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_10_mls
# Step 5: Generating Skeleton: 0.25408339500427246
# Step 5: Generating and reading Skeleton: 0.25659847259521484
# Working on split 11 with face total = 5897
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_11.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_11_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1199572086334229
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_11_mls
# Step 5: Generating Skeleton: 0.26276659965515137
# Step 5: Generating and reading Skeleton: 0.2642099857330322
# Working on split 12 with face total = 6510
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_12.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_12_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1313250064849854
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_12_mls
# Step 5: Generating Skeleton: 0.5280272960662842
# Step 5: Generating and reading Skeleton: 0.5301170349121094
# Working on split 13 with face total = 8959
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_13.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_13_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.2300670146942139
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_13_mls
# Step 5: Generating Skeleton: 0.4436309337615967
# Step 5: Generating and reading Skeleton: 0.4452512264251709
# Working on split 14 with face total = 348
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_14.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_14_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9776544570922852
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_14_mls
# Step 5: Generating Skeleton: 0.02960515022277832
# Step 5: Generating and reading Skeleton: 0.030775070190429688
# Working on split 15 with face total = 268
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_15.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_15_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9997975826263428
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_15_mls
# Step 5: Generating Skeleton: 0.03352618217468262
# Step 5: Generating and reading Skeleton: 0.03419756889343262
# Working on split 16 with face total = 9077
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_16.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_16_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.2906343936920166
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_16_mls
# Step 5: Generating Skeleton: 0.4065711498260498
# Step 5: Generating and reading Skeleton: 0.4080781936645508
# Working on split 17 with face total = 1256
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_17.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_17_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9950745105743408
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_17_mls
# Step 5: Generating Skeleton: 0.06430840492248535
# Step 5: Generating and reading Skeleton: 0.06476879119873047
# Working on split 18 with face total = 236
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_18.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_18_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9656233787536621
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_18_mls
# Step 5: Generating Skeleton: 0.021840572357177734
# Step 5: Generating and reading Skeleton: 0.023090362548828125
# Working on split 19 with face total = 1390
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_19.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_19_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0073060989379883
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_19_mls
# Step 5: Generating Skeleton: 0.09204626083374023
# Step 5: Generating and reading Skeleton: 0.09568262100219727
# Working on split 20 with face total = 7649
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_20.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_20_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1394367218017578
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_20_mls
# Step 5: Generating Skeleton: 0.5072460174560547
# Step 5: Generating and reading Skeleton: 0.5084779262542725
# Working on split 21 with face total = 12177
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_21.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_21_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.302905559539795
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_21_mls
# Step 5: Generating Skeleton: 0.40149736404418945
# Step 5: Generating and reading Skeleton: 0.40352535247802734
# Working on split 22 with face total = 2672
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_22.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_22_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0226001739501953
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_22_mls
# Step 5: Generating Skeleton: 0.10799884796142578
# Step 5: Generating and reading Skeleton: 0.10880851745605469
# Working on split 23 with face total = 5268
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_23.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_23_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.102067232131958
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_23_mls
# Step 5: Generating Skeleton: 0.19146013259887695
# Step 5: Generating and reading Skeleton: 0.19213008880615234
# Working on split 24 with face total = 1724
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_24.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_24_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.1495447158813477
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_24_mls
# Step 5: Generating Skeleton: 0.12369561195373535
# Step 5: Generating and reading Skeleton: 0.1254582405090332
# Working on split 25 with face total = 327
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_25.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_25_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0162787437438965
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_25_mls
# Step 5: Generating Skeleton: 0.019416093826293945
# Step 5: Generating and reading Skeleton: 0.020395755767822266
# Working on split 26 with face total = 1456
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_26.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_26_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9776716232299805
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_26_mls
# Step 5: Generating Skeleton: 0.15205979347229004
# Step 5: Generating and reading Skeleton: 0.15339946746826172
# Working on split 27 with face total = 2511
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_27.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_27_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.009251594543457
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_27_mls
# Step 5: Generating Skeleton: 0.1688241958618164
# Step 5: Generating and reading Skeleton: 0.16984009742736816
# Working on split 28 with face total = 1526
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_28.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_28_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9869210720062256
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_28_mls
# Step 5: Generating Skeleton: 0.12598490715026855
# Step 5: Generating and reading Skeleton: 0.1265277862548828
# Working on split 29 with face total = 2184
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_29.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_29_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0276563167572021
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_29_mls
# Step 5: Generating Skeleton: 0.19085383415222168
# Step 5: Generating and reading Skeleton: 0.19374465942382812
# Working on split 30 with face total = 625
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_30.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_30_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0508980751037598
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_30_mls
# Step 5: Generating Skeleton: 0.04295802116394043
# Step 5: Generating and reading Skeleton: 0.04378390312194824
# Working on split 31 with face total = 318
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_31.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_31_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9551308155059814
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_31_mls
# Step 5: Generating Skeleton: 0.023229598999023438
# Step 5: Generating and reading Skeleton: 0.024084091186523438
# Working on split 32 with face total = 260
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_32.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_32_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9448421001434326
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_32_mls
# Step 5: Generating Skeleton: 0.030642271041870117
# Step 5: Generating and reading Skeleton: 0.031452178955078125
# Working on split 33 with face total = 260
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_33.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_33_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9895193576812744
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_33_mls
# Step 5: Generating Skeleton: 0.017060041427612305
# Step 5: Generating and reading Skeleton: 0.01765894889831543
# Working on split 34 with face total = 396
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_34.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_34_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.99178147315979
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349470171_piece_34_mls
# Step 5: Generating Skeleton: 0.026084184646606445
# Step 5: Generating and reading Skeleton: 0.026950597763061523
# len_subgraphs AT BEGINNING = 42
# min_dist = 90.02532976890772
# min_dist_subgraph_index = 6
# min_dist_edge_index = [1655, 1658]
# min_dist_edge = [array([414366. , 204403. ,  81610.3]), array([414449. , 204393. ,  81576.9])]
# len_subgraphs AT END= 41
# min_dist = 119.34303498738541
# min_dist_subgraph_index = 3
# min_dist_edge_index = [362, 364]
# min_dist_edge = [array([372663. , 245795. ,  60676.9]), array([372717. , 245766. ,  60779.3])]
# len_subgraphs AT END= 40
# min_dist = 398.55860296824466
# min_dist_subgraph_index = 13
# min_dist_edge_index = [3676, 3672]
# min_dist_edge = [array([440825., 223925.,  34960.]), array([440723. , 223889. ,  34576.4])]
# len_subgraphs AT END= 39
# min_dist = 606.3895200281746
# min_dist_subgraph_index = 4
# min_dist_edge_index = [944, 890]
# min_dist_edge = [array([397354. , 201605. ,  52727.9]), array([396828. , 201531. ,  52435.4])]
# len_subgraphs AT END= 38
# min_dist = 1376.3038218358606
# min_dist_subgraph_index = 19
# min_dist_edge_index = [4524, 4401]
# min_dist_edge = [array([447552. , 197701. ,  34361.2]), array([447104. , 197538. ,  33070.1])]
# len_subgraphs AT END= 37
# min_dist = 1030.0339800220186
# min_dist_subgraph_index = 16
# min_dist_edge_index = [4398, 4368]
# min_dist_edge = [array([447091., 197536.,  33069.]), array([446667., 197223.,  32184.])]
# len_subgraphs AT END= 36
# min_dist = 211.6045604423495
# min_dist_subgraph_index = 15
# min_dist_edge_index = [4368, 4333]
# min_dist_edge = [array([446667., 197223.,  32184.]), array([446467. , 197283. ,  32218.3])]
# len_subgraphs AT END= 35
# min_dist = 726.6018442035504
# min_dist_subgraph_index = 15
# min_dist_edge_index = [4368, 4379]
# min_dist_edge = [array([446667., 197223.,  32184.]), array([446779. , 196629. ,  31780.8])]
# len_subgraphs AT END= 34
# min_dist = 708.567823147508
# min_dist_subgraph_index = 14
# min_dist_edge_index = [4379, 4354]
# min_dist_edge = [array([446779. , 196629. ,  31780.8]), array([446541. , 196678. ,  31115.2])]
# len_subgraphs AT END= 33
# min_dist = 1527.7543519820183
# min_dist_subgraph_index = 1
# min_dist_edge_index = [300, 298]
# min_dist_edge = [array([362459. , 212072. ,  16443.1]), array([361164. , 211888. ,  15653.7])]
# len_subgraphs AT END= 32
# min_dist = 1733.1267149288292
# min_dist_subgraph_index = 12
# min_dist_edge_index = [4191, 4152]
# min_dist_edge = [array([445846. , 196801. ,  29087.8]), array([445378. , 196314. ,  27491.7])]
# len_subgraphs AT END= 31
# min_dist = 1336.382370431456
# min_dist_subgraph_index = 13
# min_dist_edge_index = [4521, 4424]
# min_dist_edge = [array([447541. , 199327. ,  15773.4]), array([447350. , 199706. ,  14506.2])]
# len_subgraphs AT END= 30
# min_dist = 1929.1418424003973
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1022, 988]
# min_dist_edge = [array([398737.  , 172500.  ,   6871.71]), array([397834. , 172007. ,   5239.8])]
# len_subgraphs AT END= 29
# min_dist = 1992.6246610940013
# min_dist_subgraph_index = 16
# min_dist_edge_index = [5637, 5582]
# min_dist_edge = [array([451674. , 199681. ,  35009.7]), array([451495. , 200238. ,  33104.9])]
# len_subgraphs AT END= 28
# min_dist = 1184.9109207024783
# min_dist_subgraph_index = 15
# min_dist_edge_index = [5588, 5388]
# min_dist_edge = [array([451506. , 200249. ,  33087.7]), array([450863., 200599.,  32156.])]
# len_subgraphs AT END= 27
# min_dist = 826.3283185272055
# min_dist_subgraph_index = 14
# min_dist_edge_index = [5339, 5335]
# min_dist_edge = [array([450747. , 200543. ,  32137.3]), array([450723., 200731.,  31333.])]
# len_subgraphs AT END= 26
# min_dist = 1149.1210945761986
# min_dist_subgraph_index = 13
# min_dist_edge_index = [5034, 4948]
# min_dist_edge = [array([450291. , 205436. ,  22031.3]), array([450102. , 206279. ,  21273.6])]
# len_subgraphs AT END= 25
# min_dist = 759.854749277782
# min_dist_subgraph_index = 12
# min_dist_edge_index = [5006, 4906]
# min_dist_edge = [array([450249. , 209745. ,  17970.2]), array([449987., 209736.,  17257.])]
# len_subgraphs AT END= 24
# min_dist = 1306.4836049487942
# min_dist_subgraph_index = 12
# min_dist_edge_index = [5625, 5657]
# min_dist_edge = [array([451653. , 212813. ,  15298.3]), array([451975. , 213606. ,  14311.2])]
# len_subgraphs AT END= 23
# min_dist = 1071.869810191517
# min_dist_subgraph_index = 13
# min_dist_edge_index = [5778, 5927]
# min_dist_edge = [array([452515. , 214959. ,  12050.5]), array([453092. , 214954. ,  11147.2])]
# len_subgraphs AT END= 22
# min_dist = 1527.7569678780715
# min_dist_subgraph_index = 14
# min_dist_edge_index = [5888, 6099]
# min_dist_edge = [array([452984.  , 216309.  ,   8338.57]), array([453708. , 216716. ,   7056.3])]
# len_subgraphs AT END= 21
# min_dist = 2058.301484234027
# min_dist_subgraph_index = 14
# min_dist_edge_index = [6267, 6488]
# min_dist_edge = [array([454651. , 198050. ,  47811.7]), array([456219. , 199191. ,  48501.7])]
# len_subgraphs AT END= 20
# min_dist = 2219.5602469858786
# min_dist_subgraph_index = 10
# min_dist_edge_index = [4003, 4009]
# min_dist_edge = [array([444288. , 255805. ,  34914.9]), array([444374. , 254391. ,  33206.2])]
# len_subgraphs AT END= 19
# min_dist = 1124.0247728586787
# min_dist_subgraph_index = 9
# min_dist_edge_index = [4027, 3975]
# min_dist_edge = [array([444380. , 254108. ,  32960.8]), array([443891. , 253393. ,  32244.5])]
# len_subgraphs AT END= 18
# min_dist = 253.81575995197838
# min_dist_subgraph_index = 9
# min_dist_edge_index = [4381, 4387]
# min_dist_edge = [array([446806. , 248076. ,  21756.4]), array([446930. , 248028. ,  21540.2])]
# len_subgraphs AT END= 17
# min_dist = 695.554627617415
# min_dist_subgraph_index = 8
# min_dist_edge_index = [3524, 3516]
# min_dist_edge = [array([437887. , 247829. ,  22406.5]), array([437559. , 247598. ,  21838.3])]
# len_subgraphs AT END= 16
# min_dist = 699.0574010766212
# min_dist_subgraph_index = 8
# min_dist_edge_index = [5737, 5770]
# min_dist_edge = [array([452224. , 248074. ,  17921.2]), array([452454. , 248045. ,  17261.7])]
# len_subgraphs AT END= 15
# min_dist = 860.5748079045773
# min_dist_subgraph_index = 8
# min_dist_edge_index = [6295, 6277]
# min_dist_edge = [array([454846. , 247605. ,  17230.5]), array([454748. , 247714. ,  18078.5])]
# len_subgraphs AT END= 14
# min_dist = 2263.487187946952
# min_dist_subgraph_index = 7
# min_dist_edge_index = [3031, 2962]
# min_dist_edge = [array([431030. , 183575. ,  53098.8]), array([429187. , 184330. ,  52023.3])]
# len_subgraphs AT END= 13
# min_dist = 2632.4781404600485
# min_dist_subgraph_index = 2
# min_dist_edge_index = [2157, 2123]
# min_dist_edge = [array([422851. , 275361. ,  35945.4]), array([422187. , 273324. ,  34415.8])]
# len_subgraphs AT END= 12
# min_dist = 2699.324621085801
# min_dist_subgraph_index = 6
# min_dist_edge_index = [6325, 6496]
# min_dist_edge = [array([455036. , 159952. ,  53056.6]), array([456333. , 162132. ,  53979.5])]
# len_subgraphs AT END= 11
# min_dist = 2810.5995161175106
# min_dist_subgraph_index = 10
# min_dist_edge_index = [7313, 7330]
# min_dist_edge = [array([467550. , 228104. ,  51332.2]), array([468170. , 225958. ,  49626.4])]
# len_subgraphs AT END= 10
# min_dist = 4695.1073938729005
# min_dist_subgraph_index = 6
# min_dist_edge_index = [6527, 6653]
# min_dist_edge = [array([456876. , 246599. ,  56192.2]), array([460516., 246149.,  53261.])]
# len_subgraphs AT END= 9
# min_dist = 1190.7283317365063
# min_dist_subgraph_index = 7
# min_dist_edge_index = [7073, 7121]
# min_dist_edge = [array([464784. , 246587. ,  43944.5]), array([464965. , 246621. ,  42768.1])]
# len_subgraphs AT END= 8
# min_dist = 766.9696473785623
# min_dist_subgraph_index = 7
# min_dist_edge_index = [7223, 7167]
# min_dist_edge = [array([465238. , 244874. ,  37116.5]), array([465094. , 244513. ,  36455.3])]
# len_subgraphs AT END= 7
# min_dist = 892.9657832190413
# min_dist_subgraph_index = 6
# min_dist_edge_index = [7147, 6983]
# min_dist_edge = [array([465061. , 244167. ,  35906.2]), array([464667. , 243780. ,  35204.5])]
# len_subgraphs AT END= 6
# min_dist = 5477.451013929746
# min_dist_subgraph_index = 2
# min_dist_edge_index = [3179, 3021]
# min_dist_edge = [array([434728. , 177608. ,  30222.4]), array([430550. , 175916. ,  27110.5])]
# len_subgraphs AT END= 5
# min_dist = 1008.5984384282976
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2144, 2098]
# min_dist_edge = [array([422688. , 179890. ,  15646.7]), array([422001. , 180223. ,  14987.6])]
# len_subgraphs AT END= 4
# min_dist = 1811.242173206001
# min_dist_subgraph_index = 3
# min_dist_edge_index = [2341, 2612]
# min_dist_edge = [array([424758. , 178007. ,  16617.3]), array([426295. , 178417. ,  15751.2])]
# len_subgraphs AT END= 3
# min_dist = 2091.8076608522106
# min_dist_subgraph_index = 2
# min_dist_edge_index = [2601, 2547]
# min_dist_edge = [array([426227. , 172808. ,  16486.8]), array([426002. , 171979. ,  14579.5])]
# len_subgraphs AT END= 2
# min_dist = 762.8574178704683
# min_dist_subgraph_index = 1
# min_dist_edge_index = [2476, 2472]
# min_dist_edge = [array([425617. , 171080. ,  11990.8]), array([425572. , 170955. ,  11239.6])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.9002318382263184
# Total time: 221.5060896873474
#
#
#
# ----------Working on 648518346349471156:----------
# Step 1: Retrieving Mesh and removing error segments: 1.4311258792877197
# There were 561 after split and significance threshold
# There were 10 after split and significance threshold
# Mesh piece 0 with number of faces 989037
# Mesh piece 1 with number of faces 620
# Mesh piece 2 with number of faces 962
# Mesh piece 3 with number of faces 15847
# Mesh piece 4 with number of faces 3986
# Mesh piece 5 with number of faces 2778
# Mesh piece 6 with number of faces 4062
# Mesh piece 7 with number of faces 1970
# Mesh piece 8 with number of faces 7645
# Mesh piece 9 with number of faces 854
# Step 2a: Getting the number of splits: 1.4955146312713623
# largest mesh perc = 0.9597837510516953
# Working on split 0 with face total = 989037
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 59.107378005981445
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_0_mls
# Step 5: Generating Skeleton: 43.09099102020264
# Step 5: Generating and reading Skeleton: 43.09821844100952
# Working on split 1 with face total = 620
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_1.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0153045654296875
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_1_mls
# Step 5: Generating Skeleton: 0.04879045486450195
# Step 5: Generating and reading Skeleton: 0.04956197738647461
# Working on split 2 with face total = 962
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_2.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.991330623626709
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_2_mls
# Step 5: Generating Skeleton: 0.06697201728820801
# Step 5: Generating and reading Skeleton: 0.06793618202209473
# Working on split 3 with face total = 15847
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_3.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.4242146015167236
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_3_mls
# Step 5: Generating Skeleton: 0.47481870651245117
# Step 5: Generating and reading Skeleton: 0.47656679153442383
# Working on split 4 with face total = 3986
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_4.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_4_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0226304531097412
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_4_mls
# Step 5: Generating Skeleton: 0.18184924125671387
# Step 5: Generating and reading Skeleton: 0.1829056739807129
# Working on split 5 with face total = 2778
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_5.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_5_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0446293354034424
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_5_mls
# Step 5: Generating Skeleton: 0.12355184555053711
# Step 5: Generating and reading Skeleton: 0.12456965446472168
# Working on split 6 with face total = 4062
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_6.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_6_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0821723937988281
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_6_mls
# Step 5: Generating Skeleton: 0.16832566261291504
# Step 5: Generating and reading Skeleton: 0.16939353942871094
# Working on split 7 with face total = 1970
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_7.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_7_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.012631893157959
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_7_mls
# Step 5: Generating Skeleton: 0.1740281581878662
# Step 5: Generating and reading Skeleton: 0.17479681968688965
# Working on split 8 with face total = 7645
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_8.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_8_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.130265474319458
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_8_mls
# Step 5: Generating Skeleton: 0.33946847915649414
# Step 5: Generating and reading Skeleton: 0.34112977981567383
# Working on split 9 with face total = 854
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_9.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_9_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9882516860961914
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471156_piece_9_mls
# Step 5: Generating Skeleton: 0.06710362434387207
# Step 5: Generating and reading Skeleton: 0.06785726547241211
# len_subgraphs AT BEGINNING = 15
# min_dist = 713.8711088144707
# min_dist_subgraph_index = 1
# min_dist_edge_index = [99, 100]
# min_dist_edge = [array([218106. , 173736. ,  40290.5]), array([218413. , 173799. ,  40931.9])]
# len_subgraphs AT END= 14
# min_dist = 2066.9417626048394
# min_dist_subgraph_index = 1
# min_dist_edge_index = [171, 172]
# min_dist_edge = [array([219414. , 175143. ,  41919.3]), array([221248. , 175723. ,  42675.8])]
# len_subgraphs AT END= 13
# min_dist = 241.13152012957943
# min_dist_subgraph_index = 12
# min_dist_edge_index = [3124, 3123]
# min_dist_edge = [array([469331., 229369.,  82082.]), array([469148. , 229330. ,  81929.9])]
# len_subgraphs AT END= 12
# min_dist = 624.0250395617151
# min_dist_subgraph_index = 11
# min_dist_edge_index = [3075, 3077]
# min_dist_edge = [array([465821. , 199152. ,  70313.5]), array([465992., 198566.,  70443.])]
# len_subgraphs AT END= 11
# min_dist = 816.1822345530437
# min_dist_subgraph_index = 9
# min_dist_edge_index = [2665, 2666]
# min_dist_edge = [array([445432. , 200568. ,  26259.3]), array([445454. , 201354. ,  26478.1])]
# len_subgraphs AT END= 10
# min_dist = 1241.3654780120155
# min_dist_subgraph_index = 9
# min_dist_edge_index = [2879, 2775]
# min_dist_edge = [array([454629., 175389.,  72959.]), array([453965. , 175199. ,  73990.5])]
# len_subgraphs AT END= 9
# min_dist = 1536.6815707881708
# min_dist_subgraph_index = 6
# min_dist_edge_index = [2413, 2397]
# min_dist_edge = [array([436926. , 188393. ,  35050.5]), array([436449., 189826.,  34767.])]
# len_subgraphs AT END= 8
# min_dist = 899.1892181293101
# min_dist_subgraph_index = 6
# min_dist_edge_index = [2567, 2558]
# min_dist_edge = [array([439515. , 212895. ,  39832.2]), array([438896. , 212995. ,  40476.7])]
# len_subgraphs AT END= 7
# min_dist = 1976.358762978019
# min_dist_subgraph_index = 6
# min_dist_edge_index = [2537, 2495]
# min_dist_edge = [array([438630. , 165615. ,  61276.5]), array([438230. , 166048. ,  63162.9])]
# len_subgraphs AT END= 6
# min_dist = 2090.5936094803315
# min_dist_subgraph_index = 4
# min_dist_edge_index = [1258, 1221]
# min_dist_edge = [array([328517., 164895.,  16638.]), array([326591. , 164224. ,  16178.8])]
# len_subgraphs AT END= 5
# min_dist = 593.6751300164086
# min_dist_subgraph_index = 2
# min_dist_edge_index = [854, 847]
# min_dist_edge = [array([316527. , 162591. ,  15555.8]), array([316077. , 162686. ,  15180.4])]
# len_subgraphs AT END= 4
# min_dist = 515.3542470961115
# min_dist_subgraph_index = 1
# min_dist_edge_index = [484, 482]
# min_dist_edge = [array([303449. , 168955. ,  11521.5]), array([303028. , 169137. ,  11286.5])]
# len_subgraphs AT END= 3
# min_dist = 2271.4402919733548
# min_dist_subgraph_index = 2
# min_dist_edge_index = [1381, 1282]
# min_dist_edge = [array([330454. , 194927. ,  31169.6]), array([329756. , 196401. ,  29588.6])]
# len_subgraphs AT END= 2
# min_dist = 2666.0563778735063
# min_dist_subgraph_index = 1
# min_dist_edge_index = [1435, 1418]
# min_dist_edge = [array([335728. , 178778. ,  59577.6]), array([333197. , 177956. ,  59415.7])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.6419458389282227
# Total time: 127.34150385856628
#
#
#
# ----------Working on 648518346349471500:----------
# Step 1: Retrieving Mesh and removing error segments: 1.3506758213043213
# There were 675 after split and significance threshold
# There were 4 after split and significance threshold
# Mesh piece 0 with number of faces 801669
# Mesh piece 1 with number of faces 402
# Mesh piece 2 with number of faces 1274
# Mesh piece 3 with number of faces 293
# Step 2a: Getting the number of splits: 1.0607969760894775
# largest mesh perc = 0.9932881997705325
# Working on split 0 with face total = 801669
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 49.66094493865967
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_0_mls
# Step 5: Generating Skeleton: 35.0928692817688
# Step 5: Generating and reading Skeleton: 35.15486478805542
# Working on split 1 with face total = 402
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_1.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_1_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0123460292816162
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_1_mls
# Step 5: Generating Skeleton: 0.032990455627441406
# Step 5: Generating and reading Skeleton: 0.033620357513427734
# Working on split 2 with face total = 1274
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_2.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_2_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 1.0383350849151611
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_2_mls
# Step 5: Generating Skeleton: 0.07846498489379883
# Step 5: Generating and reading Skeleton: 0.07944583892822266
# Working on split 3 with face total = 293
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_3.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_3_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 0.9890897274017334
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471500_piece_3_mls
# Step 5: Generating Skeleton: 0.02586984634399414
# Step 5: Generating and reading Skeleton: 0.026889801025390625
# len_subgraphs AT BEGINNING = 17
# min_dist = 417.24190824987915
# min_dist_subgraph_index = 1
# min_dist_edge_index = [98, 97]
# min_dist_edge = [array([317326. , 203701. ,  62792.3]), array([317282. , 203289. ,  62743.2])]
# len_subgraphs AT END= 16
# min_dist = 773.2069580649155
# min_dist_subgraph_index = 14
# min_dist_edge_index = [711, 722]
# min_dist_edge = [array([455428. , 193205. ,  64637.8]), array([455772. , 192573. ,  64354.8])]
# len_subgraphs AT END= 15
# min_dist = 920.61490863444
# min_dist_subgraph_index = 13
# min_dist_edge_index = [721, 719]
# min_dist_edge = [array([455772. , 192573. ,  64354.2]), array([455573. , 191931. ,  63725.1])]
# len_subgraphs AT END= 14
# min_dist = 837.6666162621015
# min_dist_subgraph_index = 11
# min_dist_edge_index = [717, 701]
# min_dist_edge = [array([455573. , 191930. ,  63722.6]), array([454915., 192259.,  63322.])]
# len_subgraphs AT END= 13
# min_dist = 367.1040179567642
# min_dist_subgraph_index = 10
# min_dist_edge_index = [700, 697]
# min_dist_edge = [array([454914., 192260.,  63319.]), array([454825. , 191918. ,  63219.6])]
# len_subgraphs AT END= 12
# min_dist = 997.7313315717809
# min_dist_subgraph_index = 10
# min_dist_edge_index = [720, 704]
# min_dist_edge = [array([455772. , 192572. ,  64355.8]), array([455162. , 191885. ,  64744.9])]
# len_subgraphs AT END= 11
# min_dist = 1069.151925593364
# min_dist_subgraph_index = 7
# min_dist_edge_index = [695, 683]
# min_dist_edge = [array([454824. , 191918. ,  63218.4]), array([453839. , 191723. ,  63585.6])]
# len_subgraphs AT END= 10
# min_dist = 542.7155884991687
# min_dist_subgraph_index = 5
# min_dist_edge_index = [681, 674]
# min_dist_edge = [array([453837. , 191723. ,  63593.4]), array([453555. , 192020. ,  63949.5])]
# len_subgraphs AT END= 9
# min_dist = 579.0675608251584
# min_dist_subgraph_index = 5
# min_dist_edge_index = [674, 678]
# min_dist_edge = [array([453555. , 192020. ,  63949.5]), array([453829. , 192457. ,  63686.3])]
# len_subgraphs AT END= 8
# min_dist = 682.3695772819862
# min_dist_subgraph_index = 4
# min_dist_edge_index = [673, 670]
# min_dist_edge = [array([453553. , 192018. ,  63958.4]), array([453500. , 192342. ,  64556.6])]
# len_subgraphs AT END= 7
# min_dist = 391.18921253020255
# min_dist_subgraph_index = 4
# min_dist_edge_index = [670, 684]
# min_dist_edge = [array([453500. , 192342. ,  64556.6]), array([453862. , 192194. ,  64565.6])]
# len_subgraphs AT END= 6
# min_dist = 229.1551657720158
# min_dist_subgraph_index = 4
# min_dist_edge_index = [685, 687]
# min_dist_edge = [array([453862. , 192194. ,  64565.7]), array([453893. , 191967. ,  64570.4])]
# len_subgraphs AT END= 5
# min_dist = 1318.8090422801938
# min_dist_subgraph_index = 3
# min_dist_edge_index = [343, 320]
# min_dist_edge = [array([387976. , 175961. ,  46377.4]), array([387576. , 174727. ,  46139.7])]
# len_subgraphs AT END= 4
# min_dist = 2094.877046511316
# min_dist_subgraph_index = 3
# min_dist_edge_index = [753, 741]
# min_dist_edge = [array([457290. , 235360. ,  69019.4]), array([456721. , 237067. ,  67946.6])]
# len_subgraphs AT END= 3
# min_dist = 2121.0506571036926
# min_dist_subgraph_index = 1
# min_dist_edge_index = [190, 198]
# min_dist_edge = [array([359929. , 202257. ,  69078.3]), array([360261., 200452.,  68015.])]
# len_subgraphs AT END= 2
# min_dist = 3494.2056679594575
# min_dist_subgraph_index = 1
# min_dist_edge_index = [246, 258]
# min_dist_edge = [array([377508., 159605.,  79328.]), array([380477. , 159371. ,  81155.5])]
# len_subgraphs AT END= 1
# Step 6: Inserting dictionary: 0.5360236167907715
# Total time: 96.79824900627136
#
#
#
# ----------Working on 648518346349471562:----------
# Step 1: Retrieving Mesh and removing error segments: 2.1444385051727295
# There were 867 after split and significance threshold
# There were 8 after split and significance threshold
# Mesh piece 0 with number of faces 1523422
# Mesh piece 1 with number of faces 540
# Mesh piece 2 with number of faces 47976
# Mesh piece 3 with number of faces 6684
# Mesh piece 4 with number of faces 5406
# Mesh piece 5 with number of faces 412
# Mesh piece 6 with number of faces 380
# Mesh piece 7 with number of faces 506
# Step 2a: Getting the number of splits: 2.420691967010498
# largest mesh perc = 0.9587517401275296
# Working on split 0 with face total = 1523422
# Done writing OFF file
# meshlab_script = /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@  -i /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471562_piece_0.off -o /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471562_piece_0_mls.off -s /notebooks/Pass_2_Sk_Neurons/pymesh_fix_substitute.mls
# Step 4: Meshlab fixing non-manifolds: 88.80974984169006
# /notebooks/Pass_2_Sk_Neurons/pymesh_NEURONS/neuron_648518346349471562_piece_0_mls
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1c75e0c54da0> in <module>
#       1 start = time.time()
# ----> 2 NeuronSkeletonStitched.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-15-0fcf921e522b> in make(self, key)
#     165                     continue
#     166
# --> 167                 return_value = cm.calcification(output_mesh[:-4])
#     168                 if return_value > 0:
#     169                     print('skeletonization for neuron ' + str(new_key["segment_id"]) +
#
# KeyboardInterrupt:
