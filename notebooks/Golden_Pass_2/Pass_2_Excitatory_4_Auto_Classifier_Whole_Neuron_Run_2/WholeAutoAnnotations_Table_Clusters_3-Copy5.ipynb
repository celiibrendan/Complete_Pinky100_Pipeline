# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498835******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09238195419311523
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1017.0954811573029
# 2) Finished: Generating CGAL segmentation for neuron: 1038.0243294239044
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2607455253601074
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [71, 20, 26, 23, 18, 16, 10, 24, 63, 73, 65]
# soma_80_percent = 182482.7484375
# Debugging the axon filter
# [(71, 182297.796875), (20, 207991.46875), (26, 196204.90625), (23, 181800.578125), (18, 179317.734375), (16, 188922.4375), (10, 197980.984375), (24, 201435.671875), (63, 191934.890625), (73, 192687.15625), (65, 180317.375)]
# possible_Axons_filter_1 = [71, 23, 18, 65]
# possible_Axons_filter_2 = [18]
# possible_Apical = 18
# 5) Finished: Finding Apical Index: 0.07856249809265137
# 6) Staring: Classifying Entire Neuron
# 71 = cilia
# 63 = stub soma
# 65 = stub soma
# 73 = stub soma
# 22 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 45 = stub apical
# 59 = stub apical
# 60 = stub apical
# 64 = stub apical
# 66 = stub apical
# 67 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique'}
# 6) Finished: Classifying Entire Neuron: 2.404348850250244
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.658106803894043
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.462950468063354
# Finished Auto Labeling: 1053.6640124320984
#
#
# *****Starting Auto Labeling for 648518346349499939******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07403159141540527
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1311.5133039951324
# 2) Finished: Generating CGAL segmentation for neuron: 1334.360028743744
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2821619510650635
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 19, 14, 27, 6, 18, 8, 4, 66, 43]
# soma_80_percent = 189880.3484375
# Debugging the axon filter
# [(1, 206401.671875), (19, 202121.921875), (14, 206826.359375), (27, 203583.71875), (6, 185974.96875), (18, 198171.46875), (8, 216882.109375), (4, 207317.140625), (66, 187723.34375), (43, 191537.609375)]
# possible_Axons_filter_1 = [6, 66]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.08345866203308105
# 6) Staring: Classifying Entire Neuron
# 66 = cilia
# 43 = stub soma
# 26 = error
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 35 = stub apical
# 36 = stub apical
# 38 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 51 = stub apical
# 52 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 61 = stub apical
# 62 = stub apical
# 64 = stub apical
# 65 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.9485483169555664
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6889238357543945
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.120505094528198
# Finished Auto Labeling: 1352.3557221889496
#
#
# *****Starting Auto Labeling for 648518346349503011******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03932499885559082
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 703.4099836349487
# 2) Finished: Generating CGAL segmentation for neuron: 718.8437061309814
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 16
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.20453929901123047
# 5) Staring: Finding Apical Index
# Soma Index = 16
# Soma Connections = [0, 62, 30, 32, 140, 19, 58, 46, 161, 409, 350, 21, 197, 419, 198, 352, 240, 351]
# soma_80_percent = 275112.821875
# Debugging the axon filter
# [(0, 271715.96875), (62, 296463.4375), (30, 285003.78125), (32, 285364.6875), (140, 274505.5625), (19, 276657.40625), (58, 286127.59375), (46, 296354.4375), (161, 286932.8125), (409, 277346.1875), (350, 286567.9375), (21, 290644.1875), (197, 274045.40625), (419, 281299.40625), (198, 274164.78125), (352, 275268.9375), (240, 272387.84375), (351, 275776.125)]
# possible_Axons_filter_1 = [0, 140, 197, 198, 240]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.1328415870666504
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 19
# 197 = cilia
# 140 = stub soma
# 161 = stub soma
# 198 = stub soma
# 240 = stub soma
# 350 = stub soma
# 351 = stub soma
# 352 = stub soma
# 419 = stub soma
# 9 = error
# 13 = stub apical
# 14 = stub apical
# 15 = stub apical
# 18 = stub apical
# 22 = stub apical
# 24 = stub apical
# 26 = stub apical
# 28 = stub apical
# 29 = stub apical
# 31 = stub apical
# 33 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 40 = stub apical
# 41 = error
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 60 = stub apical
# 61 = error
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = error
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = error
# 286 = stub apical
# 287 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 374 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 378 = stub apical
# 379 = stub apical
# 380 = stub apical
# 381 = stub apical
# 382 = stub apical
# 383 = stub apical
# 384 = stub apical
# 385 = stub apical
# 386 = stub apical
# 387 = stub apical
# 388 = stub apical
# 389 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 393 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 402 = stub apical
# 403 = stub apical
# 404 = stub apical
# 405 = stub apical
# 406 = stub apical
# 407 = stub apical
# 408 = stub apical
# 410 = stub apical
# 411 = stub apical
# 412 = stub apical
# 413 = stub apical
# 414 = stub apical
# 415 = stub apical
# 416 = stub apical
# 417 = stub apical
# 418 = stub apical
# 421 = stub apical
# 422 = stub apical
# 423 = stub apical
# 424 = stub apical
# 425 = stub apical
# 426 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.2240891456604004
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.42171216011047363
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.288129091262817
# Finished Auto Labeling: 731.760071516037
#
#
# *****Starting Auto Labeling for 648518346349504618******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06366658210754395
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1100.2269427776337
# 2) Finished: Generating CGAL segmentation for neuron: 1119.867465019226
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.26140379905700684
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [15, 33, 28, 14, 11, 2, 12, 151, 246, 187]
# soma_80_percent = 248248.06875
# Debugging the axon filter
# [(15, 269625.15625), (33, 252865.390625), (28, 263493.53125), (14, 278055.59375), (11, 243756.65625), (2, 252407.515625), (12, 268180.5625), (151, 247535.296875), (246, 246384.359375), (187, 244638.90625)]
# possible_Axons_filter_1 = [11, 151, 246, 187]
# possible_Axons_filter_2 = [11]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.1084444522857666
# 6) Staring: Classifying Entire Neuron
# 12 = axon
# 151 = cilia
# 187 = stub soma
# 246 = stub soma
# 10 = stub apical
# 18 = stub apical
# 20 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 30 = stub apical
# 32 = stub apical
# 34 = stub apical
# 35 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 50 = stub apical
# 51 = stub apical
# 53 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 62 = stub apical
# 63 = error
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 75 = stub apical
# 76 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 82 = stub apical
# 83 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 147 = stub apical
# 149 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 184 = stub apical
# 185 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 205 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 244 = stub apical
# 245 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique', 'error', 'axon'}
# 6) Finished: Classifying Entire Neuron: 3.0894882678985596
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4697110652923584
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.765039205551147
# Finished Auto Labeling: 1135.3420085906982
#
#
# *****Starting Auto Labeling for 648518346349506425******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.042845964431762695
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 859.4670267105103
# 2) Finished: Generating CGAL segmentation for neuron: 876.9965720176697
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 12
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22667717933654785
# 5) Staring: Finding Apical Index
# Soma Index = 12
# Soma Connections = [33, 27, 9, 37, 30, 16, 26, 43, 25, 184, 166, 165, 192, 179]
# soma_80_percent = 243260.703125
# Debugging the axon filter
# [(33, 247012.65625), (27, 262111.265625), (9, 277240.125), (37, 263525.125), (30, 242056.640625), (16, 239675.453125), (26, 265485.875), (43, 252058.296875), (25, 255766.28125), (184, 242633.875), (166, 249976.5), (165, 248410.96875), (192, 254139.171875), (179, 252842.421875)]
# possible_Axons_filter_1 = [30, 16, 184]
# possible_Axons_filter_2 = [16]
# possible_Apical = 16
# 5) Finished: Finding Apical Index: 0.08960127830505371
# 6) Staring: Classifying Entire Neuron
# 37 = axon
# 165 = stub soma
# 166 = stub soma
# 179 = stub soma
# 184 = cilia
# 192 = stub soma
# 28 = stub apical
# 32 = stub apical
# 38 = stub apical
# 41 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 65 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 81 = stub apical
# 83 = stub apical
# 84 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 108 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 120 = stub apical
# 121 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 141 = stub apical
# 142 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique', 'axon'}
# 6) Finished: Classifying Entire Neuron: 2.3495190143585205
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4535989761352539
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.085870742797852
# Finished Auto Labeling: 890.8479993343353
#
#
# *****Starting Auto Labeling for 648518346349509126******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.011221170425415039
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 122.81803393363953
# 2) Finished: Generating CGAL segmentation for neuron: 126.86070704460144
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.05286121368408203
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 7, 10, 15, 30, 12, 11, 16, 29, 0, 32, 28, 19, 27]
# soma_80_percent = 278091.978125
# Debugging the axon filter
# [(2, 292843.28125), (7, 283912.0625), (10, 275894.125), (15, 279490.125), (30, 280559.625), (12, 288411.4375), (11, 293350.03125), (16, 283342.15625), (29, 281593.90625), (0, 289057.375), (32, 280781.625), (28, 281404.96875), (19, 275918.28125), (27, 274338.71875)]
# possible_Axons_filter_1 = [10, 19, 27]
# possible_Axons_filter_2 = [10]
# possible_Apical = 10
# 5) Finished: Finding Apical Index: 0.031056642532348633
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 7
# 11 = error
# 15 = stub soma
# 19 = cilia
# 27 = stub soma
# 28 = stub soma
# 29 = stub soma
# 30 = stub soma
# 32 = stub soma
# 17 = stub apical
# 23 = stub apical
# 24 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'cilia', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 0.5575947761535645
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.13776779174804688
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.2210805416107178
# Finished Auto Labeling: 130.0434854030609
#
#
# *****Starting Auto Labeling for 648518346349509204******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0777885913848877
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1579.1652081012726
# 2) Finished: Generating CGAL segmentation for neuron: 1604.0702464580536
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.30280375480651855
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [42, 11, 84, 0, 32, 29, 34, 45, 38, 107, 82]
# soma_80_percent = 215577.90625
# Debugging the axon filter
# [(42, 221424.96875), (11, 234852.453125), (84, 220373.359375), (0, 213166.75), (32, 228975.578125), (29, 236384.625), (34, 233788.125), (45, 221780.0625), (38, 228102.375), (107, 218659.828125), (82, 225303.5)]
# possible_Axons_filter_1 = [0]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.09322547912597656
# 6) Staring: Classifying Entire Neuron
# 82 = stub soma
# 107 = stub soma
# 28 = stub apical
# 33 = stub apical
# 44 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 81 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 114 = stub apical
# 119 = stub apical
# 120 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 131 = error
# 132 = stub apical
# 133 = stub apical
# 135 = stub apical
# Total Labels found = {'basal', 'apical', 'soma', 'oblique', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.4969112873077393
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6415450572967529
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.78735089302063
# Finished Auto Labeling: 1623.3545236587524
# 6920.077808141708

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
