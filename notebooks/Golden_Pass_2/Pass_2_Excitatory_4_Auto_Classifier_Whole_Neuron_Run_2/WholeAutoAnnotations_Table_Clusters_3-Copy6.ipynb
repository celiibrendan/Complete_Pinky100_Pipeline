# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349499085******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09728813171386719
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1116.4853951931
# 2) Finished: Generating CGAL segmentation for neuron: 1138.4508309364319
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2690279483795166
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [25, 4, 30, 28, 22, 15, 5, 23, 62, 61]
# soma_80_percent = 257591.6125
# Debugging the axon filter
# [(25, 272924.65625), (4, 254572.171875), (30, 278303.71875), (28, 269129.6875), (22, 267184.5), (15, 257774.1875), (5, 279865.75), (23, 279437.40625), (62, 260927.515625), (61, 260236.375)]
# possible_Axons_filter_1 = [4]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.0916752815246582
# 6) Staring: Classifying Entire Neuron
# 30 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 22
# 61 = stub soma
# 62 = stub soma
# 17 = stub apical
# 24 = stub apical
# 26 = stub apical
# 31 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 75 = stub apical
# Total Labels found = {'axon', 'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.2764320373535156
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5632121562957764
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.195054292678833
# Finished Auto Labeling: 1155.7508132457733
#
#
# *****Starting Auto Labeling for 648518346349500120******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.026662111282348633
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 194.94726753234863
# 2) Finished: Generating CGAL segmentation for neuron: 201.84055399894714
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.08661746978759766
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 7, 5, 4, 25, 27, 49, 16, 21, 68, 24, 66, 52, 50, 58, 54]
# soma_80_percent = 179949.89375
# Debugging the axon filter
# [(1, 187207.96875), (7, 184038.65625), (5, 177520.875), (4, 187971.8125), (25, 206817.046875), (27, 180752.78125), (49, 187603.75), (16, 188750.96875), (21, 178658.171875), (68, 183861.9375), (24, 202570.71875), (66, 177302.296875), (52, 188120.390625), (50, 177245.703125), (58, 179822.03125), (54, 181510.109375)]
# possible_Axons_filter_1 = [5, 21, 66, 50, 58]
# possible_Axons_filter_2 = [5, 21]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.03859519958496094
# 6) Staring: Classifying Entire Neuron
# 27 = stub soma
# 50 = stub soma
# 52 = stub soma
# 54 = stub soma
# 66 = cilia
# 58 = stub soma
# 68 = stub soma
# 22 = stub apical
# 28 = stub apical
# 55 = stub apical
# Total Labels found = {'cilia', 'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.6834964752197266
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.1891918182373047
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.649745225906372
# Finished Auto Labeling: 206.72165751457214
#
#
# *****Starting Auto Labeling for 648518346349500324******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07491350173950195
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1299.1618208885193
# 2) Finished: Generating CGAL segmentation for neuron: 1323.517147064209
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3058047294616699
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [16, 6, 27, 9, 157, 17, 32, 180, 47, 148, 107, 191, 149]
# soma_80_percent = 191653.3796875
# Debugging the axon filter
# [(16, 215372.796875), (6, 188219.96875), (27, 200784.234375), (9, 225073.046875), (157, 189018.296875), (17, 217538.578125), (32, 210532.265625), (180, 191190.265625), (47, 207603.765625), (148, 202908.46875), (107, 200693.875), (191, 195618.015625), (149, 202348.6875)]
# possible_Axons_filter_1 = [6, 157, 180]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.12374186515808105
# 6) Staring: Classifying Entire Neuron
# 107 = stub soma
# 157 = cilia
# 148 = stub soma
# 149 = stub soma
# 180 = stub soma
# 191 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.191758155822754
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.9386780261993408
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.648446559906006
# Finished Auto Labeling: 1342.7790496349335
#
#
# *****Starting Auto Labeling for 648518346349503643******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04970049858093262
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1235.525138616562
# 2) Finished: Generating CGAL segmentation for neuron: 1256.676028251648
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.27675938606262207
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [2, 32, 305, 21, 20, 9, 11, 42]
# soma_80_percent = 221750.2578125
# Debugging the axon filter
# [(2, 230469.25), (32, 243895.34375), (305, 234053.6875), (21, 226512.9375), (20, 223919.15625), (9, 217834.09375), (11, 236536.015625), (42, 240942.5)]
# possible_Axons_filter_1 = [9]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.14320087432861328
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 21
# 10 = stub apical
# 16 = stub apical
# 17 = stub apical
# 19 = stub apical
# 23 = stub apical
# 24 = error
# 30 = stub apical
# 34 = stub apical
# 37 = stub apical
# 38 = stub apical
# 43 = stub apical
# 44 = stub apical
# 48 = error
# 49 = stub apical
# 52 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 61 = stub apical
# 64 = stub apical
# 65 = stub apical
# 69 = stub apical
# 71 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 85 = stub apical
# 89 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 159 = stub apical
# 160 = error
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 174 = stub apical
# 181 = stub apical
# 182 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 194 = stub apical
# 195 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 225 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 277 = stub apical
# 279 = stub apical
# 280 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 292 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 304 = stub apical
# 313 = error
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 339 = stub apical
# 340 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 349 = stub apical
# 350 = stub apical
# 354 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 366 = stub apical
# 367 = stub apical
# 368 = stub apical
# 369 = stub apical
# 375 = stub apical
# 376 = stub apical
# 377 = stub apical
# 381 = stub apical
# 390 = stub apical
# 391 = stub apical
# 392 = stub apical
# 394 = stub apical
# 395 = stub apical
# 396 = stub apical
# 397 = stub apical
# 398 = stub apical
# 399 = stub apical
# 400 = stub apical
# 401 = stub apical
# 402 = stub apical
# Total Labels found = {'error', 'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.1197125911712646
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5847015380859375
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.83677864074707
# Finished Auto Labeling: 1273.42728972435
#
#
# *****Starting Auto Labeling for 648518346349506092******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05029630661010742
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 813.5979115962982
# 2) Finished: Generating CGAL segmentation for neuron: 831.8836915493011
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22124218940734863
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [4, 16, 8, 18, 19, 17, 15, 31]
# soma_80_percent = 183345.40625
# Debugging the axon filter
# [(4, 197040.953125), (16, 201099.1875), (8, 179872.734375), (18, 187894.96875), (19, 193609.484375), (17, 202559.546875), (15, 200368.984375), (31, 188063.984375)]
# possible_Axons_filter_1 = [8]
# possible_Axons_filter_2 = [8]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.056163787841796875
# 6) Staring: Classifying Entire Neuron
# 16 = error
# 31 = stub soma
# 24 = stub apical
# 25 = error
# Total Labels found = {'error', 'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.5404348373413086
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4492349624633789
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.17029857635498
# Finished Auto Labeling: 846.0130877494812
#
#
# *****Starting Auto Labeling for 648518346349507355******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07310199737548828
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1887.5019896030426
# 2) Finished: Generating CGAL segmentation for neuron: 1914.37792634964
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.34192657470703125
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [47, 2, 4, 43, 25, 30, 31, 17, 24, 75, 158, 120, 27, 51, 157, 240, 203]
# soma_80_percent = 202122.0421875
# Debugging the axon filter
# [(47, 202113.109375), (2, 223004.0), (4, 208685.59375), (43, 222787.984375), (25, 226460.96875), (30, 212478.390625), (31, 218431.421875), (17, 223314.96875), (24, 199006.046875), (75, 198763.28125), (158, 212748.4375), (120, 200055.59375), (27, 209210.734375), (51, 208103.25), (157, 200040.140625), (240, 210733.25), (203, 202625.96875)]
# possible_Axons_filter_1 = [47, 24, 75, 120, 157]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.14070963859558105
# 6) Staring: Classifying Entire Neuron
# 27 = stub soma
# 47 = stub soma
# 51 = stub soma
# 75 = cilia
# 120 = stub soma
# 157 = stub soma
# 158 = stub soma
# 203 = stub soma
# 240 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 3.283328056335449
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 1.0371832847595215
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 15.34557819366455
# Finished Auto Labeling: 1935.6501860618591
#
#
# *****Starting Auto Labeling for 648518346349514277******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.01650524139404297
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 112.23593854904175
# 2) Finished: Generating CGAL segmentation for neuron: 116.93248414993286
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06118917465209961
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 2, 12, 10, 14, 4, 34, 5, 16, 15, 11, 3, 33, 19, 20, 52, 43, 35, 44, 41, 21, 32, 31]
# soma_80_percent = 250851.38125
# Debugging the axon filter
# [(0, 258606.609375), (2, 255043.171875), (12, 251043.875), (10, 262124.484375), (14, 256206.78125), (4, 256592.375), (34, 250697.578125), (5, 249502.375), (16, 253055.890625), (15, 266542.8125), (11, 264533.71875), (3, 261844.78125), (33, 254000.265625), (19, 257561.859375), (20, 255285.75), (52, 248689.890625), (43, 251918.65625), (35, 253457.65625), (44, 251319.4375), (41, 262181.65625), (21, 253542.09375), (32, 250256.25), (31, 249272.484375)]
# possible_Axons_filter_1 = [34, 5, 52, 32, 31]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.03995180130004883
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 2
# 3 = axon
# 4 = stub soma
# 12 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 14
# 19 = stub soma
# 20 = stub soma
# 21 = stub soma
# 31 = stub soma
# 32 = stub soma
# 33 = stub soma
# 34 = stub soma
# 35 = stub soma
# 41 = stub soma
# 43 = stub soma
# 44 = stub soma
# 52 = stub soma
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 36 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 45 = stub apical
# 46 = stub apical
# 54 = stub apical
# 55 = stub apical
# Total Labels found = {'error', 'axon', 'apical', 'oblique', 'basal', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.6267876625061035
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.17458438873291016
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.699638605117798
# Finished Auto Labeling: 120.75141930580139
# 6883.910898685455

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
