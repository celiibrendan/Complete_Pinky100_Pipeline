# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotations(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotations.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349473833******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03217267990112305
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 144.5675151348114
# 2) Finished: Generating CGAL segmentation for neuron: 151.01605129241943
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.08215999603271484
# 4) Staring: Finding Soma Extensions
# 4) Finished: Finding Soma Extensions: 0.16361665725708008
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 181, 25]
# soma_80_percent = 230246.70625
# Debugging the axon filter
# [(0, 243135.421875), (181, 234323.625), (25, 244985.375)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.028078794479370117
# 6) Staring: Classifying Entire Neuron
# 181 = stub soma
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 0.796065092086792
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.25852370262145996
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 3.254979133605957
# Finished Auto Labeling: 155.93669033050537
#
#
# *****Starting Auto Labeling for 648518346349475101******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.02294325828552246
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 180.63140320777893
# 2) Finished: Generating CGAL segmentation for neuron: 187.2234718799591
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.09002995491027832
# 4) Staring: Finding Soma Extensions
# Found 5 soma caps and replacing labels: [88, 87, 256, 141, 250]
# done replacing soma cap labels : 3.906270980834961
# 4) Finished: Finding Soma Extensions: 4.082605600357056
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [52, 44, 6, 1, 124, 16, 206, 93, 230]
# soma_80_percent = 274829.54375
# Debugging the axon filter
# [(52, 278457.34375), (44, 286057.625), (6, 273472.65625), (1, 283931.875), (124, 279225.96875), (16, 273539.25), (206, 286033.78125), (93, 272972.90625), (230, 271865.84375)]
# possible_Axons_filter_1 = [6, 16, 93, 230]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.03186845779418945
# 6) Staring: Classifying Entire Neuron
# 93 = cilia
# 230 = stub soma
# 196 = stub apical
# 207 = stub apical
# Total Labels found = {'cilia', 'soma', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 0.7601330280303955
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.21724295616149902
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.051543712615967
# Finished Auto Labeling: 196.72613716125488
#
#
# *****Starting Auto Labeling for 648518346349475526******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.014279365539550781
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 120.21691584587097
# 2) Finished: Generating CGAL segmentation for neuron: 125.40442061424255
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.0646355152130127
# 4) Staring: Finding Soma Extensions
# Found 9 soma caps and replacing labels: [4, 5, 13, 18, 31, 33, 30, 28, 25]
# done replacing soma cap labels : 2.782637119293213
# 4) Finished: Finding Soma Extensions: 2.8983101844787598
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [6, 0, 14, 10, 12, 35, 3, 29, 34, 19, 32]
# soma_80_percent = 268147.915625
# Debugging the axon filter
# [(6, 266748.53125), (0, 277002.65625), (14, 277607.78125), (10, 291171.625), (12, 288671.5), (35, 263524.0625), (3, 263854.53125), (29, 273603.6875), (34, 268881.15625), (19, 271861.8125), (32, 276881.75)]
# possible_Axons_filter_1 = [6, 35, 3]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.020030498504638672
# 6) Staring: Classifying Entire Neuron
# 3 = cilia
# 19 = stub soma
# 29 = stub soma
# 32 = stub soma
# 34 = stub soma
# 35 = stub soma
# Total Labels found = {'soma', 'unsure', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 0.41146421432495117
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.22714829444885254
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.7896955013275146
# Finished Auto Labeling: 132.0328688621521
#
#
# *****Starting Auto Labeling for 648518346349475573******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.007867813110351562
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 35.30412149429321
# 2) Finished: Generating CGAL segmentation for neuron: 37.16142511367798
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.025278091430664062
# 4) Staring: Finding Soma Extensions
# Found 4 soma caps and replacing labels: [23, 88, 100, 83]
# done replacing soma cap labels : 0.9936501979827881
# 4) Finished: Finding Soma Extensions: 1.2228617668151855
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 11, 24, 7, 99, 78, 46, 75, 91, 86, 87, 89, 84, 43, 90, 42, 25]
# soma_80_percent = 273907.771875
# Debugging the axon filter
# [(0, 282519.6875), (11, 297068.59375), (24, 282535.21875), (7, 284798.8125), (99, 275765.65625), (78, 277990.0), (46, 274340.75), (75, 273952.21875), (91, 280138.03125), (86, 282541.125), (87, 277933.03125), (89, 277771.375), (84, 275761.71875), (43, 282459.34375), (90, 281230.25), (42, 274462.4375), (25, 277033.875)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.013634681701660156
# 6) Staring: Classifying Entire Neuron
# 11 = axon
# 24 = stub soma
# 25 = stub soma
# 42 = stub soma
# 43 = stub soma
# 46 = stub soma
# 75 = stub soma
# 78 = stub soma
# 84 = stub soma
# 86 = stub soma
# 87 = stub soma
# 89 = stub soma
# 90 = stub soma
# 91 = cilia
# 99 = stub soma
# Total Labels found = {'soma', 'unsure', 'cilia', 'axon'}
# 6) Finished: Classifying Entire Neuron: 0.17532873153686523
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.10985469818115234
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 0.9397995471954346
# Finished Auto Labeling: 39.74972891807556
#
#
# *****Starting Auto Labeling for 648518346349477981******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05809307098388672
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 523.7383301258087
# 2) Finished: Generating CGAL segmentation for neuron: 537.5602543354034
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.17793893814086914
# 4) Staring: Finding Soma Extensions
# Found 10 soma caps and replacing labels: [61, 29, 8, 96, 1, 131, 39, 104, 41, 108]
# done replacing soma cap labels : 7.820172309875488
# 4) Finished: Finding Soma Extensions: 8.084497451782227
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [6, 24, 12, 54, 105, 4, 106]
# soma_80_percent = 181022.009375
# Debugging the axon filter
# [(6, 179733.671875), (24, 185987.90625), (12, 208013.203125), (54, 187014.703125), (105, 184851.21875), (4, 177473.828125), (106, 181429.078125)]
# possible_Axons_filter_1 = [6, 4]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.03275656700134277
# 6) Staring: Classifying Entire Neuron
# 4 = stub soma
# 105 = cilia
# 106 = stub soma
# 28 = stub apical
# 52 = stub apical
# 53 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 103 = stub apical
# 109 = stub apical
# 116 = stub apical
# Total Labels found = {'apical', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.2880396842956543
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.34192419052124023
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.00556492805481
# Finished Auto Labeling: 556.0129873752594
#
#
# *****Starting Auto Labeling for 648518346349478860******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.021689414978027344
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 212.89247512817383
# 2) Finished: Generating CGAL segmentation for neuron: 221.3609619140625
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.10693502426147461
# 4) Staring: Finding Soma Extensions
# Found 1 soma caps and replacing labels: [129]
# done replacing soma cap labels : 4.777792453765869
# 4) Finished: Finding Soma Extensions: 5.2138354778289795
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [126, 537, 168, 16, 4, 44, 406, 43, 13, 106, 165, 387, 146, 400, 528, 384, 527, 381, 451, 398]
# soma_80_percent = 197954.209375
# Debugging the axon filter
# [(126, 215950.828125), (537, 209087.40625), (168, 196608.0), (16, 200656.359375), (4, 209976.890625), (44, 194259.5), (406, 200870.140625), (43, 209908.96875), (13, 212815.640625), (106, 209300.109375), (165, 209229.640625), (387, 200658.1875), (146, 202422.125), (400, 207828.6875), (528, 201250.28125), (384, 206922.53125), (527, 202945.609375), (381, 207807.171875), (451, 196108.90625), (398, 207062.453125)]
# possible_Axons_filter_1 = [168, 44, 451]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.02960491180419922
# 6) Staring: Classifying Entire Neuron
# 126 = error
# 43 = axon
# 44 = stub soma
# 146 = stub soma
# 165 = stub soma
# 381 = cilia
# 384 = stub soma
# 387 = stub soma
# 398 = stub soma
# 400 = stub soma
# 406 = stub soma
# 451 = stub soma
# 527 = stub soma
# 528 = stub soma
# Total Labels found = {'axon', 'error', 'soma', 'cilia', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.0284147262573242
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3240499496459961
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.296231746673584
# Finished Auto Labeling: 232.73150157928467
#
#
# *****Starting Auto Labeling for 648518346349481574******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.052001237869262695
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 667.8837015628815
# 2) Finished: Generating CGAL segmentation for neuron: 681.7949759960175
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.18703007698059082
# 4) Staring: Finding Soma Extensions
# 4) Finished: Finding Soma Extensions: 0.5486361980438232
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [0, 9, 34, 31, 24, 1, 23]
# soma_80_percent = 202642.671875
# Debugging the axon filter
# [(0, 212984.140625), (9, 224538.578125), (34, 223156.625), (31, 198850.375), (24, 217911.546875), (1, 210229.875), (23, 224516.734375)]
# possible_Axons_filter_1 = [31]
# possible_Axons_filter_2 = [31]
# possible_Apical = 31
# 5) Finished: Finding Apical Index: 0.12890625
# 6) Staring: Classifying Entire Neuron
# 59 = error
# 65 = stub apical
# 75 = stub apical
# 87 = stub apical
# 90 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 120 = stub apical
# 123 = stub apical
# 127 = stub apical
# 129 = stub apical
# 135 = stub apical
# 141 = stub apical
# 143 = stub apical
# 156 = stub apical
# 170 = stub apical
# 174 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 190 = stub apical
# 195 = stub apical
# 200 = stub apical
# 201 = stub apical
# 208 = stub apical
# 209 = stub apical
# 213 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 235 = stub apical
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.8650121688842773
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.38489317893981934
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.980299949645996
# Finished Auto Labeling: 693.5410087108612
#
#
# *****Starting Auto Labeling for 648518346349488659******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0393831729888916
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 737.3932354450226
# 2) Finished: Generating CGAL segmentation for neuron: 753.662629365921
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21463871002197266
# 4) Staring: Finding Soma Extensions
# Found 10 soma caps and replacing labels: [35, 30, 72, 83, 1, 115, 123, 89, 108, 105]
# done replacing soma cap labels : 9.004359722137451
# 4) Finished: Finding Soma Extensions: 9.353651762008667
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [17, 24, 62, 6, 53, 10, 25, 28, 16]
# soma_80_percent = 206821.2671875
# Debugging the axon filter
# [(17, 215001.296875), (24, 207372.671875), (62, 217861.421875), (6, 202638.453125), (53, 205243.296875), (10, 219766.640625), (25, 211026.546875), (28, 237590.6875), (16, 232763.21875)]
# possible_Axons_filter_1 = [6, 53]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.07924914360046387
# 6) Staring: Classifying Entire Neuron
# 10 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 17
# 18 = stub apical
# 22 = error
# 23 = stub apical
# 26 = stub apical
# 29 = stub apical
# 31 = stub apical
# 32 = stub apical
# 34 = stub apical
# 36 = stub apical
# 40 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = stub apical
# 54 = stub apical
# 58 = stub apical
# 61 = stub apical
# 66 = stub apical
# 68 = stub apical
# 70 = stub apical
# 71 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 90 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 106 = stub apical
# 107 = stub apical
# 109 = stub apical
# 112 = stub apical
# 114 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 121 = stub apical
# 122 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 146 = stub apical
# 147 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 170 = stub apical
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.1800684928894043
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4059116840362549
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.047483205795288
# Finished Auto Labeling: 775.585611820221
#
#
# *****Starting Auto Labeling for 648518346349493653******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05073356628417969
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 1250.1523225307465
# 2) Finished: Generating CGAL segmentation for neuron: 1271.5735204219818
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.28124380111694336
# 4) Staring: Finding Soma Extensions
# Found 7 soma caps and replacing labels: [71, 148, 42, 105, 63, 160, 72]
# done replacing soma cap labels : 12.057809352874756
# 4) Finished: Finding Soma Extensions: 12.488706588745117
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [0, 27, 29, 11, 43, 114, 97, 20]
# soma_80_percent = 194283.696875
# Debugging the axon filter
# [(0, 204046.296875), (27, 206534.859375), (29, 217535.203125), (11, 189860.265625), (43, 216703.46875), (114, 203703.21875), (97, 193649.875), (20, 202702.84375)]
# possible_Axons_filter_1 = [11, 97]
# possible_Axons_filter_2 = [11]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.05491805076599121
# 6) Staring: Classifying Entire Neuron
# 43 = axon
# 97 = cilia
# 46 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 85 = stub apical
# 98 = stub apical
# 172 = stub apical
# Total Labels found = {'axon', 'apical', 'error', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.427144765853882
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5030219554901123
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.07957649230957
# Finished Auto Labeling: 1300.2159674167633
#
#
# *****Starting Auto Labeling for 648518346349499369******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0447840690612793
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 923.2591421604156
# 2) Finished: Generating CGAL segmentation for neuron: 941.8119595050812
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.24248147010803223
# 4) Staring: Finding Soma Extensions
# Found 1 soma caps and replacing labels: [215]
# done replacing soma cap labels : 11.145082473754883
# 4) Finished: Finding Soma Extensions: 11.756985425949097
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [104, 70, 47, 26, 107, 17, 72, 40, 41, 34, 122, 56, 149, 173]
# soma_80_percent = 242044.2890625
# Debugging the axon filter
# [(104, 251090.46875), (70, 254190.578125), (47, 258985.5), (26, 238784.0), (107, 245941.390625), (17, 256216.46875), (72, 249222.65625), (40, 255639.765625), (41, 239815.78125), (34, 243924.640625), (122, 244740.375), (56, 257770.84375), (149, 240666.6875), (173, 238914.125)]
# possible_Axons_filter_1 = [26, 41, 149, 173]
# possible_Axons_filter_2 = [26, 41]
# possible_Apical = 26
# 5) Finished: Finding Apical Index: 0.07004857063293457
# 6) Staring: Classifying Entire Neuron
# 17 = axon
# 149 = cilia
# 107 = cilia
# 122 = stub soma
# 173 = stub soma
# 51 = error
# 64 = stub apical
# 65 = stub apical
# 67 = stub apical
# 74 = stub apical
# 112 = stub apical
# 113 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 147 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 158 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 172 = stub apical
# 175 = stub apical
# 177 = stub apical
# 178 = stub apical
# 184 = stub apical
# 189 = stub apical
# 192 = stub apical
# 194 = stub apical
# 198 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 213 = stub apical
# 214 = stub apical
# Total Labels found = {'axon', 'apical', 'error', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.618669033050537
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.515831470489502
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.893724203109741
# Finished Auto Labeling: 967.6474301815033
#
#
# *****Starting Auto Labeling for 648518346349500049******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03345775604248047
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 741.1006212234497
# 2) Finished: Generating CGAL segmentation for neuron: 757.52880692482
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2197554111480713
# 4) Staring: Finding Soma Extensions
# Found 2 soma caps and replacing labels: [36, 26]
# done replacing soma cap labels : 9.096404314041138
# 4) Finished: Finding Soma Extensions: 9.49709963798523
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [20, 87, 64, 34, 44, 56, 40, 23, 294]
# soma_80_percent = 181942.5015625
# Debugging the axon filter
# [(20, 187625.796875), (87, 202782.6875), (64, 188590.65625), (34, 193302.609375), (44, 195828.515625), (56, 203800.609375), (40, 179037.109375), (23, 188397.046875), (294, 185556.359375)]
# possible_Axons_filter_1 = [40]
# possible_Axons_filter_2 = [40]
# possible_Apical = 40
# 5) Finished: Finding Apical Index: 0.0513918399810791
# 6) Staring: Classifying Entire Neuron
# 87 = error
# 294 = stub soma
# 109 = error
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.7119462490081787
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4239177703857422
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.20073676109314
# Finished Auto Labeling: 779.1555986404419
#
#
# *****Starting Auto Labeling for 648518346349501481******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.060279130935668945
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 730.3299148082733
# 2) Finished: Generating CGAL segmentation for neuron: 745.9447515010834
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22916293144226074
# 4) Staring: Finding Soma Extensions
# Found 1 soma caps and replacing labels: [823]
# done replacing soma cap labels : 8.798226833343506
# 4) Finished: Finding Soma Extensions: 9.46907663345337
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [657, 31, 113, 576, 14, 25, 94, 587, 742, 671, 674, 171]
# soma_80_percent = 261109.73125
# Debugging the axon filter
# [(657, 273872.15625), (31, 268563.9375), (113, 275525.0625), (576, 276302.71875), (14, 257508.421875), (25, 272540.71875), (94, 268710.625), (587, 262154.375), (742, 272108.53125), (671, 263258.375), (674, 261603.953125), (171, 267012.34375)]
# possible_Axons_filter_1 = [14]
# possible_Axons_filter_2 = [14]
# possible_Apical = 14
# 5) Finished: Finding Apical Index: 0.08243012428283691
# 6) Staring: Classifying Entire Neuron
# 587 = stub soma
# 671 = stub soma
# 674 = stub soma
# 742 = cilia
# 32 = stub apical
# 33 = stub apical
# 54 = stub apical
# 57 = stub apical
# 64 = stub apical
# 66 = stub apical
# 68 = stub apical
# 69 = stub apical
# 71 = stub apical
# 74 = stub apical
# 92 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 101 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 115 = stub apical
# 116 = stub apical
# 118 = stub apical
# 120 = stub apical
# 121 = error
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 129 = stub apical
# 133 = stub apical
# 583 = stub apical
# 568 = stub apical
# 569 = stub apical
# 570 = stub apical
# 571 = stub apical
# 572 = stub apical
# 573 = stub apical
# 574 = stub apical
# 575 = stub apical
# 577 = stub apical
# 580 = stub apical
# 581 = stub apical
# 582 = stub apical
# 586 = stub apical
# 588 = stub apical
# 589 = stub apical
# 590 = stub apical
# 591 = stub apical
# 593 = stub apical
# 595 = stub apical
# 608 = stub apical
# 609 = stub apical
# 613 = stub apical
# 616 = stub apical
# 624 = stub apical
# 627 = stub apical
# 636 = stub apical
# 638 = stub apical
# 656 = stub apical
# 666 = stub apical
# 667 = stub apical
# 668 = stub apical
# 669 = stub apical
# 670 = stub apical
# 672 = stub apical
# 673 = stub apical
# 679 = stub apical
# 683 = stub apical
# 684 = stub apical
# 685 = stub apical
# 686 = stub apical
# 687 = stub apical
# 688 = stub apical
# 689 = stub apical
# 690 = stub apical
# 691 = stub apical
# 692 = stub apical
# 693 = stub apical
# 694 = stub apical
# 695 = stub apical
# 696 = stub apical
# 698 = stub apical
# 699 = stub apical
# 700 = stub apical
# 711 = stub apical
# 712 = stub apical
# 714 = stub apical
# 725 = stub apical
# 726 = stub apical
# 727 = stub apical
# 728 = stub apical
# 731 = stub apical
# 732 = stub apical
# 737 = stub apical
# 738 = stub apical
# 739 = stub apical
# 740 = stub apical
# 741 = stub apical
# 745 = stub apical
# 746 = stub apical
# 747 = stub apical
# 748 = stub apical
# 758 = stub apical
# 759 = stub apical
# 760 = stub apical
# 771 = stub apical
# 772 = stub apical
# 773 = stub apical
# 775 = stub apical
# 779 = stub apical
# 783 = stub apical
# 785 = stub apical
# 796 = stub apical
# 797 = stub apical
# 798 = stub apical
# 806 = stub apical
# 811 = stub apical
# 812 = stub apical
# 813 = stub apical
# 819 = stub apical
# 821 = stub apical
# 822 = stub apical
# 824 = stub apical
# 828 = stub apical
# 829 = stub apical
# 830 = stub apical
# 831 = stub apical
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.475285530090332
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.45142269134521484
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.180460929870605
# Finished Auto Labeling: 767.4375810623169
#
#
# *****Starting Auto Labeling for 648518346349503453******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04496502876281738
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 948.6651487350464
# 2) Finished: Generating CGAL segmentation for neuron: 967.0144853591919
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 18
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.24847912788391113
# 4) Staring: Finding Soma Extensions
# Found 1 soma caps and replacing labels: [524]
# done replacing soma cap labels : 10.670485496520996
# 4) Finished: Finding Soma Extensions: 11.390397310256958
# 5) Staring: Finding Apical Index
# Soma Index = 18
# Soma Connections = [101, 76, 104, 3, 74, 137, 113, 617, 112, 177, 392, 410, 239, 618]
# soma_80_percent = 257374.2296875
# Debugging the axon filter
# [(101, 265527.28125), (76, 275734.125), (104, 281600.15625), (3, 253836.890625), (74, 275584.1875), (137, 277040.34375), (113, 260028.015625), (617, 260684.515625), (112, 265394.8125), (177, 266182.84375), (392, 255895.46875), (410, 267640.28125), (239, 261444.84375), (618, 267829.125)]
# possible_Axons_filter_1 = [3, 392]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.10988402366638184
# 6) Staring: Classifying Entire Neuron
# 137 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 101
# 177 = stub soma
# 617 = cilia
# 239 = stub soma
# 392 = stub soma
# 410 = stub soma
# 618 = stub soma
# 2 = stub apical
# 21 = stub apical
# 30 = stub apical
# 33 = stub apical
# 45 = stub apical
# 48 = stub apical
# 52 = stub apical
# 57 = stub apical
# 62 = stub apical
# 65 = stub apical
# 75 = stub apical
# 102 = stub apical
# 588 = stub apical
# 109 = stub apical
# 115 = stub apical
# 118 = stub apical
# 119 = stub apical
# 121 = stub apical
# 128 = stub apical
# 131 = stub apical
# 136 = stub apical
# 141 = stub apical
# 183 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 198 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 213 = stub apical
# 216 = stub apical
# 217 = stub apical
# 219 = stub apical
# 220 = stub apical
# 225 = stub apical
# 237 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 276 = stub apical
# 277 = stub apical
# 279 = stub apical
# 281 = stub apical
# 282 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 334 = stub apical
# 335 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 344 = stub apical
# 368 = stub apical
# 377 = stub apical
# 378 = stub apical
# 380 = stub apical
# 393 = stub apical
# 403 = stub apical
# 404 = stub apical
# 407 = stub apical
# 408 = stub apical
# 430 = stub apical
# 431 = stub apical
# 432 = stub apical
# 433 = stub apical
# 448 = stub apical
# 450 = stub apical
# 451 = stub apical
# 454 = stub apical
# 455 = stub apical
# 456 = stub apical
# 457 = stub apical
# 494 = stub apical
# 495 = stub apical
# 496 = stub apical
# 497 = stub apical
# 498 = stub apical
# 499 = stub apical
# 500 = stub apical
# 504 = stub apical
# 511 = stub apical
# 512 = stub apical
# 513 = stub apical
# 514 = stub apical
# 515 = stub apical
# 587 = stub apical
# 522 = stub apical
# 523 = stub apical
# 529 = stub apical
# 530 = stub apical
# 531 = stub apical
# 532 = stub apical
# 533 = stub apical
# 534 = stub apical
# 544 = stub apical
# 545 = stub apical
# 547 = stub apical
# 564 = stub apical
# 565 = stub apical
# 566 = stub apical
# 567 = stub apical
# 568 = stub apical
# 570 = stub apical
# 578 = stub apical
# 579 = stub apical
# 586 = stub apical
# 594 = stub apical
# 595 = stub apical
# 597 = stub apical
# 598 = stub apical
# 606 = stub apical
# 607 = stub apical
# 608 = stub apical
# 609 = stub apical
# 610 = stub apical
# 611 = stub apical
# 620 = stub apical
# 623 = stub apical
# 624 = stub apical
# 625 = stub apical
# Total Labels found = {'axon', 'apical', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.9959678649902344
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5239601135253906
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.051214456558228
# Finished Auto Labeling: 993.027859210968
#
#
# *****Starting Auto Labeling for 648518346349505144******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03307366371154785
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 601.0404305458069
# 2) Finished: Generating CGAL segmentation for neuron: 615.8939182758331
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.20425128936767578
# 4) Staring: Finding Soma Extensions
# Found 20 soma caps and replacing labels: [98, 12, 425, 428, 129, 427, 608, 134, 665, 547, 604, 605, 133, 658, 650, 426, 609, 493, 659, 596]
# done replacing soma cap labels : 8.246379852294922
# 4) Finished: Finding Soma Extensions: 8.682170391082764
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [86, 22, 14, 1, 108, 7]
# soma_80_percent = 240291.6640625
# Debugging the axon filter
# [(86, 238288.421875), (22, 258387.640625), (14, 237410.1875), (1, 236940.1875), (108, 256531.3125), (7, 253223.546875)]
# possible_Axons_filter_1 = [86, 14, 1]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.09608149528503418
# 6) Staring: Classifying Entire Neuron
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 1.998779296875
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.8083691596984863
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.06424617767334
# Finished Auto Labeling: 636.3479051589966
#
#
# *****Starting Auto Labeling for 648518346349506092******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05141496658325195
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 798.7745230197906
# 2) Finished: Generating CGAL segmentation for neuron: 815.6645264625549
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21990132331848145
# 4) Staring: Finding Soma Extensions
# Found 3 soma caps and replacing labels: [14, 10, 29]
# done replacing soma cap labels : 9.75675630569458
# 4) Finished: Finding Soma Extensions: 10.28858733177185
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [3, 26, 4, 22, 17]
# soma_80_percent = 182627.4203125
# Debugging the axon filter
# [(3, 194923.734375), (26, 184472.96875), (4, 193343.75), (22, 202559.546875), (17, 179058.96875)]
# possible_Axons_filter_1 = [17]
# possible_Axons_filter_2 = [17]
# possible_Apical = 17
# 5) Finished: Finding Apical Index: 0.048081159591674805
# 6) Staring: Classifying Entire Neuron
# 30 = stub apical
# 31 = error
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.2224907875061035
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5996980667114258
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.916386604309082
# Finished Auto Labeling: 839.5682744979858
#
#
# *****Starting Auto Labeling for 648518346349507964******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04776191711425781
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 1233.2019302845001
# 2) Finished: Generating CGAL segmentation for neuron: 1255.8968415260315
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.29300737380981445
# 4) Staring: Finding Soma Extensions
# Found 17 soma caps and replacing labels: [204, 36, 40, 248, 34, 79, 19, 135, 185, 80, 249, 166, 225, 136, 182, 183, 137]
# done replacing soma cap labels : 12.752404689788818
# 4) Finished: Finding Soma Extensions: 13.24155330657959
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [13, 44, 26, 56, 47, 65, 27, 37, 125, 32, 58, 106]
# soma_80_percent = 196277.1109375
# Debugging the axon filter
# [(13, 213156.4375), (44, 202812.734375), (26, 192898.75), (56, 214893.671875), (47, 198967.15625), (65, 213277.9375), (27, 204892.65625), (37, 198710.96875), (125, 206010.875), (32, 196237.5), (58, 198992.03125), (106, 193883.953125)]
# possible_Axons_filter_1 = [26, 32, 106]
# possible_Axons_filter_2 = [26]
# possible_Apical = 26
# 5) Finished: Finding Apical Index: 0.08525419235229492
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 27
# 58 = stub soma
# 106 = cilia
# 21 = stub apical
# 28 = stub apical
# 35 = stub apical
# 48 = stub apical
# 51 = stub apical
# 62 = stub apical
# 64 = stub apical
# 72 = stub apical
# 73 = stub apical
# 75 = error
# 102 = stub apical
# 112 = stub apical
# 113 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 154 = stub apical
# 175 = stub apical
# 178 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 207 = stub apical
# 208 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 221 = stub apical
# 229 = stub apical
# 233 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# Total Labels found = {'apical', 'error', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.7649049758911133
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5470123291015625
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.456191062927246
# Finished Auto Labeling: 1286.12073636055
#
#
# *****Starting Auto Labeling for 648518346349511983******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03906869888305664
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# 1
# Finished CGAL segmentation algorithm: 601.0503325462341
# 2) Finished: Generating CGAL segmentation for neuron: 615.5904715061188
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.21041131019592285
# 4) Staring: Finding Soma Extensions
# Found 6 soma caps and replacing labels: [636, 822, 680, 495, 468, 374]
# done replacing soma cap labels : 8.059414863586426
# 4) Finished: Finding Soma Extensions: 8.496731281280518
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [16, 14, 65, 763, 494, 37, 29, 651, 769, 788, 518]
# soma_80_percent = 285465.559375
# Debugging the axon filter
# [(16, 282592.5), (14, 298894.5625), (65, 309100.25), (763, 295470.875), (494, 290568.46875), (37, 293803.53125), (29, 304509.5), (651, 297233.6875), (769, 281927.9375), (788, 294410.9375), (518, 290309.96875)]
# possible_Axons_filter_1 = [16, 769]
# possible_Axons_filter_2 = [16]
# possible_Apical = 16
# 5) Finished: Finding Apical Index: 0.06528520584106445
# 6) Staring: Classifying Entire Neuron
# 29 = axon
# 769 = cilia
# 518 = stub soma
# 788 = stub soma
# 10 = stub apical
# 17 = stub apical
# 36 = stub apical
# 42 = stub apical
# 47 = stub apical
# 63 = stub apical
# 98 = stub apical
# 135 = stub apical
# 138 = stub apical
# 139 = stub apical
# 143 = stub apical
# 218 = stub apical
# 219 = stub apical
# 222 = stub apical
# 615 = stub apical
# 330 = stub apical
# 361 = stub apical
# 362 = stub apical
# 368 = stub apical
# 369 = stub apical
# 370 = stub apical
# 371 = stub apical
# 372 = stub apical
# 373 = stub apical
# 376 = stub apical
# 377 = stub apical
# 390 = stub apical
# 391 = stub apical
# 451 = stub apical
# 521 = stub apical
# 575 = stub apical
# 576 = stub apical
# 577 = stub apical
# 579 = stub apical
# 581 = stub apical
# 582 = stub apical
# 688 = stub apical
# 689 = stub apical
# 707 = stub apical
# 740 = stub apical
# 777 = stub apical
# 786 = stub apical
# 809 = stub apical
# Total Labels found = {'axon', 'apical', 'oblique', 'soma', 'cilia', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.098968267440796
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4010281562805176
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.60078239440918
# Finished Auto Labeling: 636.0938031673431
# 10992.261020898819

# %%
#(schema.jobs & "table_name='__whole_auto_annotations'").delete()
