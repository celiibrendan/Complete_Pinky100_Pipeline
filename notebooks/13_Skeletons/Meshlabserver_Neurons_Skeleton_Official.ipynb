# %%
"""
Will generate the skeletons for all of the
Neurites

Process: 
1) Pull from ta3p100.Mesh
-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS
2) Voxelize the mesh 
3) Export the mesh to an off file
4) Clean up the mesh using:
a. smoothing normals
b. Poisson surface reconstruction
c. Extra remove duplicate filters
5) Send through skeletonization
6) Reading in skeleton segments
7) Write key to database

"""
# Out:
# "\nWill generate the skeletons for all of the\nNeurites\n\nProcess: \n1) Pull from ta3p100.Mesh\n-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS\n2) Voxelize the mesh \n3) Export the mesh to an off file\n4) Clean up the mesh using:\na. smoothing normals\nb. Poisson surface reconstruction\nc. Extra remove duplicate filters\n5) Send through skeletonization\n6) Reading in skeleton segments\n7) Write key to database\n\n"

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/temp_meshlab")) == False:
    os.mkdir("temp_meshlab")

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
#get keysource:
ta3p100.Mesh() & ta3p100.Neurite() #32207 tuples
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 2              64851834634135 28754          57350          =BLOB=     =BLOB=
# 2              64851834634135 11192          22282          =BLOB=     =BLOB=
# 2              64851834634135 58449          116104         =BLOB=     =BLOB=
# 2              64851834634135 24919          49578          =BLOB=     =BLOB=
# 2              64851834634135 37179          74128          =BLOB=     =BLOB=
# 2              64851834634135 37788          75374          =BLOB=     =BLOB=
# 2              64851834634135 20204          40278          =BLOB=     =BLOB=
# 2              64851834634135 15522          30788          =BLOB=     =BLOB=
# 2              64851834634135 45964          91650          =BLOB=     =BLOB=
# 2              64851834634135 21520          42882          =BLOB=     =BLOB=
# 2              64851834634135 12322          24626          =BLOB=     =BLOB=
# 2              64851834634135 75579          150562         =BLOB=     =BLOB=
# 2              64851834634135 16502          32932          =BLOB=     =BLOB=
# 2              64851834634135 26033          51854          =BLOB=     =BLOB=
# 2              64851834634135 29746          59138          =BLOB=     =BLOB=
# 2              64851834634135 23521          46928          =BLOB=     =BLOB=
# 2              64851834634135 29968          59422          =BLOB=     =BLOB=
# 2              64851834634135 15603          31082          =BLOB=     =BLOB=
# 2              64851834634135 42781          85094          =BLOB=     =BLOB=
# 2              64851834634135 18804          37506          =BLOB=     =BLOB=
#    ...
#  (32207 tuples)

# %%
def meshlab_shrinkwrap(key):
    
    file_loc = pathlib.Path.cwd() / "temp_meshlab"
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    midoutput_mesh = path_and_filename + "_mid.off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_script.mlx"
    meshlab_script_rem_dupl = str(pathlib.Path.cwd()) + "/" + "remeshing_script-Remove.mlx"
    #send to meshlabserver
    print("starting meshlabserver Poisson surface reconstruction")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      midoutput_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass Poisson')
    #print(type)
     
    
    #do another call to remove the final duplicate vertices
    print("starting meshlabserver cleaning")
    subprocess_result_2 = run_meshlab_script(meshlab_script_rem_dupl,
                      midoutput_mesh,
                      output_mesh)
    #print("Cleaning subprocess_result= "+ str(subprocess_result_2))
    
    if str(subprocess_result_2)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass cleaning')
    
    
    return output_mesh

# %%
#don't need the vertices for this one because not doing any filtering

@schema
class NeuriteSkeletons(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the skeleton was generated
    ---
    n_branches   :int unsigned #number of edges stored
    branches     :longblob #array storing vertices of edges and each seperated by Nan
    """
    
    key_source = ta3p100.Mesh() & ta3p100.Neurite() 
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        print("Starting on "+str(key["segment_id"]))
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        file_loc = pathlib.Path.cwd() / "temp_meshlab"
        filename = "neuron_" + str(key["segment_id"])
        path_and_filename = str(file_loc / filename)
        
        #get the mesh of the neurite
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        mesh = (ta3p100.Mesh & new_key).fetch1()
        print(f"Step 1: Retrieving Mesh: {time.time() - start_time}")
        
        #Do voxelization
        start_time = time.time()
        mesh = trimesh_io.Mesh(vertices=mesh["vertices"], faces=mesh["triangles"])
        voxels = mesh.voxelized(500)
        voxel_mesh = voxels.as_boxes()
        print(f"Step 2: Voxelization: {time.time() - start_time}")
        
        #Exporting the Voxelization as an off file for meshlabserver
        start_time = time.time()
        #try the inline printing method:
        with open(os.devnull, 'w') as devnull:
            with contextlib.redirect_stdout(devnull):
                voxel_mesh.export(str(path_and_filename) + ".off")
        print(f"Step 3: Exporting Voxel Off function: {time.time() - start_time}")
        
        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_shrinkwrap(key)
        print(f"Step 4: Meshlab shrinkwrapping: {time.time() - start_time}")
        
        #Create the skeleton and retrieve it from the generated file
        #skeletonize the mesh
        start_time = time.time()
        #print("starting creating skeleton")
        return_value = cm.calcification(output_mesh[:-4])
        #print("calcif_return_value = " + str(return_value))
        
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
        
        #read in the skeleton files into an array
        start_time = time.time()
        bone_array = read_skeleton_flat(output_mesh[:-4]+"_skeleton.cgal")
        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Reading in Skeleton: {time.time() - start_time}")
        
              
        start_time = time.time()
        new_key["n_branches"] = len(bone_array)
        new_key["branches"] = bone_array
        #new_key["branches"] = []
        
        
        new_key["time_updated"]=str(datetime.datetime.now())
        #print(new_key)
        #if all goes well then write to database
        self.insert1(new_key)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary and erased files: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
start = time.time()
NeuriteSkeletons.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# Starting on 648518346341352911
# Step 1: Retrieving Mesh: 0.04831814765930176
# Step 2: Voxelization: 0.09458017349243164
# Step 3: Exporting Voxel Off function: 0.03656649589538574
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.443084001541138
# Step 4: Generating Skeleton: 0.3896353244781494
# Step 5: Reading in Skeleton: 0.0014810562133789062
# Step 6: Inserting dictionary and erased files: 0.02983260154724121
# Total time: 5.046126127243042
#
#
#
# Starting on 648518346341353060
# Step 1: Retrieving Mesh: 0.03585529327392578
# Step 2: Voxelization: 0.10836505889892578
# Step 3: Exporting Voxel Off function: 0.05378580093383789
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.603152513504028
# Step 4: Generating Skeleton: 0.45560598373413086
# Step 5: Reading in Skeleton: 0.002617359161376953
# Step 6: Inserting dictionary and erased files: 0.040997982025146484
# Total time: 5.301974773406982
#
#
#
# Starting on 648518346341353166
# Step 1: Retrieving Mesh: 0.03191661834716797
# Step 2: Voxelization: 0.09539914131164551
# Step 3: Exporting Voxel Off function: 0.04416847229003906
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.055232763290405
# Step 4: Generating Skeleton: 0.7347445487976074
# Step 5: Reading in Skeleton: 0.0017671585083007812
# Step 6: Inserting dictionary and erased files: 0.03376197814941406
# Total time: 5.999990224838257
#
#
#
# Starting on 648518346341353249
# Step 1: Retrieving Mesh: 0.0748739242553711
# Step 2: Voxelization: 0.19707059860229492
# Step 3: Exporting Voxel Off function: 0.06905078887939453
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.205057859420776
# Step 4: Generating Skeleton: 1.7028801441192627
# Step 5: Reading in Skeleton: 0.008009672164916992
# Step 6: Inserting dictionary and erased files: 0.03509807586669922
# Total time: 8.294520378112793
#
#
#
# Starting on 648518346341353409
# Step 1: Retrieving Mesh: 0.09499120712280273
# Step 2: Voxelization: 0.33110928535461426
# Step 3: Exporting Voxel Off function: 0.08707594871520996
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.5804808139801025
# Step 4: Generating Skeleton: 1.0771946907043457
# Step 5: Reading in Skeleton: 0.006688117980957031
# Step 6: Inserting dictionary and erased files: 0.029155731201171875
# Total time: 8.209164142608643
#
#
#
# Starting on 648518346341353562
# Step 1: Retrieving Mesh: 0.059145450592041016
# Step 2: Voxelization: 0.05867171287536621
# Step 3: Exporting Voxel Off function: 0.02874755859375
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.837407350540161
# Step 4: Generating Skeleton: 0.2743380069732666
# Step 5: Reading in Skeleton: 0.00138092041015625
# Step 6: Inserting dictionary and erased files: 0.0335536003112793
# Total time: 4.294375419616699
#
#
#
# Starting on 648518346341353675
# Step 1: Retrieving Mesh: 0.07562398910522461
# Step 2: Voxelization: 0.16661310195922852
# Step 3: Exporting Voxel Off function: 0.05902242660522461
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.47838830947876
# Step 4: Generating Skeleton: 0.454866886138916
# Step 5: Reading in Skeleton: 0.0020003318786621094
# Step 6: Inserting dictionary and erased files: 0.03880810737609863
# Total time: 5.2786781787872314
#
#
#
# Starting on 648518346341353752
# Step 1: Retrieving Mesh: 0.04166865348815918
# Step 2: Voxelization: 0.05666041374206543
# Step 3: Exporting Voxel Off function: 0.034238576889038086
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.105703592300415
# Step 4: Generating Skeleton: 0.27213311195373535
# Step 5: Reading in Skeleton: 0.0027289390563964844
# Step 6: Inserting dictionary and erased files: 0.028459787368774414
# Total time: 4.543733358383179
#
#
#
# Starting on 648518346341353862
# Step 1: Retrieving Mesh: 0.04363608360290527
# Step 2: Voxelization: 0.05788731575012207
# Step 3: Exporting Voxel Off function: 0.027585983276367188
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.400824308395386
# Step 4: Generating Skeleton: 0.5982413291931152
# Step 5: Reading in Skeleton: 0.005074262619018555
# Step 6: Inserting dictionary and erased files: 0.03127479553222656
# Total time: 5.167113304138184
#
#
#
# Starting on 648518346341353888
# Step 1: Retrieving Mesh: 0.04037117958068848
# Step 2: Voxelization: 0.04114246368408203
# Step 3: Exporting Voxel Off function: 0.016644001007080078
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.766538143157959
# Step 4: Generating Skeleton: 0.37791967391967773
# Step 5: Reading in Skeleton: 0.001554250717163086
# Step 6: Inserting dictionary and erased files: 0.04304075241088867
# Total time: 4.289126634597778
#
#
#
# Starting on 648518346341353986
# Step 1: Retrieving Mesh: 0.04903149604797363
# Step 2: Voxelization: 0.17366862297058105
# Step 3: Exporting Voxel Off function: 0.06480860710144043
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.5327887535095215
# Step 4: Generating Skeleton: 0.6923325061798096
# Step 5: Reading in Skeleton: 0.002915620803833008
# Step 6: Inserting dictionary and erased files: 0.041077375411987305
# Total time: 5.5596020221710205
#
#
#
# Starting on 648518346341354076
# Step 1: Retrieving Mesh: 0.04230499267578125
# Step 2: Voxelization: 0.06095528602600098
# Step 3: Exporting Voxel Off function: 0.03399395942687988
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.059760570526123
# Step 4: Generating Skeleton: 0.22744154930114746
# Step 5: Reading in Skeleton: 0.002161264419555664
# Step 6: Inserting dictionary and erased files: 0.03369474411010742
# Total time: 4.463215112686157
#
#
#
# Starting on 648518346341354256
# Step 1: Retrieving Mesh: 0.04582691192626953
# Step 2: Voxelization: 0.06752634048461914
# Step 3: Exporting Voxel Off function: 0.030323505401611328
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.374168157577515
# Step 4: Generating Skeleton: 0.449749231338501
# Step 5: Reading in Skeleton: 0.0027997493743896484
# Step 6: Inserting dictionary and erased files: 0.03441977500915527
# Total time: 5.00702428817749
#
#
#
# Starting on 648518346341354363
# Step 1: Retrieving Mesh: 0.03106069564819336
# Step 2: Voxelization: 0.06697607040405273
# Step 3: Exporting Voxel Off function: 0.03951430320739746
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.844266414642334
# Step 4: Generating Skeleton: 0.8459851741790771
# Step 5: Reading in Skeleton: 0.00448918342590332
# Step 6: Inserting dictionary and erased files: 0.02818012237548828
# Total time: 5.8621437549591064
#
#
#
# Starting on 648518346341354514
# Step 1: Retrieving Mesh: 0.043198585510253906
# Step 2: Voxelization: 0.08407878875732422
# Step 3: Exporting Voxel Off function: 0.051126718521118164
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.288021087646484
# Step 4: Generating Skeleton: 0.35041069984436035
# Step 5: Reading in Skeleton: 0.002466440200805664
# Step 6: Inserting dictionary and erased files: 0.03280019760131836
# Total time: 4.8539886474609375
#
#
#
# Starting on 648518346341354568
# Step 1: Retrieving Mesh: 0.0456385612487793
# Step 2: Voxelization: 0.06682777404785156
# Step 3: Exporting Voxel Off function: 0.029900550842285156
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.168497323989868
# Step 4: Generating Skeleton: 0.5716962814331055
# Step 5: Reading in Skeleton: 0.0037086009979248047
# Step 6: Inserting dictionary and erased files: 0.03469276428222656
# Total time: 4.923517942428589
#
#
#
# Starting on 648518346341354587
# Step 1: Retrieving Mesh: 0.05833172798156738
# Step 2: Voxelization: 0.07238626480102539
# Step 3: Exporting Voxel Off function: 0.036615848541259766
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.779148817062378
# Step 4: Generating Skeleton: 0.48513054847717285
# Step 5: Reading in Skeleton: 0.0030574798583984375
# Step 6: Inserting dictionary and erased files: 0.03254985809326172
# Total time: 5.469558477401733
#
#
#
# Starting on 648518346341354666
# Step 1: Retrieving Mesh: 0.05482745170593262
# Step 2: Voxelization: 0.0693967342376709
# Step 3: Exporting Voxel Off function: 0.033258914947509766
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.20674467086792
# Step 4: Generating Skeleton: 0.32118749618530273
# Step 5: Reading in Skeleton: 0.0012905597686767578
# Step 6: Inserting dictionary and erased files: 0.03217601776123047
# Total time: 4.721510410308838
#
#
#
# Starting on 648518346341354703
# Step 1: Retrieving Mesh: 0.017737150192260742
# Step 2: Voxelization: 0.041387081146240234
# Step 3: Exporting Voxel Off function: 0.022349119186401367
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.051236391067505
# Step 4: Generating Skeleton: 0.4745802879333496
# Step 5: Reading in Skeleton: 0.0019185543060302734
# Step 6: Inserting dictionary and erased files: 0.02743840217590332
# Total time: 4.638832330703735
#
#
#
# Starting on 648518346341354749
# Step 1: Retrieving Mesh: 0.03980278968811035
# Step 2: Voxelization: 0.07709026336669922
# Step 3: Exporting Voxel Off function: 0.051146507263183594
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.320664644241333
# Step 4: Generating Skeleton: 0.6771175861358643
# Step 5: Reading in Skeleton: 0.003218412399291992
# Step 6: Inserting dictionary and erased files: 0.03892874717712402
# Total time: 5.209203481674194
#
#
#
# Starting on 648518346341354875
# Step 1: Retrieving Mesh: 0.040180206298828125
# Step 2: Voxelization: 0.11245322227478027
# Step 3: Exporting Voxel Off function: 0.05466818809509277
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.263094902038574
# Step 4: Generating Skeleton: 0.31887197494506836
# Step 5: Reading in Skeleton: 0.002222776412963867
# Step 6: Inserting dictionary and erased files: 0.027037858963012695
# Total time: 4.821383237838745
#
#
#
# Starting on 648518346341354976
# Step 1: Retrieving Mesh: 0.02351546287536621
# Step 2: Voxelization: 0.05395674705505371
# Step 3: Exporting Voxel Off function: 0.04260373115539551
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.36347508430481
# Step 4: Generating Skeleton: 0.32737112045288086
# Step 5: Reading in Skeleton: 0.002151966094970703
# Step 6: Inserting dictionary and erased files: 0.040404319763183594
# Total time: 4.855785131454468
#
#
#
# Starting on 648518346341355055
# Step 1: Retrieving Mesh: 0.046991586685180664
# Step 2: Voxelization: 0.1226511001586914
# Step 3: Exporting Voxel Off function: 0.05311250686645508
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.419600486755371
# Step 4: Generating Skeleton: 1.0260298252105713
# Step 5: Reading in Skeleton: 0.0054781436920166016
# Step 6: Inserting dictionary and erased files: 0.03341507911682129
# Total time: 6.709398508071899
#
#
#
# Starting on 648518346341355183
# Step 1: Retrieving Mesh: 0.06754207611083984
# Step 2: Voxelization: 0.31910157203674316
# Step 3: Exporting Voxel Off function: 0.13261890411376953
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 8.202459812164307
# Step 4: Generating Skeleton: 1.8295409679412842
# Step 5: Reading in Skeleton: 0.00893545150756836
# Step 6: Inserting dictionary and erased files: 0.04152417182922363
# Total time: 10.603882074356079
#
#
#
# Starting on 648518346341355247
# Step 1: Retrieving Mesh: 0.07417654991149902
# Step 2: Voxelization: 0.2859487533569336
# Step 3: Exporting Voxel Off function: 0.13980889320373535
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 8.566655397415161
# Step 4: Generating Skeleton: 2.060965061187744
# Step 5: Reading in Skeleton: 0.006744861602783203
# Step 6: Inserting dictionary and erased files: 0.032704830169677734
# Total time: 11.16854977607727
#
#
#
# Starting on 648518346341355352
# Step 1: Retrieving Mesh: 0.04203033447265625
# Step 2: Voxelization: 0.20869946479797363
# Step 3: Exporting Voxel Off function: 0.138502836227417
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.314351558685303
# Step 4: Generating Skeleton: 1.272310733795166
# Step 5: Reading in Skeleton: 0.005673646926879883
# Step 6: Inserting dictionary and erased files: 0.0372772216796875
# Total time: 8.020951747894287
#
#
#
# Starting on 648518346341355502
# Step 1: Retrieving Mesh: 0.04590797424316406
# Step 2: Voxelization: 0.16839361190795898
# Step 3: Exporting Voxel Off function: 0.0998542308807373
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.408761262893677
# Step 4: Generating Skeleton: 1.1991493701934814
# Step 5: Reading in Skeleton: 0.0032737255096435547
# Step 6: Inserting dictionary and erased files: 0.02452874183654785
# Total time: 7.951221466064453
#
#
#
# Starting on 648518346341355625
# Step 1: Retrieving Mesh: 0.0452580451965332
# Step 2: Voxelization: 0.12583088874816895
# Step 3: Exporting Voxel Off function: 0.06975030899047852
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.630520820617676
# Step 4: Generating Skeleton: 0.5312807559967041
# Step 5: Reading in Skeleton: 0.002834796905517578
# Step 6: Inserting dictionary and erased files: 0.027866363525390625
# Total time: 5.435503244400024
#
#
#
# Starting on 648518346341355722
# Step 1: Retrieving Mesh: 0.046616554260253906
# Step 2: Voxelization: 0.17316365242004395
# Step 3: Exporting Voxel Off function: 0.09397530555725098
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.838091850280762
# Step 4: Generating Skeleton: 1.4866993427276611
# Step 5: Reading in Skeleton: 0.006638526916503906
# Step 6: Inserting dictionary and erased files: 0.037319183349609375
# Total time: 8.685871601104736
#
#
#
# Starting on 648518346341355867
# Step 1: Retrieving Mesh: 0.021782875061035156
# Step 2: Voxelization: 0.06010699272155762
# Step 3: Exporting Voxel Off function: 0.03234076499938965
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.0429747104644775
# Step 4: Generating Skeleton: 0.7304122447967529
# Step 5: Reading in Skeleton: 0.0028595924377441406
# Step 6: Inserting dictionary and erased files: 0.028293371200561523
# Total time: 4.920263767242432
#
#
#
# Starting on 648518346341355971
# Step 1: Retrieving Mesh: 0.021923303604125977
# Step 2: Voxelization: 0.08925628662109375
# Step 3: Exporting Voxel Off function: 0.05452775955200195
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.967671632766724
# Step 4: Generating Skeleton: 0.8015282154083252
# Step 5: Reading in Skeleton: 0.0038046836853027344
# Step 6: Inserting dictionary and erased files: 0.026181697845458984
# Total time: 5.9671289920806885
#
#
#
# Starting on 648518346341356054
# Step 1: Retrieving Mesh: 0.03602433204650879
# Step 2: Voxelization: 0.08360433578491211
# Step 3: Exporting Voxel Off function: 0.06166791915893555
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.166116237640381
# Step 4: Generating Skeleton: 1.0459017753601074
# Step 5: Reading in Skeleton: 0.004642486572265625
# Step 6: Inserting dictionary and erased files: 0.023943424224853516
# Total time: 6.4231178760528564
#
#
#
# Starting on 648518346341356158
# Step 1: Retrieving Mesh: 0.026829004287719727
# Step 2: Voxelization: 0.10601806640625
# Step 3: Exporting Voxel Off function: 0.05939078330993652
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.2511887550354
# Step 4: Generating Skeleton: 0.5438575744628906
# Step 5: Reading in Skeleton: 0.0016169548034667969
# Step 6: Inserting dictionary and erased files: 0.031187772750854492
# Total time: 5.022538900375366
#
#
#
# Starting on 648518346341356223
# Step 1: Retrieving Mesh: 0.03742671012878418
# Step 2: Voxelization: 0.09552192687988281
# Step 3: Exporting Voxel Off function: 0.05618000030517578
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.607133865356445
# Step 4: Generating Skeleton: 0.672199010848999
# Step 5: Reading in Skeleton: 0.0013191699981689453
# Step 6: Inserting dictionary and erased files: 0.028319120407104492
# Total time: 5.5017290115356445
#
#
#
# Starting on 648518346341356294
# Step 1: Retrieving Mesh: 0.058527469635009766
# Step 2: Voxelization: 0.1281907558441162
# Step 3: Exporting Voxel Off function: 0.08209657669067383
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.336142301559448
# Step 4: Generating Skeleton: 1.2459757328033447
# Step 5: Reading in Skeleton: 0.0017626285552978516
# Step 6: Inserting dictionary and erased files: 0.02830052375793457
# Total time: 6.8844358921051025
#
#
#
# Starting on 648518346341356315
# Step 1: Retrieving Mesh: 0.09034919738769531
# Step 2: Voxelization: 0.3112983703613281
# Step 3: Exporting Voxel Off function: 0.1587817668914795
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 7.086430311203003
# Step 4: Generating Skeleton: 1.610525131225586
# Step 5: Reading in Skeleton: 0.007057666778564453
# Step 6: Inserting dictionary and erased files: 0.03409242630004883
# Total time: 9.300665378570557
#
#
#
# Starting on 648518346341356390
# Step 1: Retrieving Mesh: 0.02700662612915039
# Step 2: Voxelization: 0.0571744441986084
# Step 3: Exporting Voxel Off function: 0.037892818450927734
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.064001798629761
# Step 4: Generating Skeleton: 0.5298984050750732
# Step 5: Reading in Skeleton: 0.003142833709716797
# Step 6: Inserting dictionary and erased files: 0.030042171478271484
# Total time: 4.750504970550537
#
#
#
# Starting on 648518346341356579
# Step 1: Retrieving Mesh: 0.026989459991455078
# Step 2: Voxelization: 0.12740373611450195
# Step 3: Exporting Voxel Off function: 0.07395100593566895
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.747058153152466
# Step 4: Generating Skeleton: 1.2808895111083984
# Step 5: Reading in Skeleton: 0.001577138900756836
# Step 6: Inserting dictionary and erased files: 0.0281674861907959
# Total time: 7.290105104446411
#
#
#
# Starting on 648518346341356625
# Step 1: Retrieving Mesh: 0.024709224700927734
# Step 2: Voxelization: 0.1031336784362793
# Step 3: Exporting Voxel Off function: 0.0649409294128418
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.666025876998901
# Step 4: Generating Skeleton: 0.8133678436279297
# Step 5: Reading in Skeleton: 0.001850128173828125
# Step 6: Inserting dictionary and erased files: 0.027436017990112305
# Total time: 5.703348398208618
#
#
#
# Starting on 648518346341356730
# Step 1: Retrieving Mesh: 0.036562204360961914
# Step 2: Voxelization: 0.15038847923278809
# Step 3: Exporting Voxel Off function: 0.0906376838684082
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.484182119369507
# Step 4: Generating Skeleton: 0.9845232963562012
# Step 5: Reading in Skeleton: 0.006139278411865234
# Step 6: Inserting dictionary and erased files: 0.028380870819091797
# Total time: 6.78230094909668
#
#
#
# Starting on 648518346341356900
# Step 1: Retrieving Mesh: 0.024322032928466797
# Step 2: Voxelization: 0.06527328491210938
# Step 3: Exporting Voxel Off function: 0.03165769577026367
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.756925106048584
# Step 4: Generating Skeleton: 0.6754310131072998
# Step 5: Reading in Skeleton: 0.0034821033477783203
# Step 6: Inserting dictionary and erased files: 0.02223348617553711
# Total time: 4.582172155380249
#
#
#
# Starting on 648518346341356915
# Step 1: Retrieving Mesh: 0.053203582763671875
# Step 2: Voxelization: 0.08699584007263184
# Step 3: Exporting Voxel Off function: 0.050861358642578125
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.323090314865112
# Step 4: Generating Skeleton: 0.5562362670898438
# Step 5: Reading in Skeleton: 0.0013854503631591797
# Step 6: Inserting dictionary and erased files: 0.027552366256713867
# Total time: 5.102048873901367
#
#
#
# Starting on 648518346341357003
# Step 1: Retrieving Mesh: 0.05596160888671875
# Step 2: Voxelization: 0.15679025650024414
# Step 3: Exporting Voxel Off function: 0.08683013916015625
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.267192363739014
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-a4b23312f459> in <module>
#       1 start = time.time()
# ----> 2 NeuriteSkeletons.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-9-cc4a9e57f3f1> in make(self, key)
#      60         if return_value > 0:
#      61             raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) +
# ---> 62                             ' did not finish... exited with error code: ' + str(return_value))
#      63         print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
#      64
#
# Exception: skeletonization for neuron 648518346341357003 did not finish... exited with error code: 4

# %%
ta3p100.NeuriteSkeletons().delete()
