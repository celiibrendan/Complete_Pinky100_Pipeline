# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473813**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473813_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 4.891564130783081
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9191726405966354% of original mesh
#  face length 2907743 using optimized facets with 3 neighbors
# Filtering edges by size finished: 54.3357834815979, facet # = 155059
# Filtering by convexity and getting centers took: 87.35056829452515, facet # = 29616
# Finished facets for main mesh: 146.47959780693054 with facet length = 29616
# Finished 29616 facets for main mesh: 146.48016929626465
# Filtering edges by size finished: 0.03173565864562988, facet # = 10
# Filtering by convexity and getting centers took: 0.00834202766418457, facet # = 5
# Total time for facets: 146.53969526290894
# Zero faceted faces = []
# Starting Child 0
# 5 29616
# Done distance matrix: 0.010737180709838867
# Done Generating final pairs: 0.05979013442993164
# best_stitch_pair = [    1 18945]
# best_stitch_pair_size = 77216.73869712153
# best_stitch_pair_distance = 1899.5423658449608
# best_stitch_pair_size_ratio = 0.3427660523259914
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [1, 18945]}
# ---Stitching child 0 with pair: [1, 18945]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 257604, starting edge 2nd facet= 1458818,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.5033950805664062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04877066612243652
# returned from stitch mesh: 1.9932799339294434
# Finished stitching child 0 : 2.2926204204559326
# ***************Finished big stitching iteration: 2.7603139877319336***************
# All children have been processed
# total_stitch_processing_time = 2.760922431945801
# Total time for restitching = 2.7705047130584717
# missed_children = []
# Whole stitching function complete: 158.23870611190796
#
#
#
# *****Running Neuron Stitcher for 648518346349475510**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349475510_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.5507347583770752
# Number of outside child meshes =  4
# Main mesh and outside child meshes make up 0.9563104075677816% of original mesh
#  face length 764084 using optimized facets with 3 neighbors
# Filtering edges by size finished: 23.77426767349243, facet # = 39609
# Filtering by convexity and getting centers took: 24.006436824798584, facet # = 8128
# Finished 8128 facets for main mesh: 49.32475399971008
# Filtering edges by size finished: 0.0984354019165039, facet # = 474
# Filtering by convexity and getting centers took: 0.25741076469421387, facet # = 78
# Filtering edges by size finished: 0.002514362335205078, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002641439437866211, facet # = 2
# Filtering edges by size finished: 0.0008416175842285156, facet # = 5
# Filtering by convexity and getting centers took: 0.0024695396423339844, facet # = 3
# Filtering edges by size finished: 0.0006449222564697266, facet # = 5
# Filtering by convexity and getting centers took: 0.0025703907012939453, facet # = 5
# Total time for facets: 49.70689249038696
# Zero faceted faces = []
# Starting Child 0
# 78 8128
# Done distance matrix: 0.03708291053771973
# Done Generating final pairs: 0.39626240730285645
# best_stitch_pair = [   0 2718]
# best_stitch_pair_size = 449578.6839942345
# best_stitch_pair_distance = 1216.3895972922305
# best_stitch_pair_size_ratio = 0.16143171784610053
# Starting Child 1
# 2 8128
# Done distance matrix: 0.0009007453918457031
# Done Generating final pairs: 0.016683340072631836
# best_stitch_pair = [   1 7278]
# best_stitch_pair_size = 40778.50794691392
# best_stitch_pair_distance = 1671.4855210566723
# best_stitch_pair_size_ratio = 0.40556166411064576
# Starting Child 2
# 3 8128
# Done distance matrix: 0.0013699531555175781
# Done Generating final pairs: 0.0457463264465332
# best_stitch_pair = [   0 5340]
# best_stitch_pair_size = 100996.11986570068
# best_stitch_pair_distance = 1342.2075947681944
# best_stitch_pair_size_ratio = 0.36737953551927904
# Starting Child 3
# 5 8128
# Done distance matrix: 0.0018610954284667969
# Done Generating final pairs: 0.016440391540527344
# best_stitch_pair = [   3 1120]
# best_stitch_pair_size = 48948.49446942443
# best_stitch_pair_distance = 1036.6478616569793
# best_stitch_pair_size_ratio = 0.38662886470577235
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [0, 2718], 1: [1, 7278], 2: [0, 5340], 3: [3, 1120]}
# ---Stitching child 0 with pair: [0, 2718]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 352588, starting edge 2nd facet= 381550,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.956390380859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05202531814575195
# returned from stitch mesh: 0.6459853649139404
# Finished stitching child 0 : 0.6835684776306152
# ---Stitching child 1 with pair: [1, 7278]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 203865, starting edge 2nd facet= 382162,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 3.1948089599609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022683143615722656
# returned from stitch mesh: 0.9680354595184326
# Finished stitching child 1 : 1.2038662433624268
# ---Stitching child 2 with pair: [0, 5340]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 176053, starting edge 2nd facet= 382203,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.7894973754882812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.026813030242919922
# returned from stitch mesh: 0.9022946357727051
# Finished stitching child 2 : 1.033217191696167
# ---Stitching child 3 with pair: [3, 1120]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 100858, starting edge 2nd facet= 382216,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012052059173583984
# returned from stitch mesh: 0.8899803161621094
# Finished stitching child 3 : 1.020617961883545
# ***************Finished big stitching iteration: 4.615043878555298***************
# All children have been processed
# total_stitch_processing_time = 4.615491628646851
# Total time for restitching = 4.617881536483765
# missed_children = []
# Whole stitching function complete: 57.02585244178772
#
#
#
# *****Running Neuron Stitcher for 648518346349475536**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 1739 pieces after mesh split
# There were 140 pieces found after size threshold
# max_index = 0
# max_face_len = 2617384
# Total time for Mesh Cleansing: 640.7178330421448
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9918793033079646% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349482312**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349482312_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.312655687332153
# Number of outside child meshes =  52
# Main mesh and outside child meshes make up 0.9286207676077565% of original mesh
#  face length 2886132 using optimized facets with 3 neighbors
# Filtering edges by size finished: 60.2630398273468, facet # = 150412
# Filtering by convexity and getting centers took: 88.09043502807617, facet # = 30508
# Finished facets for main mesh: 155.81674528121948 with facet length = 30508
# Finished 30508 facets for main mesh: 155.81695675849915
# Filtering edges by size finished: 0.5061306953430176, facet # = 1601
# Filtering by convexity and getting centers took: 0.9956352710723877, facet # = 393
# Filtering edges by size finished: 0.0032095909118652344, facet # = 26
# Filtering by convexity and getting centers took: 0.012296915054321289, facet # = 12
# Filtering edges by size finished: 1.0882527828216553, facet # = 3141
# Filtering by convexity and getting centers took: 1.337496280670166, facet # = 758
# Filtering edges by size finished: 0.003045320510864258, facet # = 22
# Filtering by convexity and getting centers took: 0.009182214736938477, facet # = 13
# Filtering edges by size finished: 0.47556591033935547, facet # = 1930
# Filtering by convexity and getting centers took: 1.0396692752838135, facet # = 349
# Filtering edges by size finished: 0.016095399856567383, facet # = 73
# Filtering by convexity and getting centers took: 0.020882606506347656, facet # = 22
# Filtering edges by size finished: 0.5776805877685547, facet # = 1305
# Filtering by convexity and getting centers took: 0.724898099899292, facet # = 325
# Filtering edges by size finished: 0.0036029815673828125, facet # = 7
# Filtering by convexity and getting centers took: 0.005068063735961914, facet # = 5
# Filtering edges by size finished: 0.0023949146270751953, facet # = 9
# Filtering by convexity and getting centers took: 0.0062406063079833984, facet # = 7
# Filtering edges by size finished: 0.012218713760375977, facet # = 37
# Filtering by convexity and getting centers took: 0.014275074005126953, facet # = 4
# Filtering edges by size finished: 0.013876676559448242, facet # = 61
# Filtering by convexity and getting centers took: 0.01798391342163086, facet # = 32
# Filtering edges by size finished: 0.004410982131958008, facet # = 36
# Filtering by convexity and getting centers took: 0.014533042907714844, facet # = 8
# Filtering edges by size finished: 0.0016405582427978516, facet # = 12
# Filtering by convexity and getting centers took: 0.0044324398040771484, facet # = 7
# Filtering edges by size finished: 0.002954721450805664, facet # = 17
# Filtering by convexity and getting centers took: 0.00525975227355957, facet # = 7
# Filtering edges by size finished: 0.0025484561920166016, facet # = 14
# Filtering by convexity and getting centers took: 0.0048961639404296875, facet # = 7
# Filtering edges by size finished: 0.006908893585205078, facet # = 29
# Filtering by convexity and getting centers took: 0.010648488998413086, facet # = 21
# Filtering edges by size finished: 0.0023391246795654297, facet # = 11
# Filtering by convexity and getting centers took: 0.004111051559448242, facet # = 11
# Filtering edges by size finished: 0.005099058151245117, facet # = 21
# Filtering by convexity and getting centers took: 0.00833272933959961, facet # = 11
# Filtering edges by size finished: 0.004251956939697266, facet # = 18
# Filtering by convexity and getting centers took: 0.008266687393188477, facet # = 11
# Filtering edges by size finished: 0.0036377906799316406, facet # = 17
# Filtering by convexity and getting centers took: 0.008414030075073242, facet # = 4
# Filtering edges by size finished: 0.008442878723144531, facet # = 13
# Filtering by convexity and getting centers took: 0.005922794342041016, facet # = 5
# Filtering edges by size finished: 0.0012235641479492188, facet # = 7
# Filtering by convexity and getting centers took: 0.0030355453491210938, facet # = 2
# Filtering edges by size finished: 0.0024018287658691406, facet # = 12
# Filtering by convexity and getting centers took: 0.004878520965576172, facet # = 3
# Filtering edges by size finished: 0.001954317092895508, facet # = 9
# Filtering by convexity and getting centers took: 0.004961490631103516, facet # = 5
# Filtering edges by size finished: 0.002172231674194336, facet # = 10
# Filtering by convexity and getting centers took: 0.004508495330810547, facet # = 5
# Filtering edges by size finished: 0.007382392883300781, facet # = 23
# Filtering by convexity and getting centers took: 0.010411262512207031, facet # = 11
# Filtering edges by size finished: 0.02215576171875, facet # = 35
# Filtering by convexity and getting centers took: 0.019778728485107422, facet # = 12
# Filtering edges by size finished: 0.003400087356567383, facet # = 8
# Filtering by convexity and getting centers took: 0.0041124820709228516, facet # = 6
# Filtering edges by size finished: 0.005655527114868164, facet # = 28
# Filtering by convexity and getting centers took: 0.01076817512512207, facet # = 5
# Filtering edges by size finished: 0.0013647079467773438, facet # = 7
# Filtering by convexity and getting centers took: 0.003100872039794922, facet # = 2
# Filtering edges by size finished: 0.005002737045288086, facet # = 22
# Filtering by convexity and getting centers took: 0.009536504745483398, facet # = 11
# Filtering edges by size finished: 0.001667022705078125, facet # = 8
# Filtering by convexity and getting centers took: 0.0040798187255859375, facet # = 5
# Filtering edges by size finished: 0.011807918548583984, facet # = 28
# Filtering by convexity and getting centers took: 0.012074470520019531, facet # = 5
# Filtering edges by size finished: 0.01772475242614746, facet # = 87
# Filtering by convexity and getting centers took: 0.035155534744262695, facet # = 22
# Filtering edges by size finished: 0.004052639007568359, facet # = 18
# Filtering by convexity and getting centers took: 0.0069370269775390625, facet # = 4
# Filtering edges by size finished: 0.0036923885345458984, facet # = 17
# Filtering by convexity and getting centers took: 0.007635354995727539, facet # = 10
# Filtering edges by size finished: 0.004039287567138672, facet # = 35
# Filtering by convexity and getting centers took: 0.010128021240234375, facet # = 6
# Filtering edges by size finished: 0.0060613155364990234, facet # = 43
# Filtering by convexity and getting centers took: 0.012996196746826172, facet # = 21
# Filtering edges by size finished: 0.0026924610137939453, facet # = 9
# Filtering by convexity and getting centers took: 0.003510713577270508, facet # = 5
# Filtering edges by size finished: 0.0009369850158691406, facet # = 6
# Filtering by convexity and getting centers took: 0.002389192581176758, facet # = 4
# Filtering edges by size finished: 0.007279157638549805, facet # = 31
# Filtering by convexity and getting centers took: 0.013855695724487305, facet # = 11
# Filtering edges by size finished: 0.002925872802734375, facet # = 15
# Filtering by convexity and getting centers took: 0.00754547119140625, facet # = 5
# Filtering edges by size finished: 0.0027501583099365234, facet # = 14
# Filtering by convexity and getting centers took: 0.0068056583404541016, facet # = 5
# Filtering edges by size finished: 0.005421876907348633, facet # = 28
# Filtering by convexity and getting centers took: 0.012206077575683594, facet # = 7
# Filtering edges by size finished: 0.0074503421783447266, facet # = 36
# Filtering by convexity and getting centers took: 0.015080928802490234, facet # = 11
# Filtering edges by size finished: 0.004658937454223633, facet # = 17
# Filtering by convexity and getting centers took: 0.008165597915649414, facet # = 5
# Filtering edges by size finished: 0.0030279159545898438, facet # = 13
# Filtering by convexity and getting centers took: 0.006227731704711914, facet # = 7
# Filtering edges by size finished: 0.002377748489379883, facet # = 15
# Filtering by convexity and getting centers took: 0.005630970001220703, facet # = 8
# Filtering edges by size finished: 0.002686023712158203, facet # = 20
# Filtering by convexity and getting centers took: 0.006620168685913086, facet # = 7
# Filtering edges by size finished: 0.0053386688232421875, facet # = 40
# Filtering by convexity and getting centers took: 0.011563777923583984, facet # = 12
# Filtering edges by size finished: 0.0021865367889404297, facet # = 15
# Filtering by convexity and getting centers took: 0.005064487457275391, facet # = 7
# Filtering edges by size finished: 0.0007293224334716797, facet # = 7
# Filtering by convexity and getting centers took: 0.0026144981384277344, facet # = 5
# Total time for facets: 163.47550225257874
# Zero faceted faces = []
# Starting Child 0
# 393 30508
# Done distance matrix: 0.5350549221038818
# Done Generating final pairs: 0.5812234878540039
# best_stitch_pair = [ 114 3456]
# best_stitch_pair_size = 229740.83119864232
# best_stitch_pair_distance = 141.18424415767117
# best_stitch_pair_size_ratio = 0.9815795141862247
# Starting Child 1
# 12 30508
# Done distance matrix: 0.03502011299133301
# Done Generating final pairs: 0.08668398857116699
# best_stitch_pair = [    7 21146]
# best_stitch_pair_size = 34561.69516787848
# best_stitch_pair_distance = 1477.351922739051
# best_stitch_pair_size_ratio = 0.5788104181856873
# Starting Child 2
# 758 30508
# Done distance matrix: 1.079932689666748
# Done Generating final pairs: 1.1156525611877441
# best_stitch_pair = [  516 10078]
# best_stitch_pair_size = 677208.9487698551
# best_stitch_pair_distance = 581.9780738570475
# best_stitch_pair_size_ratio = 0.5353778863628686
# Starting Child 3
# 13 30508
# Done distance matrix: 0.01288604736328125
# Child 3 There were no points close enough
# Starting Child 4
# 349 30508
# Done distance matrix: 0.6304340362548828
# Done Generating final pairs: 0.6534943580627441
# best_stitch_pair = [ 156 7206]
# best_stitch_pair_size = 664018.5357490684
# best_stitch_pair_distance = 90.38694820364042
# best_stitch_pair_size_ratio = 0.9038527394470877
# Starting Child 5
# 22 30508
# Done distance matrix: 0.08660626411437988
# Done Generating final pairs: 0.1198725700378418
# best_stitch_pair = [    2 27189]
# best_stitch_pair_size = 90475.50874513469
# best_stitch_pair_distance = 1299.2209671430032
# best_stitch_pair_size_ratio = 0.19451518627682246
# Starting Child 6
# 325 30508
# Done distance matrix: 0.5335931777954102
# Done Generating final pairs: 0.5741300582885742
# best_stitch_pair = [    0 30110]
# best_stitch_pair_size = 1326395.0162711863
# best_stitch_pair_distance = 754.1313718932968
# best_stitch_pair_size_ratio = 0.4010222931899985
# Starting Child 7
# 5 30508
# Done distance matrix: 0.00605320930480957
# Done Generating final pairs: 0.04577755928039551
# best_stitch_pair = [    4 21729]
# best_stitch_pair_size = 53293.09087670834
# best_stitch_pair_distance = 1652.757961193699
# best_stitch_pair_size_ratio = 0.5827299389256361
# Starting Child 8
# 7 30508
# Done distance matrix: 0.012694358825683594
# Done Generating final pairs: 0.04484152793884277
# best_stitch_pair = [   2 5733]
# best_stitch_pair_size = 281243.4290499154
# best_stitch_pair_distance = 1832.2319933238377
# best_stitch_pair_size_ratio = 0.1581698542195133
# Starting Child 9
# 4 30508
# Done distance matrix: 0.008100271224975586
# Child 9 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 32 30508
# Done distance matrix: 0.0474247932434082
# Child 10 There were no points close enough
# Starting Child 11
# 8 30508
# Done distance matrix: 0.011007308959960938
# Done Generating final pairs: 0.04749441146850586
# best_stitch_pair = [    0 17352]
# best_stitch_pair_size = 38509.647357282716
# best_stitch_pair_distance = 876.4901293794258
# best_stitch_pair_size_ratio = 0.26211215393739234
# Starting Child 12
# 7 30508
# Done distance matrix: 0.029738187789916992
# Done Generating final pairs: 0.08998441696166992
# best_stitch_pair = [    6 18489]
# best_stitch_pair_size = 43436.11384156498
# best_stitch_pair_distance = 1695.5880421925742
# best_stitch_pair_size_ratio = 0.2989081075581297
# Starting Child 13
# 7 30508
# Done distance matrix: 0.008890867233276367
# Child 13 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 7 30508
# Done distance matrix: 0.008860349655151367
# Done Generating final pairs: 0.029793262481689453
# best_stitch_pair = [   0 4602]
# best_stitch_pair_size = 44480.700011954585
# best_stitch_pair_distance = 687.2418102845949
# best_stitch_pair_size_ratio = 0.9323191084165573
# Starting Child 15
# returning x greater max
# skipped by bounding box filter
# Starting Child 16
# returning x greater max
# skipped by bounding box filter
# Starting Child 17
# 11 30508
# Done distance matrix: 0.017958641052246094
# Done Generating final pairs: 0.0792989730834961
# best_stitch_pair = [   1 3675]
# best_stitch_pair_size = 33301.10113373872
# best_stitch_pair_distance = 1706.2108460094523
# best_stitch_pair_size_ratio = 0.7738871785073564
# Starting Child 18
# 11 30508
# Done distance matrix: 0.014966487884521484
# Done Generating final pairs: 0.055179595947265625
# best_stitch_pair = [    2 10162]
# best_stitch_pair_size = 128041.89284164947
# best_stitch_pair_distance = 1790.1439477274566
# best_stitch_pair_size_ratio = 0.1503096370255839
# Starting Child 19
# 4 30508
# Done distance matrix: 0.005944490432739258
# Child 19 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 20
# 5 30508
# Done distance matrix: 0.007612705230712891
# Child 20 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 21
# 2 30508
# Done distance matrix: 0.003614187240600586
# Done Generating final pairs: 0.036818504333496094
# best_stitch_pair = [    0 30146]
# best_stitch_pair_size = 42784.88357563979
# best_stitch_pair_distance = 1384.532632691906
# best_stitch_pair_size_ratio = 0.830683268474205
# Starting Child 22
# 3 30508
# Done distance matrix: 0.004539012908935547
# Done Generating final pairs: 0.08765625953674316
# best_stitch_pair = [    2 30126]
# best_stitch_pair_size = 137905.8895050263
# best_stitch_pair_distance = 1582.6427510700728
# best_stitch_pair_size_ratio = 0.167564928908313
# Starting Child 23
# 5 30508
# Done distance matrix: 0.0076181888580322266
# Done Generating final pairs: 0.08394813537597656
# best_stitch_pair = [    1 15030]
# best_stitch_pair_size = 46074.08369555066
# best_stitch_pair_distance = 1293.9083627403497
# best_stitch_pair_size_ratio = 0.3854738102467142
# Starting Child 24
# 5 30508
# Done distance matrix: 0.007391691207885742
# Done Generating final pairs: 0.045630455017089844
# best_stitch_pair = [    0 14901]
# best_stitch_pair_size = 127692.6426394164
# best_stitch_pair_distance = 1597.868157719774
# best_stitch_pair_size_ratio = 0.9731061813804044
# Starting Child 25
# 11 30508
# Done distance matrix: 0.02633976936340332
# Done Generating final pairs: 0.0961306095123291
# best_stitch_pair = [    8 15955]
# best_stitch_pair_size = 80394.92050894666
# best_stitch_pair_distance = 1223.3645710888923
# best_stitch_pair_size_ratio = 0.29606943165061045
# Starting Child 26
# 12 30508
# Done distance matrix: 0.020619869232177734
# Done Generating final pairs: 0.06589221954345703
# best_stitch_pair = [   2 3988]
# best_stitch_pair_size = 73513.36128384463
# best_stitch_pair_distance = 1813.5803786723343
# best_stitch_pair_size_ratio = 0.996749544273163
# Starting Child 27
# 6 30508
# Done distance matrix: 0.009407281875610352
# Done Generating final pairs: 0.04349040985107422
# best_stitch_pair = [    2 27207]
# best_stitch_pair_size = 71211.21721449908
# best_stitch_pair_distance = 1403.066952340848
# best_stitch_pair_size_ratio = 0.4040970661881717
# Starting Child 28
# 5 30508
# Done distance matrix: 0.00889897346496582
# Done Generating final pairs: 0.0794217586517334
# best_stitch_pair = [    1 30111]
# best_stitch_pair_size = 76710.87028131561
# best_stitch_pair_distance = 1916.228019369636
# best_stitch_pair_size_ratio = 0.1752423273442515
# Starting Child 29
# 2 30508
# Done distance matrix: 0.0026273727416992188
# Done Generating final pairs: 0.020598649978637695
# best_stitch_pair = [    1 27173]
# best_stitch_pair_size = 50053.171217261945
# best_stitch_pair_distance = 660.678600383223
# best_stitch_pair_size_ratio = 0.6218799930822921
# Starting Child 30
# 11 30508
# Done distance matrix: 0.01591777801513672
# Done Generating final pairs: 0.04933023452758789
# best_stitch_pair = [   4 5733]
# best_stitch_pair_size = 357124.7788308295
# best_stitch_pair_distance = 102.75257898811867
# best_stitch_pair_size_ratio = 0.47065179241314653
# Starting Child 31
# 5 30508
# Done distance matrix: 0.006569623947143555
# Done Generating final pairs: 0.023839950561523438
# best_stitch_pair = [   4 4344]
# best_stitch_pair_size = 48299.426884435095
# best_stitch_pair_distance = 1501.1603177464956
# best_stitch_pair_size_ratio = 0.2024525192127329
# Starting Child 32
# 5 30508
# Done distance matrix: 0.005457878112792969
# Child 32 There were no points close enough
# Starting Child 33
# 22 30508
# Done distance matrix: 0.02129077911376953
# Child 33 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 34
# 4 30508
# Done distance matrix: 0.004497051239013672
# Done Generating final pairs: 0.02017068862915039
# best_stitch_pair = [  2 201]
# best_stitch_pair_size = 25000.922679262876
# best_stitch_pair_distance = 1982.594915634675
# best_stitch_pair_size_ratio = 0.3939979052780658
# Starting Child 35
# 10 30508
# Done distance matrix: 0.04550433158874512
# Child 35 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 36
# 6 30508
# Done distance matrix: 0.006781339645385742
# Child 36 There were no points close enough
# Starting Child 37
# 21 30508
# Done distance matrix: 0.020336389541625977
# Done Generating final pairs: 0.04899287223815918
# best_stitch_pair = [    1 22413]
# best_stitch_pair_size = 79276.38865564973
# best_stitch_pair_distance = 1927.4365585000285
# best_stitch_pair_size_ratio = 0.6334270545169642
# Starting Child 38
# 5 30508
# Done distance matrix: 0.010607004165649414
# Done Generating final pairs: 0.0367734432220459
# best_stitch_pair = [    2 15138]
# best_stitch_pair_size = 18540.621649192035
# best_stitch_pair_distance = 1696.897951003398
# best_stitch_pair_size_ratio = 0.53203104200942
# Starting Child 39
# 4 30508
# Done distance matrix: 0.004395723342895508
# Done Generating final pairs: 0.023491859436035156
# best_stitch_pair = [  3 154]
# best_stitch_pair_size = 523804.11360983865
# best_stitch_pair_distance = 1804.3353623405912
# best_stitch_pair_size_ratio = 0.1701143767439138
# Starting Child 40
# 11 30508
# Done distance matrix: 0.02204608917236328
# Done Generating final pairs: 0.07618546485900879
# best_stitch_pair = [    5 22285]
# best_stitch_pair_size = 98776.32348593463
# best_stitch_pair_distance = 1258.783131338416
# best_stitch_pair_size_ratio = 0.17260272923261774
# Starting Child 41
# 5 30508
# Done distance matrix: 0.010765314102172852
# Done Generating final pairs: 0.05426907539367676
# best_stitch_pair = [    1 14663]
# best_stitch_pair_size = 36674.9883117077
# best_stitch_pair_distance = 1763.5734666339451
# best_stitch_pair_size_ratio = 0.2044553718927314
# Starting Child 42
# 5 30508
# Done distance matrix: 0.007338762283325195
# Done Generating final pairs: 0.025425195693969727
# best_stitch_pair = [    0 14661]
# best_stitch_pair_size = 49762.979782229784
# best_stitch_pair_distance = 54.775530398774244
# best_stitch_pair_size_ratio = 0.8854851873727799
# Starting Child 43
# 7 30508
# Done distance matrix: 0.010675191879272461
# Done Generating final pairs: 0.03977060317993164
# best_stitch_pair = [    4 13258]
# best_stitch_pair_size = 31838.445171892858
# best_stitch_pair_distance = 1996.5352279481958
# best_stitch_pair_size_ratio = 0.7623606911627926
# Starting Child 44
# returning x greater max
# skipped by bounding box filter
# Starting Child 45
# 5 30508
# Done distance matrix: 0.006129741668701172
# Done Generating final pairs: 0.038892507553100586
# best_stitch_pair = [    0 16092]
# best_stitch_pair_size = 60819.834773970346
# best_stitch_pair_distance = 1111.973572246287
# best_stitch_pair_size_ratio = 0.39277478192581655
# Starting Child 46
# 7 30508
# Done distance matrix: 0.007590532302856445
# Done Generating final pairs: 0.03185105323791504
# best_stitch_pair = [    2 10206]
# best_stitch_pair_size = 111185.85407535985
# best_stitch_pair_distance = 444.25659585670616
# best_stitch_pair_size_ratio = 0.5381800111459006
# Starting Child 47
# 8 30508
# Done distance matrix: 0.012870073318481445
# Done Generating final pairs: 0.05237436294555664
# best_stitch_pair = [    0 24586]
# best_stitch_pair_size = 65644.33145408513
# best_stitch_pair_distance = 1572.4542762523577
# best_stitch_pair_size_ratio = 0.28128222913556583
# Starting Child 48
# 7 30508
# Done distance matrix: 0.02026963233947754
# Done Generating final pairs: 0.0916743278503418
# best_stitch_pair = [    0 21338]
# best_stitch_pair_size = 92249.70021219361
# best_stitch_pair_distance = 611.9837681817953
# best_stitch_pair_size_ratio = 0.2576407194792395
# Starting Child 49
# 12 30508
# Done distance matrix: 0.02600407600402832
# Done Generating final pairs: 0.09160089492797852
# best_stitch_pair = [   2 6498]
# best_stitch_pair_size = 118072.19309535675
# best_stitch_pair_distance = 642.2713811878525
# best_stitch_pair_size_ratio = 0.6873805894993451
# Starting Child 50
# 7 30508
# Done distance matrix: 0.011082172393798828
# Done Generating final pairs: 0.04571962356567383
# best_stitch_pair = [    6 18508]
# best_stitch_pair_size = 48871.24606156808
# best_stitch_pair_distance = 1273.2736252102482
# best_stitch_pair_size_ratio = 0.21341075240536003
# Starting Child 51
# 5 30508
# Done distance matrix: 0.007509946823120117
# Done Generating final pairs: 0.062330007553100586
# best_stitch_pair = [    0 11601]
# best_stitch_pair_size = 30814.889560614327
# best_stitch_pair_distance = 1209.9558962657227
# best_stitch_pair_size_ratio = 0.4954686201827178
# repeat_main_facets = [5733]
# child_mesh_double_indexes = [8, 30]
# min_child = 30, max_ratio = 102.75257898811867
# child_meshes_stitch_facets = {0: [114, 3456], 1: [7, 21146], 2: [516, 10078], 4: [156, 7206], 5: [2, 27189], 6: [0, 30110], 7: [4, 21729], 11: [0, 17352], 12: [6, 18489], 14: [0, 4602], 17: [1, 3675], 18: [2, 10162], 21: [0, 30146], 22: [2, 30126], 23: [1, 15030], 24: [0, 14901], 25: [8, 15955], 26: [2, 3988], 27: [2, 27207], 28: [1, 30111], 29: [1, 27173], 30: [4, 5733], 31: [4, 4344], 34: [2, 201], 37: [1, 22413], 38: [2, 15138], 39: [3, 154], 40: [5, 22285], 41: [1, 14663], 42: [0, 14661], 43: [4, 13258], 45: [0, 16092], 46: [2, 10206], 47: [0, 24586], 48: [0, 21338], 49: [2, 6498], 50: [6, 18508], 51: [0, 11601]}
# ---Stitching child 0 with pair: [114, 3456]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 198444, starting edge 2nd facet= 1451994,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04451251029968262
# returned from stitch mesh: 2.050393581390381
# Finished stitching child 0 : 2.391205072402954
# ---Stitching child 1 with pair: [7, 21146]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 850781, starting edge 2nd facet= 1454268,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06880450248718262
# returned from stitch mesh: 2.222484588623047
# Finished stitching child 1 : 2.6792478561401367
# ---Stitching child 2 with pair: [516, 10078]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1274499, starting edge 2nd facet= 1461947,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 25
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 5
# About to add faces
# Finished adding faces: 4.649162292480469e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04981422424316406
# returned from stitch mesh: 2.3411307334899902
# Finished stitching child 2 : 2.668490171432495
# ---Stitching child 4 with pair: [156, 7206]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1013504, starting edge 2nd facet= 1469798,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 5.0067901611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.059990644454956055
# returned from stitch mesh: 2.4227938652038574
# Finished stitching child 4 : 2.9226577281951904
# ---Stitching child 5 with pair: [2, 27189]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 745811, starting edge 2nd facet= 1473994,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05489921569824219
# returned from stitch mesh: 2.3327524662017822
# Finished stitching child 5 : 2.647726058959961
# ---Stitching child 6 with pair: [0, 30110]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 317196, starting edge 2nd facet= 1477945,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 42
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 19
# About to add faces
# Finished adding faces: 8.749961853027344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09106135368347168
# returned from stitch mesh: 2.4905598163604736
# Finished stitching child 6 : 2.7711055278778076
# ---Stitching child 7 with pair: [4, 21729]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 687919, starting edge 2nd facet= 1479876,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07848739624023438
# returned from stitch mesh: 2.1836836338043213
# Finished stitching child 7 : 2.5526652336120605
# ---Stitching child 11 with pair: [0, 17352]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 607280, starting edge 2nd facet= 1479907,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.046895503997802734
# returned from stitch mesh: 2.384925127029419
# Finished stitching child 11 : 2.730347156524658
# ---Stitching child 12 with pair: [6, 18489]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1095626, starting edge 2nd facet= 1480021,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06086564064025879
# returned from stitch mesh: 2.4555962085723877
# Finished stitching child 12 : 2.717376470565796
# ---Stitching child 14 with pair: [0, 4602]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 720546, starting edge 2nd facet= 1480058,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04867100715637207
# returned from stitch mesh: 2.4557957649230957
# Finished stitching child 14 : 2.73795485496521
# ---Stitching child 17 with pair: [1, 3675]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 435784, starting edge 2nd facet= 1480178,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.193450927734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11294817924499512
# returned from stitch mesh: 3.178746461868286
# Finished stitching child 17 : 3.529801845550537
# ---Stitching child 18 with pair: [2, 10162]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1347475, starting edge 2nd facet= 1480279,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.8133392333984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06825542449951172
# returned from stitch mesh: 2.631458282470703
# Finished stitching child 18 : 3.0638279914855957
# ---Stitching child 21 with pair: [0, 30146]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1338280, starting edge 2nd facet= 1480302,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.621246337890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05004286766052246
# returned from stitch mesh: 2.4513864517211914
# Finished stitching child 21 : 2.708280324935913
# ---Stitching child 22 with pair: [2, 30126]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1351983, starting edge 2nd facet= 1480335,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.3126602172851562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.051640987396240234
# returned from stitch mesh: 2.575491189956665
# Finished stitching child 22 : 2.867319345474243
# ---Stitching child 23 with pair: [1, 15030]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1179232, starting edge 2nd facet= 1480400,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.3113021850585938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11191725730895996
# returned from stitch mesh: 2.5843944549560547
# Finished stitching child 23 : 2.972720146179199
# ---Stitching child 24 with pair: [0, 14901]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1088810, starting edge 2nd facet= 1480434,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.8371810913085938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05065178871154785
# returned from stitch mesh: 2.2840487957000732
# Finished stitching child 24 : 2.665428876876831
# ---Stitching child 25 with pair: [8, 15955]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1154602, starting edge 2nd facet= 1480525,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12373161315917969
# returned from stitch mesh: 2.3031680583953857
# Finished stitching child 25 : 2.6143014430999756
# ---Stitching child 26 with pair: [2, 3988]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 516401, starting edge 2nd facet= 1480789,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05041694641113281
# returned from stitch mesh: 2.2671117782592773
# Finished stitching child 26 : 2.7239034175872803
# ---Stitching child 27 with pair: [2, 27207]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1008404, starting edge 2nd facet= 1480849,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.1920928955078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04388833045959473
# returned from stitch mesh: 2.2513723373413086
# Finished stitching child 27 : 2.689971685409546
# ---Stitching child 28 with pair: [1, 30111]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 979593, starting edge 2nd facet= 1480918,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.4781951904296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.047017812728881836
# returned from stitch mesh: 2.1022660732269287
# Finished stitching child 28 : 2.414900541305542
# ---Stitching child 29 with pair: [1, 27173]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 548507, starting edge 2nd facet= 1480995,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04829001426696777
# returned from stitch mesh: 2.598884344100952
# Finished stitching child 29 : 2.937182903289795
# ---Stitching child 30 with pair: [4, 5733]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 854983, starting edge 2nd facet= 1481007,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 5
# About to add faces
# Finished adding faces: 3.62396240234375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.8902468681335449
# returned from stitch mesh: 2.7093148231506348
# Finished stitching child 30 : 2.964132308959961
# ---Stitching child 31 with pair: [4, 4344]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 953809, starting edge 2nd facet= 1481093,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.045827388763427734
# returned from stitch mesh: 1.505265474319458
# Finished stitching child 31 : 1.7767624855041504
# ---Stitching child 34 with pair: [2, 201]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1242320, starting edge 2nd facet= 1481171,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.239776611328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06911325454711914
# returned from stitch mesh: 2.2707571983337402
# Finished stitching child 34 : 2.600924015045166
# ---Stitching child 37 with pair: [1, 22413]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1404864, starting edge 2nd facet= 1481318,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.4318695068359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09345841407775879
# returned from stitch mesh: 2.1444907188415527
# Finished stitching child 37 : 2.596468210220337
# ---Stitching child 38 with pair: [2, 15138]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 336986, starting edge 2nd facet= 1481403,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# ...
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.0013265609741210938
# Child 17 There were no points close enough
# Starting Child 34
# 2 34378
# Done distance matrix: 0.00238800048828125
# Child 34 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 43
# 1 34378
# Done distance matrix: 0.0011038780212402344
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.001161336898803711
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.001371622085571289
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.001268148422241211
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.0011568069458007812
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0011363029479980469
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0013585090637207031
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.0011515617370605469
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.0011496543884277344
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0011026859283447266
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0011248588562011719
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0010976791381835938
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.0012836456298828125
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.001117706298828125
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.0011060237884521484
# Child 166 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 12
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.0014865398406982422
# Child 17 There were no points close enough
# Starting Child 34
# 2 34378
# Done distance matrix: 0.002476930618286133
# Done Generating final pairs: 0.006450176239013672
# best_stitch_pair = [   1 4987]
# best_stitch_pair_size = 25368.79144731984
# best_stitch_pair_distance = 8216.974423472015
# best_stitch_pair_size_ratio = 0.6459637450060537
# Starting Child 43
# 1 34378
# Done distance matrix: 0.0015299320220947266
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.0012869834899902344
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.0014657974243164062
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.0014085769653320312
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.0013506412506103516
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0011210441589355469
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0013415813446044922
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.0012743473052978516
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.0013833045959472656
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0012707710266113281
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0012462139129638672
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0012688636779785156
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.001512765884399414
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.0011951923370361328
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.0012383460998535156
# Child 166 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {34: [1, 4987]}
# ---Stitching child 34 with pair: [1, 4987]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 314546, starting edge 2nd facet= 1475989,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 2
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.043936729431152344
# returned from stitch mesh: 1.4587113857269287
# Finished stitching child 34 : 1.7079975605010986
# ***************Finished big stitching iteration: 1.93259859085083***************
# Starting Child 12
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.0012936592102050781
# Child 17 There were no points close enough
# Starting Child 43
# 1 34378
# Done distance matrix: 0.001264333724975586
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.0012722015380859375
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.001636505126953125
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.0016088485717773438
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.001386880874633789
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0015065670013427734
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0015492439270019531
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.0014412403106689453
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.00140380859375
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0014495849609375
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0013306140899658203
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0013315677642822266
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.0016069412231445312
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.0013897418975830078
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.001416921615600586
# Child 166 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 12
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.001489400863647461
# Child 17 There were no points close enough
# Starting Child 43
# 1 34378
# Done distance matrix: 0.0013723373413085938
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.0013813972473144531
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.0017063617706298828
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.001531839370727539
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.0014994144439697266
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0014259815216064453
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0015435218811035156
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.0014495849609375
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.0014693737030029297
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0013344287872314453
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0012824535369873047
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0013642311096191406
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.0014638900756835938
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.0013918876647949219
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.0013337135314941406
# Child 166 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 12
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.0013201236724853516
# Child 17 There were no points close enough
# Starting Child 43
# 1 34378
# Done distance matrix: 0.0014922618865966797
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.0013704299926757812
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.001688241958618164
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.0016829967498779297
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.0013439655303955078
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0015764236450195312
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0015804767608642578
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.001651763916015625
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.0014576911926269531
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0014276504516601562
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0014743804931640625
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0014023780822753906
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.001461029052734375
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.0014545917510986328
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.007062673568725586
# Child 166 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 12
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 17
# 1 34378
# Done distance matrix: 0.0014324188232421875
# Child 17 There were no points close enough
# Starting Child 43
# 1 34378
# Done distance matrix: 0.0013687610626220703
# Child 43 There were no points close enough
# Starting Child 44
# 1 34378
# Done distance matrix: 0.0014297962188720703
# Child 44 There were no points close enough
# Starting Child 49
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 50
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 61
# 1 34378
# Done distance matrix: 0.0014944076538085938
# Child 61 There were no points close enough
# Starting Child 62
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 70
# 1 34378
# Done distance matrix: 0.0015053749084472656
# Child 70 There were no points close enough
# Starting Child 72
# 1 34378
# Done distance matrix: 0.001434326171875
# Child 72 There were no points close enough
# Starting Child 75
# 1 34378
# Done distance matrix: 0.0012793540954589844
# Child 75 There were no points close enough
# Starting Child 78
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 80
# 1 34378
# Done distance matrix: 0.0013921260833740234
# Child 80 There were no points close enough
# Starting Child 83
# 1 34378
# Done distance matrix: 0.0012967586517333984
# Child 83 There were no points close enough
# Starting Child 99
# 1 34378
# Done distance matrix: 0.0011477470397949219
# Child 99 There were no points close enough
# Starting Child 100
# 1 34378
# Done distance matrix: 0.0013818740844726562
# Child 100 There were no points close enough
# Starting Child 104
# 1 34378
# Done distance matrix: 0.0012912750244140625
# Child 104 There were no points close enough
# Starting Child 133
# 1 34378
# Done distance matrix: 0.0013251304626464844
# Child 133 There were no points close enough
# Starting Child 145
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 146
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 155
# 1 34378
# Done distance matrix: 0.001516103744506836
# Child 155 There were no points close enough
# Starting Child 160
# 1 34378
# Done distance matrix: 0.001338958740234375
# Child 160 There were no points close enough
# Starting Child 166
# 1 34378
# Done distance matrix: 0.0013337135314941406
# Child 166 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 327.5914673805237
# Total time for restitching = 327.59864926338196
# missed_children = [133.0, 12.0, 17.0, 145.0, 146.0, 155.0, 160.0, 166.0, 43.0, 44.0, 49.0, 50.0, 61.0, 62.0, 70.0, 72.0, 75.0, 78.0, 80.0, 83.0, 99.0, 100.0, 104.0]
# Whole stitching function complete: 453.9087076187134
# 6294.55619263649

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
