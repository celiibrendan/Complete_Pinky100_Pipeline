# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349498286******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.052451372146606445
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 339.20501041412354
# 2) Finished: Generating CGAL segmentation for neuron: 349.67908096313477
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.12836337089538574
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [1, 19, 20, 9, 6, 13, 28, 56]
# soma_80_percent = 226337.2015625
# Debugging the axon filter
# [(1, 232502.328125), (19, 255978.5625), (20, 222179.234375), (9, 252182.640625), (6, 234417.34375), (13, 247773.578125), (28, 230377.9375), (56, 228144.28125)]
# possible_Axons_filter_1 = [20]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.03486275672912598
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 1
# 28 = stub soma
# 56 = stub soma
# Total Labels found = {'soma', 'unsure'}
# 6) Finished: Classifying Entire Neuron: 0.997194766998291
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4037292003631592
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.597317934036255
# Finished Auto Labeling: 357.32258677482605
#
#
# *****Starting Auto Labeling for 648518346349499680******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0474545955657959
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 856.4922301769257
# 2) Finished: Generating CGAL segmentation for neuron: 875.2617144584656
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 14
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.24121761322021484
# 5) Staring: Finding Apical Index
# Soma Index = 14
# Soma Connections = [17, 0, 19, 37, 35]
# soma_80_percent = 199129.6375
# Debugging the axon filter
# [(17, 208171.0), (0, 196286.09375), (19, 216463.765625), (37, 202132.140625), (35, 222692.359375)]
# possible_Axons_filter_1 = [0]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.0858452320098877
# 6) Staring: Classifying Entire Neuron
# 25 = stub apical
# 27 = stub apical
# 30 = stub apical
# 32 = stub apical
# 38 = stub apical
# 41 = stub apical
# 42 = stub apical
# 45 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 53 = stub apical
# 54 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 70 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 94 = stub apical
# 97 = stub apical
# 98 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 131 = stub apical
# Total Labels found = {'apical', 'soma', 'oblique', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.172325372695923
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.44478750228881836
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.80949592590332
# Finished Auto Labeling: 889.7959454059601
#
#
# *****Starting Auto Labeling for 648518346349500139******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05789589881896973
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 782.9875586032867
# 2) Finished: Generating CGAL segmentation for neuron: 800.0812311172485
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 5
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.22229576110839844
# 5) Staring: Finding Apical Index
# Soma Index = 5
# Soma Connections = [3, 12, 14, 16, 236, 48, 243, 24, 212, 241]
# soma_80_percent = 236877.4609375
# Debugging the axon filter
# [(3, 267732.09375), (12, 246032.140625), (14, 234605.65625), (16, 233231.140625), (236, 236975.734375), (48, 259087.921875), (243, 239104.515625), (24, 263782.84375), (212, 233619.78125), (241, 239568.75)]
# possible_Axons_filter_1 = [14, 16, 212]
# possible_Axons_filter_2 = [16]
# possible_Apical = 16
# 5) Finished: Finding Apical Index: 0.14045238494873047
# 6) Staring: Classifying Entire Neuron
# 24 = axon
# 212 = cilia
# 236 = stub soma
# 241 = cilia
# 243 = stub soma
# Total Labels found = {'cilia', 'axon', 'apical', 'soma', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.8665845394134521
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.44090771675109863
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.07566785812378
# Finished Auto Labeling: 813.4942345619202
#
#
# *****Starting Auto Labeling for 648518346349501597******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.10001063346862793
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1792.5544800758362
# 2) Finished: Generating CGAL segmentation for neuron: 1820.2725222110748
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 13
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.33423900604248047
# 5) Staring: Finding Apical Index
# Soma Index = 13
# Soma Connections = [33, 32, 37, 1, 6, 34, 3, 44]
# soma_80_percent = 230671.1546875
# Debugging the axon filter
# [(33, 256429.6875), (32, 229156.40625), (37, 232457.859375), (1, 228715.734375), (6, 253046.5625), (34, 241012.859375), (3, 241830.3125), (44, 233504.734375)]
# possible_Axons_filter_1 = [32, 1]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.11113548278808594
# 6) Staring: Classifying Entire Neuron
# 32 = cilia
# Total Labels found = {'soma', 'unsure', 'cilia'}
# 6) Finished: Classifying Entire Neuron: 3.2743537425994873
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 1.0818891525268555
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 16.396502256393433
# Finished Auto Labeling: 1842.6777393817902
#
#
# *****Starting Auto Labeling for 648518346349505696******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.061986446380615234
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1207.985909461975
# 2) Finished: Generating CGAL segmentation for neuron: 1230.2366211414337
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 3
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3020012378692627
# 5) Staring: Finding Apical Index
# Soma Index = 3
# Soma Connections = [21, 0, 15, 18, 45, 98, 262, 230, 63, 34, 82, 304, 319, 128, 343]
# soma_80_percent = 279982.140625
# Debugging the axon filter
# [(21, 303481.28125), (0, 275602.875), (15, 302851.21875), (18, 286687.40625), (45, 277805.96875), (98, 292309.78125), (262, 291835.125), (230, 284269.84375), (63, 278712.46875), (34, 307092.46875), (82, 284308.875), (304, 276773.8125), (319, 291787.40625), (128, 279524.15625), (343, 291950.25)]
# possible_Axons_filter_1 = [0, 45, 63, 304, 128]
# possible_Axons_filter_2 = [0]
# possible_Apical = 0
# 5) Finished: Finding Apical Index: 0.21154284477233887
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 45
# 128 = stub soma
# 230 = stub soma
# 304 = cilia
# 262 = stub soma
# 319 = stub soma
# 343 = stub soma
# 4 = stub apical
# 9 = stub apical
# 20 = stub apical
# 23 = stub apical
# 25 = stub apical
# 28 = stub apical
# 29 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = error
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 64 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 77 = stub apical
# 78 = stub apical
# 80 = stub apical
# 81 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = error
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 129 = stub apical
# 130 = stub apical
# 137 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 157 = stub apical
# 158 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 209 = stub apical
# 210 = stub apical
# 217 = stub apical
# 219 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 261 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 279 = stub apical
# 280 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 305 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 318 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 362 = stub apical
# Total Labels found = {'cilia', 'error', 'apical', 'soma', 'oblique', 'basal'}
# 6) Finished: Classifying Entire Neuron: 3.4639530181884766
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5714817047119141
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.744765758514404
# Finished Auto Labeling: 1247.4081213474274
#
#
# *****Starting Auto Labeling for 648518346349509112******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07296252250671387
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1067.3309893608093
# 2) Finished: Generating CGAL segmentation for neuron: 1088.0834040641785
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2859358787536621
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [60, 22, 7, 17, 25, 19, 42, 21, 38, 24, 41, 40, 68, 67, 33]
# soma_80_percent = 254811.40625
# Debugging the axon filter
# [(60, 262348.21875), (22, 270719.625), (7, 282599.8125), (17, 256287.09375), (25, 258859.609375), (19, 251852.015625), (42, 252387.484375), (21, 260533.046875), (38, 257668.46875), (24, 259082.515625), (41, 251092.078125), (40, 253722.9375), (68, 257208.40625), (67, 252121.578125), (33, 256595.6875)]
# possible_Axons_filter_1 = [19, 42, 41, 40, 67]
# possible_Axons_filter_2 = [19]
# possible_Apical = 19
# 5) Finished: Finding Apical Index: 0.08070492744445801
# 6) Staring: Classifying Entire Neuron
# 22 = axon
# 33 = stub soma
# 38 = stub soma
# 40 = stub soma
# 41 = stub soma
# 42 = stub soma
# 67 = stub soma
# 68 = stub soma
# 14 = stub apical
# 23 = stub apical
# 29 = stub apical
# 34 = stub apical
# 36 = stub apical
# 43 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 51 = stub apical
# 61 = stub apical
# 65 = stub apical
# Total Labels found = {'axon', 'oblique', 'soma', 'apical', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.6543877124786377
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.49666857719421387
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.173097610473633
# Finished Auto Labeling: 1103.591964483261
#
#
# *****Starting Auto Labeling for 648518346349512186******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0393064022064209
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 661.8843312263489
# 2) Finished: Generating CGAL segmentation for neuron: 679.4313180446625
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19729042053222656
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 2, 37, 89, 40, 13, 5, 20, 104, 26, 91, 189, 186, 190, 116]
# soma_80_percent = 240415.890625
# Debugging the axon filter
# [(0, 245728.0), (2, 252454.71875), (37, 245960.578125), (89, 239171.796875), (40, 242187.34375), (13, 258266.671875), (5, 236598.421875), (20, 264039.84375), (104, 238966.9375), (26, 262873.28125), (91, 243354.1875), (189, 240949.15625), (186, 252606.125), (190, 239010.546875), (116, 239663.328125)]
# possible_Axons_filter_1 = [89, 5, 104, 190, 116]
# possible_Axons_filter_2 = [5]
# possible_Apical = 5
# 5) Finished: Finding Apical Index: 0.10624098777770996
# 6) Staring: Classifying Entire Neuron
# 0 = stub soma
# 89 = cilia
# 91 = stub soma
# 104 = stub soma
# 116 = stub soma
# 186 = cilia
# 189 = stub soma
# 190 = stub soma
# 27 = stub apical
# 28 = error
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = error
# 41 = error
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 139 = stub apical
# 140 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 158 = stub apical
# 162 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 184 = stub apical
# 185 = stub apical
# 187 = stub apical
# 188 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 201 = stub apical
# 202 = stub apical
# Total Labels found = {'cilia', 'error', 'apical', 'soma', 'oblique', 'basal'}
# 6) Finished: Classifying Entire Neuron: 2.0625834465026855
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.35970115661621094
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.607839107513428
# Finished Auto Labeling: 691.3778071403503
# 6948.666358709335

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
