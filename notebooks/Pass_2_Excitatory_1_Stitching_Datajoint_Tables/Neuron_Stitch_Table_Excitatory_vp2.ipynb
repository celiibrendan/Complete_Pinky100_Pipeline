# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341371119**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346341371119_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.344691514968872
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9681366665349916% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349386137**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 275 pieces after mesh split
# There were 48 pieces found after size threshold
# max_index = 0
# max_face_len = 161100
# Total time for Mesh Cleansing: 6.4889445304870605
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9648670986907514% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349470171**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349470171_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.754255771636963
# Number of outside child meshes =  43
# Main mesh and outside child meshes make up 0.8810968024950274% of original mesh
#  face length 1845336 using optimized facets with 3 neighbors
# Filtering edges by size finished: 21.10056710243225, facet # = 96935
# Filtering by convexity and getting centers took: 31.789374351501465, facet # = 19837
# Finished facets for main mesh: 55.31571936607361 with facet length = 19837
# Finished 19837 facets for main mesh: 55.3162796497345
# Filtering edges by size finished: 1.4227468967437744, facet # = 6084
# Filtering by convexity and getting centers took: 2.0566635131835938, facet # = 1298
# Filtering edges by size finished: 0.3966991901397705, facet # = 2151
# Filtering by convexity and getting centers took: 0.6201667785644531, facet # = 644
# Filtering edges by size finished: 0.8423943519592285, facet # = 4380
# Filtering by convexity and getting centers took: 1.2651121616363525, facet # = 485
# Filtering edges by size finished: 0.8021986484527588, facet # = 3670
# Filtering by convexity and getting centers took: 1.0108025074005127, facet # = 887
# Filtering edges by size finished: 0.4672422409057617, facet # = 2120
# Filtering by convexity and getting centers took: 0.586111307144165, facet # = 521
# Filtering edges by size finished: 0.1163177490234375, facet # = 718
# Filtering by convexity and getting centers took: 0.21957707405090332, facet # = 203
# Filtering edges by size finished: 0.4296226501464844, facet # = 2168
# Filtering by convexity and getting centers took: 0.69600510597229, facet # = 567
# Filtering edges by size finished: 0.20891213417053223, facet # = 976
# Filtering by convexity and getting centers took: 0.3124206066131592, facet # = 212
# Filtering edges by size finished: 0.12783479690551758, facet # = 653
# Filtering by convexity and getting centers took: 0.19880390167236328, facet # = 170
# Filtering edges by size finished: 0.4799802303314209, facet # = 2357
# Filtering by convexity and getting centers took: 0.6686334609985352, facet # = 460
# Filtering edges by size finished: 0.09008598327636719, facet # = 430
# Filtering by convexity and getting centers took: 0.1664867401123047, facet # = 130
# Filtering edges by size finished: 0.3236262798309326, facet # = 1752
# Filtering by convexity and getting centers took: 0.522355318069458, facet # = 290
# Filtering edges by size finished: 0.1303107738494873, facet # = 830
# Filtering by convexity and getting centers took: 0.27046728134155273, facet # = 191
# Filtering edges by size finished: 0.13025450706481934, facet # = 792
# Filtering by convexity and getting centers took: 0.2599787712097168, facet # = 185
# Filtering edges by size finished: 0.19637775421142578, facet # = 1076
# Filtering by convexity and getting centers took: 0.30349016189575195, facet # = 187
# Filtering edges by size finished: 0.5139472484588623, facet # = 2353
# Filtering by convexity and getting centers took: 0.7565450668334961, facet # = 470
# Filtering edges by size finished: 0.17781758308410645, facet # = 1011
# Filtering by convexity and getting centers took: 0.39521074295043945, facet # = 261
# Filtering edges by size finished: 0.008097171783447266, facet # = 39
# Filtering by convexity and getting centers took: 0.012994766235351562, facet # = 10
# Filtering edges by size finished: 0.006587982177734375, facet # = 40
# Filtering by convexity and getting centers took: 0.013455867767333984, facet # = 16
# Filtering edges by size finished: 0.0015606880187988281, facet # = 12
# Filtering by convexity and getting centers took: 0.0046558380126953125, facet # = 4
# Filtering edges by size finished: 0.005774259567260742, facet # = 28
# Filtering by convexity and getting centers took: 0.010306835174560547, facet # = 16
# Filtering edges by size finished: 0.018265962600708008, facet # = 54
# Filtering by convexity and getting centers took: 0.018813371658325195, facet # = 14
# Filtering edges by size finished: 0.0013899803161621094, facet # = 0
# Filtering by convexity and getting centers took: 0.00016498565673828125, facet # = 0
# Filtering edges by size finished: 0.030188798904418945, facet # = 156
# Filtering by convexity and getting centers took: 0.0533449649810791, facet # = 63
# Filtering edges by size finished: 0.006332874298095703, facet # = 21
# Filtering by convexity and getting centers took: 0.007855653762817383, facet # = 8
# Filtering edges by size finished: 0.033423423767089844, facet # = 177
# Filtering by convexity and getting centers took: 0.05752849578857422, facet # = 56
# Filtering edges by size finished: 0.0015411376953125, facet # = 10
# Filtering by convexity and getting centers took: 0.003777742385864258, facet # = 5
# Filtering edges by size finished: 0.0015268325805664062, facet # = 10
# Filtering by convexity and getting centers took: 0.003557920455932617, facet # = 3
# Filtering edges by size finished: 0.06592226028442383, facet # = 337
# Filtering by convexity and getting centers took: 0.14149832725524902, facet # = 124
# Filtering edges by size finished: 0.10935831069946289, facet # = 684
# Filtering by convexity and getting centers took: 0.21125292778015137, facet # = 184
# Filtering edges by size finished: 0.03742671012878418, facet # = 162
# Filtering by convexity and getting centers took: 0.04571175575256348, facet # = 34
# Filtering edges by size finished: 0.10830974578857422, facet # = 399
# Filtering by convexity and getting centers took: 0.1492137908935547, facet # = 53
# Filtering edges by size finished: 0.016455411911010742, facet # = 106
# Filtering by convexity and getting centers took: 0.028920650482177734, facet # = 27
# Filtering edges by size finished: 0.015767574310302734, facet # = 67
# Filtering by convexity and getting centers took: 0.020420551300048828, facet # = 28
# Filtering edges by size finished: 0.027880191802978516, facet # = 189
# Filtering by convexity and getting centers took: 0.05156874656677246, facet # = 63
# Filtering edges by size finished: 0.013970136642456055, facet # = 96
# Filtering by convexity and getting centers took: 0.028724193572998047, facet # = 18
# Filtering edges by size finished: 0.002861499786376953, facet # = 7
# Filtering by convexity and getting centers took: 0.0033915042877197266, facet # = 5
# Filtering edges by size finished: 0.0263216495513916, facet # = 95
# Filtering by convexity and getting centers took: 0.029059886932373047, facet # = 37
# Filtering edges by size finished: 0.0035572052001953125, facet # = 23
# Filtering by convexity and getting centers took: 0.007239818572998047, facet # = 10
# Filtering edges by size finished: 0.006369113922119141, facet # = 35
# Filtering by convexity and getting centers took: 0.010635137557983398, facet # = 17
# Filtering edges by size finished: 0.001318216323852539, facet # = 7
# Filtering by convexity and getting centers took: 0.003836393356323242, facet # = 4
# Filtering edges by size finished: 0.003062725067138672, facet # = 14
# Filtering by convexity and getting centers took: 0.007132291793823242, facet # = 6
# Filtering edges by size finished: 0.010498285293579102, facet # = 41
# Filtering by convexity and getting centers took: 0.017782211303710938, facet # = 7
# Total time for facets: 74.39971375465393
# Zero faceted faces = [22]
# Starting Child 0
# 1298 19837
# Done distance matrix: 0.8799207210540771
# Child 0 There were no points close enough
# Starting Child 1
# 644 19837
# Done distance matrix: 0.48822736740112305
# Done Generating final pairs: 0.502324104309082
# best_stitch_pair = [ 297 3785]
# best_stitch_pair_size = 126407.37080777145
# best_stitch_pair_distance = 322.83217480906654
# best_stitch_pair_size_ratio = 0.4329072487180667
# Starting Child 2
# 485 19837
# Done distance matrix: 0.3220386505126953
# Done Generating final pairs: 0.36479735374450684
# best_stitch_pair = [   11 12915]
# best_stitch_pair_size = 3722036.9540146273
# best_stitch_pair_distance = 134.73286075380463
# best_stitch_pair_size_ratio = 0.9361932499479113
# Starting Child 3
# 887 19837
# Done distance matrix: 0.593897819519043
# Child 3 There were no points close enough
# Starting Child 4
# 521 19837
# Done distance matrix: 0.3533909320831299
# Done Generating final pairs: 0.3713233470916748
# best_stitch_pair = [    2 10716]
# best_stitch_pair_size = 446458.583444485
# best_stitch_pair_distance = 1948.800612497353
# best_stitch_pair_size_ratio = 0.6707399165863216
# Starting Child 5
# 203 19837
# Done distance matrix: 0.13071775436401367
# Done Generating final pairs: 0.1418917179107666
# best_stitch_pair = [  153 14535]
# best_stitch_pair_size = 77932.54022281384
# best_stitch_pair_distance = 1638.676906538496
# best_stitch_pair_size_ratio = 0.5248528754952313
# Starting Child 6
# 567 19837
# Done distance matrix: 0.36867856979370117
# Child 6 There were no points close enough
# Starting Child 7
# 212 19837
# Done distance matrix: 0.14815163612365723
# Child 7 There were no points close enough
# Starting Child 8
# 170 19837
# Done distance matrix: 0.1230316162109375
# Child 8 There were no points close enough
# Starting Child 9
# 460 19837
# Done distance matrix: 0.30684804916381836
# Done Generating final pairs: 0.3363044261932373
# best_stitch_pair = [   89 19158]
# best_stitch_pair_size = 104565.14624507957
# best_stitch_pair_distance = 1913.659841069676
# best_stitch_pair_size_ratio = 0.796130593331407
# Starting Child 10
# 130 19837
# Done distance matrix: 0.08781743049621582
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 19837
# Done distance matrix: 0.20720124244689941
# Child 11 There were no points close enough
# Starting Child 12
# 191 19837
# Done distance matrix: 0.1883378028869629
# Child 12 There were no points close enough
# Starting Child 13
# 185 19837
# Done distance matrix: 0.1470170021057129
# Child 13 There were no points close enough
# Starting Child 14
# 187 19837
# Done distance matrix: 0.14035320281982422
# Child 14 There were no points close enough
# Starting Child 15
# 470 19837
# Done distance matrix: 0.36158013343811035
# Child 15 There were no points close enough
# Starting Child 16
# 261 19837
# Done distance matrix: 0.1638927459716797
# Child 16 There were no points close enough
# Starting Child 17
# 10 19837
# Done distance matrix: 0.006968259811401367
# Child 17 There were no points close enough
# Starting Child 18
# 16 19837
# Done distance matrix: 0.015617847442626953
# Child 18 There were no points close enough
# Starting Child 19
# 4 19837
# Done distance matrix: 0.003089427947998047
# Child 19 There were no points close enough
# Starting Child 20
# 16 19837
# Done distance matrix: 0.011408805847167969
# Done Generating final pairs: 0.0259397029876709
# best_stitch_pair = [   1 1460]
# best_stitch_pair_size = 197046.001939911
# best_stitch_pair_distance = 1611.825160400705
# best_stitch_pair_size_ratio = 0.19808558642766733
# Starting Child 21
# 14 19837
# Done distance matrix: 0.009687662124633789
# Child 21 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 19837
# Done distance matrix: 0.03843975067138672
# Child 23 There were no points close enough
# Starting Child 24
# 8 19837
# Done distance matrix: 0.0055234432220458984
# Done Generating final pairs: 0.017750024795532227
# best_stitch_pair = [    2 14535]
# best_stitch_pair_size = 75520.57459223573
# best_stitch_pair_distance = 170.50810536391745
# best_stitch_pair_size_ratio = 0.4776595886234395
# Starting Child 25
# 56 19837
# Done distance matrix: 0.04025101661682129
# Child 25 There were no points close enough
# Starting Child 26
# 5 19837
# Done distance matrix: 0.004363059997558594
# Child 26 There were no points close enough
# Starting Child 27
# 3 19837
# Done distance matrix: 0.002218484878540039
# Child 27 There were no points close enough
# Starting Child 28
# 124 19837
# Done distance matrix: 0.08256936073303223
# Child 28 There were no points close enough
# Starting Child 29
# 184 19837
# Done distance matrix: 0.1232309341430664
# Done Generating final pairs: 0.13477444648742676
# best_stitch_pair = [ 182 4184]
# best_stitch_pair_size = 39424.00589093838
# best_stitch_pair_distance = 1040.2354259166111
# best_stitch_pair_size_ratio = 0.5424833150882828
# Starting Child 30
# 34 19837
# Done distance matrix: 0.02118396759033203
# Done Generating final pairs: 0.032648324966430664
# best_stitch_pair = [   9 3486]
# best_stitch_pair_size = 60300.90920274836
# best_stitch_pair_distance = 182.86285021438553
# best_stitch_pair_size_ratio = 0.15122085241284658
# Starting Child 31
# 53 19837
# Done distance matrix: 0.0317997932434082
# Done Generating final pairs: 0.0456392765045166
# best_stitch_pair = [  29 1279]
# best_stitch_pair_size = 465725.88799738925
# best_stitch_pair_distance = 1850.9528234626753
# best_stitch_pair_size_ratio = 0.5105470729150585
# Starting Child 32
# 27 19837
# Done distance matrix: 0.016331911087036133
# Done Generating final pairs: 0.02840423583984375
# best_stitch_pair = [   2 1287]
# best_stitch_pair_size = 668648.7278601378
# best_stitch_pair_distance = 409.1922434137861
# best_stitch_pair_size_ratio = 0.44071856662419007
# Starting Child 33
# 28 19837
# Done distance matrix: 0.017250776290893555
# Done Generating final pairs: 0.03151297569274902
# best_stitch_pair = [   0 1287]
# best_stitch_pair_size = 549873.1227665885
# best_stitch_pair_distance = 1541.90727406861
# best_stitch_pair_size_ratio = 0.5923019255816638
# Starting Child 34
# 63 19837
# Done distance matrix: 0.04151797294616699
# Child 34 There were no points close enough
# Starting Child 35
# 18 19837
# Done distance matrix: 0.011973381042480469
# Child 35 There were no points close enough
# Starting Child 36
# 5 19837
# Done distance matrix: 0.003495454788208008
# Child 36 There were no points close enough
# Starting Child 37
# 37 19837
# Done distance matrix: 0.02261948585510254
# Done Generating final pairs: 0.04180169105529785
# best_stitch_pair = [    7 10716]
# best_stitch_pair_size = 518370.9220367422
# best_stitch_pair_distance = 1505.551709646238
# best_stitch_pair_size_ratio = 0.528511719200476
# Starting Child 38
# 10 19837
# Done distance matrix: 0.007892131805419922
# Child 38 There were no points close enough
# Starting Child 39
# 17 19837
# Done distance matrix: 0.010627508163452148
# Done Generating final pairs: 0.020581960678100586
# best_stitch_pair = [  16 2213]
# best_stitch_pair_size = 43082.30973122103
# best_stitch_pair_distance = 1889.3378451624196
# best_stitch_pair_size_ratio = 0.9375694438890695
# Starting Child 40
# 4 19837
# Done distance matrix: 0.0028977394104003906
# Done Generating final pairs: 0.013665914535522461
# best_stitch_pair = [    0 19166]
# best_stitch_pair_size = 89638.42533658519
# best_stitch_pair_distance = 1375.3229518736973
# best_stitch_pair_size_ratio = 0.4667047983591716
# Starting Child 41
# 6 19837
# Done distance matrix: 0.0055005550384521484
# Done Generating final pairs: 0.019397497177124023
# best_stitch_pair = [    4 19162]
# best_stitch_pair_size = 25585.373303641238
# best_stitch_pair_distance = 1936.4671665837875
# best_stitch_pair_size_ratio = 0.36964275258335866
# Starting Child 42
# 7 19837
# Done distance matrix: 0.004893779754638672
# Done Generating final pairs: 0.016417741775512695
# best_stitch_pair = [    6 10716]
# best_stitch_pair_size = 360632.1641629231
# best_stitch_pair_distance = 183.46491980517186
# best_stitch_pair_size_ratio = 0.9880970540178715
# repeat_main_facets = [10716, 14535, 1287]
# child_mesh_double_indexes = [4, 37, 42]
# min_child = 42, max_ratio = 183.46491980517186
# child_mesh_double_indexes = [5, 24]
# min_child = 24, max_ratio = 170.50810536391745
# child_mesh_double_indexes = [32, 33]
# min_child = 32, max_ratio = 409.1922434137861
# child_meshes_stitch_facets = {1: [297, 3785], 2: [11, 12915], 9: [89, 19158], 20: [1, 1460], 24: [2, 14535], 29: [182, 4184], 30: [9, 3486], 31: [29, 1279], 32: [2, 1287], 39: [16, 2213], 40: [0, 19166], 41: [4, 19162], 42: [6, 10716]}
# ---Stitching child 1 with pair: [297, 3785]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 873957, starting edge 2nd facet= 930832,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02743077278137207
# returned from stitch mesh: 0.9159414768218994
# Finished stitching child 1 : 1.069927453994751
# ---Stitching child 2 with pair: [11, 12915]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 171211, starting edge 2nd facet= 949965,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 48
# Starting Organizing vertices for side 1
# edge_1_order done, len = 42
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 7.176399230957031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02804279327392578
# returned from stitch mesh: 0.9004683494567871
# Finished stitching child 2 : 1.0568139553070068
# ---Stitching child 9 with pair: [89, 19158]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 756198, starting edge 2nd facet= 954634,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.621246337890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.030863046646118164
# returned from stitch mesh: 0.9775876998901367
# Finished stitching child 9 : 1.1332204341888428
# ---Stitching child 20 with pair: [1, 1460]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 237180, starting edge 2nd facet= 960260,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02765655517578125
# returned from stitch mesh: 0.8918163776397705
# Finished stitching child 20 : 1.0503501892089844
# ---Stitching child 24 with pair: [2, 14535]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 837126, starting edge 2nd facet= 960413,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.8133392333984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.005875349044799805
# returned from stitch mesh: 1.085108757019043
# Finished stitching child 24 : 1.2370648384094238
# ---Stitching child 29 with pair: [182, 4184]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 318024, starting edge 2nd facet= 961851,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.1682510375976562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02771139144897461
# returned from stitch mesh: 0.9631588459014893
# Finished stitching child 29 : 1.1511359214782715
# ---Stitching child 30 with pair: [9, 3486]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 831453, starting edge 2nd facet= 963782,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.33514404296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02805185317993164
# returned from stitch mesh: 0.9248979091644287
# Finished stitching child 30 : 1.0964536666870117
# ---Stitching child 31 with pair: [29, 1279]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 676260, starting edge 2nd facet= 964905,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027922868728637695
# returned from stitch mesh: 0.9340472221374512
# Finished stitching child 31 : 1.0884654521942139
# ---Stitching child 32 with pair: [2, 1287]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 245616, starting edge 2nd facet= 965904,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04042696952819824
# returned from stitch mesh: 0.9178111553192139
# Finished stitching child 32 : 1.0764663219451904
# ---Stitching child 39 with pair: [16, 2213]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 555854, starting edge 2nd facet= 966274,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.1920928955078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.027208805084228516
# returned from stitch mesh: 0.8862864971160889
# Finished stitching child 39 : 1.0558576583862305
# ---Stitching child 40 with pair: [0, 19166]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 637075, starting edge 2nd facet= 966378,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.1682510375976562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.038907766342163086
# returned from stitch mesh: 0.8889288902282715
# Finished stitching child 40 : 1.0421063899993896
# ---Stitching child 41 with pair: [4, 19162]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 867207, starting edge 2nd facet= 966431,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.3828277587890625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03062272071838379
# returned from stitch mesh: 0.9780635833740234
# Finished stitching child 41 : 1.1440575122833252
# ---Stitching child 42 with pair: [6, 10716]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 730182, starting edge 2nd facet= 966500,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.028368711471557617
# returned from stitch mesh: 0.891385555267334
# Finished stitching child 42 : 1.0809032917022705
# ***************Finished big stitching iteration: 21.258994102478027***************
# Starting Child 0
# 1298 21756
# Done distance matrix: 1.0714669227600098
# Done Generating final pairs: 1.0921881198883057
# best_stitch_pair = [  634 20489]
# best_stitch_pair_size = 2764763.14464389
# best_stitch_pair_distance = 163.72694400202582
# best_stitch_pair_size_ratio = 0.5787514559158639
# Starting Child 3
# 887 21756
# Done distance matrix: 0.6781299114227295
# Child 3 There were no points close enough
# Starting Child 4
# 521 21756
# Done distance matrix: 0.3880167007446289
# Done Generating final pairs: 0.394824743270874
# best_stitch_pair = [    2 21751]
# best_stitch_pair_size = 471490.6745251275
# best_stitch_pair_distance = 1273.952270121484
# best_stitch_pair_size_ratio = 0.7644151539205241
# Starting Child 5
# 203 21756
# Done distance matrix: 0.2012617588043213
# Done Generating final pairs: 0.20581936836242676
# best_stitch_pair = [  151 21427]
# best_stitch_pair_size = 182014.01881742995
# best_stitch_pair_distance = 1972.004851465701
# best_stitch_pair_size_ratio = 0.21675339105095243
# Starting Child 6
# 567 21756
# Done distance matrix: 0.4302985668182373
# Child 6 There were no points close enough
# Starting Child 7
# 212 21756
# Done distance matrix: 0.1632061004638672
# Child 7 There were no points close enough
# Starting Child 8
# 170 21756
# Done distance matrix: 0.1198430061340332
# Child 8 There were no points close enough
# Starting Child 10
# 130 21756
# Done distance matrix: 0.12151503562927246
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 21756
# Done distance matrix: 0.2497107982635498
# Child 11 There were no points close enough
# Starting Child 12
# 191 21756
# Done distance matrix: 0.1546335220336914
# Child 12 There were no points close enough
# Starting Child 13
# 185 21756
# Done distance matrix: 0.1607968807220459
# Child 13 There were no points close enough
# Starting Child 14
# 187 21756
# Done distance matrix: 0.130385160446167
# Done Generating final pairs: 0.1560957431793213
# best_stitch_pair = [   30 20594]
# best_stitch_pair_size = 2883036.8729235698
# best_stitch_pair_distance = 390.2646613688339
# best_stitch_pair_size_ratio = 0.756428523739565
# Starting Child 15
# 470 21756
# Done distance matrix: 0.3856332302093506
# Done Generating final pairs: 0.39604711532592773
# best_stitch_pair = [  221 21661]
# best_stitch_pair_size = 859620.1038684781
# best_stitch_pair_distance = 737.0193281922791
# best_stitch_pair_size_ratio = 0.3821383730413649
# Starting Child 16
# 261 21756
# Done distance matrix: 0.2018883228302002
# Child 16 There were no points close enough
# Starting Child 17
# 10 21756
# Done distance matrix: 0.009816408157348633
# Child 17 There were no points close enough
# Starting Child 18
# 16 21756
# Done distance matrix: 0.010783672332763672
# Child 18 There were no points close enough
# Starting Child 19
# 4 21756
# Done distance matrix: 0.003122091293334961
# Child 19 There were no points close enough
# Starting Child 21
# 14 21756
# Done distance matrix: 0.012009620666503906
# Done Generating final pairs: 0.01801276206970215
# best_stitch_pair = [    5 20533]
# best_stitch_pair_size = 445825.1688913071
# best_stitch_pair_distance = 417.2369812716303
# best_stitch_pair_size_ratio = 0.7097850609379541
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 21756
# Done distance matrix: 0.04239296913146973
# Child 23 There were no points close enough
# Starting Child 25
# 56 21756
# Done distance matrix: 0.04088234901428223
# Child 25 There were no points close enough
# Starting Child 26
# 5 21756
# Done distance matrix: 0.003810405731201172
# Child 26 There were no points close enough
# Starting Child 27
# 3 21756
# Done distance matrix: 0.002251863479614258
# Child 27 There were no points close enough
# Starting Child 28
# 124 21756
# Done distance matrix: 0.09051847457885742
# Child 28 There were no points close enough
# Starting Child 33
# 28 21756
# Done distance matrix: 0.019062042236328125
# Done Generating final pairs: 0.033074378967285156
# best_stitch_pair = [    0 21700]
# best_stitch_pair_size = 883352.4059815214
# best_stitch_pair_distance = 646.9399508826754
# best_stitch_pair_size_ratio = 0.6418572978661629
# Starting Child 34
# 63 21756
# Done distance matrix: 0.061318397521972656
# Child 34 There were no points close enough
# Starting Child 35
# 18 21756
# Done distance matrix: 0.014318704605102539
# Done Generating final pairs: 0.01966094970703125
# best_stitch_pair = [    0 20560]
# best_stitch_pair_size = 129139.2523508153
# best_stitch_pair_distance = 1633.5018807506135
# best_stitch_pair_size_ratio = 0.7315768472227036
# Starting Child 36
# 5 21756
# Done distance matrix: 0.003970623016357422
# Child 36 There were no points close enough
# Starting Child 37
# 37 21756
# Done distance matrix: 0.025594711303710938
# Done Generating final pairs: 0.04183220863342285
# best_stitch_pair = [    7 21751]
# best_stitch_pair_size = 543403.0131173849
# best_stitch_pair_distance = 901.0225763628129
# best_stitch_pair_size_ratio = 0.6023234299780027
# Starting Child 38
# 10 21756
# Done distance matrix: 0.007718086242675781
# Done Generating final pairs: 0.013176202774047852
# best_stitch_pair = [    2 21730]
# best_stitch_pair_size = 300251.2315997881
# best_stitch_pair_distance = 1124.9148534122617
# best_stitch_pair_size_ratio = 0.33250451914072426
# repeat_main_facets = [21751]
# child_mesh_double_indexes = [4, 37]
# min_child = 37, max_ratio = 901.0225763628129
# child_meshes_stitch_facets = {0: [634, 20489], 5: [151, 21427], 14: [30, 20594], 15: [221, 21661], 21: [5, 20533], 33: [0, 21700], 35: [0, 20560], 37: [7, 21751], 38: [2, 21730]}
# ---Stitching child 0 with pair: [634, 20489]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 938420, starting edge 2nd facet= 1008714,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 40
# Starting Organizing vertices for side 1
# More than 2 edges possibilities for {current_vertex}
# More than 2 edges possibilities for {current_vertex}
# Start vertex reached before processed all of edges
# edge_1_order done, len = 50
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 10
# About to add faces
# Finished adding faces: 7.581710815429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.016423702239990234
# returned from stitch mesh: 1.1879444122314453
# Finished stitching child 0 : 1.3577220439910889
# ---Stitching child 5 with pair: [151, 21427]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 960374, starting edge 2nd facet= 1026054,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.8358230590820312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03082132339477539
# returned from stitch mesh: 0.8812716007232666
# Finished stitching child 5 : 1.0274124145507812
# ---Stitching child 14 with pair: [30, 20594]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 940793, starting edge 2nd facet= 1030927,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 31
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 5.936622619628906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.031255245208740234
# returned from stitch mesh: 1.1052701473236084
# Finished stitching child 14 : 1.2977557182312012
# ---Stitching child 15 with pair: [221, 21661]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 965732, starting edge 2nd facet= 1036551,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 29
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 14
# About to add faces
# Finished adding faces: 3.409385681152344e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03183269500732422
# returned from stitch mesh: 1.0667955875396729
# Finished stitching child 15 : 1.2575430870056152
# ---Stitching child 21 with pair: [5, 20533]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 946595, starting edge 2nd facet= 1041890,
# Starting Organizing vertices for side 0
# Start vertex reached before processed all of edges
# edge_0_order done, len = 22
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 2.288818359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03218555450439453
# returned from stitch mesh: 1.0755345821380615
# Finished stitching child 21 : 1.2562360763549805
# ---Stitching child 33 with pair: [0, 21700]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 966027, starting edge 2nd facet= 1042362,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.647804260253906e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.031229734420776367
# returned from stitch mesh: 1.1995513439178467
# Finished stitching child 33 : 1.3809778690338135
# ---Stitching child 35 with pair: [0, 20560]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 947060, starting edge 2nd facet= 1042523,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.811981201171875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03402209281921387
# returned from stitch mesh: 1.0205130577087402
# Finished stitching child 35 : 1.2157390117645264
# ---Stitching child 37 with pair: [7, 21751]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 966499, starting edge 2nd facet= 1042948,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 2.8371810913085938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03651070594787598
# returned from stitch mesh: 1.0299670696258545
# Finished stitching child 37 : 1.1998076438903809
# ---Stitching child 38 with pair: [2, 21730]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 966316, starting edge 2nd facet= 1043218,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03570723533630371
# returned from stitch mesh: 1.1802103519439697
# Finished stitching child 38 : 1.3697545528411865
# ***************Finished big stitching iteration: 17.569809436798096***************
# Starting Child 3
# 887 24003
# Done distance matrix: 0.7411680221557617
# Done Generating final pairs: 0.7511861324310303
# best_stitch_pair = [  232 23552]
# best_stitch_pair_size = 690856.3646172398
# best_stitch_pair_distance = 270.2210230377153
# best_stitch_pair_size_ratio = 0.7589459759005658
# Starting Child 4
# 521 24003
# Done distance matrix: 0.4683089256286621
# Done Generating final pairs: 0.485029935836792
# best_stitch_pair = [    2 23958]
# best_stitch_pair_size = 578926.3975470571
# best_stitch_pair_distance = 116.69925091478206
# best_stitch_pair_size_ratio = 0.8572934392933079
# Starting Child 6
# 567 24003
# Done distance matrix: 0.474531888961792
# Child 6 There were no points close enough
# Starting Child 7
# 212 24003
# Done distance matrix: 0.17018508911132812
# Child 7 There were no points close enough
# Starting Child 8
# 170 24003
# Done distance matrix: 0.13994455337524414
# Child 8 There were no points close enough
# Starting Child 10
# 130 24003
# Done distance matrix: 0.09972333908081055
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 290 24003
# Done distance matrix: 0.2693936824798584
# Done Generating final pairs: 0.2846860885620117
# best_stitch_pair = [  206 23285]
# best_stitch_pair_size = 2134758.3459845064
# best_stitch_pair_distance = 252.54897008950022
# best_stitch_pair_size_ratio = 0.9143665334861354
# Starting Child 12
# 191 24003
# Done distance matrix: 0.14647698402404785
# Done Generating final pairs: 0.15018630027770996
# best_stitch_pair = [  165 23238]
# best_stitch_pair_size = 75763.34031957734
# best_stitch_pair_distance = 133.59897154753196
# best_stitch_pair_size_ratio = 0.8622937409390152
# Starting Child 13
# 185 24003
# Done distance matrix: 0.15313315391540527
# Child 13 There were no points close enough
# Starting Child 16
# 261 24003
# Done distance matrix: 0.2179713249206543
# Child 16 There were no points close enough
# Starting Child 17
# 10 24003
# Done distance matrix: 0.011359691619873047
# Child 17 There were no points close enough
# Starting Child 18
# 16 24003
# Done distance matrix: 0.012460470199584961
# Child 18 There were no points close enough
# Starting Child 19
# 4 24003
# Done distance matrix: 0.0035102367401123047
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 23
# 63 24003
# Done distance matrix: 0.06553268432617188
# Done Generating final pairs: 0.07555294036865234
# best_stitch_pair = [    4 23067]
# best_stitch_pair_size = 142549.35198714465
# best_stitch_pair_distance = 301.4510828666649
# best_stitch_pair_size_ratio = 0.501101426366464
# Starting Child 25
# 56 24003
# Done distance matrix: 0.045348405838012695
# Child 25 There were no points close enough
# Starting Child 26
# 5 24003
# Done distance matrix: 0.0043294429779052734
# Child 26 There were no points close enough
# Starting Child 27
# 3 24003
# Done distance matrix: 0.002604961395263672
# Child 27 There were no points close enough
# Starting Child 28
# 124 24003
# Done distance matrix: 0.10013413429260254
# Child 28 There were no points close enough
# Starting Child 34
# 63 24003
# Done distance matrix: 0.04740619659423828
# Child 34 There were no points close enough
# Starting Child 36
# 5 24003
# Done distance matrix: 0.004354953765869141
# Done Generating final pairs: 0.013419389724731445
# best_stitch_pair = [    0 23367]
# best_stitch_pair_size = 103846.09580656198
# best_stitch_pair_distance = 1742.1879879685512
# best_stitch_pair_size_ratio = 0.359754035855908
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [232, 23552], 4: [2, 23958], 11: [206, 23285], 12: [165, 23238], 23: [4, 23067], 36: [0, 23367]}
# ---Stitching child 3 with pair: [232, 23552]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1040944, starting edge 2nd facet= 1051510,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 7.605552673339844e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05317997932434082
# returned from stitch mesh: 1.1540980339050293
# Finished stitching child 3 : 1.3231391906738281
# ---Stitching child 4 with pair: [2, 23958]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1043169, starting edge 2nd facet= 1059011,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03196549415588379
# returned from stitch mesh: 1.2917301654815674
# Finished stitching child 4 : 1.5094757080078125
# ---Stitching child 11 with pair: [206, 23285]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1031100, starting edge 2nd facet= 1068378,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 36
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 4.7206878662109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03164339065551758
# returned from stitch mesh: 1.0411491394042969
# Finished stitching child 11 : 1.2418618202209473
# ---Stitching child 12 with pair: [165, 23238]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1026630, starting edge 2nd facet= 1074816,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.8596649169921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03600955009460449
# returned from stitch mesh: 1.1513338088989258
# Finished stitching child 12 : 1.3208332061767578
# ---Stitching child 23 with pair: [4, 23067]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1026800, starting edge 2nd facet= 1075669,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.9550323486328125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03284311294555664
# returned from stitch mesh: 1.049154281616211
# Finished stitching child 23 : 1.2745041847229004
# ---Stitching child 36 with pair: [0, 23367]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1030036, starting edge 2nd facet= 1076149,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03246188163757324
# returned from stitch mesh: 1.2281219959259033
# Finished stitching child 36 : 1.4434142112731934
# ***************Finished big stitching iteration: 12.729746341705322***************
# Starting Child 6
# 567 25948
# Done distance matrix: 0.5010340213775635
# Child 6 There were no points close enough
# Starting Child 7
# 212 25948
# Done distance matrix: 0.19225382804870605
# Done Generating final pairs: 0.215559720993042
# best_stitch_pair = [   46 25296]
# best_stitch_pair_size = 136007.9956301315
# best_stitch_pair_distance = 534.6311217289636
# best_stitch_pair_size_ratio = 0.7482800030866305
# Starting Child 8
# 170 25948
# Done distance matrix: 0.15075898170471191
# Child 8 There were no points close enough
# Starting Child 10
# 130 25948
# Done distance matrix: 0.11519312858581543
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 185 25948
# Done distance matrix: 0.16216707229614258
# Child 13 There were no points close enough
# Starting Child 16
# 261 25948
# Done distance matrix: 0.23059749603271484
# Child 16 There were no points close enough
# Starting Child 17
# 10 25948
# Done distance matrix: 0.012357473373413086
# Child 17 There were no points close enough
# Starting Child 18
# 16 25948
# Done distance matrix: 0.013235807418823242
# Child 18 There were no points close enough
# Starting Child 19
# 4 25948
# Done distance matrix: 0.0036907196044921875
# Child 19 There were no points close enough
# Starting Child 22
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 25
# 56 25948
# Done distance matrix: 0.04483628273010254
# Child 25 There were no points close enough
# Starting Child 26
# 5 25948
# Done distance matrix: 0.0054416656494140625
# Child 26 There were no points close enough
# Starting Child 27
# 3 25948
# Done distance matrix: 0.0027823448181152344
# Child 27 There were no points close enough
# Starting Child 28
# 124 25948
# Done distance matrix: 0.11922264099121094
# Child 28 There were no points close enough
# Starting Child 34
# 63 25948
# Done distance matrix: 0.049938201904296875
# Done Generating final pairs: 0.05245327949523926
# best_stitch_pair = [    3 25934]
# best_stitch_pair_size = 49084.28270166188
# best_stitch_pair_distance = 297.5936887733172
# best_stitch_pair_size_ratio = 0.48412922201830955
# repeat_main_facets = []
# child_meshes_stitch_facets = {7: [46, 25296], 34: [3, 25934]}
# ---Stitching child 7 with pair: [46, 25296]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1065195, starting edge 2nd facet= 1077514,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.5020370483398438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.032887935638427734
# returned from stitch mesh: 1.1918034553527832
# Finished stitching child 7 : 1.3742523193359375
# ...
# Child 149 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 169
# 1 34511
# Done distance matrix: 0.001589059829711914
# Child 169 There were no points close enough
# Starting Child 192
# 1 34511
# Done distance matrix: 0.0014836788177490234
# Child 192 There were no points close enough
# Starting Child 194
# 1 34511
# Done distance matrix: 0.0014643669128417969
# Child 194 There were no points close enough
# Starting Child 225
# 1 34511
# Done distance matrix: 0.0013802051544189453
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34511
# Done distance matrix: 0.0016434192657470703
# Child 263 There were no points close enough
# Starting Child 294
# 1 34511
# Done distance matrix: 0.0014128684997558594
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 320
# 2 34511
# Done distance matrix: 0.00298309326171875
# Child 320 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {114: [14, 34480]}
# ---Stitching child 114 with pair: [14, 34480]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1275433, starting edge 2nd facet= 1276106,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 15
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 3.0994415283203125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.007092714309692383
# returned from stitch mesh: 1.148303508758545
# Finished stitching child 114 : 1.3087763786315918
# ***************Finished big stitching iteration: 3.28322172164917***************
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.0017864704132080078
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.0014848709106445312
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.0013432502746582031
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.0016376972198486328
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 149
# 2 34543
# Done distance matrix: 0.002791166305541992
# Child 149 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 169
# 1 34543
# Done distance matrix: 0.0012521743774414062
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.0013852119445800781
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.0013604164123535156
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.001367330551147461
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0013675689697265625
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0013797283172607422
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 320
# 2 34543
# Done distance matrix: 0.002579212188720703
# Child 320 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.0017313957214355469
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.0013508796691894531
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.001413583755493164
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.0015096664428710938
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 149
# 2 34543
# Done distance matrix: 0.0026345252990722656
# Done Generating final pairs: 0.0065119266510009766
# best_stitch_pair = [    0 10508]
# best_stitch_pair_size = 51656.26320844551
# best_stitch_pair_distance = 3325.689027596439
# best_stitch_pair_size_ratio = 0.3895536619633393
# Starting Child 169
# 1 34543
# Done distance matrix: 0.0016584396362304688
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.001581430435180664
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.00145721435546875
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.0014634132385253906
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0014584064483642578
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0014469623565673828
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 320
# 2 34543
# Done distance matrix: 0.0038390159606933594
# Done Generating final pairs: 0.013137578964233398
# best_stitch_pair = [   1 2062]
# best_stitch_pair_size = 45993.49509499938
# best_stitch_pair_distance = 3064.383119022957
# best_stitch_pair_size_ratio = 0.5398822098553147
# repeat_main_facets = []
# child_meshes_stitch_facets = {149: [0, 10508], 320: [1, 2062]}
# ---Stitching child 149 with pair: [0, 10508]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 487974, starting edge 2nd facet= 1276304,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 2
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03876304626464844
# returned from stitch mesh: 1.052276372909546
# Finished stitching child 149 : 1.201901912689209
# ---Stitching child 320 with pair: [1, 2062]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 175127, starting edge 2nd facet= 1276323,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 42
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 8, remainder = 2
# About to add faces
# Finished adding faces: 4.9114227294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.022546768188476562
# returned from stitch mesh: 0.9374034404754639
# Finished stitching child 320 : 1.1691772937774658
# ***************Finished big stitching iteration: 2.636064291000366***************
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.0014886856079101562
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.0012054443359375
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.0014185905456542969
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.001209259033203125
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 169
# 1 34543
# Done distance matrix: 0.0014793872833251953
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.004502058029174805
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.0011827945709228516
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.0011363029479980469
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0015311241149902344
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0010902881622314453
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.0016412734985351562
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.0011315345764160156
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.0014162063598632812
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.0012292861938476562
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 169
# 1 34543
# Done distance matrix: 0.001397848129272461
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.0010917186737060547
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.0012013912200927734
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.0011360645294189453
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0013642311096191406
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0011758804321289062
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.00147247314453125
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.001119852066040039
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.0016760826110839844
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.001088857650756836
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 169
# 1 34543
# Done distance matrix: 0.0010943412780761719
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.0012066364288330078
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.0012311935424804688
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.0010881423950195312
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0014085769653320312
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0011446475982666016
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 19
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 20
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 35
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 69
# 1 34543
# Done distance matrix: 0.0015416145324707031
# Child 69 There were no points close enough
# Starting Child 70
# 1 34543
# Done distance matrix: 0.001195669174194336
# Child 70 There were no points close enough
# Starting Child 92
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 104
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 111
# 1 34543
# Done distance matrix: 0.001190185546875
# Child 111 There were no points close enough
# Starting Child 118
# 1 34543
# Done distance matrix: 0.0011584758758544922
# Child 118 There were no points close enough
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 169
# 1 34543
# Done distance matrix: 0.0012891292572021484
# Child 169 There were no points close enough
# Starting Child 192
# 1 34543
# Done distance matrix: 0.001176595687866211
# Child 192 There were no points close enough
# Starting Child 194
# 1 34543
# Done distance matrix: 0.0012159347534179688
# Child 194 There were no points close enough
# Starting Child 225
# 1 34543
# Done distance matrix: 0.0011653900146484375
# Child 225 There were no points close enough
# Starting Child 248
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 254
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 263
# 1 34543
# Done distance matrix: 0.0012257099151611328
# Child 263 There were no points close enough
# Starting Child 294
# 1 34543
# Done distance matrix: 0.0011637210845947266
# Child 294 There were no points close enough
# Starting Child 316
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 605.5753350257874
# Total time for restitching = 605.5830564498901
# missed_children = [192.0, 225.0, 194.0, 35.0, 69.0, 70.0, 263.0, 104.0, 169.0, 294.0, 111.0, 19.0, 20.0, 118.0, 316.0, 248.0, 92.0, 125.0, 254.0]
# Whole stitching function complete: 741.1218359470367
# 6092.548448801041

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
