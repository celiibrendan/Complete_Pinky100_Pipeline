# %%
import datajoint as dj

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_ta3p100")
ta3p100 = dj.create_virtual_module("ta3p100","microns_ta3p100")

# %%
ta3p100.Synapse()
# Out:
# *segmentation  *synapse_id    presyn         postsyn        synapse_x     synapse_y     synapse_z     presyn_x     presyn_y     presyn_z     postsyn_x     postsyn_y     postsyn_z     syn_bbox_x1    syn_bbox_y1    syn_bbox_z1    syn_bbox_x2    syn_bbox_y2    syn_bbox_z2    size
# +------------+ +------------+ +------------+ +------------+ +-----------+ +-----------+ +-----------+ +----------+ +----------+ +----------+ +-----------+ +-----------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------+
# 1              1              64851834634450 64851834634947 54623         41105         1898          54560        41084        1899         54606         41142         1899          54560          41084          1899           54606          41142          1899           127
# 1              2              64851834634256 64851834634135 111617        68901         172           111618       68848        170          111536        68888         170           111536         68848          170            111618         68888          170            153
# 1              3              64851834634280 64851834634279 73051         67181         768           73014        67172        768          73032         67212         770           73014          67172          768            73032          67212          770            71
# 1              4              64851834634280 64851834634407 97419         71478         1839          97424        71446        1843         97370         71490         1842          97370          71446          1842           97424          71490          1843           368
# 1              5              64851834634140 64851834634947 99676         73497         1440          99656        73460        1441         99584         73470         1439          99584          73460          1439           99656          73470          1441           112
# 1              6              64851834634947 64851834634280 56024         42669         1562          56020        42658        1566         55970         42702         1566          55970          42658          1566           56020          42702          1566           714
# 1              7              64851834634205 64851834634136 66353         68082         762           66350        68076        764          66316         68092         763           66316          68076          763            66350          68092          764            123
# 1              10             64851834634630 64851834634630 78819         60649         848           78754        60688        851          78840         60650         852           78754          60650          851            78840          60688          852            308
# 1              16             64851834634135 64851834634138 58154         64556         1585          58164        64534        1584         58122         64590         1585          58122          64534          1584           58164          64590          1585           61
# 1              18             64851834634136 64851834634606 89858         57747         2143          89836        57754        2142         89838         57738         2144          89836          57738          2142           89838          57754          2144           79
# 1              19             64851834634659 64851834634659 69496         52938         346           69506        52884        345          69506         52976         345           69506          52884          345            69506          52976          345            61
# 1              21             64851834634280 64851834634137 79051         59749         1065          79024        59670        1066         79000         59760         1066          79000          59670          1066           79024          59760          1066           753
# 1              25             64851834634695 64851834634947 69361         52441         436           69344        52400        437          69326         52460         436           69326          52400          436            69344          52460          437            226
# 1              29             64851834634905 64851834634905 107519        41718         575           107544       41700        577          107484        41722         576           107484         41700          576            107544         41722          577            87
# 1              30             64851834634442 64851834634947 59112         38822         971           59056        38810        971          59152         38824         971           59056          38810          971            59152          38824          971            61
# 1              33             64851834634140 64851834634821 113388        60350         617           113420       60314        618          113364        60352         616           113364         60314          616            113420         60352          618            61
# 1              34             64851834634139 64851834634210 80270         73758         1990          80308        73776        1991         80248         73734         1990          80248          73734          1990           80308          73776          1991           61
# 1              36             64851834634280 64851834634947 78940         60462         1805          78890        60418        1805         78952         60472         1804          78890          60418          1804           78952          60472          1805           61
# 1              38             64851834634445 64851834634292 59466         38446         1927          59512        38480        1928         59434         38420         1927          59434          38420          1927           59512          38480          1928           61
# 1              40             64851834634279 64851834634947 71648         59134         1416          71660        59142        1415         71564         59120         1415          71564          59120          1415           71660          59142          1415           568
#    ...
#  (4240430 tuples)

# %%
@schema
class DatajointExampleXaq(dj.Manual):
    definition = """
    # creates the labels for the mesh table
    identifier : int     # unique identifier
    ---
    network_values   : longblob     # label data for the vertices
    training_network_performance  : int     # how good the network did, number of correct classifications
    """

# %%
ta3p100.DatajointExampleXaq()
# Out:
# *identifier    network_va training_netwo
# +------------+ +--------+ +------------+
#
#  (0 tuples)

# %%
import numpy as np
key = dict(identifier=1,network_values=np.array([1,4,5,6,67,6,3,6]),training_network_performance=100)
key
# Out:
# {'identifier': 1,
#  'network_values': array([ 1,  4,  5,  6, 67,  6,  3,  6]),
#  'training_network_performance': 100}

# %%
ta3p100.DatajointExampleXaq.insert1(key)

# %%
ta3p100.DatajointExampleXaq()
# Out:
# *identifier    network_va training_netwo
# +------------+ +--------+ +------------+
#
#  (0 tuples)

# %%
np.random.normal(size=4)
# Out:
# array([-0.80075733, -1.11041901, -1.9049227 , -1.0346882 ])

# %%
np.rand([4,5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4b9db0417ac0> in <module>
# ----> 1 np.rand([4,5])
#
# AttributeError: module 'numpy' has no attribute 'rand'

# %%
import numpy as np
array_dict = [dict(identifier=k,network_values=np.random.normal(size=4),training_network_performance=k + 10) for k in range(0,20)]
array_dict
# Out:
# [{'identifier': 0,
#   'network_values': array([ 0.54068877,  1.62567112, -0.95255859, -0.31331967]),
#   'training_network_performance': 10},
#  {'identifier': 1,
#   'network_values': array([ 2.19993114,  0.08684398, -0.33076752, -0.52608473]),
#   'training_network_performance': 11},
#  {'identifier': 2,
#   'network_values': array([-1.20882127,  0.42650934,  0.66549116, -0.44882204]),
#   'training_network_performance': 12},
#  {'identifier': 3,
#   'network_values': array([ 0.07513299,  0.48769494,  0.42025282, -1.38758192]),
#   'training_network_performance': 13},
#  {'identifier': 4,
#   'network_values': array([ 0.5368017 , -1.2319178 ,  1.96867719, -0.72695994]),
#   'training_network_performance': 14},
#  {'identifier': 5,
#   'network_values': array([-0.8963481 , -0.41546523,  0.12694262,  1.16790075]),
#   'training_network_performance': 15},
#  {'identifier': 6,
#   'network_values': array([-0.4350019 ,  1.15617468, -0.61528551,  0.77320335]),
#   'training_network_performance': 16},
#  {'identifier': 7,
#   'network_values': array([ 1.57482482, -0.23749215,  0.21117378,  0.39867249]),
#   'training_network_performance': 17},
#  {'identifier': 8,
#   'network_values': array([ 0.80306715, -1.04841113, -0.43521539,  1.40336947]),
#   'training_network_performance': 18},
#  {'identifier': 9,
#   'network_values': array([-1.36909001, -1.86120223, -0.11972449, -0.17437124]),
#   'training_network_performance': 19},
#  {'identifier': 10,
#   'network_values': array([-0.9082512 ,  0.05561959,  0.93948179,  1.42089929]),
#   'training_network_performance': 20},
#  {'identifier': 11,
#   'network_values': array([ 0.08356322, -0.26125803,  0.71379311,  1.12508129]),
#   'training_network_performance': 21},
#  {'identifier': 12,
#   'network_values': array([-0.3724928 ,  0.62960481,  1.10145283, -0.92284646]),
#   'training_network_performance': 22},
#  {'identifier': 13,
#   'network_values': array([ 0.12196825,  0.23762942, -1.15543542,  2.36970629]),
#   'training_network_performance': 23},
#  {'identifier': 14,
#   'network_values': array([-0.80001944, -0.01473118, -0.78645489, -0.41893266]),
#   'training_network_performance': 24},
#  {'identifier': 15,
#   'network_values': array([ 0.4366236 ,  0.76041151, -0.42268233, -2.23164173]),
#   'training_network_performance': 25},
#  {'identifier': 16,
#   'network_values': array([ 0.00764154, -0.09896286, -1.24205038, -1.97198464]),
#   'training_network_performance': 26},
#  {'identifier': 17,
#   'network_values': array([ 0.28373915, -1.3660099 ,  1.48647299,  0.47940493]),
#   'training_network_performance': 27},
#  {'identifier': 18,
#   'network_values': array([-0.028694  ,  0.55171234,  0.17593873,  0.60991463]),
#   'training_network_performance': 28},
#  {'identifier': 19,
#   'network_values': array([0.90117755, 0.88538378, 1.05624114, 0.69254874]),
#   'training_network_performance': 29}]

# %%
ta3p100.DatajointExampleXaq.insert(array_dict)

# %%
ta3p100.DatajointExampleXaq()
# Out:
# *identifier    network_va training_netwo
# +------------+ +--------+ +------------+
# 0              =BLOB=     10
# 1              =BLOB=     11
# 2              =BLOB=     12
# 3              =BLOB=     13
# 4              =BLOB=     14
# 5              =BLOB=     15
# 6              =BLOB=     16
# 7              =BLOB=     17
# 8              =BLOB=     18
# 9              =BLOB=     19
# 10             =BLOB=     20
# 11             =BLOB=     21
# 12             =BLOB=     22
# 13             =BLOB=     23
# 14             =BLOB=     24
# 15             =BLOB=     25
# 16             =BLOB=     26
# 17             =BLOB=     27
# 18             =BLOB=     28
# 19             =BLOB=     29
#  (20 tuples)

# %%
ta3p100.Decimation35.describe()
# Out:
# # decimated meshes using blender
# -> ta3p100.Mesh
# decimation_ratio     : decimal(3,2)
# ---
# n_vertices           : bigint
# n_triangles          : bigint
# vertices             : longblob
# triangles            : longblob
# '# decimated meshes using blender\n-> ta3p100.Mesh\ndecimation_ratio     : decimal(3,2)                 \n---\nn_vertices           : bigint                       \nn_triangles          : bigint                       \nvertices             : longblob                     \ntriangles            : longblob                     \n'

# %%
data = (ta3p100.DatajointExampleXaq & "identifier = 3").fetch1()
data
# Out:
# OrderedDict([('identifier', 3),
#              ('network_values',
#               array([ 0.07513299,  0.48769494,  0.42025282, -1.38758192])),
#              ('training_network_performance', 13)])

# %%
import time
print("hello")
time.sleep(5)
print("hi")
# Out:
# hello
# hi

# %%
@schema
class DatajointExampleXaqAnalysis(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> ta3p100.DatajointExampleXaq
    ---
    sum_of_weights   : decimal(10,3)     # sum of all their weights
    """
    
    def make(self,key):
        start_time = time.time()
        print("working on " + str(key))
        data = (ta3p100.DatajointExampleXaq & key).fetch1()
        network_values = data["network_values"]
        
        sum_network = np.sum(network_values)
        time.sleep(60)
        
        self.insert1(dict(key,sum_network))
        print(f"Total time = {time.time() - start_time}")

# %%
DatajointExampleXaqAnalysis.populate(reserve_jobs=True)
# Out:
# working on {'identifier': 0}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-79542c3451f5> in <module>
# ----> 1 DatajointExampleXaqAnalysis.populate(reserve_jobs=True)
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-30-38b50469b008> in make(self, key)
#      17         time.sleep(60)
#      18
# ---> 19         self.insert1(dict(key,sum_network))
#      20         print(f"Total time = {time.time() - start_time}")
#      21
#
# TypeError: dict expected at most 1 arguments, got 2
