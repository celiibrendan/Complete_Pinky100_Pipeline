# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349496925******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.09038519859313965
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 926.5256292819977
# 2) Finished: Generating CGAL segmentation for neuron: 946.432651758194
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 17
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.29699110984802246
# 5) Staring: Finding Apical Index
# Soma Index = 17
# Soma Connections = [64, 10, 1, 23, 20, 18, 119, 27, 93, 33, 99, 48]
# soma_80_percent = 226823.275
# Debugging the axon filter
# [(64, 240021.265625), (10, 241942.484375), (1, 223707.171875), (23, 240450.078125), (20, 232906.53125), (18, 243850.53125), (119, 224038.71875), (27, 242297.875), (93, 236289.09375), (33, 250648.359375), (99, 228528.484375), (48, 231793.28125)]
# possible_Axons_filter_1 = [1, 119]
# possible_Axons_filter_2 = [1]
# possible_Apical = 1
# 5) Finished: Finding Apical Index: 0.14118409156799316
# 6) Staring: Classifying Entire Neuron
# 33 = error
# 119 = cilia
# 48 = cilia
# 93 = stub soma
# 99 = stub soma
# 11 = error
# 16 = error
# 22 = stub apical
# 29 = stub apical
# 31 = stub apical
# 34 = stub apical
# 38 = stub apical
# 39 = error
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 55 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 69 = stub apical
# 70 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 83 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 118 = stub apical
# Total Labels found = {'soma', 'cilia', 'oblique', 'apical', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 2.2031426429748535
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5650894641876221
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.30052137374878
# Finished Auto Labeling: 961.7528803348541
#
#
# *****Starting Auto Labeling for 648518346349499803******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07706451416015625
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 630.6031830310822
# 2) Finished: Generating CGAL segmentation for neuron: 646.4088320732117
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 5
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19915366172790527
# 5) Staring: Finding Apical Index
# Soma Index = 5
# Soma Connections = [13, 11, 8, 28, 27, 51, 53, 23, 26, 17, 21, 39, 14, 54, 49, 38, 46, 31, 25, 29, 47, 58, 33, 56, 55, 36, 32, 37]
# soma_80_percent = 158300.4484375
# Debugging the axon filter
# [(13, 179614.65625), (11, 156451.15625), (8, 161037.96875), (28, 163610.78125), (27, 157296.59375), (51, 161111.6875), (53, 158406.75), (23, 170807.328125), (26, 166381.0), (17, 174375.203125), (21, 162686.390625), (39, 165919.34375), (14, 160038.21875), (54, 156587.84375), (49, 161023.375), (38, 159704.546875), (46, 157275.546875), (31, 160955.046875), (25, 161961.84375), (29, 163141.1875), (47, 163381.28125), (58, 156349.8125), (33, 158157.421875), (56, 156134.984375), (55, 156058.125), (36, 159456.15625), (32, 157736.140625), (37, 158258.015625)]
# possible_Axons_filter_1 = [11, 27, 54, 46, 58, 33, 56, 55, 32, 37]
# possible_Axons_filter_2 = [11]
# possible_Apical = 11
# 5) Finished: Finding Apical Index: 0.08535575866699219
# 6) Staring: Classifying Entire Neuron
# 21 = stub soma
# 25 = stub soma
# 27 = stub soma
# 28 = stub soma
# 29 = stub soma
# 31 = stub soma
# 32 = stub soma
# 33 = stub soma
# 36 = stub soma
# 37 = stub soma
# 38 = stub soma
# 39 = stub soma
# 46 = stub soma
# 47 = stub soma
# 49 = stub soma
# 51 = stub soma
# 53 = stub soma
# 54 = stub soma
# 55 = stub soma
# 56 = stub soma
# 58 = stub soma
# 10 = stub apical
# 16 = stub apical
# 18 = stub apical
# 20 = stub apical
# Total Labels found = {'soma', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.001742124557495
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4352233409881592
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.641136407852173
# Finished Auto Labeling: 658.3557832241058
#
#
# *****Starting Auto Labeling for 648518346349500657******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.07999324798583984
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1416.1480078697205
# 2) Finished: Generating CGAL segmentation for neuron: 1440.0854270458221
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 12
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.3116884231567383
# 5) Staring: Finding Apical Index
# Soma Index = 12
# Soma Connections = [23, 4, 24, 11, 27, 34, 54, 7, 302, 72, 294, 269, 348, 227, 273, 51, 320]
# soma_80_percent = 252824.4625
# Debugging the axon filter
# [(23, 262395.9375), (4, 249099.484375), (24, 257799.484375), (11, 274363.75), (27, 277735.34375), (34, 262954.5), (54, 254580.234375), (7, 252671.078125), (302, 251128.078125), (72, 281992.46875), (294, 253026.578125), (269, 258301.125), (348, 259175.765625), (227, 256632.546875), (273, 253039.984375), (51, 261974.234375), (320, 248469.25)]
# possible_Axons_filter_1 = [4, 7, 302, 320]
# possible_Axons_filter_2 = [4]
# possible_Apical = 4
# 5) Finished: Finding Apical Index: 0.1735374927520752
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 23
# 27 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 54
# 51 = stub soma
# 227 = stub soma
# 269 = stub soma
# 302 = cilia
# 273 = stub soma
# 294 = stub soma
# 320 = stub soma
# 348 = stub soma
# 26 = stub apical
# 37 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 53 = stub apical
# 57 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 70 = stub apical
# 73 = stub apical
# 75 = stub apical
# 76 = error
# 79 = stub apical
# 83 = stub apical
# 85 = stub apical
# 86 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 94 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 102 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 126 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 167 = stub apical
# 175 = stub apical
# 176 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# 188 = stub apical
# 189 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 209 = stub apical
# 213 = stub apical
# 214 = stub apical
# 223 = stub apical
# 225 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 234 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 254 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 270 = stub apical
# 272 = stub apical
# 274 = stub apical
# 280 = stub apical
# 287 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 308 = stub apical
# 318 = stub apical
# 319 = stub apical
# 322 = stub apical
# 326 = stub apical
# 327 = stub apical
# 329 = stub apical
# 331 = stub apical
# 343 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 350 = stub apical
# 359 = stub apical
# Total Labels found = {'soma', 'cilia', 'oblique', 'apical', 'axon', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.770637035369873
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5508885383605957
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 13.444365501403809
# Finished Auto Labeling: 1459.3074402809143
#
#
# *****Starting Auto Labeling for 648518346349504324******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.14134860038757324
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1890.5959975719452
# 2) Finished: Generating CGAL segmentation for neuron: 1918.5219271183014
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 11
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.34869909286499023
# 5) Staring: Finding Apical Index
# Soma Index = 11
# Soma Connections = [38, 29, 118, 32, 16, 6, 39, 148, 24]
# soma_80_percent = 249936.2390625
# Debugging the axon filter
# [(38, 267370.6875), (29, 250238.375), (118, 250113.53125), (32, 250128.46875), (16, 245621.734375), (6, 266131.96875), (39, 271923.03125), (148, 259283.453125), (24, 269512.8125)]
# possible_Axons_filter_1 = [16]
# possible_Axons_filter_2 = [16]
# possible_Apical = 16
# 5) Finished: Finding Apical Index: 0.10532116889953613
# 6) Staring: Classifying Entire Neuron
# 148 = stub soma
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 30 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 41 = stub apical
# 45 = stub apical
# 46 = stub apical
# 49 = stub apical
# 50 = stub apical
# 55 = stub apical
# 56 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 88 = stub apical
# 89 = stub apical
# 90 = stub apical
# 96 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 111 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 126 = stub apical
# 127 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 163 = stub apical
# Total Labels found = {'soma', 'basal', 'oblique', 'apical'}
# 6) Finished: Classifying Entire Neuron: 4.2092180252075195
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.6515109539031982
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 16.475525379180908
# Finished Auto Labeling: 1941.5792326927185
#
#
# *****Starting Auto Labeling for 648518346349507658******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.011070013046264648
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 95.02421426773071
# 2) Finished: Generating CGAL segmentation for neuron: 98.14389824867249
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 7
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.039292335510253906
# 5) Staring: Finding Apical Index
# Soma Index = 7
# Soma Connections = [1, 10, 15, 6, 20, 24, 19, 13, 21, 22, 26, 25, 23]
# soma_80_percent = 253939.94375
# Debugging the axon filter
# [(1, 269938.4375), (10, 264730.375), (15, 260634.734375), (6, 262312.5625), (20, 260710.671875), (24, 254183.0), (19, 261191.984375), (13, 255087.90625), (21, 258738.390625), (22, 255012.015625), (26, 254286.703125), (25, 254819.046875), (23, 254152.390625)]
# possible_Axons_filter_1 = []
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.013958215713500977
# 6) Staring: Classifying Entire Neuron
# 1 = error
# 6 = cilia
# 10 = error
# 13 = stub soma
# 19 = stub soma
# 20 = stub soma
# 21 = stub soma
# 22 = stub soma
# 23 = stub soma
# 24 = stub soma
# 25 = stub soma
# 26 = stub soma
# Total Labels found = {'soma', 'unsure', 'cilia', 'error'}
# 6) Finished: Classifying Entire Neuron: 0.343900203704834
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.17082548141479492
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 1.6366796493530273
# Finished Auto Labeling: 100.4537444114685
#
#
# *****Starting Auto Labeling for 648518346349508960******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04895281791687012
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 261.27463817596436
# 2) Finished: Generating CGAL segmentation for neuron: 270.1998279094696
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1121664047241211
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [14, 17, 7, 12, 5, 16, 23, 26, 30, 46, 41, 52]
# soma_80_percent = 215243.684375
# Debugging the axon filter
# [(14, 216299.171875), (17, 235468.9375), (7, 213954.125), (12, 232353.84375), (5, 217400.34375), (16, 227894.359375), (23, 222663.84375), (26, 222808.6875), (30, 225560.5625), (46, 225426.015625), (41, 222504.109375), (52, 216855.078125)]
# possible_Axons_filter_1 = [7]
# possible_Axons_filter_2 = [7]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.08203458786010742
# 6) Staring: Classifying Entire Neuron
# 14 = stub soma
# 16 = axon
# 26 = stub soma
# 30 = stub soma
# 41 = stub soma
# 46 = stub soma
# 52 = stub soma
# 20 = stub apical
# 22 = stub apical
# 27 = stub apical
# 29 = stub apical
# 31 = stub apical
# 34 = stub apical
# 45 = stub apical
# 49 = stub apical
# Total Labels found = {'soma', 'oblique', 'apical', 'axon', 'basal'}
# 6) Finished: Classifying Entire Neuron: 0.9373371601104736
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.23424720764160156
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.698351621627808
# Finished Auto Labeling: 276.6211588382721
#
#
# *****Starting Auto Labeling for 648518346349509300******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06927871704101562
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 1161.4803268909454
# 2) Finished: Generating CGAL segmentation for neuron: 1182.9229600429535
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 9
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.26471590995788574
# 5) Staring: Finding Apical Index
# Soma Index = 9
# Soma Connections = [19, 22, 18, 16, 29, 73, 21, 11, 37, 66, 33, 64]
# soma_80_percent = 230580.5375
# Debugging the axon filter
# [(19, 255162.21875), (22, 235294.015625), (18, 249185.359375), (16, 227210.59375), (29, 240732.921875), (73, 228725.0625), (21, 246394.796875), (11, 253730.46875), (37, 239881.265625), (66, 227443.828125), (33, 228916.734375), (64, 241083.296875)]
# possible_Axons_filter_1 = [16, 73, 66, 33]
# possible_Axons_filter_2 = [16]
# possible_Apical = 16
# 5) Finished: Finding Apical Index: 0.08332967758178711
# 6) Staring: Classifying Entire Neuron
# 33 = stub soma
# 37 = stub soma
# 66 = cilia
# 64 = stub soma
# 73 = stub soma
# 27 = stub apical
# 38 = error
# 55 = stub apical
# 60 = stub apical
# 65 = stub apical
# 72 = stub apical
# Total Labels found = {'soma', 'cilia', 'oblique', 'apical', 'basal', 'error'}
# 6) Finished: Classifying Entire Neuron: 3.432084083557129
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.598442554473877
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 12.36360478401184
# Finished Auto Labeling: 1200.5512101650238
#
#
# *****Starting Auto Labeling for 648518346349513135******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05260467529296875
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 803.142085313797
# 2) Finished: Generating CGAL segmentation for neuron: 821.3764605522156
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.25877809524536133
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [11, 17, 19, 73, 9, 24, 6, 27, 31, 37, 35, 22]
# soma_80_percent = 254702.8875
# Debugging the axon filter
# [(11, 262831.3125), (17, 266359.84375), (19, 276416.15625), (73, 262888.6875), (9, 250501.515625), (24, 283918.90625), (6, 256377.953125), (27, 256253.359375), (31, 259246.171875), (37, 253189.359375), (35, 269690.9375), (22, 276526.46875)]
# possible_Axons_filter_1 = [9, 37]
# possible_Axons_filter_2 = [9]
# possible_Apical = 9
# 5) Finished: Finding Apical Index: 0.09476256370544434
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 31
# 37 = cilia
# 73 = stub soma
# 33 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 49 = stub apical
# 50 = stub apical
# 52 = stub apical
# 53 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 61 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 69 = stub apical
# 72 = stub apical
# 74 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 102 = stub apical
# 108 = stub apical
# 114 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 135 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 145 = stub apical
# 146 = stub apical
# 148 = stub apical
# 150 = stub apical
# 151 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 185 = stub apical
# 186 = stub apical
# 187 = stub apical
# Total Labels found = {'soma', 'cilia', 'oblique', 'apical', 'basal'}
# 6) Finished: Classifying Entire Neuron: 1.9187192916870117
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.39776182174682617
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.356388807296753
# Finished Auto Labeling: 834.1092348098755
# 7435.62212729454

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
