# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURITES")) == False:
    os.mkdir("pymesh_NEURITES")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURITES"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURITES"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuriteRawSkeleton(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the skeleton was generated
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :tinyint unsigned #the amount of segments the neurite was originally split into
    lagest_mesh_perc : float #the percentage of the entire mesh that the largest submesh makes up
     
    """
    
    
    key_source = ta3p100.Mesh() & ta3p100.Neurite() & ta3p100.CurrentSegmentation
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        print(str(key['segment_id']) +  ":")
        my_dict = (ta3p100.Mesh & ta3p100.Neurite.proj() & ta3p100.CurrentSegmentation
                           & key).fetch1()
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        
        
# Don't need these attributes      
#vertices=key["vertices"],
#                       triangles=new_key["triangles"],n_vertices=key["n_vertices"],
#                       n_triangles=key["n_triangles"])
        
        
        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        
        mesh = trimesh_io.Mesh(vertices=my_dict["vertices"], faces=my_dict["triangles"])
        count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                            mesh.edges_sparse,
                                                            directed=False,
                                                            return_labels=True)
        
        new_key["n_bodies"] = count
        values = np.array(labels)
        searchval = 0
        ii = np.where(values == searchval)[0]
        new_key["lagest_mesh_perc"] = len(ii)/len(labels)
        
        print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")
        
        
        
        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        meshfix = pymeshfix.MeshFix(my_dict["vertices"],my_dict["triangles"])
        meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
        print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")
        
        #print("Step 2: Writing Off File")
        start_time = time.time()
        #write the new mesh to off file
        path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
        print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
        
        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_fix_manifold(key)
        print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

        print(output_mesh[:-4])
              
        #send to be skeletonized
        start_time = time.time()
        return_value = cm.calcification(output_mesh[:-4])
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")
        
              
              
        #read in the skeleton files into an array
        bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            
        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")
        
              
        start_time = time.time()
        new_key["n_edges"] = len(bone_array)
        new_key["edges"] = bone_array
        #new_key["branches"] = []
        
        
        new_key["time_updated"]=str(datetime.datetime.now())
        #print(key)
        #if all goes well then write to database
        self.insert1(new_key,skip_duplicates=True)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
start = time.time()
NeuriteRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341351503:
# Step 1: Retrieving Mesh and removing error segments: 0.03591132164001465
# Step 2a: Getting the number of splits: 0.03012371063232422
# Step 2b: Pymesh shrinkwrapping: 0.46872401237487793
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12234663963317871
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9702105522155762
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351503_mls
# Step 5: Generating and reading Skeleton: 0.6728551387786865
# Step 6: Inserting dictionary: 0.022675037384033203
# Total time: 2.3240318298339844
#
#
#
# 648518346341351508:
# Step 1: Retrieving Mesh and removing error segments: 0.10586953163146973
# Step 2a: Getting the number of splits: 0.11849308013916016
# Step 2b: Pymesh shrinkwrapping: 5.600031614303589
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.9503569602966309
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.9175915718078613
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351508_mls
# Step 5: Generating and reading Skeleton: 3.0668303966522217
# Step 6: Inserting dictionary: 0.03762102127075195
# Total time: 11.799902200698853
#
#
#
# 648518346341351509:
# Step 1: Retrieving Mesh and removing error segments: 0.07895994186401367
# Step 2a: Getting the number of splits: 0.0693204402923584
# Step 2b: Pymesh shrinkwrapping: 1.3134031295776367
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2542684078216553
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2120246887207031
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351509_mls
# Step 5: Generating and reading Skeleton: 1.362048864364624
# Step 6: Inserting dictionary: 0.033596038818359375
# Total time: 4.3248207569122314
#
#
#
# 648518346341351512:
# Step 1: Retrieving Mesh and removing error segments: 0.10361766815185547
# Step 2a: Getting the number of splits: 0.10283041000366211
# Step 2b: Pymesh shrinkwrapping: 1.5787453651428223
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.45738649368286133
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.570718765258789
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351512_mls
# Step 5: Generating and reading Skeleton: 2.2186899185180664
# Step 6: Inserting dictionary: 0.03861689567565918
# Total time: 6.072211742401123
#
#
#
# 648518346341351514:
# Step 1: Retrieving Mesh and removing error segments: 0.08086085319519043
# Step 2a: Getting the number of splits: 0.08796024322509766
# Step 2b: Pymesh shrinkwrapping: 2.0554723739624023
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3063380718231201
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3303840160369873
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351514_mls
# Step 5: Generating and reading Skeleton: 1.8725018501281738
# Step 6: Inserting dictionary: 0.03531646728515625
# Total time: 5.770022392272949
#
#
#
# 648518346341351518:
# Step 1: Retrieving Mesh and removing error segments: 0.07807302474975586
# Step 2a: Getting the number of splits: 0.05307459831237793
# Step 2b: Pymesh shrinkwrapping: 0.9140563011169434
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15671849250793457
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1256115436553955
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351518_mls
# Step 5: Generating and reading Skeleton: 1.167893648147583
# Step 6: Inserting dictionary: 0.03608441352844238
# Total time: 3.5324599742889404
#
#
#
# 648518346341351523:
# Step 1: Retrieving Mesh and removing error segments: 0.049021244049072266
# Step 2a: Getting the number of splits: 0.0379791259765625
# Step 2b: Pymesh shrinkwrapping: 1.0051178932189941
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2347874641418457
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0340054035186768
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351523_mls
# Step 5: Generating and reading Skeleton: 0.9169561862945557
# Step 6: Inserting dictionary: 0.03009939193725586
# Total time: 3.308973550796509
#
#
#
# 648518346341351525:
# Step 1: Retrieving Mesh and removing error segments: 0.07072973251342773
# Step 2a: Getting the number of splits: 0.08392786979675293
# Step 2b: Pymesh shrinkwrapping: 2.833301544189453
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.42863035202026367
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4087779521942139
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351525_mls
# Step 5: Generating and reading Skeleton: 1.8214972019195557
# Step 6: Inserting dictionary: 0.033133745193481445
# Total time: 6.682368040084839
#
#
#
# 648518346341351531:
# Step 1: Retrieving Mesh and removing error segments: 0.10242772102355957
# Step 2a: Getting the number of splits: 0.06507611274719238
# Step 2b: Pymesh shrinkwrapping: 1.5119256973266602
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.25765347480773926
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.185002088546753
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351531_mls
# Step 5: Generating and reading Skeleton: 1.1675565242767334
# Step 6: Inserting dictionary: 0.030598163604736328
# Total time: 4.321423768997192
#
#
#
# 648518346341351545:
# Step 1: Retrieving Mesh and removing error segments: 0.06845879554748535
# Step 2a: Getting the number of splits: 0.03236961364746094
# Step 2b: Pymesh shrinkwrapping: 0.5808918476104736
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1369025707244873
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.971172571182251
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351545_mls
# Step 5: Generating and reading Skeleton: 0.808819055557251
# Step 6: Inserting dictionary: 0.032630205154418945
# Total time: 2.6332507133483887
#
#
#
# 648518346341351631:
# Step 1: Retrieving Mesh and removing error segments: 0.15909576416015625
# Step 2a: Getting the number of splits: 0.14902210235595703
# Step 2b: Pymesh shrinkwrapping: 7.574254751205444
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7073543071746826
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.079831123352051
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351631_mls
# Step 5: Generating and reading Skeleton: 4.028871536254883
# Step 6: Inserting dictionary: 0.04005837440490723
# Total time: 14.73999571800232
#
#
#
# 648518346341351638:
# Step 1: Retrieving Mesh and removing error segments: 0.11861371994018555
# Step 2a: Getting the number of splits: 0.045200347900390625
# Step 2b: Pymesh shrinkwrapping: 1.042494297027588
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.22858262062072754
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9878437519073486
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351638_mls
# Step 5: Generating and reading Skeleton: 0.9716911315917969
# Step 6: Inserting dictionary: 0.03437614440917969
# Total time: 3.430103063583374
#
#
#
# 648518346341351695:
# Step 1: Retrieving Mesh and removing error segments: 0.05217170715332031
# Step 2a: Getting the number of splits: 0.056844234466552734
# Step 2b: Pymesh shrinkwrapping: 1.0093026161193848
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.32305192947387695
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.290564775466919
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351695_mls
# Step 5: Generating and reading Skeleton: 1.4028129577636719
# Step 6: Inserting dictionary: 0.03537297248840332
# Total time: 4.171207427978516
#
#
#
# 648518346341351710:
# Step 1: Retrieving Mesh and removing error segments: 0.08558511734008789
# Step 2a: Getting the number of splits: 0.0791933536529541
# Step 2b: Pymesh shrinkwrapping: 1.9366788864135742
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.41042256355285645
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.219658613204956
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351710_mls
# Step 5: Generating and reading Skeleton: 1.5759024620056152
# Step 6: Inserting dictionary: 0.03918194770812988
# Total time: 5.348551034927368
#
#
#
# 648518346341351713:
# Step 1: Retrieving Mesh and removing error segments: 0.05560111999511719
# Step 2a: Getting the number of splits: 0.058542490005493164
# Step 2b: Pymesh shrinkwrapping: 0.9625575542449951
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3891901969909668
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1022601127624512
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351713_mls
# Step 5: Generating and reading Skeleton: 1.198307991027832
# Step 6: Inserting dictionary: 0.04110074043273926
# Total time: 3.809157609939575
#
#
#
# 648518346341351718:
# Step 1: Retrieving Mesh and removing error segments: 0.12877535820007324
# Step 2a: Getting the number of splits: 0.06885933876037598
# Step 2b: Pymesh shrinkwrapping: 2.761505603790283
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3630483150482178
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4282629489898682
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351718_mls
# Step 5: Generating and reading Skeleton: 1.6409687995910645
# Step 6: Inserting dictionary: 0.030195236206054688
# Total time: 6.4232017993927
#
#
#
# 648518346341351719:
# Step 1: Retrieving Mesh and removing error segments: 0.13849997520446777
# Step 2a: Getting the number of splits: 0.041261911392211914
# Step 2b: Pymesh shrinkwrapping: 0.6918621063232422
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2056412696838379
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0922482013702393
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351719_mls
# Step 5: Generating and reading Skeleton: 0.906757116317749
# Step 6: Inserting dictionary: 0.0308835506439209
# Total time: 3.1086392402648926
#
#
#
# 648518346341351722:
# Step 1: Retrieving Mesh and removing error segments: 0.1950376033782959
# Step 2a: Getting the number of splits: 0.08539009094238281
# Step 2b: Pymesh shrinkwrapping: 3.3300163745880127
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4969520568847656
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4565763473510742
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351722_mls
# Step 5: Generating and reading Skeleton: 2.3797731399536133
# Step 6: Inserting dictionary: 0.04290437698364258
# Total time: 7.988191604614258
#
#
#
# 648518346341351731:
# Step 1: Retrieving Mesh and removing error segments: 0.15801763534545898
# Step 2a: Getting the number of splits: 0.058565378189086914
# Step 2b: Pymesh shrinkwrapping: 0.8406052589416504
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.32712578773498535
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.124873161315918
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351731_mls
# Step 5: Generating and reading Skeleton: 1.1845521926879883
# Step 6: Inserting dictionary: 0.03507399559020996
# Total time: 3.7301809787750244
#
#
#
# 648518346341351733:
# Step 1: Retrieving Mesh and removing error segments: 0.1262364387512207
# Step 2a: Getting the number of splits: 0.04760599136352539
# Step 2b: Pymesh shrinkwrapping: 1.258868932723999
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2783958911895752
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0804104804992676
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351733_mls
# Step 5: Generating and reading Skeleton: 1.0243470668792725
# Step 6: Inserting dictionary: 0.0343780517578125
# Total time: 3.851330518722534
#
#
#
# 648518346341351757:
# Step 1: Retrieving Mesh and removing error segments: 0.12557721138000488
# Step 2a: Getting the number of splits: 0.05528855323791504
# Step 2b: Pymesh shrinkwrapping: 0.9391546249389648
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.18352293968200684
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1561541557312012
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351757_mls
# Step 5: Generating and reading Skeleton: 1.3675134181976318
# Step 6: Inserting dictionary: 0.03765583038330078
# Total time: 3.8660149574279785
#
#
#
# 648518346341351759:
# Step 1: Retrieving Mesh and removing error segments: 0.1445612907409668
# Step 2a: Getting the number of splits: 0.057804107666015625
# Step 2b: Pymesh shrinkwrapping: 1.4512372016906738
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.33324599266052246
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2590546607971191
# /notebooks/13_Skeletons/pymesh_NEURITES/neuron_648518346341351759_mls
# Step 5: Generating and reading Skeleton: 1.2756168842315674
# Step 6: Inserting dictionary: 0.03702664375305176
# Total time: 4.559876203536987
#
#
#
# 648518346341351764:
# Step 1: Retrieving Mesh and removing error segments: 0.15076279640197754
# Step 2a: Getting the number of splits: 0.08901453018188477
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f8cabc44febf> in <module>
#       1 start = time.time()
# ----> 2 NeuriteRawSkeleton.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-9-84236032e322> in make(self, key)
#      56         #pass the vertices and faces to pymeshfix to become watertight
#      57         meshfix = pymeshfix.MeshFix(my_dict["vertices"],my_dict["triangles"])
# ---> 58         meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
#      59         print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")
#      60
#
# /usr/local/lib/python3.6/dist-packages/pymeshfix/meshfix.py in repair(self, verbose, joincomp, remove_smallest_components)
#     136         self.v, self.f = _meshfix.clean_from_arrays(self.v, self.f,
#     137                                                     verbose, joincomp,
# --> 138                                                     remove_smallest_components)
#     139
#     140     def write(self, filename, binary=True):
#
# pymeshfix/cython/_meshfix.pyx in pymeshfix._meshfix.clean_from_arrays()
#
# pymeshfix/cython/_meshfix.pyx in pymeshfix._meshfix.PyTMesh.return_arrays()
#
# ValueError: Buffer dtype mismatch, expected 'int' but got Python object

# %%
#(schema.jobs & "table_name='__neurite_skeletons'").delete()
#ta3p100.NeuriteSkeletons()#.delete()
