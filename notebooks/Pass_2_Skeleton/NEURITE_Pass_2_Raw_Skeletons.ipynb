# %%
"""
Table that will run the skeletons on the full Neurite meshes

1) No longer filters the mesh for only connectedd parts
2) Runs pymeshfix (don't need to do that anymore)
----------------------------------
3) Runs meshlab server script for 
a) Close Holes
b) Select Border
c) Delete Border Vertices
d) Close Holes
e) Remove Duplicate Vertices
f) Remove Zero Area Faces
g) Remove Duplicate Vertices

-- repeat a couple of times --
----------------------------------
4) Run skeletonization

Extra Folders
test_error
pymesh_NEURITES
pymesh_neurons
temp
temp_pymesh
temp_meshlab

"""
# Out:
# "\nTable that will run the skeletons on the full Neurite meshes\n\n1) No longer filters the mesh for only connectedd parts\n2) Runs pymeshfix (don't need to do that anymore)\n----------------------------------\n3) Runs meshlab server script for \na) Close Holes\nb) Select Border\nc) Delete Border Vertices\nd) Close Holes\ne) Remove Duplicate Vertices\nf) Remove Zero Area Faces\ng) Remove Duplicate Vertices\n\n-- repeat a couple of times --\n----------------------------------\n4) Run skeletonization\n\nExtra Folders\ntest_error\npymesh_NEURITES\npymesh_neurons\ntemp\ntemp_pymesh\ntemp_meshlab\n\n"

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')

# %%
pinky.NeuriteRawSkeleton()
# Out:
# *segmentation  *segment_id    n_edges     edges      n_bodies     lagest_mesh_pe
# +------------+ +------------+ +---------+ +--------+ +----------+ +------------+
# 3              64851834634135 7           =BLOB=     5            0.999109
# 3              64851834634135 4           =BLOB=     1            1.0
# 3              64851834634135 21          =BLOB=     9            0.998368
# 3              64851834634135 7           =BLOB=     4            0.999239
# 3              64851834634135 18          =BLOB=     2            0.999757
# 3              64851834634135 9           =BLOB=     9            0.997685
# 3              64851834634135 9           =BLOB=     4            0.997558
# 3              64851834634135 5           =BLOB=     2            0.998364
# 3              64851834634135 19          =BLOB=     1            1.0
# 3              64851834634135 19          =BLOB=     7            0.999126
# 3              64851834634135 9           =BLOB=     9            0.998198
# 3              64851834634135 3           =BLOB=     4            0.994745
# 3              64851834634135 42          =BLOB=     8            0.999042
# 3              64851834634135 7           =BLOB=     3            0.998883
# 3              64851834634135 3           =BLOB=     7            0.99726
# 3              64851834634135 3           =BLOB=     5            0.991785
# 3              64851834634135 3           =BLOB=     4            0.999333
# 3              64851834634135 17          =BLOB=     9            0.996323
# 3              64851834634135 9           =BLOB=     4            0.997493
# 3              64851834634135 19          =BLOB=     13           0.998061
#    ...
#  (30070 tuples)

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURITES")) == False:
    os.mkdir("pymesh_NEURITES")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURITES"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    print(file_loc)
    print(path_and_filename)
    print(len(vertices))
    print(len(triangles))
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURITES"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuriteRawSkeleton(dj.Computed):
    definition="""  
    -> pinky.Mesh
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :tinyint unsigned #the amount of segments the neurite was originally split into
    lagest_mesh_perc : float #the percentage of the entire mesh that the largest submesh makes up
    """
    
    
    key_source = pinky.Mesh() & pinky.Neurite() & pinky.CurrentSegmentation

    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        print(str(key['segment_id']) +  ":")
        my_dict = (pinky.Mesh & pinky.Neurite.proj() & pinky.CurrentSegmentation
                           & key).fetch1()
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        
        vertices = my_dict["vertices"]
        triangles = my_dict["triangles"]

        #print("Skipping Step 2 with finding mesh pieces and running pymeshfix")
        
        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        
        mesh = trimesh_io.Mesh(vertices=my_dict["vertices"], faces=my_dict["triangles"])
        count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                            mesh.edges_sparse,
                                                            directed=False,
                                                            return_labels=True)
        
        new_key["n_bodies"] = count
        values = np.array(labels)
        searchval = 0
        ii = np.where(values == searchval)[0]
        new_key["lagest_mesh_perc"] = len(ii)/len(labels)
        
        print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")
        
              
        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        meshfix = pymeshfix.MeshFix(my_dict["vertices"],my_dict["triangles"])
        meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
        print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")
        
        #print("Step 2: Writing Off File")
        vertices = meshfix.v
        triangles = meshfix.f
        
        start_time = time.time()
        #write the new mesh to off file
        path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),vertices,triangles)
        print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")
        
        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_fix_manifold(key)
        print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

        print(output_mesh[:-4])
              
        #send to be skeletonized
        start_time = time.time()
        return_value = cm.calcification(output_mesh[:-4])
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")
        
              
              
        #read in the skeleton files into an array
        bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            
        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")
        
              
        start_time = time.time()
        new_key["n_edges"] = len(bone_array)
        new_key["edges"] = bone_array
        #new_key["branches"] = []
        
        #print(key)
        #if all goes well then write to database
        self.insert1(new_key,skip_duplicates=True)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
start = time.time()
NeuriteRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346341351518:
# Step 1: Retrieving Mesh and removing error segments: 0.02868056297302246
# Step 2a: Getting the number of splits: 0.02557969093322754
# Step 2: Pymesh shrinkwrapping: 0.6879787445068359
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351518
# 20187
# 40370
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.17165303230285645
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.947991132736206
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351518_mls
# Step 5: Generating and reading Skeleton: 0.9289419651031494
# Step 6: Inserting dictionary: 0.022121191024780273
# Total time: 2.8138208389282227
#
#
#
# 648518346341351523:
# Step 1: Retrieving Mesh and removing error segments: 0.025869369506835938
# Step 2a: Getting the number of splits: 0.02231764793395996
# Step 2: Pymesh shrinkwrapping: 0.8397843837738037
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351523
# 15560
# 31120
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12836527824401855
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8024158477783203
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351523_mls
# Step 5: Generating and reading Skeleton: 0.6569371223449707
# Step 6: Inserting dictionary: 0.022542238235473633
# Total time: 2.499271869659424
#
#
#
# 648518346341351525:
# Step 1: Retrieving Mesh and removing error segments: 0.04445219039916992
# Step 2a: Getting the number of splits: 0.05352520942687988
# Step 2: Pymesh shrinkwrapping: 1.7874171733856201
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351525
# 45905
# 91842
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3810751438140869
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.315047025680542
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351525_mls
# Step 5: Generating and reading Skeleton: 2.278132677078247
# Step 6: Inserting dictionary: 0.02703070640563965
# Total time: 5.887577533721924
#
#
#
# 648518346341351526:
# Step 1: Retrieving Mesh and removing error segments: 0.02611255645751953
# Step 2a: Getting the number of splits: 0.02436542510986328
# Step 2: Pymesh shrinkwrapping: 0.5154447555541992
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351526
# 17080
# 34160
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.13836336135864258
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7920608520507812
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351526_mls
# Step 5: Generating and reading Skeleton: 0.7584340572357178
# Step 6: Inserting dictionary: 0.020885229110717773
# Total time: 2.276665449142456
#
#
#
# 648518346341351545:
# Step 1: Retrieving Mesh and removing error segments: 0.021232128143310547
# Step 2a: Getting the number of splits: 0.017518281936645508
# Step 2: Pymesh shrinkwrapping: 0.373126745223999
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351545
# 12316
# 24632
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.14208483695983887
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7936484813690186
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351545_mls
# Step 5: Generating and reading Skeleton: 0.5813424587249756
# Step 6: Inserting dictionary: 0.02147674560546875
# Total time: 1.951235055923462
#
#
#
# 648518346341351635:
# Step 1: Retrieving Mesh and removing error segments: 0.046575069427490234
# Step 2a: Getting the number of splits: 0.04361701011657715
# Step 2: Pymesh shrinkwrapping: 1.830681324005127
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351635
# 33152
# 66308
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.28708910942077637
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0841071605682373
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351635_mls
# Step 5: Generating and reading Skeleton: 1.5992534160614014
# Step 6: Inserting dictionary: 0.024772167205810547
# Total time: 4.917343854904175
#
#
#
# 648518346341351641:
# Step 1: Retrieving Mesh and removing error segments: 0.03446531295776367
# Step 2a: Getting the number of splits: 0.027019739151000977
# Step 2: Pymesh shrinkwrapping: 0.556347131729126
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351641
# 18380
# 36760
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.16395020484924316
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8197312355041504
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351641_mls
# Step 5: Generating and reading Skeleton: 0.8026213645935059
# Step 6: Inserting dictionary: 0.0229642391204834
# Total time: 2.4284632205963135
#
#
#
# 648518346341351675:
# Step 1: Retrieving Mesh and removing error segments: 0.0265655517578125
# Step 2a: Getting the number of splits: 0.02181553840637207
# Step 2: Pymesh shrinkwrapping: 0.5129666328430176
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351675
# 15247
# 30494
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.16915273666381836
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.768366813659668
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351675_mls
# Step 5: Generating and reading Skeleton: 0.7377798557281494
# Step 6: Inserting dictionary: 0.027858257293701172
# Total time: 2.265507698059082
#
#
#
# 648518346341351695:
# Step 1: Retrieving Mesh and removing error segments: 0.03804922103881836
# Step 2a: Getting the number of splits: 0.042183637619018555
# Step 2: Pymesh shrinkwrapping: 0.8533518314361572
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351695
# 26027
# 52058
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2163069248199463
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0200998783111572
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351695_mls
# Step 5: Generating and reading Skeleton: 1.161151647567749
# Step 6: Inserting dictionary: 0.026402950286865234
# Total time: 3.358560562133789
#
#
#
# 648518346341351710:
# Step 1: Retrieving Mesh and removing error segments: 0.038283348083496094
# Step 2a: Getting the number of splits: 0.03760337829589844
# Step 2: Pymesh shrinkwrapping: 1.040978193283081
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351710
# 29699
# 59422
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.25327396392822266
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0208585262298584
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351710_mls
# Step 5: Generating and reading Skeleton: 1.5110292434692383
# Step 6: Inserting dictionary: 0.026380300521850586
# Total time: 3.9296164512634277
#
#
#
# 648518346341351718:
# Step 1: Retrieving Mesh and removing error segments: 0.03044605255126953
# Step 2a: Getting the number of splits: 0.03759884834289551
# Step 2: Pymesh shrinkwrapping: 2.6158690452575684
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351718
# 28610
# 57228
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2862122058868408
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.045821189880371
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351718_mls
# Step 5: Generating and reading Skeleton: 1.353426456451416
# Step 6: Inserting dictionary: 0.025620222091674805
# Total time: 5.39656925201416
#
#
#
# 648518346341351719:
# Step 1: Retrieving Mesh and removing error segments: 0.02545905113220215
# Step 2a: Getting the number of splits: 0.023175477981567383
# Step 2: Pymesh shrinkwrapping: 0.5220916271209717
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351719
# 15521
# 31054
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.16920137405395508
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.742905855178833
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351719_mls
# Step 5: Generating and reading Skeleton: 0.7176716327667236
# Step 6: Inserting dictionary: 0.02437424659729004
# Total time: 2.226210117340088
#
#
#
# 648518346341351722:
# Step 1: Retrieving Mesh and removing error segments: 0.04267692565917969
# Step 2a: Getting the number of splits: 0.052535295486450195
# Step 2: Pymesh shrinkwrapping: 2.8165032863616943
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351722
# 42716
# 85436
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.36887240409851074
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3220677375793457
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351722_mls
# Step 5: Generating and reading Skeleton: 2.1738860607147217
# Step 6: Inserting dictionary: 0.027882814407348633
# Total time: 6.805838584899902
#
#
#
# 648518346341351731:
# Step 1: Retrieving Mesh and removing error segments: 0.03048253059387207
# Step 2a: Getting the number of splits: 0.034511566162109375
# Step 2: Pymesh shrinkwrapping: 0.6413419246673584
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351731
# 18774
# 37548
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2027754783630371
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7947862148284912
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351731_mls
# Step 5: Generating and reading Skeleton: 0.8412117958068848
# Step 6: Inserting dictionary: 0.023793697357177734
# Total time: 2.569817066192627
#
#
#
# 648518346341351733:
# Step 1: Retrieving Mesh and removing error segments: 0.0262758731842041
# Step 2a: Getting the number of splits: 0.024472951889038086
# Step 2: Pymesh shrinkwrapping: 1.0870795249938965
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351733
# 18574
# 37148
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15946173667907715
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9478890895843506
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351733_mls
# Step 5: Generating and reading Skeleton: 0.8630340099334717
# Step 6: Inserting dictionary: 0.026460886001586914
# Total time: 3.1361000537872314
#
#
#
# 648518346341351755:
# Step 1: Retrieving Mesh and removing error segments: 0.029424667358398438
# Step 2a: Getting the number of splits: 0.01993250846862793
# Step 2: Pymesh shrinkwrapping: 0.48569798469543457
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351755
# 14721
# 29478
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.12704825401306152
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7805180549621582
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351755_mls
# Step 5: Generating and reading Skeleton: 0.717853307723999
# Step 6: Inserting dictionary: 0.02678966522216797
# Total time: 2.1883087158203125
#
#
#
# 648518346341351757:
# Step 1: Retrieving Mesh and removing error segments: 0.028575658798217773
# Step 2a: Getting the number of splits: 0.02859044075012207
# Step 2: Pymesh shrinkwrapping: 0.7882912158966064
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351757
# 22477
# 44950
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.23166918754577637
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9447054862976074
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351757_mls
# Step 5: Generating and reading Skeleton: 1.0289418697357178
# Step 6: Inserting dictionary: 0.025809288024902344
# Total time: 3.0774827003479004
#
#
#
# 648518346341351759:
# Step 1: Retrieving Mesh and removing error segments: 0.03285694122314453
# Step 2a: Getting the number of splits: 0.022397756576538086
# Step 2: Pymesh shrinkwrapping: 1.3103783130645752
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351759
# 24103
# 48210
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.21027731895446777
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9799661636352539
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351759_mls
# Step 5: Generating and reading Skeleton: 1.0535948276519775
# Step 6: Inserting dictionary: 0.025812864303588867
# Total time: 3.637014865875244
#
#
#
# 648518346341351764:
# Step 1: Retrieving Mesh and removing error segments: 0.03295397758483887
# Step 2a: Getting the number of splits: 0.04082632064819336
# Step 2: Pymesh shrinkwrapping: 4.173064231872559
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351764
# 34090
# 68184
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3274838924407959
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1773314476013184
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351764_mls
# Step 5: Generating and reading Skeleton: 1.6544742584228516
# Step 6: Inserting dictionary: 0.029941082000732422
# Total time: 7.437289714813232
#
#
#
# 648518346341351767:
# Step 1: Retrieving Mesh and removing error segments: 0.0445713996887207
# Step 2a: Getting the number of splits: 0.06175088882446289
# Step 2: Pymesh shrinkwrapping: 2.5931854248046875
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351767
# 43796
# 87638
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3836171627044678
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4424517154693604
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351767_mls
# Step 5: Generating and reading Skeleton: 2.225278615951538
# Step 6: Inserting dictionary: 0.03071308135986328
# Total time: 6.782695531845093
#
#
#
# 648518346341351768:
# Step 1: Retrieving Mesh and removing error segments: 0.029277324676513672
# Step 2a: Getting the number of splits: 0.02672290802001953
# Step 2: Pymesh shrinkwrapping: 0.7817933559417725
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351768
# 23787
# 47590
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.19853925704956055
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9728889465332031
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351768_mls
# Step 5: Generating and reading Skeleton: 1.1761155128479004
# Step 6: Inserting dictionary: 0.022454023361206055
# Total time: 3.2091636657714844
#
#
#
# 648518346341351770:
# Step 1: Retrieving Mesh and removing error segments: 0.026623249053955078
# Step 2a: Getting the number of splits: 0.017734050750732422
# Step 2: Pymesh shrinkwrapping: 0.4038097858428955
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351770
# 12015
# 24026
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.14063668251037598
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7963800430297852
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351770_mls
# Step 5: Generating and reading Skeleton: 0.5828738212585449
# Step 6: Inserting dictionary: 0.024988889694213867
# Total time: 1.9949414730072021
#
#
#
# 648518346341351775:
# Step 1: Retrieving Mesh and removing error segments: 0.039194345474243164
# Step 2a: Getting the number of splits: 0.041570186614990234
# Step 2: Pymesh shrinkwrapping: 1.3354554176330566
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351775
# 25467
# 50930
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.21528935432434082
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9968471527099609
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351775_mls
# Step 5: Generating and reading Skeleton: 1.2562463283538818
# Step 6: Inserting dictionary: 0.02628636360168457
# Total time: 3.9121193885803223
#
#
#
# 648518346341351776:
# Step 1: Retrieving Mesh and removing error segments: 0.02357006072998047
# Step 2a: Getting the number of splits: 0.01320195198059082
# Step 2: Pymesh shrinkwrapping: 0.5300161838531494
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351776
# 10354
# 20708
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0857844352722168
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7843012809753418
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351776_mls
# Step 5: Generating and reading Skeleton: 0.4607563018798828
# Step 6: Inserting dictionary: 0.026283740997314453
# Total time: 1.9250166416168213
#
#
#
# 648518346341351785:
# Step 1: Retrieving Mesh and removing error segments: 0.02806234359741211
# Step 2a: Getting the number of splits: 0.022276639938354492
# Step 2: Pymesh shrinkwrapping: 0.8705875873565674
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351785
# 16844
# 33700
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.14189839363098145
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7912077903747559
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351785_mls
# Step 5: Generating and reading Skeleton: 0.9201128482818604
# Step 6: Inserting dictionary: 0.026170969009399414
# Total time: 2.8018314838409424
#
#
#
# 648518346341351802:
# Step 1: Retrieving Mesh and removing error segments: 0.03091597557067871
# Step 2a: Getting the number of splits: 0.022571563720703125
# Step 2: Pymesh shrinkwrapping: 0.7051804065704346
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351802
# 23523
# 47046
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1938612461090088
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.879939079284668
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351802_mls
# Step 5: Generating and reading Skeleton: 1.037628412246704
# Step 6: Inserting dictionary: 0.026049137115478516
# Total time: 2.897031307220459
#
#
#
# 648518346341351806:
# Step 1: Retrieving Mesh and removing error segments: 0.0369107723236084
# Step 2a: Getting the number of splits: 0.04399561882019043
# Step 2: Pymesh shrinkwrapping: 1.266303300857544
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351806
# 34269
# 68558
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.27715253829956055
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.185060739517212
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351806_mls
# Step 5: Generating and reading Skeleton: 1.6206088066101074
# Step 6: Inserting dictionary: 0.028965473175048828
# Total time: 4.460454940795898
#
#
#
# 648518346341351838:
# Step 1: Retrieving Mesh and removing error segments: 0.037261009216308594
# Step 2a: Getting the number of splits: 0.0331573486328125
# Step 2: Pymesh shrinkwrapping: 0.9728250503540039
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351838
# 28987
# 57982
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2422025203704834
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9943206310272217
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351838_mls
# Step 5: Generating and reading Skeleton: 1.295741081237793
# Step 6: Inserting dictionary: 0.0263674259185791
# Total time: 3.6031036376953125
#
#
#
# 648518346341351894:
# Step 1: Retrieving Mesh and removing error segments: 0.02672719955444336
# Step 2a: Getting the number of splits: 0.018871545791625977
# Step 2: Pymesh shrinkwrapping: 0.3854029178619385
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351894
# 13100
# 26196
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1137998104095459
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7139475345611572
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351894_mls
# Step 5: Generating and reading Skeleton: 0.5971806049346924
# Step 6: Inserting dictionary: 0.025029659271240234
# Total time: 1.8820044994354248
#
#
#
# 648518346341351896:
# Step 1: Retrieving Mesh and removing error segments: 0.028111696243286133
# Step 2a: Getting the number of splits: 0.0346989631652832
# Step 2: Pymesh shrinkwrapping: 0.9270398616790771
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351896
# 28386
# 56780
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.23933649063110352
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.974510908126831
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351896_mls
# Step 5: Generating and reading Skeleton: 1.2246012687683105
# Step 6: Inserting dictionary: 0.027495384216308594
# Total time: 3.4569289684295654
#
#
#
# 648518346341351900:
# Step 1: Retrieving Mesh and removing error segments: 0.03628897666931152
# Step 2a: Getting the number of splits: 0.03205513954162598
# Step 2: Pymesh shrinkwrapping: 1.1069812774658203
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351900
# 33225
# 66450
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.29913806915283203
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2163596153259277
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351900_mls
# Step 5: Generating and reading Skeleton: 1.54998779296875
# Step 6: Inserting dictionary: 0.02420783042907715
# Total time: 4.266049861907959
#
#
#
# 648518346341351901:
# Step 1: Retrieving Mesh and removing error segments: 0.03511643409729004
# Step 2a: Getting the number of splits: 0.03361320495605469
# Step 2: Pymesh shrinkwrapping: 0.8140683174133301
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351901
# 26394
# 52784
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.22816991806030273
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.024137258529663
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351901_mls
# Step 5: Generating and reading Skeleton: 1.282332420349121
# Step 6: Inserting dictionary: 0.02343010902404785
# Total time: 3.4421260356903076
#
#
#
# 648518346341351904:
# Step 1: Retrieving Mesh and removing error segments: 0.032155513763427734
# Step 2a: Getting the number of splits: 0.03130626678466797
# Step 2: Pymesh shrinkwrapping: 1.941990852355957
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351904
# 24561
# 49126
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2007288932800293
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0339477062225342
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351904_mls
# Step 5: Generating and reading Skeleton: 1.2370975017547607
# Step 6: Inserting dictionary: 0.027550697326660156
# Total time: 4.5056140422821045
#
#
#
# 648518346341351978:
# Step 1: Retrieving Mesh and removing error segments: 0.03787994384765625
# Step 2a: Getting the number of splits: 0.05063176155090332
# Step 2: Pymesh shrinkwrapping: 1.4331560134887695
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351978
# 40816
# 81628
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.34563326835632324
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2117645740509033
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351978_mls
# Step 5: Generating and reading Skeleton: 1.9303557872772217
# Step 6: Inserting dictionary: 0.025353193283081055
# Total time: 5.035775184631348
#
#
#
# 648518346341351981:
# Step 1: Retrieving Mesh and removing error segments: 0.026621103286743164
# Step 2a: Getting the number of splits: 0.01416468620300293
# Step 2: Pymesh shrinkwrapping: 0.34052252769470215
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351981
# 11072
# 22140
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10027360916137695
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.717118501663208
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351981_mls
# Step 5: Generating and reading Skeleton: 0.5307626724243164
# Step 6: Inserting dictionary: 0.02883124351501465
# Total time: 1.7598974704742432
#
#
#
# 648518346341351983:
# Step 1: Retrieving Mesh and removing error segments: 0.025000810623168945
# Step 2a: Getting the number of splits: 0.024803638458251953
# Step 2: Pymesh shrinkwrapping: 0.9509015083312988
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351983
# 28794
# 57596
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2398667335510254
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0136311054229736
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351983_mls
# Step 5: Generating and reading Skeleton: 1.329077959060669
# Step 6: Inserting dictionary: 0.029207229614257812
# Total time: 3.6132373809814453
#
#
#
# 648518346341351984:
# Step 1: Retrieving Mesh and removing error segments: 0.03444528579711914
# Step 2a: Getting the number of splits: 0.03603959083557129
# Step 2: Pymesh shrinkwrapping: 1.8700478076934814
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351984
# 32566
# 65136
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2929205894470215
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0400826930999756
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351984_mls
# Step 5: Generating and reading Skeleton: 1.4861478805541992
# Step 6: Inserting dictionary: 0.02260732650756836
# Total time: 4.783278226852417
#
#
#
# 648518346341351986:
# Step 1: Retrieving Mesh and removing error segments: 0.03384590148925781
# Step 2a: Getting the number of splits: 0.03495430946350098
# Step 2: Pymesh shrinkwrapping: 1.8400847911834717
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351986
# 30438
# 60872
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2744920253753662
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1102015972137451
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351986_mls
# Step 5: Generating and reading Skeleton: 1.5009150505065918
# Step 6: Inserting dictionary: 0.024730920791625977
# Total time: 4.820821762084961
#
#
#
# 648518346341351988:
# Step 1: Retrieving Mesh and removing error segments: 0.03136181831359863
# Step 2a: Getting the number of splits: 0.03975534439086914
# Step 2: Pymesh shrinkwrapping: 2.3787078857421875
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351988
# 36688
# 73416
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2977941036224365
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1406712532043457
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351988_mls
# Step 5: Generating and reading Skeleton: 1.818315029144287
# Step 6: Inserting dictionary: 0.023023605346679688
# Total time: 5.730586290359497
#
#
#
# 648518346341351990:
# Step 1: Retrieving Mesh and removing error segments: 0.026358366012573242
# Step 2a: Getting the number of splits: 0.021811246871948242
# Step 2: Pymesh shrinkwrapping: 0.8691041469573975
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351990
# 17470
# 34948
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.14756417274475098
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8137917518615723
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351990_mls
# Step 5: Generating and reading Skeleton: 0.7615067958831787
# Step 6: Inserting dictionary: 0.02726149559020996
# Total time: 2.668445348739624
#
#
#
# 648518346341351995:
# Step 1: Retrieving Mesh and removing error segments: 0.0413823127746582
# Step 2a: Getting the number of splits: 0.04980659484863281
# Step 2: Pymesh shrinkwrapping: 2.109206438064575
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351995
# 50734
# 101480
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.45539093017578125
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3840653896331787
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351995_mls
# Step 5: Generating and reading Skeleton: 2.579928398132324
# Step 6: Inserting dictionary: 0.02219676971435547
# Total time: 6.643346309661865
#
#
#
# 648518346341351996:
# Step 1: Retrieving Mesh and removing error segments: 0.034353017807006836
# Step 2a: Getting the number of splits: 0.037950992584228516
# Step 2: Pymesh shrinkwrapping: 1.438133955001831
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351996
# 40218
# 80444
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3478052616119385
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3124668598175049
# /notebooks/Skeleton_Pass_2/pymesh_NEURITES/neuron_648518346341351996_mls
# Step 5: Generating and reading Skeleton: 1.9139268398284912
# Step 6: Inserting dictionary: 0.024445772171020508
# Total time: 5.110166788101196
#
#
#
# 648518346341351998:
# Step 1: Retrieving Mesh and removing error segments: 0.03854990005493164
# Step 2a: Getting the number of splits: 0.03891158103942871
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f8cabc44febf> in <module>
#       1 start = time.time()
# ----> 2 NeuriteRawSkeleton.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-11-f0d5235c5577> in make(self, key)
#      50         #pass the vertices and faces to pymeshfix to become watertight
#      51         meshfix = pymeshfix.MeshFix(my_dict["vertices"],my_dict["triangles"])
# ---> 52         meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
#      53         print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")
#      54
#
# /usr/local/lib/python3.6/dist-packages/pymeshfix/meshfix.py in repair(self, verbose, joincomp, remove_smallest_components)
#     136         self.v, self.f = _meshfix.clean_from_arrays(self.v, self.f,
#     137                                                     verbose, joincomp,
# --> 138                                                     remove_smallest_components)
#     139
#     140     def write(self, filename, binary=True):
#
# pymeshfix/cython/_meshfix.pyx in pymeshfix._meshfix.clean_from_arrays()
#
# pymeshfix/cython/_meshfix.pyx in pymeshfix._meshfix.PyTMesh.return_arrays()
#
# ValueError: Buffer dtype mismatch, expected 'int' but got Python object

# %%
#(schema.jobs & "table_name='__neurite_skeletons'").delete()
#ta3p100.NeuriteSkeletons()#.delete()
