# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')
pinky_nda = dj.create_virtual_module('pinky_nda','microns_pinky_nda')
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
(pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634135 111754         222198         =BLOB=     =BLOB=
# 3              64851834634135 169648         336849         =BLOB=     =BLOB=
# 3              64851834634135 131505         261279         =BLOB=     =BLOB=
# 3              64851834634135 59818          118694         =BLOB=     =BLOB=
# 3              64851834634135 908546         1806745        =BLOB=     =BLOB=
# 3              64851834634135 248717         495526         =BLOB=     =BLOB=
# 3              64851834634136 278231         553936         =BLOB=     =BLOB=
#    ...
#  (841 tuples)

# %%
@schema
class OrphanStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = (pinky.Mesh() & "segmentation=3") - pinky.AllenSoma & ( pinky_nda.Spike() & "segmentation=3") - pinky.Neurite.proj()
    
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
OrphanStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346341353058**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 12 pieces found after size threshold
# max_index = 0
# max_face_len = 220826
# Total time for Mesh Cleansing: 4.47838020324707
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9938253269606387% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341353574**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 118 pieces after mesh split
# There were 21 pieces found after size threshold
# max_index = 0
# max_face_len = 334417
# Total time for Mesh Cleansing: 6.1266865730285645
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9927801477813502% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341354313**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 76 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 260864
# Total time for Mesh Cleansing: 0.41289401054382324
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984116595669763% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341355198**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 30 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 118492
# Total time for Mesh Cleansing: 1.4732847213745117
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9982981448093416% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341356256**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 478 pieces after mesh split
# There were 13 pieces found after size threshold
# max_index = 0
# max_face_len = 1803313
# Total time for Mesh Cleansing: 44.19792103767395
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9981004513641936% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341359123**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 45 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 495216
# Total time for Mesh Cleansing: 6.208472013473511
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993744021504422% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341360739**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 109 pieces after mesh split
# There were 5 pieces found after size threshold
# max_index = 0
# max_face_len = 552784
# Total time for Mesh Cleansing: 8.098695278167725
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979203373674937% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362034**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 7 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 30438
# Total time for Mesh Cleansing: 0.48064661026000977
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9925003260727795% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341363182**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 36 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 229830
# Total time for Mesh Cleansing: 0.2864542007446289
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992174253293336% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341365659**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 11 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 143104
# Total time for Mesh Cleansing: 0.23284244537353516
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997065932684113% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341366757**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 159 pieces after mesh split
# There were 10 pieces found after size threshold
# max_index = 0
# max_face_len = 431780
# Total time for Mesh Cleansing: 6.663175582885742
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.995233353616935% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341368678**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 118 pieces after mesh split
# There were 18 pieces found after size threshold
# max_index = 0
# max_face_len = 351177
# Total time for Mesh Cleansing: 12.599911212921143
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9950696622718657% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341373380**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 78 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 389059
# Total time for Mesh Cleansing: 6.456868886947632
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989985851806014% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341374333**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 64 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 243847
# Total time for Mesh Cleansing: 4.2778260707855225
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9973496390519233% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341379591**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 113 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 881070
# Total time for Mesh Cleansing: 13.295619010925293
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990361937590712% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341383525**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 43 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 228888
# Total time for Mesh Cleansing: 4.188326358795166
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989089544292086% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341388112**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 104 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 637198
# Total time for Mesh Cleansing: 12.38554835319519
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989120415368119% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341398502**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 59 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 277344
# Total time for Mesh Cleansing: 5.954651832580566
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9984591679506933% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399743**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 255 pieces after mesh split
# There were 26 pieces found after size threshold
# max_index = 0
# max_face_len = 468092
# Total time for Mesh Cleansing: 25.522553205490112
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9923847321511859% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341410553**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 79 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 320260
# Total time for Mesh Cleansing: 7.430671215057373
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9979465223311802% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342790849**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 71 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 226742
# Total time for Mesh Cleansing: 4.94238805770874
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9974485531536763% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342794090**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 30 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 159960
# Total time for Mesh Cleansing: 0.371920108795166
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991629917423513% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797936**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 26 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 268460
# Total time for Mesh Cleansing: 0.6057813167572021
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995904233533157% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797993**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 52 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 380168
# Total time for Mesh Cleansing: 8.15951132774353
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992430136467818% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342800590**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 76 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 388282
# Total time for Mesh Cleansing: 10.486751794815063
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9897729763901564% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342804367**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 59 pieces after mesh split
# There were 6 pieces found after size threshold
# max_index = 0
# max_face_len = 229320
# Total time for Mesh Cleansing: 5.694897174835205
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9971648722453168% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342806927**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 538 pieces after mesh split
# There were 139 pieces found after size threshold
# max_index = 0
# max_face_len = 816000
# Total time for Mesh Cleansing: 186.53408098220825
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9845374239160293% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346342806927_30_main_and_child_meshes_array.npz
#  face length 816000 using optimized facets with 3 neighbors
# Filtering edges by size finished: 23.734032154083252, facet # = 38640
# Filtering by convexity and getting centers took: 28.24958562850952, facet # = 11506
# Finished facets for main mesh: 53.94258737564087 with facet length = 11506
# Finished 11506 facets for main mesh: 53.942822217941284
# Filtering edges by size finished: 0.03872323036193848, facet # = 155
# Filtering by convexity and getting centers took: 0.06332850456237793, facet # = 46
# Total time for facets: 54.050628423690796
# Zero faceted faces = []
# Starting Child 0
# 46 11506
# Done distance matrix: 0.025624990463256836
# Done Generating final pairs: 0.06352353096008301
# best_stitch_pair = [   9 2635]
# best_stitch_pair_size = 85547.14812439118
# best_stitch_pair_distance = 1978.5079825714931
# best_stitch_pair_size_ratio = 0.3296739457069262
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [9, 2635]}
# ---Stitching child 0 with pair: [9, 2635]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 109831, starting edge 2nd facet= 408283,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004129886627197266
# returned from stitch mesh: 0.6232039928436279
# Finished stitching child 0 : 0.7499680519104004
# ***************Finished big stitching iteration: 0.9704771041870117***************
# All children have been processed
# total_stitch_processing_time = 0.9706335067749023
# Total time for restitching = 0.9741241931915283
# missed_children = []
# Whole stitching function complete: 244.46156787872314
#
#
#
# *****Running Neuron Stitcher for 648518346341355736**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 45 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 373230
# Total time for Mesh Cleansing: 1.1143715381622314
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992022017091088% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341357933**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 29 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 192990
# Total time for Mesh Cleansing: 5.467531442642212
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989544080500228% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341358332**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 63472
# Total time for Mesh Cleansing: 0.28834033012390137
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9997164907859506% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341359145**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 535 pieces after mesh split
# There were 84 pieces found after size threshold
# max_index = 0
# max_face_len = 932160
# Total time for Mesh Cleansing: 143.06807255744934
# Number of outside child meshes =  1
# Main mesh and outside child meshes make up 0.9886016077375018% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346341359145_30_main_and_child_meshes_array.npz
#  face length 932160 using optimized facets with 3 neighbors
# Filtering edges by size finished: 31.501526355743408, facet # = 52308
# Filtering by convexity and getting centers took: 37.769683599472046, facet # = 8212
# Finished 8212 facets for main mesh: 72.59569454193115
# Filtering edges by size finished: 0.0006115436553955078, facet # = 3
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0022284984588623047, facet # = 3
# Total time for facets: 72.60396981239319
# Zero faceted faces = []
# Starting Child 0
# 3 8212
# Done distance matrix: 0.0017657279968261719
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# 3 8212
# Done distance matrix: 0.001489400863647461
# Child 0 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# 3 8212
# Done distance matrix: 0.0014145374298095703
# Done Generating final pairs: 0.008008956909179688
# best_stitch_pair = [   2 6699]
# best_stitch_pair_size = 35266.611290463465
# best_stitch_pair_distance = 2840.391997868288
# best_stitch_pair_size_ratio = 0.3124336207586235
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [2, 6699]}
# ---Stitching child 0 with pair: [2, 6699]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 183130, starting edge 2nd facet= 468054,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004947185516357422
# returned from stitch mesh: 0.6463556289672852
# Finished stitching child 0 : 0.7181589603424072
# ***************Finished big stitching iteration: 0.8261635303497314***************
# All children have been processed
# total_stitch_processing_time = 0.9968724250793457
# Total time for restitching = 0.9997947216033936
# missed_children = []
# Whole stitching function complete: 221.09964179992676
#
#
#
# *****Running Neuron Stitcher for 648518346342918705**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 149 pieces after mesh split
# There were 9 pieces found after size threshold
# max_index = 0
# max_face_len = 492490
# Total time for Mesh Cleansing: 22.858515977859497
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9960924068912791% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344083055**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 54826
# Total time for Mesh Cleansing: 0.1921241283416748
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994895540890364% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344083113**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 15 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 96640
# Total time for Mesh Cleansing: 0.2667057514190674
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994001944197398% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346344142665**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 40 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 107040
# Total time for Mesh Cleansing: 0.320953369140625
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9978000671165964% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346346910642**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 4 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 24200
# Total time for Mesh Cleansing: 0.04636693000793457
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999504377994383% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348123146**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 39 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 163172
# Total time for Mesh Cleansing: 0.5602626800537109
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9990815689251907% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348192004**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 78434
# Total time for Mesh Cleansing: 0.4155595302581787
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993629274756638% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348192292**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 25 pieces after mesh split
# There were 7 pieces found after size threshold
# max_index = 0
# max_face_len = 133676
# Total time for Mesh Cleansing: 8.625391483306885
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9727692150955479% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346348525348**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 20272
# Total time for Mesh Cleansing: 0.12985658645629883
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9994084007099191% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349104958**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 26318
# Total time for Mesh Cleansing: 0.12042713165283203
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.99916476841306% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349385325**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 41500
# Total time for Mesh Cleansing: 0.32418298721313477
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.999133281972265% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349475412**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 893 pieces after mesh split
# There were 100 pieces found after size threshold
# max_index = 0
# max_face_len = 372336
# Total time for Mesh Cleansing: 90.44129800796509
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9668377879394557% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341361901**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 3 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 13048
# Total time for Mesh Cleansing: 0.0706934928894043
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9993872549019608% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341362267**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 58 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 336622
# Total time for Mesh Cleansing: 0.8669159412384033
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9991333099841503% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341364962**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 58 pieces after mesh split
# There were 4 pieces found after size threshold
# max_index = 0
# max_face_len = 278628
# Total time for Mesh Cleansing: 9.645595073699951
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9983517743507424% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341369387**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 61 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 240678
# Total time for Mesh Cleansing: 10.16585898399353
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9967696245309743% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341394310**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 22 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 118058
# Total time for Mesh Cleansing: 0.39684271812438965
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.998275016488813% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341394654**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 228 pieces after mesh split
# There were 47 pieces found after size threshold
# max_index = 0
# max_face_len = 120122
# Total time for Mesh Cleansing: 8.330681324005127
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9504375484626462% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341399129**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 26 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 113616
# Total time for Mesh Cleansing: 2.6049082279205322
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.997646728249798% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341400619**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 6 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 45904
# Total time for Mesh Cleansing: 0.17592334747314453
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995644978660395% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341401351**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 5 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 77946
# Total time for Mesh Cleansing: 0.24296808242797852
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9995383550050011% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341403533**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 29 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 91462
# Total time for Mesh Cleansing: 0.255673885345459
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9987769454211894% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341403822**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 49 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 254861
# Total time for Mesh Cleansing: 6.964804172515869
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9989495510114491% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346341408647**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 47 pieces after mesh split
# There were 2 pieces found after size threshold
# max_index = 0
# max_face_len = 254722
# Total time for Mesh Cleansing: 6.677070140838623
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9966819266737097% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342157584**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 12 pieces after mesh split
# There were 1 pieces found after size threshold
# max_index = 0
# max_face_len = 59894
# Total time for Mesh Cleansing: 0.24500274658203125
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9992325658992326% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342405443**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 147 pieces after mesh split
# There were 33 pieces found after size threshold
# max_index = 0
# max_face_len = 161310
# Total time for Mesh Cleansing: 19.542346477508545
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9812998832003115% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342795219**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 110 pieces after mesh split
# There were 33 pieces found after size threshold
# max_index = 0
# max_face_len = 134346
# Total time for Mesh Cleansing: 14.425110340118408
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9798838837670674% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346342797668**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 252 pieces after mesh split
# There were 12 pieces found after size threshold
# max_index = 0
# max_face_len = 988380
# Total time for Mesh Cleansing: 48.325634717941284
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9975323593974718% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349502209**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 18 pieces after mesh split
# There were 3 pieces found after size threshold
# max_index = 0
# max_face_len = 93980
# Total time for Mesh Cleansing: 3.3004555702209473
# Number of outside child meshes =  0
# Main mesh and outside child meshes make up 0.9968814307232111% of original mesh
#
#
#
# *****Running Neuron Stitcher for 648518346349509557**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 102 pieces after mesh split
# There were 8 pieces found after size threshold
# max_index = 0
# max_face_len = 262824
# Total time for Mesh Cleansing: 9.202614307403564
# Number of outside child meshes =  5
# Main mesh and outside child meshes make up 0.9978438918855276% of original mesh
# Saved child and main meshes at stitch_mesh_saved/648518346349509557_30_main_and_child_meshes_array.npz
#  face length 262824 using optimized facets with 3 neighbors
# Filtering edges by size finished: 9.153214931488037, facet # = 13934
# Filtering by convexity and getting centers took: 12.497502326965332, facet # = 3041
# Finished 3041 facets for main mesh: 21.981131553649902
# Filtering edges by size finished: 0.444995641708374, facet # = 962
# Filtering by convexity and getting centers took: 0.9571614265441895, facet # = 183
# Filtering edges by size finished: 0.10248827934265137, facet # = 99
# Filtering by convexity and getting centers took: 0.17374587059020996, facet # = 17
# Filtering edges by size finished: 0.014581918716430664, facet # = 4
# Filtering by convexity and getting centers took: 0.002844095230102539, facet # = 3
# Filtering edges by size finished: 0.036733388900756836, facet # = 44
# Filtering by convexity and getting centers took: 0.05534648895263672, facet # = 15
# Filtering edges by size finished: 0.025898456573486328, facet # = 30
# Filtering by convexity and getting centers took: 0.018894195556640625, facet # = 6
# Total time for facets: 23.9065523147583
# Zero faceted faces = []
# Starting Child 0
# 183 3041
# Done distance matrix: 0.05979299545288086
# Done Generating final pairs: 0.09657883644104004
# best_stitch_pair = [ 111 1624]
# best_stitch_pair_size = 93506.04153072336
# best_stitch_pair_distance = 973.2441082393572
# best_stitch_pair_size_ratio = 0.26783601101953175
# Starting Child 1
# 17 3041
# Done distance matrix: 0.0038204193115234375
# Done Generating final pairs: 0.05014801025390625
# best_stitch_pair = [   7 1650]
# best_stitch_pair_size = 17397.323423724054
# best_stitch_pair_distance = 1979.572621790985
# best_stitch_pair_size_ratio = 0.9783780358590776
# Starting Child 2
# 3 3041
# Done distance matrix: 0.0008821487426757812
# Child 2 There were no points close enough
# Starting Child 3
# 15 3041
# Done distance matrix: 0.003296375274658203
# Child 3 There were no points close enough
# Starting Child 4
# 6 3041
# Done distance matrix: 0.0015690326690673828
# Done Generating final pairs: 0.023243427276611328
# best_stitch_pair = [   5 1638]
# best_stitch_pair_size = 25197.753541871767
# best_stitch_pair_distance = 1918.8731832849317
# best_stitch_pair_size_ratio = 0.9219213212059842
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [111, 1624], 1: [7, 1650], 4: [5, 1638]}
# ---Stitching child 0 with pair: [111, 1624]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 100978, starting edge 2nd facet= 135824,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 19
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 3.838539123535156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0015251636505126953
# returned from stitch mesh: 0.24350643157958984
# Finished stitching child 0 : 0.29076719284057617
# ---Stitching child 1 with pair: [7, 1650]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 45288, starting edge 2nd facet= 135928,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.2874603271484375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0035054683685302734
# returned from stitch mesh: 0.21636199951171875
# Finished stitching child 1 : 0.33144617080688477
# ---Stitching child 4 with pair: [5, 1638]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 11670, starting edge 2nd facet= 136351,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00153350830078125
# returned from stitch mesh: 0.3155786991119385
# Finished stitching child 4 : 0.33820676803588867
# ***************Finished big stitching iteration: 1.3321850299835205***************
# Starting Child 2
# 3 3241
# Done distance matrix: 0.0010077953338623047
# Done Generating final pairs: 0.0047109127044677734
# best_stitch_pair = [   1 3236]
# best_stitch_pair_size = 232270.38517229643
# best_stitch_pair_distance = 1801.1258233840617
# best_stitch_pair_size_ratio = 0.3298479038055746
# Starting Child 3
# 15 3241
# Done distance matrix: 0.002957582473754883
# Done Generating final pairs: 0.016978979110717773
# best_stitch_pair = [  10 3236]
# best_stitch_pair_size = 78845.73698560969
# best_stitch_pair_distance = 1572.277394391184
# best_stitch_pair_size_ratio = 0.3685876650650623
# repeat_main_facets = [3236]
# child_mesh_double_indexes = [2, 3]
# min_child = 3, max_ratio = 1572.277394391184
# child_meshes_stitch_facets = {3: [10, 3236]}
# ---Stitching child 3 with pair: [10, 3236]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 136328, starting edge 2nd facet= 136538,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.193450927734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0037186145782470703
# returned from stitch mesh: 0.28594374656677246
# Finished stitching child 3 : 0.32824087142944336
# ***************Finished big stitching iteration: 0.6336171627044678***************
# Starting Child 2
# 3 3254
# Done distance matrix: 0.056249141693115234
# Done Generating final pairs: 0.060158491134643555
# best_stitch_pair = [   1 3179]
# best_stitch_pair_size = 218356.27604548103
# best_stitch_pair_distance = 439.7883589324843
# best_stitch_pair_size_ratio = 0.25018364164881457
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [1, 3179]}
# ---Stitching child 2 with pair: [1, 3179]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 135063, starting edge 2nd facet= 136628,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.4318695068359375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011761903762817383
# returned from stitch mesh: 0.321566104888916
# Finished stitching child 2 : 0.34188175201416016
# ***************Finished big stitching iteration: 0.6501057147979736***************
# All children have been processed
# total_stitch_processing_time = 2.617426872253418
# Total time for restitching = 2.618433713912964
# missed_children = []
# Whole stitching function complete: 37.02640962600708
# 1083.257285118103

# %%
#(schema.jobs & "table_name='__orphan_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
