# %%
from whole_neuron_classifier_datajoint_adapted import extract_branches_whole_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time

# %%
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config["display.limit"] = 20
    
#schema = dj.schema('microns_ta3p100')
#ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
schema = dj.schema("microns_pinky")
pinky = dj.create_virtual_module("pinky","microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
@schema
class WholeAutoAnnotationsClusters3(dj.Computed):
    definition = """
    # creates the labels for the mesh table
    -> pinky.PymeshfixDecimatedExcitatoryStitchedMesh
    ---
    vertices   : longblob     # label data for the vertices
    triangles  : longblob     # label data for the faces
    """
    
    def make(self, key):
        start_time = time.time()
        
        print("\n\n*****Starting Auto Labeling for " + str(key["segment_id"]) + "******")
        
        segment_id = key["segment_id"]

        #get the vertices and faces from datajoint
        # get the newly stitched mesh
        # get the original mesh

        
        verts,faces = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh() & key).fetch1("vertices","triangles")


        #run the whole algorithm on the neuron to test
        verts_labels, faces_labels = extract_branches_whole_neuron(import_Off_Flag=False,segment_id=segment_id,vertices=verts,
                             triangles=faces,pymeshfix_Flag=False,
                             import_CGAL_Flag=False,
                             return_Only_Labels=True,
                             clusters=3,
                             smoothness=0.2)
        
        #insert the key
        self.insert1(dict(key,
                  vertices=verts_labels,
                  triangles=faces_labels),skip_duplicates=True)


        
        print(f"Finished Auto Labeling: {time.time() - start_time}")

# %%
start = time.time()
WholeAutoAnnotationsClusters3.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Starting Auto Labeling for 648518346349497184******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0702826976776123
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 378.52567648887634
# 2) Finished: Generating CGAL segmentation for neuron: 389.18874883651733
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.13625717163085938
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [0, 12, 18, 21, 26, 2, 24, 22, 57, 40]
# soma_80_percent = 182940.1828125
# Debugging the axon filter
# [(0, 200590.59375), (12, 185437.265625), (18, 201556.53125), (21, 197740.609375), (26, 204393.5625), (2, 190974.296875), (24, 196412.4375), (22, 184837.0), (57, 182044.984375), (40, 182530.0)]
# possible_Axons_filter_1 = [57, 40]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.044595956802368164
# 6) Staring: Classifying Entire Neuron
# 26 = error
# 22 = stub soma
# 40 = stub soma
# 57 = stub soma
# Total Labels found = {'error', 'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 1.2375295162200928
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.47976064682006836
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 5.780567646026611
# Finished Auto Labeling: 397.3795666694641
#
#
# *****Starting Auto Labeling for 648518346349499689******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.033536672592163086
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 620.9868402481079
# 2) Finished: Generating CGAL segmentation for neuron: 635.7717475891113
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1874992847442627
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [12, 8, 14, 15, 21, 35, 22, 115, 18, 107, 53, 74, 49, 58, 108, 66, 94, 122, 123]
# soma_80_percent = 182720.8046875
# Debugging the axon filter
# [(12, 201024.171875), (8, 179328.71875), (14, 200952.203125), (15, 213908.296875), (21, 184684.3125), (35, 188604.28125), (22, 205482.859375), (115, 194719.25), (18, 179191.875), (107, 190121.9375), (53, 192586.609375), (74, 190171.296875), (49, 180759.40625), (58, 190891.953125), (108, 190817.390625), (66, 178993.828125), (94, 180169.203125), (122, 194215.34375), (123, 193039.46875)]
# possible_Axons_filter_1 = [8, 18, 49, 66, 94]
# possible_Axons_filter_2 = [8, 18]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.07694554328918457
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 21
# 66 = cilia
# 35 = stub soma
# 49 = stub soma
# 53 = stub soma
# 58 = stub soma
# 74 = stub soma
# 94 = stub soma
# 107 = stub soma
# 108 = stub soma
# 115 = stub soma
# 122 = stub soma
# 123 = stub soma
# 95 = stub apical
# Total Labels found = {'soma', 'basal', 'oblique', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.69252610206604
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3617219924926758
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.54784369468689
# Finished Auto Labeling: 647.1691007614136
#
#
# *****Starting Auto Labeling for 648518346349499910******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03067755699157715
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 423.5667085647583
# 2) Finished: Generating CGAL segmentation for neuron: 434.72082018852234
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1408860683441162
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [13, 1, 9, 25, 18, 43, 20, 19, 17, 30, 33, 65]
# soma_80_percent = 197309.5578125
# Debugging the axon filter
# [(13, 209275.828125), (1, 206237.78125), (9, 200711.671875), (25, 196906.515625), (18, 194975.984375), (43, 209002.21875), (20, 218148.03125), (19, 204474.15625), (17, 216198.46875), (30, 208990.984375), (33, 201069.875), (65, 197654.953125)]
# possible_Axons_filter_1 = [25, 18]
# possible_Axons_filter_2 = [18]
# possible_Apical = 18
# 5) Finished: Finding Apical Index: 0.05515623092651367
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 1
# 25 = cilia
# 33 = stub soma
# 65 = stub soma
# 68 = stub apical
# Total Labels found = {'soma', 'basal', 'oblique', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.411829948425293
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.33532238006591797
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.326632976531982
# Finished Auto Labeling: 443.43919467926025
#
#
# *****Starting Auto Labeling for 648518346349500341******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03908824920654297
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 534.8676164150238
# 2) Finished: Generating CGAL segmentation for neuron: 548.1392939090729
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 1
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.17177844047546387
# 5) Staring: Finding Apical Index
# Soma Index = 1
# Soma Connections = [80, 8, 48, 32, 7, 21, 91, 15, 19, 119, 66, 85, 77, 110, 60, 105, 84, 79, 109, 112, 106, 123, 83, 100, 113, 117, 89]
# soma_80_percent = 192424.7484375
# Debugging the axon filter
# [(80, 198761.65625), (8, 202274.578125), (48, 192035.34375), (32, 199499.296875), (7, 189492.890625), (21, 213679.859375), (91, 201111.171875), (15, 208212.328125), (19, 202028.4375), (119, 197692.328125), (66, 195833.15625), (85, 197874.578125), (77, 199868.578125), (110, 192051.015625), (60, 201005.90625), (105, 194874.546875), (84, 198669.25), (79, 200032.140625), (109, 193030.25), (112, 198305.265625), (106, 192480.59375), (123, 202231.875), (83, 199821.609375), (100, 200340.34375), (113, 197312.796875), (117, 202200.875), (89, 191531.546875)]
# possible_Axons_filter_1 = [48, 7, 110, 89]
# possible_Axons_filter_2 = [7]
# possible_Apical = 7
# 5) Finished: Finding Apical Index: 0.07981276512145996
# 6) Staring: Classifying Entire Neuron
# 21 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 15
# 48 = stub soma
# 60 = stub soma
# 66 = stub soma
# 110 = cilia
# 77 = cilia
# 79 = stub soma
# 80 = stub soma
# 83 = stub soma
# 84 = stub soma
# 85 = stub soma
# 89 = stub soma
# 91 = stub soma
# 100 = stub soma
# 105 = stub soma
# 106 = stub soma
# 109 = stub soma
# 112 = stub soma
# 113 = stub soma
# 117 = stub soma
# 119 = stub soma
# 123 = stub soma
# 11 = stub apical
# 12 = stub apical
# 14 = stub apical
# 16 = stub apical
# 18 = stub apical
# 20 = stub apical
# 22 = stub apical
# 23 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 31 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 42 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = error
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 68 = stub apical
# 70 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 82 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 118 = stub apical
# 120 = stub apical
# 121 = stub apical
# 124 = stub apical
# 125 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# Total Labels found = {'axon', 'soma', 'basal', 'oblique', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.9803695678710938
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.37181806564331055
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 7.994212627410889
# Finished Auto Labeling: 559.2857978343964
#
#
# *****Starting Auto Labeling for 648518346349501517******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.02617025375366211
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 417.2669680118561
# 2) Finished: Generating CGAL segmentation for neuron: 428.2186372280121
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.14117670059204102
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [4, 11, 0, 17, 7, 8, 14, 21]
# soma_80_percent = 236442.7703125
# Debugging the axon filter
# [(4, 250685.90625), (11, 244774.640625), (0, 255306.703125), (17, 262638.84375), (7, 241007.203125), (8, 232027.921875), (14, 254875.875), (21, 233515.625)]
# possible_Axons_filter_1 = [8, 21]
# possible_Axons_filter_2 = [8]
# possible_Apical = 8
# 5) Finished: Finding Apical Index: 0.04815030097961426
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 0
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 11
# 21 = stub soma
# 15 = stub apical
# 22 = stub apical
# 28 = stub apical
# 32 = stub apical
# 37 = stub apical
# 38 = stub apical
# Total Labels found = {'soma', 'basal', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.310439109802246
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.3952181339263916
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.183404445648193
# Finished Auto Labeling: 436.7017345428467
#
#
# *****Starting Auto Labeling for 648518346349503086******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04346656799316406
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 449.174786567688
# 2) Finished: Generating CGAL segmentation for neuron: 460.75779128074646
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.15881729125976562
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [1, 6, 38, 205]
# soma_80_percent = 288207.24375
# Debugging the axon filter
# [(1, 299955.125), (6, 285579.5625), (38, 300620.3125), (205, 295246.25)]
# possible_Axons_filter_1 = [6]
# possible_Axons_filter_2 = [6]
# possible_Apical = 6
# 5) Finished: Finding Apical Index: 0.08830881118774414
# 6) Staring: Classifying Entire Neuron
# 205 = stub soma
# 9 = stub apical
# 10 = stub apical
# 11 = stub apical
# 14 = stub apical
# 16 = stub apical
# 17 = stub apical
# 19 = error
# 21 = stub apical
# 23 = stub apical
# 25 = stub apical
# 26 = stub apical
# 27 = stub apical
# 28 = stub apical
# 29 = stub apical
# 30 = stub apical
# 31 = stub apical
# 32 = stub apical
# 33 = stub apical
# 34 = stub apical
# 35 = stub apical
# 36 = stub apical
# 37 = stub apical
# 39 = stub apical
# 40 = stub apical
# 41 = stub apical
# 43 = stub apical
# 44 = stub apical
# 45 = stub apical
# 46 = stub apical
# 47 = stub apical
# 48 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 54 = stub apical
# 55 = stub apical
# 56 = stub apical
# 57 = stub apical
# 58 = stub apical
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 64 = stub apical
# 65 = stub apical
# 66 = stub apical
# 67 = stub apical
# 68 = stub apical
# 69 = stub apical
# 70 = stub apical
# 71 = stub apical
# 72 = stub apical
# 73 = stub apical
# 74 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 85 = stub apical
# 86 = stub apical
# 87 = stub apical
# 88 = stub apical
# 90 = stub apical
# 91 = error
# 92 = stub apical
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 125 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 144 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 188 = stub apical
# 189 = stub apical
# 190 = stub apical
# 191 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 199 = stub apical
# 200 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 220 = stub apical
# 221 = stub apical
# 222 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 228 = stub apical
# 229 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 238 = stub apical
# 239 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 244 = stub apical
# 245 = stub apical
# 246 = stub apical
# 247 = stub apical
# 248 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 266 = stub apical
# 267 = stub apical
# 268 = stub apical
# 269 = stub apical
# 270 = stub apical
# 271 = stub apical
# 272 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 279 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 309 = stub apical
# 310 = stub apical
# 311 = stub apical
# 312 = stub apical
# 313 = stub apical
# 314 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 320 = stub apical
# 321 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 346 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 355 = stub apical
# 356 = stub apical
# 357 = stub apical
# 358 = stub apical
# Total Labels found = {'soma', 'basal', 'oblique', 'error', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.7318079471588135
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.26514101028442383
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.481257200241089
# Finished Auto Labeling: 469.9852809906006
#
#
# *****Starting Auto Labeling for 648518346349504130******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.04327845573425293
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 936.7120666503906
# 2) Finished: Generating CGAL segmentation for neuron: 956.8861734867096
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.2635762691497803
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [12, 33, 7, 145, 36, 38, 32, 45, 27, 198, 199, 428]
# soma_80_percent = 257538.203125
# Debugging the axon filter
# [(12, 258556.296875), (33, 264557.4375), (7, 254035.125), (145, 254715.84375), (36, 281314.40625), (38, 258559.796875), (32, 269876.28125), (45, 276425.0625), (27, 261044.75), (198, 260397.046875), (199, 260162.03125), (428, 262804.34375)]
# possible_Axons_filter_1 = [7, 145]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.12436270713806152
# 6) Staring: Classifying Entire Neuron
# 36 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 38
# 145 = cilia
# 198 = stub soma
# 199 = stub soma
# 428 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma', 'axon'}
# 6) Finished: Classifying Entire Neuron: 3.032644033432007
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.8575544357299805
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 10.750601291656494
# Finished Auto Labeling: 972.7922773361206
#
#
# *****Starting Auto Labeling for 648518346349505813******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.005190134048461914
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 35.53899669647217
# 2) Finished: Generating CGAL segmentation for neuron: 37.05030632019043
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.020310163497924805
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [1, 4, 12, 11, 3]
# soma_80_percent = 270478.5875
# Debugging the axon filter
# [(1, 285043.28125), (4, 270335.59375), (12, 269863.25), (11, 270162.15625), (3, 276245.125)]
# possible_Axons_filter_1 = [4, 12, 11]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.014447689056396484
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 4
# 11 = stub soma
# 12 = stub soma
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.12860655784606934
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.09367251396179199
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 0.7701454162597656
# Finished Auto Labeling: 38.14768862724304
#
#
# *****Starting Auto Labeling for 648518346349505911******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.06003880500793457
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 599.0215911865234
# 2) Finished: Generating CGAL segmentation for neuron: 614.2595453262329
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 4
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19206809997558594
# 5) Staring: Finding Apical Index
# Soma Index = 4
# Soma Connections = [2, 3, 12, 18, 21, 22, 20, 14, 36, 43, 31]
# soma_80_percent = 169214.2265625
# Debugging the axon filter
# [(2, 179411.796875), (3, 173205.078125), (12, 174964.078125), (18, 165974.78125), (21, 177096.140625), (22, 186786.046875), (20, 190994.78125), (14, 177193.59375), (36, 179419.234375), (43, 169827.9375), (31, 170068.296875)]
# possible_Axons_filter_1 = [18]
# possible_Axons_filter_2 = [18]
# possible_Apical = 18
# 5) Finished: Finding Apical Index: 0.05089712142944336
# 6) Staring: Classifying Entire Neuron
# 2 = axon
# 43 = cilia
# 31 = stub soma
# 36 = stub soma
# 27 = error
# 30 = stub apical
# 33 = stub apical
# Total Labels found = {'axon', 'soma', 'basal', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.979313850402832
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.4254581928253174
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.53348159790039
# Finished Auto Labeling: 626.0204200744629
#
#
# *****Starting Auto Labeling for 648518346349506808******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.01479792594909668
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 96.99949669837952
# 2) Finished: Generating CGAL segmentation for neuron: 101.53518009185791
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.06117391586303711
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [6, 12, 109, 98, 108, 102, 7, 23, 17, 101, 99, 107]
# soma_80_percent = 222062.0578125
# Debugging the axon filter
# [(6, 252348.1875), (12, 235337.765625), (109, 227224.59375), (98, 218787.21875), (108, 223605.609375), (102, 224731.109375), (7, 250888.046875), (23, 227329.59375), (17, 228173.59375), (101, 222848.890625), (99, 224154.984375), (107, 218226.8125)]
# possible_Axons_filter_1 = [98, 107]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.02912592887878418
# 6) Staring: Classifying Entire Neuron
# 17 = stub soma
# 99 = stub soma
# 101 = stub soma
# 102 = stub soma
# 107 = stub soma
# 108 = stub soma
# 109 = stub soma
# Total Labels found = {'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 0.6984133720397949
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.23924994468688965
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 2.675379514694214
# Finished Auto Labeling: 105.42994689941406
#
#
# *****Starting Auto Labeling for 648518346349506952******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.0032744407653808594
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 6.279641151428223
# 2) Finished: Generating CGAL segmentation for neuron: 6.989068031311035
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.008844375610351562
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [9, 33, 34, 43, 29, 30, 42, 17, 45]
# soma_80_percent = 163916.115625
# Debugging the axon filter
# [(9, 170323.03125), (33, 171467.84375), (34, 169666.09375), (43, 163252.59375), (29, 170274.078125), (30, 159495.34375), (42, 165937.625), (17, 177930.8125), (45, 164424.796875)]
# possible_Axons_filter_1 = [43, 30]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.003971576690673828
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 30
# 17 = axon
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 9
# 29 = cilia
# 33 = stub soma
# 34 = cilia
# 42 = stub soma
# 43 = stub soma
# 45 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma', 'axon'}
# 6) Finished: Classifying Entire Neuron: 0.16987347602844238
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.03834176063537598
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 0.3736412525177002
# Finished Auto Labeling: 7.617508411407471
#
#
# *****Starting Auto Labeling for 648518346349507015******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05797266960144043
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 867.6729278564453
# 2) Finished: Generating CGAL segmentation for neuron: 885.1383166313171
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 8
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.23389792442321777
# 5) Staring: Finding Apical Index
# Soma Index = 8
# Soma Connections = [13, 20, 3, 27, 21, 238, 28, 356, 271, 355, 314, 189]
# soma_80_percent = 275663.128125
# Debugging the axon filter
# [(13, 279290.5625), (20, 306827.46875), (3, 272215.34375), (27, 281830.84375), (21, 282002.78125), (238, 285227.1875), (28, 296019.21875), (356, 283996.21875), (271, 273254.65625), (355, 284363.90625), (314, 284295.71875), (189, 274702.34375)]
# possible_Axons_filter_1 = [3, 271, 189]
# possible_Axons_filter_2 = [3]
# possible_Apical = 3
# 5) Finished: Finding Apical Index: 0.13263845443725586
# 6) Staring: Classifying Entire Neuron
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 27
# 28 = axon
# 189 = stub soma
# 238 = stub soma
# 271 = cilia
# 314 = stub soma
# 355 = stub soma
# 356 = stub soma
# 4 = stub apical
# 5 = stub apical
# 6 = error
# 15 = stub apical
# 18 = stub apical
# 22 = stub apical
# 23 = error
# 24 = stub apical
# 25 = stub apical
# 31 = stub apical
# 32 = stub apical
# 35 = error
# 36 = stub apical
# 37 = stub apical
# 38 = stub apical
# 39 = stub apical
# 41 = stub apical
# 42 = stub apical
# 44 = stub apical
# 46 = stub apical
# 47 = stub apical
# 49 = stub apical
# 50 = stub apical
# 51 = stub apical
# 52 = stub apical
# 53 = stub apical
# 56 = stub apical
# 58 = error
# 59 = stub apical
# 60 = stub apical
# 61 = stub apical
# 62 = stub apical
# 63 = stub apical
# 65 = stub apical
# 67 = stub apical
# 68 = stub apical
# 70 = stub apical
# 71 = stub apical
# 75 = stub apical
# 76 = stub apical
# 77 = stub apical
# 78 = stub apical
# 79 = stub apical
# 80 = stub apical
# 81 = stub apical
# 82 = stub apical
# 83 = stub apical
# 84 = stub apical
# 86 = stub apical
# 87 = error
# 89 = stub apical
# 90 = stub apical
# 91 = stub apical
# 92 = error
# 93 = stub apical
# 94 = stub apical
# 95 = stub apical
# 96 = stub apical
# 97 = stub apical
# 98 = stub apical
# 99 = stub apical
# 100 = stub apical
# 101 = stub apical
# 102 = stub apical
# 103 = stub apical
# 104 = stub apical
# 105 = stub apical
# 106 = stub apical
# 107 = stub apical
# 108 = stub apical
# 109 = stub apical
# 110 = stub apical
# 111 = stub apical
# 112 = stub apical
# 113 = stub apical
# 114 = stub apical
# 115 = stub apical
# 116 = stub apical
# 117 = stub apical
# 118 = stub apical
# 119 = stub apical
# 120 = stub apical
# 121 = stub apical
# 122 = stub apical
# 123 = stub apical
# 124 = stub apical
# 126 = stub apical
# 127 = stub apical
# 128 = stub apical
# 129 = stub apical
# 130 = stub apical
# 131 = stub apical
# 132 = stub apical
# 133 = stub apical
# 134 = stub apical
# 135 = stub apical
# 136 = stub apical
# 137 = stub apical
# 138 = stub apical
# 139 = stub apical
# 140 = stub apical
# 141 = stub apical
# 142 = stub apical
# 143 = stub apical
# 145 = stub apical
# 146 = stub apical
# 147 = stub apical
# 148 = stub apical
# 149 = stub apical
# 150 = stub apical
# 151 = stub apical
# 152 = stub apical
# 153 = stub apical
# 154 = stub apical
# 155 = stub apical
# 156 = stub apical
# 157 = stub apical
# 158 = stub apical
# 159 = stub apical
# 160 = stub apical
# 161 = stub apical
# 162 = stub apical
# 163 = stub apical
# 164 = stub apical
# 165 = stub apical
# 166 = stub apical
# 167 = stub apical
# 168 = stub apical
# 169 = stub apical
# 170 = stub apical
# 171 = stub apical
# 172 = stub apical
# 173 = stub apical
# 174 = stub apical
# 175 = stub apical
# 176 = stub apical
# 177 = stub apical
# 178 = stub apical
# 179 = stub apical
# 180 = stub apical
# 181 = stub apical
# 182 = stub apical
# 183 = stub apical
# 184 = stub apical
# 190 = stub apical
# 192 = stub apical
# 193 = stub apical
# 194 = stub apical
# 195 = stub apical
# 196 = stub apical
# 197 = stub apical
# 198 = stub apical
# 201 = stub apical
# 202 = stub apical
# 203 = stub apical
# 204 = stub apical
# 205 = stub apical
# 206 = stub apical
# 207 = stub apical
# 208 = stub apical
# 209 = stub apical
# 210 = stub apical
# 211 = stub apical
# 212 = stub apical
# 213 = stub apical
# 214 = stub apical
# 215 = stub apical
# 216 = stub apical
# 217 = stub apical
# 218 = stub apical
# 219 = stub apical
# 220 = stub apical
# 223 = stub apical
# 224 = stub apical
# 225 = stub apical
# 226 = stub apical
# 227 = stub apical
# 230 = stub apical
# 231 = stub apical
# 232 = stub apical
# 233 = stub apical
# 234 = stub apical
# 235 = stub apical
# 236 = stub apical
# 237 = stub apical
# 240 = stub apical
# 241 = stub apical
# 242 = stub apical
# 243 = stub apical
# 246 = stub apical
# 249 = stub apical
# 250 = stub apical
# 251 = stub apical
# 252 = stub apical
# 253 = stub apical
# 254 = stub apical
# 255 = stub apical
# 256 = stub apical
# 257 = stub apical
# 258 = stub apical
# 259 = stub apical
# 260 = stub apical
# 261 = stub apical
# 262 = stub apical
# 263 = stub apical
# 264 = stub apical
# 265 = stub apical
# 269 = stub apical
# 270 = stub apical
# 273 = stub apical
# 274 = stub apical
# 275 = stub apical
# 276 = stub apical
# 277 = stub apical
# 278 = stub apical
# 280 = stub apical
# 281 = stub apical
# 282 = stub apical
# 283 = stub apical
# 284 = stub apical
# 285 = stub apical
# 286 = stub apical
# 287 = stub apical
# 288 = stub apical
# 289 = stub apical
# 290 = stub apical
# 291 = stub apical
# 292 = stub apical
# 293 = stub apical
# 294 = stub apical
# 295 = stub apical
# 296 = stub apical
# 297 = stub apical
# 298 = stub apical
# 299 = stub apical
# 300 = stub apical
# 301 = stub apical
# 302 = stub apical
# 303 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 315 = stub apical
# 316 = stub apical
# 317 = stub apical
# 318 = stub apical
# 319 = stub apical
# 322 = stub apical
# 323 = stub apical
# 324 = stub apical
# 325 = stub apical
# 326 = stub apical
# 327 = stub apical
# 328 = stub apical
# 329 = stub apical
# 330 = stub apical
# 331 = stub apical
# 332 = stub apical
# 333 = stub apical
# 334 = stub apical
# 335 = stub apical
# 336 = stub apical
# 337 = stub apical
# 338 = stub apical
# 339 = stub apical
# 340 = stub apical
# 341 = stub apical
# 342 = stub apical
# 343 = stub apical
# 344 = stub apical
# 345 = stub apical
# 347 = stub apical
# 348 = stub apical
# 349 = stub apical
# 350 = stub apical
# 351 = stub apical
# 352 = stub apical
# 353 = stub apical
# 354 = stub apical
# 357 = stub apical
# 358 = stub apical
# 359 = stub apical
# 360 = stub apical
# 361 = stub apical
# 362 = stub apical
# 363 = stub apical
# 364 = stub apical
# 365 = stub apical
# Total Labels found = {'axon', 'soma', 'basal', 'oblique', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 2.908055305480957
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.41388940811157227
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 9.724615573883057
# Finished Auto Labeling: 899.2752153873444
#
#
# *****Starting Auto Labeling for 648518346349509512******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.024449825286865234
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 234.55129528045654
# 2) Finished: Generating CGAL segmentation for neuron: 242.66225409507751
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 0
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.10666418075561523
# 5) Staring: Finding Apical Index
# Soma Index = 0
# Soma Connections = [12, 13, 9, 25, 20, 31, 6, 39, 21, 43, 45, 33, 24, 44, 46, 26, 28, 48, 42, 27, 36, 14, 37]
# soma_80_percent = 293740.0875
# Debugging the axon filter
# [(12, 306338.6875), (13, 291603.0), (9, 299135.78125), (25, 310119.40625), (20, 296785.34375), (31, 297496.53125), (6, 302617.28125), (39, 293317.3125), (21, 303719.46875), (43, 302562.0), (45, 301362.1875), (33, 302416.21875), (24, 301245.125), (44, 302792.28125), (46, 300348.28125), (26, 296491.6875), (28, 296003.75), (48, 301854.71875), (42, 291263.0), (27, 298908.25), (36, 293343.03125), (14, 301599.46875), (37, 292855.25)]
# possible_Axons_filter_1 = [13, 39, 42, 36, 37]
# possible_Axons_filter_2 = [13]
# possible_Apical = 13
# 5) Finished: Finding Apical Index: 0.0465550422668457
# 6) Staring: Classifying Entire Neuron
# 14 = cilia
# 21 = stub soma
# 24 = stub soma
# 26 = stub soma
# 27 = stub soma
# 28 = stub soma
# 31 = stub soma
# 33 = stub soma
# 43 = cilia
# 36 = stub soma
# 37 = stub soma
# 39 = stub soma
# 42 = stub soma
# 44 = stub soma
# 45 = stub soma
# 46 = stub soma
# 48 = stub soma
# 16 = error
# Total Labels found = {'soma', 'basal', 'oblique', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.3329181671142578
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.2940046787261963
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 4.6006786823272705
# Finished Auto Labeling: 249.37225461006165
#
#
# *****Starting Auto Labeling for 648518346349510951******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.03537702560424805
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 282.2297866344452
# 2) Finished: Generating CGAL segmentation for neuron: 291.9448664188385
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 2
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.1498713493347168
# 5) Staring: Finding Apical Index
# Soma Index = 2
# Soma Connections = [74, 3, 17, 612, 73, 151, 133, 125, 211, 452, 413, 277, 205, 610, 614, 674, 944, 140, 741, 675, 57, 209, 18, 628, 673, 102, 1, 672, 905, 146, 920, 571, 737, 898, 795, 735, 103, 110, 19, 173, 244, 203, 303, 616, 840, 128, 945, 280, 792, 638, 676, 870, 613, 946, 871, 216, 639, 212, 70, 214, 943, 670, 624, 607, 669, 573, 78, 858, 457, 732, 730, 572, 65, 279, 559, 738, 959, 608, 394, 740, 948, 44, 796, 400, 900, 575, 671, 386, 509, 395, 219, 942, 563, 793, 729, 794, 245, 609, 677, 145, 947, 560, 440, 623, 437, 438, 565, 678, 562, 566, 627, 564, 810, 439, 615, 441, 736, 391, 731, 267, 510, 611, 739, 561, 398, 90, 906, 392, 150, 733]
# soma_80_percent = 191395.0375
# Debugging the axon filter
# [(74, 172962.0625), (3, 271520.0), (17, 249382.34375), (612, 189175.84375), (73, 225266.0), (151, 180425.53125), (133, 187257.15625), (125, 176740.796875), (211, 184534.46875), (452, 168407.671875), (413, 171652.09375), (277, 174556.0625), (205, 218732.328125), (610, 188181.421875), (614, 184628.390625), (674, 195779.328125), (944, 193861.53125), (140, 192806.875), (741, 170884.21875), (675, 197777.90625), (57, 200140.203125), (209, 184792.875), (18, 195722.359375), (628, 191456.296875), (673, 183545.296875), (102, 186478.0), (1, 169975.9375), (672, 181866.5625), (905, 221653.296875), (146, 189225.328125), (920, 179892.890625), (571, 183001.578125), (737, 170441.71875), (898, 221168.75), (795, 183281.390625), (735, 183165.421875), (103, 170045.28125), (110, 178383.21875), (19, 174168.953125), (173, 197944.84375), (244, 193034.453125), (203, 188983.75), (303, 170011.953125), (616, 197131.53125), (840, 236423.875), (128, 172983.8125), (945, 198676.109375), (280, 176061.109375), (792, 181833.28125), (638, 179262.515625), (676, 199188.65625), (870, 200199.5), (613, 185187.3125), (946, 198738.125), (871, 198577.515625), (216, 197150.375), (639, 193699.296875), (212, 172845.953125), (70, 178299.140625), (214, 176888.359375), (943, 196340.53125), (670, 181732.953125), (624, 191254.546875), (607, 186227.125), (669, 182297.6875), (573, 183841.9375), (78, 195871.296875), (858, 203808.484375), (457, 171100.34375), (732, 177814.234375), (730, 178712.90625), (572, 182975.25), (65, 187323.125), (279, 173773.296875), (559, 173289.234375), (738, 169613.734375), (959, 171103.359375), (608, 187595.765625), (394, 192013.59375), (740, 169157.6875), (948, 198732.4375), (44, 172648.03125), (796, 183112.328125), (400, 182562.625), (900, 240106.859375), (575, 199387.15625), (671, 181488.390625), (386, 192424.1875), (509, 196580.1875), (395, 175469.859375), (219, 208919.984375), (942, 194603.84375), (563, 174970.78125), (793, 182586.6875), (729, 178510.21875), (794, 181914.15625), (245, 233975.640625), (609, 186732.71875), (677, 200016.765625), (145, 213021.453125), (947, 198864.8125), (560, 173610.1875), (440, 201459.75), (623, 179397.3125), (437, 188707.03125), (438, 202137.015625), (565, 173631.25), (678, 198679.921875), (562, 173579.1875), (566, 177364.78125), (627, 191611.375), (564, 175584.0625), (810, 231451.859375), (439, 203740.46875), (615, 199499.828125), (441, 202845.640625), (736, 171449.421875), (391, 221676.90625), (731, 178063.953125), (267, 200040.4375), (510, 196417.5625), (611, 185185.921875), (739, 171860.828125), (561, 175917.375), (398, 201684.875), (90, 184575.703125), (906, 194896.984375), (392, 172085.0625), (150, 172651.265625), (733, 177924.9375)]
# possible_Axons_filter_1 = [74, 612, 151, 133, 125, 211, 452, 413, 277, 610, 614, 741, 209, 673, 102, 1, 672, 146, 920, 571, 737, 795, 735, 103, 110, 19, 203, 303, 128, 280, 792, 638, 613, 212, 70, 214, 670, 624, 607, 669, 573, 457, 732, 730, 572, 65, 279, 559, 738, 959, 608, 740, 44, 796, 400, 671, 395, 563, 793, 729, 794, 609, 560, 623, 437, 565, 562, 566, 564, 736, 731, 611, 739, 561, 90, 392, 150, 733]
# possible_Axons_filter_2 = [1, 19]
# possible_Apical = 19
# 5) Finished: Finding Apical Index: 0.17601799964904785
# 6) Staring: Classifying Entire Neuron
# 73 = error
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 18
# 44 = cilia
# 57 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 65
# 70 = stub soma
# 74 = cilia
# 78 = stub soma
# 90 = stub soma
# 102 = stub soma
# 103 = cilia
# 110 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 125
# 128 = cilia
# 140 = stub soma
# 209 = cilia
# 173 = cilia
# 145 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 146
# 150 = stub soma
# 151 = cilia
# 203 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 205
# 211 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 212
# 214 = stub soma
# 216 = cilia
# 219 = stub soma
# 244 = stub soma
# 245 = stub soma
# 267 = cilia
# 279 = stub soma
# 280 = stub soma
# 303 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 386
# 391 = cilia
# 392 = stub soma
# 394 = cilia
# 395 = stub soma
# 398 = stub soma
# 400 = cilia
# 413 = stub soma
# 437 = stub soma
# 438 = stub soma
# 439 = stub soma
# 440 = cilia
# 441 = cilia
# 452 = cilia
# 457 = stub soma
# 510 = stub soma
# 509 = stub soma
# 559 = stub soma
# 560 = stub soma
# 561 = cilia
# 562 = stub soma
# 563 = cilia
# 564 = stub soma
# 565 = stub soma
# 566 = cilia
# 571 = stub soma
# 572 = cilia
# 573 = stub soma
# 575 = stub soma
# 607 = stub soma
# 608 = stub soma
# 609 = stub soma
# 610 = stub soma
# 611 = cilia
# 612 = cilia
# 613 = stub soma
# 614 = stub soma
# 615 = cilia
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 616
# 623 = stub soma
# 624 = stub soma
# MET AXON THRESHOLD CRITERIA but not low enough on soma for neighbor = 627
# 628 = cilia
# 638 = stub soma
# 639 = cilia
# 669 = cilia
# 670 = cilia
# 672 = stub soma
# 673 = stub soma
# 675 = stub soma
# 676 = cilia
# 677 = cilia
# 678 = stub soma
# 729 = stub soma
# 731 = stub soma
# 732 = stub soma
# 733 = stub soma
# 735 = stub soma
# 736 = stub soma
# 737 = stub soma
# 738 = stub soma
# 739 = stub soma
# 740 = stub soma
# 741 = stub soma
# 792 = stub soma
# 793 = stub soma
# 794 = stub soma
# 795 = stub soma
# 796 = stub soma
# 810 = stub soma
# 840 = stub soma
# 858 = stub soma
# 870 = stub soma
# 871 = stub soma
# 898 = stub soma
# 900 = stub soma
# 905 = stub soma
# 906 = stub soma
# 920 = stub soma
# 942 = stub soma
# 943 = stub soma
# 944 = stub soma
# 945 = cilia
# 946 = stub soma
# 947 = stub soma
# 948 = stub soma
# 959 = cilia
# 100 = error
# 34 = error
# 53 = stub apical
# 64 = stub apical
# 71 = stub apical
# 76 = stub apical
# 79 = stub apical
# 83 = stub apical
# 87 = stub apical
# 92 = stub apical
# 95 = stub apical
# 98 = stub apical
# 99 = stub apical
# 143 = stub apical
# 186 = stub apical
# 197 = stub apical
# 256 = stub apical
# 258 = stub apical
# 286 = stub apical
# 304 = stub apical
# 305 = stub apical
# 306 = stub apical
# 307 = stub apical
# 308 = stub apical
# 310 = stub apical
# 312 = stub apical
# 315 = stub apical
# 339 = stub apical
# 348 = stub apical
# 403 = stub apical
# 404 = stub apical
# 405 = stub apical
# 411 = stub apical
# 412 = stub apical
# 445 = stub apical
# 446 = stub apical
# 448 = stub apical
# 494 = stub apical
# 496 = stub apical
# 497 = stub apical
# 511 = stub apical
# 512 = stub apical
# 514 = stub apical
# 515 = stub apical
# 576 = stub apical
# 584 = stub apical
# 595 = stub apical
# 602 = stub apical
# 605 = stub apical
# 606 = stub apical
# 637 = stub apical
# 660 = stub apical
# 661 = stub apical
# 663 = stub apical
# 664 = stub apical
# 665 = stub apical
# 666 = stub apical
# 668 = stub apical
# 691 = stub apical
# 753 = stub apical
# 755 = stub apical
# 767 = stub apical
# 768 = stub apical
# 769 = stub apical
# 803 = stub apical
# 804 = stub apical
# 805 = stub apical
# 837 = stub apical
# 865 = stub apical
# 866 = stub apical
# 867 = stub apical
# 868 = stub apical
# 872 = stub apical
# 873 = stub apical
# 874 = stub apical
# 875 = stub apical
# 958 = stub apical
# Total Labels found = {'soma', 'basal', 'error', 'cilia', 'apical'}
# 6) Finished: Classifying Entire Neuron: 1.8526535034179688
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.2547457218170166
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 6.243160247802734
# Finished Auto Labeling: 301.1503858566284
#
#
# *****Starting Auto Labeling for 648518346349511866******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05202007293701172
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 565.6092731952667
# 2) Finished: Generating CGAL segmentation for neuron: 580.986409664154
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 14
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.19161772727966309
# 5) Staring: Finding Apical Index
# Soma Index = 14
# Soma Connections = [73, 23, 52, 10, 242, 0, 11, 20, 3, 17, 353, 332, 84, 107, 134]
# soma_80_percent = 262681.0875
# Debugging the axon filter
# [(73, 265215.3125), (23, 272101.9375), (52, 271765.46875), (10, 280085.84375), (242, 260802.0625), (0, 259921.328125), (11, 271399.65625), (20, 272917.8125), (3, 265180.1875), (17, 278773.40625), (353, 273088.875), (332, 265016.90625), (84, 262673.25), (107, 261316.28125), (134, 261004.0)]
# possible_Axons_filter_1 = [242, 0, 84, 107, 134]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.11813068389892578
# 6) Staring: Classifying Entire Neuron
# 10 = axon
# 84 = stub soma
# 107 = stub soma
# 134 = stub soma
# 242 = cilia
# 332 = stub soma
# 353 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma', 'axon'}
# 6) Finished: Classifying Entire Neuron: 2.221884250640869
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.5745501518249512
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 8.231524229049683
# Finished Auto Labeling: 593.0331547260284
#
#
# *****Starting Auto Labeling for 648518346349513655******
# 1) Starting: Mesh importing and Pymesh fix
# loading mesh from vertices and triangles array
# 1) Finished: Mesh importing and Pymesh fix: 0.05525660514831543
# 2) Staring: Generating CGAL segmentation for neuron
# Done writing OFF file
#
# Starting CGAL segmentation
# Right before cgal segmentation, clusters = 3, smoothness = 0.2
# 1
# Finished CGAL segmentation algorithm: 946.9197053909302
# 2) Finished: Generating CGAL segmentation for neuron: 966.5322599411011
# 3) Staring: Generating Graph Structure and Identifying Soma
# soma_index = 6
# 3) Finished: Generating Graph Structure and Identifying Soma: 0.26030874252319336
# 5) Staring: Finding Apical Index
# Soma Index = 6
# Soma Connections = [36, 26, 0, 48, 290, 37, 67, 35, 42, 24, 258, 183, 207, 378, 335]
# soma_80_percent = 230472.678125
# Debugging the axon filter
# [(36, 237668.890625), (26, 233767.265625), (0, 226674.65625), (48, 247084.265625), (290, 236069.90625), (37, 254589.09375), (67, 246517.046875), (35, 240168.328125), (42, 254945.328125), (24, 243832.5), (258, 226748.453125), (183, 241035.015625), (207, 241512.046875), (378, 228911.40625), (335, 227591.8125)]
# possible_Axons_filter_1 = [0, 258, 378, 335]
# possible_Axons_filter_2 = []
# possible_Apical = None
# 5) Finished: Finding Apical Index: 0.12836694717407227
# 6) Staring: Classifying Entire Neuron
# 258 = cilia
# 183 = stub soma
# 207 = stub soma
# 290 = stub soma
# 335 = stub soma
# 378 = stub soma
# Total Labels found = {'cilia', 'unsure', 'soma'}
# 6) Finished: Classifying Entire Neuron: 2.4368577003479004
# 7) Staring: Transfering Segmentation Labels to Face Labels
# 7) Finished: Transfering Segmentation Labels to Face Labels: 0.7351503372192383
# 8) Staring: Generating final Vertex and Face Labels
# 8) Finished: Generating final Vertex and Face Labels: 11.05944299697876
# Finished Auto Labeling: 982.0964639186859
# 7730.83060836792

# %%
#(schema.jobs & "table_name='__whole_auto_annotations_clusters3'").delete()

# %%
#schema.jobs
