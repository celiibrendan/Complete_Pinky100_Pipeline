# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349473044**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349473044_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 4.3439037799835205
# Number of outside child meshes =  5
# Main mesh and outside child meshes make up 0.9359237893716871% of original mesh
#  face length 2918238 using optimized facets with 3 neighbors
# Filtering edges by size finished: 43.6659836769104, facet # = 149943
# Filtering by convexity and getting centers took: 97.63394403457642, facet # = 32296
# Finished facets for main mesh: 146.3442006111145 with facet length = 32296
# Finished 32296 facets for main mesh: 146.34546828269958
# Filtering edges by size finished: 0.45311450958251953, facet # = 1379
# Filtering by convexity and getting centers took: 0.4924154281616211, facet # = 396
# Filtering edges by size finished: 0.03537702560424805, facet # = 216
# Filtering by convexity and getting centers took: 0.08824896812438965, facet # = 49
# Filtering edges by size finished: 0.4644782543182373, facet # = 1243
# Filtering by convexity and getting centers took: 0.6634988784790039, facet # = 367
# Filtering edges by size finished: 0.0684816837310791, facet # = 217
# Filtering by convexity and getting centers took: 0.1028592586517334, facet # = 65
# Filtering edges by size finished: 0.031151771545410156, facet # = 99
# Filtering by convexity and getting centers took: 0.04745173454284668, facet # = 30
# Total time for facets: 148.87828493118286
# Zero faceted faces = []
# Starting Child 0
# 396 32296
# Done distance matrix: 0.5635278224945068
# Done Generating final pairs: 0.6272597312927246
# best_stitch_pair = [   52 21176]
# best_stitch_pair_size = 115360.1026586986
# best_stitch_pair_distance = 537.1726435224156
# best_stitch_pair_size_ratio = 0.3933228003743042
# Starting Child 1
# 49 32296
# Done distance matrix: 0.0547332763671875
# Child 1 There were no points close enough
# Starting Child 2
# 367 32296
# Done distance matrix: 0.6959419250488281
# Done Generating final pairs: 0.7148158550262451
# best_stitch_pair = [  280 18144]
# best_stitch_pair_size = 123041.85856606204
# best_stitch_pair_distance = 157.21832895763183
# best_stitch_pair_size_ratio = 0.5207125560675816
# Starting Child 3
# 65 32296
# Done distance matrix: 0.0753021240234375
# Child 3 There were no points close enough
# Starting Child 4
# 30 32296
# Done distance matrix: 0.03175616264343262
# Child 4 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [52, 21176], 2: [280, 18144]}
# ---Stitching child 0 with pair: [52, 21176]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 804696, starting edge 2nd facet= 1466934,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 3.3855438232421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11849379539489746
# returned from stitch mesh: 2.162092924118042
# Finished stitching child 0 : 2.5090603828430176
# ---Stitching child 2 with pair: [280, 18144]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 693455, starting edge 2nd facet= 1472301,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.0503997802734375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05092763900756836
# returned from stitch mesh: 2.1029837131500244
# Finished stitching child 2 : 2.5759425163269043
# ***************Finished big stitching iteration: 7.161883115768433***************
# Starting Child 1
# 49 33055
# Done distance matrix: 0.08170008659362793
# Done Generating final pairs: 0.08728361129760742
# best_stitch_pair = [   17 32989]
# best_stitch_pair_size = 79853.53547869647
# best_stitch_pair_distance = 1214.4809818336964
# best_stitch_pair_size_ratio = 0.8823388175165523
# Starting Child 3
# 65 33055
# Done distance matrix: 0.2940967082977295
# Child 3 There were no points close enough
# Starting Child 4
# 30 33055
# Done distance matrix: 0.04031801223754883
# Child 4 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [17, 32989]}
# ---Stitching child 1 with pair: [17, 32989]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1473328, starting edge 2nd facet= 1474031,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.0742416381835938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04929995536804199
# returned from stitch mesh: 2.3173038959503174
# Finished stitching child 1 : 2.6973297595977783
# ***************Finished big stitching iteration: 6.070230007171631***************
# Starting Child 3
# 65 33102
# Done distance matrix: 0.07535147666931152
# Done Generating final pairs: 0.07978630065917969
# best_stitch_pair = [    9 33081]
# best_stitch_pair_size = 102890.0137298083
# best_stitch_pair_distance = 331.61707952173464
# best_stitch_pair_size_ratio = 0.516356396554519
# Starting Child 4
# 30 33102
# Done distance matrix: 0.07443666458129883
# Child 4 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {3: [9, 33081]}
# ---Stitching child 3 with pair: [9, 33081]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1474604, starting edge 2nd facet= 1475041,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.5020370483398438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05179572105407715
# returned from stitch mesh: 2.960858106613159
# Finished stitching child 3 : 3.4375429153442383
# ***************Finished big stitching iteration: 6.0926666259765625***************
# Starting Child 4
# 30 33165
# Done distance matrix: 0.050579071044921875
# Done Generating final pairs: 0.0547482967376709
# best_stitch_pair = [   10 33115]
# best_stitch_pair_size = 90008.32291521608
# best_stitch_pair_distance = 1815.9126660306447
# best_stitch_pair_size_ratio = 0.3679560585814005
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [10, 33115]}
# ---Stitching child 4 with pair: [10, 33115]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1475264, starting edge 2nd facet= 1475676,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.24249267578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.053276777267456055
# returned from stitch mesh: 2.7238166332244873
# Finished stitching child 4 : 3.409881114959717
# ***************Finished big stitching iteration: 6.375927209854126***************
# All children have been processed
# total_stitch_processing_time = 25.702351808547974
# Total time for restitching = 25.714707851409912
# missed_children = []
# Whole stitching function complete: 185.5614378452301
#
#
#
# *****Running Neuron Stitcher for 648518346349475522**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349475522_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.4241669178009033
# Number of outside child meshes =  19
# Main mesh and outside child meshes make up 0.8587040448646744% of original mesh
#  face length 759515 using optimized facets with 3 neighbors
# Filtering edges by size finished: 26.7190420627594, facet # = 40832
# Filtering by convexity and getting centers took: 34.38389325141907, facet # = 7594
# Finished 7594 facets for main mesh: 63.17452788352966
# Filtering edges by size finished: 0.0023796558380126953, facet # = 3
# Filtering by convexity and getting centers took: 0.001611471176147461, facet # = 0
# Filtering edges by size finished: 0.006114006042480469, facet # = 5
# Filtering by convexity and getting centers took: 0.003960132598876953, facet # = 2
# Filtering edges by size finished: 0.004174947738647461, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0028760433197021484, facet # = 2
# Filtering edges by size finished: 0.002901792526245117, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003114461898803711, facet # = 2
# Filtering edges by size finished: 0.0011653900146484375, facet # = 4
# Filtering by convexity and getting centers took: 0.0025453567504882812, facet # = 4
# Filtering edges by size finished: 0.002628803253173828, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0022513866424560547, facet # = 2
# Filtering edges by size finished: 0.002801179885864258, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.004961729049682617, facet # = 2
# Filtering edges by size finished: 0.002907991409301758, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.006498098373413086, facet # = 2
# Filtering edges by size finished: 0.0027840137481689453, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0067522525787353516, facet # = 2
# Filtering edges by size finished: 0.002897500991821289, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.00592494010925293, facet # = 2
# Filtering edges by size finished: 0.02861166000366211, facet # = 16
# Filtering by convexity and getting centers took: 0.010994434356689453, facet # = 10
# Filtering edges by size finished: 0.0028960704803466797, facet # = 7
# Filtering by convexity and getting centers took: 0.0039844512939453125, facet # = 4
# Filtering edges by size finished: 0.001796722412109375, facet # = 4
# Filtering by convexity and getting centers took: 0.00222015380859375, facet # = 2
# Filtering edges by size finished: 0.0037529468536376953, facet # = 14
# Filtering by convexity and getting centers took: 0.006689310073852539, facet # = 9
# Filtering edges by size finished: 0.002491474151611328, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002160310745239258, facet # = 2
# Filtering edges by size finished: 0.0030412673950195312, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002460479736328125, facet # = 2
# Filtering edges by size finished: 0.002141714096069336, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002155303955078125, facet # = 2
# Filtering edges by size finished: 0.0034563541412353516, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0027413368225097656, facet # = 2
# Filtering edges by size finished: 0.002111673355102539, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002129793167114258, facet # = 2
# Total time for facets: 63.44438171386719
# Zero faceted faces = [0]
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 1
# 2 7594
# Done distance matrix: 0.0008833408355712891
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# 2 7594
# Done distance matrix: 0.0008327960968017578
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 2 7594
# Done distance matrix: 0.0006508827209472656
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 4 7594
# Done distance matrix: 0.0015916824340820312
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 7594
# Done distance matrix: 0.0006287097930908203
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 6
# 2 7594
# Done distance matrix: 0.0007460117340087891
# Done Generating final pairs: 0.005810976028442383
# best_stitch_pair = [   0 5809]
# best_stitch_pair_size = 24803.98900211395
# best_stitch_pair_distance = 1906.7257904592464
# best_stitch_pair_size_ratio = 0.8269863358199288
# Starting Child 7
# 2 7594
# Done distance matrix: 0.0007987022399902344
# Child 7 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 8
# 2 7594
# Done distance matrix: 0.0009255409240722656
# Done Generating final pairs: 0.007040977478027344
# best_stitch_pair = [   0 4347]
# best_stitch_pair_size = 26247.803717644667
# best_stitch_pair_distance = 1697.4283826613882
# best_stitch_pair_size_ratio = 0.9333333333333339
# Starting Child 9
# 2 7594
# Done distance matrix: 0.0011699199676513672
# Done Generating final pairs: 0.01057124137878418
# best_stitch_pair = [  1 350]
# best_stitch_pair_size = 28283.69644190481
# best_stitch_pair_distance = 930.0842729349484
# best_stitch_pair_size_ratio = 0.923112999833663
# Starting Child 10
# 10 7594
# Done distance matrix: 0.00499725341796875
# Child 10 There were no points close enough
# Starting Child 11
# 4 7594
# Done distance matrix: 0.0015921592712402344
# Child 11 There were no points close enough
# Starting Child 12
# 2 7594
# Done distance matrix: 0.0012049674987792969
# Child 12 There were no points close enough
# Starting Child 13
# 9 7594
# Done distance matrix: 0.0038976669311523438
# Child 13 There were no points close enough
# Starting Child 14
# 2 7594
# Done distance matrix: 0.0009071826934814453
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 15
# 2 7594
# Done distance matrix: 0.000926971435546875
# Done Generating final pairs: 0.009870290756225586
# best_stitch_pair = [   0 4318]
# best_stitch_pair_size = 22793.92256259594
# best_stitch_pair_distance = 1687.4280892705272
# best_stitch_pair_size_ratio = 0.4814096703908687
# Starting Child 16
# 2 7594
# Done distance matrix: 0.001055002212524414
# Child 16 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 2 7594
# Done distance matrix: 0.0009016990661621094
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 2 7594
# Done distance matrix: 0.0008373260498046875
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {6: [0, 5809], 8: [0, 4347], 9: [1, 350], 15: [0, 4318]}
# ---Stitching child 6 with pair: [0, 5809]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 25105, starting edge 2nd facet= 381333,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 5.245208740234375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.01313161849975586
# returned from stitch mesh: 0.6013827323913574
# Finished stitching child 6 : 0.6586782932281494
# ---Stitching child 8 with pair: [0, 4347]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 46229, starting edge 2nd facet= 381381,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 20
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 5.7220458984375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013132572174072266
# returned from stitch mesh: 0.7663447856903076
# Finished stitching child 8 : 0.8328373432159424
# ---Stitching child 9 with pair: [1, 350]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 307446, starting edge 2nd facet= 381412,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 4, remainder = 1
# About to add faces
# Finished adding faces: 3.9577484130859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013541460037231445
# returned from stitch mesh: 0.5865721702575684
# Finished stitching child 9 : 0.6669886112213135
# ---Stitching child 15 with pair: [0, 4318]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 62499, starting edge 2nd facet= 381431,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 23
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 4, remainder = 3
# About to add faces
# Finished adding faces: 3.743171691894531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012656211853027344
# returned from stitch mesh: 0.8214786052703857
# Finished stitching child 15 : 1.0299298763275146
# ***************Finished big stitching iteration: 3.5531022548675537***************
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 1
# 2 7594
# Done distance matrix: 0.0013854503631591797
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# 2 7594
# Done distance matrix: 0.0008254051208496094
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 2 7594
# Done distance matrix: 0.0007770061492919922
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 4 7594
# Done distance matrix: 0.0018115043640136719
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 7594
# Done distance matrix: 0.0007874965667724609
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 7
# 2 7594
# Done distance matrix: 0.0007898807525634766
# Child 7 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 10 7594
# Done distance matrix: 0.004876136779785156
# Child 10 There were no points close enough
# Starting Child 11
# 4 7594
# Done distance matrix: 0.0015451908111572266
# Child 11 There were no points close enough
# Starting Child 12
# 2 7594
# Done distance matrix: 0.0008254051208496094
# Child 12 There were no points close enough
# Starting Child 13
# 9 7594
# Done distance matrix: 0.004250764846801758
# Child 13 There were no points close enough
# Starting Child 14
# 2 7594
# Done distance matrix: 0.0008790493011474609
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 16
# 2 7594
# Done distance matrix: 0.0008282661437988281
# Child 16 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 2 7594
# Done distance matrix: 0.0008161067962646484
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 2 7594
# Done distance matrix: 0.0008261203765869141
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 1
# 2 7594
# Done distance matrix: 0.00092315673828125
# Child 1 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 2
# 2 7594
# Done distance matrix: 0.0007982254028320312
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 3
# 2 7594
# Done distance matrix: 0.0007905960083007812
# Child 3 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 4
# 4 7594
# Done distance matrix: 0.001561880111694336
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 7594
# Done distance matrix: 0.0007843971252441406
# Child 5 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 7
# 2 7594
# Done distance matrix: 0.0007843971252441406
# Child 7 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 10
# 10 7594
# Done distance matrix: 0.0036978721618652344
# Child 10 There were no points close enough
# Starting Child 11
# 4 7594
# Done distance matrix: 0.001489877700805664
# Child 11 There were no points close enough
# Starting Child 12
# 2 7594
# Done distance matrix: 0.0007917881011962891
# Child 12 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 13
# 9 7594
# Done distance matrix: 0.0033426284790039062
# Child 13 There were no points close enough
# Starting Child 14
# 2 7594
# Done distance matrix: 0.0008027553558349609
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 16
# 2 7594
# Done distance matrix: 0.0008044242858886719
# Child 16 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 2 7594
# Done distance matrix: 0.0007910728454589844
# Child 17 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 18
# 2 7594
# Done distance matrix: 0.0007948875427246094
# Child 18 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 1
# 2 7594
# Done distance matrix: 0.0009174346923828125
# Done Generating final pairs: 0.006982088088989258
# best_stitch_pair = [   1 6777]
# best_stitch_pair_size = 36133.69277057558
# best_stitch_pair_distance = 2476.398570161262
# best_stitch_pair_size_ratio = 0.6018665692657855
# Starting Child 2
# 2 7594
# Done distance matrix: 0.0009088516235351562
# Done Generating final pairs: 0.012299776077270508
# best_stitch_pair = [   1 6777]
# best_stitch_pair_size = 42469.36953000706
# best_stitch_pair_distance = 2800.400063598087
# best_stitch_pair_size_ratio = 0.8827376349231527
# Starting Child 3
# 2 7594
# Done distance matrix: 0.0009608268737792969
# Done Generating final pairs: 0.014549016952514648
# best_stitch_pair = [   0 6777]
# best_stitch_pair_size = 37038.78945049437
# best_stitch_pair_distance = 2515.626057263547
# best_stitch_pair_size_ratio = 0.641991007216838
# Starting Child 4
# 4 7594
# Done distance matrix: 0.0016629695892333984
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 5
# 2 7594
# Done distance matrix: 0.0008521080017089844
# Done Generating final pairs: 0.015285968780517578
# best_stitch_pair = [   0 6388]
# best_stitch_pair_size = 47671.25429919041
# best_stitch_pair_distance = 3303.7440506026473
# best_stitch_pair_size_ratio = 0.36203969829494986
# Starting Child 7
# 2 7594
# Done distance matrix: 0.0009801387786865234
# Done Generating final pairs: 0.016115427017211914
# best_stitch_pair = [   1 7309]
# best_stitch_pair_size = 22627.416997969514
# best_stitch_pair_distance = 3303.951220509417
# best_stitch_pair_size_ratio = 0.6666666666666684
# Starting Child 10
# 10 7594
# Done distance matrix: 0.0038826465606689453
# Done Generating final pairs: 0.019821882247924805
# best_stitch_pair = [   1 4923]
# best_stitch_pair_size = 46823.27006472524
# best_stitch_pair_distance = 3325.2340204639363
# best_stitch_pair_size_ratio = 0.7821300219248307
# Starting Child 11
# 4 7594
# Done distance matrix: 0.0016627311706542969
# Done Generating final pairs: 0.057872772216796875
# best_stitch_pair = [   2 4926]
# best_stitch_pair_size = 97640.89964982042
# best_stitch_pair_distance = 3110.2619432891725
# best_stitch_pair_size_ratio = 0.18318350638032782
# Starting Child 12
# 2 7594
# Done distance matrix: 0.002315998077392578
# Done Generating final pairs: 0.022608518600463867
# best_stitch_pair = [   0 2111]
# best_stitch_pair_size = 17627.40969522874
# best_stitch_pair_distance = 2838.529431524875
# best_stitch_pair_size_ratio = 0.5578415071975038
# Starting Child 13
# 9 7594
# Done distance matrix: 0.0033898353576660156
# Done Generating final pairs: 0.1876201629638672
# best_stitch_pair = [   6 2077]
# best_stitch_pair_size = 259674.6825489339
# best_stitch_pair_distance = 3109.097251484841
# best_stitch_pair_size_ratio = 0.1273110569429369
# Starting Child 14
# 2 7594
# Done distance matrix: 0.0009126663208007812
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 16
# 2 7594
# Done distance matrix: 0.0007865428924560547
# Child 16 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 17
# 2 7594
# Done distance matrix: 0.0007648468017578125
# Done Generating final pairs: 0.005529165267944336
# best_stitch_pair = [   0 3036]
# best_stitch_pair_size = 26680.73883784068
# best_stitch_pair_distance = 2821.044213009365
# best_stitch_pair_size_ratio = 0.5514910657322721
# Starting Child 18
# 2 7594
# Done distance matrix: 0.0009493827819824219
# Done Generating final pairs: 0.00726771354675293
# best_stitch_pair = [   0 6777]
# best_stitch_pair_size = 32513.306050900457
# best_stitch_pair_distance = 2632.313082748382
# best_stitch_pair_size_ratio = 0.44136881746157586
# repeat_main_facets = [6777]
# child_mesh_double_indexes = [1, 2, 3, 18]
# min_child = 1, max_ratio = 2476.398570161262
# child_meshes_stitch_facets = {1: [1, 6777], 5: [0, 6388], 7: [1, 7309], 10: [1, 4923], 11: [2, 4926], 12: [0, 2111], 13: [6, 2077], 17: [0, 3036]}
# ---Stitching child 1 with pair: [1, 6777]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 199175, starting edge 2nd facet= 381503,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 3
# About to add faces
# Finished adding faces: 4.506111145019531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06649470329284668
# returned from stitch mesh: 1.1694369316101074
# Finished stitching child 1 : 1.3625216484069824
# ---Stitching child 5 with pair: [0, 6388]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 322151, starting edge 2nd facet= 381565,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 4.458427429199219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.040601253509521484
# returned from stitch mesh: 0.9463088512420654
# Finished stitching child 5 : 1.0760037899017334
# ---Stitching child 7 with pair: [1, 7309]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2447, starting edge 2nd facet= 381612,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 5.507469177246094e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.013046979904174805
# returned from stitch mesh: 0.8357129096984863
# Finished stitching child 7 : 0.9831922054290771
# ---Stitching child 10 with pair: [1, 4923]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 115359, starting edge 2nd facet= 381741,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 2.4557113647460938e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0042819976806640625
# returned from stitch mesh: 0.8276631832122803
# Finished stitching child 10 : 0.924166202545166
# ---Stitching child 11 with pair: [2, 4926]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 175428, starting edge 2nd facet= 381777,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 2.384185791015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003937959671020508
# returned from stitch mesh: 0.7084600925445557
# Finished stitching child 11 : 0.865391731262207
# ---Stitching child 12 with pair: [0, 2111]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 139089, starting edge 2nd facet= 381807,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.09808349609375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.003968238830566406
# returned from stitch mesh: 0.6539661884307861
# Finished stitching child 12 : 0.8263940811157227
# ---Stitching child 13 with pair: [6, 2077]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 247846, starting edge 2nd facet= 381816,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 19
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 3, remainder = 4
# About to add faces
# Finished adding faces: 2.002716064453125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011474370956420898
# returned from stitch mesh: 0.6602387428283691
# Finished stitching child 13 : 0.6975500583648682
# ---Stitching child 17 with pair: [0, 3036]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 185741, starting edge 2nd facet= 381931,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 5, remainder = 0
# About to add faces
# Finished adding faces: 2.47955322265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010308504104614258
# returned from stitch mesh: 0.4544236660003662
# Finished stitching child 17 : 0.5170745849609375
# ***************Finished big stitching iteration: 8.08962869644165***************
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 2
# 2 7611
# Done distance matrix: 0.0009074211120605469
# Done Generating final pairs: 0.007917404174804688
# best_stitch_pair = [   0 5451]
# best_stitch_pair_size = 35632.128163906884
# best_stitch_pair_distance = 3054.1863192721703
# best_stitch_pair_size_ratio = 0.7894687111368434
# Starting Child 3
# 2 7611
# Done distance matrix: 0.00090789794921875
# Done Generating final pairs: 0.005934476852416992
# best_stitch_pair = [   1 6181]
# best_stitch_pair_size = 26051.651244078224
# best_stitch_pair_distance = 2826.009320554246
# best_stitch_pair_size_ratio = 0.798955005448698
# Starting Child 4
# 4 7611
# Done distance matrix: 0.001644134521484375
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 2 7611
# Done distance matrix: 0.0009312629699707031
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 16
# 2 7611
# Done distance matrix: 0.0007915496826171875
# Done Generating final pairs: 0.003354787826538086
# best_stitch_pair = [   1 7592]
# best_stitch_pair_size = 22027.41313633648
# best_stitch_pair_distance = 2389.384073604428
# best_stitch_pair_size_ratio = 0.8247680468060674
# Starting Child 18
# 2 7611
# Done distance matrix: 0.0009157657623291016
# Done Generating final pairs: 0.003876209259033203
# best_stitch_pair = [   0 6744]
# best_stitch_pair_size = 23643.181998720345
# best_stitch_pair_distance = 2675.4152929654024
# best_stitch_pair_size_ratio = 0.7274039064423569
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [0, 5451], 3: [1, 6181], 16: [1, 7592], 18: [0, 6744]}
# ---Stitching child 2 with pair: [0, 5451]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 184255, starting edge 2nd facet= 381985,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 29
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 5
# About to add faces
# Finished adding faces: 4.792213439941406e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012725353240966797
# returned from stitch mesh: 0.8221707344055176
# Finished stitching child 2 : 0.9845192432403564
# ---Stitching child 3 with pair: [1, 6181]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 280506, starting edge 2nd facet= 382021,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 22
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 4, remainder = 2
# About to add faces
# Finished adding faces: 2.5510787963867188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.011120319366455078
# returned from stitch mesh: 0.6651196479797363
# Finished stitching child 3 : 0.8538978099822998
# ---Stitching child 16 with pair: [1, 7592]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 381740, starting edge 2nd facet= 382032,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 4, remainder = 0
# About to add faces
# Finished adding faces: 3.123283386230469e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.012684106826782227
# returned from stitch mesh: 0.46890687942504883
# Finished stitching child 16 : 0.5445156097412109
# ---Stitching child 18 with pair: [0, 6744]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 135372, starting edge 2nd facet= 382085,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 3.0040740966796875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023375272750854492
# returned from stitch mesh: 0.7861464023590088
# Finished stitching child 18 : 0.880018949508667
# ***************Finished big stitching iteration: 4.7619218826293945***************
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 4
# 4 7611
# Done distance matrix: 0.001954793930053711
# Child 4 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 14
# 2 7611
# Done distance matrix: 0.0011570453643798828
# Child 14 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 4
# 4 7611
# Done distance matrix: 0.0016858577728271484
# Done Generating final pairs: 0.004872560501098633
# best_stitch_pair = [   0 3900]
# best_stitch_pair_size = 24393.2650158829
# best_stitch_pair_distance = 3934.8379970797746
# best_stitch_pair_size_ratio = 0.41305303342894883
# Starting Child 14
# 2 7611
# Done distance matrix: 0.0009171962738037109
# Done Generating final pairs: 0.005466938018798828
# best_stitch_pair = [   1 7582]
# best_stitch_pair_size = 28057.997077482178
# best_stitch_pair_distance = 3537.4463623602805
# best_stitch_pair_size_ratio = 0.8235294117647046
# repeat_main_facets = []
# child_meshes_stitch_facets = {4: [0, 3900], 14: [1, 7582]}
# ---Stitching child 4 with pair: [0, 3900]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 230609, starting edge 2nd facet= 382106,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.384185791015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.00468134880065918
# returned from stitch mesh: 0.8037242889404297
# Finished stitching child 4 : 0.9497554302215576
# ---Stitching child 14 with pair: [1, 7582]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 381458, starting edge 2nd facet= 382132,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 23
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 6.365776062011719e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.023728132247924805
# returned from stitch mesh: 0.730710506439209
# Finished stitching child 14 : 0.9100918769836426
# ***************Finished big stitching iteration: 1.9623548984527588***************
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 0
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 21.628675937652588
# Total time for restitching = 21.630821704864502
# missed_children = [0.0]
# Whole stitching function complete: 87.1263678073883
#
#
#
# *****Running Neuron Stitcher for 648518346349476159**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349476159_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 1.926196813583374
# Number of outside child meshes =  3
# Main mesh and outside child meshes make up 0.8452781953349491% of original mesh
#  face length 799982 using optimized facets with 3 neighbors
# Filtering edges by size finished: 30.365564107894897, facet # = 44118
# Filtering by convexity and getting centers took: 40.56018042564392, facet # = 7528
# Finished 7528 facets for main mesh: 73.3911337852478
# Filtering edges by size finished: 1.2690730094909668, facet # = 2301
# Filtering by convexity and getting centers took: 2.1044883728027344, facet # = 387
# Filtering edges by size finished: 0.2883484363555908, facet # = 1180
# Filtering by convexity and getting centers took: 0.7756047248840332, facet # = 231
# Filtering edges by size finished: 0.0044062137603759766, facet # = 2
# Filtering by convexity and getting centers took: 0.0025701522827148438, facet # = 2
# Total time for facets: 77.93979477882385
# Zero faceted faces = []
# Starting Child 0
# 387 7528
# Done distance matrix: 0.3015320301055908
# Done Generating final pairs: 0.39641332626342773
# best_stitch_pair = [  29 4824]
# best_stitch_pair_size = 3679217.904050482
# best_stitch_pair_distance = 185.75169007633514
# best_stitch_pair_size_ratio = 0.9914047027712556
# Starting Child 1
# returning z greater max
# skipped by bounding box filter
# Starting Child 2
# 2 7528
# Done distance matrix: 0.0010497570037841797
# Done Generating final pairs: 0.007092475891113281
# best_stitch_pair = [   1 5218]
# best_stitch_pair_size = 28394.062099650426
# best_stitch_pair_distance = 1712.3053713182917
# best_stitch_pair_size_ratio = 0.6511212052709495
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [29, 4824], 2: [1, 5218]}
# ---Stitching child 0 with pair: [29, 4824]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 52584, starting edge 2nd facet= 406039,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 56
# Starting Organizing vertices for side 1
# edge_1_order done, len = 49
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 7
# About to add faces
# Finished adding faces: 0.0001380443572998047
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004484891891479492
# returned from stitch mesh: 1.2165870666503906
# Finished stitching child 0 : 1.2878518104553223
# ---Stitching child 2 with pair: [1, 5218]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 14265, starting edge 2nd facet= 409536,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 5.435943603515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004340171813964844
# returned from stitch mesh: 0.7095062732696533
# Finished stitching child 2 : 0.770939826965332
# ***************Finished big stitching iteration: 2.66241192817688***************
# Starting Child 1
# 231 7913
# Done distance matrix: 0.08625078201293945
# Done Generating final pairs: 0.09109973907470703
# best_stitch_pair = [  16 7851]
# best_stitch_pair_size = 791385.736900726
# best_stitch_pair_distance = 303.9242193248852
# best_stitch_pair_size_ratio = 0.9806437598779415
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [16, 7851]}
# ---Stitching child 1 with pair: [16, 7851]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 405163, starting edge 2nd facet= 413684,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 5.030632019042969e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.004824638366699219
# returned from stitch mesh: 0.43024706840515137
# Finished stitching child 1 : 0.4782216548919678
# ***************Finished big stitching iteration: 1.2704846858978271***************
# All children have been processed
# total_stitch_processing_time = 3.9337570667266846
# Total time for restitching = 3.9361412525177
# missed_children = []
# Whole stitching function complete: 85.6276798248291
#
#
#
# *****Running Neuron Stitcher for 648518346349478330**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478330_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 5.804146766662598
# Number of outside child meshes =  25
# Main mesh and outside child meshes make up 0.956701376463532% of original mesh
#  face length 2252750 using optimized facets with 3 neighbors
# Filtering edges by size finished: 69.72030568122864, facet # = 119656
# Filtering by convexity and getting centers took: 89.42312669754028, facet # = 24191
# Finished facets for main mesh: 165.88379096984863 with facet length = 24191
# Finished 24191 facets for main mesh: 165.8842089176178
# Filtering edges by size finished: 0.007027864456176758, facet # = 29
# Filtering by convexity and getting centers took: 0.014465570449829102, facet # = 23
# Filtering edges by size finished: 0.04864168167114258, facet # = 31
# Filtering by convexity and getting centers took: 0.03857874870300293, facet # = 4
# Filtering edges by size finished: 0.007962942123413086, facet # = 16
# Filtering by convexity and getting centers took: 0.007946491241455078, facet # = 6
# Filtering edges by size finished: 0.0062427520751953125, facet # = 13
# Filtering by convexity and getting centers took: 0.006175518035888672, facet # = 13
# Filtering edges by size finished: 0.0014541149139404297, facet # = 6
# Filtering by convexity and getting centers took: 0.0030820369720458984, facet # = 5
# Filtering edges by size finished: 0.22781682014465332, facet # = 740
# Filtering by convexity and getting centers took: 0.3476107120513916, facet # = 187
# Filtering edges by size finished: 0.032770395278930664, facet # = 205
# Filtering by convexity and getting centers took: 0.06872224807739258, facet # = 70
# Filtering edges by size finished: 0.6455225944519043, facet # = 1520
# Filtering by convexity and getting centers took: 0.9114532470703125, facet # = 167
# Filtering edges by size finished: 0.0027971267700195312, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0029778480529785156, facet # = 2
# Filtering edges by size finished: 0.0027348995208740234, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002645730972290039, facet # = 2
# Filtering edges by size finished: 0.06962275505065918, facet # = 367
# Filtering by convexity and getting centers took: 0.25020790100097656, facet # = 123
# Filtering edges by size finished: 0.002744913101196289, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0024726390838623047, facet # = 2
# Filtering edges by size finished: 0.0033473968505859375, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002662181854248047, facet # = 2
# Filtering edges by size finished: 0.0026755332946777344, facet # = 2
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0023958683013916016, facet # = 2
# Filtering edges by size finished: 0.0018062591552734375, facet # = 6
# Filtering by convexity and getting centers took: 0.003739595413208008, facet # = 6
# Filtering edges by size finished: 0.0023899078369140625, facet # = 2
# ...
# Done Generating final pairs: 0.15540432929992676
# best_stitch_pair = [    9 48915]
# best_stitch_pair_size = 504103.08037856687
# best_stitch_pair_distance = 266.91200957053877
# best_stitch_pair_size_ratio = 0.45572314099800953
# Starting Child 94
# 10 49126
# Done distance matrix: 0.0239102840423584
# Done Generating final pairs: 0.033237457275390625
# best_stitch_pair = [    1 48957]
# best_stitch_pair_size = 191575.957617276
# best_stitch_pair_distance = 882.8393193077549
# best_stitch_pair_size_ratio = 0.15389923054183544
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 49126
# Done distance matrix: 0.0020596981048583984
# Child 147 There were no points close enough
# Starting Child 162
# 1 49126
# Done distance matrix: 0.0018658638000488281
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = [48915]
# child_mesh_double_indexes = [0, 93]
# min_child = 93, max_ratio = 266.91200957053877
# child_meshes_stitch_facets = {40: [4, 48469], 43: [0, 48510], 93: [9, 48915], 94: [1, 48957]}
# ---Stitching child 40 with pair: [4, 48469]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1870878, starting edge 2nd facet= 1881250,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 53
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 15
# About to add faces
# Finished adding faces: 9.036064147949219e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06316542625427246
# returned from stitch mesh: 1.936373233795166
# Finished stitching child 40 : 2.273615598678589
# ---Stitching child 43 with pair: [0, 48510]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1870998, starting edge 2nd facet= 1881513,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 2.2649765014648438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05594491958618164
# returned from stitch mesh: 1.8362669944763184
# Finished stitching child 43 : 2.12550950050354
# ---Stitching child 93 with pair: [9, 48915]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1878579, starting edge 2nd facet= 1881803,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 38
# Starting Organizing vertices for side 1
# edge_1_order done, len = 20
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 18
# About to add faces
# Finished adding faces: 5.841255187988281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05694127082824707
# returned from stitch mesh: 1.803091287612915
# Finished stitching child 93 : 2.1290106773376465
# ---Stitching child 94 with pair: [1, 48957]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1878791, starting edge 2nd facet= 1882414,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 28
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 3, remainder = 4
# About to add faces
# Finished adding faces: 2.9087066650390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05744457244873047
# returned from stitch mesh: 1.7280030250549316
# Finished stitching child 94 : 2.0231590270996094
# ***************Finished big stitching iteration: 12.76910400390625***************
# Starting Child 0
# 778 49245
# Done distance matrix: 1.342336654663086
# Done Generating final pairs: 1.3684329986572266
# best_stitch_pair = [   28 49237]
# best_stitch_pair_size = 574248.1504362405
# best_stitch_pair_distance = 193.91966207726216
# best_stitch_pair_size_ratio = 0.276615560270275
# Starting Child 2
# 2 49245
# Done distance matrix: 0.025271177291870117
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 42
# 11 49245
# Done distance matrix: 0.016457080841064453
# Done Generating final pairs: 0.025922298431396484
# best_stitch_pair = [    5 49182]
# best_stitch_pair_size = 788984.5017849179
# best_stitch_pair_distance = 658.3292088621071
# best_stitch_pair_size_ratio = 0.42762398328195267
# Starting Child 73
# 1 49245
# Done distance matrix: 0.0019822120666503906
# Child 73 There were no points close enough
# Starting Child 78
# 1 49245
# Done distance matrix: 0.0016181468963623047
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 49245
# Done distance matrix: 0.001505136489868164
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 49245
# Done distance matrix: 0.0017969608306884766
# Child 147 There were no points close enough
# Starting Child 162
# 1 49245
# Done distance matrix: 0.0017702579498291016
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [28, 49237], 42: [5, 49182]}
# ---Stitching child 0 with pair: [28, 49237]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1882478, starting edge 2nd facet= 1882737,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 31
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 1
# About to add faces
# Finished adding faces: 4.2438507080078125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05478668212890625
# returned from stitch mesh: 1.776167869567871
# Finished stitching child 0 : 2.0843265056610107
# ---Stitching child 42 with pair: [5, 49182]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1881514, starting edge 2nd facet= 1896631,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 2.3365020751953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.05566906929016113
# returned from stitch mesh: 1.7543795108795166
# Finished stitching child 42 : 2.0570483207702637
# ***************Finished big stitching iteration: 7.617647409439087***************
# Starting Child 2
# 2 50030
# Done distance matrix: 0.008356094360351562
# Child 2 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 73
# 1 50030
# Done distance matrix: 0.004398822784423828
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.0033681392669677734
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.0033578872680664062
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.0031249523162841797
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.0031325817108154297
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 2
# 2 50030
# Done distance matrix: 0.00448298454284668
# Done Generating final pairs: 0.0069577693939208984
# best_stitch_pair = [    0 46871]
# best_stitch_pair_size = 23501.491771274807
# best_stitch_pair_distance = 2205.0878910047245
# best_stitch_pair_size_ratio = 0.8488707422521847
# Starting Child 73
# 1 50030
# Done distance matrix: 0.0016069412231445312
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.0013992786407470703
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.0015344619750976562
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.0016107559204101562
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.0014295578002929688
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# repeat_main_facets = []
# child_meshes_stitch_facets = {2: [0, 46871]}
# ---Stitching child 2 with pair: [0, 46871]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1841610, starting edge 2nd facet= 1896744,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.4543533325195312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.010434865951538086
# returned from stitch mesh: 1.3179895877838135
# Finished stitching child 2 : 1.5393755435943604
# ***************Finished big stitching iteration: 1.9693939685821533***************
# Starting Child 73
# 1 50030
# Done distance matrix: 0.002002716064453125
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.016672849655151367
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.0019216537475585938
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.0017459392547607422
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.0016396045684814453
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 73
# 1 50030
# Done distance matrix: 0.0017597675323486328
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.001653432846069336
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.0016226768493652344
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.0017483234405517578
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.0017917156219482422
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 73
# 1 50030
# Done distance matrix: 0.0023560523986816406
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.002379179000854492
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.0024170875549316406
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.0024755001068115234
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.002138853073120117
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 73
# 1 50030
# Done distance matrix: 0.0021936893463134766
# Child 73 There were no points close enough
# Starting Child 78
# 1 50030
# Done distance matrix: 0.0020110607147216797
# Child 78 There were no points close enough
# Starting Child 82
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 87
# 1 50030
# Done distance matrix: 0.001976490020751953
# Child 87 There were no points close enough
# Starting Child 89
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 101
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 125
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 135
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 147
# 1 50030
# Done distance matrix: 0.002195596694946289
# Child 147 There were no points close enough
# Starting Child 162
# 1 50030
# Done distance matrix: 0.0019605159759521484
# Child 162 There were no points close enough
# Starting Child 167
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 177
# child_facets_centers for child {i} was 0, so skipping
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 470.8351113796234
# Total time for restitching = 470.8504891395569
# missed_children = [162.0, 101.0, 135.0, 167.0, 73.0, 78.0, 177.0, 82.0, 147.0, 87.0, 89.0, 125.0]
# Whole stitching function complete: 656.398225069046
# 6431.557626962662

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""
# Out:
# "\nThings didn't think about: \n1) if there are no child meshes to be stitched \n2) If there is only one mesh\n\n\n"

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
