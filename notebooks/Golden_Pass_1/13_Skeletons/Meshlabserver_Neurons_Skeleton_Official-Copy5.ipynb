# %%
"""
Will generate the skeletons for all of the
Neurites

Process: 
1) Pull from ta3p100.Mesh
-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS
2) Voxelize the mesh 
3) Export the mesh to an off file
4) Clean up the mesh using:
a. smoothing normals
b. Poisson surface reconstruction
c. Extra remove duplicate filters
5) Send through skeletonization
6) Reading in skeleton segments
7) Write key to database

"""
# Out:
# "\nWill generate the skeletons for all of the\nNeurites\n\nProcess: \n1) Pull from ta3p100.Mesh\n-- DO NOT NEED TO FILTER B/C DON'T HAVE LABELS\n2) Voxelize the mesh \n3) Export the mesh to an off file\n4) Clean up the mesh using:\na. smoothing normals\nb. Poisson surface reconstruction\nc. Extra remove duplicate filters\n5) Send through skeletonization\n6) Reading in skeleton segments\n7) Write key to database\n\n"

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/temp_meshlab")) == False:
    os.mkdir("temp_meshlab")

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
#get keysource:
ta3p100.Mesh() & ta3p100.Neurite() #32207 tuples
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 2              64851834634135 28754          57350          =BLOB=     =BLOB=
# 2              64851834634135 11192          22282          =BLOB=     =BLOB=
# 2              64851834634135 58449          116104         =BLOB=     =BLOB=
# 2              64851834634135 24919          49578          =BLOB=     =BLOB=
# 2              64851834634135 37179          74128          =BLOB=     =BLOB=
# 2              64851834634135 37788          75374          =BLOB=     =BLOB=
# 2              64851834634135 20204          40278          =BLOB=     =BLOB=
# 2              64851834634135 15522          30788          =BLOB=     =BLOB=
# 2              64851834634135 45964          91650          =BLOB=     =BLOB=
# 2              64851834634135 21520          42882          =BLOB=     =BLOB=
# 2              64851834634135 12322          24626          =BLOB=     =BLOB=
# 2              64851834634135 75579          150562         =BLOB=     =BLOB=
# 2              64851834634135 16502          32932          =BLOB=     =BLOB=
# 2              64851834634135 26033          51854          =BLOB=     =BLOB=
# 2              64851834634135 29746          59138          =BLOB=     =BLOB=
# 2              64851834634135 23521          46928          =BLOB=     =BLOB=
# 2              64851834634135 29968          59422          =BLOB=     =BLOB=
# 2              64851834634135 15603          31082          =BLOB=     =BLOB=
# 2              64851834634135 42781          85094          =BLOB=     =BLOB=
# 2              64851834634135 18804          37506          =BLOB=     =BLOB=
#    ...
#  (32207 tuples)

# %%
def meshlab_shrinkwrap(key):
    
    file_loc = pathlib.Path.cwd() / "temp_meshlab"
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    midoutput_mesh = path_and_filename + "_mid.off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_script.mlx"
    meshlab_script_rem_dupl = str(pathlib.Path.cwd()) + "/" + "remeshing_script-Remove.mlx"
    #send to meshlabserver
    print("starting meshlabserver Poisson surface reconstruction")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      midoutput_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass Poisson')
    #print(type)
     
    
    #do another call to remove the final duplicate vertices
    print("starting meshlabserver cleaning")
    subprocess_result_2 = run_meshlab_script(meshlab_script_rem_dupl,
                      midoutput_mesh,
                      output_mesh)
    #print("Cleaning subprocess_result= "+ str(subprocess_result_2))
    
    if str(subprocess_result_2)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not get pass cleaning')
    
    
    return output_mesh

# %%
#don't need the vertices for this one because not doing any filtering

@schema
class NeuriteSkeletons(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the skeleton was generated
    ---
    n_branches   :int unsigned #number of edges stored
    branches     :longblob #array storing vertices of edges and each seperated by Nan
    """
    
    key_source = ta3p100.Mesh() & ta3p100.Neurite() 
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        print("Starting on "+str(key["segment_id"]))
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        
        file_loc = pathlib.Path.cwd() / "temp_meshlab"
        filename = "neuron_" + str(key["segment_id"])
        path_and_filename = str(file_loc / filename)
        
        #get the mesh of the neurite
        new_key = dict(segmentation=key["segmentation"],
                       segment_id=key["segment_id"])
        mesh = (ta3p100.Mesh & new_key).fetch1()
        print(f"Step 1: Retrieving Mesh: {time.time() - start_time}")
        
        #Do voxelization
        start_time = time.time()
        mesh = trimesh_io.Mesh(vertices=mesh["vertices"], faces=mesh["triangles"])
        voxels = mesh.voxelized(500)
        voxel_mesh = voxels.as_boxes()
        print(f"Step 2: Voxelization: {time.time() - start_time}")
        
        #Exporting the Voxelization as an off file for meshlabserver
        start_time = time.time()
        #try the inline printing method:
        with open(os.devnull, 'w') as devnull:
            with contextlib.redirect_stdout(devnull):
                voxel_mesh.export(str(path_and_filename) + ".off")
        print(f"Step 3: Exporting Voxel Off function: {time.time() - start_time}")
        
        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_shrinkwrap(key)
        print(f"Step 4: Meshlab shrinkwrapping: {time.time() - start_time}")
        
        #Create the skeleton and retrieve it from the generated file
        #skeletonize the mesh
        start_time = time.time()
        #print("starting creating skeleton")
        return_value = cm.calcification(output_mesh[:-4])
        #print("calcif_return_value = " + str(return_value))
        
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
        
        #read in the skeleton files into an array
        start_time = time.time()
        bone_array = read_skeleton_flat(output_mesh[:-4]+"_skeleton.cgal")
        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Reading in Skeleton: {time.time() - start_time}")
        
              
        start_time = time.time()
        new_key["n_branches"] = len(bone_array)
        new_key["branches"] = bone_array
        #new_key["branches"] = []
        
        
        new_key["time_updated"]=str(datetime.datetime.now())
        #print(new_key)
        #if all goes well then write to database
        self.insert1(new_key)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary and erased files: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
start = time.time()
NeuriteSkeletons.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# Starting on 648518346341352392
# Step 1: Retrieving Mesh: 0.030025720596313477
# Step 2: Voxelization: 0.1255664825439453
# Step 3: Exporting Voxel Off function: 0.0742788314819336
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.1946165561676025
# Step 4: Generating Skeleton: 1.4140489101409912
# Step 5: Reading in Skeleton: 0.0068738460540771484
# Step 6: Inserting dictionary and erased files: 0.02830052375793457
# Total time: 7.876701354980469
#
#
#
# Starting on 648518346341352414
# Step 1: Retrieving Mesh: 0.02709484100341797
# Step 2: Voxelization: 0.058983802795410156
# Step 3: Exporting Voxel Off function: 0.03191828727722168
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.466506004333496
# Step 4: Generating Skeleton: 0.773789644241333
# Step 5: Reading in Skeleton: 0.003494739532470703
# Step 6: Inserting dictionary and erased files: 0.021499156951904297
# Total time: 5.386981248855591
#
#
#
# Starting on 648518346341352475
# Step 1: Retrieving Mesh: 0.027698516845703125
# Step 2: Voxelization: 0.07116556167602539
# Step 3: Exporting Voxel Off function: 0.04231595993041992
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.230539560317993
# Step 4: Generating Skeleton: 0.3198423385620117
# Step 5: Reading in Skeleton: 0.0021483898162841797
# Step 6: Inserting dictionary and erased files: 0.023741483688354492
# Total time: 4.719738721847534
#
#
#
# Starting on 648518346341352551
# Step 1: Retrieving Mesh: 0.03934836387634277
# Step 2: Voxelization: 0.09914803504943848
# Step 3: Exporting Voxel Off function: 0.07916045188903809
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.924264669418335
# Step 4: Generating Skeleton: 0.6303658485412598
# Step 5: Reading in Skeleton: 0.003412008285522461
# Step 6: Inserting dictionary and erased files: 0.02677607536315918
# Total time: 5.805530309677124
#
#
#
# Starting on 648518346341352629
# Step 1: Retrieving Mesh: 0.04423975944519043
# Step 2: Voxelization: 0.06204557418823242
# Step 3: Exporting Voxel Off function: 0.023215770721435547
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7266440391540527
# Step 4: Generating Skeleton: 0.17992019653320312
# Step 5: Reading in Skeleton: 0.0012030601501464844
# Step 6: Inserting dictionary and erased files: 0.023810386657714844
# Total time: 4.06386661529541
#
#
#
# Starting on 648518346341352730
# Step 1: Retrieving Mesh: 0.039107561111450195
# Step 2: Voxelization: 0.08390688896179199
# Step 3: Exporting Voxel Off function: 0.05272340774536133
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.731504201889038
# Step 4: Generating Skeleton: 0.34325122833251953
# Step 5: Reading in Skeleton: 0.002064943313598633
# Step 6: Inserting dictionary and erased files: 0.02489924430847168
# Total time: 5.279021263122559
#
#
#
# Starting on 648518346341352785
# Step 1: Retrieving Mesh: 0.06161046028137207
# Step 2: Voxelization: 0.09450316429138184
# Step 3: Exporting Voxel Off function: 0.04427981376647949
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.984957456588745
# Step 4: Generating Skeleton: 0.7278118133544922
# Step 5: Reading in Skeleton: 0.0030336380004882812
# Step 6: Inserting dictionary and erased files: 0.022312164306640625
# Total time: 5.940373659133911
#
#
#
# Starting on 648518346341352835
# Step 1: Retrieving Mesh: 0.027899503707885742
# Step 2: Voxelization: 0.06405878067016602
# Step 3: Exporting Voxel Off function: 0.03674507141113281
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8337690830230713
# Step 4: Generating Skeleton: 0.6011650562286377
# Step 5: Reading in Skeleton: 0.003216981887817383
# Step 6: Inserting dictionary and erased files: 0.02024388313293457
# Total time: 4.589318752288818
#
#
#
# Starting on 648518346341352891
# Step 1: Retrieving Mesh: 0.06807136535644531
# Step 2: Voxelization: 0.29593992233276367
# Step 3: Exporting Voxel Off function: 0.11174988746643066
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.667154312133789
# Step 4: Generating Skeleton: 1.5139174461364746
# Step 5: Reading in Skeleton: 0.002710580825805664
# Step 6: Inserting dictionary and erased files: 0.02261972427368164
# Total time: 6.684200763702393
#
#
#
# Starting on 648518346341353042
# Step 1: Retrieving Mesh: 0.037110328674316406
# Step 2: Voxelization: 0.11741352081298828
# Step 3: Exporting Voxel Off function: 0.07656097412109375
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.225704193115234
# Step 4: Generating Skeleton: 0.7563769817352295
# Step 5: Reading in Skeleton: 0.006002187728881836
# Step 6: Inserting dictionary and erased files: 0.03426671028137207
# Total time: 6.256901979446411
#
#
#
# Starting on 648518346341353185
# Step 1: Retrieving Mesh: 0.02986931800842285
# Step 2: Voxelization: 0.07511043548583984
# Step 3: Exporting Voxel Off function: 0.02654433250427246
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7897045612335205
# Step 4: Generating Skeleton: 0.31432366371154785
# Step 5: Reading in Skeleton: 0.001415252685546875
# Step 6: Inserting dictionary and erased files: 0.024852752685546875
# Total time: 4.264863729476929
#
#
#
# Starting on 648518346341353217
# Step 1: Retrieving Mesh: 0.0481877326965332
# Step 2: Voxelization: 0.0460965633392334
# Step 3: Exporting Voxel Off function: 0.02188849449157715
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.7742552757263184
# Step 4: Generating Skeleton: 0.307110071182251
# Step 5: Reading in Skeleton: 0.0015513896942138672
# Step 6: Inserting dictionary and erased files: 0.02407050132751465
# Total time: 4.225092649459839
#
#
#
# Starting on 648518346341353315
# Step 1: Retrieving Mesh: 0.05443286895751953
# Step 2: Voxelization: 0.05762195587158203
# Step 3: Exporting Voxel Off function: 0.037550926208496094
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.961827278137207
# Step 4: Generating Skeleton: 0.25688838958740234
# Step 5: Reading in Skeleton: 0.001531839370727539
# Step 6: Inserting dictionary and erased files: 0.02309870719909668
# Total time: 4.395756483078003
#
#
#
# Starting on 648518346341353397
# Step 1: Retrieving Mesh: 0.04689621925354004
# Step 2: Voxelization: 0.10996127128601074
# Step 3: Exporting Voxel Off function: 0.07386207580566406
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.97501802444458
# Step 4: Generating Skeleton: 0.5520200729370117
# Step 5: Reading in Skeleton: 0.0026564598083496094
# Step 6: Inserting dictionary and erased files: 0.02203536033630371
# Total time: 5.785188674926758
#
#
#
# Starting on 648518346341353471
# Step 1: Retrieving Mesh: 0.06926274299621582
# Step 2: Voxelization: 0.0847625732421875
# Step 3: Exporting Voxel Off function: 0.04066729545593262
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.486436367034912
# Step 4: Generating Skeleton: 0.6505312919616699
# Step 5: Reading in Skeleton: 0.0016205310821533203
# Step 6: Inserting dictionary and erased files: 0.03812909126281738
# Total time: 5.373828411102295
#
#
#
# Starting on 648518346341353596
# Step 1: Retrieving Mesh: 0.06257843971252441
# Step 2: Voxelization: 0.09630346298217773
# Step 3: Exporting Voxel Off function: 0.05915498733520508
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.893887042999268
# Step 4: Generating Skeleton: 0.6289470195770264
# Step 5: Reading in Skeleton: 0.003252267837524414
# Step 6: Inserting dictionary and erased files: 0.027390718460083008
# Total time: 5.7739222049713135
#
#
#
# Starting on 648518346341353718
# Step 1: Retrieving Mesh: 0.06529736518859863
# Step 2: Voxelization: 0.20315146446228027
# Step 3: Exporting Voxel Off function: 0.11789512634277344
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 6.8575146198272705
# Step 4: Generating Skeleton: 1.4110517501831055
# Step 5: Reading in Skeleton: 0.0057184696197509766
# Step 6: Inserting dictionary and erased files: 0.02550029754638672
# Total time: 8.69058084487915
#
#
#
# Starting on 648518346341353868
# Step 1: Retrieving Mesh: 0.04958367347717285
# Step 2: Voxelization: 0.09290933609008789
# Step 3: Exporting Voxel Off function: 0.04519248008728027
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.626523017883301
# Step 4: Generating Skeleton: 0.5718317031860352
# Step 5: Reading in Skeleton: 0.0017347335815429688
# Step 6: Inserting dictionary and erased files: 0.04543304443359375
# Total time: 5.435968637466431
#
#
#
# Starting on 648518346341353909
# Step 1: Retrieving Mesh: 0.06758284568786621
# Step 2: Voxelization: 0.12989139556884766
# Step 3: Exporting Voxel Off function: 0.07200884819030762
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.498624324798584
# Step 4: Generating Skeleton: 1.028245210647583
# Step 5: Reading in Skeleton: 0.004160881042480469
# Step 6: Inserting dictionary and erased files: 0.025853633880615234
# Total time: 6.827943801879883
#
#
#
# Starting on 648518346341354068
# Step 1: Retrieving Mesh: 0.04580259323120117
# Step 2: Voxelization: 0.11777758598327637
# Step 3: Exporting Voxel Off function: 0.07246017456054688
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.603343725204468
# Step 4: Generating Skeleton: 0.5903708934783936
# Step 5: Reading in Skeleton: 0.00405120849609375
# Step 6: Inserting dictionary and erased files: 0.024972915649414062
# Total time: 5.4604172706604
#
#
#
# Starting on 648518346341354263
# Step 1: Retrieving Mesh: 0.03956007957458496
# Step 2: Voxelization: 0.07943511009216309
# Step 3: Exporting Voxel Off function: 0.04503941535949707
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.901934385299683
# Step 4: Generating Skeleton: 0.8412468433380127
# Step 5: Reading in Skeleton: 0.0019023418426513672
# Step 6: Inserting dictionary and erased files: 0.028522968292236328
# Total time: 5.939889669418335
#
#
#
# Starting on 648518346341354367
# Step 1: Retrieving Mesh: 0.027968645095825195
# Step 2: Voxelization: 0.08599019050598145
# Step 3: Exporting Voxel Off function: 0.04471278190612793
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.447389841079712
# Step 4: Generating Skeleton: 0.3540332317352295
# Step 5: Reading in Skeleton: 0.0031042098999023438
# Step 6: Inserting dictionary and erased files: 0.01933908462524414
# Total time: 4.9837646484375
#
#
#
# Starting on 648518346341354516
# Step 1: Retrieving Mesh: 0.0716104507446289
# Step 2: Voxelization: 0.24068593978881836
# Step 3: Exporting Voxel Off function: 0.13962435722351074
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 7.537886619567871
# Step 4: Generating Skeleton: 1.4471509456634521
# Step 5: Reading in Skeleton: 0.005749702453613281
# Step 6: Inserting dictionary and erased files: 0.02754688262939453
# Total time: 9.47290849685669
#
#
#
# Starting on 648518346341354591
# Step 1: Retrieving Mesh: 0.060285091400146484
# Step 2: Voxelization: 0.05625748634338379
# Step 3: Exporting Voxel Off function: 0.03394651412963867
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.530614376068115
# Step 4: Generating Skeleton: 0.6335251331329346
# Step 5: Reading in Skeleton: 0.0030450820922851562
# Step 6: Inserting dictionary and erased files: 0.02376532554626465
# Total time: 5.3438379764556885
#
#
#
# Starting on 648518346341354673
# Step 1: Retrieving Mesh: 0.05394554138183594
# Step 2: Voxelization: 0.10756540298461914
# Step 3: Exporting Voxel Off function: 0.04847121238708496
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.771240472793579
# Step 4: Generating Skeleton: 0.504847526550293
# Step 5: Reading in Skeleton: 0.0032019615173339844
# Step 6: Inserting dictionary and erased files: 0.031989336013793945
# Total time: 5.523622512817383
#
#
#
# Starting on 648518346341354715
# Step 1: Retrieving Mesh: 0.02687835693359375
# Step 2: Voxelization: 0.06434106826782227
# Step 3: Exporting Voxel Off function: 0.022707223892211914
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8985884189605713
# Step 4: Generating Skeleton: 0.3313109874725342
# Step 5: Reading in Skeleton: 0.001542806625366211
# Step 6: Inserting dictionary and erased files: 0.031571388244628906
# Total time: 4.37904167175293
#
#
#
# Starting on 648518346341354793
# Step 1: Retrieving Mesh: 0.02277541160583496
# Step 2: Voxelization: 0.040990591049194336
# Step 3: Exporting Voxel Off function: 0.02862858772277832
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.8663368225097656
# Step 4: Generating Skeleton: 0.3374795913696289
# Step 5: Reading in Skeleton: 0.0019578933715820312
# Step 6: Inserting dictionary and erased files: 0.026435375213623047
# Total time: 4.326354026794434
#
#
#
# Starting on 648518346341354876
# Step 1: Retrieving Mesh: 0.041124582290649414
# Step 2: Voxelization: 0.0738832950592041
# Step 3: Exporting Voxel Off function: 0.0405428409576416
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.751572132110596
# Step 4: Generating Skeleton: 0.7339472770690918
# Step 5: Reading in Skeleton: 0.004636049270629883
# Step 6: Inserting dictionary and erased files: 0.024620771408081055
# Total time: 5.672501802444458
#
#
#
# Starting on 648518346341354991
# Step 1: Retrieving Mesh: 0.04757237434387207
# Step 2: Voxelization: 0.08386945724487305
# Step 3: Exporting Voxel Off function: 0.04684185981750488
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.279546737670898
# Step 4: Generating Skeleton: 0.3800332546234131
# Step 5: Reading in Skeleton: 0.0019142627716064453
# Step 6: Inserting dictionary and erased files: 0.02608489990234375
# Total time: 4.867130517959595
#
#
#
# Starting on 648518346341355058
# Step 1: Retrieving Mesh: 0.048606157302856445
# Step 2: Voxelization: 0.1374044418334961
# Step 3: Exporting Voxel Off function: 0.07221627235412598
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.731527090072632
# Step 4: Generating Skeleton: 0.450547456741333
# Step 5: Reading in Skeleton: 0.0030744075775146484
# Step 6: Inserting dictionary and erased files: 0.0409698486328125
# Total time: 5.486431360244751
#
#
#
# Starting on 648518346341355181
# Step 1: Retrieving Mesh: 0.03674006462097168
# Step 2: Voxelization: 0.07403159141540527
# Step 3: Exporting Voxel Off function: 0.05195355415344238
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.872020721435547
# Step 4: Generating Skeleton: 0.8167250156402588
# Step 5: Reading in Skeleton: 0.003385305404663086
# Step 6: Inserting dictionary and erased files: 0.02517390251159668
# Total time: 5.88247013092041
#
#
#
# Starting on 648518346341355206
# Step 1: Retrieving Mesh: 0.044893503189086914
# Step 2: Voxelization: 0.11369514465332031
# Step 3: Exporting Voxel Off function: 0.054131269454956055
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.42727255821228
# Step 4: Generating Skeleton: 0.9010469913482666
# Step 5: Reading in Skeleton: 0.0021135807037353516
# Step 6: Inserting dictionary and erased files: 0.02499246597290039
# Total time: 6.570328950881958
#
#
#
# Starting on 648518346341355252
# Step 1: Retrieving Mesh: 0.02613377571105957
# Step 2: Voxelization: 0.07021522521972656
# Step 3: Exporting Voxel Off function: 0.04377460479736328
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.9006845951080322
# Step 4: Generating Skeleton: 0.4097409248352051
# Step 5: Reading in Skeleton: 0.001741647720336914
# Step 6: Inserting dictionary and erased files: 0.02753734588623047
# Total time: 4.484183073043823
#
#
#
# Starting on 648518346341355272
# Step 1: Retrieving Mesh: 0.016608715057373047
# Step 2: Voxelization: 0.06493568420410156
# Step 3: Exporting Voxel Off function: 0.042023658752441406
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.38800311088562
# Step 4: Generating Skeleton: 0.6377220153808594
# Step 5: Reading in Skeleton: 0.0029664039611816406
# Step 6: Inserting dictionary and erased files: 0.026823043823242188
# Total time: 5.182164430618286
#
#
#
# Starting on 648518346341355329
# Step 1: Retrieving Mesh: 0.016129732131958008
# Step 2: Voxelization: 0.0703132152557373
# Step 3: Exporting Voxel Off function: 0.03163003921508789
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.6489779949188232
# Step 4: Generating Skeleton: 0.2505497932434082
# Step 5: Reading in Skeleton: 0.0012705326080322266
# Step 6: Inserting dictionary and erased files: 0.02393054962158203
# Total time: 4.046514987945557
#
#
#
# Starting on 648518346341355387
# Step 1: Retrieving Mesh: 0.029253721237182617
# Step 2: Voxelization: 0.09930562973022461
# Step 3: Exporting Voxel Off function: 0.06366991996765137
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.002474069595337
# Step 4: Generating Skeleton: 0.9801521301269531
# Step 5: Reading in Skeleton: 0.005938529968261719
# Step 6: Inserting dictionary and erased files: 0.024563074111938477
# Total time: 6.207059621810913
#
#
#
# Starting on 648518346341355518
# Step 1: Retrieving Mesh: 0.027814865112304688
# Step 2: Voxelization: 0.07513689994812012
# Step 3: Exporting Voxel Off function: 0.04933905601501465
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.069428205490112
# Step 4: Generating Skeleton: 0.3300628662109375
# Step 5: Reading in Skeleton: 0.002163410186767578
# Step 6: Inserting dictionary and erased files: 0.02832770347595215
# Total time: 4.585319995880127
#
#
#
# Starting on 648518346341355585
# Step 1: Retrieving Mesh: 0.02664470672607422
# Step 2: Voxelization: 0.06007552146911621
# Step 3: Exporting Voxel Off function: 0.04276442527770996
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.0288405418396
# Step 4: Generating Skeleton: 0.3697211742401123
# Step 5: Reading in Skeleton: 0.002383708953857422
# Step 6: Inserting dictionary and erased files: 0.024999618530273438
# Total time: 4.556540489196777
#
#
#
# Starting on 648518346341355655
# Step 1: Retrieving Mesh: 0.03008866310119629
# Step 2: Voxelization: 0.09663176536560059
# Step 3: Exporting Voxel Off function: 0.056780099868774414
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.200855493545532
# Step 4: Generating Skeleton: 0.9207549095153809
# Step 5: Reading in Skeleton: 0.004365682601928711
# Step 6: Inserting dictionary and erased files: 0.023234128952026367
# Total time: 6.334652423858643
#
#
#
# Starting on 648518346341355809
# Step 1: Retrieving Mesh: 0.018787622451782227
# Step 2: Voxelization: 0.04325675964355469
# Step 3: Exporting Voxel Off function: 0.02546095848083496
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.4981582164764404
# Step 4: Generating Skeleton: 0.5794477462768555
# Step 5: Reading in Skeleton: 0.0035505294799804688
# Step 6: Inserting dictionary and erased files: 0.023885726928710938
# Total time: 4.194074392318726
#
#
#
# Starting on 648518346341355846
# Step 1: Retrieving Mesh: 0.04207897186279297
# Step 2: Voxelization: 0.1118781566619873
# Step 3: Exporting Voxel Off function: 0.06286740303039551
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.31389307975769
# Step 4: Generating Skeleton: 0.6194422245025635
# Step 5: Reading in Skeleton: 0.0033447742462158203
# Step 6: Inserting dictionary and erased files: 0.026947498321533203
# Total time: 5.183856010437012
#
#
#
# Starting on 648518346341355933
# Step 1: Retrieving Mesh: 0.03920245170593262
# Step 2: Voxelization: 0.08296728134155273
# Step 3: Exporting Voxel Off function: 0.048026084899902344
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.89011812210083
# Step 4: Generating Skeleton: 0.4313642978668213
# Step 5: Reading in Skeleton: 0.002422809600830078
# Step 6: Inserting dictionary and erased files: 0.022622108459472656
# Total time: 4.518878936767578
#
#
#
# Starting on 648518346341356047
# Step 1: Retrieving Mesh: 0.0290069580078125
# Step 2: Voxelization: 0.07753682136535645
# Step 3: Exporting Voxel Off function: 0.05005502700805664
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.248547792434692
# Step 4: Generating Skeleton: 0.5103297233581543
# Step 5: Reading in Skeleton: 0.0027658939361572266
# Step 6: Inserting dictionary and erased files: 0.030046701431274414
# Total time: 4.9510509967803955
#
#
#
# Starting on 648518346341356070
# Step 1: Retrieving Mesh: 0.027788400650024414
# Step 2: Voxelization: 0.057861328125
# Step 3: Exporting Voxel Off function: 0.032208919525146484
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 3.685680627822876
# Step 4: Generating Skeleton: 0.6069376468658447
# Step 5: Reading in Skeleton: 0.0025489330291748047
# Step 6: Inserting dictionary and erased files: 0.023401260375976562
# Total time: 4.439051389694214
#
#
#
# Starting on 648518346341356160
# Step 1: Retrieving Mesh: 0.02378678321838379
# Step 2: Voxelization: 0.059902191162109375
# Step 3: Exporting Voxel Off function: 0.035164594650268555
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.44866156578064
# Step 4: Generating Skeleton: 0.6828882694244385
# Step 5: Reading in Skeleton: 0.003828287124633789
# Step 6: Inserting dictionary and erased files: 0.02699589729309082
# Total time: 5.28439998626709
#
#
#
# Starting on 648518346341356262
# Step 1: Retrieving Mesh: 0.03716874122619629
# Step 2: Voxelization: 0.09426379203796387
# Step 3: Exporting Voxel Off function: 0.046365976333618164
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.406574964523315
# Step 4: Generating Skeleton: 0.4468066692352295
# Step 5: Reading in Skeleton: 0.0020945072174072266
# Step 6: Inserting dictionary and erased files: 0.026705265045166016
# Total time: 5.0615074634552
#
#
#
# Starting on 648518346341356301
# Step 1: Retrieving Mesh: 0.04688525199890137
# Step 2: Voxelization: 0.14924359321594238
# Step 3: Exporting Voxel Off function: 0.08398580551147461
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 5.371243953704834
# Step 4: Generating Skeleton: 1.4251809120178223
# Step 5: Reading in Skeleton: 0.0014865398406982422
# Step 6: Inserting dictionary and erased files: 0.029870986938476562
# Total time: 7.1109583377838135
#
#
#
# Starting on 648518346341356317
# Step 1: Retrieving Mesh: 0.03242158889770508
# Step 2: Voxelization: 0.1224513053894043
# Step 3: Exporting Voxel Off function: 0.06753230094909668
# starting meshlabserver Poisson surface reconstruction
# starting meshlabserver cleaning
# Step 4: Meshlab shrinkwrapping: 4.588297367095947
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-a4b23312f459> in <module>
#       1 start = time.time()
# ----> 2 NeuriteSkeletons.populate(reserve_jobs=True)
#       3 print(time.time() - start)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     152                     self._allow_insert = True
#     153                     try:
# --> 154                         make(dict(key))
#     155                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     156                         try:
#
# <ipython-input-9-cc4a9e57f3f1> in make(self, key)
#      60         if return_value > 0:
#      61             raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) +
# ---> 62                             ' did not finish... exited with error code: ' + str(return_value))
#      63         print(f"Step 4: Generating Skeleton: {time.time() - start_time}")
#      64
#
# Exception: skeletonization for neuron 648518346341356317 did not finish... exited with error code: 4

# %%
ta3p100.NeuriteSkeletons().delete()
