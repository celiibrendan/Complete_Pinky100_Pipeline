# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from meshparty import trimesh_io

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#will take in and populate the soma table based on the key it gets
def axon_verts_faces(query_key):
    
    table=""
    vertices_soma,triangles_soma = (ta3p100.CompartmentFinal.ComponentFinal() & query_key
                                   & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).fetch("vertex_indices","triangle_indices")

    if len(vertices_soma) > 0:
        print("Soma found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (ta3p100.CleansedMesh & query_key).fetch("vertices","triangles")
    else:
        vertices_soma,triangles_soma = (ta3p100.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]
                                       ).fetch("vertex_indices","triangle_indices")
        if len(vertices_soma) > 0:
            print("Soma found in Orphans")
            vertices_mesh,triangles_mesh = (ta3p100.CleansedMeshOrphan & query_key).fetch("vertices","triangles")
        else:
            print("No Soma exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
            
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY"""
#practice reading in dummy skeleton file
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURITES")) == False:
    os.mkdir("pymesh_NEURITES")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURITES"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURITES"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
ta3p100.Mesh.proj()
# Out:
# *segmentation  *segment_id
# +------------+ +------------+
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
# 1              64851834634135
#    ...
#  (417734 tuples)

# %%
# key_source = (dj.U("segment_id","segmentation") & (ta3p100.CompartmentFinal.ComponentFinal() 
#                                  & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj() )

# %%
#shows that there are no orphans with axons
orphan_key_source = (dj.U("segment_id","segmentation") & (ta3p100.CompartmentOrphan.ComponentOrphan() 
                                 & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj())

# %%
ta3p100.CompartmentOrphan.ComponentOrphan() & "compartment_type='Axon-Soma'"
# Out:
# *segmentation  *segment_id    *decimation_ra *compartment_t *component_ind n_vertex_indic n_triangle_ind vertex_ind triangle_i
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
#
#  (0 tuples)

# %%
@schema
class NeuriteRawPostsynAxon(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    ---
    vertices  :longblob #vertices for extracted axon
    triangles :longblob #faces for extracted axon
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :tinyint unsigned #the amount of segments the neurite was originally split into
    lagest_mesh_perc : float #the percentage of the entire mesh that the largest submesh makes up
     
    """
    
    
    key_source = dj.U("segment_id","segmentation") & (ta3p100.CompartmentFinal.ComponentFinal() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]) 

    
    def make(self, key):
        global_time = time.time()
        
        
        print(str(key["segment_id"])+ ":")
        
        #create return key
        return_key = key.copy()


        #get the vertices and triangles for the Soma
        start_time = time.time()
        vertices_whole, triangles_whole = axon_verts_faces(key)
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")


        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():
            print("Error no axon")


        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])



        #find the bounding box
        # start_time = time.time()
        # mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        # mesh.export(str(key["segment_id"]) + "_axon.off","off")

        #now skeletonize the mesh

        #gets all of the different parts
        mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                            mesh.edges_sparse,
                                                            directed=False,
                                                            return_labels=True)

        new_key["n_bodies"] = count
        values = np.array(labels)
        searchval = 0
        ii = np.where(values == searchval)[0]
        new_key["lagest_mesh_perc"] = len(ii)/len(labels)

        print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")



        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        meshfix = pymeshfix.MeshFix(vertices_whole,triangles_whole)
        meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
        print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

        #print("Step 2: Writing Off File")
        start_time = time.time()
        #write the new mesh to off file
        path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
        print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_fix_manifold(key)
        print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

        print(output_mesh[:-4])

        #send to be skeletonized
        start_time = time.time()
        return_value = cm.calcification(output_mesh[:-4])
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



        #read in the skeleton files into an array
        bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")

        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


        start_time = time.time()
        new_key["n_edges"] = len(bone_array)
        new_key["edges"] = bone_array
        
        new_key["vertices"] = vertices_whole
        new_key["triangles"] = triangles_whole
        
        self.insert1(new_key,skip_duplicates=True)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
#(schema.jobs & "table_name='__neurite_raw_postsyn_axon'").delete()

# %%
start_time = time.time()
NeuriteRawPostsynAxon.populate(reserve_jobs = True)
print(f"Total time = {time.time() - start_time}")
# Out:
# 648518346349471565:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.7725458145141602
# Step 2a: Getting the number of splits: 0.8530449867248535
# Step 2b: Pymesh shrinkwrapping: 7.244632720947266
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7708408832550049
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.924448013305664
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349471565_mls
# Step 5: Generating and reading Skeleton: 4.161513328552246
# Step 6: Inserting dictionary: 0.40302038192749023
# Total time: 15.359115362167358
#
#
#
# 648518346349471910:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349474146_mls
# Step 5: Generating and reading Skeleton: 10.226458549499512
# Step 6: Inserting dictionary: 0.8569736480712891
# Total time: 33.01178550720215
#
#
#
# 648518346349474703:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.8001081943511963
# Step 2a: Getting the number of splits: 0.9706583023071289
# Step 2b: Pymesh shrinkwrapping: 8.61128544807434
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.067584753036499
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 3.0205018520355225
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349474703_mls
# Step 5: Generating and reading Skeleton: 6.542410135269165
# Step 6: Inserting dictionary: 0.5871706008911133
# Total time: 20.801199436187744
#
#
#
# 648518346349478197:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.38471317291259766
# Step 2a: Getting the number of splits: 0.4286177158355713
# Step 2b: Pymesh shrinkwrapping: 1.5285298824310303
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15536832809448242
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0357580184936523
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349478197_mls
# Step 5: Generating and reading Skeleton: 1.1061735153198242
# Step 6: Inserting dictionary: 0.22016406059265137
# Total time: 4.4768431186676025
#
#
#
# 648518346349478348:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6549625396728516
# Step 2a: Getting the number of splits: 0.8145849704742432
# Step 2b: Pymesh shrinkwrapping: 8.873702764511108
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.9132993221282959
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.492276668548584
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349478348_mls
# Step 5: Generating and reading Skeleton: 5.027095079421997
# Step 6: Inserting dictionary: 0.46659398078918457
# Total time: 18.589988470077515
#
#
#
# 648518346349479479:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6480917930603027
# Step 2a: Getting the number of splits: 0.7538957595825195
# Step 2b: Pymesh shrinkwrapping: 8.934685230255127
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7420363426208496
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.3550665378570557
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349479479_mls
# Step 5: Generating and reading Skeleton: 4.12886643409729
# Step 6: Inserting dictionary: 0.4224545955657959
# Total time: 17.338746070861816
#
#
#
# 648518346349491811:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1449129581451416
# Step 2a: Getting the number of splits: 0.152587890625
# Step 2b: Pymesh shrinkwrapping: 0.16820144653320312
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04202413558959961
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8943097591400146
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349491811_mls
# Step 5: Generating and reading Skeleton: 0.6262116432189941
# Step 6: Inserting dictionary: 0.07882213592529297
# Total time: 1.9649982452392578
#
#
#
# 648518346349493733:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26952505111694336
# Step 2a: Getting the number of splits: 0.27324724197387695
# Step 2b: Pymesh shrinkwrapping: 0.03508329391479492
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.010584354400634766
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8398702144622803
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349493733_mls
# Step 5: Generating and reading Skeleton: 0.2090287208557129
# Step 6: Inserting dictionary: 0.06324887275695801
# Total time: 1.4325900077819824
#
#
#
# 648518346349495174:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24321985244750977
# Step 2a: Getting the number of splits: 0.25209760665893555
# Step 2b: Pymesh shrinkwrapping: 0.24138355255126953
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08731722831726074
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8204402923583984
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349495174_mls
# Step 5: Generating and reading Skeleton: 0.6506097316741943
# Step 6: Inserting dictionary: 0.08700752258300781
# Total time: 2.1403579711914062
#
#
#
# 648518346349496058:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.09875655174255371
# Step 2a: Getting the number of splits: 0.10756587982177734
# Step 2b: Pymesh shrinkwrapping: 0.08564424514770508
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05211758613586426
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8890762329101562
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349496058_mls
# Step 5: Generating and reading Skeleton: 0.5014758110046387
# Step 6: Inserting dictionary: 0.07745552062988281
# Total time: 1.7158334255218506
#
#
#
# 648518346349498051:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.38221263885498047
# Step 2a: Getting the number of splits: 0.3978910446166992
# Step 2b: Pymesh shrinkwrapping: 0.41396307945251465
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09339714050292969
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0476720333099365
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349498051_mls
# Step 5: Generating and reading Skeleton: 0.8354043960571289
# Step 6: Inserting dictionary: 0.09870529174804688
# Total time: 2.8889880180358887
#
#
#
# 648518346349499297:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24459075927734375
# Step 2a: Getting the number of splits: 0.25063204765319824
# Step 2b: Pymesh shrinkwrapping: 0.0719902515411377
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03375673294067383
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8619644641876221
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349499297_mls
# Step 5: Generating and reading Skeleton: 0.4437992572784424
# Step 6: Inserting dictionary: 0.07744503021240234
# Total time: 1.7409141063690186
#
#
#
# 648518346349499689:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.227463960647583
# Step 2a: Getting the number of splits: 0.24315500259399414
# Step 2b: Pymesh shrinkwrapping: 0.597510814666748
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10117173194885254
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.990253210067749
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349499689_mls
# Step 5: Generating and reading Skeleton: 0.7901723384857178
# Step 6: Inserting dictionary: 0.11865973472595215
# Total time: 2.843496561050415
#
#
#
# 648518346349499824:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.9617574214935303
# Step 2a: Getting the number of splits: 1.1803817749023438
# Step 2b: Pymesh shrinkwrapping: 10.980348348617554
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.2165935039520264
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 3.2274036407470703
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349499824_mls
# Step 5: Generating and reading Skeleton: 6.93625545501709
# Step 6: Inserting dictionary: 0.6859312057495117
# Total time: 24.230005502700806
#
#
#
# 648518346349504185:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3877992630004883
# Step 2a: Getting the number of splits: 0.4002237319946289
# Step 2b: Pymesh shrinkwrapping: 0.30683279037475586
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10414814949035645
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9316370487213135
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349504185_mls
# Step 5: Generating and reading Skeleton: 0.6249761581420898
# Step 6: Inserting dictionary: 0.0992593765258789
# Total time: 2.469155788421631
#
#
#
# 648518346349504868:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.06811809539794922
# Step 2a: Getting the number of splits: 0.07309484481811523
# Step 2b: Pymesh shrinkwrapping: 0.026600122451782227
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.013509273529052734
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8812975883483887
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349504868_mls
# Step 5: Generating and reading Skeleton: 0.2906455993652344
# Step 6: Inserting dictionary: 0.04355287551879883
# Total time: 1.33036208152771
#
#
#
# 648518346349505592:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2241683006286621
# Step 2a: Getting the number of splits: 0.22725939750671387
# Step 2b: Pymesh shrinkwrapping: 0.020549535751342773
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.004974842071533203
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8473036289215088
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349505592_mls
# Step 5: Generating and reading Skeleton: 0.13110876083374023
# Step 6: Inserting dictionary: 0.06325697898864746
# Total time: 1.2968127727508545
#
#
#
# 648518346349506008:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.21372318267822266
# Step 2a: Getting the number of splits: 0.2206864356994629
# Step 2b: Pymesh shrinkwrapping: 0.12908601760864258
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.045536041259765625
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.905522346496582
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349506008_mls
# Step 5: Generating and reading Skeleton: 0.4174659252166748
# Step 6: Inserting dictionary: 0.06707072257995605
# Total time: 1.7869741916656494
#
#
#
# 648518346349507015:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26175451278686523
# Step 2a: Getting the number of splits: 0.26981496810913086
# Step 2b: Pymesh shrinkwrapping: 0.1724865436553955
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06444573402404785
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9553418159484863
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349507015_mls
# Step 5: Generating and reading Skeleton: 0.6281425952911377
# Step 6: Inserting dictionary: 0.09040021896362305
# Total time: 2.182668924331665
#
#
#
# 648518346349507788:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18535685539245605
# Step 2a: Getting the number of splits: 0.19388985633850098
# Step 2b: Pymesh shrinkwrapping: 0.11588287353515625
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0636909008026123
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8713490962982178
# /notebooks/14_Contacts/pymesh_NEURITES/neuron_648518346349507788_mls
# Step 5: Generating and reading Skeleton: 0.5061397552490234
# Step 6: Inserting dictionary: 0.07102227210998535
# Total time: 1.8233630657196045
#
#
#
# Total time = 242.46608066558838
