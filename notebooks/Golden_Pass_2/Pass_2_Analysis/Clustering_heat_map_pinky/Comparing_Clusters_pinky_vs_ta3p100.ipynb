# %%
import datajoint as dj
import numpy as np
import time

import pandas as pd
import seaborn as sns
sns.set() #sets the asethetics parameters in what set

# %%
ta3p100 = dj.create_virtual_module("ta3p100","microns_ta3p100")
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
pinky = dj.create_virtual_module("pinky","microns_pinky")

# %%
"""
Reminder: the neurites were 
only taken if had more than 6 synapes
"""

# %%
ta3p100.SpineClusters()
# Out:
# *segmentation  *segment_id    cluster_id
# +------------+ +------------+ +------------+
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
# 2              64851834634135 0
#    ...
#  (Total: 6268)

# %%
pinky.SpineClustersKey()
# Out:
# *cluster_id    description    threshold
# +------------+ +------------+ +-----------+
# 0              Soma           0.25
# 1              Axon           0.0001
# 2              Spine Head     0.6
# 3              Shaft          0.5
# 4              Unused         0.0
#  (Total: 5)

# %%
#get the number for each group

# %%
pinky.SpineClusters()
# Out:
# *segmentation  *segment_id    cluster_id
# +------------+ +------------+ +------------+
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
# 3              64851834634135 0
#    ...
#  (Total: 8664)
