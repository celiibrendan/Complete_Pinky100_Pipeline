# %%
"""
Will generate the skeletons for all of the
Exhitatory Neurons and Orphan Neurons

Process: 
1) Check which table the neuron is in
2) Filter away any error labels 
3) Run pymeshfix on neuron
4) Run skeletonization
5) Write to datajoint as array

"""
# Out:
# '\nWill generate the skeletons for all of the\nExhitatory Neurons and Orphan Neurons\n\nProcess: \n1) Check which table the neuron is in\n2) Filter away any error labels \n3) Run pymeshfix on neuron\n4) Run skeletonization\n5) Write to datajoint as array\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#ta3p100.CoarseLabelFinal() #ta3p100.CoarseLabelOrphan()

# %%
#function that will filter out error triangles
def generate_neighborhood(triangles, num_vertices):
    neighborhood = dict()
    for i in range(num_vertices):
        neighborhood[i] = set()
    for node1, node2, node3 in triangles:
        neighborhood[node1].update([node2, node3])
        neighborhood[node2].update([node1, node3])
        neighborhood[node3].update([node1, node2])
    return neighborhood

def set_search_first(starting_node, neighborhood):
    """
    Modified Depth-First-Search utilizing sets to reduce duplicate checks:

    Neighborhood must be a dict with the keys being the vertex indices!
    """    
    visited_nodes = set()
    temp_stack = set()
    temp_stack.add(starting_node)
    while len(temp_stack) > 0:
        starting_node = temp_stack.pop()
        if starting_node not in visited_nodes:
            visited_nodes.add(starting_node)
            temp_stack.update(neighborhood[starting_node])
    return list(visited_nodes)
def get_connected_portions(neighborhood):
    neighborhood_copy = neighborhood.copy()
    portions = []
    while len(neighborhood_copy) > 0:
        starting_node = next(iter(neighborhood_copy))
        portion = set_search_first(starting_node, neighborhood_copy)
        for node in portion:
            neighborhood_copy.pop(node)
        portions.append(portion)
    return portions

def get_largest_portion_index(portions):
    portion_lengths = [len(portion) for portion in portions]
    return portion_lengths.index(max(portion_lengths))

def get_largest_portion(portions):
    return portions[get_largest_portion_index(portions)]

def remove_floating_artifacts(mesh,key,mesh_labels):    
    mesh_copy = mesh.copy()
    
#     #get the labels for the mesh
#     #find out if in Orphan Table or Regular Neuron Table
#     if len(ta3p100.CoarseLabelFinal() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
#     elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
#         mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
#     else:
#         raise Exception('neuron' + str(key["segment_id"]) + 
#                         'not present in any labels!')

    
    #look for errors
    not_errors = [i for i,k in enumerate(mesh_labels["triangles"]) if k != 10]
    original_triangles = mesh["triangles"]
    """
    print(type(not_errors))
    print(len(not_errors))
    print("not_errors = "+ str(not_errors[:100]))
    print(type(original_triangles))
    print(len(original_triangles))
    #print(original_triangles)
    print("not_errors = " + str(original_triangles[not_errors]))
    """
    
    mesh_copy['triangles'] = np.array(original_triangles[not_errors])
    
    return mesh_copy


def remove_isolated_vertices(mesh):
    mesh_copy = mesh.copy()

    neighborhood = generate_neighborhood(mesh_copy['triangles'], len(mesh_copy['vertices']))
    isolated_nodes = [portion.pop() for portion in get_connected_portions(neighborhood) if len(portion) == 1]

    vertices = mesh_copy['vertices']
    triangles = mesh_copy['triangles']
    vertex_list = list(vertices)

    if len(isolated_nodes) > 0:
        num_isolated_nodes_passed = 0
        isolated_nodes_set = set(isolated_nodes)
        count_to_decrement = np.zeros(len(vertices))
        for i in range(len(vertices)):
            if i in isolated_nodes_set:
                num_isolated_nodes_passed += 1
            else:
                count_to_decrement[i] = num_isolated_nodes_passed

        for i, triangle in enumerate(triangles):
            start = time.time()
            node1, node2, node3 = triangle
            triangles[i][0] -= count_to_decrement[node1]
            triangles[i][1] -= count_to_decrement[node2]
            triangles[i][2] -= count_to_decrement[node3]
        for i, isolated_node in enumerate(isolated_nodes):
            vertex_list.pop(isolated_node - i)

    mesh_copy['vertices'] = np.array(vertex_list)

    return mesh_copy


def remove_error_segments(key):

    full_start = time.time()

    print(str(key['segment_id']) +  ":")
    start = time.time()

    #find out if in Orphan Table or Regular Neuron Table
    if len(ta3p100.CoarseLabelFinal() & key) > 0:
        mesh = (ta3p100.CleansedMesh & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelFinal & key).fetch1()
    elif len(ta3p100.CoarseLabelOrphan() & key) > 0:
        mesh = (ta3p100.CleansedMeshOrphan & key).fetch1()
        mesh_labels = (ta3p100.CoarseLabelOrphan & key).fetch1()
    else:
        raise Exception('neuron' + str(key["segment_id"]) + 
                        'not present in any labels!')
    
    print(key['segment_id'], "mesh fetched.", time.time() - start)
    start = time.time()
    
    #print(mesh['triangles'])
    myCounter = Counter(mesh_labels['triangles'])#.tolist())
    print(myCounter)
    
    keys = list(myCounter.keys())
    #print(len(keys))
    
    if len(keys) < 2 and keys[0] == 10:
        print("only error segments")
        key['n_vertices'] = 0
        key['n_triangles'] = 0
        key['vertices'] = np.ndarray([])
        key['triangles'] = np.ndarray([])
        
        print("This took ", time.time() - full_start, "seconds.")
        print()
        return key
    
    neighborhood = generate_neighborhood(mesh['triangles'], len(mesh['vertices']))
    print(key['segment_id'] , "neighborhood generated.", time.time() - start)
    start = time.time()
    
    mesh = remove_floating_artifacts(mesh,key,mesh_labels)
    print(key['segment_id'], "floating artifacts removed.", time.time() - start)
    start = time.time()

    mesh = remove_isolated_vertices(mesh)
    print(key['segment_id'], "isolated nodes removed.", time.time() - start)
    start = time.time()

    key['n_vertices'] = len(mesh['vertices'])
    key['n_triangles'] = len(mesh['triangles'])
    key['vertices'] = mesh['vertices']
    key['triangles'] = mesh['triangles']

    #self.insert1(key, skip_duplicates=True)
    print(key['segment_id'], "key successfully filtered.", time.time() - start)
    start = time.time()

    print("This took ", time.time() - full_start, "seconds.")
    print()
    return key

# %%
#output for the skeleton edges to be stored by datajoint
""" OLD WAY THAT DATAJOINT WAS GETTING MAD AT 
def read_skeleton(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            bones.append(np.array(line.split()[1:], float).reshape(-1, 3))
    return np.array(bones)
"""

""" NEW FLAT LIST WAY, this is outdated for one below"""
#
def read_skeleton_flat(file_path):
    with open(file_path) as f:
        bones = list()
        for line in f.readlines():
            for r in (np.array(line.split()[1:], float).reshape(-1, 3)):
                bones.append(r)
            bones.append([np.nan,np.nan,np.nan])
    return np.array(bones).astype(float)


""" New read function: for adjusted 2 vert skeleton output"""
def read_raw_skeleton(file_path):
    edges = list()
    with open(file_path) as f:
        reader = csv.reader(f, delimiter=' ', quoting=csv.QUOTE_NONE)
        for i,row in enumerate(reader):
            v1 = (float(row[1]),float(row[2]),float(row[3]))
            v2 = (float(row[4]),float(row[5]),float(row[6]))
            edges.append((v1,v2))
    return np.array(edges).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_neurons")) == False:
    os.mkdir("pymesh_neurons")

# %%
#keysource for neuron table
ta3p100.CoarseLabelFinal()
print(len(ta3p100.CoarseLabelFinal()))
# Out:
# 322

# %%
ta3p100.CoarseLabelOrphan()
print(len(ta3p100.CoarseLabelOrphan()))
# Out:
# 702

# %%
ns_table = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
print(len(ns_table))
ns_table
# Out:
# 1024
# *segmentation  *segment_id
# +------------+ +------------+
# 2              64851834634136
# 2              64851834634137
# 2              64851834634138
# 2              64851834634139
# 2              64851834634279
# 2              64851834634280
# 2              64851834634938
# 2              64851834634946
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
# 2              64851834634947
#    ...
#  (1024 tuples)

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_neurons"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_neurons"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting remeshing_remove_non_man_edges")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
@schema
class NeuronRawSkeleton(dj.Computed):
    definition="""
    -> ta3p100.Mesh
    time_updated      :timestamp    # the time at which the component labels were updated
    ---
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_vertices   :int unsigned #number of vertices in mesh filtered of error segments
    n_triangles  :int unsigned #number of faces in mesh filtered of error segments
    vertices     :longblob #mesh data for vertices in mesh filtered of error segments
    triangles    :longblob #mesh data for faces in mesh filtered of error segments
     
    """
    
    key_source = ((dj.U("segmentation","segment_id") & ta3p100.CoarseLabelFinal.proj()) 
     + (dj.U("segmentation","segment_id") & ta3p100.CoarseLabelOrphan.proj()))
    
    #how you get the date and time  datetime.datetime.now()
    
    def make(self, key):
        global_time = time.time()
        #get the mesh with the error segments filtered away
        start_time = time.time()
        new_key = remove_error_segments(key)
        print(f"Step 1: Retrieving Mesh and removing error segments: {time.time() - start_time}")
        
        #where i deal with the error segments
        if new_key["vertices"].size<2:
            start_time = time.time()
            print("All faces were error segments, inserting dummy entry")
            #create the key with None
            new_key["n_vertices"] = 0
            new_key["n_triangles"] = 0
            new_key["vertices"] = np.array([]).astype(float)
            new_key["triangles"] = np.array([]).astype(float)
            new_key["n_edges"] = 0
            new_key["edges"] = np.array([]).astype(float)
            new_key["time_updated"]=str(datetime.datetime.now())
            self.insert1(new_key,skip_duplicates=True)
            
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = 0,
                                           correspondence=np.array([]).astype(float))
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            print(f"Step 2: Inserting dummy dictionary: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")
        
        else:
        
            #print("Step 2: Remove all error semgents")
            start_time = time.time()
            #pass the vertices and faces to pymeshfix to become watertight
            meshfix = pymeshfix.MeshFix(new_key["vertices"],new_key["triangles"])
            meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
            print(f"Step 2: Pymesh shrinkwrapping: {time.time() - start_time}")

            #print("Step 2: Writing Off File")
            start_time = time.time()
            #write the new mesh to off file
            path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
            print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

            #Run the meshlabserver scripts
            start_time = time.time()
            output_mesh = meshlab_fix_manifold(key)
            print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

            print(output_mesh[:-4])

            #send to be skeletonized
            start_time = time.time()
            return_value = cm.calcification(output_mesh[:-4])
            if return_value > 0:
                raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                                ' did not finish... exited with error code: ' + str(return_value))
            #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



            #read in the skeleton files into an array
            #start_time = time.time()
            
            ##****** this needs to be changed for reading them in******
            bone_array = read_raw_skeleton(output_mesh[:-4]+"_skeleton.cgal")
            correspondence_array = read_raw_skeleton(output_mesh[:-4]+"_correspondance.cgal")
            #print(bone_array)
            if len(bone_array) <= 0:
                raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
            
            if len(correspondence_array) <= 0:
                raise Exception('No CORRESPONDENCE generated for ' + str(new_key["segment_id"]))
                
            print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


            start_time = time.time()
            
            new_key["n_edges"] = bone_array.shape[0]
            new_key["edges"] = bone_array
            #new_key["branches"] = []

            time_updated = str(datetime.datetime.now())
            new_key["time_updated"]=time_updated
            #print(key)
            #if all goes well then write to database
            self.insert1(new_key,skip_duplicates=True)
            
            #create a new dictionary key to be inserted into correspondence table
            """
            time_updated      :timestamp    # the time at which the component labels were updated
            ---
            n_correspondence   :int unsigned #number of mappings from skeleton vert to original surface vert 
            correspondence     :longblob #array storing mapping of every skeleton vert to original surface vert  
            """
            #insert dummy dictionary into correspondence table
            new_correspondence_dict = dict(segmentation=key["segmentation"],
                                           segment_id=key["segment_id"],
                                           time_updated=str(datetime.datetime.now()),
                                           n_correspondence = correspondence_array.shape[0],
                                           correspondence=correspondence_array)
            
            #if all goes well then write to correspondence database
            ta3p100.NeuronRawSkeletonCorrespondence.insert1(new_correspondence_dict,skip_duplicates=True)
            
            
            os.system("rm "+str(path_and_filename)+"*")
            print(f"Step 6: Inserting both dictionaries: {time.time() - start_time}")
            print(f"Total time: {time.time() - global_time}")
            print("\n\n")

# %%
#ta3p100.NeuronSkeletons()#.delete()
#(schema.jobs & "table_name='__neuron_skeletons'").delete()

# %%
start = time.time()
NeuronRawSkeleton.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# 648518346349473821:
# 648518346349473821 mesh fetched. 0.23296332359313965
# Counter({2: 292828, 4: 134257, 5: 70477, 3: 16842, 12: 193})
# 648518346349473821 neighborhood generated. 4.525704860687256
# 648518346349473821 floating artifacts removed. 0.9364829063415527
# 648518346349473821 isolated nodes removed. 5.520229339599609
# 648518346349473821 key successfully filtered. 7.867813110351562e-06
# This took  11.21802282333374 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 11.46822738647461
# Step 2: Pymesh shrinkwrapping: 124.83837080001831
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 3.387986898422241
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 6.794314384460449
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349473821_mls
# Step 5: Generating and reading Skeleton: 22.313600540161133
# Step 6: Inserting both dictionaries: 2.776724338531494
# Total time: 171.58201718330383
#
#
#
# 648518346349473848:
# 648518346349473848 mesh fetched. 0.3470652103424072
# Counter({3: 542000, 10: 255483, 2: 225692, 5: 157994, 7: 8887, 12: 481})
# 648518346349473848 neighborhood generated. 10.768787145614624
# 648518346349473848 floating artifacts removed. 2.3837215900421143
# 648518346349473848 isolated nodes removed. 90.35266399383545
# 648518346349473848 key successfully filtered. 9.5367431640625e-06
# This took  103.85539484024048 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 104.36093163490295
# Step 2: Pymesh shrinkwrapping: 274.46201038360596
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 4.644051551818848
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 14.65023159980774
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346
seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 8.396938800811768
# Step 2: Pymesh shrinkwrapping: 20.35191822052002
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.8688063621520996
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 6.165099143981934
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341377161_mls
# Step 5: Generating and reading Skeleton: 15.045368671417236
# Step 6: Inserting both dictionaries: 1.8852803707122803
# Total time: 53.71500253677368
#
#
#
# 648518346341384207:
# 648518346341384207 mesh fetched. 0.1996476650238037
# Counter({10: 416771})
# only error segments
# This took  0.28514909744262695 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.2853062152862549
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.007780313491821289
# Total time: 0.29320335388183594
#
#
#
# 648518346341384400:
# 648518346341384400 mesh fetched. 0.055332183837890625
# Counter({8: 12126})
# 648518346341384400 neighborhood generated. 0.15964341163635254
# 648518346341384400 floating artifacts removed. 0.031647682189941406
# 648518346341384400 isolated nodes removed. 0.21970462799072266
# 648518346341384400 key successfully filtered. 4.0531158447265625e-06
# This took  0.4672973155975342 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.47174739837646484
# Step 2: Pymesh shrinkwrapping: 0.47499680519104004
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07434654235839844
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9136443138122559
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341384400_mls
# Step 5: Generating and reading Skeleton: 1.8069026470184326
# Step 6: Inserting both dictionaries: 0.17146682739257812
# Total time: 3.9143564701080322
#
#
#
# 648518346341386441:
# 648518346341386441 mesh fetched. 0.2047569751739502
# Counter({8: 392288, 10: 41511})
# 648518346341386441 neighborhood generated. 3.935319423675537
# 648518346341386441 floating artifacts removed. 0.856034517288208
# 648518346341386441 isolated nodes removed. 12.19264006614685
# 648518346341386441 key successfully filtered. 8.821487426757812e-06
# This took  17.190202713012695 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 17.369257926940918
# Step 2: Pymesh shrinkwrapping: 25.245455026626587
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 2.2195446491241455
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 5.223428249359131
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341386441_mls
# Step 5: Generating and reading Skeleton: 15.225636720657349
# Step 6: Inserting both dictionaries: 2.1136035919189453
# Total time: 67.39834642410278
#
#
#
# 648518346341397321:
# 648518346341397321 mesh fetched. 0.12170648574829102
# Counter({8: 125753})
# 648518346341397321 neighborhood generated. 1.4845457077026367
# 648518346341397321 floating artifacts removed. 0.25815606117248535
# 648518346341397321 isolated nodes removed. 1.6785814762115479
# 648518346341397321 key successfully filtered. 5.9604644775390625e-06
# This took  3.5437262058258057 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.5876529216766357
# Step 2: Pymesh shrinkwrapping: 3.723653554916382
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6691179275512695
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.028442859649658
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341397321_mls
# Step 5: Generating and reading Skeleton: 5.49189019203186
# Step 6: Inserting both dictionaries: 0.8056402206420898
# Total time: 16.308058500289917
#
#
#
# 648518346341399129:
# 648518346341399129 mesh fetched. 0.1130363941192627
# Counter({8: 39787})
# 648518346341399129 neighborhood generated. 0.5081334114074707
# 648518346341399129 floating artifacts removed. 0.09454226493835449
# 648518346341399129 isolated nodes removed. 0.511582612991333
# 648518346341399129 key successfully filtered. 5.245208740234375e-06
# This took  1.2286832332611084 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.2419230937957764
# Step 2: Pymesh shrinkwrapping: 1.61531400680542
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.28778862953186035
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0191960334777832
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341399129_mls
# Step 5: Generating and reading Skeleton: 1.8599843978881836
# Step 6: Inserting both dictionaries: 0.34490275382995605
# Total time: 6.3703391551971436
#
#
#
# 648518346341399743:
# 648518346341399743 mesh fetched. 0.10955810546875
# Counter({8: 164086})
# 648518346341399743 neighborhood generated. 1.8738539218902588
# 648518346341399743 floating artifacts removed. 0.3459322452545166
# 648518346341399743 isolated nodes removed. 2.342918634414673
# 648518346341399743 key successfully filtered. 6.198883056640625e-06
# This took  4.673001050949097 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 4.72804594039917
# Step 2: Pymesh shrinkwrapping: 9.464734077453613
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.178715467453003
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.6741199493408203
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341399743_mls
# Step 5: Generating and reading Skeleton: 7.5034284591674805
# Step 6: Inserting both dictionaries: 1.0842993259429932
# Total time: 26.63453984260559
#
#
#
# 648518346341402643:
# 648518346341402643 mesh fetched. 0.22036004066467285
# Counter({8: 93455})
# 648518346341402643 neighborhood generated. 0.9928624629974365
# 648518346341402643 floating artifacts removed. 0.18972492218017578
# 648518346341402643 isolated nodes removed. 1.1109108924865723
# 648518346341402643 key successfully filtered. 5.245208740234375e-06
# This took  2.5148637294769287 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.547013998031616
# Step 2: Pymesh shrinkwrapping: 4.4194395542144775
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.47739720344543457
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.9211606979370117
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341402643_mls
# Step 5: Generating and reading Skeleton: 4.2225563526153564
# Step 6: Inserting both dictionaries: 0.7788662910461426
# Total time: 14.367634296417236
#
#
#
# 648518346341404564:
# 648518346341404564 mesh fetched. 0.2965357303619385
# Counter({8: 382875, 10: 45453})
# 648518346341404564 neighborhood generated. 3.8966124057769775
# 648518346341404564 floating artifacts removed. 0.8393487930297852
# 648518346341404564 isolated nodes removed. 13.134450674057007
# 648518346341404564 key successfully filtered. 7.3909759521484375e-06
# This took  18.169085025787354 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 18.360222578048706
# Step 2: Pymesh shrinkwrapping: 22.38140082359314
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.77889084815979
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 4.204212188720703
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341404564_mls
# Step 5: Generating and reading Skeleton: 15.960923194885254
# Step 6: Inserting both dictionaries: 2.1337473392486572
# Total time: 64.82049536705017
#
#
#
# 648518346341935219:
# 648518346341935219 mesh fetched. 0.09168648719787598
# Counter({8: 14712})
# 648518346341935219 neighborhood generated. 0.1450176239013672
# 648518346341935219 floating artifacts removed. 0.031218290328979492
# 648518346341935219 isolated nodes removed. 0.1965956687927246
# 648518346341935219 key successfully filtered. 4.291534423828125e-06
# This took  0.4659452438354492 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4704122543334961
# Step 2: Pymesh shrinkwrapping: 0.2993645668029785
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08553552627563477
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8510823249816895
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346341935219_mls
# Step 5: Generating and reading Skeleton: 1.6737558841705322
# Step 6: Inserting both dictionaries: 0.21939849853515625
# Total time: 3.6014046669006348
#
#
#
# 648518346342157329:
# 648518346342157329 mesh fetched. 0.1915442943572998
# Counter({10: 16180, 8: 7736})
# 648518346342157329 neighborhood generated. 0.31894659996032715
# 648518346342157329 floating artifacts removed. 0.09123706817626953
# 648518346342157329 isolated nodes removed. 0.3271181583404541
# 648518346342157329 key successfully filtered. 5.4836273193359375e-06
# This took  0.9307692050933838 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9398186206817627
# Step 2: Pymesh shrinkwrapping: 0.3181912899017334
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.046463966369628906
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7740581035614014
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342157329_mls
# Step 5: Generating and reading Skeleton: 1.4913651943206787
# Step 6: Inserting both dictionaries: 0.18324613571166992
# Total time: 3.754452705383301
#
#
#
# 648518346342406253:
# 648518346342406253 mesh fetched. 0.08805656433105469
# Counter({8: 46468})
# 648518346342406253 neighborhood generated. 0.467266321182251
# 648518346342406253 floating artifacts removed. 0.10228419303894043
# 648518346342406253 isolated nodes removed. 0.5259130001068115
# 648518346342406253 key successfully filtered. 3.814697265625e-06
# This took  1.1842777729034424 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.1991980075836182
# Step 2: Pymesh shrinkwrapping: 1.6639645099639893
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.24541449546813965
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0609948635101318
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342406253_mls
# Step 5: Generating and reading Skeleton: 5.105701208114624
# Step 6: Inserting both dictionaries: 0.5218842029571533
# Total time: 9.798730850219727
#
#
#
# 648518346342790189:
# 648518346342790189 mesh fetched. 0.16194415092468262
# Counter({8: 59662, 10: 8060})
# 648518346342790189 neighborhood generated. 0.7429840564727783
# 648518346342790189 floating artifacts removed. 0.16521072387695312
# 648518346342790189 isolated nodes removed. 1.587402582168579
# 648518346342790189 key successfully filtered. 5.245208740234375e-06
# This took  2.658936023712158 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.6811704635620117
# Step 2: Pymesh shrinkwrapping: 2.803290605545044
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3071157932281494
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1677367687225342
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346342790189_mls
# Step 5: Generating and reading Skeleton: 3.2043731212615967
# ...
# 648518346346307118 neighborhood generated. 0.5537278652191162
# 648518346346307118 floating artifacts removed. 0.12367939949035645
# 648518346346307118 isolated nodes removed. 0.714618444442749
# 648518346346307118 key successfully filtered. 5.245208740234375e-06
# This took  1.4974665641784668 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.5148539543151855
# Step 2: Pymesh shrinkwrapping: 1.2797844409942627
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2647879123687744
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1203651428222656
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346307118_mls
# Step 5: Generating and reading Skeleton: 2.8580129146575928
# Step 6: Inserting both dictionaries: 0.41741180419921875
# Total time: 7.456273317337036
#
#
#
# 648518346346586248:
# 648518346346586248 mesh fetched. 0.060233116149902344
# Counter({8: 38405})
# 648518346346586248 neighborhood generated. 0.3247866630554199
# 648518346346586248 floating artifacts removed. 0.07760763168334961
# 648518346346586248 isolated nodes removed. 0.5163946151733398
# 648518346346586248 key successfully filtered. 5.245208740234375e-06
# This took  0.9799742698669434 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.9925477504730225
# Step 2: Pymesh shrinkwrapping: 0.9536900520324707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.18174290657043457
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9670877456665039
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346346586248_mls
# Step 5: Generating and reading Skeleton: 1.9592676162719727
# Step 6: Inserting both dictionaries: 0.34619855880737305
# Total time: 5.401597738265991
#
#
#
# 648518346347001035:
# 648518346347001035 mesh fetched. 0.13635993003845215
# Counter({8: 35373})
# 648518346347001035 neighborhood generated. 0.45074987411499023
# 648518346347001035 floating artifacts removed. 0.08324098587036133
# 648518346347001035 isolated nodes removed. 0.4074819087982178
# 648518346347001035 key successfully filtered. 5.0067901611328125e-06
# This took  1.0786769390106201 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.0888514518737793
# Step 2: Pymesh shrinkwrapping: 1.0958588123321533
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.18005132675170898
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.0433106422424316
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346347001035_mls
# Step 5: Generating and reading Skeleton: 1.8736615180969238
# Step 6: Inserting both dictionaries: 0.33473825454711914
# Total time: 5.617628812789917
#
#
#
# 648518346348110410:
# 648518346348110410 mesh fetched. 0.1541891098022461
# Counter({10: 10975, 8: 8669})
# 648518346348110410 neighborhood generated. 0.2255709171295166
# 648518346348110410 floating artifacts removed. 0.04633688926696777
# 648518346348110410 isolated nodes removed. 0.38398170471191406
# 648518346348110410 key successfully filtered. 5.0067901611328125e-06
# This took  0.811262845993042 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8181698322296143
# Step 2: Pymesh shrinkwrapping: 0.17862296104431152
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04451870918273926
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7893123626708984
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348110410_mls
# Step 5: Generating and reading Skeleton: 1.007885217666626
# Step 6: Inserting both dictionaries: 0.21007704734802246
# Total time: 3.0492920875549316
#
#
#
# 648518346348117070:
# 648518346348117070 mesh fetched. 0.1763744354248047
# Counter({8: 10099})
# 648518346348117070 neighborhood generated. 0.11058592796325684
# 648518346348117070 floating artifacts removed. 0.02601766586303711
# 648518346348117070 isolated nodes removed. 0.15236186981201172
# 648518346348117070 key successfully filtered. 4.0531158447265625e-06
# This took  0.4663877487182617 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.47005128860473633
# Step 2: Pymesh shrinkwrapping: 0.2188854217529297
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07196259498596191
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6724302768707275
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348117070_mls
# Step 5: Generating and reading Skeleton: 1.829587459564209
# Step 6: Inserting both dictionaries: 0.17361116409301758
# Total time: 3.437699317932129
#
#
#
# 648518346348189857:
# 648518346348189857 mesh fetched. 0.1043555736541748
# Counter({8: 12523})
# 648518346348189857 neighborhood generated. 0.17992305755615234
# 648518346348189857 floating artifacts removed. 0.03199958801269531
# 648518346348189857 isolated nodes removed. 0.1840057373046875
# 648518346348189857 key successfully filtered. 4.5299530029296875e-06
# This took  0.5013976097106934 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.5061767101287842
# Step 2: Pymesh shrinkwrapping: 0.2672879695892334
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07387852668762207
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.57126784324646
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348189857_mls
# Step 5: Generating and reading Skeleton: 0.8450841903686523
# Step 6: Inserting both dictionaries: 0.2163243293762207
# Total time: 2.4812865257263184
#
#
#
# 648518346348191963:
# 648518346348191963 mesh fetched. 0.10150742530822754
# Counter({8: 39150})
# 648518346348191963 neighborhood generated. 0.45314526557922363
# 648518346348191963 floating artifacts removed. 0.09662961959838867
# 648518346348191963 isolated nodes removed. 0.5991511344909668
# 648518346348191963 key successfully filtered. 5.0067901611328125e-06
# This took  1.2512645721435547 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.2640366554260254
# Step 2: Pymesh shrinkwrapping: 0.7965247631072998
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.19390392303466797
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.1643619537353516
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348191963_mls
# Step 5: Generating and reading Skeleton: 2.514361619949341
# Step 6: Inserting both dictionaries: 0.3641176223754883
# Total time: 6.298521041870117
#
#
#
# 648518346348204225:
# 648518346348204225 mesh fetched. 0.09759640693664551
# Counter({10: 26670})
# only error segments
# This took  0.10677170753479004 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.10689234733581543
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.019029617309570312
# Total time: 0.1260673999786377
#
#
#
# 648518346348204330:
# 648518346348204330 mesh fetched. 0.13509917259216309
# Counter({8: 8036})
# 648518346348204330 neighborhood generated. 0.10142850875854492
# 648518346348204330 floating artifacts removed. 0.020398855209350586
# 648518346348204330 isolated nodes removed. 0.11889386177062988
# 648518346348204330 key successfully filtered. 6.4373016357421875e-06
# This took  0.37688660621643066 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.3820030689239502
# Step 2: Pymesh shrinkwrapping: 0.21320867538452148
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04996204376220703
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.6857321262359619
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348204330_mls
# Step 5: Generating and reading Skeleton: 1.2280597686767578
# Step 6: Inserting both dictionaries: 0.15207743644714355
# Total time: 2.712254047393799
#
#
#
# 648518346348209350:
# 648518346348209350 mesh fetched. 0.12192773818969727
# Counter({8: 22848})
# 648518346348209350 neighborhood generated. 0.3240485191345215
# 648518346348209350 floating artifacts removed. 0.058709144592285156
# 648518346348209350 isolated nodes removed. 0.3668801784515381
# 648518346348209350 key successfully filtered. 6.198883056640625e-06
# This took  0.872870922088623 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.880763053894043
# Step 2: Pymesh shrinkwrapping: 0.5412776470184326
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.13533711433410645
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9736988544464111
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348209350_mls
# Step 5: Generating and reading Skeleton: 1.4982402324676514
# Step 6: Inserting both dictionaries: 0.2667555809020996
# Total time: 4.297335624694824
#
#
#
# 648518346348459912:
# 648518346348459912 mesh fetched. 0.12134480476379395
# Counter({10: 20294})
# only error segments
# This took  0.1317744255065918 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.13192963600158691
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.03315544128417969
# Total time: 0.16523480415344238
#
#
#
# 648518346348462142:
# 648518346348462142 mesh fetched. 0.07689499855041504
# Counter({8: 19097})
# 648518346348462142 neighborhood generated. 0.24640631675720215
# 648518346348462142 floating artifacts removed. 0.04674243927001953
# 648518346348462142 isolated nodes removed. 0.2637293338775635
# 648518346348462142 key successfully filtered. 5.245208740234375e-06
# This took  0.6346080303192139 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.6407921314239502
# Step 2: Pymesh shrinkwrapping: 0.43380141258239746
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09454822540283203
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.7171485424041748
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348462142_mls
# Step 5: Generating and reading Skeleton: 1.1396520137786865
# Step 6: Inserting both dictionaries: 0.2688276767730713
# Total time: 3.295896530151367
#
#
#
# 648518346348465553:
# 648518346348465553 mesh fetched. 0.16510772705078125
# Counter({8: 22189})
# 648518346348465553 neighborhood generated. 0.3288760185241699
# 648518346348465553 floating artifacts removed. 0.053676605224609375
# 648518346348465553 isolated nodes removed. 0.30273914337158203
# 648518346348465553 key successfully filtered. 3.814697265625e-06
# This took  0.8515782356262207 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.8590126037597656
# Step 2: Pymesh shrinkwrapping: 0.6937351226806641
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.10808563232421875
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9265284538269043
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346348465553_mls
# Step 5: Generating and reading Skeleton: 1.254420518875122
# Step 6: Inserting both dictionaries: 0.24942541122436523
# Total time: 4.09209680557251
#
#
#
# 648518346349374821:
# 648518346349374821 mesh fetched. 0.15614533424377441
# Counter({8: 88228})
# 648518346349374821 neighborhood generated. 0.8217575550079346
# 648518346349374821 floating artifacts removed. 0.1721494197845459
# 648518346349374821 isolated nodes removed. 0.970475435256958
# 648518346349374821 key successfully filtered. 5.7220458984375e-06
# This took  2.1216468811035156 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.1497650146484375
# Step 2: Pymesh shrinkwrapping: 4.31501841545105
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4696316719055176
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.6865415573120117
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349374821_mls
# Step 5: Generating and reading Skeleton: 4.620625257492065
# Step 6: Inserting both dictionaries: 0.6289851665496826
# Total time: 13.87208080291748
#
#
#
# 648518346349386619:
# 648518346349386619 mesh fetched. 0.1605372428894043
# Counter({8: 30441})
# 648518346349386619 neighborhood generated. 0.4195139408111572
# 648518346349386619 floating artifacts removed. 0.07433009147644043
# 648518346349386619 isolated nodes removed. 0.4070603847503662
# 648518346349386619 key successfully filtered. 4.76837158203125e-06
# This took  1.0630526542663574 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 1.0722277164459229
# Step 2: Pymesh shrinkwrapping: 0.7346086502075195
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15082764625549316
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.8543426990509033
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349386619_mls
# Step 5: Generating and reading Skeleton: 1.5528373718261719
# Step 6: Inserting both dictionaries: 0.3020036220550537
# Total time: 4.667834997177124
#
#
#
# 648518346349462805:
# 648518346349462805 mesh fetched. 0.14888501167297363
# Counter({8: 112436})
# 648518346349462805 neighborhood generated. 1.1680104732513428
# 648518346349462805 floating artifacts removed. 0.23071765899658203
# 648518346349462805 isolated nodes removed. 1.510622501373291
# 648518346349462805 key successfully filtered. 1.6927719116210938e-05
# This took  3.0592193603515625 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.096919059753418
# Step 2: Pymesh shrinkwrapping: 5.0610339641571045
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6557090282440186
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 1.6989080905914307
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349462805_mls
# Step 5: Generating and reading Skeleton: 5.605401515960693
# Step 6: Inserting both dictionaries: 0.7743656635284424
# Total time: 16.894548416137695
#
#
#
# 648518346349478853:
# 648518346349478853 mesh fetched. 0.1276860237121582
# Counter({5: 50896, 2: 9885, 3: 2372, 8: 9})
# 648518346349478853 neighborhood generated. 0.8081223964691162
# 648518346349478853 floating artifacts removed. 0.15005970001220703
# 648518346349478853 isolated nodes removed. 0.9336037635803223
# 648518346349478853 key successfully filtered. 5.245208740234375e-06
# This took  2.0209708213806152 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 2.0417027473449707
# Step 2: Pymesh shrinkwrapping: 6.864934682846069
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.20688223838806152
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 0.9809260368347168
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349478853_mls
# Step 5: Generating and reading Skeleton: 6.8285815715789795
# Step 6: Inserting both dictionaries: 0.3706696033477783
# Total time: 17.29536747932434
#
#
#
# 648518346349484154:
# 648518346349484154 mesh fetched. 2.5669941902160645
# Counter({10: 7672830})
# only error segments
# This took  3.857036590576172 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 3.8683454990386963
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.04608774185180664
# Total time: 3.914733648300171
#
#
#
# 648518346349492054:
# 648518346349492054 mesh fetched. 0.2904493808746338
# Counter({10: 469395})
# only error segments
# This took  0.42798542976379395 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 0.4281301498413086
# All faces were error segments, inserting dummy entry
# Step 2: Inserting dummy dictionary: 0.011066913604736328
# Total time: 0.43933773040771484
#
#
#
# 648518346349492682:
# 648518346349492682 mesh fetched. 0.17714858055114746
# Counter({3: 156373, 5: 80255, 8: 2180, 11: 710})
# 648518346349492682 neighborhood generated. 2.185431718826294
# 648518346349492682 floating artifacts removed. 0.48339390754699707
# 648518346349492682 isolated nodes removed. 3.037963628768921
# 648518346349492682 key successfully filtered. 4.5299530029296875e-06
# This took  5.885108709335327 seconds.
#
# Step 1: Retrieving Mesh and removing error segments: 5.962714195251465
# Step 2: Pymesh shrinkwrapping: 71.07692289352417
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 1.1296329498291016
# starting remeshing_remove_non_man_edges
# Step 4: Meshlab fixing non-manifolds: 2.772841215133667
# /notebooks/13_Skeletons/pymesh_neurons/neuron_648518346349492682_mls
# Step 5: Generating and reading Skeleton: 7.673833131790161
# Step 6: Inserting both dictionaries: 1.0954101085662842
# Total time: 89.71368551254272
#
#
#
# 7033.850564241409
