# %%
"""
Changes made from 1st version: 
1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done
2) Fixed the stitch function error that was using an index number instead of vertex number Done
3) Fixed stitching function so when reverses order still starts on the original vertex Done
4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done
--> for time saver



"""
# Out:
# '\nChanges made from 1st version: \n1) Changed the starting stitch distance to 1800 to account for the larger faces needing stitching Done\n2) Fixed the stitch function error that was using an index number instead of vertex number Done\n3) Fixed stitching function so when reverses order still starts on the original vertex Done\n4) Made it so that function has "load_meshes_flag=True" and "save_meshes_flag=False" Done\n--> for time saver\n\n\n\n'

# %%
from Stitcher_vp2 import stitch_neuron
import datajoint as dj
import numpy as np
import datajoint as dj
import trimesh
import time
import os

# %%
# testing which table to pull from
pinky = dj.create_virtual_module("pinky","microns_pinky")
schema = dj.schema("microns_pinky")
# Out:
# Connecting celiib@10.28.0.34:3306

# %% [markdown]
# # Check the datajoint parent will be correct

# %%
#gets the possible segment ids
pinky.Mesh() & (pinky.AllenSoma() & "cell_class='excitatory'")
# Out:
# *segmentation  *segment_id    n_vertices     n_triangles    vertices   triangles
# +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634137 669574         1316372        =BLOB=     =BLOB=
# 3              64851834634938 85806          166966         =BLOB=     =BLOB=
# 3              64851834634947 1254494        2496165        =BLOB=     =BLOB=
# 3              64851834634947 865120         1721566        =BLOB=     =BLOB=
# 3              64851834634947 803277         1599182        =BLOB=     =BLOB=
# 3              64851834634947 1343736        2654580        =BLOB=     =BLOB=
# 3              64851834634947 2232110        4423873        =BLOB=     =BLOB=
#    ...
#  (327 tuples)

# %%
@schema
class ExcitatoryStitchedMeshVp2(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    n_vertices           : bigint           # number of vertices in this mesh
    n_triangles          : bigint           # number of triangles in this mesh
    vertices             : longblob         # x,y,z coordinates of vertices
    triangles            : longblob         # triangles (triplets of vertices)
    n_pieces             : int              # number of unconnected mesh pieces outside the largest mesh piece
    largest_piece_perc   : decimal(6,5)     # number of faces percentage of largest mesh piece in respect to total mesh
    outside_perc         : decimal(6,5)     # number of faces percentage of mesh outside the biggest mesh piece
    n_stitched           : int              # number of mesh pieces stitched back to main mesh
    stitched_addon_perc  : decimal(6,5)     # number of faces percentage of pieces that were stitched back in respect to largest mesh piece
    n_unstitched         : int              # number of mesh pieces remaining unstitched back to main mesh        
    unstitched_perc     : decimal(6,5)     # number of faces percentage of pieces that were not in respect to largest mesh piece
    
    
    """
    
    key_source = pinky.Mesh() & ((pinky.AllenSoma() & "cell_class='excitatory'").proj())
    
    
    def make(self, key):
        
        segment_id = key["segment_id"]
        key = dict(segment_id=segment_id,segmentation=3)
        vertices,triangles = (pinky.Mesh & key).fetch("vertices","triangles")

        verts = vertices[0]
        faces = triangles[0]

        print(f"\n\n\n*****Running Neuron Stitcher for {segment_id}**********")
        
        load_file_check = str(segment_id) + "_30_main_and_child_meshes_array.npz"
        files_to_list = os.listdir("./stitch_mesh_saved/")
        
        #check to see if file exists:
        if load_file_check in files_to_list:
            print("Using a load file for meshes")
            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = True,
                                                     save_meshes_flag = False,
                                                        pymeshfix_flag = False
                                                       )
        else:
        
            print("NOT Using a load file for meshes")

            [n_vertices,
             n_triangles,
             vertices,
             triangles,
             n_pieces,
             largest_piece_perc,
             outside_perc,
             n_stitched,
             stitched_addon_perc,
             n_unstitched,
             unstitched_perc] = stitch_neuron(segment_id=segment_id,
                                                          vertices=verts,
                                                          faces=faces,
                                                        import_from_off=False,
                                                         load_meshes_flag = False,
                                                     save_meshes_flag = True,
                                                        pymeshfix_flag = False
                                                       )

        #insert dummy dictionary into correspondence table
        insert_key = dict(key,
                          n_vertices=n_vertices,
                         n_triangles=n_triangles,
                         vertices=vertices,
                         triangles=triangles,
                         n_pieces=n_pieces,
                         largest_piece_perc=largest_piece_perc,
                         outside_perc=outside_perc,
                         n_stitched=n_stitched,
                         stitched_addon_perc=stitched_addon_perc,
                         n_unstitched=n_unstitched,
                         unstitched_perc=unstitched_perc)
                        
        
        self.insert1(insert_key,skip_duplicates=True)

# %%
start = time.time()
ExcitatoryStitchedMeshVp2.populate(reserve_jobs=True)
print(time.time() - start)
# Out:
# *****Running Neuron Stitcher for 648518346349471565**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349471565_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 4.403107166290283
# Number of outside child meshes =  16
# Main mesh and outside child meshes make up 0.9837759809108444% of original mesh
#  face length 4082553 using optimized facets with 3 neighbors
# Filtering edges by size finished: 56.17925310134888, facet # = 214916
# Filtering by convexity and getting centers took: 116.86207342147827, facet # = 41934
# Finished facets for main mesh: 179.77913808822632 with facet length = 41934
# Finished 41934 facets for main mesh: 179.77948021888733
# Filtering edges by size finished: 1.0582287311553955, facet # = 3153
# Filtering by convexity and getting centers took: 1.5724141597747803, facet # = 651
# Filtering edges by size finished: 0.15791916847229004, facet # = 568
# Filtering by convexity and getting centers took: 0.2352604866027832, facet # = 158
# Filtering edges by size finished: 0.7061216831207275, facet # = 2374
# Filtering by convexity and getting centers took: 0.8430767059326172, facet # = 770
# Filtering edges by size finished: 0.8449563980102539, facet # = 3247
# Filtering by convexity and getting centers took: 1.3168444633483887, facet # = 695
# Filtering edges by size finished: 1.317145824432373, facet # = 6391
# Filtering by convexity and getting centers took: 3.0405335426330566, facet # = 1398
# Filtering edges by size finished: 1.0579249858856201, facet # = 3171
# Filtering by convexity and getting centers took: 1.5296106338500977, facet # = 686
# Filtering edges by size finished: 1.7923476696014404, facet # = 5103
# Filtering by convexity and getting centers took: 2.203221321105957, facet # = 1365
# Filtering edges by size finished: 0.6476049423217773, facet # = 1941
# Filtering by convexity and getting centers took: 0.8418333530426025, facet # = 562
# Filtering edges by size finished: 0.000774383544921875, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0012483596801757812, facet # = 1
# Filtering edges by size finished: 0.6382081508636475, facet # = 2170
# Filtering by convexity and getting centers took: 1.291316032409668, facet # = 549
# Filtering edges by size finished: 0.4922444820404053, facet # = 1542
# Filtering by convexity and getting centers took: 0.7388675212860107, facet # = 334
# Filtering edges by size finished: 0.03442859649658203, facet # = 89
# Filtering by convexity and getting centers took: 0.2045886516571045, facet # = 37
# Filtering edges by size finished: 0.0008518695831298828, facet # = 5
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.003120899200439453, facet # = 5
# Filtering edges by size finished: 0.0007088184356689453, facet # = 4
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.002963542938232422, facet # = 4
# Filtering edges by size finished: 0.03714632987976074, facet # = 81
# Filtering by convexity and getting centers took: 0.08169245719909668, facet # = 28
# Filtering edges by size finished: 0.0014271736145019531, facet # = 1
# Had to restructure the array because was 2D array
# Filtering by convexity and getting centers took: 0.0012836456298828125, facet # = 1
# Total time for facets: 202.87141036987305
# Zero faceted faces = []
# Starting Child 0
# 651 41934
# Done distance matrix: 1.1688671112060547
# Done Generating final pairs: 1.2122807502746582
# best_stitch_pair = [  234 35527]
# best_stitch_pair_size = 720232.4591682404
# best_stitch_pair_distance = 385.7478512928278
# best_stitch_pair_size_ratio = 0.7736087962706647
# Starting Child 1
# 158 41934
# Done distance matrix: 0.37430739402770996
# Done Generating final pairs: 0.409151554107666
# best_stitch_pair = [   41 30084]
# best_stitch_pair_size = 281657.6752403149
# best_stitch_pair_distance = 1036.4090091745072
# best_stitch_pair_size_ratio = 0.1508808671372868
# Starting Child 2
# 770 41934
# Done distance matrix: 1.6028201580047607
# Done Generating final pairs: 1.642796277999878
# best_stitch_pair = [  686 13632]
# best_stitch_pair_size = 82392.97060880312
# best_stitch_pair_distance = 581.3289340438145
# best_stitch_pair_size_ratio = 0.8783034717794017
# Starting Child 3
# 695 41934
# Done distance matrix: 1.343122959136963
# Done Generating final pairs: 1.3787591457366943
# best_stitch_pair = [  125 30801]
# best_stitch_pair_size = 600653.5727066911
# best_stitch_pair_distance = 400.51239614892705
# best_stitch_pair_size_ratio = 0.982113042034436
# Starting Child 4
# 1398 41934
# Done distance matrix: 3.1125736236572266
# Done Generating final pairs: 3.1713037490844727
# best_stitch_pair = [   12 40523]
# best_stitch_pair_size = 673332.9718577227
# best_stitch_pair_distance = 255.76716037045753
# best_stitch_pair_size_ratio = 0.7124705334618868
# Starting Child 5
# 686 41934
# Done distance matrix: 1.3730647563934326
# Done Generating final pairs: 1.4178879261016846
# best_stitch_pair = [  636 20949]
# best_stitch_pair_size = 713285.5159922681
# best_stitch_pair_distance = 207.03395940673218
# best_stitch_pair_size_ratio = 0.5284905717300626
# Starting Child 6
# 1365 41934
# Done distance matrix: 3.0815529823303223
# Done Generating final pairs: 3.1402149200439453
# best_stitch_pair = [  116 35038]
# best_stitch_pair_size = 692114.1277008099
# best_stitch_pair_distance = 271.7172725659568
# best_stitch_pair_size_ratio = 0.6199163679859031
# Starting Child 7
# 562 41934
# Done distance matrix: 1.2783255577087402
# Done Generating final pairs: 1.3054041862487793
# best_stitch_pair = [   38 34181]
# best_stitch_pair_size = 364302.8249519665
# best_stitch_pair_distance = 678.2182151844115
# best_stitch_pair_size_ratio = 0.34267602413986736
# Starting Child 8
# returning x greater max
# skipped by bounding box filter
# Starting Child 9
# 549 41934
# Done distance matrix: 1.3930861949920654
# Done Generating final pairs: 1.4449701309204102
# best_stitch_pair = [ 482 4281]
# best_stitch_pair_size = 187698.40451282525
# best_stitch_pair_distance = 642.4219011066562
# best_stitch_pair_size_ratio = 0.529930295297457
# Starting Child 10
# 334 41934
# Done distance matrix: 0.7821342945098877
# Done Generating final pairs: 0.8948290348052979
# best_stitch_pair = [  255 27078]
# best_stitch_pair_size = 100330.60223138686
# best_stitch_pair_distance = 176.39319904631978
# best_stitch_pair_size_ratio = 0.4706250376339773
# Starting Child 11
# 37 41934
# Done distance matrix: 0.07314324378967285
# Child 11 There were no points close enough
# Starting Child 12
# 5 41934
# Done distance matrix: 0.007634162902832031
# Child 12 There were no points close enough
# Starting Child 13
# 4 41934
# Done distance matrix: 0.006014347076416016
# Child 13 There were no points close enough
# Starting Child 14
# 28 41934
# Done distance matrix: 0.035349369049072266
# Child 14 There were no points close enough
# Starting Child 15
# 1 41934
# Done distance matrix: 0.004141092300415039
# Child 15 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {0: [234, 35527], 1: [41, 30084], 2: [686, 13632], 3: [125, 30801], 4: [12, 40523], 5: [636, 20949], 6: [116, 35038], 7: [38, 34181], 9: [482, 4281], 10: [255, 27078]}
# ---Stitching child 0 with pair: [234, 35527]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1551396, starting edge 2nd facet= 2069802,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 5.53131103515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07455873489379883
# returned from stitch mesh: 3.6574413776397705
# Finished stitching child 0 : 4.335317611694336
# ---Stitching child 1 with pair: [41, 30084]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1878161, starting edge 2nd facet= 2079439,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 2.7179718017578125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.16482925415039062
# returned from stitch mesh: 3.633375644683838
# Finished stitching child 1 : 4.122911214828491
# ---Stitching child 2 with pair: [686, 13632]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 524433, starting edge 2nd facet= 2082628,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 1.6689300537109375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08140420913696289
# returned from stitch mesh: 4.021463632583618
# Finished stitching child 2 : 4.8110973834991455
# ---Stitching child 3 with pair: [125, 30801]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 743857, starting edge 2nd facet= 2097161,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 6
# About to add faces
# Finished adding faces: 3.552436828613281e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09004068374633789
# returned from stitch mesh: 3.993155002593994
# Finished stitching child 3 : 4.4953131675720215
# ---Stitching child 4 with pair: [12, 40523]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 868821, starting edge 2nd facet= 2114080,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 30
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 4
# About to add faces
# Finished adding faces: 5.745887756347656e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1179664134979248
# returned from stitch mesh: 3.6114840507507324
# Finished stitching child 4 : 4.137366771697998
# ---Stitching child 5 with pair: [636, 20949]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 796217, starting edge 2nd facet= 2140351,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 21
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 9
# About to add faces
# Finished adding faces: 4.506111145019531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07506132125854492
# returned from stitch mesh: 3.985936164855957
# Finished stitching child 5 : 4.719649314880371
# ---Stitching child 6 with pair: [116, 35038]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1409660, starting edge 2nd facet= 2153989,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 3.910064697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07703852653503418
# returned from stitch mesh: 3.781442165374756
# Finished stitching child 6 : 4.376799583435059
# ---Stitching child 7 with pair: [38, 34181]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1046215, starting edge 2nd facet= 2161353,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 1.9788742065429688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0666351318359375
# returned from stitch mesh: 3.532217264175415
# Finished stitching child 7 : 4.155534029006958
# ---Stitching child 9 with pair: [482, 4281]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1036159, starting edge 2nd facet= 2170119,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 3.337860107421875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.1444401741027832
# returned from stitch mesh: 4.945776462554932
# Finished stitching child 9 : 5.673241376876831
# ---Stitching child 10 with pair: [255, 27078]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1571339, starting edge 2nd facet= 2180468,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 1.5974044799804688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07853245735168457
# returned from stitch mesh: 3.474480628967285
# Finished stitching child 10 : 4.010494947433472
# ***************Finished big stitching iteration: 63.037355184555054***************
# Starting Child 8
# 1 49082
# Done distance matrix: 0.012605428695678711
# Child 8 There were no points close enough
# Starting Child 11
# 37 49082
# Done distance matrix: 0.21578311920166016
# Child 11 There were no points close enough
# Starting Child 12
# 5 49082
# Done distance matrix: 0.032353878021240234
# Done Generating final pairs: 0.04933023452758789
# best_stitch_pair = [    4 42070]
# best_stitch_pair_size = 48177.0145578094
# best_stitch_pair_distance = 1696.9714485282793
# best_stitch_pair_size_ratio = 0.21187204667805465
# Starting Child 13
# 4 49082
# Done distance matrix: 0.020731210708618164
# Done Generating final pairs: 0.028105974197387695
# best_stitch_pair = [    3 42948]
# best_stitch_pair_size = 71346.3954390533
# best_stitch_pair_distance = 202.81431877264103
# best_stitch_pair_size_ratio = 0.1514372724895154
# Starting Child 14
# 28 49082
# Done distance matrix: 0.04829668998718262
# Done Generating final pairs: 0.10384011268615723
# best_stitch_pair = [    6 42645]
# best_stitch_pair_size = 94609.46598661519
# best_stitch_pair_distance = 861.0879439834714
# best_stitch_pair_size_ratio = 0.5370165079343476
# Starting Child 15
# 1 49082
# Done distance matrix: 0.0020875930786132812
# Child 15 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {12: [4, 42070], 13: [3, 42948], 14: [6, 42645]}
# ---Stitching child 12 with pair: [4, 42070]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2067874, starting edge 2nd facet= 2182442,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.6450881958007812e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08350110054016113
# returned from stitch mesh: 3.3801193237304688
# Finished stitching child 12 : 4.028951406478882
# ---Stitching child 13 with pair: [3, 42948]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2084227, starting edge 2nd facet= 2182458,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.7642974853515625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.12218737602233887
# returned from stitch mesh: 3.2880749702453613
# Finished stitching child 13 : 3.761094570159912
# ---Stitching child 14 with pair: [6, 42645]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2080050, starting edge 2nd facet= 2182607,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 1
# About to add faces
# Finished adding faces: 2.5987625122070312e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.11018204689025879
# returned from stitch mesh: 4.877078533172607
# Finished stitching child 14 : 5.805505037307739
# ***************Finished big stitching iteration: 18.895501613616943***************
# Starting Child 8
# 1 49113
# Done distance matrix: 0.0021648406982421875
# Child 8 There were no points close enough
# Starting Child 11
# 37 49113
# Done distance matrix: 0.07962179183959961
# Done Generating final pairs: 0.08885931968688965
# best_stitch_pair = [   10 49090]
# best_stitch_pair_size = 211755.15770246432
# best_stitch_pair_distance = 289.2447542425842
# best_stitch_pair_size_ratio = 0.5645362006222852
# Starting Child 15
# 1 49113
# Done distance matrix: 0.002693653106689453
# Child 15 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [10, 49090]}
# ---Stitching child 11 with pair: [10, 49090]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2182615, starting edge 2nd facet= 2183169,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 9
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 8
# About to add faces
# Finished adding faces: 4.696846008300781e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.16082119941711426
# returned from stitch mesh: 4.152865409851074
# Finished stitching child 11 : 4.779794692993164
# ***************Finished big stitching iteration: 10.233781814575195***************
# Starting Child 8
# 1 49148
# Done distance matrix: 0.002964019775390625
# Child 8 There were no points close enough
# Starting Child 15
# 1 49148
# Done distance matrix: 0.0021009445190429688
# Child 15 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 8
# 1 49148
# Done distance matrix: 0.0030579566955566406
# Child 8 There were no points close enough
# Starting Child 15
# 1 49148
# Done distance matrix: 0.05999755859375
# Child 15 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 8
# 1 49148
# Done distance matrix: 0.0017824172973632812
# Child 8 There were no points close enough
# Starting Child 15
# 1 49148
# Done distance matrix: 0.00162506103515625
# Child 15 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 8
# 1 49148
# Done distance matrix: 0.002380847930908203
# Child 8 There were no points close enough
# Starting Child 15
# 1 49148
# Done distance matrix: 0.05179572105407715
# Child 15 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 101.77617311477661
# Total time for restitching = 101.83614563941956
# missed_children = [8.0, 15.0]
# Whole stitching function complete: 315.63721227645874
#
#
#
# *****Running Neuron Stitcher for 648518346349477981**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349477981_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 7.2797675132751465
# Number of outside child meshes =  16
# Main mesh and outside child meshes make up 0.9808629581543367% of original mesh
#  face length 2045669 using optimized facets with 3 neighbors
# Filtering edges by size finished: 75.573659658432, facet # = 107646
# Filtering by convexity and getting centers took: 83.28536677360535, facet # = 21416
# Finished facets for main mesh: 166.2745440006256 with facet length = 21416
# Finished 21416 facets for main mesh: 166.27495050430298
# Filtering edges by size finished: 5.121239900588989, facet # = 7809
# Filtering by convexity and getting centers took: 6.197089433670044, facet # = 2277
# Filtering edges by size finished: 5.509514331817627, facet # = 11432
# Filtering by convexity and getting centers took: 8.54098629951477, facet # = 3261
# Filtering edges by size finished: 1.7706434726715088, facet # = 4622
# Filtering by convexity and getting centers took: 2.313910722732544, facet # = 1186
# Filtering edges by size finished: 0.8152704238891602, facet # = 1405
# Filtering by convexity and getting centers took: 0.7667124271392822, facet # = 393
# Filtering edges by size finished: 0.029423952102661133, facet # = 81
# Filtering by convexity and getting centers took: 0.029163360595703125, facet # = 53
# Filtering edges by size finished: 0.2931504249572754, facet # = 916
# Filtering by convexity and getting centers took: 0.5680220127105713, facet # = 270
# Filtering edges by size finished: 0.11537337303161621, facet # = 237
# Filtering by convexity and getting centers took: 0.06954073905944824, facet # = 70
# Filtering edges by size finished: 0.01098322868347168, facet # = 58
# Filtering by convexity and getting centers took: 0.02629876136779785, facet # = 39
# Filtering edges by size finished: 0.06327104568481445, facet # = 187
# Filtering by convexity and getting centers took: 0.08159327507019043, facet # = 69
# Filtering edges by size finished: 0.19252228736877441, facet # = 401
# Filtering by convexity and getting centers took: 0.3412754535675049, facet # = 117
# Filtering edges by size finished: 0.010194540023803711, facet # = 22
# Filtering by convexity and getting centers took: 0.012021780014038086, facet # = 2
# Filtering edges by size finished: 0.003965616226196289, facet # = 7
# Filtering by convexity and getting centers took: 0.006042003631591797, facet # = 5
# Filtering edges by size finished: 0.005129098892211914, facet # = 11
# Filtering by convexity and getting centers took: 0.007425546646118164, facet # = 5
# Filtering edges by size finished: 0.00820469856262207, facet # = 18
# Filtering by convexity and getting centers took: 0.014179468154907227, facet # = 10
# Filtering edges by size finished: 0.002296924591064453, facet # = 6
# Filtering by convexity and getting centers took: 0.004065513610839844, facet # = 5
# Filtering edges by size finished: 0.00677943229675293, facet # = 11
# Filtering by convexity and getting centers took: 0.008490800857543945, facet # = 11
# Total time for facets: 200.35092520713806
# Zero faceted faces = []
# Starting Child 0
# 2277 21416
# Done distance matrix: 3.11946964263916
# Child 0 There were no points close enough
# Starting Child 1
# 3261 21416
# Done distance matrix: 4.908429384231567
# Done Generating final pairs: 5.106020927429199
# best_stitch_pair = [709 554]
# best_stitch_pair_size = 942861.85647744
# best_stitch_pair_distance = 339.23232408653575
# best_stitch_pair_size_ratio = 0.48420869596064325
# Starting Child 2
# 1186 21416
# Done distance matrix: 2.0380876064300537
# Child 2 There were no points close enough
# Starting Child 3
# 393 21416
# Done distance matrix: 0.5266671180725098
# Child 3 There were no points close enough
# Starting Child 4
# 53 21416
# Done distance matrix: 0.03982186317443848
# Child 4 There were no points close enough
# Starting Child 5
# 270 21416
# Done distance matrix: 0.2037501335144043
# Child 5 There were no points close enough
# Starting Child 6
# 70 21416
# Done distance matrix: 0.16200685501098633
# Child 6 There were no points close enough
# Starting Child 7
# 39 21416
# Done distance matrix: 0.027707576751708984
# Done Generating final pairs: 0.053073883056640625
# best_stitch_pair = [   35 15008]
# best_stitch_pair_size = 96128.01518294915
# best_stitch_pair_distance = 1515.8471850054339
# best_stitch_pair_size_ratio = 0.39535541915852185
# Starting Child 8
# returning x greater max
# skipped by bounding box filter
# Starting Child 9
# 117 21416
# Done distance matrix: 0.08711433410644531
# Child 9 There were no points close enough
# Starting Child 10
# 2 21416
# Done distance matrix: 0.0021533966064453125
# Child 10 There were no points close enough
# Starting Child 11
# 5 21416
# Done distance matrix: 0.0070726871490478516
# Child 11 There were no points close enough
# Starting Child 12
# 5 21416
# Done distance matrix: 0.0051670074462890625
# Child 12 There were no points close enough
# Starting Child 13
# 10 21416
# Done distance matrix: 0.014302730560302734
# Child 13 There were no points close enough
# Starting Child 14
# 5 21416
# Done distance matrix: 0.005951881408691406
# Child 14 There were no points close enough
# Starting Child 15
# 11 21416
# Done distance matrix: 0.009957075119018555
# Child 15 There were no points close enough
# repeat_main_facets = []
# child_meshes_stitch_facets = {1: [709, 554], 7: [35, 15008]}
# ---Stitching child 1 with pair: [709, 554]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 33796, starting edge 2nd facet= 1086721,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 21
# Starting Organizing vertices for side 1
# edge_1_order done, len = 36
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 15
# About to add faces
# Finished adding faces: 7.486343383789062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06421351432800293
# returned from stitch mesh: 2.3595926761627197
# Finished stitching child 1 : 2.736132860183716
# ---Stitching child 7 with pair: [35, 15008]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 883782, starting edge 2nd facet= 1141594,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.6464462280273438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03385424613952637
# returned from stitch mesh: 2.152453660964966
# Finished stitching child 7 : 2.510554552078247
# ***************Finished big stitching iteration: 17.966598510742188***************
# Starting Child 0
# 2277 24712
# Done distance matrix: 3.3358538150787354
# Done Generating final pairs: 3.402423143386841
# best_stitch_pair = [ 1870 21849]
# best_stitch_pair_size = 483817.0629104107
# best_stitch_pair_distance = 1524.7248494306966
# best_stitch_pair_size_ratio = 0.46487570300250364
# Starting Child 2
# 1186 24712
# Done distance matrix: 1.724635362625122
# Done Generating final pairs: 1.7314579486846924
# best_stitch_pair = [  674 23125]
# best_stitch_pair_size = 110084.05223150131
# best_stitch_pair_distance = 910.4825861391306
# best_stitch_pair_size_ratio = 0.8280306006339927
# Starting Child 3
# 393 24712
# Done distance matrix: 0.5697379112243652
# Child 3 There were no points close enough
# Starting Child 4
# 53 24712
# Done distance matrix: 0.15557622909545898
# Done Generating final pairs: 0.1639115810394287
# best_stitch_pair = [   15 21524]
# best_stitch_pair_size = 62108.70124815138
# best_stitch_pair_distance = 1924.3461475773568
# best_stitch_pair_size_ratio = 0.8975665464723473
# Starting Child 5
# 270 24712
# Done distance matrix: 0.5313234329223633
# Child 5 There were no points close enough
# Starting Child 6
# 70 24712
# Done distance matrix: 0.058675289154052734
# Done Generating final pairs: 0.061615943908691406
# best_stitch_pair = [   60 21457]
# best_stitch_pair_size = 124476.68389948456
# best_stitch_pair_distance = 1985.6791010767213
# best_stitch_pair_size_ratio = 0.18743112274015816
# Starting Child 8
# 69 24712
# Done distance matrix: 0.05365729331970215
# Done Generating final pairs: 0.05591249465942383
# best_stitch_pair = [   19 22974]
# best_stitch_pair_size = 102528.72174422894
# best_stitch_pair_distance = 1957.2372874708658
# best_stitch_pair_size_ratio = 0.2638050868799565
# Starting Child 9
# 117 24712
# Done distance matrix: 0.09403705596923828
# Child 9 There were no points close enough
# Starting Child 10
# 2 24712
# Done distance matrix: 0.0024933815002441406
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 5 24712
# Done distance matrix: 0.004775524139404297
# Done Generating final pairs: 0.007618427276611328
# best_stitch_pair = [    0 23220]
# best_stitch_pair_size = 181331.60397915775
# best_stitch_pair_distance = 1817.0496022032107
# best_stitch_pair_size_ratio = 0.43208998975357493
# Starting Child 12
# 5 24712
# Done distance matrix: 0.004650115966796875
# Done Generating final pairs: 0.009589672088623047
# best_stitch_pair = [    0 23220]
# best_stitch_pair_size = 311736.8742161689
# best_stitch_pair_distance = 1295.7399303388918
# best_stitch_pair_size_ratio = 0.6840026605121995
# Starting Child 13
# 10 24712
# Done distance matrix: 0.009550333023071289
# Done Generating final pairs: 0.015196561813354492
# best_stitch_pair = [    2 23220]
# best_stitch_pair_size = 365725.3654391335
# best_stitch_pair_distance = 1364.4515513948265
# best_stitch_pair_size_ratio = 0.5295589849723067
# Starting Child 14
# 5 24712
# Done distance matrix: 0.015755891799926758
# Done Generating final pairs: 0.020457744598388672
# best_stitch_pair = [    0 23220]
# best_stitch_pair_size = 200655.89918238367
# best_stitch_pair_distance = 1371.9620415111665
# best_stitch_pair_size_ratio = 0.5847061311889298
# Starting Child 15
# 11 24712
# Done distance matrix: 0.010526180267333984
# Done Generating final pairs: 0.014925241470336914
# best_stitch_pair = [    6 23220]
# best_stitch_pair_size = 397865.511462669
# best_stitch_pair_distance = 1573.3291507857998
# best_stitch_pair_size_ratio = 0.4668109630707504
# repeat_main_facets = [23220]
# child_mesh_double_indexes = [11, 12, 13, 14, 15]
# min_child = 12, max_ratio = 1295.7399303388918
# child_meshes_stitch_facets = {0: [1870, 21849], 2: [674, 23125], 4: [15, 21524], 6: [60, 21457], 8: [19, 22974], 12: [0, 23220]}
# ---Stitching child 0 with pair: [1870, 21849]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1070728, starting edge 2nd facet= 1201989,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 17
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 4.601478576660156e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.08269643783569336
# returned from stitch mesh: 2.5737199783325195
# Finished stitching child 0 : 3.0064337253570557
# ---Stitching child 2 with pair: [674, 23125]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1129790, starting edge 2nd facet= 1231475,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 6
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.1457672119140625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04197978973388672
# returned from stitch mesh: 1.8797767162322998
# Finished stitching child 2 : 2.2940945625305176
# ---Stitching child 4 with pair: [15, 21524]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1064323, starting edge 2nd facet= 1240030,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.4781951904296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.006992816925048828
# returned from stitch mesh: 2.5149078369140625
# Finished stitching child 4 : 2.7809903621673584
# ---Stitching child 6 with pair: [60, 21457]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1082006, starting edge 2nd facet= 1241114,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 5
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 1.5020370483398438e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03790736198425293
# returned from stitch mesh: 2.469468116760254
# Finished stitching child 6 : 2.786926507949829
# ---Stitching child 8 with pair: [19, 22974]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1134076, starting edge 2nd facet= 1241890,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 11
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 1.71661376953125e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.037496089935302734
# returned from stitch mesh: 2.1834230422973633
# Finished stitching child 8 : 2.6794967651367188
# ---Stitching child 12 with pair: [0, 23220]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1064384, starting edge 2nd facet= 1242041,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 10
# Starting Organizing vertices for side 1
# edge_1_order done, len = 13
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 3
# About to add faces
# Finished adding faces: 3.7670135498046875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04836273193359375
# returned from stitch mesh: 2.257582426071167
# Finished stitching child 12 : 2.4946367740631104
# ***************Finished big stitching iteration: 25.903699159622192***************
# Starting Child 3
# 393 28360
# Done distance matrix: 0.5205607414245605
# Done Generating final pairs: 0.5252861976623535
# best_stitch_pair = [  330 27757]
# best_stitch_pair_size = 46773.6215542561
# best_stitch_pair_distance = 1409.8045177007973
# best_stitch_pair_size_ratio = 0.42947501425805645
# Starting Child 5
# 270 28360
# Done distance matrix: 0.2864203453063965
# Child 5 There were no points close enough
# Starting Child 9
# 117 28360
# Done distance matrix: 0.39655160903930664
# Done Generating final pairs: 0.4110739231109619
# best_stitch_pair = [   68 28270]
# best_stitch_pair_size = 184638.11273752374
# best_stitch_pair_distance = 1047.5527671745986
# best_stitch_pair_size_ratio = 0.8488816358228948
# Starting Child 10
# 2 28360
# Done distance matrix: 0.004124879837036133
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 5 28360
# Done distance matrix: 0.007318019866943359
# Done Generating final pairs: 0.018713712692260742
# best_stitch_pair = [    0 28356]
# best_stitch_pair_size = 258235.7894046121
# best_stitch_pair_distance = 780.9504645444075
# best_stitch_pair_size_ratio = 0.2688195337163587
# Starting Child 13
# 10 28360
# Done distance matrix: 0.044400930404663086
# Done Generating final pairs: 0.05425310134887695
# best_stitch_pair = [    2 28356]
# best_stitch_pair_size = 442629.5508645879
# best_stitch_pair_distance = 151.72070663893786
# best_stitch_pair_size_ratio = 0.8511923714294916
# Starting Child 14
# 5 28360
# Done distance matrix: 0.007680416107177734
# Done Generating final pairs: 0.012644290924072266
# best_stitch_pair = [    0 28356]
# best_stitch_pair_size = 277560.084607838
# best_stitch_pair_distance = 431.04783289928224
# best_stitch_pair_size_ratio = 0.3637678105825725
# Starting Child 15
# 11 28360
# Done distance matrix: 0.1209416389465332
# Done Generating final pairs: 0.12766504287719727
# best_stitch_pair = [    6 28356]
# best_stitch_pair_size = 474769.69688812335
# best_stitch_pair_distance = 574.8156227019261
# best_stitch_pair_size_ratio = 0.750333658650426
# repeat_main_facets = [28356]
# child_mesh_double_indexes = [11, 13, 14, 15]
# min_child = 13, max_ratio = 151.72070663893786
# child_meshes_stitch_facets = {3: [330, 27757], 9: [68, 28270], 13: [2, 28356]}
# ---Stitching child 3 with pair: [330, 27757]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1236187, starting edge 2nd facet= 1247016,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 4
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.1219253540039062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04339599609375
# returned from stitch mesh: 2.7629287242889404
# Finished stitching child 3 : 3.5277838706970215
# ---Stitching child 9 with pair: [68, 28270]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1240973, starting edge 2nd facet= 1249173,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 10
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 3.743171691894531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04301142692565918
# returned from stitch mesh: 2.4396114349365234
# Finished stitching child 9 : 2.8147952556610107
# ---Stitching child 13 with pair: [2, 28356]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1242011, starting edge 2nd facet= 1249230,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 12
# Starting Organizing vertices for side 1
# edge_1_order done, len = 14
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.910064697265625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04265093803405762
# returned from stitch mesh: 2.1320297718048096
# Finished stitching child 13 : 2.500865936279297
# ***************Finished big stitching iteration: 13.533150672912598***************
# Starting Child 5
# 270 28874
# Done distance matrix: 0.37810683250427246
# Done Generating final pairs: 0.3985555171966553
# best_stitch_pair = [  129 28797]
# best_stitch_pair_size = 47491.19609440926
# best_stitch_pair_distance = 361.1469952233655
# best_stitch_pair_size_ratio = 0.8181381093155301
# Starting Child 10
# 2 28874
# Done distance matrix: 0.008896350860595703
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 5 28874
# Done distance matrix: 0.016779422760009766
# Done Generating final pairs: 0.02592921257019043
# best_stitch_pair = [    0 28867]
# best_stitch_pair_size = 326107.39177595096
# best_stitch_pair_distance = 439.52562577557893
# best_stitch_pair_size_ratio = 0.20159227383273018
# Starting Child 14
# 5 28874
# Done distance matrix: 0.007208585739135742
# Done Generating final pairs: 0.052280426025390625
# best_stitch_pair = [    0 28867]
# best_stitch_pair_size = 345431.6869791769
# best_stitch_pair_distance = 197.85727728607688
# best_stitch_pair_size_ratio = 0.2727955780172983
# Starting Child 15
# 11 28874
# Done distance matrix: 0.019640207290649414
# Done Generating final pairs: 0.03699755668640137
# best_stitch_pair = [    6 28867]
# best_stitch_pair_size = 542641.2992594622
# best_stitch_pair_distance = 248.62059047455537
# best_stitch_pair_size_ratio = 0.9994443827286742
# repeat_main_facets = [28867]
# child_mesh_double_indexes = [11, 14, 15]
# min_child = 14, max_ratio = 197.85727728607688
# child_meshes_stitch_facets = {5: [129, 28797], 14: [0, 28867]}
# ---Stitching child 5 with pair: [129, 28797]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1248652, starting edge 2nd facet= 1252358,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 5
# Main originally was clockwise --> flipping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 1.9311904907226562e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06854128837585449
# returned from stitch mesh: 2.315739393234253
# Finished stitching child 5 : 2.7842981815338135
# ---Stitching child 14 with pair: [0, 28867]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1249265, starting edge 2nd facet= 1253087,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 17
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 3
# About to add faces
# Finished adding faces: 2.5033950805664062e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03086090087890625
# returned from stitch mesh: 2.1415817737579346
# Finished stitching child 14 : 2.40145206451416
# ***************Finished big stitching iteration: 8.967816829681396***************
# Starting Child 10
# 2 29145
# Done distance matrix: 0.0030574798583984375
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 5 29145
# Done distance matrix: 0.008508443832397461
# Done Generating final pairs: 0.013371706008911133
# best_stitch_pair = [    0 29141]
# best_stitch_pair_size = 211675.3893159916
# best_stitch_pair_distance = 314.61894580955686
# best_stitch_pair_size_ratio = 0.34855973902413623
# Starting Child 15
# 11 29145
# Done distance matrix: 0.022441387176513672
# Done Generating final pairs: 0.031476736068725586
# best_stitch_pair = [    6 29141]
# best_stitch_pair_size = 428209.29679950286
# best_stitch_pair_distance = 141.02381182014108
# best_stitch_pair_size_ratio = 0.5786794103495981
# repeat_main_facets = [29141]
# child_mesh_double_indexes = [11, 15]
# min_child = 15, max_ratio = 141.02381182014108
# child_meshes_stitch_facets = {15: [6, 29141]}
# ---Stitching child 15 with pair: [6, 29141]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1253073, starting edge 2nd facet= 1253104,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 8
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 3.743171691894531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04334712028503418
# returned from stitch mesh: 1.6989860534667969
# Finished stitching child 15 : 2.3131556510925293
# ***************Finished big stitching iteration: 4.806843280792236***************
# Starting Child 10
# 2 29154
# Done distance matrix: 0.008124589920043945
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# Starting Child 11
# 5 29154
# Done distance matrix: 0.007265329360961914
# Done Generating final pairs: 0.011667966842651367
# best_stitch_pair = [    0 29146]
# best_stitch_pair_size = 322713.4763922411
# best_stitch_pair_distance = 178.18029038957874
# best_stitch_pair_size_ratio = 0.20414519055151942
# repeat_main_facets = []
# child_meshes_stitch_facets = {11: [0, 29146]}
# ---Stitching child 11 with pair: [0, 29146]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1253109, starting edge 2nd facet= 1253138,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 16
# Starting Organizing vertices for side 1
# edge_1_order done, len = 8
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 2, remainder = 0
# About to add faces
# Finished adding faces: 2.574920654296875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.03939366340637207
# returned from stitch mesh: 2.2533583641052246
# Finished stitching child 11 : 2.527850866317749
# ***************Finished big stitching iteration: 4.784630298614502***************
# Starting Child 10
# 2 29157
# Done distance matrix: 0.0030896663665771484
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 10
# 2 29157
# Done distance matrix: 0.0022950172424316406
# Child 10 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 10
# 2 29157
# Done distance matrix: 0.0029845237731933594
# Done Generating final pairs: 0.006319522857666016
# best_stitch_pair = [    0 23298]
# best_stitch_pair_size = 45348.06613230807
# best_stitch_pair_distance = 2761.709676556143
# best_stitch_pair_size_ratio = 0.57568225781733
# repeat_main_facets = []
# child_meshes_stitch_facets = {10: [0, 23298]}
# ---Stitching child 10 with pair: [0, 23298]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1096437, starting edge 2nd facet= 1253155,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 7
# Starting Organizing vertices for side 1
# edge_1_order done, len = 7
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 0
# About to add faces
# Finished adding faces: 2.6702880859375e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.04549217224121094
# returned from stitch mesh: 2.268394947052002
# Finished stitching child 10 : 2.667884111404419
# ***************Finished big stitching iteration: 2.8702569007873535***************
# All children have been processed
# total_stitch_processing_time = 81.47738027572632
# Total time for restitching = 81.48669219017029
# missed_children = []
# Whole stitching function complete: 293.57869815826416
#
#
#
# *****Running Neuron Stitcher for 648518346349478860**********
# Using a load file for meshes
# import child and main meshes fromstitch_mesh_saved/648518346349478860_30_main_and_child_meshes_array.npz
# Total time for Mesh Cleansing: 3.0211832523345947
# Number of outside child meshes =  11
# Main mesh and outside child meshes make up 0.9802410616415106% of original mesh
#  face length 1075218 using optimized facets with 3 neighbors
# Filtering edges by size finished: 27.28723406791687, facet # = 54956
# Filtering by convexity and getting centers took: 34.93947076797485, facet # = 10985
# Finished facets for main mesh: 64.36654472351074 with facet length = 10985
# Finished 10985 facets for main mesh: 64.36676049232483
# Filtering edges by size finished: 3.7054567337036133, facet # = 8322
# Filtering by convexity and getting centers took: 5.196105241775513, facet # = 2581
# Filtering edges by size finished: 0.5660560131072998, facet # = 1685
# Filtering by convexity and getting centers took: 0.939225435256958, facet # = 527
# Filtering edges by size finished: 0.20554518699645996, facet # = 446
# ...
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 25
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 2, remainder = 7
# About to add faces
# Finished adding faces: 3.504753112792969e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.0638265609741211
# returned from stitch mesh: 2.3303844928741455
# Finished stitching child 30 : 3.017289400100708
# ---Stitching child 34 with pair: [9, 46359]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2012941, starting edge 2nd facet= 2103697,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 15
# Starting Organizing vertices for side 1
# edge_1_order done, len = 19
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.743171691894531e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.09842967987060547
# returned from stitch mesh: 2.390428304672241
# Finished stitching child 34 : 2.7809362411499023
# ***************Finished big stitching iteration: 31.763484954833984***************
# Starting Child 15
# 43 48767
# Done distance matrix: 0.10725736618041992
# Done Generating final pairs: 0.1334986686706543
# best_stitch_pair = [   17 48689]
# best_stitch_pair_size = 683409.7470838015
# best_stitch_pair_distance = 1192.7228495776658
# best_stitch_pair_size_ratio = 0.4090693353992881
# Starting Child 19
# 2 48767
# Done distance matrix: 0.00640559196472168
# Done Generating final pairs: 0.009163141250610352
# best_stitch_pair = [    1 47038]
# best_stitch_pair_size = 28938.114188333755
# best_stitch_pair_distance = 1609.5445796886138
# best_stitch_pair_size_ratio = 0.3682613432571457
# Starting Child 20
# 22 48767
# Done distance matrix: 0.03698539733886719
# Done Generating final pairs: 0.04186844825744629
# best_stitch_pair = [    6 48715]
# best_stitch_pair_size = 634726.7322960435
# best_stitch_pair_distance = 1601.9126515826379
# best_stitch_pair_size_ratio = 0.547805148984704
# Starting Child 21
# 9 48767
# Done distance matrix: 0.0146484375
# Done Generating final pairs: 0.022586822509765625
# best_stitch_pair = [    1 48757]
# best_stitch_pair_size = 693589.9110662958
# best_stitch_pair_distance = 1834.36293695088
# best_stitch_pair_size_ratio = 0.9438317211655035
# Starting Child 22
# 10 48767
# Done distance matrix: 0.022082805633544922
# Done Generating final pairs: 0.03891158103942871
# best_stitch_pair = [    1 48757]
# best_stitch_pair_size = 731019.84581518
# best_stitch_pair_distance = 1555.975011744271
# best_stitch_pair_size_ratio = 0.8542237564866753
# Starting Child 27
# 11 48767
# Done distance matrix: 0.017180919647216797
# Done Generating final pairs: 0.023450374603271484
# best_stitch_pair = [    7 48689]
# best_stitch_pair_size = 446140.37484095624
# best_stitch_pair_distance = 1969.616593253861
# best_stitch_pair_size_ratio = 0.8008518679504018
# Starting Child 32
# 1 48767
# Done distance matrix: 0.0016937255859375
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48767
# Done distance matrix: 0.0019152164459228516
# Child 40 There were no points close enough
# Starting Child 41
# 15 48767
# Done distance matrix: 0.025104522705078125
# Done Generating final pairs: 0.03400826454162598
# best_stitch_pair = [    4 48757]
# best_stitch_pair_size = 683870.9798331477
# best_stitch_pair_distance = 372.2180062127653
# best_stitch_pair_size_ratio = 0.9702596030326368
# Starting Child 42
# 2 48767
# Done distance matrix: 0.005533933639526367
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [48689, 48757]
# child_mesh_double_indexes = [15, 27]
# min_child = 15, max_ratio = 1192.7228495776658
# child_mesh_double_indexes = [21, 22, 41]
# min_child = 41, max_ratio = 372.2180062127653
# child_meshes_stitch_facets = {15: [17, 48689], 19: [1, 47038], 20: [6, 48715], 41: [4, 48757]}
# ---Stitching child 15 with pair: [17, 48689]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2102751, starting edge 2nd facet= 2104235,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 11
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 5
# About to add faces
# Finished adding faces: 2.5510787963867188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06406688690185547
# returned from stitch mesh: 2.4905967712402344
# Finished stitching child 15 : 2.880741834640503
# ---Stitching child 19 with pair: [1, 47038]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2082125, starting edge 2nd facet= 2104567,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 6
# Starting Organizing vertices for side 1
# edge_1_order done, len = 4
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 1.7881393432617188e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07179427146911621
# returned from stitch mesh: 2.485586404800415
# Finished stitching child 19 : 2.9866340160369873
# ---Stitching child 20 with pair: [6, 48715]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2103154, starting edge 2nd facet= 2104584,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 18
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = main
# dividend = 1, remainder = 4
# About to add faces
# Finished adding faces: 3.4332275390625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06269526481628418
# returned from stitch mesh: 2.2785861492156982
# Finished stitching child 20 : 2.676210641860962
# ---Stitching child 41 with pair: [4, 48757]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2103766, starting edge 2nd facet= 2104759,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 13
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 1, remainder = 1
# About to add faces
# Finished adding faces: 2.7418136596679688e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.07491230964660645
# returned from stitch mesh: 2.5405449867248535
# Finished stitching child 41 : 2.921980619430542
# ***************Finished big stitching iteration: 14.674258470535278***************
# Starting Child 21
# 9 48841
# Done distance matrix: 0.01581597328186035
# Done Generating final pairs: 0.6570994853973389
# best_stitch_pair = [    1 48807]
# best_stitch_pair_size = 900163.5723350524
# best_stitch_pair_distance = 635.8590236120185
# best_stitch_pair_size_ratio = 0.6566988080399858
# Starting Child 22
# 10 48841
# Done distance matrix: 0.01675248146057129
# Done Generating final pairs: 0.03342413902282715
# best_stitch_pair = [    1 48807]
# best_stitch_pair_size = 937593.5070839366
# best_stitch_pair_distance = 891.4824760772842
# best_stitch_pair_size_ratio = 0.7255864304558037
# Starting Child 27
# 11 48841
# Done distance matrix: 0.01746392250061035
# Done Generating final pairs: 0.028973102569580078
# best_stitch_pair = [    7 48776]
# best_stitch_pair_size = 871406.2586369106
# best_stitch_pair_distance = 1175.992169438933
# best_stitch_pair_size_ratio = 0.397228369147596
# Starting Child 32
# 1 48841
# Done distance matrix: 0.001760244369506836
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48841
# Done distance matrix: 0.0017409324645996094
# Child 40 There were no points close enough
# Starting Child 42
# 2 48841
# Done distance matrix: 0.005659818649291992
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = [48807]
# child_mesh_double_indexes = [21, 22]
# min_child = 21, max_ratio = 635.8590236120185
# child_meshes_stitch_facets = {21: [1, 48807], 27: [7, 48776]}
# ---Stitching child 21 with pair: [1, 48807]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2104645, starting edge 2nd facet= 2104811,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 14
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 4.9114227294921875e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.02361607551574707
# returned from stitch mesh: 2.4064011573791504
# Finished stitching child 21 : 2.7540738582611084
# ---Stitching child 27 with pair: [7, 48776]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2104468, starting edge 2nd facet= 2104860,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 26
# Starting Organizing vertices for side 1
# edge_1_order done, len = 12
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = child
# dividend = 2, remainder = 2
# About to add faces
# Finished adding faces: 3.2901763916015625e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06636834144592285
# returned from stitch mesh: 2.3192598819732666
# Finished stitching child 27 : 2.6633377075195312
# ***************Finished big stitching iteration: 9.484017848968506***************
# Starting Child 22
# 10 48857
# Done distance matrix: 0.01630091667175293
# Done Generating final pairs: 0.033066749572753906
# best_stitch_pair = [    1 48839]
# best_stitch_pair_size = 794583.4485948808
# best_stitch_pair_distance = 376.92756330258436
# best_stitch_pair_size_ratio = 0.9847830028953799
# Starting Child 32
# 1 48857
# Done distance matrix: 0.001749277114868164
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48857
# Done distance matrix: 0.0017631053924560547
# Child 40 There were no points close enough
# Starting Child 42
# 2 48857
# Done distance matrix: 0.004775285720825195
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# repeat_main_facets = []
# child_meshes_stitch_facets = {22: [1, 48839]}
# ---Stitching child 22 with pair: [1, 48839]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 2104813, starting edge 2nd facet= 2104968,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 18
# Starting Organizing vertices for side 1
# edge_1_order done, len = 16
# Main originally was counter-clockwise --> keeping
# Child originally was clockwise --> keeping
# smaller_face = child
# dividend = 1, remainder = 2
# About to add faces
# Finished adding faces: 3.790855407714844e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06299519538879395
# returned from stitch mesh: 2.5262930393218994
# Finished stitching child 22 : 3.142453670501709
# ***************Finished big stitching iteration: 6.257384300231934***************
# Starting Child 32
# 1 48865
# Done distance matrix: 0.0021784305572509766
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.0021414756774902344
# Child 40 There were no points close enough
# Starting Child 42
# 2 48865
# Done distance matrix: 0.004428386688232422
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 32
# 1 48865
# Done distance matrix: 0.002143383026123047
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.0023407936096191406
# Child 40 There were no points close enough
# Starting Child 42
# 2 48865
# Done distance matrix: 0.00501704216003418
# Child 42 There was no possible stitch found after stitch distance and face normal filters
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 32
# 1 48865
# Done distance matrix: 0.0017278194427490234
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.0019953250885009766
# Child 40 There were no points close enough
# Starting Child 42
# 2 48865
# Done distance matrix: 0.004253387451171875
# Done Generating final pairs: 0.008901596069335938
# best_stitch_pair = [    0 30677]
# best_stitch_pair_size = 48404.37923973544
# best_stitch_pair_distance = 3246.665725176064
# best_stitch_pair_size_ratio = 0.8778154999702337
# repeat_main_facets = []
# child_meshes_stitch_facets = {42: [0, 30677]}
# ---Stitching child 42 with pair: [0, 30677]---
# opposite direction normals
# Found boundary edges
# starting edge 1st facet = 1740223, starting edge 2nd facet= 2105017,
# Starting Organizing vertices for side 0
# edge_0_order done, len = 9
# Starting Organizing vertices for side 1
# edge_1_order done, len = 32
# Main originally was clockwise --> flipping
# Child originally was counter-clockwise --> flipping
# smaller_face = main
# dividend = 3, remainder = 5
# About to add faces
# Finished adding faces: 5.650520324707031e-05
# Starting creating stitch mesh
# Finished creating stitch mesh: 0.06766843795776367
# returned from stitch mesh: 2.464717149734497
# Finished stitching child 42 : 2.9406259059906006
# ***************Finished big stitching iteration: 3.385408878326416***************
# Starting Child 32
# 1 48865
# Done distance matrix: 0.0019261837005615234
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.002000570297241211
# Child 40 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 1
# Starting Child 32
# 1 48865
# Done distance matrix: 0.0018053054809570312
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.0017974376678466797
# Child 40 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 2
# Starting Child 32
# 1 48865
# Done distance matrix: 0.001990079879760742
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.001936197280883789
# Child 40 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 3
# Starting Child 32
# 1 48865
# Done distance matrix: 0.0018589496612548828
# Child 32 There were no points close enough
# Starting Child 33
# child_facets_centers for child {i} was 0, so skipping
# Starting Child 40
# 1 48865
# Done distance matrix: 0.002824068069458008
# Child 40 There were no points close enough
# no stitch points found IN ALL CHILDREN --> relaxing the parameters time 4
# The number of times expanding the thresholds has exceed the limit /n Just returning main mesh
# total_stitch_processing_time = 180.4665801525116
# Total time for restitching = 180.4787118434906
# missed_children = [32.0, 33.0, 40.0]
# Whole stitching function complete: 367.78286814689636
#
#
#
# *****Running Neuron Stitcher for 648518346349506596**********
# NOT Using a load file for meshes
# generating child and main meshes
# ------Starting the stitcher vp2-------
# There were 27572 pieces after mesh split
# There were 6626 pieces found after size threshold
# max_index = 0
# max_face_len = 24286914

# %%
#(schema.jobs & "table_name='__excitatory_stitched_mesh_vp2'").delete()
#schema.jobs

# %%
"""
Things didn't think about: 
1) if there are no child meshes to be stitched 
2) If there is only one mesh


"""

# %%
# import os
# files_to_list = os.listdir("./stitch_mesh_saved/")

# str(segment_id) + "_30_main_and_child_meshes_array.npz"
# "648518346349470171_30_main_and_child_meshes_array.npz" in files_to_list
