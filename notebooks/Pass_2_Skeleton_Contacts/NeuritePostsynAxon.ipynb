# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv

from meshparty import trimesh_io

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_pinky')
pinky = dj.create_virtual_module('pinky', 'microns_pinky')

# %%
pinky.SynapseSpineLabelFinalThresholdRevised
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid       connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-------+ +------------+ +------------+
# __excitatory_s 60ab82cf1f443b reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   45018     422637         2019-06-28 00:
# __filtered_ske 0f47beab46be0f reserved     =BLOB=                    =BLOB=     cpapadop@10.21 starfox        420       434486         2019-06-28 15:
# __filtered_ske 466b09deb744c4 reserved     =BLOB=                    =BLOB=     cpapadop@10.21 starfox        441       434489         2019-06-28 15:
# __filtered_ske e07f43882db2cb reserved     =BLOB=                    =BLOB=     cpapadop@10.21 starfox        394       434485         2019-06-28 15:
# __neurite_skel 12931c78cc2376 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   44071     422184         2019-06-28 00:
# __neurite_skel 133fe6b939891b reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   43979     422170         2019-06-28 00:
# __neurite_skel e87606d15ef3e1 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   44225     422264         2019-06-28 00:
# __neuron_skele 19347c4bfa2bd8 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   18821     437313         2019-06-28 19:
# __orphan_stitc 64b0ee0b4efb32 reserved     =BLOB=                    =BLOB=     celiib@10.28.0 20812b49dcd8   44632     422460         2019-06-28 00:
#  (9 tuples)

# %%
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#will take in and populate the soma table based on the key it gets
def axon_verts_faces(query_key):
    
    table=""
    vertices_soma,triangles_soma = (pinky.CompartmentFinal.ComponentFinal() & query_key
                                   & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).fetch("vertex_indices","triangle_indices")

    if len(vertices_soma) > 0:
        print("Soma found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (pinky.PymeshfixDecimatedExcitatoryStitchedMesh & query_key).fetch("vertices","triangles")
    else:
        vertices_soma,triangles_soma = (pinky.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]
                                       ).fetch("vertex_indices","triangle_indices")
        if len(vertices_soma) > 0:
            print("Soma found in Orphans")
            vertices_mesh,triangles_mesh = (pinky.Decimation35OrphanStitched & query_key).fetch("vertices","triangles")
        else:
            print("No Soma exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
            
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def read_skeleton_revised(file_path):
    with open(file_path) as f:
        bones = np.array([])
        for line in f.readlines():
            #print(line)
            line = (np.array(line.split()[1:], float).reshape(-1, 3))
            #print(line[:-1])
            #print(line[1:])

            #print(bones.size)
            if bones.size <= 0:
                bones = np.stack((line[:-1],line[1:]),axis=1)
            else:
                bones = np.vstack((bones,(np.stack((line[:-1],line[1:]),axis=1))))
            #print(bones)


    return np.array(bones).astype(float)

# %%
#make sure there is a temp file in the directory, if not then make one
#if temp folder doesn't exist then create it
if (os.path.isdir(os.getcwd() + "/pymesh_NEURITES")) == False:
    os.mkdir("pymesh_NEURITES")

# %%
#create the output file
##write the OFF file for the neuron
import pathlib
def write_Whole_Neuron_Off_file(neuron_ID,
                                vertices=[], 
                                triangles=[],
                                folder="pymesh_NEURITES"):
    #primary_key = dict(segmentation=1, segment_id=segment_id, decimation_ratio=0.35)
    #vertices, triangles = (mesh_Table_35 & primary_key).fetch1('vertices', 'triangles')
    
    num_vertices = (len(vertices))
    num_faces = len(triangles)
    
    #get the current file location
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(neuron_ID)
    path_and_filename = file_loc / filename
    
    #print(file_loc)
    #print(path_and_filename)
    
    #open the file and start writing to it    
    f = open(str(path_and_filename) + ".off", "w")
    f.write("OFF\n")
    f.write(str(num_vertices) + " " + str(num_faces) + " 0\n" )
    
    
    #iterate through and write all of the vertices in the file
    for verts in vertices:
        f.write(str(verts[0]) + " " + str(verts[1]) + " " + str(verts[2])+"\n")
    
    #print("Done writing verts")
        
    for faces in triangles:
        f.write("3 " + str(faces[0]) + " " + str(faces[1]) + " " + str(faces[2])+"\n")
    
    print("Done writing OFF file")
    #f.write("end")
    
    return str(path_and_filename),str(filename),str(file_loc)

# %%
def meshlab_fix_manifold(key,folder="pymesh_NEURITES"):
    
    file_loc = pathlib.Path.cwd() / folder
    filename = "neuron_" + str(key["segment_id"])
    path_and_filename = str(file_loc / filename)
    
    
    input_mesh = path_and_filename + ".off"
    output_mesh = path_and_filename+"_mls.off"
    
    
    meshlab_script = str(pathlib.Path.cwd()) + "/" + "remeshing_remove_non_man_edges.mls"
    
    print("starting meshlabserver fixing non-manifolds")
    subprocess_result_1 = run_meshlab_script(meshlab_script,
                      input_mesh,
                      output_mesh)
    #print("Poisson subprocess_result= "+ str(subprocess_result_1))
    
    if str(subprocess_result_1)[-13:] != "returncode=0)":
        raise Exception('neuron' + str(key["segment_id"]) + 
                         ' did not fix the manifold edges')
    
    return output_mesh

# %%
def run_meshlab_script(mlx_script,input_mesh_file,output_mesh_file):
    script_command = (" -i " + str(input_mesh_file) + " -o " + 
                                    str(output_mesh_file) + " -s " + str(mlx_script))
    #return script_command
    subprocess_result = subprocess.run('xvfb-run -a -s "-screen 0 800x600x24" meshlabserver $@ ' + 
                   script_command,shell=True)
    
    return subprocess_result

# %%
pinky.Mesh.proj()
# Out:
# *segmentation  *segment_id
# +------------+ +------------+
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
# 3              64851834634135
#    ...
#  (217567 tuples)

# %%
# key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
#                                  & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj() )

# %%
#shows that there are no orphans with axons
orphan_key_source = (dj.U("segment_id","segmentation") & (pinky.CompartmentOrphan.ComponentOrphan() 
                                 & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]).proj())

# %%
pinky.CompartmentOrphan.ComponentOrphan() & "compartment_type='Axon-Soma'"
# Out:
# *segmentation  *segment_id    *decimation_ra *compartment_t *component_ind n_vertex_indic n_triangle_ind vertex_ind triangle_i
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +--------+
# 3              64851834634135 0.35           Axon-Soma      0              17821          35437          =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      0              30             33             =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      1              1557           3081           =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      2              32006          63769          =BLOB=     =BLOB=
# 3              64851834634949 0.35           Axon-Soma      3              2334           4655           =BLOB=     =BLOB=
#  (5 tuples)

# %%
@schema
class NeuritePostsynAxon(dj.Computed):
    definition="""
    -> pinky.Mesh
    ---
    vertices  :longblob #vertices for extracted axon
    triangles :longblob #faces for extracted axon
    n_edges   :int unsigned #number of edges stored
    edges     :longblob #array storing edges on each row
    n_bodies    :tinyint unsigned #the amount of segments the neurite was originally split into
    largest_mesh_perc : float #the percentage of the entire mesh that the largest submesh makes up
     
    """
    
    
    key_source = dj.U("segment_id","segmentation") & (pinky.CompartmentFinal.ComponentFinal() 
                                     & [dict(compartment_type=x) for x in ["Axon-Dendr","Axon-Soma"]]) 

    
    def make(self, key):
        global_time = time.time()
        
        
        print(str(key["segment_id"])+ ":")
        
        #create return key
        return_key = key.copy()


        #get the vertices and triangles for the Soma
        start_time = time.time()
        vertices_whole, triangles_whole = axon_verts_faces(key)
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")


        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():
            print("Error no axon")


        new_key = dict(segmentation=key["segmentation"],
                           segment_id=key["segment_id"])



        #find the bounding box
        # start_time = time.time()
        # mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        # mesh.export(str(key["segment_id"]) + "_axon.off","off")

        #now skeletonize the mesh

        #gets all of the different parts
        mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
        count, labels = trimesh_io.trimesh.graph.csgraph.connected_components(
                                                            mesh.edges_sparse,
                                                            directed=False,
                                                            return_labels=True)

        new_key["n_bodies"] = count
        values = np.array(labels)
        searchval = 0
        ii = np.where(values == searchval)[0]
        new_key["largest_mesh_perc"] = len(ii)/len(labels)

        print(f"Step 2a: Getting the number of splits: {time.time() - start_time}")



        start_time = time.time()
        #pass the vertices and faces to pymeshfix to become watertight
        meshfix = pymeshfix.MeshFix(vertices_whole,triangles_whole)
        meshfix.repair(verbose=False,joincomp=True,remove_smallest_components=False)
        print(f"Step 2b: Pymesh shrinkwrapping: {time.time() - start_time}")

        #print("Step 2: Writing Off File")
        start_time = time.time()
        #write the new mesh to off file
        path_and_filename,filename,file_loc = write_Whole_Neuron_Off_file(str(new_key["segment_id"]),meshfix.v,meshfix.f)
        print(f"Step 3: Writing shrinkwrap off file: {time.time() - start_time}")

        #Run the meshlabserver scripts
        start_time = time.time()
        output_mesh = meshlab_fix_manifold(key)
        print(f"Step 4: Meshlab fixing non-manifolds: {time.time() - start_time}")

        print(output_mesh[:-4])

        #send to be skeletonized
        start_time = time.time()
        return_value = cm.calcification(output_mesh[:-4])
        if return_value > 0:
            raise Exception('skeletonization for neuron ' + str(new_key["segment_id"]) + 
                            ' did not finish... exited with error code: ' + str(return_value))
        #print(f"Step 5: Generating Skeleton: {time.time() - start_time}")



        #read in the skeleton files into an array
        bone_array = read_skeleton_revised(output_mesh[:-4]+"_skeleton.cgal")

        #print(bone_array)
        if len(bone_array) <= 0:
            raise Exception('No skeleton generated for ' + str(new_key["segment_id"]))
        print(f"Step 5: Generating and reading Skeleton: {time.time() - start_time}")


        start_time = time.time()
        new_key["n_edges"] = len(bone_array)
        new_key["edges"] = bone_array
        
        new_key["vertices"] = vertices_whole
        new_key["triangles"] = triangles_whole
        
        self.insert1(new_key,skip_duplicates=True)
        os.system("rm "+str(path_and_filename)+"*")
        print(f"Step 6: Inserting dictionary: {time.time() - start_time}")
        print(f"Total time: {time.time() - global_time}")
        print("\n\n")

# %%
#(schema.jobs & "table_name='__neurite_postsyn_axon'").delete()

# %%
start_time = time.time()
NeuritePostsynAxon.populate(reserve_jobs = True)
print(f"Total time = {time.time() - start_time}")
# Out:
# 648518346341371119:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11496829986572266
# Step 2a: Getting the number of splits: 0.11838269233703613
# Step 2b: Pymesh shrinkwrapping: 0.03390336036682129
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.015444517135620117
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5828568935394287
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346341371119_mls
# Step 5: Generating and reading Skeleton: 0.16818594932556152
# Step 6: Inserting dictionary: 0.028867244720458984
# Total time: 0.9487423896789551
#
#
#
# 648518346349386137:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.029316425323486328
# Step 2a: Getting the number of splits: 0.03270530700683594
# Step 2b: Pymesh shrinkwrapping: 0.051798343658447266
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.01035165786743164
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5580141544342041
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349386137_mls
# Step 5: Generating and reading Skeleton: 0.12688446044921875
# Step 6: Inserting dictionary: 0.02406907081604004
# Total time: 0.8051838874816895
#
#
#
# 648518346349470171:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4679737091064453
# Step 2a: Getting the number of splits: 0.5314717292785645
# Step 2b: Pymesh shrinkwrapping: 5.02658486366272
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6036632061004639
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.6067006587982178
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349470171_mls
# Step 5: Generating and reading Skeleton: 3.7252557277679443
# Step 6: Inserting dictionary: 0.566176176071167
# Total time: 12.06374216079712
#
#
#
# 648518346349471156:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4961836338043213
# Step 2a: Getting the number of splits: 0.5956459045410156
# Step 2b: Pymesh shrinkwrapping: 2.7974815368652344
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6243896484375
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.806182622909546
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349471156_mls
# Step 5: Generating and reading Skeleton: 3.7509493827819824
# Step 6: Inserting dictionary: 0.4024229049682617
# Total time: 9.978743076324463
#
#
#
# 648518346349471500:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.14848947525024414
# Step 2a: Getting the number of splits: 0.15909695625305176
# Step 2b: Pymesh shrinkwrapping: 0.14159035682678223
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04772782325744629
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6677806377410889
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349471500_mls
# Step 5: Generating and reading Skeleton: 0.2608175277709961
# Step 6: Inserting dictionary: 0.05861186981201172
# Total time: 1.3368239402770996
#
#
#
# 648518346349471562:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3885636329650879
# Step 2a: Getting the number of splits: 0.4434378147125244
# Step 2b: Pymesh shrinkwrapping: 4.458916902542114
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.43559980392456055
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3720226287841797
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349471562_mls
# Step 5: Generating and reading Skeleton: 2.6739296913146973
# Step 6: Inserting dictionary: 0.3464314937591553
# Total time: 9.732213973999023
#
#
#
# 648518346349471565:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6064655780792236
# Step 2a: Getting the number of splits: 0.6838858127593994
# Step 2b: Pymesh shrinkwrapping: 3.942453145980835
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5913925170898438
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.684129238128662
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349471565_mls
# Step 5: Generating and reading Skeleton: 3.5178639888763428
# Step 6: Inserting dictionary: 0.37700557708740234
# Total time: 10.797632217407227
#
#
#
# 648518346349471910:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.33058881759643555
# Step 2a: Getting the number of splits: 0.3527364730834961
# Step 2b: Pymesh shrinkwrapping: 0.5993924140930176
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.1642012596130371
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8692634105682373
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349471910_mls
# Step 5: Generating and reading Skeleton: 0.9256110191345215
# Step 6: Inserting dictionary: 0.13752961158752441
# Total time: 3.0499801635742188
#
#
#
# 648518346349473044:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4530339241027832
# Step 2a: Getting the number of splits: 0.5214405059814453
# Step 2b: Pymesh shrinkwrapping: 5.011364459991455
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5582599639892578
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.5890860557556152
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473044_mls
# Step 5: Generating and reading Skeleton: 3.5613908767700195
# Step 6: Inserting dictionary: 0.37113308906555176
# Total time: 11.614084720611572
#
#
#
# 648518346349473583:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11858177185058594
# Step 2a: Getting the number of splits: 0.12996435165405273
# Step 2b: Pymesh shrinkwrapping: 0.4206581115722656
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06647038459777832
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7494275569915771
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473583_mls
# Step 5: Generating and reading Skeleton: 0.38407373428344727
# Step 6: Inserting dictionary: 0.07032918930053711
# Total time: 1.8221356868743896
#
#
#
# 648518346349473597:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4007604122161865
# Step 2a: Getting the number of splits: 0.45243120193481445
# Step 2b: Pymesh shrinkwrapping: 1.4387123584747314
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.35550570487976074
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.280278205871582
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473597_mls
# Step 5: Generating and reading Skeleton: 2.271960735321045
# Step 6: Inserting dictionary: 0.26214146614074707
# Total time: 6.063049554824829
#
#
#
# 648518346349473838:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.21717429161071777
# Step 2a: Getting the number of splits: 0.22242379188537598
# Step 2b: Pymesh shrinkwrapping: 0.04675579071044922
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.019677400588989258
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5800473690032959
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349473838_mls
# Step 5: Generating and reading Skeleton: 0.16637301445007324
# Step 6: Inserting dictionary: 0.03948712348937988
# Total time: 1.0760269165039062
#
#
#
# 648518346349475035:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.42679357528686523
# Step 2a: Getting the number of splits: 0.48142004013061523
# Step 2b: Pymesh shrinkwrapping: 1.7241387367248535
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4280726909637451
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.440676212310791
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475035_mls
# Step 5: Generating and reading Skeleton: 2.4612643718719482
# Step 6: Inserting dictionary: 0.3008382320404053
# Total time: 6.838860511779785
#
#
#
# 648518346349475101:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11575484275817871
# Step 2a: Getting the number of splits: 0.12043237686157227
# Step 2b: Pymesh shrinkwrapping: 0.04690957069396973
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.018815994262695312
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5656692981719971
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475101_mls
# Step 5: Generating and reading Skeleton: 0.1906890869140625
# Step 6: Inserting dictionary: 0.0482025146484375
# Total time: 0.9923152923583984
#
#
#
# 648518346349475132:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15237808227539062
# Step 2a: Getting the number of splits: 0.15854859352111816
# Step 2b: Pymesh shrinkwrapping: 0.0689706802368164
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.022957801818847656
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5849285125732422
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475132_mls
# Step 5: Generating and reading Skeleton: 0.2450699806213379
# Step 6: Inserting dictionary: 0.04715323448181152
# Total time: 1.129328727722168
#
#
#
# 648518346349475425:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.0714414119720459
# Step 2a: Getting the number of splits: 0.0733957290649414
# Step 2b: Pymesh shrinkwrapping: 0.0012505054473876953
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0014164447784423828
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5500664710998535
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475425_mls
# Step 5: Generating and reading Skeleton: 0.004972934722900391
# Step 6: Inserting dictionary: 0.03529977798461914
# Total time: 0.6676788330078125
#
#
#
# 648518346349475518:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26291799545288086
# Step 2a: Getting the number of splits: 0.27091217041015625
# Step 2b: Pymesh shrinkwrapping: 0.11084222793579102
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.043337106704711914
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6295475959777832
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475518_mls
# Step 5: Generating and reading Skeleton: 0.3283870220184326
# Step 6: Inserting dictionary: 0.05653882026672363
# Total time: 1.440833330154419
#
#
#
# 648518346349475523:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.0937201976776123
# Step 2a: Getting the number of splits: 0.09895634651184082
# Step 2b: Pymesh shrinkwrapping: 0.0666801929473877
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.027826786041259766
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6721105575561523
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475523_mls
# Step 5: Generating and reading Skeleton: 0.2807576656341553
# Step 6: Inserting dictionary: 0.05337834358215332
# Total time: 1.2008893489837646
#
#
#
# 648518346349475525:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2045581340789795
# Step 2a: Getting the number of splits: 0.20865297317504883
# Step 2b: Pymesh shrinkwrapping: 0.040311336517333984
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.017838001251220703
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5760774612426758
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475525_mls
# Step 5: Generating and reading Skeleton: 0.1804494857788086
# Step 6: Inserting dictionary: 0.048021554946899414
# Total time: 1.0725061893463135
#
#
#
# 648518346349475573:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.051163673400878906
# Step 2a: Getting the number of splits: 0.05657243728637695
# Step 2b: Pymesh shrinkwrapping: 0.05751824378967285
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.026347637176513672
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5880916118621826
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349475573_mls
# Step 5: Generating and reading Skeleton: 0.2575230598449707
# Step 6: Inserting dictionary: 0.05755615234375
# Total time: 1.0446178913116455
#
#
#
# 648518346349476159:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12825298309326172
# Step 2a: Getting the number of splits: 0.14171242713928223
# Step 2b: Pymesh shrinkwrapping: 0.5177326202392578
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06788945198059082
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7278740406036377
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349476159_mls
# Step 5: Generating and reading Skeleton: 0.3716318607330322
# Step 6: Inserting dictionary: 0.07221388816833496
# Total time: 1.9004004001617432
#
#
#
# 648518346349476961:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.48809027671813965
# Step 2a: Getting the number of splits: 0.5683643817901611
# Step 2b: Pymesh shrinkwrapping: 4.571982145309448
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5934216976165771
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.7746455669403076
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349476961_mls
# Step 5: Generating and reading Skeleton: 3.3279175758361816
# Step 6: Inserting dictionary: 0.3940744400024414
# Total time: 11.231723308563232
#
#
#
# 648518346349478054:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.48941683769226074
# Step 2a: Getting the number of splits: 0.5595149993896484
# Step 2b: Pymesh shrinkwrapping: 2.3160998821258545
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5563457012176514
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.7042882442474365
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478054_mls
# Step 5: Generating and reading Skeleton: 3.6499223709106445
# Step 6: Inserting dictionary: 0.3840446472167969
# Total time: 9.17141056060791
#
#
#
# 648518346349478118:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17824959754943848
# Step 2a: Getting the number of splits: 0.19970440864562988
# Step 2b: Pymesh shrinkwrapping: 0.47516894340515137
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15448212623596191
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.921234130859375
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478118_mls
# Step 5: Generating and reading Skeleton: 0.8914656639099121
# Step 6: Inserting dictionary: 0.13562798500061035
# Total time: 2.779005289077759
#
#
#
# 648518346349478248:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6573038101196289
# Step 2a: Getting the number of splits: 0.753154993057251
# Step 2b: Pymesh shrinkwrapping: 6.911099672317505
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7347948551177979
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.1073825359344482
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478248_mls
# Step 5: Generating and reading Skeleton: 4.392460346221924
# Step 6: Inserting dictionary: 0.484250545501709
# Total time: 15.384666204452515
#
#
#
# 648518346349478399:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4633667469024658
# Step 2a: Getting the number of splits: 0.5295631885528564
# Step 2b: Pymesh shrinkwrapping: 2.100080966949463
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5081758499145508
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4862875938415527
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478399_mls
# Step 5: Generating and reading Skeleton: 2.936016082763672
# Step 6: Inserting dictionary: 0.3778376579284668
# Total time: 7.939081430435181
#
#
#
# 648518346349478431:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6516623497009277
# Step 2a: Getting the number of splits: 0.753993034362793
# Step 2b: Pymesh shrinkwrapping: 3.4603474140167236
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.8301122188568115
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.1907312870025635
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478431_mls
# Step 5: Generating and reading Skeleton: 4.929384708404541
# Step 6: Inserting dictionary: 0.5241658687591553
# Total time: 12.690070867538452
#
#
#
# 648518346349478860:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.354123592376709
# Step 2a: Getting the number of splits: 0.40703892707824707
# Step 2b: Pymesh shrinkwrapping: 4.258369445800781
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.42646074295043945
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3606407642364502
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349478860_mls
# Step 5: Generating and reading Skeleton: 2.6778833866119385
# Step 6: Inserting dictionary: 0.3028857707977295
# Total time: 9.43488883972168
#
#
#
# 648518346349479478:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.23543977737426758
# Step 2a: Getting the number of splits: 0.2441871166229248
# Step 2b: Pymesh shrinkwrapping: 0.27539730072021484
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.047733306884765625
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.624706506729126
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349479478_mls
# Step 5: Generating and reading Skeleton: 0.315809965133667
# Step 6: Inserting dictionary: 0.07677102088928223
# Total time: 1.5856258869171143
#
#
#
# 648518346349479706:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2114696502685547
# Step 2a: Getting the number of splits: 0.24917984008789062
# Step 2b: Pymesh shrinkwrapping: 0.9515604972839355
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.26482367515563965
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.185831069946289
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349479706_mls
# Step 5: Generating and reading Skeleton: 1.772346019744873
# Step 6: Inserting dictionary: 0.20238828659057617
# Total time: 4.628544569015503
#
#
#
# 648518346349479837:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2720305919647217
# Step 2a: Getting the number of splits: 0.28220415115356445
# Step 2b: Pymesh shrinkwrapping: 0.565847635269165
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07230782508850098
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7137935161590576
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349479837_mls
# Step 5: Generating and reading Skeleton: 0.4037322998046875
# Step 6: Inserting dictionary: 0.07634115219116211
# Total time: 2.115363597869873
#
#
#
# 648518346349479981:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5455586910247803
# Step 2a: Getting the number of splits: 0.635420560836792
# Step 2b: Pymesh shrinkwrapping: 3.164799213409424
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7472162246704102
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.206667423248291
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349479981_mls
# Step 5: Generating and reading Skeleton: 4.468503713607788
# Step 6: Inserting dictionary: 0.4858717918395996
# Total time: 11.709482192993164
#
#
#
# 648518346349481574:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2532370090484619
# Step 2a: Getting the number of splits: 0.27460718154907227
# Step 2b: Pymesh shrinkwrapping: 0.7859106063842773
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.15611672401428223
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8709378242492676
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349481574_mls
# Step 5: Generating and reading Skeleton: 0.9015157222747803
# Step 6: Inserting dictionary: 0.13513994216918945
# Total time: 3.1253662109375
#
#
#
# 648518346349482196:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19519972801208496
# Step 2a: Getting the number of splits: 0.20592617988586426
# Step 2b: Pymesh shrinkwrapping: 0.1680431365966797
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06465268135070801
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6761929988861084
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349482196_mls
# Step 5: Generating and reading Skeleton: 0.37890172004699707
# Step 6: Inserting dictionary: 0.07599472999572754
# Total time: 1.57120680809021
#
#
#
# 648518346349482312:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4655749797821045
# Step 2a: Getting the number of splits: 0.5321507453918457
# Step 2b: Pymesh shrinkwrapping: 4.710907697677612
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4983103275299072
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.6035220623016357
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349482312_mls
# Step 5: Generating and reading Skeleton: 2.931069850921631
# Step 6: Inserting dictionary: 0.3323969841003418
# Total time: 10.611310482025146
#
#
#
# 648518346349483124:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3508625030517578
# Step 2a: Getting the number of splits: 0.3773961067199707
# Step 2b: Pymesh shrinkwrapping: 1.1569101810455322
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.20128965377807617
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.9280679225921631
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349483124_mls
# Step 5: Generating and reading Skeleton: 1.1604983806610107
# Step 6: Inserting dictionary: 0.1554861068725586
# Total time: 3.980802536010742
#
#
#
# 648518346349483228:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1468520164489746
# Step 2a: Getting the number of splits: 0.15346407890319824
# Step 2b: Pymesh shrinkwrapping: 0.20210838317871094
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03536200523376465
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6136434078216553
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349483228_mls
# Step 5: Generating and reading Skeleton: 0.2732834815979004
# Step 6: Inserting dictionary: 0.0639193058013916
# Total time: 1.3429079055786133
#
#
#
# 648518346349483956:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.4673593044281006
# Step 2a: Getting the number of splits: 0.5086383819580078
# Step 2b: Pymesh shrinkwrapping: 1.2498114109039307
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3228778839111328
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.2432940006256104
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349483956_mls
# Step 5: Generating and reading Skeleton: 1.9290924072265625
# Step 6: Inserting dictionary: 0.22845840454101562
# Total time: 5.48364520072937
#
#
#
# 648518346349485701:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.196213960647583
# Step 2a: Getting the number of splits: 0.2008519172668457
# Step 2b: Pymesh shrinkwrapping: 0.05382847785949707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.023344993591308594
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6273722648620605
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349485701_mls
# Step 5: Generating and reading Skeleton: 0.24314188957214355
# Step 6: Inserting dictionary: 0.04384422302246094
# Total time: 1.19344162940979
#
#
#
# 648518346349485870:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.410003662109375
# Step 2a: Getting the number of splits: 0.46276211738586426
# Step 2b: Pymesh shrinkwrapping: 1.574655294418335
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3974344730377197
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.401064395904541
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349485870_mls
# Step 5: Generating and reading Skeleton: 2.2777225971221924
# Step 6: Inserting dictionary: 0.2700538635253906
# Total time: 6.387307405471802
#
#
#
# 648518346349487499:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.07595992088317871
# Step 2a: Getting the number of splits: 0.08118796348571777
# Step 2b: Pymesh shrinkwrapping: 0.05359983444213867
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.023636579513549805
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5881257057189941
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349487499_mls
# Step 5: Generating and reading Skeleton: 0.22837376594543457
# Step 6: Inserting dictionary: 0.043616533279418945
# Total time: 1.0195341110229492
#
#
#
# 648518346349490614:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2017958164215088
# Step 2a: Getting the number of splits: 0.2049252986907959
# Step 2b: Pymesh shrinkwrapping: 0.02206730842590332
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0060465335845947266
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.602614164352417
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349490614_mls
# Step 5: Generating and reading Skeleton: 0.06325387954711914
# Step 6: Inserting dictionary: 0.031018972396850586
# Total time: 0.9310257434844971
#
#
#
# 648518346349490654:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15953373908996582
# Step 2a: Getting the number of splits: 0.16785669326782227
# Step 2b: Pymesh shrinkwrapping: 0.29150962829589844
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0467073917388916
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6577000617980957
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349490654_mls
# Step 5: Generating and reading Skeleton: 0.2598998546600342
# Step 6: Inserting dictionary: 0.05622601509094238
# Total time: 1.4813122749328613
#
#
#
# 648518346349490749:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.45709848403930664
# Step 2a: Getting the number of splits: 0.5275354385375977
# Step 2b: Pymesh shrinkwrapping: 3.919619083404541
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3823411464691162
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.3435401916503906
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349490749_mls
# Step 5: Generating and reading Skeleton: 2.2405002117156982
# Step 6: Inserting dictionary: 0.3504948616027832
# Total time: 8.76534652709961
#
#
#
# 648518346349491953:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2723684310913086
# Step 2a: Getting the number of splits: 0.27693867683410645
# Step 2b: Pymesh shrinkwrapping: 0.050104379653930664
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.021401405334472656
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6073813438415527
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349491953_mls
# Step 5: Generating and reading Skeleton: 0.18793129920959473
# Step 6: Inserting dictionary: 0.04264092445373535
# Total time: 1.1876187324523926
#
#
#
# 648518346349492097:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22466588020324707
# Step 2a: Getting the number of splits: 0.22860503196716309
# Step 2b: Pymesh shrinkwrapping: 0.03751254081726074
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.015902996063232422
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.567615270614624
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349492097_mls
# Step 5: Generating and reading Skeleton: 0.18694114685058594
# Step 6: Inserting dictionary: 0.038776397705078125
# Total time: 1.0763075351715088
#
#
#
# 648518346349493106:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17422056198120117
# Step 2a: Getting the number of splits: 0.18573570251464844
# Step 2b: Pymesh shrinkwrapping: 0.4804999828338623
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08105897903442383
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7505502700805664
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349493106_mls
# Step 5: Generating and reading Skeleton: 0.4388000965118408
# Step 6: Inserting dictionary: 0.08185410499572754
# Total time: 2.0197362899780273
#
#
#
# 648518346349493653:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.24671316146850586
# Step 2a: Getting the number of splits: 0.250713586807251
# Step 2b: Pymesh shrinkwrapping: 0.03782510757446289
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.01712322235107422
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5501368045806885
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349493653_mls
# Step 5: Generating and reading Skeleton: 0.18351483345031738
# Step 6: Inserting dictionary: 0.04158306121826172
# Total time: 1.0818321704864502
#
#
#
# 648518346349493881:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.16931438446044922
# Step 2a: Getting the number of splits: 0.1745924949645996
# Step 2b: Pymesh shrinkwrapping: 0.07213401794433594
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.02989053726196289
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6449248790740967
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349493881_mls
# Step 5: Generating and reading Skeleton: 0.1964857578277588
# Step 6: Inserting dictionary: 0.04627871513366699
# Total time: 1.165452480316162
#
#
#
# 648518346349494194:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.07826805114746094
# Step 2a: Getting the number of splits: 0.08119845390319824
# Step 2b: Pymesh shrinkwrapping: 0.03966832160949707
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.010350227355957031
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5580959320068359
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349494194_mls
# Step 5: Generating and reading Skeleton: 0.10436272621154785
# Step 6: Inserting dictionary: 0.03329586982727051
# Total time: 0.8281476497650146
#
#
#
# 648518346349494515:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.11560392379760742
# Step 2a: Getting the number of splits: 0.12051153182983398
# Step 2b: Pymesh shrinkwrapping: 0.07951879501342773
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.027959585189819336
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5844759941101074
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349494515_mls
# Step 5: Generating and reading Skeleton: 0.24098706245422363
# Step 6: Inserting dictionary: 0.045639991760253906
# Total time: 1.100590467453003
#
#
#
# 648518346349494969:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.18396735191345215
# Step 2a: Getting the number of splits: 0.1891164779663086
# Step 2b: Pymesh shrinkwrapping: 0.11941289901733398
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.028561115264892578
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5918610095977783
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349494969_mls
# Step 5: Generating and reading Skeleton: 0.2103567123413086
# Step 6: Inserting dictionary: 0.04723978042602539
# Total time: 1.187596082687378
#
#
#
# 648518346349495181:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22494935989379883
# Step 2a: Getting the number of splits: 0.23140668869018555
# Step 2b: Pymesh shrinkwrapping: 0.2210986614227295
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04200911521911621
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6473608016967773
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495181_mls
# Step 5: Generating and reading Skeleton: 0.23809814453125
# Step 6: Inserting dictionary: 0.06657576560974121
# Total time: 1.4477407932281494
#
#
#
# 648518346349495481:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34132981300354004
# Step 2a: Getting the number of splits: 0.36420702934265137
# Step 2b: Pymesh shrinkwrapping: 0.5460729598999023
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.17110085487365723
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.8933079242706299
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495481_mls
# Step 5: Generating and reading Skeleton: 1.0094695091247559
# Step 6: Inserting dictionary: 0.1346275806427002
# Total time: 3.119730234146118
#
#
#
# 648518346349495935:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.0921926498413086
# Step 2a: Getting the number of splits: 0.10247015953063965
# Step 2b: Pymesh shrinkwrapping: 0.18604040145874023
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0704813003540039
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6727707386016846
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349495935_mls
# Step 5: Generating and reading Skeleton: 0.38087964057922363
# Step 6: Inserting dictionary: 0.0728144645690918
# Total time: 1.4864072799682617
#
#
#
# 648518346349496058:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10016202926635742
# Step 2a: Getting the number of splits: 0.10957837104797363
# Step 2b: Pymesh shrinkwrapping: 0.33832359313964844
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06647777557373047
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.664078950881958
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349496058_mls
# Step 5: Generating and reading Skeleton: 0.4216189384460449
# Step 6: Inserting dictionary: 0.07661700248718262
# Total time: 1.6778502464294434
#
#
#
# 648518346349496103:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.26365208625793457
# Step 2a: Getting the number of splits: 0.27036070823669434
# Step 2b: Pymesh shrinkwrapping: 0.22960853576660156
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0418088436126709
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6828780174255371
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349496103_mls
# Step 5: Generating and reading Skeleton: 0.2416822910308838
# Step 6: Inserting dictionary: 0.06116366386413574
# Total time: 1.5289998054504395
#
#
#
# 648518346349496245:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.614938497543335
# Step 2a: Getting the number of splits: 0.7088391780853271
# Step 2b: Pymesh shrinkwrapping: 2.991584539413452
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6977155208587646
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.0803048610687256
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349496245_mls
# Step 5: Generating and reading Skeleton: 4.25905442237854
# Step 6: Inserting dictionary: 0.4641134738922119
# Total time: 11.203288555145264
#
#
#
# 648518346349497184:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.34210801124572754
# Step 2a: Getting the number of splits: 0.3873569965362549
# Step 2b: Pymesh shrinkwrapping: 3.1731553077697754
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.3536989688873291
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1564421653747559
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349497184_mls
# Step 5: Generating and reading Skeleton: 2.0245718955993652
# Step 6: Inserting dictionary: 0.2423231601715088
# Total time: 7.3395843505859375
#
#
#
# 648518346349498406:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.1047060489654541
# Step 2a: Getting the number of splits: 0.11302781105041504
# Step 2b: Pymesh shrinkwrapping: 0.29683685302734375
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04958701133728027
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6469404697418213
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349498406_mls
# Step 5: Generating and reading Skeleton: 0.27833008766174316
# Step 6: Inserting dictionary: 0.06740093231201172
# Total time: 1.453221321105957
#
#
#
# 648518346349498632:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.31588125228881836
# Step 2a: Getting the number of splits: 0.32894277572631836
# Step 2b: Pymesh shrinkwrapping: 0.25756239891052246
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09442877769470215
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6942653656005859
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349498632_mls
# Step 5: Generating and reading Skeleton: 0.6503391265869141
# Step 6: Inserting dictionary: 0.0878896713256836
# Total time: 2.1147079467773438
#
#
#
# 648518346349499085:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.284285306930542
# Step 2a: Getting the number of splits: 0.29042935371398926
# Step 2b: Pymesh shrinkwrapping: 0.09045243263244629
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0381925106048584
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6558914184570312
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499085_mls
# Step 5: Generating and reading Skeleton: 0.24122238159179688
# Step 6: Inserting dictionary: 0.05894303321838379
# Total time: 1.3765993118286133
#
#
#
# 648518346349499369:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2676074504852295
# Step 2a: Getting the number of splits: 0.2760453224182129
# Step 2b: Pymesh shrinkwrapping: 0.1449871063232422
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05588507652282715
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6442432403564453
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499369_mls
# Step 5: Generating and reading Skeleton: 0.29928088188171387
# Step 6: Inserting dictionary: 0.0633845329284668
# Total time: 1.4848620891571045
#
#
#
# 648518346349499624:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.39002108573913574
# Step 2a: Getting the number of splits: 0.40192699432373047
# Step 2b: Pymesh shrinkwrapping: 0.22769474983215332
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.09491276741027832
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6709194183349609
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499624_mls
# Step 5: Generating and reading Skeleton: 0.43835020065307617
# Step 6: Inserting dictionary: 0.07872986793518066
# Total time: 1.9136109352111816
#
#
#
# 648518346349499636:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3500378131866455
# Step 2a: Getting the number of splits: 0.39043664932250977
# Step 2b: Pymesh shrinkwrapping: 2.350170373916626
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2754390239715576
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0305578708648682
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499636_mls
# Step 5: Generating and reading Skeleton: 1.62703275680542
# Step 6: Inserting dictionary: 0.21206378936767578
# Total time: 5.887052297592163
#
#
#
# 648518346349499689:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2724120616912842
# Step 2a: Getting the number of splits: 0.28470611572265625
# Step 2b: Pymesh shrinkwrapping: 0.45886826515197754
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06439590454101562
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6885108947753906
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499689_mls
# Step 5: Generating and reading Skeleton: 0.38247084617614746
# Step 6: Inserting dictionary: 0.0871429443359375
# Total time: 1.967226505279541
#
#
#
# 648518346349499759:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.19738030433654785
# Step 2a: Getting the number of splits: 0.20745396614074707
# Step 2b: Pymesh shrinkwrapping: 0.16873407363891602
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06573104858398438
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6352572441101074
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499759_mls
# Step 5: Generating and reading Skeleton: 0.34444451332092285
# Step 6: Inserting dictionary: 0.07535672187805176
# Total time: 1.4984509944915771
#
#
#
# 648518346349499783:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20885920524597168
# Step 2a: Getting the number of splits: 0.21891474723815918
# Step 2b: Pymesh shrinkwrapping: 0.17425203323364258
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06505775451660156
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7017495632171631
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499783_mls
# Step 5: Generating and reading Skeleton: 0.3939347267150879
# Step 6: Inserting dictionary: 0.07370543479919434
# Total time: 1.6287016868591309
#
#
#
# 648518346349499824:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5803086757659912
# Step 2a: Getting the number of splits: 0.6748464107513428
# Step 2b: Pymesh shrinkwrapping: 5.4079976081848145
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.7322070598602295
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.08890700340271
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499824_mls
# Step 5: Generating and reading Skeleton: 4.41605544090271
# Step 6: Inserting dictionary: 0.47054266929626465
# Total time: 13.792120933532715
#
#
#
# 648518346349499851:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6140832901000977
# Step 2a: Getting the number of splits: 0.6996288299560547
# Step 2b: Pymesh shrinkwrapping: 6.341090679168701
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6675398349761963
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.9472124576568604
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499851_mls
# Step 5: Generating and reading Skeleton: 4.202808380126953
# Step 6: Inserting dictionary: 0.4442589282989502
# Total time: 14.304135799407959
#
#
#
# 648518346349499896:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.17709016799926758
# Step 2a: Getting the number of splits: 0.1880941390991211
# Step 2b: Pymesh shrinkwrapping: 0.1678023338317871
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06712007522583008
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6870429515838623
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499896_mls
# Step 5: Generating and reading Skeleton: 0.36336278915405273
# Step 6: Inserting dictionary: 0.0690619945526123
# Total time: 1.5434534549713135
#
#
#
# 648518346349499910:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2646217346191406
# Step 2a: Getting the number of splits: 0.3057830333709717
# Step 2b: Pymesh shrinkwrapping: 1.040867567062378
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.28039097785949707
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0578117370605469
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349499910_mls
# Step 5: Generating and reading Skeleton: 1.5675320625305176
# Step 6: Inserting dictionary: 0.20343828201293945
# Total time: 4.457381725311279
#
#
#
# 648518346349500049:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.647695779800415
# Step 2a: Getting the number of splits: 0.7501552104949951
# Step 2b: Pymesh shrinkwrapping: 3.4311554431915283
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.800419807434082
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 2.319340229034424
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500049_mls
# Step 5: Generating and reading Skeleton: 5.032378196716309
# Step 6: Inserting dictionary: 0.5144202709197998
# Total time: 12.849148273468018
#
#
#
# 648518346349500155:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2596406936645508
# Step 2a: Getting the number of splits: 0.2709691524505615
# Step 2b: Pymesh shrinkwrapping: 0.4703371524810791
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07873845100402832
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6629061698913574
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500155_mls
# Step 5: Generating and reading Skeleton: 0.4346795082092285
# Step 6: Inserting dictionary: 0.09018969535827637
# Total time: 2.0090441703796387
#
#
#
# 648518346349500277:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2555265426635742
# Step 2a: Getting the number of splits: 0.26479387283325195
# Step 2b: Pymesh shrinkwrapping: 0.2921290397644043
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06599068641662598
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6472799777984619
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500277_mls
# Step 5: Generating and reading Skeleton: 0.30720973014831543
# Step 6: Inserting dictionary: 0.07060909271240234
# Total time: 1.6493566036224365
#
#
#
# 648518346349500341:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20403218269348145
# Step 2a: Getting the number of splits: 0.21107864379882812
# Step 2b: Pymesh shrinkwrapping: 0.09683918952941895
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.038867950439453125
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6600620746612549
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500341_mls
# Step 5: Generating and reading Skeleton: 0.24086475372314453
# Step 6: Inserting dictionary: 0.059128761291503906
# Total time: 1.3077750205993652
#
#
#
# 648518346349500431:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3134293556213379
# Step 2a: Getting the number of splits: 0.32148051261901855
# Step 2b: Pymesh shrinkwrapping: 0.1337282657623291
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05357837677001953
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6776418685913086
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500431_mls
# Step 5: Generating and reading Skeleton: 0.3023390769958496
# Step 6: Inserting dictionary: 0.06614542007446289
# Total time: 1.556105613708496
#
#
#
# 648518346349500440:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22278499603271484
# Step 2a: Getting the number of splits: 0.22944879531860352
# Step 2b: Pymesh shrinkwrapping: 0.10323667526245117
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04230523109436035
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6126742362976074
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500440_mls
# Step 5: Generating and reading Skeleton: 0.27684473991394043
# Step 6: Inserting dictionary: 0.05878162384033203
# Total time: 1.3243138790130615
#
#
#
# 648518346349500486:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.28180575370788574
# Step 2a: Getting the number of splits: 0.2885315418243408
# Step 2b: Pymesh shrinkwrapping: 0.10921025276184082
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.04394936561584473
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6430726051330566
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349500486_mls
# ...
# Step 6: Inserting dictionary: 0.049391984939575195
# Total time: 1.3086936473846436
#
#
#
# 648518346349507175:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12810373306274414
# Step 2a: Getting the number of splits: 0.13572192192077637
# Step 2b: Pymesh shrinkwrapping: 0.12378048896789551
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.05010199546813965
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6756353378295898
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507175_mls
# Step 5: Generating and reading Skeleton: 0.291536808013916
# Step 6: Inserting dictionary: 0.06265854835510254
# Total time: 1.3414990901947021
#
#
#
# 648518346349507351:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.16210627555847168
# Step 2a: Getting the number of splits: 0.16562819480895996
# Step 2b: Pymesh shrinkwrapping: 0.025181055068969727
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.01214599609375
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5595884323120117
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507351_mls
# Step 5: Generating and reading Skeleton: 0.12927651405334473
# Step 6: Inserting dictionary: 0.03152298927307129
# Total time: 0.9244053363800049
#
#
#
# 648518346349507355:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.5001437664031982
# Step 2a: Getting the number of splits: 0.5506258010864258
# Step 2b: Pymesh shrinkwrapping: 3.4089691638946533
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.33328747749328613
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.1595816612243652
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349507355_mls
# Step 5: Generating and reading Skeleton: 2.0141403675079346
# Step 6: Inserting dictionary: 0.27018022537231445
# Total time: 7.7379820346832275
#
#
#
# 648518346349508390:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.16599607467651367
# Step 2a: Getting the number of splits: 0.17806506156921387
# Step 2b: Pymesh shrinkwrapping: 0.23042702674865723
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.08216667175292969
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7308673858642578
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508390_mls
# Step 5: Generating and reading Skeleton: 0.4817681312561035
# Step 6: Inserting dictionary: 0.08599734306335449
# Total time: 1.7906920909881592
#
#
#
# 648518346349508447:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.14172649383544922
# Step 2a: Getting the number of splits: 0.1476573944091797
# Step 2b: Pymesh shrinkwrapping: 0.08328437805175781
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03300046920776367
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.590501070022583
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508447_mls
# Step 5: Generating and reading Skeleton: 0.23985886573791504
# Step 6: Inserting dictionary: 0.05655026435852051
# Total time: 1.151780605316162
#
#
#
# 648518346349508765:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12462401390075684
# Step 2a: Getting the number of splits: 0.1301710605621338
# Step 2b: Pymesh shrinkwrapping: 0.17281031608581543
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03175187110900879
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6566934585571289
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508765_mls
# Step 5: Generating and reading Skeleton: 0.21658849716186523
# Step 6: Inserting dictionary: 0.04825234413146973
# Total time: 1.2572376728057861
#
#
#
# 648518346349508960:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12108469009399414
# Step 2a: Getting the number of splits: 0.1266188621520996
# Step 2b: Pymesh shrinkwrapping: 0.07696914672851562
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03145408630371094
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6109726428985596
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508960_mls
# Step 5: Generating and reading Skeleton: 0.2229156494140625
# Step 6: Inserting dictionary: 0.0648036003112793
# Total time: 1.1350784301757812
#
#
#
# 648518346349508969:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.49950504302978516
# Step 2a: Getting the number of splits: 0.5716917514801025
# Step 2b: Pymesh shrinkwrapping: 5.766544580459595
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.5526349544525146
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.6877481937408447
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349508969_mls
# Step 5: Generating and reading Skeleton: 3.179126024246216
# Step 6: Inserting dictionary: 0.35304880142211914
# Total time: 12.11292028427124
#
#
#
# 648518346349509390:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12099575996398926
# Step 2a: Getting the number of splits: 0.13460111618041992
# Step 2b: Pymesh shrinkwrapping: 0.48267269134521484
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.0932931900024414
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.7345812320709229
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509390_mls
# Step 5: Generating and reading Skeleton: 0.5567173957824707
# Step 6: Inserting dictionary: 0.09550333023071289
# Total time: 2.098658800125122
#
#
#
# 648518346349509393:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.561682939529419
# Step 2a: Getting the number of splits: 0.6400675773620605
# Step 2b: Pymesh shrinkwrapping: 2.542787790298462
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.6126983165740967
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.8462677001953125
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509393_mls
# Step 5: Generating and reading Skeleton: 3.8013510704040527
# Step 6: Inserting dictionary: 0.39298462867736816
# Total time: 9.837429761886597
#
#
#
# 648518346349509410:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2672910690307617
# Step 2a: Getting the number of splits: 0.27373766899108887
# Step 2b: Pymesh shrinkwrapping: 0.09544086456298828
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03909635543823242
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6472649574279785
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509410_mls
# Step 5: Generating and reading Skeleton: 0.2471005916595459
# Step 6: Inserting dictionary: 0.06157398223876953
# Total time: 1.3653204441070557
#
#
#
# 648518346349509512:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.12964820861816406
# Step 2a: Getting the number of splits: 0.13348841667175293
# Step 2b: Pymesh shrinkwrapping: 0.0289156436920166
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.013345718383789062
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5266084671020508
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509512_mls
# Step 5: Generating and reading Skeleton: 0.13235235214233398
# Step 6: Inserting dictionary: 0.04359173774719238
# Total time: 0.8794064521789551
#
#
#
# 648518346349509523:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.3868265151977539
# Step 2a: Getting the number of splits: 0.3935215473175049
# Step 2b: Pymesh shrinkwrapping: 0.08584833145141602
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03515005111694336
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5646049976348877
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509523_mls
# Step 5: Generating and reading Skeleton: 0.23165392875671387
# Step 6: Inserting dictionary: 0.05212593078613281
# Total time: 1.3640620708465576
#
#
#
# 648518346349509855:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15153193473815918
# Step 2a: Getting the number of splits: 0.16031980514526367
# Step 2b: Pymesh shrinkwrapping: 0.3061959743499756
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.049558162689208984
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6577863693237305
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349509855_mls
# Step 5: Generating and reading Skeleton: 0.31728553771972656
# Step 6: Inserting dictionary: 0.06533288955688477
# Total time: 1.557485818862915
#
#
#
# 648518346349510323:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.2706620693206787
# Step 2a: Getting the number of splits: 0.2805805206298828
# Step 2b: Pymesh shrinkwrapping: 0.14954233169555664
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.059983253479003906
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6738615036010742
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349510323_mls
# Step 5: Generating and reading Skeleton: 0.34107422828674316
# Step 6: Inserting dictionary: 0.07024955749511719
# Total time: 1.5762755870819092
#
#
#
# 648518346349510800:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10128903388977051
# Step 2a: Getting the number of splits: 0.10770559310913086
# Step 2b: Pymesh shrinkwrapping: 0.21355128288269043
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.033206939697265625
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5934674739837646
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349510800_mls
# Step 5: Generating and reading Skeleton: 0.2174060344696045
# Step 6: Inserting dictionary: 0.049924373626708984
# Total time: 1.2164616584777832
#
#
#
# 648518346349510900:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.10397672653198242
# Step 2a: Getting the number of splits: 0.10957169532775879
# Step 2b: Pymesh shrinkwrapping: 0.07456660270690918
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.03432273864746094
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6392514705657959
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349510900_mls
# Step 5: Generating and reading Skeleton: 0.2451329231262207
# Step 6: Inserting dictionary: 0.05205845832824707
# Total time: 1.1558663845062256
#
#
#
# 648518346349511076:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.08112120628356934
# Step 2a: Getting the number of splits: 0.08484268188476562
# Step 2b: Pymesh shrinkwrapping: 0.03733396530151367
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.017981767654418945
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6023378372192383
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511076_mls
# Step 5: Generating and reading Skeleton: 0.1695411205291748
# Step 6: Inserting dictionary: 0.04439687728881836
# Total time: 0.9576337337493896
#
#
#
# 648518346349511382:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.20122814178466797
# Step 2a: Getting the number of splits: 0.21687030792236328
# Step 2b: Pymesh shrinkwrapping: 0.2563166618347168
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.030992746353149414
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5817959308624268
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511382_mls
# Step 5: Generating and reading Skeleton: 0.2245020866394043
# Step 6: Inserting dictionary: 0.07029199600219727
# Total time: 1.3820765018463135
#
#
#
# 648518346349511866:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.21748089790344238
# Step 2a: Getting the number of splits: 0.22295904159545898
# Step 2b: Pymesh shrinkwrapping: 0.11702704429626465
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.020711183547973633
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5704689025878906
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349511866_mls
# Step 5: Generating and reading Skeleton: 0.18190455436706543
# Step 6: Inserting dictionary: 0.04425501823425293
# Total time: 1.1585540771484375
#
#
#
# 648518346349512186:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.22719383239746094
# Step 2a: Getting the number of splits: 0.23527932167053223
# Step 2b: Pymesh shrinkwrapping: 0.2577688694000244
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.044304847717285156
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6012461185455322
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349512186_mls
# Step 5: Generating and reading Skeleton: 0.2658066749572754
# Step 6: Inserting dictionary: 0.06250286102294922
# Total time: 1.4680581092834473
#
#
#
# 648518346349512869:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.6429123878479004
# Step 2a: Getting the number of splits: 0.7026171684265137
# Step 2b: Pymesh shrinkwrapping: 1.8378455638885498
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.4393904209136963
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.4259588718414307
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349512869_mls
# Step 5: Generating and reading Skeleton: 2.5033698081970215
# Step 6: Inserting dictionary: 0.29607248306274414
# Total time: 7.206578731536865
#
#
#
# 648518346349512870:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.371462345123291
# Step 2a: Getting the number of splits: 0.380861759185791
# Step 2b: Pymesh shrinkwrapping: 0.36273193359375
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.06482911109924316
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6798491477966309
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349512870_mls
# Step 5: Generating and reading Skeleton: 0.422640323638916
# Step 6: Inserting dictionary: 0.07856440544128418
# Total time: 1.9906878471374512
#
#
#
# 648518346349513221:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.39327216148376465
# Step 2a: Getting the number of splits: 0.42739391326904297
# Step 2b: Pymesh shrinkwrapping: 1.000528335571289
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.2608463764190674
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 1.0527503490447998
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513221_mls
# Step 5: Generating and reading Skeleton: 1.4746837615966797
# Step 6: Inserting dictionary: 0.1977214813232422
# Total time: 4.414783954620361
#
#
#
# 648518346349513655:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.28350305557250977
# Step 2a: Getting the number of splits: 0.29441356658935547
# Step 2b: Pymesh shrinkwrapping: 0.1900312900543213
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.07288169860839844
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.6768898963928223
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513655_mls
# Step 5: Generating and reading Skeleton: 0.3863871097564697
# Step 6: Inserting dictionary: 0.06899380683898926
# Total time: 1.690812110900879
#
#
#
# 648518346349513769:
# Soma found in Exhitatory
# Step 1: extracted Soma Mesh = 0.15026378631591797
# Step 2a: Getting the number of splits: 0.15421104431152344
# Step 2b: Pymesh shrinkwrapping: 0.08514833450317383
# Done writing OFF file
# Step 3: Writing shrinkwrap off file: 0.01563882827758789
# starting meshlabserver fixing non-manifolds
# Step 4: Meshlab fixing non-manifolds: 0.5937588214874268
# /notebooks/Pass_2_Skeleton_Contacts/pymesh_NEURITES/neuron_648518346349513769_mls
# Step 5: Generating and reading Skeleton: 0.15273523330688477
# Step 6: Inserting dictionary: 0.04034113883972168
# Total time: 1.042842149734497
#
#
#
# Total time = 495.4525816440582
