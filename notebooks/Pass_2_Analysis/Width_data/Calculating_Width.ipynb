# %%
"""Pseudo Code:
Pt1
1) Create highly discretized skeletons to pull from in main function
Pt2
2) Create a table that pulls from both Orphan and Exhitatory that has any sort of dendrite part
Do get the width of the dendrite:
3) Get neuron
3b) Pull down the highly discretized skeleton 
4) For each significant dendritic compartment piece in the neurons components
    a. Extract the mesh of that piece and the bounding box
    b. Get rid of all skeleton edges whose both vertices are not within bounding box
    c. Make the KDTree from the mesh
    d. Find the nearest distance for each of the points on the skeleton
    e. Find percentiles of these minimum distances
    f. Save the following to the database:
        1. mesh id
        2. Label/Compartment type
        3. Compartment Index
        4. Different percentiles/quartiles of lengths
"""

""" 2 Ways can do this:
1) Use Mesh as source of KDTree and sample each point of the skeleton
-- think i want to do this because this will give you shortest distance for every point on the skeleton

2) Use skeleton as source of KD






"""
# Out:
# ' 2 Ways can do this:\n1) Use Mesh as source of KDTree and sample each point of the skeleton\n-- think i want to do this because this will give you shortest distance for every point on the skeleton\n\n2) Use skeleton as source of KD\n\n\n\n\n\n\n'

# %%
import numpy as np
import datajoint as dj
import time
import pymeshfix
import os
import datetime
import calcification_Module as cm
from meshparty import trimesh_io

#for supressing the output
import os, contextlib
import pathlib
import subprocess

#for error counting
from collections import Counter

#for reading in the new raw_skeleton files
import csv
import pandas as pd
from tqdm import tqdm


from meshparty import trimesh_io

#for filtering
import math
from pykdtree.kdtree import KDTree

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 20

schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
#will create the vertex and face indices given a 3x3xn array
#function that takes in a 3x3 array of coordinates for faces and returns triangles and vertices
def index_unique_rows(full_coordinate_array):
    """
    Separates an array of nested coordinate rows into an array of unique rows and and index array.
    """
    vertices, flat_idx = np.unique(full_coordinate_array.reshape(-1, full_coordinate_array.shape[-1]), axis=0, return_inverse=True)
    return vertices, flat_idx.reshape(-1, full_coordinate_array.shape[-2])

# %%
#function will take in either array of skeletons or single skeleton 
#returns: Either list of the edges or dictionary of list of the edges
def discretize_skeletons(skeletons, maximum_length, skeleton_ids=None):
        def discretize_skeleton(full_edges, maximum_length):
            p0s = full_edges[:, 0]
            p1s = full_edges[:, 1]

            diffs = p1s - p0s
            distances = np.linalg.norm(diffs, axis=1)
            inc_nums = np.ceil(distances / maximum_length).astype(int)
            inc_nums[inc_nums<2] = 2
            diffs_inc = np.repeat(diffs / inc_nums[:, None], inc_nums, axis=0)

            p0s_stack = np.repeat(p0s, inc_nums, axis=0)
            max_arange = np.arange(inc_nums.max())
            multiplicative_incrementer = np.hstack([max_arange[0:i] for i in inc_nums.tolist()])
            evenly_spaced = p0s_stack + (multiplicative_incrementer[:, None] * diffs_inc)

            total = 0
            incremented_edges = list()
            for i, p1 in zip(inc_nums, p1s):
                temp_total = total+i
                inc_edge = evenly_spaced[total:temp_total]
                inc_edge[-1] = p1
                incremented_edges.append(inc_edge)
                total = temp_total
            new_full_edges = np.vstack([np.array((inc_edge[:-1], inc_edge[1:])).transpose(1, 0, 2) for inc_edge in incremented_edges])
            return new_full_edges

        if skeleton_ids is None:
            output = list()
            for full_edges in skeletons:
                output.append(discretize_skeleton(full_edges, maximum_length))
        else:
            output = dict()
            for seg_id, full_edges in zip(skeleton_ids, skeletons):
                output[seg_id] = discretize_skeleton(full_edges, maximum_length)

        return output

# %%
#goes and gets the unique mesh faces and vertices
#will take in and populate the soma table based on the key it gets

#Original Query: 

comp_interest = ["Apical","Basal","Oblique","Dendrite"]
significance_threshold = 10000
    
# key_source = (ta3p100.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
#          & "n_vertex_indices>"+str(significance_threshold)).proj() + (ta3p100.CompartmentFinal.ComponentFinal & [dict(compartment_type=f) for f in comp_interest] 
#          & "n_vertex_indices>"+str(significance_threshold)).proj()


def get_component_mesh(query_key):
    
    #gets the vertices indices and triangle indices of significant, dendritic components
    # of the excitatory neurons
    table=""
    vertices_soma,triangles_soma = (ta3p100.CompartmentFinal.ComponentFinal() & query_key
                                    & [dict(compartment_type=f) for f in comp_interest] 
                                    & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices",
                                                                                             "triangle_indices")
    # check if there were any vertices found in the excitatory table
    # of dendritic compartment, significant size for that segment_id
    if len(vertices_soma) > 0:
        print("Component found in Exhitatory")
        #get the regular mesh from CleansedMesh
        vertices_mesh,triangles_mesh = (ta3p100.CleansedMesh & query_key).fetch("vertices","triangles")
    else:
        #if there weren't any indices found in excitatory table, now check the orphan
        vertices_soma,triangles_soma = (ta3p100.CompartmentOrphan.ComponentOrphan() & query_key 
                                        & [dict(compartment_type=f) for f in comp_interest] 
                                        & "n_vertex_indices>"+str(significance_threshold)).fetch("vertex_indices","triangle_indices")
        # check if there were any vertices found in the orphan table
        # of dendritic compartment, significant size for that segment_id
        if len(vertices_soma) > 0:
            print("Component found in Orphans")
            vertices_mesh,triangles_mesh = (ta3p100.CleansedMeshOrphan & query_key).fetch("vertices","triangles")
        else:
            print("No Component exists for " + str(query_key["segment_id"]))
            return np.array([]),np.array([])
    
    
    #gets the triangles of the submesh for those dendrite compartments
    #and all the compartment triangles on top of each other
    ts_flatten = np.hstack(triangles_soma).astype("int64")

    #the full vertices of the mesh
    vertices_real = vertices_mesh[0]
    triangles_real = triangles_mesh[0]

    ts_stack_whole = vertices_real[triangles_real[ts_flatten]]

    vertices_whole, triangles_whole = index_unique_rows(ts_stack_whole)
    return vertices_whole, triangles_whole

# %%
def filter_edges_by_bounding_box(edges,max_bb_zone,min_bb_zone):
    """
    Filters edges by only those inside the bounding box
    """
    
    #can just use bounding box function to get rid of any inside edges
    filtered_remaining = list()

    for i,e in enumerate(edges):
        #print(e)
        if min(e[0][0],e[1][0])>max_bb_zone[0]:
            #print("minx>maxx")
            #filtered_remaining.append(e)
            
            continue

        if max(e[0][0],e[1][0])<min_bb_zone[0]:
            #print("maxx<minx")
            #filtered_remaining.append(e)
            continue

        if min(e[0][1],e[1][1])>max_bb_zone[1]:
            #print("miny>maxy")
            #filtered_remaining.append(e)
            continue

        if max(e[0][1],e[1][1])<min_bb_zone[1]:
            #print("maxy<miny")
            #filtered_remaining.append(e)
            continue

        if min(e[0][2],e[1][2])>max_bb_zone[2]:
            #print("minz>maxz")
            #filtered_remaining.append(e)
            continue

        if max(e[0][2],e[1][2])<min_bb_zone[2]:
            #print("maxz<minz")
            #filtered_remaining.append(e)
            continue

        filtered_remaining.append(e)

    return np.array(filtered_remaining)

# %% [markdown]
# # Keysource is All Dendritic Sections of Neuron that has Filtered Skeleton that is of significant size

# %%
ta3p100.FilteredSkeletonMinusSoma()

# %%
key_source = (ta3p100.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold)).proj() + (ta3p100.CompartmentFinal.ComponentFinal & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold)).proj()

key_source

# %%
#ta3p100.DendriteWidth.drop()

# %%
    #getting all of the axons and dendrites that have dendrites
    key_source = (ta3p100.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & 
        ta3p100.FilteredSkeleton()).proj() + 
        (ta3p100.CompartmentFinal.ComponentFinal & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & ta3p100.FilteredSkeleton()).proj()

# %%
#ta3p100.Decimation35.describe()

# %%
"""
Keysource = 
a. All orphan dendritic components of significant length that have a filtered skeleton
b. All excitatory dendritic components of significant length that have a filtered skeleton
"""

# %%
#filtered Skeleton stripping out the mesh
@schema
class DendriteWidth(dj.Computed):
    definition="""
    -> ta3p100.Segment
    decimation_ratio     : decimal(3,2) 
    compartment_type     : varchar(16)                  # Basal, Apical, spine head, etc.
    component_index      : smallint unsigned            # Which sub-compartment of a certain label this is.
    discrete_length :int #the maximum size of a discretized segment of postsyn skeleton
    ---
    min_width_perc_50           :float #50th pecentile min width range for all skeleton
    min_width_perc_55           :float #55th pecentile min width range for all skeleton
    min_width_perc_60           :float #60th pecentile min width range for all skeleton
    min_width_perc_65           :float #65th pecentile min width range for all skeleton
    min_width_perc_70           :float #70th pecentile min width range for all skeleton
    min_width_perc_75           :float #75th pecentile min width range for all skeleton
    min_width_perc_80           :float #80th pecentile min width range for all skeleton
    min_width_perc_85           :float #85th pecentile min width range for all skeleton
    min_width_perc_90           :float #90th pecentile min width range for all skeleton
    min_width_perc_95           :float #95th pecentile min width range for all skeleton
    min_width_max               :float #max min width range for all skeleton
    """
    
    comp_interest = ["Apical","Basal","Oblique","Dendrite"]
    significance_threshold = 10000

    #getting all of the axons and dendrites that have dendrites
    key_source = (ta3p100.CompartmentOrphan.ComponentOrphan & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & ta3p100.FilteredSkeleton()).proj() + (ta3p100.CompartmentFinal.ComponentFinal & [dict(compartment_type=f) for f in comp_interest] 
         & "n_vertex_indices>"+str(significance_threshold) & ta3p100.FilteredSkeleton()).proj()
    
    """
    3) Get neuron (Obtained from key source)
    3b) Pull down the highly discretized skeleton 
    4) For each significant dendritic compartment piece in the neurons components
        a. Extract the mesh of that piece and the bounding box
        b. Get rid of all skeleton edges whose both vertices are not within bounding box
        c. Make the KDTree from the mesh
        d. Find the nearest distance for each of the points on the skeleton
        e. Find percentiles of these minimum distances
        f. Save the following to the database:
            1. mesh id
            2. Label/Compartment type
            3. Compartment Index
            4. Different percentiles/quartiles of lengths
    """
    def make(self, key):
        print()
        print()
        
        print(str(key["segment_id"])+ ": " + str(key["compartment_type"])+ "-" + str(key["component_index"] ))
        global_start_time = time.time()
        #create return key
        return_key = key.copy()

        #*****pull down the skeleton for the mesh (should be from highly discretized list****
        skeleton_data = (ta3p100.FilteredSkeleton() & key).fetch(as_dict=True)[0]



        #get the vertices and triangles for the Dendrite
        start_time = time.time()
        vertices_whole, triangles_whole = get_component_mesh(key)
        print("len of vertices = " + str(len(vertices_whole)))
        print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")
        
        discrete_threshold=10

        #if no soma portion was found then just write regular skeleton
        if not vertices_whole.any():

            print("ERROR NO COMPONENT MESH FOUND")
            new_key = dict(key,
                        discrete_length = discrete_threshold,
                        min_width_perc_50 = -2,
                        min_width_perc_55 = -2,
                        min_width_perc_60 = -2,
                        min_width_perc_65 = -2,
                        min_width_perc_70 = -2,
                        min_width_perc_75 = -2,
                        min_width_perc_80 = -2,
                        min_width_perc_85 = -2,
                        min_width_perc_90 = -2,
                        min_width_perc_95 = -2,
                        min_width_max = -2
                      )

        else:
            print("Mesh successfully extracted")
            #get the discretized skeleton
            discrete_threshold = 10
            new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

            #calculate the bounding box by hand
            min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
                 min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                 min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
                max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

            mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
            min_bb = np.array(mesh.bounding_box.vertices).min(0)
            max_bb = np.array(mesh.bounding_box.vertices).max(0)


            #filter all of the skeleton points away that are outside of the bounding box of the compartment
            filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
            
            if (not filtered_edges_postsyn.any()):
                print("FILTERED EDGES EMPTY")
                new_key = dict(key,
                            discrete_length = discrete_threshold,
                            min_width_perc_50 = -1,
                            min_width_perc_55 = -1,
                            min_width_perc_60 = -1,
                            min_width_perc_65 = -1,
                            min_width_perc_70 = -1,
                            min_width_perc_75 = -1,
                            min_width_perc_80 = -1,
                            min_width_perc_85 = -1,
                            min_width_perc_90 = -1,
                            min_width_perc_95 = -1,
                            min_width_max = -1
                          )
                
                

            else:
                # #do KDTree on the midpoints of the new edges to find which ones to keep
                kdtree = KDTree(vertices_whole)

                distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))

                #what is stored in the key






                new_key = dict(key,
                               discrete_length = discrete_threshold,
                                min_width_perc_50 = np.percentile(distances, 50),
                                min_width_perc_55 = np.percentile(distances, 55),
                                min_width_perc_60 = np.percentile(distances, 60),
                                min_width_perc_65 = np.percentile(distances, 65),
                                min_width_perc_70 = np.percentile(distances, 70),
                                min_width_perc_75 = np.percentile(distances, 75),
                                min_width_perc_80 = np.percentile(distances, 80),
                                min_width_perc_85 = np.percentile(distances, 85),
                                min_width_perc_90 = np.percentile(distances, 90),
                                min_width_perc_95 = np.percentile(distances, 95),
                                min_width_max = np.max(distances)
                              )

        self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
        print(f"Total time = {time.time()-global_start_time}")

# %%
#(schema.jobs & "table_name='__dendrite_width'").delete()

# %%
start_time = time.time()
DendriteWidth.populate(reserve_jobs=True)
print(f"Total time = {time.time()-start_time}")
# Out:
# 648518346341355539: Dendrite-0
# Component found in Orphans
# len of vertices = 71989
# Step 1: extracted Soma Mesh = 0.555560827255249
# Mesh successfully extracted
# Total time = 1.3222744464874268
#
#
# 648518346341356260: Dendrite-0
# Component found in Orphans
# len of vertices = 13531
# Step 1: extracted Soma Mesh = 0.13676118850708008
# Mesh successfully extracted
# Total time = 0.29706668853759766
#
#
# 648518346341357297: Dendrite-0
# Component found in Orphans
# len of vertices = 220522
# Step 1: extracted Soma Mesh = 1.518176555633545
# Mesh successfully extracted
# Total time = 3.01755952835083
#
#
# 648518346341359123: Dendrite-0
# Component found in Orphans
# len of vertices = 73676
# Step 1: extracted Soma Mesh = 0.5520081520080566
# Mesh successfully extracted
# Total time = 1.2449095249176025
#
#
# 648518346341359289: Dendrite-0
# Component found in Orphans
# len of vertices = 48685
# Step 1: extracted Soma Mesh = 0.37787532806396484
# Mesh successfully extracted
# Total time = 1.0728638172149658
#
#
# 648518346341359804: Dendrite-0
# Component found in Orphans
# len of vertices = 14926
# Step 1: extracted Soma Mesh = 0.17563748359680176
# Mesh successfully extracted
# Total time = 0.4072849750518799
#
#
# 648518346341360739: Dendrite-0
# Component found in Orphans
# len of vertices = 90175
# Step 1: extracted Soma Mesh = 0.6901955604553223
# Mesh successfully extracted
# Total time = 1.6494569778442383
#
#
# 648518346341361981: Dendrite-0
# Component found in Orphans
# len of vertices = 254876
# Step 1: extracted Soma Mesh = 1.6933987140655518
# Mesh successfully extracted
# Total time = 3.761484146118164
#
#
# 648518346341362477: Dendrite-0
# Component found in Orphans
# len of vertices = 16477
# Step 1: extracted Soma Mesh = 0.178239107131958
# Mesh successfully extracted
# Total time = 0.3928382396697998
#
#
# 648518346341362995: Dendrite-0
# Component found in Orphans
# len of vertices = 176993
# Step 1: extracted Soma Mesh = 1.2278459072113037
# Mesh successfully extracted
# Total time = 2.5674800872802734
#
#
# 648518346341363175: Dendrite-0
# Component found in Orphans
# len of vertices = 135685
# Step 1: extracted Soma Mesh = 1.043569803237915
# Mesh successfully extracted
# Total time = 2.1289234161376953
#
#
# 648518346341363807: Dendrite-0
# Component found in Orphans
# len of vertices = 35329
# Step 1: extracted Soma Mesh = 0.32373666763305664
# Mesh successfully extracted
# Total time = 0.8606810569763184
#
#
# 648518346341364698: Dendrite-0
# Component found in Orphans
# len of vertices = 60203
# Step 1: extracted Soma Mesh = 0.4884910583496094
# Mesh successfully extracted
# Total time = 1.2749519348144531
#
#
# 648518346341364863: Dendrite-0
# Component found in Orphans
# len of vertices = 77441
# Step 1: extracted Soma Mesh = 0.5962245464324951
# Mesh successfully extracted
# Total time = 1.3653903007507324
#
#
# 648518346341366118: Dendrite-0
# Component found in Orphans
# len of vertices = 12567
# Step 1: extracted Soma Mesh = 0.17423343658447266
# Mesh successfully extracted
# Total time = 0.4210395812988281
#
#
# 648518346341366161: Dendrite-0
# Component found in Orphans
# len of vertices = 42582
# Step 1: extracted Soma Mesh = 0.35262513160705566
# Mesh successfully extracted
# Total time = 0.9613368511199951
#
#
# 648518346341366247: Dendrite-0
# Component found in Orphans
# len of vertices = 53029
# Step 1: extracted Soma Mesh = 0.46164894104003906
# Mesh successfully extracted
# Total time = 1.2272865772247314
#
#
# 648518346341366347: Dendrite-0
# Component found in Orphans
# len of vertices = 29948
# Step 1: extracted Soma Mesh = 0.27392077445983887
# Mesh successfully extracted
# Total time = 0.6416711807250977
#
#
# 648518346341366450: Dendrite-0
# Component found in Orphans
# len of vertices = 18805
# Step 1: extracted Soma Mesh = 0.23012781143188477
# Mesh successfully extracted
# Total time = 0.6486678123474121
#
#
# 648518346341366757: Dendrite-0
# Component found in Orphans
# len of vertices = 75857
# Step 1: extracted Soma Mesh = 0.556999921798706
# Mesh successfully extracted
# Total time = 1.365483045578003
#
#
# 648518346341366977: Dendrite-0
# Component found in Orphans
# len of vertices = 24062
# Step 1: extracted Soma Mesh = 0.19054222106933594
# Mesh successfully extracted
# Total time = 0.4416651725769043
#
#
# 648518346341366999: Dendrite-0
# Component found in Orphans
# len of vertices = 17673
# Step 1: extracted Soma Mesh = 0.17316031455993652
# Mesh successfully extracted
# Total time = 0.3776414394378662
#
#
# 648518346341367473: Dendrite-0
# Component found in Orphans
# len of vertices = 71386
# Step 1: extracted Soma Mesh = 0.5424058437347412
# Mesh successfully extracted
# Total time = 1.264350414276123
#
#
# 648518346341367500: Dendrite-0
# Component found in Orphans
# len of vertices = 18073
# Step 1: extracted Soma Mesh = 0.19910025596618652
# Mesh successfully extracted
# Total time = 0.46611881256103516
#
#
# 648518346341367927: Dendrite-0
# Component found in Orphans
# len of vertices = 75340
# Step 1: extracted Soma Mesh = 0.6103551387786865
# Mesh successfully extracted
# Total time = 1.5330755710601807
#
#
# 648518346341368321: Dendrite-0
# Component found in Orphans
# len of vertices = 46851
# Step 1: extracted Soma Mesh = 0.38959670066833496
# Mesh successfully extracted
# Total time = 0.9543466567993164
#
#
# 648518346341368792: Dendrite-0
# Component found in Orphans
# len of vertices = 14870
# Step 1: extracted Soma Mesh = 0.1797943115234375
# Mesh successfully extracted
# Total time = 0.4211094379425049
#
#
# 648518346341368823: Dendrite-0
# Component found in Orphans
# len of vertices = 32958
# Step 1: extracted Soma Mesh = 0.29935193061828613
# Mesh successfully extracted
# Total time = 0.7982313632965088
#
#
# 648518346341368864: Dendrite-0
# Component found in Orphans
# len of vertices = 51749
# Step 1: extracted Soma Mesh = 0.44320201873779297
# Mesh successfully extracted
# Total time = 1.2144155502319336
#
#
# 648518346341369198: Dendrite-0
# Component found in Orphans
# len of vertices = 12095
# Step 1: extracted Soma Mesh = 0.15218138694763184
# Mesh successfully extracted
# Total time = 0.3196887969970703
#
#
# 648518346341369920: Dendrite-0
# Component found in Orphans
# len of vertices = 75086
# Step 1: extracted Soma Mesh = 0.6015574932098389
# Mesh successfully extracted
# Total time = 1.270986795425415
#
#
# 648518346341371676: Dendrite-0
# Component found in Orphans
# len of vertices = 23613
# Step 1: extracted Soma Mesh = 0.2252492904663086
# Mesh successfully extracted
# Total time = 0.5142581462860107
#
#
# 648518346341372038: Dendrite-0
# Component found in Orphans
# len of vertices = 14183
# Step 1: extracted Soma Mesh = 0.15790700912475586
# Mesh successfully extracted
# Total time = 0.45525097846984863
#
#
# 648518346341372187: Dendrite-0
# Component found in Orphans
# len of vertices = 61905
# Step 1: extracted Soma Mesh = 0.49399518966674805
# Mesh successfully extracted
# Total time = 1.258714199066162
#
#
# 648518346341372248: Dendrite-0
# Component found in Orphans
# len of vertices = 125338
# Step 1: extracted Soma Mesh = 0.9506354331970215
# Mesh successfully extracted
# Total time = 2.1465563774108887
#
#
# 648518346341372763: Dendrite-0
# Component found in Orphans
# len of vertices = 17797
# Step 1: extracted Soma Mesh = 0.20163488388061523
# Mesh successfully extracted
# Total time = 0.4983713626861572
#
#
# 648518346341373284: Dendrite-0
# Component found in Orphans
# len of vertices = 224718
# Step 1: extracted Soma Mesh = 1.513608694076538
# Mesh successfully extracted
# Total time = 3.2642078399658203
#
#
# 648518346341375427: Apical-0
# Component found in Orphans
# len of vertices = 122111
# Step 1: extracted Soma Mesh = 0.7849810123443604
# Mesh successfully extracted
# Total time = 2.58380126953125
#
#
# 648518346341375427: Basal-0
# Component found in Orphans
# len of vertices = 73762
# Step 1: extracted Soma Mesh = 0.6251964569091797
# Mesh successfully extracted
# Total time = 2.15584659576416
#
#
# 648518346341375427: Basal-1
# Component found in Orphans
# len of vertices = 116608
# Step 1: extracted Soma Mesh = 0.8971023559570312
# Mesh successfully extracted
# Total time = 2.6377358436584473
#
#
# 648518346341375427: Oblique-1
# Component found in Orphans
# len of vertices = 26606
# Step 1: extracted Soma Mesh = 0.32022690773010254
# Mesh successfully extracted
# Total time = 1.820009708404541
#
#
# 648518346341375430: Dendrite-0
# Component found in Orphans
# len of vertices = 40715
# Step 1: extracted Soma Mesh = 0.3076145648956299
# Mesh successfully extracted
# Total time = 0.734490156173706
#
#
# 648518346341375782: Dendrite-0
# Component found in Orphans
# len of vertices = 34347
# Step 1: extracted Soma Mesh = 0.23479247093200684
# Mesh successfully extracted
# Total time = 0.5497641563415527
#
#
# 648518346341375784: Dendrite-0
# Component found in Orphans
# len of vertices = 27508
# Step 1: extracted Soma Mesh = 0.20617127418518066
# Mesh successfully extracted
# Total time = 0.4726746082305908
#
#
# 648518346341375951: Dendrite-0
# Component found in Orphans
# len of vertices = 35373
# Step 1: extracted Soma Mesh = 0.31438517570495605
# Mesh successfully extracted
# Total time = 0.9343881607055664
#
#
# 648518346341376143: Dendrite-0
# Component found in Orphans
# len of vertices = 209525
# Step 1: extracted Soma Mesh = 1.440706491470337
# Mesh successfully extracted
# Total time = 2.906784772872925
#
#
# 648518346341376727: Dendrite-0
# Component found in Orphans
# len of vertices = 43502
# Step 1: extracted Soma Mesh = 0.3844740390777588
# Mesh successfully extracted
# Total time = 0.7873077392578125
#
#
# 648518346341377161: Dendrite-0
# Component found in Orphans
# len of vertices = 168322
# Step 1: extracted Soma Mesh = 1.198413372039795
# Mesh successfully extracted
# Total time = 2.50341796875
#
#
# 648518346341377360: Dendrite-0
# Component found in Orphans
# len of vertices = 65731
# Step 1: extracted Soma Mesh = 0.41443514823913574
# Mesh successfully extracted
# Total time = 1.2397019863128662
#
#
# 648518346341377443: Dendrite-0
# Component found in Orphans
# len of vertices = 15970
# Step 1: extracted Soma Mesh = 0.1960773468017578
# Mesh successfully extracted
# Total time = 0.3744077682495117
#
#
# 648518346341378749: Basal-2
# Component found in Orphans
# len of vertices = 18988
# Step 1: extracted Soma Mesh = 0.15458250045776367
# Mesh successfully extracted
# Total time = 0.466156005859375
#
#
# 648518346341379038: Dendrite-0
# Component found in Orphans
# len of vertices = 28487
# Step 1: extracted Soma Mesh = 0.2781498432159424
# Mesh successfully extracted
# Total time = 0.6616747379302979
#
#
# 648518346341379581: Dendrite-0
# Component found in Orphans
# len of vertices = 16465
# Step 1: extracted Soma Mesh = 0.17961716651916504
# Mesh successfully extracted
# Total time = 0.4625515937805176
#
#
# 648518346341379609: Dendrite-0
# Component found in Orphans
# len of vertices = 55268
# Step 1: extracted Soma Mesh = 0.476517915725708
# Mesh successfully extracted
# Total time = 1.0603399276733398
#
#
# 648518346341379688: Dendrite-0
# Component found in Orphans
# len of vertices = 29444
# Step 1: extracted Soma Mesh = 0.2650601863861084
# Mesh successfully extracted
# Total time = 0.7469866275787354
#
#
# 648518346341379951: Dendrite-0
# Component found in Orphans
# len of vertices = 59882
# Step 1: extracted Soma Mesh = 0.4635772705078125
# Mesh successfully extracted
# Total time = 1.1079297065734863
#
#
# 648518346341380192: Dendrite-0
# Component found in Orphans
# len of vertices = 44790
# Step 1: extracted Soma Mesh = 0.40594911575317383
# Mesh successfully extracted
# Total time = 0.9698655605316162
#
#
# 648518346341380208: Dendrite-0
# Component found in Orphans
# len of vertices = 80806
# Step 1: extracted Soma Mesh = 0.623462438583374
# Mesh successfully extracted
# Total time = 1.5620851516723633
#
#
# 648518346341380839: Dendrite-0
# Component found in Orphans
# len of vertices = 11831
# Step 1: extracted Soma Mesh = 0.18415141105651855
# Mesh successfully extracted
# Total time = 0.33764052391052246
#
#
# 648518346341383043: Dendrite-0
# Component found in Orphans
# len of vertices = 76457
# Step 1: extracted Soma Mesh = 0.6082925796508789
# Mesh successfully extracted
# Total time = 1.2325770854949951
#
#
# 648518346341383525: Dendrite-0
# Component found in Orphans
# len of vertices = 32188
# Step 1: extracted Soma Mesh = 0.3387794494628906
# Mesh successfully extracted
# Total time = 0.9663922786712646
#
#
# 648518346341383775: Dendrite-0
# Component found in Orphans
# len of vertices = 38213
# Step 1: extracted Soma Mesh = 0.3380420207977295
# Mesh successfully extracted
# Total time = 0.7651987075805664
#
#
# 648518346341384076: Dendrite-0
# Component found in Orphans
# len of vertices = 13939
# Step 1: extracted Soma Mesh = 0.19578194618225098
# Mesh successfully extracted
# Total time = 0.3999507427215576
#
#
# 648518346341384355: Dendrite-0
# Component found in Orphans
# len of vertices = 37496
# Step 1: extracted Soma Mesh = 0.33391523361206055
# Mesh successfully extracted
# Total time = 0.862375020980835
#
#
# 648518346341387401: Dendrite-0
# Component found in Orphans
# len of vertices = 23813
# Step 1: extracted Soma Mesh = 0.20516014099121094
# Mesh successfully extracted
# Total time = 0.515411376953125
#
#
# 648518346341389060: Basal-0
# Component found in Orphans
# len of vertices = 58912
# Step 1: extracted Soma Mesh = 0.457927942276001
# Mesh successfully extracted
# Total time = 1.2030525207519531
#
#
# 648518346341389651: Dendrite-0
# Component found in Orphans
# len of vertices = 26349
# Step 1: extracted Soma Mesh = 0.25691914558410645
# Mesh successfully extracted
# Total time = 0.7497131824493408
#
#
# 648518346341390126: Dendrite-0
# Component found in Orphans
# len of vertices = 200019
# Step 1: extracted Soma Mesh = 1.4758358001708984
# Mesh successfully extracted
# Total time = 3.165088653564453
#
#
# 648518346341391111: Dendrite-0
# Component found in Orphans
# len of vertices = 81457
# Step 1: extracted Soma Mesh = 0.6270155906677246
# Mesh successfully extracted
# Total time = 1.2845258712768555
#
#
# 648518346341392422: Dendrite-0
# Component found in Orphans
# len of vertices = 29983
# Step 1: extracted Soma Mesh = 0.3093118667602539
# Mesh successfully extracted
# Total time = 0.7813601493835449
#
#
# 648518346341392564: Dendrite-0
# Component found in Orphans
# len of vertices = 17807
# Step 1: extracted Soma Mesh = 0.2244584560394287
# Mesh successfully extracted
# Total time = 0.44101977348327637
#
#
# 648518346341393950: Dendrite-0
# Component found in Orphans
# len of vertices = 63589
# Step 1: extracted Soma Mesh = 0.5253791809082031
# Mesh successfully extracted
# Total time = 1.078338384628296
#
#
# 648518346341394208: Dendrite-0
# Component found in Orphans
# len of vertices = 80239
# Step 1: extracted Soma Mesh = 0.6744515895843506
# Mesh successfully extracted
# Total time = 1.6065962314605713
#
#
# 648518346341394346: Dendrite-0
# Component found in Orphans
# len of vertices = 12564
# Step 1: extracted Soma Mesh = 0.17917203903198242
# Mesh successfully extracted
# Total time = 0.381152868270874
#
#
# 648518346341394374: Dendrite-0
# Component found in Orphans
# len of vertices = 106103
# Step 1: extracted Soma Mesh = 0.8398377895355225
# Mesh successfully extracted
# Total time = 1.7502570152282715
#
#
# 648518346341394569: Dendrite-0
# Component found in Orphans
# len of vertices = 35783
# Step 1: extracted Soma Mesh = 0.2926630973815918
# Mesh successfully extracted
# Total time = 0.7337703704833984
#
#
# 648518346341394638: Dendrite-0
# Component found in Orphans
# len of vertices = 64430
# Step 1: extracted Soma Mesh = 0.5210814476013184
# Mesh successfully extracted
# Total time = 1.3470664024353027
#
#
# 648518346341394683: Dendrite-0
# Component found in Orphans
# len of vertices = 86450
# Step 1: extracted Soma Mesh = 0.6804311275482178
# Mesh successfully extracted
# Total time = 1.502821683883667
#
#
# 648518346341394791: Dendrite-0
# Component found in Orphans
# len of vertices = 43806
# Step 1: extracted Soma Mesh = 0.30179524421691895
# Mesh successfully extracted
# Total time = 0.7587268352508545
#
#
# 648518346341394813: Dendrite-0
# Component found in Orphans
# len of vertices = 46997
# Step 1: extracted Soma Mesh = 0.388594388961792
# Mesh successfully extracted
# Total time = 1.097405195236206
#
#
# 648518346341395182: Dendrite-0
# Component found in Orphans
# len of vertices = 14298
# Step 1: extracted Soma Mesh = 0.1570603847503662
# Mesh successfully extracted
# Total time = 0.47000885009765625
#
#
# 648518346341395255: Dendrite-0
# Component found in Orphans
# len of vertices = 24094
# Step 1: extracted Soma Mesh = 0.25473690032958984
# Mesh successfully extracted
# Total time = 0.5460419654846191
#
#
# 648518346341395530: Dendrite-0
# Component found in Orphans
# len of vertices = 97158
# Step 1: extracted Soma Mesh = 0.7305383682250977
# Mesh successfully extracted
# Total time = 1.542229413986206
#
#
# 648518346341395826: Dendrite-0
# Component found in Orphans
# len of vertices = 19136
# Step 1: extracted Soma Mesh = 0.20519328117370605
# Mesh successfully extracted
# Total time = 0.48170042037963867
#
#
# 648518346341396164: Dendrite-0
# Component found in Orphans
# len of vertices = 19708
# Step 1: extracted Soma Mesh = 0.23054718971252441
# Mesh successfully extracted
# Total time = 0.5597047805786133
#
#
# 648518346341396418: Dendrite-0
# Component found in Orphans
# len of vertices = 54151
# Step 1: extracted Soma Mesh = 0.44820451736450195
# Mesh successfully extracted
# Total time = 1.2378535270690918
#
#
# 648518346341396532: Dendrite-0
# Component found in Orphans
# len of vertices = 30769
# Step 1: extracted Soma Mesh = 0.3302724361419678
# Mesh successfully extracted
# Total time = 0.6756563186645508
#
#
# 648518346341396536: Dendrite-0
# Component found in Orphans
# len of vertices = 14421
# Step 1: extracted Soma Mesh = 0.198167085647583
# Mesh successfully extracted
# Total time = 0.4459366798400879
#
#
# 648518346341396698: Dendrite-0
# Component found in Orphans
# len of vertices = 149105
# Step 1: extracted Soma Mesh = 1.103024959564209
# Mesh successfully extracted
# Total time = 2.3736605644226074
#
#
# 648518346341396962: Dendrite-0
# Component found in Orphans
# len of vertices = 62369
# Step 1: extracted Soma Mesh = 0.5138039588928223
# Mesh successfully extracted
# Total time = 1.1004579067230225
#
#
# 648518346341397321: Dendrite-0
# Component found in Orphans
# len of vertices = 63004
# Step 1: extracted Soma Mesh = 0.501272439956665
# Mesh successfully extracted
# Total time = 1.1615421772003174
#
#
# 648518346341398089: Dendrite-0
# Component found in Orphans
# len of vertices = 12865
# Step 1: extracted Soma Mesh = 0.14641761779785156
# Mesh successfully extracted
# Total time = 0.349750280380249
#
#
# 648518346341398438: Dendrite-0
# Component found in Orphans
# len of vertices = 66613
# Step 1: extracted Soma Mesh = 0.5264773368835449
# Mesh successfully extracted
# Total time = 1.2057628631591797
#
#
# 648518346341398503: Dendrite-0
# Component found in Orphans
# len of vertices = 83264
# Step 1: extracted Soma Mesh = 0.6364154815673828
# Mesh successfully extracted
# Total time = 1.6060564517974854
#
#
# 648518346341398702: Dendrite-0
# Component found in Orphans
# len of vertices = 23065
# Step 1: extracted Soma Mesh = 0.23998284339904785
# Mesh successfully extracted
# Total time = 0.5702822208404541
#
#
# 648518346341398823: Dendrite-0
# Component found in Orphans
# len of vertices = 70356
# Step 1: extracted Soma Mesh = 0.5555553436279297
# Mesh successfully extracted
# Total time = 1.3345861434936523
#
#
# 648518346341399051: Dendrite-0
# Component found in Orphans
# len of vertices = 53243
# Step 1: extracted Soma Mesh = 0.44423341751098633
# Mesh successfully extracted
# Total time = 1.0388624668121338
#
#
# 648518346341399068: Dendrite-0
# Component found in Orphans
# len of vertices = 23322
# Step 1: extracted Soma Mesh = 0.16096711158752441
# Mesh successfully extracted
# Total time = 0.40967869758605957
#
#
# 648518346341399129: Dendrite-0
# Component found in Orphans
# len of vertices = 19956
# Step 1: extracted Soma Mesh = 0.2426471710205078
# Mesh successfully extracted
# Total time = 0.5293216705322266
#
#
# 648518346341399130: Dendrite-0
# Component found in Orphans
# len of vertices = 91401
# Step 1: extracted Soma Mesh = 0.7002508640289307
# Mesh successfully extracted
# Total time = 1.468186616897583
#
#
# 648518346341399296: Dendrite-0
# Component found in Orphans
# len of vertices = 69915
# Step 1: extracted Soma Mesh = 0.5414597988128662
# Mesh successfully extracted
# Total time = 1.32914137840271
#
#
# 648518346341399382: Dendrite-0
# Component found in Orphans
# len of vertices = 33727
# Step 1: extracted Soma Mesh = 0.2965884208679199
# Mesh successfully extracted
# Total time = 0.844806432723999
#
#
# 648518346341399743: Dendrite-0
# Component found in Orphans
# len of vertices = 82353
# Step 1: extracted Soma Mesh = 0.6627528667449951
# Mesh successfully extracted
# Total time = 1.3057878017425537
#
#
# 648518346341400003: Dendrite-0
# Component found in Orphans
# len of vertices = 87125
# Step 1: extracted Soma Mesh = 0.694544792175293
# Mesh successfully extracted
# Total time = 1.7461636066436768
#
#
# 648518346341400173: Dendrite-0
# Component found in Orphans
# len of vertices = 91632
# Step 1: extracted Soma Mesh = 0.5179131031036377
# Mesh successfully extracted
# Total time = 1.275801420211792
#
#
# 648518346341400285: Dendrite-0
# Component found in Orphans
# len of vertices = 26330
# Step 1: extracted Soma Mesh = 0.263293981552124
# Mesh successfully extracted
# Total time = 0.6327142715454102
#
#
# 648518346341401013: Dendrite-0
# Component found in Orphans
# len of vertices = 20628
# Step 1: extracted Soma Mesh = 0.22175216674804688
# Mesh successfully extracted
# Total time = 0.5185699462890625
#
#
# 648518346341401448: Dendrite-0
# Component found in Orphans
# len of vertices = 40316
# Step 1: extracted Soma Mesh = 0.34610939025878906
# Mesh successfully extracted
# Total time = 0.936046838760376
#
#
# 648518346341401733: Dendrite-2
# Component found in Orphans
# len of vertices = 17595
# Step 1: extracted Soma Mesh = 0.26242876052856445
# Mesh successfully extracted
# Total time = 0.4878509044647217
#
#
# 648518346341401776: Dendrite-0
# Component found in Orphans
# len of vertices = 37278
# Step 1: extracted Soma Mesh = 0.3011195659637451
# Mesh successfully extracted
# Total time = 0.8175356388092041
#
#
# 648518346341401904: Dendrite-0
# Component found in Orphans
# len of vertices = 98572
# Step 1: extracted Soma Mesh = 0.6954901218414307
# Mesh successfully extracted
# Total time = 1.3842298984527588
#
#
# 648518346341402112: Dendrite-0
# Component found in Orphans
# len of vertices = 45348
# Step 1: extracted Soma Mesh = 0.2919449806213379
# Mesh successfully extracted
# Total time = 0.8470053672790527
#
#
# 648518346341402446: Dendrite-0
# Component found in Orphans
# len of vertices = 63356
# Step 1: extracted Soma Mesh = 0.438291072845459
# Mesh successfully extracted
# Total time = 1.1389248371124268
#
#
# 648518346341402454: Dendrite-0
# Component found in Orphans
# len of vertices = 223861
# Step 1: extracted Soma Mesh = 1.4814019203186035
# Mesh successfully extracted
# Total time = 3.107713460922241
#
#
# 648518346341402616: Dendrite-0
# Component found in Orphans
# len of vertices = 16592
# Step 1: extracted Soma Mesh = 0.0950312614440918
# Mesh successfully extracted
# Total time = 0.250856876373291
#
#
# 648518346341402643: Dendrite-0
# Component found in Orphans
# len of vertices = 46897
# Step 1: extracted Soma Mesh = 0.31519556045532227
# Mesh successfully extracted
# Total time = 0.7651257514953613
#
#
# 648518346341402768: Dendrite-0
# Component found in Orphans
# len of vertices = 25478
# Step 1: extracted Soma Mesh = 0.22535967826843262
# Mesh successfully extracted
# Total time = 0.5690751075744629
#
#
# 648518346341403146: Dendrite-0
# Component found in Orphans
# len of vertices = 23494
# Step 1: extracted Soma Mesh = 0.23854923248291016
# Mesh successfully extracted
# Total time = 0.5760400295257568
#
#
# 648518346341403146: Dendrite-1
# Component found in Orphans
# len of vertices = 17494
# Step 1: extracted Soma Mesh = 0.23900675773620605
# Mesh successfully extracted
# FILTERED EDGES EMPTY
# Total time = 0.47355175018310547
#
#
# 648518346341403291: Dendrite-0
# Component found in Orphans
# len of vertices = 44108
# Step 1: extracted Soma Mesh = 0.3804433345794678
# Mesh successfully extracted
# Total time = 1.0000574588775635
#
#
# 648518346341403533: Dendrite-0
# Component found in Orphans
# len of vertices = 16053
# Step 1: extracted Soma Mesh = 0.1441950798034668
# Mesh successfully extracted
# Total time = 0.35973453521728516
#
#
# 648518346341403967: Apical-0
# Component found in Orphans
# len of vertices = 66568
# Step 1: extracted Soma Mesh = 0.5451130867004395
# Mesh successfully extracted
# Total time = 1.8156752586364746
#
#
# 648518346341403967: Basal-0
# Component found in Orphans
# len of vertices = 35459
# Step 1: extracted Soma Mesh = 0.22911477088928223
# Mesh successfully extracted
# Total time = 1.2548210620880127
#
#
# 648518346341403967: Oblique-0
# Component found in Orphans
# len of vertices = 11012
# Step 1: extracted Soma Mesh = 0.1352841854095459
# Mesh successfully extracted
# Total time = 1.069265604019165
#
#
# 648518346341403967: Oblique-1
# Component found in Orphans
# len of vertices = 33615
# Step 1: extracted Soma Mesh = 0.34803009033203125
# Mesh successfully extracted
# Total time = 1.3755366802215576
#
#
# 648518346341404064: Dendrite-0
# Component found in Orphans
# len of vertices = 43187
# Step 1: extracted Soma Mesh = 0.2400667667388916
# Mesh successfully extracted
# Total time = 0.7311630249023438
#
#
# 648518346341404619: Dendrite-0
# Component found in Orphans
# len of vertices = 13007
# Step 1: extracted Soma Mesh = 0.1860637664794922
# Mesh successfully extracted
# Total time = 0.35688090324401855
#
#
# 648518346341404885: Dendrite-0
# Component found in Orphans
# len of vertices = 17501
# Step 1: extracted Soma Mesh = 0.14803171157836914
# Mesh successfully extracted
# Total time = 0.4241213798522949
#
#
# 648518346341405100: Dendrite-0
# Component found in Orphans
# len of vertices = 24170
# Step 1: extracted Soma Mesh = 0.24071764945983887
# Mesh successfully extracted
# Total time = 0.5699913501739502
#
#
# 648518346341405357: Dendrite-0
# Component found in Orphans
# len of vertices = 31275
# Step 1: extracted Soma Mesh = 0.2715928554534912
# Mesh successfully extracted
# Total time = 0.829984188079834
#
#
# 648518346341405768: Dendrite-0
# Component found in Orphans
# len of vertices = 37445
# Step 1: extracted Soma Mesh = 0.3061237335205078
# Mesh successfully extracted
# Total time = 0.9817166328430176
#
#
# 648518346341406323: Dendrite-0
# Component found in Orphans
# len of vertices = 32826
# Step 1: extracted Soma Mesh = 0.2595858573913574
# Mesh successfully extracted
# Total time = 0.7828967571258545
#
#
# 648518346341407034: Dendrite-0
# Component found in Orphans
# len of vertices = 35858
# Step 1: extracted Soma Mesh = 0.2601494789123535
# Mesh successfully extracted
# Total time = 0.7597858905792236
#
#
# 648518346341407554: Dendrite-0
# Component found in Orphans
# len of vertices = 19439
# Step 1: extracted Soma Mesh = 0.22920513153076172
# Mesh successfully extracted
# Total time = 0.4220468997955322
#
#
# 648518346341407642: Dendrite-0
# Component found in Orphans
# len of vertices = 65444
# Step 1: extracted Soma Mesh = 0.36542487144470215
# Mesh successfully extracted
# Total time = 0.919600248336792
#
#
# 648518346341408647: Dendrite-0
# Component found in Orphans
# len of vertices = 44700
# Step 1: extracted Soma Mesh = 0.2732250690460205
# Mesh successfully extracted
# Total time = 0.8157422542572021
#
#
# 648518346341409351: Dendrite-0
# Component found in Orphans
# len of vertices = 37898
# Step 1: extracted Soma Mesh = 0.20667171478271484
# Mesh successfully extracted
# Total time = 0.5523102283477783
#
#
# 648518346341409819: Dendrite-0
# Component found in Orphans
# len of vertices = 40364
# Step 1: extracted Soma Mesh = 0.32215070724487305
# Mesh successfully extracted
# Total time = 0.6906096935272217
#
#
# 648518346341409969: Dendrite-0
# Component found in Orphans
# len of vertices = 24315
# Step 1: extracted Soma Mesh = 0.13744616508483887
# Mesh successfully extracted
# Total time = 0.3713493347167969
#
#
# 648518346341410186: Dendrite-0
# Component found in Orphans
# len of vertices = 23389
# Step 1: extracted Soma Mesh = 0.2011277675628662
# Mesh successfully extracted
# Total time = 0.4483494758605957
#
#
# 648518346341410600: Dendrite-0
# Component found in Orphans
# len of vertices = 99366
# Step 1: extracted Soma Mesh = 0.7520191669464111
# Mesh successfully extracted
# Total time = 1.7774734497070312
#
#
# 648518346341410774: Dendrite-0
# Component found in Orphans
# len of vertices = 88330
# Step 1: extracted Soma Mesh = 0.541593074798584
# Mesh successfully extracted
# Total time = 1.220198154449463
#
#
# 648518346341410882: Dendrite-0
# Component found in Orphans
# len of vertices = 55806
# Step 1: extracted Soma Mesh = 0.2983376979827881
# Mesh successfully extracted
# Total time = 0.8628792762756348
#
#
# 648518346341411107: Dendrite-0
# Component found in Orphans
# len of vertices = 21584
# Step 1: extracted Soma Mesh = 0.18520188331604004
# Mesh successfully extracted
# Total time = 0.4156625270843506
#
#
# 648518346341412652: Dendrite-0
# Component found in Orphans
# len of vertices = 37772
# Step 1: extracted Soma Mesh = 0.35130786895751953
# Mesh successfully extracted
# Total time = 0.8421638011932373
#
#
# 648518346341412854: Dendrite-0
# Component found in Orphans
# len of vertices = 41519
# Step 1: extracted Soma Mesh = 0.31084108352661133
# Mesh successfully extracted
# Total time = 0.9367718696594238
#
#
# 648518346341413029: Dendrite-0
# Component found in Orphans
# len of vertices = 32203
# Step 1: extracted Soma Mesh = 0.261523962020874
# Mesh successfully extracted
# Total time = 0.6490874290466309
#
#
# 648518346341413168: Dendrite-0
# Component found in Orphans
# len of vertices = 26923
# Step 1: extracted Soma Mesh = 0.20898699760437012
# Mesh successfully extracted
# Total time = 0.47394847869873047
#
#
# 648518346341413209: Dendrite-0
# Component found in Orphans
# len of vertices = 98243
# Step 1: extracted Soma Mesh = 0.7118606567382812
# Mesh successfully extracted
# Total time = 1.6642487049102783
#
#
# 648518346341413417: Dendrite-0
# Component found in Orphans
# len of vertices = 25295
# Step 1: extracted Soma Mesh = 0.20465731620788574
# Mesh successfully extracted
# Total time = 0.41010570526123047
#
#
# 648518346341413916: Dendrite-0
# Component found in Orphans
# len of vertices = 33214
# Step 1: extracted Soma Mesh = 0.2300558090209961
# Mesh successfully extracted
# Total time = 0.5639138221740723
#
#
# 648518346341413929: Dendrite-0
# Component found in Orphans
# len of vertices = 73541
# Step 1: extracted Soma Mesh = 0.41374754905700684
# Mesh successfully extracted
# Total time = 0.9590349197387695
#
#
# 648518346341414073: Dendrite-0
# Component found in Orphans
# len of vertices = 74570
# Step 1: extracted Soma Mesh = 0.42501378059387207
# Mesh successfully extracted
# Total time = 1.183933973312378
#
#
# 648518346341414090: Dendrite-0
# Component found in Orphans
# len of vertices = 14021
# Step 1: extracted Soma Mesh = 0.17433953285217285
# Mesh successfully extracted
# Total time = 0.41011857986450195
#
#
# 648518346341414287: Dendrite-0
# Component found in Orphans
# len of vertices = 31506
# Step 1: extracted Soma Mesh = 0.3002970218658447
# Mesh successfully extracted
# Total time = 0.7031457424163818
#
#
# 648518346341414621: Dendrite-0
# Component found in Orphans
# len of vertices = 28647
# Step 1: extracted Soma Mesh = 0.2820925712585449
# Mesh successfully extracted
# Total time = 0.6879558563232422
#
#
# 648518346341414626: Dendrite-0
# Component found in Orphans
# len of vertices = 25717
# Step 1: extracted Soma Mesh = 0.23746323585510254
# Mesh successfully extracted
# Total time = 0.6546711921691895
#
#
# 648518346341415622: Dendrite-0
# Component found in Orphans
# len of vertices = 14580
# Step 1: extracted Soma Mesh = 0.16499996185302734
# Mesh successfully extracted
# Total time = 0.3997948169708252
#
#
# 648518346341415626: Dendrite-0
# Component found in Orphans
# len of vertices = 13362
# Step 1: extracted Soma Mesh = 0.19795942306518555
# Mesh successfully extracted
# Total time = 0.3898956775665283
#
#
# 648518346341416667: Dendrite-0
# Component found in Orphans
# len of vertices = 11527
# Step 1: extracted Soma Mesh = 0.14751958847045898
# Mesh successfully extracted
# Total time = 0.33403611183166504
#
#
# 648518346342098479: Dendrite-0
# Component found in Orphans
# len of vertices = 25320
# Step 1: extracted Soma Mesh = 0.23742413520812988
# Mesh successfully extracted
# Total time = 0.5754528045654297
#
#
# 648518346342101390: Dendrite-0
# Component found in Orphans
# len of vertices = 16437
# Step 1: extracted Soma Mesh = 0.1760098934173584
# Mesh successfully extracted
# Total time = 0.3939087390899658
#
#
# 648518346342105321: Dendrite-0
# Component found in Orphans
# len of vertices = 20780
# Step 1: extracted Soma Mesh = 0.1846470832824707
# Mesh successfully extracted
# Total time = 0.4258420467376709
#
#
# 648518346342107130: Dendrite-0
# Component found in Orphans
# len of vertices = 22411
# Step 1: extracted Soma Mesh = 0.21478557586669922
# Mesh successfully extracted
# Total time = 0.5070252418518066
#
#
# 648518346342159130: Dendrite-0
# Component found in Orphans
# len of vertices = 13258
# Step 1: extracted Soma Mesh = 0.18573713302612305
# Mesh successfully extracted
# Total time = 0.41808319091796875
#
#
# 648518346342405491: Dendrite-0
# Component found in Orphans
# len of vertices = 14330
# Step 1: extracted Soma Mesh = 0.16970062255859375
# Mesh successfully extracted
# Total time = 0.41049885749816895
#
#
# 648518346342406253: Dendrite-0
# Component found in Orphans
# len of vertices = 23282
# Step 1: extracted Soma Mesh = 0.2217719554901123
# Mesh successfully extracted
# Total time = 0.5518126487731934
#
#
# 648518346342413345: Dendrite-0
# Component found in Orphans
# len of vertices = 14616
# Step 1: extracted Soma Mesh = 0.2114238739013672
# Mesh successfully extracted
# Total time = 0.4278128147125244
#
#
# 648518346342416145: Dendrite-0
# Component found in Orphans
# len of vertices = 16220
# Step 1: extracted Soma Mesh = 0.21599531173706055
# Mesh successfully extracted
# Total time = 0.525623083114624
#
#
# 648518346342468856: Dendrite-0
# Component found in Orphans
# len of vertices = 15758
# Step 1: extracted Soma Mesh = 0.1832747459411621
# Mesh successfully extracted
# Total time = 0.41747236251831055
#
#
# 648518346342788331: Dendrite-0
# Component found in Orphans
# len of vertices = 30231
# Step 1: extracted Soma Mesh = 0.2760598659515381
# Mesh successfully extracted
# Total time = 0.806117057800293
#
#
# 648518346342788606: Dendrite-0
# Component found in Orphans
# len of vertices = 35547
# Step 1: extracted Soma Mesh = 0.3226318359375
# Mesh successfully extracted
# Total time = 0.7432832717895508
#
#
# 648518346342788893: Dendrite-0
# Component found in Orphans
# len of vertices = 13951
# Step 1: extracted Soma Mesh = 0.16149163246154785
# Mesh successfully extracted
# Total time = 0.36631035804748535
#
#
# 648518346342789026: Dendrite-0
# Component found in Orphans
# len of vertices = 22041
# Step 1: extracted Soma Mesh = 0.22052526473999023
# Mesh successfully extracted
# Total time = 0.48879170417785645
#
#
# 648518346342789286: Dendrite-0
# Component found in Orphans
# len of vertices = 71321
# Step 1: extracted Soma Mesh = 0.5907135009765625
# Mesh successfully extracted
# Total time = 1.2457606792449951
#
#
# 648518346342789414: Dendrite-0
# Component found in Orphans
# len of vertices = 19170
# Step 1: extracted Soma Mesh = 0.19423127174377441
# Mesh successfully extracted
# Total time = 0.4956810474395752
#
#
# 648518346342789831: Dendrite-0
# Component found in Orphans
# len of vertices = 50306
# Step 1: extracted Soma Mesh = 0.41290879249572754
# Mesh successfully extracted
# Total time = 1.1444082260131836
#
#
# 648518346342790189: Dendrite-0
# Component found in Orphans
# len of vertices = 29871
# Step 1: extracted Soma Mesh = 0.2903859615325928
# Mesh successfully extracted
# Total time = 0.7080624103546143
#
#
# 648518346342790335: Dendrite-0
# Component found in Orphans
# len of vertices = 51189
# Step 1: extracted Soma Mesh = 0.4189596176147461
# Mesh successfully extracted
# Total time = 1.0240590572357178
#
#
# 648518346342790849: Dendrite-0
# Component found in Orphans
# len of vertices = 39913
# Step 1: extracted Soma Mesh = 0.34206604957580566
# Mesh successfully extracted
# Total time = 0.9973747730255127
#
#
# 648518346342790864: Dendrite-0
# Component found in Orphans
# len of vertices = 119553
# Step 1: extracted Soma Mesh = 0.9317309856414795
# Mesh successfully extracted
# Total time = 2.128404140472412
#
#
# 648518346342790990: Dendrite-0
# Component found in Orphans
# len of vertices = 40496
# Step 1: extracted Soma Mesh = 0.3209238052368164
# Mesh successfully extracted
# Total time = 0.9401335716247559
#
#
# 648518346342791382: Dendrite-0
# Component found in Orphans
# len of vertices = 66191
# Step 1: extracted Soma Mesh = 0.5155155658721924
# Mesh successfully extracted
# Total time = 1.1691789627075195
#
#
# 648518346342791547: Dendrite-0
# Component found in Orphans
# len of vertices = 47899
# Step 1: extracted Soma Mesh = 0.40030455589294434
# Mesh successfully extracted
# Total time = 0.9486241340637207
#
#
# 648518346342791878: Dendrite-0
# Component found in Orphans
# len of vertices = 27964
# Step 1: extracted Soma Mesh = 0.25551915168762207
# Mesh successfully extracted
# Total time = 0.6315507888793945
#
#
# 648518346342791920: Dendrite-0
# Component found in Orphans
# len of vertices = 51755
# Step 1: extracted Soma Mesh = 0.4518156051635742
# Mesh successfully extracted
# Total time = 1.1651983261108398
#
#
# 648518346342791929: Dendrite-0
# Component found in Orphans
# len of vertices = 25293
# Step 1: extracted Soma Mesh = 0.26256346702575684
# Mesh successfully extracted
# Total time = 0.6857898235321045
#
#
# 648518346342792040: Basal-0
# Component found in Orphans
# len of vertices = 104053
# Step 1: extracted Soma Mesh = 0.8406412601470947
# Mesh successfully extracted
# Total time = 1.8845257759094238
#
#
# 648518346342792042: Dendrite-0
# Component found in Orphans
# len of vertices = 12360
# Step 1: extracted Soma Mesh = 0.1674940586090088
# Mesh successfully extracted
# Total time = 0.3546488285064697
#
#
# 648518346342792394: Dendrite-0
# Component found in Orphans
# len of vertices = 71583
# Step 1: extracted Soma Mesh = 0.5767931938171387
# Mesh successfully extracted
# Total time = 1.3209068775177002
#
#
# 648518346342792507: Apical-0
# Component found in Orphans
# len of vertices = 236057
# Step 1: extracted Soma Mesh = 1.6607811450958252
# Mesh successfully extracted
# Total time = 3.751504898071289
#
#
# 648518346342792507: Basal-0
# Component found in Orphans
# len of vertices = 54300
# Step 1: extracted Soma Mesh = 0.5031352043151855
# Mesh successfully extracted
# Total time = 2.1067988872528076
#
#
# 648518346342792831: Dendrite-0
# Component found in Orphans
# len of vertices = 17115
# Step 1: extracted Soma Mesh = 0.21883535385131836
# Mesh successfully extracted
# Total time = 0.48230838775634766
#
#
# 648518346342792939: Dendrite-0
# Component found in Orphans
# len of vertices = 44580
# Step 1: extracted Soma Mesh = 0.3836960792541504
# Mesh successfully extracted
# Total time = 0.9740948677062988
#
#
# 648518346342793052: Dendrite-0
# Component found in Orphans
# len of vertices = 26759
# Step 1: extracted Soma Mesh = 0.23575139045715332
# Mesh successfully extracted
# Total time = 0.6335084438323975
#
#
# 648518346342793058: Dendrite-0
# Component found in Orphans
# len of vertices = 15172
# Step 1: extracted Soma Mesh = 0.18355679512023926
# Mesh successfully extracted
# Total time = 0.4260382652282715
#
#
# 648518346342793875: Dendrite-0
# Component found in Orphans
# len of vertices = 54820
# Step 1: extracted Soma Mesh = 0.4732227325439453
# Mesh successfully extracted
# Total time = 1.0644869804382324
#
#
# 648518346342793912: Dendrite-0
# Component found in Orphans
# len of vertices = 116676
# Step 1: extracted Soma Mesh = 0.9211564064025879
# Mesh successfully extracted
# Total time = 1.9901187419891357
#
#
# 648518346342793913: Dendrite-0
# Component found in Orphans
# len of vertices = 32237
# Step 1: extracted Soma Mesh = 0.30806493759155273
# Mesh successfully extracted
# Total time = 0.7491309642791748
#
#
# 648518346342793994: Basal-0
# Component found in Orphans
# len of vertices = 80211
# Step 1: extracted Soma Mesh = 0.6447250843048096
# Mesh successfully extracted
# Total time = 1.4217991828918457
#
#
# 648518346342794090: Dendrite-0
# Component found in Orphans
# len of vertices = 28114
# Step 1: extracted Soma Mesh = 0.27583980560302734
# Mesh successfully extracted
# Total time = 0.7122983932495117
#
#
# 648518346342795839: Dendrite-0
# Component found in Orphans
# len of vertices = 19214
# Step 1: extracted Soma Mesh = 0.19830107688903809
# Mesh successfully extracted
# Total time = 0.47263336181640625
#
#
# 648518346342795887: Dendrite-0
# Component found in Orphans
# len of vertices = 68622
# Step 1: extracted Soma Mesh = 0.5489749908447266
# Mesh successfully extracted
# Total time = 1.343341588973999
#
#
# 648518346342795954: Dendrite-0
# Component found in Orphans
# len of vertices = 32491
# Step 1: extracted Soma Mesh = 0.30069494247436523
# Mesh successfully extracted
# Total time = 0.8341608047485352
#
#
# 648518346342796094: Dendrite-0
# Component found in Orphans
# len of vertices = 21056
# Step 1: extracted Soma Mesh = 0.23306679725646973
# Mesh successfully extracted
# Total time = 0.6303365230560303
#
#
# 648518346342796299: Dendrite-0
# Component found in Orphans
# len of vertices = 45546
# Step 1: extracted Soma Mesh = 0.3831620216369629
# Mesh successfully extracted
# Total time = 1.0429449081420898
#
#
# 648518346342796517: Dendrite-0
# Component found in Orphans
# len of vertices = 66482
# Step 1: extracted Soma Mesh = 0.5173072814941406
# Mesh successfully extracted
# Total time = 1.2406890392303467
#
#
# 648518346342796747: Dendrite-0
# Component found in Orphans
# len of vertices = 72008
# Step 1: extracted Soma Mesh = 0.5834207534790039
# Mesh successfully extracted
# Total time = 1.3176815509796143
#
#
# 648518346342796832: Dendrite-0
# Component found in Orphans
# len of vertices = 37480
# Step 1: extracted Soma Mesh = 0.29596614837646484
# Mesh successfully extracted
# Total time = 0.7739231586456299
#
#
# 648518346342797258: Dendrite-0
# Component found in Orphans
# len of vertices = 27363
# Step 1: extracted Soma Mesh = 0.31156039237976074
# Mesh successfully extracted
# Total time = 0.6842296123504639
#
#
# 648518346342797258: Dendrite-1
# Component found in Orphans
# len of vertices = 20263
# Step 1: extracted Soma Mesh = 0.265838623046875
# Mesh successfully extracted
# FILTERED EDGES EMPTY
# Total time = 0.48298120498657227
#
#
# 648518346342797579: Dendrite-0
# Component found in Orphans
# len of vertices = 96091
# Step 1: extracted Soma Mesh = 0.7180628776550293
# Mesh successfully extracted
# Total time = 1.8226616382598877
#
#
# 648518346342797591: Dendrite-0
# Component found in Orphans
# len of vertices = 35346
# Step 1: extracted Soma Mesh = 0.293781042098999
# Mesh successfully extracted
# Total time = 0.882537841796875
#
#
# 648518346342797732: Dendrite-0
# Component found in Orphans
# len of vertices = 11673
# Step 1: extracted Soma Mesh = 0.1471540927886963
# Mesh successfully extracted
# Total time = 0.32321834564208984
#
#
# 648518346342797967: Dendrite-0
# Component found in Orphans
# len of vertices = 43849
# Step 1: extracted Soma Mesh = 0.38594746589660645
# Mesh successfully extracted
# Total time = 0.9681520462036133
#
#
# 648518346342797983: Dendrite-0
# Component found in Orphans
# len of vertices = 11170
# Step 1: extracted Soma Mesh = 0.14014053344726562
# Mesh successfully extracted
# Total time = 0.32674098014831543
#
#
# 648518346342798657: Dendrite-0
# Component found in Orphans
# len of vertices = 63108
# Step 1: extracted Soma Mesh = 0.49422287940979004
# Mesh successfully extracted
# Total time = 1.0183241367340088
#
#
# 648518346342798808: Dendrite-0
# Component found in Orphans
# len of vertices = 25140
# Step 1: extracted Soma Mesh = 0.23762297630310059
# Mesh successfully extracted
# Total time = 0.5834338665008545
#
#
# 648518346342798923: Dendrite-0
# Component found in Orphans
# len of vertices = 240426
# Step 1: extracted Soma Mesh = 1.6322410106658936
# Mesh successfully extracted
# Total time = 3.156622886657715
#
#
# 648518346342798986: Dendrite-0
# Component found in Orphans
# len of vertices = 26070
# Step 1: extracted Soma Mesh = 0.16359281539916992
# Mesh successfully extracted
# Total time = 0.403378963470459
#
#
# 648518346342799012: Dendrite-0
# Component found in Orphans
# len of vertices = 25787
# Step 1: extracted Soma Mesh = 0.25179171562194824
# Mesh successfully extracted
# Total time = 0.6775243282318115
#
#
# 648518346342799047: Dendrite-0
# Component found in Orphans
# len of vertices = 54144
# Step 1: extracted Soma Mesh = 0.4265742301940918
# Mesh successfully extracted
# Total time = 1.0571179389953613
#
#
# 648518346342799072: Dendrite-0
# Component found in Orphans
# len of vertices = 26554
# Step 1: extracted Soma Mesh = 0.270763635635376
# Mesh successfully extracted
# Total time = 0.5878655910491943
#
#
# 648518346342799263: Dendrite-0
# Component found in Orphans
# len of vertices = 38884
# Step 1: extracted Soma Mesh = 0.33339929580688477
# Mesh successfully extracted
# Total time = 0.7754504680633545
#
#
# 648518346342799930: Dendrite-0
# Component found in Orphans
# len of vertices = 38061
# Step 1: extracted Soma Mesh = 0.3146958351135254
# Mesh successfully extracted
# Total time = 0.8300909996032715
#
#
# 648518346342800580: Dendrite-0
# Component found in Orphans
# len of vertices = 38715
# Step 1: extracted Soma Mesh = 0.34757447242736816
# Mesh successfully extracted
# Total time = 0.8672521114349365
#
#
# 648518346342800762: Dendrite-0
# Component found in Orphans
# len of vertices = 121029
# Step 1: extracted Soma Mesh = 0.9552316665649414
# Mesh successfully extracted
# Total time = 2.0521838665008545
#
#
# 648518346342800774: Dendrite-0
# Component found in Orphans
# len of vertices = 19418
# Step 1: extracted Soma Mesh = 0.2320241928100586
# Mesh successfully extracted
# Total time = 0.6918294429779053
#
#
# 648518346342800778: Dendrite-0
# Component found in Orphans
# len of vertices = 28684
# Step 1: extracted Soma Mesh = 0.30049920082092285
# Mesh successfully extracted
# Total time = 0.7733116149902344
#
#
# 648518346342800822: Dendrite-0
# Component found in Orphans
# len of vertices = 44391
# Step 1: extracted Soma Mesh = 0.39563941955566406
# Mesh successfully extracted
# Total time = 0.9737732410430908
#
#
# 648518346342801155: Dendrite-0
# Component found in Orphans
# len of vertices = 55345
# Step 1: extracted Soma Mesh = 0.44809412956237793
# Mesh successfully extracted
# Total time = 1.1830859184265137
#
#
# 648518346342801949: Dendrite-0
# Component found in Orphans
# len of vertices = 188485
# Step 1: extracted Soma Mesh = 1.1038563251495361
# Mesh successfully extracted
# Total time = 2.432209014892578
#
#
# 648518346342802113: Dendrite-0
# Component found in Orphans
# len of vertices = 56337
# Step 1: extracted Soma Mesh = 0.421278715133667
# Mesh successfully extracted
# Total time = 0.943706750869751
#
#
# 648518346342802390: Dendrite-0
# Component found in Orphans
# len of vertices = 82324
# Step 1: extracted Soma Mesh = 0.62925124168396
# Mesh successfully extracted
# Total time = 1.4471192359924316
#
#
# 648518346342802989: Dendrite-0
# Component found in Orphans
# len of vertices = 77946
# Step 1: extracted Soma Mesh = 0.6141567230224609
# Mesh successfully extracted
# Total time = 1.3525094985961914
#
#
# 648518346342803020: Dendrite-0
# Component found in Orphans
# len of vertices = 86140
# Step 1: extracted Soma Mesh = 0.6878480911254883
# Mesh successfully extracted
# Total time = 1.4295673370361328
#
#
# 648518346342803184: Dendrite-0
# Component found in Orphans
# len of vertices = 70022
# Step 1: extracted Soma Mesh = 0.5445270538330078
# Mesh successfully extracted
# Total time = 1.2659902572631836
#
#
# 648518346342803480: Dendrite-0
# Component found in Orphans
# len of vertices = 82627
# Step 1: extracted Soma Mesh = 0.6858773231506348
# Mesh successfully extracted
# Total time = 1.5288350582122803
#
#
# 648518346342803569: Dendrite-0
# Component found in Orphans
# len of vertices = 16185
# Step 1: extracted Soma Mesh = 0.17917180061340332
# Mesh successfully extracted
# Total time = 0.39415693283081055
#
#
# 648518346342804152: Dendrite-0
# Component found in Orphans
# len of vertices = 24821
# Step 1: extracted Soma Mesh = 0.13605928421020508
# Mesh successfully extracted
# Total time = 0.5247805118560791
#
#
# 648518346342804194: Dendrite-0
# Component found in Orphans
# len of vertices = 32215
# Step 1: extracted Soma Mesh = 0.22707128524780273
# Mesh successfully extracted
# Total time = 0.6063923835754395
#
#
# 648518346342804520: Dendrite-0
# Component found in Orphans
# len of vertices = 43092
# Step 1: extracted Soma Mesh = 0.30188655853271484
# Mesh successfully extracted
# Total time = 0.7297158241271973
#
#
# 648518346342805498: Dendrite-0
# Component found in Orphans
# len of vertices = 38114
# Step 1: extracted Soma Mesh = 0.24682140350341797
# Mesh successfully extracted
# Total time = 0.6925990581512451
#
#
# 648518346342805599: Dendrite-0
# Component found in Orphans
# len of vertices = 103249
# Step 1: extracted Soma Mesh = 0.5315866470336914
# Mesh successfully extracted
# Total time = 1.3487071990966797
#
#
# 648518346342805754: Dendrite-0
# Component found in Orphans
# len of vertices = 48594
# Step 1: extracted Soma Mesh = 0.2977428436279297
# Mesh successfully extracted
# Total time = 0.7332649230957031
#
#
# 648518346342805834: Dendrite-0
# Component found in Orphans
# len of vertices = 28762
# Step 1: extracted Soma Mesh = 0.25524091720581055
# Mesh successfully extracted
# Total time = 0.6189453601837158
#
#
# 648518346342805978: Dendrite-0
# Component found in Orphans
# len of vertices = 191919
# Step 1: extracted Soma Mesh = 1.0614206790924072
# Mesh successfully extracted
# Total time = 2.538747549057007
#
#
# 648518346342806313: Dendrite-0
# Component found in Orphans
# len of vertices = 139987
# Step 1: extracted Soma Mesh = 0.8755686283111572
# Mesh successfully extracted
# Total time = 1.9619150161743164
#
#
# 648518346342806333: Dendrite-0
# ...
# Mesh successfully extracted
# Total time = 2.366842269897461
#
#
# 648518346349506748: Basal-0
# Component found in Exhitatory
# len of vertices = 41982
# Step 1: extracted Soma Mesh = 0.3515360355377197
# Mesh successfully extracted
# Total time = 1.346611738204956
#
#
# 648518346349506748: Basal-1
# Component found in Exhitatory
# len of vertices = 109366
# Step 1: extracted Soma Mesh = 0.649895429611206
# Mesh successfully extracted
# Total time = 1.8979778289794922
#
#
# 648518346349506770: Apical-0
# Component found in Exhitatory
# len of vertices = 88316
# Step 1: extracted Soma Mesh = 0.7969808578491211
# Mesh successfully extracted
# Total time = 3.9188175201416016
#
#
# 648518346349506770: Basal-0
# Component found in Exhitatory
# len of vertices = 273879
# Step 1: extracted Soma Mesh = 1.6855123043060303
# Mesh successfully extracted
# Total time = 5.566802024841309
#
#
# 648518346349506770: Basal-2
# Component found in Exhitatory
# len of vertices = 167378
# Step 1: extracted Soma Mesh = 1.358520269393921
# Mesh successfully extracted
# Total time = 5.352473735809326
#
#
# 648518346349506770: Basal-3
# Component found in Exhitatory
# len of vertices = 126519
# Step 1: extracted Soma Mesh = 1.1291077136993408
# Mesh successfully extracted
# Total time = 5.052679061889648
#
#
# 648518346349506770: Oblique-0
# Component found in Exhitatory
# len of vertices = 47048
# Step 1: extracted Soma Mesh = 0.5370190143585205
# Mesh successfully extracted
# Total time = 3.8031413555145264
#
#
# 648518346349506778: Basal-0
# Component found in Exhitatory
# len of vertices = 64864
# Step 1: extracted Soma Mesh = 0.38959360122680664
# Mesh successfully extracted
# Total time = 1.9035677909851074
#
#
# 648518346349506778: Basal-2
# Component found in Exhitatory
# len of vertices = 73304
# Step 1: extracted Soma Mesh = 0.45272302627563477
# Mesh successfully extracted
# Total time = 2.022448778152466
#
#
# 648518346349506778: Oblique-0
# Component found in Exhitatory
# len of vertices = 99125
# Step 1: extracted Soma Mesh = 0.5880839824676514
# Mesh successfully extracted
# Total time = 2.1308889389038086
#
#
# 648518346349506803: Basal-0
# Component found in Exhitatory
# len of vertices = 82994
# Step 1: extracted Soma Mesh = 0.49522948265075684
# Mesh successfully extracted
# Total time = 2.1062235832214355
#
#
# 648518346349506803: Basal-1
# Component found in Exhitatory
# len of vertices = 39882
# Step 1: extracted Soma Mesh = 0.29219603538513184
# Mesh successfully extracted
# Total time = 1.8780202865600586
#
#
# 648518346349506803: Basal-4
# Component found in Exhitatory
# len of vertices = 20827
# Step 1: extracted Soma Mesh = 0.28937411308288574
# Mesh successfully extracted
# Total time = 1.800382137298584
#
#
# 648518346349506803: Basal-5
# Component found in Exhitatory
# len of vertices = 96332
# Step 1: extracted Soma Mesh = 0.5832037925720215
# Mesh successfully extracted
# Total time = 2.4235851764678955
#
#
# 648518346349506808: Basal-0
# Component found in Exhitatory
# len of vertices = 15265
# Step 1: extracted Soma Mesh = 0.1490495204925537
# Mesh successfully extracted
# Total time = 0.36420488357543945
#
#
# 648518346349506944: Basal-0
# Component found in Exhitatory
# len of vertices = 16728
# Step 1: extracted Soma Mesh = 0.14310860633850098
# Mesh successfully extracted
# Total time = 0.9708695411682129
#
#
# 648518346349506944: Basal-1
# Component found in Exhitatory
# len of vertices = 122308
# Step 1: extracted Soma Mesh = 0.6417782306671143
# Mesh successfully extracted
# Total time = 1.9696009159088135
#
#
# 648518346349506944: Basal-2
# Component found in Exhitatory
# len of vertices = 59815
# Step 1: extracted Soma Mesh = 0.36419057846069336
# Mesh successfully extracted
# Total time = 1.5446577072143555
#
#
# 648518346349507015: Apical-0
# Component found in Exhitatory
# len of vertices = 113625
# Step 1: extracted Soma Mesh = 0.7802612781524658
# Mesh successfully extracted
# Total time = 2.7283880710601807
#
#
# 648518346349507015: Basal-1
# Component found in Exhitatory
# len of vertices = 53194
# Step 1: extracted Soma Mesh = 0.3978145122528076
# Mesh successfully extracted
# Total time = 2.0202412605285645
#
#
# 648518346349507015: Basal-3
# Component found in Exhitatory
# len of vertices = 68045
# Step 1: extracted Soma Mesh = 0.533362627029419
# Mesh successfully extracted
# Total time = 2.341447114944458
#
#
# 648518346349507015: Oblique-0
# Component found in Exhitatory
# len of vertices = 39331
# Step 1: extracted Soma Mesh = 0.30852246284484863
# Mesh successfully extracted
# Total time = 1.927518367767334
#
#
# 648518346349507015: Oblique-1
# Component found in Exhitatory
# len of vertices = 38147
# Step 1: extracted Soma Mesh = 0.31185269355773926
# Mesh successfully extracted
# Total time = 1.8978569507598877
#
#
# 648518346349507015: Oblique-2
# Component found in Exhitatory
# len of vertices = 35658
# Step 1: extracted Soma Mesh = 0.28574633598327637
# Mesh successfully extracted
# Total time = 1.848841667175293
#
#
# 648518346349507015: Oblique-3
# Component found in Exhitatory
# len of vertices = 22604
# Step 1: extracted Soma Mesh = 0.2894401550292969
# Mesh successfully extracted
# Total time = 1.9655735492706299
#
#
# 648518346349507087: Apical-0
# Component found in Exhitatory
# len of vertices = 75776
# Step 1: extracted Soma Mesh = 0.5296380519866943
# Mesh successfully extracted
# Total time = 2.5255346298217773
#
#
# 648518346349507087: Basal-0
# Component found in Exhitatory
# len of vertices = 217804
# Step 1: extracted Soma Mesh = 1.2106709480285645
# Mesh successfully extracted
# Total time = 3.7401163578033447
#
#
# 648518346349507087: Oblique-0
# Component found in Exhitatory
# len of vertices = 82962
# Step 1: extracted Soma Mesh = 0.5537827014923096
# Mesh successfully extracted
# Total time = 2.784698486328125
#
#
# 648518346349507087: Oblique-1
# Component found in Exhitatory
# len of vertices = 14617
# Step 1: extracted Soma Mesh = 0.30441761016845703
# Mesh successfully extracted
# Total time = 1.9914271831512451
#
#
# 648518346349507092: Apical-0
# Component found in Exhitatory
# len of vertices = 103603
# Step 1: extracted Soma Mesh = 0.5607285499572754
# Mesh successfully extracted
# Total time = 2.0387327671051025
#
#
# 648518346349507092: Basal-4
# Component found in Exhitatory
# len of vertices = 17234
# Step 1: extracted Soma Mesh = 0.2200181484222412
# Mesh successfully extracted
# Total time = 1.3501935005187988
#
#
# 648518346349507092: Oblique-0
# Component found in Exhitatory
# len of vertices = 60862
# Step 1: extracted Soma Mesh = 0.3832662105560303
# Mesh successfully extracted
# Total time = 1.6116347312927246
#
#
# 648518346349507092: Oblique-2
# Component found in Exhitatory
# len of vertices = 29225
# Step 1: extracted Soma Mesh = 0.24940061569213867
# Mesh successfully extracted
# Total time = 1.5327911376953125
#
#
# 648518346349507103: Apical-0
# Component found in Exhitatory
# len of vertices = 96662
# Step 1: extracted Soma Mesh = 0.7267825603485107
# Mesh successfully extracted
# Total time = 4.010328769683838
#
#
# 648518346349507103: Basal-0
# Component found in Exhitatory
# len of vertices = 103012
# Step 1: extracted Soma Mesh = 0.7050621509552002
# Mesh successfully extracted
# Total time = 3.5382041931152344
#
#
# 648518346349507103: Basal-2
# Component found in Exhitatory
# len of vertices = 21866
# Step 1: extracted Soma Mesh = 0.3805208206176758
# Mesh successfully extracted
# Total time = 2.9746034145355225
#
#
# 648518346349507103: Basal-3
# Component found in Exhitatory
# len of vertices = 80321
# Step 1: extracted Soma Mesh = 0.5834617614746094
# Mesh successfully extracted
# Total time = 3.8085598945617676
#
#
# 648518346349507103: Basal-4
# Component found in Exhitatory
# len of vertices = 165053
# Step 1: extracted Soma Mesh = 1.0360169410705566
# Mesh successfully extracted
# Total time = 4.533213376998901
#
#
# 648518346349507103: Oblique-0
# Component found in Exhitatory
# len of vertices = 16149
# Step 1: extracted Soma Mesh = 0.3737213611602783
# Mesh successfully extracted
# Total time = 3.153848886489868
#
#
# 648518346349507103: Oblique-1
# Component found in Exhitatory
# len of vertices = 11524
# Step 1: extracted Soma Mesh = 0.33849048614501953
# Mesh successfully extracted
# Total time = 2.910975456237793
#
#
# 648518346349507103: Oblique-2
# Component found in Exhitatory
# len of vertices = 13221
# Step 1: extracted Soma Mesh = 0.3033263683319092
# Mesh successfully extracted
# Total time = 3.0690014362335205
#
#
# 648518346349507103: Oblique-3
# Component found in Exhitatory
# len of vertices = 10057
# Step 1: extracted Soma Mesh = 0.3270251750946045
# Mesh successfully extracted
# Total time = 2.8721566200256348
#
#
# 648518346349507103: Oblique-4
# Component found in Exhitatory
# len of vertices = 12354
# Step 1: extracted Soma Mesh = 0.34865689277648926
# Mesh successfully extracted
# Total time = 2.881361722946167
#
#
# 648518346349507226: Apical-0
# Component found in Exhitatory
# len of vertices = 75423
# Step 1: extracted Soma Mesh = 0.6588060855865479
# Mesh successfully extracted
# Total time = 2.3701767921447754
#
#
# 648518346349507226: Basal-0
# Component found in Exhitatory
# len of vertices = 143171
# Step 1: extracted Soma Mesh = 0.8765711784362793
# Mesh successfully extracted
# Total time = 2.9252021312713623
#
#
# 648518346349507226: Basal-2
# Component found in Exhitatory
# len of vertices = 35156
# Step 1: extracted Soma Mesh = 0.4175596237182617
# Mesh successfully extracted
# Total time = 2.0685181617736816
#
#
# 648518346349507226: Oblique-0
# Component found in Exhitatory
# len of vertices = 13197
# Step 1: extracted Soma Mesh = 0.2561342716217041
# Mesh successfully extracted
# Total time = 1.6731345653533936
#
#
# 648518346349507226: Oblique-1
# Component found in Exhitatory
# len of vertices = 17731
# Step 1: extracted Soma Mesh = 0.33515429496765137
# Mesh successfully extracted
# Total time = 1.9096202850341797
#
#
# 648518346349507226: Oblique-2
# Component found in Exhitatory
# len of vertices = 55834
# Step 1: extracted Soma Mesh = 0.526787281036377
# Mesh successfully extracted
# Total time = 2.2477617263793945
#
#
# 648518346349507226: Oblique-4
# Component found in Exhitatory
# len of vertices = 32119
# Step 1: extracted Soma Mesh = 0.4190223217010498
# Mesh successfully extracted
# Total time = 2.1178033351898193
#
#
# 648518346349507351: Apical-0
# Component found in Exhitatory
# len of vertices = 76577
# Step 1: extracted Soma Mesh = 0.7371432781219482
# Mesh successfully extracted
# Total time = 2.1898419857025146
#
#
# 648518346349507351: Basal-0
# Component found in Exhitatory
# len of vertices = 76414
# Step 1: extracted Soma Mesh = 0.6473314762115479
# Mesh successfully extracted
# Total time = 2.2386648654937744
#
#
# 648518346349507351: Basal-4
# Component found in Exhitatory
# len of vertices = 48674
# Step 1: extracted Soma Mesh = 0.4657783508300781
# Mesh successfully extracted
# Total time = 2.0409703254699707
#
#
# 648518346349507351: Oblique-0
# Component found in Exhitatory
# len of vertices = 37012
# Step 1: extracted Soma Mesh = 0.4162251949310303
# Mesh successfully extracted
# Total time = 1.8793647289276123
#
#
# 648518346349507351: Oblique-1
# Component found in Exhitatory
# len of vertices = 17586
# Step 1: extracted Soma Mesh = 0.28962087631225586
# Mesh successfully extracted
# Total time = 1.6466972827911377
#
#
# 648518346349507351: Oblique-2
# Component found in Exhitatory
# len of vertices = 26910
# Step 1: extracted Soma Mesh = 0.3320474624633789
# Mesh successfully extracted
# Total time = 1.710472583770752
#
#
# 648518346349507355: Apical-0
# Component found in Exhitatory
# len of vertices = 31679
# Step 1: extracted Soma Mesh = 0.5447206497192383
# Mesh successfully extracted
# Total time = 3.3053975105285645
#
#
# 648518346349507355: Basal-0
# Component found in Exhitatory
# len of vertices = 161540
# Step 1: extracted Soma Mesh = 1.240776777267456
# Mesh successfully extracted
# Total time = 4.2466723918914795
#
#
# 648518346349507355: Basal-2
# Component found in Exhitatory
# len of vertices = 94032
# Step 1: extracted Soma Mesh = 0.907952070236206
# Mesh successfully extracted
# Total time = 4.0063862800598145
#
#
# 648518346349507355: Basal-3
# Component found in Exhitatory
# len of vertices = 14273
# Step 1: extracted Soma Mesh = 0.43613529205322266
# Mesh successfully extracted
# Total time = 3.097597122192383
#
#
# 648518346349507355: Basal-4
# Component found in Exhitatory
# len of vertices = 234277
# Step 1: extracted Soma Mesh = 1.5022268295288086
# Mesh successfully extracted
# Total time = 5.044546604156494
#
#
# 648518346349507355: Basal-5
# Component found in Exhitatory
# len of vertices = 26222
# Step 1: extracted Soma Mesh = 0.5249319076538086
# Mesh successfully extracted
# Total time = 3.2490079402923584
#
#
# 648518346349507355: Basal-6
# Component found in Exhitatory
# len of vertices = 64635
# Step 1: extracted Soma Mesh = 0.802515983581543
# Mesh successfully extracted
# Total time = 3.769577980041504
#
#
# 648518346349507355: Oblique-0
# Component found in Exhitatory
# len of vertices = 13960
# Step 1: extracted Soma Mesh = 0.41330671310424805
# Mesh successfully extracted
# Total time = 3.183842182159424
#
#
# 648518346349507537: Apical-0
# Component found in Exhitatory
# len of vertices = 75349
# Step 1: extracted Soma Mesh = 0.6563384532928467
# Mesh successfully extracted
# Total time = 2.4776461124420166
#
#
# 648518346349507537: Basal-0
# Component found in Exhitatory
# len of vertices = 94349
# Step 1: extracted Soma Mesh = 0.7784130573272705
# Mesh successfully extracted
# Total time = 2.628242015838623
#
#
# 648518346349507537: Basal-1
# Component found in Exhitatory
# len of vertices = 19894
# Step 1: extracted Soma Mesh = 0.2994680404663086
# Mesh successfully extracted
# Total time = 1.8325018882751465
#
#
# 648518346349507537: Basal-4
# Component found in Exhitatory
# len of vertices = 40883
# Step 1: extracted Soma Mesh = 0.4496498107910156
# Mesh successfully extracted
# Total time = 2.344808578491211
#
#
# 648518346349507537: Oblique-3
# Component found in Exhitatory
# len of vertices = 61441
# Step 1: extracted Soma Mesh = 0.6133146286010742
# Mesh successfully extracted
# Total time = 2.301168918609619
#
#
# 648518346349507658: Basal-0
# Component found in Exhitatory
# len of vertices = 43276
# Step 1: extracted Soma Mesh = 0.3564474582672119
# Mesh successfully extracted
# Total time = 1.0910611152648926
#
#
# 648518346349507788: Apical-0
# Component found in Exhitatory
# len of vertices = 77756
# Step 1: extracted Soma Mesh = 0.6474151611328125
# Mesh successfully extracted
# Total time = 2.128361463546753
#
#
# 648518346349507788: Basal-0
# Component found in Exhitatory
# len of vertices = 104869
# Step 1: extracted Soma Mesh = 0.8065140247344971
# Mesh successfully extracted
# Total time = 2.298780679702759
#
#
# 648518346349507788: Oblique-0
# Component found in Exhitatory
# len of vertices = 39151
# Step 1: extracted Soma Mesh = 0.38501977920532227
# Mesh successfully extracted
# Total time = 1.8021066188812256
#
#
# 648518346349507963: Apical-0
# Component found in Exhitatory
# len of vertices = 120241
# Step 1: extracted Soma Mesh = 0.9313876628875732
# Mesh successfully extracted
# Total time = 2.6089065074920654
#
#
# 648518346349507963: Basal-0
# Component found in Exhitatory
# len of vertices = 145578
# Step 1: extracted Soma Mesh = 1.1238930225372314
# Mesh successfully extracted
# Total time = 2.855647563934326
#
#
# 648518346349507963: Basal-1
# Component found in Exhitatory
# len of vertices = 28949
# Step 1: extracted Soma Mesh = 0.3268616199493408
# Mesh successfully extracted
# Total time = 1.6801307201385498
#
#
# 648518346349507984: Apical-0
# Component found in Exhitatory
# len of vertices = 73753
# Step 1: extracted Soma Mesh = 0.6854462623596191
# Mesh successfully extracted
# Total time = 2.5214643478393555
#
#
# 648518346349507984: Basal-0
# Component found in Exhitatory
# len of vertices = 111140
# Step 1: extracted Soma Mesh = 0.9301238059997559
# Mesh successfully extracted
# Total time = 2.7503151893615723
#
#
# 648518346349507984: Basal-1
# Component found in Exhitatory
# len of vertices = 28144
# Step 1: extracted Soma Mesh = 0.37343645095825195
# Mesh successfully extracted
# Total time = 2.0293691158294678
#
#
# 648518346349507984: Basal-3
# Component found in Exhitatory
# len of vertices = 60997
# Step 1: extracted Soma Mesh = 0.5960524082183838
# Mesh successfully extracted
# Total time = 2.498507261276245
#
#
# 648518346349507984: Basal-5
# Component found in Exhitatory
# len of vertices = 40288
# Step 1: extracted Soma Mesh = 0.435070276260376
# Mesh successfully extracted
# Total time = 2.2583372592926025
#
#
# 648518346349507984: Oblique-0
# Component found in Exhitatory
# len of vertices = 67825
# Step 1: extracted Soma Mesh = 0.5857217311859131
# Mesh successfully extracted
# Total time = 2.4113447666168213
# Total time = 4265.393620967865

# %%
# key=dict(segmentation=2,segment_id=648518346341401733,decimation=0.35,
#         compartment_type="Dendrite",component_index=2)
# print(str(key["segment_id"])+ ":")
# global_start_time = time.time()
# #create return key
# return_key = key.copy()

# #*****pull down the skeleton for the mesh (should be from highly discretized list****
# skeleton_data = (ta3p100.FilteredSkeleton() & key).fetch(as_dict=True)[0]



# #get the vertices and triangles for the Dendrite
# start_time = time.time()
# vertices_whole, triangles_whole = get_component_mesh(key)
# print("len of vertices = " + str(len(vertices_whole)))
# print(f"Step 1: extracted Soma Mesh = {time.time()-start_time}")

# discrete_threshold=10

# #if no soma portion was found then just write regular skeleton
# if not vertices_whole.any():

#     print("ERROR NO COMPONENT MESH FOUND")
    
#     distances=[-1,-1,-1]
#     new_key = dict(segmentation=key["segmentation"],
#                segment_id=key["segment_id"],
#                spine_filter_length = skeleton_data["spine_filter_length"],
#                discrete_length = discrete_threshold,
#                compartment_type = key["compartment_type"],
#                component_index = key["component_index"],
#                 min_width_perc_50 = np.percentile(distances, 50),
#                 min_width_perc_55 = np.percentile(distances, 55),
#                 min_width_perc_60 = np.percentile(distances, 60),
#                 min_width_perc_65 = np.percentile(distances, 65),
#                 min_width_perc_70 = np.percentile(distances, 70),
#                 min_width_perc_75 = np.percentile(distances, 75),
#                 min_width_perc_80 = np.percentile(distances, 80),
#                 min_width_perc_85 = np.percentile(distances, 85),
#                 min_width_perc_90 = np.percentile(distances, 90),
#                 min_width_perc_95 = np.percentile(distances, 95),
#                 min_width_max = np.max(distances)
#               )

#     #return

# else:
    
#     print("mesh was extracted properly")
#     #get the discretized skeleton
#     new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]

#     #calculate the bounding box by hand
#     min_bb_bac = (min(new_skeleton.reshape(-1,1,3)[:,:,0])[0], 
#          min(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
#          min(new_skeleton.reshape(-1,1,3)[:,:,2])[0])

#     max_bb_bac = (max(new_skeleton.reshape(-1,1,3)[:,:,0])[0],
#         max(new_skeleton.reshape(-1,1,3)[:,:,1])[0],
#         max(new_skeleton.reshape(-1,1,3)[:,:,2])[0])
    
#     mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
#     min_bb = np.array(mesh.bounding_box.vertices).min(0)
#     max_bb = np.array(mesh.bounding_box.vertices).max(0)
        

#     #filter all of the skeleton points away that are outside of the bounding box of the compartment
#     filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
#     #filtered_edges_postsyn_2 = filter_edges_by_labels(filtered_edges_postsyn,)
    


#     # #do KDTree on the midpoints of the new edges to find which ones to keep
#     kdtree = KDTree(vertices_whole)

#     distances, nearest_nodes = kdtree.query(filtered_edges_postsyn.reshape(-1,3))
    
#     #what is stored in the key

#     print("about to write to database")
#     new_key = dict(segmentation=key["segmentation"],
#                    segment_id=key["segment_id"],
#                    spine_filter_length = skeleton_data["spine_filter_length"],
#                    discrete_length = discrete_threshold,
#                    compartment_type = key["compartment_type"],
#                    component_index = key["component_index"],
#                     min_width_perc_50 = np.percentile(distances, 50),
#                     min_width_perc_55 = np.percentile(distances, 55),
#                     min_width_perc_60 = np.percentile(distances, 60),
#                     min_width_perc_65 = np.percentile(distances, 65),
#                     min_width_perc_70 = np.percentile(distances, 70),
#                     min_width_perc_75 = np.percentile(distances, 75),
#                     min_width_perc_80 = np.percentile(distances, 80),
#                     min_width_perc_85 = np.percentile(distances, 85),
#                     min_width_perc_90 = np.percentile(distances, 90),
#                     min_width_perc_95 = np.percentile(distances, 95),
#                     min_width_max = np.max(distances)
#                   )
    
#     #self.insert1(new_key,skip_duplicates=True,ignore_extra_fields=True)
# Out:
# 648518346341401733:
# Component found in Orphans
# len of vertices = 17595
# Step 1: extracted Soma Mesh = 0.20729851722717285
# mesh was extracted properly
# about to write to database

# %%
# np.savez("filtered_dnedrite_2.npz",filtered_edges_postsyn=filtered_edges_postsyn)

# %%
# new_skeleton = discretize_skeletons([skeleton_data["edges"]],discrete_threshold)[0]
# new_skeleton

# %%
# mesh = trimesh_io.Mesh(vertices=vertices_whole, faces=triangles_whole)
# min_bb = np.array(mesh.bounding_box.vertices).min(0)
# max_bb = np.array(mesh.bounding_box.vertices).max(0)

# filtered_edges_postsyn = filter_edges_by_bounding_box(new_skeleton,max_bb,min_bb)
# filtered_edges_postsyn.any()
# Out:
# True

# %%
# mesh.export("648518346341401733_dendr_2.off","off")
# Out:
# 'OFF\n17595 35077 0\n361216.0000000000 265444.0625000000 5732.0000000000\n361216.0000000000 258811.2031250000 1860.0000000000\n367360.0000000000 301058.5312500000 10249.2656250000\n360448.0000000000 265648.0000000000 2720.0000000000\n360448.0000000000 269167.8750000000 5240.0312500000\n364544.0000000000 272896.0000000000 4060.0000000000\n364544.0000000000 290112.0000000000 7020.0000000000\n364544.0000000000 290208.0000000000 7020.0000000000\n364544.0000000000 296320.1250000000 7820.0000000000\n364544.0000000000 274495.9687500000 3939.9375000000\n366592.0000000000 290816.0000000000 6660.0000000000\n364032.0000000000 288928.0000000000 7380.0000000000\n359424.0000000000 253504.0000000000 1300.0000000000\n365089.0000000000 286855.8750000000 7786.9062500000\n364833.0000000000 268942.8125000000 4916.2968750000\n365601.0000000000 295703.0000000000 8748.3828125000\n365345.0000000000 294417.7500000000 8835.0000000000\n364098.0000000000 284841.2187500000 8175.9687500000\n361538.0000000000 265572.9687500000 5682.5000000000\n361059.0000000000 261570.2812500000 2161.5625000000\n363107.0000000000 272271.7812500000 4191.7812500000\n362884.0000000000 274778.6562500000 4456.8750000000\n364932.0000000000 285239.9687500000 8148.8437500000\n364676.0000000000 272311.8125000000 4280.5937500000\n365700.0000000000 295535.1875000000 8933.8750000000\n364709.0000000000 290660.1250000000 8955.7968750000\n362149.0000000000 269847.6250000000 5132.2500000000\n364197.0000000000 273436.1875000000 4173.8750000000\n365989.0000000000 291645.6250000000 7663.5000000000\n364965.0000000000 285404.0625000000 9076.2968750000\n361158.0000000000 265635.7500000000 1954.7265625000\n362950.0000000000 272204.4062500000 3701.0625000000\n362694.0000000000 274718.6875000000 5611.4375000000\n362694.0000000000 282068.7500000000 6823.1875000000\n360134.0000000000 269645.5312500000 5697.5078125000\n361447.0000000000 265351.3750000000 3503.2500000000\n359143.0000000000 265372.2500000000 3348.2500000000\n369639.0000000000 299491.7500000000 9314.2500000000\n362471.0000000000 280038.9375000000 6152.7187500000\n364519.0000000000 285417.1250000000 7326.5000000000\n361959.0000000000 261978.9062500000 2078.7187500000\n366856.0000000000 291181.0625000000 7912.3125000000\n360456.0000000000 269202.7500000000 5147.1250000000\n360968.0000000000 266336.7500000000 3766.2500000000\n361513.0000000000 258798.8593750000 1795.1093750000\n367145.0000000000 297675.8125000000 10263.3125000000\n361067.0000000000 265357.0000000000 3195.0000000000\n360811.0000000000 264928.1250000000 2248.0156250000\n366732.0000000000 295551.8437500000 8295.6875000000\n363916.0000000000 285747.2500000000 7931.0156250000\n361100.0000000000 266176.2500000000 3934.0000000000\n362636.0000000000 270345.3437500000 3771.6875000000\n365741.0000000000 289418.5625000000 6689.7578125000\n363437.0000000000 270462.0625000000 4742.9687500000\n363181.0000000000 293438.9062500000 11102.5986328125\n363470.0000000000 288005.7500000000 8638.5000000000\n365006.0000000000 291328.7187500000 7771.5000000000\n361422.0000000000 259858.2968750000 1908.1250000000\n361711.0000000000 278466.1562500000 5748.7265625000\n361455.0000000000 277340.1250000000 5075.0468750000\n366352.0000000000 293168.7500000000 8100.4716796875\n366352.0000000000 297087.9687500000 8237.9531250000\n364048.0000000000 287065.4375000000 7619.1093750000\n363536.0000000000 277598.4687500000 5801.9047851562\n361232.0000000000 271292.6875000000 3632.5000000000\n363024.0000000000 280480.0000000000 5120.0000000000\n367120.0000000000 298096.7500000000 10628.0000000000\n364560.0000000000 282486.9687500000 6705.7421875000\n362834.0000000000 271981.1250000000 3630.3750000000\n364882.0000000000 287439.0937500000 9158.7734375000\n364114.0000000000 290623.0312500000 10158.6699218750\n363635.0000000000 289130.8125000000 7197.7968750000\n359283.0000000000 256945.3125000000 1517.6250000000\n360819.0000000000 268573.7812500000 4739.0000000000\n361876.0000000000 261650.2187500000 2046.1250000000\ ...

# %%
# vertices_whole, triangles_whole

# %%
# import seaborn as sns;sns.set();
# sns.distplot(distances)
